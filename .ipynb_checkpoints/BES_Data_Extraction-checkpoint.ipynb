# %% [raw]
# Things to do
# (1) Replicate this graph: http://blogs.lse.ac.uk/politicsandpolicy/files/2016/07/figure3-1.png DONE-ish
# (2) Then this one: http://blogs.lse.ac.uk/politicsandpolicy/files/2016/07/figure2-1.png (Kaufmann says this is just regression analysis)
# (3) Missing values? Set everything that is a missing value (and maybe "don't knows"?) to np.nan and have a quick look at what the distribution of % is for all variables
# (4) Principal Component analysis - would love to see what the two major axes in the dataset are
# (5) One Hot Encoding - for the categorical data - this sidestep assumptions about categories being ordered and linearly increasing

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# https://www.dataquest.io/mission/74/getting-started-with-kaggle/
# Getting Started With Kaggle
BES = pd.read_stata("../BES_analysis_data/BES2015_W8_v1.3.dta")
# print(BES.describe())

# %%
BES3 = pd.read_stata("../BES_analysis_data/BES2015_W3_Panel_v1.2.dta")
# print(BES3.describe())

# %%
euRefcols = [s for s in list(BES3.columns) if "gross" in s]
euRefcols
# Out:
# ['profile_gross_household', 'profile_gross_personal']

# %%
BES3[euRefcols].count()



# profile_gross_household    36525
# profile_gross_personal     36533
# not many missing values (household 18, perasonal 10)
# profile_gross_personal: codes 14 and 15 are "Prefer not to answer" and "Don't know" 
# profile_gross_household: codes 15 and 16 are "Prefer not to anwer" and "Don't know"
# household 7280, 2535
# personal  6986, 1517
# -> use personal
# How to divide up?
# Out:
# profile_gross_household    36525
# profile_gross_personal     36533
# dtype: int64

# %%
BES3[euRefcols]
# Out:
#            profile_gross_household       profile_gross_personal
# 0                       Don't know  £10,000 to £14,999 per year
# 1                       Don't know                   Don't know
# 2      £30,000 to £34,999 per year  £20,000 to £24,999 per year
# 3      £50,000 to £59,999 per year    £5,000 to £9,999 per year
# 4      £20,000 to £24,999 per year  £15,000 to £19,999 per year
# 5      £35,000 to £39,999 per year    £5,000 to £9,999 per year
# 6      £35,000 to £39,999 per year  £35,000 to £39,999 per year
# 7      £30,000 to £34,999 per year  £30,000 to £34,999 per year
# 8      £15,000 to £19,999 per year    £5,000 to £9,999 per year
# 9             Prefer not to answer  £20,000 to £24,999 per year
# 10     £30,000 to £34,999 per year  £25,000 to £29,999 per year
# 11           under £5,000 per year        under £5,000 per year
# 12            Prefer not to answer         Prefer not to answer
# 13     £30,000 to £34,999 per year        under £5,000 per year
# 14     £60,000 to £69,999 per year  £20,000 to £24,999 per year
# 15     £35,000 to £39,999 per year  £35,000 to £39,999 per year
# 16     £40,000 to £44,999 per year  £40,000 to £44,999 per year
# 17       £5,000 to £9,999 per year    £5,000 to £9,999 per year
# 18     £45,000 to £49,999 per year  £45,000 to £49,999 per year
# 19     £20,000 to £24,999 per year  £20,000 to £24,999 per year
# 20            Prefer not to answer         Prefer not to answer
# 21     £10,000 to £14,999 per year    £5,000 to £9,999 per year
# 22     £50,000 to £59,999 per year        under £5,000 per year
# 23     £35,000 to £39,999 per year  £10,000 to £14,999 per year
# 24     £45,000 to £49,999 per year  £20,000 to £24,999 per year
# 25     £70,000 to £99,999 per year  £40,000 to £44,999 per year
# 26                      Don't know                   Don't know
# 27            Prefer not to answer         Prefer not to answer
# 28     £10,000 to £14,999 per year  £10,000 to £14,999 per year
# 29       £5,000 to £9,999 per year    £5,000 to £9,999 per year
# ...                            ...                          ...
# 36513                   Don't know        under £5,000 per year
# 36514        under £5,000 per year        under £5,000 per year
# 36515  £20,000 to £24,999 per year        under £5,000 per year
# 36516  £25,000 to £29,999 per year    £5,000 to £9,999 per year
# 36517  £20,000 to £24,999 per year        under £5,000 per year
# 36518  £10,000 to £14,999 per year    £5,000 to £9,999 per year
# 36519  £30,000 to £34,999 per year  £15,000 to £19,999 per year
# 36520            £150,000 and over            £100,000 and over
# 36521  £15,000 to £19,999 per year  £10,000 to £14,999 per year
# 36522  £50,000 to £59,999 per year  £50,000 to £59,999 per year
# 36523  £70,000 to £99,999 per year  £70,000 to £99,999 per year
# 36524         Prefer not to answer        under £5,000 per year
# 36525                   Don't know                   Don't know
# 36526         Prefer not to answer         Prefer not to answer
# 36527                   Don't know        under £5,000 per year
# 36528  £25,000 to £29,999 per year  £15,000 to £19,999 per year
# 36529         Prefer not to answer         Prefer not to answer
# 36530  £25,000 to £29,999 per year  £25,000 to £29,999 per year
# 36531                   Don't know        under £5,000 per year
# 36532  £25,000 to £29,999 per year  £20,000 to £24,999 per year
# 36533         Prefer not to answer         Prefer not to answer
# 36534         Prefer not to answer         Prefer not to answer
# 36535  £25,000 to £29,999 per year  £25,000 to £29,999 per year
# 36536                   Don't know                   Don't know
# 36537  £30,000 to £34,999 per year  £20,000 to £24,999 per year
# 36538         Prefer not to answer  £40,000 to £44,999 per year
# 36539  £30,000 to £34,999 per year  £25,000 to £29,999 per year
# 36540  £20,000 to £24,999 per year  £15,000 to £19,999 per year
# 36541  £10,000 to £14,999 per year  £10,000 to £14,999 per year
# 36542  £25,000 to £29,999 per year         Prefer not to answer
#
# [36543 rows x 2 columns]

# %%
#BES3[euRefcols].apply(lambda x: x.cat.codes)
income = BES3[euRefcols].apply(lambda x: x.cat.codes).profile_gross_personal
income[(income>=0 )& (income <14)].hist(bins=range(0,14))

# N= 28030

print( income[(income>=0 )& (income <14)].quantile([0, .33, .66, 1]) )
#print( income[(income>=0 )& (income <14)].quantile(.5) )
#print( income[(income>=0 )& (income <14)].quantile(.75) )
# Out:
# 0.00     0.0
# 0.33     2.0
# 0.66     5.0
# 1.00    13.0
# Name: profile_gross_personal, dtype: float64

# %%
# Missing value = -1
# Stay in the EU = 0
# Leave the EU = 1
# Would not vote = 2
# Don't know = 3

euRefVote = BES3.euRefVoteW3.cat.codes
euRefVote[euRefVote==-1] = np.nan
euRefVote[euRefVote==2] = np.nan
euRefVote[euRefVote==3] = np.nan
euRefVote
# including missing value in a series transforms it to floats from ints
# Out:
# 0        1.0
# 1        0.0
# 2        0.0
# 3        1.0
# 4        1.0
# 5        NaN
# 6        0.0
# 7        1.0
# 8        1.0
# 9        0.0
# 10       0.0
# 11       0.0
# 12       0.0
# 13       1.0
# 14       0.0
# 15       1.0
# 16       1.0
# 17       0.0
# 18       0.0
# 19       NaN
# 20       0.0
# 21       NaN
# 22       0.0
# 23       1.0
# 24       1.0
# 25       NaN
# 26       NaN
# 27       0.0
# 28       1.0
# 29       0.0
#         ...
# 36513    NaN
# 36514    NaN
# 36515    0.0
# 36516    0.0
# 36517    1.0
# 36518    0.0
# 36519    1.0
# 36520    NaN
# 36521    NaN
# 36522    NaN
# 36523    NaN
# 36524    0.0
# 36525    1.0
# 36526    NaN
# 36527    NaN
# 36528    NaN
# 36529    NaN
# 36530    1.0
# 36531    1.0
# 36532    1.0
# 36533    NaN
# 36534    NaN
# 36535    1.0
# 36536    0.0
# 36537    1.0
# 36538    1.0
# 36539    0.0
# 36540    0.0
# 36541    1.0
# 36542    NaN
# dtype: float64

# %%
death_penalty = BES3.al2.cat.codes
#                  ['Strongly disagree', 'Disagree', 'Neither agree nor disagree', 'Agree', 'Strongly agree', 'Don't know']
# -1 missing value, 0,                    1,          2,                            3,      4,                 5, 
death_penalty[death_penalty==-1] = np.nan
death_penalty[death_penalty==5] = np.nan
death_penalty
# Out:
# 0        2.0
# 1        1.0
# 2        1.0
# 3        2.0
# 4        2.0
# 5        0.0
# 6        2.0
# 7        3.0
# 8        3.0
# 9        0.0
# 10       0.0
# 11       0.0
# 12       2.0
# 13       3.0
# 14       3.0
# 15       4.0
# 16       4.0
# 17       0.0
# 18       0.0
# 19       2.0
# 20       1.0
# 21       2.0
# 22       1.0
# 23       2.0
# 24       NaN
# 25       0.0
# 26       4.0
# 27       0.0
# 28       3.0
# 29       0.0
#         ...
# 36513    1.0
# 36514    0.0
# 36515    1.0
# 36516    3.0
# 36517    4.0
# 36518    0.0
# 36519    3.0
# 36520    3.0
# 36521    4.0
# 36522    0.0
# 36523    0.0
# 36524    0.0
# 36525    4.0
# 36526    3.0
# 36527    2.0
# 36528    4.0
# 36529    0.0
# 36530    3.0
# 36531    1.0
# 36532    3.0
# 36533    2.0
# 36534    3.0
# 36535    4.0
# 36536    0.0
# 36537    3.0
# 36538    4.0
# 36539    3.0
# 36540    1.0
# 36541    4.0
# 36542    4.0
# dtype: float64

# %%
np.correlate(euRefVote,death_penalty)
# Out:
# array([ nan])

# %%
euRefVote.corr(death_penalty)
# Out:
# 0.47621066203915768

# %%
BES3.leftRightW3.cat.codes.hist(bins=12)

# %%
leftRight = BES3.leftRightW3.cat.codes
leftRight[leftRight == -1] = np.nan
leftRight[leftRight == 11] = np.nan

# %%
leftRight.hist()

# %%
euRefVote.corr(leftRight)
# Out:
# 0.43201660014281051

# %%
sum(pd.isnull(BES3.eesEUIntegrationSelfW3))/len(BES3.eesEUIntegrationSelfW3)
# Out:
# 0.61740962701474977

# %%
BES3.eesEUIntegrationSelfW3.cat.categories
# Out:
# Index(['Unification has already gone too far', '1', '2', '3', '4', '5', '6',
#        '7', '8', '9', 'Unification should be pushed further', 'Don't know'],
#       dtype='object')

# %%
EUIntegration = BES3.eesEUIntegrationSelfW3.cat.codes
EUIntegration[EUIntegration==-1] = np.nan
EUIntegration[EUIntegration==11] = np.nan

# %%
euRefVote.corr(EUIntegration)
# Out:
# -0.6934850632862114

# %%
sum(euRefVote[death_penalty==0]==1)/sum(~euRefVote[death_penalty==0].isnull())
# Out:
# 0.1344199088678584

# %%
sum(euRefVote[death_penalty==0]==1)/sum(~euRefVote[death_penalty==0].isnull())
# Out:
# 0.1344199088678584

# %%
dp_by_eu = pd.DataFrame(data=pd.concat([euRefVote,death_penalty],axis=1),copy=True  )   #,columns=["euRefVote","death_penalty"])
dp_by_eu.columns =["euRefVote","death_penalty"]

# %%
dp_by_eu.hist(column="euRefVote",by="death_penalty")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000047D3BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000104EA978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AF7B518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AF9CBE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000000AFCA5F8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000000AFEC748>]], dtype=object)

# %%
dp_by_eu.groupby(['death_penalty'])["euRefVote"].mean()
# Out:
# death_penalty
# 0.0    0.134420
# 1.0    0.286700
# 2.0    0.477306
# 3.0    0.576778
# 4.0    0.741603
# Name: euRefVote, dtype: float64

# %%
# Whites only
# income

# %%
BES3["profile_ethnicity"].value_counts()
WhiteBritish = BES3["profile_ethnicity"]=="White British"

# %%
income = BES3[euRefcols].apply(lambda x: x.cat.codes).profile_gross_personal
income[(income>=0 )& (income <14)].hist(bins=range(0,14))

# N= 28030

print( income[(income>=0 )& (income <14)].quantile([0, .33, .66, 1]) )

income[ ~( (income>=0 )& (income <14) )] = np.nan
def set_income_tertile(inc):
    if inc<0 or inc > 13:
        raise Exception("income out of 0-13 range")
    if inc>=5:
        return 2 # High Income
    elif inc>=2:
        return 1 # Medium Income
    else:
        return 0 # Low Income
plt.figure()
income = income.apply(set_income_tertile)
income.hist()
# Out:
# 0.00     0.0
# 0.33     2.0
# 0.66     5.0
# 1.00    13.0
# Name: profile_gross_personal, dtype: float64

# %%
eu_by_dp_inc = pd.DataFrame(data=pd.concat( [euRefVote,death_penalty,income],axis=1) ,copy=True  )   #,columns=["euRefVote","death_penalty"])
eu_by_dp_inc.columns =["euRefVote","death_penalty","personal gross income"]

# %%
eu_by_dp_inc[WhiteBritish].groupby(['personal gross income','death_penalty'])["euRefVote"].mean()
# Out:
# personal gross income  death_penalty
# 0                      0.0              0.167254
#                        1.0              0.314991
#                        2.0              0.551920
#                        3.0              0.640823
#                        4.0              0.796490
# 1                      0.0              0.150868
#                        1.0              0.301734
#                        2.0              0.493243
#                        3.0              0.601732
#                        4.0              0.756934
# 2                      0.0              0.105559
#                        1.0              0.265458
#                        2.0              0.406190
#                        3.0              0.509564
#                        4.0              0.685889
# Name: euRefVote, dtype: float64

# %%
temp = eu_by_dp_inc[WhiteBritish].groupby( ["personal gross income","death_penalty"] ).mean()
income_labels = ["Low Income", "Medium Income", "High Income"]
for income in range(0,3):
    temp["euRefVote"][income].plot(label=income_labels[income])
plt.legend(loc='best')

# %%
# length 36,543
# number who gave a clear Leave/Remain answer 23,358

# %%
BES.stack().value_counts()
# Out:
# No                                                                                                                        1140558
# Don't know                                                                                                                1059203
# __NA__                                                                                                                     660972
# Agree                                                                                                                      558891
# Yes                                                                                                                        514181
# 1                                                                                                                          321320
# 5                                                                                                                          290551
# Strongly agree                                                                                                             271647
# Disagree                                                                                                                   264865
# Neither agree nor disagree                                                                                                 260570
# Strongly dislike                                                                                                           199084
# 4                                                                                                                          185488
# 2                                                                                                                          182991
# 3                                                                                                                          182770
#                                                                                                                            178904
# 6                                                                                                                          178287
# 7                                                                                                                          146548
# About the same                                                                                                             129192
# Mainly remain                                                                                                              117590
# 8                                                                                                                          114631
# 0                                                                                                                          113259
# 1                                                                                                                          110581
# Strongly disagree                                                                                                          106923
# 2.0                                                                                                                        102986
# Yes, voted                                                                                                                 102982
# Very unlikely                                                                                                               88345
# Fairly evenly divided                                                                                                       73870
# False                                                                                                                       73410
# Staying about the same                                                                                                      65939
# Fairly united                                                                                                               64350
#                                                                                                                            ...
# 2016-06-09 16:27:18.684000                                                                                                      1
# 2016-05-25 06:11:22.727000                                                                                                      1
# 2016-06-26 12:47:12.069000                                                                                                      1
# I dont want europe to break down on tribal lines                                                                                1
# 2016-06-26 16:02:30.383000                                                                                                      1
# 2016-06-10 09:29:53.248000                                                                                                      1
# tERROISM                                                                                                                        1
# 2016-05-12 18:43:22.965000                                                                                                      1
# 1.7447667720793338                                                                                                              1
# 2016-06-20 18:18:39.179000                                                                                                      1
# 2016-06-26 00:14:13.718000                                                                                                      1
# 2016-05-25 12:27:36.742000                                                                                                      1
# 2016-06-07 16:17:49.484000                                                                                                      1
# 2016-05-11 16:18:14.596000                                                                                                      1
# 2016-06-24 21:32:56.279000                                                                                                      1
# The economy, stupid.                                                                                                            1
# 1.6561539253373971                                                                                                              1
# The loss of everything that has been achieved for ordinary working people                                                       1
# If it is broken(breaking) mend it. Don't throw it away unless you are certain you can replace it with something better          1
# 2016-05-10 15:42:31.394000                                                                                                      1
# 2016-05-27 08:57:21.306000                                                                                                      1
# 2016-06-30 15:26:05.019000                                                                                                      1
# 2016-06-27 08:40:56.246000                                                                                                      1
# 2016-06-29 13:54:51.754000                                                                                                      1
# 2016-06-19 11:52:00.110000                                                                                                      1
# 2016-06-27 22:02:06.942000                                                                                                      1
# 1.3467130467413349                                                                                                              1
# 0.17473528187269172                                                                                                             1
# 0.23164217583936472                                                                                                             1
# 2016-05-20 18:42:41.291000                                                                                                      1
# dtype: int64

# %%
BES.dtypes[BES.dtypes=="datetime64[ns]"].index
# Out:
# Index(['respdate', 'starttime', 'endtime', 'respdateW9', 'starttimeW9',
#        'endtimeW9'],
#       dtype='object')

# %%
BES[BES.columns[list(BES.dtypes=="category")]].stack().value_counts()
# Out:
# No                                            1140530
# Don't know                                    1059162
# Agree                                          558891
# Yes                                            514181
# 5                                              290549
# Strongly agree                                 271647
# Disagree                                       264865
# Neither agree nor disagree                     260570
# Strongly dislike                               199084
# 4                                              185468
# 2                                              182971
# 3                                              182759
# 6                                              178283
# 7                                              146539
# About the same                                 129192
# Mainly remain                                  117590
# 8                                              114630
# 1                                              110554
# Strongly disagree                              106923
# Yes, voted                                     102982
# 2.0                                             90022
# Very unlikely                                   88345
# Fairly evenly divided                           73870
# False                                           73410
# 1                                               67365
# Staying about the same                          65939
# Fairly united                                   64350
# Allow many fewer                                60894
# Fairly divided                                  60871
# Conservative                                    60542
#                                                ...
# Botswana                                            1
# Iceland                                             1
# Paraguay                                            1
# Faroe Islands                                       1
# Montenegro                                          1
# Angola                                              1
# Cameroon                                            1
# Macedonia, the former Yugoslav Republic of          1
# Costa Rica                                          1
# Antarctica                                          1
# Sudan                                               1
# Uzbekistan                                          1
# Niger                                               1
# Isle of Man                                         1
# Qatar                                               1
# Georgia                                             1
# Anguilla                                            1
# Uruguay                                             1
# Andorra                                             1
# Equatorial Guinea                                   1
# Mexico                                              1
# Congo, the Democratic Republic of the               1
# Papua New Guinea                                    1
# Haiti                                               1
# Cape Verde                                          1
# Martinique                                          1
# Greenland                                           1
# Syrian Arab Republic                                1
# Slovenia                                            1
# Aruba                                               1
# dtype: int64

# %%
BES[BES.columns[BES.dtypes=="category"]]
# Out:
#         country                       generalElectionVote  \
# 0       England  United Kingdom Independence Party (UKIP)
# 1       England                              Conservative
# 2      Scotland                                     Other
# 3         Wales                                    Labour
# 4       England                              Conservative
# 5       England                              Conservative
# 6       England                              Conservative
# 7      Scotland             Scottish National Party (SNP)
# 8       England  United Kingdom Independence Party (UKIP)
# 9         Wales  United Kingdom Independence Party (UKIP)
# 10      England                                    Labour
# 11      England                              Conservative
# 12      England                              Conservative
# 13      England  United Kingdom Independence Party (UKIP)
# 14      England  United Kingdom Independence Party (UKIP)
# 15     Scotland             Scottish National Party (SNP)
# 16      England                              Conservative
# 17      England                                    Labour
# 18      England  United Kingdom Independence Party (UKIP)
# 19      England                                    Labour
# 20        Wales                              Conservative
# 21     Scotland             Scottish National Party (SNP)
# 22      England                                    Labour
# 23      England                                Don't know
# 24      England                              Conservative
# 25      England                                Don't know
# 26      England                              Conservative
# 27      England                              Conservative
# 28      England                               Green Party
# 29      England                              Conservative
# ...         ...                                       ...
# 31379       NaN                                    Labour
# 31380       NaN                                    Labour
# 31381       NaN                               Green Party
# 31382       NaN                                    Labour
# 31383       NaN                               Green Party
# 31384       NaN  United Kingdom Independence Party (UKIP)
# 31385       NaN                               Green Party
# 31386       NaN                                    Labour
# 31387       NaN                                    Labour
# 31388       NaN                                Don't know
# 31389       NaN                                Don't know
# 31390       NaN                                    Labour
# 31391       NaN                              Conservative
# 31392       NaN                               Green Party
# 31393       NaN                          Liberal Democrat
# 31394       NaN                                    Labour
# 31395       NaN                                    Labour
# 31396       NaN                                Don't know
# 31397       NaN  United Kingdom Independence Party (UKIP)
# 31398       NaN                              Conservative
# 31399       NaN                                Don't know
# 31400       NaN                          I would not vote
# 31401       NaN                                    Labour
# 31402       NaN                                Don't know
# 31403       NaN                          Liberal Democrat
# 31404       NaN                                    Labour
# 31405       NaN                               Plaid Cymru
# 31406       NaN  United Kingdom Independence Party (UKIP)
# 31407       NaN                                    Labour
# 31408       NaN                                    Labour
#
#                           generalElectionVoteW9  \
# 0      United Kingdom Independence Party (UKIP)
# 1                                  Conservative
# 2                                           NaN
# 3                                   Plaid Cymru
# 4                                           NaN
# 5                                  Conservative
# 6                                           NaN
# 7                 Scottish National Party (SNP)
# 8      United Kingdom Independence Party (UKIP)
# 9      United Kingdom Independence Party (UKIP)
# 10                                   Don't know
# 11                                 Conservative
# 12                                 Conservative
# 13     United Kingdom Independence Party (UKIP)
# 14                                 Conservative
# 15                Scottish National Party (SNP)
# 16                                          NaN
# 17                                       Labour
# 18     United Kingdom Independence Party (UKIP)
# 19                                       Labour
# 20                                 Conservative
# 21                Scottish National Party (SNP)
# 22                                       Labour
# 23                                   Don't know
# 24                                   Don't know
# 25                                 Conservative
# 26                                 Conservative
# 27                                   Don't know
# 28                                       Labour
# 29                                 Conservative
# ...                                         ...
# 31379                                    Labour
# 31380                                    Labour
# 31381                          Liberal Democrat
# 31382                                    Labour
# 31383                               Green Party
# 31384  United Kingdom Independence Party (UKIP)
# 31385                               Green Party
# 31386                                Don't know
# 31387                                    Labour
# 31388                              Conservative
# 31389                                Don't know
# 31390                                    Labour
# 31391                              Conservative
# 31392                                Don't know
# 31393                                       NaN
# 31394                                    Labour
# 31395                                Don't know
# 31396                                Don't know
# 31397                                Don't know
# 31398                              Conservative
# 31399             Scottish National Party (SNP)
# 31400                                       NaN
# 31401                                    Labour
# 31402                                Don't know
# 31403                          Liberal Democrat
# 31404                                    Labour
# 31405                              Conservative
# 31406  United Kingdom Independence Party (UKIP)
# 31407                                       NaN
# 31408                                    Labour
#
#                                         partyId  \
# 0                                        Labour
# 1                                  Conservative
# 2                 Scottish National Party (SNP)
# 3                                     No - none
# 4                                  Conservative
# 5                                  Conservative
# 6                                  Conservative
# 7                                     No - none
# 8                                     No - none
# 9                                  Conservative
# 10                                    No - none
# 11                                 Conservative
# 12                                 Conservative
# 13                                 Conservative
# 14     United Kingdom Independence Party (UKIP)
# 15                Scottish National Party (SNP)
# 16                                 Conservative
# 17                                    No - none
# 18                                        Other
# 19                                       Labour
# 20                                 Conservative
# 21                Scottish National Party (SNP)
# 22                                       Labour
# 23                                   Don't know
# 24                                 Conservative
# 25                                 Conservative
# 26                                 Conservative
# 27                                    No - none
# 28                                       Labour
# 29                                 Conservative
# ...                                         ...
# 31379                                 No - none
# 31380                               Green Party
# 31381                                    Labour
# 31382                                    Labour
# 31383                               Green Party
# 31384  United Kingdom Independence Party (UKIP)
# 31385                          Liberal Democrat
# 31386                                 No - none
# 31387                                    Labour
# 31388                              Conservative
# 31389                                    Labour
# 31390                                    Labour
# 31391                              Conservative
# 31392                               Green Party
# 31393                          Liberal Democrat
# 31394                               Green Party
# 31395                                    Labour
# 31396                                    Labour
# 31397                                    Labour
# 31398                              Conservative
# 31399                                Don't know
# 31400                                 No - none
# 31401                                    Labour
# 31402                                Don't know
# 31403                                    Labour
# 31404                                    Labour
# 31405                                 No - none
# 31406                                 No - none
# 31407                                    Labour
# 31408                                    Labour
#
#                                  partyIdSqueeze            partyIdEU  \
# 0                                           NaN         Mainly leave
# 1                                           NaN  Fairly evenly split
# 2                                           NaN  Fairly evenly split
# 3                                        Labour        Mainly remain
# 4                                           NaN  Fairly evenly split
# 5                                           NaN         Mainly leave
# 6                                           NaN  Fairly evenly split
# 7                 Scottish National Party (SNP)        Mainly remain
# 8      United Kingdom Independence Party (UKIP)         Mainly leave
# 9                                           NaN        Mainly remain
# 10                                       Labour           Don't know
# 11                                          NaN           Don't know
# 12                                          NaN  Fairly evenly split
# 13                                          NaN         Mainly leave
# 14                                          NaN         Mainly leave
# 15                                          NaN        Mainly remain
# 16                                          NaN  Fairly evenly split
# 17                                    No - none                  NaN
# 18                                          NaN         Mainly leave
# 19                                          NaN  Fairly evenly split
# 20                                          NaN        Mainly remain
# 21                                          NaN        Mainly remain
# 22                                          NaN        Mainly remain
# 23                                   Don't know                  NaN
# 24                                          NaN  Fairly evenly split
# 25                                          NaN  Fairly evenly split
# 26                                          NaN         Mainly leave
# 27                             Liberal Democrat        Mainly remain
# 28                                          NaN        Mainly remain
# 29                                          NaN         Mainly leave
# ...                                         ...                  ...
# 31379                                    Labour        Mainly remain
# 31380                                       NaN        Mainly remain
# 31381                                       NaN        Mainly remain
# 31382                                       NaN  Fairly evenly split
# 31383                                       NaN        Mainly remain
# 31384                                       NaN         Mainly leave
# 31385                                       NaN        Mainly remain
# 31386                                 No - none                  NaN
# 31387                                       NaN           Don't know
# 31388                                       NaN  Fairly evenly split
# 31389                                       NaN  Fairly evenly split
# 31390                                       NaN        Mainly remain
# 31391                                       NaN        Mainly remain
# 31392                                       NaN        Mainly remain
# 31393                                       NaN        Mainly remain
# 31394                                       NaN        Mainly remain
# 31395                                       NaN  Fairly evenly split
# 31396                                       NaN        Mainly remain
# 31397                                       NaN  Fairly evenly split
# 31398                                       NaN  Fairly evenly split
# 31399                                Don't know                  NaN
# 31400                                    Labour  Fairly evenly split
# 31401                                       NaN        Mainly remain
# 31402                              Conservative  Fairly evenly split
# 31403                                       NaN        Mainly remain
# 31404                                       NaN         Mainly leave
# 31405                                 No - none                  NaN
# 31406  United Kingdom Independence Party (UKIP)         Mainly leave
# 31407                                       NaN           Don't know
# 31408                                       NaN           Don't know
#
#                                       partyIdW9  \
# 0                                        Labour
# 1                                  Conservative
# 2                                           NaN
# 3                                        Labour
# 4                                           NaN
# 5                                  Conservative
# 6                                           NaN
# 7                                     No - none
# 8                                     No - none
# 9                                  Conservative
# 10                                       Labour
# 11                                 Conservative
# 12                                 Conservative
# 13                                 Conservative
# 14                                    No - none
# 15                Scottish National Party (SNP)
# 16                                          NaN
# 17                                    No - none
# 18                                        Other
# 19                                       Labour
# 20                                 Conservative
# 21                Scottish National Party (SNP)
# 22                                       Labour
# 23                             Liberal Democrat
# 24                                 Conservative
# 25                                    No - none
# 26                                 Conservative
# 27                             Liberal Democrat
# 28                                       Labour
# 29                                 Conservative
# ...                                         ...
# 31379                                 No - none
# 31380                               Green Party
# 31381                               Green Party
# 31382                                    Labour
# 31383                               Green Party
# 31384                                 No - none
# 31385                          Liberal Democrat
# 31386                                 No - none
# 31387                                    Labour
# 31388  United Kingdom Independence Party (UKIP)
# 31389                                    Labour
# 31390                                    Labour
# 31391                              Conservative
# 31392                               Green Party
# 31393                                       NaN
# 31394                               Green Party
# 31395                                    Labour
# 31396                                    Labour
# 31397                                    Labour
# 31398                              Conservative
# 31399                                Don't know
# 31400                                       NaN
# 31401                                    Labour
# 31402                                Don't know
# 31403                          Liberal Democrat
# 31404                                    Labour
# 31405                               Plaid Cymru
# 31406                                Don't know
# 31407                                       NaN
# 31408                                    Labour
#
#                                partyIdSqueezeW9     partyIdEUretroW9  \
# 0                                           NaN        Mainly remain
# 1                                           NaN  Fairly evenly split
# 2                                           NaN                  NaN
# 3                                           NaN        Mainly remain
# 4                                           NaN                  NaN
# 5                                           NaN  Fairly evenly split
# 6                                           NaN                  NaN
# 7                 Scottish National Party (SNP)        Mainly remain
# 8      United Kingdom Independence Party (UKIP)         Mainly leave
# 9                                           NaN  Fairly evenly split
# 10                                          NaN         Mainly leave
# 11                                          NaN        Mainly remain
# 12                                          NaN  Fairly evenly split
# 13                                          NaN  Fairly evenly split
# 14                                    No - none                  NaN
# 15                                          NaN        Mainly remain
# 16                                          NaN                  NaN
# 17                                    No - none                  NaN
# 18                                          NaN         Mainly leave
# 19                                          NaN  Fairly evenly split
# 20                                          NaN        Mainly remain
# 21                                          NaN        Mainly remain
# 22                                          NaN  Fairly evenly split
# 23                                          NaN        Mainly remain
# 24                                          NaN  Fairly evenly split
# 25                                 Conservative        Mainly remain
# 26                                          NaN  Fairly evenly split
# 27                                          NaN        Mainly remain
# 28                                          NaN        Mainly remain
# 29                                          NaN         Mainly leave
# ...                                         ...                  ...
# 31379                                    Labour  Fairly evenly split
# 31380                                       NaN           Don't know
# 31381                                       NaN  Fairly evenly split
# 31382                                       NaN  Fairly evenly split
# 31383                                       NaN  Fairly evenly split
# 31384                                 No - none                  NaN
# 31385                                       NaN        Mainly remain
# 31386                                 No - none                  NaN
# 31387                                       NaN        Mainly remain
# 31388                                       NaN         Mainly leave
# 31389                                       NaN         Mainly leave
# 31390                                       NaN  Fairly evenly split
# 31391                                       NaN        Mainly remain
# 31392                                       NaN        Mainly remain
# 31393                                       NaN                  NaN
# 31394                                       NaN        Mainly remain
# 31395                                       NaN  Fairly evenly split
# 31396                                       NaN           Don't know
# 31397                                       NaN        Mainly remain
# 31398                                       NaN  Fairly evenly split
# 31399                                Don't know                  NaN
# 31400                                       NaN                  NaN
# 31401                                       NaN        Mainly remain
# 31402                                Don't know                  NaN
# 31403                                       NaN  Fairly evenly split
# 31404                                       NaN         Mainly leave
# 31405                                       NaN           Don't know
# 31406                                Don't know                  NaN
# 31407                                       NaN                  NaN
# 31408                                       NaN         Mainly leave
#
#       countryOfBirth      ...                     polKnowOsborne  \
# 0            England      ...        Chancellor of the Exchequer
# 1            England      ...        Chancellor of the Exchequer
# 2           Scotland      ...        Chancellor of the Exchequer
# 3              Wales      ...        Chancellor of the Exchequer
# 4            England      ...        Chancellor of the Exchequer
# 5            England      ...        Chancellor of the Exchequer
# 6            England      ...        Chancellor of the Exchequer
# 7           Scotland      ...        Chancellor of the Exchequer
# 8            England      ...        Chancellor of the Exchequer
# 9              Wales      ...        Chancellor of the Exchequer
# 10           England      ...              Deputy Prime Minister
# 11           England      ...        Chancellor of the Exchequer
# 12           England      ...        Chancellor of the Exchequer
# 13           England      ...        Chancellor of the Exchequer
# 14           England      ...        Chancellor of the Exchequer
# 15          Scotland      ...        Chancellor of the Exchequer
# 16           England      ...        Chancellor of the Exchequer
# 17           England      ...        Chancellor of the Exchequer
# 18           England      ...        Chancellor of the Exchequer
# 19           England      ...        Chancellor of the Exchequer
# 20             Wales      ...        Chancellor of the Exchequer
# 21          Scotland      ...        Chancellor of the Exchequer
# 22           England      ...        Chancellor of the Exchequer
# 23           England      ...        Chancellor of the Exchequer
# 24           England      ...        Chancellor of the Exchequer
# 25           England      ...        Chancellor of the Exchequer
# 26           England      ...        Chancellor of the Exchequer
# 27           England      ...        Chancellor of the Exchequer
# 28           England      ...        Chancellor of the Exchequer
# 29           England      ...        Chancellor of the Exchequer
# ...              ...      ...                                ...
# 31379            NaN      ...                                NaN
# 31380            NaN      ...                                NaN
# 31381            NaN      ...                                NaN
# 31382            NaN      ...                                NaN
# 31383            NaN      ...                                NaN
# 31384            NaN      ...                                NaN
# 31385            NaN      ...                                NaN
# 31386            NaN      ...                                NaN
# 31387            NaN      ...                                NaN
# 31388            NaN      ...                                NaN
# 31389            NaN      ...                                NaN
# 31390            NaN      ...                                NaN
# 31391            NaN      ...                                NaN
# 31392            NaN      ...                                NaN
# 31393            NaN      ...                                NaN
# 31394            NaN      ...                                NaN
# 31395            NaN      ...                                NaN
# 31396            NaN      ...                                NaN
# 31397            NaN      ...                                NaN
# 31398            NaN      ...                                NaN
# 31399            NaN      ...                                NaN
# 31400            NaN      ...                                NaN
# 31401            NaN      ...                                NaN
# 31402            NaN      ...                                NaN
# 31403            NaN      ...                                NaN
# 31404            NaN      ...                                NaN
# 31405            NaN      ...                                NaN
# 31406            NaN      ...                                NaN
# 31407            NaN      ...                                NaN
# 31408            NaN      ...                                NaN
#
#            polKnowMay                    polKnowBercow  \
# 0      Home secretary  Speaker of the House of Commons
# 1      Home secretary  Speaker of the House of Commons
# 2      Home secretary  Speaker of the House of Commons
# 3      Home secretary  Speaker of the House of Commons
# 4      Home secretary  Speaker of the House of Commons
# 5      Home secretary  Speaker of the House of Commons
# 6      Home secretary  Speaker of the House of Commons
# 7      Home secretary  Speaker of the House of Commons
# 8      Home secretary  Speaker of the House of Commons
# 9      Home secretary  Speaker of the House of Commons
# 10     Home secretary                       Don't know
# 11     Home secretary  Speaker of the House of Commons
# 12     Home secretary  Speaker of the House of Commons
# 13     Home secretary  Speaker of the House of Commons
# 14     Home secretary  Speaker of the House of Commons
# 15     Home secretary  Speaker of the House of Commons
# 16     Home secretary  Speaker of the House of Commons
# 17     Home secretary  Speaker of the House of Commons
# 18     Home secretary  Speaker of the House of Commons
# 19     Home secretary  Speaker of the House of Commons
# 20     Home secretary  Speaker of the House of Commons
# 21     Home secretary  Speaker of the House of Commons
# 22     Home secretary  Speaker of the House of Commons
# 23     Home secretary  Speaker of the House of Commons
# 24     Home secretary  Speaker of the House of Commons
# 25     Home secretary  Speaker of the House of Commons
# 26     Home secretary  Speaker of the House of Commons
# 27     Home secretary  Speaker of the House of Commons
# 28     Home secretary  Speaker of the House of Commons
# 29     Home secretary  Speaker of the House of Commons
# ...               ...                              ...
# 31379             NaN                              NaN
# 31380             NaN                              NaN
# 31381             NaN                              NaN
# 31382             NaN                              NaN
# 31383             NaN                              NaN
# 31384             NaN                              NaN
# 31385             NaN                              NaN
# 31386             NaN                              NaN
# 31387             NaN                              NaN
# 31388             NaN                              NaN
# 31389             NaN                              NaN
# 31390             NaN                              NaN
# 31391             NaN                              NaN
# 31392             NaN                              NaN
# 31393             NaN                              NaN
# 31394             NaN                              NaN
# 31395             NaN                              NaN
# 31396             NaN                              NaN
# 31397             NaN                              NaN
# 31398             NaN                              NaN
# 31399             NaN                              NaN
# 31400             NaN                              NaN
# 31401             NaN                              NaN
# 31402             NaN                              NaN
# 31403             NaN                              NaN
# 31404             NaN                              NaN
# 31405             NaN                              NaN
# 31406             NaN                              NaN
# 31407             NaN                              NaN
# 31408             NaN                              NaN
#
#                                                subjectHE subjectHECurrent  \
# 0      I never attended higher education (university ...              NaN
# 1                                                    Law              NaN
# 2                                                    NaN              NaN
# 3                                  Economics or business              NaN
# 4                                                  Other              NaN
# 5           Engineering, Mathematics or Natural sciences              NaN
# 6           Engineering, Mathematics or Natural sciences              NaN
# 7           Engineering, Mathematics or Natural sciences              NaN
# 8                                                    NaN              NaN
# 9                                                    NaN              NaN
# 10                                                   NaN              NaN
# 11                                                   NaN              NaN
# 12                                                   NaN              NaN
# 13                                                   NaN              NaN
# 14                                                   NaN              NaN
# 15                                 Economics or business              NaN
# 16     Humanities, social sciences, psychology or edu...              NaN
# 17                                              Medicine              NaN
# 18                                                   Law              NaN
# 19     Humanities, social sciences, psychology or edu...              NaN
# 20     Humanities, social sciences, psychology or edu...              NaN
# 21                                                   NaN              NaN
# 22                                                   NaN              NaN
# 23     Humanities, social sciences, psychology or edu...              NaN
# 24     Humanities, social sciences, psychology or edu...              NaN
# 25                                                   NaN              NaN
# 26                                                   Law              NaN
# 27                                                   NaN              NaN
# 28                                                   NaN              NaN
# 29     Humanities, social sciences, psychology or edu...              NaN
# ...                                                  ...              ...
# 31379                                                NaN              NaN
# 31380                                                NaN              NaN
# 31381                                                NaN              NaN
# 31382                                                NaN              NaN
# 31383                                                NaN              NaN
# 31384                                                NaN              NaN
# 31385                                                NaN              NaN
# 31386                                                NaN              NaN
# 31387                                                NaN              NaN
# 31388                                                NaN              NaN
# 31389                                                NaN              NaN
# 31390                                                NaN              NaN
# 31391                                                NaN              NaN
# 31392                                                NaN              NaN
# 31393                                                NaN              NaN
# 31394                                                NaN              NaN
# 31395                                                NaN              NaN
# 31396                                                NaN              NaN
# 31397                                                NaN              NaN
# 31398                                                NaN              NaN
# 31399                                                NaN              NaN
# 31400                                                NaN              NaN
# 31401                                                NaN              NaN
# 31402                                                NaN              NaN
# 31403                                                NaN              NaN
# 31404                                                NaN              NaN
# 31405                                                NaN              NaN
# 31406                                                NaN              NaN
# 31407                                                NaN              NaN
# 31408                                                NaN              NaN
#
#              edlevel profile_turnout_2015  \
# 0                NaN           Yes, voted
# 1      Undergraduate           Yes, voted
# 2          GCSE A*-C           Yes, voted
# 3      Undergraduate           Yes, voted
# 4      Undergraduate           Yes, voted
# 5      Undergraduate           Yes, voted
# 6      Undergraduate           Yes, voted
# 7           Postgrad           Yes, voted
# 8           GCSE D-G           Yes, voted
# 9            A-level           Yes, voted
# 10           A-level           Yes, voted
# 11         GCSE A*-C           Yes, voted
# 12         GCSE A*-C           Yes, voted
# 13         GCSE A*-C           Yes, voted
# 14         GCSE A*-C           Yes, voted
# 15     Undergraduate           Yes, voted
# 16     Undergraduate           Yes, voted
# 17               NaN           Yes, voted
# 18     Undergraduate           Yes, voted
# 19     Undergraduate           Yes, voted
# 20     Undergraduate           Yes, voted
# 21     Undergraduate           Yes, voted
# 22           A-level           Yes, voted
# 23     Undergraduate           Yes, voted
# 24     Undergraduate           Yes, voted
# 25           A-level           Yes, voted
# 26          Postgrad           Yes, voted
# 27         GCSE A*-C           Yes, voted
# 28           A-level           Yes, voted
# 29               NaN           Yes, voted
# ...              ...                  ...
# 31379       Postgrad                  NaN
# 31380        A-level                  NaN
# 31381            NaN                  NaN
# 31382        A-level                  NaN
# 31383  Undergraduate                  NaN
# 31384      GCSE A*-C                  NaN
# 31385       Postgrad                  NaN
# 31386            NaN                  NaN
# 31387  Undergraduate                  NaN
# 31388      GCSE A*-C                  NaN
# 31389       GCSE D-G                  NaN
# 31390  Undergraduate                  NaN
# 31391  Undergraduate                  NaN
# 31392  Undergraduate                  NaN
# 31393        A-level                  NaN
# 31394  Undergraduate                  NaN
# 31395            NaN                  NaN
# 31396  Undergraduate                  NaN
# 31397      GCSE A*-C                  NaN
# 31398      GCSE A*-C                  NaN
# 31399      GCSE A*-C                  NaN
# 31400      GCSE A*-C                  NaN
# 31401  Undergraduate                  NaN
# 31402      GCSE A*-C                  NaN
# 31403        A-level                  NaN
# 31404      GCSE A*-C                  NaN
# 31405            NaN                  NaN
# 31406       Postgrad                  NaN
# 31407  Undergraduate                  NaN
# 31408  Undergraduate                  NaN
#
#                          profile_past_vote_2015 lr_scale       al_scale
# 0                                        Labour      0.5              8
# 1                                  Conservative      7.5              6
# 2                 Scottish National Party (SNP)      0.5  Authoritarian
# 3                                        Labour        3            3.5
# 4                                  Conservative        5  Authoritarian
# 5                                  Conservative        6              6
# 6                                  Conservative      7.5              9
# 7                 Scottish National Party (SNP)     Left            1.5
# 8      United Kingdom Independence Party (UKIP)     Left            NaN
# 9      United Kingdom Independence Party (UKIP)        4              6
# 10                                       Labour        3            7.5
# 11                                 Conservative        9              9
# 12                                 Conservative      2.5            6.5
# 13                                 Conservative      6.5            7.5
# 14                                 Conservative      6.5            8.5
# 15                Scottish National Party (SNP)        3            8.5
# 16                             Liberal Democrat      4.5            6.5
# 17                                   Don't know        6              7
# 18     United Kingdom Independence Party (UKIP)        1            9.5
# 19                                       Labour        3            5.5
# 20                                 Conservative        6            9.5
# 21                Scottish National Party (SNP)     Left            2.5
# 22                                       Labour        1              5
# 23                             Liberal Democrat     Left            7.5
# 24                                 Conservative        6            NaN
# 25                                 Conservative        4            6.5
# 26                                 Conservative        8              6
# 27                                 Conservative      5.5              6
# 28                                       Labour      2.5              5
# 29                                 Conservative      5.5            4.5
# ...                                         ...      ...            ...
# 31379                                       NaN        1            2.5
# 31380                                       NaN        2              2
# 31381                                       NaN        5              5
# 31382                                       NaN      2.5            NaN
# 31383                                       NaN     Left            5.5
# 31384                                       NaN      2.5            8.5
# 31385                                       NaN      2.5              6
# 31386                                       NaN      2.5              6
# 31387                                       NaN      0.5            4.5
# 31388                                       NaN      3.5              8
# 31389                                       NaN      NaN            NaN
# 31390                                       NaN     Left              4
# 31391                                       NaN      3.5            7.5
# 31392                                       NaN     Left              7
# 31393                                       NaN        3            2.5
# 31394                                       NaN      NaN            NaN
# 31395                                       NaN     Left            1.5
# 31396                                       NaN        3            4.5
# 31397                                       NaN      2.5              7
# 31398                                       NaN        5            6.5
# 31399                                       NaN        5              5
# 31400                                       NaN        4  Authoritarian
# 31401                                       NaN      1.5              5
# 31402                                       NaN      3.5              7
# 31403                                       NaN      NaN            NaN
# 31404                                       NaN      NaN            NaN
# 31405                                       NaN     Left            8.5
# 31406                                       NaN        4              5
# 31407                                       NaN        2            5.5
# 31408                                       NaN        4            6.5
#
# [31409 rows x 664 columns]

# %%
BES[BES.columns[BES.dtypes=="category"]].cat.ordered
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-de47b99e0f21> in <module>()
# ----> 1 BES[BES.columns[BES.dtypes=="category"]].cat.ordered
#
# C:\ANACON~1\envs\BES_analysis\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2670             if name in self._info_axis:
#    2671                 return self[name]
# -> 2672             return object.__getattribute__(self, name)
#    2673
#    2674     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cat'

# %%
# I'm a fucking genius
# All category columns changed to their code values
# e.g. Index(['Strongly disagree', 'Disagree', 'Neither agree nor disagree', 'Agree', 'Strongly agree', 'Don't know'],
#      dtype='object')
# becomes [0,1,2,3,4,5,6]
# -1 codes for missing value

BES[BES.columns[BES.dtypes=="category"]] = BES[BES.columns[BES.dtypes=="category"]].apply(lambda x: x.cat.codes)
#df.applymap(lambda x: '%.2f' % x)

# %%
BES.dtypes.value_counts()

# %%
features = list(BES.columns[(BES.dtypes=="int8") | (BES.dtypes=="int16") | (BES.dtypes=="float64") ])

# %%
corrmat = BES[features].corr()

# %%
corrmat["euRefVote"].sort_values()

# %%
BES.dtypes.value_counts()

# %%
BES[1:5][BES.columns[1:20]]

# %%
BES["riskScale"]

# %%
BES.euRefVote.value_counts()

# %%
list(BES.columns)

# %%
BES.al2

# %%
death_by_EU = BES[["euRefVote","al2"]]

# %%
death_by_EU.plot(kind='line')

# %%
death_by_EU.al2[death_by_EU.al2=="Strongly agree"]=5
death_by_EU.al2[death_by_EU.al2=="Agree"]=4
death_by_EU.al2[death_by_EU.al2=="Neither agree nor disagree"]=3
death_by_EU.al2[death_by_EU.al2=="Disagree"]=2
death_by_EU.al2[death_by_EU.al2=="Strongly disagree"]=1
death_by_EU.al2[death_by_EU.al2=="Don't know"]=0

# %%
BES.al2[death_by_EU.al2=="Strongly agree"] = 5
#df.loc[df['A'] > 2, 'B'] = new_val

# %%
BES.al2.value_counts()

# %%
def score_to_numeric(x):
    if x=='Strongly agree':
        return 5
    if x=='Agree':
        return 4
    if x=='Neither agree nor disagree':
        return 3
    if x=='Disagree':
        return 2
    if x=='Strongly disagree':
        return 1
    if x=="Don't know":
        return 0

# %%
BES.al2.apply(score_to_numeric).hist(by=BES.euRefVote,bins=6)

# %%
BES.al2
