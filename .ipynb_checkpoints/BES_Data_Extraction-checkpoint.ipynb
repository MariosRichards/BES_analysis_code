# %%
import pandas as pd
# https://www.dataquest.io/mission/74/getting-started-with-kaggle/
# Getting Started With Kaggle
BES = pd.read_stata("../BES_analysis_data/BES2015_W8_v1.3.dta")
print(BES.describe())
# Out:
#                  id    wt_core_W8    wt_core_W9    wt_full_W8  \
# count  31409.000000  20404.000000  17166.000000  31409.000000
# mean   30915.403897      0.999133      0.997006      0.999607
# std    18166.000537      0.557657      0.627291      0.970221
# min        1.000000      0.094874      0.081213      0.020122
# 25%    14191.000000      0.636279      0.592813      0.430321
# 50%    31750.000000      0.867910      0.853670      0.716418
# 75%    48198.000000      1.267446      1.264708      1.256861
# max    57535.000000     11.041887     12.410820     23.809603
#
#        wt_full_W1W2W3W4W5W6W7    wt_full_W7    wt_full_W9  \
# count            10681.000000  22881.000000  25832.000000
# mean                 1.000804      0.998954      0.994459
# std                  1.800674      0.958344      1.025174
# min                  0.008100      0.025678      0.020288
# 25%                  0.249271      0.435604      0.411350
# 50%                  0.527899      0.729597      0.699581
# 75%                  1.078647      1.241260      1.228953
# max                 50.960657     21.810673     25.406103
#
#        wt_full_W1W2W3W4W5W6W7W8W9  wt_full_W7W8W9         wave9  \
# count                 9529.000000    19604.000000  31409.000000
# mean                     1.000316        0.999308      0.822439
# std                      1.951971        1.007542      0.382148
# min                      0.007010        0.023959      0.000000
# 25%                      0.240667        0.413094      1.000000
# 50%                      0.505599        0.720216      1.000000
# 75%                      1.043672        1.231726      1.000000
# max                     67.127257       21.171578      1.000000
#
#                ...                 w2full        w2core        w1full  \
# count          ...           31409.000000  31409.000000  31409.000000
# mean           ...               0.512783      0.357859      0.480053
# std            ...               0.499845      0.479378      0.499610
# min            ...               0.000000      0.000000      0.000000
# 25%            ...               0.000000      0.000000      0.000000
# 50%            ...               1.000000      0.000000      0.000000
# 75%            ...               1.000000      1.000000      1.000000
# max            ...               1.000000      1.000000      1.000000
#
#              w1core          pano  personality_agreeableness  \
# count  31409.000000  31409.000000               28969.000000
# mean       0.362030    322.973861                   6.091166
# std        0.480595    184.763220                   1.760068
# min        0.000000      1.000000                   0.000000
# 25%        0.000000    163.000000                   5.000000
# 50%        0.000000    321.000000                   6.000000
# 75%        1.000000    480.000000                   7.000000
# max        1.000000    650.000000                  10.000000
#
#        personality_conscientiousness  personality_extraversion  \
# count                   28969.000000              28970.000000
# mean                        6.789741                  4.138695
# std                         1.853964                  2.174740
# min                         0.000000                  0.000000
# 25%                         5.000000                  2.000000
# 50%                         7.000000                  5.000000
# 75%                         8.000000                  5.000000
# max                        10.000000                 10.000000
#
#        personality_neuroticism  personality_openness
# count             28969.000000          28969.000000
# mean                  3.686458              5.551486
# std                   2.177715              1.698781
# min                   0.000000              0.000000
# 25%                   2.000000              5.000000
# 50%                   4.000000              5.000000
# 75%                   5.000000              7.000000
# max                  10.000000             10.000000
#
# [8 rows x 30 columns]

# %%
BES.stack().value_counts()
# Out:
# No                                               1140558
# Don't know                                       1059203
# __NA__                                            660972
# Agree                                             558891
# Yes                                               514181
# 1                                                 321320
# 5                                                 290551
# Strongly agree                                    271647
# Disagree                                          264865
# Neither agree nor disagree                        260570
# Strongly dislike                                  199084
# 4                                                 185488
# 2                                                 182991
# 3                                                 182770
#                                                   178904
# 6                                                 178287
# 7                                                 146548
# About the same                                    129192
# Mainly remain                                     117590
# 8                                                 114631
# 0                                                 113259
# 1                                                 110581
# Strongly disagree                                 106923
# 2.0                                               102986
# Yes, voted                                        102982
# Very unlikely                                      88345
# Fairly evenly divided                              73870
# False                                              73410
# Staying about the same                             65939
# Fairly united                                      64350
#                                                   ...
# Possible recession and crap due to leaving EU          1
# 0.5025204437552235                                     1
# 0.8426628891029998                                     1
# 1.1729487344751663                                     1
# 2016-05-24 12:14:23.804000                             1
# 2016-06-30 08:24:21.225000                             1
# 2016-06-27 18:12:24.905000                             1
# 2016-06-05 21:46:23.440000                             1
# 2016-06-27 08:43:33.981000                             1
# 2016-06-19 14:48:23.560000                             1
# 2016-06-21 13:03:20.386000                             1
# 1.0502164815005866                                     1
# 2016-05-31 12:34:54.121000                             1
# Stopping immigration, permanently!                     1
# 2016-05-29 17:26:01.480000                             1
# the snp                                                1
# 2016-05-12 17:39:06.138000                             1
# Sovereignty, economics.                                1
# 0.7416264339509347                                     1
# 2016-06-29 15:04:02.195000                             1
# 2016-06-29 16:49:07.460000                             1
# I don't have enough information                        1
# 0.670132575534468                                      1
# 2016-05-17 17:37:58.026000                             1
# 2016-06-07 15:17:14.387000                             1
# 0.3941918042488298                                     1
# 2016-06-27 16:38:28.987000                             1
# 2016-06-26 13:09:43.309000                             1
# 2016-06-26 09:42:02.512000                             1
# 2016-06-15 10:29:59.161000                             1
# dtype: int64

# %%
BES.dtypes[BES.dtypes=="datetime64[ns]"].index
# Out:
# Index(['respdate', 'starttime', 'endtime', 'respdateW9', 'starttimeW9',
#        'endtimeW9'],
#       dtype='object')

# %%
BES[BES.columns[list(BES.dtypes=="category")]].stack().value_counts()
# Out:
# No                                            1140530
# Don't know                                    1059162
# Agree                                          558891
# Yes                                            514181
# 5                                              290549
# Strongly agree                                 271647
# Disagree                                       264865
# Neither agree nor disagree                     260570
# Strongly dislike                               199084
# 4                                              185468
# 2                                              182971
# 3                                              182759
# 6                                              178283
# 7                                              146539
# About the same                                 129192
# Mainly remain                                  117590
# 8                                              114630
# 1                                              110554
# Strongly disagree                              106923
# Yes, voted                                     102982
# 2.0                                             90022
# Very unlikely                                   88345
# Fairly evenly divided                           73870
# False                                           73410
# 1                                               67365
# Staying about the same                          65939
# Fairly united                                   64350
# Allow many fewer                                60894
# Fairly divided                                  60871
# Conservative                                    60542
#                                                ...
# Martinique                                          1
# Greenland                                           1
# Uruguay                                             1
# Mexico                                              1
# Georgia                                             1
# Iceland                                             1
# Papua New Guinea                                    1
# Somalia                                             1
# Cameroon                                            1
# Isle of Man                                         1
# Uzbekistan                                          1
# Angola                                              1
# Macedonia, the former Yugoslav Republic of          1
# Sudan                                               1
# Slovenia                                            1
# Jordan                                              1
# Costa Rica                                          1
# Faroe Islands                                       1
# Aruba                                               1
# Saudi Arabia                                        1
# Congo, the Democratic Republic of the               1
# Equatorial Guinea                                   1
# R̩union                                            1
# Cape Verde                                          1
# Cambodia                                            1
# Montenegro                                          1
# Andorra                                             1
# Haiti                                               1
# United Arab Emirates                                1
# Cayman Islands                                      1
# dtype: int64

# %%
BES[BES.columns[BES.dtypes=="category"]]
# Out:
#         country                       generalElectionVote  \
# 0       England  United Kingdom Independence Party (UKIP)
# 1       England                              Conservative
# 2      Scotland                                     Other
# 3         Wales                                    Labour
# 4       England                              Conservative
# 5       England                              Conservative
# 6       England                              Conservative
# 7      Scotland             Scottish National Party (SNP)
# 8       England  United Kingdom Independence Party (UKIP)
# 9         Wales  United Kingdom Independence Party (UKIP)
# 10      England                                    Labour
# 11      England                              Conservative
# 12      England                              Conservative
# 13      England  United Kingdom Independence Party (UKIP)
# 14      England  United Kingdom Independence Party (UKIP)
# 15     Scotland             Scottish National Party (SNP)
# 16      England                              Conservative
# 17      England                                    Labour
# 18      England  United Kingdom Independence Party (UKIP)
# 19      England                                    Labour
# 20        Wales                              Conservative
# 21     Scotland             Scottish National Party (SNP)
# 22      England                                    Labour
# 23      England                                Don't know
# 24      England                              Conservative
# 25      England                                Don't know
# 26      England                              Conservative
# 27      England                              Conservative
# 28      England                               Green Party
# 29      England                              Conservative
# ...         ...                                       ...
# 31379       NaN                                    Labour
# 31380       NaN                                    Labour
# 31381       NaN                               Green Party
# 31382       NaN                                    Labour
# 31383       NaN                               Green Party
# 31384       NaN  United Kingdom Independence Party (UKIP)
# 31385       NaN                               Green Party
# 31386       NaN                                    Labour
# 31387       NaN                                    Labour
# 31388       NaN                                Don't know
# 31389       NaN                                Don't know
# 31390       NaN                                    Labour
# 31391       NaN                              Conservative
# 31392       NaN                               Green Party
# 31393       NaN                          Liberal Democrat
# 31394       NaN                                    Labour
# 31395       NaN                                    Labour
# 31396       NaN                                Don't know
# 31397       NaN  United Kingdom Independence Party (UKIP)
# 31398       NaN                              Conservative
# 31399       NaN                                Don't know
# 31400       NaN                          I would not vote
# 31401       NaN                                    Labour
# 31402       NaN                                Don't know
# 31403       NaN                          Liberal Democrat
# 31404       NaN                                    Labour
# 31405       NaN                               Plaid Cymru
# 31406       NaN  United Kingdom Independence Party (UKIP)
# 31407       NaN                                    Labour
# 31408       NaN                                    Labour
#
#                           generalElectionVoteW9  \
# 0      United Kingdom Independence Party (UKIP)
# 1                                  Conservative
# 2                                           NaN
# 3                                   Plaid Cymru
# 4                                           NaN
# 5                                  Conservative
# 6                                           NaN
# 7                 Scottish National Party (SNP)
# 8      United Kingdom Independence Party (UKIP)
# 9      United Kingdom Independence Party (UKIP)
# 10                                   Don't know
# 11                                 Conservative
# 12                                 Conservative
# 13     United Kingdom Independence Party (UKIP)
# 14                                 Conservative
# 15                Scottish National Party (SNP)
# 16                                          NaN
# 17                                       Labour
# 18     United Kingdom Independence Party (UKIP)
# 19                                       Labour
# 20                                 Conservative
# 21                Scottish National Party (SNP)
# 22                                       Labour
# 23                                   Don't know
# 24                                   Don't know
# 25                                 Conservative
# 26                                 Conservative
# 27                                   Don't know
# 28                                       Labour
# 29                                 Conservative
# ...                                         ...
# 31379                                    Labour
# 31380                                    Labour
# 31381                          Liberal Democrat
# 31382                                    Labour
# 31383                               Green Party
# 31384  United Kingdom Independence Party (UKIP)
# 31385                               Green Party
# 31386                                Don't know
# 31387                                    Labour
# 31388                              Conservative
# 31389                                Don't know
# 31390                                    Labour
# 31391                              Conservative
# 31392                                Don't know
# 31393                                       NaN
# 31394                                    Labour
# 31395                                Don't know
# 31396                                Don't know
# 31397                                Don't know
# 31398                              Conservative
# 31399             Scottish National Party (SNP)
# 31400                                       NaN
# 31401                                    Labour
# 31402                                Don't know
# 31403                          Liberal Democrat
# 31404                                    Labour
# 31405                              Conservative
# 31406  United Kingdom Independence Party (UKIP)
# 31407                                       NaN
# 31408                                    Labour
#
#                                         partyId  \
# 0                                        Labour
# 1                                  Conservative
# 2                 Scottish National Party (SNP)
# 3                                     No - none
# 4                                  Conservative
# 5                                  Conservative
# 6                                  Conservative
# 7                                     No - none
# 8                                     No - none
# 9                                  Conservative
# 10                                    No - none
# 11                                 Conservative
# 12                                 Conservative
# 13                                 Conservative
# 14     United Kingdom Independence Party (UKIP)
# 15                Scottish National Party (SNP)
# 16                                 Conservative
# 17                                    No - none
# 18                                        Other
# 19                                       Labour
# 20                                 Conservative
# 21                Scottish National Party (SNP)
# 22                                       Labour
# 23                                   Don't know
# 24                                 Conservative
# 25                                 Conservative
# 26                                 Conservative
# 27                                    No - none
# 28                                       Labour
# 29                                 Conservative
# ...                                         ...
# 31379                                 No - none
# 31380                               Green Party
# 31381                                    Labour
# 31382                                    Labour
# 31383                               Green Party
# 31384  United Kingdom Independence Party (UKIP)
# 31385                          Liberal Democrat
# 31386                                 No - none
# 31387                                    Labour
# 31388                              Conservative
# 31389                                    Labour
# 31390                                    Labour
# 31391                              Conservative
# 31392                               Green Party
# 31393                          Liberal Democrat
# 31394                               Green Party
# 31395                                    Labour
# 31396                                    Labour
# 31397                                    Labour
# 31398                              Conservative
# 31399                                Don't know
# 31400                                 No - none
# 31401                                    Labour
# 31402                                Don't know
# 31403                                    Labour
# 31404                                    Labour
# 31405                                 No - none
# 31406                                 No - none
# 31407                                    Labour
# 31408                                    Labour
#
#                                  partyIdSqueeze            partyIdEU  \
# 0                                           NaN         Mainly leave
# 1                                           NaN  Fairly evenly split
# 2                                           NaN  Fairly evenly split
# 3                                        Labour        Mainly remain
# 4                                           NaN  Fairly evenly split
# 5                                           NaN         Mainly leave
# 6                                           NaN  Fairly evenly split
# 7                 Scottish National Party (SNP)        Mainly remain
# 8      United Kingdom Independence Party (UKIP)         Mainly leave
# 9                                           NaN        Mainly remain
# 10                                       Labour           Don't know
# 11                                          NaN           Don't know
# 12                                          NaN  Fairly evenly split
# 13                                          NaN         Mainly leave
# 14                                          NaN         Mainly leave
# 15                                          NaN        Mainly remain
# 16                                          NaN  Fairly evenly split
# 17                                    No - none                  NaN
# 18                                          NaN         Mainly leave
# 19                                          NaN  Fairly evenly split
# 20                                          NaN        Mainly remain
# 21                                          NaN        Mainly remain
# 22                                          NaN        Mainly remain
# 23                                   Don't know                  NaN
# 24                                          NaN  Fairly evenly split
# 25                                          NaN  Fairly evenly split
# 26                                          NaN         Mainly leave
# 27                             Liberal Democrat        Mainly remain
# 28                                          NaN        Mainly remain
# 29                                          NaN         Mainly leave
# ...                                         ...                  ...
# 31379                                    Labour        Mainly remain
# 31380                                       NaN        Mainly remain
# 31381                                       NaN        Mainly remain
# 31382                                       NaN  Fairly evenly split
# 31383                                       NaN        Mainly remain
# 31384                                       NaN         Mainly leave
# 31385                                       NaN        Mainly remain
# 31386                                 No - none                  NaN
# 31387                                       NaN           Don't know
# 31388                                       NaN  Fairly evenly split
# 31389                                       NaN  Fairly evenly split
# 31390                                       NaN        Mainly remain
# 31391                                       NaN        Mainly remain
# 31392                                       NaN        Mainly remain
# 31393                                       NaN        Mainly remain
# 31394                                       NaN        Mainly remain
# 31395                                       NaN  Fairly evenly split
# 31396                                       NaN        Mainly remain
# 31397                                       NaN  Fairly evenly split
# 31398                                       NaN  Fairly evenly split
# 31399                                Don't know                  NaN
# 31400                                    Labour  Fairly evenly split
# 31401                                       NaN        Mainly remain
# 31402                              Conservative  Fairly evenly split
# 31403                                       NaN        Mainly remain
# 31404                                       NaN         Mainly leave
# 31405                                 No - none                  NaN
# 31406  United Kingdom Independence Party (UKIP)         Mainly leave
# 31407                                       NaN           Don't know
# 31408                                       NaN           Don't know
#
#                                       partyIdW9  \
# 0                                        Labour
# 1                                  Conservative
# 2                                           NaN
# 3                                        Labour
# 4                                           NaN
# 5                                  Conservative
# 6                                           NaN
# 7                                     No - none
# 8                                     No - none
# 9                                  Conservative
# 10                                       Labour
# 11                                 Conservative
# 12                                 Conservative
# 13                                 Conservative
# 14                                    No - none
# 15                Scottish National Party (SNP)
# 16                                          NaN
# 17                                    No - none
# 18                                        Other
# 19                                       Labour
# 20                                 Conservative
# 21                Scottish National Party (SNP)
# 22                                       Labour
# 23                             Liberal Democrat
# 24                                 Conservative
# 25                                    No - none
# 26                                 Conservative
# 27                             Liberal Democrat
# 28                                       Labour
# 29                                 Conservative
# ...                                         ...
# 31379                                 No - none
# 31380                               Green Party
# 31381                               Green Party
# 31382                                    Labour
# 31383                               Green Party
# 31384                                 No - none
# 31385                          Liberal Democrat
# 31386                                 No - none
# 31387                                    Labour
# 31388  United Kingdom Independence Party (UKIP)
# 31389                                    Labour
# 31390                                    Labour
# 31391                              Conservative
# 31392                               Green Party
# 31393                                       NaN
# 31394                               Green Party
# 31395                                    Labour
# 31396                                    Labour
# 31397                                    Labour
# 31398                              Conservative
# 31399                                Don't know
# 31400                                       NaN
# 31401                                    Labour
# 31402                                Don't know
# 31403                          Liberal Democrat
# 31404                                    Labour
# 31405                               Plaid Cymru
# 31406                                Don't know
# 31407                                       NaN
# 31408                                    Labour
#
#                                partyIdSqueezeW9     partyIdEUretroW9  \
# 0                                           NaN        Mainly remain
# 1                                           NaN  Fairly evenly split
# 2                                           NaN                  NaN
# 3                                           NaN        Mainly remain
# 4                                           NaN                  NaN
# 5                                           NaN  Fairly evenly split
# 6                                           NaN                  NaN
# 7                 Scottish National Party (SNP)        Mainly remain
# 8      United Kingdom Independence Party (UKIP)         Mainly leave
# 9                                           NaN  Fairly evenly split
# 10                                          NaN         Mainly leave
# 11                                          NaN        Mainly remain
# 12                                          NaN  Fairly evenly split
# 13                                          NaN  Fairly evenly split
# 14                                    No - none                  NaN
# 15                                          NaN        Mainly remain
# 16                                          NaN                  NaN
# 17                                    No - none                  NaN
# 18                                          NaN         Mainly leave
# 19                                          NaN  Fairly evenly split
# 20                                          NaN        Mainly remain
# 21                                          NaN        Mainly remain
# 22                                          NaN  Fairly evenly split
# 23                                          NaN        Mainly remain
# 24                                          NaN  Fairly evenly split
# 25                                 Conservative        Mainly remain
# 26                                          NaN  Fairly evenly split
# 27                                          NaN        Mainly remain
# 28                                          NaN        Mainly remain
# 29                                          NaN         Mainly leave
# ...                                         ...                  ...
# 31379                                    Labour  Fairly evenly split
# 31380                                       NaN           Don't know
# 31381                                       NaN  Fairly evenly split
# 31382                                       NaN  Fairly evenly split
# 31383                                       NaN  Fairly evenly split
# 31384                                 No - none                  NaN
# 31385                                       NaN        Mainly remain
# 31386                                 No - none                  NaN
# 31387                                       NaN        Mainly remain
# 31388                                       NaN         Mainly leave
# 31389                                       NaN         Mainly leave
# 31390                                       NaN  Fairly evenly split
# 31391                                       NaN        Mainly remain
# 31392                                       NaN        Mainly remain
# 31393                                       NaN                  NaN
# 31394                                       NaN        Mainly remain
# 31395                                       NaN  Fairly evenly split
# 31396                                       NaN           Don't know
# 31397                                       NaN        Mainly remain
# 31398                                       NaN  Fairly evenly split
# 31399                                Don't know                  NaN
# 31400                                       NaN                  NaN
# 31401                                       NaN        Mainly remain
# 31402                                Don't know                  NaN
# 31403                                       NaN  Fairly evenly split
# 31404                                       NaN         Mainly leave
# 31405                                       NaN           Don't know
# 31406                                Don't know                  NaN
# 31407                                       NaN                  NaN
# 31408                                       NaN         Mainly leave
#
#       countryOfBirth      ...                     polKnowOsborne  \
# 0            England      ...        Chancellor of the Exchequer
# 1            England      ...        Chancellor of the Exchequer
# 2           Scotland      ...        Chancellor of the Exchequer
# 3              Wales      ...        Chancellor of the Exchequer
# 4            England      ...        Chancellor of the Exchequer
# 5            England      ...        Chancellor of the Exchequer
# 6            England      ...        Chancellor of the Exchequer
# 7           Scotland      ...        Chancellor of the Exchequer
# 8            England      ...        Chancellor of the Exchequer
# 9              Wales      ...        Chancellor of the Exchequer
# 10           England      ...              Deputy Prime Minister
# 11           England      ...        Chancellor of the Exchequer
# 12           England      ...        Chancellor of the Exchequer
# 13           England      ...        Chancellor of the Exchequer
# 14           England      ...        Chancellor of the Exchequer
# 15          Scotland      ...        Chancellor of the Exchequer
# 16           England      ...        Chancellor of the Exchequer
# 17           England      ...        Chancellor of the Exchequer
# 18           England      ...        Chancellor of the Exchequer
# 19           England      ...        Chancellor of the Exchequer
# 20             Wales      ...        Chancellor of the Exchequer
# 21          Scotland      ...        Chancellor of the Exchequer
# 22           England      ...        Chancellor of the Exchequer
# 23           England      ...        Chancellor of the Exchequer
# 24           England      ...        Chancellor of the Exchequer
# 25           England      ...        Chancellor of the Exchequer
# 26           England      ...        Chancellor of the Exchequer
# 27           England      ...        Chancellor of the Exchequer
# 28           England      ...        Chancellor of the Exchequer
# 29           England      ...        Chancellor of the Exchequer
# ...              ...      ...                                ...
# 31379            NaN      ...                                NaN
# 31380            NaN      ...                                NaN
# 31381            NaN      ...                                NaN
# 31382            NaN      ...                                NaN
# 31383            NaN      ...                                NaN
# 31384            NaN      ...                                NaN
# 31385            NaN      ...                                NaN
# 31386            NaN      ...                                NaN
# 31387            NaN      ...                                NaN
# 31388            NaN      ...                                NaN
# 31389            NaN      ...                                NaN
# 31390            NaN      ...                                NaN
# 31391            NaN      ...                                NaN
# 31392            NaN      ...                                NaN
# 31393            NaN      ...                                NaN
# 31394            NaN      ...                                NaN
# 31395            NaN      ...                                NaN
# 31396            NaN      ...                                NaN
# 31397            NaN      ...                                NaN
# 31398            NaN      ...                                NaN
# 31399            NaN      ...                                NaN
# 31400            NaN      ...                                NaN
# 31401            NaN      ...                                NaN
# 31402            NaN      ...                                NaN
# 31403            NaN      ...                                NaN
# 31404            NaN      ...                                NaN
# 31405            NaN      ...                                NaN
# 31406            NaN      ...                                NaN
# 31407            NaN      ...                                NaN
# 31408            NaN      ...                                NaN
#
#            polKnowMay                    polKnowBercow  \
# 0      Home secretary  Speaker of the House of Commons
# 1      Home secretary  Speaker of the House of Commons
# 2      Home secretary  Speaker of the House of Commons
# 3      Home secretary  Speaker of the House of Commons
# 4      Home secretary  Speaker of the House of Commons
# 5      Home secretary  Speaker of the House of Commons
# 6      Home secretary  Speaker of the House of Commons
# 7      Home secretary  Speaker of the House of Commons
# 8      Home secretary  Speaker of the House of Commons
# 9      Home secretary  Speaker of the House of Commons
# 10     Home secretary                       Don't know
# 11     Home secretary  Speaker of the House of Commons
# 12     Home secretary  Speaker of the House of Commons
# 13     Home secretary  Speaker of the House of Commons
# 14     Home secretary  Speaker of the House of Commons
# 15     Home secretary  Speaker of the House of Commons
# 16     Home secretary  Speaker of the House of Commons
# 17     Home secretary  Speaker of the House of Commons
# 18     Home secretary  Speaker of the House of Commons
# 19     Home secretary  Speaker of the House of Commons
# 20     Home secretary  Speaker of the House of Commons
# 21     Home secretary  Speaker of the House of Commons
# 22     Home secretary  Speaker of the House of Commons
# 23     Home secretary  Speaker of the House of Commons
# 24     Home secretary  Speaker of the House of Commons
# 25     Home secretary  Speaker of the House of Commons
# 26     Home secretary  Speaker of the House of Commons
# 27     Home secretary  Speaker of the House of Commons
# 28     Home secretary  Speaker of the House of Commons
# 29     Home secretary  Speaker of the House of Commons
# ...               ...                              ...
# 31379             NaN                              NaN
# 31380             NaN                              NaN
# 31381             NaN                              NaN
# 31382             NaN                              NaN
# 31383             NaN                              NaN
# 31384             NaN                              NaN
# 31385             NaN                              NaN
# 31386             NaN                              NaN
# 31387             NaN                              NaN
# 31388             NaN                              NaN
# 31389             NaN                              NaN
# 31390             NaN                              NaN
# 31391             NaN                              NaN
# 31392             NaN                              NaN
# 31393             NaN                              NaN
# 31394             NaN                              NaN
# 31395             NaN                              NaN
# 31396             NaN                              NaN
# 31397             NaN                              NaN
# 31398             NaN                              NaN
# 31399             NaN                              NaN
# 31400             NaN                              NaN
# 31401             NaN                              NaN
# 31402             NaN                              NaN
# 31403             NaN                              NaN
# 31404             NaN                              NaN
# 31405             NaN                              NaN
# 31406             NaN                              NaN
# 31407             NaN                              NaN
# 31408             NaN                              NaN
#
#                                                subjectHE subjectHECurrent  \
# 0      I never attended higher education (university ...              NaN
# 1                                                    Law              NaN
# 2                                                    NaN              NaN
# 3                                  Economics or business              NaN
# 4                                                  Other              NaN
# 5           Engineering, Mathematics or Natural sciences              NaN
# 6           Engineering, Mathematics or Natural sciences              NaN
# 7           Engineering, Mathematics or Natural sciences              NaN
# 8                                                    NaN              NaN
# 9                                                    NaN              NaN
# 10                                                   NaN              NaN
# 11                                                   NaN              NaN
# 12                                                   NaN              NaN
# 13                                                   NaN              NaN
# 14                                                   NaN              NaN
# 15                                 Economics or business              NaN
# 16     Humanities, social sciences, psychology or edu...              NaN
# 17                                              Medicine              NaN
# 18                                                   Law              NaN
# 19     Humanities, social sciences, psychology or edu...              NaN
# 20     Humanities, social sciences, psychology or edu...              NaN
# 21                                                   NaN              NaN
# 22                                                   NaN              NaN
# 23     Humanities, social sciences, psychology or edu...              NaN
# 24     Humanities, social sciences, psychology or edu...              NaN
# 25                                                   NaN              NaN
# 26                                                   Law              NaN
# 27                                                   NaN              NaN
# 28                                                   NaN              NaN
# 29     Humanities, social sciences, psychology or edu...              NaN
# ...                                                  ...              ...
# 31379                                                NaN              NaN
# 31380                                                NaN              NaN
# 31381                                                NaN              NaN
# 31382                                                NaN              NaN
# 31383                                                NaN              NaN
# 31384                                                NaN              NaN
# 31385                                                NaN              NaN
# 31386                                                NaN              NaN
# 31387                                                NaN              NaN
# 31388                                                NaN              NaN
# 31389                                                NaN              NaN
# 31390                                                NaN              NaN
# 31391                                                NaN              NaN
# 31392                                                NaN              NaN
# 31393                                                NaN              NaN
# 31394                                                NaN              NaN
# 31395                                                NaN              NaN
# 31396                                                NaN              NaN
# 31397                                                NaN              NaN
# 31398                                                NaN              NaN
# 31399                                                NaN              NaN
# 31400                                                NaN              NaN
# 31401                                                NaN              NaN
# 31402                                                NaN              NaN
# 31403                                                NaN              NaN
# 31404                                                NaN              NaN
# 31405                                                NaN              NaN
# 31406                                                NaN              NaN
# 31407                                                NaN              NaN
# 31408                                                NaN              NaN
#
#              edlevel profile_turnout_2015  \
# 0                NaN           Yes, voted
# 1      Undergraduate           Yes, voted
# 2          GCSE A*-C           Yes, voted
# 3      Undergraduate           Yes, voted
# 4      Undergraduate           Yes, voted
# 5      Undergraduate           Yes, voted
# 6      Undergraduate           Yes, voted
# 7           Postgrad           Yes, voted
# 8           GCSE D-G           Yes, voted
# 9            A-level           Yes, voted
# 10           A-level           Yes, voted
# 11         GCSE A*-C           Yes, voted
# 12         GCSE A*-C           Yes, voted
# 13         GCSE A*-C           Yes, voted
# 14         GCSE A*-C           Yes, voted
# 15     Undergraduate           Yes, voted
# 16     Undergraduate           Yes, voted
# 17               NaN           Yes, voted
# 18     Undergraduate           Yes, voted
# 19     Undergraduate           Yes, voted
# 20     Undergraduate           Yes, voted
# 21     Undergraduate           Yes, voted
# 22           A-level           Yes, voted
# 23     Undergraduate           Yes, voted
# 24     Undergraduate           Yes, voted
# 25           A-level           Yes, voted
# 26          Postgrad           Yes, voted
# 27         GCSE A*-C           Yes, voted
# 28           A-level           Yes, voted
# 29               NaN           Yes, voted
# ...              ...                  ...
# 31379       Postgrad                  NaN
# 31380        A-level                  NaN
# 31381            NaN                  NaN
# 31382        A-level                  NaN
# 31383  Undergraduate                  NaN
# 31384      GCSE A*-C                  NaN
# 31385       Postgrad                  NaN
# 31386            NaN                  NaN
# 31387  Undergraduate                  NaN
# 31388      GCSE A*-C                  NaN
# 31389       GCSE D-G                  NaN
# 31390  Undergraduate                  NaN
# 31391  Undergraduate                  NaN
# 31392  Undergraduate                  NaN
# 31393        A-level                  NaN
# 31394  Undergraduate                  NaN
# 31395            NaN                  NaN
# 31396  Undergraduate                  NaN
# 31397      GCSE A*-C                  NaN
# 31398      GCSE A*-C                  NaN
# 31399      GCSE A*-C                  NaN
# 31400      GCSE A*-C                  NaN
# 31401  Undergraduate                  NaN
# 31402      GCSE A*-C                  NaN
# 31403        A-level                  NaN
# 31404      GCSE A*-C                  NaN
# 31405            NaN                  NaN
# 31406       Postgrad                  NaN
# 31407  Undergraduate                  NaN
# 31408  Undergraduate                  NaN
#
#                          profile_past_vote_2015 lr_scale       al_scale
# 0                                        Labour      0.5              8
# 1                                  Conservative      7.5              6
# 2                 Scottish National Party (SNP)      0.5  Authoritarian
# 3                                        Labour        3            3.5
# 4                                  Conservative        5  Authoritarian
# 5                                  Conservative        6              6
# 6                                  Conservative      7.5              9
# 7                 Scottish National Party (SNP)     Left            1.5
# 8      United Kingdom Independence Party (UKIP)     Left            NaN
# 9      United Kingdom Independence Party (UKIP)        4              6
# 10                                       Labour        3            7.5
# 11                                 Conservative        9              9
# 12                                 Conservative      2.5            6.5
# 13                                 Conservative      6.5            7.5
# 14                                 Conservative      6.5            8.5
# 15                Scottish National Party (SNP)        3            8.5
# 16                             Liberal Democrat      4.5            6.5
# 17                                   Don't know        6              7
# 18     United Kingdom Independence Party (UKIP)        1            9.5
# 19                                       Labour        3            5.5
# 20                                 Conservative        6            9.5
# 21                Scottish National Party (SNP)     Left            2.5
# 22                                       Labour        1              5
# 23                             Liberal Democrat     Left            7.5
# 24                                 Conservative        6            NaN
# 25                                 Conservative        4            6.5
# 26                                 Conservative        8              6
# 27                                 Conservative      5.5              6
# 28                                       Labour      2.5              5
# 29                                 Conservative      5.5            4.5
# ...                                         ...      ...            ...
# 31379                                       NaN        1            2.5
# 31380                                       NaN        2              2
# 31381                                       NaN        5              5
# 31382                                       NaN      2.5            NaN
# 31383                                       NaN     Left            5.5
# 31384                                       NaN      2.5            8.5
# 31385                                       NaN      2.5              6
# 31386                                       NaN      2.5              6
# 31387                                       NaN      0.5            4.5
# 31388                                       NaN      3.5              8
# 31389                                       NaN      NaN            NaN
# 31390                                       NaN     Left              4
# 31391                                       NaN      3.5            7.5
# 31392                                       NaN     Left              7
# 31393                                       NaN        3            2.5
# 31394                                       NaN      NaN            NaN
# 31395                                       NaN     Left            1.5
# 31396                                       NaN        3            4.5
# 31397                                       NaN      2.5              7
# 31398                                       NaN        5            6.5
# 31399                                       NaN        5              5
# 31400                                       NaN        4  Authoritarian
# 31401                                       NaN      1.5              5
# 31402                                       NaN      3.5              7
# 31403                                       NaN      NaN            NaN
# 31404                                       NaN      NaN            NaN
# 31405                                       NaN     Left            8.5
# 31406                                       NaN        4              5
# 31407                                       NaN        2            5.5
# 31408                                       NaN        4            6.5
#
# [31409 rows x 664 columns]

# %%
BES[BES.columns[BES.dtypes=="category"]].cat.ordered
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-111-de47b99e0f21> in <module>()
# ----> 1 BES[BES.columns[BES.dtypes=="category"]].cat.ordered
#
# C:\Users\Marios\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    2667             if name in self._info_axis:
#    2668                 return self[name]
# -> 2669             return object.__getattribute__(self, name)
#    2670
#    2671     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'cat'

# %%
# I'm a fucking genius
# All category columns changed to their code values
# e.g. Index(['Strongly disagree', 'Disagree', 'Neither agree nor disagree', 'Agree', 'Strongly agree', 'Don't know'],
#      dtype='object')
# becomes [0,1,2,3,4,5,6]
# -1 codes for missing value

BES[BES.columns[BES.dtypes=="category"]] = BES[BES.columns[BES.dtypes=="category"]].apply(lambda x: x.cat.codes)
#df.applymap(lambda x: '%.2f' % x)

# %%
BES.dtypes.value_counts()
# Out:
# int8              668
# object             33
# float64            20
# datetime64[ns]      6
# int16               5
# int32               1
# dtype: int64

# %%
features = list(BES.columns[(BES.dtypes=="int8") | (BES.dtypes=="int16") | (BES.dtypes=="float64") ])

# %%
BES[features].dtypes
# Out:
# wt_core_W8                      float64
# wt_core_W9                      float64
# wt_full_W8                      float64
# wt_full_W1W2W3W4W5W6W7          float64
# wt_full_W7                      float64
# wt_full_W9                      float64
# wt_full_W1W2W3W4W5W6W7W8W9      float64
# wt_full_W7W8W9                  float64
# wave9                              int8
# country                            int8
# generalElectionVote                int8
# generalElectionVoteW9              int8
# partyId                            int8
# partyIdSqueeze                     int8
# partyIdEU                          int8
# partyIdW9                          int8
# partyIdSqueezeW9                   int8
# partyIdEUretroW9                   int8
# countryOfBirth                     int8
# w6full                          float64
# w6core                          float64
# w7full                          float64
# w7core                          float64
# Dailyweight                     float64
# ukCitizen                          int8
# euCitizen                          int8
# commonwealthCitizen                int8
# otherCitizen                       int8
# mii                                int8
# bestOnMII                          int8
#                                  ...
# privateSecondarySchool             int8
# neverPrivateSchool                 int8
# RPrivSchnew_dk                     int8
# workingStatus                      int8
# preschoolChildrenInHousehold       int8
# schoolChildrenInHousehold          int8
# sickOrElderlyInHousehold           int8
# noDependentsInHousehold            int8
# speakWelsh                         int8
# prevJob                            int8
# selfNumEmployees                   int8
# selfNumEmployeesLast               int8
# headHouseholdPast                  int8
# fatherNumEmployees                 int8
# motherNumEmployees                 int8
# selfOccStatus                      int8
# selfOccStatusLast                  int8
# subjClass                          int8
# polKnowMiliband                    int8
# polKnowClegg                       int8
# polKnowOsborne                     int8
# polKnowMay                         int8
# polKnowBercow                      int8
# subjectHE                          int8
# subjectHECurrent                   int8
# edlevel                            int8
# profile_turnout_2015               int8
# profile_past_vote_2015             int8
# lr_scale                           int8
# al_scale                           int8
# dtype: object

# %%
BES.dtypes.value_counts()
# Out:
# category          664
# object             33
# float64            20
# int8                8
# datetime64[ns]      6
# int16               1
# int32               1
# dtype: int64

# %%
BES[1:5][BES.columns[1:20]]
# Out:
#    wt_core_W8  wt_core_W9  wt_full_W8  wt_full_W1W2W3W4W5W6W7  wt_full_W7  \
# 1         NaN         NaN    0.664886                     NaN    0.820500
# 2         NaN         NaN    0.187094                     NaN    0.164377
# 3    0.487754    0.427025    0.498063                0.259198    0.428161
# 4    0.850734         NaN    0.888353                     NaN    1.018703
#
#    wt_full_W9  wt_full_W1W2W3W4W5W6W7W8W9  wt_full_W7W8W9  wave9   country  \
# 1    0.657050                         NaN        0.803742      1   England
# 2         NaN                         NaN             NaN      0  Scotland
# 3    0.488054                    0.273093        0.426970      1     Wales
# 4         NaN                         NaN             NaN      0   England
#
#   generalElectionVote                             generalElectionVoteOth  \
# 1        Conservative                                             __NA__
# 2               Other  a "True" Labour Party, united under Jeremy Corbyn
# 3              Labour                                             __NA__
# 4        Conservative                                             __NA__
#
#   generalElectionVoteW9 generalElectionVoteOthW9  \
# 1          Conservative                   __NA__
# 2                   NaN
# 3           Plaid Cymru                   __NA__
# 4                   NaN
#
#                          partyId partyIdSqueeze partyIdSqueezeOth  \
# 1                   Conservative            NaN            __NA__
# 2  Scottish National Party (SNP)            NaN            __NA__
# 3                      No - none         Labour            __NA__
# 4                   Conservative            NaN            __NA__
#
#              partyIdEU     partyIdW9
# 1  Fairly evenly split  Conservative
# 2  Fairly evenly split           NaN
# 3        Mainly remain        Labour
# 4  Fairly evenly split           NaN

# %%
BES["riskScale"]
# Out:
# 0         8
# 1         6
# 2         4
# 3         2
# 4         6
# 5         2
# 6         5
# 7         5
# 8         5
# 9         5
# 10        6
# 11        4
# 12       10
# 13        6
# 14        5
# 15        5
# 16       12
# 17        4
# 18        9
# 19        1
# 20        5
# 21        6
# 22        9
# 23        5
# 24       11
# 25        6
# 26        9
# 27        1
# 28       10
# 29        1
#          ..
# 31379     4
# 31380     5
# 31381    10
# 31382     6
# 31383     5
# 31384     4
# 31385     5
# 31386    13
# 31387     5
# 31388     5
# 31389     1
# 31390     5
# 31391     7
# 31392    15
# 31393     5
# 31394    13
# 31395     2
# 31396     6
# 31397     5
# 31398     7
# 31399     1
# 31400     2
# 31401     6
# 31402    12
# 31403     1
# 31404    16
# 31405     7
# 31406     4
# 31407     7
# 31408     1
# Name: riskScale, dtype: int8

# %%
BES.euRefVote.value_counts()
# Out:
# Leave the EU             14803
# Stay/remain in the EU    14262
# Don't know                1899
# I would/will not vote      444
# dtype: int64

# %%
list(BES.columns)
# Out:
# ['id',
#  'wt_core_W8',
#  'wt_core_W9',
#  'wt_full_W8',
#  'wt_full_W1W2W3W4W5W6W7',
#  'wt_full_W7',
#  'wt_full_W9',
#  'wt_full_W1W2W3W4W5W6W7W8W9',
#  'wt_full_W7W8W9',
#  'wave9',
#  'country',
#  'generalElectionVote',
#  'generalElectionVoteOth',
#  'generalElectionVoteW9',
#  'generalElectionVoteOthW9',
#  'partyId',
#  'partyIdSqueeze',
#  'partyIdSqueezeOth',
#  'partyIdEU',
#  'partyIdW9',
#  'partyIdSqueezeW9',
#  'partyIdSqueezeOthW9',
#  'partyIdEUretroW9',
#  'countryOfBirth',
#  'w6full',
#  'w6core',
#  'w7full',
#  'w7core',
#  'Dailyweight',
#  'respdate',
#  'starttime',
#  'endtime',
#  'ukCitizen',
#  'euCitizen',
#  'commonwealthCitizen',
#  'otherCitizen',
#  'mii',
#  'MII_text',
#  'bestOnMII',
#  'bestOnMIIOth',
#  'postalapply',
#  'postalTurnout',
#  'euRefVotePost',
#  'euRefTurnout',
#  'euRefVote',
#  'euRefVoteSqueeze',
#  'euRefCertainty',
#  'euRefInterest',
#  'euRefExpectation',
#  'euRefFinal',
#  'MIIEU',
#  'MIIEU_text',
#  'britishness',
#  'scottishness',
#  'welshness',
#  'englishness',
#  'europeanness',
#  'polAttention',
#  'likeCameron',
#  'likeCorbyn',
#  'likeFarron',
#  'likeSturgeon',
#  'likeWood',
#  'likeFarage',
#  'likeBennett',
#  'likeBoris',
#  'likeGove',
#  'likeOsborne',
#  'likeAlanJohnson',
#  'bestPM',
#  'likeCon',
#  'likeLab',
#  'likeLD',
#  'likeSNP',
#  'likePC',
#  'likeUKIP',
#  'likeGrn',
#  'changeEconomy',
#  'changeNHS',
#  'changeEducation',
#  'changeCostLive',
#  'changeImmig',
#  'changeCrime',
#  'localTurnoutRetro',
#  'localElectionVote',
#  'localElectionVoteOth',
#  'welshTurnoutRetro',
#  'welshElectionVoteConst',
#  'welshElectionVoteConstOth',
#  'welshElectionVoteList',
#  'welshElectionVoteListOth',
#  'scotTurnoutRetro',
#  'scotElectionVoteConst',
#  'scotElectionVoteConstOth',
#  'scotElectionVoteList',
#  'scotElectionVoteListOth',
#  'pccTurnout',
#  'pccVote1',
#  'pccVote2',
#  'EUIntegrationSelf',
#  'EUIntegrationCon',
#  'EUIntegrationLab',
#  'EUIntegrationLD',
#  'EUIntegrationSNP',
#  'EUIntegrationPC',
#  'EUIntegrationUKIP',
#  'EUIntegrationGreen',
#  'certaintyEUCon',
#  'certaintyEULab',
#  'certaintyEULD',
#  'certaintyEUSNP',
#  'certaintyEUPC',
#  'certaintyEUUKIP',
#  'certaintyEUGreen',
#  'efficacyUnderstand',
#  'efficacyPolCare',
#  'monarch',
#  'efficacyEU',
#  'leaveImpactSelf',
#  'leaveImpactBritain',
#  'betterDealEU',
#  'benefitsToMigrants',
#  'childBenefitsRepatriate',
#  'immigContributeTake',
#  'ukCoopTrade',
#  'ukCoopWorkers',
#  'ukCoopCAP',
#  'ukCoopMovement',
#  'ukCoopEuro',
#  'effectsEUUnemployment',
#  'effectsEUTrade',
#  'effectsEUImmigration',
#  'effectsEUTerror',
#  'euLeaveVoice',
#  'effectsEUWorkers',
#  'effectsEUEcon',
#  'effectsEUFinance',
#  'effectsEUNHS',
#  'euLeaveBigBusiness',
#  'euLeaveScotIndep',
#  'certaintyUKLeave',
#  'certaintyUKRemain',
#  'businessSupport',
#  'tuSupport',
#  'labSupport',
#  'conSupport',
#  'ldSupport',
#  'snpSupport',
#  'plaidSupport',
#  'parliamentSupport',
#  'cabinetSupport',
#  'franceFairShare',
#  'britainFairShare',
#  'germanyFairShare',
#  'euPreventWar',
#  'euUKRich',
#  'euCloser',
#  'UKsovereignty',
#  'euRedTape',
#  'euMemberJoin',
#  'euDominance',
#  'turkey',
#  'euParlOverRide',
#  'euLawsLevel',
#  'echr',
#  'normEU',
#  'euUndermineIdentity',
#  'socialIdentityGlobalLeave',
#  'socialIdentityGlobalRemain',
#  'infoSourceTV',
#  'infoSourcePaper',
#  'infoSourceRadio',
#  'infoSourceInternet',
#  'infoSourcePeople',
#  'euSources_1',
#  'euSources_2',
#  'euSources_3',
#  'euSources_4',
#  'euSources_5',
#  'euSources_111',
#  'euSources_99',
#  'discussPolDays',
#  'euGovtLeaflet',
#  'partyContact1',
#  'partyContactCon',
#  'partyContactLab',
#  'partyContactLD',
#  'partyContactSNP',
#  'partyContactPC',
#  'partyContactUKIP',
#  'partyContactGrn',
#  'partyContactOtherParty',
#  'partyContactStrongerIn',
#  'partyContactVoteLeave',
#  'partyContactOthLeave',
#  'partyContactOthRemain',
#  'partyContactNone',
#  'partyContactDK',
#  'othContact',
#  'partyContactCon_1',
#  'partyContactCon_2',
#  'partyContactCon_3',
#  'partyContactCon_4',
#  'partyContactCon_5',
#  'partyContactCon_6',
#  'partyContactCon_7',
#  'partyContactLab_1',
#  'partyContactLab_2',
#  'partyContactLab_3',
#  'partyContactLab_4',
#  'partyContactLab_5',
#  'partyContactLab_6',
#  'partyContactLab_7',
#  'partyContactLD_1',
#  'partyContactLD_2',
#  'partyContactLD_3',
#  'partyContactLD_4',
#  'partyContactLD_5',
#  'partyContactLD_6',
#  'partyContactLD_7',
#  'partyContactSNP_1',
#  'partyContactSNP_2',
#  'partyContactSNP_3',
#  'partyContactSNP_4',
#  'partyContactSNP_5',
#  'partyContactSNP_6',
#  'partyContactSNP_7',
#  'partyContactPC_1',
#  'partyContactPC_2',
#  'partyContactPC_3',
#  'partyContactPC_4',
#  'partyContactPC_5',
#  'partyContactPC_6',
#  'partyContactPC_7',
#  'partyContactUKIP_1',
#  'partyContactUKIP_2',
#  'partyContactUKIP_3',
#  'partyContactUKIP_4',
#  'partyContactUKIP_5',
#  'partyContactUKIP_6',
#  'partyContactUKIP_7',
#  'partyContactGreen_1',
#  'partyContactGreen_2',
#  'partyContactGreen_3',
#  'partyContactGreen_4',
#  'partyContactGreen_5',
#  'partyContactGreen_6',
#  'partyContactGreen_7',
#  'partyContactOther_1',
#  'partyContactOther_2',
#  'partyContactOther_3',
#  'partyContactOther_4',
#  'partyContactOther_5',
#  'partyContactOther_6',
#  'partyContactOther_7',
#  'EUContactRemainCon',
#  'EUContactRemainLab',
#  'EUContactRemainLD',
#  'EUContactRemainSNP',
#  'EUContactRemainPC',
#  'EUContactRemainUKIP',
#  'EUContactRemainGreen',
#  'EUContactRemainOth',
#  'EUContactRemainNone',
#  'EUContactRemainDK',
#  'EUContactLeaveCon',
#  'EUContactLeaveLab',
#  'EUContactLeaveLD',
#  'EUContactLeaveSNP',
#  'EUContactLeavePC',
#  'EUContactLeaveUKIP',
#  'EUContactLeaveGreen',
#  'EUContactLeaveOth',
#  'EUContactLeaveNone',
#  'EUContactLeaveDK',
#  'leaveTone',
#  'remainTone',
#  'proConRemain',
#  'proConLeave',
#  'campaigninfoLeave',
#  'campaigninfoRemain',
#  'immigrantsWelfareState',
#  'prefTradeoff',
#  'beliefTradeoff',
#  'controlImmig',
#  'satDemUK',
#  'satDemScot',
#  'satDemWales',
#  'satDemEng',
#  'satDemEU',
#  'riskTaking',
#  'immigEcon',
#  'immigCultural',
#  'asylumMore',
#  'euMore',
#  'noneuMore',
#  'studentsMore',
#  'familiesMore',
#  'immigSelf',
#  'immigCon',
#  'immigLab',
#  'immigLD',
#  'immigSNP',
#  'immigPC',
#  'immigUKIP',
#  'immigGreen',
#  'registered',
#  'registeredUpToDate',
#  'reasonNotRegistered_1',
#  'reasonNotRegistered_2',
#  'reasonNotRegistered_3',
#  'reasonNotRegistered_4',
#  'reasonNotRegistered_5',
#  'reasonNotRegistered_6',
#  'reasonNotRegistered_7',
#  'reasonNotRegistered_8',
#  'reasonNotRegistered_none',
#  'reasonNotRegistered_dk',
#  'regSatisfaction',
#  'conUnited',
#  'labUnited',
#  'ldUnited',
#  'snpUnited',
#  'pcUnited',
#  'ukipUnited',
#  'grnUnited',
#  'euKnow6',
#  'euKnow2',
#  'euKnow1',
#  'euKnow3',
#  'euKnow4',
#  'euKnow5',
#  'leftRight',
#  'lrCon',
#  'lrLab',
#  'lrLD',
#  'lrUKIP',
#  'lrSNP',
#  'lrPC',
#  'lrgreens',
#  'lrCameron',
#  'lrCorbyn',
#  'tv1_1',
#  'tv2_1',
#  'tv3_1',
#  'radio1_1',
#  'radio2_1',
#  'radio3_1',
#  'paper1_1',
#  'paper2_1',
#  'paper3_1',
#  'internet1_1',
#  'internet2_1',
#  'internet3_1',
#  'participation_1',
#  'participation_2',
#  'participation_3',
#  'participation_4',
#  'participation_5',
#  'participation_6',
#  'handed',
#  'goodTimePurchase',
#  'riskPoverty',
#  'riskUnemployment',
#  'econPersonalRetro',
#  'econGenRetro',
#  'remainVoteConLab',
#  'leaveVoteUKIPCon',
#  'euID',
#  'euID1',
#  'euID2',
#  'euID3',
#  'euID4',
#  'euID5',
#  'euID6',
#  'euID7',
#  'locusControl',
#  'locus1',
#  'locus2',
#  'tolUncertain1',
#  'tolUncertain2',
#  'tolUncertain3',
#  'livedAbroad',
#  'abroadCountry_1',
#  'abroadCountry_2',
#  'friendsEU',
#  'parentsForeign',
#  'country_of_residence1',
#  'country_of_residence2',
#  'languageSkills',
#  'languageSkillsWelsh',
#  'partyMember',
#  'partyMemberPast',
#  'partyMemberPastOth',
#  'partyMemberNow',
#  'partyMemberNowOth',
#  'antiIntellectual',
#  'efficacyTooMuchEffort',
#  'efficacyNotUnderstand',
#  'efficacyNoMatter',
#  'dutyToVote2',
#  'socialPressureVote',
#  'ptvCon',
#  'ptvLab',
#  'ptvLD',
#  'ptvSNP',
#  'ptvPC',
#  'ptvUKIP',
#  'ptvGrn',
#  'age',
#  'voted2015',
#  'recallVote15',
#  'trustMPs',
#  'debateOneWatch',
#  'debateTwoWatch',
#  'debateThreeWatch',
#  'debateFourWatch',
#  'debatefiveWatch',
#  'riskScale',
#  'euRefVoteUnsqueeze',
#  'euRefVote2',
#  'w8full',
#  'w8core',
#  'respdateW9',
#  'starttimeW9',
#  'endtimeW9',
#  'BESwave9_SamplesurveyW9',
#  'miiW9',
#  'MII_textW9',
#  'bestOnMIIW9',
#  'bestOnMIIOthW9',
#  'euRefTurnoutRetroW9',
#  'euRefVoteHypotheticalW9',
#  'euRefVoteW9',
#  'voteMethodW9',
#  'regretsIHaveAFewW9',
#  'euRefFinalPostW9',
#  'referendumSettledW9',
#  'scotReferendumIntentionW9',
#  'happyEULeaveW9',
#  'expectGoodConductEURefW9',
#  'pidWeTheyW9',
#  'pidInterestedOthersW9',
#  'pidCriticisePartyW9',
#  'pidCommonPartyW9',
#  'pidRuinDayW9',
#  'pidConnectedW9',
#  'pidMyPartyW9',
#  'pidPraiseGoodW9',
#  'britishnessW9',
#  'scottishnessW9',
#  'welshnessW9',
#  'englishnessW9',
#  'europeannessW9',
#  'likeCameronW9',
#  'likeCorbynW9',
#  'likeFarronW9',
#  'likeSturgeonW9',
#  'likeWoodW9',
#  'likeFarageW9',
#  'likeBennettW9',
#  'likeBorisW9',
#  'likeOsborneW9',
#  'trustMPsW9',
#  'likeConW9',
#  'likeLabW9',
#  'likeLDW9',
#  'likeSNPW9',
#  'likePCW9',
#  'likeUKIPW9',
#  'likeGrnW9',
#  'blameLeave_1W9',
#  'blameLeave_2W9',
#  'blameLeave_3W9',
#  'blameLeave_4W9',
#  'blameLeave_5W9',
#  'blameLeave_6W9',
#  'blameLeave_7W9',
#  'blameLeave_8W9',
#  'blameLeave_12W9',
#  'blameLeave_99W9',
#  'creditLeave_1W9',
#  'creditLeave_2W9',
#  'creditLeave_3W9',
#  'creditLeave_4W9',
#  'creditLeave_5W9',
#  'creditLeave_6W9',
#  'creditLeave_7W9',
#  'creditLeave_8W9',
#  'creditLeave_12W9',
#  'creditLeave_99W9',
#  'approveUKGovtW9',
#  'approveScotGovtW9',
#  'approveWelshGovtW9',
#  'approveEUW9',
#  'conUnitedW9',
#  'labUnitedW9',
#  'ldUnitedW9',
#  'snpUnitedW9',
#  'pcUnitedW9',
#  'ukipUnitedW9',
#  'grnUnitedW9',
#  'goodTimePurchaseW9',
#  'riskPovertyW9',
#  'riskUnemploymentW9',
#  'travelEUW9',
#  'EUIntegrationSelfW9',
#  'changeIssue1W9',
#  'changeEconomyW9',
#  'satDemUKW9',
#  'satDemScotW9',
#  'satDemWalesW9',
#  'satDemEngW9',
#  'satDemEUW9',
#  'controlImmigW9',
#  'negotiationSpecifics_1W9',
#  'negotiationSpecifics_2W9',
#  'negotiationSpecifics_3W9',
#  'negotiationSpecifics_111W9',
#  'negotiationSpecifics_99W9',
#  'socialIdentityGlobalLeaveW9',
#  'socialIdentityGlobalRemainW9',
#  'antiIntellectualW9',
#  'efficacyUnderstandW9',
#  'efficacyTooMuchEffortW9',
#  'efficacyNotUnderstandW9',
#  'efficacyPolCareW9',
#  'efficacyNoMatterW9',
#  'immigSelfW9',
#  'immigConW9',
#  'immigLabW9',
#  'immigLDW9',
#  'immigSNPW9',
#  'immigPCW9',
#  'immigUKIPW9',
#  'immigGreenW9',
#  'achieveReduceImmigConW9',
#  'achieveReduceImmigLabW9',
#  'achieveReduceImmigLDW9',
#  'achieveReduceImmigSNPW9',
#  'achieveReduceImmigPCW9',
#  'achieveReduceImmigUKIPW9',
#  'achieveReduceImmigGrnW9',
#  'achieveReduceImmigNoneW9',
#  'achieveReduceImmigDKW9',
#  'ptvConW9',
#  'ptvLabW9',
#  'ptvLDW9',
#  'ptvSNPW9',
#  'ptvPCW9',
#  'ptvUKIPW9',
#  'ptvGrnW9',
#  'passports_1W9',
#  'passports_2W9',
#  'passports_3W9',
#  'passports_4W9',
#  'passports_99W9',
#  'euIDW9',
#  'euID1W9',
#  'euID2W9',
#  'euID3W9',
#  'euID4W9',
#  'euID5W9',
#  'euID6W9',
#  'euID7W9',
#  'handleMIIConW9',
#  'handleMIILabW9',
#  'handleMIILDW9',
#  'handleMIISNPW9',
#  'handleMIIPCW9',
#  'handleMIIUKIPW9',
#  'handleMIIGrnW9',
#  'ethno1W9',
#  'ethno2W9',
#  'ethno3W9',
#  'ethno4W9',
#  'ethno5W9',
#  'ethno6W9',
#  'prPreferenceW9',
#  'locusControlW9',
#  'locus1W9',
#  'locus2W9',
#  'conPriorities_econW9',
#  'conPriorities_costLiveW9',
#  'conPriorities_nhsW9',
#  'conPriorities_immigW9',
#  'conPriorities_crimeW9',
#  'conPriorities_schoolW9',
#  'conPriorities_noneW9',
#  'labPriorities_econW9',
#  'labPriorities_costLiveW9',
#  'labPriorities_nhsW9',
#  'labPriorities_immigW9',
#  'labPriorities_crimeW9',
#  'labPriorities_schoolW9',
#  'labPriorities_noneW9',
#  'ldPriorities_econW9',
#  'ldPriorities_costLiveW9',
#  'ldPriorities_nhsW9',
#  'ldPriorities_immigW9',
#  'ldPriorities_crimeW9',
#  'ldPriorities_schoolW9',
#  'ldPriorities_noneW9',
#  'ukipPriorities_econW9',
#  'ukipPriorities_costLiveW9',
#  'ukipPriorities_nhsW9',
#  'ukipPriorities_immigW9',
#  'ukipPriorities_crimeW9',
#  'ukipPriorities_schoolW9',
#  'ukipPriorities_noneW9',
#  'leftRightW9',
#  'lrConW9',
#  'lrLabW9',
#  'lrLDW9',
#  'lrUKIPW9',
#  'lrSNPW9',
#  'lrPCW9',
#  'lrgreensW9',
#  'conLeaderLikeW9',
#  'likeMayW9',
#  'likeGoveW9',
#  'likeJarvisW9',
#  'likeWatsonW9',
#  'likeMcDonnellW9',
#  'scotReferendumRetroW9',
#  'scotReferendumVoteW9',
#  'currentUnionMemberW9',
#  'everUnionMemberW9',
#  'polKnowKerryW9',
#  'polKnowHollandeW9',
#  'polKnowNetanyahuW9',
#  'polKnowPutinW9',
#  'polKnowMerkelW9',
#  'polKnowAssadW9',
#  'selfOccSuperviseW9',
#  'selfOccOrgSizeW9',
#  'selfOccEmployeesW9',
#  'selfOccSuperviseLastW9',
#  'selfOccOrgSizeLastW9',
#  'selfOccEmployeesLastW9',
#  'anyUniW9',
#  'w9full',
#  'w9core',
#  'EUMIICategory',
#  'euMIISmall',
#  'disability',
#  'ageGroup',
#  'w2full',
#  'w2core',
#  'w1full',
#  'w1core',
#  'euRefLA',
#  'pano',
#  'onscode',
#  'gender',
#  'Age',
#  'marital',
#  'housing',
#  'gor',
#  'education',
#  'pcon',
#  'profile_education_age',
#  'profile_ethnicity',
#  'profile_lea',
#  'profile_oslaua',
#  'profile_gross_household',
#  'profile_gross_personal',
#  'profile_household_size',
#  'profile_household_children',
#  'profile_newspaper_readership_201',
#  'profile_past_vote_2005',
#  'profile_past_vote_2010',
#  'profile_religion',
#  'profile_religion_denom',
#  'personality_agreeableness',
#  'personality_conscientiousness',
#  'personality_extraversion',
#  'personality_neuroticism',
#  'personality_openness',
#  'ns_sec',
#  'ns_sec_analytic',
#  'lr1',
#  'lr2',
#  'lr3',
#  'lr4',
#  'lr5',
#  'al1',
#  'al2',
#  'al3',
#  'al4',
#  'al5',
#  'blackEquality',
#  'femaleEquality',
#  'gayEquality',
#  'socialDesScale',
#  'socialDes_1',
#  'socialDes_2',
#  'socialDes_3',
#  'socialDes_4',
#  'socialDes_none',
#  'socialDes_dk',
#  'privatePrimarySchool',
#  'privateSecondarySchool',
#  'neverPrivateSchool',
#  'RPrivSchnew_dk',
#  'workingStatus',
#  'preschoolChildrenInHousehold',
#  'schoolChildrenInHousehold',
#  'sickOrElderlyInHousehold',
#  'noDependentsInHousehold',
#  'speakWelsh',
#  'prevJob',
#  'selfNumEmployees',
#  'selfNumEmployeesLast',
#  'headHouseholdPast',
#  'fatherNumEmployees',
#  'motherNumEmployees',
#  'selfOccStatus',
#  'selfOccStatusLast',
#  'subjClass',
#  'othSubjClass',
#  'polKnowMiliband',
#  'polKnowClegg',
#  'polKnowOsborne',
#  'polKnowMay',
#  'polKnowBercow',
#  'subjectHE',
#  'subjectHECurrent',
#  'edlevel',
#  'profile_turnout_2015',
#  'profile_past_vote_2015',
#  'lr_scale',
#  'al_scale']

# %%
BES.al2
# Out:
# 0                    Strongly agree
# 1                          Disagree
# 2                    Strongly agree
# 3                 Strongly disagree
# 4                    Strongly agree
# 5        Neither agree nor disagree
# 6                    Strongly agree
# 7                 Strongly disagree
# 8                        Don't know
# 9        Neither agree nor disagree
# 10                            Agree
# 11       Neither agree nor disagree
# 12                            Agree
# 13                            Agree
# 14                   Strongly agree
# 15                   Strongly agree
# 16       Neither agree nor disagree
# 17                            Agree
# 18                   Strongly agree
# 19                Strongly disagree
# 20                   Strongly agree
# 21                Strongly disagree
# 22                Strongly disagree
# 23                         Disagree
# 24                         Disagree
# 25       Neither agree nor disagree
# 26                            Agree
# 27       Neither agree nor disagree
# 28                Strongly disagree
# 29                Strongly disagree
#                     ...
# 31379             Strongly disagree
# 31380             Strongly disagree
# 31381    Neither agree nor disagree
# 31382                      Disagree
# 31383                      Disagree
# 31384                         Agree
# 31385                      Disagree
# 31386                         Agree
# 31387                Strongly agree
# 31388                         Agree
# 31389                           NaN
# 31390                      Disagree
# 31391                      Disagree
# 31392    Neither agree nor disagree
# 31393             Strongly disagree
# 31394                           NaN
# 31395             Strongly disagree
# 31396                      Disagree
# 31397    Neither agree nor disagree
# 31398    Neither agree nor disagree
# 31399    Neither agree nor disagree
# 31400                Strongly agree
# 31401                         Agree
# 31402    Neither agree nor disagree
# 31403                    Don't know
# 31404                    Don't know
# 31405                Strongly agree
# 31406             Strongly disagree
# 31407                      Disagree
# 31408                         Agree
# Name: al2, dtype: category
# Categories (6, object): [Strongly disagree < Disagree < Neither agree nor disagree < Agree < Strongly agree < Don't know]

# %%
death_by_EU = BES[["euRefVote","al2"]]

# %%
death_by_EU.plot(kind='line')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-f900d1e84549> in <module>()
# ----> 1 death_by_EU.plot(kind='line')
#
# C:\ANACON~1\lib\site-packages\pandas\tools\plotting.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3735                           fontsize=fontsize, colormap=colormap, table=table,
#    3736                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3737                           sort_columns=sort_columns, **kwds)
#    3738     __call__.__doc__ = plot_frame.__doc__
#    3739
#
# C:\ANACON~1\lib\site-packages\pandas\tools\plotting.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2609                  yerr=yerr, xerr=xerr,
#    2610                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2611                  **kwds)
#    2612
#    2613
#
# C:\ANACON~1\lib\site-packages\pandas\tools\plotting.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    2436         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    2437
# -> 2438     plot_obj.generate()
#    2439     plot_obj.draw()
#    2440     return plot_obj.result
#
# C:\ANACON~1\lib\site-packages\pandas\tools\plotting.py in generate(self)
#    1021     def generate(self):
#    1022         self._args_adjust()
# -> 1023         self._compute_plot_data()
#    1024         self._setup_subplots()
#    1025         self._make_plot()
#
# C:\ANACON~1\lib\site-packages\pandas\tools\plotting.py in _compute_plot_data(self)
#    1130         if is_empty:
#    1131             raise TypeError('Empty {0!r}: no numeric data to '
# -> 1132                             'plot'.format(numeric_data.__class__.__name__))
#    1133
#    1134         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
death_by_EU.al2[death_by_EU.al2=="Strongly agree"]=5
death_by_EU.al2[death_by_EU.al2=="Agree"]=4
death_by_EU.al2[death_by_EU.al2=="Neither agree nor disagree"]=3
death_by_EU.al2[death_by_EU.al2=="Disagree"]=2
death_by_EU.al2[death_by_EU.al2=="Strongly disagree"]=1
death_by_EU.al2[death_by_EU.al2=="Don't know"]=0
# Out:
# C:\ANACON~1\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-675f54d779bf> in <module>()
# ----> 1 death_by_EU.al2[death_by_EU.al2=="Strongly agree"]=5
#       2 death_by_EU.al2[death_by_EU.al2=="Agree"]=4
#       3 death_by_EU.al2[death_by_EU.al2=="Neither agree nor disagree"]=3
#       4 death_by_EU.al2[death_by_EU.al2=="Disagree"]=2
#       5 death_by_EU.al2[death_by_EU.al2=="Strongly disagree"]=1
#
# C:\ANACON~1\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#     726         # do the setitem
#     727         cacher_needs_updating = self._check_is_chained_assignment_possible()
# --> 728         setitem(key, value)
#     729         if cacher_needs_updating:
#     730             self._maybe_update_cacher()
#
# C:\ANACON~1\lib\site-packages\pandas\core\series.py in setitem(key, value)
#     717                 key = check_bool_indexer(self.index, key)
#     718                 try:
# --> 719                     self.where(~key, value, inplace=True)
#     720                     return
#     721                 except InvalidIndexError:
#
# C:\ANACON~1\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    4425             new_data = self._data.putmask(mask=cond, new=other, align=align,
#    4426                                           inplace=True, axis=block_axis,
# -> 4427                                           transpose=self._AXIS_REVERSED)
#    4428             self._update_inplace(new_data)
#    4429
#
# C:\ANACON~1\lib\site-packages\pandas\core\internals.py in putmask(self, **kwargs)
#    2853
#    2854     def putmask(self, **kwargs):
# -> 2855         return self.apply('putmask', **kwargs)
#    2856
#    2857     def diff(self, **kwargs):
#
# C:\ANACON~1\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2830
#    2831             kwargs['mgr'] = self
# -> 2832             applied = getattr(b, f)(**kwargs)
#    2833             result_blocks = _extend_blocks(applied, result_blocks)
#    2834
#
# C:\ANACON~1\lib\site-packages\pandas\core\internals.py in putmask(self, mask, new, align, inplace, axis, transpose, mgr)
#    1339         if isinstance(new, np.ndarray) and len(new) == len(mask):
#    1340             new = new[mask]
# -> 1341         new_values[mask] = new
#    1342         new_values = self._try_coerce_result(new_values)
#    1343         return [self.make_block(values=new_values)]
#
# C:\ANACON~1\lib\site-packages\pandas\core\categorical.py in __setitem__(self, key, value)
#    1594         # something to np.nan
#    1595         if len(to_add) and not isnull(to_add).all():
# -> 1596             raise ValueError("Cannot setitem on a Categorical with a new "
#    1597                              "category, set the categories first")
#    1598
#
# ValueError: Cannot setitem on a Categorical with a new category, set the categories first

# %%
BES.al2[death_by_EU.al2=="Strongly agree"] = 5
#df.loc[df['A'] > 2, 'B'] = new_val
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-32eb56acb8c8> in <module>()
# ----> 1 BES.al2[death_by_EU.al2=="Strongly agree"] = 5
#       2 #df.loc[df['A'] > 2, 'B'] = new_val
#
# C:\ANACON~1\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#     726         # do the setitem
#     727         cacher_needs_updating = self._check_is_chained_assignment_possible()
# --> 728         setitem(key, value)
#     729         if cacher_needs_updating:
#     730             self._maybe_update_cacher()
#
# C:\ANACON~1\lib\site-packages\pandas\core\series.py in setitem(key, value)
#     717                 key = check_bool_indexer(self.index, key)
#     718                 try:
# --> 719                     self.where(~key, value, inplace=True)
#     720                     return
#     721                 except InvalidIndexError:
#
# C:\ANACON~1\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    4425             new_data = self._data.putmask(mask=cond, new=other, align=align,
#    4426                                           inplace=True, axis=block_axis,
# -> 4427                                           transpose=self._AXIS_REVERSED)
#    4428             self._update_inplace(new_data)
#    4429
#
# C:\ANACON~1\lib\site-packages\pandas\core\internals.py in putmask(self, **kwargs)
#    2853
#    2854     def putmask(self, **kwargs):
# -> 2855         return self.apply('putmask', **kwargs)
#    2856
#    2857     def diff(self, **kwargs):
#
# C:\ANACON~1\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    2830
#    2831             kwargs['mgr'] = self
# -> 2832             applied = getattr(b, f)(**kwargs)
#    2833             result_blocks = _extend_blocks(applied, result_blocks)
#    2834
#
# C:\ANACON~1\lib\site-packages\pandas\core\internals.py in putmask(self, mask, new, align, inplace, axis, transpose, mgr)
#    1339         if isinstance(new, np.ndarray) and len(new) == len(mask):
#    1340             new = new[mask]
# -> 1341         new_values[mask] = new
#    1342         new_values = self._try_coerce_result(new_values)
#    1343         return [self.make_block(values=new_values)]
#
# C:\ANACON~1\lib\site-packages\pandas\core\categorical.py in __setitem__(self, key, value)
#    1594         # something to np.nan
#    1595         if len(to_add) and not isnull(to_add).all():
# -> 1596             raise ValueError("Cannot setitem on a Categorical with a new "
#    1597                              "category, set the categories first")
#    1598
#
# ValueError: Cannot setitem on a Categorical with a new category, set the categories first

# %%
BES.al2.value_counts()
# Out:
# Strongly agree                8092
# Agree                         7446
# Strongly disagree             6850
# Disagree                      4316
# Neither agree nor disagree    3281
# Don't know                    1341
# dtype: int64

# %%
def score_to_numeric(x):
    if x=='Strongly agree':
        return 5
    if x=='Agree':
        return 4
    if x=='Neither agree nor disagree':
        return 3
    if x=='Disagree':
        return 2
    if x=='Strongly disagree':
        return 1
    if x=="Don't know":
        return 0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


BES.al2.apply(score_to_numeric).hist(by=BES.euRefVote,bins=6)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000000F422F98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000010898F98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000000108ED748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000001092A400>]], dtype=object)

# %%
BES.al2
# Out:
# 0                    Strongly agree
# 1                          Disagree
# 2                    Strongly agree
# 3                 Strongly disagree
# 4                    Strongly agree
# 5        Neither agree nor disagree
# 6                    Strongly agree
# 7                 Strongly disagree
# 8                        Don't know
# 9        Neither agree nor disagree
# 10                            Agree
# 11       Neither agree nor disagree
# 12                            Agree
# 13                            Agree
# 14                   Strongly agree
# 15                   Strongly agree
# 16       Neither agree nor disagree
# 17                            Agree
# 18                   Strongly agree
# 19                Strongly disagree
# 20                   Strongly agree
# 21                Strongly disagree
# 22                Strongly disagree
# 23                         Disagree
# 24                         Disagree
# 25       Neither agree nor disagree
# 26                            Agree
# 27       Neither agree nor disagree
# 28                Strongly disagree
# 29                Strongly disagree
#                     ...
# 31379             Strongly disagree
# 31380             Strongly disagree
# 31381    Neither agree nor disagree
# 31382                      Disagree
# 31383                      Disagree
# 31384                         Agree
# 31385                      Disagree
# 31386                         Agree
# 31387                Strongly agree
# 31388                         Agree
# 31389                           NaN
# 31390                      Disagree
# 31391                      Disagree
# 31392    Neither agree nor disagree
# 31393             Strongly disagree
# 31394                           NaN
# 31395             Strongly disagree
# 31396                      Disagree
# 31397    Neither agree nor disagree
# 31398    Neither agree nor disagree
# 31399    Neither agree nor disagree
# 31400                Strongly agree
# 31401                         Agree
# 31402    Neither agree nor disagree
# 31403                    Don't know
# 31404                    Don't know
# 31405                Strongly agree
# 31406             Strongly disagree
# 31407                      Disagree
# 31408                         Agree
# Name: al2, dtype: category
# Categories (6, object): [Strongly disagree < Disagree < Neither agree nor disagree < Agree < Strongly agree < Don't know]
