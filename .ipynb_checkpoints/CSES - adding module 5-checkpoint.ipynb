# %%
## Processes module 5
# outputs CSES_int_5 dataframe ready to be appended to the CSES IMD dataset
# also outputs the CSES_int_final dataframe of CSES IMD with module 5 appended and dtypes cleaned up a little

# %%
# %%time
# %matplotlib inline
# %run Prosser_header.py
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# Wall time: 3.42 s

# %%
dataset_folder = "C:\\Users\\Marios\\Documents\\GitHub\\Thomas Prosser project\\datasets\\"
output_folder = "C:\\Users\\Marios\\Documents\\GitHub\\Thomas Prosser project\\output\\"

# %%
CSES_int = pd.read_stata(dataset_folder + "CSES"+os.sep+"integrated 1-4"+os.sep+"cses_imd.dta")

# %%
CSES_5 = pd.read_stata(dataset_folder + "CSES"+os.sep+"module 5"+os.sep+"cses5.dta")

# %%
def get_dta_meta(fn):
    reader = pd.io.stata.StataReader( fn )
    header = reader.variable_labels()
    labels = reader.value_labels()
    return header,labels

header5,labels5 = get_dta_meta(dataset_folder + "CSES"+os.sep+"module 5"+os.sep+"cses5.dta")
header4,labels4 = get_dta_meta(dataset_folder + "CSES"+os.sep+"module 4"+os.sep+"cses4.dta")
header3,labels3 = get_dta_meta(dataset_folder + "CSES"+os.sep+"module 3"+os.sep+"cses3.dta")
header2,labels2 = get_dta_meta(dataset_folder + "CSES"+os.sep+"module 2"+os.sep+"cses2.dta")
header1,labels1 = get_dta_meta(dataset_folder + "CSES"+os.sep+"module 1"+os.sep+"cses1.dta")
headerINT,labelsINT = get_dta_meta(dataset_folder + "CSES"+os.sep+"integrated 1-4"+os.sep+"cses_imd.dta")

# %%
CSES_int_5 = CSES_int.loc[[]].copy()

# %%
Int_variable_df_fi = pd.read_csv(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"Int_variable_df_filledin.csv")

# %%
Int_variable_df_fi["var_descr_E"].isnull().sum()
# Out:
# 21

# %%
int_or_ds_specific = (Int_variable_df_fi["INT_only"].notnull() | Int_variable_df_fi["Dataset_specific"].notnull())

# %%
Int_variable_df_fi[int_or_ds_specific&Int_variable_df_fi["var_descr_E"].notnull()]
# Out:
#       Unnamed: 0                                        description  \
# 0        IMD1001                                            dataset
# 1    IMD1002_VER                                    DATASET VERSION
# 2    IMD1002_DOI                          DIGITAL OBJECT IDENTIFIER
# 29     IMD1014_1  INTERVIEW TIMING - NUMBER OF DAYS BETWEEN INTE...
# 30     IMD1014_2  INTERVIEW TIMING - NUMBER OF DAYS BETWEEN INTE...
# 33     IMD1016_2                   MODE OF INTERVIEW - STUDY SECOND
# 34     IMD1016_3                    MODE OF INTERVIEW - STUDY THIRD
# 117    IMD5000_A                     PARTY A IDENTIFIER - NUMERICAL
# 118    IMD5000_B                     PARTY B IDENTIFIER - NUMERICAL
# 119    IMD5000_C                     PARTY C IDENTIFIER - NUMERICAL
# 120    IMD5000_D                     PARTY D IDENTIFIER - NUMERICAL
# 121    IMD5000_E                     PARTY E IDENTIFIER - NUMERICAL
# 122    IMD5000_F                     PARTY F IDENTIFIER - NUMERICAL
# 123    IMD5000_G                     PARTY G IDENTIFIER - NUMERICAL
# 124    IMD5000_H                     PARTY H IDENTIFIER - NUMERICAL
# 125    IMD5000_I                     PARTY I IDENTIFIER - NUMERICAL
#
#           20% matching contents_A  20% matching contents(length)_A  \
# 0                              {}                                0
# 1                              {}                                0
# 2                              {}                                0
# 29   {'A2026': 0.515839061673797}                                1
# 30                             {}                                0
# 33                             {}                                0
# 34                             {}                                0
# 117                            {}                                0
# 118                            {}                                0
# 119                            {}                                0
# 120                            {}                                0
# 121                            {}                                0
# 122                            {}                                0
# 123                            {}                                0
# 124                            {}                                0
# 125                            {}                                0
#
#      Top Score_A Top Match_A  \
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 29      0.515839       A2026
# 30           NaN         NaN
# 33           NaN         NaN
# 34           NaN         NaN
# 117          NaN         NaN
# 118          NaN         NaN
# 119          NaN         NaN
# 120          NaN         NaN
# 121          NaN         NaN
# 122          NaN         NaN
# 123          NaN         NaN
# 124          NaN         NaN
# 125          NaN         NaN
#
#                                20% matching contents_B  \
# 0                                                   {}
# 1                                                   {}
# 2                                                   {}
# 29                       {'B2032': 0.5855795567729084}
# 30                                                  {}
# 33   {'B3020': 0.8771632221115537, 'B3008': 0.83414...
# 34   {'B3020': 1.0, 'B3008': 0.9334225597609562, 'B...
# 117                                                 {}
# 118                                                 {}
# 119                                                 {}
# 120                                                 {}
# 121                                                 {}
# 122                                                 {}
# 123                                                 {}
# 124                                                 {}
# 125                                                 {}
#
#      20% matching contents(length)_B  Top Score_B Top Match_B  ...  \
# 0                                  0          NaN         NaN  ...
# 1                                  0          NaN         NaN  ...
# 2                                  0          NaN         NaN  ...
# 29                                 1     0.585580       B2032  ...
# 30                                 0          NaN         NaN  ...
# 33                                22     0.877163       B3020  ...
# 34                                22     1.000000       B3020  ...
# 117                                0          NaN         NaN  ...
# 118                                0          NaN         NaN  ...
# 119                                0          NaN         NaN  ...
# 120                                0          NaN         NaN  ...
# 121                                0          NaN         NaN  ...
# 122                                0          NaN         NaN  ...
# 123                                0          NaN         NaN  ...
# 124                                0          NaN         NaN  ...
# 125                                0          NaN         NaN  ...
#
#     var_descr_C  var_descr_D  var_descr_E Match_A_discrepancy  \
# 0         C1001        D1001        E1001                 NaN
# 1     C1002_VER    D1002_VER    E1002_VER                 NaN
# 2     C1002_DOI    D1002_DOI    E1002_DOI                 NaN
# 29        C2032        D1029      E1035_1                 NaN
# 30          NaN          NaN      E1035_2                 NaN
# 33          NaN          NaN      E1024_2                 NaN
# 34          NaN          NaN      E1024_3                 NaN
# 117         NaN          NaN      E5000_A                 NaN
# 118         NaN          NaN      E5000_B                 NaN
# 119         NaN          NaN      E5000_C                 NaN
# 120         NaN          NaN      E5000_D                 NaN
# 121         NaN          NaN      E5000_E                 NaN
# 122         NaN          NaN      E5000_F                 NaN
# 123         NaN          NaN      E5000_G                 NaN
# 124         NaN          NaN      E5000_H                 NaN
# 125         NaN          NaN      E5000_I                 NaN
#
#     Match_B_discrepancy  Match_C_discrepancy  Match_D_discrepancy INT_only  \
# 0                   NaN                  NaN                  NaN      NaN
# 1                   NaN                  NaN                  NaN      NaN
# 2                   NaN                  NaN                  NaN      NaN
# 29                  NaN                  NaN                  NaN        x
# 30                  NaN                  NaN                  NaN        x
# 33                  NaN                  NaN                  NaN        x
# 34                  NaN                  NaN                  NaN        x
# 117                 NaN                  NaN                  NaN        x
# 118                 NaN                  NaN                  NaN        x
# 119                 NaN                  NaN                  NaN        x
# 120                 NaN                  NaN                  NaN        x
# 121                 NaN                  NaN                  NaN        x
# 122                 NaN                  NaN                  NaN        x
# 123                 NaN                  NaN                  NaN        x
# 124                 NaN                  NaN                  NaN        x
# 125                 NaN                  NaN                  NaN        x
#
#     Dataset_specific notes
# 0                  x   NaN
# 1                  x   NaN
# 2                  x   NaN
# 29               NaN   NaN
# 30               NaN   NaN
# 33               NaN   NaN
# 34               NaN   NaN
# 117              NaN   NaN
# 118              NaN   NaN
# 119              NaN   NaN
# 120              NaN   NaN
# 121              NaN   NaN
# 122              NaN   NaN
# 123              NaN   NaN
# 124              NaN   NaN
# 125              NaN   NaN
#
# [16 rows x 30 columns]

# %%
Int_variable_df_fi[ Int_variable_df_fi["var_descr_E"].isnull() & ~int_or_ds_specific ]
# Out:
#           Unnamed: 0                                        description  \
# 35         IMD2001_1                       AGE OF RESPONDENT (IN YEARS)
# 55   IMD3002_UH_DC_3  CURRENT UPPER HOUSE ELECTION: VOTE CHOICE - DI...
# 56   IMD3002_UH_DC_4  CURRENT UPPER HOUSE ELECTION: VOTE CHOICE - DI...
# 69   IMD3004_UH_DC_3  PREVIOUS UPPER HOUSE ELECTION: VOTE CHOICE - D...
# 106        IMD3013_2                          STATE OF ECONOMY - BETTER
# 107        IMD3013_3                           STATE OF ECONOMY - WORSE
# 109        IMD3015_1     DICHOTOMIZED POLITICAL INFORMATION ITEM  - 1ST
# 110        IMD3015_2     DICHOTOMIZED POLITICAL INFORMATION ITEM  - 2ND
# 111        IMD3015_3     DICHOTOMIZED POLITICAL INFORMATION ITEM  - 3RD
# 112        IMD3015_4     DICHOTOMIZED POLITICAL INFORMATION ITEM  - 4TH
# 225        IMD5026_2             NUMBER OF ELECTED LEGISLATIVE CHAMBERS
#
#                                20% matching contents_A  \
# 35                        {'A2001': 0.959428928519925}
# 55                                                  {}
# 56                                                  {}
# 69                                                  {}
# 106                     {'A3024': 0.25086125398580333}
# 107                     {'A3025': 0.22650579243378358}
# 109  {'A2023': 0.5196365908763159, 'A2024': 0.29665...
# 110  {'A2024': 0.35490073547084555, 'A2023': 0.2966...
# 111  {'A2025': 0.23881170984954092, 'A2023': 0.2071...
# 112                                                 {}
# 225                                                 {}
#
#      20% matching contents(length)_A  Top Score_A Top Match_A  \
# 35                                 1     0.959429       A2001
# 55                                 0          NaN         NaN
# 56                                 0          NaN         NaN
# 69                                 0          NaN         NaN
# 106                                1     0.250861       A3024
# 107                                1     0.226506       A3025
# 109                                3     0.519637       A2023
# 110                                2     0.354901       A2024
# 111                                2     0.238812       A2025
# 112                                0          NaN         NaN
# 225                                0          NaN         NaN
#
#                                20% matching contents_B  \
# 35                       {'B2001': 0.9631318476095617}
# 55                                                  {}
# 56                                                  {}
# 69                                                  {}
# 106  {'B3020': 0.9991284860557769, 'B3008': 0.93255...
# 107  {'B3020': 0.9891060756972112, 'B3008': 0.92252...
# 109  {'B3047_1': 0.7850317480079682, 'B3047_2': 0.5...
# 110  {'B3047_2': 0.6104488296812749, 'B3047_1': 0.5...
# 111  {'B3047_3': 0.43275336155378485, 'B3047_1': 0....
# 112  {'B3020': 1.0, 'B3008': 0.9334225597609562, 'B...
# 225                                                 {}
#
#      20% matching contents(length)_B  Top Score_B Top Match_B  ...  \
# 35                                 1     0.963132       B2001  ...
# 55                                 0          NaN         NaN  ...
# 56                                 0          NaN         NaN  ...
# 69                                 0          NaN         NaN  ...
# 106                               22     0.999128       B3020  ...
# 107                               22     0.989106       B3020  ...
# 109                                3     0.785032     B3047_1  ...
# 110                                3     0.610449     B3047_2  ...
# 111                                3     0.432753     B3047_3  ...
# 112                               22     1.000000       B3020  ...
# 225                                0          NaN         NaN  ...
#
#        var_descr_C  var_descr_D  var_descr_E Match_A_discrepancy  \
# 35           C2001          NaN          NaN                 NaN
# 55   C3023_UH_DC_3          NaN          NaN                 NaN
# 56   C3023_UH_DC_4          NaN          NaN                 NaN
# 69             NaN          NaN          NaN                 NaN
# 106            NaN      D3003_2          NaN                 NaN
# 107            NaN      D3003_3          NaN                 NaN
# 109        C3036_1    D3025_1_A          NaN                 NaN
# 110        C3036_2    D3025_2_A          NaN                 NaN
# 111        C3036_3    D3025_3_A          NaN                 NaN
# 112            NaN    D3025_4_A          NaN                 NaN
# 225            NaN          NaN          NaN                 NaN
#
#     Match_B_discrepancy  Match_C_discrepancy  Match_D_discrepancy INT_only  \
# 35                  NaN                  NaN                  NaN      NaN
# 55                  NaN                  NaN                  NaN      NaN
# 56                  NaN                  NaN                  NaN      NaN
# 69                  NaN                  NaN                  NaN      NaN
# 106                 NaN                  NaN                  NaN      NaN
# 107                 NaN                  NaN                False      NaN
# 109                 NaN                  NaN                  NaN      NaN
# 110                 NaN                  NaN                  NaN      NaN
# 111                 NaN                  NaN                  NaN      NaN
# 112                 NaN                  NaN                  NaN      NaN
# 225                 NaN                  NaN                  NaN      NaN
#
#     Dataset_specific                                              notes
# 35               NaN  In mod 4/5, it becomes date of birth 2001_M,20...
# 55               NaN                                                NaN
# 56               NaN                                                NaN
# 69               NaN                                                NaN
# 106              NaN                                                NaN
# 107              NaN                                                NaN
# 109              NaN                                                NaN
# 110              NaN                                                NaN
# 111              NaN                                                NaN
# 112              NaN                                                NaN
# 225              NaN                                                NaN
#
# [11 rows x 30 columns]

# %%
missing_dict = dict(zip(["99. MISSING","97. VOLUNTEERED: REFUSED","98. VOLUNTEERED: DON'T KNOW",
                "9997. VOLUNTEERED: REFUSED","9998. VOLUNTEERED: DON'T KNOW","9999. MISSING"],[np.nan]*6))
CSES_5["E2001_Y"].value_counts().sort_index()

birth_year = CSES_5["E2001_Y"].replace(missing_dict).astype(float)
birth_year

birth_month = CSES_5["E2001_M"].replace(missing_dict).apply(lambda x: int(x[0:2]) if pd.notnull(x) else np.nan)
birth_month.value_counts()

#     E2001_M      >>> D01a    DATE OF BIRTH OF RESPONDENT - MONTH
#     E2001_Y      >>> D01b    DATE OF BIRTH OF RESPONDENT - YEAR


# lots of mossing months, a lot of studies didn't ask for birth year/month but age - either at a fixed point (June 30th)
# or at the interview time ... kind of unclear why they didn't include an age column!
# I guess we just set month as June by default and day by 14

birth_year.isnull().sum(),birth_month.isnull().sum()

# when year present but month missing, replace with June (most common and also the ref point used for some studies)
birth_month[birth_year.notnull()&birth_month.isnull()] = 6.0
# when month present but year missing (N=34), drop month so this is recorded as birthdate unknown!
birth_month[birth_year.isnull()&birth_month.notnull()] = np.nan

birth_date = pd.to_datetime((birth_year.astype(str)+birth_month.astype(str)).apply(lambda x: x.replace(".0","\\")+"14" if x!="nannan" else np.nan),
              format = "%Y\\%M\\%d")

# %%
#     E1016        >>>         DATE 1ST ROUND ELECTION BEGAN - MONTH
#     E1017        >>>         DATE 1ST ROUND ELECTION BEGAN - DAY
#     E1018        >>>         DATE 1ST ROUND ELECTION BEGAN - YEAR

# figure out election date

election_date = pd.to_datetime(CSES_5["E1018"].astype(str)+"\\"+CSES_5["E1016"].apply(lambda x: x[0:2]).astype(str)+"\\"+CSES_5["E1017"].astype(str),
               format = "%Y\\%M\\%d")

age_at_election = (election_date - birth_date).dt.days/365.25
age_at_election.hist(bins=100)
age_at_election = age_at_election.apply(lambda x: np.floor(x))


missing_value_rows = CSES_5["E2001_Y"].apply(lambda x: x in missing_dict.keys())
age_at_election[missing_value_rows] = CSES_5["E2001_Y"][missing_value_rows]

# age in years
CSES_int_5["IMD2001_1"] = age_at_election

# age in categories
age_at_election[~missing_value_rows.astype('bool')] = pd.cut(age_at_election[~missing_value_rows.astype('bool')],
       bins = [0,24,34,44,54,64,200],
       labels = CSES_int["IMD2001_2"].cat.categories[0:6])

CSES_int_5["IMD2001_2"] = age_at_election

# %%
int_to_mod5 = Int_variable_df_fi[Int_variable_df_fi["var_descr_E"].notnull()].set_index("Unnamed: 0")["var_descr_E"]

# %%
## okay - by inspection
# float64, int16, object dtypes 
for int_var in CSES_int[int_to_mod5.index].select_dtypes('float64').columns:
    CSES_int_5[int_var] = CSES_5[int_to_mod5.loc[int_var]]

for int_var in CSES_int[int_to_mod5.index].select_dtypes('int16').columns:
    CSES_int_5[int_var] = CSES_5[int_to_mod5.loc[int_var]]
    
for int_var in CSES_int[int_to_mod5.index].select_dtypes('object').columns:
    CSES_int_5[int_var] = CSES_5[int_to_mod5.loc[int_var]]

# %%
int_cats = CSES_int[int_to_mod5.index].select_dtypes('category').apply(lambda x: "|".join([str(x) for x in x.cat.categories]))

# %%
mod5_cats = CSES_5[int_to_mod5.values].select_dtypes('category').apply(lambda x: "|".join([str(x) for x in x.cat.categories]))

# %%
matched_cats = CSES_int[int_to_mod5.index].select_dtypes('category').columns[(int_cats.values == mod5_cats.values)]
matched_cats
# Out:
# Index(['IMD2006', 'IMD2007', 'IMD3005_4', 'IMD3006', 'IMD3007_A', 'IMD3007_B',
#        'IMD3007_C', 'IMD3007_D', 'IMD3007_E', 'IMD3007_F', 'IMD3007_G',
#        'IMD3007_H', 'IMD3007_I', 'IMD3008_A', 'IMD3008_B', 'IMD3008_C',
#        'IMD3008_D', 'IMD3008_E', 'IMD3008_F', 'IMD3008_G', 'IMD3008_H',
#        'IMD3008_I', 'IMD3009_A', 'IMD3009_B', 'IMD3009_C', 'IMD3009_D',
#        'IMD3009_E', 'IMD3009_F', 'IMD3009_G', 'IMD3009_H', 'IMD3009_I',
#        'IMD3011', 'IMD3012', 'IMD5007', 'IMD5013', 'IMD5016_4', 'IMD5017_4',
#        'IMD5018_2', 'IMD5018_4', 'IMD5031_I'],
#       dtype='object')

# %%
for int_var in matched_cats:
    CSES_int_5[int_var] = CSES_5[int_to_mod5.loc[int_var]]

# %%
unmatched_cats = CSES_int[int_to_mod5.index].select_dtypes('category').columns[(int_cats.values != mod5_cats.values)]
unmatched_cats
# Out:
# Index(['IMD1003', 'IMD1007', 'IMD1009', 'IMD1011_M', 'IMD1011_D', 'IMD1011_Y',
#        'IMD1012_M', 'IMD1012_D', 'IMD1012_Y', 'IMD1013_M',
#        ...
#        'IMD5056_1', 'IMD5056_2', 'IMD5056_3', 'IMD5057_1', 'IMD5057_2',
#        'IMD5057_3', 'IMD5058_1', 'IMD5058_2', 'IMD5059_1', 'IMD5059_2'],
#       dtype='object', length=202)

# %%
int_modes = CSES_int[unmatched_cats].describe(include='all').loc["top"]

# %%
mod5_modes = CSES_5[int_to_mod5.loc[unmatched_cats]].describe(include='all').loc["top"]

# %%
(int_modes.values==mod5_modes.values).sum(),(int_modes.values!=mod5_modes.values).sum(),
# Out:
# (79, 123)

# %%
int_cats_alpha = int_cats[unmatched_cats].apply(lambda x: "|".join( [cat for cat in x.split("|") if np.isnan(pd.to_numeric(cat,errors='coerce'))]))
int_cats_num = int_cats[unmatched_cats].apply(lambda x: [float(cat) for cat in x.split("|") if not np.isnan(pd.to_numeric(cat,errors='coerce'))]).apply(lambda x: (np.max(x),np.min(x)) if x!=[] else np.nan)
int_cats_num
# Out:
# IMD1003                          NaN
# IMD1007                          NaN
# IMD1009                          NaN
# IMD1011_M                        NaN
# IMD1011_D                (31.0, 1.0)
#                       ...
# IMD5057_3    (309326304.0, 271128.0)
# IMD5058_1               (14.1, 1.32)
# IMD5058_2             (150.96, 2.15)
# IMD5059_1              (13.33, 1.16)
# IMD5059_2             (121.76, 1.75)
# Length: 202, dtype: object

# %%
mod_cats_alpha = mod5_cats[int_to_mod5.loc[unmatched_cats]].apply(lambda x: "|".join([cat for cat in x.split("|") if np.isnan(pd.to_numeric(cat,errors='coerce'))]))
mod_cats_num = mod5_cats[int_to_mod5.loc[unmatched_cats]].apply(lambda x: [float(cat) for cat in x.split("|") if not np.isnan(pd.to_numeric(cat,errors='coerce'))]).apply(lambda x: (np.max(x),np.min(x)) if x!=[] else np.nan)
mod_cats_num
# Out:
# var_descr_E
# E1003                          NaN
# E1007                          NaN
# E1015                          NaN
# E1016                          NaN
# E1017                  (29.0, 4.0)
#                     ...
# E5098_3    (318622528.0, 327386.0)
# E5078                (18.02, 2.82)
# E5079                (18.02, 2.82)
# E5080                (16.54, 2.09)
# E5081                (16.54, 2.09)
# Length: 202, dtype: object

# %%
int_cats_alpha[unmatched_cats][int_cats_alpha.values != mod_cats_alpha.values]
# Out:
# IMD1003      00802005. ALBANIA (2005)|03202015. ARGENTINA (...
# IMD1007      001. [SEE ELECTION STUDY NOTES]|002. [SEE ELEC...
# IMD1009      10. PARLIAMENTARY/LEGISLATIVE|12. PARLIAMENTAR...
# IMD1011_M    01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...
# IMD1012_M    01. JANUARY|03. MARCH|04. APRIL|05. MAY|06. JU...
#                                    ...
# IMD5057_2    999999999. MISSING AND/OR NOT AVAILABLE AT TIM...
# IMD5058_1    997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCU...
# IMD5058_2    997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCU...
# IMD5059_1    997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCU...
# IMD5059_2    997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCU...
# Length: 129, dtype: object

# %%
mod_cats_alpha[int_to_mod5.loc[unmatched_cats]][int_cats_alpha.values != mod_cats_alpha.values]
# Out:
# var_descr_E
# E1003      03602019. AUSTRALIA (2019)|04002017. AUSTRIA (...
# E1007      001. [SEE ELECTION STUDY NOTES]|002. [SEE ELEC...
# E1015      10. PARLIAMENTARY/LEGISLATIVE|12. PARLIAMENTAR...
# E1016      01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...
# E1019      05. MAY|10. OCTOBER|12. DECEMBER|96. NOT APPLI...
#                                  ...
# E5098_2
# E5078      997. PRESIDENTIAL ELECTION ONLY - NOT CALCULAT...
# E5079      997. PRESIDENTIAL ELECTION ONLY - NOT CALCULAT...
# E5080      997. PRESIDENTIAL ELECTION ONLY - NOT CALCULAT...
# E5081      997. PRESIDENTIAL ELECTION ONLY - NOT CALCULAT...
# Length: 129, dtype: object

# %%
mod5_int_category_discrepancies = pd.DataFrame()
mod5_int_category_discrepancies["int_var"] = int_cats_alpha[unmatched_cats][int_cats_alpha.values != mod_cats_alpha.values].index
mod5_int_category_discrepancies["int_cat"] = int_cats_alpha[unmatched_cats][int_cats_alpha.values != mod_cats_alpha.values].values
mod5_int_category_discrepancies["mod_var"] = mod_cats_alpha[int_to_mod5.loc[unmatched_cats]][int_cats_alpha.values != mod_cats_alpha.values].index
mod5_int_category_discrepancies["mod_cat"] = mod_cats_alpha[int_to_mod5.loc[unmatched_cats]][int_cats_alpha.values != mod_cats_alpha.values].values

# %%
mod5_int_category_discrepancies.to_csv(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"mod5_int_category_discrepancies.csv")

# %%
# (set(int_to_mod5.index) - set(unmatched_cats)) - set(matched_cats)

# discrepancy between matched and unmatched cats == 'float64','int16','object' columns

# %%
# CSES_5["E1016"].value_counts()
# really, no december
# 21 studies ... pretty realistic

# %%
# CSES_5["E1019"].value_counts()
# CSES_int_5["IMD1016_1"]

# %%
# IMD1015 and E1023 - same variable name, but different contents
# -> one is about study timing, the other about study context
# updated in csv

int_to_mod5.drop("IMD1015",errors='ignore',inplace=True)

# %%
def replace_categories(ser, replace_dict, int_ser):
    return ser.replace(replace_dict).astype('category').cat.set_categories(int_ser.cat.categories,
                                                                                    ordered = int_ser.cat.ordered)

# %%
#{IMD1016_1, E1024_1}
# need to be harmonized!
# 1. FACE-TO-FACE|2. TELEPHONE|3. MAIL OR SELF-COMPLETED SUPPLEMENT|4. INTERNET|9. MISSING
# 1. IN PERSON, FACE-TO-FACE - USING A QUESTIONNAIRE ON PAPER|2. IN PERSON, FACE-TO-FACE - USING AN ELECTRONIC/COMPUTERIZED QUESTIONNAIRE|3. TELEPHONE|4. MAIL OR SELF-COMPLETION SUPPLEMENT|5. INTERNET

# IMD1016_2	3. MAIL OR SELF-COMPLETED SUPPLEMENT|9. MISSING	E1024_2	0. NOT APPLICABLE|3. TELEPHONE|5. INTERNET
# IMD1016_3	9. MISSING	E1024_3	0. NOT APPLICABLE

# CSES_5["E1024_1"].value_counts()

replace_dict = {"0. NOT APPLICABLE":"9. MISSING",
    "1. IN PERSON, FACE-TO-FACE - USING A QUESTIONNAIRE ON PAPER":"1. FACE-TO-FACE",
 "2. IN PERSON, FACE-TO-FACE - USING AN ELECTRONIC/COMPUTERIZED QUESTIONNAIRE":"1. FACE-TO-FACE",
 "3. TELEPHONE":"2. TELEPHONE",
 "4. MAIL OR SELF-COMPLETION SUPPLEMENT":"3. MAIL OR SELF-COMPLETED SUPPLEMENT",
 "5. INTERNET":"4. INTERNET",}




# temp = CSES_5["E1024_1"].replace(replace_dict).astype('category').cat.set_categories(CSES_int["IMD1016_1"].cat.categories,
#                                                                                     ordered = CSES_int["IMD1016_1"].cat.ordered)

# CSES_int["IMD1016_1"].append(temp)

# CSES_int_5["IMD1016_1"]

CSES_int_5["IMD1016_1"] = replace_categories(CSES_5["E1024_1"], replace_dict, CSES_int["IMD1016_1"])
CSES_int_5["IMD1016_2"] = replace_categories(CSES_5["E1024_2"], replace_dict, CSES_int["IMD1016_1"])
CSES_int_5["IMD1016_3"] = replace_categories(CSES_5["E1024_3"], replace_dict, CSES_int["IMD1016_1"])

# %%
# gender: trivial harmonising
# IMD2002	1. MALE|2. FEMALE|3. [SEE ELECTION STUDY NOTES]|7. REFUSED|9. MISSING	E2002	1. MALE|2. FEMALE|3. [SEE ELECTION STUDY NOTES]|7. VOLUNTEERED: REFUSED|9. MISSING

rename_dict = {"7. VOLUNTEERED: REFUSED":"7. REFUSED"}
CSES_int_5["IMD2002"] = CSES_5["E2002"].cat.rename_categories(rename_dict)

# %%
# education: non-trivial harmonising
# IMD2003	0. NONE (NO EDUCATION) / ILLITERATE|1. PRIMARY EDUCATION/LOWER SECONDARY EDUCATION|2. HIGHER SECONDARY EDUCATION|3. POST-SECONDARY (NON-UNIVERSITY) EDUCATION|4. UNIVERSITY EDUCATION|6. OTHER|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING	E2003	01. ISCED LEVEL 0 - EARLY CHILDHOOD EDUCATION|02. ISCED LEVEL 1 - PRIMARY|03. ISCED LEVEL 2 - LOWER SECONDARY|04. ISCED LEVEL 3 - UPPER SECONDARY|05. ISCED LEVEL 4 - POST-SECONDARY NON-TERTIARY|06. ISCED LEVEL 5 - SHORT-CYCLE TERTIARY|07. ISCED LEVEL 6 - BACHELOR OR EQUIVALENT|08. ISCED LEVEL 7 - MASTER OR EQUIVALENT|09. ISCED LEVEL 8 - DOCTORAL OR EQUIVALENT|96. NONE (NO EDUCATION)|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING

# Mod 5
#  01. ISCED LEVEL 0 - EARLY CHILDHOOD EDUCATION
#  02. ISCED LEVEL 1 - PRIMARY
#  03. ISCED LEVEL 2 - LOWER SECONDARY
#  04. ISCED LEVEL 3 - UPPER SECONDARY
#  05. ISCED LEVEL 4 - POST-SECONDARY NON-TERTIARY
#  06. ISCED LEVEL 5 - SHORT-CYCLE TERTIARY
#  07. ISCED LEVEL 6 - BACHELOR OR EQUIVALENT
#  08. ISCED LEVEL 7 - MASTER OR EQUIVALENT
#  09. ISCED LEVEL 8 - DOCTORAL OR EQUIVALENT

#  96. NONE (NO EDUCATION)

#  97. VOLUNTEERED: REFUSED
#  98. VOLUNTEERED: DON'T KNOW

#  99. MISSING

# IMD 

#  0. NONE (NO EDUCATION)/ILLITERATE
#  1. PRIMARY EDUCATION/LOWER SECONDARY EDUCATION
#  2. HIGHER SECONDARY EDUCATION
#  3. POST-SECONDARY (NON-UNIVERSITY) EDUCATION 
#  4. UNIVERSITY EDUCATION
#  6. OTHER [SEE Standalone CSES MODULE CODEBOOK]

#  7. VOLUNTEERED: REFUSED
#  8. VOLUNTEERED: DON'T KNOW

#  9. MISSING

#  |      +++ TABLE: MAPPING OF EDUCATION CODES IN CSES MODULE 4
#  |                  TO EDUCATION CODES IN CSES IMD
#  | 
#  | IMD CODE   CSES MODULE 4 CLASSIFICATION (CSES MODULE 4 CODE)
#  |-----------------------------------------------------------------
#  |        0.  None/ISCED Level 0 - Early Childhood Education (0/96)
#  |        1.  ISCED Level 1 - Primary & ISCED Level 2 Lower
#  |            Secondary (2/3)
#  |        2.  ISCED Level 3 - Upper Secondary
#  |        3.  ISCED Level 4 - Post-Secondary Non-Tertiary
#  |            ISCED Level 5 - Short-Cycle Tertiary
#  |        4.  ISCED Level 6 - Bachelor or equivalent
#  |            ISCED Level 7 - Master or equivalent
#  |            ISCED Level 8 - Doctoral or equivalent


replace_dict = {      '01. ISCED LEVEL 0 - EARLY CHILDHOOD EDUCATION':'0. NONE (NO EDUCATION) / ILLITERATE',
       '02. ISCED LEVEL 1 - PRIMARY':'1. PRIMARY EDUCATION/LOWER SECONDARY EDUCATION',
       '03. ISCED LEVEL 2 - LOWER SECONDARY':'1. PRIMARY EDUCATION/LOWER SECONDARY EDUCATION',
       '04. ISCED LEVEL 3 - UPPER SECONDARY':'2. HIGHER SECONDARY EDUCATION',
       '05. ISCED LEVEL 4 - POST-SECONDARY NON-TERTIARY':'3. POST-SECONDARY (NON-UNIVERSITY) EDUCATION',
       '06. ISCED LEVEL 5 - SHORT-CYCLE TERTIARY':'3. POST-SECONDARY (NON-UNIVERSITY) EDUCATION',
       '07. ISCED LEVEL 6 - BACHELOR OR EQUIVALENT':'4. UNIVERSITY EDUCATION',
       '08. ISCED LEVEL 7 - MASTER OR EQUIVALENT':'4. UNIVERSITY EDUCATION',
       '09. ISCED LEVEL 8 - DOCTORAL OR EQUIVALENT':'4. UNIVERSITY EDUCATION',
       '96. NONE (NO EDUCATION)':'0. NONE (NO EDUCATION) / ILLITERATE',
       '97. VOLUNTEERED: REFUSED':'7. VOLUNTEERED: REFUSED',
       "98. VOLUNTEERED: DON'T KNOW":"8. VOLUNTEERED: DON'T KNOW",
       '99. MISSING':'9. MISSING'}


CSES_int_5["IMD2003"] = replace_categories(CSES_5["E2003"], replace_dict, CSES_int["IMD2003"])

# %%
# marital: trivial harmonising
# IMD2004	1. MARRIED OR LIVING TOGETHER AS MARRIED|2. WIDOWED|3. DIVORCED OR SEPARATED (MARRIED BUT SEPARATED/NOT LIVING WITH LEGAL SPOUSE)|4. SINGLE, NEVER MARRIED|5. [SEE ELECTION STUDY NOTES]|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING	E2004	1. MARRIED OR LIVING TOGETHER AS MARRIED|2. WIDOWED|3. DIVORCED OR SEPARATED|4. SINGLE, NEVER MARRIED|5. [SEE ELECTION STUDY NOTES]|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING

rename_dict = {'1. MARRIED OR LIVING TOGETHER AS MARRIED': '1. MARRIED OR LIVING TOGETHER AS MARRIED',
 '2. WIDOWED': '2. WIDOWED',
 '3. DIVORCED OR SEPARATED': '3. DIVORCED OR SEPARATED (MARRIED BUT SEPARATED/NOT LIVING WITH LEGAL SPOUSE)',
 '4. SINGLE, NEVER MARRIED': '4. SINGLE, NEVER MARRIED',
 '5. [SEE ELECTION STUDY NOTES]': '5. [SEE ELECTION STUDY NOTES]',
 '7. VOLUNTEERED: REFUSED': '7. VOLUNTEERED: REFUSED',
 "8. VOLUNTEERED: DON'T KNOW": "8. VOLUNTEERED: DON'T KNOW",
 '9. MISSING': '9. MISSING'}

CSES_int_5["IMD2004"] = CSES_5["E2004"].cat.rename_categories(rename_dict)

# %%
# religion: non-trivial harmonising
# IMD2005	1. CATHOLIC|2. PROTESTANT|3. ORTHODOX/EASTERN CATHOLIC CHURCHES|4. OTHER CHRISTIAN (NO DENOMINATION GIVEN; INDEPENDENT; NON-AFFILIATED; NON-TRADITIONAL PROTESTANTS; MORMONS)|5. JEWISH|6. ISLAM - SUNNI|7. ISLAM - OTHER|8. BUDDHISM|9. HINDUISM|10. INDIGENOUS|11. ETHNORELIGIONS|12. NON-BELIEVERS|13. AGNOSTICS|96. OTHER: NOT SPECIFIED|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING	E2013	1000. CHRISTIAN (NO DENOMINATION GIVEN)|1101. ROMAN CATHOLIC|1199. CATHOLIC, OTHER [SEE ELECTION STUDY VARIABLE NOTES]|1200. PROTESTANT, NO DENOMINATION GIVEN|1201. ADVENTIST|1203. BAPTIST|1205. EUROPEAN FREE CHURCH (ANABAPTISTS, MENNONITES)|1206. HOLINESS|1208. LUTHERAN|1209. METHODIST|1210. PENTECOSTAL|1211. PRESBYTERIAN|1213. SALVATION ARMY/SALVATIONIST|1214. CHRISTIAN BRETHEN|1215. CHURCHES OF CHRIST|1216. REFORMED CHURCHES|1298. PROTESTANT, OTHER [SEE ELECTION STUDY NOTES]|1299. PROTESTANT, OTHER [SEE ELECTION STUDY NOTES]|1300. EPISCOPALIAN, ANGLICAN, CHURCH OF ENGLAND, CHURCH OF IRELAND|1499. INDEPENDENT, OTHER [SEE ELECTION STUDY NOTES]|1501. CHRISTIAN SCIENTISTS|1502. MORMONS, CHURCH OF LATTER DAY SAINTS|1503. UNITARIAN UNIVERSALISTS|1504. JEHOVAH'S WITNESSES|1600. EASTERN ORTHODOX|1699. ORTHODOX, OTHER [SEE ELECTION STUDY NOTES]|2000. JEWISH|3000. MUSLIM; MOHAMMEDAN; ISLAM (NO DENOMINATION GIVEN)|4000. BUDDHIST|5000. HINDU|5600. SIKHISM|6100. CONFUCIANISM|6200. TAOISM|7100. PAGAN, HEATHEN, TRIBAL RELIGIONSIST, TRADITIONAL RELIGIONIST, ANIMISM, SHAMANISM|7110. RATANA, MAORI|7200. SPIRITISM|7500. BAHAI|7900. EHTNORELIGIONIST, OTHER [SEE ELECTION STUDY NOTES]|7901. EHTNORELIGIONIST, OTHER [SEE ELECTION STUDY NOTES]|8100. AGNOSTIC|8200. ATHEIST|8300. NONE|9001. [SEE ELECTION STUDY NOTES]|9002. [SEE ELECTION STUDY NOTES]|9003. [SEE ELECTION STUDY NOTES]|9004. [SEE ELECTION STUDY NOTES]|9005. [SEE ELECTION STUDY NOTES]|9600. OTHER: NOT SPECIFIED|9997. VOLUNTEERED: REFUSED|9998. VOLUNTEERED: DON'T KNOW|9999. MISSING
# dict(zip(CSES_5["E2013"].cat.categories,CSES_5["E2013"].cat.categories))


#  |        01. Roman Catholic (1/1101)
#  |            Catholic, Other [see Election Study Notes] (1199)
#  |        02. Protestant, no Denomination Given (2/1200)
#  |            Adventist (3/1201)
#  |            Episcopalian, Anglican, Church of England, 
#  |            Church of Ireland (4/1300)
#  |            Baptist (5/1203)
#  |            Congregational (6/1204)
#  |            European Free Church (Anabaptists) (7/1205)
#  |            Holiness (8/1206)
#  |            Independent-Fundamentalist (9/1401)
#  |            Lutheran (10/1208)
#  |            Methodist (11/1209)
#  |            Pentecostal (12/1210)
#  |            Presbyterian (13/1211)
#  |            Christian Scientists (14/1501)
#  |            Unitarian; Universalist (16/1503)
#  |            Reformed Calvinist (not Presb) / Calvinist (91/1212)
#  |            Salvation Army/Salvationist (1213)
#  |            Christian Brethren (1214)
#  |            Churches of Christ (1215)
#  |            Reformed Churches (1216)
#  |            Protestant Church of The Netherlands (1217)
#  |            Protestant, Other [see Election Study Notes] 
#  |            (1298/1299)               
#  |        03. Eastern Orthodox (Greek Rite Catholic) (17/1600)
#  |            Eastern Catholic Churches (e.g., Eastern Rite
#  |            Catholic, Greek Rite Cathole, Uniate) (19/1102)
#  |            Orthodox, Other [see Election Study Notes] (1699)
#  |        04. Christian (no Denomination Given) (18/1000)
#  |            Mormons; Latter Day Saints (15/1502)
#  |            Apostolic (1410)
#  |            United Churches (1420)
#  |            Independent, Other [see Election Study Notes] (1499)
#  |            Jehovah's Witnesses (1504)
#  |            Non-traditional Protestant, Other [see Election 
#  |            Study Notes] (1599)
#  |        05. Jewish (20/2000)
#  |        06. Sunni (33/3100)
#  |        07. Muslim; Mohammedan; Islam (no Denomination Given) 
#  |            (30/3000)
#  |            Kharijism (31)
#  |            Mu'tazilism (32)
#  |            Shi'ism (34/3200)
#  |            Isma'ilis (35/3210)
#  |            Baha'i (36/22)
#  |            Druse (37/3211)
#  |        08. Buddhist (40/4000)
#  |            Theravada (41/4100)
#  |            Mahayana (42/4200)
#  |            Tantrism (43)
#  |            Tibetan Buddhism (44)
#  |            Shingon (45)
#  |        09. Hindu (50/5000)
#  |            Jainism (51/5500)
#  |            Sikhism (52/5600)
#  |            Parsiism (53/5010)
#  |            Vedism (54)
#  |            Brahmanism (55)
#  |            Vaishnavism (56/5020)
#  |            Shaivism (57/5030)
#  |            Tantrism (58)
#  |            Shaktism (59/5040)
#  |            Folk Hinduism (60)
#  |        10. Confucianism (71/6100)
#  |            Taoism (72/6200)
#  |            Shinto (73/6300)
#  |            Bahai (74)
#  |            I-Kuan-Tao (75/6401)
#  |            New Religionists (6400)
#  |            Traditional Folk Belief/Nichiren Shoshu (6500)
#  |        11. Pagan, Heathen, Tribal Religionist, Traditional 
#  |            Religionist, Animism, Shamanism (7100)
#  |            Ratana, Maori (7110)
#  |            Spiritism (7200)
#  |            Bahai (7500)
#  |            Ehtnoreligionist, Other [see Election Study Notes] 
#  |            (7900/7901)
#  |        12. Atheists (82/92/8200)
#  |            None (83/93/8300)
#  |        13. Agnostics (81/91/8100)
#  |        96. Other Religions (80)
#  |            Other: Not Specified (9600)
#  |        97. Refused (97/9997)
#  |        98. Don't Know (98/9998)
#  |        99. Missing (99/9999)

# ['1. CATHOLIC',
#  '2. PROTESTANT',
#  '3. ORTHODOX/EASTERN CATHOLIC CHURCHES',
#  '4. OTHER CHRISTIAN (NO DENOMINATION GIVEN; INDEPENDENT; NON-AFFILIATED; NON-TRADITIONAL PROTESTANTS; MORMONS)',
#  '5. JEWISH',
#  '6. ISLAM - SUNNI',
#  '7. ISLAM - OTHER',
#  '8. BUDDHISM',
#  '9. HINDUISM',
#  '10. INDIGENOUS',
#  '11. ETHNORELIGIONS',
#  '12. NON-BELIEVERS',
#  '13. AGNOSTICS',
#  '96. OTHER: NOT SPECIFIED',
#  '97. VOLUNTEERED: REFUSED',
#  "98. VOLUNTEERED: DON'T KNOW",
#  '99. MISSING']


# no sunni category???
replace_dict = {'1000. CHRISTIAN (NO DENOMINATION GIVEN)': '4. OTHER CHRISTIAN (NO DENOMINATION GIVEN; INDEPENDENT; NON-AFFILIATED; NON-TRADITIONAL PROTESTANTS; MORMONS)',
 '1101. ROMAN CATHOLIC': '1. CATHOLIC',
 '1199. CATHOLIC, OTHER [SEE ELECTION STUDY VARIABLE NOTES]': '1. CATHOLIC',
 '1200. PROTESTANT, NO DENOMINATION GIVEN': '2. PROTESTANT',
 '1201. ADVENTIST': '2. PROTESTANT',
 '1203. BAPTIST': '2. PROTESTANT',
 '1205. EUROPEAN FREE CHURCH (ANABAPTISTS, MENNONITES)':'2. PROTESTANT',
 '1206. HOLINESS': '2. PROTESTANT',
 '1208. LUTHERAN': '2. PROTESTANT',
 '1209. METHODIST': '2. PROTESTANT',
 '1210. PENTECOSTAL': '2. PROTESTANT',
 '1211. PRESBYTERIAN': '2. PROTESTANT',
 '1213. SALVATION ARMY/SALVATIONIST': '2. PROTESTANT',
 '1214. CHRISTIAN BRETHEN':'2. PROTESTANT',
 '1215. CHURCHES OF CHRIST': '2. PROTESTANT',
 '1216. REFORMED CHURCHES': '2. PROTESTANT',
 '1298. PROTESTANT, OTHER [SEE ELECTION STUDY NOTES]': '2. PROTESTANT',
 '1299. PROTESTANT, OTHER [SEE ELECTION STUDY NOTES]': '2. PROTESTANT',
 '1300. EPISCOPALIAN, ANGLICAN, CHURCH OF ENGLAND, CHURCH OF IRELAND': '2. PROTESTANT',
 '1499. INDEPENDENT, OTHER [SEE ELECTION STUDY NOTES]': '4. OTHER CHRISTIAN (NO DENOMINATION GIVEN; INDEPENDENT; NON-AFFILIATED; NON-TRADITIONAL PROTESTANTS; MORMONS)',
 '1501. CHRISTIAN SCIENTISTS': '2. PROTESTANT',
 '1502. MORMONS, CHURCH OF LATTER DAY SAINTS': '4. OTHER CHRISTIAN (NO DENOMINATION GIVEN; INDEPENDENT; NON-AFFILIATED; NON-TRADITIONAL PROTESTANTS; MORMONS)',
 '1503. UNITARIAN UNIVERSALISTS': '2. PROTESTANT',
 "1504. JEHOVAH'S WITNESSES": '4. OTHER CHRISTIAN (NO DENOMINATION GIVEN; INDEPENDENT; NON-AFFILIATED; NON-TRADITIONAL PROTESTANTS; MORMONS)',
 '1600. EASTERN ORTHODOX': '3. ORTHODOX/EASTERN CATHOLIC CHURCHES',
 '1699. ORTHODOX, OTHER [SEE ELECTION STUDY NOTES]': '3. ORTHODOX/EASTERN CATHOLIC CHURCHES',
 '2000. JEWISH': '5. JEWISH',
 '3000. MUSLIM; MOHAMMEDAN; ISLAM (NO DENOMINATION GIVEN)': '7. ISLAM - OTHER',
 '4000. BUDDHIST': '8. BUDDHISM',
 '5000. HINDU': '9. HINDUISM',
 '5600. SIKHISM': '9. HINDUISM',
 '6100. CONFUCIANISM': '10. INDIGENOUS',
 '6200. TAOISM': '10. INDIGENOUS',
 '7100. PAGAN, HEATHEN, TRIBAL RELIGIONSIST, TRADITIONAL RELIGIONIST, ANIMISM, SHAMANISM': '11. ETHNORELIGIONS',
 '7110. RATANA, MAORI': '11. ETHNORELIGIONS',
 '7200. SPIRITISM': '11. ETHNORELIGIONS',
 '7500. BAHAI': '10. INDIGENOUS',
 '7900. EHTNORELIGIONIST, OTHER [SEE ELECTION STUDY NOTES]': '11. ETHNORELIGIONS',
 '7901. EHTNORELIGIONIST, OTHER [SEE ELECTION STUDY NOTES]': '11. ETHNORELIGIONS',
 '8100. AGNOSTIC': '13. AGNOSTICS',
 '8200. ATHEIST': '12. NON-BELIEVERS',
 '8300. NONE': '12. NON-BELIEVERS',
 '9001. [SEE ELECTION STUDY NOTES]': '96. OTHER: NOT SPECIFIED',
 '9002. [SEE ELECTION STUDY NOTES]': '96. OTHER: NOT SPECIFIED',
 '9003. [SEE ELECTION STUDY NOTES]': '96. OTHER: NOT SPECIFIED',
 '9004. [SEE ELECTION STUDY NOTES]': '96. OTHER: NOT SPECIFIED',
 '9005. [SEE ELECTION STUDY NOTES]': '96. OTHER: NOT SPECIFIED',
 '9600. OTHER: NOT SPECIFIED': '96. OTHER: NOT SPECIFIED',
 '9997. VOLUNTEERED: REFUSED': '97. VOLUNTEERED: REFUSED',
 "9998. VOLUNTEERED: DON'T KNOW": "98. VOLUNTEERED: DON'T KNOW",
 '9999. MISSING':'99. MISSING'}

CSES_int_5["IMD2005"] = replace_categories(CSES_5["E2013"], replace_dict, CSES_int["IMD2005"])

# %%
# turnout: trivial harmonising
# IMD3001_PR_1	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999995. NOT APPLICABLE: NO ROLE OF PRESIDENT|9999996. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3012_PR_1	0. RESPONDENT DID NOT/WILL NOT CAST A BALLOT|1. RESPONDENT CAST/WILL CAST A BALLOT|93. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS|95. NOT APPLICABLE: NO ROLE OF PRESIDENT|96. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING
# IMD3001_PR_2	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999995. NOT APPLICABLE: NO ROLE OF PRESIDENT|9999996. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS / NO SECOND ROUND|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3012_PR_2	0. RESPONDENT DID NOT/WILL NOT CAST A BALLOT|1. RESPONDENT CAST/WILL CAST A BALLOT|95. NOT APPLICABLE: NO ROLE OF PRESIDENT|96. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS / NO SECOND ROUND|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW
# IMD3001_LH	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999996. NOT APPLICABLE: NO LOWER HOUSE ELECTION|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3012_LH	0. RESPONDENT DID NOT/WILL NOT CAST A BALLOT|1. RESPONDENT CAST/WILL CAST A BALLOT|93. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS|96. NOT APPLICABLE: NO LOWER HOUSE ELECTION|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING
# IMD3001_UH	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999995. NOT APPLICABLE: UNICAMERAL SYSTEM|9999996. NOT APPLICABLE: NO UPPER HOUSE ELECTION|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3012_UH	0. RESPONDENT DID NOT/WILL NOT CAST A BALLOT|1. RESPONDENT CAST/WILL CAST A BALLOT|93. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS|95. NOT APPLICABLE: UNICAMERAL SYSTEM|96. NOT APPLICABLE: NO UPPER HOUSE ELECTION|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING

rename_dict = dict(zip(CSES_5["E3012_PR_1"].cat.categories,CSES_int["IMD3001_PR_1"].cat.categories))
CSES_int_5["IMD3001_PR_1"] = CSES_5["E3012_PR_1"].cat.rename_categories(rename_dict)
rename_dict = dict(zip(CSES_5["E3012_PR_2"].cat.categories,CSES_int["IMD3001_PR_2"].cat.categories))
CSES_int_5["IMD3001_PR_2"] = CSES_5["E3012_PR_2"].cat.rename_categories(rename_dict)
rename_dict = dict(zip(CSES_5["E3012_LH"].cat.categories,CSES_int["IMD3001_LH"].cat.categories))
CSES_int_5["IMD3001_LH"] = CSES_5["E3012_LH"].cat.rename_categories(rename_dict)
rename_dict = dict(zip(CSES_5["E3012_UH"].cat.categories,CSES_int["IMD3001_UH"].cat.categories))
CSES_int_5["IMD3001_UH"] = CSES_5["E3012_UH"].cat.rename_categories(rename_dict)

# %%
# past turnout: trivial harmonising
# IMD3002_OUTGOV	0. DID NOT VOTE FOR THE OUTGOING GOVERNMENT (INCUMBENT)|1. VOTED FOR THE OUTGOING GOVERNMENT (INCUMBENT)|9999996. NOT ASCERTAINED/INCUMBENT CANDIDATE/PARTY DID NOT CONTEST|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING / ABSTAINED (DID NOT VOTE)	E3013_OUTGOV	0. DID NOT VOTE FOR THE OUTGOING GOVERNMENT (INCUMBENT)|1. VOTED FOR THE OUTGOING GOVERNMENT (INCUMBENT)|999996. NOT ASCERTAINED / INCUMBENT CANDIDATE/PARTY DID NOT CONTEST|999997. VOLUNTEERED: REFUSED|999998. VOLUNTEERED: DON'T KNOW|999999. MISSING / ABSTAINED (DID NOT VOTE)
rename_dict = dict(zip(CSES_5["E3013_OUTGOV"].cat.categories,CSES_int["IMD3002_OUTGOV"].cat.categories))
CSES_int_5["IMD3002_OUTGOV"] = CSES_5["E3013_OUTGOV"].cat.rename_categories(rename_dict)
# IMD3003_PR_1	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999995. NOT APPLICABLE: NO ROLE OF PRESIDENT|9999996. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3014_PR_1	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|93. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS|95. NOT APPLICABLE: NO ROLE OF PRESIDENT|96. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING
rename_dict = dict(zip(CSES_5["E3014_PR_1"].cat.categories,CSES_int["IMD3003_PR_1"].cat.categories))
CSES_int_5["IMD3003_PR_1"] = CSES_5["E3014_PR_1"].cat.rename_categories(rename_dict)
# IMD3003_PR_2	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999995. NOT APPLICABLE: NO ROLE OF PRESIDENT|9999996. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS / NO SECOND ROUND|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3014_PR_2	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|93. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS|95. NOT APPLICABLE: NO ROLE OF PRESIDENT|96. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS / NO SECOND ROUND|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING
rename_dict = dict(zip(CSES_5["E3014_PR_2"].cat.categories,CSES_int["IMD3003_PR_2"].cat.categories))
CSES_int_5["IMD3003_PR_2"] = CSES_5["E3014_PR_2"].cat.rename_categories(rename_dict)

# last two miss 'not applicable' category because doesn't all cases have a lower house election in module 5 dataset
# IMD3003_LH	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999996. NOT APPLICABLE: NO LOWER HOUSE ELECTION|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3014_LH	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|93. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING
rename_dict = dict(zip(CSES_5["E3014_LH"].cat.categories,CSES_int["IMD3003_LH"].cat.remove_categories('9999996. NOT APPLICABLE: NO LOWER HOUSE ELECTION').cat.categories))
CSES_int_5["IMD3003_UH"] = replace_categories(CSES_5["E3014_LH"], rename_dict, CSES_int["IMD3003_LH"])
# IMD3003_UH	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]|9999995. NOT APPLICABLE: UNICAMERAL SYSTEM|9999996. NOT APPLICABLE: NO UPPER HOUSE ELECTION|9999997. VOLUNTEERED: REFUSED|9999998. VOLUNTEERED: DON'T KNOW|9999999. MISSING	E3014_UH	0. RESPONDENT DID NOT CAST A BALLOT|1. RESPONDENT CAST A BALLOT|95. NOT APPLICABLE: UNICAMERAL SYSTEM|96. NOT APPLICABLE: NO UPPER HOUSE ELECTION|97. VOLUNTEERED: REFUSED|98. VOLUNTEERED: DON'T KNOW|99. MISSING
rename_dict = dict(zip(CSES_5["E3014_UH"].cat.categories,CSES_int["IMD3003_UH"].cat.remove_categories('9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]').cat.categories))
CSES_int_5["IMD3003_UH"] = replace_categories(CSES_5["E3014_UH"], rename_dict, CSES_int["IMD3003_UH"])

# %%
# PARTY IDENTIFICATION: ARE YOU CLOSE TO ANY POLITICAL : trivial harmonising
# IMD3005_1	1. YES|5. NO|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING	E3024_1	0. NO|1. YES|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING

rename_dict = {'1. YES': '1. YES',
 '0. NO': '5. NO',
 '7. VOLUNTEERED: REFUSED': '7. VOLUNTEERED: REFUSED',
 "8. VOLUNTEERED: DON'T KNOW": "8. VOLUNTEERED: DON'T KNOW",
 '9. MISSING': '9. MISSING'}

CSES_int_5["IMD3005_1"] = replace_categories(CSES_5["E3024_1"], rename_dict, CSES_int["IMD3005_1"])

# IMD3005_2	1. YES|5. NO|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING	E3024_2	0. NO|1. YES|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING

rename_dict = {'1. YES': '1. YES',
 '0. NO': '5. NO',
 '7. VOLUNTEERED: REFUSED': '7. VOLUNTEERED: REFUSED',
 "8. VOLUNTEERED: DON'T KNOW": "8. VOLUNTEERED: DON'T KNOW",
 '9. MISSING': '9. MISSING'}
CSES_int_5["IMD3005_2"] = replace_categories(CSES_5["E3024_2"], rename_dict, CSES_int["IMD3005_2"])

# dict(zip(CSES_5["E3024_2"].cat.categories,CSES_int["IMD3005_2"].cat.categories))

# %%
# Some nontrivial harmonisation
# IMD3010	1. VERY SATISFIED|2. FAIRLY SATISFIED|4. NOT VERY SATISFIED|5. NOT AT ALL SATISFIED|6. NEITHER SATISFIED NOR DISSATISFIED|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING	E3023	1. VERY SATISFIED|2. FAIRLY SATISFIED|4. NOT VERY SATISFIED|5. NOT AT ALL SATISFIED|6. [SEE ELECTION STUDY NOTES]|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING
rename_dict = dict(zip(CSES_5["E3023"].cat.categories,CSES_int["IMD3010"].cat.categories))
CSES_int_5["IMD3010"] = CSES_5["E3023"].cat.rename_categories(rename_dict)
# IMD3013_1	1. GOTTEN BETTER|3. STAYED THE SAME|5. GOTTEN WORSE|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING	E3011	1. GOTTEN MUCH BETTER|2. GOTTEN SOMEWHAT BETTER|3. STAYED ABOUT THE SAME|4. GOTTEN SOMEWHAT WORSE|5. GOTTEN MUCH WORSE|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING
replace_dict = {'1. GOTTEN MUCH BETTER':'1. GOTTEN BETTER',
 '2. GOTTEN SOMEWHAT BETTER':'1. GOTTEN BETTER',
 '3. STAYED ABOUT THE SAME':'3. STAYED THE SAME',
 '4. GOTTEN SOMEWHAT WORSE':'5. GOTTEN WORSE',
 '5. GOTTEN MUCH WORSE':'5. GOTTEN WORSE',
 '7. VOLUNTEERED: REFUSED':'7. VOLUNTEERED: REFUSED',
 "8. VOLUNTEERED: DON'T KNOW":"8. VOLUNTEERED: DON'T KNOW",
 '9. MISSING':'9. MISSING'}

CSES_int_5["IMD3013_1"] = replace_categories(CSES_5["E3011"], replace_dict, CSES_int["IMD3013_1"])

## We could actually use this to build those "how much better/how much worse" variables
# IMD3013_2 , E3011
replace_dict = {'1. GOTTEN MUCH BETTER': '1. MUCH BETTER',
 '2. GOTTEN SOMEWHAT BETTER': '2. SOMEWHAT BETTER',
 '3. STAYED ABOUT THE SAME': '9. MISSING',
 '4. GOTTEN SOMEWHAT WORSE': '9. MISSING',
 '5. GOTTEN MUCH WORSE': '9. MISSING',
 '7. VOLUNTEERED: REFUSED': '7. VOLUNTEERED: REFUSED',
 "8. VOLUNTEERED: DON'T KNOW": "8. VOLUNTEERED: DON'T KNOW",
 '9. MISSING': '9. MISSING'}

CSES_int_5["IMD3013_2"] = replace_categories(CSES_5["E3011"], replace_dict, CSES_int["IMD3013_2"])

# IMD3013_3 , E3011
replace_dict = {'1. GOTTEN MUCH BETTER': '9. MISSING',
 '2. GOTTEN SOMEWHAT BETTER': '9. MISSING',
 '3. STAYED ABOUT THE SAME': '9. MISSING',
 '4. GOTTEN SOMEWHAT WORSE': '4. SOMEWHAT WORSE',
 '5. GOTTEN MUCH WORSE': '5. MUCH WORSE',
 '7. VOLUNTEERED: REFUSED': '7. VOLUNTEERED: REFUSED',
 "8. VOLUNTEERED: DON'T KNOW": "8. VOLUNTEERED: DON'T KNOW",
 '9. MISSING': '9. MISSING'}

CSES_int_5["IMD3013_3"] = replace_categories(CSES_5["E3011"], replace_dict, CSES_int["IMD3013_3"])

# IMD3014	1. VERY GOOD JOB|2. GOOD JOB|3. BAD JOB|4. VERY BAD JOB|6. NEITHER GOOD NOR BAD|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING	E3009	1. VERY GOOD JOB|2. GOOD JOB|3. BAD JOB|4. VERY BAD JOB|6. [SEE ELECTION STUDY NOTES]|7. VOLUNTEERED: REFUSED|8. VOLUNTEERED: DON'T KNOW|9. MISSING
# CSES_int["IMD3014"].value_counts()

# 6. NEITHER GOOD NOR BAD not in the notes!
rename_dict = dict(zip(CSES_5["E3009"].cat.categories,CSES_int["IMD3014"].cat.categories))

CSES_int_5["IMD3014"] = replace_categories(CSES_5["E3009"], rename_dict, CSES_int["IMD3014"])

# %%
# IMD5002_C	997. NOT APPLICABLE: NO LOWER HOUSE ELECTION|999. MISSING	E5002_C	997. NOT APPLICABLE: NO LOWER HOUSE ELECTION
# IMD5002_D	997. NOT APPLICABLE: NO LOWER HOUSE ELECTION|999. MISSING	E5002_D	997. NOT APPLICABLE: NO LOWER HOUSE ELECTION
# IMD5004_C	996. NOT APPLICABLE: UNICAMERAL SYSTEM|997. NOT APPLICABLE: NO UPPER HOUSE ELECTION|999. MISSING	E5004_C	996. NOT APPLICABLE: UNICAMERAL SYSTEM|997. NOT APPLICABLE: NO UPPER HOUSE ELECTION
# IMD5004_D	996. NOT APPLICABLE: UNICAMERAL SYSTEM|997. NOT APPLICABLE: NO UPPER HOUSE ELECTION|999. MISSING	E5004_D	996. NOT APPLICABLE: UNICAMERAL SYSTEM|997. NOT APPLICABLE: NO UPPER HOUSE ELECTION
# IMD5005_A	996. NOT APPLICABLE: NO ROLE OF PRESIDENT|997. NOT APPLICABLE: NO PRESIDENTIAL ELECTION|999. MISSING	E5005_A	996. NOT APPLICABLE: NO ROLE OF PRESIDENT|997. NOT APPLICABLE: NO PRESIDENTIAL ELECTION

# all fine as they are, the mod 5 set just doesn't have any "missing" values
# note that these are mostly-numerical - so the cats just won't match

CSES_int_5["IMD5002_C"] = CSES_5["E5002_C"]
CSES_int_5["IMD5002_D"] = CSES_5["E5002_D"]
CSES_int_5["IMD5004_C"] = CSES_5["E5004_C"]
CSES_int_5["IMD5004_D"] = CSES_5["E5004_D"]
CSES_int_5["IMD5005_A"] = CSES_5["E5005_A"]

# %%
replace_dict = {'01. ECOLOGY PARTIES':'1. ECOLOGY PARTIES',
 '02. COMMUNIST PARTIES':'2. COMMUNIST PARTIES',   
 '03. SOCIALIST PARTIES':'3. SOCIALIST PARTIES',   
 '04. SOCIAL DEMOCRATIC PARTIES': '4. SOCIAL DEMOCRATIC PARTIES',
 '05. LEFT LIBERAL PARTIES': '5. LEFT LIBERAL PARTIES',
 '06. LIBERAL PARTIES': '6. LIBERAL PARTIES',
 '07. RIGHT LIBERAL PARTIES': '7. RIGHT LIBERAL PARTIES',
 '08. CHRISTIAN DEMOCRATIC PARTIES': '8. CHRISTIAN DEMOCRATIC PARTIES',
 '09. CONSERVATIVE PARTIES': '9. CONSERVATIVE PARTIES',
 '10. NATIONAL PARTIES': '10. NATIONAL PARTIES',
 '11. AGRARIAN PARTIES': '11. AGRARIAN PARTIES',
 '12. ETHNIC PARTIES': '12. ETHNIC PARTIES',
 '13. REGIONAL PARTIES': '13. REGIONAL PARTIES',
 '14. INDEPENDENT PARTIES': '14. INDEPENDENT PARTIES',
 '15. OTHER': '90. OTHER',
 '97. NOT APPLICABLE':'97. NOT APPLICABLE',
 '98. NO IDEOLOGICAL FAMILY MENTIONED': '98. NO IDEOLOGICAL FAMILY MENTIONED',
 '99. MISSING':'99. MISSING'}
# dict(zip(CSES_5["E5017_A"].cat.categories,CSES_int["IMD5011_A"].cat.categories))

## should do for all of these!

# IMD5011_A	2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|12. ETHNIC PARTIES|14. INDEPENDENT PARTIES|18. SOCIAL-LIBERAL|22. NATIONALIST LEFT|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_A	04. SOCIAL DEMOCRATIC PARTIES|05. LEFT LIBERAL PARTIES|06. LIBERAL PARTIES|07. RIGHT LIBERAL PARTIES|08. CHRISTIAN DEMOCRATIC PARTIES|09. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED
CSES_int_5["IMD5011_A"] = replace_categories(CSES_5["E5017_A"], replace_dict, CSES_int["IMD5011_A"])
# IMD5011_B	2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|14. INDEPENDENT PARTIES|16. RELIGIOUS PARTIES|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_B	03. SOCIALIST PARTIES|04. SOCIAL DEMOCRATIC PARTIES|06. LIBERAL PARTIES|09. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|98. NO IDEOLOGICAL FAMILY MENTIONED
CSES_int_5["IMD5011_B"] = replace_categories(CSES_5["E5017_B"], replace_dict, CSES_int["IMD5011_B"])
# IMD5011_C	1. ECOLOGY PARTIES|2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|12. ETHNIC PARTIES|13. REGIONAL PARTIES|14. INDEPENDENT PARTIES|16. RELIGIOUS PARTIES|25. COMMUNIST-GREEN|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_C	01. ECOLOGY PARTIES|04. SOCIAL DEMOCRATIC PARTIES|06. LIBERAL PARTIES|07. RIGHT LIBERAL PARTIES|08. CHRISTIAN DEMOCRATIC PARTIES|09. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|12. ETHNIC PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED
CSES_int_5["IMD5011_C"] = replace_categories(CSES_5["E5017_C"], replace_dict, CSES_int["IMD5011_C"])
# IMD5011_D	1. ECOLOGY PARTIES|2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|12. ETHNIC PARTIES|13. REGIONAL PARTIES|14. INDEPENDENT PARTIES|16. RELIGIOUS PARTIES|22. NATIONALIST LEFT|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_D	01. ECOLOGY PARTIES|03. SOCIALIST PARTIES|04. SOCIAL DEMOCRATIC PARTIES|06. LIBERAL PARTIES|07. RIGHT LIBERAL PARTIES|09. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED
CSES_int_5["IMD5011_D"] = replace_categories(CSES_5["E5017_D"], replace_dict, CSES_int["IMD5011_D"])
# IMD5011_E	1. ECOLOGY PARTIES|2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|12. ETHNIC PARTIES|13. REGIONAL PARTIES|14. INDEPENDENT PARTIES|19. EXTREME LEFT|21. EXTREME NATIONALIST|23. EXTREME RIGHT|24. CENTRIST|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_E	02. COMMUNIST PARTIES|03. SOCIALIST PARTIES|04. SOCIAL DEMOCRATIC PARTIES|05. LEFT LIBERAL PARTIES|06. LIBERAL PARTIES|07. RIGHT LIBERAL PARTIES|09. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING
CSES_int_5["IMD5011_E"] = replace_categories(CSES_5["E5017_E"], replace_dict, CSES_int["IMD5011_E"])
# IMD5011_F	1. ECOLOGY PARTIES|2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|12. ETHNIC PARTIES|13. REGIONAL PARTIES|14. INDEPENDENT PARTIES|18. SOCIAL-LIBERAL|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_F	01. ECOLOGY PARTIES|03. SOCIALIST PARTIES|04. SOCIAL DEMOCRATIC PARTIES|05. LEFT LIBERAL PARTIES|06. LIBERAL PARTIES|09. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|12. ETHNIC PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING
CSES_int_5["IMD5011_F"] = replace_categories(CSES_5["E5017_F"], replace_dict, CSES_int["IMD5011_F"])
# IMD5011_G	1. ECOLOGY PARTIES|2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|12. ETHNIC PARTIES|13. REGIONAL PARTIES|14. INDEPENDENT PARTIES|17. SINGLE ISSUE PARTIES|90. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_G	01. ECOLOGY PARTIES|02. COMMUNIST PARTIES|03. SOCIALIST PARTIES|04. SOCIAL DEMOCRATIC PARTIES|06. LIBERAL PARTIES|07. RIGHT LIBERAL PARTIES|08. CHRISTIAN DEMOCRATIC PARTIES|10. NATIONAL PARTIES|12. ETHNIC PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING
CSES_int_5["IMD5011_G"] = replace_categories(CSES_5["E5017_G"], replace_dict, CSES_int["IMD5011_G"])
# IMD5011_H	1. ECOLOGY PARTIES|2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|11. AGRARIAN PARTIES|12. ETHNIC PARTIES|13. REGIONAL PARTIES|24. CENTRIST|26. ORTHODOX-CALVINIST|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_H	01. ECOLOGY PARTIES|03. SOCIALIST PARTIES|05. LEFT LIBERAL PARTIES|06. LIBERAL PARTIES|07. RIGHT LIBERAL PARTIES|12. ETHNIC PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING
CSES_int_5["IMD5011_H"] = replace_categories(CSES_5["E5017_H"], replace_dict, CSES_int["IMD5011_H"])
# IMD5011_I	1. ECOLOGY PARTIES|2. COMMUNIST PARTIES|3. SOCIALIST PARTIES|4. SOCIAL DEMOCRATIC PARTIES|5. LEFT LIBERAL PARTIES|6. LIBERAL PARTIES|7. RIGHT LIBERAL PARTIES|8. CHRISTIAN DEMOCRATIC PARTIES|9. CONSERVATIVE PARTIES|10. NATIONAL PARTIES|12. ETHNIC PARTIES|13. REGIONAL PARTIES|14. INDEPENDENT PARTIES|26. ORTHODOX-CALVINIST|90. OTHER|97. NOT APPLICABLE|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING	E5017_I	04. SOCIAL DEMOCRATIC PARTIES|09. CONSERVATIVE PARTIES|12. ETHNIC PARTIES|15. OTHER|98. NO IDEOLOGICAL FAMILY MENTIONED|99. MISSING
CSES_int_5["IMD5011_I"] = replace_categories(CSES_5["E5017_I"], replace_dict, CSES_int["IMD5011_I"])

# dict(zip(CSES_5["E5017_A"].cat.categories,CSES_int["IMD5011_A"].cat.categories))

# %%
## already the same!


# IMD5012_A	00. LEFT|97. NOT APPLICABLE|99. MISSING	E5018_A	10. RIGHT|99. MISSING
# IMD5012_B	00. LEFT|97. NOT APPLICABLE|99. MISSING	E5018_B	10. RIGHT|99. MISSING
# IMD5012_C	00. LEFT|10. RIGHT|99. MISSING	E5018_C	10. RIGHT|99. MISSING
# IMD5012_D	00. LEFT|10. RIGHT|97. NOT APPLICABLE|99. MISSING	E5018_D	99. MISSING
# IMD5012_E	00. LEFT|10. RIGHT|97. NOT APPLICABLE|99. MISSING	E5018_E	99. MISSING
# IMD5012_F	00. LEFT|10. RIGHT|97. NOT APPLICABLE|99. MISSING	E5018_F	99. MISSING
# IMD5012_G	00. LEFT|10. RIGHT|99. MISSING	E5018_G	97. NOT APPLICABLE|99. MISSING
# IMD5012_H	10. RIGHT|99. MISSING	E5018_H	99. MISSING
# IMD5012_I	10. RIGHT|99. MISSING	E5018_I	99. MISSING
for party in ["A","B","C","D","E","F","G","H","I"]:
    CSES_int_5["IMD5012_"+party] = CSES_5["E5018_"+party]

# %%
# IMD5014	1. PLURALITY|2. ABSOLUTE MAJORITY RULE|3. QUALIFIED MAJORITY RULE|4. ELECTORAL COLLEGE|5. ALTERNATIVE VOTE|7. NOT APPLICABLE|9. MISSING	E5054	1. PLURALITY|2. ABSOLUTE MAJORITY RULE|4. ELECTORAL COLLEGE|5. SINGLE TRANSFERABLE VOTE|7. NOT APPLICABLE
rename_dict = {'5. SINGLE TRANSFERABLE VOTE':'5. ALTERNATIVE VOTE'}
CSES_int_5["IMD5014"] = CSES_5["E5054"].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5014"].cat.categories)

# %%
# IMD5016_1	91. [SEE ELECTION STUDY NOTES]	E5040_1	91. 0THER [SEE ELECTION STUDY NOTES]
# IMD5016_2	91. [SEE ELECTION STUDY NOTES]|97. NOT APPLICABLE	E5040_2	91. 0THER [SEE ELECTION STUDY NOTES]|97. NOT APPLICABLE
# IMD5016_3	91. [SEE ELECTION STUDY NOTES]|97. NOT APPLICABLE	E5040_3	91. 0THER [SEE ELECTION STUDY NOTES]|97. NOT APPLICABLE

# for all three
rename_dict = {"91. 0THER [SEE ELECTION STUDY NOTES]":"91. [SEE ELECTION STUDY NOTES]"}
for party in ["1","2","3"]:
    CSES_int_5["IMD5016_"+party] = CSES_5["E5040_"+party].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5016_"+party].cat.categories)

# %%
# IMD5017_1	1. CANDIDATES|2. PARTY LISTS|4. [SEE ELECTION STUDY NOTES]	E5041_1	1. CANDIDATES|2. PARTY LISTS|4. OTHER [SEE ELECTION STUDY NOTES]
# IMD5017_2	1. CANDIDATES|2. PARTY LISTS|7. NOT APPLICABLE	E5041_2	2. PARTY LISTS|7. NOT APPLICABLE
# IMD5017_3	1. CANDIDATES|2. PARTY LISTS|4. [SEE ELECTION STUDY NOTES]|7. NOT APPLICABLE	E5041_3	1. CANDIDATES|2. PARTY LISTS|4. OTHER [SEE ELECTION STUDY NOTES]|7. NOT APPLICABLE

# for all three
rename_dict = {'4. OTHER [SEE ELECTION STUDY NOTES]': '4. [SEE ELECTION STUDY NOTES]'}

for party in ["1","2","3"]:
    CSES_int_5["IMD5017_"+party] = CSES_5["E5041_"+party].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5017_"+party].cat.categories)

# %%
# IMD5026_1	1. UNICAMERAL LEGISLATURE (ONE LEGISLATIVE CHAMBER)|2. BICAMERAL LEGISLATURE (TWO LEGISLATIVE CHAMBERS)	E5074	1. ONE LEGISLATIVE CHAMBER; UNICAMERAL LEGISLATURE|2. TWO LEGISLATIVE CHAMBERS; BICAMERAL LEGISLATURE
rename_dict = dict(zip(CSES_5["E5074"].cat.categories,CSES_int["IMD5026_1"].cat.categories))

CSES_int_5["IMD5026_1"] = CSES_5["E5074"].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5026_1"].cat.categories)

# %%
rename_dict = {'99. MISSING':'99.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION'}
# IMD5052_1	99.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5093_1	99. MISSING
# IMD5052_2	99.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5093_2	99. MISSING
# IMD5052_3	99.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5093_3	99. MISSING
for party in ["1","2","3"]:
    CSES_int_5["IMD5052_"+party] = CSES_5["E5093_"+party].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5052_"+party].cat.categories)

rename_dict = {'999999. MISSING':'999999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION'}
# IMD5053_1	999999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5094_1	999999. MISSING
# IMD5053_2	999999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5094_2	
# IMD5053_3	999999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5094_3	999999. MISSING
for party in ["1","2","3"]:
    CSES_int_5["IMD5053_"+party] = CSES_5["E5094_"+party].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5053_"+party].cat.categories)

rename_dict = {'999. MISSING':'999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION'}
# IMD5054_1	999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5099_1	999. MISSING
# IMD5054_2	999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5099_2	999. MISSING
# IMD5054_3	999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5099_3	999. MISSING
for party in ["1","2","3"]:
    CSES_int_5["IMD5054_"+party] = CSES_5["E5099_"+party].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5054_"+party].cat.categories)

# IMD5055_1	999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5097_1	999. MISSING
# IMD5055_2	999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5097_2	999. MISSING
# IMD5055_3	999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5097_3	999. MISSING
for party in ["1","2","3"]:
    CSES_int_5["IMD5055_"+party] = CSES_5["E5097_"+party].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5055_"+party].cat.categories)

rename_dict = {'99999. MISSING':'	99999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION'}
# IMD5056_1	99999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5095_1	99999. MISSING
# IMD5056_2	99999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5095_2	99999. MISSING
# IMD5056_3	99999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLICATION	E5095_3	99999. MISSING

for party in ["1","2","3"]:
    CSES_int_5["IMD5056_"+party] = CSES_5["E5095_"+party].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5056_"+party].cat.categories)

# %%
rename_dict = {'997. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED':'997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED',
               '999. MISSING':'999.00. MISSING'}
# IMD5058_1	997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999.00. MISSING	E5078	997. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999. MISSING
CSES_int_5["IMD5058_1"] = CSES_5["E5078"].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5058_1"].cat.categories)
# IMD5058_2	997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999.00. MISSING	E5079	997. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999. MISSING
CSES_int_5["IMD5058_2"] = CSES_5["E5079"].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5058_2"].cat.categories)
# IMD5059_1	997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999.00. MISSING	E5080	997. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999. MISSING
CSES_int_5["IMD5059_1"] = CSES_5["E5080"].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5059_1"].cat.categories)
# IMD5059_2	997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999.00. MISSING	E5081	997. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED|999. MISSING
CSES_int_5["IMD5059_2"] = CSES_5["E5081"].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD5059_2"].cat.categories)

# %%
pres_election_studies = [      '07602018. BRAZIL (2018)', '15202017. CHILE (2017)',
       '15802016. TAIWAN (2016)', '25002017. FRANCE (2017)',
       '79202018. TURKEY (2018)', '84002016. UNITED STATES (2016)']

pres_es_rows = CSES_5["E1003"].apply(lambda x: x in pres_election_studies)

categories_to_be_dropped = ['9999995. NOT APPLICABLE: NO ROLE OF PRESIDENT',
 '9999996. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS' ]

CSES_int_5["IMD3001"] = CSES_int_5["IMD3001_LH"].cat.remove_categories('9999996. NOT APPLICABLE: NO LOWER HOUSE ELECTION',)
CSES_int_5.loc[pres_es_rows,"IMD3001"] = CSES_int_5.loc[pres_es_rows,"IMD3001_PR_1"].cat.remove_categories(['9999995. NOT APPLICABLE: NO ROLE OF PRESIDENT',
 '9999996. NOT APPLICABLE: NO PRESIDENTIAL ELECTIONS', ])

# %%
## variables that *need* to be added

# age - already in the works DONE

## variables that *could* be added

# module no
# "main election" turnout DONE

# %%
### IMD variables with no obvious module 5 analogue

# Int_variable_df_fi[Int_variable_df_fi["var_descr_E"].isnull()].set_index("Unnamed: 0")["var_descr_E"]

## module no - trivial!

## age variables - has to be manually reconstructed

## IMD3001

#  The wording of this item, which is to record voting in the
#  national election, follows national standards.

#  This item ascertains whether or not the respondent cast a ballot
#  in the main election, regardless of whether or not it was valid.
#  In case of a single election taking place, e.g., a lower house
#  election only, then this variable reports the turnout decision for
#  that particular election. In cases where multiple elections took 
#  place, e.g., a presidential and a lower house election, this
#  variable reports the turnout decision in the main election. 
#  See variable notes for more information.

# superhelpful!

#  | VARIABLE VARIABLE NOTES: E3013_OUTGOV
#  |
#  | +++ TABLE: ELECTION STUDIES BY TYPE OF MAIN ELECTION
#  |
#  |                        Presidential  Lower House  Upper House  
#  | POLITY (ELEC YEAR)       Election     Election      Election  
#  | -------------------------------------------------------------
#  | AUSTRALIA (2019)             -            X            -
#  | AUSTRIA (2017)               -            X            -
#  | BRAZIL (2018)                X            -            -
#  | CHILE (2017)                 X            -            -
#  | FRANCE (2017)                X            -            -
#  | GERMANY (2016)               -            X            -
#  | GREECE (2015)                -            X            -
#  | HONG KONG (2016)             -            X*           -
#  | HUNGARY (2018)               -            X            -
#  | ICELAND (2016)               -            X            -
#  | ICELAND (2017)               -            X            -
#  | IRELAND (2016)               -            X            -
#  | ITALY (2018)                 -            X            -
#  | LITHUANIA (2016)             -            X            -
#  | MONTENEGRO (2016)            -            X            -
#  | NEW ZEALAND (2017)           -            X            -
#  | NORWAY (2017)                -            X            -     
#  | SOUTH KOREA (2016)           -            X            -
#  | TAIWAN (2016)                X            -            -
#  | TURKEY (2018)                X            -            -
#  | UNITED STATES (2016)         X            -            -

# I presume:
# IMD3001_PR_1    46337
# IMD3001_PR_2    17200 (but not this second round pres vote)
# IMD3001_LH      56224
# IMD3001_UH      30765

# IMD3002_UH_DC_3    NaN
# IMD3002_UH_DC_4    NaN
# IMD3004_UH_DC_3    NaN
## guess they didn't feel they needed to get all upper house theoretical extra vote options


# IMD3013_2          NaN
# IMD3013_3          NaN
## sad that they didn't get these "how much better/worse" options for mod 5 as well

# IMD3015_1          NaN
# IMD3015_2          NaN
# IMD3015_3          NaN
# IMD3015_4          NaN
# IMD3015_A          NaN
# IMD3015_B          NaN
# IMD3015_C          NaN
# IMD3015_D          NaN
# IMD5026_2          NaN
## very sad they didn't continue the series of dichotomized political information!

# %%
# CSES_int_5["IMD1007"]

# %%
CSES_int_5["IMD1003"] = CSES_5["E1003"]
CSES_int_5["IMD1007"] = CSES_5["E1007"]

# %%
CSES_int_5["IMD1008_MOD_1"] = "00. NOT IN CSES MODULE 1"
CSES_int_5["IMD1008_MOD_1"] = CSES_int_5["IMD1008_MOD_1"].astype('category').cat.set_categories(CSES_int["IMD1008_MOD_1"].cat.categories)
CSES_int_5["IMD1008_MOD_2"] = "00. NOT IN CSES MODULE 2"
CSES_int_5["IMD1008_MOD_2"] = CSES_int_5["IMD1008_MOD_2"].astype('category').cat.set_categories(CSES_int["IMD1008_MOD_2"].cat.categories)
CSES_int_5["IMD1008_MOD_3"] = "00. NOT IN CSES MODULE 3"
CSES_int_5["IMD1008_MOD_3"] = CSES_int_5["IMD1008_MOD_3"].astype('category').cat.set_categories(CSES_int["IMD1008_MOD_3"].cat.categories)
CSES_int_5["IMD1008_MOD_4"] = "00. NOT IN CSES MODULE 4"
CSES_int_5["IMD1008_MOD_4"] = CSES_int_5["IMD1008_MOD_4"].astype('category').cat.set_categories(CSES_int["IMD1008_MOD_4"].cat.categories)
CSES_int_5["IMD1008_MOD_5"] = "01. IN CSES MODULE 5"
CSES_int_5["IMD1008_MOD_5"] = CSES_int_5["IMD1008_MOD_5"].astype('category').cat.set_categories(['00. NOT IN CSES MODULE 5', '01. IN CSES MODULE 5'])

# %%
CSES_int_5["IMD1009"] = CSES_5["E1015"].cat.set_categories(CSES_int["IMD1009"].cat.categories)

# %%
CSES_int_5["IMD1011_M"] = CSES_5["E1016"].cat.set_categories(CSES_int["IMD1011_M"].cat.categories)
CSES_int_5["IMD1011_D"] = CSES_5["E1017"].cat.set_categories(CSES_int["IMD1011_D"].cat.categories)
CSES_int_5["IMD1011_Y"] = CSES_5["E1018"]

CSES_int_5["IMD1012_M"] = CSES_5["E1019"].cat.set_categories(CSES_int["IMD1012_M"].cat.categories)
CSES_int_5["IMD1012_D"] = CSES_5["E1020"]
# weird - original never had anything on day 7
CSES_int_5["IMD1012_Y"] = CSES_5["E1021"]

CSES_int_5["IMD1013_M"] = CSES_5["E1032"].cat.set_categories(CSES_int["IMD1013_M"].cat.categories)
CSES_int_5["IMD1013_D"] = CSES_5["E1033"].cat.set_categories(CSES_int["IMD1013_D"].cat.categories)
CSES_int_5["IMD1013_Y"] = CSES_5["E1034"]

# will have to expand categories for years

# %%
# CSES_5["E1020"][CSES_int_5["IMD1012_D"].isnull()].value_counts()

# %%
# CSES_5["E1019"].cat.set_categories(CSES_int["IMD1012_M"].cat.categories)

# %%
# CSES_5["E1019"].cat.set_categories(CSES_int["IMD1012_M"].cat.categories)

# %%
CSES_int_5["IMD1012_M"] =CSES_5["E1019"].cat.set_categories(CSES_int["IMD1012_M"].cat.categories)

# %%
# CSES_int_5["IMD1012_M"]

# %%
CSES_int_5["IMD1014_1"] = CSES_5["E1035_1"]
CSES_int_5["IMD1014_2"] = CSES_5["E1035_2"]

# %%
vote_vars = ['IMD3002_PR_1', 'IMD3002_PR_2', 'IMD3002_LH_PL', 'IMD3002_LH_DC',
       'IMD3002_UH_PL', 'IMD3002_UH_DC_1', 'IMD3002_UH_DC_2',
       'IMD3004_PR_1', 'IMD3004_PR_2', 'IMD3004_LH_PL',
       'IMD3004_LH_DC', 'IMD3004_UH_PL', 'IMD3004_UH_DC_1',
       'IMD3004_UH_DC_2',"IMD5009_2","IMD5008_1","IMD5008_2",]
for int_var in vote_vars:
    CSES_int_5[int_var] = CSES_5[int_to_mod5.loc[int_var]]

# %%
CSES_int_5["IMD3005_3"] = CSES_5["E3024_3"]

# %%
macro_party_vars = ["IMD5000","IMD5001","IMD5002","IMD5003","IMD5004","IMD5005","IMD5029","IMD5031",]
# numerical
for macro_var in macro_party_vars:
    for party in ["A","B","C","D","E","F","G","H","I"]:
        int_var = macro_var+"_"+party
        CSES_int_5[int_var] = CSES_5[int_to_mod5.loc[int_var]]

# %%
# CSES_int_5["IMD5059_2"].cat.categories

# %%
pres_rename_dict=  {'997. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED':'997.00. PRESIDENTIAL ELECTION ONLY - NOT CALCULATED',
                            '999. MISSING':'999.00. MISSING'}

CSES_int_5["IMD5058_1"] = CSES_5["E5078"]\
    .cat.rename_categories(pres_rename_dict)
CSES_int_5["IMD5058_2"] = CSES_5["E5079"]\
    .cat.rename_categories(pres_rename_dict)
CSES_int_5["IMD5059_1"] = CSES_5["E5080"]\
    .cat.rename_categories(pres_rename_dict)
CSES_int_5["IMD5059_2"] = CSES_5["E5081"]\
    .cat.rename_categories(pres_rename_dict)




CSES_int_5["IMD5016_2"] = CSES_5["E5040_2"]\
    .cat.rename_categories({'91. 0THER [SEE ELECTION STUDY NOTES]':'91. [SEE ELECTION STUDY NOTES]'})

CSES_int_5["IMD5009_1"] = CSES_5["E5009"]

threshold_rename_dict = {'96. OTHER THRESHOLD [SEE ELECTION STUDY NOTES]':'96.00 OTHER THRESHOLD [SEE ELECTION STUDY NOTES]',
                        0:'00.00 THERE IS NO THRESHOLD'}

CSES_int_5["IMD5022_1"] = CSES_5["E5048_1"]\
    .cat.rename_categories(threshold_rename_dict)
CSES_int_5["IMD5022_2"] = CSES_5["E5048_2"]\
    .cat.rename_categories(threshold_rename_dict)

# %%
df = (CSES_int_5.isnull().sum()>0)[CSES_int_5.isnull().sum()>0].reset_index()
df["mod5 var name"] = df["index"].apply(lambda x: int_to_mod5.loc[x] if x in int_to_mod5.index else np.nan)
df["descr"] = df["index"].apply(lambda x: headerINT[x])

# %%
# df.dropna()#.head(60)

# 64	IMD5006_1	True	E5006_1
# 65	IMD5006_2	True	E5006_2
# 66	IMD5008_1	True	E5010
# 67	IMD5008_2	True	E5014
# 68	IMD5009_1	True	E5009
# 69	IMD5009_2	True	E5013

# IMD5030	True	E5016

# %%
last_batch = df.dropna()["index"].values

# only 48 left at this point

# %%
# CSES_int[last_batch]

# %%
last_batch_overlap = set(last_batch).intersection(set(mod5_int_category_discrepancies["int_var"]))


mod5_int_category_discrepancies.set_index("int_var").loc[last_batch_overlap]
# Out:
#                                                       int_cat   mod_var  \
# int_var
# IMD5025_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...   E5026_1
# IMD5024_2          96. [SEE ELECTION STUDY NOTES]|99. MISSING   E5025_2
# IMD5051_1   -88. Transition Periods|10. Democratic|99. MIS...   E5091_1
# IMD5055_2   999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLI...   E5097_2
# IMD5021_1                             1. YES|5. NO|9. MISSING   E5047_1
# IMD5006_1                                        999. MISSING   E5006_1
# IMD5056_2   99999.00. MISSING/NOT AVAILABLE AT TIME OF PUB...   E5095_2
# IMD5057_2   999999999. MISSING AND/OR NOT AVAILABLE AT TIM...   E5098_2
# IMD5021_2           1. YES|5. NO|7. NOT APPLICABLE|9. MISSING   E5047_2
# IMD5022_4   00.00 THERE IS NO THRESHOLD|97.00 NOT APPLICAB...   E5048_4
# IMD5025_2                      96. [SEE ELECTION STUDY NOTES]   E5026_2
# IMD5052_1   99.00. MISSING/NOT AVAILABLE AT TIME OF PUBLIC...   E5093_1
# IMD5054_2   999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLI...   E5099_2
# IMD5024_3                                       9999. MISSING   E5025_3
# IMD5055_1   999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLI...   E5097_1
# IMD5053_3   999999.00. MISSING/NOT AVAILABLE AT TIME OF PU...   E5094_3
# IMD5022_3   00.00 THERE IS NO THRESHOLD|96.00 OTHER THRESH...   E5048_3
# IMD5053_2   999999.00. MISSING/NOT AVAILABLE AT TIME OF PU...   E5094_2
# IMD5021_4           1. YES|5. NO|7. NOT APPLICABLE|9. MISSING   E5047_4
# IMD5054_1   999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLI...   E5099_1
# IMD5021_3           1. YES|5. NO|7. NOT APPLICABLE|9. MISSING   E5047_3
# IMD5056_3   99999.00. MISSING/NOT AVAILABLE AT TIME OF PUB...   E5095_3
# IMD5050_1                                                       E5090_1
# IMD3003_LH  0. RESPONDENT DID NOT CAST A BALLOT|1. RESPOND...  E3014_LH
# IMD5051_2   -88. Transition Periods|10. Democratic|99. MIS...   E5091_2
# IMD5024_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...   E5025_1
# IMD5054_3   999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLI...   E5099_3
# IMD5018_1                                  97. NOT APPLICABLE   E5042_1
# IMD5052_3   99.00. MISSING/NOT AVAILABLE AT TIME OF PUBLIC...   E5093_3
# IMD5053_1   999999.00. MISSING/NOT AVAILABLE AT TIME OF PU...   E5094_1
# IMD5055_3   999.00. MISSING/NOT AVAILABLE AT TIME OF PUBLI...   E5097_3
# IMD5052_2   99.00. MISSING/NOT AVAILABLE AT TIME OF PUBLIC...   E5093_2
# IMD5056_1   99999.00. MISSING/NOT AVAILABLE AT TIME OF PUB...   E5095_1
#
#                                                       mod_cat
# int_var
# IMD5025_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...
# IMD5024_2                      96. [SEE ELECTION STUDY NOTES]
# IMD5051_1                          10. Democratic|99. MISSING
# IMD5055_2                                        999. MISSING
# IMD5021_1                                        1. YES|5. NO
# IMD5006_1
# IMD5056_2                                      99999. MISSING
# IMD5057_2
# IMD5021_2                      1. YES|5. NO|7. NOT APPLICABLE
# IMD5022_4                                  97. NOT APPLICABLE
# IMD5025_2
# IMD5052_1                                         99. MISSING
# IMD5054_2                                        999. MISSING
# IMD5024_3
# IMD5055_1                                        999. MISSING
# IMD5053_3                                     999999. MISSING
# IMD5022_3                                  97. NOT APPLICABLE
# IMD5053_2
# IMD5021_4                            1. YES|7. NOT APPLICABLE
# IMD5054_1                                        999. MISSING
# IMD5021_3                             5. NO|7. NOT APPLICABLE
# IMD5056_3                                      99999. MISSING
# IMD5050_1                                          9. MISSING
# IMD3003_LH  0. RESPONDENT DID NOT CAST A BALLOT|1. RESPOND...
# IMD5051_2                          10. Democratic|99. MISSING
# IMD5024_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...
# IMD5054_3                                        999. MISSING
# IMD5018_1
# IMD5052_3                                         99. MISSING
# IMD5053_1                                     999999. MISSING
# IMD5055_3                                        999. MISSING
# IMD5052_2                                         99. MISSING
# IMD5056_1                                      99999. MISSING

# %%
# whole bunch of these have only a single weird non-response value (e.g 999. MISSING -> 999.00 MISSING)
# handled below

# %%
single_weird_non_response = mod5_int_category_discrepancies.set_index("int_var").loc[last_batch_overlap]["mod_cat"].apply(lambda x: ("|" not in x) and (len(x)>0) and (x[0]=="9") ) 
single_weird_non_response_destination = mod5_int_category_discrepancies.set_index("int_var").loc[last_batch_overlap]["int_cat"].apply(lambda x: ("|" not in x) and (len(x)>0) and (x[0]=="9") ) 

rename_df = mod5_int_category_discrepancies.set_index("int_var").loc[last_batch_overlap][single_weird_non_response&single_weird_non_response_destination].copy()

# rename_df.set_index("mod_cat")["int_cat"]

rename_df["conversion"] =rename_df.apply(lambda x: {x["mod_cat"]:x["int_cat"]},axis=1)

for int_var in rename_df.index:
    CSES_int_5[ int_var ] = CSES_5[ rename_df.loc[ int_var , "mod_var" ] ].replace( rename_df.loc[ int_var , "conversion" ] )
## BUG HERE - FIXED!

# %%
last_few = mod5_int_category_discrepancies.set_index("int_var").loc[last_batch_overlap][~(single_weird_non_response&single_weird_non_response_destination)]

# %%
last_few
# Out:
#                                                       int_cat   mod_var  \
# int_var
# IMD5025_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...   E5026_1
# IMD5024_2          96. [SEE ELECTION STUDY NOTES]|99. MISSING   E5025_2
# IMD5051_1   -88. Transition Periods|10. Democratic|99. MIS...   E5091_1
# IMD5021_1                             1. YES|5. NO|9. MISSING   E5047_1
# IMD5006_1                                        999. MISSING   E5006_1
# IMD5057_2   999999999. MISSING AND/OR NOT AVAILABLE AT TIM...   E5098_2
# IMD5021_2           1. YES|5. NO|7. NOT APPLICABLE|9. MISSING   E5047_2
# IMD5022_4   00.00 THERE IS NO THRESHOLD|97.00 NOT APPLICAB...   E5048_4
# IMD5025_2                      96. [SEE ELECTION STUDY NOTES]   E5026_2
# IMD5024_3                                       9999. MISSING   E5025_3
# IMD5022_3   00.00 THERE IS NO THRESHOLD|96.00 OTHER THRESH...   E5048_3
# IMD5053_2   999999.00. MISSING/NOT AVAILABLE AT TIME OF PU...   E5094_2
# IMD5021_4           1. YES|5. NO|7. NOT APPLICABLE|9. MISSING   E5047_4
# IMD5021_3           1. YES|5. NO|7. NOT APPLICABLE|9. MISSING   E5047_3
# IMD5050_1                                                       E5090_1
# IMD3003_LH  0. RESPONDENT DID NOT CAST A BALLOT|1. RESPOND...  E3014_LH
# IMD5051_2   -88. Transition Periods|10. Democratic|99. MIS...   E5091_2
# IMD5024_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...   E5025_1
# IMD5018_1                                  97. NOT APPLICABLE   E5042_1
#
#                                                       mod_cat
# int_var
# IMD5025_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...
# IMD5024_2                      96. [SEE ELECTION STUDY NOTES]
# IMD5051_1                          10. Democratic|99. MISSING
# IMD5021_1                                        1. YES|5. NO
# IMD5006_1
# IMD5057_2
# IMD5021_2                      1. YES|5. NO|7. NOT APPLICABLE
# IMD5022_4                                  97. NOT APPLICABLE
# IMD5025_2
# IMD5024_3
# IMD5022_3                                  97. NOT APPLICABLE
# IMD5053_2
# IMD5021_4                            1. YES|7. NOT APPLICABLE
# IMD5021_3                             5. NO|7. NOT APPLICABLE
# IMD5050_1                                          9. MISSING
# IMD3003_LH  0. RESPONDENT DID NOT CAST A BALLOT|1. RESPOND...
# IMD5051_2                          10. Democratic|99. MISSING
# IMD5024_1   01. JANUARY|02. FEBRUARY|03. MARCH|04. APRIL|0...
# IMD5018_1

# %%
rename_dict = {"93. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS":"9999993. VOLUNTEERED: RESPONDENT NOT REGISTERED ON ELECTORAL LISTS [IF APPLICABLE]",
               "97. VOLUNTEERED: REFUSED":"9999997. VOLUNTEERED: REFUSED",
               "98. VOLUNTEERED: DON'T KNOW":"9999998. VOLUNTEERED: DON'T KNOW",
               "99. MISSING":"9999999. MISSING"}

CSES_int_5["IMD3003_LH"] = CSES_5["E3014_LH"].cat.rename_categories(rename_dict).cat.set_categories(CSES_int["IMD3003_LH"].cat.categories)

# %%
# I've done a manual pass of the leftovers checking cases where there's a discrepancy in the category types
# *and it's one resolveable by renaming a category*

# what remains should be amenable to directly copying across

last_few.drop("IMD3003_LH",inplace=True)

# %%
for int_var in last_few.index:
    CSES_int_5[ int_var ] = CSES_5[ last_few.loc[ int_var , "mod_var" ] ]

# %%
## complete nulls!

legitimately_missing = CSES_int_5.isnull().sum()[CSES_int_5.isnull().sum()>0].index

# LEGITIMATELY NOT PRESENT (or not really analogues for IMD variables) in MOD5
# Study context: IMD1015 (actually, just confusing naming - it matching STUDY TIMING variable from other datasets) -> FIXED
# 3rd/4th canidates for upper house elections: 'IMD3002_UH_DC_3', 'IMD3002_UH_DC_4', 'IMD3004_UH_DC_3'
# dichotomous political information variables: 'IMD3015_1', 'IMD3015_2', 'IMD3015_3', 'IMD3015_4', 'IMD3015_A',
#        'IMD3015_B', 'IMD3015_C', 'IMD3015_D',
# LEGISLATIVE CHAMBERS: MEANS OF ELECTION: IMD5026_2
legitimately_missing
# Out:
# Index(['IMD1015', 'IMD3002_UH_DC_3', 'IMD3002_UH_DC_4', 'IMD3004_UH_DC_3',
#        'IMD3015_1', 'IMD3015_2', 'IMD3015_3', 'IMD3015_4', 'IMD3015_A',
#        'IMD3015_B', 'IMD3015_C', 'IMD3015_D', 'IMD5006_2', 'IMD5018_3',
#        'IMD5025_3', 'IMD5026_2', 'IMD5027', 'IMD5028', 'IMD5030', 'IMD5049',
#        'IMD5050_2', 'IMD5050_3', 'IMD5051_3', 'IMD5057_1', 'IMD5057_3'],
#       dtype='object')

# %%
## ah - we missed a few that didn't go into the mod5_int_category_discrepancies csv!

CSES_int_5["IMD5006_2"] = CSES_5["E5006_2"]
CSES_int_5["IMD5018_3"] = CSES_5["E5042_3"]
CSES_int_5["IMD5025_3"] = CSES_5["E5026_3"]

CSES_int_5["IMD5027"] = CSES_5["E5072"]
CSES_int_5["IMD5028"] = CSES_5["E5012"]

CSES_int_5["IMD5030"] = CSES_5["E5016"]
CSES_int_5["IMD5049"] = CSES_5["E5050"]

CSES_int_5["IMD5049"] = CSES_5["E5050"]

CSES_int_5["IMD5050_2"] = CSES_5["E5090_2"]

CSES_int_5["IMD5050_3"] = CSES_5["E5090_3"]

CSES_int_5["IMD5051_3"] = CSES_5["E5091_3"]

CSES_int_5["IMD5057_1"] = CSES_5["E5098_1"]

CSES_int_5["IMD5057_3"] = CSES_5["E5098_3"]

CSES_int_5["IMD1015"]   = CSES_5["E1022"].cat.set_categories(CSES_int["IMD1015"].cat.categories)

# %%
CSES_int_5["IMD3002_UH_DC_3"] = CSES_int_5["IMD3002_UH_DC_2"]
CSES_int_5["IMD3002_UH_DC_4"] = CSES_int_5["IMD3002_UH_DC_2"]
CSES_int_5["IMD3004_UH_DC_3"] = CSES_int_5["IMD3004_UH_DC_2"]
# best filler option (contains no parties - presumably they look at the empty dataset for 2nd candidated and decided 3/4 redundant)
dichotomous_pol_inf_variabels = ['IMD3015_1', 'IMD3015_2', 'IMD3015_3', 'IMD3015_4', 'IMD3015_A',
       'IMD3015_B', 'IMD3015_C', 'IMD3015_D']
for dich_var in dichotomous_pol_inf_variabels:
    CSES_int_5[dich_var] = '9. MISSING'

CSES_int_5["IMD5026_2"] = '9. MISSING'
# this adds a category that doesn't appear in the original - nothing to be done about that though!

# %%
# pipe_infiltration = CSES_int_5.applymap(lambda x: "|" in x if isinstance(x,str) else False).sum()
# pipe_infiltration.sort_values()


# Quick check to see if "|" separator had leaked into some columns - it hasn't (now)
# #WARNING - some vote category sets include "|" as legitimate character!

# %%
# set(CSES_int["IMD1004"].value_counts().index).intersection(set(CSES_int_5["IMD1004"].value_counts().index))

# okay - only one problem!

## Greece_2015 election studies in both Mod4 and Mod5 refere to January and September elections
# need to give them new 'polity' codes 30002015 -> 30012015/30022015

CSES_int_5["IMD1003"] = CSES_int_5["IMD1003"].replace({"30002015. GREECE (2015)":"30022015. GREECE (2015)"})
CSES_int["IMD1003"] = CSES_int["IMD1003"].replace({"30002015. GREECE (2015)":"30012015. GREECE (2015)"})

year_2015_5 = CSES_int_5["IMD1008_YEAR"]==2015
CSES_int_5["IMD1006"][year_2015_5] = CSES_int_5["IMD1006"][year_2015_5].replace({"3000":"3002"})
year_2015_int = CSES_int["IMD1008_YEAR"]==2015
CSES_int["IMD1006"][year_2015_int] = CSES_int["IMD1006"][year_2015_int].replace({"3000":"3001"})
# Conveniently, "30002015" only appears as the polity string (e.g. ever in the respondent part of the string)
CSES_int_5["IMD1005"] = CSES_int_5["IMD1005"].apply(lambda x: x.replace("30002015","30022015"))
CSES_int["IMD1005"]   = CSES_int["IMD1005"  ].apply(lambda x: x.replace("30002015","30012015"))


### Actually, not pertinent - only the first 3 numbers are the country code in the party code
# but it did help me to notice that mod5 uses a completely different party id system!!!

# %%
CSES_int_5[list(search(CSES_int,"IMD5000").index)].drop_duplicates().stack().unique()#.shape

# expecting to see 157 different party codes
# 157 + MISSING CODE
# not necessarily 157 different lines (some parties repeated between years!)
# Out:
# array(['036001. AUS - Liberal Party',
#        '036002. AUS - Australian Labor Party',
#        '036003. AUS - Australian Greens',
#        '036004. AUS - National Party of Australia',
#        '036005. AUS - United Australia Party',
#        "036006. AUS - Pauline Hanson's One Nation", '999999. MISSING',
#        '040001. AUT - Sebastian Kurz List – The New People’s Party',
#        '040002. AUT - Social Democratic Party of Austria',
#        '040003. AUT - Freedom Party of Austria',
#        '040004. AUT - NEOS – The New Austria together with Irmgard Griss, Citizens for Freedom and Responsibility',
#        '040005. AUT - Peter Pilz List',
#        '040006. AUT - The Greens – The Green Alternative',
#        '076001. BRA - Social Liberal Party - PSL',
#        "076002. BRA - Workers' Party - PT",
#        '076003. BRA - Brazilian Social Democracy Party - PSDB',
#        '076004. BRA - Social Democratic Party - PSD',
#        '076005. BRA - Progressive Party - PP',
#        '076006. BRA - Brazilian Democratic Movement - MDB',
#        '076007. BRA - Brazilian Socialist Party - PSB',
#        '076008. BRA - Republic Party - PR',
#        '076009. BRA - Brazilian Republican Party - PRB',
#        '152001. CHL - National Renewal',
#        '152002. CHL - Independent Democratic Union',
#        '152003. CHL - Christian Democratic Party',
#        '152004. CHL - Socialist Party of Chile',
#        '152005. CHL - Party for Democracy',
#        '152006. CHL - Democratic Revolution',
#        '152007. CHL - Communist Party of Chile',
#        '152008. CHL - Political Evolution',
#        '152009. CHL - Social Democrat Radical Party',
#        '276001. DEU - Christian Democratic Union',
#        '276002. DEU - Social Democratic Party',
#        '276003. DEU - Alternative for Germany',
#        '276004. DEU - Free Democratic Party', '276005. DEU - Left Party',
#        '276006. DEU - Alliance 90/The Greens',
#        '276007. DEU - Christian Social Union in Bavaria',
#        '276008. DEU - Free Voters', '250001. FRA - The Republic Onwards!',
#        '250002. FRA - National Front', '250003. FRA - The Republicans',
#        '250004. FRA - Indomitable France',
#        '250005. FRA - Socialist Party', '250006. FRA - France Arise',
#        '250014. FRA - Europe Ecology – The Greens',
#        '300001. GRC - Coalition of the Radical Left (SYRIZA)',
#        '300002. GRC - New Democracy',
#        '300003. GRC - Popular Association - Golden Dawn',
#        '300004. GRC - Democratic Coalition – PASOK-DIMAR',
#        '300005. GRC - Communist Party of Greece',
#        '300006. GRC - The River',
#        '300007. GRC - Independent Greeks - National Patriotic Alliance',
#        '300008. GRC - Union of Centrists',
#        '344001. HKG - Democratic Alliance for the Betterment and Progress of Hong Kong',
#        '344002. HKG - Civic Party', '344003. HKG - Democratic Party',
#        '344004. HKG - Hong Kong Federation of Trade Unions',
#        "344005. HKG - New People's Party",
#        '344006. HKG - People Power – League of Social Democrats',
#        '344009. HKG - Civic Passion - Proletariat Political Institute – Hong Kong Resurgence Order',
#        '344014. HKG - Labour Party', '344015. HKG - ALLinHKG',
#        '348001. HUN - Fidesz – KDNP',
#        '348002. HUN - Jobbik – Movement for a Better Hungary',
#        '348003. HUN - Hungarian Socialist Party – Dialogue for Hungary',
#        '348004. HUN - Politics Can Be Different – LMP',
#        '348005. HUN - Democratic Coalition – DK',
#        '348006. HUN - Momentum Movement',
#        '348007. HUN - Hungarian Two-tailed Dog Party',
#        '348008. HUN - Together', '372001. IRL - Fine Gael',
#        '372002. IRL - Fianna Fail', '372003. IRL - Sinn Fein',
#        '372004. IRL - Labour Party',
#        '372005. IRL - Anti-Austerity Alliance - People Before Profit',
#        '372006. IRL - Social Democrats', '372007. IRL - Green Party',
#        '372008. IRL - Renua Ireland', '352001. ISL - Independence Party',
#        '352002. ISL - Left-Green Movement', '352003. ISL - Pirate Party',
#        '352004. ISL - Progressive Party', '352005. ISL - Reform Party',
#        '352006. ISL - Bright Future',
#        '352007. ISL - Social Democratic Alliance',
#        '352008. ISL - People’s Party', '352009. ISL - Dawn',
#        '352101. ISL - Independence Party',
#        '352102. ISL - Left-Green Movement',
#        '352103. ISL - Social Democratic Alliance',
#        '352104. ISL - Centre Party', '352105. ISL - Progressive Party',
#        '352106. ISL - Pirate Party', '352107. ISL - People’s Party',
#        '352108. ISL - Reform Party', '352109. ISL - Bright Future',
#        '380001. ITA - Five Star Movement',
#        '380002. ITA - Democratic Party', '380003. ITA - League',
#        '380004. ITA - Go Italy', '380005. ITA - Brothers of Italy',
#        '380006. ITA - Free and Equal', '410001. KOR - Saenuri Party',
#        '410002. KOR - Democratic Party of Korea',
#        "410003. KOR - People's Party", '410004. KOR - Justice Party',
#        '440001. LTU - Homeland Union - Lithuanian Christian Democrats',
#        '440002. LTU - Lithuania Union of Farmers and Greens',
#        '440003. LTU - Lithuanian Social Democratic Party',
#        '440004. LTU - Liberal Movement of the Republic of Lithuania',
#        "440005. LTU - Anti-Corruption Coalition (Lithuanian Center Party; Lithuanian Pensioners' Party)",
#        '440006. LTU - Lithuanian Poles Electoral Action',
#        "440007. LTU - Party 'Order and Justice'",
#        '440008. LTU - Labour Party',
#        '499001. MNE - Democratic Party of Socialists of Montenegro',
#        '499002. MNE - Democratic Front', '499003. MNE - Key Coalition',
#        '499004. MNE - Democratic Montenegro',
#        '499005. MNE - Social Democratic Party of Montenegro',
#        '499006. MNE - Social Democrats of Montenegro',
#        '499007. MNE - Bosniak Party',
#        '499008. MNE - Albanians Decisively',
#        '499009. MNE - Croatian Civic Initiative',
#        '578001. NOR - Labour Party', '578002. NOR - Conservative Party',
#        '578003. NOR - Progress Party', '578004. NOR - Center Party',
#        '578005. NOR - Socialist Left Party',
#        '578006. NOR - Liberal Party',
#        '578007. NOR - Christian Democratic Party',
#        '578008. NOR - Environment Party', '578009. NOR - Red Party',
#        '554001. NZL - National Party', '554002. NZL - Labour Party',
#        '554003. NZL - New Zealand First', '554004. NZL - Green Party',
#        '554005. NZL - The Opportunities Party',
#        '554006. NZL - Maori Party', '554007. NZL - ACT New Zealand',
#        '554008. NZL - MANA Movement',
#        '792001. TUR - Justice and Development Party',
#        '792002. TUR - Republican People’s Party',
#        '792003. TUR - Peoples’ Democratic Party',
#        '792004. TUR - Nationalist Action Party',
#        '792005. TUR - Good Party', '792006. TUR - Felicity Party',
#        '158001. TWN - Democratic Progressive Party',
#        '158002. TWN - Kuomintang', '158003. TWN - New Power Party',
#        '158004. TWN - Green-Social Democratic Coalition',
#        '158005. TWN - Minkuotang', '158006. TWN - People First Party',
#        '158007. TWN - Taiwan Solidarity Union',
#        '840001. USA - Democratic Party', '840002. USA - Republican Party',
#        '840003. USA - Libertarian', '840004. USA - Greens'], dtype=object)

# %%
(CSES_int_5[list(search(CSES_int,"IMD3009").index)]!="99. MISSING").groupby(CSES_int_5["IMD1003"]).max().sum(axis=1).sum()

# Expecting to see 133 LEADER rows (may include same person different years)
# Out:
# 133

# %%
party_content_vars = list( variable_manifest[variable_manifest["variable type"]=="party"]["index"].values )

# %%
party_non_references = [x for x in CSES_int_5[party_content_vars].stack().value_counts().index if x[0:2]=="99"]
MOD5_party_references = CSES_int_5[party_content_vars].replace(dict(zip(party_non_references,[np.nan]*len(party_non_references)))).stack().value_counts()
MOD5_party_references = pd.DataFrame(MOD5_party_references).reset_index()
MOD5_party_references["cses_no"] = MOD5_party_references["index"].apply(lambda x: x[0:6]).astype(int)
MOD5_party_references["country"] = MOD5_party_references["index"].apply(lambda x: x[8:11])
MOD5_party_references["party_name"] = MOD5_party_references["index"].apply(lambda x: x[14:])
MOD5_party_references
# Out:
#                                                index      0  cses_no country  \
# 0                     840001. USA - Democratic Party  13865   840001     USA
# 1                     840002. USA - Republican Party  13082   840002     USA
# 2                        036001. AUS - Liberal Party   8681    36001     AUS
# 3         158001. TWN - Democratic Progressive Party   8582   158001     TWN
# 4              276002. DEU - Social Democratic Party   8016   276002     DEU
# ..                                               ...    ...      ...     ...
# 400  440020. LTU - Democratic Labour and Unity Party      1   440020     LTU
# 401          792009. TUR - Rights and Equality Party      1   792009     TUR
# 402                        352015. ISL - Rural Party      1   352015     ISL
# 403                554014. NZL - Climate First Party      1   554014     NZL
# 404                     352012. ISL - Humanist Party      1   352012     ISL
#
#                             party_name
# 0                     Democratic Party
# 1                     Republican Party
# 2                        Liberal Party
# 3         Democratic Progressive Party
# 4              Social Democratic Party
# ..                                 ...
# 400  Democratic Labour and Unity Party
# 401          Rights and Equality Party
# 402                        Rural Party
# 403                Climate First Party
# 404                     Humanist Party
#
# [405 rows x 5 columns]

# %%
party_non_references = [x for x in CSES_int[party_content_vars].stack().value_counts().index if x[0:2]=="99"]
IMD_party_references = CSES_int[party_content_vars].replace(dict(zip(party_non_references,[np.nan]*len(party_non_references)))).stack().value_counts()
IMD_party_references = pd.DataFrame(IMD_party_references).reset_index()

# %%
IMD_party_references["cses_no"] = IMD_party_references["index"].apply(lambda x: x[0:7]).astype(int)
IMD_party_references["country"] = IMD_party_references["index"].apply(lambda x: x[9:12])
IMD_party_references["party_name"] = IMD_party_references["index"].apply(lambda x: x[15:])
IMD_party_references
IMD_party_references = IMD_party_references.rename(columns = {0:"frequency"})
# Out:
#                                                   index      0  cses_no  \
# 0                          0760001. BRA - Workers Party  43960   760001
# 1                     1240002. CAN - Conservative Party  42143  1240002
# 2                2760004. DEU - Social Democratic Party  42022  2760004
# 3           1580001. TWN - Democratic Progressive Party  37792  1580001
# 4                  4840002. MEX - National Action Party  37593  4840002
# ...                                                 ...    ...      ...
# 1531  2030071. CZE - Association Of Pensioners Of Th...      1  2030071
# 1532  2030054. CZE - Club of Committed Non-Party Mem...      1  2030054
# 1533                                 6080201. PHL - Alu      1  6080201
# 1534            4280020. LVA - Party Daugava for Latvia      1  4280020
# 1535  1120039. BLR - The Social-Democratic Party of ...      1  1120039
#
#      country                                         party_name
# 0        BRA                                      Workers Party
# 1        CAN                                 Conservative Party
# 2        DEU                            Social Democratic Party
# 3        TWN                       Democratic Progressive Party
# 4        MEX                              National Action Party
# ...      ...                                                ...
# 1531     CZE    Association Of Pensioners Of The Czech Republic
# 1532     CZE                Club of Committed Non-Party Members
# 1533     PHL                                                Alu
# 1534     LVA                           Party Daugava for Latvia
# 1535     BLR  The Social-Democratic Party of the People Agre...
#
# [1536 rows x 5 columns]

# %%
es_and_party_ref = ["IMD1004","IMD1003","IMD1008_MOD_5"]+list(search(CSES_int,"IMD5000").index)
CSES_int_final.sort_values(by="IMD1004")[es_and_party_ref].drop_duplicates().to_csv(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"module5_party_codes.csv")

# %%
# search(CSES_int_final,"MOD")
cses_variable_types = pd.read_pickle(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"cses_variable_types.pkl")
variable_manifest = pd.read_csv(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"variable_manifest.csv",index_col="Unnamed: 0")
variable_manifest
# Out:
#              index  un_val_len final_dtypes original_dtypes  \
# 0          IMD1001           2       object          object
# 1      IMD1002_VER           2       object          object
# 2      IMD1002_DOI           2       object          object
# 3          IMD1003         194       object        category
# 4          IMD1004         194       object          object
# ..             ...         ...          ...             ...
# 272      IMD5058_1         148       object        category
# 273      IMD5058_2         108       object        category
# 274      IMD5059_1         149       object        category
# 275      IMD5059_2         106       object        category
# 276  IMD1008_MOD_5           2     category        category
#
#                                                  descr  \
# 0                                              dataset
# 1                                      DATASET VERSION
# 2                            DIGITAL OBJECT IDENTIFIER
# 3        ID VARIABLE - ELECTION STUDY (NUMERIC POLITY)
# 4     ID VARIABLE - ELECTION STUDY (ALPHABETIC POLITY)
# ..                                                 ...
# 272              EFFECTIVE NUMBER OF ELECTORAL PARTIES
# 273    CORRECTED EFFECTIVE NUMBER OF ELECTORAL PARTIES
# 274          EFFECTIVE NUMBER OF PARLIAMENTARY PARTIES
# 275  CORRECTED EFFECTIVE NUMBER OF PARLIAMENTARY PA...
# 276                       ID COMPONENT - CSES MODULE 4
#
#                                      Short Description  \
# 0                                         Dataset Name
# 1                                      Dataset Version
# 2                            Digital Object Identifier
# 3                                          Study Id No
# 4                                        Study Id Name
# ..                                                 ...
# 272              Effective Number of Electoral Parties
# 273    Corrected Effective Number of Electoral Parties
# 274          Effective Number of Parliamentary Parties
# 275  Corrected Effective Number of Parliamentary Pa...
# 276                                           Module 5
#
#                                                      0 variable type  \
# 0                               CSES-IMD|CSES-MODULE-5          meta
# 1                        VER2019-OCT-17|VER2020-MAY-14          meta
# 2    doi:10.7804/cses.imd.2019-10-17|doi:10.7804/cs...          meta
# 3    ['00802005. ALBANIA (2005)', '03202015. ARGENT...          meta
# 4    ['ALB_2005', 'ARG_2015', 'AUS_1996', 'AUS_2004...          meta
# ..                                                 ...           ...
# 272  ['10.46', '3.4', '3.21', '3.17', '3.03', '3.42...   seminumeric
# 273  ['999.00. MISSING', '3.4', '3.03', '3.42', '4....   seminumeric
# 274  ['3.75', '3.52', '2.62', '2.44', '2.43', '2.36...   seminumeric
# 275  ['999.00. MISSING', '3.48', '2.43', '2.36', '4...   seminumeric
# 276      00. NOT IN CSES MODULE 5|01. IN CSES MODULE 5          meta
#
#     variable structural type
# 0                    dataset
# 1                    dataset
# 2                    dataset
# 3                    country
# 4                    country
# ..                       ...
# 272                  country
# 273                  country
# 274                  country
# 275                  country
# 276                  country
#
# [277 rows x 9 columns]

# %%
module5_party_codes_filled_in = pd.read_csv(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"module5_party_codes_fille_in.csv").drop("Unnamed: 0",axis=1)
filled_in_rows = module5_party_codes_filled_in["IMD1004"].isnull()[ module5_party_codes_filled_in["IMD1004"].isnull() ].index
# in every filled_in row
# need to find non-empty cells and pair with cell 'above'

mod5_to_IMD_party_dict = {}

for fi_row in filled_in_rows:
    for fi_col in module5_party_codes_filled_in.columns:
        if pd.notnull( module5_party_codes_filled_in.loc[fi_row,fi_col] ):
            mod5_to_IMD_party_dict[ module5_party_codes_filled_in.loc[fi_row-1,fi_col] ] = module5_party_codes_filled_in.loc[fi_row,fi_col]

# %%
df = pd.melt(module5_party_codes_filled_in[ module5_party_codes_filled_in["IMD1008_MOD_5"]=="01. IN CSES MODULE 5" ]\
    .replace("999999. MISSING",np.nan)\
    .drop(["IMD1004","IMD1008_MOD_5"],axis=1),id_vars="IMD1003",value_vars=list(search(CSES_int,"IMD5000").index))\
    .dropna().sort_values(by=["IMD1003","value"])
df.columns = ["IMD1003","party letter","mod5 cses party id"]
df["party letter"] = df["party letter"].apply(lambda x: x.split("_")[1])
df["IMD cses party id"] = df["mod5 cses party id"].apply(lambda x: mod5_to_IMD_party_dict[x])
df["mod5 id"] =df["mod5 cses party id"].apply(lambda x: int( x.split(".")[0] ) )
df["IMD id"] =df["IMD cses party id"].apply(lambda x: x  if ( (x=="NEW") or (x=="????") ) else int( x.split(".")[0] ) )

#.applymap(lambda x: x if x not in mod5_to_IMD_party_dict.keys() else {x:mod5_to_IMD_party_dict[x]})

mod5_parties_list = df.copy()
mod5_parties_list["NEW"] = mod5_parties_list["IMD cses party id"]=="NEW"
mod5_parties_list["????"] = mod5_parties_list["IMD cses party id"]=="????"

mod5_parties_list["election_study"] = mod5_parties_list["IMD1003"].apply(lambda x: x.split(". ")[1])

# How do we marry this against the marpor/parlgov data at the bottom half of the text file?
# For some reason they didn't include the CSES mod 5 id - just strings

# %%
(mod5_parties_list["IMD cses party id"]=="NEW").sum()
# Out:
# 31

# %%
# mod5_parties_list[mod5_parties_list["election_study"]=="IRELAND (2016)"]

# %%
election_studies_in_common = list(set(mod5_parties_list["election_study"].unique()).intersection(set(mod5_major_party_ids["election_study"].unique())))
# mod5_parties_list[mod5_parties_list["election_study"].apply(lambda x: x in election_studies_in_common)]["election_study"].value_counts()

# %%
# mod5_major_party_ids[mod5_major_party_ids["election_study"].apply(lambda x: x in election_studies_in_common)]["election_study"].value_counts()
#.head(50)
#.reset_index().set_index("cses_from_both")

# %%
# mod5_parties_list[mod5_parties_list["election_study"].apply(lambda x: x in election_studies_in_common)]["election_study"].value_counts() - mod5_major_party_ids[mod5_major_party_ids["election_study"].apply(lambda x: x in election_studies_in_common)]["election_study"].value_counts()

# %%
mod5_parties_list = mod5_parties_list.sort_values(by=["election_study","party letter"])
ser = mod5_parties_list[mod5_parties_list["election_study"].apply(lambda x: x in election_studies_in_common)].reset_index().reset_index().set_index("index")["level_0"]
mod5_parties_list["merge_index"] = ser
# mod5_parties_list.tail(50)

# %%
mod5_mpi_df = mod5_major_party_ids.sort_index()[mod5_major_party_ids.sort_index()["election_study"].apply(lambda x: x in election_studies_in_common)].reset_index().reset_index()
mod5_mpi_df = mod5_mpi_df.rename(columns={"index":"mpi_index","level_0":"merge_index"})
# mod5_mpi_df.tail(50)

# %%
## fiddly, but now I've added the manual entry for the major (A-I) parties listed
# with the study ids


df = mod5_parties_list.merge( mod5_mpi_df, how='left', on="merge_index" )
df = df.drop("election_study_y",axis=1).rename(columns = {"election_study_x":"election_study"})

df
# Out:
#                             IMD1003 party letter  \
# 0        03602019. AUSTRALIA (2019)            A
# 1        03602019. AUSTRALIA (2019)            B
# 2        03602019. AUSTRALIA (2019)            C
# 3        03602019. AUSTRALIA (2019)            D
# 4        03602019. AUSTRALIA (2019)            E
# ..                              ...          ...
# 152         79202018. TURKEY (2018)            F
# 153  84002016. UNITED STATES (2016)            A
# 154  84002016. UNITED STATES (2016)            B
# 155  84002016. UNITED STATES (2016)            C
# 156  84002016. UNITED STATES (2016)            D
#
#                             mod5 cses party id  \
# 0                  036001. AUS - Liberal Party
# 1         036002. AUS - Australian Labor Party
# 2              036003. AUS - Australian Greens
# 3    036004. AUS - National Party of Australia
# 4         036005. AUS - United Australia Party
# ..                                         ...
# 152               792006. TUR - Felicity Party
# 153             840001. USA - Democratic Party
# 154             840002. USA - Republican Party
# 155                  840003. USA - Libertarian
# 156                       840004. USA - Greens
#
#                               IMD cses party id  mod5 id   IMD id    NEW  \
# 0                  0360001. AUS - Liberal Party    36001   360001  False
# 1         0360003. AUS - Australian Labor Party    36002   360003  False
# 2              0360005. AUS - Australian Greens    36003   360005  False
# 3    0360002. AUS - National Party of Australia    36004   360002  False
# 4            0360013. AUS - Palmer United Party    36005   360013  False
# ..                                          ...      ...      ...    ...
# 152               7920005. TUR - Felicity Party   792006  7920005  False
# 153             8400002. USA - Democratic Party   840001  8400002  False
# 154             8400001. USA - Republican Party   840002  8400001  False
# 155            8400003. USA - Libertarian Party   840003  8400003  False
# 156                  8400005. USA - Green Party   840004  8400005  False
#
#       ????        election_study  merge_index  mpi_index  \
# 0    False      AUSTRALIA (2019)          0.0     1652.0
# 1    False      AUSTRALIA (2019)          1.0     1653.0
# 2    False      AUSTRALIA (2019)          2.0     1654.0
# 3    False      AUSTRALIA (2019)          3.0     1655.0
# 4    False      AUSTRALIA (2019)          4.0     1656.0
# ..     ...                   ...          ...        ...
# 152  False         TURKEY (2018)        118.0     1879.0
# 153  False  UNITED STATES (2016)        119.0     1885.0
# 154  False  UNITED STATES (2016)        120.0     1886.0
# 155  False  UNITED STATES (2016)        121.0     1887.0
# 156  False  UNITED STATES (2016)        122.0     1888.0
#
#                        partyname party abbrev marpor id parlgov id  \
# 0                  Liberal Party         (LP)     63620       1411
# 1         Australian Labor Party        (ALP)     63320       1253
# 2              Australian Greens         (AG)     63110        751
# 3    National Party of Australia         (NP)     63810        184
# 4         United Australia Party        (UAP)     63410       1912
# ..                           ...          ...       ...        ...
# 152               Felicity Party         (SP)     74717       1315
# 153             Democratic Party        (DEM)     61320       9999
# 154             Republican Party        (REP)     61620       9999
# 155                  Libertarian         (LP)    999999       9999
# 156                        Green       (GPUS)    999999       9999
#
#      pf_from_marpor  pf_from_parlgov  cses_from_marpor  cses_from_parlgov  \
# 0             486.0            486.0               NaN                NaN
# 1             424.0            424.0          360003.0           360003.0
# 2            1209.0           1209.0          360005.0           360005.0
# 3            1743.0           1743.0          360002.0           360002.0
# 4            1996.0            566.0          360013.0                NaN
# ..              ...              ...               ...                ...
# 152             NaN            572.0               NaN                NaN
# 153           432.0              NaN         8400002.0                NaN
# 154           809.0              NaN         8400001.0                NaN
# 155             NaN              NaN               NaN                NaN
# 156             NaN              NaN               NaN                NaN
#
#      cses_from_both
# 0               NaN
# 1          360003.0
# 2          360005.0
# 3          360002.0
# 4          360013.0
# ..              ...
# 152             NaN
# 153       8400002.0
# 154       8400001.0
# 155             NaN
# 156             NaN
#
# [157 rows x 20 columns]

# %%
# MOD5_party_references

# %%
df[ df["NEW"]|df["????"] ]["cses_from_both"].notnull().sum()

# 53 gaps
# 44 instances where the mpi comparative data is present
# 4 instances where there's a cses reference!
# Out:
# 1

# %%
df[ (df["NEW"]|df["????"]) &df["cses_from_both"].notnull()]["mod5 cses party id"].values
# Out:
# array(['440002. LTU - Lithuania Union of Farmers and Greens'],
#       dtype=object)

# %%
# IMD_party_references[IMD_party_references["cses_no"]==3000013]

# %%
# IMD_party_references[IMD_party_references["cses_no"]==3800003]

# %%
# IMD_party_references[IMD_party_references["cses_no"]==3800002]

# %%
# IMD_party_references[IMD_party_references["cses_no"]==4400001]

## BUG in the references!

# %%
# IMD_party_references[IMD_party_references["country"]=="LTU"]

# %%
# partyfacts: 1490

# %%
# pf_ids_to_cses.loc[1490]
# df

# %%
# AllMod5PartyReferences
# this is probably how you want to link in all 400+ mod 5 party references

# %%
# Out:
#                                                   index  frequency  cses_no  \
# 0                          0760001. BRA - Workers Party      43960   760001
# 1                     1240002. CAN - Conservative Party      42143  1240002
# 2                2760004. DEU - Social Democratic Party      42022  2760004
# 3           1580001. TWN - Democratic Progressive Party      37792  1580001
# 4                  4840002. MEX - National Action Party      37593  4840002
# ...                                                 ...        ...      ...
# 1531  2030071. CZE - Association Of Pensioners Of Th...          1  2030071
# 1532  2030054. CZE - Club of Committed Non-Party Mem...          1  2030054
# 1533                                 6080201. PHL - Alu          1  6080201
# 1534            4280020. LVA - Party Daugava for Latvia          1  4280020
# 1535  1120039. BLR - The Social-Democratic Party of ...          1  1120039
#
#      country                                         party_name
# 0        BRA                                      Workers Party
# 1        CAN                                 Conservative Party
# 2        DEU                            Social Democratic Party
# 3        TWN                       Democratic Progressive Party
# 4        MEX                              National Action Party
# ...      ...                                                ...
# 1531     CZE    Association Of Pensioners Of The Czech Republic
# 1532     CZE                Club of Committed Non-Party Members
# 1533     PHL                                                Alu
# 1534     LVA                           Party Daugava for Latvia
# 1535     BLR  The Social-Democratic Party of the People Agre...
#
# [1536 rows x 5 columns]

# %%
AllMod5PartyReferences = MOD5_party_references.merge(df,how='left',left_on='index',right_on='mod5 cses party id').drop("mod5 cses party id",axis=1).rename(columns={"index":"mod5 cses party id",0:"frequency"})

abbrev_mod5_to_imd = match_by_abbrev[ match_by_abbrev["imd_cses_ids"].notnull() ].set_index("mod5_cses_ids")["imd_cses_ids"]
AllMod5PartyReferences["still_missing"] = AllMod5PartyReferences['IMD id'].isnull()|AllMod5PartyReferences['NEW']|AllMod5PartyReferences['????']
AllMod5PartyReferences["cses_from_abbrev"] = AllMod5PartyReferences["cses_no"].apply(lambda x: abbrev_mod5_to_imd.loc[str(x)] if str(x) in abbrev_mod5_to_imd.index else np.nan)
AllMod5PartyReferences["cses_no"].apply(lambda x: abbrev_mod5_to_imd.loc[str(x)] if str(x) in abbrev_mod5_to_imd.index else np.nan)
AllMod5PartyReferences["cses_from_abbrev"] = AllMod5PartyReferences["cses_from_abbrev"].astype(float)
AllMod5PartyReferences["IMD cses party id from abbrev"] = AllMod5PartyReferences["cses_from_abbrev"].apply(lambda x: IMD_party_references.set_index("cses_no")["index"].loc[x] if (x in IMD_party_references["cses_no"].values) & (pd.notnull(x)) else np.nan)

# %%
partyname_mod5_to_imd = match_by_partyname[ match_by_partyname["imd_cses_ids"].notnull() ].set_index("mod5_cses_ids")["imd_cses_ids"]
partyname_mod5_to_imd.shape
# Out:
# (36,)

# %%
AllMod5PartyReferences["cses_from_partyname"] = AllMod5PartyReferences["cses_no"].apply(lambda x: partyname_mod5_to_imd.loc[str(x)] if str(x) in partyname_mod5_to_imd.index else np.nan)
AllMod5PartyReferences["cses_from_partyname"] = AllMod5PartyReferences["cses_from_partyname"].astype(float)
AllMod5PartyReferences["IMD cses party id from partyname"] = AllMod5PartyReferences["cses_from_partyname"].apply(lambda x: IMD_party_references.set_index("cses_no")["index"].loc[x] if (x in IMD_party_references["cses_no"].values) & (pd.notnull(x)) else np.nan)

# %%
# AllMod5PartyReferences[AllMod5PartyReferences["IMD cses party id from partyname"].notnull()]

# %%
# AllMod5PartyReferences[AllMod5PartyReferences["still_missing"]&AllMod5PartyReferences["IMD cses party id from abbrev"]][["mod5 cses party id","IMD cses party id from abbrev"]]

# %%
# IMD_party_references[IMD_party_references["cses_no"]==8400002]
# IMD_party_references.set_index("cses_no")["index"].loc[8400002.0]

# %%
# AllMod5PartyReferences["cses_from_abbrev"]

# %%
# IMD_party_references[ IMD_party_references["country"]=="ITA" ]


# 3800001.[ ITA -] Democratic Party (PD)
# present in IMD, but not in any of the data!

# %%
# (IMD_party_references["cses_no"]==3800001).sum()

# %%
AllMod5PartyReferences[AllMod5PartyReferences["still_missing"]\
                       &AllMod5PartyReferences["cses_from_abbrev"].notnull()\
                       &AllMod5PartyReferences["party letter"].notnull()]["mod5 cses party id"].values


# 380006. ITA - Free and Equal : 3800010. ITA - Free and Equal (LeU)
# 348002. HUN - Jobbik – Movement for a Better Hungary : 3480003. HUN - Jobbik The Movement for a Better Hungary (Jobbik)
# 4990013. MNE - Democratic Montenegro (DCG) : 499004. MNE - Democratic Montenegro
# 4990004. MNE - Social Democratic Party (SDP) : 499005. MNE - Social Democratic Party of Montenegro
# Out:
# array(['499004. MNE - Democratic Montenegro',
#        '499005. MNE - Social Democratic Party of Montenegro'],
#       dtype=object)

# %%
AllMod5PartyReferences["IMD id"] = AllMod5PartyReferences["IMD id"].replace("NEW",np.nan).replace("????",np.nan)
IMD_cses_refs = AllMod5PartyReferences[["IMD id","cses_from_abbrev"]].fillna(method='bfill',axis=1)["IMD id"]

# 148/257

# %%
AllMod5PartyReferences["frequency"].sort_values()[150:].head(50)
# Out:
# 254    11
# 253    11
# 252    11
# 251    11
# 247    12
# 246    12
# 248    12
# 250    12
# 249    12
# 244    13
# 243    13
# 242    13
# 241    13
# 245    13
# 236    14
# 237    14
# 234    14
# 239    14
# 240    14
# 238    14
# 235    14
# 233    15
# 232    16
# 231    16
# 230    16
# 229    16
# 228    17
# 227    17
# 223    18
# 222    18
# 224    18
# 226    18
# 225    18
# 221    19
# 220    19
# 219    19
# 218    19
# 217    19
# 216    20
# 215    22
# 212    23
# 214    23
# 213    23
# 211    24
# 210    24
# 209    25
# 208    25
# 207    26
# 206    28
# 205    28
# Name: frequency, dtype: int64

# %%
AllMod5PartyReferences[AllMod5PartyReferences["IMD id"].isnull()&(AllMod5PartyReferences["frequency"]<=50)&(AllMod5PartyReferences["frequency"]>25)]["mod5 cses party id"].sort_values().values

manual_mod5_party_conversion_dict = {'276009. DEU - Christian Democratic Union / Christian Social Union':'2760001.  Christian Democratic Union / Christian Social Union (Union)',
 '410005. KOR - Democratic United Party': '4100004. Democratic United Party (DUP)',
 "499026. MNE - Coalition 'For a European Montenegro'":'4990011. Coalition "For a European Montenegro"',
 '076011. BRA - Democratic Labour Party - PDT':'0760011. Labor Democratic Party (PDT)',
 '840003. USA - Libertarian Party':'8400003. Libertarian Party (LP)',
 '250015. FRA - Left Front':'2500006. FRA - Left Front',
 '250012. FRA - Democratic Movement':'2500003. FRA - Democratic Movement',
 '076012. BRA - Socialism and Liberty Party - PSOL':'0760021. BRA - Socialism and Freedom Party',
 '499019. MNE - Socialist Peoples Party of Montenegro':"4990003. MNE - Socialist People's Party",
 '076010. BRA - Democrats - DEM':'0760009. BRA - Democrats',
 '276010. DEU - The Party':'2760030. DEU - The Party',
 '076014. BRA - Podemos - PODE':'0760025. BRA - National Labour Party',
 '076015. BRA - Republican Party of the Social Order - PROS':'0760019. BRA - Republican Party of the Social Order',
 '076016. BRA - Brazilian Labour Party - PTB':'0760010.  Brazilian Labor Party (PTB)',
 '076017. BRA - Solidariedade - SOLIDARIEDADAE':'0760012. BRA - Solidarity',
 '076018. BRA - Avante - AVANTE':'0760023.  Labor Party of Brazil (PT do B)',
 '076019. BRA - Social Christian Party - PSC':'0760016.  Social Christian Party (PSC)',
 '076020. BRA - Green Party - PV':'0760017.  Green Party (PV)',
 '076021. BRA - Popular Socialist Party - PPS':'0760018.  Popular Socialist Party (PPS)',
 '076022. BRA - Patriota - PATRI':'0760027.  National Ecologic Party (PEN)',
 '076024. BRA - Communist Party of Brazil - PC do B':'0760020.  Communist Party of Brazil (PC do B)',
 '076027. BRA - Brazilian Labour Renewal Party - PRTB':'0760032.  Brazilian Labor Renewal Party (PRTB)',
 '250008. FRA - New Anticapitalist Party':'2500028. FRA - New Anticapitalist Party',
 '250010. FRA - Workers’ Struggle':"2500009. FRA - Workers' Struggle",
 '250013. FRA - French Communist Party':'2500004. FRA - French Communist Party',
 '276012. DEU - National Democratic Party Of Germany':'2760009. DEU - National Democratic Party Of Germany',
 '276013. DEU - Pirates Party':'2760014. DEU - Pirates Party',
 '344007. HKG - People Power':'3440004. HKG - People Power',
 '344008. HKG - League of Social Democrats':'3440007. HKG - League of Social Democrats',
#  '344011. HKG - Civic Passion': '344016. HKG - Youngspiration',
 '352112. ISL - Humanist Party':'3520022. ISL - Humanist Party',
 '380009. ITA - Popular Civic List':"3800025. ITA - Popular Civic List",
 '410006. KOR - Unified Progressive Party':'4100005. KOR - Unified Progressive Party',
 '499010. MNE - Positive Montenegro':'4990006. MNE - Positive Montenegro',
 '840004. USA - Green Party of the United States':'8400005. USA - Green Party',
 '380010. ITA - Popular Civic List':'3800025.  Popular Civic List (CP)',
 '344035. HKG - Democratic Alliance':'3440025. HKG - Democratic Alliance',
 '554002. NZL - Labour Party':'5540002. NZL - Labour Party',
                                    }
 
 
 
 # '276009. DEU - Christian Democratic Union / Christian Social Union': 
## but it seems redundant
# 2760002. DEU - Christian Democratic Party

# '348010. HUN - Unity': ... new party
# '152011. CHL - Progressive Party': new party!

# '036007. AUS - Animal Justice Party':NEW/SMALL
# '036035. AUS - Australian Conservatives':NEW
# '076026. BRA - Sustainability Network - REDE':????

# '300009. GRC - Popular Unity':NEW,
# '380008. ITA - Us with Italy - Christian Democratic Union':???,
# '380011. ITA - Together List',
# '380019. ITA - Left Ecology Freedom',

# 344035. HKG - Democratic Alliance:3440025. HKG - Democratic Alliance
# 554002. NZL - Labour Party:5540002. NZL - Labour Party

# %%
len( manual_mod5_party_conversion_dict )
# Out:
# 37

# %%
AllMod5PartyReferences["manual IMD cses party id"] = AllMod5PartyReferences["mod5 cses party id"].apply(lambda x: manual_mod5_party_conversion_dict[x] if x in manual_mod5_party_conversion_dict.keys() else np.nan)


## we want to convert everything to a "full cses <no> <country code> <party name>" string because next step is

# %%
# 348010. HUN - Unity: partyfacts id - 8265
# 152011. CHL - Progressive Party: pf id -7017
# 380007. ITA - Us with Italy - Christian Democratic Union: pf id -6158
# 380019. ITA - Left Ecology Freedom :pf id -7031
# '440002. LTU - Lithuania Union of Farmers and Greens': partyfacts id: 1490
# 380010. ITA - Together List: partyfacts id -7671

manual_mod5_to_pf_dict = {"348010. HUN - Unity":8265,
 "152011. CHL - Progressive Party":7017,
 "380007. ITA - Us with Italy - Christian Democratic Union":6158,
 "380019. ITA - Left Ecology Freedom":7031,
 "440002. LTU - Lithuania Union of Farmers and Greens":1490,
 "380010. ITA - Together List":7671,
 '076001. BRA - Social Liberal Party - PSL': 6920,
  '076014. BRA - Podemos - PODE': 4650,
#   '076018. BRA - Avante - AVANTE': ????,
#   '076022. BRA - Patriota - PATRI': ????,
  '076027. BRA - Brazilian Labour Renewal Party - PRTB': 8290,
  '158011. TWN - Non-Partisan Solidarity Union': 5936,
#   '158018. TWN - Taiwan Independence Party': ????,
#   '158020. TWN - Taiwan National Congress': ????,
  '250006. FRA - France Arise': 3207,
  '250008. FRA - New Anticapitalist Party': 6684,
  '276008. DEU - Free Voters': 1090,
  '276010. DEU - The Party': 6126,
  '276011. DEU - Animal Protection Party': 749,
  '276018. DEU - Bavarian Party': 61,
  '276021. DEU - The Greys - Grey Panthers': 1652,
#   '276022. DEU - Civil Movement for Solidarity': ????,
#   '276025. DEU - Family Party': ????,
#   '276026. DEU - Pensioners/Greys': ????,
#   '276027. DEU - Party of Literal Exegesis': ????,
  '300008. GRC - Union of Centrists': 2510,
  '300013. GRC - Recreate Greece': 471,
#   '344034. HKG - Civil Force': ????,
#   '344035. HKG - Democratic Alliance': ????,
  '348002. HUN - Jobbik – Movement for a Better Hungary': 42,
  '352112. ISL - Humanist Party': 1070,
  '372005. IRL - Anti-Austerity Alliance - People Before Profit': 8241,
  '380005. ITA - Brothers of Italy': 2280,
  '380006. ITA - Free and Equal': 8246,
  '380009. ITA - Popular Civic List': 7670,
  '380010. ITA - Popular Civic List': 7670,
  '440006. LTU - Lithuanian Poles Electoral Action': 556,
  '499001. MNE - Democratic Party of Socialists of Montenegro': 3162,
  '499009. MNE - Croatian Civic Initiative': 3253,
  '499013. MNE - Serb Party': 5487,
  '499022. MNE - New Democratic Power – Forca': 3251,
  '554008. NZL - MANA Movement': 1427,
  '792006. TUR - Felicity Party': 572,
  '792010. TUR - Grand Unity Party': 1330,
# '036007. AUS - Animal Justice Party': ????,
#   '036035. AUS - Australian Conservatives': ????,
  '040005. AUT - Peter Pilz List': 6137,
#   '076013. BRA - New Party - NOVO': ????,
#   '076018. BRA - Avante - AVANTE': ????,
#   '076022. BRA - Patriota - PATRI': ????,
#   '076026. BRA - Sustainability Network - REDE': ????,
  '152006. CHL - Democratic Revolution': 6911,
  '152008. CHL - Political Evolution': 7021,
  '152032. CHL - Broad Front': 812,
#   '152089. CHL - Jose Antonio Kast (Independent)': ????,
  '158003. TWN - New Power Party': 5935,
#   '158004. TWN - Green-Social Democratic Coalition': ????,
#   '158005. TWN - Minkuotang': ????,
#   '158009. TWN - Faith and Hope League': ????,
  '250001. FRA - The Republic Onwards!': 5857,
  '250004. FRA - Indomitable France': 5858,
#   '300004. GRC - Democratic Coalition – PASOK-DIMAR': ????,
  '300009. GRC - Popular Unity': 4512,
  '344009. HKG - Civic Passion - Proletariat Political Institute – Hong Kong Resurgence Order': 8008,
  '344011. HKG - Civic Passion': 8008,
#   '344015. HKG - ALLinHKG': ????,
#   '344016. HKG - Youngspiration': ????,
  '348004. HUN - Politics Can Be Different – LMP': 1650,
  '348005. HUN - Democratic Coalition – DK': 469,
  '348006. HUN - Momentum Movement': 8249,
  '348007. HUN - Hungarian Two-tailed Dog Party': 6129,
  '348008. HUN - Together': 2458,
  '352005. ISL - Reform Party': 5454,
  '352008. ISL - People’s Party': 5852,
  '352104. ISL - Centre Party': 7565,
  '352107. ISL - People’s Party': 5852,
  '352108. ISL - Reform Party': 5454,
  '372006. IRL - Social Democrats': 4870,
  '372008. IRL - Renua Ireland': 4869,
  '380001. ITA - Five Star Movement': 2046,
  '380008. ITA - Us with Italy - Christian Democratic Union': 6158,
  '380011. ITA - Together List': 7671,
#   '380015. ITA - The People of Family': ????,
  '410004. KOR - Justice Party': 6560,
  '440004. LTU - Liberal Movement of the Republic of Lithuania': 1744,
#   "440005. LTU - Anti-Corruption Coalition (Lithuanian Center Party; Lithuanian Pensioners' Party)": ????,
  "440007. LTU - Party 'Order and Justice'": 237,
  '499003. MNE - Key Coalition': 7624,
  '499004. MNE - Democratic Montenegro': 5469,
  '499005. MNE - Social Democratic Party of Montenegro': 3185,
  '499006. MNE - Social Democrats of Montenegro': 5470,
#   '499008. MNE - Albanians Decisively': ????,
  '554005. NZL - The Opportunities Party': 6130,
  '792005. TUR - Good Party': 6236,                      
#   '036007. AUS - Animal Justice Party': ????,
#   '036035. AUS - Australian Conservatives': ?????,
  '040010. AUT - Alliance for the Future of Austria': 599,
  '076010. BRA - Democrats - DEM': 1536,
  '076011. BRA - Democratic Labour Party - PDT': 1009,
  '076012. BRA - Socialism and Liberty Party - PSOL': 501,
#   '076013. BRA - New Party - NOVO': ????,
  '076015. BRA - Republican Party of the Social Order - PROS': 6958,
  '076016. BRA - Brazilian Labour Party - PTB': 458,
  '076017. BRA - Solidariedade - SOLIDARIEDADAE': 6959,
#   '076018. BRA - Avante - AVANTE': ????,
  '076019. BRA - Social Christian Party - PSC': 861,
  '076020. BRA - Green Party - PV': 547,
  '076021. BRA - Popular Socialist Party - PPS': 267,
#   '076022. BRA - Patriota - PATRI': ????,
  '076023. BRA - Humanist Party of Solidarity - PHS': 7078,
  '076024. BRA - Communist Party of Brazil - PC do B': 565,
#   '076026. BRA - Sustainability Network - REDE': ????,
#   '152089. CHL - Jose Antonio Kast (Independent)': ????,
#   '158004. TWN - Green-Social Democratic Coalition': ????,
#   '158005. TWN - Minkuotang': ????,
#   '158009. TWN - Faith and Hope League': ????,
#   '250007. FRA - Resist!': ????,
  '250010. FRA - Workers’ Struggle': 617,
  '250012. FRA - Democratic Movement': 496,
  '250013. FRA - French Communist Party': 1251,
  '250015. FRA - Left Front': 4363,
  '276009. DEU - Christian Democratic Union / Christian Social Union': 211,
  '276012. DEU - National Democratic Party Of Germany': 1723,
  '276013. DEU - Pirates Party': 1287,
#   '300004. GRC - Democratic Coalition – PASOK-DIMAR': ????,
  '300010. GRC - Greek Anticapitalist Left-Workers Revolutionary Party': 95,
  '300016. GRC - Panhellenic Socialist Movement (PASOK)': 1468,
  '344007. HKG - People Power': 4520,
  '344008. HKG - League of Social Democrats': 4522,
#   '344015. HKG - ALLinHKG': ????,
#   '344016. HKG - Youngspiration': ????,
  '380008. ITA - More Europe': 6155,
  '380014. ITA - CasaPound Italy': 8244,
#   '380015. ITA - The People of Family': ????,
  '410005. KOR - Democratic United Party': 4464,
  '410006. KOR - Unified Progressive Party': 2543,
#   "440005. LTU - Anti-Corruption Coalition (Lithuanian Center Party; Lithuanian Pensioners' Party)": ????,
#   '499008. MNE - Albanians Decisively': ????,
  '499010. MNE - Positive Montenegro': 4767,
  '499018. MNE - Democratic Alliance - DEMOS': 5467,
  '499019. MNE - Socialist Peoples Party of Montenegro': 3104,
  "499026. MNE - Coalition 'For a European Montenegro'": 3163,
  '840003. USA - Libertarian Party': 2291,
#   '840004. USA - Green Party of the United States': ????                         
                         
                         }

# %%
AllMod5PartyReferences[AllMod5PartyReferences[['IMD cses party id','IMD cses party id from abbrev','IMD cses party id from partyname',
       'manual IMD cses party id']].isnull().all(axis=1)].dropna(how='all',axis=1)["frequency"].sum()

#.drop("cses_from_partyname",axis=1).dropna()
# Out:
# 2088

# %%
# AllMod5PartyReferences["frequency"].sum()

# 2045 missing references out of 447903!

# %%
AllMod5PartyReferences[['mod5 cses party id','IMD cses party id','IMD cses party id from abbrev','IMD cses party id from partyname',
       'manual IMD cses party id']][ AllMod5PartyReferences[['IMD cses party id','IMD cses party id from abbrev','IMD cses party id from partyname',
       'manual IMD cses party id']].apply(lambda x: len(x.dropna().unique()),axis=1)>1 ]
# Out:
#                         mod5 cses party id             IMD cses party id  \
# 95             554008. NZL - MANA Movement  5540010. NZL - Internet MANA
# 144  410005. KOR - Democratic United Party                           NaN
#
#               IMD cses party id from abbrev IMD cses party id from partyname  \
# 95             5540011. NZL - MANA Movement     5540011. NZL - MANA Movement
# 144  4100004. KOR - Democratic United Party                              NaN
#
#                    manual IMD cses party id
# 95                                      NaN
# 144  4100004. Democratic United Party (DUP)

# %%
AllMod5PartyReferences["final IMD reference"] = AllMod5PartyReferences[['IMD cses party id','IMD cses party id from abbrev','IMD cses party id from partyname',
       'manual IMD cses party id']].replace("NEW",np.nan).replace("????",np.nan).fillna(method='ffill',axis=1)#["manual IMD cses party id"].notnull().sum()



# 185 matching instances!

# %%
AllMod5PartyReferences["partyfacts_id_manual"] = AllMod5PartyReferences["mod5 cses party id"].apply(lambda x: manual_mod5_to_pf_dict[x] if x in manual_mod5_to_pf_dict.keys() else np.nan)

# %%
AllMod5PartyReferences["final cses no"] = AllMod5PartyReferences["final IMD reference"].apply(lambda x: int(x[0:7]) if pd.notnull(x) else np.nan)

# %%
# we have 11 cses numbers mentioned twice ... but they all check out

# AllMod5PartyReferences[AllMod5PartyReferences["final cses no"].apply(lambda x: x in AllMod5PartyReferences["final cses no"].value_counts()[AllMod5PartyReferences["final cses no"].value_counts()>=2].index)].sort_values(by='final cses no')

# %%
AllMod5PartyReferences["final pf no"] = AllMod5PartyReferences["final cses no"].apply(lambda x: cses_ids_to_pf.loc[x] if x in cses_ids_to_pf.index else np.nan)
AllMod5PartyReferences["final pf no"][AllMod5PartyReferences["partyfacts_id_manual"].notnull()] = AllMod5PartyReferences["partyfacts_id_manual"][AllMod5PartyReferences["partyfacts_id_manual"].notnull()]
# cses_ids_to_pf

# %%
## partyfacts_id_manual has no overlap with "final cses no"

# AllMod5PartyReferences



# AllMod5PartyReferences[AllMod5PartyReferences["final pf no"].isnull()&AllMod5PartyReferences["final cses no"].notnull()][["mod5 cses party id","final cses no"]].sort_values(by="mod5 cses party id").set_index("mod5 cses party id").to_dict()
# Out:
#                                   mod5 cses party id  frequency  cses_no  \
# 0                     840001. USA - Democratic Party      13865   840001
# 1                     840002. USA - Republican Party      13082   840002
# 2                        036001. AUS - Liberal Party       8681    36001
# 3         158001. TWN - Democratic Progressive Party       8582   158001
# 4              276002. DEU - Social Democratic Party       8016   276002
# ..                                               ...        ...      ...
# 400  440020. LTU - Democratic Labour and Unity Party          1   440020
# 401          792009. TUR - Rights and Equality Party          1   792009
# 402                        352015. ISL - Rural Party          1   352015
# 403                554014. NZL - Climate First Party          1   554014
# 404                     352012. ISL - Humanist Party          1   352012
#
#     country                         party_name  \
# 0       USA                   Democratic Party
# 1       USA                   Republican Party
# 2       AUS                      Liberal Party
# 3       TWN       Democratic Progressive Party
# 4       DEU            Social Democratic Party
# ..      ...                                ...
# 400     LTU  Democratic Labour and Unity Party
# 401     TUR          Rights and Equality Party
# 402     ISL                        Rural Party
# 403     NZL                Climate First Party
# 404     ISL                     Humanist Party
#
#                             IMD1003 party letter  \
# 0    84002016. UNITED STATES (2016)            A
# 1    84002016. UNITED STATES (2016)            B
# 2        03602019. AUSTRALIA (2019)            A
# 3           15802016. TAIWAN (2016)            A
# 4          27602017. GERMANY (2017)            B
# ..                              ...          ...
# 400                             NaN          NaN
# 401                             NaN          NaN
# 402                             NaN          NaN
# 403                             NaN          NaN
# 404                             NaN          NaN
#
#                                IMD cses party id   mod5 id   IMD id  ...  \
# 0                8400002. USA - Democratic Party  840001.0  8400002  ...
# 1                8400001. USA - Republican Party  840002.0  8400001  ...
# 2                   0360001. AUS - Liberal Party   36001.0   360001  ...
# 3    1580001. TWN - Democratic Progressive Party  158001.0  1580001  ...
# 4         2760004. DEU - Social Democratic Party  276002.0  2760004  ...
# ..                                           ...       ...      ...  ...
# 400                                          NaN       NaN      NaN  ...
# 401                                          NaN       NaN      NaN  ...
# 402                                          NaN       NaN      NaN  ...
# 403                                          NaN       NaN      NaN  ...
# 404                                          NaN       NaN      NaN  ...
#
#     still_missing cses_from_abbrev  \
# 0           False        8400002.0
# 1           False              NaN
# 2           False              NaN
# 3           False        1580001.0
# 4           False        2760004.0
# ..            ...              ...
# 400          True              NaN
# 401          True              NaN
# 402          True              NaN
# 403          True              NaN
# 404          True              NaN
#
#                    IMD cses party id from abbrev  cses_from_partyname  \
# 0                8400002. USA - Democratic Party            8400002.0
# 1                                            NaN            8400001.0
# 2                                            NaN                  NaN
# 3    1580001. TWN - Democratic Progressive Party            1580001.0
# 4         2760004. DEU - Social Democratic Party                  NaN
# ..                                           ...                  ...
# 400                                          NaN                  NaN
# 401                                          NaN                  NaN
# 402                                          NaN                  NaN
# 403                                          NaN                  NaN
# 404                                          NaN                  NaN
#
#                 IMD cses party id from partyname manual IMD cses party id  \
# 0                8400002. USA - Democratic Party                      NaN
# 1                8400001. USA - Republican Party                      NaN
# 2                                            NaN                      NaN
# 3    1580001. TWN - Democratic Progressive Party                      NaN
# 4                                            NaN                      NaN
# ..                                           ...                      ...
# 400                                          NaN                      NaN
# 401                                          NaN                      NaN
# 402                                          NaN                      NaN
# 403                                          NaN                      NaN
# 404                                          NaN                      NaN
#
#     partyfacts_id_manual                          final IMD reference  \
# 0                    NaN              8400002. USA - Democratic Party
# 1                    NaN              8400001. USA - Republican Party
# 2                    NaN                 0360001. AUS - Liberal Party
# 3                    NaN  1580001. TWN - Democratic Progressive Party
# 4                    NaN       2760004. DEU - Social Democratic Party
# ..                   ...                                          ...
# 400                  NaN                                          NaN
# 401                  NaN                                          NaN
# 402                  NaN                                          NaN
# 403                  NaN                                          NaN
# 404                  NaN                                          NaN
#
#     final cses no  final pf no
# 0       8400002.0        432.0
# 1       8400001.0        809.0
# 2        360001.0       1998.0
# 3       1580001.0       1596.0
# 4       2760004.0        383.0
# ..            ...          ...
# 400           NaN          NaN
# 401           NaN          NaN
# 402           NaN          NaN
# 403           NaN          NaN
# 404           NaN          NaN
#
# [405 rows x 34 columns]

# %%
AllMod5PartyReferences[ AllMod5PartyReferences["final pf no"].isnull() & AllMod5PartyReferences["party letter"].notnull()]


#.sort_values(by="frequency",ascending=False).head(50).sort_values("mod5 cses party id")[["mod5 cses party id","frequency"]].set_index("mod5 cses party id").to_dict()
# Out:
#                                     mod5 cses party id  frequency  cses_no  \
# 102    158004. TWN - Green-Social Democratic Coalition       1773   158004
# 104                           158005. TWN - Minkuotang       1720   158005
# 111  440005. LTU - Anti-Corruption Coalition (Lithu...       1535   440005
# 134                 499008. MNE - Albanians Decisively       1235   499008
# 142   300004. GRC - Democratic Coalition – PASOK-DIMAR       1188   300004
# 158                             344015. HKG - ALLinHKG       1020   344015
#
#     country                                         party_name  \
# 102     TWN                  Green-Social Democratic Coalition
# 104     TWN                                         Minkuotang
# 111     LTU  Anti-Corruption Coalition (Lithuanian Center P...
# 134     MNE                               Albanians Decisively
# 142     GRC                 Democratic Coalition – PASOK-DIMAR
# 158     HKG                                           ALLinHKG
#
#                          IMD1003 party letter IMD cses party id   mod5 id  \
# 102      15802016. TAIWAN (2016)            D               NEW  158004.0
# 104      15802016. TAIWAN (2016)            E               NEW  158005.0
# 111   44002016. LITHUANIA (2016)            E               NEW  440005.0
# 134  49902016. MONTENEGRO (2016)            H              ????  499008.0
# 142      30022015. GREECE (2015)            D               NEW  300004.0
# 158   34402016. HONG KONG (2016)            I               NEW  344015.0
#
#     IMD id  ... still_missing cses_from_abbrev IMD cses party id from abbrev  \
# 102    NEW  ...          True              NaN                           NaN
# 104    NEW  ...          True              NaN                           NaN
# 111    NEW  ...          True              NaN                           NaN
# 134   ????  ...          True              NaN                           NaN
# 142    NEW  ...          True              NaN                           NaN
# 158    NEW  ...          True              NaN                           NaN
#
#      cses_from_partyname  IMD cses party id from partyname  \
# 102                  NaN                               NaN
# 104                  NaN                               NaN
# 111                  NaN                               NaN
# 134                  NaN                               NaN
# 142                  NaN                               NaN
# 158                  NaN                               NaN
#
#     manual IMD cses party id partyfacts_id_manual final IMD reference  \
# 102                      NaN                  NaN                 NaN
# 104                      NaN                  NaN                 NaN
# 111                      NaN                  NaN                 NaN
# 134                      NaN                  NaN                 NaN
# 142                      NaN                  NaN                 NaN
# 158                      NaN                  NaN                 NaN
#
#     final cses no  final pf no
# 102           NaN          NaN
# 104           NaN          NaN
# 111           NaN          NaN
# 134           NaN          NaN
# 142           NaN          NaN
# 158           NaN          NaN
#
# [6 rows x 34 columns]

# %%
partyfacts_core_parties[partyfacts_core_parties["country"]=="USA"].sort_values(by="year_last")[::-1].head(50)
#.loc[44#["wikipedia"].values


# partyfacts_core_parties[partyfacts_core_parties["partyfacts_id"]==95]


# AllMod5PartyReferences[AllMod5PartyReferences["partyfacts_id_manual"].notnull()&AllMod5PartyReferences["final cses no"].notnull()]
# Out:
#      country  partyfacts_id  technical name_short  \
# 2457     GRC             95        NaN   Antarsya
#
#                                                    name  \
# 2457  Antikapitalistiki Aristeri Synergasia gia tin ...
#
#                                 name_english  \
# 2457  Front of the Greek Anticapitalist Left
#
#                                              name_other  year_first  \
# 2457  Greek: Αντικαπιταλιστική Αριστερή Συνεργασία γ...        2009
#
#       year_last  share  share_year  new  \
# 2457        NaN    1.2      2012.0  NaN
#
#                                               wikipedia description comment  \
# 2457  https://en.wikipedia.org/wiki/Anticapitalist_L...         NaN     NaN
#
#                                created                          modified
# 2457  2012-12-29 10:52:43.809000+00:00  2020-03-21 22:50:08.082452+00:00

# %%
IMD_party_references["pf_from_cses_no"] = IMD_party_references["cses_no"].apply(lambda x: cses_ids_to_pf.loc[x] if x in cses_ids_to_pf.index else np.nan)
# notnull/isnull = (688, 848)
# IMD_party_references["pf_from_cses_no"].notnull().sum(),IMD_party_references["pf_from_cses_no"].isnull().sum(),
mod5_cses_to_pf = AllMod5PartyReferences[["final cses no","final pf no"]].dropna().drop_duplicates().astype(int).set_index("final cses no")["final pf no"]
IMD_party_references["pf_from_mod5_cses_to_pf"] = IMD_party_references["cses_no"].apply(lambda x: mod5_cses_to_pf.loc[x] if x in mod5_cses_to_pf.index else np.nan)
# IMD_party_references["pf_from_mod5_cses_to_pf"].notnull().sum(),IMD_party_references["pf_from_mod5_cses_to_pf"].isnull().sum(),
#(112, 1424) - 10 non-overlapping cases, 102 other cases agree
# Out:
# (112, 1424)

# %%
# (IMD_party_references["pf_from_cses_no"].notnull()&IMD_party_references["pf_from_mod5_cses_to_pf"].notnull()).sum()

# non_overlap = IMD_party_references["pf_from_cses_no"].isnull()&IMD_party_references["pf_from_mod5_cses_to_pf"].notnull()
# IMD_party_references[non_overlap]
# IMD_party_references[non_overlap]["pf_from_mod5_cses_to_pf"].apply(lambda x: partyfacts_core_parties.set_index("partyfacts_id").loc[x,"name_english"])
## these all check out manually!


# (IMD_party_references["pf_from_cses_no"][overlap].astype(int)==IMD_party_references["pf_from_mod5_cses_to_pf"][overlap].astype(int)).sum()

# IMD_party_references[["pf_from_cses_no","pf_from_mod5_cses_to_pf"]][overlap]
# Out:
#                                               index  frequency  cses_no  \
# 338                   7920005. TUR - Felicity Party       2226  7920005
# 510                    5540010. NZL - Internet MANA       1263  5540010
# 620        4990007. MNE - Croatian Civic Initiative        975  4990007
# 650   4990001. MNE - Democratic Party of Socialists        221  4990001
# 753             0760024. BRA - Social Liberal Party         34   760024
# 778               2500025. FRA - Arise the Republic         28  2500025
# 799                      2760025. DEU - Free Voters         25  2760025
# 918               3000021. GRC - Union of Centrists         11  3000021
# 988    3720010. IRL - People Before Profit Alliance          8  3720010
# 1093           4400013. LTU - Poles Election Action          5  4400013
#
#      country                      party_name country_long  \
# 338      TUR                  Felicity Party       TURKEY
# 510      NZL                   Internet MANA  NEW ZEALAND
# 620      MNE       Croatian Civic Initiative   MONTENEGRO
# 650      MNE  Democratic Party of Socialists   MONTENEGRO
# 753      BRA            Social Liberal Party       BRAZIL
# 778      FRA              Arise the Republic       FRANCE
# 799      DEU                     Free Voters      GERMANY
# 918      GRC              Union of Centrists       GREECE
# 988      IRL   People Before Profit Alliance      IRELAND
# 1093     LTU           Poles Election Action    LITHUANIA
#
#                               country_partyname  pf_from_cses_no  \
# 338                       TURKEY|felicity party              NaN
# 510                   NEW ZEALAND|internet mana              NaN
# 620        MONTENEGRO|croatian civic initiative              NaN
# 650   MONTENEGRO|democratic party of socialists              NaN
# 753                 BRAZIL|social liberal party              NaN
# 778                   FRANCE|arise the republic              NaN
# 799                         GERMANY|free voters              NaN
# 918                   GREECE|union of centrists              NaN
# 988       IRELAND|people before profit alliance              NaN
# 1093            LITHUANIA|poles election action              NaN
#
#       pf_from_mod5_cses_to_pf
# 338                     572.0
# 510                    1427.0
# 620                    3253.0
# 650                    3162.0
# 753                    6920.0
# 778                    3207.0
# 799                    1090.0
# 918                    2510.0
# 988                    8241.0
# 1093                    556.0

# %%
# imd_cb3_upper_listing[imd_cb3_upper_listing["election study"]=="HUNGARY"]

# %%
# IMD_party_references[(IMD_party_references["country"]=="ALB")]
#["index"].values
# Out:
#                                                  index  frequency  cses_no  \
# 244                     0080001. ALB - Socialist Party       3668    80001
# 261                    0080002. ALB - Democratic Party       3328    80002
# 494  0080003. ALB - Socialist Movement for Integration       1314    80003
# 509                    0080004. ALB - Republican Party       1266    80004
# 526             0080005. ALB - Social Democratic Party       1215    80005
# 551                      0080031. ALB - Agrarian Party       1154    80031
# 552          0080010. ALB - Christian Democratic Party       1151    80010
# 553           0080011. ALB - Democratic Alliance Party       1151    80011
# 556                0080030. ALB - New Democratic Party       1139    80030
# 629  0080100. ALB - Union for Victory (Parta Demokr...        698    80100
# 694            0080033. ALB - Human Rights Union Party         63    80033
# 710             0080032. ALB - Movement of Leka Zogu I         49    80032
#
#     country                                         party_name country_long  \
# 244     ALB                                    Socialist Party      ALBANIA
# 261     ALB                                   Democratic Party      ALBANIA
# 494     ALB                 Socialist Movement for Integration      ALBANIA
# 509     ALB                                   Republican Party      ALBANIA
# 526     ALB                            Social Democratic Party      ALBANIA
# 551     ALB                                     Agrarian Party      ALBANIA
# 552     ALB                         Christian Democratic Party      ALBANIA
# 553     ALB                          Democratic Alliance Party      ALBANIA
# 556     ALB                               New Democratic Party      ALBANIA
# 629     ALB  Union for Victory (Parta Demokratike+PR+PLL+PB...      ALBANIA
# 694     ALB                           Human Rights Union Party      ALBANIA
# 710     ALB                            Movement of Leka Zogu I      ALBANIA
#
#                                      country_partyname  pf_from_cses_no  \
# 244                            ALBANIA|socialist party           1729.0
# 261                           ALBANIA|democratic party            190.0
# 494         ALBANIA|socialist movement for integration           2297.0
# 509                           ALBANIA|republican party            819.0
# 526                    ALBANIA|social democratic party            838.0
# 551                             ALBANIA|agrarian party            840.0
# 552                 ALBANIA|christian democratic party           4715.0
# 553                  ALBANIA|democratic alliance party            594.0
# 556                       ALBANIA|new democratic party           1558.0
# 629  ALBANIA|union for victory (parta demokratike+p...              NaN
# 694                   ALBANIA|human rights union party           1636.0
# 710                    ALBANIA|movement of leka zogu i            732.0
#
#      pf_from_mod5_cses_to_pf
# 244                      NaN
# 261                      NaN
# 494                      NaN
# 509                      NaN
# 526                      NaN
# 551                      NaN
# 552                      NaN
# 553                      NaN
# 556                      NaN
# 629                      NaN
# 694                      NaN
# 710                      NaN

# %%
# Out:
#     country  partyfacts_id  technical name_short  \
# 220     ARG           3889       15.0       ally
# 219     ARG           1210        NaN        MST
# 218     ARG           8082        NaN         PO
# 217     ARG           6649        NaN        FIT
# 216     ARG           5121        NaN        OBR
# 213     ARG           6518        NaN     UDELPA
# 209     ARG           1215        NaN        ARI
# 208     ARG           7751        NaN       PSOL
# 207     ARG           7752        NaN       USpV
# 206     ARG           1365        NaN         PS
# 205     ARG           1790        NaN        PRO
# 204     ARG           6160        NaN         RF
# 199     ARG           1724        NaN        UCR
# 198     ARG           8083        NaN         PS
# 197     ARG           6554        NaN      FPCyS
# 196     ARG           5086        NaN         UP
# 192     ARG            868        NaN        MPN
# 187     ARG           7717        NaN         NU
# 184     ARG           5186        NaN        LIB
# 183     ARG           7049        NaN          C
# 181     ARG           7746        NaN          K
# 180     ARG            623        NaN         PJ
# 178     ARG           4183        NaN         PI
# 174     ARG           4180        NaN         PH
# 173     ARG           8045        NaN        GEN
# 172     ARG           2530        NaN     FPV-PJ
# 170     ARG           8059        NaN      FP-PJ
# 169     ARG           6648        NaN      PF-PJ
# 168     ARG           6040        NaN         PF
# 167     ARG           4204        NaN        PUF
# 166     ARG           8122        NaN         CF
# 165     ARG           7747        NaN         FC
# 163     ARG           5112        NaN        PDP
# 162     ARG           5187        NaN       DEMO
# 161     ARG           7719        NaN        CPD
# 159     ARG           8043        NaN      FORJA
# 158     ARG           7745        NaN       PCCE
# 157     ARG            832        NaN         PC
# 155     ARG           7975        NaN        FCS
# 154     ARG           6159        NaN         CC
# 153     ARG           7664        NaN         CU
# 150     ARG           7743        NaN         BF
# 145     ARG           7750        NaN        ANM
# 143     ARG           7672        NaN         1P
# 214     ARG           4182        NaN        UCD
# 151     ARG           6161        NaN        FAP
# 193     ARG           6088        NaN         NE
# 186     ARG           4181        NaN      MODIN
# 203     ARG           1116        NaN    Recrear
# 156     ARG           2529        NaN        CPC
#
#                                                   name  \
# 220                                           alliance
# 219          Movimiento Socialista de los Trabajadores
# 218                                     Partido Obrero
# 217          Frente de Izquierda y de los Trabajadores
# 216                                             Obrero
# 213                         Unión del Pueblo Argentino
# 209          Afirmación para una República Igualitaria
# 208                                  Partido Solidario
# 207                 Unidad Socialista para la Victoria
# 206                                 Partido Socialista
# 205                              Propuesta Republicana
# 204                                   Frente Renovador
# 199                               Unión Cívica Radical
# 198                                       Proyecto Sur
# 197                 Frente Progresista Cívico y Social
# 196                                      Unión Popular
# 192                        Movimiento Popular Neuquino
# 187                                     Nacional Union
# 184                      Partido Liberal de Corrientes
# 183                                          Cambiemos
# 181                                             Kolina
# 180                              Partido Justicialista
# 178                              Partido Intransigente
# 174                                  Partido Humanista
# 173              Generación para un Encuentro Nacional
# 172                            Frente para la Victoria
# 170                               Frente Justicialista
# 169            Peronismo Federal / Peronismo disidente
# 168                                    Partido Federal
# 167                         Partido Unidad Federalista
# 166                                   Consenso Federal
# 165                                 Federal Commitment
# 163                      Partido Demócrata Progresista
# 162                       Partido Demócrata de Mendoza
# 161           Confederación de los Partidos de Derecha
# 159                         Partido de la Concertación
# 158  Partido Comunista de la Argentina (Congreso Ex...
# 157                                  Partido Comunista
# 155                         Frente Cívico por Santiago
# 154                               Coalición Cívica ARI
# 153                                   Unidad Ciudadana
# 150                                      Frente Grande
# 145                   Movimiento Nacional Alfonsinista
# 143                                              1País
# 214                       Unión del Centro Democrático
# 151                          Frente Amplio Progresista
# 193                                    Nuevo Encuentro
# 186      Movimiento por la Dignidad y la Independencia
# 203                        Recrear para el Crecimiento
# 156                          Compromiso para el cambio
#
#                                           name_english  \
# 220                                           alliance
# 219                        Workers' Socialist Movement
# 218                                     Workers' Party
# 217                                Workers' Left Front
# 216                                      Woker's Party
# 213                         Unión del Pueblo Argentino
# 209                Support for an Egalitarian Republic
# 208                                   Solidarity Party
# 207                         Socialist Unit for Victory
# 206                                    Socialist Party
# 205                                Republican Proposal
# 204                                      Renewal Front
# 199                                Radical Civic Union
# 198                                      Project South
# 197                Progressive, Civic and Social Front
# 196                                      Popular Union
# 192                          Neuquén People's Movement
# 187                                     Nacional Union
# 184                        Liberal Party of Corrientes
# 183                                       Let’s change
# 181                                             Kolina
# 180                      Justicialist [Peronist] Party
# 178                                 Intransigent Party
# 174                                     Humanist Party
# 173                Generation for a National Encounter
# 172                                  Front for Victory
# 170  Frente Justicialista-Justicialist [Peronist] P...
# 169              Federal Peronism / Dissident Peronism
# 168                                      Federal Party
# 167                             Federalist Unity Party
# 166                                  Federal Consensus
# 165                                 Federal Commitment
# 163                       Democratic Progressive Party
# 162                        Democratic Party of Mendoza
# 161           Confederación de los Partidos de Derecha
# 159                                 Concertation Party
# 158  Communist Party of Argentina (Extraordinary Co...
# 157                       Communist Party of Argentina
# 155                           Civic Front for Santiago
# 154                                Civic Coalition ARI
# 153                                    Citizen's Unity
# 150                                        Broad Front
# 145                      Alfonsinist National Movement
# 143                                              1País
# 214                     Union of the Democratic Centre
# 151                            Broad Progressive Front
# 193                                      New Encounter
# 186              Movement for Dignity and Independence
# 203                                Recreate for Growth
# 156                               Commitment to Change
#
#                                     name_other  year_first  year_last  share  \
# 220                                        NaN        1800        NaN    NaN
# 219                                        NaN        1992        NaN    2.0
# 218                                        NaN        1964        NaN    1.1
# 217                                        NaN        2011        NaN    2.3
# 216                                        NaN        1960        NaN    1.1
# 213                                        NaN        1962        NaN    9.5
# 209                                        NaN        2001        NaN    3.7
# 208                                        NaN        2008        NaN    NaN
# 207                                        NaN        2007        NaN    NaN
# 206                                        NaN        1896        NaN    5.7
# 205                                        NaN        2005        NaN   17.7
# 204  Alternative translation: Front for Reform        2013        NaN   17.5
# 199                                        NaN        1891        NaN   48.0
# 198                                        NaN        2007        NaN    NaN
# 197                                        NaN        2006        NaN   25.2
# 196                                        NaN        1955        NaN   27.1
# 192                                        NaN        1961        NaN    1.5
# 187                                        NaN        1912        NaN    8.7
# 184                                        NaN        1856        NaN    2.7
# 183                                        NaN        2015        NaN   29.2
# 181                                        NaN        2010        NaN    NaN
# 180                                        NaN        1946        NaN   38.5
# 178                                        NaN        1963        NaN    6.1
# 174                                        NaN        1985        NaN    2.5
# 173                                        NaN        2007        NaN    1.9
# 172                                        NaN        2003        NaN   49.1
# 170                                        NaN        2017        NaN   13.7
# 169                                        NaN        2010        NaN    9.2
# 168                                        NaN        1973        NaN   11.3
# 167                                        NaN        2001        NaN    2.5
# 166                                        NaN        2019        NaN    5.9
# 165                                        NaN        2011        NaN    NaN
# 163                                        NaN        1914        NaN   12.0
# 162                                        NaN        1931        NaN    1.9
# 161                                        NaN        1928        NaN    6.4
# 159                                        NaN        2007        NaN    3.9
# 158                                        NaN        1996        NaN    NaN
# 157                                        NaN        1918        NaN    NaN
# 155                                        NaN        2005        NaN    7.0
# 154                                        NaN        2001        NaN    7.4
# 153                                        NaN        2017        NaN   22.5
# 150                                        NaN        1993        NaN    3.5
# 145                                        NaN        2014        NaN    NaN
# 143                                        NaN        2017        NaN    5.9
# 214                                        NaN        1982     2015.0    5.2
# 151                                        NaN        2011     2013.0    5.4
# 193                                        NaN        2009     2011.0    2.1
# 186                                        NaN        1988     2010.0    5.8
# 203                                        NaN        2002     2009.0   16.4
# 156                                        NaN        2003     2008.0    4.0
#
#      share_year    new                                          wikipedia  \
# 220         NaN    NaN                                                NaN
# 219      1999.0    NaN  https://en.wikipedia.org/wiki/Workers%27_Socia...
# 218      2009.0    NaN  https://en.wikipedia.org/wiki/Workers%27_Party...
# 217      2011.0    NaN  https://en.wikipedia.org/wiki/Workers%27_Left_...
# 216      2009.0    NaN  https://en.wikipedia.org/wiki/Workers'_Party_%...
# 213      1963.0    NaN  https://es.wikipedia.org/wiki/Uni%C3%B3n_del_P...
# 209      2005.0    NaN  https://en.wikipedia.org/wiki/Civic_Coalition_ARI
# 208         NaN    NaN                                                NaN
# 207         NaN    NaN                                                NaN
# 206      2007.0    NaN  https://en.wikipedia.org/wiki/Socialist_Party_...
# 205      2009.0    NaN  https://en.wikipedia.org/wiki/Republican_Proposal
# 204      2013.0    NaN        https://en.wikipedia.org/wiki/Renewal_Front
# 199      1983.0  False  https://en.wikipedia.org/wiki/Radical_Civic_Union
# 198      2018.0    NaN         https://en.wikipedia.org/wiki/Proyecto_Sur
# 197      2013.0    NaN  https://en.wikipedia.org/wiki/Progressive,_Civ...
# 196      1965.0    NaN   https://en.wikipedia.org/wiki/Uni%C3%B3n_Popular
# 192      2005.0    NaN  https://en.wikipedia.org/wiki/Neuqu%C3%A9n_Peo...
# 187      1912.0    NaN  https://en.wikipedia.org/wiki/1912_Argentine_l...
# 184      1930.0    NaN  https://en.wikipedia.org/wiki/Liberal_Party_of...
# 183      2015.0    NaN            https://en.wikipedia.org/wiki/Cambiemos
# 181         NaN    NaN                                                NaN
# 180      1983.0    NaN  https://en.wikipedia.org/wiki/Partido_Justicia...
# 178      1985.0    NaN   https://en.wikipedia.org/wiki/Intransigent_Party
# 174      2001.0    NaN  https://en.wikipedia.org/wiki/Humanist_Party_(...
# 173      2011.0    NaN  https://es.wikipedia.org/wiki/Generaci%C3%B3n_...
# 172      2011.0   True    https://en.wikipedia.org/wiki/Front_for_Victory
# 170      2017.0    NaN   https://en.wikipedia.org/wiki/Justicialist_Party
# 169      2017.0    NaN     https://en.wikipedia.org/wiki/Federal_Peronism
# 168      2009.0    NaN  https://en.wikipedia.org/wiki/Federal_Party_(1...
# 167      2001.0    NaN  https://en.wikipedia.org/wiki/Federalist_Unity...
# 166         NaN   True  https://es.wikipedia.org/wiki/Consenso_Federal...
# 165         NaN    NaN   https://en.wikipedia.org/wiki/Federal_Commitment
# 163      1920.0    NaN  https://en.wikipedia.org/wiki/Democratic_Progr...
# 162      1963.0    NaN  https://en.wikipedia.org/wiki/Democratic_Party...
# 161      1928.0    NaN                                                NaN
# 159      2007.0   True  https://es.wikipedia.org/wiki/Partido_de_la_Co...
# 158         NaN    NaN  https://en.wikipedia.org/wiki/Communist_Party_...
# 157         NaN    NaN  https://en.wikipedia.org/wiki/Communist_Party_...
# 155      2015.0    NaN  https://en.wikipedia.org/wiki/Civic_Front_for_...
# 154      2009.0    NaN  https://en.wikipedia.org/wiki/Civic_Coalition_ARI
# 153      2017.0    NaN    https://en.wikipedia.org/wiki/Citizen%27s_Unity
# 150      1993.0    NaN  https://en.wikipedia.org/wiki/Broad_Front_(Arg...
# 145         NaN    NaN                                                NaN
# 143      2017.0    NaN           https://es.wikipedia.org/wiki/1Pa%C3%ADs
# 214      1991.0    NaN  https://en.wikipedia.org/wiki/Union_of_the_Dem...
# 151      2013.0    NaN  https://en.wikipedia.org/wiki/Broad_Progressiv...
# 193      2009.0    NaN                                                NaN
# 186      1993.0    NaN  https://en.wikipedia.org/wiki/Movement_for_Dig...
# 203      2003.0    NaN  https://en.wikipedia.org/wiki/Recreate_for_Growth
# 156      2003.0    NaN  https://en.wikipedia.org/wiki/Commitment_to_Ch...
#
#                                            description  \
# 220                                                NaN
# 219                                     member of 8128
# 218                                                NaN
# 217               alliance of three Trotskyist parties
# 216                                                NaN
# 213                                                NaN
# 209                                                NaN
# 208  There is no available information on Wikipedia...
# 207  There is no available information on Wikipedia...
# 206                                                NaN
# 205                                     member of 7049
# 204                                                NaN
# 199                                member of 6117 7049
# 198             2019 part of alliance Everyone's Front
# 197                                                NaN
# 196                                                NaN
# 192                                    2 seats in 2005
# 187                                                NaN
# 184                                                NaN
# 183  38 of 130 seats in 2015 Argentine general elec...
# 181  There is no available information on Wikipedia...
# 180                                                NaN
# 178                                                NaN
# 174                                                NaN
# 173  Part of the Frente Amplio Progresista (FAP) al...
# 172                  faction of the Justicialist Party
# 170                                     Faction of 623
# 169  informal names given to a political alliance b...
# 168                                                NaN
# 167                                                NaN
# 166                                                NaN
# 165                                                NaN
# 163                                                NaN
# 162                                                NaN
# 161  The vote_share refers to an alliance with one ...
# 159                                Splinter of the UCR
# 158                                                NaN
# 157                    long term party; member of 8128
# 155  7 of 257 seats in 2015 Argentine general election
# 154                                     member of 7049
# 153                                                NaN
# 150                                                NaN
# 145  There is no available information on Wikipedia...
# 143                      Alliance members include 6160
# 214                                                NaN
# 151                                                NaN
# 193                                                NaN
# 186                                                NaN
# 203                                                NaN
# 156                                                NaN
#
#                                   comment                           created  \
# 220                                   NaN  2015-09-09 13:49:30.613821+00:00
# 219                                   NaN  2012-12-29 10:56:21.500000+00:00
# 218                                   NaN  2019-12-15 14:33:16.548193+00:00
# 217                                   NaN  2019-02-11 23:19:49.088520+00:00
# 216                                   NaN  2016-08-04 14:25:36.099477+00:00
# 213                                   NaN  2019-01-04 01:52:40.513809+00:00
# 209                                   NaN  2012-12-29 10:56:22.472000+00:00
# 208                                   NaN  2019-09-13 02:32:51.008444+00:00
# 207                                   NaN  2019-09-13 02:34:52.017116+00:00
# 206                                   NaN  2012-12-29 10:56:52.907000+00:00
# 205                                   NaN  2012-12-29 10:58:22.553000+00:00
# 204                                   NaN  2018-09-10 21:29:59.738856+00:00
# 199                                   NaN  2012-12-29 10:58:08.816000+00:00
# 198                                   NaN  2019-12-15 14:37:19.659568+00:00
# 197                                   NaN  2019-01-04 19:26:28.735778+00:00
# 196                                   NaN  2016-07-13 10:25:13.513270+00:00
# 192                                   NaN  2012-12-29 10:55:11.572000+00:00
# 187                                   NaN  2019-09-12 14:31:39.381386+00:00
# 184                                   NaN  2016-08-17 08:00:24.275881+00:00
# 183                                   NaN  2019-05-16 11:05:05.875683+00:00
# 181                                   NaN  2019-09-13 02:12:31.628476+00:00
# 180                                   NaN  2012-12-29 10:54:23.512000+00:00
# 178                                   NaN  2015-10-13 14:42:23.483506+00:00
# 174                                   NaN  2015-10-13 14:35:55.990263+00:00
# 173                                   NaN  2019-11-21 21:44:02.227270+00:00
# 172                                   NaN  2014-06-27 21:33:10.159815+00:00
# 170                                   NaN  2019-11-22 10:30:42.028539+00:00
# 169                                   NaN  2019-02-11 23:11:52.092105+00:00
# 168                                   NaN  2018-07-11 15:23:42.021797+00:00
# 167                                   NaN  2015-10-14 13:30:23.764349+00:00
# 166                                   NaN  2020-01-02 16:08:58.176902+00:00
# 165                                   NaN  2019-09-13 02:15:15.045928+00:00
# 163                                   NaN  2016-08-04 12:47:39.894760+00:00
# 162                                   NaN  2016-08-17 08:03:00.801536+00:00
# 161                                   NaN  2019-09-12 14:43:37.813649+00:00
# 159                                   NaN  2019-11-21 21:11:23.140377+00:00
# 158                                   NaN  2019-09-13 02:09:14.588973+00:00
# 157                                   NaN  2012-12-29 10:55:04.381000+00:00
# 155                                   NaN  2019-10-25 11:51:09.212961+00:00
# 154                                   NaN  2018-09-10 21:25:15.529516+00:00
# 153  consists of 7743 7747 7746 6088 7744  2019-09-12 05:46:12.504352+00:00
# 150                                   NaN  2019-09-13 02:00:16.466982+00:00
# 145                                   NaN  2019-09-13 02:30:33.913039+00:00
# 143                                   NaN  2019-09-12 08:56:56.499556+00:00
# 214                                   NaN  2015-10-13 14:40:19.786804+00:00
# 151                                   NaN  2018-09-10 21:36:13.669364+00:00
# 193                                   NaN  2018-07-30 11:44:44.384018+00:00
# 186                                   NaN  2015-10-13 14:38:22.516131+00:00
# 203                                   NaN  2012-12-29 10:56:02.257000+00:00
# 156                                   NaN  2014-06-27 21:27:14.690757+00:00
#
#                              modified
# 220  2020-10-06 07:19:14.910795+00:00
# 219  2020-01-07 16:03:48.271855+00:00
# 218  2019-12-15 14:33:16.548232+00:00
# 217  2019-02-11 23:19:49.089828+00:00
# 216  2016-08-04 14:25:36.099524+00:00
# 213  2019-01-04 01:52:40.513865+00:00
# 209  2018-07-07 19:50:17.570045+00:00
# 208  2019-09-13 02:32:51.008490+00:00
# 207  2019-09-13 02:34:52.017175+00:00
# 206  2018-07-07 19:50:17.467145+00:00
# 205  2019-11-21 20:32:58.745451+00:00
# 204  2019-11-21 21:58:14.657452+00:00
# 199  2019-05-16 11:11:53.705913+00:00
# 198  2019-12-15 14:37:19.659603+00:00
# 197  2019-11-21 21:57:24.182411+00:00
# 196  2016-07-13 10:25:13.513296+00:00
# 192  2018-10-09 14:08:00.605853+00:00
# 187  2019-09-12 14:31:39.381423+00:00
# 184  2018-07-08 14:21:41.427984+00:00
# 183  2019-07-17 17:36:32.508309+00:00
# 181  2019-09-13 02:12:31.628521+00:00
# 180  2019-11-22 10:25:06.752140+00:00
# 178  2019-02-03 15:06:21.583630+00:00
# 174  2015-11-07 18:32:26.623472+00:00
# 173  2019-11-21 21:44:02.227322+00:00
# 172  2019-11-21 20:39:09.763589+00:00
# 170  2019-11-22 10:30:42.028590+00:00
# 169  2019-11-21 21:32:03.378139+00:00
# 168  2018-07-11 15:23:42.021842+00:00
# 167  2015-11-07 18:32:26.585156+00:00
# 166  2020-01-02 16:08:58.176972+00:00
# 165  2019-09-13 02:15:15.045984+00:00
# 163  2017-03-11 15:23:07.967835+00:00
# 162  2018-07-08 14:19:13.606639+00:00
# 161  2019-09-12 14:44:05.356734+00:00
# 159  2019-11-21 21:13:23.921851+00:00
# 158  2019-09-13 02:09:14.589011+00:00
# 157  2020-01-07 16:03:42.408059+00:00
# 155  2019-10-25 11:51:09.213020+00:00
# 154  2019-05-16 11:11:58.764805+00:00
# 153  2019-10-25 10:18:43.926681+00:00
# 150  2019-09-13 12:10:59.808341+00:00
# 145  2019-09-13 02:30:33.913087+00:00
# 143  2019-11-22 10:20:01.209016+00:00
# 214  2019-02-03 15:26:23.788209+00:00
# 151  2018-09-10 21:36:13.669393+00:00
# 193  2018-07-30 11:44:44.384048+00:00
# 186  2019-02-03 15:14:50.685253+00:00
# 203  2018-10-09 14:09:39.386781+00:00
# 156  2018-07-07 19:50:14.062543+00:00

# %%
partyfacts_core_parties["country_partyname"] = partyfacts_core_parties["country"]+"|"+partyfacts_core_parties["name_english"].apply(lambda x: x.lower())
pf_repeated_country_partynames = partyfacts_core_parties["country_partyname"].value_counts()[partyfacts_core_parties["country_partyname"].value_counts()>=2].index
# lazy way to drop this reference - there are two references to People Before Profit
pf_repeated_country_partynames = list(pf_repeated_country_partynames)+['IRL|people before profit alliance']
partyfacts_core_parties["country_partyname"] = partyfacts_core_parties["country_partyname"].replace(dict(zip(pf_repeated_country_partynames,[np.nan]*len(pf_repeated_country_partynames))))
## drop cases with non unique country_partynames!


# partyfacts_core_parties.set_index("country_partyname")["partyfacts_id"]

IMD_party_references["shortcountry_partyname"] = IMD_party_references["country"]+"|"+IMD_party_references["party_name"].apply(lambda x: x.lower())

IMD_merged_on_party_names = IMD_party_references.merge(partyfacts_core_parties, how='left',left_on="shortcountry_partyname",right_on="country_partyname")
IMD_merged_on_party_names["country_partyname_y"].notnull().sum()

## 508 matches before dropping non-unique country_partynames
# 486 matcves after dropping non-unique country-partynames
# IMD_merged_on_party_names[IMD_merged_on_party_names["country_partyname_y"].notnull()][["pf_from_cses_no","pf_from_mod5_cses_to_pf","partyfacts_id"]].loc[988]
# IMD_merged_on_party_names.loc[988]

# IMD_merged_on_party_names.shape,IMD_party_references.shape
#.set_index("index")["partyfacts_id"]
#

# 988
IMD_party_references["pf_from_party_name"] = IMD_merged_on_party_names["partyfacts_id"]

# %%
IMD_party_references
# Out:
#                                                   index  frequency  cses_no  \
# 0                          0760001. BRA - Workers Party      43960   760001
# 1                     1240002. CAN - Conservative Party      42143  1240002
# 2                2760004. DEU - Social Democratic Party      42022  2760004
# 3           1580001. TWN - Democratic Progressive Party      37792  1580001
# 4                  4840002. MEX - National Action Party      37593  4840002
# ...                                                 ...        ...      ...
# 1531  2030071. CZE - Association Of Pensioners Of Th...          1  2030071
# 1532  2030054. CZE - Club of Committed Non-Party Mem...          1  2030054
# 1533                                 6080201. PHL - Alu          1  6080201
# 1534            4280020. LVA - Party Daugava for Latvia          1  4280020
# 1535  1120039. BLR - The Social-Democratic Party of ...          1  1120039
#
#      country                                         party_name  \
# 0        BRA                                      Workers Party
# 1        CAN                                 Conservative Party
# 2        DEU                            Social Democratic Party
# 3        TWN                       Democratic Progressive Party
# 4        MEX                              National Action Party
# ...      ...                                                ...
# 1531     CZE    Association Of Pensioners Of The Czech Republic
# 1532     CZE                Club of Committed Non-Party Members
# 1533     PHL                                                Alu
# 1534     LVA                           Party Daugava for Latvia
# 1535     BLR  The Social-Democratic Party of the People Agre...
#
#         country_long                                  country_partyname  \
# 0             BRAZIL                               BRAZIL|workers party
# 1             CANADA                          CANADA|conservative party
# 2            GERMANY                    GERMANY|social democratic party
# 3             TAIWAN                TAIWAN|democratic progressive party
# 4             MEXICO                       MEXICO|national action party
# ...              ...                                                ...
# 1531  CZECH REPUBLIC  CZECH REPUBLIC|association of pensioners of th...
# 1532  CZECH REPUBLIC  CZECH REPUBLIC|club of committed non-party mem...
# 1533     PHILIPPINES                                    PHILIPPINES|alu
# 1534          LATVIA                    LATVIA|party daugava for latvia
# 1535         BELARUS  BELARUS|the social-democratic party of the peo...
#
#       pf_from_cses_no  pf_from_mod5_cses_to_pf  \
# 0               356.0                    356.0
# 1              1004.0                      NaN
# 2               383.0                    383.0
# 3              1596.0                   1596.0
# 4               696.0                      NaN
# ...               ...                      ...
# 1531              NaN                      NaN
# 1532              NaN                      NaN
# 1533              NaN                      NaN
# 1534              NaN                      NaN
# 1535              NaN                      NaN
#
#                                  shortcountry_partyname
# 0                                     BRA|workers party
# 1                                CAN|conservative party
# 2                           DEU|social democratic party
# 3                      TWN|democratic progressive party
# 4                             MEX|national action party
# ...                                                 ...
# 1531  CZE|association of pensioners of the czech rep...
# 1532            CZE|club of committed non-party members
# 1533                                            PHL|alu
# 1534                       LVA|party daugava for latvia
# 1535  BLR|the social-democratic party of the people ...
#
# [1536 rows x 10 columns]

# %%
IMD_repeated_country_partynames = IMD_party_references["shortcountry_partyname"].value_counts()[IMD_party_references["shortcountry_partyname"].value_counts()>=2].index
IMD_party_references[ IMD_party_references["shortcountry_partyname"].apply(lambda x: x in IMD_repeated_country_partynames) ].sort_values(by='index')
# Out:
#                                                   index  frequency  cses_no  \
# 922            0560011. BEL - Worker's Party of Belgium         11   560011
# 1061           0560020. BEL - Worker's Party of Belgium          5   560020
# 1340  1120033. BLR - Republican Party of Labour and ...          1  1120033
# 1017  1120333. BLR - Republican Party of Labour and ...          7  1120333
# 833                                 2030049. CZE - Hope         19  2030049
# 1085                                2030061. CZE - Hope          5  2030061
# 524           4040010. KEN - National Rainbow Coalition       1218  4040010
# 986           4040024. KEN - National Rainbow Coalition          8  4040024
# 384                      4840011. MEX - Possible Mexico       1999  4840011
# 1337                     4840032. MEX - Possible Mexico          1  4840032
# 1198                         5540019. NZL - Libertarian          3  5540019
# 1476                         5540025. NZL - Libertarian          1  5540025
# 83                         6040008. PER - Possible Peru      10392  6040008
# 398            6040015. PER - National Solidarity Party       1937  6040015
# 354                        6040017. PER - Possible Peru       2084  6040017
# 561            6040034. PER - National Solidarity Party       1131  6040034
# 484                    6080008. PHL - Democratic Action       1366  6080008
# 757       6080030. PHL - Akbayan Citizens' Action Party         33  6080030
# 491                    6080084. PHL - Democratic Action       1335  6080084
# 1153      6080155. PHL - Akbayan Citizens' Action Party          4  6080155
# 861                     6160039. POL - Democratic Party         15  6160039
# 316                     6160051. POL - Democratic Party       2490  6160051
# 1079               6160052. POL - Polish National Party          5  6160052
# 1465               6160057. POL - Polish National Party          1  6160057
# 549              8040018. UKR - Social-Democratic Party       1161  8040018
# 712              8040041. UKR - Social-Democratic Party         48  8040041
#
#      country                              party_name    country_long  \
# 922      BEL               Worker's Party of Belgium         BELGIUM
# 1061     BEL               Worker's Party of Belgium         BELGIUM
# 1340     BLR  Republican Party of Labour and Justice         BELARUS
# 1017     BLR  Republican Party of Labour and Justice         BELARUS
# 833      CZE                                    Hope  CZECH REPUBLIC
# 1085     CZE                                    Hope  CZECH REPUBLIC
# 524      KEN              National Rainbow Coalition           KENYA
# 986      KEN              National Rainbow Coalition           KENYA
# 384      MEX                         Possible Mexico          MEXICO
# 1337     MEX                         Possible Mexico          MEXICO
# 1198     NZL                             Libertarian     NEW ZEALAND
# 1476     NZL                             Libertarian     NEW ZEALAND
# 83       PER                           Possible Peru            PERU
# 398      PER               National Solidarity Party            PERU
# 354      PER                           Possible Peru            PERU
# 561      PER               National Solidarity Party            PERU
# 484      PHL                       Democratic Action     PHILIPPINES
# 757      PHL          Akbayan Citizens' Action Party     PHILIPPINES
# 491      PHL                       Democratic Action     PHILIPPINES
# 1153     PHL          Akbayan Citizens' Action Party     PHILIPPINES
# 861      POL                        Democratic Party          POLAND
# 316      POL                        Democratic Party          POLAND
# 1079     POL                   Polish National Party          POLAND
# 1465     POL                   Polish National Party          POLAND
# 549      UKR                 Social-Democratic Party         UKRAINE
# 712      UKR                 Social-Democratic Party         UKRAINE
#
#                                    country_partyname  pf_from_cses_no  \
# 922                BELGIUM|worker's party of belgium              NaN
# 1061               BELGIUM|worker's party of belgium              NaN
# 1340  BELARUS|republican party of labour and justice              NaN
# 1017  BELARUS|republican party of labour and justice              NaN
# 833                              CZECH REPUBLIC|hope              NaN
# 1085                             CZECH REPUBLIC|hope              NaN
# 524                 KENYA|national rainbow coalition           5834.0
# 986                 KENYA|national rainbow coalition              NaN
# 384                           MEXICO|possible mexico           2809.0
# 1337                          MEXICO|possible mexico              NaN
# 1198                         NEW ZEALAND|libertarian              NaN
# 1476                         NEW ZEALAND|libertarian              NaN
# 83                                PERU|possible peru           1749.0
# 398                   PERU|national solidarity party           3997.0
# 354                               PERU|possible peru           1749.0
# 561                   PERU|national solidarity party            290.0
# 484                    PHILIPPINES|democratic action           7086.0
# 757       PHILIPPINES|akbayan citizens' action party           2391.0
# 491                    PHILIPPINES|democratic action           7086.0
# 1153      PHILIPPINES|akbayan citizens' action party              NaN
# 861                          POLAND|democratic party              NaN
# 316                          POLAND|democratic party            919.0
# 1079                    POLAND|polish national party              NaN
# 1465                    POLAND|polish national party              NaN
# 549                  UKRAINE|social-democratic party           2210.0
# 712                  UKRAINE|social-democratic party           2210.0
#
#       pf_from_mod5_cses_to_pf                      shortcountry_partyname
# 922                       NaN               BEL|worker's party of belgium
# 1061                      NaN               BEL|worker's party of belgium
# 1340                      NaN  BLR|republican party of labour and justice
# 1017                      NaN  BLR|republican party of labour and justice
# 833                       NaN                                    CZE|hope
# 1085                      NaN                                    CZE|hope
# 524                       NaN              KEN|national rainbow coalition
# 986                       NaN              KEN|national rainbow coalition
# 384                       NaN                         MEX|possible mexico
# 1337                      NaN                         MEX|possible mexico
# 1198                      NaN                             NZL|libertarian
# 1476                      NaN                             NZL|libertarian
# 83                        NaN                           PER|possible peru
# 398                       NaN               PER|national solidarity party
# 354                       NaN                           PER|possible peru
# 561                       NaN               PER|national solidarity party
# 484                       NaN                       PHL|democratic action
# 757                       NaN          PHL|akbayan citizens' action party
# 491                       NaN                       PHL|democratic action
# 1153                      NaN          PHL|akbayan citizens' action party
# 861                       NaN                        POL|democratic party
# 316                       NaN                        POL|democratic party
# 1079                      NaN                   POL|polish national party
# 1465                      NaN                   POL|polish national party
# 549                       NaN                 UKR|social-democratic party
# 712                       NaN                 UKR|social-democratic party

# %%
pf_repeated_country_partynames = partyfacts_core_parties["country_partyname"].value_counts()[partyfacts_core_parties["country_partyname"].value_counts()>=2].index
partyfacts_core_parties[ partyfacts_core_parties["country_partyname"].apply(lambda x: x in pf_repeated_country_partynames) ].sort_values(by='country')

pf_repeated_country_partynames
# partyfacts_core_parties["country_partyname"]
# Out:
# Index(['GTM|humanist party of guatemala', 'GIB|integration with britain party',
#        'SMR|democratic convention', 'IRN|principlists grand coalition',
#        'BRA|social democratic party', 'GRC|progressive party',
#        'SYR|arab socialist movement', 'SRB|serbian progressive party',
#        'JPN|imperial rule assistance association',
#        'SVK|communist party of slovakia', 'HRV|human shield',
#        'KGZ|önügüü–progress', 'KAZ|alash party', 'GBR|repeal association',
#        'MDA|association of women in moldova', 'SRB|social democratic party',
#        'MNG|mongolian national democratic party', 'POL|democratic party',
#        'NZL|alliance', 'CYP|democratic party', 'JPN|liberal party',
#        'MKD|social democratic union of macedonia', 'MDA|social liberal party',
#        'DOM|modern revolutionary party', 'URY|independent national party',
#        'DEU|german people's party', 'ZMB|united party', 'CZE|independent',
#        'CHL|alliance', 'ITA|italian people's party', 'PER|national unity',
#        'ISL|farmers' party', 'ISL|liberal party', 'GAB|national union',
#        'CHL|democratic party', 'BOL|socialist party',
#        'HRV|croatian christian democratic party',
#        'SLB|solomon islands labour party', 'PRT|alliance',
#        'VGB|concerned citizens' movement', 'NIC|neoliberal party',
#        'PHL|democratic party', 'UKR|communist party of ukraine',
#        'BEL|christian social party', 'BFA|voltaic democratic movement',
#        'CRI|libertarian movement party', 'ISR|together',
#        'BRA|republican party', 'KOR|democratic party', 'ZWE|united party'],
#       dtype='object')

# %%
partyfacts_core_parties[partyfacts_core_parties["country"]=="RUS"].sort_values(by="year_last")[::-1][5:].head(50)
# Out:
#      country  partyfacts_id  technical name_short  \
# 5392     RUS           4003       15.0       ally
# 5389     RUS           2256        NaN         YR
# 5382     RUS           2252        NaN    Yabloko
# 5381     RUS           5823        NaN      RPPSS
# 5379     RUS           5822        NaN      REP-Z
# 5378     RUS           2248        NaN    RPR-PNS
# 5375     RUS           8362        NaN         PR
# 5374     RUS           7409        NaN        PVR
# 5371     RUS           6739        NaN        PoG
# 5368     RUS           2246        NaN     Rodina
# 5367     RUS           2245        NaN       LDPR
# 5365     RUS           2244        NaN         SR
# 5356     RUS           6759        NaN         CR
# 5355     RUS           2236        NaN       KPRF
# 5353     RUS           5547        NaN         GS
# 5351     RUS           2235        NaN        APR
# 5388     RUS           2255        NaN        SPS
# 5359     RUS           2238        NaN        DPR
# 5357     RUS           2237        NaN        KRO
# 5360     RUS           2240        NaN        OVR
# 5390     RUS           2242        NaN          Y
# 5370     RUS           2247        NaN        NDR
# 5383     RUS           2253        NaN        DVR
# 5384     RUS           2254        NaN     DVR-OD
# 5352     RUS           3239        NaN         GS
# 5361     RUS           2241        NaN         VR
# 5364     RUS           2243        NaN       IBIR
# 5391     RUS           2257        NaN         ZR
# 5376     RUS           2250        NaN         VN
# 5373     RUS           2249        NaN       PRES
# 5380     RUS           2251        NaN       RDDR
# 5354     RUS           4784        NaN       KPSS
# 5385     RUS           7305        NaN        SRP
# 5386     RUS           7310        NaN       USRP
# 5362     RUS           8579        NaN        GKP
# 5363     RUS           7308        NaN        GPr
# 5366     RUS           7303        NaN  Trudoviks
# 5358     RUS           7302        NaN         KD
# 5387     RUS           7306        NaN       UO17
# 5377     RUS           7304        NaN         PP
# 5369     RUS           7307        NaN          N
# 5372     RUS           7309        NaN        PPR
#
#                                                    name  \
# 5392                                           alliance
# 5389                                   Yedinaya Rossiya
# 5382  Rossiyskaya obyedinyonnaya demokraticheskaya p...
# 5381  Rossiyskaya Partiya Pensionerov za sotsialnuyu...
# 5379     Rossiiskaya ekologicheskaya partiya "Zelyonyye
# 5378  Respublikanskaya partiya Rossii — Partiya naro...
# 5375                                    Patrioty Rossii
# 5374                       Partiya Vozrozhdeniya Rossii
# 5371                                      Partiya Rosta
# 5368            Rodina -- Narodno-Patrioticheskij Soyuz
# 5367        Liberal'no-Demokraticheskaya Partiya Rossii
# 5365                            A Spravedlivaya Rossiya
# 5356                               Communists of Russia
# 5355   Kommunisticheskaya Partiya Rossiyskoy Federatsii
# 5353                          Russian: Гражданская сила
# 5351                           Agrarnaya Partiya Rossii
# 5388                                  Soyuz Pravykh Sil
# 5359                   Demokraticheskaya Partiya Rossii
# 5357                          Kongress russkikh obschin
# 5360                          Otechestvo – Vsya Rossiya
# 5390                                          Yedinstvo
# 5370                                 Nash Dom - Rossiya
# 5383                      Demokraticheskij Vybor Rossii
# 5384  Demokraticheskij Vybor Rossii – Ob’edinennye D...
# 5352                                  Grazhdansky soyuz
# 5361                                   Vpered, Rossiya!
# 5364                                 Blok Ivana Rybkina
# 5391                                 Zhenshchiny Rossii
# 5376                                      Vlast Narodu!
# 5373           Partiya Rossijskogo Edinstva I Soglasiya
# 5380     Rossijskoe Dvizheniye Demokraticheskikh Reform
# 5354       Kommunisticheskaya Partiya Sovetskogo Soyuza
# 5385                      Socialist Revolutionary Party
# 5386            Ukrainian Socialist-Revolutionary Party
# 5362                              Gruppa Krayne Pravykh
# 5363                                     Gruppa Pravykh
# 5366                                   Trudovaya gruppa
# 5358          Konstitutsionno-Demokraticheskaya Partiya
# 5387                                Union of October 17
# 5377                                  Progressive Party
# 5369                                       Nationalists
# 5372                       Party of Peaceful Renovation
#
#                                            name_english  \
# 5392                                           alliance
# 5389                                      United Russia
# 5382          Russian United Democratic Party "Yabloko"
# 5381     Russian Party of Pensioners for Social Justice
# 5379  Russian Ecological Party "The Greens" /  Const...
# 5378  Republican Party of Russia -- People's Freedom...
# 5375                                 Patriots of Russia
# 5374                          Party of Russia's Rebirth
# 5371                                    Party of Growth
# 5368             Motherland -- National Patriotic Union
# 5367                 Liberal Democratic Party of Russia
# 5365                                        Just Russia
# 5356                               Communists of Russia
# 5355          Communist Party ot the Russian Federation
# 5353                                     Civilian Power
# 5351                           Agrarian Party of Russia
# 5388                              Union of Right Forces
# 5359                         Democratic Party of Russia
# 5357                    Congress of Russian Communities
# 5360                            Fatherland – All Russia
# 5390                                              Unity
# 5370                                  Our Home - Russia
# 5383                         Russia’s Democratic Choice
# 5384      Russia’s Democratic Choice – United Democrats
# 5352                                        Civic Union
# 5361                                   Forward, Russia!
# 5364                                 Ivan Rybkin’s Bloc
# 5391                                    Women of Russia
# 5376                               Power to the People!
# 5373                  Party of Russian Unity and Accord
# 5380             Russian Movement for Democratic Reform
# 5354                Communist Party of the Soviet Union
# 5385                      Socialist Revolutionary Party
# 5386            Ukrainian Socialist-Revolutionary Party
# 5362                        Group of extreme right wing
# 5363                                Group of Right-wing
# 5366                                       Labour Group
# 5358                    Constitutional Democratic Party
# 5387                                Union of October 17
# 5377                                  Progressive Party
# 5369                                       Nationalists
# 5372                       Party of Peaceful Renovation
#
#                                              name_other  year_first  \
# 5392                                                NaN        1800
# 5389                                                NaN        2001
# 5382  Russian: Росси́йская объединённая демократи́че...        1993
# 5381  Russian: Российская партия пенсионеров за соци...        1997
# 5379  Russian: Российская экологическая партия «Зеле...        1992
# 5378  Russian: Республиканская партия России — Парти...        1990
# 5375                           Russian: Патриоты России        2005
# 5374                                                NaN        2000
# 5371                              Russian: Партия Роста        2009
# 5368                                                NaN        2003
# 5367  Russian: Либерально-Демократическая Партия России        1991
# 5365                   Russian: Справедливая Россия, СР        2006
# 5356                                                NaN        2012
# 5355  Russian: Коммунистическая Партия Российской Фе...        1993
# 5353                                    Citizens' Force        2002
# 5351               Russian: Аграрная Партия России, АПР        1993
# 5388                    Russian: Сою́з Пра́вых Сил, СПС        1999
# 5359                                                NaN        1990
# 5357                     Russian: Когресс русских общин        1990
# 5360                    Russian: Отечество – Вся Россия        1999
# 5390                                  Russian: Единство        1999
# 5370                                                NaN        1995
# 5383                                                NaN        1993
# 5384                                                NaN        1995
# 5352                                                NaN        1992
# 5361                                                NaN        1995
# 5364                                                NaN        1995
# 5391                                                NaN        1993
# 5376                                                NaN        1995
# 5373                                                NaN        1993
# 5380                                                NaN        1993
# 5354  Russian: Коммунистическая партия Советского Союза        1912
# 5385         Russian: Партия социалистов-революционеров        1900
# 5386  Russian: Украинская партия социалистов-революц...        1917
# 5362                                                NaN        1906
# 5363                                                NaN        1906
# 5366                         Russian: Трудова́я гру́ппа        1906
# 5358     Russian: Конституционно-демократическая партия        1905
# 5387       Russian: Союз 17 Октября, Soyuz 17 Oktyabrya        1905
# 5377        Russian: Прогрессивная партия, прогрессисты        1906
# 5369                                                NaN        1907
# 5372                                                NaN        1906
#
#       year_last  share  share_year    new  \
# 5392        NaN    NaN         NaN    NaN
# 5389        NaN   65.0      2007.0  False
# 5382        NaN    7.9      1993.0    NaN
# 5381        NaN    2.0      1999.0    NaN
# 5379        NaN    1.4      1995.0   True
# 5378        NaN    1.6      1995.0    NaN
# 5375        NaN    1.0      2011.0    NaN
# 5374        NaN    1.9      2003.0    NaN
# 5371        NaN    1.2      2016.0    NaN
# 5368        NaN    9.2      2003.0    NaN
# 5367        NaN   22.9      1993.0    NaN
# 5365        NaN   13.5      2011.0    NaN
# 5356        NaN    3.8      2016.0    NaN
# 5355        NaN   24.8      1999.0  False
# 5353        NaN    1.1      2007.0    NaN
# 5351     2008.0    8.0      1993.0    NaN
# 5388     2008.0    8.7      1999.0    NaN
# 5359     2008.0    5.5      1993.0    NaN
# 5357     2007.0    4.4      1995.0    NaN
# 5360     2002.0   13.6      1999.0  False
# 5390     2001.0   23.8      1999.0  False
# 5370     1999.0   10.3      1995.0    NaN
# 5383     1995.0   15.5      1993.0    NaN
# 5384     1995.0    3.9      1995.0    NaN
# 5352     1995.0    2.0      1993.0    NaN
# 5361     1995.0    2.0      1995.0    NaN
# 5364     1995.0    1.1      1995.0    NaN
# 5391     1995.0    8.1      1993.0    NaN
# 5376     1995.0    1.6      1995.0    NaN
# 5373     1993.0    6.7      1993.0    NaN
# 5380     1993.0    4.1      1993.0    NaN
# 5354     1991.0  100.0      1990.0    NaN
# 5385     1921.0    7.1      1906.0    NaN
# 5386     1919.0   12.7      1917.0    NaN
# 5362     1918.0    NaN         NaN    NaN
# 5363     1918.0    9.8      1907.0    NaN
# 5366     1917.0   20.3      1906.0    NaN
# 5358     1917.0   37.4      1906.0    NaN
# 5387     1917.0   30.3      1907.0    NaN
# 5377     1917.0   12.6      1906.0    NaN
# 5369     1912.0   19.1      1907.0    NaN
# 5372     1907.0    7.7      1907.0    NaN
#
#                                               wikipedia  \
# 5392                                                NaN
# 5389        https://en.wikipedia.org/wiki/United_Russia
# 5382              https://en.wikipedia.org/wiki/Yabloko
# 5381  https://en.wikipedia.org/wiki/Russian_Party_of...
# 5379  https://en.wikipedia.org/wiki/Russian_Ecologic...
# 5378  https://en.wikipedia.org/wiki/Republican_Party...
# 5375   https://en.wikipedia.org/wiki/Patriots_of_Russia
# 5374  https://en.wikipedia.org/wiki/Party_of_Russia%...
# 5371      https://en.wikipedia.org/wiki/Party_of_Growth
# 5368  https://en.wikipedia.org/wiki/Rodina_%28politi...
# 5367  https://en.wikipedia.org/wiki/LDPR_%28politica...
# 5365        https://en.wikipedia.org/wiki/A_Just_Russia
# 5356  https://en.wikipedia.org/wiki/Communists_of_Ru...
# 5355  https://en.wikipedia.org/wiki/Communist_Party_...
# 5353       https://en.wikipedia.org/wiki/Civilian_Power
# 5351  https://en.wikipedia.org/wiki/Agrarian_Party_o...
# 5388  https://en.wikipedia.org/wiki/Union_of_Right_F...
# 5359  https://en.wikipedia.org/wiki/Democratic_Party...
# 5357  https://en.wikipedia.org/wiki/Congress_of_Russ...
# 5360  https://en.wikipedia.org/wiki/Fatherland_%E2%8...
# 5390  https://en.wikipedia.org/wiki/Unity_(Russian_p...
# 5370                                                NaN
# 5383                                                NaN
# 5384                                                NaN
# 5352                                                NaN
# 5361                                                NaN
# 5364                                                NaN
# 5391                                                NaN
# 5376                                                NaN
# 5373                                                NaN
# 5380                                                NaN
# 5354  https://en.wikipedia.org/wiki/Communist_Party_...
# 5385  https://en.wikipedia.org/wiki/Socialist_Revolu...
# 5386  https://en.wikipedia.org/wiki/Ukrainian_Social...
# 5362                                                NaN
# 5363                                                NaN
# 5366            https://en.wikipedia.org/wiki/Trudoviks
# 5358  https://en.wikipedia.org/wiki/Constitutional_D...
# 5387  https://en.wikipedia.org/wiki/Union_of_October_17
# 5377  https://en.wikipedia.org/wiki/Progressive_Part...
# 5369                                                NaN
# 5372  https://en.wikipedia.org/wiki/Party_of_Peacefu...
#
#                                             description  \
# 5392                                                NaN
# 5389                                                NaN
# 5382                                                NaN
# 5381                                                NaN
# 5379                                                NaN
# 5378                                                NaN
# 5375                                                NaN
# 5374                                                NaN
# 5371                                                NaN
# 5368                                                NaN
# 5367                                                NaN
# 5365                                                NaN
# 5356                                                NaN
# 5355                                                NaN
# 5353                                                NaN
# 5351                                                NaN
# 5388                                                NaN
# 5359                                                NaN
# 5357                                                NaN
# 5360                                                NaN
# 5390  Inter-Regional Movement "Unity" (Mezhregional’...
# 5370                                                NaN
# 5383                                                NaN
# 5384                                                NaN
# 5352                                                NaN
# 5361                                                NaN
# 5364                                                NaN
# 5391                                                NaN
# 5376                                                NaN
# 5373                                                NaN
# 5380                                                NaN
# 5354                                                NaN
# 5385  34 of 478 seats in 1906 Russian legislative el...
# 5386                                                NaN
# 5362                                prime minister 1916
# 5363  50 of 509 seats in October 1907 Russian legisl...
# 5366  97 of 478 seats in 1906 Russian legislative el...
# 5358  179 of 478 seats in 1906 Russian legislative e...
# 5387  154 of 509 seats in October 1907 Russian legis...
# 5377  60 of 478 seats in 1906 Russian legislative el...
# 5369  97 of 509 seats in October 1907 Russian legisl...
# 5372     1907 in alliance with 7304 (Progressive Party)
#
#                                                 comment  \
# 5392                                                NaN
# 5389                                                NaN
# 5382                                                NaN
# 5381                                                NaN
# 5379                                                NaN
# 5378                                                NaN
# 5375                                                NaN
# 5374                                                NaN
# 5371                                                NaN
# 5368                                                NaN
# 5367                                                NaN
# 5365                                                NaN
# 5356                                                NaN
# 5355                                                NaN
# 5353                                                NaN
# 5351                                                NaN
# 5388                                                NaN
# 5359                                                NaN
# 5357                                                NaN
# 5360                                                NaN
# 5390                                                NaN
# 5370                                                NaN
# 5383                                                NaN
# 5384  composed of: DVR Demokraticheskiy Vibor Rossi ...
# 5352                                                NaN
# 5361                                                NaN
# 5364                                                NaN
# 5391                                                NaN
# 5376                                                NaN
# 5373                                                NaN
# 5380                                                NaN
# 5354                                                NaN
# 5385                                              ParIS
# 5386                                              ParIS
# 5362                                                NaN
# 5363                                              ParIS
# 5366                                              ParIS
# 5358                                              ParIS
# 5387                                              ParIS
# 5377                                              ParIS
# 5369                                              ParIS
# 5372                                              ParIS
#
#                                created                          modified  \
# 5392  2015-09-09 13:49:42.106274+00:00  2020-10-06 07:19:25.389513+00:00
# 5389  2014-05-16 20:57:28.329893+00:00  2020-06-03 18:57:51.396550+00:00
# 5382  2014-05-16 20:57:15.402978+00:00  2018-07-07 20:08:44.340716+00:00
# 5381  2017-09-09 18:01:38.598804+00:00  2017-09-09 18:01:38.598830+00:00
# 5379  2017-09-09 17:58:17.918592+00:00  2017-09-09 17:58:17.918614+00:00
# 5378  2014-05-16 20:57:07.428247+00:00  2018-07-07 20:08:43.812730+00:00
# 5375  2020-04-16 18:27:11.554499+00:00  2020-04-16 18:27:11.554528+00:00
# 5374  2019-08-20 19:11:57.916496+00:00  2019-08-20 19:11:57.916768+00:00
# 5371  2019-02-24 20:22:51.106536+00:00  2019-02-24 20:22:51.106571+00:00
# 5368  2014-05-16 20:57:02.192625+00:00  2018-07-07 20:08:43.545341+00:00
# 5367  2014-05-16 20:56:59.914736+00:00  2018-07-07 20:08:43.359462+00:00
# 5365  2014-05-16 20:56:52.800955+00:00  2018-07-07 20:08:43.149563+00:00
# 5356  2019-03-04 12:12:31.735947+00:00  2019-03-04 12:12:31.735980+00:00
# 5355  2014-05-16 20:56:26.947431+00:00  2018-07-07 20:08:42.485082+00:00
# 5353  2017-03-01 11:23:44.824895+00:00  2018-11-11 18:57:52.434741+00:00
# 5351  2014-05-16 20:56:24.940916+00:00  2018-07-07 20:08:42.119615+00:00
# 5388  2014-05-16 20:57:26.113125+00:00  2018-07-14 12:21:14.427688+00:00
# 5359  2014-05-16 20:56:31.455836+00:00  2020-04-16 18:20:51.914926+00:00
# 5357  2014-05-16 20:56:29.194466+00:00  2018-07-07 20:08:42.689699+00:00
# 5360  2014-05-16 20:56:35.159208+00:00  2016-09-19 10:19:13.920628+00:00
# 5390  2014-05-16 20:56:43.126546+00:00  2016-09-19 10:22:21.117501+00:00
# 5370  2014-05-16 20:57:04.085594+00:00  2015-11-07 21:00:04.283187+00:00
# 5383  2014-05-16 20:57:17.367343+00:00  2015-11-07 21:00:04.421077+00:00
# 5384  2014-05-16 20:57:23.170292+00:00  2015-11-07 21:00:04.443098+00:00
# 5352  2015-02-21 10:48:42.724611+00:00  2018-11-11 21:45:28.514982+00:00
# 5361  2014-05-16 20:56:40.786390+00:00  2015-11-07 21:00:04.116496+00:00
# 5364  2014-05-16 20:56:45.141048+00:00  2015-11-07 21:00:04.177253+00:00
# 5391  2014-05-16 20:57:30.355592+00:00  2015-11-07 21:00:04.522233+00:00
# 5376  2014-05-16 20:57:11.795467+00:00  2015-11-07 21:00:04.354619+00:00
# 5373  2014-05-16 20:57:09.998810+00:00  2015-11-07 21:00:04.332146+00:00
# 5380  2014-05-16 20:57:13.729637+00:00  2015-11-07 21:00:04.376574+00:00
# 5354  2016-01-14 13:45:05.504537+00:00  2020-06-03 19:00:21.872917+00:00
# 5385  2019-07-22 14:12:30.986895+00:00  2019-07-22 14:12:30.986928+00:00
# 5386  2019-07-22 14:29:15.796650+00:00  2019-07-22 14:29:15.796681+00:00
# 5362  2020-10-02 10:45:06.210258+00:00  2020-10-02 15:24:46.322812+00:00
# 5363  2019-07-22 14:20:39.195578+00:00  2020-06-03 19:05:29.909912+00:00
# 5366  2019-07-22 14:08:33.746575+00:00  2019-07-22 14:08:33.746631+00:00
# 5358  2019-07-22 14:07:00.608703+00:00  2019-07-22 14:07:00.608738+00:00
# 5387  2019-07-22 14:18:15.741811+00:00  2019-07-22 14:18:15.741856+00:00
# 5377  2019-07-22 14:10:54.225208+00:00  2019-07-22 14:10:54.225238+00:00
# 5369  2019-07-22 14:19:24.358257+00:00  2019-07-22 14:19:24.358322+00:00
# 5372  2019-07-22 14:22:33.017804+00:00  2019-07-22 14:22:33.017856+00:00
#
#                                       country_partyname
# 5392                                       RUS|alliance
# 5389                                  RUS|united russia
# 5382      RUS|russian united democratic party "yabloko"
# 5381  RUS|russian party of pensioners for social jus...
# 5379  RUS|russian ecological party "the greens" /  c...
# 5378  RUS|republican party of russia -- people's fre...
# 5375                             RUS|patriots of russia
# 5374                      RUS|party of russia's rebirth
# 5371                                RUS|party of growth
# 5368         RUS|motherland -- national patriotic union
# 5367             RUS|liberal democratic party of russia
# 5365                                    RUS|just russia
# 5356                           RUS|communists of russia
# 5355      RUS|communist party ot the russian federation
# 5353                                 RUS|civilian power
# 5351                       RUS|agrarian party of russia
# 5388                          RUS|union of right forces
# 5359                     RUS|democratic party of russia
# 5357                RUS|congress of russian communities
# 5360                        RUS|fatherland – all russia
# 5390                                          RUS|unity
# 5370                              RUS|our home - russia
# 5383                     RUS|russia’s democratic choice
# 5384  RUS|russia’s democratic choice – united democrats
# 5352                                    RUS|civic union
# 5361                               RUS|forward, russia!
# 5364                             RUS|ivan rybkin’s bloc
# 5391                                RUS|women of russia
# 5376                           RUS|power to the people!
# 5373              RUS|party of russian unity and accord
# 5380         RUS|russian movement for democratic reform
# 5354            RUS|communist party of the soviet union
# 5385                  RUS|socialist revolutionary party
# 5386        RUS|ukrainian socialist-revolutionary party
# 5362                    RUS|group of extreme right wing
# 5363                            RUS|group of right-wing
# 5366                                   RUS|labour group
# 5358                RUS|constitutional democratic party
# 5387                            RUS|union of october 17
# 5377                              RUS|progressive party
# 5369                                   RUS|nationalists
# 5372                   RUS|party of peaceful renovation

# %%
## 96 entries

manual_imd_to_pf_dict = { 
 '0080100. ALB - Union for Victory (Parta Demokratike+PR+PLL+PBK+PBL)': 7075,
#  '0360010. AUS - The Australian Sex Party': ????,
 "0360012. AUS - Katter's Australia Party": 1997,
 '0400013. AUT - Dinkhauser List': 439,
#  '0760023. BRA - Labour Party of Brazil': ????,
#  '0760026. BRA - Progressive Republican Party': ????,
#  '0760028. BRA - Party of National Mobilization': ????,
#  "0760033. BRA - Unified Socialist Workers' Party": ????,
 '1000029. BGR - Coalition: Bulgarian Social Democratic Party, Democratic Left': 1665,
 '1000040. BGR - Euroleft': 149,
#  '1120018. BLR - United Democratic Forces of Belarus': ????,
#  '1120040. BLR - United Democratic Opposition': ????,
#  '1120101. BLR - A. Lukashenko (Independent)': ????,
#  '1129987. BLR - Vote for at-large Candidate': ????,
#  '1520011. CHL - Peruvian Aprista Party': ????,
#  '1580018. TWN - China Youth Party': ????,
 '2030017. CZE - Freedom Union - Democratic Union': 104,
 '2460009. FIN - The Independence Party': 1259,
 '2500011. FRA - Hunting, Fishing, Nature and Tradtion': 1313,
 '2500019. FRA - Miscellaneous left': 126,
#  "2500032. FRA - Jose Bove - ran as an activist from 'After Globalization'": ????,
 '2760019. DEU - The Greys': 1652,
#  '2760024. DEU - Party Of The Rule Of Law Offensive': ????,
#  '3440026. HKG - April Fifth Action': ????,
#  '3440036. HKG - Article 45 Concern Group': ????,
#  '3520023. ISL - The Movement': ????,
 "3720008. IRL - Workers' Party": 208,
#  '3760090. ISR - Right Bloc': ????,
 '3920013. JPN - New Party Harbinger': 392,
#  '3920015. JPN - New Party Daichi': ????,
 '4040107. KEN - Forum for the Restoration of Democracy - People': 7971,
#  '4100020. KOR - National Integration 21': ????,
 '4170011. KGZ - Communist Party': 5613,
#  '4170101. KGZ - Akbarali Aitikeev (Independent)': ????,
#  '4170102. KGZ - Kurmanbek Bakiev (Independent)': ????,
#  '4170103. KGZ - Bakir uulu Tursunbai (Independent)': ????,
#  '4170108. KGZ - Askar Akaev (Independent)': ????,
#  '4170110. KGZ - Atambaev Almazbek (Independent)': ????,
#  '4170111. KGZ - Masaliev Apsamat (Independent)': ????,
#  '4170112. KGZ - Tekebaev Omurbek (Independent)': ????,
 '4280006. LVA - For Human Rights in United Latvia': 176,
 '4280024. LVA - First Party of Latvia': 1778,
 '4280026. LVA - All for Latvia': 506,
 "4280036. LVA - Latvia's First Party/Latvian Way": 461,
 '4280038. LVA - Union For Fatherland and Freedom/LNNK': 1704,
#  '4400101. LTU - A. Paulauskas (Independent)': ????,
#  '4400102. LTU - V. Adamkus (Independent)': ????,
#  '4840028. MEX - Coalition for the Good of All': ????,
#  '4840029. MEX - Institutional Revolutionary Party - Ecological Green Party of Mexico':????,
#  '4840031. MEX - Social Democracy': ????,
 '4990002. MNE - New Serb Democracy': 3252,
#  '4990032. MNE - Albanian Coalition': ????,
#  '4990037. MNE - Serbian Unity': ????,
#  '4990039. MNE - Force for Unity': ????,
#  '5280012. NLD - One NL': ????,
 '5540011. NZL - MANA Movement': 1427,
#  '5540023. NZL - Mana Maori': ????,
 '5540038. NZL - Aotearoa Legalise Cannabis': 1741,
 "6040028. PER - Let's Go Neighbour": 8130,
#  '6040031. PER - Forwards': ????,
 '6080007. PHL - Lakas - Christian-Muslim Democrats': 2388,
#  '6080019. PHL - Voice of the Masses Party': ????,
 '6080070. PHL - Struggle for Democratic Philippinos': 4252,
#  '6080107. PHL - Coalition of United Filipinos': ????,
 '6080116. PHL - Progressive Movement for the Devolution of Initiatives': 4250,
 '6080150. PHL - Kabalikat ng Bayan sa Kaunlaran': 'PHL',
#  '6080167. PHL - Candidates with no information about party affiliation': ????,
#  '6080900. PHL - Voted but did not vote for a lower house candidate': ????,
#  '6160065. POL - Patriotic Movement of the Republic of Poland': ????,
#  '6160081. POL - Coalition Electoral Solidarity': ????,
#  '6160110. POL - Senate 2001 coalition': ????,
#  '6160114. POL - Solidarity 80 Trade Union': ????,
 '6160115. POL - Solidarity Electoral Action Right Wing': 863,
 "6200015. PRT - People's Monarchist Party": 1480,
 '6200017. PRT - Earth Party': 3226,
 '6420025. ROU - CDR 2000': 192,
#  '6420300. ROU - Calin-Constantin-Anton Popescu-Tariceanu (Independent)': ????,
 '6430022. RUS - Our Home is Russia': 2247,
#  '6430026. RUS - For Civil Dignity':  ????,
#  '6430101. RUS - Initiative Group A: Vladimir Putin': ????,
#  '6430102. RUS - Initiative Group B: Gennady Zyuganov': ????,
#  '6430104. RUS - Initiative Group C: Grigory Yavlinsky': ????,
#  '6430111. RUS - Initiative Group D: Aman Tuleyev': ????,
#  '6430194. RUS - Sergey Glazyev (Independent)': ????,
#  '6430196. RUS - Irina Khakamada (Independent)': ????,
 "6880008. SRB - Alliance of Vojvodina's Hungarians": 2203,
#  '6880040. SRB - Democratic Party of Serbia - New Serbia Alliance': ????,
 '7030027. SVK - Communist Party of Slovakia': 340,
 '7560010. CHE - Swiss Democrats': 1819,
#  '7560019. CHE - Center parties': ????,
 '7560026. CHE - Christian-Social Party': 1122,
#  '7640006. THA - National Development of the Motherland Party': ????,
#  '7640007. THA - Peaceloving Party': ????,
#  '7640009. THA - Power of Choburi Party': ????,
#  "7920009. TUR - People's Voice Party": ????,
#  '8580005. URY - Popular Assembly': ????
}

IMD_party_references["pf_from_manual"] = IMD_party_references["index"].apply(lambda x: manual_imd_to_pf_dict[x] if x in manual_imd_to_pf_dict.keys() else np.nan)

# %%
no_current_pf_reference = IMD_party_references["pf_from_cses_no"].isnull()\
                            &IMD_party_references["pf_from_mod5_cses_to_pf"].isnull()\
                            &IMD_party_references["pf_from_party_name"].isnull()\
                            &IMD_party_references["pf_from_manual"].isnull()\
    
IMD_party_references[no_current_pf_reference&(IMD_party_references["frequency"]>=25)].sort_values(by="frequency",ascending=False)#.sort_values(by="index").set_index("index")["country"].to_dict()
# Out:
#                                                  index  frequency  cses_no  \
# 103  6430101. RUS - Initiative Group A: Vladimir Putin       9113  6430101
# 178      4170102. KGZ - Kurmanbek Bakiev (Independent)       5426  4170102
# 195         1120101. BLR - A. Lukashenko (Independent)       5081  1120101
# 271        0760026. BRA - Progressive Republican Party       3158   760026
# 275  2760024. DEU - Party Of The Rule Of Law Offensive       3045  2760024
# 428  4840029. MEX - Institutional Revolutionary Par...       1645  4840029
# 450  7640006. THA - National Development of the Mot...       1525  7640006
# 455       4840028. MEX - Coalition for the Good of All       1511  4840028
# 456              7640009. THA - Power of Choburi Party       1510  7640009
# 458                   7640007. THA - Peaceloving Party       1506  7640007
# 459             4100020. KOR - National Integration 21       1502  4100020
# 485         4400101. LTU - A. Paulauskas (Independent)       1364  4400101
# 505            4400102. LTU - V. Adamkus (Independent)       1275  4400102
# 529              1520011. CHL - Peruvian Aprista Party       1205  1520011
# 555  6420300. ROU - Calin-Constantin-Anton Popescu-...       1146  6420300
# 571                7920009. TUR - People's Voice Party       1112  7920009
# 618                    8580005. URY - Popular Assembly        996  8580005
# 619                     4990039. MNE - Force for Unity        989  4990039
# 621                       4990037. MNE - Serbian Unity        971  4990037
# 622                  4990032. MNE - Albanian Coalition        969  4990032
# 625           4170108. KGZ - Askar Akaev (Independent)        834  4170108
# 628  6080167. PHL - Candidates with no information ...        701  6080167
# 630      6160081. POL - Coalition Electoral Solidarity        691  6160081
# 634                  3440026. HKG - April Fifth Action        623  3440026
# 637               6160110. POL - Senate 2001 coalition        501  6160110
# 640  6430102. RUS - Initiative Group B: Gennady Zyu...        410  6430102
# 641       6080107. PHL - Coalition of United Filipinos        368  6080107
# 649      4170111. KGZ - Masaliev Apsamat (Independent)        224  4170111
# 651         1129987. BLR - Vote for at-large Candidate        218  1129987
# 655        1120040. BLR - United Democratic Opposition        157  1120040
# 663  6430104. RUS - Initiative Group C: Grigory Yav...        117  6430104
# 667      4170112. KGZ - Tekebaev Omurbek (Independent)         98  4170112
# 669  6080900. PHL - Voted but did not vote for a lo...         92  6080900
# 673                    4840031. MEX - Social Democracy         87  4840031
# 674  4170103. KGZ - Bakir uulu Tursunbai (Independent)         86  4170103
# 676     4170110. KGZ - Atambaev Almazbek (Independent)         84  4170110
# 679    0760033. BRA - Unified Socialist Workers' Party         79   760033
# 686  6880040. SRB - Democratic Party of Serbia - Ne...         69  6880040
# 704                          5540023. NZL - Mana Maori         55  5540023
# 708  1120018. BLR - United Democratic Forces of Bel...         51  1120018
# 719                            6040031. PER - Forwards         46  6040031
# 723  6160065. POL - Patriotic Movement of the Repub...         45  6160065
# 724     4170101. KGZ - Akbarali Aitikeev (Independent)         44  4170101
# 725            0360010. AUS - The Australian Sex Party         44   360010
# 728              0760023. BRA - Labour Party of Brazil         42   760023
# 731           6080019. PHL - Voice of the Masses Party         41  6080019
# 736           6160114. POL - Solidarity 80 Trade Union         39  6160114
# 742            3440036. HKG - Article 45 Concern Group         37  3440036
# 743                   6430026. RUS - For Civil Dignity         37  6430026
# 754                        3520023. ISL - The Movement         34  3520023
# 756    6430111. RUS - Initiative Group D: Aman Tuleyev         33  6430111
# 759                          3760090. ISR - Right Bloc         32  3760090
# 762                    3920015. JPN - New Party Daichi         32  3920015
# 764       6430196. RUS - Irina Khakamada (Independent)         32  6430196
# 768        6430194. RUS - Sergey Glazyev (Independent)         31  6430194
# 769      0760028. BRA - Party of National Mobilization         30   760028
# 775                   1580018. TWN - China Youth Party         29  1580018
# 793  2500032. FRA - Jose Bove - ran as an activist ...         25  2500032
# 794                              5280012. NLD - One NL         25  5280012
# 798                      7560019. CHE - Center parties         25  7560019
#
#     country                                         party_name country_long  \
# 103     RUS                 Initiative Group A: Vladimir Putin       RUSSIA
# 178     KGZ                     Kurmanbek Bakiev (Independent)   KYRGYZSTAN
# 195     BLR                        A. Lukashenko (Independent)      BELARUS
# 271     BRA                       Progressive Republican Party       BRAZIL
# 275     DEU                 Party Of The Rule Of Law Offensive      GERMANY
# 428     MEX  Institutional Revolutionary Party - Ecological...       MEXICO
# 450     THA       National Development of the Motherland Party     THAILAND
# 455     MEX                      Coalition for the Good of All       MEXICO
# 456     THA                             Power of Choburi Party     THAILAND
# 458     THA                                  Peaceloving Party     THAILAND
# 459     KOR                            National Integration 21  SOUTH KOREA
# 485     LTU                        A. Paulauskas (Independent)    LITHUANIA
# 505     LTU                           V. Adamkus (Independent)    LITHUANIA
# 529     CHL                             Peruvian Aprista Party        CHILE
# 555     ROU  Calin-Constantin-Anton Popescu-Tariceanu (Inde...      ROMANIA
# 571     TUR                               People's Voice Party       TURKEY
# 618     URY                                   Popular Assembly      URUGUAY
# 619     MNE                                    Force for Unity   MONTENEGRO
# 621     MNE                                      Serbian Unity   MONTENEGRO
# 622     MNE                                 Albanian Coalition   MONTENEGRO
# 625     KGZ                          Askar Akaev (Independent)   KYRGYZSTAN
# 628     PHL  Candidates with no information about party aff...  PHILIPPINES
# 630     POL                     Coalition Electoral Solidarity       POLAND
# 634     HKG                                 April Fifth Action    HONG KONG
# 637     POL                              Senate 2001 coalition       POLAND
# 640     RUS               Initiative Group B: Gennady Zyuganov       RUSSIA
# 641     PHL                      Coalition of United Filipinos  PHILIPPINES
# 649     KGZ                     Masaliev Apsamat (Independent)   KYRGYZSTAN
# 651     BLR                        Vote for at-large Candidate      BELARUS
# 655     BLR                       United Democratic Opposition      BELARUS
# 663     RUS              Initiative Group C: Grigory Yavlinsky       RUSSIA
# 667     KGZ                     Tekebaev Omurbek (Independent)   KYRGYZSTAN
# 669     PHL  Voted but did not vote for a lower house candi...  PHILIPPINES
# 673     MEX                                   Social Democracy       MEXICO
# 674     KGZ                 Bakir uulu Tursunbai (Independent)   KYRGYZSTAN
# 676     KGZ                    Atambaev Almazbek (Independent)   KYRGYZSTAN
# 679     BRA                   Unified Socialist Workers' Party       BRAZIL
# 686     SRB   Democratic Party of Serbia - New Serbia Alliance       SERBIA
# 704     NZL                                         Mana Maori  NEW ZEALAND
# 708     BLR                United Democratic Forces of Belarus      BELARUS
# 719     PER                                           Forwards         PERU
# 723     POL       Patriotic Movement of the Republic of Poland       POLAND
# 724     KGZ                    Akbarali Aitikeev (Independent)   KYRGYZSTAN
# 725     AUS                           The Australian Sex Party    AUSTRALIA
# 728     BRA                             Labour Party of Brazil       BRAZIL
# 731     PHL                          Voice of the Masses Party  PHILIPPINES
# 736     POL                          Solidarity 80 Trade Union       POLAND
# 742     HKG                           Article 45 Concern Group    HONG KONG
# 743     RUS                                  For Civil Dignity       RUSSIA
# 754     ISL                                       The Movement      ICELAND
# 756     RUS                   Initiative Group D: Aman Tuleyev       RUSSIA
# 759     ISR                                         Right Bloc       ISRAEL
# 762     JPN                                   New Party Daichi        JAPAN
# 764     RUS                      Irina Khakamada (Independent)       RUSSIA
# 768     RUS                       Sergey Glazyev (Independent)       RUSSIA
# 769     BRA                     Party of National Mobilization       BRAZIL
# 775     TWN                                  China Youth Party       TAIWAN
# 793     FRA  Jose Bove - ran as an activist from 'After Glo...       FRANCE
# 794     NLD                                             One NL  NETHERLANDS
# 798     CHE                                     Center parties  SWITZERLAND
#
#                                      country_partyname  pf_from_cses_no  \
# 103          RUSSIA|initiative group a: vladimir putin              NaN
# 178          KYRGYZSTAN|kurmanbek bakiev (independent)              NaN
# 195                BELARUS|a. lukashenko (independent)              NaN
# 271                BRAZIL|progressive republican party              NaN
# 275         GERMANY|party of the rule of law offensive              NaN
# 428  MEXICO|institutional revolutionary party - eco...              NaN
# 450  THAILAND|national development of the motherlan...              NaN
# 455               MEXICO|coalition for the good of all              NaN
# 456                    THAILAND|power of choburi party              NaN
# 458                         THAILAND|peaceloving party              NaN
# 459                SOUTH KOREA|national integration 21              NaN
# 485              LITHUANIA|a. paulauskas (independent)              NaN
# 505                 LITHUANIA|v. adamkus (independent)              NaN
# 529                       CHILE|peruvian aprista party              NaN
# 555  ROMANIA|calin-constantin-anton popescu-taricea...              NaN
# 571                        TURKEY|people's voice party              NaN
# 618                           URUGUAY|popular assembly              NaN
# 619                         MONTENEGRO|force for unity              NaN
# 621                           MONTENEGRO|serbian unity              NaN
# 622                      MONTENEGRO|albanian coalition              NaN
# 625               KYRGYZSTAN|askar akaev (independent)              NaN
# 628  PHILIPPINES|candidates with no information abo...              NaN
# 630              POLAND|coalition electoral solidarity              NaN
# 634                       HONG KONG|april fifth action              NaN
# 637                       POLAND|senate 2001 coalition              NaN
# 640        RUSSIA|initiative group b: gennady zyuganov              NaN
# 641          PHILIPPINES|coalition of united filipinos              NaN
# 649          KYRGYZSTAN|masaliev apsamat (independent)              NaN
# 651                BELARUS|vote for at-large candidate              NaN
# 655               BELARUS|united democratic opposition              NaN
# 663       RUSSIA|initiative group c: grigory yavlinsky              NaN
# 667          KYRGYZSTAN|tekebaev omurbek (independent)              NaN
# 669  PHILIPPINES|voted but did not vote for a lower...              NaN
# 673                            MEXICO|social democracy              NaN
# 674      KYRGYZSTAN|bakir uulu tursunbai (independent)              NaN
# 676         KYRGYZSTAN|atambaev almazbek (independent)              NaN
# 679            BRAZIL|unified socialist workers' party              NaN
# 686  SERBIA|democratic party of serbia - new serbia...              NaN
# 704                             NEW ZEALAND|mana maori              NaN
# 708        BELARUS|united democratic forces of belarus              NaN
# 719                                      PERU|forwards              NaN
# 723  POLAND|patriotic movement of the republic of p...              NaN
# 724         KYRGYZSTAN|akbarali aitikeev (independent)              NaN
# 725                 AUSTRALIA|the australian sex party              NaN
# 728                      BRAZIL|labour party of brazil              NaN
# 731              PHILIPPINES|voice of the masses party              NaN
# 736                   POLAND|solidarity 80 trade union              NaN
# 742                 HONG KONG|article 45 concern group              NaN
# 743                           RUSSIA|for civil dignity              NaN
# 754                               ICELAND|the movement              NaN
# 756            RUSSIA|initiative group d: aman tuleyev              NaN
# 759                                  ISRAEL|right bloc              NaN
# 762                             JAPAN|new party daichi              NaN
# 764               RUSSIA|irina khakamada (independent)              NaN
# 768                RUSSIA|sergey glazyev (independent)              NaN
# 769              BRAZIL|party of national mobilization              NaN
# 775                           TAIWAN|china youth party              NaN
# 793  FRANCE|jose bove - ran as an activist from 'af...              NaN
# 794                                 NETHERLANDS|one nl              NaN
# 798                         SWITZERLAND|center parties              NaN
#
#      pf_from_mod5_cses_to_pf  \
# 103                      NaN
# 178                      NaN
# 195                      NaN
# 271                      NaN
# 275                      NaN
# 428                      NaN
# 450                      NaN
# 455                      NaN
# 456                      NaN
# 458                      NaN
# 459                      NaN
# 485                      NaN
# 505                      NaN
# 529                      NaN
# 555                      NaN
# 571                      NaN
# 618                      NaN
# 619                      NaN
# 621                      NaN
# 622                      NaN
# 625                      NaN
# 628                      NaN
# 630                      NaN
# 634                      NaN
# 637                      NaN
# 640                      NaN
# 641                      NaN
# 649                      NaN
# 651                      NaN
# 655                      NaN
# 663                      NaN
# 667                      NaN
# 669                      NaN
# 673                      NaN
# 674                      NaN
# 676                      NaN
# 679                      NaN
# 686                      NaN
# 704                      NaN
# 708                      NaN
# 719                      NaN
# 723                      NaN
# 724                      NaN
# 725                      NaN
# 728                      NaN
# 731                      NaN
# 736                      NaN
# 742                      NaN
# 743                      NaN
# 754                      NaN
# 756                      NaN
# 759                      NaN
# 762                      NaN
# 764                      NaN
# 768                      NaN
# 769                      NaN
# 775                      NaN
# 793                      NaN
# 794                      NaN
# 798                      NaN
#
#                                 shortcountry_partyname  pf_from_party_name  \
# 103             RUS|initiative group a: vladimir putin                 NaN
# 178                 KGZ|kurmanbek bakiev (independent)                 NaN
# 195                    BLR|a. lukashenko (independent)                 NaN
# 271                   BRA|progressive republican party                 NaN
# 275             DEU|party of the rule of law offensive                 NaN
# 428  MEX|institutional revolutionary party - ecolog...                 NaN
# 450   THA|national development of the motherland party                 NaN
# 455                  MEX|coalition for the good of all                 NaN
# 456                         THA|power of choburi party                 NaN
# 458                              THA|peaceloving party                 NaN
# 459                        KOR|national integration 21                 NaN
# 485                    LTU|a. paulauskas (independent)                 NaN
# 505                       LTU|v. adamkus (independent)                 NaN
# 529                         CHL|peruvian aprista party                 NaN
# 555  ROU|calin-constantin-anton popescu-tariceanu (...                 NaN
# 571                           TUR|people's voice party                 NaN
# 618                               URY|popular assembly                 NaN
# 619                                MNE|force for unity                 NaN
# 621                                  MNE|serbian unity                 NaN
# 622                             MNE|albanian coalition                 NaN
# 625                      KGZ|askar akaev (independent)                 NaN
# 628  PHL|candidates with no information about party...                 NaN
# 630                 POL|coalition electoral solidarity                 NaN
# 634                             HKG|april fifth action                 NaN
# 637                          POL|senate 2001 coalition                 NaN
# 640           RUS|initiative group b: gennady zyuganov                 NaN
# 641                  PHL|coalition of united filipinos                 NaN
# 649                 KGZ|masaliev apsamat (independent)                 NaN
# 651                    BLR|vote for at-large candidate                 NaN
# 655                   BLR|united democratic opposition                 NaN
# 663          RUS|initiative group c: grigory yavlinsky                 NaN
# 667                 KGZ|tekebaev omurbek (independent)                 NaN
# 669  PHL|voted but did not vote for a lower house c...                 NaN
# 673                               MEX|social democracy                 NaN
# 674             KGZ|bakir uulu tursunbai (independent)                 NaN
# 676                KGZ|atambaev almazbek (independent)                 NaN
# 679               BRA|unified socialist workers' party                 NaN
# 686  SRB|democratic party of serbia - new serbia al...                 NaN
# 704                                     NZL|mana maori                 NaN
# 708            BLR|united democratic forces of belarus                 NaN
# 719                                       PER|forwards                 NaN
# 723   POL|patriotic movement of the republic of poland                 NaN
# 724                KGZ|akbarali aitikeev (independent)                 NaN
# 725                       AUS|the australian sex party                 NaN
# 728                         BRA|labour party of brazil                 NaN
# 731                      PHL|voice of the masses party                 NaN
# 736                      POL|solidarity 80 trade union                 NaN
# 742                       HKG|article 45 concern group                 NaN
# 743                              RUS|for civil dignity                 NaN
# 754                                   ISL|the movement                 NaN
# 756               RUS|initiative group d: aman tuleyev                 NaN
# 759                                     ISR|right bloc                 NaN
# 762                               JPN|new party daichi                 NaN
# 764                  RUS|irina khakamada (independent)                 NaN
# 768                   RUS|sergey glazyev (independent)                 NaN
# 769                 BRA|party of national mobilization                 NaN
# 775                              TWN|china youth party                 NaN
# 793  FRA|jose bove - ran as an activist from 'after...                 NaN
# 794                                         NLD|one nl                 NaN
# 798                                 CHE|center parties                 NaN
#
#     pf_from_manual
# 103            NaN
# 178            NaN
# 195            NaN
# 271            NaN
# 275            NaN
# 428            NaN
# 450            NaN
# 455            NaN
# 456            NaN
# 458            NaN
# 459            NaN
# 485            NaN
# 505            NaN
# 529            NaN
# 555            NaN
# 571            NaN
# 618            NaN
# 619            NaN
# 621            NaN
# 622            NaN
# 625            NaN
# 628            NaN
# 630            NaN
# 634            NaN
# 637            NaN
# 640            NaN
# 641            NaN
# 649            NaN
# 651            NaN
# 655            NaN
# 663            NaN
# 667            NaN
# 669            NaN
# 673            NaN
# 674            NaN
# 676            NaN
# 679            NaN
# 686            NaN
# 704            NaN
# 708            NaN
# 719            NaN
# 723            NaN
# 724            NaN
# 725            NaN
# 728            NaN
# 731            NaN
# 736            NaN
# 742            NaN
# 743            NaN
# 754            NaN
# 756            NaN
# 759            NaN
# 762            NaN
# 764            NaN
# 768            NaN
# 769            NaN
# 775            NaN
# 793            NaN
# 794            NaN
# 798            NaN

# %%
IMD_party_references[no_current_pf_reference]["frequency"].sum(),IMD_party_references[~no_current_pf_reference]["frequency"].sum(),


# 3,267,923 party references covered : 54,029 references not covered
# Out:
# (54029, 3267923)

# %%
### these should be recoded as "missing"
# '6080167. PHL - Candidates with no information about party affiliation': ????,
#  '6080900. PHL - Voted but did not vote for a lower house candidate': 'PHL',

# %%
# partyfacts_core_parties
# IMD_party_references["pf_from_mod5_cses_to_pf"][overlap][ IMD_party_references["pf_from_mod5_cses_to_pf"][overlap].astype(str).apply(lambda x: not x.isnumeric()) ]

# %%
IMD_party_references
# Out:
#                                                   index  frequency  cses_no  \
# 0                          0760001. BRA - Workers Party      43960   760001
# 1                     1240002. CAN - Conservative Party      42143  1240002
# 2                2760004. DEU - Social Democratic Party      42022  2760004
# 3           1580001. TWN - Democratic Progressive Party      37792  1580001
# 4                  4840002. MEX - National Action Party      37593  4840002
# ...                                                 ...        ...      ...
# 1531  2030071. CZE - Association Of Pensioners Of Th...          1  2030071
# 1532  2030054. CZE - Club of Committed Non-Party Mem...          1  2030054
# 1533                                 6080201. PHL - Alu          1  6080201
# 1534            4280020. LVA - Party Daugava for Latvia          1  4280020
# 1535  1120039. BLR - The Social-Democratic Party of ...          1  1120039
#
#      country                                         party_name  \
# 0        BRA                                      Workers Party
# 1        CAN                                 Conservative Party
# 2        DEU                            Social Democratic Party
# 3        TWN                       Democratic Progressive Party
# 4        MEX                              National Action Party
# ...      ...                                                ...
# 1531     CZE    Association Of Pensioners Of The Czech Republic
# 1532     CZE                Club of Committed Non-Party Members
# 1533     PHL                                                Alu
# 1534     LVA                           Party Daugava for Latvia
# 1535     BLR  The Social-Democratic Party of the People Agre...
#
#         country_long                                  country_partyname  \
# 0             BRAZIL                               BRAZIL|workers party
# 1             CANADA                          CANADA|conservative party
# 2            GERMANY                    GERMANY|social democratic party
# 3             TAIWAN                TAIWAN|democratic progressive party
# 4             MEXICO                       MEXICO|national action party
# ...              ...                                                ...
# 1531  CZECH REPUBLIC  CZECH REPUBLIC|association of pensioners of th...
# 1532  CZECH REPUBLIC  CZECH REPUBLIC|club of committed non-party mem...
# 1533     PHILIPPINES                                    PHILIPPINES|alu
# 1534          LATVIA                    LATVIA|party daugava for latvia
# 1535         BELARUS  BELARUS|the social-democratic party of the peo...
#
#       pf_from_cses_no  pf_from_mod5_cses_to_pf
# 0               356.0                    356.0
# 1              1004.0                      NaN
# 2               383.0                    383.0
# 3              1596.0                   1596.0
# 4               696.0                      NaN
# ...               ...                      ...
# 1531              NaN                      NaN
# 1532              NaN                      NaN
# 1533              NaN                      NaN
# 1534              NaN                      NaN
# 1535              NaN                      NaN
#
# [1536 rows x 9 columns]

# %%
# %debug
# mod5_cses_to_pf.index
# IMD_party_references["cses_no"]
# AllMod5PartyReferences

# keep seeing listings for chile parties that appear to be for peruvian parties ... BUG?
# '152032. CHL - Broad Front',
# 6040003.  Broad Front for Justice, Life and Liberty (Frente Amplio)

# %%
# unlinked_IND_references = IMD_party_references["cses_no"].apply(lambda x: x not in IMD_cses_refs.dropna().astype(int).values)

# %%
# IMD_party_references[(IMD_party_references["country"]=="LTU")]

# %%
# abbrev_mod5_to_imd.index

# %%
# pattern = "-{10,100}|\s+\|"
# cses_5_cb3[0].apply(lambda x: re.match(pattern,x) if re.match(pattern,x) is not None else np.nan).dropna()

## this pattern finds structural elements noting the beginning/end of party list section

# %%
## frustrating the way some lines are split with nothing to really mark it except context

# %%
# cses_5_cb3[0][500:].head(50)

# %%
## read CSES parties_and_leaders text file

# cses5_codebook_part3_parties_and_leaders.txt

cses_5_cb3 = pd.read_csv(dataset_folder + "CSES"+os.sep+"module 5"+os.sep+"cses5_codebook_part3_parties_and_leaders.txt",
            header = None,delimiter= '\n', index_col=False,encoding = "ISO-8859-1")

pattern = "^(<<>>|>>>)\sPARTIES\sAND\sLEADERS:\s([A-Z\s]+\s\(\d+\))"

matches = cses_5_cb3[0].apply(lambda x: re.search(pattern,x).groups()[1] if re.search(pattern,x) is not None else np.nan)
# cses_5_cb3[0][matches]
party_ids_election_studies = matches.dropna()

def get_matches_cb3_upper(x):
    if x is None:
        return (np.nan,np.nan,np.nan,np.nan,)
#     if len(x.groups())==3:
#         return (x.groups()[0],np.nan,x.groups()[1],x.groups()[2])
    else:
        return x.groups()

# %%
pattern = "^(\d{6})\.\s+(\s|PARTY\s+[A-I])\s+([A-Za-z\s\-'\!\./0-9]+)(\s\(.*\)|\s|$)"
# "(\s-\sSEE.*$)?"

matches = cses_5_cb3[0].apply(lambda x: get_matches_cb3_upper(re.match(pattern,x)))
# cses_5_cb3[0][matches].values
# matches.dropna()
# 413 - looks about right!

mod_5_cb3_upper_listing = pd.DataFrame(matches.values.tolist())#.dropna(how='all')
mod_5_cb3_upper_listing["election study"] = party_ids_election_studies
mod_5_cb3_upper_listing["election study"] = mod_5_cb3_upper_listing["election study"].fillna(method='ffill')
mod_5_cb3_upper_listing = mod_5_cb3_upper_listing.drop(mod_5_cb3_upper_listing[mod_5_cb3_upper_listing[[0,1,2,3]].isnull().all(axis=1)].index)
# mod_5_cb3_upper_listing

mod_5_cb3_upper_listing[1] = mod_5_cb3_upper_listing[1].apply(lambda x: x.replace("PARTY ","")).replace(" ",np.nan)
mod_5_cb3_upper_listing[3] = mod_5_cb3_upper_listing[3].apply(lambda x: x.replace("(","").replace(")","").lower())
mod_5_cb3_upper_listing.columns = ["mod5_cses_ids","party letter","party name","abbrev","election study"]
mod_5_cb3_upper_listing

# we're still missing some rows due to stuff that goes over the line!!!!
# Out:
#      mod5_cses_ids party letter                   party name abbrev  \
# 246         036001            A                Liberal Party     lp
# 248         036002            B       Australian Labor Party    alp
# 251         036003            C            Australian Greens     ag
# 253         036004            D  National Party of Australia     np
# 256         036005            E       United Australia Party    uap
# ...            ...          ...                          ...    ...
# 1592        792010          NaN         Buyuk Birlik Partisi    bbp
# 1616        840001            A             Democratic Party    dem
# 1618        840002            B             Republican Party    rep
# 1620        840003            C                  Libertarian     lp
# 1621        840004            D                       Greens   gpus
#
#             election study
# 246       AUSTRALIA (2019)
# 248       AUSTRALIA (2019)
# 251       AUSTRALIA (2019)
# 253       AUSTRALIA (2019)
# 256       AUSTRALIA (2019)
# ...                    ...
# 1592         TURKEY (2018)
# 1616  UNITED STATES (2016)
# 1618  UNITED STATES (2016)
# 1620  UNITED STATES (2016)
# 1621  UNITED STATES (2016)
#
# [413 rows x 5 columns]

# %%
## try to do the same thing for the IMD part 3 text file

# %%
## read CSES parties_and_leaders text file

# cses5_codebook_part3_parties_and_leaders.txt

cses_IMD_cb3 = pd.read_csv(dataset_folder + "CSES"+os.sep+"integrated 1-4"+os.sep+"csesIMD_codebook_part3_parties_coalitions_numerical_codes.txt",
            header = None,delimiter= '\n', index_col=False,encoding = "ISO-8859-1")

#.drop("Unnamed: 0",axis=1)

# %%
pattern = "^(<<>>|>>>) CSES IMD PARTY/COALITION HARMONIZED NUMERICAL CODES: ("+name_char+"+)"
party_ids_election_studies = cses_IMD_cb3[0].apply(lambda x: re.match(pattern,x).groups()[1] if re.match(pattern,x) is not None else np.nan)
# pd.DataFrame(matches.values.tolist()).dropna(how='all')

pattern = "^(\d{7})\.\s+([A-Za-z\s\-'\!\./0-9]+)(\s\(.*\)|\s|$)"

matches = cses_IMD_cb3[0].apply(lambda x: get_matches_cb3_upper(re.match(pattern,x)))
imd_cb3_upper_listing = pd.DataFrame(matches.values.tolist())

imd_cb3_upper_listing["election study"] = party_ids_election_studies
imd_cb3_upper_listing["election study"] = imd_cb3_upper_listing["election study"].fillna(method='ffill')
imd_cb3_upper_listing = imd_cb3_upper_listing.drop(imd_cb3_upper_listing[imd_cb3_upper_listing[[0,1,2,3]].isnull().all(axis=1)].index).drop(3,axis=1)

imd_cb3_upper_listing[2] = imd_cb3_upper_listing[2].apply(lambda x: x.replace("(","").replace(")","").lower())
imd_cb3_upper_listing.columns = ["imd_cses_ids","party name","abbrev","election study"]
imd_cb3_upper_listing["abbrev"] = imd_cb3_upper_listing["abbrev"].apply(lambda x: x.strip()).replace("",np.nan)
imd_cb3_upper_listing
# Out:
#      imd_cses_ids                          party name abbrev election study
# 288       0080001                     Socialist Party     ps        ALBANIA
# 289       0080002                    Democratic Party     pd        ALBANIA
# 290       0080003  Socialist Movement for Integration    lsi        ALBANIA
# 291       0080004                    Republican Party     pr        ALBANIA
# 292       0080005             Social Democratic Party    psd        ALBANIA
# ...           ...                                 ...    ...            ...
# 3324      8580002                      National Party     pn        URUGUAY
# 3325      8580003                      Colorado Party    NaN        URUGUAY
# 3326      8580004                   Independent Party     pi        URUGUAY
# 3327      8580005                    Popular Assembly    NaN        URUGUAY
# 3328      8580006                         Civic Union    NaN        URUGUAY
#
# [1778 rows x 4 columns]

# %%
mod_5_cb3_upper_listing["country"] = mod_5_cb3_upper_listing["election study"].apply(lambda x: x.split(" (")[0])

# %%
mod_5_cb3_upper_listing["abbrev"] = mod_5_cb3_upper_listing["abbrev"].apply(lambda x: x.strip() if pd.notnull(x) else np.nan).replace("",np.nan)

# %%
mod_5_cb3_upper_listing["abbrev"].isnull().sum()

# 287 instances with abbrev, 126 instances without abbrev
# Out:
# 126

# %%
mod_5_cb3_upper_listing["country|abbrev"] = mod_5_cb3_upper_listing["country"]+"|"+mod_5_cb3_upper_listing["abbrev"]
mod_5_cb3_upper_listing["country|abbrev"][mod_5_cb3_upper_listing["abbrev"].isnull()]=np.nan

# %%
imd_cb3_upper_listing["country|abbrev"] = imd_cb3_upper_listing["election study"]+"|"+imd_cb3_upper_listing["abbrev"]
imd_cb3_upper_listing["country|abbrev"][imd_cb3_upper_listing["abbrev"].isnull()]=np.nan

# %%
len( set(imd_cb3_upper_listing["country|abbrev"].dropna().values) )
# Out:
# 1218

# %%
len( set(mod_5_cb3_upper_listing["country|abbrev"].dropna().values) )
# Out:
# 278

# %%
len( set(mod_5_cb3_upper_listing["country|abbrev"].dropna().values).intersection( set(imd_cb3_upper_listing["country|abbrev"].dropna().values) ) )
# Out:
# 142

# %%
match_by_abbrev = mod_5_cb3_upper_listing.merge(imd_cb3_upper_listing.dropna(),how='left',on="country|abbrev")

# %%
match_by_abbrev[ match_by_abbrev["imd_cses_ids"].notnull() ]
# Out:
#     mod5_cses_ids party letter                party name_x abbrev_x  \
# 0          036001            A               Liberal Party       lp
# 1          036002            B      Australian Labor Party      alp
# 2          036003            C           Australian Greens       ag
# 9          036010          NaN   Katter's Australian Party      kap
# 13         036014          NaN           Liberal Democrats      ldp
# ..            ...          ...                         ...      ...
# 402        792004            D  Milliyetci Hareket Partisi      mhp
# 404        792006            F              Saadet Partisi       sp
# 406        792008          NaN               Vatan Partisi       vp
# 408        792010          NaN        Buyuk Birlik Partisi      bbp
# 409        840001            A            Democratic Party      dem
#
#          election study_x        country     country|abbrev imd_cses_ids  \
# 0        AUSTRALIA (2019)      AUSTRALIA       AUSTRALIA|lp      0360001
# 1        AUSTRALIA (2019)      AUSTRALIA      AUSTRALIA|alp      0360003
# 2        AUSTRALIA (2019)      AUSTRALIA       AUSTRALIA|ag      0360005
# 9        AUSTRALIA (2019)      AUSTRALIA      AUSTRALIA|kap      0360012
# 13       AUSTRALIA (2019)      AUSTRALIA      AUSTRALIA|ldp      0360007
# ..                    ...            ...                ...          ...
# 402         TURKEY (2018)         TURKEY         TURKEY|mhp      7920003
# 404         TURKEY (2018)         TURKEY          TURKEY|sp      7920005
# 406         TURKEY (2018)         TURKEY          TURKEY|vp      7920006
# 408         TURKEY (2018)         TURKEY         TURKEY|bbp      7920015
# 409  UNITED STATES (2016)  UNITED STATES  UNITED STATES|dem      8400002
#
#                  party name_y abbrev_y election study_y
# 0               Liberal Party       lp        AUSTRALIA
# 1      Australian Labor Party      alp        AUSTRALIA
# 2           Australian Greens       ag        AUSTRALIA
# 9    Katter's Australia Party      kap        AUSTRALIA
# 13   Liberal Democratic Party      ldp        AUSTRALIA
# ..                        ...      ...              ...
# 402  Nationalist Action Party      mhp           TURKEY
# 404            Felicity Party       sp           TURKEY
# 406           Patriotic Party       vp           TURKEY
# 408         Great Union Party      bbp           TURKEY
# 409          Democratic Party      dem    UNITED STATES
#
# [147 rows x 11 columns]

# %%
imd_cb3_upper_listing["country_partyname"]   = imd_cb3_upper_listing["election study"]  +"|"+imd_cb3_upper_listing["party name"].apply(lambda x: x.lower())
mod_5_cb3_upper_listing["country_partyname"] = mod_5_cb3_upper_listing["election study"].apply(lambda x: x.split(" (")[0])+"|"+mod_5_cb3_upper_listing["party name"].apply(lambda x: x.lower())

# %%
match_by_partyname = mod_5_cb3_upper_listing.merge(imd_cb3_upper_listing,how='left',on="country_partyname")
match_by_partyname["imd_cses_ids"].notnull().sum()
# Out:
# 36

# %%
# match_by_partyname[match_by_partyname["mod5_cses_ids"]=="276012"]

# okay - we should also merge on the listed version that tends to be in english!

#'276012. DEU - National Democratic Party Of Germany'

# %%
# imd_cb3_upper_listing["imd_cses_ids"] = imd_cb3_upper_listing["imd_cses_ids"].astype(int)
# short_to_long_country_names =imd_cb3_upper_listing.merge(IMD_party_references,how='left',left_on="imd_cses_ids",right_on="cses_no")[["election study","country"]].dropna().drop_duplicates().set_index("country")

# %%
# imd_cb3_upper_listing.shape[0]- IMD_party_references.shape[0]

# slovenia:
# united list of social democrats/social democrats listed twice with same cses no

# %%
# IMD_party_references[ IMD_party_references["cses_no"]==1580028 ]

# Taiwanese Red Party/Home Party listed twice by typo!

# %%
# IMD_party_references["country_long"] = IMD_party_references["country"].apply(lambda x: short_to_long_country_names.loc[x])
# IMD_party_references["country_partyname"] = IMD_party_references["country_long"]+"|"+IMD_party_references["party_name"].apply(lambda x: x.lower())

# # mod_5_cb3_upper_listing["country_partyname"]

# %%
# match_by_partyname_2 = mod_5_cb3_upper_listing.merge(IMD_party_references,how='left',on="country_partyname")
# match_by_partyname_2[["cses_no","index"]].dropna()

# %%
## damnit - only difference is
# 346, 214

# %%
# match_by_partyname_2.loc[[346,214]]

# %%
# leader/party ref string
lp_str = "(A|B|C|D|E|F|G|H|I)"
name_char = "[A-Za-z\s\-'\!\./0-9,]"

matches = cses_5_cb3[0].apply(lambda x: re.match("^\s+LEADER\s+"+lp_str+"\s+"+name_char+"+",x) is not None)
cses_5_cb3[0][matches].values
# Out:
# array(['        LEADER A  Scott Morrison',
#        '        LEADER B  Bill Shorten',
#        '        LEADER G  Anthony Albanese - SEE ELECTION STUDY NOTES',
#        '        LEADER C  Richard Di Natale',
#        '        LEADER D  Michael McCormack',
#        '        LEADER F  Pauline Hanson',
#        '        LEADER A  Sebastian Kurz',
#        '        LEADER B  Christian Kern',
#        '        LEADER C  Heinz-Christian Strache ',
#        '        LEADER D  Matthias Strolz',
#        '        LEADER E  Peter Pilz', '        LEADER F  Ulrike Lunacek',
#        '        LEADER A  Jair Bolsonaro - SEE ELECTION STUDY NOTES',
#        '        LEADER B  Fernando Haddad - SEE ELECTION STUDY NOTES',
#        '        LEADER C  Geraldo Alckmin - SEE ELECTION STUDY NOTES',
#        '        LEADER F  Henrique Meirelles - SEE ELECTION STUDY NOTES',
#        '        LEADER A  Sebastian Pinera',
#        '        LEADER C  Carolina Goic',
#        '        LEADER D  Alejandro Guillier',
#        '        LEADER F  Beatriz Sanchez',
#        '        LEADER G  Marco Enriquez-Ominami - SEE ELECTION STUDY NOTES',
#        '        LEADER H  Eduardo Artes - SEE ELECTION STUDY NOTES',
#        '        LEADER I  Alejandro Navarro - SEE ELECTION STUDY NOTES',
#        '       LEADER A  Emmanuel Macron ',
#        '       LEADER B  Marine Le Pen',
#        '       LEADER C  Francois Fillon',
#        '       LEADER D  Jean-Luc Melenchon',
#        '       LEADER E  Benoit Hamon', '        LEADER A  Angela Merkel',
#        '        LEADER B  Martin Schulz',
#        '        LEADER C  Alexander Gauland',
#        '        LEADER D  Christian Lindner',
#        '        LEADER E  Sahra Wagenknecht',
#        '        LEADER F  Cem Oezdemir',
#        '        LEADER G  Horst Seehofer',
#        '        LEADER A  Alexis Tsipras',
#        '        LEADER B  Vaggelis Meimarakis',
#        '        LEADER C  Nikos Michaloliakos',
#        '        LEADER D  Fofi Gennimata\t\t\t  ',
#        '        LEADER E  Dimitris Koutsoumbas ',
#        '        LEADER F  Stavros Theodorakis',
#        '        LEADER G  Panos Kammenos',
#        '        LEADER H  Vassilis Leventis',
#        '        LEADER A  LEE Wai King, Starry',
#        '        LEADER B  EU Yuet Mee, Audrey',
#        '        LEADER C  LAU Wai Hing, Emily',
#        '        LEADER D  LAM Shuk Yee',
#        '        LEADER E  IP LAU Suk Yee, Regina',
#        '        LEADER I  LEUNG Chung Hang, Baggio - see ELECTION STUDY NOTES',
#        '        LEADER A  Victor Orban', '        LEADER B  Vona Gabor',
#        '        LEADER C  Molnar Gyla',
#        '        LEADER I  Karacsony Gergely - SEE ELECTION STUDY NOTES',
#        '        LEADER D  Szel Bernadett',
#        '        LEADER E  Gyurcsany Ferenc',
#        '        LEADER A  Bjarni Benediktsson',
#        '        LEADER B  Katrin Jakobsdottir',
#        '        LEADER C  Birgitta Jonsdottir',
#        '        LEADER D  Sigurour Ingi Johannsson',
#        '        LEADER E  Benedikt Johannesson',
#        '        LEADER F  Ottar Proppe',
#        '        LEADER G  Oddny Haroardottir',
#        '        LEADER A  Bjarni Benediktsson',
#        '        LEADER B  Katrin Jakobsdottir',
#        '        LEADER C  Oddny Haroardottir',
#        '        LEADER D  Sigmundur Davio Gunnlaugsson',
#        '        LEADER E  Sigurour Ingi Johannsson',
#        '        LEADER F  Porhilder Sunna Aevarsdottir - SEE ELECTION STUDY NOTES',
#        '        LEADER G  Inga Saeland                   ',
#        '        LEADER H  Porgerour Katrin Gunnarsdottir',
#        '        LEADER A  Enda Kenny ',
#        '        LEADER B  Michael Martin',
#        '        LEADER C  Gerry Adams', '        LEADER D  Joan Burton',
#        '        LEADER E  Richard Boyd Barrett - SEE ELECTION STUDY NOTES',
#        '        LEADER F  Stephen Donnelly - SEE ELECTION STUDY NOTES',
#        '        LEADER G  Eamon Ryan', '        LEADER A  Luigi Di Maio',
#        '        LEADER B  Matteo Renzi',
#        '        LEADER I  Paolo Gentiloni - SEE ELECTION STUDY NOTES',
#        '        LEADER C  Matteo Salvini  ',
#        '        LEADER D  Silvio Berlusconi',
#        '        LEADER E  Giorgia Meloni',
#        '        LEADER F  Pietro Grasso',
#        '        LEADER A  Gabrielius Landsbergis',
#        '        LEADER B  Ramunas Karbauskis',
#        '        LEADER C  Algirdas Butkevicius',
#        '        LEADER D  Remigijus Simasius',
#        '        LEADER E  Naglis Puteikis',
#        '        LEADER F  Valdemar Tomasevski',
#        '        LEADER G  Rolandas Paksas',
#        '        LEADER H  Valentinas Mazuronis',
#        '        LEADER A  Milo Djukanovic',
#        '        LEADER B  Andrija Mandic - SEE ELECTION STUDY NOTES ',
#        '        LEADER C  Miodrag Lekic - SEE ELECTION STUDY NOTES ',
#        '        LEADER D  Aleksa Becic',
#        '        LEADER E  Ranko Krivokapic',
#        '        LEADER F  Ivan Brajovic',
#        '        LEADER G  Rafet Husovic',
#        '        LEADER A  Bill English',
#        '        LEADER B  Jacinda Ardern',
#        '        LEADER C  Winston Peters', '        LEADER D  James Shaw',
#        '        LEADER E  Gareth Morgan',
#        '        LEADER F  Te Ururoa Flavel ',
#        '        LEADER I  Marama Fox - SEE ELECTION STUDY NOTES',
#        '        LEADER G  David Seymour ',
#        '        LEADER H  Hone Harawira',
#        '        LEADER A  Jonas Gahr Store',
#        '        LEADER B  Erna Solberg', '        LEADER C  Siv Jensen',
#        '        LEADER D  Trygve Slagsvold Vedum',
#        '        LEADER E  Audun Lysbakken',
#        '        LEADER F  Trin Skei Grande',
#        '        LEADER G  Knut Arild Hareide',
#        '        LEADER H  Rasmus Hansson',
#        '        LEADER I  Bjornar Moxnes',
#        '        LEADER A  Moo-sung Kim',
#        '        LEADER B  Jong-in Kim - SEE ELECTION STUDY NOTES',
#        '        LEADER I  Jae-in Moon - SEE ELECTION STUDY NOTES',
#        '        LEADER C  Cheol-soo Ahn',
#        '        LEADER A  Tsai Ing-wen - SEE ELECTION STUDY NOTES',
#        '        LEADER B  Eric Chu - SEE ELECTION STUDY NOTES',
#        '        LEADER F  James Soong - SEE ELECTION STUDY NOTES',
#        '        LEADER A  Recep Tayyip Erdogan - SEE ELECTION STUDY NOTES',
#        '        LEADER B  Kemal Kilicdaroglu',
#        '        LEADER C  Pervin Buldan',
#        '        LEADER D  Devlet Bahceli',
#        '        LEADER E  Meral Aksener - SEE ELECTION STUDY NOTES',
#        '        LEADER F  Temel Karamollaoglu - SEE ELECTION STUDY NOTES',
#        '       LEADER A  Hillary Rodham Clinton                     ',
#        '       LEADER B  Donald Trump'], dtype=object)

# %%
re.search("^(<<>>|>>>)\sPARTIES\sAND\sLEADERS:\s[A-Z\s]+\s",cses_5_cb3.loc[1614,0])
# Out:
# <re.Match object; span=(0, 39), match='>>> PARTIES AND LEADERS: UNITED STATES '>

# %%
# leader/party ref string
lp_str = "(A|B|C|D|E|F|G|H|I)"
name_char = "[A-Za-z\s\-'\!\./0-9,]"
# PARTY IDS FROM OTHER COMPARATIVE STUDIES: AUSTRALIA (2019)

pattern = "^(<<>>|>>>)\sPARTY IDS FROM OTHER COMPARATIVE STUDIES: ("+name_char+"+\s\(\d{4}\))"

matches = cses_5_cb3[0].apply(lambda x: re.match(pattern,x).groups()[1] if re.match(pattern,x) is not None else np.nan)
# cses_5_cb3[0][matches]
party_ids_election_studies = matches
# matches.dropna()
# we don't have data for all election studies - there really are only 17 listed!

# %%
def get_matches_cb3_lower(x):
    if x is None:
        return (np.nan,np.nan,np.nan,np.nan,)
    if len(x.groups())==3:
        return (x.groups()[0],np.nan,x.groups()[1],x.groups()[2])
    else:
        return x.groups()

# %%
## BOTTOM SECTION of MOD5 part 3 codebook


# PARTY NAME (Abbreviation)                          MARPOR ID     ParlGov ID
# Liberal Party (LP)                                     63620           1411


# leader/party ref string
lp_str = "(A|B|C|D|E|F|G|H|I)"
name_char = "[A-Za-z\s\-'\!\./0-9,]"
# PARTY IDS FROM OTHER COMPARATIVE STUDIES: AUSTRALIA (2019)

pattern = "^\s?("+name_char+"+)\s(\("+name_char+"+\))?\s{3,100}(\d{1,6})\s{3,20}(\d{1,6})\s{0,20}$"

# matches = cses_5_cb3[0].apply(lambda x: re.match(pattern,x).groups() if re.match(pattern,x) is not None else (np.nan,np.nan,np.nan,np.nan,))
matches = cses_5_cb3[0].apply(lambda x: get_matches_cb3_lower(re.match(pattern,x)))


# cses_5_cb3[0][matches].values
# matches.dropna()


# 111 entries - is that about right?
# looks right from manual inspection through notepad++
# not all election studies have this information!

# %%
# ^([A-Za-z\s\-'\!\./0-9,]+)\s(\([A-Za-z\s\-'\!\./0-9,]+\))?\s{4,100}(\d{1,6})\s{4,20}(\d{1,6})$

matches
# Out:
# 0                         (nan, nan, nan, nan)
# 1                         (nan, nan, nan, nan)
# 2                         (nan, nan, nan, nan)
# 3                         (nan, nan, nan, nan)
# 4                         (nan, nan, nan, nan)
#                          ...
# 1885    (Democratic Party, (DEM), 61320, 9999)
# 1886    (Republican Party, (REP), 61620, 9999)
# 1887         (Libertarian, (LP), 999999, 9999)
# 1888             (Green, (GPUS), 999999, 9999)
# 1889                      (nan, nan, nan, nan)
# Name: 0, Length: 1890, dtype: object

# %%
# mod5_major_party_ids["party abbrev"].isnull().sum()

# %%
df = pd.DataFrame(matches.values.tolist())
df["election_study"]= party_ids_election_studies
df.columns = ["partyname","party abbrev","marpor id","parlgov id","election_study"]
df = df.dropna(how='all')
df["election_study"] = df["election_study"].fillna(method='ffill')
df["party abbrev"] = df["party abbrev"].fillna("")
mod5_major_party_ids = df.dropna()
mod5_major_party_ids.loc[1781] = ["Renua Ireland","",999999,2620,"IRELAND (2016)"]

## for some weird reason *this single party* wasn't present - have manually added it in the position it "ought" to have had

# %%
mod5_major_party_ids
# Out:
#                         partyname party abbrev marpor id parlgov id  \
# 1652                Liberal Party         (LP)     63620       1411
# 1653       Australian Labor Party        (ALP)     63320       1253
# 1654            Australian Greens         (AG)     63110        751
# 1655  National Party of Australia         (NP)     63810        184
# 1656       United Australia Party        (UAP)     63410       1912
# ...                           ...          ...       ...        ...
# 1885             Democratic Party        (DEM)     61320       9999
# 1886             Republican Party        (REP)     61620       9999
# 1887                  Libertarian         (LP)    999999       9999
# 1888                        Green       (GPUS)    999999       9999
# 1781                Renua Ireland                 999999       2620
#
#             election_study  pf_from_marpor  pf_from_parlgov  cses_from_marpor  \
# 1652      AUSTRALIA (2019)           486.0            486.0               NaN
# 1653      AUSTRALIA (2019)           424.0            424.0          360003.0
# 1654      AUSTRALIA (2019)          1209.0           1209.0          360005.0
# 1655      AUSTRALIA (2019)          1743.0           1743.0          360002.0
# 1656      AUSTRALIA (2019)          1996.0            566.0          360013.0
# ...                    ...             ...              ...               ...
# 1885  UNITED STATES (2016)           432.0              NaN         8400002.0
# 1886  UNITED STATES (2016)           809.0              NaN         8400001.0
# 1887  UNITED STATES (2016)             NaN              NaN               NaN
# 1888  UNITED STATES (2016)             NaN              NaN               NaN
# 1781        IRELAND (2016)             NaN           4869.0               NaN
#
#       cses_from_parlgov  cses_from_both
# 1652                NaN             NaN
# 1653           360003.0        360003.0
# 1654           360005.0        360005.0
# 1655           360002.0        360002.0
# 1656                NaN        360013.0
# ...                 ...             ...
# 1885                NaN       8400002.0
# 1886                NaN       8400001.0
# 1887                NaN             NaN
# 1888                NaN             NaN
# 1781                NaN             NaN
#
# [123 rows x 10 columns]

# %%
# mod5_major_party_ids[mod5_major_party_ids["election_study"]=="IRELAND (2016)"]

# %%
# mod5_major_party_ids[30:].head(50)

# 1780	Green Party	(GP)	53110	1573	IRELAND (2016)
#

# %%
# mod5_parties_list[mod5_parties_list["election_study"]=="IRELAND (2016)"]
# https://partyfacts.herokuapp.com/data/partycodes/4869/

# %%
# cses_5_cb3.loc[1666,0]

# %%
# re.match(pattern, cses_5_cb3.loc[1666,0]).groups()

# %%
# df = pd.DataFrame(matches.values.tolist())
# df["election_study"]= party_ids_election_studies
# df.columns = ["partyname","party abbrev","marpor id","parlgov id","election_study"]
# df = df.dropna(how='all')
# # df.loc[1736]

# %%
# matches.loc[1736]

# %%
# mod5_major_party_ids["election_study"].value_counts()

# %%
# df

# %%
# matches

# %%
partyfacts_core_parties = pd.read_csv(dataset_folder+"PartyFacts"+os.sep+"Newest version"+os.sep+"partyfacts-core-parties.csv")
### bug!
partyfacts_core_parties.drop(partyfacts_core_parties[partyfacts_core_parties["partyfacts_id"]==8245].index,inplace=True)

partyfacts_external_parties = pd.read_csv(dataset_folder+"PartyFacts"+os.sep+ "Newest version"+os.sep+"partyfacts-external-parties.csv")

# %%
cses_ids_to_pf = partyfacts_external_parties[partyfacts_external_parties["dataset_key"]=="cses"].set_index("dataset_party_id")["partyfacts_id"]
cses_ids_to_pf.index = [int(x) for x in cses_ids_to_pf.index]

# %%
# cses
cses_ids_to_pf = partyfacts_external_parties[partyfacts_external_parties["dataset_key"]=="cses"].set_index("dataset_party_id")["partyfacts_id"]
cses_ids_to_pf.index = [int(x) for x in cses_ids_to_pf.index]

# parlgov
parlgov_ids_to_pf = partyfacts_external_parties[partyfacts_external_parties["dataset_key"]=="parlgov"].set_index("dataset_party_id")["partyfacts_id"]
parlgov_ids_to_pf.index = [int(x) for x in parlgov_ids_to_pf.index]

# manifesto
manifesto_ids_to_pf = partyfacts_external_parties[partyfacts_external_parties["dataset_key"]=="manifesto"].set_index("dataset_party_id")["partyfacts_id"]
manifesto_ids_to_pf.index = [int(x) for x in manifesto_ids_to_pf.index]

# back to cses
pf_ids_to_cses = cses_ids_to_pf.reset_index().set_index("partyfacts_id")["index"]

# %%
mod5_major_party_ids["pf_from_marpor"] = mod5_major_party_ids["marpor id"].astype(float).apply(lambda x: manifesto_ids_to_pf.loc[x] if x in manifesto_ids_to_pf.index else np.nan)
mod5_major_party_ids["pf_from_parlgov"] = mod5_major_party_ids["parlgov id"].astype(float).apply(lambda x: parlgov_ids_to_pf.loc[x] if x in parlgov_ids_to_pf.index else np.nan)

# %%
(mod5_major_party_ids[["pf_from_marpor","pf_from_parlgov"]].notnull().sum(axis=1)>=2).sum()

# quite a bit of overlap, sometimes they disagree
# Out:
# 82

# %%
mod5_major_party_ids["cses_from_marpor"] = mod5_major_party_ids["pf_from_marpor"].astype(float).apply(lambda x: pf_ids_to_cses.loc[x] if x in pf_ids_to_cses.index else np.nan)
mod5_major_party_ids["cses_from_parlgov"] = mod5_major_party_ids["pf_from_parlgov"].astype(float).apply(lambda x: pf_ids_to_cses.loc[x] if x in pf_ids_to_cses.index else np.nan)

# %%
# do the inferred cses_ids from marpor/parlgov agree?
# mostly - except in the case of CDU/CSU - which marpor only lists as CDU+CSU

cses_ids_from_both_cmp_pg = mod5_major_party_ids[["cses_from_marpor","cses_from_parlgov"]].notnull().sum(axis=1)==2
mod5_major_party_ids[cses_ids_from_both_cmp_pg][mod5_major_party_ids["cses_from_marpor"][cses_ids_from_both_cmp_pg]!=mod5_major_party_ids["cses_from_parlgov"][cses_ids_from_both_cmp_pg]]
# Out:
#                        partyname party abbrev marpor id parlgov id  \
# 1687  Christian Democratic Union        (CDU)     41521        808
# 1693      Christian Social Union        (CSU)     41521       1180
#
#       election_study  pf_from_marpor  pf_from_parlgov  cses_from_marpor  \
# 1687  GERMANY (2017)           211.0           1375.0         2760001.0
# 1693  GERMANY (2017)           211.0           1731.0         2760001.0
#
#       cses_from_parlgov
# 1687          2760002.0
# 1693          2760003.0

# %%
mod5_major_party_ids["cses_from_both"] = np.nan
mod5_major_party_ids["cses_from_both"] = mod5_major_party_ids[["cses_from_marpor","cses_from_parlgov","cses_from_both"]].fillna(method='ffill',axis=1)
mod5_major_party_ids["cses_from_both"].notnull().sum()
# Out:
# 72

# %%
## Still remains a question of how to handle
##     text overrun scenarios

# %%
## Now try the same thing with the IMD text file (cross fingers and hope for same format!)
cses_IMD_cb3 = pd.read_csv(dataset_folder + "CSES"+os.sep+"integrated 1-4"+os.sep+"csesIMD_codebook_part3_parties_coalitions_numerical_codes.txt",
            header = None,delimiter= '\n', index_col=False,encoding = "ISO-8859-1")


char_replace_dict = {'â\x80\x9d':'\"','â\x80\x9c':'\"','â':'\"','Ã³':'o',
                     }

for irrit_char in char_replace_dict.keys():
    cses_IMD_cb3[0]= cses_IMD_cb3[0].apply(lambda x: x.replace(irrit_char,char_replace_dict[irrit_char]))

# %%
matches = cses_IMD_cb3[0].apply(lambda x: re.search("^>>> CSES IMD PARTY/COALITION HARMONIZED NUMERICAL CODES: "+name_char+"+",x) is not None)
cses_IMD_cb3[0][matches]

# one per *polity*
# Out:
# 286     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 301     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 329     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 356     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 372     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 453     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 508     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 575     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 634     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 652     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 688     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 714     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 824     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 844     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 866     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 899     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 950     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 994     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1010    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1031    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1069    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1101    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1149    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1165    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1296    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1353    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1385    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1460    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1505    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1601    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1625    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1704    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1762    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1831    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1896    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1919    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2013    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2274    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2459    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2504    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2635    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2709    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2802    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2873    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2929    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2958    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2994    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3056    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3069    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3118    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3168    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3228    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3261    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3313    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3321    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# Name: 0, dtype: object

# %%
matches = cses_IMD_cb3[0].apply(lambda x: re.search("^>>> CSES IMD PARTY/COALITION HARMONIZED NUMERICAL CODES: "+name_char+"+",x) is not None)
cses_IMD_cb3[0][matches]

# one per *polity*
# Out:
# 286     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 301     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 329     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 356     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 372     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 453     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 508     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 575     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 634     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 652     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 688     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 714     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 824     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 844     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 866     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 899     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 950     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 994     >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1010    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1031    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1069    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1101    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1149    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1165    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1296    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1353    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1385    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1460    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1505    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1601    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1625    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1704    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1762    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1831    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1896    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 1919    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2013    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2274    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2459    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2504    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2635    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2709    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2802    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2873    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2929    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2958    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 2994    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3056    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3069    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3118    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3168    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3228    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3261    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3313    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# 3321    >>> CSES IMD PARTY/COALITION HARMONIZED NUMERI...
# Name: 0, dtype: object

# %%
name_char = "[A-Za-z\s\-'\!\./0-9,\+&\":]"

matches = cses_IMD_cb3[0].apply(lambda x: re.search("^\d{7}\.\s+"+name_char+"+(\("+name_char+"+\))?",x) is not None)
cses_IMD_cb3[0][matches]

#  "- SEE POLITY NOTES"
# & Flemish (CD&V) - SEE POLITY/ELECTION STUDY 
#  - SEE POLITY/ELECTION STUDY NOTES
# 9999998.  Volunteered: Don't Know - SEE ELECTION STUDY NOTES
# 2500032.  Jose Bove - ran as an activist from "After Globalization"
# 5280040.  Union 55+

# 6160048.  Ogólnopolska Koalicja Obywatelska (OKO)
# 6160077.  „Niezalezna i bezpartyjna”
# 6430032.  All-Russian Social-Political Movement “Spiritual Heritage”
# COME ON!!!

# 0080001.  Socialist Party (PS)


# notepad++ search matches ... but only when the name_char string is removed ... confusing!
# Out:
# 288                        0080001.  Socialist Party (PS)
# 289                       0080002.  Democratic Party (PD)
# 290     0080003.  Socialist Movement for Integration (...
# 291                       0080004.  Republican Party (PR)
# 292               0080005.  Social Democratic Party (PSD)
#                               ...
# 3324                        8580002.  National Party (PN)
# 3325                             8580003.  Colorado Party
# 3326                     8580004.  Independent Party (PI)
# 3327                           8580005.  Popular Assembly
# 3328                                8580006.  Civic Union
# Name: 0, Length: 1810, dtype: object

# %%
## IMD LEADER REFERENCES ARE IN ANOTHER DOCUMENT!

# %%
## Modules 1-4 do contain party/leader references ... but it's all a bit ad hoc/variable format!

# %%
mod_5_parties = [x for x in sorted( CSES_int_5[party_content_vars].stack().unique() ) if x[0:4]!="9999"]

# %%
len(mod_5_parties)

## hmm - quite a lot - only ~100 parties listed A-I / with marpor references

# 8 of these maybe due to differences in alphanumeric

# ~19 parties per election study

# you can make a case that only the first 150 matter because only they have a reference sample size >50
# Out:
# 405

# %%
len(np.unique([int(x[0:6]) for x in sorted( CSES_int_5[party_content_vars].stack().unique() ) if x[0:4]!="9999"]))
# Out:
# 397

# %%
CSES_int_5[party_content_vars].stack().value_counts()[150:].head(50)
# Out:
# 410004. KOR - Justice Party                                                                   1238
# 499008. MNE - Albanians Decisively                                                            1235
# 348007. HUN - Hungarian Two-tailed Dog Party                                                  1227
# 499009. MNE - Croatian Civic Initiative                                                       1223
# 348008. HUN - Together                                                                        1222
# 344003. HKG - Democratic Party                                                                1221
# 792005. TUR - Good Party                                                                      1218
# 344002. HKG - Civic Party                                                                     1211
# 300005. GRC - Communist Party of Greece                                                       1201
# 300004. GRC - Democratic Coalition – PASOK-DIMAR                                              1188
# 344001. HKG - Democratic Alliance for the Betterment and Progress of Hong Kong                1176
# 410005. KOR - Democratic United Party                                                         1162
# 300007. GRC - Independent Greeks - National Patriotic Alliance                                1157
# 300008. GRC - Union of Centrists                                                              1150
# 999989. INDEPENDENT CANDIDATE                                                                 1133
# 300003. GRC - Popular Association - Golden Dawn                                               1117
# 372007. IRL - Green Party                                                                     1111
# 344005. HKG - New People's Party                                                              1101
# 372006. IRL - Social Democrats                                                                1098
# 792006. TUR - Felicity Party                                                                  1087
# 344014. HKG - Labour Party                                                                    1075
# 344004. HKG - Hong Kong Federation of Trade Unions                                            1057
# 372008. IRL - Renua Ireland                                                                   1025
# 372005. IRL - Anti-Austerity Alliance - People Before Profit                                  1021
# 344015. HKG - ALLinHKG                                                                        1020
# 344009. HKG - Civic Passion - Proletariat Political Institute – Hong Kong Resurgence Order    1020
# 344006. HKG - People Power – League of Social Democrats                                       1020
# 999992. OTHER CANDIDATE/PARTY (NOT FURTHER SPECIFIED)                                          963
# 999992. OTHER PARTY/CANDIDATE (NOT FURTHER SPECIFIED)                                          415
# 499026. MNE - Coalition 'For a European Montenegro'                                            388
# 076011. BRA - Democratic Labour Party - PDT                                                    262
# 348010. HUN - Unity                                                                            261
# 999988. NONE OF THE CANDIDATES/PARTIES                                                         171
# 840003. USA - Libertarian Party                                                                117
# 250015. FRA - Left Front                                                                       114
# 152011. CHL - Progressive Party                                                                112
# 250012. FRA - Democratic Movement                                                               97
# 076012. BRA - Socialism and Liberty Party - PSOL                                                91
# 380007. ITA - Us with Italy - Christian Democratic Union                                        91
# 499019. MNE - Socialist Peoples Party of Montenegro                                             88
# 076013. BRA - New Party - NOVO                                                                  70
# 076010. BRA - Democrats - DEM                                                                   69
# 300016. GRC - Panhellenic Socialist Movement (PASOK)                                            54
# 276010. DEU - The Party                                                                         51
# 076020. BRA - Green Party - PV                                                                  50
# 152089. CHL - Jose Antonio Kast (Independent)                                                   49
# 076022. BRA - Patriota - PATRI                                                                  49
# 276013. DEU - Pirates Party                                                                     49
# 380009. ITA - Popular Civic List                                                                47
# 344007. HKG - People Power                                                                      46
# dtype: int64

# %%
# ^\d{7}\.\s+[A-Za-z\s\-\'\!\./0-9,\+&":]+(\([A-Za-z\s\-\'\!\./0-9,\+&":]+\))?

# %%
### Woah Mod 5 doesn't appear to use the same party numbering system as IMD!

# doesn't even use the same number of digits!

# Good thing I noticed this ... now!

# %%
# CSES_int_5 = pd.read_pickle(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"CSES_int_5.pkl")

category_cols = list(CSES_int.select_dtypes('category').columns)
category_cols.append( "IMD1008_MOD_5" )
# category_cols
CSES_int_5[category_cols] = CSES_int_5[category_cols].astype('category').apply(lambda x: x.cat.as_ordered())
CSES_int_final = CSES_int.append(CSES_int_5)
CSES_int_final["IMD1008_MOD_5"] = CSES_int_final["IMD1008_MOD_5"].astype('category').cat.set_categories(CSES_int_5["IMD1008_MOD_5"].cat.categories).fillna("00. NOT IN CSES MODULE 5")

# %%
CSES_int_final = CSES_int_final.reset_index().rename(columns={"index":"original_index"})

replace_dict= {"9997. VOLUNTEERED: REFUSED":"9997. REFUSED",
 "9998. VOLUNTEERED: DON'T KNOW":"9998. DON'T KNOW",}
CSES_int_final["IMD2001_1"] = CSES_int_final["IMD2001_1"].replace(replace_dict)
#
replace_dict = {'9997. VOLUNTEERED: REFUSED':'9997. REFUSED',
                "9998. VOLUNTEERED: DON'T KNOW":"9998. DON'T KNOW"}
CSES_int_final["IMD2001_2"] = CSES_int_final["IMD2001_2"]\
                                  .replace(replace_dict).astype('category').cat.set_categories(CSES_int["IMD2001_2"].cat.categories,
                                  ordered=True)
#
replace_dict = {'97. NOT APPLICABLE':'97.00 NOT APPLICABLE'}

CSES_int_final["IMD5022_2"] = CSES_int_final["IMD5022_2"].replace(replace_dict)
CSES_int_final["IMD5022_3"] = CSES_int_final["IMD5022_3"].replace(replace_dict)
CSES_int_final["IMD5022_4"] = CSES_int_final["IMD5022_4"].replace(replace_dict)

# %%
CSES_int_final.to_pickle(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"CSES_int_final.pkl")
CSES_int_5.to_pickle(dataset_folder + "CSES"+os.sep+"Integration"+os.sep+"CSES_int_5.pkl")

# %%
# CSES_int_final.dtypes.value_counts()

# %%
# CSES_int_5.dtypes.value_counts()

# %%
# CSES_int.dtypes.value_counts()
