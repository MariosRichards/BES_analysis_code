# %%
dataset_name = "W14_comb"
df_list = ["BES_Panel","BES_reduced_with_na"]#,"BESnumeric"]

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import pickle, os, gc, re

from IPython.display import display

import Jupyter_module_loader
from utility import *

# you should clone this git to a subdirectory called 'BES_analysis_code' (in some directory - I call it BES_analysis - doesn't matter though)
# %matplotlib inline
encoding = "ISO-8859-1"

(BES_code_folder, BES_small_data_files, BES_data_folder,
 BES_output_folder, BES_file_manifest, BES_R_data_files) = setup_directories()


global BES_Panel, BES_numeric, BES_reduced, BES_reduced_with_na, BES_non_numeric
data_subfolder = BES_data_folder + dataset_name + os.sep

(manifest, dataset_filename, dataset_description, dataset_citation,
 dataset_start, dataset_stop, dataset_wave) = get_manifest(dataset_name, BES_file_manifest)

for df in df_list:
    if df=="BES_Panel":
        globals()[df]  = pd.read_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))

    else:
        globals()[df]  = pd.read_msgpack(data_subfolder + df + '.msgpack' )
        globals()[df].replace(-1,np.nan,inplace=True)

(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)
# Out:
# var_type (5692, 13)

# %%
memory_use(locs = locals().items())
# Out:
#            BES_reduced_with_na:   1.9GiB
#                      BES_Panel: 506.4MiB
#                       var_type:   4.3MiB
#              new_old_col_names: 288.1KiB
#                 cat_dictionary: 144.1KiB
#              old_new_col_names: 144.1KiB
#              BES_file_manifest:  42.4KiB
#                       manifest:   1.7KiB
#                             _i:   1.2KiB
#                            _i2:   1.2KiB

# %%
max_wave, num_to_wave, num_to_weight, weights = get_weights(dataset_name,BES_Panel)

# %%
def get_all_weights(mask):

    wts = BES_Panel[list(num_to_weight.values())][mask]
    # wts.hist(bins=100,figsize=(16,12));

    wts = wts/wts.mean()
    # wts.mean(axis=1).hist(bins=100,figsize=(16,12));
    # # wts = wts/wts.mean(axis=1)
    wts = wts.mean(axis=1)
    wts =wts/wts.mean()
    return wts
# wts

# %%
treatment = "Housing Tenure by EuRef2016 Vote"
output_subfolder = create_subdir(BES_output_folder, treatment)
# Out:
# Warning, filename truncated because it was over 30. Filenames may no longer be unique

# %%
mask = BES_Panel["profile_eurefvote"].notnull()&BES_Panel["profile_house_tenure"].notnull()
ct = pd.crosstab( BES_Panel["profile_eurefvote"], BES_Panel["profile_house_tenure"],
                  values= get_all_weights(mask), aggfunc=sum, normalize='columns')*100

# %%
sorted_labels = list(BES_Panel["profile_house_tenure"].value_counts().index)

# %%
import textwrap 
  
wrapper = textwrap.TextWrapper(width=15) 

stacked = ct.stack().reset_index().rename(columns={0:'%'})
fig = plt.figure(figsize=(20, 8))
ax = fig.subplots()

sns.barplot(x=stacked["profile_house_tenure"],
            y=stacked['%'],
            hue=stacked["profile_eurefvote"],
            ax=ax, order = sorted_labels, ci=.95);
# plt.xticks(rotation=90);
# ax = plt.gca()

# labels = stacked["profile_house_tenure"].cat.categories
title = "Housing Tenure by euRefVote"
plt.title(title)
ax.set_xticklabels([ wrapper.fill(text=x) for x in sorted_labels], rotation=0, fontsize=14);

ax.annotate(dataset_citation, (0,0), (0, -140),
                 xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 7) ;           
fname = output_subfolder + title.replace(" ","_") + ".png"
fig.savefig( fname, bbox_inches='tight' )

# %%
amalgamated_age = amalgamate_waves(BES_Panel, 'age(W\d+)')
amalgamated_age.notnull().sum()
# Out:
# Amalgamating variables:
# {1: 'ageW1', 7: 'ageW7', 8: 'ageW8', 9: 'ageW9', 11: 'ageW11', 12: 'ageW12', 13: 'ageW13', 14: 'ageW14'}
# 67193

# %%
amalgamated_age_group = pd.cut(amalgamated_age,[0,18,26,36,46,56,66,200], right=False, labels=BES_Panel['ageGroup'].cat.categories)
amalgamated_age_group.name = "ageGroup"

# %%
import textwrap 
  
wrapper = textwrap.TextWrapper(width=15)

for age_gp in amalgamated_age_group.cat.categories:
    
    mask = BES_Panel["profile_eurefvote"].notnull()&BES_Panel["profile_house_tenure"].notnull()
    mask = mask & (amalgamated_age_group==age_gp)
    ct = pd.crosstab( BES_Panel["profile_eurefvote"], BES_Panel["profile_house_tenure"],
                      values= get_all_weights(mask), aggfunc=sum, normalize='columns')*100

    sorted_labels = list(BES_Panel["profile_house_tenure"].value_counts().index)

    stacked = ct.stack().reset_index().rename(columns={0:'%'})
    fig = plt.figure(figsize=(20, 8))
    ax = fig.subplots()

    sns.barplot(hue=stacked[ct.index.name],
                y=stacked['%'],
                x=stacked[ct.columns.name],
                ax=ax, order = sorted_labels, ci=95);

    title = "euRefVote by House Tenure" + "("+age_gp+")"
    plt.title(title)
    ax.set_xticklabels([ wrapper.fill(text=x) for x in sorted_labels], rotation=0, fontsize=14);

    ax.annotate(dataset_citation, (0,0), (0, -60),
                     xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 7) ;           
    fname = output_subfolder + title.replace(" ","_") + ".png"
    fig.savefig( fname, bbox_inches='tight' )

# %%
########### Why is it so hard to added weighted error bars!!!!

# %%
mask = BES_Panel["profile_eurefvote"].notnull()&BES_Panel["profile_house_tenure"].notnull()
ct = pd.crosstab( BES_Panel["profile_eurefvote"], BES_Panel["profile_house_tenure"],
                  values= get_all_weights(mask), aggfunc=sum, normalize='all')*100

# %%
ct
# Out:
# profile_house_tenure   Own outright  Own with a mortgage  \
# profile_eurefvote
# Stay/remain in the EU     14.008963            15.723650
# Leave the EU              18.647171            14.228679
# Don't know                 0.190769             0.244261
#
# profile_house_tenure   Own (part-own) through shared ownership scheme (i.e. pay part mortgage, part rent)  \
# profile_eurefvote
# Stay/remain in the EU                                           0.510200
# Leave the EU                                                    0.341292
# Don't know                                                      0.004620
#
# profile_house_tenure   Rent from a private landlord  \
# profile_eurefvote
# Stay/remain in the EU                      8.312696
# Leave the EU                               5.196351
# Don't know                                 0.083100
#
# profile_house_tenure   Rent from my local authority  \
# profile_eurefvote
# Stay/remain in the EU                      1.842857
# ...

# %%
BES_Panel["weighted_focal_var"]
# Out:
# 0        <zip object at 0x000000002A1B86C8>
# 1        <zip object at 0x000000002A1B86C8>
# 2        <zip object at 0x000000002A1B86C8>
# 3        <zip object at 0x000000002A1B86C8>
# 4        <zip object at 0x000000002A1B86C8>
# 5        <zip object at 0x000000002A1B86C8>
# 6        <zip object at 0x000000002A1B86C8>
# 7        <zip object at 0x000000002A1B86C8>
# 8        <zip object at 0x000000002A1B86C8>
# 9        <zip object at 0x000000002A1B86C8>
# 10       <zip object at 0x000000002A1B86C8>
# 11       <zip object at 0x000000002A1B86C8>
# 12       <zip object at 0x000000002A1B86C8>
# 13       <zip object at 0x000000002A1B86C8>
# 14       <zip object at 0x000000002A1B86C8>
# 15       <zip object at 0x000000002A1B86C8>
# 16       <zip object at 0x000000002A1B86C8>
# 17       <zip object at 0x000000002A1B86C8>
# 18       <zip object at 0x000000002A1B86C8>
# 19       <zip object at 0x000000002A1B86C8>
# 20       <zip object at 0x000000002A1B86C8>
# ...

# %%
weighted_focal_var = list(zip(focal_var[mask], get_all_weights(mask)))
# BES_Panel[["weighted_focal_var"]] = zip_list
# BES_Panel["weighted_focal_var"]
# BES_Panel[["weighted_focal_var"]].apply(lambda x: list(x))

# %%
zip_obj = BES_Panel[["weighted_focal_var"]].loc[0].values[0]

# %%
 [ii for ii in zip(*zip_obj)]
# Out:
# []

# %%
mask = BES_Panel["profile_eurefvote"].notnull()&BES_Panel["profile_house_tenure"].notnull()
ct = pd.crosstab( BES_Panel["profile_eurefvote"], BES_Panel["profile_house_tenure"],
                  values= get_all_weights(mask), aggfunc=sum, normalize='columns')*100

# %%
sorted_labels = list(BES_Panel["profile_house_tenure"].value_counts().index)

# %%
focal_var = BES_Panel["profile_eurefvote"]
mask = focal_var.notnull()&BES_Panel["profile_house_tenure"].notnull()
weighted_focal_var = zip(focal_var[mask], get_all_weights(mask))

# %%
weighted_focal_var
# Out:
# [('Leave the EU', 1.033217262996091),
#  ('Leave the EU', 0.7548818973284888),
#  ('Leave the EU', 2.2389512161545095),
#  ('Leave the EU', 0.6779975036498159),
#  ('Stay/remain in the EU', 0.7053520107653732),
#  ('Leave the EU', 0.6774128281168736),
#  ('Stay/remain in the EU', 0.4795900950935547),
#  ('Stay/remain in the EU', 0.7664421518919884),
#  ('Leave the EU', 1.1689044930597865),
#  ('Leave the EU', 0.9344095744908052),
#  ('Leave the EU', 0.782463346812219),
#  ('Leave the EU', 1.5446524078728452),
#  ('Stay/remain in the EU', 0.7127067406204916),
#  ('Stay/remain in the EU', 0.377760520333464),
#  ('Stay/remain in the EU', 1.8445612230286572),
#  ('Leave the EU', 0.30427439912065685),
#  ('Stay/remain in the EU', 0.6863649332620345),
#  ('Leave the EU', 0.5445994640508395),
#  ('Stay/remain in the EU', 1.1715372288284185),
#  ('Leave the EU', 0.8128522555419466),
#  ('Stay/remain in the EU', 0.8034930755888404),
#  ('Stay/remain in the EU', 0.7397115963119805),
# ...

# %%
def weighted_mean(x, **kws):
    val, weight = zip(*x[0])
#     val, weight = map(np.asarray, zip(*x))
    print(val, weight)
    return weight

# %%
weighted_focal_var = list(zip(focal_var[mask], get_all_weights(mask)))

import textwrap 
  
wrapper = textwrap.TextWrapper(width=15) 

# stacked = ct.stack().reset_index().rename(columns={0:'%'})
fig = plt.figure(figsize=(20, 8))
ax = fig.subplots()

sns.barplot(x = BES_Panel["profile_house_tenure"][mask],
            y = weighted_focal_var,
#             hue = BES_Panel["profile_eurefvote"],
            ax = ax, 
            estimator = weighted_mean, orient="v");

# plt.xticks(rotation=90);
# ax = plt.gca()

# labels = stacked["profile_house_tenure"].cat.categories
title = "Housing Tenure by euRefVote"
plt.title(title)
ax.set_xticklabels([ wrapper.fill(text=x) for x in sorted_labels], rotation=0, fontsize=14);

ax.annotate(dataset_citation, (0,0), (0, -140),
                 xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 7) ;           
fname = output_subfolder + title.replace(" ","_") + ".png"
# fig.savefig( fname, bbox_inches='tight' )
# Out:
# ('Leave the EU', 1.033217262996091)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-144-b0f88e6cf8f5> in <module>
#      13 #             hue = BES_Panel["profile_eurefvote"],
#      14             ax = ax,
# ---> 15             estimator = weighted_mean, orient="v");
#      16
#      17 # plt.xticks(rotation=90);
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ...

# %%
tips = sns.load_dataset("tips")
tips["weight"] = 10 * np.random.rand(len(tips))

tips["tip_and_weight"] = list(zip(tips.tip, tips.weight))

def weighted_mean(x, **kws):
    val, weight = map(np.asarray, zip(*x))
    return (val * weight).sum() / weight.sum()

g = sns.catplot("size", "tip_and_weight", data=tips,
                   estimator=weighted_mean, orient="v", kind='point')
g.set_axis_labels("size", "tip");

# %%
#################################

# %%
# Out:
# ['Own outright',
#  'Own with a mortgage',
#  'Rent from a private landlord',
#  'Rent from a housing association',
#  'Rent from my local authority',
#  'Neither I live rent-free with my parents, family or friends']

# %%
house_ten
# Out:
# 0                                             Own outright
# 1                                             Own outright
# 2                                             Own outright
# 3                                      Own with a mortgage
# 4                                             Own outright
# 5                                             Own outright
# 6                                             Own outright
# 7                                             Own outright
# 8                                             Own outright
# 9                                             Own outright
# 10                                            Own outright
# 11                                            Own outright
# 12                            Rent from a private landlord
# 13                                            Own outright
# 14                                     Own with a mortgage
# 15                                            Own outright
# ...

# %%
amalgamated_age = amalgamate_waves(BES_Panel, 'age(W\d+)')
mask = BES_Panel["profile_eurefvote"].notnull()&BES_Panel["profile_house_tenure"].notnull()&amalgamated_age.notnull()
# ct = pd.crosstab( BES_Panel["profile_eurefvote"], BES_Panel["profile_house_tenure"],
#                   values= get_all_weights(mask), aggfunc=sum, normalize='columns')*100

# %%
# BES_Panel["profile_eurefvote"][mask].value_counts()
sorted_labels = list(BES_Panel["profile_house_tenure"].value_counts().index)
house_ten = BES_Panel["profile_house_tenure"].cat.reorder_categories(sorted_labels)
remove_last =3

house_ten = house_ten.apply(lambda x: x if x not in sorted_labels[-1-remove_last:-1] else np.nan)
house_ten = house_ten.astype('category', ordered=True, categories = sorted_labels[:-1-remove_last])
house_ten.value_counts()
# Out:
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: specifying 'categories' or 'ordered' in .astype() is deprecated; pass a CategoricalDtype instead
#   import sys
# Own outright                       18753
# Own with a mortgage                15936
# Rent from a private landlord        8431
# Rent from a housing association     3328
# Rent from my local authority        3143
# Name: profile_house_tenure, dtype: int64

# %%
clean_filename(fname)
# Out:
# Warning, filename truncated because it was over 30. Filenames may no longer be unique
# '..BES_analysis_outputHousing_T'

# %%
Leave = BES_Panel["profile_eurefvote"]
Leave = Leave.replace("Don't know", np.nan)
Leave_not_null = Leave.notnull()
Leave = (Leave == "Leave the EU").astype('float')

amalgamated_age_group = pd.cut(amalgamated_age,[0,18,26,36,46,56,66,200], right=False, labels=BES_Panel['ageGroup'].cat.categories)
amalgamated_age_group.name = "ageGroup"
amalgamated_age_group = amalgamated_age_group.replace("Under 18", np.nan)

# house_ten = BES_Panel["profile_house_tenure"].cat.reorder_categories(sorted_labels)

mask = Leave_not_null&house_ten.notnull()&amalgamated_age_group.notnull()
fig = plt.figure(figsize = (16,12))
g = sns.lineplot(y = Leave[mask],
             x=amalgamated_age_group[mask].cat.codes,
             estimator = 'mean',ci=95,
             hue=house_ten[mask]);

g.set_xticklabels(amalgamated_age_group[mask].cat.categories);
plt.ylabel("Leave%")
plt.xlabel("Age Group")
title = "House Tenure (common types) by Leave % (DKs dropped) with 95% confidence intervals"
plt.title(title);
fname = output_subfolder + clean_filename(title) + ".png"
fig.savefig( fname, bbox_inches='tight' )
# Out:
# Warning, filename truncated because it was over 30. Filenames may no longer be unique

# %%
mask = (Leave ==1.0)&BES_Panel["profile_house_tenure"].notnull()&amalgamated_age.notnull()

temp = pd.DataFrame(pd.concat([BES_Panel["profile_house_tenure"][mask],
                              amalgamated_age[mask].astype('float')[mask]],axis=1))
# temp
g = sns.FacetGrid(data = temp, col='profile_house_tenure', col_wrap=3)
g = g.map(sns.kdeplot, 'ageW1&7&8&9&11&12&13&14', )
# Out:
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
