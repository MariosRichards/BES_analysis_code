# %%
dataset_name = "W14_comb"
df_list = [
           "BES_Panel",
           "BES_reduced_with_na",
           "BES_reduced",
#            "BESnumeric"
          ]

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import pickle, os, gc, re

from IPython.display import display

import Jupyter_module_loader
from utility import display_components, display_pca_data, weighted_kde, setup_directories,\
                    get_manifest, get_small_files, clean_filename, create_subdir, amalgamate_waves

# %%
# you should clone this git to a subdirectory called 'BES_analysis_code' (in some directory - I call it BES_analysis - doesn't matter though)
# %matplotlib inline
encoding = "ISO-8859-1"

(BES_code_folder, BES_small_data_files, BES_data_folder,
 BES_output_folder, BES_file_manifest, BES_R_data_files) = setup_directories()

# %%
# %%time
global BES_Panel, BES_numeric, BES_reduced, BES_reduced_with_na, BES_non_numeric
data_subfolder = BES_data_folder + dataset_name + os.sep

(manifest, dataset_filename, dataset_description, dataset_citation,
 dataset_start, dataset_stop, dataset_wave) = get_manifest(dataset_name, BES_file_manifest)

# dataset_filename = "BES2015_W8_v1.6.dta"

for df in df_list:
    if df=="BES_Panel":
        globals()[df]  = pd.read_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))
#     elif df=="BES_reduced_with_na":
#         globals()[df] = pd.read_msgpack(data_subfolder + "BES_reduced" + '.msgpack')
#         nans = pd.read_msgpack(data_subfolder + "nans" + '.msgpack')
#         globals()[df][nans] = np.nan
# #         globals()[df] = temp[nans]
#         del nans
    else:
        globals()[df]  = pd.read_msgpack(data_subfolder + df + '.msgpack' )
        globals()[df].replace(-1,np.nan,inplace=True)
#         globals()[df] = globals()[df].apply(pd.to_numeric,downcast='integer')
    print(df+":")
    globals()[df].info(memory_usage='deep')    
(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)
# Out:
# BES_Panel:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73703 entries, 0 to 73702
# Columns: 5692 entries, id to small_mii_catW10
# dtypes: category(5483), datetime64[ns](31), float32(4), float64(154), int8(18), object(2)
# memory usage: 506.4 MB
# BES_reduced_with_na:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73703 entries, 0 to 73702
# Columns: 6864 entries, ageW1 to partyContactConW12_Yes
# dtypes: float32(6864)
# memory usage: 1.9 GB
# BES_reduced:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73703 entries, 0 to 73702
# Columns: 7810 entries, ageW1 to partyContactConW12_Yes
# dtypes: float32(4), int32(8), int8(7791), uint16(7)
# memory usage: 552.5 MB
# var_type (5692, 13)

# %%
# %%time
# # Create correlation matrix
# corr_matrix = np.corrcoef(BES_reduced_with_na, rowvar=False)

# %%
# %%time
# masked_df = np.ma.masked_array(BES_reduced_with_na.values,np.isnan(BES_reduced_with_na.values))

# %%
# %%time
# corr_matrix = np.ma.corrcoef(masked_df, rowvar=False)

# %%
# corr_matrix

# %%
# [x for x in BES_Panel.columns if "wt" in x]

# %%
# BES_Panel[['euMIISmallW7', 'euMIISmallW8']].notnull().sum()

# %%
# BES_Panel['profile_eurefvote']

# %%
Leavers   = (BES_Panel['profile_eurefvote'] == "Leave the EU")
Remainers = (BES_Panel['profile_eurefvote'] == "Stay/remain in the EU")

# %%
# first look at crosstabs (e.g. likely transitions to get a sense of similarity!)

# then backfill to get largest of amalgamated data

pd.crosstab( BES_Panel['euMIISmallW7'], BES_Panel['euMIISmallW8'],
             values= BES_Panel['wt_new_W8'], aggfunc=sum, normalize='index')*100
# BES_Panel[['euMIISmallW7', 'euMIISmallW8']]
# Out:
# euMIISmallW8                            Immigration    Economy  \
# euMIISmallW7
# Immigration                               61.431339   5.713422
# Economy                                    6.666552  56.016658
# Foreign policy                             8.483874  21.248095
# British/english identity                  20.537066   7.965131
# Protection of rights                       5.260416  12.574065
# Sovereignty/EU bureaucracy                19.087384   3.645401
# Cosmopolitanism                            3.940653  17.107753
# Campaign/outcome fairness                 12.110814  15.830555
# Social identity/partisanship               8.658129   8.995642
# EU integration/stability                  13.934004  14.263788
# Family                                    10.835854  14.852326
# EU spending/regulations/cost              17.271873  14.040799
# Other stability or uncertainty concern     8.103738  29.552987
# No content to reason                       9.649327  16.899385
# Other                                     10.778097  13.380533
#
# euMIISmallW8                            Foreign policy  \
# euMIISmallW7
# Immigration                                   1.779228
# Economy                                       4.903982
# Foreign policy                               29.435540
# British/english identity                      1.801518
# Protection of rights                          4.075210
# Sovereignty/EU bureaucracy                    1.343851
# Cosmopolitanism                               9.312934
# Campaign/outcome fairness                     1.984768
# Social identity/partisanship                  2.763979
# EU integration/stability                      4.173162
# Family                                        3.970601
# EU spending/regulations/cost                  1.249279
# Other stability or uncertainty concern        6.761770
# No content to reason                          5.517368
# Other                                         5.152881
#
# euMIISmallW8                            British/english identity  \
# euMIISmallW7
# Immigration                                             1.773648
# Economy                                                 0.485648
# Foreign policy                                          0.488698
# British/english identity                               17.561137
# Protection of rights                                    0.096128
# Sovereignty/EU bureaucracy                              4.104262
# Cosmopolitanism                                         0.659280
# Campaign/outcome fairness                               1.522633
# Social identity/partisanship                            0.000000
# EU integration/stability                                2.951912
# Family                                                  2.746910
# EU spending/regulations/cost                            1.356370
# Other stability or uncertainty concern                  0.486835
# No content to reason                                    2.515413
# Other                                                   4.477449
#
# euMIISmallW8                            Protection of rights  \
# euMIISmallW7
# Immigration                                         0.388606
# Economy                                             1.716877
# Foreign policy                                      3.428666
# British/english identity                            0.176865
# Protection of rights                               48.274757
# Sovereignty/EU bureaucracy                          1.029638
# Cosmopolitanism                                     4.409815
# Campaign/outcome fairness                           1.016305
# Social identity/partisanship                        7.077860
# EU integration/stability                            0.401633
# Family                                              1.426697
# EU spending/regulations/cost                        1.413941
# Other stability or uncertainty concern              1.957944
# No content to reason                                1.809293
# Other                                               4.531540
#
# euMIISmallW8                            Sovereignty/EU bureaucracy  \
# euMIISmallW7
# Immigration                                              14.214792
# Economy                                                   4.437089
# Foreign policy                                            3.150061
# British/english identity                                 30.880536
# Protection of rights                                      5.045229
# Sovereignty/EU bureaucracy                               55.582104
# Cosmopolitanism                                           3.860054
# Campaign/outcome fairness                                12.690503
# Social identity/partisanship                              7.343940
# EU integration/stability                                 30.436091
# Family                                                    4.780380
# EU spending/regulations/cost                             22.137708
# Other stability or uncertainty concern                    7.206160
# No content to reason                                     11.667176
# Other                                                     8.711260
#
# euMIISmallW8                            Cosmopolitanism  \
# euMIISmallW7
# Immigration                                    0.834362
# Economy                                        4.085101
# Foreign policy                                10.559450
# British/english identity                       0.000000
# Protection of rights                           7.473442
# Sovereignty/EU bureaucracy                     0.666056
# Cosmopolitanism                               38.936358
# Campaign/outcome fairness                      2.413201
# Social identity/partisanship                  16.742063
# EU integration/stability                       5.017944
# Family                                         1.857972
# EU spending/regulations/cost                   0.824918
# Other stability or uncertainty concern         6.168458
# No content to reason                           7.224739
# Other                                          6.887889
#
# euMIISmallW8                            Campaign/outcome fairness  \
# euMIISmallW7
# Immigration                                              2.996039
# Economy                                                  4.823852
# Foreign policy                                           3.539296
# British/english identity                                 5.137121
# Protection of rights                                     3.328142
# Sovereignty/EU bureaucracy                               4.283864
# Cosmopolitanism                                          2.418263
# Campaign/outcome fairness                               33.448245
# Social identity/partisanship                             8.189945
# EU integration/stability                                 4.121205
# Family                                                   2.305976
# EU spending/regulations/cost                             5.269275
# Other stability or uncertainty concern                   5.138718
# No content to reason                                     5.621028
# Other                                                    8.232860
#
# euMIISmallW8                            Social identity/partisanship  \
# euMIISmallW7
# Immigration                                                 0.343111
# Economy                                                     0.991798
# Foreign policy                                              1.566595
# British/english identity                                    0.896306
# Protection of rights                                        5.469932
# Sovereignty/EU bureaucracy                                  0.734497
# Cosmopolitanism                                             2.829760
# Campaign/outcome fairness                                   1.279695
# Social identity/partisanship                               21.587349
# EU integration/stability                                    0.609660
# Family                                                      0.177883
# EU spending/regulations/cost                                0.825294
# Other stability or uncertainty concern                      1.565004
# No content to reason                                        0.882938
# Other                                                       1.888435
#
# euMIISmallW8                            EU integration/stability     Family  \
# euMIISmallW7
# Immigration                                             0.835652   0.671053
# Economy                                                 0.408759   1.269811
# Foreign policy                                          0.864518   1.313806
# British/english identity                                0.276078   0.264428
# Protection of rights                                    0.000000   0.265294
# Sovereignty/EU bureaucracy                              0.605260   0.453932
# Cosmopolitanism                                         1.007561   1.270858
# Campaign/outcome fairness                               1.333661   1.370322
# Social identity/partisanship                            0.705078   0.500491
# EU integration/stability                                8.665936   0.000000
# Family                                                  0.450948  40.140357
# EU spending/regulations/cost                            0.437042   0.100115
# Other stability or uncertainty concern                  0.111352   2.960782
# No content to reason                                    0.929433   3.550695
# Other                                                   1.673583   3.134643
#
# euMIISmallW8                            EU spending/regulations/cost  \
# euMIISmallW7
# Immigration                                                 2.741537
# Economy                                                     2.115552
# Foreign policy                                              1.771682
# British/english identity                                    2.811820
# Protection of rights                                        1.125218
# Sovereignty/EU bureaucracy                                  2.390259
# Cosmopolitanism                                             0.507982
# Campaign/outcome fairness                                   1.611524
# Social identity/partisanship                                1.860229
# EU integration/stability                                    2.534035
# Family                                                      1.112655
# EU spending/regulations/cost                               24.013143
# Other stability or uncertainty concern                      2.466431
# No content to reason                                        2.359363
# Other                                                       3.417204
#
# euMIISmallW8                            Other stability or uncertainty concern  \
# euMIISmallW7
# Immigration                                                           0.247115
# Economy                                                               2.424199
# Foreign policy                                                        2.830825
# British/english identity                                              0.224921
# Protection of rights                                                  1.350183
# Sovereignty/EU bureaucracy                                            0.363589
# Cosmopolitanism                                                       1.968261
# Campaign/outcome fairness                                             1.899817
# Social identity/partisanship                                          5.134208
# EU integration/stability                                              3.024715
# Family                                                                3.416790
# EU spending/regulations/cost                                          2.747400
# Other stability or uncertainty concern                               10.991752
# No content to reason                                                  2.312895
# Other                                                                 2.074832
#
# euMIISmallW8                            No content to reason      Other
# euMIISmallW7
# Immigration                                         3.103641   2.926455
# Economy                                             5.968390   3.685730
# Foreign policy                                      5.666201   5.652693
# British/english identity                            7.902947   3.564128
# Protection of rights                                2.440380   3.221604
# Sovereignty/EU bureaucracy                          2.950822   2.759082
# Cosmopolitanism                                     6.115144   5.655324
# Campaign/outcome fairness                           7.195745   4.292211
# Social identity/partisanship                        4.559479   5.881607
# EU integration/stability                            6.977143   2.888772
# Family                                              4.474156   7.450494
# EU spending/regulations/cost                        3.871422   4.441421
# Other stability or uncertainty concern             10.727206   5.800862
# No content to reason                               22.870557   6.190387
# Other                                               7.034024  18.624770

# %%
pd.crosstab( BES_Panel['euMIISmallW7'][Leavers], BES_Panel['euMIISmallW8'][Leavers],
             values= BES_Panel['wt_new_W8'][Leavers], aggfunc=sum, normalize='index')*100
# Out:
# euMIISmallW8                            Immigration    Economy  \
# euMIISmallW7
# Immigration                               63.589025   3.517500
# Economy                                   20.160781  32.306718
# Foreign policy                            30.246455   6.237425
# British/english identity                  21.007776   2.442215
# Protection of rights                      33.601581   2.793990
# Sovereignty/EU bureaucracy                19.945078   2.044353
# Cosmopolitanism                           29.787627   8.996285
# Campaign/outcome fairness                 19.635921   6.126762
# Social identity/partisanship              24.275060   1.829729
# EU integration/stability                  20.496289   4.174443
# Family                                    21.706019   4.140720
# EU spending/regulations/cost              22.772970   8.733569
# Other stability or uncertainty concern    17.075625   6.775871
# No content to reason                      19.815679  10.346822
# Other                                     13.649824   5.840221
#
# euMIISmallW8                            Foreign policy  \
# euMIISmallW7
# Immigration                                   1.159080
# Economy                                       1.219378
# Foreign policy                               26.226315
# British/english identity                      1.849082
# Protection of rights                          0.000000
# Sovereignty/EU bureaucracy                    0.843178
# Cosmopolitanism                               2.449687
# Campaign/outcome fairness                     0.555287
# Social identity/partisanship                  0.000000
# EU integration/stability                      2.515912
# Family                                        0.000000
# EU spending/regulations/cost                  0.625365
# Other stability or uncertainty concern        4.481906
# No content to reason                          0.441692
# Other                                         6.527119
#
# euMIISmallW8                            British/english identity  \
# euMIISmallW7
# Immigration                                             2.026471
# Economy                                                 1.566749
# Foreign policy                                          0.000000
# British/english identity                               17.996035
# Protection of rights                                    1.060499
# Sovereignty/EU bureaucracy                              4.626464
# Cosmopolitanism                                         4.082299
# Campaign/outcome fairness                               2.745757
# Social identity/partisanship                            0.000000
# EU integration/stability                                3.509945
# Family                                                  1.773037
# EU spending/regulations/cost                            1.973944
# Other stability or uncertainty concern                  0.000000
# No content to reason                                    6.330008
# Other                                                  11.822802
#
# euMIISmallW8                            Protection of rights  \
# euMIISmallW7
# Immigration                                         0.223221
# Economy                                             1.298008
# Foreign policy                                      0.000000
# British/english identity                            0.223863
# Protection of rights                               13.325649
# Sovereignty/EU bureaucracy                          0.569286
# Cosmopolitanism                                     2.378779
# Campaign/outcome fairness                           0.581979
# Social identity/partisanship                        0.000000
# EU integration/stability                            0.000000
# Family                                              0.000000
# EU spending/regulations/cost                        0.826203
# Other stability or uncertainty concern              0.000000
# No content to reason                                0.534327
# Other                                               5.029489
#
# euMIISmallW8                            Sovereignty/EU bureaucracy  \
# euMIISmallW7
# Immigration                                              15.982406
# Economy                                                  17.412683
# Foreign policy                                           13.040689
# British/english identity                                 34.593248
# Protection of rights                                     24.800223
# Sovereignty/EU bureaucracy                               58.811230
# Cosmopolitanism                                          17.964893
# Campaign/outcome fairness                                20.926511
# Social identity/partisanship                             19.868353
# EU integration/stability                                 35.821747
# Family                                                   13.911177
# EU spending/regulations/cost                             27.476329
# Other stability or uncertainty concern                   20.434788
# No content to reason                                     23.561771
# Other                                                    19.304636
#
# euMIISmallW8                            Cosmopolitanism  \
# euMIISmallW7
# Immigration                                    0.550653
# Economy                                        0.437821
# Foreign policy                                 0.705300
# British/english identity                       0.000000
# Protection of rights                           0.000000
# Sovereignty/EU bureaucracy                     0.271720
# Cosmopolitanism                               14.087749
# Campaign/outcome fairness                      0.343110
# Social identity/partisanship                   2.191773
# EU integration/stability                       2.663829
# Family                                         1.427405
# EU spending/regulations/cost                   0.306853
# Other stability or uncertainty concern         0.505165
# No content to reason                           0.000000
# Other                                          1.602456
#
# euMIISmallW8                            Campaign/outcome fairness  \
# euMIISmallW7
# Immigration                                              3.008047
# Economy                                                  6.182565
# Foreign policy                                           7.849595
# British/english identity                                 3.229103
# Protection of rights                                     2.239062
# Sovereignty/EU bureaucracy                               3.614191
# Cosmopolitanism                                          6.340794
# Campaign/outcome fairness                               31.816725
# Social identity/partisanship                            15.178947
# EU integration/stability                                 3.159539
# Family                                                   3.816558
# EU spending/regulations/cost                             5.936826
# Other stability or uncertainty concern                  11.242570
# No content to reason                                     4.205970
# Other                                                    9.021536
#
# euMIISmallW8                            Social identity/partisanship  \
# euMIISmallW7
# Immigration                                                 0.316727
# Economy                                                     0.079811
# Foreign policy                                              0.000000
# British/english identity                                    0.661580
# Protection of rights                                        1.174423
# Sovereignty/EU bureaucracy                                  0.517551
# Cosmopolitanism                                             2.198041
# Campaign/outcome fairness                                   1.443154
# Social identity/partisanship                               19.731383
# EU integration/stability                                    1.019466
# Family                                                      0.000000
# EU spending/regulations/cost                                0.000000
# Other stability or uncertainty concern                      0.000000
# No content to reason                                        0.688412
# Other                                                       1.432490
#
# euMIISmallW8                            EU integration/stability     Family  \
# euMIISmallW7
# Immigration                                             1.022689   0.521369
# Economy                                                 0.716153   1.103296
# Foreign policy                                          3.645661   0.000000
# British/english identity                                0.349439   0.334694
# Protection of rights                                    0.000000   0.000000
# Sovereignty/EU bureaucracy                              0.629696   0.332154
# Cosmopolitanism                                         1.452498   0.000000
# Campaign/outcome fairness                               1.756868   0.913575
# Social identity/partisanship                            0.000000   1.286546
# EU integration/stability                                8.084688   0.000000
# Family                                                  1.375957  38.211135
# EU spending/regulations/cost                            0.143448   0.145698
# Other stability or uncertainty concern                  0.000000   6.249359
# No content to reason                                    0.692341   4.899896
# Other                                                   4.743607   0.298444
#
# euMIISmallW8                            EU spending/regulations/cost  \
# euMIISmallW7
# Immigration                                                 2.712383
# Economy                                                     2.768138
# Foreign policy                                              2.215047
# British/english identity                                    3.558996
# Protection of rights                                        5.027893
# Sovereignty/EU bureaucracy                                  2.549421
# Cosmopolitanism                                             0.000000
# Campaign/outcome fairness                                   2.282441
# Social identity/partisanship                                4.724852
# EU integration/stability                                    4.237384
# Family                                                      0.000000
# EU spending/regulations/cost                               22.158819
# Other stability or uncertainty concern                      8.636872
# No content to reason                                        2.604603
# Other                                                       4.388081
#
# euMIISmallW8                            Other stability or uncertainty concern  \
# euMIISmallW7
# Immigration                                                           0.191171
# Economy                                                               1.857133
# Foreign policy                                                        0.363355
# British/english identity                                              0.284688
# Protection of rights                                                  3.818442
# Sovereignty/EU bureaucracy                                            0.203142
# Cosmopolitanism                                                       7.181679
# Campaign/outcome fairness                                             0.391870
# Social identity/partisanship                                          0.000000
# EU integration/stability                                              0.000000
# Family                                                                3.850854
# EU spending/regulations/cost                                          1.425511
# Other stability or uncertainty concern                                0.000000
# No content to reason                                                  1.592727
# Other                                                                 1.042430
#
# euMIISmallW8                            No content to reason      Other
# euMIISmallW7
# Immigration                                         2.721384   2.457873
# Economy                                             7.119452   5.771316
# Foreign policy                                      5.044031   4.426127
# British/english identity                            9.607076   3.862205
# Protection of rights                                8.611126   3.547112
# Sovereignty/EU bureaucracy                          3.003006   2.039531
# Cosmopolitanism                                     0.000000   3.079670
# Campaign/outcome fairness                           6.863490   3.616550
# Social identity/partisanship                        0.384130  10.529227
# EU integration/stability                            9.486187   4.830571
# Family                                              5.663914   4.123225
# EU spending/regulations/cost                        2.729628   4.744836
# Other stability or uncertainty concern             18.686369   5.911475
# No content to reason                               19.336272   4.949480
# Other                                               5.965001   9.331862

# %%
# ffil
# amalgamated_euMIISmall = BES_Panel[['euMIISmallW7', 'euMIISmallW8']].fillna(method="ffill",axis=1)["euMIISmallW8"]

# %%
amalgamated_euMIISmall = amalgamate_waves(BES_Panel, 'euMIISmallW', forward_fill=True)
    # euref_imm = amalgamate_waves(BES_reduced_with_na,"euRefVoteW",forward_fill=False)
# Out:
# Amalgamating variables:
# {7: 'euMIISmallW7', 8: 'euMIISmallW8'}

# %%
# amalgamated_euMIISmall

# %%
# [x for x in BES_reduced.columns if "sovereig" in x.lower()]

# %%
sovereignty = "Sovereignty/EU bureaucracy"
immigration = "Immigration"
SovOrImmLeavers = Leavers&((amalgamated_euMIISmall == sovereignty) | (amalgamated_euMIISmall == immigration))

Sov = (amalgamated_euMIISmall[SovOrImmLeavers] == sovereignty)
BES_sov = BES_reduced[SovOrImmLeavers]
drop_vars = [x for x in BES_reduced.columns if ("euRefVote" in x) or ("profile_eurefvote" in x)\
             or ("euMII" in x) or ("EUMII" in x)]
BES_sov = BES_sov.drop(drop_vars , axis=1)

# %%
BES_Panel["profile_eurefvote"].value_counts()
# Out:
# Stay/remain in the EU    26047
# Leave the EU             23278
# Don't know                 420
# Name: profile_eurefvote, dtype: int64

# %%
amalgamated_euMIISmall[Leavers].value_counts()
# Out:
# Sovereignty/EU bureaucracy                3933
# Immigration                               3391
# Campaign/outcome fairness                  788
# Economy                                    712
# No content to reason                       548
# EU spending/regulations/cost               455
# British/english identity                   428
# Other                                      400
# Foreign policy                             164
# EU integration/stability                   120
# Family                                     116
# Protection of rights                        97
# Other stability or uncertainty concern      90
# Social identity/partisanship                88
# Cosmopolitanism                             82
# Name: euMIISmallW7&8, dtype: int64

# %%
amalgamated_euMIISmall[Remainers].value_counts()
# Out:
# Economy                                   3717
# Cosmopolitanism                           1190
# Foreign policy                             992
# Protection of rights                       899
# No content to reason                       882
# Campaign/outcome fairness                  778
# Other                                      606
# Immigration                                495
# Other stability or uncertainty concern     449
# Sovereignty/EU bureaucracy                 410
# Social identity/partisanship               330
# Family                                     202
# EU spending/regulations/cost               197
# EU integration/stability                    64
# British/english identity                    34
# Name: euMIISmallW7&8, dtype: int64

# %%
var_vals = BES_sov.var()
# var_vals[var_vals<1].hist(bins=1000);
(var_vals==0).sum()
# Out:
# 111

# %%
def de_collinearise(df):
    # remove zero variance columns
    df = df.drop( df.columns[df.var()==0] , axis=1)
    return df

# %%
df = de_collinearise(BES_sov)
drops = [x for x in BES_reduced_with_na if re.match("small_mii_cat|ns_secW|age|miilabel",x)]
df = df.drop(drops, axis=1, errors ='ignore')

# %%
# %%time
# # Create correlation matrix
# corr_matrix = df.corr().abs()

# %%
# %%time
# Create correlation matrix
corr_matrix = np.corrcoef(df, rowvar=False)
# Out:
# Wall time: 12.7 s

# %%
corr_df = pd.DataFrame(corr_matrix, columns=df.columns, index=df.columns)

# %%
# age_drops = [x for x in BES_reduced_with_na if re.match("age",x)]

# %%
# BES_reduced_with_na[[x for x in BES_reduced_with_na if re.search("mii",x)]].notnull().sum()

# %%
# BES_Panel['miilabel']

# %%
# corr_df['mii_catW6_social care'].sort_values()


# choose *one of*: small_mii_cat, mii_cat
# small_mii_catW5_Immigration                                       0.999384
# mii_catW5_immigration                                             1.000000

# got to choose same thing with age

# and ns_sec/ns_sec_analytic

# choose one of miilabel and mii_cat

# %%
upper = corr_df.where(np.triu(np.ones(corr_df.shape), k=1).astype(np.bool))
high_corr_columns = [column for column in upper.columns if any(upper[column] >= 0.9)]
high_corr_columns
# Out:
# ['dv2w2W2__Should definitely become independent',
#  'likeSturgeonW5__Strongly like',
#  'likeSNPW5__Strongly like',
#  "fbInfo_3W5__Don't follow politics on facebook",
#  'ptvSNPW6__Very likely',
#  'likeSNPW7__Strongly like',
#  'ptvSNPW7__Very likely',
#  'likeSNPW8__Strongly like',
#  'likeSNPW9__Strongly like',
#  'ptvSNPW9__Very likely',
#  'competentFarageW10__A great deal of competence',
#  'likeSNPW10__Strongly like',
#  'likeUKIPW10__Strongly like',
#  'ptvSNPW10__Very likely',
#  'ptvUKIPW10__Very likely',
#  "fbInfo_3W12__Don't follow politics on facebook",
#  'likeSNPW14__Strongly like',
#  'generalElectionVoteUnsqueezeW4_Scottish National Party (SNP)',
#  'generalElectionVoteUnsqueezeW11_Conservative',
#  'generalElectionVoteUnsqueezeW11_Scottish National Party (SNP)',
#  'partyIdW1_Scottish National Party (SNP)',
#  'partyIdW3_Scottish National Party (SNP)',
#  'welshElectionVoteListW1_Conservative',
#  'welshElectionVoteListW1_United Kingdom Independence Party (UKIP)',
#  'welshElectionVoteListW2_United Kingdom Independence Party (UKIP)',
#  'scotElectionVoteListW3_Scottish National Party (SNP)',
#  'welshElectionVoteListW3_Conservative',
#  'ashcroftW4_Scottish National Party (SNP)',
#  'ashcroftW5_Conservative',
#  'ashcroftW5_Scottish National Party (SNP)',
#  'scotElectionVoteListW6_Scottish National Party (SNP)',
#  'scotElectionVoteListW6_Scottish Conservative',
#  'scotElectionVoteListW7_Scottish National Party (SNP)',
#  'londonAssemblyConstituencyW7_The Labour candidate',
#  'londonAssemblyWideW7_Labour',
#  'londonAssemblyWideW7_Conservative',
#  'londonAssemblyConstituencyW8_The Labour candidate',
#  'londonAssemblyWideW8_Labour',
#  'fatherCountryBornW8_East Asia',
#  'polKnowAssadW10_Chancellor of Germany',
#  'gorW3_Scotland',
#  'gorW3_Wales',
#  'gorW3_North West',
#  'gorW3_East Midlands',
#  'gorW6_Scotland',
#  'gorW6_Wales',
#  'gor_Scotland',
#  'gor_Wales',
#  'profile_newspaperW11_Other local daily morning newspaper',
#  'profile_religionW12_Yes - Sikhism',
#  'profile_religionW12_Yes - Brethren',
#  'profile_religionW13_Yes - Sikhism',
#  'profile_religionW13_Yes - Brethren',
#  'profile_work_statW14_Working full time (30 or more hours per week)',
#  'profile_work_statW14_Retired',
#  'profile_work_statW14_Working part time (8-29 hours a week)',
#  'profile_past_vote_2017_Liberal Democrat',
#  'profile_past_vote_2017_United Kingdom Independence Party (UKIP)',
#  'profile_past_vote_2017_Green Party',
#  'profile_past_vote_2017_Plaid Cymru',
#  'profile_past_vote_2015_Scottish National Party (SNP)',
#  'profile_past_vote_2015_Plaid Cymru',
#  'profile_past_vote_2015_British National Party (BNP)',
#  'mii_catW6_social care',
#  'mii_catW3_transport/infrastructure',
#  'mii_catW3_social care',
#  "scotReferendumIntentionW4_Will vote 'Yes'",
#  "scotReferendumIntentionW9_Will vote 'Yes'",
#  "scotReferendumIntentionW6_Will vote 'Yes'",
#  'euIDW13_The leave side',
#  'profile_turnout_2017_Yes',
#  'euIDW11_The leave side',
#  "scotReferendumVoteW3_I voted 'Yes' (Scotland should be an independent country)"]

# %%
df = df.drop(high_corr_columns, axis=1, errors='ignore')

# %%
# %%time
np.linalg.matrix_rank(df)
# Out:
# Wall time: 3min 24s
# 6738

# %%
df.shape
# Out:
# (7324, 7090)

# %%
qr = np.linalg.qr(df)

# %%
df.columns[np.abs(np.sum(qr[1],axis=0))<.5]
# Out:
# Index(['ldToneW5__5 - Focused mainly on putting forward their own policies and personalities',
#        'snpSupportW8__Mainly leave', 'conUnitedW9__Very united',
#        'labUnitedW10__Very united', 'infoSourceInternetW12__More than 2 hours',
#        'bestOnMIIW1_Other party',
#        'countryOfBirth_Other: European Union member country',
#        'generalElectionVoteW2_Scottish National Party (SNP)',
#        'generalElectionVoteW4_Plaid Cymru',
#        'generalElectionVoteSqueezeW4_Liberal Democrat',
#        ...
#        'partyContactLDW3_Yes', 'blameScotUnion_cleggW3_Yes',
#        'referendumContact_3W3_Yes', 'referendumContact_7W2_Yes',
#        'referendumContact_4W2_Yes', 'partyContactLab_6W2_Yes',
#        'conPriorities_costLiveW2_Yes', 'successReduceInequalityDKW12_Yes',
#        'successReduceInequalityLabW12_Yes', 'RV1W2_Female'],
#       dtype='object', length=263)

# %%
df = df.drop(df.columns[np.abs(np.sum(qr[1],axis=0))<.5],axis=1)

# %%
# %%time
np.linalg.matrix_rank(df), df.shape
# Out:
# Wall time: 3min 56s
# (6923, (7324, 7323))

# %%
def intersection(lst1, lst2): 
  
    # Use of hybrid method 
    temp = set(lst2) 
    lst3 = [value for value in lst1 if value in temp] 
    return lst3

# %%
missing_vals = BES_reduced_with_na[ intersection(df.columns , BES_reduced_with_na.columns) ][SovOrImmLeavers].isnull()
missing_vals = (missing_vals.sum()/missing_vals.shape[0]).sort_values()
missing_vals.hist(bins=100);

# %%
drop_vars = list(missing_vals[missing_vals>.5].index)
drop_vars
# Out:
# ['generalElectionCertaintyUnsqW12__Completely certain',
#  'labPartnerGreenW11_Would join Labour',
#  'scotIndepGoodEngW3__Very good',
#  'scotReferendumOutsideW1_Scotland should become an independent country',
#  'labLookAfterBAW10__Very closely',
#  'profile_gross_householdW11__£150,000 and over',
#  'euKnow4W8_False',
#  'generalElectionVoteUnsqueezeW12_Plaid Cymru',
#  'generalElectionVoteUnsqueezeW12_United Kingdom Independence Party (UKIP)',
#  'generalElectionVoteUnsqueezeW12_Liberal Democrat',
#  'generalElectionVoteUnsqueezeW12_Scottish National Party (SNP)',
#  'generalElectionVoteUnsqueezeW12_Conservative',
#  'generalElectionVoteUnsqueezeW12_Labour',
#  'generalElectionVoteUnsqueezeW12_Green Party',
#  'voteMethodEurope_3W2_Yes',
#  'ldUnitedW10__Very united',
#  'lrUKIPW10__Right',
#  'EUIntegrationLDW14__Protect our independence',
#  'pidCommonPartyW13__Strongly agree',
#  'taxSpendConW14__Government should increase taxes a lot and spend much more on health and social services',
#  'localElectionVoteW7_United Kingdom Independence Party (UKIP)',
#  'localElectionVoteW7_Liberal Democrat',
#  'localElectionVoteW7_Green Party',
#  'immigLDW10__Allow many more',
#  'discussantturnoutName1W2_Yes, I think they *will* vote',
#  'localElectionVoteW7_Conservative',
#  'localElectionVoteW7_Labour',
#  'euID7W10__Strongly agree',
#  'ukipUnitedW14__Very united',
#  'satDemEngW10__Very satisfied',
#  'euLeaveScotIndepW14__Much more likely',
#  'grnUnitedW13__Very united',
#  'grnUnitedW11__Very united',
#  'englandGovernW3__By a new, separate parliament for England, and with England becoming independent from the rest of the UK',
#  'discussantClassName1W2_Yes, working class',
#  'lrgreensW11__Right',
#  'redistLDW11__Government should be less concerned about equal incomes',
#  'likeFarronW10__Strongly like',
#  'redistConW10__Government should be less concerned about equal incomes',
#  'likeLucasW11__Strongly like',
#  'satDemEngW1__Very satisfied',
#  'londonEconW11__Got a lot better',
#  'expectAccessW13_Yes',
#  'generalElectionVoteW14_Conservative',
#  'generalElectionVoteW14_Labour',
#  'generalElectionVoteW14_Liberal Democrat',
#  'generalElectionVoteW14_United Kingdom Independence Party (UKIP)',
#  'generalElectionVoteW14_Green Party',
#  'generalElectionVoteW14_Plaid Cymru',
#  'bestPMW10_Jeremy Corbyn',
#  'redistConW14__Government should be less concerned about equal incomes',
#  'inequalityChangeLargerW3_Somewhat larger',
#  'englandGovernW2__By a new, separate parliament for England, and with England becoming independent from the rest of the UK',
#  'redistLabW14__Government should be less concerned about equal incomes',
#  'euID4W10__Strongly agree',
#  'euID6W10__Strongly agree',
#  'likeWatsonW9__Strongly like',
#  'lrLDW10__Right',
#  'taxSpendLabW14__Government should increase taxes a lot and spend much more on health and social services',
#  'negotiationSpecifics_2W14_Yes',
#  'negotiationSpecifics_3W14_Yes',
#  'negotiationSpecifics_noneW14_Yes',
#  'natSecurityConW10__Protect civil liberties',
#  'negotiationSpecifics_1W14_Yes',
#  'voteMethodEurope_4W2_Yes',
#  'euID1W14__Strongly agree',
#  'ukipUnitedW1__Very united',
#  'likeMcDonnellW9__Strongly like',
#  'secondHomeW14__Yes: I/we own another property outright (without a mortgage)',
#  'scotIndepGoodEngW2__Very good',
#  'redistLabW10__Government should be less concerned about equal incomes',
#  'EUIntegrationGreenW11__Protect our independence',
#  'redistUKIPW13__Government should be less concerned about equal incomes',
#  'redistUKIPW11__Government should be less concerned about equal incomes',
#  'euID7W14__Strongly agree',
#  'ldUnitedW14__Very united',
#  'discussantVoteName1W2_Labour',
#  'discussantVoteName1W2_Conservative',
#  'discussantVoteName1W2_UKIP',
#  'discussantVoteName1W2_Liberal Democrat',
#  'discussantVoteName1W2_They do not vote',
#  'discussantVoteName1W2_SNP',
#  'discussantVoteName1W2_Greens',
#  'discussantVoteName1W2_Plaid Cymru',
#  'discussantVoteName1W2_BNP',
#  'redistUKIPW3__Government should be less concerned about equal incomes',
#  'grnUnitedW6__Very united',
#  'euID6W14__Strongly agree',
#  'conLookAfterBAW10__Very closely',
#  'immigLDW14__Allow many more',
#  'englandGovernW1__By a new, separate parliament for England, and with England becoming independent from the rest of the UK',
#  'scotIndepGoodEngW1__Very good',
#  'natSecurityLabW10__Protect civil liberties',
#  'ukipLookAfterWCW12__Very closely',
#  'prevJobW1W2W3W4W5_Yes, I have done paid work in the past',
#  'selfOccSuperviseLastW6_W12_Yes',
#  'negotiationSpecifics_noneW10_Yes',
#  'negotiationSpecifics_3W10_Yes',
#  'negotiationSpecifics_2W10_Yes',
#  'negotiationSpecifics_1W10_Yes',
#  'expectAccessW10_Yes',
#  'profile_gross_householdW10__£150,000 and over',
#  'redistUKIPW2__Government should be less concerned about equal incomes',
#  'expectAccessW14_Yes',
#  'natSecurityGrnW13__Protect civil liberties',
#  'ukipLookAfterMCW12__Very closely',
#  'selfOccStatusLastW1W2W3W4W5_An employee',
#  'redistGreenW13__Government should be less concerned about equal incomes',
#  'immigGreenW11__Allow many more',
#  'redistUKIPW1__Government should be less concerned about equal incomes',
#  'mpBrexitViewW11__Strongly support',
#  'grnUnitedW4__Very united',
#  'localTurnoutRetroW8_Yes, voted',
#  'bestPMW7_Jeremy Corbyn',
#  'redistGreenW6__Government should be less concerned about equal incomes',
#  'profile_gross_householdW14__£150,000 and over',
#  'debateOneWatchW12_Yes',
#  'sharedContentOnline_1W12_Yes',
#  'likeLucasW14__Strongly like',
#  'localTurnoutRetroW12_Yes, voted',
#  'partyContactDKW6_Yes',
#  'euID4W14__Strongly agree',
#  'redistGreenW11__Government should be less concerned about equal incomes',
#  'natSecurityLDW10__Protect civil liberties',
#  'partyContactLabW6_Yes',
#  'partyContactConW6_Yes',
#  'partyContactOtherPartyW6_Yes',
#  'partyContactUKIPW6_Yes',
#  'partyContactGrnW6_Yes',
#  'natSecurityGrnW11__Protect civil liberties',
#  'partyContactLDW6_Yes',
#  "fbInfo_1W12__Don't follow politics on facebook",
#  "fbInfo_2W12__Don't follow politics on facebook",
#  'natSecurityUKIPW10__Protect civil liberties',
#  'localElectionVoteW6_Scottish National Party (SNP)',
#  'localElectionVoteW6_Conservative',
#  'localElectionVoteW6_Plaid Cymru',
#  'localElectionVoteW6_British National Party (BNP)',
#  'localElectionVoteW6_Labour',
#  'localElectionVoteW6_United Kingdom Independence Party (UKIP)',
#  'localElectionVoteW6_Green Party',
#  'localElectionVoteW6_Liberal Democrat',
#  'redistLDW10__Government should be less concerned about equal incomes',
#  'discussantsSameAddress_2W2_Yes',
#  'lrgreensW10__Right',
#  'askVoteDiscuss2W2_Yes',
#  'discussantEthnicity2W2_Different ethnicity',
#  'fbInfof2fW6_Yes',
#  'discussPolDaysD2W2__7 days',
#  'redistGreenW4__Government should be less concerned about equal incomes',
#  'ukipLookAfterWCW10__Very closely',
#  'taxSpendLDW14__Government should increase taxes a lot and spend much more on health and social services',
#  'redistGreenW3__Government should be less concerned about equal incomes',
#  'redistUKIPW10__Government should be less concerned about equal incomes',
#  'grnUnitedW14__Very united',
#  'grnUnitedW10__Very united',
#  'sharedContentOnline_1W5_Yes',
#  'sharedContentOnline_1W4_Yes',
#  'likeLucasW10__Strongly like',
#  'ukipLookAfterMCW10__Very closely',
#  'EUIntegrationGreenW14__Protect our independence',
#  'EUIntegrationGreenW10__Protect our independence',
#  'redistLDW14__Government should be less concerned about equal incomes',
#  "fbInfo_1W5__Don't follow politics on facebook",
#  "fbInfo_2W5__Don't follow politics on facebook",
#  'relationshipName2W2_Another relative',
#  'relationshipName2W2_A friend',
#  'relationshipName2W2_Your spouse or partner',
#  'relationshipName2W2_A neighbour or co-worker',
#  'ukipLookAfterBAW10__Very closely',
#  'inequalityGoodBadW2_Bad thing',
#  'selfOccStatusW6_W12_An employee',
#  "fbInfo_3W4__Don't follow politics on facebook",
#  "fbInfo_2W4__Don't follow politics on facebook",
#  "fbInfo_1W4__Don't follow politics on facebook",
#  'inequalityGoodBadW4_Bad thing',
#  'immigGreenW10__Allow many more',
#  'debateTwoWatchW5_Yes',
#  'pccVote1W7_The UKIP candidate',
#  'pccVote1W7_The Conservative candidate',
#  'pccVote1W7_The Labour candidate',
#  'pccVote1W7_Any other candidate',
#  'pccVote1W7_The Liberal Democrat candidate',
#  'pccVote1W7_The Green candidate',
#  'pccVote1W7_The Plaid Cymru candidate',
#  'pccVote1W8_The Liberal Democrat candidate',
#  'pccVote1W8_The Labour candidate',
#  'pccVote1W8_The Plaid Cymru candidate',
#  'pccVote1W8_The Conservative candidate',
#  'pccVote1W8_The UKIP candidate',
#  'pccVote1W8_Any other candidate',
#  'pccVote1W8_The Green candidate',
#  'ukipLookAfterUnempW10__Very closely',
#  'homeAmtbW14__£1 million or above',
#  'profile_work_industryW14_Media/Publishing/Entertainment',
#  'profile_work_industryW14_Hospitality/Recreation',
#  'profile_work_industryW14_Service',
#  'profile_work_industryW14_Computers/Electronics',
#  'profile_work_industryW14_Travel/Transportation',
#  'profile_work_industryW14_Have never worked',
#  'profile_work_industryW14_Medical/Health Services',
#  'profile_work_industryW14_Government/Military/Public Service',
#  'profile_work_industryW14_Retail',
#  'profile_work_industryW14_Education',
#  'profile_work_industryW14_Finance/Insurance/Real Estate',
#  'profile_work_industryW14_Telecommunications/Networking',
#  'profile_work_industryW14_Construction',
#  'profile_work_industryW14_Consumer Goods',
#  'profile_work_industryW14_Energy/Mining',
#  'profile_work_industryW14_Advertising/Marketing/PR',
#  'profile_work_industryW14_Aerospace',
#  'profile_work_industryW14_Agriculture/Chemicals/Forest Products',
#  'profile_work_industryW14_Pharmaceuticals',
#  'profile_work_industryW14_Automotive',
#  'redistGreenW10__Government should be less concerned about equal incomes',
#  'likeConW6__Strongly like',
#  'redistGreenW2__Government should be less concerned about equal incomes',
#  'likeLabW6__Strongly like',
#  'ptvBNPW6__Very likely',
#  'likeUKIPW6__Strongly like',
#  'likeLDW6__Strongly like',
#  'ptvUKIPW6__Very likely',
#  'likeLabW5__Strongly like',
#  'ptvLabW6__Very likely',
#  'likeConW5__Strongly like',
#  'ptvConW6__Very likely',
#  'ptvBNPW5__Very likely',
#  'ptvGrnW6__Very likely',
#  'ptvLDW6__Very likely',
#  'likeLDW5__Strongly like',
#  'ptvUKIPW5__Very likely',
#  'immigGreenW14__Allow many more',
#  'ptvLDW5__Very likely',
#  'likeUKIPW5__Strongly like',
#  'likeLabW4__Strongly like',
#  'likeConW4__Strongly like',
#  'ptvGrnW5__Very likely',
#  'EUIntegrationSelfW6__Protect our independence',
#  'ptvBNPW4__Very likely',
#  'ptvLabW5__Very likely',
#  'likeUKIPW4__Strongly like',
#  'ptvConW5__Very likely',
#  'likeLDW4__Strongly like',
#  'ptvGrnW4__Very likely',
#  'ptvUKIPW4__Very likely',
#  'ptvLabW4__Very likely',
#  'ptvLDW4__Very likely',
#  'EUIntegrationSelfW4__Protect our independence',
#  'euDominanceW8__Many more powers',
#  'ptvConW4__Very likely',
#  'likeBNPW6__Strongly like',
#  'likeBNPW5__Strongly like',
#  'likeBNPW4__Strongly like',
#  'discussantClassName2W2_Yes, working class',
#  'likeSNPW6__Strongly like',
#  'EUIntegrationUKIPW6__Protect our independence',
#  'likeGrnW6__Strongly like',
#  'likeGrnW4__Strongly like',
#  'natSecurityGrnW10__Protect civil liberties',
#  'taxSpendGreenW14__Government should increase taxes a lot and spend much more on health and social services',
#  'likeGrnW5__Strongly like',
#  'redistUKIPW14__Government should be less concerned about equal incomes',
#  'mapdefined_9W3_Yes',
#  'EUIntegrationConW6__Protect our independence',
#  'nationalUnemployment_a_1W3',
#  'localUnemployment_a_1W3',
#  'EUIntegrationUKIPW4__Protect our independence',
#  'localEconNowW12__Very good',
#  'redistGreenW14__Government should be less concerned about equal incomes',
#  'mapLiveWorkW3_I live *and* work there',
#  'mapLiveWorkW3_I just live there',
#  'mapLiveWorkW3_I neither live nor work there',
#  'mapLiveWorkW3_I just work there',
#  'EUIntegrationConW4__Protect our independence',
#  'taxSpendUKIPW14__Government should increase taxes a lot and spend much more on health and social services',
#  'EUIntegrationLabW6__Protect our independence',
#  'mapBelongW3__Very strongly',
#  'discussantApprovalVoteName2W2_Yes',
#  'eesEUIntegrationSelfW6__Unification should be pushed further',
#  'mapLiveTimeW3__More than ten years',
#  'EUIntegrationLabW4__Protect our independence',
#  'bestPMW8_Jeremy Corbyn',
#  'eesEUIntegrationSelfW4__Unification should be pushed further',
#  'mapWhiteW3',
#  'mapRepresentW3__A great deal',
#  'EUIntegrationLDW6__Protect our independence',
#  'mapdefined_5W3_Yes',
#  'mapdefined_4W3_Yes',
#  'mapdefined_6W3_Yes',
#  'mapdefined_3W3_Yes',
#  'mapdefined_8W3_Yes',
#  'mapdefined_7W3_Yes',
#  'mapdefined_2W3_Yes',
#  'mapdefined_1W3_Yes',
#  'EUIntegrationLDW4__Protect our independence',
#  'mapEconW3__Got a lot better',
#  'likeConW2__Strongly like',
#  'likeLabW2__Strongly like',
#  'likeLDW2__Strongly like',
#  'competentMayW13__A great deal of competence',
#  'ptvBNPW2__Very likely',
#  'ptvGrnW2__Very likely',
#  'ptvUKIPW2__Very likely',
#  'selfOccStatusW1W2W3W4W5_An employee',
#  'ptvLabW2__Very likely',
#  'competentCorbynW13__A great deal of competence',
#  'ptvLDW2__Very likely',
#  'integrityMayW13__Complete integrity',
#  'mapWorkingClassW3',
#  'integrityCorbynW13__Complete integrity',
#  'ptvConW2__Very likely',
#  'likeUKIPW2__Strongly like',
#  'mapAsianW3',
#  'likeConW3__Strongly like',
#  'likeLabW3__Strongly like',
#  'eesEUIntegrationUKIPW6__Unification should be pushed further',
#  'likeBNPW2__Strongly like',
#  'likeBorisW13__Strongly like',
#  'likeLDW3__Strongly like',
#  'partyContactCon_6W6_Yes',
#  'partyContactCon_7W6_Yes',
#  'partyContactCon_5W6_Yes',
#  'partyContactCon_3W6_Yes',
#  'partyContactCon_1W6_Yes',
#  'partyContactCon_4W6_Yes',
#  'partyContactCon_2W6_Yes',
#  'diversityChangeW3__Much more diverse',
#  'mapMiddleClassW3',
#  'selfOccSuperviseW6_W12_Yes',
#  'mapBlackW3',
#  'likeUKIPW3__Strongly like',
#  'EUIntegrationSelfW3__Protect our independence',
#  'likeBNPW3__Strongly like',
#  'localEcon1520YrW12__Very good',
#  'ptvUKIPW3__Very likely',
#  'EUIntegrationSelfW2__Protect our independence',
#  'ptvBNPW3__Very likely',
#  'likeGrnW2__Strongly like',
#  'ptvLDW3__Very likely',
#  'ptvLabW3__Very likely',
#  'competentFarageW13__A great deal of competence',
#  'eesEUIntegrationUKIPW4__Unification should be pushed further',
#  'ptvConW3__Very likely',
#  'ptvGrnW3__Very likely',
#  'eesEUIntegrationConW6__Unification should be pushed further',
#  'mapConW3',
#  'EUIntegrationUKIPW2__Protect our independence',
#  'askVotePartnerW2_Yes',
#  'selfOccSuperviseLastW1_Yes',
#  'likeGrnW3__Strongly like',
#  'EUIntegrationUKIPW3__Protect our independence',
#  'mapLabW3',
#  'pccVote2W7_The Plaid Cymru candidate',
#  'pccVote2W7_The Green candidate',
#  'pccVote2W7_Any other candidate',
#  'pccVote2W7_The Conservative candidate',
#  'pccVote2W7_The UKIP candidate',
#  'pccVote2W7_The Liberal Democrat candidate',
#  'pccVote2W7_The Labour candidate',
#  'ptvBNPW1__Very likely',
#  'eesEUIntegrationConW4__Unification should be pushed further',
#  'EUIntegrationConW2__Protect our independence',
#  'eesEUIntegrationLabW6__Unification should be pushed further',
#  'ptvGrnW1__Very likely',
#  'ptvLabW1__Very likely',
#  'pccVote2W8_The Plaid Cymru candidate',
#  'pccVote2W8_Any other candidate',
#  'pccVote2W8_The Labour candidate',
#  'pccVote2W8_The Liberal Democrat candidate',
#  'pccVote2W8_The Conservative candidate',
#  'pccVote2W8_The UKIP candidate',
#  'pccVote2W8_The Green candidate',
#  'ptvUKIPW1__Very likely',
#  'ptvLDW1__Very likely',
#  'EUIntegrationConW3__Protect our independence',
#  'ptvConW1__Very likely',
#  'likeLabW1__Strongly like',
#  'likeConW1__Strongly like',
#  'discussantVoteName2W2_BNP',
#  'discussantVoteName2W2_Plaid Cymru',
#  'discussantVoteName2W2_Greens',
#  'discussantVoteName2W2_SNP',
#  'discussantVoteName2W2_Liberal Democrat',
#  'discussantVoteName2W2_Labour',
#  'discussantVoteName2W2_Conservative',
#  'discussantVoteName2W2_They do not vote',
#  'discussantVoteName2W2_UKIP',
#  'likeLDW1__Strongly like',
#  'EUIntegrationSelfW1__Protect our independence',
#  'postalTurnoutW8_Yes',
#  'EUIntegrationLabW2__Protect our independence',
#  'EUIntegrationLDW2__Protect our independence',
#  'partyContactLab_2W6_Yes',
#  'partyContactLab_5W6_Yes',
#  'partyContactLab_6W6_Yes',
#  'partyContactLab_3W6_Yes',
#  'partyContactLab_7W6_Yes',
#  'partyContactLab_4W6_Yes',
#  'eesEUIntegrationLabW4__Unification should be pushed further',
#  'eesEUIntegrationLDW6__Unification should be pushed further',
#  'partyContactDKW13_Yes',
#  'likeUKIPW1__Strongly like',
#  'likeBNPW1__Strongly like',
#  'competentFarronW13__A great deal of competence',
#  'eesEUIntegrationSelfW2__Unification should be pushed further',
#  'discussantsSameAddress_3W2_Yes',
#  'partyContactConW13_Yes',
#  'partyContactLabW13_Yes',
#  'partyContactUKIPW13_Yes',
#  'partyContactLDW13_Yes',
#  'partyContactGrnW13_Yes',
#  'partyContactOtherPartyW13_Yes',
#  'partyContactNoneW13_Yes',
#  'EUIntegrationLabW3__Protect our independence',
#  'localElectionVoteW8_Liberal Democrat',
#  'localElectionVoteW8_United Kingdom Independence Party (UKIP)',
#  'localElectionVoteW8_Green Party',
#  'localElectionVoteW8_Conservative',
#  'localElectionVoteW8_Labour',
#  'eesEUIntegrationLDW4__Unification should be pushed further',
#  'mapLDW3',
#  'askVoteDiscuss3W2_Yes',
#  'eesEUIntegrationSelfW3__Unification should be pushed further',
#  'pContactEday_99W13_Yes',
#  'EUIntegrationLDW3__Protect our independence',
#  'mapUKBirthW3',
#  'discussantEthnicity3W2_Different ethnicity',
#  'discussPolDaysD3W2__7 days',
#  'likeGrnW1__Strongly like',
#  'discussantturnoutName2W2_Yes, I think they *will* vote',
#  'eesEUIntegrationUKIPW2__Unification should be pushed further',
#  'mapUKIPW3',
#  'EUIntegrationUKIPW1__Protect our independence',
#  'pContactEday_10W13_Yes',
#  'EUIntegrationConW1__Protect our independence',
#  'eesEUIntegrationSelfW1__Unification should be pushed further',
#  'localElectionVoteW12_Liberal Democrat',
#  'localElectionVoteW12_United Kingdom Independence Party (UKIP)',
#  'localElectionVoteW12_Scottish National Party (SNP)',
#  'localElectionVoteW12_Plaid Cymru',
#  'localElectionVoteW12_Green Party',
#  'localElectionVoteW12_Labour',
#  'localElectionVoteW12_Conservative',
#  'eesEUIntegrationConW2__Unification should be pushed further',
#  'eesEUIntegrationUKIPW3__Unification should be pushed further',
#  'relationshipName3W2_Another relative',
#  'relationshipName3W2_Your spouse or partner',
#  'relationshipName3W2_A neighbour or co-worker',
#  'relationshipName3W2_A friend',
#  'mapInequalityW3__Differences in income are very large',
#  'EUIntegrationLabW1__Protect our independence',
#  'mapGreenW3',
#  'mapTurnoutW3',
#  'studentloanW14_Yes',
#  'EUIntegrationLDW1__Protect our independence',
#  'eesEUIntegrationLDW2__Unification should be pushed further',
#  'eesEUIntegrationConW3__Unification should be pushed further',
#  'eesEUIntegrationLabW2__Unification should be pushed further',
#  'postalTurnoutW12_Yes',
#  'likeRuddW13__Strongly like',
#  'eesEUIntegrationLabW3__Unification should be pushed further',
#  'eesEUIntegrationUKIPW1__Unification should be pushed further',
#  'partyContactDKW4_Yes',
#  'eesEUIntegrationLDW3__Unification should be pushed further',
#  'partyContactLabW4_Yes',
#  'partyContactOtherPartyW4_Yes',
#  'partyContactLDW4_Yes',
#  'partyContactUKIPW4_Yes',
#  'partyContactConW4_Yes',
#  'partyContactGrnW4_Yes',
#  'likeDavisW13__Strongly like',
#  'eesEUIntegrationConW1__Unification should be pushed further',
#  'econPersonalRetroW8__Got a lot better',
#  'savingsAmtbW14__£200,000 or above',
#  'econGenRetroW8__Got a lot better',
#  'eesEUIntegrationLDW1__Unification should be pushed further',
#  'localTurnoutRetroW14_Yes, voted',
#  'partyContact1W5_Yes',
#  'eesEUIntegrationLabW1__Unification should be pushed further',
#  'discussantClassName3W2_Yes, working class',
#  'profile_work_responsibilityW14__Over 100',
#  'likeNuttallW10__Strongly like',
#  'partyContactNoneW12_Yes',
#  'partyContactLDW12_Yes',
#  'partyContactOtherPartyW12_Yes',
#  'partyContactUKIPW12_Yes',
#  'partyContactConW12_Yes',
#  'partyContactLabW12_Yes',
#  'localTurnoutRetroW2_Yes, voted',
#  'likeJarvisW9__Strongly like',
#  'likeBattenW14__Strongly like',
#  'competentLucasW13__A great deal of competence',
#  'selfOccOrgSizeLastW6_W12__500 or more employees',
#  'partyContactDKW7_Yes',
#  'postalTurnoutW5_Yes',
#  'labCandCorbyniteW12_Yes',
#  'partyContactLDW7_Yes',
#  'partyContactUKIPW7_Yes',
#  'partyContactLabW7_Yes',
#  'partyContactOtherPartyW7_Yes',
#  'partyContactOthLeaveW7_Yes',
#  'partyContactVoteLeaveW7_Yes',
#  'partyContactStrongerInW7_Yes',
#  'partyContactNoneW7_Yes',
#  'partyContactGrnW7_Yes',
#  'partyContactConW7_Yes',
#  'partyContactOthRemainW7_Yes',
#  'eesEUIntegrationGreenW6__Unification should be pushed further',
#  'labPartnerSNPW5_Would join Labour',
#  'debateOneWatchW8_Yes',
#  'govtHandleImmigW7__Very well',
#  'resourceAccess1_99W7_Yes',
#  'resourceAccess2_99W7_Yes',
#  'resourceAccess3_99W7_Yes',
#  'govtHandleNHSW7__Very well',
#  'govtHandleCostLiveW7__Very well',
#  'govtHandleEconW7__Very well',
#  'EUIntegrationGreenW3__Protect our independence',
#  'aom4W7__Strongly agree',
#  'populism1W7__Strongly agree',
#  'partyContactCon_2W13_Yes',
#  'partyContactCon_1W13_Yes',
#  'partyContactCon_3W13_Yes',
#  'partyContactCon_4W13_Yes',
#  'partyContactCon_5W13_Yes',
#  'partyContactCon_7W13_Yes',
#  'partyContactCon_6W13_Yes',
#  'govtHandleLevelCrimeW7__Very well',
#  'populism5W7__Strongly agree',
#  'partyContactNoneW2_Yes',
#  'eesEUIntegrationGreenW4__Unification should be pushed further',
#  'auth3W7_To be well-behaved',
#  'resourceAccess2_3W7_Yes',
#  'resourceAccess1_5W7_Yes',
#  'resourceAccess1_1W7_Yes',
#  'resourceAccess1_3W7_Yes',
#  'resourceAccess1_111W7_Yes',
#  'resourceAccess1_2W7_Yes',
#  'resourceAccess2_4W7_Yes',
#  'resourceAccess2_111W7_Yes',
#  'resourceAccess2_1W7_Yes',
#  'resourceAccess1_4W7_Yes',
#  'resourceAccess1_6W7_Yes',
#  'resourceAccess2_2W7_Yes',
#  'conPartnerSNPW5_Would join Conservatives',
#  'aom3W7__Strongly agree',
#  'partyContactLDW2_Yes',
#  'aom2W7__Strongly agree',
#  'partyContactUKIPW2_Yes',
#  'csplRank_3W7__Least common reason',
#  'csplRank_2W7__Least common reason',
#  'csplRank_1W7__Least common reason',
#  'partyContactConW2_Yes',
#  'partyContactLabW2_Yes',
#  'populism2W7__Strongly agree',
#  'partyContactOtherPartyW2_Yes',
#  'aom5W7__Strongly agree',
#  'aom7W7__Strongly agree',
#  'euScepticismW7__Work towards single European government',
#  'discussantApprovalVoteName3W2_Yes',
#  'aom1W7__Strongly agree',
#  'auth4W7_Good manners',
#  'aom6W7__Strongly agree',
#  'natSecuritySpendingW7__A lot more',
#  'govtHandleEducW7__Very well',
#  'resourceAccess3_1W7_Yes',
#  'resourceAccess3_8W7_Yes',
#  'resourceAccess3_5W7_Yes',
#  'resourceAccess3_111W7_Yes',
#  'resourceAccess3_7W7_Yes',
#  'resourceAccess3_6W7_Yes',
#  'resourceAccess3_2W7_Yes',
#  'resourceAccess3_4W7_Yes',
#  'resourceAccess3_3W7_Yes',
#  'populism6W7__Strongly agree',
#  'auth2W7_Self-reliance',
#  "genTrustW7_Can't be too careful",
#  'spendLeast5W2_Education',
#  'spendLeast5W2_Foreign Aid',
#  'spendLeast5W2_Research and Development',
#  'spendLeast5W2_Infrastructure: Roads and Public Transport',
#  'spendLeast5W2_Health',
#  'spendLeast2W2_Pensions',
#  'spendLeast2W2_Social Security',
#  'spendLeast2W2_Defence',
#  'spendLeast2W2_Foreign Aid',
#  'pContactEday_1W13_Yes',
#  'spendLeast4W2_Pensions',
#  'spendLeast4W2_Environmental Policy',
#  'spendLeast4W2_Research and Development',
#  'spendLeast4W2_Education',
#  'spendLeast4W2_Foreign Aid',
#  'populism4W7__Strongly agree',
#  'socialDistConW7__Very happy',
#  'warmFranceW7__Very warm',
#  'socialDistUKIPW7__Very happy',
#  'happyLeaveW7__Very happy',
#  'socialDistLabW7__Very happy',
#  'labHandleEconW7__Very well',
#  'spendMost5W2_Health',
#  'spendMost5W2_Foreign Aid',
#  'spendMost5W2_Research and Development',
#  'spendMost5W2_Infrastructure: Roads and Public Transport',
#  'spendMost5W2_Education',
#  'spendMost1W2_Environmental Policy',
#  'spendMost1W2_Social Security',
#  'spendMost1W2_Research and Development',
#  'spendMost1W2_Infrastructure: Roads and Public Transport',
#  'spendMost1W2_Health',
#  'labHandleImmigW7__Very well',
#  'warmPolandW7__Very warm',
#  'labHandleNHSW7__Very well',
#  'labHandleCostLiveW7__Very well',
#  'spendMost3W2_Health',
#  'spendMost3W2_Defence',
#  'spendMost3W2_Environmental Policy',
#  'spendMost3W2_Pensions',
#  'socialDistLDW7__Very happy',
#  'eesEUIntegrationGreenW2__Unification should be pushed further',
#  'auth1W7_Respect for elders',
#  'euIDW7_The leave side',
#  'warmSpainW7__Very warm',
#  'cspl2W7__Completely acceptable',
#  'warmGreeceW7__Very warm',
#  'cspl1W7__Very often',
#  'socialDistGreenW7__Very happy',
#  'labHandleLevelCrimeW7__Very well',
#  'spendMost6W2_Education',
#  'spendMost6W2_Pensions',
#  'spendMost6W2_Social Security',
#  'spendMost6W2_Environmental Policy',
#  'spendMost6W2_Defence',
#  'spendMost4W2_Pensions',
#  'spendMost4W2_Environmental Policy',
#  'spendMost4W2_Education',
#  'warmRomaniaW7__Very warm',
#  'spendMost4W2_Research and Development',
#  'socialDistSNPW7__Very happy',
#  'warmDenmarkW7__Very warm',
#  'spendMost2W2_Defence',
#  'spendMost2W2_Pensions',
#  'spendMost2W2_Social Security',
#  'spendMost2W2_Research and Development',
#  'spendMost2W2_Foreign Aid',
#  'natSecuritySelfW7__Protect civil liberties',
#  'labHandleEducW7__Very well',
#  'selfRedistCertainW7__Very certain',
#  'warmUKW7__Very warm',
#  'certaintyEUUKIPW7__Very certain',
#  'handleMIIConW7__Very well',
#  'certaintyEUConW7__Very certain',
#  'locus1W9__Strongly agree',
#  'controlImmigW8__Complete control',
#  'spendLeast6W2_Environmental Policy',
#  'spendLeast6W2_Pensions',
#  'spendLeast6W2_Education',
#  'spendLeast6W2_Social Security',
#  'spendLeast6W2_Defence',
#  'euExpRefW7_To leave the European Union',
#  'EUContactLeaveDKW7_Yes',
#  'EUContactRemainDKW7_Yes',
#  'EUIntegrationGreenW6__Protect our independence',
#  'locus2W9__Strongly agree',
#  'cspl5W7__Of great importance',
#  'spendLeast1W2_Health',
#  'spendLeast1W2_Infrastructure: Roads and Public Transport',
#  'spendLeast1W2_Research and Development',
#  'spendLeast1W2_Social Security',
#  'spendLeast1W2_Environmental Policy',
#  'handleMIILabW7__Very well',
#  'climateChangeW7__Climate not changing',
#  'certaintyEULabW7__Very certain',
#  'debateTwoWatchW8_Yes',
#  'discussantVoteName3W2_Labour',
#  'partyContactLab_1W13_Yes',
#  'partyContactLab_2W13_Yes',
#  'partyContactLab_6W13_Yes',
#  'partyContactLab_5W13_Yes',
#  'partyContactLab_7W13_Yes',
#  'partyContactLab_4W13_Yes',
#  'partyContactLab_3W13_Yes',
#  'discussantVoteName3W2_Conservative',
#  'discussantVoteName3W2_They do not vote',
#  'discussantVoteName3W2_BNP',
#  'discussantVoteName3W2_UKIP',
#  'discussantVoteName3W2_Plaid Cymru',
#  'discussantVoteName3W2_Greens',
#  'discussantVoteName3W2_Liberal Democrat',
#  'discussantVoteName3W2_SNP',
#  'spendLeast3W2_Health',
#  'spendLeast3W2_Pensions',
#  'spendLeast3W2_Defence',
#  'spendLeast3W2_Environmental Policy',
#  'welfarePreferenceW7__Much too low',
#  'eesEUIntegrationGreenW3__Unification should be pushed further',
#  'partyContactNoneW11_Yes',
#  'partyContactUKIP_7W6_Yes',
#  'partyContactUKIP_1W6_Yes',
#  'partyContactUKIP_2W6_Yes',
#  'partyContactUKIP_3W6_Yes',
#  'partyContactUKIP_4W6_Yes',
#  'partyContactUKIP_5W6_Yes',
#  'partyContactUKIP_6W6_Yes',
#  'partyContactUKIPW11_Yes',
#  'partyContactConW11_Yes',
#  'partyContactLabW11_Yes',
#  'partyContactLDW11_Yes',
#  'partyContactOtherPartyW11_Yes',
#  'euID2W7__Strongly agree',
#  'cspl4W7__Very often',
#  'participation_6W8_Yes',
#  'participation_5W8_Yes',
#  'participation_4W8_Yes',
#  'participation_2W8_Yes',
#  'participation_1W8_Yes',
#  'participation_3W8_Yes',
#  'ethno3W9__Strongly agree',
#  'subjectHEW1W2W3_Medicine',
#  'subjectHEW1W2W3_Law',
#  'subjectHEW1W2W3_I never attended higher education (university etc)',
#  'subjectHEW1W2W3_Economics or business',
#  'subjectHEW1W2W3_Engineering, Mathematics or Natural sciences',
#  'subjectHEW1W2W3_Humanities, social sciences, psychology or education',
#  'ethno4W9__Strongly agree',
#  'pContactEday_2W13_Yes',
#  'riskPovertyW8__Very likely',
#  'ethno6W9__Strongly agree',
#  'EUIntegrationGreenW4__Protect our independence',
#  'pidCriticisePartyW7__Strongly agree',
#  'ethno2W9__Strongly agree',
#  'handleMIIUKIPW7__Very well',
#  'pidRuinDayW7__Strongly agree',
#  'pidInterestedOthersW7__Strongly agree',
#  'pidMyPartyW7__Strongly agree',
#  'EUContactRemainNoneW7_Yes',
#  'euID3W7__Strongly agree',
#  'ethno1W9__Strongly agree',
#  'EUContactLeaveNoneW7_Yes',
#  'handedW8_Right handed',
#  'handedW8_Left handed',
#  'handleMIILDW7__Very well',
#  'certaintyEULDW7__Very certain',
#  'selfOccSuperviseW1_Yes',
#  'conPriorities_immigW9_Yes',
#  'euID5W7__Strongly agree',
#  'conPriorities_noneW9_Yes',
#  'conPriorities_nhsW9_Yes',
#  'conPriorities_schoolW9_Yes',
#  'conPriorities_crimeW9_Yes',
#  'conPriorities_econW9_Yes',
#  'conPriorities_costLiveW9_Yes',
#  'ukipPriorities_schoolW9_Yes',
#  'ukipPriorities_econW9_Yes',
#  'euIDW8_The leave side',
#  'ukipPriorities_costLiveW9_Yes',
#  'ukipPriorities_noneW9_Yes',
#  'ukipPriorities_nhsW9_Yes',
#  'ukipPriorities_immigW9_Yes',
#  'ukipPriorities_crimeW9_Yes',
#  'discussantturnoutName3W2_Yes, I think they *will* vote',
#  'pidWeTheyW7__Strongly agree',
#  'ethno5W9__Strongly agree',
#  'localElectionVoteW2_Conservative',
#  'localElectionVoteW2_United Kingdom Independence Party (UKIP)',
#  'localElectionVoteW2_Liberal Democrat',
#  'localElectionVoteW2_Green Party',
#  'localElectionVoteW2_British National Party (BNP)',
#  'localElectionVoteW2_Labour',
#  'EUIntegrationGreenW2__Protect our independence',
#  'goodTimePurchaseW8__Good time to buy',
#  'remainVoteConLabW7__Many more of them are Conservative than Labour',
#  'euID1W7__Strongly agree',
#  'riskUnemploymentW8__Very likely',
#  'leaveVoteUKIPConW7__Many more of them are Conservative than UKIP',
#  'likeSEvansW10__Strongly like',
#  'certaintyRedistConW7__Very certain',
#  'pidPraiseGoodW7__Strongly agree',
#  'handleMIIConW9__Very well',
#  'natSecurityConW7__Protect civil liberties',
#  'handleMIILabW9__Very well',
#  'pidConnectedW7__Strongly agree',
#  'certaintyRedistLabW7__Very certain',
#  'euID6W7__Strongly agree',
#  'leftRightW9__Right',
#  'headHouseholdPastW7_My mother',
#  'headHouseholdPastW7_My father',
#  'headHouseholdPastW7_No one in my house worked',
#  'headHouseholdPastW7_Someone else',
#  'partyContactLD_1W6_Yes',
#  'partyContactLD_6W6_Yes',
#  'partyContactLD_5W6_Yes',
#  'partyContactLD_4W6_Yes',
#  'partyContactLD_3W6_Yes',
#  'partyContactLD_2W6_Yes',
#  'partyContactLD_7W6_Yes',
#  'conPriorities2_natsecW4_Yes',
#  'labPriorities2_natsecW4_Yes',
#  'ldPriorities2_natsecW4_Yes',
#  'ukipPriorities2_natsecW4_Yes',
#  'contactMPW4_Yes',
#  'euID2W8__Strongly agree',
#  'govtHandleImmigW4__Very well',
#  'lrLabW9__Right',
#  'govtHandleCostLiveW4__Very well',
#  'govtHandleEconW4__Very well',
#  'lrConW9__Right',
#  'govtHandleNHSW4__Very well',
#  'trustMPsW12__A great deal of trust',
#  'natSecurityLabW7__Protect civil liberties',
#  'euID7W7__Strongly agree',
#  'handleMIIUKIPW9__Very well',
#  'euID3W8__Strongly agree',
#  'localismImportanceW4__10- Very important',
#  'debateThreeWatchW12_Yes',
#  'leftRightW8__Right',
#  'natSecuritySpendingW4__A lot more',
#  'govtHandleLevelCrimeW4__Very well',
#  'govtNatSecuritySuccessW4__Very successful',
#  'ptvUKIPW12__Very likely',
#  'lrCorbynW8__Right',
#  'lrCameronW8__Right',
#  'ptvConW12__Very likely',
#  'ptvLDW12__Very likely',
#  'ptvLabW12__Very likely',
#  'partyHelpW6_Yes',
#  'lrUKIPW9__Right',
#  'labHandleNHSW4__Very well',
#  'ptvGrnW12__Very likely',
#  'labHandleEconW4__Very well',
#  'econPersonalRetroW6__Got a lot better',
#  'keepNukesW4__Strongly agree',
#  'labHandleCostLiveW4__Very well',
#  'lrLabW8__Right',
#  'euID5W8__Strongly agree',
#  'labHandleImmigW4__Very well',
#  'econGenRetroW6__Got a lot better',
#  'lrConW8__Right',
#  'selfOccOrgSizeLastW1__500 or more employees',
#  'pidRuinDayW9__Strongly agree',
#  'labPriorities_noneW9_Yes',
#  'labPriorities_schoolW9_Yes',
#  'labPriorities_econW9_Yes',
#  'labPriorities_crimeW9_Yes',
#  'labPriorities_nhsW9_Yes',
#  'labPriorities_costLiveW9_Yes',
#  "prPreferenceW9_That every party's percentage of seats in parliament is the same as their percentage of the vote",
#  'pidCriticisePartyW9__Strongly agree',
#  'labHandleLevelCrimeW4__Very well',
#  'pidInterestedOthersW9__Strongly agree',
#  'pidMyPartyW9__Strongly agree',
#  'euIDW12_The leave side',
#  'govtHandleEducW4__Very well',
#  'handleMIILDW9__Very well',
#  'handleMIIConW6__Very well',
#  'conPriorities_noneW6_Yes',
#  'conPriorities_costLiveW6_Yes',
#  'conPriorities_econW6_Yes',
#  'conPriorities_nhsW6_Yes',
#  'conPriorities_immigW6_Yes',
#  'conPriorities_crimeW6_Yes',
#  'conPriorities_schoolW6_Yes',
#  'labHandleEducW4__Very well',
#  'pidCommonPartyW7__Strongly agree',
#  'partyContactCon_1W12_Yes',
#  'partyContactCon_2W12_Yes',
#  'partyContactCon_5W12_Yes',
#  'partyContactCon_6W12_Yes',
#  'partyContactCon_7W12_Yes',
#  "mainSourceIncomeW6_Earnings from employment (own or spouse / partner's)",
#  'mainSourceIncomeW6_Occupational pension(s) - from previous employer(s)',
#  'mainSourceIncomeW6_Invalidity, sickness or disabled pension or benefit(s)',
#  'mainSourceIncomeW6_Other main source',
#  'mainSourceIncomeW6_Dependent on parents/other relatives',
#  "mainSourceIncomeW6_Jobseeker's Allowance / Unemployment benefit",
#  'mainSourceIncomeW6_Other state benefit',
#  'mainSourceIncomeW6_Income Support or family credit',
#  'partyContactCon_4W12_Yes',
#  'partyContactCon_3W12_Yes',
#  'econPersonalProspW6__Get a lot better',
#  'certaintyRedistLDW7__Very certain',
#  'handleMIIGrnW7__Very well',
#  'lrUKIPW8__Right',
#  'handleMIILabW6__Very well',
#  'abroadCountry_2W8_Yes',
#  'abroadCountry_1W8_Yes',
#  'discussantsAccompaniedVote_6W2_Yes',
#  'discussantsAccompaniedVote_noW2_Yes',
#  'discussantsAccompaniedVote_5W2_Yes',
#  'handleMIIConW4__Very well',
#  'leaveVoteUKIPConW8__Many more of them are Conservative than UKIP',
#  'econGenProspW6__Get a lot better',
#  'ukipPriorities_schoolW6_Yes',
#  'ukipPriorities_nhsW6_Yes',
#  'ukipPriorities_crimeW6_Yes',
#  'ukipPriorities_noneW6_Yes',
#  'ukipPriorities_econW6_Yes',
#  'ukipPriorities_costLiveW6_Yes',
#  'ukipPriorities_immigW6_Yes',
#  'euID7W8__Strongly agree',
#  'euID1W8__Strongly agree',
#  'pidWeTheyW9__Strongly agree',
#  'certaintyEUGreenW7__Very certain',
#  'partyContactCon_5W2_Yes',
#  'partyContactCon_4W2_Yes',
#  'partyContactCon_1W2_Yes',
#  'partyContactCon_2W2_Yes',
#  'partyContactCon_3W2_Yes',
#  'partyContactCon_7W2_Yes',
#  'partyContactCon_6W2_Yes',
#  'remainVoteConLabW8__Many more of them are Conservative than Labour',
#  'handleMIILDW6__Very well',
#  'redistSelfW12__Government should be less concerned about equal incomes',
#  'handleMIILabW4__Very well',
#  'lrLDW9__Right',
#  'conPriorities_noneW4_Yes',
#  'conPriorities_econW4_Yes',
#  'natSecurityUKIPW7__Protect civil liberties',
#  'conPriorities_costLiveW4_Yes',
#  'conPriorities_schoolW4_Yes',
#  'conPriorities_crimeW4_Yes',
#  'conPriorities_immigW4_Yes',
#  'conPriorities_nhsW4_Yes',
#  'euID6W8__Strongly agree',
#  'labToneW12__5 - Focused mainly on putting forward their own policies and personalities',
#  'handleMIILDW4__Very well',
#  'natSecuritySelfW4__Protect civil liberties',
#  'preferMPLocalW6__A lot more',
#  'conToneW12__5 - Focused mainly on putting forward their own policies and personalities',
#  'euID4W7__Strongly agree',
#  'natSecurityLDW7__Protect civil liberties',
#  'preferMPWomenW6__A lot more',
#  'preferMPWorkClassW6__A lot more',
#  'ukipPriorities_noneW4_Yes',
#  'ukipPriorities_schoolW4_Yes',
#  'ukipPriorities_crimeW4_Yes',
#  'ukipPriorities_immigW4_Yes',
#  'ukipPriorities_nhsW4_Yes',
#  'ukipPriorities_costLiveW4_Yes',
#  'ukipPriorities_econW4_Yes',
#  'certaintyRedistUKIPW7__Very certain',
#  'lrLDW8__Right',
#  'ukipPriorities2_schoolW4_Yes',
#  'ukipPriorities2_crimeW4_Yes',
#  'ukipPriorities2_immigW4_Yes',
#  'ukipPriorities2_noneW4_Yes',
#  'ukipPriorities2_nhsW4_Yes',
#  'handleMIIConW12__Very well',
#  'ukipPriorities2_costLiveW4_Yes',
#  'ukipPriorities2_econW4_Yes',
#  'conPriorities2_crimeW4_Yes',
#  'conPriorities2_econW4_Yes',
#  'conPriorities2_noneW4_Yes',
#  'conPriorities2_immigW4_Yes',
#  'conPriorities2_costLiveW4_Yes',
#  'conPriorities2_schoolW4_Yes',
#  'conPriorities2_nhsW4_Yes',
#  'populism1W11__Strongly agree',
#  'takeTheJobVoteOutcomeW11__Very likely',
#  'preferMPEthnicW6__A lot more',
#  'pidConnectedW9__Strongly agree',
#  'labPriorities_nhsW6_Yes',
#  'labPriorities_immigW6_Yes',
#  'labPriorities_econW6_Yes',
#  'labPriorities_noneW6_Yes',
#  'labPriorities_costLiveW6_Yes',
#  'labPriorities_schoolW6_Yes',
#  'labPriorities_crimeW6_Yes',
#  'handleMIILabW12__Very well',
#  'handleMIIUKIPW6__Very well',
#  'euID3W12__Strongly agree',
#  'localElectionVoteW14_United Kingdom Independence Party (UKIP)',
#  'localElectionVoteW14_Green Party',
#  'localElectionVoteW14_Conservative',
#  'localElectionVoteW14_Labour',
#  'localElectionVoteW14_Liberal Democrat',
#  'govtHandleImmigW3__Very well',
#  'govtHandleEconW3__Very well',
#  'dutyLongW11_Choice',
#  'welfarePreferenceW4__Much too low',
#  'govtHandleCostLiveW3__Very well',
#  'motive1W11__Strongly agree',
#  'populism5W11__Strongly agree',
#  'mpSecondJob1W11__Strongly agree',
#  'preferMPYoungW6__A lot more',
#  'auth3W11_To be well-behaved',
#  'govtHandleNHSW3__Very well',
#  'euID2W12__Strongly agree',
#  'pidPraiseGoodW9__Strongly agree',
#  'mpSecondJob3W11__Strongly agree',
#  'mpSecondJob2W11__Strongly agree',
#  'mpSecondJob4W11__Strongly agree',
#  'govtHandleLevelCrimeW3__Very well',
#  'partyContactCon_3W4_Yes',
#  'partyContactCon_7W4_Yes',
#  'partyContactCon_6W4_Yes',
#  'partyContactCon_5W4_Yes',
#  'partyContactCon_4W4_Yes',
#  'partyContactCon_2W4_Yes',
#  'partyContactCon_1W4_Yes',
#  'welfarePreferenceW6__Much too low',
#  ...]

# %%
# drop_vars = []
BES_sov = df.drop(drop_vars,axis=1)

# %%
# SovOrImmLeavers = (BES_Panel["euRefVote"]=="Leave the EU")&((BES_Panel["euMIISmall"] == "Sovereignty/EU bureaucracy") | (BES_Panel["euMIISmall"] == "Immigration"))

# Sov = BES_Panel[SovOrImmLeavers]["euMIISmall"] == "Sovereignty/EU bureaucracy"
# BES_sov = BES_reduced[SovOrImmLeavers]
# BES_sov = BES_sov.drop([x for x in BES_sov.columns if "euRefVote" in x] , axis=1)
# BES_sov = BES_sov.drop([x for x in BES_sov.columns if "euMIISmall" in x], axis=1)

# %%
Treatment = "TwoLeaverTribes" + dataset_name
output_subfolder = BES_output_folder + Treatment + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
from sklearn import datasets
from sklearn.decomposition import PCA, IncrementalPCA, NMF, TruncatedSVD, FastICA, FactorAnalysis, SparsePCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from gaussian_kde import gaussian_kde
from utility import display_components, display_pca_data, weighted_kde

# %%
# normalise data (subtract out the mean, divide through by standard deviation)
clean_feature_set_std = StandardScaler().fit_transform(BES_sov.values )
BES_std = pd.DataFrame(      clean_feature_set_std,
                             columns = BES_sov.columns,
                             index   = BES_sov.index      )

# %%
# %%time
# 5 mins
## RUN (some variant of) PCA (potentially v slow!)
n_components = BES_std.shape[1]
n_components = 1
# n_components = 2
# (svd_solver='full', n_components='mle',whiten=True)
# decomp = PCA(n_components = n_components,svd_solver='full')
# decomp = FastICA(algorithm='deflation', fun='exp', fun_args=None, max_iter=1000,
#     n_components=None, random_state=None, tol=0.07, w_init=None, whiten=False) # 2h 1min 4s "fast"
# decomp = SparsePCA(n_components=n_components, alpha=2,max_iter=1000,n_jobs=4,tol=1e-10, verbose=True) # 5min
#
# alpha=2 -> 1hr

decomp = LinearDiscriminantAnalysis() ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 
# ,n_components=30

X_r = decomp.fit_transform(BES_std, Sov)

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_sov.index)
# Out:
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# Wall time: 2min 8s

# %%
# %%time
# shrinkage


# 5 mins
## RUN (some variant of) PCA (potentially v slow!)
n_components = BES_std.shape[1]
n_components = 1
# n_components = 2
# (svd_solver='full', n_components='mle',whiten=True)
# decomp = PCA(n_components = n_components,svd_solver='full')
# decomp = FastICA(algorithm='deflation', fun='exp', fun_args=None, max_iter=1000,
#     n_components=None, random_state=None, tol=0.07, w_init=None, whiten=False) # 2h 1min 4s "fast"
# decomp = SparsePCA(n_components=n_components, alpha=2,max_iter=1000,n_jobs=4,tol=1e-10, verbose=True) # 5min
#
# alpha=2 -> 1hr

decomp = LinearDiscriminantAnalysis(solver="eigen",shrinkage = 'auto') ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 
# ,n_components=30

X_r = decomp.fit_transform(BES_std, Sov)

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_sov.index)
# Out:
# Wall time: 4min 43s

# %%
# treatdir = BES_data_folder+Treatment
# subdir = BES_data_folder+Treatment+decomp_method
load_suff = "FactorAnalysis"
save = True # False => Load

if save & ( 'decomp' in globals() ): # SAVE    ##( 'decomp' not in globals() )
    decomp_method = str(decomp).split("(")[0] 
    subdir = output_subfolder + decomp_method
    fname = subdir+ os.sep + decomp_method
    # create dir, save decomp object, BES_decomp, BES_std    
    if not os.path.exists(subdir): os.makedirs(subdir)
    with open(fname+".pkl", "wb") as f: pickle.dump( decomp, f )
    BES_decomp.to_hdf(fname+".hdf"        , decomp_method)
    BES_std.to_hdf(   fname+"_std"+".hdf" , decomp_method)
    
else: # LOAD decomp results (default is SAVE)
    decomp_method = load_suff
    subdir = output_subfolder + os.sep + decomp_method    
    fname = subdir + os.sep + decomp_method
    if not os.path.exists(subdir): raise Exception(subdir + ' does not exist!')
    # load decomp object, BES_decomp, BES_std, n_components
    with open(fname+".pkl", "rb") as f: decomp = pickle.load(f) 
    BES_decomp = pd.read_hdf(fname+".hdf")
    BES_std    = pd.read_hdf(fname+"_std"+".hdf")
    n_components = decomp.components_.shape[0]

# %%
# display_pca_data(n_components, decomp, BES_std)

# %%
(BES_decomp, comp_labels, comp_dict) = display_components(n_components, decomp,
                                                          BES_sov.columns, BES_decomp, manifest, 
                                                          save_folder = subdir,  
                                                          show_first_x_comps= 4, show_histogram = False)

# %%
subdir
# Out:
# '../BES_analysis_output/TwoLeaverTribesW14_comb\\LinearDiscriminantAnalysis'

# %%
# drop_vars

# %%
Sov.value_counts()
# Out:
# True     3933
# False    3391
# Name: euMIISmallW8, dtype: int64

# %%
# try again with all categories?

# %%
sovereignty = "Sovereignty/EU bureaucracy"
immigration = "Immigration"
SovOrImmLeavers = Leavers&amalgamated_euMIISmall.notnull()

Sov = amalgamated_euMIISmall[SovOrImmLeavers]
BES_sov = BES_reduced[SovOrImmLeavers]
drop_vars = [x for x in BES_reduced.columns if ("euRefVote" in x) or ("profile_eurefvote" in x)\
             or ("euMII" in x) or ("EUMII" in x)]
BES_sov = BES_sov.drop(drop_vars , axis=1)

# %%
df = de_collinearise(BES_sov)
drops = [x for x in BES_reduced_with_na if re.match("small_mii_cat|ns_secW|age|miilabel",x)]
df = df.drop(drops, axis=1, errors ='ignore')
BES_sov = df

# %%
# SovOrImmLeavers = (BES_Panel["euRefVote"]=="Leave the EU") & BES_Panel["euMIISmall"].notnull()
# #&((BES_Panel["euMIISmall"] == "Sovereignty/EU bureaucracy") | (BES_Panel["euMIISmall"] == "Immigration"))

# Sov_temp = BES_Panel[SovOrImmLeavers]["euMIISmall"]
# Sov = Sov_temp.cat.codes.copy()

# Sov[Sov_temp == "Sovereignty/EU bureaucracy"] = 0
# Sov[Sov_temp == "Immigration"] = 1
# Sov[(Sov_temp != "Sovereignty/EU bureaucracy") & (Sov_temp != "Immigration")] = 2

# Sov = BES_Panel[SovOrImmLeavers]["euMIISmall"]

# #== "Sovereignty/EU bureaucracy"
# BES_sov = BES_reduced[SovOrImmLeavers]
# BES_sov = BES_sov.drop([x for x in BES_sov.columns if "euRefVote" in x] , axis=1)
# BES_sov = BES_sov.drop([x for x in BES_sov.columns if "euMIISmall" in x], axis=1)

# %%
Treatment = "AllLeaverTribes"  + dataset_name
output_subfolder = BES_output_folder + Treatment + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
# normalise data (subtract out the mean, divide through by standard deviation)
clean_feature_set_std = StandardScaler().fit_transform(BES_sov.values )
BES_std = pd.DataFrame(      clean_feature_set_std,
                             columns = BES_sov.columns,
                             index   = BES_sov.index      )

# %%
# %%time
# 5 mins
## RUN (some variant of) PCA (potentially v slow!)
# n_components = BES_std.shape[1]

# n_components = 2
# (svd_solver='full', n_components='mle',whiten=True)
# decomp = PCA(n_components = n_components,svd_solver='full')
# decomp = FastICA(algorithm='deflation', fun='exp', fun_args=None, max_iter=1000,
#     n_components=None, random_state=None, tol=0.07, w_init=None, whiten=False) # 2h 1min 4s "fast"
# decomp = SparsePCA(n_components=n_components, alpha=2,max_iter=1000,n_jobs=4,tol=1e-10, verbose=True) # 5min
#
# alpha=2 -> 1hr

decomp = LinearDiscriminantAnalysis(n_components=2) ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 
# ,n_components=30

X_r = decomp.fit_transform(BES_std, Sov)

n_components = X_r.shape[1]

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_sov.index)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     463         else:
#     464             # fit method of arity 2 (supervised transformation)
# --> 465             return self.fit(X, y, **fit_params).transform(X)
#     466
#     467
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\sklearn\discriminant_analysis.py in fit(self, X, y)
#     453             if self.shrinkage is not None:
#     454                 raise NotImplementedError('shrinkage not supported')
# --> 455             self._solve_svd(X, y)
#     456         elif self.solver == 'lsqr':
#     457             self._solve_lsqr(X, y, shrinkage=self.shrinkage)
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\sklearn\discriminant_analysis.py in _solve_svd(self, X, y)
#     360         n_classes = len(self.classes_)
#     361
# --> 362         self.means_ = _class_means(X, y)
#     363         if self.store_covariance:
#     364             self.covariance_ = _class_cov(X, y, self.priors_)
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\sklearn\discriminant_analysis.py in _class_means(X, y)
#      90     cnt = np.bincount(y)
#      91     means = np.zeros(shape=(len(classes), X.shape[1]))
# ---> 92     np.add.at(means, y, X)
#      93     means /= cnt[:, None]
#      94     return means
#
# KeyboardInterrupt:

# %%
# %%time
# 5 mins
## RUN (some variant of) PCA (potentially v slow!)
# n_components = BES_std.shape[1]

# n_components = 2
# (svd_solver='full', n_components='mle',whiten=True)
# decomp = PCA(n_components = n_components,svd_solver='full')
# decomp = FastICA(algorithm='deflation', fun='exp', fun_args=None, max_iter=1000,
#     n_components=None, random_state=None, tol=0.07, w_init=None, whiten=False) # 2h 1min 4s "fast"
# decomp = SparsePCA(n_components=n_components, alpha=2,max_iter=1000,n_jobs=4,tol=1e-10, verbose=True) # 5min
#
# alpha=2 -> 1hr

decomp = LinearDiscriminantAnalysis(n_components=2, solver="eigen",shrinkage = 'auto') ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 
# ,n_components=30

X_r = decomp.fit_transform(BES_std, Sov)

n_components = X_r.shape[1]

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_sov.index)
# Out:
# Wall time: 8min 33s

# %%
# treatdir = BES_data_folder+Treatment
# subdir = BES_data_folder+Treatment+decomp_method
load_suff = "FactorAnalysis"
save = True # False => Load

if save & ( 'decomp' in globals() ): # SAVE    ##( 'decomp' not in globals() )
    decomp_method = str(decomp).split("(")[0] 
    subdir = output_subfolder + decomp_method
    fname = subdir+ os.sep + decomp_method
    # create dir, save decomp object, BES_decomp, BES_std    
    if not os.path.exists(subdir): os.makedirs(subdir)
    with open(fname+".pkl", "wb") as f: pickle.dump( decomp, f )
    BES_decomp.to_hdf(fname+".hdf"        , decomp_method)
    BES_std.to_hdf(   fname+"_std"+".hdf" , decomp_method)
    
else: # LOAD decomp results (default is SAVE)
    decomp_method = load_suff
    subdir = output_subfolder + os.sep + decomp_method    
    fname = subdir + os.sep + decomp_method
    if not os.path.exists(subdir): raise Exception(subdir + ' does not exist!')
    # load decomp object, BES_decomp, BES_std, n_components
    with open(fname+".pkl", "rb") as f: decomp = pickle.load(f) 
    BES_decomp = pd.read_hdf(fname+".hdf")
    BES_std    = pd.read_hdf(fname+"_std"+".hdf")
    n_components = decomp.components_.shape[0]

# %%
(BES_decomp, comp_labels, comp_dict) = display_components(n_components, decomp,
                                                          BES_sov.columns, BES_decomp, manifest, 
                                                          save_folder = subdir,  
                                                          show_first_x_comps= 4, show_histogram = False)

# %%
decomp
# Out:
# LinearDiscriminantAnalysis(n_components=2, priors=None, shrinkage='auto',
#               solver='eigen', store_covariance=False, tol=0.0001)

# %%
x_axis = 0
y_axis = 1

xlim = np.floor( BES_decomp.loc[ :, x_axis ].min() ), np.ceil( BES_decomp.loc[ :, x_axis ].max() )
ylim = np.floor( BES_decomp.loc[ :, y_axis ].min() ), np.ceil( BES_decomp.loc[ :, y_axis ].max() )

# SparsePCA
if decomp_method == 'SparsePCA':
    xlim =  BES_decomp.loc[ :, x_axis ].min() ,  BES_decomp.loc[ :, x_axis ].max() 
    ylim =  BES_decomp.loc[ :, y_axis ].min() ,  BES_decomp.loc[ :, y_axis ].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [1] is not in the [columns]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-cfaa18fb5936> in <module>
#       3
#       4 xlim = np.floor( BES_decomp.loc[ :, x_axis ].min() ), np.ceil( BES_decomp.loc[ :, x_axis ].max() )
# ----> 5 ylim = np.floor( BES_decomp.loc[ :, y_axis ].min() ), np.ceil( BES_decomp.loc[ :, y_axis ].max() )
#       6
#       7 # SparsePCA
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     996         for i, key in enumerate(tup):
#     997             if is_label_like(key) or isinstance(key, tuple):
# --> 998                 section = self._getitem_axis(key, axis=i)
#     999
#    1000                 # we have yielded a scalar ?
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1909
#    1910         # fall thru to straight lookup
# -> 1911         self._validate_key(key, axis)
#    1912         return self._get_label(key, axis=axis)
#    1913
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1796                 raise
#    1797             except:
# -> 1798                 error()
#    1799
#    1800     def _is_scalar_access(self, key):
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in error()
#    1783                 raise KeyError(u"the label [{key}] is not in the [{axis}]"
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#    1787             try:
#
# KeyError: 'the label [1] is not in the [columns]'

# %%
from itertools import cycle

colours = cycle('ycmkgbr')
markers = cycle('v^<>,oD*x+')

cat_col_mar_dict = {} # category-colour-marker dictionary
# basic set of common ones! 
cat_col_mar_dict['Conservative'] = ('b', '.')
cat_col_mar_dict['Conservative Party'] = ('b', '.')
cat_col_mar_dict['The Conservative candidate']       = ('b', 'x')
cat_col_mar_dict['Labour']       = ('r', '.')
cat_col_mar_dict['Labour Party']       = ('r', '.')
cat_col_mar_dict['The Labour candidate']       = ('r', 'x')
cat_col_mar_dict['Green Party']  = ('g', '.')
cat_col_mar_dict['The Green candidate']       = ('g', 'x')
cat_col_mar_dict['Plaid Cymru']  = ('k', '.')
cat_col_mar_dict['The Plaid Cymru candidate']  = ('k', 'x')
cat_col_mar_dict['Scottish National Party']           = ('c', '.')
cat_col_mar_dict['United Kingdom Independence Party'] = ('m', '.')
cat_col_mar_dict['The UKIP candidate'] = ('m', 'x')
cat_col_mar_dict['Liberal Democrat']                         = ('orange', '.')
cat_col_mar_dict['Liberal Democrats']                        = ('orange', '.')
cat_col_mar_dict['The Liberal Democrat candidate']                         = ('orange', 'x')

# %%
# amalgamated_euMIISmall = amalgamated_euMIISmall.astype('category',categories=BES_Panel["euMIISmallW8"].cat.categories)

# %%
# %%time

graph_type = "non_ordinal_scatter/"
folder = output_subfolder +os.sep+ graph_type + os.sep
if not os.path.exists(folder):
    os.makedirs(folder)

dummy_list = ['euMIISmallW8']

# non-ordinal categories
fig_no = 0
for decomp_label_col in dummy_list:
    if decomp_label_col in ["profile_religion","country",
                            'polKnowMay','polKnowOsborne',
                            'polKnowClegg', 'polKnowBercow',
                            'polKnowMiliband', 'registered', 'ns_sec']:
        continue
    
    fig = plt.figure( figsize=(16,10) )

    decomp_label_categories = [ x for x in BES_reduced_with_na.columns if (decomp_label_col + "_") in x ]
    if len(decomp_label_categories) == 0:
        continue
        
#     if (decomp_label_col not in BES_reduced.columns):
#         if decomp_label_col in new_old_col_names.keys(): # variable renamed in transformation
#             decomp_label_categories = new_old_col_names[decomp_label_col]
#         else:
#             continue ## variable removed in transformation
#     else:
#         decomp_label_categories = decomp_label_col        

    # 'No party is best able to handle this issue'
    drop_cat_list = ['profile_education_age', 'profile_ethnicity_White British']
    for drop_cat in drop_cat_list:
        if drop_cat in decomp_label_categories:
            decomp_label_categories.remove(drop_cat)
            
    replace_dict = {'Scottish National Party (SNP)' : 'Scottish National Party',
                    'United Kingdom Independence Party (UKIP)' : 'United Kingdom Independence Party'}

    lab_to_cat = {}
    sample_sizes = {}
    for cat in decomp_label_categories:
        
        lab = re.search('_([^_]+)$',cat).groups()[0]
        if lab in replace_dict.keys(): # replace party name variants with single version
            lab = replace_dict[lab]
        
        if lab not in cat_col_mar_dict.keys(): # try to give parties consistent colour, marker pairs
            cat_col_mar_dict[lab] = (next(colours),next(markers))
        
        sample_sizes[lab] = sum( BES_reduced_with_na[ cat ][Leavers]==1 )
        lab_to_cat[lab] = cat

    for lab in sorted(sample_sizes, key=sample_sizes.get, reverse=True):
        
        samp = sample_sizes[lab]
            
        (col, mar) = cat_col_mar_dict[lab]

        cat_entries = BES_reduced_with_na[ lab_to_cat[lab] ][Leavers]==1
        
        plt.scatter(BES_decomp.loc[ cat_entries, x_axis ],
                    BES_decomp.loc[ cat_entries, y_axis ],
                    c= col,
                    marker=mar,
                    label=lab + "(N="+str(samp)+")",
                    edgecolors=col,
                    alpha = .9 )
    
    plt.xlim(xlim)
    plt.ylim(ylim)    
    
    plt.xlabel( comp_labels[x_axis] )
    plt.ylabel( comp_labels[y_axis] ) 
    plt.legend(prop={'size':8})
    plt.title('Decomposition of BES dataset; labelled variable: ' + decomp_label_col)
    
    fig.savefig( folder+decomp_label_col, bbox_inches='tight' )
    if fig_no >1:
        plt.close()
    fig_no = fig_no + 1
plt.show()

# %%
gc.collect()
# Out:
# 0

# %%
target.cat.categories
# Out:
# Index(['Did not vote', 'Conservative Party', 'Labour Party',
#        'Liberal Democrats', 'Scottish National Party', 'Plaid Cymru',
#        'British National Party (BNP)', 'Green Party', 'Respect',
#        'United Kingdom Independence Party (UKIP)', 'Veritas',
#        'Some other party', 'Don't know'],
#       dtype='object')

# %%
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
# 5        False
# 6        False
# 7         True
# 8         True
# 9         True
# 10        True
# 11       False
# 12        True
# 13        True
# 14        True
# 15       False
# 16        True
# 17       False
# 18        True
# 19       False
# 20        True
# 21        True
# 22        True
# 23        True
# 24       False
# 26       False
# 27        True
# 28        True
# 29        True
# 30        True
#          ...
# 68489    False
# 68490    False
# 68491    False
# 68492     True
# 68493    False
# 68494    False
# 68495    False
# 68496    False
# 68497     True
# 68498     True
# 68499    False
# 68500    False
# 68501    False
# 68502    False
# 68503    False
# 68504    False
# 68505    False
# 68506    False
# 68507     True
# 68508    False
# 68509    False
# 68510    False
# 68511    False
# 68512    False
# 68513    False
# 68514    False
# 68515     True
# 68516    False
# 68517    False
# 68518    False
# Name: profile_past_vote_2005, Length: 58280, dtype: object

# %%
# [x for x in BES_reduced.columns if "profile_past" in x]

# %%
focal_variable = "profile_past_vote_2005"
target = BES_Panel[focal_variable]
train = BES_reduced.drop([x for x in BES_reduced.columns if focal_variable in x],axis=1)
mask = target.notnull() & target.apply(lambda x: x in ['Conservative Party', 'Labour Party',
       'Liberal Democrats'])
target = target[mask]
train = train[mask]

# %%
missing_vals = BES_reduced_with_na[ intersection(train.columns , BES_reduced_with_na.columns) ][mask].isnull()
missing_vals = (missing_vals.sum()/missing_vals.shape[0]).sort_values()
missing_vals.hist(bins=100);

# %%
# train.shape
drop_vars = list(missing_vals[missing_vals>.4].index)
drop_vars
# Out:
# ['countryOfBirth_Northern Ireland',
#  'countryOfBirth_Republic of Ireland',
#  'countryOfBirth_Other: Commonwealth member country',
#  'countryOfBirth_Other: Rest of world',
#  'countryOfBirth_Other: European Union member country',
#  'countryOfBirth_Wales',
#  'countryOfBirth_Scotland',
#  'countryOfBirth_England',
#  'polKnowMilibandW1W2W3_Home secretary',
#  'polKnowMilibandW1W2W3_Speaker of the House of Commons',
#  'polKnowMilibandW1W2W3_Chancellor of the Exchequer',
#  'polKnowMilibandW1W2W3_Deputy Prime Minister',
#  'polKnowMilibandW1W2W3_Leader of the Labour Party',
#  'polKnowCleggW1W2W3_Chancellor of the Exchequer',
#  'polKnowCleggW1W2W3_Speaker of the House of Commons',
#  'polKnowCleggW1W2W3_Leader of the Labour Party',
#  'polKnowCleggW1W2W3_Deputy Prime Minister',
#  'polKnowCleggW1W2W3_Home secretary',
#  'riskScaleW8',
#  'ageW8',
#  'riskTakingW8__Very willing to take risks',
#  'knowf2f3W11W12W14_False',
#  'polAttentionW8__Pay a great deal of attention',
#  'polKnowOsborneW1W2W3_Leader of the Labour Party',
#  'polKnowOsborneW1W2W3_Chancellor of the Exchequer',
#  'polKnowOsborneW1W2W3_Home secretary',
#  'polKnowOsborneW1W2W3_Deputy Prime Minister',
#  'polKnowOsborneW1W2W3_Speaker of the House of Commons',
#  'registeredW8_No',
#  'registeredW8_Yes - another address',
#  'registeredW8_Yes - at $postcode_hidden',
#  'euRefInterestW8__Very interested',
#  'polKnowAssadW5W7W9_Prime Minister of Italy',
#  'polKnowAssadW5W7W9_President of Russia',
#  'polKnowAssadW5W7W9_President of Syria',
#  'polKnowAssadW5W7W9_President of Turkey',
#  'polKnowAssadW5W7W9_Chancellor of Germany',
#  'britishnessW8__Very strongly British',
#  'englishnessW8__Very strongly English',
#  'newspaperW12_The Herald (Glasgow)',
#  'gorW12_East of England',
#  'gorW12_West Midlands',
#  'gorW12_East Midlands',
#  'gorW12_Wales',
#  'gorW12_North East',
#  'achieveReduceImmigDKW12_Yes',
#  'gorW12_South West',
#  'gorW12_Yorkshire and the Humber',
#  'newspaperW12_The Financial Times',
#  'gorW12_Scotland',
#  'newspaperW12_The Daily Star / The Daily Star of Scotland',
#  'newspaperW12_The Express',
#  'newspaperW12_The Independent',
#  'newspaperW12_The Western Mail',
#  'newspaperW12_Other local daily morning newspaper',
#  'newspaperW12_The Mirror / Daily Record',
#  'gorW12_London',
#  'newspaperW12_The Daily Telegraph',
#  'newspaperW12_The Sun',
#  'newspaperW12_Other Newspaper',
#  'newspaperW12_The Guardian',
#  'newspaperW12_The Daily Mail / The Scottish Daily Mail',
#  'newspaperW12_None',
#  'gorW12_South East',
#  'newspaperW12_The Times',
#  'gorW12_North West',
#  'newspaperW12_The Scotsman',
#  'ageW12',
#  'turnoutUKGeneralW8__Very likely that I will vote',
#  'regSatisfactionW8__Very dissatisfied',
#  'efficacyUnderstandW8__Strongly agree',
#  'efficacyPolCareW8__Strongly agree',
#  'changeCostLiveW8__Getting a lot higher',
#  'monarchW8__Strongly agree',
#  'fbUseW12_Yes',
#  'efficacyEUW8__Strongly agree',
#  'twitterUseW12_Yes',
#  'profile_past_vote_2017_United Kingdom Independence Party (UKIP)',
#  'profile_past_vote_2017_Green Party',
#  'profile_past_vote_2017_Plaid Cymru',
#  'profile_past_vote_2017_Liberal Democrat',
#  'profile_past_vote_2017_Labour',
#  'profile_past_vote_2017_Conservative',
#  'electionInterestW12__Very interested',
#  'profile_past_vote_2017_Scottish National Party (SNP)',
#  'europeannessW8__Very strongly European',
#  'likeConW8__Strongly like',
#  'postalapplyW12_Yes',
#  'likeLabW8__Strongly like',
#  'likeCameronW8__Strongly like',
#  'euRefTurnoutRetroW12_Yes',
#  'profile_socgradeW12__E',
#  'profile_socgradeW8__E',
#  'changeNHSW8__Getting a lot better',
#  'changeEconomyW8__Getting a lot better',
#  'dutyToVote2W12__Strongly agree',
#  'partyMemberW12__Yes, I am a member of a party',
#  'sharedContentOnline_5W12_Yes',
#  'sharedContentOnline_3W12_Yes',
#  'sharedContentOnline_4W12_Yes',
#  'partyContact1W8_Yes',
#  'likeUKIPW8__Strongly like',
#  'participation_6W12_Yes',
#  'participation_3W12_Yes',
#  'participation_2W12_Yes',
#  'participation_1W12_Yes',
#  'participation_5W12_Yes',
#  'participation_4W12_Yes',
#  'infoSourceRadioW8__More than 2 hours',
#  'infoSourceTVW8__More than 2 hours',
#  'postalapplyW8_Yes',
#  'changeImmigW8__Getting a lot higher',
#  'likeBorisW8__Strongly like',
#  'infoSourcePaperW8__More than 2 hours',
#  'infoSourceInternetW8__More than 2 hours',
#  'likeFarageW8__Strongly like',
#  'likeConW12__Strongly like',
#  'anyUniW12__Yes, I graduated from higher education',
#  'infoSourcePeopleW8__More than 2 hours',
#  'changeViewW12_Yes',
#  'likeLabW12__Strongly like',
#  'likeMayW12__Strongly like',
#  'houseBuildW12__Strongly support',
#  'immigCulturalW8__Enriches cultural life',
#  'profile_work_statW12_Working full time (30 or more hours per week)',
#  'profile_work_statW12_Working part time (Less than 8 hours a week)',
#  'profile_work_statW12_Retired',
#  'profile_work_statW12_Working part time (8-29 hours a week)',
#  'profile_work_statW12_Unemployed',
#  'profile_work_statW12_Not working',
#  'profile_work_statW12_Full time student',
#  'likeCorbynW8__Strongly like',
#  'infoSourceRadioW12__More than 2 hours',
#  'partyContact1W12_Yes',
#  'changeNHSW12__Getting a lot better',
#  'edlevelW1_W6__Postgrad',
#  'infoSourcePaperW12__More than 2 hours',
#  'euSources_99W8_Yes',
#  'likeLDW8__Strongly like',
#  'likeCorbynW12__Strongly like',
#  'infoSourceInternetW12__More than 2 hours',
#  'immigrantsWelfareStateW8__Strongly agree',
#  'likeUKIPW12__Strongly like',
#  'profile_house_tenureW12_Own (part-own) - through shared ownership scheme (i.e. pay part mortgage, part rent)',
#  'profile_house_tenureW12_Own - outright',
#  'profile_house_tenureW12_Own - with a mortgage',
#  'profile_house_tenureW12_Neither - I live rent-free with my parents, family or friends',
#  'profile_house_tenureW12_Rent - from a private landlord',
#  'profile_house_tenureW12_Rent - from a housing association',
#  'profile_house_tenureW12_Neither - I live with my parents, family or friends but pay some rent to them',
#  'changeEconomyW12__Getting a lot better',
#  'profile_house_tenureW12_Rent - from my local authority',
#  'energyPriceCapW12__Strongly agree',
#  'euUndermineIdentityW8__Strongly agree',
#  'infoSourceTVW12__More than 2 hours',
#  'educationW12_University diploma',
#  'educationW12_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW12_GCE A level or Higher Certificate',
#  'educationW12_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW12_Other technical, professional or higher qualification',
#  'educationW12_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW12_No formal qualifications',
#  'educationW12_City and Guild certificate',
#  'educationW12_Youth training certificate/skillseekers',
#  'educationW12_CSE grades 2-5',
#  'educationW12_Teaching qualification (not degree)',
#  'educationW12_Scottish Higher Certificate',
#  'educationW12_Clerical and commercial',
#  'educationW12_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW12_Recognised trade apprenticeship completed',
#  'educationW12_onc',
#  'educationW12_Scottish Ordinary/ Lower Certificate',
#  'educationW12_City and Guild certificate - advanced',
#  'childBenefitsRepatriateW8__No, not at any level',
#  'beliefTradeoffW8__Strongly agree',
#  'euParlOverRideW8__Strongly agree',
#  'partyIdW8_Labour',
#  'partyIdW8_Green Party',
#  'partyIdW8_Conservative',
#  'partyIdW8_No - none',
#  'partyIdW8_Plaid Cymru',
#  'partyIdW8_Liberal Democrat',
#  'partyIdW8_Scottish National Party (SNP)',
#  'partyIdW8_United Kingdom Independence Party (UKIP)',
#  'EUIntegrationSelfW8__Protect our independence',
#  'likeLDW12__Strongly like',
#  'immigEconW8__Good for economy',
#  'councilHouseW12__Strongly agree',
#  'euCloserW8__Strongly agree',
#  'echrW8__Strongly agree',
#  'UKsovereigntyW8__Strongly agree',
#  'changeCrimeW8__Getting a lot higher',
#  'euMoreW8__Many more',
#  'prefTradeoffW8__Strongly agree',
#  'euLawsLevelW8__Strongly agree',
#  'likeOsborneW8__Strongly like',
#  'satDemUKW8__Very satisfied',
#  'discussPolDaysW8__7 days',
#  'tripleLockW12__Strongly agree',
#  'ukCoopMovementW8__Bad for Britain',
#  'noneuMoreW8__Many more',
#  'profile_religionW12_Yes - Other',
#  'profile_religionW12_Yes - Methodist',
#  'profile_religionW12_Yes - Presbyterian/Church of Scotland',
#  'profile_religionW12_Yes - Roman Catholic',
#  'profile_religionW12_Yes - Church of England/Anglican/Episcopal',
#  'profile_religionW12_Yes - Baptist',
#  'profile_religionW12_Yes - Evangelical /independent/non-denominational',
#  'profile_religionW12_Yes - United Reformed Church',
#  'profile_religionW12_Yes - Islam',
#  'profile_religionW12_Yes - Pentecostal',
#  'profile_religionW12_Yes - Orthodox Christian',
#  'profile_religionW12_Yes - Buddhism',
#  'EUIntegrationSelfW12__Protect our independence',
#  'profile_religionW12_Yes - Hinduism',
#  'profile_religionW12_Yes - Sikhism',
#  'profile_religionW12_Yes - Brethren',
#  'profile_religionW12_Yes - Free Presbyterian',
#  'profile_religionW12_Yes - Judaism',
#  'profile_religionW12_No, I do not regard myself as belonging to any particular religion.',
#  'polKnowMayW1W2W3_Leader of the Labour Party',
#  'polKnowMayW1W2W3_Chancellor of the Exchequer',
#  'polKnowMayW1W2W3_Deputy Prime Minister',
#  'polKnowMayW1W2W3_Speaker of the House of Commons',
#  'polKnowMayW1W2W3_Home secretary',
#  'noChanceCoalitionSNPW12_Yes',
#  'noChanceCoalitionGrnW12_Yes',
#  'noChanceCoalitionPCW12_Yes',
#  'noChanceCoalitionNoneW12_Yes',
#  'noChanceCoalitionLDW12_Yes',
#  'noChanceCoalitionUKIPW12_Yes',
#  'noChanceCoalitionLabW12_Yes',
#  'noChanceCoalitionConW12_Yes',
#  'euLeaveVoiceW8__Much higher',
#  'asylumMoreW8__Many more',
#  'euMemberJoinW8__Strongly agree',
#  'studentsMoreW8__Many more',
#  'likeSturgeonW12__Strongly like',
#  'euRefpastVoteW12_Leave the EU',
#  'partyIdW12_Green Party',
#  'partyIdW12_Conservative',
#  'partyIdW12_Labour',
#  'partyIdW12_Plaid Cymru',
#  'partyIdW12_No - none',
#  'partyIdW12_United Kingdom Independence Party (UKIP)',
#  'partyIdW12_Scottish National Party (SNP)',
#  'partyIdW12_Liberal Democrat',
#  'ukCoopTradeW8__Bad for Britain',
#  'euSources_111W8_Yes',
#  'benefitsToMigrantsW8__Never',
#  'familiesMoreW8__Many more',
#  'effectsEUWorkersW8__Much better',
#  'winConstituencyUKIPW12__100 - Very likely to win',
#  'effectsEUTerrorW8__Much higher',
#  'likeGrnW8__Strongly like',
#  'winConstituencyLabW12__100 - Very likely to win',
#  'winConstituencyLDW12__100 - Very likely to win',
#  'campaigninfoRemainW8__Strongly agree',
#  'euRefVoteW8_Leave the EU',
#  'cutsTooFarNHSW12__Gone much too far',
#  'winConstituencyGreenW12__98.0',
#  'campaigninfoLeaveW8__Strongly agree',
#  'euRefVoteW12_Leave the EU',
#  'subjClassW12W14_Yes, working class',
#  'subjClassW12W14_Yes, middle class',
#  'subjClassW12W14_No',
#  'effectsEUImmigrationW8__Much higher',
#  'leaveImpactBritainW8__A very large impact',
#  'keepNukesW12__Strongly agree',
#  'euPreventWarW8__Strongly agree',
#  'winConstituencyConW12__100 - Very likely to win',
#  'discussPolDaysW12__7 days',
#  'mii_catW8_health',
#  'mii_catW8_austerity',
#  'mii_catW8_europe',
#  'mii_catW8_inflation',
#  'mii_catW8_pol value-auth',
#  'mii_catW8_environment',
#  'mii_catW8_housing',
#  'mii_catW8_inequality',
#  'mii_catW8_terrorism',
#  'mii_catW8_election outcome',
#  'mii_catW8_war',
#  'mii_catW8_transport/infrastructure',
#  'mii_catW8_immigration',
#  'mii_catW8_economy-general',
#  'mii_catW8_pol values-right',
#  'mii_catW8_pensions/ageing',
#  'mii_catW8_pol-neg',
#  'mii_catW8_social care',
#  'mii_catW8_Referendum unspecified',
#  'mii_catW8_societal divides',
#  'mii_catW8_morals',
#  'mii_catW8_devolution',
#  'mii_catW8_nat ident, goals-loss',
#  'mii_catW8_taxation',
#  'mii_catW8_pol values-left',
#  'mii_catW8_racism/discrimination',
#  'mii_catW8_living costs',
#  'mii_catW8_pol values-liberal',
#  'mii_catW8_economy-personal',
#  'mii_catW8_scot-ind',
#  'mii_catW8_crime',
#  'mii_catW8_uncoded',
#  'mii_catW8_welfare',
#  'mii_catW8_partisan-neg',
#  'mii_catW8_other',
#  'mii_catW8_defence',
#  'mii_catW8_debt/deficit',
#  'mii_catW8_education',
#  'mii_catW8_poverty',
#  'mii_catW8_unemployment',
#  'mii_catW8_international trade',
#  'mii_catW8_asylum',
#  'mii_catW8_constitutional',
#  'mii_catW8_foreign affairs',
#  'euUKRichW8__Strongly agree',
#  'handleEUNegotiateW12__Very well',
#  'polKnowKerryW2W3W4W7W9_Secretary General of the United Nations',
#  'polKnowKerryW2W3W4W7W9_Prime Minister of Israel',
#  'polKnowKerryW2W3W4W7W9_Prime Minister of Canada',
#  'polKnowKerryW2W3W4W7W9_United States Secretary of State',
#  'polKnowKerryW2W3W4W7W9_President of France',
#  'likeGrnW12__Strongly like',
#  'immigSelfW8__Allow many more',
#  'euRedTapeW8__Strongly agree',
#  'cutsTooFarNationalW12__Gone much too far',
#  'effectsEUNHSW8__Much better',
#  'ukCoopEuroW8__Bad for Britain',
#  'housing_Buying leasehold/freehold on a mortgage',
#  'housing_Own the leasehold/freehold outright',
#  'housing_Rented from private landlord',
#  'housing_It belongs to a Housing Association',
#  'housing_Rented from local authority',
#  'conLookAfterWCW12__Very closely',
#  'conLookAfterMCW12__Very closely',
#  'effectsEUEconW8__Much better',
#  'labLookAfterWCW12__Very closely',
#  'euPriorityBalanceW12__Control immigration',
#  'mii_catW12_pensions/ageing',
#  'mii_catW12_education',
#  'mii_catW12_crime',
#  'mii_catW12_transport/infrastructure',
#  'mii_catW12_Referendum unspecified',
#  'mii_catW12_housing',
#  'mii_catW12_austerity',
#  'mii_catW12_poverty',
#  'mii_catW12_uncoded',
#  'mii_catW12_unemployment',
#  'mii_catW12_welfare',
#  'mii_catW12_scot-ind',
#  'mii_catW12_debt/deficit',
#  'mii_catW12_pol-neg',
#  'mii_catW12_devolution',
#  'changeEducationW8__Getting a lot better',
#  'mii_catW12_nat ident, goals-loss',
#  'mii_catW12_societal divides',
#  'mii_catW12_foreign affairs',
#  'mii_catW12_morals',
#  'mii_catW12_pol values-liberal',
#  'mii_catW12_living costs',
#  'mii_catW12_defence',
#  'mii_catW12_racism/discrimination',
#  'mii_catW12_environment',
#  'mii_catW12_pol values-right',
#  'mii_catW12_asylum',
#  'mii_catW12_pol value-auth',
#  'mii_catW12_international trade',
#  'mii_catW12_constitutional',
#  'mii_catW12_inflation',
#  'mii_catW12_europe',
#  'mii_catW12_terrorism',
#  'mii_catW12_health',
#  'mii_catW12_economy-general',
#  'mii_catW12_immigration',
#  'mii_catW12_war',
#  'mii_catW12_election outcome',
#  'mii_catW12_other',
#  'mii_catW12_taxation',
#  'mii_catW12_economy-personal',
#  'mii_catW12_partisan-neg',
#  'mii_catW12_inequality',
#  'mii_catW12_social care',
#  'mii_catW12_pol values-left',
#  'remainToneW8__5 - Hope',
#  'effectsEUTradeW8__Much higher',
#  'changeNHSLabW12__Getting a lot better',
#  'effectsEUUnemploymentW8__Much higher',
#  'edlevelW12__Postgrad',
#  'socialPressureVoteW12__Strongly agree',
#  'profile_work_organisationW1_W3_Self-employed',
#  'profile_work_organisationW1_W3_Private sector firm or company (e.g. limited companies and Plcs)',
#  'profile_work_organisationW1_W3_Other public sector employer (e.g. Central Government)',
#  'profile_work_organisationW1_W3_Nationalised industry or public corporation (e.g. Post Office)',
#  'profile_work_organisationW1_W3_Have never worked',
#  'profile_work_organisationW1_W3_Charity/voluntary sector',
#  'labLookAfterMCW12__Very closely',
#  'enviroProtectionW12__Gone much too far',
#  'ukCoopWorkersW8__Bad for Britain',
#  'likeSNPW12__Strongly like',
#  'labUnitedW12__Very united',
#  'polKnowBercowW1W2W3_Speaker of the House of Commons',
#  'polKnowBercowW1W2W3_Home secretary',
#  'polKnowBercowW1W2W3_Chancellor of the Exchequer',
#  'polKnowBercowW1W2W3_Leader of the Labour Party',
#  'polKnowBercowW1W2W3_Deputy Prime Minister',
#  'changeEconomyLabW12__Getting a lot better',
#  'knowf2f2W11W12W14_False',
#  'leaveToneW8__5 - Hope',
#  'proConRemainW8__7- Upsides of remaining',
#  'conSupportW8__Mainly leave',
#  'majorityPartyConW12__Very likely',
#  'proConLeaveW8__7- Upsides of leaving',
#  'conUnitedW12__Very united',
#  'conUnitedW8__Very united',
#  'leaveImpactSelfW8__A very large impact',
#  'majorityPartyLabW12__Very likely',
#  'businessSupportW8__Mainly leave',
#  'effectsEUFinanceW8__Much better',
#  'responsibleDebtDontKnowW4_Yes',
#  'tryReduceImmigDKW4_Yes',
#  'achieveReduceImmigDKW4_Yes',
#  'tryReduceInequalityDKW4_Yes',
#  'successReduceInequalityDKW4_Yes',
#  'satDemEUW8__Very satisfied',
#  'cutsTooFarLocalW12__Gone much too far',
#  'changeEducationW12__Getting a lot better',
#  'partyIdStrengthW8__Not very strong',
#  'fbUseW4_Yes',
#  'privatTooFarW12__Gone much too far',
#  'polAttentionW4__Pay a great deal of attention',
#  'twitterUseW4_Yes',
#  'ageW1',
#  'ukCitizenW1_Yes',
#  'euCitizenW1_Yes',
#  'commonwealthCitizenW1_Yes',
#  'otherCitizenW1_Yes',
#  'responsibleDebtDontKnowW1_Yes',
#  'changeEducationLabW12__Getting a lot better',
#  'responsibleDebtDontKnowW2_Yes',
#  'gorW2_East of England',
#  'gorW2_East Midlands',
#  'gorW2_North East',
#  'gorW2_Scotland',
#  'gorW2_North West',
#  'gorW2_London',
#  'gorW2_Wales',
#  'gorW2_Yorkshire and the Humber',
#  'gorW2_West Midlands',
#  'gorW2_South East',
#  'gorW2_South West',
#  'labUnitedW8__Very united',
#  'polAttentionW1__Pay a great deal of attention',
#  'efficacyVoteEffortW4__Strongly agree',
#  'registeredW4_No',
#  'registeredW4_Yes - another address',
#  'registeredW4_Yes - at $postcode_hidden',
#  'dutyToVote2W4__Strongly agree',
#  'britishnessW4__Very strongly British',
#  'polAttentionW2__Pay a great deal of attention',
#  'visitPartySiteW4_Yes',
#  'econPersonalRetroW4__Got a lot better',
#  'achieveReduceImmigDKW9_Yes',
#  'ageW9',
#  'efficacyEnjoyVoteW4__Strongly agree',
#  'efficacyNotUnderstandW4__Strongly agree',
#  'turnoutUKGeneralW4__Very likely that I will vote',
#  'twitterUseW5_Yes',
#  'fbUseW5_Yes',
#  'euRefTurnoutRetroW9_Yes',
#  'profile_newspaperW13_The Sun',
#  'profile_newspaperW13_The Times',
#  'profile_newspaperW13_The Daily Telegraph',
#  'profile_newspaperW13_The Mirror / Daily Record',
#  'profile_newspaperW13_Other local daily morning newspaper',
#  'profile_newspaperW13_The Herald (Glasgow)',
#  'profile_newspaperW13_The Independent',
#  'profile_newspaperW13_The Daily Star / The Daily Star of Scotland',
#  'profile_newspaperW13_The Guardian',
#  'profile_newspaperW13_The Financial Times',
#  'profile_newspaperW13_The Scotsman',
#  'profile_newspaperW13_The Western Mail',
#  'profile_newspaperW13_The Express',
#  'profile_newspaperW13_The Daily Mail / The Scottish Daily Mail',
#  'profile_newspaperW13_Other Newspaper',
#  'profile_marital_statW13_Married',
#  'profile_newspaperW13_None',
#  'profile_marital_statW13_Never married',
#  'profile_marital_statW13_Living as married',
#  'profile_marital_statW13_Widowed',
#  'profile_marital_statW13_Separated (after being married)',
#  'profile_marital_statW13_Divorced',
#  'ageW13',
#  'profile_marital_statW13_Civil Partnership',
#  'euroTurnoutRetroW2_Yes, I voted',
#  'englishnessW4__Very strongly English',
#  'electionInterestW5__Very interested',
#  'econPersonalRetroW1__Got a lot better',
#  'genElecTurnoutRetroW13_Yes',
#  'sharedContentOnline_3W4_Yes',
#  'sharedContentOnline_4W4_Yes',
#  'sharedContentOnline_5W4_Yes',
#  'efficacyVoteEffortW2__Strongly agree',
#  'electionInterestW4__Very interested',
#  'responsibleCostLiveDontKnowW4_Yes',
#  'changeCostLiveW4__Getting a lot higher',
#  'trustMPsW4__A great deal of trust',
#  'headHouseholdPastW1_My mother',
#  'headHouseholdPastW1_My father',
#  'headHouseholdPastW1_Someone else',
#  'headHouseholdPastW1_No one in my house worked',
#  'generalElectionVoteW12_Scottish National Party (SNP)',
#  'generalElectionVoteW12_Labour',
#  'generalElectionVoteW12_Liberal Democrat',
#  'generalElectionVoteW12_United Kingdom Independence Party (UKIP)',
#  'generalElectionVoteW12_Green Party',
#  'generalElectionVoteW12_Plaid Cymru',
#  'generalElectionVoteW12_Conservative',
#  'passportNeverW9_Yes',
#  'passportOtherW9_Yes',
#  'passportUKW9_Yes',
#  'passportExpiredW9_Yes',
#  'travelEUW9_Yes',
#  'dutyToVote2W1__Strongly agree',
#  'likeCameronW4__Strongly like',
#  'efficacyNotUnderstandW2__Strongly agree',
#  'efficacyNotUnderstandW1__Strongly agree',
#  'efficacyEnjoyVoteW2__Strongly agree',
#  'econPersonalRetroW2__Got a lot better',
#  'regSatisfactionW4__Very dissatisfied',
#  'postalapplyW5_Yes',
#  'EUIntegrationUKIPW8__Protect our independence',
#  'registeredW13_No',
#  'registeredW13_Yes - at $postcode_hidden',
#  'registeredW13_Yes - another address',
#  'electionInterestW13__Very interested',
#  'responsibleCostLiveDontKnowW1_Yes',
#  'changeCostLiveW1__Getting a lot higher',
#  'efficacyNoMatterW4__Strongly agree',
#  'visitPartySiteW5_Yes',
#  'participation_3W13_Yes',
#  'participation_4W13_Yes',
#  'britishnessW9__Very strongly British',
#  'dutyToVote2W2__Strongly agree',
#  'participation_1W13_Yes',
#  'participation_5W13_Yes',
#  'participation_2W13_Yes',
#  'sharedContentOnline_5W5_Yes',
#  'sharedContentOnline_4W5_Yes',
#  'sharedContentOnline_3W5_Yes',
#  'govtHandoutsW4__Strongly agree',
#  'trustMPsW1__A great deal of trust',
#  'polAttentionW13__Pay a great deal of attention',
#  'britishnessW1__Very strongly British',
#  'efficacyPolCareW4__Strongly agree',
#  'gorW13_South East',
#  'gorW13_Scotland',
#  'gorW13_East Midlands',
#  'gorW13_London',
#  'gorW13_Wales',
#  'gorW13_North East',
#  'gorW13_West Midlands',
#  'gorW13_North West',
#  'gorW13_East of England',
#  'gorW13_South West',
#  'gorW13_Yorkshire and The Humber',
#  'englishnessW9__Very strongly English',
#  'participation_2W5_Yes',
#  'participation_4W5_Yes',
#  'participation_3W5_Yes',
#  'participation_5W5_Yes',
#  'participation_6W5_Yes',
#  'participation_1W5_Yes',
#  'britishnessW2__Very strongly British',
#  'businessBonusW4__Strongly agree',
#  'approveUKGovtW4__Strongly approve',
#  'changeCostLiveW2__Getting a lot higher',
#  'responsibleCostLiveDontKnowW2_Yes',
#  'efficacyUnderstandW4__Strongly agree',
#  'LRAL_mii_catW8_Lib-auth',
#  'small_mii_catW8_Europe',
#  'small_mii_catW8_Other lib-auth',
#  'LRAL_mii_catW8_Left-right',
#  'LRAL_mii_catW8_General-negativity',
#  'small_mii_catW8_Immigration',
#  'small_mii_catW8_Economy',
#  'small_mii_catW8_Inequality',
#  'small_mii_catW8_Other Left-right',
#  'small_mii_catW8_Environment',
#  'small_mii_catW8_Negativity',
#  'small_mii_catW8_Health',
#  'small_mii_catW8_Terrorism',
#  'small_mii_catW8_Austerity/spending',
#  'likeMilibandW4__Strongly like',
#  'likeCameronW1__Strongly like',
#  'trustMPsW2__A great deal of trust',
#  'howDidYouFillRegFormW4_Yes - filled it in myself',
#  'howDidYouFillRegFormW4_I am not aware of a registration form',
#  'howDidYouFillRegFormW4_No - someone else filled it in on my behalf',
#  'efficacyUnderstandW2__Strongly agree',
#  'turnoutUKGeneralW2__Very likely that I will vote',
#  'likeCleggW4__Strongly like',
#  'euRefTurnoutRetroW13_Yes',
#  'efficacyNotUnderstandW9__Strongly agree',
#  'turnoutUKGeneralW1__Very likely that I will vote',
#  'likeGoveW8__Strongly like',
#  'polPreferToFightW5__Strongly agree',
#  'englishnessW2__Very strongly English',
#  'likeCameronW2__Strongly like',
#  'partyContact1W4_Yes',
#  'englishnessW1__Very strongly English',
#  'euLeaveBigBusinessW8__Much more likely',
#  'EUIntegrationConW8__Protect our independence',
#  'polForTheRichW4__Strongly agree',
#  'approveUKGovtW1__Strongly approve',
#  'responsibleEconDontKnowW4_Yes',
#  'changeEconomyW4__Getting a lot better',
#  'econGenRetroW4__Got a lot better',
#  'happyEULeaveW9__Extremely happy',
#  'responsibleEconDontKnowW1_Yes',
#  'changeEconomyW1__Getting a lot better',
#  'immigrantsWelfareStateW4__Strongly agree',
#  'efficacyPolCareW1__Strongly agree',
#  'europeannessW9__Very strongly European',
#  'infoSourcePeopleW5__More than 2 hours',
#  'approveUKGovtW2__Strongly approve',
#  'efficacyUnderstandW1__Strongly agree',
#  'econGenRetroW1__Got a lot better',
#  'difficultBlameCoalitionW4__Strongly agree',
#  'govtHandoutsW1__Strongly agree',
#  'smallPartyWastedVoteW4__Strongly agree',
#  'likeCleggW1__Strongly like',
#  'likeCameronW5__Strongly like',
#  'likeMilibandW2__Strongly like',
#  'coalitionDontDeliverW4__Strongly agree',
#  'infoSourceRadioW4__More than 2 hours',
#  'likeCleggW2__Strongly like',
#  'businessBonusW1__Strongly agree',
#  'likeMilibandW1__Strongly like',
#  'businessBonusW2__Strongly agree',
#  'labSupportW8__Mainly leave',
#  'efficacyUnderstandW9__Strongly agree',
#  'infoSourceRadioW5__More than 2 hours',
#  'anyUniW9__Yes, I graduated from higher education',
#  'infoSourcePaperW4__More than 2 hours',
#  'infoSourceTVW4__More than 2 hours',
#  'changeEconomyW2__Getting a lot better',
#  'responsibleEconDontKnowW2_Yes',
#  'likeFarageW4__Strongly like',
#  'infoSourcePaperW5__More than 2 hours',
#  'efficacyNoMatterW9__Strongly agree',
#  'govtHandoutsW2__Strongly agree',
#  'partydiffconlabW5__There is not much difference between them',
#  'changeNHSW4__Getting a lot better',
#  'responsibleNHSDontKnowW4_Yes',
#  'efficacyPolCareW2__Strongly agree',
#  'likeMilibandW5__Strongly like',
#  'infoSourceInternetW5__More than 2 hours',
#  'profile_education_ageW13__Still at school/Full time student',
#  'infoSourceTVW5__More than 2 hours',
#  'econPersonalRetroW13__Got a lot better',
#  'trustMPsW9__A great deal of trust',
#  'reasonForUnemploymentW4__Strongly agree',
#  'econGenRetroW2__Got a lot better',
#  'efficacyPolCareW9__Strongly agree',
#  'likeCleggW5__Strongly like',
#  'infoSourceInternetW4__More than 2 hours',
#  'polForTheRichW1__Strongly agree',
#  'likeCameronW9__Strongly like',
#  'coalitionDontDeliverW2__Strongly agree',
#  'regSatisfactionW2__Very dissatisfied',
#  'polKnowMerkelW2W3W4_Chancellor of Germany',
#  'polKnowMerkelW2W3W4_Prime Minister of Italy',
#  'polKnowMerkelW2W3W4_President of Turkey',
#  'polKnowMerkelW2W3W4_President of Syria',
#  'polKnowMerkelW2W3W4_President of Russia',
#  'discussAskVoteNoneW2_Yes',
#  'askVoteLivingWithW2_Yes',
#  'askVoteOtherW2_Yes',
#  'anyUniW13__Yes, I graduated from higher education',
#  'nonelecParticipation_99W6_Yes',
#  'allSourceIncome_99W6_Yes',
#  'turnoutUKGeneralW9__Very likely that I will vote',
#  'likeFarageW5__Strongly like',
#  'likeBorisW9__Strongly like',
#  'likeConW9__Strongly like',
#  'likeConW13__Strongly like',
#  'decidedVoteW4_No, not decided yet',
#  'coalitionDontDeliverW1__Strongly agree',
#  'difficultBlameCoalitionW2__Strongly agree',
#  'likeLabW13__Strongly like',
#  'immigrantsWelfareStateW2__Strongly agree',
#  'infoSourcePeopleW4__More than 2 hours',
#  'racismAmountW4__A lot',
#  'immigCulturalW4__Enriches cultural life',
#  'smallVoterPrefW4__Strongly agree',
#  'likeLabW9__Strongly like',
#  'genElecTurnoutRetroW6_Yes',
#  'likeMayW13__Strongly like',
#  'fbUseW6_Yes',
#  'likeUKIPW9__Strongly like',
#  'difficultBlameCoalitionW1__Strongly agree',
#  'profile_socgradeW13__E',
#  'turkeyW8__Much better',
#  'polForTheRichW2__Strongly agree',
#  'approveUKGovtW9__Strongly approve',
#  'likeFarageW9__Strongly like',
#  'immigrantsWelfareStateW1__Strongly agree',
#  'polAttentionW6__Pay a great deal of attention',
#  'likeCorbynW13__Strongly like',
#  'immigUKIPW8__Allow many more',
#  'partyContact1W13_Yes',
#  'twitterUseW6_Yes',
#  'euSources_1W8_Yes',
#  'discussPolDaysW2__7 days',
#  'immigCulturalW1__Enriches cultural life',
#  'al3W13__Strongly agree',
#  'approveEUW9__Strongly approve',
#  'likeFarageW2__Strongly like',
#  'registeredW6_Yes - another address',
#  'responsibleNHSDontKnowW1_Yes',
#  'registeredW6_Yes - at $postcode_hidden',
#  'registeredW6_No',
#  'lr4W13__Strongly agree',
#  'changeNHSW1__Getting a lot better',
#  'reasonForUnemploymentW2__Strongly agree',
#  'partyIdStrengthW12__Not very strong',
#  'responsibleNHSDontKnowW2_Yes',
#  'changeNHSW2__Getting a lot better',
#  'conGovTrustW5__ Would do a good job',
#  'riskPovertyW4__Very likely',
#  'immigCulturalW2__Enriches cultural life',
#  'likeFarronW12__Strongly like',
#  'profile_work_statW13_Working full time (30 or more hours per week)',
#  'profile_work_statW13_Retired',
#  'profile_work_statW13_Working part time (8-29 hours a week)',
#  'profile_work_statW13_Not working',
#  'profile_work_statW13_Full time student',
#  'profile_work_statW13_Unemployed',
#  'profile_work_statW13_Working part time (Less than 8 hours a week)',
#  'certaintyEUUKIPW8__Very certain',
#  'reasonForUnemploymentW1__Strongly agree',
#  'electionInterestW6__Very interested',
#  'antiIntellectualW9__Strongly agree',
#  'efficacyVoteEffortW6__Strongly agree',
#  'dutyToVote2W6__Strongly agree',
#  'labGovTrustW5__ Would do a good job',
#  'profile_house_tenureW13_Own (part-own) - through shared ownership scheme (i.e. pay part mortgage, part rent)',
#  'profile_house_tenureW13_Rent - from a private landlord',
#  'profile_house_tenureW13_Neither - I live rent-free with my parents, family or friends',
#  'profile_house_tenureW13_Neither - I live with my parents, family or friends but pay some rent to them',
#  'profile_house_tenureW13_Rent - from my local authority',
#  'profile_house_tenureW13_Rent - from a housing association',
#  'profile_house_tenureW13_Own - outright',
#  'profile_house_tenureW13_Own - with a mortgage',
#  'responsibleImmigDontKnowW4_Yes',
#  'changeImmigW4__Getting a lot higher',
#  'likeCorbynW9__Strongly like',
#  'educationW13_No formal qualifications',
#  'educationW13_City and Guild certificate',
#  'educationW13_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW13_Scottish Higher Certificate',
#  'educationW13_Scottish Ordinary/ Lower Certificate',
#  'educationW13_University diploma',
#  'educationW13_Other technical, professional or higher qualification',
#  'educationW13_CSE grades 2-5',
#  'educationW13_onc',
#  'educationW13_Recognised trade apprenticeship completed',
#  'educationW13_Clerical and commercial',
#  'educationW13_Teaching qualification (not degree)',
#  'educationW13_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW13_City and Guild certificate - advanced',
#  'educationW13_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW13_Youth training certificate/skillseekers',
#  'educationW13_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW13_GCE A level or Higher Certificate',
#  'polKnowPutinW2W3W4_Prime Minister of Italy',
#  'polKnowPutinW2W3W4_President of Syria',
#  'voteMethodW9__By proxy (someone else voted on my behalf)',
#  'polKnowPutinW2W3W4_President of Turkey',
#  'polKnowPutinW2W3W4_Chancellor of Germany',
#  'polKnowPutinW2W3W4_President of Russia',
#  'winConstituencyLDW4__100 - Very likely to win',
#  'participation_2W6_Yes',
#  'participation_3W6_Yes',
#  'participation_1W6_Yes',
#  'participation_4W6_Yes',
#  'immigrationLevelW4__Increased a lot',
#  'immigEconW4__Good for economy',
#  'EUIntegrationConW12__Protect our independence',
#  'efficacyNotUnderstandW6__Strongly agree',
#  'ptvUKIPW9__Very likely',
#  'efficacyEnjoyVoteW6__Strongly agree',
#  'partyMemberW6__Yes, I am a member of a party',
#  'noChanceCoalitionLabW4_Yes',
#  'noChanceCoalitionNoneW4_Yes',
#  'noChanceCoalitionUKIPW4_Yes',
#  'noChanceCoalitionLDW4_Yes',
#  'noChanceCoalitionGrnW4_Yes',
#  'noChanceCoalitionPCW4_Yes',
#  'noChanceCoalitionSNPW4_Yes',
#  'noChanceCoalitionConW4_Yes',
#  'singlePartyEffectiveW4__Strongly agree',
#  'ptvUKIPW13__Very likely',
#  'riskPovertyW1__Very likely',
#  'EUIntegrationSelfW9__Protect our independence',
#  'likeUKIPW13__Strongly like',
#  'trustMPsW6__A great deal of trust',
#  'infoSourceRadioW13__More than 2 hours',
#  'likeCameronW6__Strongly like',
#  'coalitionInTuneW4__Strongly agree',
#  'riskPovertyW2__Very likely',
#  'partyIdW4_British National Party (BNP)',
#  'partyIdW4_Conservative',
#  'partyIdW4_No - none',
#  'partyIdW4_Liberal Democrat',
#  'partyIdW4_Scottish National Party (SNP)',
#  'partyIdW4_United Kingdom Independence Party (UKIP)',
#  'partyIdW4_Green Party',
#  'partyIdW4_Labour',
#  'partyIdW4_Plaid Cymru',
#  'changeViewW13_Yes',
#  'discussPolDaysW4__7 days',
#  'lr5W13__Strongly agree',
#  'conFearW4_Yes',
#  'conPrideW4_Yes',
#  'conNoneW4_Yes',
#  'conHopeW4_Yes',
#  'conAngryW4_Yes',
#  'efficacyNoMatterW6__Strongly agree',
#  'LRAL_mii_catW12_Lib-auth',
#  'small_mii_catW12_Environment',
#  'small_mii_catW12_Austerity/spending',
#  'small_mii_catW12_Other lib-auth',
#  'small_mii_catW12_Inequality',
#  'small_mii_catW12_Negativity',
#  'small_mii_catW12_Economy',
#  'small_mii_catW12_Immigration',
#  'small_mii_catW12_Health',
#  'small_mii_catW12_Terrorism',
#  'small_mii_catW12_Europe',
#  'LRAL_mii_catW12_Left-right',
#  'LRAL_mii_catW12_General-negativity',
#  'small_mii_catW12_Other Left-right',
#  'ldGovTrustW5__ Would do a good job',
#  'noChanceCoalitionConW5_Yes',
#  'noChanceCoalitionLDW5_Yes',
#  'noChanceCoalitionSNPW5_Yes',
#  'noChanceCoalitionLabW5_Yes',
#  'noChanceCoalitionGrnW5_Yes',
#  'noChanceCoalitionPCW5_Yes',
#  'noChanceCoalitionNoneW5_Yes',
#  'noChanceCoalitionUKIPW5_Yes',
#  'lr3W13__Strongly agree',
#  'lr2W13__Strongly agree',
#  'likeOsborneW9__Strongly like',
#  'certaintyEUConW8__Very certain',
#  'disabilityW6_Yes',
#  'discussPolDaysW5__7 days',
#  'polPreferToFightW6__Strongly agree',
#  'infoSourceInternetW13__More than 2 hours',
#  'singlePartyEffectiveW2__Strongly agree',
#  'euRefVoteW9_Leave the EU',
#  'euroTurnoutW1__Very likely that I will vote',
#  'responsibleImmigDontKnowW2_Yes',
#  'changeImmigW2__Getting a lot higher',
#  'regSatisfactionW6__Very dissatisfied',
#  'profile_religionW13_Yes - Islam',
#  'profile_religionW13_Yes - Orthodox Christian',
#  'profile_religionW13_Yes - Presbyterian/Church of Scotland',
#  'profile_religionW13_Yes - Other',
#  'profile_religionW13_Yes - Roman Catholic',
#  'profile_religionW13_Yes - Methodist',
#  'profile_religionW13_Yes - Judaism',
#  'profile_religionW13_Yes - Baptist',
#  'profile_religionW13_No, I do not regard myself as belonging to any particular religion.',
#  'profile_religionW13_Yes - Evangelical /independent/non-denominational',
#  'profile_religionW13_Yes - Buddhism',
#  'profile_religionW13_Yes - Pentecostal',
#  'profile_religionW13_Yes - Brethren',
#  'profile_religionW13_Yes - United Reformed Church',
#  'profile_religionW13_Yes - Church of England/Anglican/Episcopal',
#  'profile_religionW13_Yes - Sikhism',
#  'profile_religionW13_Yes - Free Presbyterian',
#  'profile_religionW13_Yes - Hinduism',
#  'likeLDW13__Strongly like',
#  'winConstituencyConW4__100 - Very likely to win',
#  'lr4W6__Strongly agree',
#  'infoSourcePeopleW13__More than 2 hours',
#  'immigEconW1__Good for economy',
#  'al3W6__Strongly agree',
#  'coalitionInTuneW1__Strongly agree',
#  'satDemUKW1__Very satisfied',
#  'satDemUKW9__Very satisfied',
#  'coalitionInTuneW2__Strongly agree',
#  'al4W13__Strongly agree',
#  'infoSourceTVW13__More than 2 hours',
#  'likeMilibandW6__Strongly like',
#  'infoSourcePaperW13__More than 2 hours',
#  'singlePartyEffectiveW1__Strongly agree',
#  'likeFarageW6__Strongly like',
#  'efficacyUnderstandW6__Strongly agree',
#  'responsibleImmigDontKnowW1_Yes',
#  'labPrideW4_Yes',
#  'labHopeW4_Yes',
#  'labFearW4_Yes',
#  'labNoneW4_Yes',
#  'labAngryW4_Yes',
#  'satDemUKW2__Very satisfied',
#  'changeImmigW1__Getting a lot higher',
#  'al5W13__Strongly agree',
#  'efficacyTooMuchEffortW1__Strongly agree',
#  'partyIdW13_Green Party',
#  'partyIdW13_Plaid Cymru',
#  'partyIdW13_United Kingdom Independence Party (UKIP)',
#  'partyIdW13_Liberal Democrat',
#  'partyIdW13_No - none',
#  'partyIdW13_Labour',
#  'partyIdW13_Scottish National Party (SNP)',
#  'partyIdW13_Conservative',
#  'winConstituencyLDW5__100 - Very likely to win',
#  'partyContact1W6_Yes',
#  'winConstituencyLabW4__100 - Very likely to win',
#  'likeCleggW6__Strongly like',
#  'preferOtherGovW4__Ranked fifth',
#  'preferConCoalitionW4__Ranked fifth',
#  'preferConMajorityW4__Ranked fifth',
#  'ptvConW13__Very likely',
#  'preferLabMajorityW4__Ranked fifth',
#  'preferLabCoalitionW4__Ranked fifth',
#  'labToneW5__5 - Focused mainly on putting forward their own policies and personalities',
#  'ptvLabW13__Very likely',
#  'efficacyPolCareW6__Strongly agree',
#  'efficacyTooMuchEffortW4__Strongly agree',
#  'efficacyTooMuchEffortW2__Strongly agree',
#  'nonelecParticipation_4W6_Yes',
#  'nonelecParticipation_5W6_Yes',
#  'nonelecParticipation_3W6_Yes',
#  'nonelecParticipation_1W6_Yes',
#  'nonelecParticipation_6W6_Yes',
#  'nonelecParticipation_8W6_Yes',
#  'howDidYouFillRegFormW6_No - someone else filled it in on my behalf',
#  'nonelecParticipation_7W6_Yes',
#  'howDidYouFillRegFormW6_Yes - filled it in myself',
#  'nonelecParticipation_2W6_Yes',
#  'howDidYouFillRegFormW6_I am not aware of a registration form',
#  'smallPartyWastedVoteW6__Strongly agree',
#  'immigEconW2__Good for economy',
#  'satDemUKW4__Very satisfied',
#  'ptvConW9__Very likely',
#  'conToneW5__5 - Focused mainly on putting forward their own policies and personalities',
#  'econGenRetroW13__Got a lot better',
#  'profile_work_typeW7W10_Foreman or Supervisor of Other Workers (e.g. building site foreman, supervisor of cleaning workers)',
#  'profile_work_typeW7W10_Sales or Services (e.g. commercial traveller, shop assistant, nursery nurse, care assistant, paramedic)',
#  'profile_work_typeW7W10_Semi-Skilled or Unskilled Manual Work (e.g. machine operator, assembler, postman, waitress, cleaner, labourer, driver, b',
#  'profile_work_typeW7W10_Have never worked',
#  'profile_work_typeW7W10_Skilled Manual Work (e.g. plumber, electrician, fitter)',
#  'profile_work_typeW7W10_Manager or Senior Administrator / intermediate managerial / professional (e.g. company director, finance manager, person',
#  'profile_work_typeW7W10_Clerical/junior managerial/professional/administrator (e.g. office worker, student doctor, sales person, clerk, secretar',
#  'profile_work_typeW7W10_Professional or higher technical work / higher managerial - work that requires at least degree-level qualifications (e.g',
#  'likeLDW9__Strongly like',
#  'winConstituencyUKIPW5__100 - Very likely to win',
#  'ptvLDW13__Very likely',
#  'coalitionDontDeliverW6__Strongly agree',
#  'winConstituencyGreenW4__100 - Very likely to win',
#  'EUIntegrationUKIPW12__Protect our independence',
#  'ptvLabW9__Very likely',
#  'responsibleCrimeDontKnowW4_Yes',
#  'changeCrimeW4__Getting a lot higher',
#  'lr2W6__Strongly agree',
#  'preferConCoalitionW5__Ranked fifth',
#  'preferLabCoalitionW5__Ranked fifth',
#  'preferConMajorityW5__Ranked fifth',
#  'preferLabMajorityW5__Ranked fifth',
#  'preferOtherGovW5__Ranked fifth',
#  'lr1W13__Strongly agree',
#  'changeCrimeW2__Getting a lot higher',
#  'responsibleCrimeDontKnowW2_Yes',
#  'changeEconomyW9__Getting a lot better',
#  'immigSelfW9__Allow many more',
#  'difficultBlameCoalitionW6__Strongly agree',
#  'immigCulturalW13__Enriches cultural life',
#  'winConstituencyUKIPW4__100 - Very likely to win',
#  'lr5W6__Strongly agree',
#  'ukipGovTrustW5__ Would do a good job',
#  'satDemUKW13__Very satisfied',
#  'al1W13__Strongly agree',
#  'efficacyTooMuchEffortW9__Strongly agree',
#  'lr3W6__Strongly agree',
#  'responsibleCrimeDontKnowW1_Yes',
#  'changeCrimeW1__Getting a lot higher',
#  'cutsTooFarNationalW4__Gone much too far',
#  'al5W6__Strongly agree',
#  'ptvGrnW13__Very likely',
#  'al4W6__Strongly agree',
#  'partyIdW9_Plaid Cymru',
#  'partyIdW9_Green Party',
#  'partyIdW9_Scottish National Party (SNP)',
#  'partyIdW9_United Kingdom Independence Party (UKIP)',
#  'partyIdW9_Labour',
#  ...]

# %%
# %%time

decomp = LinearDiscriminantAnalysis(n_components=2, solver="eigen",shrinkage = 'auto')
decomp_method = str(decomp).split("(")[0] 

X_r = decomp.fit_transform(train.drop(drop_vars,axis=1), target)

n_components = X_r.shape[1]

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = train.index)
# Out:
# Wall time: 35.8 s

# %%
BES_decomp.shape
# Out:
# (36806, 2)

# %%
x_axis = 0
y_axis = 1

xlim = np.floor( BES_decomp.loc[ :, x_axis ].min() ), np.ceil( BES_decomp.loc[ :, x_axis ].max() )
ylim = np.floor( BES_decomp.loc[ :, y_axis ].min() ), np.ceil( BES_decomp.loc[ :, y_axis ].max() )

# SparsePCA
if decomp_method == 'SparsePCA' or (decomp_method=='LinearDiscriminantAnalysis' and decomp.shrinkage=='auto'):
    xlim =  BES_decomp.loc[ :, x_axis ].min() ,  BES_decomp.loc[ :, x_axis ].max() 
    ylim =  BES_decomp.loc[ :, y_axis ].min() ,  BES_decomp.loc[ :, y_axis ].max()

# %%
# %%time

graph_type = "non_ordinal_scatter/"
folder = output_subfolder +os.sep+ graph_type + os.sep
if not os.path.exists(folder):
    os.makedirs(folder)

dummy_list = [focal_variable]

# non-ordinal categories
fig_no = 0
for decomp_label_col in dummy_list:
    if decomp_label_col in ["profile_religion","country",
                            'polKnowMay','polKnowOsborne',
                            'polKnowClegg', 'polKnowBercow',
                            'polKnowMiliband', 'registered', 'ns_sec']:
        continue
    
    fig = plt.figure( figsize=(16,10) )

    decomp_label_categories = [ x for x in BES_reduced_with_na.columns if (decomp_label_col + "_") in x ]
    if len(decomp_label_categories) == 0:
        continue
            

    # 'No party is best able to handle this issue'
    drop_cat_list = ['profile_education_age', 'profile_ethnicity_White British']
    for drop_cat in drop_cat_list:
        if drop_cat in decomp_label_categories:
            decomp_label_categories.remove(drop_cat)
            
    replace_dict = {'Scottish National Party (SNP)' : 'Scottish National Party',
                    'United Kingdom Independence Party (UKIP)' : 'United Kingdom Independence Party'}

    lab_to_cat = {}
    sample_sizes = {}
    for cat in decomp_label_categories:
        
        lab = re.search('_([^_]+)$',cat).groups()[0]
        if lab in replace_dict.keys(): # replace party name variants with single version
            lab = replace_dict[lab]
        
        if lab not in cat_col_mar_dict.keys(): # try to give parties consistent colour, marker pairs
            cat_col_mar_dict[lab] = (next(colours),next(markers))
        
        sample_sizes[lab] = BES_reduced_with_na[ cat ][mask].sum()
        lab_to_cat[lab] = cat

    for lab in sorted(sample_sizes, key=sample_sizes.get, reverse=True):
        
        samp = sample_sizes[lab]
            
        (col, mar) = cat_col_mar_dict[lab]

        cat_entries = BES_reduced_with_na[ lab_to_cat[lab] ][mask]==True
        
        plt.scatter(BES_decomp.loc[ cat_entries, x_axis ],
                    BES_decomp.loc[ cat_entries, y_axis ],
                    c= col,
                    marker=mar,
                    label=lab + "(N="+str(samp)+")",
                    edgecolors=col,
                    alpha = .9 )
    
    plt.xlim(xlim)
    plt.ylim(ylim)    
    
    plt.xlabel( comp_labels[x_axis] )
    plt.ylabel( comp_labels[y_axis] ) 
    plt.legend(prop={'size':8})
    plt.title('Decomposition of BES dataset; labelled variable: ' + decomp_label_col)
    
    fig.savefig( folder+decomp_label_col, bbox_inches='tight' )
    if fig_no >1:
        plt.close()
    fig_no = fig_no + 1
plt.show()

# %%
# BES_reduced_with_na[ lab_to_cat[lab] ][mask].value_counts()
# Out:
# 0.0    41723
# 1.0       15
# Name: profile_past_vote_2005_Veritas, dtype: int64

# %%
BES_decomp.loc[ cat_entries==True, x_axis ]
# Out:
# 130      0.831492
# 5175     0.621734
# 6320     0.590109
# 8203     1.148010
# 12912    1.092623
# 22496    1.264486
# 22888    0.394150
# 31139    0.486170
# 34395    0.679528
# 37184    0.279697
# 37209    0.286743
# 37297    1.382055
# 46090    1.129903
# 54808    0.762866
# 67180    1.233825
# Name: 0, dtype: float64

# %%
(BES_decomp, comp_labels, comp_dict) = display_components(n_components, decomp,
                                                          train.drop(drop_vars,axis=1).columns, BES_decomp, manifest, 
                                                          save_folder = subdir,  
                                                          show_first_x_comps= 4, show_histogram = False)
