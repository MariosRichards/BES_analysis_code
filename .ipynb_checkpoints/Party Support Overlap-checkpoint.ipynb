# %%
## https://twitter.com/MattSingh_/status/1787496333600862460

## I'm just skeptical that UK age patterns of support for radical right parties can all be explained by euroskepticism

## But the two are *so* heavily correlated that the best I can think of is to compare BNP vs UKIP at the BNP's high point in 2010

##

# %%
# %%time
dataset_name = "W25_comb"
df_list = "BES_Panel"

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}

global BES_label_list, BES_df_list
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (10365, 13)
# CPU times: total: 2min 10s
# Wall time: 3min 2s

# %%
search(BES_Panel,"ageW25|p_socgradeW25|wt_new")
# Out:
# wt_new_W10            30237
# wt_new_W11            30956
# wt_new_W14            31063
# wt_new_W15            30842
# wt_new_W16            37959
# wt_new_W1_W16          2427
# wt_new_W18            37825
# wt_new_W20            31468
# wt_new_W21            30281
# wt_new_W22            28113
# wt_new_W23            30949
# wt_new_W24            15439
# wt_new_W25            30407
# wt_new_W6W7           21081
# wt_new_W2W6           23163
# wt_new_W2W6W7         17076
# wt_new_W9_W13         12562
# wt_new_W12            34394
# wt_new_W1_W11          6473
# wt_new_W1_W12          5833
# wt_new_W1_W13          5301
# wt_new_W6_W11          9373
# wt_new_W6_W12          8398
# wt_new_W6_W13          7622
# wt_new_W11_W13        21520
# wt_new_W13W16         14647
# wt_new_W13_result     31135
# wt_new_W6W16           9587
# wt_new_W2W16           8388
# wt_new_W17            34366
# wt_new_W13W17         15744
# wt_new_W6W13W19        8743
# wt_new_W9W19          13604
# ...

# %%
ageW25 = BES_Panel["ageW25"].astype('float')
ageW25.loc[ageW25>=100]=np.nan

# %%
ageW25.hist(bins=100)
# Out:
# <Axes: >

# %%
ageW25.groupby(BES_Panel["p_socgradeW25"].replace("Unknown",np.nan))\
    .apply(lambda x: (x*BES_Panel["wt_new_W25"]).mean() )
# Out:
# p_socgradeW25
# A     34.642146
# B     35.379517
# C1    54.632859
# C2    68.089236
# D     52.945329
# E     54.239992
# Name: ageW25, dtype: float64

# %%
ageW25.groupby(BES_Panel["p_socgradeW25"].replace("Unknown",np.nan))\
    .apply(lambda x: (x*BES_Panel["wt_new_W25"]).count() )
# Out:
# p_socgradeW25
# A     4860
# B     6593
# C1    7829
# C2    4418
# D     3005
# E     3615
# Name: ageW25, dtype: int64

# %%
# ageW25.groupby(BES_Panel["p_socgradeW25"].replace("Unknown",np.nan))\
#     .apply(lambda x: (x*BES_Panel["wt_new_W25"]).mean() ).plot(kind='bar');
# plt.ylabel("Average Age");
# plt.title("British Election Study Online Panel (May 2023)\nAverage Age of Respondents in each Social Grade\n(Using Demographic Weights)");

# %%
ageW25.groupby(BES_Panel["p_socgradeW25"].replace("Unknown",np.nan))\
    .apply(lambda x: (weighted_mean(list(zip(x,BES_Panel["wt_new_W25"])))) ).plot(kind='bar');
plt.ylabel("Average Age");
plt.title("British Election Study Online Panel (May 2023)\nAverage Age of (Adult) Respondents in each Social Grade\n(Using Demographic Weights)");

# %%
ageW25_zipped = pd.Series(list(zip(ageW25,BES_Panel["wt_new_W25"])),index=ageW25.index)

# %%
ageW25_zipped.groupby(BES_Panel["p_socgradeW25"].replace("Unknown",np.nan))\
    .apply(lambda x: weighted_mean(x) ).plot(kind='bar');
plt.ylabel("Average Age");
plt.title("British Election Study Online Panel (May 2023)\nAverage Age of (Adult) Respondents in each Social Grade\n(Using Demographic Weights)");

# %%
ageW25[ageW25>=65].mean()
# Out:
# 72.46335227272728

# %%
weighted_mean(list(zip()))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 weighted_mean()
#
# TypeError: weighted_mean() missing 1 required positional argument: 'x'

# %%
BES_Panel["ageW25"].astype('float')
# Out:
# id
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
#           ...
# 113062    32.0
# 113063    24.0
# 113064    21.0
# 113065    20.0
# 113066    36.0
# Name: ageW25, Length: 111621, dtype: float64

# %%
search(BES_Panel,"ageGroupW6|ageW6")
# Out:
# likeFarageW6         30258
# ageW6                30150
# ageGroupW6           30150
# p_education_ageW6    30114
# dtype: int64

# %%
search(BES_Panel,"(like|ptv)UKIPW(1|2|3|4|5|6)$")
# Out:
# likeUKIPW1    15332
# ptvUKIPW1     15196
# likeUKIPW2    15364
# ptvUKIPW2     15523
# likeUKIPW3    13854
# ptvUKIPW3     13972
# likeUKIPW4    15695
# ptvUKIPW4     15855
# likeUKIPW5    15443
# ptvUKIPW5     15527
# likeUKIPW6    15008
# ptvUKIPW6     15249
# dtype: int64

# %%
BES_Panel[search(BES_Panel,".*BNP").index].replace("Don't know",np.nan).notnull().sum()

# 1-6
# Out:
# likeBNPW1    14412
# ptvBNPW1     14617
# likeBNPW2    14638
# ptvBNPW2     15057
# likeBNPW3    13182
# ptvBNPW3     13377
# likeBNPW4    14790
# ptvBNPW4     15250
# likeBNPW5    14670
# ptvBNPW5     15018
# likeBNPW6    14277
# ptvBNPW6     14856
# dtype: int64

# %%
BES_Panel[search(BES_Panel,".*BNP").index].replace("Don't know",np.nan).apply(lambda x: x.cat.codes.replace(-1,np.nan)).var()
# Out:
# likeBNPW1    4.106815
# ptvBNPW1     3.883266
# likeBNPW2    4.238892
# ptvBNPW2     3.186291
# likeBNPW3    3.602348
# ptvBNPW3     3.292676
# likeBNPW4    3.442865
# ptvBNPW4     3.042102
# likeBNPW5    3.290952
# ptvBNPW5     2.899612
# likeBNPW6    2.860765
# ptvBNPW6     2.465420
# dtype: float64

# %%
BES_Panel[search(BES_Panel,"(like|ptv)UKIPW(1|2|3|4|5|6)$").index].replace("Don't know",np.nan).apply(lambda x: x.cat.codes.replace(-1,np.nan)).var()
# Out:
# likeUKIPW1     9.743648
# ptvUKIPW1     12.623096
# likeUKIPW2    11.372168
# ptvUKIPW2     13.937809
# likeUKIPW3    10.962495
# ptvUKIPW3     12.565136
# likeUKIPW4    10.454600
# ptvUKIPW4     12.749051
# likeUKIPW5    11.198604
# ptvUKIPW5     13.316847
# likeUKIPW6    11.051496
# ptvUKIPW6     13.153988
# dtype: float64

# %%
BES_Panel["likeUKIPW1"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
BES_Panel["ptvUKIPW1"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
BES_Panel["likeBNPW1"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
BES_Panel["ptvBNPW1"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
BES_Panel["likeUKIPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
BES_Panel["ptvUKIPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
BES_Panel["likeBNPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
BES_Panel["ptvBNPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).hist(bins=10);

# %%
sns.lineplot(x=BES_Panel["ageGroupW1"],y=BES_Panel["ptvBNPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));

# %%
sns.lineplot(x=BES_Panel["ageGroupW6"],y=BES_Panel["ptvBNPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));
# Out:
# <Axes: xlabel='ageGroupW6'>

# %%
sns.lineplot(x=BES_Panel["ageW6"],y=BES_Panel["ptvBNPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));

# %%
sns.lineplot(x=BES_Panel["ageGroupW6"],y=BES_Panel["ptvUKIPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));
# Out:
# <Axes: xlabel='ageGroupW6'>

# %%
sns.lineplot(x=BES_Panel["ageW6"],y=BES_Panel["ptvUKIPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));

# %%
sns.lineplot(x=BES_Panel["ageGroupW6"],y=BES_Panel["ptvUKIPW6"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));

# %%
sns.lineplot(x=BES_Panel["ageW18"],y=BES_Panel["ptvUKIPW18"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));

# %%
sns.lineplot(x=BES_Panel["ageGroupW18"],y=BES_Panel["ptvUKIPW18"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));

# %%
sns.lineplot(x=BES_Panel["ageGroupW18"],y=BES_Panel["ptvUKIPW15"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan));

# %%
################## hmm - BNP looks pretty different to UKIP - even after UKIP has shrunk and BNPified

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 5
#       1 global BES_label_list, BES_df_list
#       3 # %run f2f_utility.py
# ----> 5 BES_df_list = pickle.load( open( "E:\\BES_analysis_data\\Face_to_face\\BES_df_list.pickle", "rb" ) )
#       6 f2f_harmonised = pd.read_pickle("E:\\BES_analysis_data\\Face_to_face\\f2f_harmonised.zip", compression='zip')
#       7 BES_label_list = pickle.load( open( "E:\\BES_analysis_data\\Face_to_face\\BES_label_list.pickle", "rb" ) )
#
# ModuleNotFoundError: No module named 'pandas.core.indexes.numeric'
