# %% [markdown]
# 'We define progressive parties as ones which combine redistributive and liberal cultural goals (see figure one). Research suggests that culturally liberal voters advocate redistribution irrespective of their income; this contrasts with culturally conservative voters whose advocacy of redistribution depends on their income (Geering and Häusermann, 2013; Mellon and Prosser, 2017). In Europe, social-democratic parties are the main occupants of such political space, yet radical left parties also exist. Though many European liberal parties have liberal (i.e. market-oriented) economic and cultural goals, such as Ciudadanos (Spain) and LREM (France), some adopt redistributive and liberal cultural goals, such as the Liberal Democrats (UK).'

# %%
## Be nice to have a plot reflecting that research
# (but maybe obnoxious to replicate research you're citing - particularly since one of the authors is matched!)

# %% [markdown]
# Would you be able to produce one image which visualizes such parties in value space (i.e. the bottom left-hand corner)?
# I guess this could be operationalized in a few ways
# you don't have to do anything with data - you could just produce stylized party positions

# %%
## Better double-check to make sure I'm clear on what's desired here
# sounds like just a figure to convey point
# stylised - figurative rather than real data

# right - but which axes (e.g. Party Redistribution Stance vs Electorate Mean Income or Ec Left-Right vs Soc Lib-Auth)

# %%
## Header code + where did you put the files/where do you want the output?

# %matplotlib inline
# %run Prosser_header.py

dataset_folder = "C:\\Users\\Marios\\Documents\\GitHub\\Thomas Prosser project\\datasets\\"
output_folder  = "C:\\Users\\Marios\\Documents\\GitHub\\Thomas Prosser project\\output\\"

## Toggle button to hide code!
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
CSES_resp_mean = pd.read_csv(dataset_folder+\
                          "Google Drive Share Folder"+os.sep+\
                          "PARTY-COUNTRY-VOTER.0.3"+os.sep+\
                          "CSES_respondent_aggregates"+os.sep+\
                          "CSES_resp-agg_sample_broad_mean_party_csv.zip")

CSES_resp_mean = CSES_resp_mean.set_index("partyfacts_id")

CSES_VL = pd.read_csv(dataset_folder+\
                          "Google Drive Share Folder"+os.sep+\
                          "PARTY-COUNTRY-VOTER.0.3"+os.sep+\
                          "CSES_VL_csv.zip")

# %%
mean_inc_decile = CSES_resp_mean["IMD2006_ORD"]

# %%
party_level = pd.read_csv(dataset_folder+\
                          "Google Drive Share Folder"+os.sep+\
                          "PARTY-COUNTRY-VOTER.0.3"+os.sep+\
                          "party_level_csv.zip")

party_level_VL = pd.read_csv(dataset_folder+\
                          "Google Drive Share Folder"+os.sep+\
                          "PARTY-COUNTRY-VOTER.0.3"+os.sep+\
                          "party_level_VL_csv.zip")

# %%
cmp_redist_ish_vars = ["(manifesto)per"+x for x in ["404","405","409","413","504","701"]]
party_level_VL.set_index("new_variable_name").loc[cmp_redist_ish_vars]
# Out:
#                   source_variable_name                  description    group  \
# new_variable_name
# (manifesto)per404               per404            economic planning  man_cod
# (manifesto)per405               per405    corporatism/mixed economy  man_cod
# (manifesto)per409               per409  keynesian demand management  man_cod
# (manifesto)per413               per413              nationalisation  man_cod
# (manifesto)per504               per504                    welfare +  man_cod
# (manifesto)per701               per701              labour groups +  man_cod
#
#                       type
# new_variable_name
# (manifesto)per404  man_cod
# (manifesto)per405  man_cod
# (manifesto)per409  man_cod
# (manifesto)per413  man_cod
# (manifesto)per504  man_cod
# (manifesto)per701  man_cod

# %%
cross_year_rows = party_level["ELECTORAL EVENT"].isnull()
party_level_cross_year_aggregates = party_level[cross_year_rows].set_index("partyfacts_id").select_dtypes('number').sort_index()

# %%
manifesto_redist = party_level_cross_year_aggregates[cmp_redist_ish_vars].mean(axis=1)

# %%
party_overlap = set(manifesto_redist.dropna().index).intersection(mean_inc_decile.dropna().index)

# %%
manifesto_party_family_vars = search(party_level_cross_year_aggregates,"\(manifesto\)family").index
party_family = party_level_cross_year_aggregates[manifesto_party_family_vars].idxmax(axis=1).apply(lambda x: x.replace("(manifesto)family__","") if pd.notnull(x) else np.nan)
pf_to_abbrev  = party_level[ cross_year_rows ].set_index("partyfacts_id")["(pf)name_short"]

# %%
EEA_and_UK_countries = ['aut', 'bel', 'bgr', 'hrv', 'cyp', 'cze', 'dnk', 'est', 'fin', 'fra', 'deu', 'grc', 'hun', 'irl', 'ita', 'lva', 'ltu', 'lux', 'mlt', 'nld', 'pol', 'prt', 'rou', 'svk', 'svn', 'esp', 'swe', 'gbr']
pf_to_country = party_level[ cross_year_rows ].set_index("partyfacts_id")["country"]
party_overlap = [ x for x in party_overlap if pf_to_country.loc[x] in EEA_and_UK_countries]

# %%
x_axis = "Support Base Affluence"
y_axis = "Support For Redistribution"

# %%
df =pd.DataFrame()
df[x_axis] = mean_inc_decile.loc[party_overlap]
df[y_axis] = manifesto_redist.loc[party_overlap]
df["Abbreviation"] = [pf_to_abbrev.loc[x] for x in df.index]
df["Party Family"] = party_family.loc[party_overlap].astype('category')

party_family_vc = df["Party Family"].value_counts()
df["Party Family"] = df["Party Family"].cat.rename_categories({k:k+" (N="+str(party_family_vc.loc[k])+")" for k in df["Party Family"].cat.categories})


party_colour_dict = {'green':'green', 'rad left':'pink', 'socialist':'red',
       'liberal':'orange', 'christdem':'darkblue', 'cons':'lightblue',
       'rad right':'purple', 'agrarian':'brown', 'regional':'yellow',
       'special issue':'olive','coalition':'black','unknown':'grey'}
party_colour_dict = {k+" (N="+str(party_family_vc.loc[k])+")":party_colour_dict[k] for k in party_family_vc.index}

plt.figure(figsize=(12,8))
sns.scatterplot(data = df,x=x_axis,y=y_axis,
                hue="Party Family",palette=party_colour_dict);

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.02, point['y'], str(point['val']), fontsize=8)

label_point(df[x_axis],
            df[y_axis],
            df["Abbreviation"], plt.gca())

# %%
party_level_VL["group"].value_counts()
# Out:
# man_cod                        859
# dummied_variables               84
# policy_dimensions               36
# observation_variables           32
# party_electoral                 31
# party_id                        22
# party_names                     22
# country_variables               18
# ideological_dimensions          17
# dummiable_variables             14
# eu_policy_questions             13
# coder_ratings                   12
# eu_integration_admission        11
# computed_values                 10
# source_variables                10
# index_jahn_gg                    9
# index_jahn_lr                    9
# leadership_divisions             9
# immigration_integration_pos      7
# index_budge                      5
# ukraine_specific_questions       5
# party_characteristics            4
# parlgov_index                    4
# index_franzmann_kaiser           3
# eu_membership_requirements       3
# notes                            3
# adhoc_index                      2
# index_jahn_oberst_cohesion       2
# Name: group, dtype: int64

# %%
party_level_VL[ party_level_VL["group"] == "policy_dimensions"]
# Out:
#                  new_variable_name    source_variable_name  \
# 1083                 (ches)pubserv                 pubserv
# 1084        (ches)pubserv_salience        pubserv_salience
# 1085                   (ches)dereg                   dereg
# 1086          (ches)dereg_salience          dereg_salience
# 1087                  (ches)redist                  redist
# 1088         (ches)redist_salience         redist_salience
# 1089                  (ches)civlib                  civlib
# 1090         (ches)civlib_salience         civlib_salience
# 1091               (ches)lifestyle               lifestyle
# 1092      (ches)lifestyle_salience      lifestyle_salience
# 1093                (ches)religion                religion
# 1094       (ches)religion_salience       religion_salience
# 1095                   (ches)immig                   immig
# 1096          (ches)immig_salience          immig_salience
# 1097               (ches)multicult               multicult
# 1098      (ches)multicult_salience      multicult_salience
# 1099                   (ches)urban                   urban
# 1100          (ches)urban_salience          urban_salience
# 1101                   (ches)cosmo                   cosmo
# 1102          (ches)cosmo_salience          cosmo_salience
# 1103               (ches)decentral               decentral
# 1104      (ches)decentral_salience      decentral_salience
# 1105                      (ches)us                      us
# 1106             (ches)us_salience             us_salience
# 1107                   (ches)minor                   minor
# 1108          (ches)minor_salience          minor_salience
# 1109                  (ches)enviro                  enviro
# 1110         (ches)enviro_salience         enviro_salience
# 1111  (ches)international_security  international_security
# 1112  (ches)international_salience  international_salience
# 1113           (ches)econ_interven           econ_interven
# 1114           (ches)immig_dissent           immig_dissent
# 1115       (ches)multicult_dissent       multicult_dissent
# 1116           (ches)protectionism           protectionism
# 1117    (ches)russian_interference    russian_interference
# 1118     (ches)anti_islam_rhetoric     anti_islam_rhetoric
#
#                                             description              group  \
# 1083                     Position on immigration policy  policy_dimensions
# 1084  Relative salience of immigration policy in the...  policy_dimensions
# 1085                Position on deregulation of markets  policy_dimensions
# 1086  Relative salience of market deregulation in pa...  policy_dimensions
# 1087  Position on redistribution of wealth from the ...  policy_dimensions
# 1088  Relative salience of redistribution in the par...  policy_dimensions
# 1089      Position on civil liberties vs. law and order  policy_dimensions
# 1090  Relative salience of civil liberties in the pa...  policy_dimensions
# 1091  Position on social lifestyle (e.g. rights for ...  policy_dimensions
# 1092  Relative salience of social lifestyle in the p...  policy_dimensions
# 1093  Position on role of religious principles in po...  policy_dimensions
# 1094  Relative salience of religious principles in t...  policy_dimensions
# 1095                     Position on immigration policy  policy_dimensions
# 1096  Relative salience of imigration policy in the ...  policy_dimensions
# 1097  Position on integration of immigrants and asyl...  policy_dimensions
# 1098  Relative salience of immigrants and asylum see...  policy_dimensions
# 1099                  Position on urban/rural interests  policy_dimensions
# 1100  Relative salience of rural/urban interests in ...  policy_dimensions
# 1101   Position towards cosmopolitanism vs. nationalism  policy_dimensions
# 1102  Relative salience of cosmopolitianism vs natio...  policy_dimensions
# 1103  Position on political decentralization to regi...  policy_dimensions
# 1104  Relative salience of political decentralizatio...  policy_dimensions
# 1105         Position towards US power in world affairs  policy_dimensions
# 1106   Importance/salience of US power in world affairs  policy_dimensions
# 1107                 Position towards ethnic minorities  policy_dimensions
# 1108           Importance/salience of ethnic minorities  policy_dimensions
# 1109                   Position towards the environment  policy_dimensions
# 1110             Importance/salience of the environment  policy_dimensions
# 1111  Position towards international security and pe...  policy_dimensions
# 1112  Importance/salience of international security ...  policy_dimensions
# 1113      Position on state intervention in the economy  policy_dimensions
# 1114            Degree of dissent on immigration policy  policy_dimensions
# 1115  Degree of dissent on immigrants and asylum see...  policy_dimensions
# 1116  Position towards trade liberalization/protecti...  policy_dimensions
# 1117  Salience of Russian interference in domestic a...  policy_dimensions
# 1118  Salience of anti-Islam rhetoric for the party ...  policy_dimensions
#
#            type
# 1083  expert_op
# 1084  expert_op
# 1085  expert_op
# 1086  expert_op
# 1087  expert_op
# 1088  expert_op
# 1089  expert_op
# 1090  expert_op
# 1091  expert_op
# 1092  expert_op
# 1093  expert_op
# 1094  expert_op
# 1095  expert_op
# 1096  expert_op
# 1097  expert_op
# 1098  expert_op
# 1099  expert_op
# 1100  expert_op
# 1101  expert_op
# 1102  expert_op
# 1103  expert_op
# 1104  expert_op
# 1105  expert_op
# 1106  expert_op
# 1107  expert_op
# 1108  expert_op
# 1109  expert_op
# 1110  expert_op
# 1111  expert_op
# 1112  expert_op
# 1113  expert_op
# 1114  expert_op
# 1115  expert_op
# 1116  expert_op
# 1117  expert_op
# 1118  expert_op

# %%
party_level_VL[party_level_VL["description"].apply(lambda x: "redist" in x.lower())]
# Out:
#                     new_variable_name       source_variable_name  \
# 97                 (ees14)redistribut                redistribut
# 1087                     (ches)redist                     redist
# 1088            (ches)redist_salience            redist_salience
# 1171    (ches)mip_one__redistribution    mip_one__redistribution
# 1172    (ches)mip_two__redistribution    mip_two__redistribution
# 1173  (ches)mip_three__redistribution  mip_three__redistribution
#
#                                             description              group  \
# 97    Pro Redistribution of Wealth - No Redistributi...      coder_ratings
# 1087  Position on redistribution of wealth from the ...  policy_dimensions
# 1088  Relative salience of redistribution in the par...  policy_dimensions
# 1171               Most Important Issue: Redistribution  dummied_variables
# 1172        Second Most Important Issue: Redistribution  dummied_variables
# 1173         Third Most Important Issue: Redistribution  dummied_variables
#
#                type
# 97    coder_ratings
# 1087      expert_op
# 1088      expert_op
# 1171     dummy_vars
# 1172     dummy_vars
# 1173     dummy_vars

# %%
CSES_VL[CSES_VL["description"].apply(lambda x: "income" in x.lower())]
# Out:
#     new_variable_name source_variable_name  \
# 102       IMD2006_ORD              IMD2006
# 103        IMD2006_DK              IMD2006
#
#                                  description response/non-response  resp_rows  \
# 102  GROSS PRE-TAX HOUSEHOLD INCOME QUINTILE              response     252263
# 103  GROSS PRE-TAX HOUSEHOLD INCOME QUINTILE          non-response     252263
#
#      non_resp_rows variable type variable structural type
# 102          63985       ordinal               respondent
# 103          63985       ordinal               respondent

# %%
redist_vars = party_level_VL[party_level_VL["description"].apply(lambda x: "redist" in x.lower())]["new_variable_name"].values

# %%
party_level_cross_year_aggregates[redist_vars].notnull().sum()
# Out:
# (ees14)redistribut                 134
# (ches)redist                       462
# (ches)redist_salience              359
# (ches)mip_one__redistribution      242
# (ches)mip_two__redistribution      240
# (ches)mip_three__redistribution    238
# dtype: int64

# %%
party_level_cross_year_aggregates[redist_vars]
# Out:
#                (ees14)redistribut  (ches)redist  (ches)redist_salience  \
# partyfacts_id
# 1                             NaN           NaN                    NaN
# 3                             NaN           NaN                    NaN
# 4                             1.0      0.208696               0.755667
# 5                             NaN           NaN                    NaN
# 6                             NaN           NaN                    NaN
# ...                           ...           ...                    ...
# 8605                          NaN           NaN                    NaN
# 8606                          NaN           NaN                    NaN
# 8607                          NaN           NaN                    NaN
# 8608                          NaN           NaN                    NaN
# 8609                          NaN           NaN                    NaN
#
#                (ches)mip_one__redistribution  (ches)mip_two__redistribution  \
# partyfacts_id
# 1                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        0.0                            1.0
# 5                                        NaN                            NaN
# 6                                        NaN                            NaN
# ...                                      ...                            ...
# 8605                                     NaN                            NaN
# 8606                                     NaN                            NaN
# 8607                                     NaN                            NaN
# 8608                                     NaN                            NaN
# 8609                                     NaN                            NaN
#
#                (ches)mip_three__redistribution
# partyfacts_id
# 1                                          NaN
# 3                                          NaN
# 4                                          0.0
# 5                                          NaN
# 6                                          NaN
# ...                                        ...
# 8605                                       NaN
# 8606                                       NaN
# 8607                                       NaN
# 8608                                       NaN
# 8609                                       NaN
#
# [5624 rows x 6 columns]

# %%
manifesto_redist.notnull().sum()
# Out:
# 1036

# %%
party_level_cross_year_aggregates[redist_vars].corrwith(manifesto_redist)
# Out:
# (ees14)redistribut                -0.570084
# (ches)redist                      -0.443335
# (ches)redist_salience              0.455003
# (ches)mip_one__redistribution      0.331728
# (ches)mip_two__redistribution      0.312703
# (ches)mip_three__redistribution   -0.005585
# dtype: float64

# %%
# Out:
# Index(['(ches)expert', '(ches)party_id', 'year', '(ches)vote',
#        '(ches)eu_position', '(ches)future', '(ches)eu_ep', '(ches)eu_fiscal',
#        '(ches)eu_employ', '(ches)eu_cohesion',
#        ...
#        '(parlgov)family__agrarian', '(parlgov)family__christdem',
#        '(parlgov)family__cons', '(parlgov)family__green',
#        '(parlgov)family__liberal', '(parlgov)family__no family',
#        '(parlgov)family__rad left', '(parlgov)family__rad right',
#        '(parlgov)family__socialist', '(parlgov)family__special issue'],
#       dtype='object', length=1202)

# %%
mask = party_level_cross_year_aggregates[manifesto_redist.notnull()].notnull().sum()>100
party_level_cross_year_aggregates[mask[mask].index].corrwith(manifesto_redist).dropna().sort_values().head(20)
# Out:
# (manifesto)rile                                   -0.640086
# (pip)Index Budge et al.: RILE                     -0.614698
# (ees14)redistribut                                -0.570084
# (ees14)left                                       -0.471747
# (ees14)rile_mrg                                   -0.466426
# (ches)econ_interven                               -0.463276
# (pip)Index Jahn: LR Core                          -0.459453
# (pip)Index Jahn: LR Core (Unstandardized)         -0.459453
# (pip)Index Franzmann/Kaiser: Economic Dimension   -0.445561
# (ches)redist                                      -0.443335
# (ches)pubserv                                     -0.434995
# (ches)lrecon                                      -0.431367
# (pip)Index Jahn: LR                               -0.430321
# (pip)Index Jahn: LR (Unstandardized)              -0.429524
# (ees14)state                                      -0.423059
# (ees14)pubservice                                 -0.418619
# (ches)lrgen                                       -0.414218
# (ches)dereg                                       -0.406708
# (pip)Index Franzmann/Kaiser: Left-Right           -0.400101
# (parlgov)state_market                             -0.378897
# dtype: float64

# %%
party_level_cross_year_aggregates[mask[mask].index].corrwith(manifesto_redist).dropna().sort_values().tail(20)
# Out:
# (ees14)per_v2_701a                                                   0.332968
# (manifesto)planeco                                                   0.333160
# (ees14)per_v2_401b                                                   0.333281
# (ees14)per_v2_503a                                                   0.334938
# (parlgov)family__rad left                                            0.337948
# (ches)family__rad left                                               0.338668
# (ches)epgroup__Party of European Socialists (PES)                    0.340533
# (ches)intgroup__socialist international                              0.340533
# (ees14)per_v2_5041a                                                  0.343646
# (manifesto)per413                                                    0.380507
# (ees14)mfamily__rad left                                             0.382904
# (ees14)pfamily__(post-)communist                                     0.406661
# (ees14)ofamily__(post-)communist                                     0.411633
# (ches)epgroup__European United Left – Nordic Green Left (GUE-NGL)    0.411994
# (ches)redist_salience                                                0.455003
# (ees14)welfare                                                       0.525030
# (manifesto)per701                                                    0.594271
# (pip)Index Budge et al.: Welfare                                     0.714775
# (manifesto)welfare                                                   0.750575
# (manifesto)per504                                                    0.821037
# dtype: float64

# %%
party_level_VL[party_level_VL["source_variable_name"].apply(lambda x: "gal" in x.lower())]
# Out:
#               new_variable_name source_variable_name  \
# 1068               (ches)galtan               galtan
# 1070      (ches)galtan_salience      galtan_salience
# 1072         (ches)galtan_clear         galtan_clear
# 1075       (ches)galtan_dissent       galtan_dissent
# 1076          (ches)galtan_blur          galtan_blur
# 1077           (ches)galtan_new           galtan_new
# 1078     (ches)galtan_new_clear     galtan_new_clear
# 1079  (ches)galtan_new_salience  galtan_new_salience
# 1082            (ches)galtan_sd            galtan_sd
#
#                                             description  \
# 1068  Position of the party in terms of their views ...
# 1070  Relative salience of libertarian/traditional i...
# 1072  Clarity of a partys position on libertarian/t...
# 1075  Degree of dissent on libertarian/traditional i...
# 1076  How blurry was each partys position on libert...
# 1077  Position of the party in terms of a cultural d...
# 1078  Clarity of a partys position on the cultural ...
# 1079  Importance/salience of a partys position on t...
# 1082  Position of the party in terms of their views ...
#
#                        group       type
# 1068  ideological_dimensions  expert_op
# 1070  ideological_dimensions  expert_op
# 1072  ideological_dimensions  expert_op
# 1075  ideological_dimensions  expert_op
# 1076  ideological_dimensions  expert_op
# 1077  ideological_dimensions  expert_op
# 1078  ideological_dimensions  expert_op
# 1079  ideological_dimensions  expert_op
# 1082  ideological_dimensions  expert_op

# %%
lr_vals = party_level_VL[party_level_VL["source_variable_name"].apply(lambda x: "lrecon" in x.lower())]["new_variable_name"].values
galtan_vals = party_level_VL[party_level_VL["source_variable_name"].apply(lambda x: "gal" in x.lower())]["new_variable_name"].values

# %%
lr_vals,galtan_vals
# Out:
# (array(['(ches)lrecon', '(ches)lrecon_salience', '(ches)lrecon_clear',
#         '(ches)lrecon_dissent', '(ches)lrecon_blur', '(ches)lrecon_sd'],
#        dtype=object),
#  array(['(ches)galtan', '(ches)galtan_salience', '(ches)galtan_clear',
#         '(ches)galtan_dissent', '(ches)galtan_blur', '(ches)galtan_new',
#         '(ches)galtan_new_clear', '(ches)galtan_new_salience',
#         '(ches)galtan_sd'], dtype=object))

# %%
party_level_cross_year_aggregates[lr_vals].notnull().sum()
# Out:
# (ches)lrecon             522
# (ches)lrecon_salience    395
# (ches)lrecon_clear       126
# (ches)lrecon_dissent     270
# (ches)lrecon_blur        269
# (ches)lrecon_sd          424
# dtype: int64

# %%
party_level_cross_year_aggregates[galtan_vals].notnull().sum()
# Out:
# (ches)galtan                 521
# (ches)galtan_salience        395
# (ches)galtan_clear           125
# (ches)galtan_dissent         264
# (ches)galtan_blur            270
# (ches)galtan_new             126
# (ches)galtan_new_clear       125
# (ches)galtan_new_salience    126
# (ches)galtan_sd              423
# dtype: int64

# %%
party_level_cross_year_aggregates[["(ches)lrecon","(ches)galtan",]].dropna()
# Out:
#                (ches)lrecon  (ches)galtan
# partyfacts_id
# 4                  0.203770      0.494643
# 14                 0.650000      0.585714
# 21                 0.324487      0.750886
# 29                 0.179545      0.155177
# 36                 0.695278      0.639960
# ...                     ...           ...
# 8249               0.593333      0.160000
# 8392               0.675000      0.500000
# 8393               0.590000      0.190909
# 8394               0.662500      0.500000
# 8395               0.280000      0.166667
#
# [521 rows x 2 columns]

# %%
x_axis = "lrecon"
y_axis = "galtan"

# %%
df =pd.DataFrame()
df[x_axis] = party_level_cross_year_aggregates["(ches)lrecon"].loc[party_overlap]
df[y_axis] = party_level_cross_year_aggregates["(ches)galtan"].loc[party_overlap]
# manifesto_redist.loc[party_overlap]

# df[x_axis][df[x_axis]>.5]=np.nan
# df[y_axis][df[y_axis]>.5]=np.nan

df["Abbreviation"] = [pf_to_abbrev.loc[x] for x in df.index]

party_family_replace_dict = {"special issue":np.nan,"regional":np.nan,"coalition":np.nan}

df["Party Family"] = party_family.replace(party_family_replace_dict).loc[party_overlap].astype('category')

party_family_vc = df["Party Family"][df[x_axis].notnull()].value_counts()
df["Party Family"] = df["Party Family"].cat.rename_categories({k:k+" (N="+str(party_family_vc.loc[k])+")" for k in df["Party Family"].cat.categories})


party_colour_dict = {'green':'green', 'rad left':'pink', 'socialist':'red',
       'liberal':'orange', 'christdem':'darkblue', 'cons':'lightblue',
       'rad right':'purple', 'agrarian':'brown', 'regional':'yellow',
       'special issue':'olive','coalition':'black','unknown':'grey'}
party_colour_dict = {k+" (N="+str(party_family_vc.loc[k])+")":party_colour_dict[k] for k in party_family_vc.index}

plt.figure(figsize=(16,12))
sns.scatterplot(data = df,x=x_axis,y=y_axis,
                hue="Party Family",palette=party_colour_dict);

def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x']+.01, point['y'], str(point['val']), fontsize=8)

label_point(df[x_axis][df["Party Family"].notnull()],
            df[y_axis][df["Party Family"].notnull()],
            df["Abbreviation"][df["Party Family"].notnull()], plt.gca())

plt.xlim([0,1.0]);
plt.ylim([0,1.0]);

plt.title("Party Positions from Chapel Hill Expert Surveys\n(Average over all years in dataset, parties in EEA)")
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
