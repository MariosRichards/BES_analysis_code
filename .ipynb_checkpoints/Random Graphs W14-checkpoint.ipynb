# %%
dataset_name = "W14_comb"
df_list = [
           "BES_Panel",
           "BES_reduced_with_na",
           "BESnumeric"
#            "BES_reduced",
#            "BESnumeric"
          ]

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import pickle, os, gc, re

from IPython.display import display, display_html, HTML
def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )

import Jupyter_module_loader
from utility import *
import gaussian_kde
# display_components, display_pca_data, weighted_kde, setup_directories,\
#                     get_manifest, get_small_files, clean_filename, create_subdir, amalgamate_waves

# %%
# you should clone this git to a subdirectory called 'BES_analysis_code' (in some directory - I call it BES_analysis - doesn't matter though)
# %matplotlib inline
encoding = "ISO-8859-1"

(BES_code_folder, BES_small_data_files, BES_data_folder,
 BES_output_folder, BES_file_manifest, BES_R_data_files) = setup_directories()

# %%
global BES_Panel, BES_numeric, BES_reduced, BES_reduced_with_na, BES_non_numeric
data_subfolder = BES_data_folder + dataset_name + os.sep

(manifest, dataset_filename, dataset_description, dataset_citation,
 dataset_start, dataset_stop, dataset_wave) = get_manifest(dataset_name, BES_file_manifest)

for df in df_list:
    if df=="BES_Panel":
        globals()[df]  = pd.read_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))
    else:
        globals()[df]  = pd.read_msgpack(data_subfolder + df + '.msgpack' )
        globals()[df].replace(-1,np.nan,inplace=True)
  
(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)
# Out:
# var_type (5692, 13)

# %%
def sort_by_wave(lst):
    dict_by_wave = {int(x.split("W")[-1]):x for x in lst}
    return [dict_by_wave[x] for x in sorted(dict_by_wave.keys())]

# %%
max_wave, num_to_wave, num_to_weight, weights = get_weights(dataset_name,BES_Panel)

# %%
# search(BES_Panel,'edlevel')

# %%
# mean weights?
# maybe as part of amalgamation?
# BES_Panel[ num_to_weight[8] ]

# %%
def get_all_weights(mask, specific_wave = None):

    if specific_wave is None:
        wts = BES_Panel[list(num_to_weight.values())][mask]
    else:
        wts = BES_Panel[specific_wave][mask]
    # wts.hist(bins=100,figsize=(16,12));

    wts = wts/wts.mean()
    # wts.mean(axis=1).hist(bins=100,figsize=(16,12));
    # # wts = wts/wts.mean(axis=1)
    wts = wts.mean(axis=1)
    wts =wts/wts.mean()
    return wts
# wts

# %%
var1 ="profile_eurefvote"
var2 ="euRefVoteW14"
# amal_al_3cat.name = var2

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='index',drop_insig=False,
              title="Change in euRefVote since euRef")

# %%
var1 ="climateChangeW10"
var2 ="euRefVoteW10"
# amal_al_3cat.name = var2

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='all',drop_insig=False,
              title="Change in euRefVote since euRef")

# %%
search(BES_Panel, "hous", mask = BES_Panel["houseBuildW12"].notnull()&BES_Panel["houseBuildW12"].notnull())
# Out:
# headHouseholdPastW1               14255
# headHouseholdPastW2                 943
# headHouseholdPastW3                 883
# headHouseholdPastW4                1688
# headHouseholdPastW7                3763
# headHouseholdPastW9               18353
# headHouseholdPastW10              19222
# headHouseholdPastW11              22253
# councilHouseW12                   34394
# houseBuildW12                     34394
# headHouseholdPastW13              23460
# preschoolKidsInHouseW14           20741
# schoolKidsInHouseW14              20741
# sickElderlyInHouseW14             20741
# noDependentsInHouseW14            20741
# headHouseholdPast                 31871
# housing                           15518
# profile_house_tenureW10           21719
# profile_household_sizeW10         21718
# profile_gross_householdW10        21719
# profile_gross_householdW11        25018
# profile_house_tenureW11           24943
# profile_gross_householdW12        33641
# profile_house_tenureW12           33478
# profile_gross_householdW13        26253
# profile_house_tenureW13           26105
# profile_gross_householdW14        20734
# profile_gross_household           27844
# profile_household_size            28157
# profile_household_children        26380
# profile_house_tenure              26344
# preschoolKidsInHouseW1W2W3W4W5    18471
# schoolKidsInHouseW1W2W3W4W5       18471
# sickElderlyInHouseW1W2W3W4W5      18471
# noDependentsInHouseW1W2W3W4W5     18471
# preschoolKidsInHouseW6_W12        32988
# schoolKidsInHouseW6_W12           32988
# sickElderlyInHouseW6_W12          32988
# noDependentsInHouseW6_W12         32988
# dtype: int64

# %%
BES_Panel["profile_house_tenure"].value_counts()
# Out:
# Own outright                                                                          18753
# Own with a mortgage                                                                   15936
# Rent from a private landlord                                                           8431
# Rent from a housing association                                                        3328
# Rent from my local authority                                                           3143
# Neither I live rent-free with my parents, family or friends                            2734
# Neither I live with my parents, family or friends but pay some rent to them            2273
# Other                                                                                  1066
# Own (part-own) through shared ownership scheme (i.e. pay part mortgage, part rent)      400
# Name: profile_house_tenure, dtype: int64

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

# mask = (BES_reduced_with_na["Age"]>15) & (BES_reduced_with_na["Age"]<=64)

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='all',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign)" )

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

mask = (BES_Panel["profile_house_tenure"]=="Own outright")# | (BES_Panel["profile_house_tenure"]=="Own with a mortgage")

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign - HomeOwnersOnly)", mask=mask )

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

mask = (BES_Panel["profile_house_tenure"]=="Rent from a private landlord")# | (BES_Panel["profile_house_tenure"]=="Own with a mortgage")

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign - Private Rent)", mask=mask )

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

mask = (BES_Panel["profile_house_tenure"]=="Own with a mortgage")# | (BES_Panel["profile_house_tenure"]=="Own with a mortgage")

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign - Mortgage)", mask=mask )

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

mask = (BES_Panel["profile_house_tenure"]=="Rent from a housing association")# | (BES_Panel["profile_house_tenure"]=="Own with a mortgage")

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign - Housing Association)", mask=mask )

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

mask = (BES_Panel["profile_house_tenure"]=="Rent from my local authority")# | (BES_Panel["profile_house_tenure"]=="Own with a mortgage")

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign - Local Authority)", mask=mask )

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

mask = (BES_Panel["profile_house_tenure"]=="Neither I live rent-free with my parents, family or friends")# | (BES_Panel["profile_house_tenure"]=="Own with a mortgage")

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign - Live with family&friends)", mask=mask )

# %%
var1 ="euRefVoteW12"
var2 ="houseBuildW12"
# amal_al_3cat.name = var2

mask = (BES_Panel["profile_house_tenure"]=="Neither I live with my parents, family or friends but pay some rent to them")# | (BES_Panel["profile_house_tenure"]=="Own with a mortgage")

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Nimbyism_by_eurefVotepref(2017 GE campaign - Live with family&friends&pay some rent)", mask=mask )

# %%
var1 ="profile_eurefvote"
var2 ="profile_gross_personal"
# amal_al_3cat.name = var2

mask = (BES_reduced_with_na["Age"]>15) & (BES_reduced_with_na["Age"]<=64)

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='all',drop_insig=False,
              title="Profile_gross_person_by_euref_15_64_unnormalised", mask=mask)

# %%
var1 ="euRefVoteW14"
var2 ="buyHomeFutureW14"
# amal_al_3cat.name = var2

# mask = (BES_reduced_with_na["ageW12"]>=30) & (BES_reduced_with_na["ageW12"]<=50)

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='all',drop_insig=False,
              title="Do you expect to be able to purchase a home in the next 5 to 10 years (current renters)")

# %%
var1 ="euRefVoteW14"
var2 ="mortgagePaymentW14"
# amal_al_3cat.name = var2

# mask = (BES_reduced_with_na["ageW12"]>=30) & (BES_reduced_with_na["ageW12"]<=50)

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='all',drop_insig=False,
              title="Please estimate the proportion (%) of household income, after tax, spent on your mortgage per month")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-109-4020a4369202> in <module>
#      11
#      12 nice_bar_plot(df1, df2, min_sample_size=1, normalize='all',drop_insig=False,
# ---> 13               title="Please estimate the proportion (%) of household income, after tax, spent on your mortgage per month")
#      14
#
# <ipython-input-35-fdafdc6bc0ec> in nice_bar_plot(ser1, ser2, normalize, sort_labels, output_folder, text_width, text_fontsize, min_sample_size, title, drop_insig, fuckErrors, mask)
#      17     errors = 100 * np.sqrt(unweighted)/unweighted
#      18
# ---> 19     labels_by_sample_size = {unweighted.sum().values[x]:sorted_labels[x]+" (N="+str(unweighted.sum().values[x])+")" for x in range(0,len(sorted_labels))}
#      20     labels_by_sample_size = {sorted_labels[x]+" (N="+str(unweighted.sum().values[x])+")":unweighted.sum().values[x] for x in range(0,len(sorted_labels))}
#      21     labels_restricted = [x for x in labels_by_sample_size.keys() if labels_by_sample_size[x] > min_sample_size]
#
# <ipython-input-35-fdafdc6bc0ec> in <dictcomp>(.0)
#      17     errors = 100 * np.sqrt(unweighted)/unweighted
#      18
# ---> 19     labels_by_sample_size = {unweighted.sum().values[x]:sorted_labels[x]+" (N="+str(unweighted.sum().values[x])+")" for x in range(0,len(sorted_labels))}
#      20     labels_by_sample_size = {sorted_labels[x]+" (N="+str(unweighted.sum().values[x])+")":unweighted.sum().values[x] for x in range(0,len(sorted_labels))}
#      21     labels_restricted = [x for x in labels_by_sample_size.keys() if labels_by_sample_size[x] > min_sample_size]
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
search(BES_reduced_with_na,"mortgage", mask = BES_Panel["euRefVoteW14"].notnull())
# Out:
# mortgagePaymentW14__100.0                                                                                        5989
# secondHomeW14__Yes: I/we own another property outright (without a mortgage)                                     21679
# homeOwnW14_Own with a mortgage                                                                                  30076
# buyHomeFutureW14_Yes, I will be able to buy with a mortgage                                                      7221
# housing_Buying leasehold/freehold on a mortgage                                                                 12101
# profile_house_tenureW10_Own with a mortgage                                                                     17649
# profile_house_tenureW10_Own (part-own) through shared ownership scheme (i.e. pay part mortgage, part rent)      17649
# profile_house_tenureW11_Own - with a mortgage                                                                   19068
# profile_house_tenureW11_Own (part-own) - through shared ownership scheme (i.e. pay part mortgage, part rent)    19068
# profile_house_tenureW12_Own - with a mortgage                                                                   20279
# profile_house_tenureW12_Own (part-own) - through shared ownership scheme (i.e. pay part mortgage, part rent)    20279
# profile_house_tenureW13_Own - with a mortgage                                                                   19874
# profile_house_tenureW13_Own (part-own) - through shared ownership scheme (i.e. pay part mortgage, part rent)    19874
# profile_house_tenure_Own with a mortgage                                                                        20486
# profile_house_tenure_Own (part-own) through shared ownership scheme (i.e. pay part mortgage, part rent)         20486
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.distplot(BES_reduced_with_na["mortgagePaymentW14__100.0"][df1=='Stay/remain in the EU'].dropna(), label="Remain");
sns.distplot(BES_reduced_with_na["mortgagePaymentW14__100.0"][df1=='Leave the EU'].dropna(), label="Leave");
plt.legend();
plt.title("Please estimate the proportion (%) of household income, after tax, spent on your mortgage per month\n(May 2008, current euRefVote preference)");

# %%
plt.figure(figsize=(12,8))
sns.distplot(BES_reduced_with_na["mortgagePaymentW14__100.0"][df1=='Stay/remain in the EU'].dropna(), label="Remain");
sns.distplot(BES_reduced_with_na["mortgagePaymentW14__100.0"][df1=='Leave the EU'].dropna(), label="Leave");
plt.legend();
plt.title("Please estimate the proportion (%) of household income, after tax, spent on your mortgage per month\n(May 2008, current euRefVote preference)");
# Out:
# Index(['Stay/remain in the EU', 'Leave the EU', 'I would/will not vote',
#        'Don't know'],
#       dtype='object')

# %%
gc.collect()
# Out:
# 44

# %%
all_source_inc_vars
# Out:
# ['allSourceIncome_1W11',
#  'allSourceIncome_2W11',
#  'allSourceIncome_3W11',
#  'allSourceIncome_4W11',
#  'allSourceIncome_5W11',
#  'allSourceIncome_6W11',
#  'allSourceIncome_7W11',
#  'allSourceIncome_8W11',
#  'allSourceIncome_9W11']

# %%
flat_euref_ethno = euref_ethno.set_index("euRef").stack().reset_index()
ques_stub = "How much do you agree or disagree with the following statements?\n"
flat_euref_ethno.columns = ["euRef",ques_stub,"answers"]
flat_euref_ethno["answers"] = flat_euref_ethno["answers"].replace("Neither agree nor disagree","Neither")
order  = list(ethno1amal.cat.categories)
order = ["Neither" if x=="Neither agree nor disagree" else x for x in order]

# %%
all_source_inc_vars = list(search(BES_Panel,"allSourceIncome_\d+W11").index)
euref_var_name = "euRefVoteW11"
euref_var = [euref_var_name]
new_euref_var_name = "euRefVotePref(pre2017GE)"

mask = (BES_Panel[all_source_inc_vars].notnull().all(axis=1))
mask = mask & (BES_Panel[euref_var].notnull())[euref_var_name]

allSource_df = BES_Panel[all_source_inc_vars+euref_var][mask].copy()
allSource_df.columns = ["Earnings from employment (own or spouse / partner’s)",
                        "Occupational pension(s) – from previous employer(s)",
                        "State retirement or widow’s pension(s)",
                        "Jobseeker’s Allowance / Unemployment benefit",
                        "Income Support or family credit",
                        "Invalidity, sickness or disabled pension or benefit(s)",
                        "Other state benefit",
                        "Interest from savings or investments",
                        "Student grant or loan",
                        "Dependent on parents/other relatives",
                        "Other source",
                        "Don’t know",
                        new_euref_var_name]

allSource_df = allSource_df.set_index(new_euref_var_name).stack().reset_index()
ques_stub = "Do you get income from any of these sources\n(and your wife / husband / partner) at present?\n *Tick all that apply*"
allSource_df.columns = [new_euref_var_name,
                        ques_stub,
                        "answers"]


sns.catplot(x="answers", hue=new_euref_var_name, col_wrap=2,
            col = ques_stub,
            data=allSource_df,
            kind='count', orient='h', aspect=1.3);
Treatment = "allSourceIncome_by_eurefvote"
output_subfolder = create_subdir(BES_output_folder,Treatment)
fname = output_subfolder +Treatment + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
allSource_df["euRefVotePref(pre2017GE)"].value_counts()
# Out:
# Stay/remain in the EU    177276
# Leave the EU             164436
# Don't know                18036
# I would/will not vote     11724
# Name: euRefVotePref(pre2017GE), dtype: int64

# %%
search(BES_Panel,"personal", mask = BES_Panel["profile_eurefvote"].notnull())
# Out:
# econPersonalRetroW1              18792
# econPersonalProspW1               3393
# econPersonalRetroW2              19773
# econPersonalProspW2               3714
# econPersonalRetroW3              19596
# econPersonalRetroW4              22589
# econPersonalRetroW6               5663
# econPersonalProspW6               5662
# econPersonalRetroW7              25992
# econPersonalRetroW8              13083
# econPersonalRetroW10             27246
# econPersonalProspW10             27237
# econPersonalRetroW11             28321
# econPersonalRetroW12              8051
# econPersonalRetroW13             28546
# econPersonalRetroW14             27582
# profile_gross_personal           37319
# personality_agreeableness        34014
# personality_conscientiousness    34014
# personality_extraversion         34015
# personality_neuroticism          34013
# personality_openness             34013
# dtype: int64

# %%
search(BES_Panel,"age", mask = BES_Panel["profile_eurefvote"].notnull())
# Out:
# ageW1                       18809
# likeFarageW1                18790
# likeFarageW2                19763
# likeFarageW3                19597
# likeFarageW4                22589
# likeFarageW5                22585
# likeFarageW6                22530
# likeFarageW7                25992
# ageW7                       25992
# likeFarageW8                29464
# languageSkillsW8            20101
# languageSkillsWelshW8        1854
# ageW8                       29464
# ageW9                       28248
# likeFarageW9                28248
# likeFarageW10               27246
# integrityFarageW10           6669
# competentFarageW10           6669
# gayMarriageW10              27246
# likeFarageW11               28321
# ageW11                      28321
# ageW12                      31434
# competentFarageW13          14376
# ageW13                      28546
# mortgagePaymentW14           7994
# impAgeW14                    6898
# ageW14                      27582
# age                         12212
# ageGroup                    13436
# Age                         31905
# profile_education_ageW13    28240
# profile_education_age       36930
# dtype: int64

# %%
f, (ax1, ax2) = plt.subplots(1,2, figsize=(12,6))
sns.countplot( BES_Panel["achieveReduceImmigLabW14"] , ax=ax1);
sns.countplot( BES_Panel["achieveReduceImmigConW14"] , ax=ax2);

plt.suptitle("Would any of the following political parties be successful – if elected – in reducing the level of immigration?", y=1.05);
ax1.set_title("Labour")
ax2.set_title("The Conservatives")

for ax in (ax1, ax2):
    plt.sca(ax)
    plt.xticks(rotation=90)

Treatment = "Immigration_Perception_Lab_Con"
output_subfolder = create_subdir(BES_output_folder,Treatment)
fname = output_subfolder + "AchieveReduceImmig_Lab_Con" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
f, (ax1, ax2) = plt.subplots(1,2, figsize=(12,6))
sns.countplot( BES_Panel["immigLabW14"] , ax=ax1);
sns.countplot( BES_Panel["immigConW14"] , ax=ax2);

plt.suptitle("Some people think that the Uf, (ax1, ax2) = plt.subplots(1,2, figsize=(12,6))
sns.countplot( BES_Panel["immigLabW14"] , ax=ax1);
sns.countplot( BES_Panel["immigConW14"] , ax=ax2);

plt.suptitle("Some people think that the UK should allow *many more* immigrants\nto come to the UK to live and others think that the UK\nshould allow *many fewer* immigrants.\nWhere would you place the parties on this scale?", y=1.05);
ax1.set_title("Labour")
ax2.set_title("The Conservatives")

for ax in (ax1, ax2):
    plt.sca(ax)
    plt.xticks(rotation=90)

Treatment = "Immigration_Perception_Lab_Con"
output_subfolder = create_subdir(BES_output_folder,Treatment)
fname = output_subfolder + "Immigration_Perception_Lab_Con" + ".png"
plt.savefig( fname, bbox_inches='tight' )K should allow *many more* immigrants\nto come to the UK to live and others think that the UK\nshould allow *many fewer* immigrants.\nWhere would you place the parties on this scale?", y=1.05);
ax1.set_title("Labour")
ax2.set_title("The Conservatives")

for ax in (ax1, ax2):
    plt.sca(ax)
    plt.xticks(rotation=90)

Treatment = "Immigration_Perception_Lab_Con"
output_subfolder = create_subdir(BES_output_folder,Treatment)
fname = output_subfolder + "Immigration_Perception_Lab_Con" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
var1 ="profile_eurefvote"
var2 ="ethno"
# amal_al_3cat.name = var2

df1 = BES_Panel["profile_house_tenure"]
df2 = BES_Panel["profile_house_tenure"]  #amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=True,
              title="Social Liberalism-Conservativism vs Housing Tenure")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3172             try:
# -> 3173                 value = Series(value)
#    3174             except:
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     276
# --> 277                 data = SingleBlockManager(data, index, fastpath=True)
#     278
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\internals.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    4676         if not isinstance(block, Block):
# -> 4677             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    4678
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\internals.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3204
# -> 3205     return klass(values, ndim=ndim, placement=placement)
#    3206
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim)
#    2302         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2303                                           placement=placement)
#    2304
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\internals.py in __init__(self, values, placement, ndim)
#     124                 'Wrong number of items passed {val}, placement implies '
# --> 125                 '{mgr}'.format(val=len(self.values), mgr=len(self.mgr_locs)))
#     126
#
# ValueError: Wrong number of items passed 2, placement implies 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d07fc0e407fb> in <module>
#       9
#      10 nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=True,
# ---> 11               title="Social Liberalism-Conservativism vs Housing Tenure")
#      12
#
# <ipython-input-16-7893203cb55f> in nice_bar_plot(ser1, ser2, normalize, sort_labels, output_folder, text_width, text_fontsize, min_sample_size, title, drop_insig, fuckErrors)
#      52 #     iter(a)
#      53
# ---> 54     stacked[var1] = stacked[var1].apply( lambda x: x +" (N="+str(unweighted.sum(axis=1).loc[x])+")" )
#      55     stacked[var1].cat.set_categories(stacked[var1].cat.categories[all_nan_rows],inplace=True)
#      56 #     return stacked
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3191         """
#    3192
# -> 3193         self._ensure_valid_index(value)
#    3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\frame.py in _ensure_valid_index(self, value)
#    3173                 value = Series(value)
#    3174             except:
# -> 3175                 raise ValueError('Cannot set a frame with no defined index '
#    3176                                  'and a value that cannot be converted to a '
#    3177                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
search(BES_Panel,"ethno")
# Out:
# ethno1W7     30895
# ethno2W7     30895
# ethno3W7     30895
# ethno4W7     30895
# ethno5W7     30895
# ethno6W7     30895
# ethno1W9      7482
# ethno2W9      7482
# ethno3W9      7482
# ethno4W9      7482
# ethno5W9      7482
# ethno6W9      7482
# ethno1W10    30237
# ethno2W10    30237
# ethno3W10    30237
# ethno4W10    30237
# ethno5W10    30237
# ethno6W10    30237
# dtype: int64

# %%
ethno1amal = amalgamate_waves(BES_Panel, "ethno1")
ethno2amal = amalgamate_waves(BES_Panel, "ethno2")
ethno3amal = amalgamate_waves(BES_Panel, "ethno3")
ethno4amal = amalgamate_waves(BES_Panel, "ethno4")
ethno5amal = amalgamate_waves(BES_Panel, "ethno5")
ethno6amal = amalgamate_waves(BES_Panel, "ethno6")

amalgamated_eurefvote = amalgamate_waves(BES_Panel, "euRefVoteW\d+$")
# Out:
# Amalgamating variables:
# {7: 'ethno1W7', 9: 'ethno1W9', 10: 'ethno1W10'}
# Amalgamating variables:
# {7: 'ethno2W7', 9: 'ethno2W9', 10: 'ethno2W10'}
# Amalgamating variables:
# {7: 'ethno3W7', 9: 'ethno3W9', 10: 'ethno3W10'}
# Amalgamating variables:
# {7: 'ethno4W7', 9: 'ethno4W9', 10: 'ethno4W10'}
# Amalgamating variables:
# {7: 'ethno5W7', 9: 'ethno5W9', 10: 'ethno5W10'}
# Amalgamating variables:
# {7: 'ethno6W7', 9: 'ethno6W9', 10: 'ethno6W10'}
# Amalgamating variables:
# {1: 'euRefVoteW1', 2: 'euRefVoteW2', 3: 'euRefVoteW3', 4: 'euRefVoteW4', 6: 'euRefVoteW6', 7: 'euRefVoteW7', 8: 'euRefVoteW8', 9: 'euRefVoteW9', 10: 'euRefVoteW10', 11: 'euRefVoteW11', 12: 'euRefVoteW12', 13: 'euRefVoteW13', 14: 'euRefVoteW14'}

# %%
# g = sns.catplot("alive", col="deck", col_wrap=4,
#                 data=titanic[titanic.deck.notnull()],
#                 kind="count", height=2.5, aspect=.8)

# %%
euref_ethno = pd.concat([amalgamated_eurefvote, ethno1amal, ethno2amal, ethno3amal, ethno4amal, ethno5amal, ethno6amal], axis=1).dropna()
euref_ethno.columns = ["euRef",
                       "Britain has a lot to learn from other countries in running its affairs",
                       "I would rather be a citizen of Britain than of any other country in the world",
                       "There are some things about Britain today that make me ashamed to be British",
                       "People in Britain are too ready to criticise their country",
                       "The world would be a better place if people from other countries were more like the British",
                       "I am often less proud of Britain than I would like to be"]

flat_euref_ethno = euref_ethno.set_index("euRef").stack().reset_index()
ques_stub = "How much do you agree or disagree with the following statements?\n"
flat_euref_ethno.columns = ["euRef",ques_stub,"answers"]
flat_euref_ethno["answers"] = flat_euref_ethno["answers"].replace("Neither agree nor disagree","Neither")
order  = list(ethno1amal.cat.categories)
order = ["Neither" if x=="Neither agree nor disagree" else x for x in order]

# flat_euref_ethno
# Out:
# ['Strongly disagree',
#  'Disagree',
#  'Neither',
#  'Agree',
#  'Strongly agree',
#  "Don't know"]

# %%
sns.catplot(x="answers", hue="euRef", col_wrap=2,
            col = ques_stub,
            data=flat_euref_ethno,
            kind='count', order = order, orient='h', aspect=1.3);
Treatment = "ethno_by_eurefvote"
output_subfolder = create_subdir(BES_output_folder,Treatment)
fname = output_subfolder + "ethno_by_eurefvote" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
amalgamated_eurefvote = amalgamate_waves(BES_Panel, "euRefVoteW(7|8)$", forward_fill=True)
amalgamated_eurefvote.notnull().sum()
# Out:
# Amalgamating variables:
# {7: 'euRefVoteW7', 8: 'euRefVoteW8'}
# 39964

# %%
amalgamated_eurefvote = amalgamate_waves(BES_Panel, "euRefVoteW", forward_fill=False)
amalgamated_eurefvote.notnull().sum()
# Out:
# Amalgamating variables:
# {1: 'euRefVoteW1', 2: 'euRefVoteW2', 3: 'euRefVoteW3', 4: 'euRefVoteW4', 6: 'euRefVoteW6', 7: 'euRefVoteW7', 8: 'euRefVoteW8', 9: 'euRefVoteW9', 10: 'euRefVoteW10', 11: 'euRefVoteW11', 12: 'euRefVoteW12', 13: 'euRefVoteW13', 14: 'euRefVoteW14'}
# 73683

# %%
amalgamated_age = amalgamate_waves(BES_Panel, 'age(W\d+)')
amalgamated_age.notnull().sum()
# Out:
# Amalgamating variables:
# {1: 'ageW1', 7: 'ageW7', 8: 'ageW8', 9: 'ageW9', 11: 'ageW11', 12: 'ageW12', 13: 'ageW13', 14: 'ageW14'}
# 67193

# %%
sns.lineplot(x=amalgamated_age, y=(amalgamated_eurefvote=="Leave the EU"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     917             try:
# --> 918                 result = self._python_apply_general(f)
#     919             except Exception:
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\relational.py in bootstrapped_cis(vals)
#     698
# --> 699             boots = bootstrap(vals, func=func, n_boot=n_boot)
#     700             cis = utils.ci(boots, ci)
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      85     for i in range(int(n_boot)):
# ---> 86         resampler = rs.randint(0, n, n)
#      87         sample = [a.take(resampler, axis=0) for a in args]
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: low >= high
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-29370f5399af> in <module>
# ----> 1 sns.lineplot(x=amalgamated_age, y=(amalgamated_eurefvote=="Leave the EU"))
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, sort, err_style, err_kws, legend, ax, **kwargs)
#    1082         ax = plt.gca()
#    1083
# -> 1084     p.plot(ax, kwargs)
#    1085
#    1086     return ax
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     773                     err = "estimator must be None when specifying units"
#     774                     raise ValueError(err)
# --> 775                 x, y, y_ci = self.aggregate(y, x, units)
#     776             else:
#     777                 y_ci = None
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\relational.py in aggregate(self, vals, grouper, units)
#     716                                columns=["low", "high"]).stack()
#     717         else:
# --> 718             cis = grouped.apply(bootstrapped_cis)
#     719
#     720         # Unpack the CIs into "wide" format for plotting
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#    3467                       examples=_apply_docs['series_examples']))
#    3468     def apply(self, func, *args, **kwargs):
# -> 3469         return super(SeriesGroupBy, self).apply(func, *args, **kwargs)
#    3470
#    3471     @Appender(_agg_doc)
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, func, *args, **kwargs)
#     928
#     929                 with _group_selection_context(self):
# --> 930                     return self._python_apply_general(f)
#     931
#     932         return result
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     934     def _python_apply_general(self, f):
#     935         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 936                                                    self.axis)
#     937
#     938         return self._wrap_applied_output(
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\groupby\groupby.py in apply(self, f, data, axis)
#    2271             # group might be modified
#    2272             group_axes = _get_axes(group)
# -> 2273             res = f(group)
#    2274             if not _is_indexed_like(res, group_axes):
#    2275                 mutated = True
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\relational.py in bootstrapped_cis(vals)
#     697                 return null_ci
#     698
# --> 699             boots = bootstrap(vals, func=func, n_boot=n_boot)
#     700             cis = utils.ci(boots, ci)
#     701             return pd.Series(cis, ["low", "high"])
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\algorithms.py in bootstrap(*args, **kwargs)
#      84     boot_dist = []
#      85     for i in range(int(n_boot)):
# ---> 86         resampler = rs.randint(0, n, n)
#      87         sample = [a.take(resampler, axis=0) for a in args]
#      88         boot_dist.append(f(*sample, **func_kwargs))
#
# mtrand.pyx in mtrand.RandomState.randint()
#
# ValueError: low >= high

# %%
amalgamated_eurefvote_minus_dk = amalgamated_eurefvote.replace("I would/will not vote",np.nan).replace("Don't know",np.nan)
mask = amalgamated_eurefvote_minus_dk.notnull()&amalgamated_age.notnull()

# %%
amal_leave = amalgamated_eurefvote_minus_dk[mask] =="Leave the EU"
sns.lineplot(x=amalgamated_age[mask].astype('float'), y=amal_leave);
plt.xlim([16,90]);
plt.xlabel('age');
plt.ylabel('Prob of Voting Leave over Remain');
Treatment = "Age_by_leave_vote"
output_subfolder = create_subdir(BES_output_folder,Treatment)
fname = output_subfolder + "Age_by_leave_vote" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
mask.sum()
# Out:
# 57707

# %%
amalgamated_al_scale = amalgamate_waves(BES_Panel, "al_scale", forward_fill=False)

amal_al_3cat = pd.qcut(amalgamated_al_scale.cat.codes.replace(-1, np.nan),3)
amal_al_3cat.cat.rename_categories(["Liberal","Centrist","Authoritarian"],inplace=True)
amal_al_3cat.value_counts()
# Out:
# Amalgamating variables:
# {7: 'al_scaleW7W8W9', 6: 'al_scaleW6', 1: 'al_scaleW1W2W3W4W5', 10: 'al_scaleW10W11W12', 13: 'al_scaleW13', 14: 'al_scaleW14'}
# Liberal          24916
# Centrist         24888
# Authoritarian    19392
# dtype: int64

# %%
sns.countplot(x = amal_al_3cat, hue = BES_Panel["profile_house_tenure"])

# %%
def nice_bar_plot(ser1, ser2, normalize = 'columns', sort_labels=False, output_folder = BES_output_folder,
                  text_width=8, text_fontsize=14, min_sample_size=100, title=None, drop_insig=True, fuckErrors=True,
                  mask=1):
    var1 = ser1.name
    var2 = ser2.name
    
    mask = ser1.notnull() & ser2.notnull() & mask
    ct = pd.crosstab( ser1, ser2,
                      values= get_all_weights(mask), aggfunc=sum, normalize=normalize)*100
    if sort_labels:
        sorted_labels = list(ser2.value_counts().index)
    else:
        sorted_labels = list(ser2.cat.categories)
           

    unweighted = pd.crosstab( ser1, ser2 )
    errors = 100 * np.sqrt(unweighted)/unweighted     

    labels_by_sample_size = {unweighted.sum().values[x]:sorted_labels[x]+" (N="+str(unweighted.sum().values[x])+")" for x in range(0,len(sorted_labels))}    
    labels_by_sample_size = {sorted_labels[x]+" (N="+str(unweighted.sum().values[x])+")":unweighted.sum().values[x] for x in range(0,len(sorted_labels))}    
    labels_restricted = [x for x in labels_by_sample_size.keys() if labels_by_sample_size[x] > min_sample_size] 
#     return labels_by_sample_size, labels_restricted
    if drop_insig:
        rubbish_entries = ct<errors
        ct[rubbish_entries]=np.nan
        errors[rubbish_entries]=np.nan
#     return(sorted_labels, errors, labels_by_sample_size)
    all_nan_rows = ~errors.isnull().any(axis=1)
    errors.columns = list( labels_by_sample_size.keys() )
   
    ct.columns = list( labels_by_sample_size.keys() )
    ct = ct.loc[all_nan_rows, labels_restricted]
#     return errors, labels_restricted
    errors = errors.loc[all_nan_rows, labels_restricted]
#     errors=errors.T
#     return errors
#     return errors, ct
    treatment = var2 +" by " + var1
    output_subfolder = create_subdir(output_folder, treatment)
    
    import textwrap 

    wrapper = textwrap.TextWrapper(width=text_width) 

    stacked = ct.stack().reset_index().rename(columns={0:'%',"level_1":var2})
    err_stacked = errors.stack().reset_index().rename(columns={0:'%',"level_1":var2})
    fig = plt.figure(figsize=(20, 8))
    ax = fig.subplots()

#     a = [np.ones(16),np.ones(16)]
#     a = errors.values
#     return a
#     iter(a)    
    
    stacked[var1] = stacked[var1].apply( lambda x: x +" (N="+str(unweighted.sum(axis=1).loc[x])+")" )
    stacked[var1].cat.set_categories(stacked[var1].cat.categories[all_nan_rows],inplace=True)
#     return stacked
#     return stacked['%'].shape,err_stacked["%"].values.reshape(len(stacked),1).shape
    if fuckErrors:
        sns.barplot(x = stacked[var2],
                    y = stacked['%'],
                    hue = stacked[var1],
                    ax = ax, order = labels_restricted);
    else:
        sns.barplot(x = stacked[var2],
                    y = stacked['%'],
                    hue = stacked[var1],
                    ax = ax, order = labels_restricted,
                    yerr = errors.values);        
                    # err_stacked["%"].values );
# .reshape(len(stacked),1)
    if title is None:
        title = var2 +" by " + var1
    plt.title(title)
    sorted_labels = [sorted_labels[x]+" (N="+str(unweighted.sum().values[x])+")" for x in range(0,len(sorted_labels))]
    ax.set_xticklabels([ wrapper.fill(text=x) for x in labels_restricted], rotation=0, fontsize=text_fontsize);

    ax.annotate(dataset_citation, (0,0), (0, -140),
                     xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 7) ;           
    fname = output_subfolder + title.replace(" ","_") + ".png"
    fig.savefig( fname, bbox_inches='tight' )

# %%
var1 ="profile_house_tenure"
var2 ="Lib-Auth Scale"
amal_al_3cat.name = var2

df1 = BES_Panel["profile_house_tenure"]
df2 = amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=True,
              title="Social Liberalism-Conservativism vs Housing Tenure")

# %%
var1 ="profile_gross_personal"
var2 ="Lib-Auth Scale"
amal_al_3cat.name = var2

df1 = BES_Panel[var1]
df2 = amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=True,
              title="Social Liberalism-Conservativism vs Gross Personal Income")

# %%
var1 ="riskPoverty"
var2 ="Lib-Auth Scale"
amal_al_3cat.name = var2
amalgamated_riskPoverty.name=var1

df1 = amalgamated_riskPoverty
df2 = amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=True,
              title="Social Liberalism-Conservativism vs Risk Poverty")

# %%
var1 ="welfarePreference"
var2 ="Lib-Auth Scale"
amal_al_3cat.name = var2
amalgamated_welfarePreference.name=var1

df1 = amalgamated_welfarePreference
df2 = amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Social Liberalism-Conservativism vs welfarePreference")

# %%
var1 ="borrowEssentialsW14"
var2 ="Lib-Auth Scale"
amal_al_3cat.name = var2
# amalgamated_welfarePreference.name=var1

df1 = BES_Panel[var1]
df2 = amal_al_3cat
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="Social Liberalism-Conservativism vs borrowEssentials")

# %%
BES_Panel['welfarePreferenceW2'][amal_al_3cat.notnull()].value_counts()
# Out:
# Too high         1630
# About right      1142
# Don't know        887
# Too low           796
# Much too high     767
# Much too low      252
# Name: welfarePreferenceW2, dtype: int64

# %%
# %%time
# BES_reduced_with_na["amalgamated_riskPoverty"] = amalgamated_riskPoverty
pattern = "riskPoverty"
name = "riskPovertyW1__Very likely"
corr_type = "spearman"
df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type)
display_corr(df, name, corr_type, text_wrap_length=50)
# Out:
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\numpy\lib\function_base.py:2400: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\numpy\lib\function_base.py:2401: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# <style  type="text/css" >
# </style>
# <table id="T_335c169c_1808_11e9_848d_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for riskPovertyW1__Very likely</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >p</th>
#         <th class="col_heading level0 col2" >N</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row0" class="row_heading level0 row0" >riskUnemploymentW1__Very likely</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row0_col0" class="data row0 col0" >0.48</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row0_col2" class="data row0 col2" >26733</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row1" class="row_heading level0 row1" >worryEconSecurityW14__10.0</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row1_col0" class="data row1 col0" >0.43</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row1_col2" class="data row1 col2" >10452</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row2" class="row_heading level0 row2" >polForTheRichW1__Strongly agree</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row2_col0" class="data row2 col0" >0.3</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row2_col1" class="data row2 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row2_col2" class="data row2 col2" >28360</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row3" class="row_heading level0 row3" >profile_socgradeW7__E</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row3_col0" class="data row3 col0" >0.27</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row3_col1" class="data row3 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row3_col2" class="data row3 col2" >15943</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row4" class="row_heading level0 row4" >debtW14_Yes</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row4_col0" class="data row4 col0" >0.26</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row4_col2" class="data row4 col2" >10157</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row5" class="row_heading level0 row5" >changeCostLiveW4__Getting a lot higher</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row5_col0" class="data row5 col0" >0.26</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row5_col1" class="data row5 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row5_col2" class="data row5 col2" >20608</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row6" class="row_heading level0 row6" >lr3W1W2W3W4W5__Strongly agree</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row6_col0" class="data row6 col0" >0.25</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row6_col1" class="data row6 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row6_col2" class="data row6 col2" >28556</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row7" class="row_heading level0 row7" >cutsTooFarNationalW1__Gone much too far</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row7_col0" class="data row7 col0" >0.25</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row7_col1" class="data row7 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row7_col2" class="data row7 col2" >27314</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row8" class="row_heading level0 row8" >lr4W1W2W3W4W5__Strongly agree</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row8_col0" class="data row8 col0" >0.25</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row8_col1" class="data row8 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row8_col2" class="data row8 col2" >28726</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row9" class="row_heading level0 row9" >cutsTooFarLocalW1__Gone much too far</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row9_col0" class="data row9 col0" >0.25</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row9_col1" class="data row9 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row9_col2" class="data row9 col2" >26155</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row10" class="row_heading level0 row10" >bestPMW8_Jeremy Corbyn</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row10_col0" class="data row10 col0" >0.25</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row10_col1" class="data row10 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row10_col2" class="data row10 col2" >7386</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row11" class="row_heading level0 row11" >mortgagePaymentW14__100.0</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row11_col0" class="data row11 col0" >0.24</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row11_col1" class="data row11 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row11_col2" class="data row11 col2" >1987</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row12" class="row_heading level0 row12" >smallEmergency_5W14_Yes</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row12_col0" class="data row12 col0" >0.24</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row12_col1" class="data row12 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row12_col2" class="data row12 col2" >10298</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row13" class="row_heading level0 row13" >scotUnionEconomyW3__Very likely</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row13_col0" class="data row13 col0" >0.24</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row13_col1" class="data row13 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row13_col2" class="data row13 col2" >3853</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row14" class="row_heading level0 row14" >forcedSubjClassW14_Working class</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row14_col0" class="data row14 col0" >0.24</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row14_col1" class="data row14 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row14_col2" class="data row14 col2" >2725</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row15" class="row_heading level0 row15" >efficacyPolCareW3__Strongly agree</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row15_col0" class="data row15 col0" >0.24</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row15_col1" class="data row15 col1" >0.00</td>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row15_col2" class="data row15 col2" >21009</td>
#     </tr>    <tr>
#         <th id="T_335c169c_1808_11e9_848d_20cf301b91b3level0_row16" class="row_heading level0 row16" >borrowEssentialsW14_Yes</th>
#         <td id="T_335c169c_1808_11e9_848d_20cf301b91b3row16_col0" class="data row
# Wall time: 1min 3s

# %%
# borrowEssentials
#

# %%
search(BES_Panel,"profile_past").index
# Out:
# Index(['profile_past_vote_2005', 'profile_past_vote_2010',
#        'profile_past_vote_2017', 'profile_past_vote_2015'],
#       dtype='object')

# %%
prof_past = ['profile_past_vote_2005', 'profile_past_vote_2010',
       'profile_past_vote_2015']

# %%
search(BES_Panel,"generalElectionVote")
# euRefVoteW14    31063
# generalElectionVoteW14
Remain = BES_Panel["euRefVoteW14"]=="Stay/remain in the EU"
Conservative = BES_Panel["generalElectionVoteW14"]=="Conservative"
England = BES_Panel["country"]=="England"
ppv = BES_Panel[Conservative&Remain&England][prof_past]

# %%
ppv[prof_past[1]].value_counts()
# Out:
# Conservative Party                          1114
# Liberal Democrats                            208
# Did not vote                                 157
# Labour Party                                 124
# Don't know                                    29
# United Kingdom Independence Party (UKIP)      11
# Green Party                                   11
# Some other party                               6
# British National Party (BNP)                   2
# Respect                                        0
# Plaid Cymru                                    0
# Scottish National Party                        0
# Name: profile_past_vote_2010, dtype: int64

# %%
search(BES_reduced_with_na,'ptv.*ExpW14').index
# Out:
# Index(['ptvConExpW14__Very likely', 'ptvLabExpW14__Very likely',
#        'ptvLDExpW14__Very likely', 'ptvUKIPExpW14__Very likely',
#        'ptvGrnExpW14__Very likely'],
#       dtype='object')

# %%
BES_reduced_with_na[Conservative&Remain&England][search(BES_reduced_with_na,'ptv.*ExpW14').index].describe()
# Out:
#        ptvConExpW14__Very likely  ptvLabExpW14__Very likely  \
# count                 412.000000                   400.0000
# mean                    8.674757                     1.1125
# std                     1.859032                     2.0568
# min                     0.000000                     0.0000
# 25%                     8.000000                     0.0000
# 50%                    10.000000                     0.0000
# 75%                    10.000000                     1.0000
# max                    10.000000                    10.0000
#
#        ptvLDExpW14__Very likely  ptvUKIPExpW14__Very likely  \
# count                396.000000                  400.000000
# mean                   2.881313                    0.665000
# std                    2.846906                    1.730682
# min                    0.000000                    0.000000
# 25%                    0.000000                    0.000000
# 50%                    2.500000                    0.000000
# 75%                    5.000000                    0.000000
# max                   10.000000                   10.000000
#
#        ptvGrnExpW14__Very likely
# count                 389.000000
# mean                    1.424165
# std                     2.246996
# min                     0.000000
# 25%                     0.000000
# 50%                     0.000000
# 75%                     2.000000
# max                    10.000000

# %%
BES_Panel["smallEmergency_2W14"].value_counts()
# Out:
# 2.0           28311
# Don't know     1778
# Yes             974
# Name: smallEmergency_2W14, dtype: int64

# %%
# %%time
BES_reduced_with_na["amalgamated_riskPoverty"] = amalgamated_riskPoverty
pattern = "riskPoverty"
name = "amalgamated_riskPoverty"
corr_type = "spearman"
df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type)
display_corr(df, name, corr_type, text_wrap_length=50)

# %%
# Out:
# 'riskPovertyW1&2&3&4&6&7&8&9&10&11&14'

# %%
amalgamated_riskPoverty = amalgamate_waves(BES_reduced_with_na, "riskPoverty", forward_fill=False)
amalgamated_riskPoverty.name
# Out:
# Amalgamating variables:
# {1: 'riskPovertyW1__Very likely', 2: 'riskPovertyW2__Very likely', 3: 'riskPovertyW3__Very likely', 4: 'riskPovertyW4__Very likely', 6: 'riskPovertyW6__Very likely', 7: 'riskPovertyW7__Very likely', 8: 'riskPovertyW8__Very likely', 9: 'riskPovertyW9__Very likely', 10: 'riskPovertyW10__Very likely', 11: 'riskPovertyW11__Very likely', 14: 'riskPovertyW14__Very likely'}

# %%
amalgamated_welfarePreference = amalgamate_waves(BES_Panel, "welfarePreference", forward_fill=False)
# Out:
# Amalgamating variables:
# {2: 'welfarePreferenceW2', 3: 'welfarePreferenceW3', 4: 'welfarePreferenceW4', 6: 'welfarePreferenceW6', 7: 'welfarePreferenceW7', 11: 'welfarePreferenceW11', 14: 'welfarePreferenceW14'}

# %%
search(BES_reduced_with_na,"riskPoverty")
# Out:
# riskPovertyW1__Very likely     29069
# riskPovertyW2__Very likely     28939
# riskPovertyW3__Very likely     26659
# riskPovertyW4__Very likely     30031
# riskPovertyW6__Very likely     28790
# riskPovertyW7__Very likely     29611
# riskPovertyW8__Very likely      5922
# riskPovertyW9__Very likely     28042
# riskPovertyW10__Very likely    28539
# riskPovertyW11__Very likely    29446
# riskPovertyW14__Very likely    29507
# dtype: int64

# %%
search(BES_reduced_with_na,"euRefVoteW\d+_")
# Out:
# euRefVoteW4_Leave the EU     26312
# euRefVoteW10_Leave the EU    27697
# euRefVoteW9_Leave the EU     28069
# euRefVoteW7_Leave the EU     28044
# euRefVoteW6_Leave the EU     25266
# euRefVoteW8_Leave the EU     31008
# euRefVoteW2_Leave the EU     21661
# euRefVoteW13_Leave the EU    28805
# euRefVoteW14_Leave the EU    28061
# euRefVoteW1_Leave the EU     25130
# euRefVoteW11_Leave the EU    28476
# euRefVoteW3_Leave the EU     23358
# euRefVoteW12_Leave the EU    31831
# dtype: int64

# %%
eurefcorrs = BES_reduced_with_na.corrwith(BES_reduced_with_na["euRefVoteW8_Leave the EU"])

# %%
eurefcorrs.sort_values()
# Out:
# approveEUW9__Strongly approve                                           -0.707062
# euUKRichW8__Strongly agree                                              -0.699203
# euScepticismW7__Work towards single European government                 -0.689121
# approveEUW7__Strongly approve                                           -0.678462
# euLawsLevelW8__Strongly agree                                           -0.669226
# euUKRichW7__Strongly agree                                              -0.666262
# euRefDoOverW10_Yes                                                      -0.663029
# euRefDoOverW14_Yes                                                      -0.658313
# euRefDoOverW11_Yes                                                      -0.656222
# euRefFinalPostW9_Yes                                                    -0.653816
# euLeaveBigBusinessW8__Much more likely                                  -0.645867
# euPreventWarW8__Strongly agree                                          -0.644986
# euRefDoOverW13_Yes                                                      -0.643109
# euLawsLevelW7__Strongly agree                                           -0.630921
# approveEUW10__Strongly approve                                          -0.618366
# euLeaveBigBusinessW7__Much more likely                                  -0.616109
# europeannessW11__Very strongly European                                 -0.613733
# immigSelfW9__Allow many more                                            -0.609973
# immigSelfW12__Allow many more                                           -0.607670
# eesEUIntegrationSelfW3__Unification should be pushed further            -0.605485
# immigSelfW11__Allow many more                                           -0.605067
# europeannessW9__Very strongly European                                  -0.604542
# euCloserW8__Strongly agree                                              -0.603704
# immigSelfW8__Allow many more                                            -0.601558
# eesEUIntegrationSelfW6__Unification should be pushed further            -0.600847
# europeannessW8__Very strongly European                                  -0.599134
# euLeaveBigBusinessW10__Much more likely                                 -0.598401
# europeannessW12__Very strongly European                                 -0.598016
# eesEUIntegrationSelfW4__Unification should be pushed further            -0.597804
# europeannessW10__Very strongly European                                 -0.596596
#                                                                            ...
# euRefpastVoteW12_Leave the EU                                            0.889395
# euIDW9_The leave side                                                    0.891142
# euRefVoteW9_Leave the EU                                                 0.892972
# profile_eurefvote_Leave the EU                                           0.893136
# euIDW7_The leave side                                                    0.896432
# euRefVoteW7_Leave the EU                                                 0.905525
# euRefVoteUnsqueezeW7_Leave the EU                                        0.923747
# euExpRefW7_To leave the European Union                                   0.926534
# euIDW8_The leave side                                                    0.958127
# euRefVoteUnsqueezeW8_Leave the EU                                        1.000000
# euRefVoteW8_Leave the EU                                                 1.000000
# euRefVotePostW8_Leave the EU                                             1.000000
# euRefVote2W8_Leave the EU                                                1.000000
# blackEquality2W14__Gone much too far                                          NaN
# femaleEquality2W14__Gone much too far                                         NaN
# gayEquality2W14__Gone much too far                                            NaN
# polKnowMerkelW10_President of Turkey                                          NaN
# miilabelW1_pol values-left                                                    NaN
# miilabelW3_energy                                                             NaN
# miilabelW4_youth                                                              NaN
# miilabelW5_flooding                                                           NaN
# gor_Northern Ireland                                                          NaN
# profile_work_statW1_W10_Working full time (30 or more hours per week)         NaN
# profile_work_statW1_W10_Retired                                               NaN
# profile_work_statW1_W10_Working part time (8-29 hours a week)                 NaN
# profile_work_statW1_W10_Full time student                                     NaN
# profile_work_statW1_W10_Not working                                           NaN
# profile_work_statW1_W10_Unemployed                                            NaN
# profile_work_statW1_W10_Working part time (Less than 8 hours a week)          NaN
# euRefpastVoteW14_Leave the EU                                                 NaN
# Length: 6864, dtype: float64

# %%
Treatment = "immigSelf_by_wave_and_corr_with_eurefVote"
output_subfolder = create_subdir(BES_output_folder, Treatment)

plt.figure(figsize=(12,8))
# immigSelfW7__Allow many more
# imvar = "immigSelf"
cols = search(BES_reduced_with_na,"immigSelf").index
waves = [int(re.match("immigSelfW(\d+)__",x).groups()[0]) for x in cols]
df= BES_reduced_with_na[cols]/6
df.columns = waves
stacked = df.stack().reset_index().rename(columns={0:'likert',"level_1":"immigSelf"})
stacked["immigSelf"] = stacked["immigSelf"].astype('category').cat.reorder_categories(waves)
ax = sns.lineplot(data = stacked, x = "immigSelf", y="likert", label="immigSelf");
plt.ylim(stacked["likert"].min(),stacked["likert"].max());

corrs = []
for wave in waves:
#     print(BES_reduced_with_na["euRefVoteW"+str(wave)+"_Leave the EU"].mean())
#     print(BES_reduced_with_na["immigEconW"+str(wave)+"__Good for economy"].mean())
    corrs.append(-BES_reduced_with_na["euRefVoteW"+str(wave)+"_Leave the EU"].corr(BES_reduced_with_na["immigSelfW"+str(wave)+"__Allow many more"]))
#     print(BES_reduced_with_na["euRefVoteW"+str(wave)+"_Leave the EU"].corr(BES_reduced_with_na["immigEconW"+str(wave)+"__Good for economy"]))
sns.lineplot(ax=ax, x=waves, y=corrs, label="immigSelf corr Leave|Remain");
plt.ylim([0,1]);
title = "immigSelf: Some people think that the UK should allow *many more* immigrants to come to the UK to live and others think that the UK should allow *many fewer* immigrants. Where would you place yourself and the parties on this scale?"

fname = output_subfolder + "immigSelf_by_wave_and_corr_with_eurefVote" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
plt.figure(figsize=(12,8))

cols = search(BES_reduced_with_na,"immigEcon").index
waves = [int(re.match("immigEconW(\d+)__",x).groups()[0]) for x in cols]
df= BES_reduced_with_na[cols]/6
df.columns = waves
stacked = df.stack().reset_index().rename(columns={0:'likert',"level_1":"immigEcon"})
stacked["immigEcon"] = stacked["immigEcon"].astype('category').cat.reorder_categories(waves)
ax = sns.lineplot(data = stacked, x = "immigEcon", y="likert", label="immigEcon");
plt.ylim(stacked["likert"].min(),stacked["likert"].max());

corrs = []
for wave in waves:
#     print(BES_reduced_with_na["euRefVoteW"+str(wave)+"_Leave the EU"].mean())
#     print(BES_reduced_with_na["immigEconW"+str(wave)+"__Good for economy"].mean())
    corrs.append(-BES_reduced_with_na["euRefVoteW"+str(wave)+"_Leave the EU"].corr(BES_reduced_with_na["immigEconW"+str(wave)+"__Good for economy"]))
#     print(BES_reduced_with_na["euRefVoteW"+str(wave)+"_Leave the EU"].corr(BES_reduced_with_na["immigEconW"+str(wave)+"__Good for economy"]))
sns.lineplot(ax=ax, x=waves, y=corrs, label="immigEcon corr Leave|Remain");
plt.ylim([0,1]);
# Out:
# [-0.5486133330870787,
#  -0.5854394887936015,
#  -0.5681409454748365,
#  -0.5637465953235029,
#  -0.564375345795741,
#  -0.5736370921074672,
#  -0.5264728290960424,
#  -0.5290646428639084,
#  -0.5482372086744626,
#  -0.5106039556485504]

# %%
waves
# Out:
# ['1', '2', '3', '4', '7', '8', '10', '11', '13', '14']

# %%
def display_corr(df, name, corr_type, top_num = 20, round_places = 2,
                 correlation_text = "r", p_value_text = "p", sample_size_text = "N",
                 text_wrap_length=50):
#     df.index = [x[0:60] for x in df.index]
    df.index =  [trim_strings(x) for x in df.index.str.wrap(width = text_wrap_length)]
    
    df[correlation_text] = df[correlation_text].round(round_places)
    
    df1 = df.sort_values(by=correlation_text, ascending=False)[0:top_num][[correlation_text,p_value_text,sample_size_text]]
    df2 = df.sort_values(by=correlation_text)[0:top_num][[correlation_text,p_value_text,sample_size_text]]
    
    df1[p_value_text]     = df1[p_value_text].apply(lambda x: "{0:0.2f}".format(x))
    df2[p_value_text]     = df2[p_value_text].apply(lambda x: "{0:0.2f}".format(x))

    df1_caption = "Top "+str(top_num)+ " positive "+"("+corr_type+")"+" correlations for "+name
    df2_caption = "Top "+str(top_num)+ " negative "+"("+corr_type+")"+" correlations for "+name

    df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption(df1_caption)
    df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption(df2_caption)

    display_html(df1_styler._repr_html_().replace("\\n","<br />")+df2_styler._repr_html_().replace("\\n","<br />"), raw=True)

# %%
def trim_strings(x):
    if len( x.split("\n") )>1:
        return x.split("\n")[0] + "[...]"
    else:
        return x

# %%
def make_corr_summary(input_df, name, corr_type = "spearman", sample_size_text = "N", correlation_text = "r",
                      abs_correlation_text = "abs_r", p_value_text = "p",
                      min_p_value = 0.01, min_variance = 0.0, min_sample_size = 500):

    df1 = input_df.copy()
    focal_var = df1[name]
    focal_mask = focal_var.notnull()


    pattern_list = [x for x in df1.columns if re.search(pattern,x)]

    variances = df1[focal_mask].var()
    low_var_list = list(variances[variances<min_variance].index)
    sample_sizes = df1[focal_mask].notnull().sum()
    low_sample_size_list = list(sample_sizes[sample_sizes<min_sample_size].index)

    drop_list = pattern_list+low_var_list+low_sample_size_list
    df1.drop(drop_list,axis=1,inplace=True)

    if corr_type == "pearson":
        df = df1.apply(lambda x: corr_simple_pearsonr(x,focal_var)).apply(pd.Series)
    elif corr_type == "spearman":
        df = df1.apply(lambda x: corr_simple_spearmanr(x,focal_var)).apply(pd.Series)

    if len(df.columns)!=3:
        df=df.T
    df.columns = [correlation_text,p_value_text,sample_size_text]
 
    df[sample_size_text] = df[sample_size_text].astype('int')
    df[abs_correlation_text] = df[correlation_text].abs()

    zero_var_other_way_around_list = list(df[df[correlation_text].isnull()].index)
    df.dropna(inplace=True)

    insignificant_list = df[df[p_value_text]>min_p_value].index
    df.drop(insignificant_list,inplace=True)

    df.sort_values(by=abs_correlation_text,ascending=False,inplace=True)


    stub_dict = {}
    drop_list = []
    # drop repeated references to same variable in different waves???
    # so, what about different categories??? eg. blahWX_subcat
    # how about, just replace wave match as "X"
    # create a dictionary keyed on the top corr variable with all the drops inside
    for ind in df.index:
        waveless = remove_wave(ind)
        if waveless in stub_dict.keys():
            drop_list.append(ind)
            stub_dict[waveless].append(ind)
        else:
            stub_dict[waveless] = [ind]
    df.drop(drop_list,inplace=True)
    return df, corr_type

# %%
search(BES_Panel,"profile_past")
# Out:
# profile_past_vote_2005    58280
# profile_past_vote_2010    64996
# profile_past_vote_2017    37245
# profile_past_vote_2015    57064
# dtype: int64

# %%
search(BES_Panel,"pano")
# Out:
# panoW11    48507
# panoW12    34393
# panoW13    30985
# panoW14    32578
# panoW2     30467
# panoW3     27837
# panoW6     28582
# dtype: int64

# %%
cat_dictionary["profile_past_vote_2017"]
# Out:
# Index(['Conservative', 'Labour', 'Liberal Democrat',
#        'Scottish National Party (SNP)', 'Plaid Cymru',
#        'United Kingdom Independence Party (UKIP)', 'Green Party',
#        'British National Party (BNP)'],
#       dtype='object')

# %%
# df1[NotLabour2015&Labour2017].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-02b5c81d0d92> in <module>
#       1 df1 = BES_Panel["profile_past_vote_2017"].replace(9999.0, np.nan).astype('category').cat.rename_categories(cat_dictionary["profile_past_vote_2017"])
# ----> 2 df1[NotLabour2015&Labour2017].value_counts()
#
# NameError: name 'Labour2017' is not defined

# %%
df1 = BES_Panel["profile_past_vote_2017"].replace(9999.0, np.nan).astype('category').cat.rename_categories(cat_dictionary["profile_past_vote_2017"])
NotLabour2015 = BES_Panel["profile_past_vote_2015"]!="Labour"
Labour2017 = df1=="Labour"
England = BES_Panel["country"] =="England"

# %%
    mask = ser1.notnull() & ser2.notnull()
    ct = pd.crosstab( ser1, ser2,
                      values= get_all_weights(mask), aggfunc=sum, normalize=normalize)*100

# %%
100*BES_Panel["profile_eurefvote"][NotLabour2015&Labour2017&England].value_counts()/BES_Panel["profile_eurefvote"][NotLabour2015&Labour2017&England].value_counts().sum()
# Out:
# Stay/remain in the EU    61.322043
# Leave the EU             38.104343
# Don't know                0.573614
# Name: profile_eurefvote, dtype: float64

# %%
100*BES_Panel["euRefVoteW14"][NotLabour2015&Labour2017&England].value_counts()/BES_Panel["euRefVoteW14"][NotLabour2015&Labour2017&England].value_counts().sum()
# Out:
# Stay/remain in the EU    60.867966
# Leave the EU             30.305259
# Don't know                6.693637
# I would/will not vote     2.133137
# Name: euRefVoteW14, dtype: float64

# %%
100*BES_Panel["profile_eurefvote"][NotLabour2015&Labour2017&England&One_of_the_seats_Labour_gained].value_counts()/BES_Panel["profile_eurefvote"][NotLabour2015&Labour2017&England&One_of_the_seats_Labour_gained].value_counts().sum()
# Out:
# Stay/remain in the EU    61.187215
# Leave the EU             36.529680
# Don't know                2.283105
# Name: profile_eurefvote, dtype: float64

# %%
100*BES_Panel["euRefVoteW14"][NotLabour2015&Labour2017&England&One_of_the_seats_Labour_gained].value_counts()/BES_Panel["euRefVoteW14"][NotLabour2015&Labour2017&England&One_of_the_seats_Labour_gained].value_counts().sum()
# Out:
# Stay/remain in the EU    62.111801
# Leave the EU             29.813665
# Don't know                6.832298
# I would/will not vote     1.242236
# Name: euRefVoteW14, dtype: float64

# %%
pano_where_lab_gained = [ 38,  41,  97, 100, 111, 125, 127, 158, 169, 170, 181, 238, 273,
       314, 332, 338, 340, 368, 451, 453, 458, 464, 536, 546, 588, 600,
       601, 607]

# %%
search(BES_Panel,'euRefVote')
# Out:
# euRefVoteW1                30327
# euRefVoteW2                25798
# euRefVoteW3                27830
# euRefVoteW4                31442
# euRefVoteW6                30150
# euRefVoteW7                30895
# euRefVoteSqueezeW7          4717
# euRefVoteUnsqueezeW7       30895
# euRefVotePostW8             4326
# euRefVoteW8                33501
# euRefVoteSqueezeW8          3818
# euRefVoteUnsqueezeW8       29175
# euRefVote2W8               29175
# euRefVoteHypotheticalW9     1788
# euRefVoteW9                28248
# euRefVoteW10               30237
# euRefVoteW11               30956
# euRefVoteW12               34394
# euRefVoteW13               31136
# euRefVoteW14               31063
# profile_eurefvote          49745
# dtype: int64

# %%
amalgamate_pano = amalgamate_waves(BES_Panel, "pano", forward_fill=True)
# Out:
# Amalgamating variables:
# {11: 'panoW11', 12: 'panoW12', 13: 'panoW13', 14: 'panoW14', 2: 'panoW2', 3: 'panoW3', 6: 'panoW6'}

# %%
One_of_the_seats_Labour_gained = amalgamate_pano.apply(lambda x: x in pano_where_lab_gained)
One_of_the_seats_Labour_gained.name = "One_of_the_seats_Labour_gained"

# %%
# One_of_the_seats_Labour_gained

# %%
# pd.crosstab( df1, df2 )
# Out:
# euRefInterestW8       Not at all interested  Not very interested  \
# profile_eurefturnout
# No, did not vote                        324                  271
# Yes, voted                              399                 1349
# Don't know                               12                   21
#
# euRefInterestW8       Somewhat interested  Very interested  Don't know
# profile_eurefturnout
# No, did not vote                      590              520          92
# Yes, voted                           8117            19354         245
# Don't know                             44               47          51

# %%
var1 ="profile_eurefturnout"
var2 ="euRefInterestW8"

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
              title="How interested are you in the EU referendum that will be held on June 23rd?")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-9f7bc78d0525> in <module>
#       8
#       9 nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
# ---> 10               title="How interested are you in the EU referendum that will be held on June 23rd?")
#      11
#
# <ipython-input-29-97613a982939> in nice_bar_plot(ser1, ser2, normalize, sort_labels, output_folder, text_width, text_fontsize, min_sample_size, title, drop_insig)
#      58                 hue = stacked[var1],
#      59                 ax = ax, order = labels_restricted,
# ---> 60                 yerr = errors.values);
#      61                 # err_stacked["%"].values );
#      62 # .reshape(len(stacked),1)
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
#    1644                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1645                         color=self.colors[j], align="center",
# -> 1646                         label=hue_level, **kws)
#    1647
#    1648                 # Draw the confidence intervals
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2312             errorbar = self.errorbar(ex, ey,
#    2313                                      yerr=yerr, xerr=xerr,
# -> 2314                                      fmt='none', **error_kw)
#    2315         else:
#    2316             errorbar = None
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\axes\_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3243
#    3244         if yerr is not None:
# -> 3245             lower, upper = extract_err(yerr, y)
#    3246             # select points without upper/lower limits in y and
#    3247             # draw normal errorbars for these points
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\axes\_axes.py in extract_err(err, data)
#    3184                 fe = safe_first_element(err)
#    3185                 if len(err) != len(data) or np.size(fe) > 1:
# -> 3186                     raise ValueError("err must be [ scalar | N, Nx1 "
#    3187                                      "or 2xN array-like ]")
#    3188             # using list comps rather than arrays to preserve units
#
# ValueError: err must be [ scalar | N, Nx1 or 2xN array-like ]

# %%
# %debug
# Out:
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\matplotlib\axes\_axes.py(3186)extract_err()
#    3184                 fe = safe_first_element(err)
#    3185                 if len(err) != len(data) or np.size(fe) > 1:
# -> 3186                     raise ValueError("err must be [ scalar | N, Nx1 "
#    3187                                      "or 2xN array-like ]")
#    3188             # using list comps rather than arrays to preserve units
#
# ipdb> up
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\matplotlib\axes\_axes.py(3245)errorbar()
#    3243
#    3244         if yerr is not None:
# -> 3245             lower, upper = extract_err(yerr, y)
#    3246             # select points without upper/lower limits in y and
#    3247             # draw normal errorbars for these points
#
# ipdb> up
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\matplotlib\__init__.py(1805)inner()
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ipdb> u
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\matplotlib\axes\_axes.py(2314)bar()
#    2312             errorbar = self.errorbar(ex, ey,
#    2313                                      yerr=yerr, xerr=xerr,
# -> 2314                                      fmt='none', **error_kw)
#    2315         else:
#    2316             errorbar = None
#
# ipdb> up
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\matplotlib\__init__.py(1805)inner()
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ipdb> up
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\seaborn\categorical.py(1646)draw_bars()
#    1644                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1645                         color=self.colors[j], align="center",
# -> 1646                         label=hue_level, **kws)
#    1647
#    1648                 # Draw the confidence intervals
#
# ipdb> up
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\seaborn\categorical.py(1661)plot()
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# ipdb> up
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\seaborn\categorical.py(3154)barplot()
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# ipdb> up
# > <ipython-input-29-97613a982939>(60)nice_bar_plot()
#      58                 hue = stacked[var1],
#      59                 ax = ax, order = labels_restricted,
# ---> 60                 yerr = errors.values);
#      61                 # err_stacked["%"].values );
#      62 # .reshape(len(stacked),1)
#
# ipdb> up
# > <ipython-input-30-9f7bc78d0525>(10)<module>()
#       7
#       8
#       9 nice_bar_plot(df1, df2, min_sample_size=1, normalize='columns',drop_insig=False,
# ---> 10               title="How interested are you in the EU referendum that will be held on June 23rd?")
#      11
#
# ipdb> down
# > <ipython-input-29-97613a982939>(60)nice_bar_plot()
#      58                 hue = stacked[var1],
#      59                 ax = ax, order = labels_restricted,
# ---> 60                 yerr = errors.values);
#      61                 # err_stacked["%"].values );
#      62 # .reshape(len(stacked),1)
#
# ipdb> err_stacked
#    profile_eurefturnout                euRefInterestW8          %
# 0      No, did not vote  Not at all interested (N=735)   5.555556
# 1      No, did not vote   Not very interested (N=1641)   6.074567
# 2      No, did not vote   Somewhat interested (N=8751)   4.116935
# 3      No, did not vote      Very interested (N=19921)   4.385290
# 4      No, did not vote             Don't know (N=388)  10.425721
# 5            Yes, voted  Not at all interested (N=735)   5.006262
# 6            Yes, voted   Not very interested (N=1641)   2.722664
# 7            Yes, voted   Somewhat interested (N=8751)   1.109947
# 8            Yes, voted      Very interested (N=19921)   0.718811
# 9            Yes, voted             Don't know (N=388)   6.388766
# 10           Don't know  Not at all interested (N=735)  28.867513
# 11           Don't know   Not very interested (N=1641)  21.821789
# 12           Don't know   Somewhat interested (N=8751)  15.075567
# 13           Don't know      Very interested (N=19921)  14.586499
# 14           Don't know             Don't know (N=388)  14.002801
# ipdb> stacked
#          profile_eurefturnout                euRefInterestW8          %
# 0   No, did not vote (N=1797)  Not at all interested (N=735)  57.492584
# 1   No, did not vote (N=1797)   Not very interested (N=1641)  22.982514
# 2   No, did not vote (N=1797)   Somewhat interested (N=8751)   9.477409
# 3   No, did not vote (N=1797)      Very interested (N=19921)   3.937203
# 4   No, did not vote (N=1797)             Don't know (N=388)  27.963375
# 5        Yes, voted (N=29464)  Not at all interested (N=735)  40.776556
# 6        Yes, voted (N=29464)   Not very interested (N=1641)  74.829872
# 7        Yes, voted (N=29464)   Somewhat interested (N=8751)  89.799154
# 8        Yes, voted (N=29464)      Very interested (N=19921)  95.741144
# 9        Yes, voted (N=29464)             Don't know (N=388)  55.274130
# 10         Don't know (N=175)  Not at all interested (N=735)   1.730861
# 11         Don't know (N=175)   Not very interested (N=1641)   2.187614
# 12         Don't know (N=175)   Somewhat interested (N=8751)   0.723437
# 13         Don't know (N=175)      Very interested (N=19921)   0.321652
# 14         Don't know (N=175)             Don't know (N=388)  16.762496
# ipdb> quit
# --KeyboardInterrupt--

# %%
var1 ="profile_eurefturnout"
var2 ="euRefInterestW8"

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]
mask = df1.notnull()&df2.notnull()

# sns.barplot(x=var1,hue=var2,data=BES_Panel[[var1,var2]][mask], orient='v')
ax = sns.barplot(x=var1, y=var1, hue=var2, data=BES_Panel[[var1,var2]][mask],
                 estimator=lambda x: len(x) / sum(mask) * 100, orient='v')
# ax.set(ylabel="Percent")

# %%
search(BES_reduced_with_na,"Amtb")
# Out:
# homeAmtbW14__£1 million or above     18139
# savingsAmtbW14__£200,000 or above    12850
# debtAmtbW14__£200,000 or above        6937
# dtype: int64

# %%
# %%time

pattern = "debtAmtbW14"
name = "debtAmtbW14__£200,000 or above"
corr_type = "spearman"
df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type)
display_corr(df, name, corr_type, text_wrap_length=50)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_134190ba_1474_11e9_acc9_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for debtAmtbW14__£200,000 or above</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >p</th>
#         <th class="col_heading level0 col2" >N</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row0" class="row_heading level0 row0" >profile_gross_householdW10__£150,000 and over</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row0_col0" class="data row0 col0" >0.26</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row0_col2" class="data row0 col2" >3300</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row1" class="row_heading level0 row1" >profile_gross_personal__£100,000 and over</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row1_col0" class="data row1 col0" >0.22</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row1_col2" class="data row1 col2" >4155</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row2" class="row_heading level0 row2" >profile_house_tenure_Own with a mortgage</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row2_col0" class="data row2 col0" >0.2</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row2_col1" class="data row2 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row2_col2" class="data row2 col2" >4202</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row3" class="row_heading level0 row3" >mainSourceIncomeW6_Earnings from employment (own[...]</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row3_col0" class="data row3 col0" >0.19</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row3_col1" class="data row3 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row3_col2" class="data row3 col2" >620</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row4" class="row_heading level0 row4" >profile_house_tenureW13_Own - with a mortgage</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row4_col0" class="data row4 col0" >0.19</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row4_col2" class="data row4 col2" >4070</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row5" class="row_heading level0 row5" >allSourceIncome_1W6_Yes</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row5_col0" class="data row5 col0" >0.18</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row5_col1" class="data row5 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row5_col2" class="data row5 col2" >2513</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row6" class="row_heading level0 row6" >housing_Buying leasehold/freehold on a mortgage</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row6_col0" class="data row6 col0" >0.18</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row6_col1" class="data row6 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row6_col2" class="data row6 col2" >2320</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row7" class="row_heading level0 row7" >homeOwnW14_Own with a mortgage</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row7_col0" class="data row7 col0" >0.17</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row7_col1" class="data row7 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row7_col2" class="data row7 col2" >6816</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row8" class="row_heading level0 row8" >workingStatusW1W2W3W4W5_Working full time (30 or[...]</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row8_col0" class="data row8 col0" >0.16</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row8_col1" class="data row8 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row8_col2" class="data row8 col2" >2817</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row9" class="row_heading level0 row9" >profile_work_statW11_Working full time (30 or more[...]</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row9_col0" class="data row9 col0" >0.16</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row9_col1" class="data row9 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row9_col2" class="data row9 col2" >3826</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row10" class="row_heading level0 row10" >profile_household_sizeW10__8 or more</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row10_col0" class="data row10 col0" >0.15</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row10_col1" class="data row10 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row10_col2" class="data row10 col2" >3624</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row11" class="row_heading level0 row11" >profile_marital_statW14_Married</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row11_col0" class="data row11 col0" >0.14</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row11_col1" class="data row11 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row11_col2" class="data row11 col2" >6937</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row12" class="row_heading level0 row12" >leaveVoteUKIPConW8__Many more of them are[...]</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row12_col0" class="data row12 col0" >0.14</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row12_col1" class="data row12 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row12_col2" class="data row12 col2" >554</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row13" class="row_heading level0 row13" >workingStatusW6_W12_Working full time (30 or more[...]</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row13_col0" class="data row13 col0" >0.14</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row13_col1" class="data row13 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row13_col2" class="data row13 col2" >5040</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row14" class="row_heading level0 row14" >relationshipName1W12_Your spouse or partner</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row14_col0" class="data row14 col0" >0.14</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row14_col1" class="data row14 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row14_col2" class="data row14 col2" >589</td>
#     </tr>    <tr>
#         <th id="T_134190ba_1474_11e9_acc9_20cf301b91b3level0_row15" class="row_heading level0 row15" >marital_Married</th>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row15_col0" class="data row15 col0" >0.13</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row15_col1" class="data row15 col1" >0.00</td>
#         <td id="T_134190ba_1474_11e9_acc9_20cf301b91b3row15_col2" class="data row15 col2" >5105</td>
#     </tr>    <tr>
#         <th id="T_134190
# Wall time: 31.6 s

# %%
# %%time

pattern = "homeAmtbW14"
name = "homeAmtbW14__£1 million or above"
corr_type = "spearman"
df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type)
display_corr(df, name, corr_type)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for homeAmtbW14__£1 million or above</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >p</th>
#         <th class="col_heading level0 col2" >N</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row0" class="row_heading level0 row0" >mapMiddleClassW3</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row0_col0" class="data row0 col0" >0.42</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row0_col2" class="data row0 col2" >3862</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row1" class="row_heading level0 row1" >profile_gross_householdW11__£150,000 and over</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row1_col0" class="data row1 col0" >0.39</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row1_col2" class="data row1 col2" >10241</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row2" class="row_heading level0 row2" >mapConW3</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row2_col0" class="data row2 col0" >0.38</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row2_col1" class="data row2 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row2_col2" class="data row2 col2" >3734</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row3" class="row_heading level0 row3" >gorW2_London</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row3_col0" class="data row3 col0" >0.37</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row3_col1" class="data row3 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row3_col2" class="data row3 col2" >7593</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row4" class="row_heading level0 row4" >savingsAmtbW14__£200,000 or above</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row4_col0" class="data row4 col0" >0.37</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row4_col2" class="data row4 col2" >10018</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row5" class="row_heading level0 row5" >subjClassW2_W4W7W9_Yes, middle class</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row5_col0" class="data row5 col0" >0.33</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row5_col1" class="data row5 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row5_col2" class="data row5 col2" >11953</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row6" class="row_heading level0 row6" >subjClassW12W14_Yes, middle class</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row6_col0" class="data row6 col0" >0.32</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row6_col1" class="data row6 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row6_col2" class="data row6 col2" >14550</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row7" class="row_heading level0 row7" >winConstituencyConW4__100 - Very likely to win</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row7_col0" class="data row7 col0" >0.29</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row7_col1" class="data row7 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row7_col2" class="data row7 col2" >8160</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row8" class="row_heading level0 row8" >localEconNowW12__Very good</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row8_col0" class="data row8 col0" >0.28</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row8_col1" class="data row8 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row8_col2" class="data row8 col2" >5849</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row9" class="row_heading level0 row9" >gorW14_South East</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row9_col0" class="data row9 col0" >0.26</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row9_col1" class="data row9 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row9_col2" class="data row9 col2" >18139</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row10" class="row_heading level0 row10" >profile_gross_personal__£100,000 and over</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row10_col0" class="data row10 col0" >0.26</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row10_col1" class="data row10 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row10_col2" class="data row10 col2" >11457</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row11" class="row_heading level0 row11" >econGenProspW2__Get a lot better</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row11_col0" class="data row11 col0" >0.24</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row11_col1" class="data row11 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row11_col2" class="data row11 col2" >1359</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row12" class="row_heading level0 row12" >lr_scaleW7W8W9__Right</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row12_col0" class="data row12 col0" >0.23</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row12_col1" class="data row12 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row12_col2" class="data row12 col2" >11351</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row13" class="row_heading level0 row13" >belongGroup_3W11_Yes</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row13_col0" class="data row13 col0" >0.23</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row13_col1" class="data row13 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row13_col2" class="data row13 col2" >11450</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row14" class="row_heading level0 row14" >allSourceIncome_8W11_Yes</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row14_col0" class="data row14 col0" >0.22</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row14_col1" class="data row14 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row14_col2" class="data row14 col2" >11629</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row15" class="row_heading level0 row15" >partyContactConW6_Yes</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row15_col0" class="data row15 col0" >0.22</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row15_col1" class="data row15 col1" >0.00</td>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row15_col2" class="data row15 col2" >4893</td>
#     </tr>    <tr>
#         <th id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3level0_row16" class="row_heading level0 row16" >redistSelfW1__Government should be less concerned about equa</th>
#         <td id="T_27f9a4c2_146f_11e9_bc35_20cf301b91b3row16_col0"
# Wall time: 49.1 s

# %%
# %%time

pattern = "savingsAmtbW14"
name = "savingsAmtbW14__£200,000 or above"
corr_type = "spearman"
df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type)
display_corr(df, name, corr_type, text_wrap_length=50)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_628ae63e_1474_11e9_903a_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for savingsAmtbW14__£200,000 or above</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >p</th>
#         <th class="col_heading level0 col2" >N</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row0" class="row_heading level0 row0" >homeOwnW14_Owned outright</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row0_col0" class="data row0 col0" >0.48</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row0_col2" class="data row0 col2" >12685</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row1" class="row_heading level0 row1" >profile_house_tenureW10_Own outright</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row1_col0" class="data row1 col0" >0.47</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row1_col2" class="data row1 col2" >7666</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row2" class="row_heading level0 row2" >profile_house_tenureW12_Own - outright</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row2_col0" class="data row2 col0" >0.47</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row2_col1" class="data row2 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row2_col2" class="data row2 col2" >8823</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row3" class="row_heading level0 row3" >allSourceIncome_8W11_Yes</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row3_col0" class="data row3 col0" >0.47</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row3_col1" class="data row3 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row3_col2" class="data row3 col2" >8314</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row4" class="row_heading level0 row4" >housing_Own the leasehold/freehold outright</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row4_col0" class="data row4 col0" >0.41</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row4_col2" class="data row4 col2" >5390</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row5" class="row_heading level0 row5" >homeAmtbW14__£1 million or above</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row5_col0" class="data row5 col0" >0.37</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row5_col1" class="data row5 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row5_col2" class="data row5 col2" >10018</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row6" class="row_heading level0 row6" >ageW14</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row6_col0" class="data row6 col0" >0.36</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row6_col1" class="data row6 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row6_col2" class="data row6 col2" >12850</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row7" class="row_heading level0 row7" >ageGroup__66+</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row7_col0" class="data row7 col0" >0.35</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row7_col1" class="data row7 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row7_col2" class="data row7 col2" >3109</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row8" class="row_heading level0 row8" >allSourceIncome_2W11_Yes</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row8_col0" class="data row8 col0" >0.35</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row8_col1" class="data row8 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row8_col2" class="data row8 col2" >8314</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row9" class="row_heading level0 row9" >mainSourceIncomeW11_Occupational pension(s) - from[...]</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row9_col0" class="data row9 col0" >0.32</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row9_col1" class="data row9 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row9_col2" class="data row9 col2" >8231</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row10" class="row_heading level0 row10" >workingStatusW14_Retired</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row10_col0" class="data row10 col0" >0.31</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row10_col1" class="data row10 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row10_col2" class="data row10 col2" >12697</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row11" class="row_heading level0 row11" >Age</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row11_col0" class="data row11 col0" >0.3</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row11_col1" class="data row11 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row11_col2" class="data row11 col2" >8332</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row12" class="row_heading level0 row12" >profile_work_statW14_Retired</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row12_col0" class="data row12 col0" >0.3</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row12_col1" class="data row12 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row12_col2" class="data row12 col2" >12666</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row13" class="row_heading level0 row13" >profile_work_statW1_W10_Retired</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row13_col0" class="data row13 col0" >0.29</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row13_col1" class="data row13 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row13_col2" class="data row13 col2" >1667</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row14" class="row_heading level0 row14" >workingStatusW6_W12_Retired</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row14_col0" class="data row14 col0" >0.25</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row14_col1" class="data row14 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row14_col2" class="data row14 col2" >10401</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row15" class="row_heading level0 row15" >profile_gross_householdW10__£150,000 and over</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row15_col0" class="data row15 col0" >0.24</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row15_col1" class="data row15 col1" >0.00</td>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row15_col2" class="data row15 col2" >7242</td>
#     </tr>    <tr>
#         <th id="T_628ae63e_1474_11e9_903a_20cf301b91b3level0_row16" class="row_heading level0 row16" >subjClassW2_W4W7W9_Yes, middle class</th>
#         <td id="T_628ae63e_1474_11e9_903a_20cf301b91b3row16_col0" class
# Wall time: 44.1 s

# %%
# %%time

pattern = "strongLeader"
name = "strongLeaderW14__Strongly agree"
corr_type = "spearman"
df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type)
display_corr(df, name, corr_type, text_wrap_length=50)
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_5826f676_1475_11e9_853a_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for strongLeaderW14__Strongly agree</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >p</th>
#         <th class="col_heading level0 col2" >N</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row0" class="row_heading level0 row0" >al_scaleW14__Authoritarian</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row0_col0" class="data row0 col0" >0.5</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row0_col2" class="data row0 col2" >26095</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row1" class="row_heading level0 row1" >nhsEUW14__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row1_col0" class="data row1 col0" >0.46</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row1_col2" class="data row1 col2" >24634</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row2" class="row_heading level0 row2" >al2W14__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row2_col0" class="data row2 col0" >0.46</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row2_col1" class="data row2 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row2_col2" class="data row2 col2" >27599</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row3" class="row_heading level0 row3" >overseasAidW14__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row3_col0" class="data row3 col0" >0.45</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row3_col1" class="data row3 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row3_col2" class="data row3 col2" >27895</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row4" class="row_heading level0 row4" >immigrantsWelfareStateW7__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row4_col0" class="data row4 col0" >0.43</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row4_col2" class="data row4 col2" >14134</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row5" class="row_heading level0 row5" >immigContributeTakeW8__Get more than they pay</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row5_col0" class="data row5 col0" >0.42</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row5_col1" class="data row5 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row5_col2" class="data row5 col2" >13846</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row6" class="row_heading level0 row6" >euPriorityBalanceW14__Control immigration</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row6_col0" class="data row6 col0" >0.41</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row6_col1" class="data row6 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row6_col2" class="data row6 col2" >25731</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row7" class="row_heading level0 row7" >taxSpendUKIPW14__Government should increase taxes[...]</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row7_col0" class="data row7 col0" >0.4</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row7_col1" class="data row7 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row7_col2" class="data row7 col2" >15074</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row8" class="row_heading level0 row8" >aom7W7__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row8_col0" class="data row8 col0" >0.39</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row8_col1" class="data row8 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row8_col2" class="data row8 col2" >3531</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row9" class="row_heading level0 row9" >authLong2W10__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row9_col0" class="data row9 col0" >0.39</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row9_col1" class="data row9 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row9_col2" class="data row9 col2" >4043</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row10" class="row_heading level0 row10" >likeNuttallW10__Strongly like</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row10_col0" class="data row10 col0" >0.38</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row10_col1" class="data row10 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row10_col2" class="data row10 col2" >6372</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row11" class="row_heading level0 row11" >al1W14__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row11_col0" class="data row11 col0" >0.38</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row11_col1" class="data row11 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row11_col2" class="data row11 col2" >27748</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row12" class="row_heading level0 row12" >likeUKIPW11__Strongly like</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row12_col0" class="data row12 col0" >0.37</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row12_col1" class="data row12 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row12_col2" class="data row12 col2" >17286</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row13" class="row_heading level0 row13" >handleMIIUKIPW9__Very well</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row13_col0" class="data row13 col0" >0.37</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row13_col1" class="data row13 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row13_col2" class="data row13 col2" >3231</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row14" class="row_heading level0 row14" >effectsEUWorkersW8__Much better</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row14_col0" class="data row14 col0" >0.37</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row14_col1" class="data row14 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row14_col2" class="data row14 col2" >15483</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row15" class="row_heading level0 row15" >al5W13__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row15_col0" class="data row15 col0" >0.37</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row15_col1" class="data row15 col1" >0.00</td>
#         <td id="T_5826f676_1475_11e9_853a_20cf301b91b3row15_col2" class="data row15 col2" >18205</td>
#     </tr>    <tr>
#         <th id="T_5826f676_1475_11e9_853a_20cf301b91b3level0_row16" class="row_heading level0 row16" >harkBackW7__Strongly agree</th>
#         <td id="T_5826f676_1475_11e9_853a_2
# Wall time: 1min

# %%
search(BES_reduced_with_na,"euRefVoteW14")
# Out:
# euRefVoteW14_Leave the EU    28061
# dtype: int64

# %%
search(BES_reduced_with_na,"strongLeader",mask=BES_Panel[var1].notnull())
# Out:
# strongLeaderW10__Strongly agree    25020
# strongLeaderW11__Strongly agree    26051
# strongLeaderW14__Strongly agree    25758
# dtype: int64

# %%
var1 ="profile_eurefvote"
var2 ="strongLeaderW14"

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]
# df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=100, normalize='all', title="The best way to run the country would be to have a strong leader who does not have to bother with parliament or elections")

# %%
ct
# Out:
# strongLeaderW14        Strongly disagree   Disagree  \
# profile_eurefvote
# Stay/remain in the EU          19.195689  12.528686
# Leave the EU                    8.881913  13.922983
# Don't know                      0.144244   0.194044
#
# strongLeaderW14        Neither agree nor disagree     Agree  Strongly agree  \
# profile_eurefvote
# Stay/remain in the EU                    6.651277  4.372655        1.898113
# Leave the EU                            10.267811  7.767514        5.334059
# Don't know                               0.256554  0.104004        0.052247
#
# strongLeaderW14        Don't know
# profile_eurefvote
# Stay/remain in the EU    3.942277
# Leave the EU             4.287151
# Don't know               0.198781

# %%
errors
# Out:
# strongLeaderW14        Strongly disagree  Disagree  \
# profile_eurefvote
# Stay/remain in the EU           0.242112  0.214581
# Leave the EU                    0.166813  0.219402
# Don't know                      0.021503  0.027442
#
# strongLeaderW14        Neither agree nor disagree     Agree  Strongly agree  \
# profile_eurefvote
# Stay/remain in the EU                    0.166804  0.139324        0.091429
# Leave the EU                             0.198562  0.175004        0.144006
# Don't know                               0.036651  0.022696        0.013963
#
# strongLeaderW14        Don't know
# profile_eurefvote
# Stay/remain in the EU    0.136265
# Leave the EU             0.138874
# Don't know               0.034091

# %%
var1 ="profile_eurefvote"
var2 ="debtAmtbW14"

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]
df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-434-d78caa079801> in <module>
#       7
#       8
# ----> 9 nice_bar_plot(df1, df2, min_sample_size=100)
#
# <ipython-input-432-a674566c83aa> in nice_bar_plot(ser1, ser2, normalize, sort_labels, output_folder, text_width, text_fontsize, min_sample_size)
#      61                 hue = stacked[var1],
#      62                 ax = ax, order = labels_restricted,
# ---> 63                 yerr = errors.values);
#      64                 # err_stacked["%"].values );
#      65 # .reshape(len(stacked),1)
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3152         ax = plt.gca()
#    3153
# -> 3154     plotter.plot(ax, kwargs)
#    3155     return ax
#    3156
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\categorical.py in plot(self, ax, bar_kws)
#    1659     def plot(self, ax, bar_kws):
#    1660         """Make the plot."""
# -> 1661         self.draw_bars(ax, bar_kws)
#    1662         self.annotate_axes(ax)
#    1663         if self.orient == "h":
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\seaborn\categorical.py in draw_bars(self, ax, kws)
#    1644                 barfunc(offpos, self.statistic[:, j], self.nested_width,
#    1645                         color=self.colors[j], align="center",
# -> 1646                         label=hue_level, **kws)
#    1647
#    1648                 # Draw the confidence intervals
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2312             errorbar = self.errorbar(ex, ey,
#    2313                                      yerr=yerr, xerr=xerr,
# -> 2314                                      fmt='none', **error_kw)
#    2315         else:
#    2316             errorbar = None
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1803                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1804                         RuntimeWarning, stacklevel=2)
# -> 1805             return func(ax, *args, **kwargs)
#    1806
#    1807         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\axes\_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3243
#    3244         if yerr is not None:
# -> 3245             lower, upper = extract_err(yerr, y)
#    3246             # select points without upper/lower limits in y and
#    3247             # draw normal errorbars for these points
#
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\matplotlib\axes\_axes.py in extract_err(err, data)
#    3184                 fe = safe_first_element(err)
#    3185                 if len(err) != len(data) or np.size(fe) > 1:
# -> 3186                     raise ValueError("err must be [ scalar | N, Nx1 "
#    3187                                      "or 2xN array-like ]")
#    3188             # using list comps rather than arrays to preserve units
#
# ValueError: err must be [ scalar | N, Nx1 or 2xN array-like ]

# %%
# %debug

# %%
var1 ="profile_eurefvote"
var2 ="savingsAmtbW14"

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]
df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=100, text_width=9, text_fontsize=12)

# %%
var1 ="profile_eurefvote"
var2 ="homeAmtbW14"

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]
df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=100, text_width=9, text_fontsize=12)

# %%
var1 ="profile_eurefvote"
var2 ="secondHomeAmtbW14"

df1 = BES_Panel[var1]
df2 = BES_Panel[var2]
df2 = df2.cat.rename_categories(list(cat_dictionary[var2]) + ["Prefer not to answer / Don't know"])


nice_bar_plot(df1, df2, min_sample_size=50, text_width=9, text_fontsize=12)

# %%
search(BES_Panel,"amtb",case_sensitive=False)
# Out:
# homeAmtbW14          21912
# secondHomeAmtbW14     2501
# savingsAmtbW14       19367
# debtAmtbW14           8650
# dtype: int64

# %%
var1 ="profile_eurefvote"
# var2 ="profile_gross_household"
var2 = "debtAmtbW14__£200,000 or above"
sorted_labels = cat_dictionary["debtAmtbW14"]

text_width =8
import textwrap 

wrapper = textwrap.TextWrapper(width=text_width)  

fig = plt.figure(figsize=(20, 8))
ax = fig.subplots()
sns.violinplot( BES_Panel[var1], BES_reduced_with_na[var2], cut = 0, ax=ax );
ax.set_yticklabels([ wrapper.fill(text=x) for x in sorted_labels], rotation=0, fontsize=14);

# %%
var1 ="profile_eurefvote"
# var2 ="profile_gross_household"
var2 = "savingsAmtbW14__£200,000 or above"
sorted_labels = cat_dictionary["savingsAmtbW14"]

text_width =8
import textwrap 

wrapper = textwrap.TextWrapper(width=text_width)  

fig = plt.figure(figsize=(20, 8))
ax = fig.subplots()
sns.violinplot( BES_Panel[var1], BES_reduced_with_na[var2], cut = 0, ax=ax );
ax.set_yticklabels([ wrapper.fill(text=x) for x in sorted_labels], rotation=0, fontsize=14);

# %%
# Out:
# Index(['£0-£99', '£100-£499', '£500-£999', '£1,000-£1,999', '£2,000-£2,999',
#        '£3,000-£4,999', '£5,000-£9,999', '£10,000-£14,999', '£15,000-£19,999',
#        '£20,000-£29,999', '£30,000-£39,999', '£40,000-£49,999',
#        '£50,000-£74,999', '£75,000-£999,999', '£100,000-£149,999',
#        '£150-000-£199,999', '£200,000 or above'],
#       dtype='object')

# %%
search(BES_reduced_with_na,"Amtb")
# Out:
# homeAmtbW14__£1 million or above     18139
# savingsAmtbW14__£200,000 or above    12850
# debtAmtbW14__£200,000 or above        6937
# dtype: int64

# %%
# amalgamated_eurefvote

# %%
wts = get_all_weights(amalgamated_eurefvote.notnull())
((amalgamated_eurefvote=="Leave the EU")*wts).mean(), ((amalgamated_eurefvote=="Stay/remain in the EU")*wts).mean()
# Out:
# (0.44765342122869417, 0.43558521771775943)

# %%
wts = get_all_weights(BES_Panel["euRefVoteW8"].notnull())
((BES_Panel["euRefVoteW8"]=="Leave the EU")*wts).mean(), ((BES_Panel["euRefVoteW8"]=="Stay/remain in the EU")*wts).mean()
# Out:
# (0.4626339769186727, 0.42543007882371064)

# %%
wts = get_all_weights(BES_Panel["profile_eurefvote"].notnull())
((BES_Panel["profile_eurefvote"]=="Leave the EU")*wts).mean(), ((BES_Panel["profile_eurefvote"]=="Stay/remain in the EU")*wts).mean()
# Out:
# (0.4774822873568766, 0.5119516808933413)

# %%
((BES_Panel["profile_eurefvote"]=="Leave the EU")).mean(), ((BES_Panel["profile_eurefvote"]=="Stay/remain in the EU")).mean()
# Out:
# (0.31583517631575375, 0.35340488175515244)

# %%
# BES_Panel["profile_eurefvote"].cat.categories

((BES_Panel["profile_eurefvote"]=="Don't know")*wts).mean()
# Out:
# 0.006409827988762454

# %%
BES_Panel["profile_eurefvote"].notnull().sum()

# how to get the fullest version possible?
# Out:
# 49745

# %%
((BES_Panel["profile_eurefvote"]=="Leave the EU")*wts).mean()
# Out:
# 0.28996800077594587

# %%
((BES_Panel["profile_eurefvote"]=="Stay/remain in the EU")*wts).mean()
# Out:
# 0.3110076224066323

# %%
((BES_Panel["profile_eurefvote"]=="Leave the EU")).mean()
# Out:
# 0.31583517631575375

# %%
((BES_Panel["profile_eurefvote"]=="Stay/remain in the EU")).mean()
# Out:
# 0.35340488175515244

# %%
BES_Panel["profile_eurefvote"]

# %%
# ageGroup, profile_eurefvote
# edlevel

# %%
amalgamated_edlevel = amalgamate_waves(BES_Panel, "edlevel")
amalgamated_edlevel.notnull().sum()
# Out:
# Amalgamating variables:
# {1: 'edlevelW1_W6', 7: 'edlevelW7', 8: 'edlevelW8W9W10', 11: 'edlevelW11', 12: 'edlevelW12', 13: 'edlevelW13', 14: 'edlevelW14'}
# 69141

# %%
wts = get_all_weights(BES_Panel["profile_eurefvote"].notnull()&amalgamated_edlevel.notnull())

ct = pd.crosstab( amalgamated_edlevel, BES_Panel["profile_eurefvote"],
             values= wts, aggfunc=sum, normalize='index')*100

sorted_labels = list(amalgamated_edlevel.cat.categories)

# %%
# search(BES_Panel,'profile')

# %%
BES_Panel[match(BES_Panel,'age(W\d+|Group|$)')].notnull().sum()
# Out:
# ageW1       30386
# ageW7       30895
# ageW8       33502
# ageW9       30036
# ageW11      30956
# ageW12      34394
# ageW13      31136
# ageW14      31063
# age         18059
# ageGroup    18108
# dtype: int64

# %%
amalgamated_edlevel = amalgamate_waves(BES_Panel, "edlevel")
amalgamated_edlevel.notnull().sum()

# %%
amalgamated_age = amalgamate_waves(BES_Panel, 'age(W\d+)')
amalgamated_age.notnull().sum()
# Out:
# Amalgamating variables:
# {1: 'ageW1', 7: 'ageW7', 8: 'ageW8', 9: 'ageW9', 11: 'ageW11', 12: 'ageW12', 13: 'ageW13', 14: 'ageW14'}
# 67193

# %%
BES_Panel['ageGroup'].cat.categories
# Out:
# Index(['Under 18', '18-25', '26-35', '36-45', '46-55', '56-65', '66+'], dtype='object')

# %%
amalgamated_age_group = pd.cut(amalgamated_age,[0,18,26,36,46,56,66,200], right=False, labels=BES_Panel['ageGroup'].cat.categories)
amalgamated_age_group.name = "ageGroup"

# %%
Treatment = "euRefVote_by_edlevel"
output_subfolder = create_subdir(BES_output_folder, Treatment)

# %%
# amalgamated_age_group

# %%
## climate change?

# %%
[x for x in BES_Panel.columns if "climate" in x]
# Out:
# ['climateChangeW7', 'climateChangeW10', 'climateChangeW11']

# %%
climateChange = amalgamate_waves(BES_Panel, "climate")
# Out:
# Amalgamating variables:
# {7: 'climateChangeW7', 10: 'climateChangeW10', 11: 'climateChangeW11'}

# %%
Notebook_Treatment = "RandomFunPlots_December"
output_subfolder = BES_output_folder + os.sep + "RandomFunPlots_December" + os.sep
notebook_subfolder = create_subdir(BES_output_folder,Notebook_Treatment)

# %%
Treatment = "ClimateChange"
output_subfolder = create_subdir(notebook_subfolder,Treatment)

# %%
sns.countplot(climateChange);
plt.xticks(rotation=90);
fname = output_subfolder + "climate_change_raw_numbers" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
[x for x in BES_Panel.columns if "enviro" in x]
# Out:
# ['enviroProtectionW1',
#  'enviroProtectionW2',
#  'enviroProtectionW3',
#  'enviroProtectionW4',
#  'enviroGrowthW4',
#  'enviroProtectionW6',
#  'enviroProtectionW7',
#  'enviroGrowthW7',
#  'enviroProtectionW12',
#  'enviroProtectionW14']

# %%
enviroGrowth = amalgamate_waves(BES_Panel, "enviroGrowth")
# Out:
# Amalgamating variables:
# {4: 'enviroGrowthW4', 7: 'enviroGrowthW7'}

# %%
enviroGrowth.value_counts().sum()
# Out:
# 41264

# %%
sns.countplot(enviroGrowth);
plt.xticks(rotation=90);
fname = output_subfolder + "enviroGrowth_raw_numbers" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
enviroProtection = amalgamate_waves(BES_Panel, "enviroProtection")
# Out:
# Amalgamating variables:
# {1: 'enviroProtectionW1', 2: 'enviroProtectionW2', 3: 'enviroProtectionW3', 4: 'enviroProtectionW4', 6: 'enviroProtectionW6', 7: 'enviroProtectionW7', 12: 'enviroProtectionW12', 14: 'enviroProtectionW14'}

# %%
enviroProtection.value_counts()
# Out:
# Not gone far enough           22066
# About right                   18841
# Not gone nearly far enough    10850
# Don't know                     7234
# Gone too far                   6560
# Gone much too far              2966
# Name: enviroProtectionW1&2&3&4&6&7&12&14, dtype: int64

# %%
sns.countplot(enviroProtection);
plt.xticks(rotation=90);
fname = output_subfolder + "enviroProtection_raw_numbers" + ".png"
plt.savefig( fname, bbox_inches='tight' )

# %%
pd.crosstab(index = climateChange, columns = enviroProtection, normalize='all', margins=True).round(2)
# Out:
# enviroProtectionW1&2&3&4&6&7&12&14              Not gone nearly far enough  \
# climateChangeW7&10&11
# Climate changing due to human activity                                0.14
# Climate changing but not due to human activity                        0.01
# Climate not changing                                                  0.00
# Don't know                                                            0.00
# All                                                                   0.16
#
# enviroProtectionW1&2&3&4&6&7&12&14              Not gone far enough  \
# climateChangeW7&10&11
# Climate changing due to human activity                         0.25
# Climate changing but not due to human activity                 0.03
# Climate not changing                                           0.01
# Don't know                                                     0.02
# All                                                            0.31
#
# enviroProtectionW1&2&3&4&6&7&12&14              About right  Gone too far  \
# climateChangeW7&10&11
# Climate changing due to human activity                 0.15          0.04
# Climate changing but not due to human activity         0.08          0.04
# Climate not changing                                   0.02          0.01
# Don't know                                             0.04          0.01
# All                                                    0.29          0.09
#
# enviroProtectionW1&2&3&4&6&7&12&14              Gone much too far  Don't know  \
# climateChangeW7&10&11
# Climate changing due to human activity                       0.01        0.04
# Climate changing but not due to human activity               0.02        0.01
# Climate not changing                                         0.01        0.00
# Don't know                                                   0.00        0.04
# All                                                          0.04        0.10
#
# enviroProtectionW1&2&3&4&6&7&12&14               All
# climateChangeW7&10&11
# Climate changing due to human activity          0.64
# Climate changing but not due to human activity  0.19
# Climate not changing                            0.04
# Don't know                                      0.13
# All                                             1.00

# %%
enviroProtection_hardcore = (climateChange=="Climate changing due to human activity") & (enviroProtection == "Not gone nearly far enough")
enviroProtection_softcore = (climateChange=="Climate changing due to human activity") & (enviroProtection == "Not gone far enough")

# %%
# ep_hardcore_corrs = BES_reduced_with_na[enviroProtection_hardcore|enviroProtection_softcore].corrwith(enviroProtection_hardcore)
# ep_hardcore_corrs.drop([x for x in BES_reduced_with_na.columns if re.match("enviroProtection|climateChange", x)]).dropna().sort_values()

# %%
# ep_hardcore_corrs = BES_reduced_with_na.corrwith(enviroProtection_hardcore)
# ep_hardcore_corrs.drop([x for x in BES_reduced_with_na.columns if re.match("enviroProtection|climateChange", x)]).dropna().sort_values()

# %%
sample_size_text = "N"
correlation_text = "r"
abs_correlation_text = "abs_r"
p_value_text = "p"
corr_type = "spearman"#"pearson"

top_num = 20
round_places = 2

min_p_value = 0.01
min_variance = 0.0
min_sample_size = 500

pattern = "enviroProtection|climateChange"
name = "enviroProtection_hardcore"

# %%
# %%time

df1 = BES_reduced_with_na

pattern_list = [x for x in df1.columns if re.match(pattern,x)]
focal_mask = enviroProtection_hardcore.notnull()
variances = df1[focal_mask].var()
low_var_list = list(variances[variances<min_variance].index)
sample_sizes = df1[focal_mask].notnull().sum()
low_sample_size_list = list(sample_sizes[sample_sizes<min_sample_size].index)

drop_list = pattern_list+low_var_list+low_sample_size_list
df1.drop(drop_list,axis=1,inplace=True)
# Out:
# Wall time: 47.2 s

# %%
# %%time
if corr_type == "pearson":
    df = df1.apply(lambda x: corr_simple_pearsonr(x,enviroProtection_hardcore)).apply(pd.Series)
elif corr_type == "spearman":
    df = df1.apply(lambda x: corr_simple_spearmanr(x,enviroProtection_hardcore)).apply(pd.Series)
    
df.columns = [correlation_text,p_value_text,sample_size_text]
df[sample_size_text] = df[sample_size_text].astype('int')
df[abs_correlation_text] = df[correlation_text].abs()
# Out:
# Wall time: 1min

# %%
zero_var_other_way_around_list = list(df[df[correlation_text].isnull()].index)
df.dropna(inplace=True)

insignificant_list = df[df[p_value_text]>min_p_value].index
df.drop(insignificant_list,inplace=True)

df.sort_values(by=abs_correlation_text,ascending=False,inplace=True)
# df=df.round(round_places)

# %%
stub_dict = {}
drop_list = []
# drop repeated references to same variable in different waves???
# so, what about different categories??? eg. blahWX_subcat
# how about, just replace wave match as "X"
# create a dictionary keyed on the top corr variable with all the drops inside
for ind in df.index:
    waveless = remove_wave(ind)
    if waveless in stub_dict.keys():
        drop_list.append(ind)
        stub_dict[waveless].append(ind)
    else:
        stub_dict[waveless] = [ind]
df.drop(drop_list,inplace=True)

# %%
def display_corr():
    df.index = [x[0:60] for x in df.index]
    df[correlation_text] = df[correlation_text].round(round_places)
    
    df1 = df.sort_values(by=correlation_text, ascending=False)[0:top_num][[correlation_text,p_value_text,sample_size_text]]
    df2 = df.sort_values(by=correlation_text)[0:top_num][[correlation_text,p_value_text,sample_size_text]]
    
    df1[p_value_text]     = df1[p_value_text].apply(lambda x: "{0:0.2f}".format(x))
    df2[p_value_text]     = df2[p_value_text].apply(lambda x: "{0:0.2f}".format(x))
#     df1[[correlation_text,p_value_text]] = df1[[correlation_text,p_value_text]].apply(lambda x: "{0:0.2f}".format(x))
#     df2[[correlation_text,p_value_text]] = df2[[correlation_text,p_value_text]].apply(lambda x: "{0:0.2f}".format(x))

    df1_caption = "Top "+str(top_num)+ " positive "+"("+corr_type+")"+" correlations for "+name
    df2_caption = "Top "+str(top_num)+ " negative "+"("+corr_type+")"+" correlations for "+name

    df1_styler = df1.style.set_table_attributes("style='display:inline'").set_caption(df1_caption)
    df2_styler = df2.style.set_table_attributes("style='display:inline'").set_caption(df2_caption)

    display_html(df1_styler._repr_html_()+df2_styler._repr_html_(), raw=True)

# %%
display_corr()
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for enviroProtection_hardcore</caption>
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >r</th>
#         <th class="col_heading level0 col1" >p</th>
#         <th class="col_heading level0 col2" >N</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row0" class="row_heading level0 row0" >enviroGrowthW7__Protecting the environment should have prior</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row0_col0" class="data row0 col0" >0.31</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row0_col2" class="data row0 col2" >27820</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row1" class="row_heading level0 row1" >likeGrnW10__Strongly like</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row1_col0" class="data row1 col0" >0.3</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row1_col2" class="data row1 col2" >26548</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row2" class="row_heading level0 row2" >likeLucasW10__Strongly like</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row2_col0" class="data row2 col0" >0.3</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row2_col1" class="data row2 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row2_col2" class="data row2 col2" >17585</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row3" class="row_heading level0 row3" >bestPMW10_Jeremy Corbyn</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row3_col0" class="data row3 col0" >0.3</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row3_col1" class="data row3 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row3_col2" class="data row3 col2" >18699</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row4" class="row_heading level0 row4" >ptvGrnW10__Very likely</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row4_col0" class="data row4 col0" >0.3</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row4_col1" class="data row4 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row4_col2" class="data row4 col2" >26909</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row5" class="row_heading level0 row5" >euScepticismW7__Work towards single European government</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row5_col0" class="data row5 col0" >0.28</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row5_col1" class="data row5 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row5_col2" class="data row5 col2" >6784</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row6" class="row_heading level0 row6" >successReduceInequalityGrnW12_Yes</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row6_col0" class="data row6 col0" >0.28</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row6_col1" class="data row6 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row6_col2" class="data row6 col2" >6432</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row7" class="row_heading level0 row7" >competentLucasW13__A great deal of competence</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row7_col0" class="data row7 col0" >0.26</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row7_col1" class="data row7 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row7_col2" class="data row7 col2" >10517</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row8" class="row_heading level0 row8" >euLeaveBigBusinessW10__Much more likely</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row8_col0" class="data row8 col0" >0.23</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row8_col1" class="data row8 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row8_col2" class="data row8 col2" >26196</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row9" class="row_heading level0 row9" >natSecuritySelfW7__Protect civil liberties</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row9_col0" class="data row9 col0" >0.23</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row9_col1" class="data row9 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row9_col2" class="data row9 col2" >6593</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row10" class="row_heading level0 row10" >partyIdSqueezeW10_Green Party</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row10_col0" class="data row10 col0" >0.23</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row10_col1" class="data row10 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row10_col2" class="data row10 col2" >6624</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row11" class="row_heading level0 row11" >asylumMoreW13__Many more</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row11_col0" class="data row11 col0" >0.22</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row11_col1" class="data row11 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row11_col2" class="data row11 col2" >28448</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row12" class="row_heading level0 row12" >handleMIIGrnW7__Very well</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row12_col0" class="data row12 col0" >0.22</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row12_col1" class="data row12 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row12_col2" class="data row12 col2" >5013</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row13" class="row_heading level0 row13" >leaveImpactBritainW10__A very large impact</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row13_col0" class="data row13 col0" >0.22</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row13_col1" class="data row13 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row13_col2" class="data row13 col2" >27826</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row14" class="row_heading level0 row14" >immigSelfW10__Allow many more</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row14_col0" class="data row14 col0" >0.22</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row14_col1" class="data row14 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row14_col2" class="data row14 col2" >26967</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row15" class="row_heading level0 row15" >immigEconW10__Good for economy</th>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row15_col0" class="data row15 col0" >0.22</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row15_col1" class="data row15 col1" >0.00</td>
#         <td id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3row15_col2" class="data row15 col2" >28118</td>
#     </tr>    <tr>
#         <th id="T_35a5dd98_ffca_11e8_911d_20cf301b91b3level0_row16" class="row_heading level0 row16" >immigCulturalW10__Enric

# %%
# var_type.loc["turnoutUKGeneralW1","pruned"]
for ind in df.index:
    print(get_pruned(ind))
# Out:
# ptvGrn
# enviroGrowth
# likeLucas
# euScepticism
# likeGrn
# ptvGrn
# bestPM
# ptvGrn
# likeLucas
# leftRight
# likeNuttall
# likeGrn
# bestPM
# approveUKGovt
# successReduceInequalityGrn
# likeGrn
# effectsEUWorkers
# ptvGrn
# likeLucas
# likeGrn
# enviroGrowth
# likeLucas
# bestPM
# ptvGrn
# approveUKGovt
# leftRight
# likeGrn
# effectsEUWorkers
# ptvGrn
# competentLucas
# likeMay
# likeCon
# likeMay
# competentLucas
# natSecuritySpending
# likeSEvans
# bestPM
# handleEUNegotiate
# effectsEUEcon
# climateChange
# leftRight
# likeGrn
# handleEUNegotiate
# likeCon
# bestPM
# effectsEUEcon
# climateChange
# ptvGrn
# likeMay
# conLookAfterBA
# handleEUNegotiate
# likeCon
# euLeaveVoice
# likeGrn
# euLeaveVoice
# keepNukes
# leftRight
# effectsEUNHS
# ptvGrn
# keepNukes
# handleMIICon
# leftRight
# al_scale
# effectsEUWorkers
# likeLucas
# al_scale
# euPriorityBalance
# ptvGrn
# generalElectionVoteUnsqueeze
# effectsEUNHS
# EUIntegrationSelf
# ptvGrn
# asylumMore
# natSecuritySelf
# overseasAid
# euLeaveVoice
# handleMIIGrn
# spendLeast
# immigSelf
# effectsEUNHS
# immigrantsWelfareState
# likeGrn
# ptvCon
# effectsEUEcon
# ptvCon
# euPriorityBalance
# likeGrn
# generalElectionVoteUnsqueeze
# leftRight
# euPriorityBalance
# likeDavis
# partyIdSqueeze
# likeGrn
# euPriorityBalance
# euLeaveBigBusiness
# likeGrn
# EUIntegrationSelf
# handleEUNegotiate
# leftRight
# ptvGrn
# asylumMore
# climateChange
# handleMIIGrn
# likeSturgeon
# keepNukes
# EUIntegrationSelf
# euLeaveBigBusiness
# overseasAid
# likeCon
# ptvGrn
# immigrantsWelfareState
# immigrantsWelfareState
# likeGrn
# immigSelf
# happyEULeave
# likeMay
# grammar
# ptvConExp
# euParlOverRide
# immigCultural
# ptvGrnExp
# changeEconomy
# immigSelf
# integrityMay
# spendLeast
# howToReduceDeficit
# spendMost
# likeGove
# ptvCon
# handleMIIGrn
# happyEULeave
# euParlOverRide
# immigContributeTake
# EUIntegrationSelf
# integrityMay
# aom
# echr
# leaveImpactBritain
# econGenProsp
# conLookAfterWC
# ptvCon
# likeBennett
# effectsEUWorkers
# euUndermineIdentity
# generalElectionVote
# al
# effectsEUWorkers
# likeGrn
# conLookAfterWC
# conLookAfterUnemp
# likeBennett
# effectsEUTrade
# ukipLookAfterUnemp
# spendLeast
# grammar
# satDemUK
# likeBoris
# likeSNP
# handleMIIGrn
# immigrantsWelfareState
# euUndermineIdentity
# likeSturgeon
# generalElectionVote
# asylumMore
# immigCultural
# changeEconomy
# al_scale
# ukCoopMovement
# competentMay
# immigEcon
# effectsEUWorkers
# ethno
# profile_newspaper
# echr
# likeSturgeon
# handleMIIGrn
# generalElectionVote
# EUIntegrationSelf
# immigSelf
# immigSelf
# bestOnMII
# al
# euLawsLevel
# immigContributeTake
# spendLeast
# effectsEUTrade
# govtHandouts
# UKsovereignty
# likeGove
# satDemUK
# prPreference
# immigCultural
# grnGovTrust
# UKsovereignty
# likeGove
# approveUKGovt
# EUIntegrationSelf
# immigCultural
# bestOnMII
# leftRight
# spendMost
# likeUKIP
# approveUKGovt
# ethno
# ukCoopWorkers
# likeCorbyn
# antiIntellectual
# al
# euLawsLevel
# womenJobs
# effectsEUEcon
# leftRight
# partyIdSqueeze
# partyIdSqueeze
# likeCon
# likeBennett
# handleMIIGrn
# satDemEng
# likeGrn
# euLeaveVoice
# leftRight
# effectsEUUnemployment
# spendMost
# EUIntegrationSelf
# immigEcon
# taxSpendCon
# spendLeast
# spendLeast
# likeBoris
# redistUKIP
# likeBennett
# small_mii_cat
# lr_scale
# likeBoris
# partyIdSqueeze
# likeSNP
# likeBoris
# generalElectionVote
# euID
# euID
# euPriorityBalance
# conUnited
# bestOnMII
# mii_cat
# likeFarage
# euFinancialHelp
# likeFarage
# EUIntegrationSelf
# integrityCorbyn
# spendLeast
# auth
# effectsEUUnemployment
# ptvGrn
# changeEconomyLab
# scotReferendumIntention
# al
# EUIntegrationSelf
# immigEcon
# bestOnMII
# natSecuritySelf
# europeanness
# al_scale
# likeUKIP
# leftRight
# taxSpendUKIP
# likeCorbyn
# ukCoopMovement
# ukipLookAfterWC
# leftRight
# EUIntegrationSelf
# euRefDoOver
# socialDistGreen
# spendMost
# likeRudd
# welfarePreference
# changeEconomy
# grnHope
# econGenRetro
# newspaper
# likeSNP
# euRefVote
# likeCorbyn
# euID
# immigEcon
# euRefVote
# warmSyrians
# likeNuttall
# natSecuritySelf
# lr_scale
# redistSelf
# effectsEUTrade
# socialIdentityGlobalLeave
# partyIdSqueeze
# likeCorbyn
# euRefVote
# howToReduceDeficit
# natSecuritySelf
# spendLeast
# likeCon
# handleMIIUKIP
# grnHope
# euRefDoOver
# europeanness
# ethno
# al
# happyEULeave
# conTone
# euLeaveBigBusiness
# overseasAid
# ptvCon
# ukCoopWorkers
# changeEconomy
# integrityCorbyn
# effectsEUNHS
# euRefpastVote
# immigCultural
# tuitionFeesTooFar
# nonelecParticipation
# profile_newspaper
# euLeaveScotIndep
# expectGoodConductEURef
# spendLeast
# satDemEng
# euRefDoOver
# leaveImpactSelf
# likeSturgeon
# euRefpastVote
# spendLeast
# authLong
# bestOnMII
# al
# effectsEUFinance
# euRefVote
# ukipLookAfterWC
# happyTrump
# profile_newspaper
# euLeaveScotIndep
# cutsTooFarNational
# ukCoopMovement
# natSecuritySelf
# partyIdSqueeze
# likeCorbyn
# leftRight
# effectsEUFinance
# auth
# monarch
# conAngry
# generalElectionVote
# expectGoodConductEURef
# spendLeast
# grnTone
# immigEcon
# econGenRetro
# euRefpastVote
# effectsEUUnemployment
# effectsEUEcon
# competentMay
# likeBennett
# auth
# al_scale
# localElectionVote
# likeMogg
# localElectionVote
# likeBennett
# wcEcon
# lr
# likeCorbyn
# likeCon
# changeEconomyLab
# effectsEUFinance
# successReduceInequalityLab
# govtHandouts
# integrityFarage
# likeUKIP
# ethno
# likeUKIP
# euRedTape
# handleEUNegotiate
# likeFarage
# approveUKGovt
# effectsEUEcon
# partyMember
# euRedTape
# redistUKIP
# satDemUK
# likeCon
# socialIdentityGlobalLeave
# likeCon
# likeNuttall
# euLeaveBigBusiness
# euLeaveVoice
# spendLeast
# partyIdSqueeze
# satDemUK
# expectGoodConductGeneral
# immigrantsWelfareState
# changeNHSLab
# likeMay
# scotElectionVoteList
# privatTooFar
# partyIdSqueeze
# refAreGood
# likeFarage
# conUnited
# bestOnMII
# discrimWhite
# euroElectionVote
# aom
# aom
# approveScotGovt
# redistSelf
# likeCorbyn
# al
# ptvSNP
# small_mii_cat
# profile_past_vote
# generalElectionVotePost
# changeEducationLab
# strongLeader
# al
# antiIntellectual
# ukipLookAfterBA
# redistUKIP
# bestOnMII
# euRefVote
# euID
# likeUKIP
# bestOnMII
# approveEU
# scotReferendumIntention
# familiesMore
# strongLeader
# competentCorbyn
# small_mii_cat
# bestOnMII
# euUKRich
# immigrantsWelfareState
# controlImmig
# partyContactLab
# mii_cat
# handleMIICon
# happyEULeave
# controlImmig
# redistSelf
# likeMay
# likeFarage
# govtHandouts
# generalElectionVote
# euRefVoteUnsqueeze
# leftRight
# gayMarriage
# EUIntegrationSelf
# cutsTooFarLocal
# lr
# scotElectionVoteList
# lr
# likeUKIP
# aom
# changeEconomyLab
# conUnited
# renationaliseRail
# bestOnMII
# al
# emEcon
# natSecuritySpending
# resourceAccess
# partyId
# euRefVoteUnsqueeze
# euUKRich
# spendMost
# partyIdSqueeze
# euLeaveVoice
# controlImmig
# changeEducationLab
# ethno
# lr_scale
# small_mii_cat
# europeanness
# ptvCon
# socialDistUKIP
# bestOnMII
# effectsEUNHS
# euroElectionVote
# immigrantsWelfareState
# likeBatten
# likeUKIP
# generalElectionVote
# small_mii_cat
# grnHope
# mii_cat
# bestOnMII
# satDemEng
# approveEU
# redistSelf
# bestOnMII
# grnUnited
# handleMIIUKIP
# conUnited
# likeMcDonnell
# bestOnMII
# motive
# partyIdSqueeze
# auth
# euRefVote
# changeNHSLab
# miilabel
# partyId
# partyIdSqueeze
# generalElectionVote
# bestOnMII
# preferMPWomen
# conGovTrust
# approveScotGovt
# likeSNP
# EUIntegrationSelf
# miilabel
# mii_cat
# likeCon
# immigSelf
# familiesMore
# preferConMajority
# euRefVote
# handleMIICon
# achieveReduceImmigNone
# changeNHSLab
# partySiteGreen
# ptvLab
# auth
# successReduceInequalityGrn
# partyIdEU
# approveEU
# genderRoles
# preferConMajority
# antiIntellectual
# al
# cutsTooFarNational
# changeEconomyLab
# al
# al
# mii_cat
# redistUKIP
# govtHandleCostLive
# handleMIIUKIP
# nhsEU
# likeCon
# grnUnited
# generalElectionVoteUnsqueeze
# motive
# effectsEUTrade
# al
# britCustoms
# ptvLab
# spendMost
# referendumrecall
# likeNuttall
# deficitReduce
# euRefVote
# lr
# socialIdentityGlobalLeave
# effectsEUTrade
# euMemberJoin
# partyId
# conAngry
# howToReduceDeficit
# satDemEng
# partyId
# referendumSettled
# redistSelf
# euPreventWar
# auth
# scotElectionVoteList
# euID
# lr
# partyContactLab
# miilabel
# likeCameron
# localElectionVote
# govtHandouts
# euPreventWar
# lr_scale
# miilabel
# scotDevoMax
# changeNHS
# likeLab
# controlImmig
# socialIdentityGlobalLeave
# econGenRetro
# successReduceInequalityNone
# likeHunt
# competentFarage
# euCloser
# govtHandleEcon
# partyContactLab
# small_mii_cat
# likeBoris
# ptvUKIP
# preferMPLGBT
# britChristian
# ptvUKIP
# spendLeast
# likeCon
# ptvLab
# warmEastern
# grnUnited
# earlyElecSupport
# EUIntegrationSelf
# lr_scale
# expectAccess
# aom
# changeEducationLab
# britBornHere
# redistUKIP
# UKsovereigntyPost
# euLeaveBigBusiness
# privatTooFar
# generalElectionVoteSqueeze
# cutsTooFarNational
# handleMIICon
# euLeaveBigBusiness
# studentsMore
# approveUKGovt
# changeEducation
# euMemberJoin
# happyLeave
# miilabel
# small_mii_cat
# euCloser
# preferMPEthnic
# bestOnMII
# likeGove
# europeanness
# renationaliseRail
# socialDistCon
# natSecurityCon
# welfarePreference
# govtHandleNHS
# ashcroft
# likeCameron
# euID
# immigEcon
# generalElectionVoteUnsqueeze
# euMore
# ptvUKIP
# redistCon
# blackEquality
# cutsTooFarNational
# labTone
# eesEUIntegrationSelf
# privatTooFar
# immigrantsWelfareState
# likeOsborne
# mii_cat
# ptvLab
# zeroSum
# effectsEUUnemployment
# redistCon
# changeImmig
# al
# changeEducation
# euRefVotePost
# spendLeast
# partyId
# small_mii_cat
# partyId
# small_mii_cat
# familiesMore
# miilabel
# immigCultural
# generalElectionVote
# lr
# welfarePreference
# effectsEUTrade
# immigCultural
# likeCameron
# small_mii_cat
# generalElectionVote
# handleMIIUKIP
# small_mii_cat
# likeSturgeon
# ethno
# mii_cat
# studentsMore
# changeEconomy
# conUnited
# partyIdEU
# cutsTooFarNHS
# al
# ptvCon
# partyIdSqueeze
# normEU
# campaigninfoLeave
# UKsovereigntyPost
# expectAccess
# generalElectionVote
# partyIdSqueeze
# pccVote
# ethno
# immigEcon
# socialIdentityGlobalRemain
# euLeaveScotIndep
# euID
# europeanness
# achieveReduceImmigNone
# benefitsToMigrants
# normEU
# effectsEUUnemployment
# generalElectionVote
# govtHandleEduc
# cutsTooFarLocal
# euMore
# al
# mii_cat
# likeUKIP
# gayEquality
# changeNHS
# immigEcon
# discrimChristians
# partySiteGreen
# euMore
# ptvUKIP
# changeNHSLab
# mii_cat
# partyId
# achieveReduceImmigNone
# likeUKIP
# satDemUK
# ptvCon
# approveEU
# thatcherGood
# blameLeave
# generalElectionVoteSqueeze
# ethno
# likeSturgeon
# femaleEquality
# lr
# generalElectionVote
# euRefVote
# likeLab
# snpLookAfterMC
# partyContactLab
# spendMost
# redistCon
# partyIdEUretro
# approveUKGovt
# euRefDoOver
# partyId
# discrimMen
# mii_cat
# spendMost
# competentCorbyn
# lr
# pccVote
# localElectionVote
# govtHandleEduc
# euExpRef
# al
# grnUnited
# ptvSNP
# tryReduceInequalityGrn
# howToReduceDeficit
# likeCameron
# grnTone
# blameLeave
# lr
# likeUKIP
# changeImmig
# govtHandouts
# al_scale
# generalElectionVote
# generalElectionVoteUnsqueeze
# immigCon
# britLiveHere
# generalElectionVoteUnsqueeze
# ukipAngry
# partyId
# preferMPDisabled
# handleMIIUKIP
# partyId
# deficitReduce
# handleMIIUKIP
# immigCultural
# europeanness
# discussantVoteName
# eesEUIntegrationSelf
# discrimBME
# conUnited
# benefitsToMigrants
# privatTooFar
# bestOnMII
# changeNHS
# participation
# immigCultural
# achieveReduceImmigNone
# mii_cat
# lr
# generalElectionVote
# govtHandleEcon
# redistCon
# ethno
# partyId
# profile_eurefvote
# partyMember
# deficitReduce
# eesEUIntegrationSelf
# partyMember
# leaveTone
# childBenefitsRepatriate
# renationaliseRail
# likeFarage
# likeUKIP
# scotElectionVoteConst
# ethno
# likeFarage
# britishness
# effectsEUFinance
# strongLeader
# scotElectionVoteList
# euRefVote
# lrUKIP
# euLeaveScotIndep
# overseasAid
# partyId
# partyId
# cutsTooFarLocal
# auth
# prPreference
# euLeaveScotIndep
# studentsMore
# redistSelf
# likeCameron
# al
# al
# ptvLabExp
# bestOnMII
# radical
# ptvCon
# lr
# profile_past_vote
# achieveReduceImmigCon
# ethno
# grnPride
# euID
# cutsTooFarLocal
# likeCameron
# leaveTone
# generalElectionVote
# likeLab
# likeCon
# natSecurityUKIP
# ashcroft
# negotiationSpecifics
# policeCuts
# lr
# likeLab
# grnUnited
# likeFarage
# euLeaveScotIndep
# immigEcon
# generalElectionVote
# immigrationLevel
# likeUKIP
# discrimMuslims
# resourceAccess
# sharedContentOnline
# handleMIICon
# euRefVote
# UKsovereigntyPost
# immigSelf
# auth
# labLookAfterMC
# ptvUKIP
# warmRomania
# discrimWomen
# expectAccess
# ptvCon
# cutsTooFarNational
# harkBack
# competentFarage
# govtHandleEduc
# welfarePreference
# redistSelf
# britCitizen
# scotElectionVoteConst
# nonelecParticipation
# noneuMore
# satDemUK
# conUnited
# al
# britishness
# bestOnMII
# ptvLab
# effectsEUFinance
# controlImmig
# al
# conAngry
# preferLabCoalition
# cutsTooFarNHS
# redistUKIP
# generalElectionVoteSqueeze
# taxSpendSelf
# generalElectionVoteSqueeze
# lr
# euRefVote
# ukipGovTrust
# effectsEUUnemployment
# englishness
# natSecurityCon
# lr
# likeFarage
# redistUKIP
# scotElectionVoteConst
# ethno
# al
# ethno
# govtHandleNHS
# lr
# likeSturgeon
# generalElectionVote
# redistUKIP
# redistCon
# generalElectionVote
# partyMember
# likeOsborne
# conTone
# scotElectionVoteConst
# al
# coalitionInTune
# likeSNP
# euFinancialHelp
# likeUKIP
# preferLabCoalition
# privatTooFar
# immigrationLevel
# immigCultural
# bestOnMII
# cutsTooFarNHS
# changeCrimeLab
# warmIndian
# govtHandleEduc
# spendLeast
# noneuMore
# grnTone
# leaveImpactBritain
# localElectionVote
# generalElectionVoteUnsqueeze
# britSpeakEnglish
# discrimWhite
# govtHandleCostLive
# govtHandleEcon
# likeCameron
# lr
# ptvLab
# approveUKGovt
# effectsEUFinance
# euRefVote
# redistSelf
# devoResponsibleScotDefence
# eesEUIntegrationSelf
# partyId
# profile_education_age
# sharedContentOnline
# populism
# negotiationSpecifics
# govtHandleCostLive
# lrUKIP
# controlImmig
# govtHandleEcon
# approveUKGovt
# likeSNP
# immigEcon
# partyId
# bestOnMII
# likeSNP
# ukipAngry
# proConLeave
# govtHandleEduc
# likeJavid
# redistCon
# preferConCoalition
# gayEquality
# infoSourceInternet
# auth
# partyContactGreen
# ptvCon
# pccVote
# approveScotGovt
# ethno
# likeFarage
# spendLeast
# ukCoopCAP
# happyScotIndepResultNo
# ptvCon
# govtHandleNHS
# scotReferendumIntention
# bestOnMII
# generalElectionVoteUnsqueeze
# likeCorbyn
# devoResponsibleScotDefence
# britRespectLaw
# partyContactLab
# pccVote
# femaleEquality
# generalElectionVoteUnsqueeze
# ptvUKIP
# govtHandleCostLive
# partyContactLab
# lrUKIP
# ptvUKIP
# lr
# govtHandleNHS
# immigCon
# blackEquality
# discussPolDays
# cutsTooFarNational
# likeOsborne
# warmBenefits
# edlevel
# satDemEng
# localElectionVote
# childBenefitsRepatriate
# handleMIICon
# scotReferendumIntention
# small_mii_cat
# negotiationSpecifics
# welfarePreference
# aom
# britFeelBritish
# deficitReduce
# partyId
# ptvUKIP
# ukCoopCAP
# partyId
# harkBack
# generalElectionVoteSqueeze
# contactMP
# localElectionVote
# cutsTooFarLocal
# participation
# authLong
# ukipAngry
# econGenRetro
# effectsEUTerror
# britishness
# britainFairShare
# britainFairShare
# infoSourceInternet
# bestOnMII
# partyId
# participation
# immigCon
# achieveReduceImmigCon
# mpSecondJob
# lr
# redistUKIP
# cutsTooFarNHS
# renationaliseRail
# ukCoopEuro
# scotReferendumIntention
# efficacyTooMuchEffort
# likeFarage
# referendumSettled
# ptvUKIP
# cutsTooFarNational
# euRefFinalPost
# likeLab
# councilHouse
# regionEcon
# euMIISmall
# generalElectionVote
# negotiationSpecifics
# socialIdentityGlobalRemain
# redistSelf
# grnPride
# ukCoopEuro
# localElectionVote
# lrUKIP
# edlevel
# conTone
# mii_cat
# welfarePreference
# likeLab
# conHope
# happyScotIndepResult
# immigCon
# partyId
# dv
# polAttention
# likeSturgeon
# resourceAccess
# grnUnited
# satDemUK
# englishness
# negotiationSpecifics
# changeEducation
# tuitionFeesTooFar
# englishness
# achieveReduceImmigNone
# labHandleEcon
# conUnited
# lr
# welfarePreference
# immigCon
# euRefVote
# auth
# pccVote
# britishness
# immigCon
# profile_newspaper
# likeLab
# radical
# natSecurityUKIP
# ptvCon
# edlevel
# UKsovereigntyPost
# singlePartyEffective
# generalElectionVote
# likeSturgeon
# lr
# negotiationSpecifics
# al
# likeUKIP
# changeImmig
# discrimMen
# generalElectionVoteSqueeze
# snpHope
# britishness
# devoResponsibleScotWelfare
# conFear
# discussPolDays
# devoResponsibleScotDefence
# ethno
# scotUnionEconomy
# grnPride
# sharedContentOnline
# scotReferendumVote
# EUIntegrationCon
# satDemEng
# socialIdentityGlobalRemain
# europeanness
# labHandleCostLive
# govtHandleEduc
# privatTooFar
# euMIISmall
# partyId
# effectsEUTerror
# prPreference
# preferConCoalition
# ethno
# likeCameron
# negotiationSpecifics
# partyContactGrn
# localEcon
# scotDevoMax
# ethno
# labHandleEcon
# labHandleCostLive
# generalElectionVote
# scotElectionVoteConst
# govtHandleNHS
# partyContactLab
# edlevel
# successReduceInequalityDK
# govtHandleImmig
# cutsTooFarLocal
# likeCameron
# socialDistSNP
# generalElectionVote
# localElectionVote
# lrCon
# econGenRetro
# conUnited
# scotElectionVoteConst
# efficacyTooMuchEffort
# scotGrn
# scotUnionInequality
# conHope
# effectsEUTerror
# auth
# ptvUKIP
# ptvUKIP
# generalElectionVote
# partyId
# labHandleImmig
# expectAccess
# bestOnMII
# labLookAfterMC
# EUIntegrationCon
# ptvUKIPExp
# localElectionVote
# ashcroft
# prPreference
# antiIntellectual
# generalElectionVote
# britishness
# responsibleImmigNone
# pidConnected
# snpGovTrust
# govtHandleCostLive
# bestOnMII
# generalElectionVote
# scotElectionVoteConst
# partyMember
# profile_religion
# participation
# coalitionDontDeliver
# likeCon
# changeEconomyLab
# euroElectionVote
# localElectionVote
# anyUni
# authLong
# lr_scale
# govtHandleEcon
# changeNHS
# devoResponsibleScotDefence
# bestLeaderCampaign
# negotiationSpecifics
# lr
# generalElectionVote
# bestOnMII
# scotDevoMax
# auth
# lrUKIP
# efficacyUnderstand
# participation
# redistGreen
# harkBack
# profile_past_vote
# partyContactCon
# redistCon
# responsibleImmigNone
# negotiationSpecifics
# preferMPYoung
# econGenProsp
# ashcroft
# effectsEUImmigration
# referendumSettled
# conFear
# ukipUnited
# govtHandleCostLive
# labHandleNHS
# preferMPChrist
# bestOnMII
# devoResponsibleScotTax
# achieveReduceImmigCon
# govtHandleLevelCrime
# pocketBookAccurateDV
# lrUKIP
# populism
# lrMay
# populism
# noneuMore
# labHandleNHS
# redistSelf
# labHandleEduc
# redistCon
# negotiationSpecifics
# changeEconomy
# likeWatson
# changeCrimeLab
# cutsTooFarNational
# changeCostLiveLab
# scotReferendumIntention
# cutsTooFarNHS
# likeFarron
# ptvUKIP
# campaignVisionNo
# changeImmigLab
# lrLab
# eesEUIntegrationSelf
# nan
# ptvUKIP
# lrUKIP
# EUIntegrationCon
# edlevel
# edlevel
# lrUKIP
# radical
# labHandleEduc
# redistCon
# likeLab
# socialIdentityGlobalRemain
# devoResponsibleScotDefence
# ukipUnited
# efficacyNotUnderstand
# auth
# al
# govtHandleNHS
# negotiationSpecifics
# localElectionVote
# scotElectionVoteConst
# responsibleImmigNone
# partySiteCon
# bestOnMII
# satDemUK
# franceFairShare
# devoResponsibleScotTax
# ptvLD
# lrCon
# generalElectionVote
# generalElectionVoteUnsqueeze
# changeEconomyLab
# generalElectionVote
# lrUKIP
# changeImmigLab
# ukipLookAfterMC
# antiIntellectual
# authLong
# localElectionVote
# effectsEUImmigration
# redistSelf
# preferMPWorkClass
# snpHope
# al
# grnNone
# generalElectionVote
# scotRefVote
# achieveReduceImmigUKIP
# efficacyNoMatter
# lrUKIP
# effectsEUImmigration
# britishness
# partyId
# changeImmig
# cspl
# englishness
# privatTooFar
# scotElectionVoteList
# changeNHSLab
# ptvLD
# satDemEU
# changeEconomyLab
# lrLD
# nonelecParticipation
# polAttention
# reasonForUnemployment
# generalElectionVote
# likeRudd
# profile_religion
# ldUnited
# generalElectionVote
# conFear
# successReduceInequalityCon
# spendLeast
# govtHandleEcon
# labHandleImmig
# anyUni
# cutsTooFarLocal
# approveScotGovt
# lrCon
# happyScotIndepResult
# ptvLD
# conHope
# snpUnited
# natSecurityUKIP
# preferMPMuslim
# bestOnMII
# partyId
# generalElectionVote
# likeLD
# noChanceCoalitionGrn
# snpTone
# partyId
# scotFairShare
# localElectionVote
# leaveImpactSelf
# groupempathy
# profile_religion
# natSecurityCon
# satDemEng
# bestOnMII
# bestOnMII
# econPersonalProsp
# conUnited
# pccVote
# labHope
# profile_past_vote
# turkey
# labHandleLevelCrime
# scotIndepVoice
# changeEducation
# labHandleImmig
# scotIndepJoinEU
# ptvLab
# natSecurityCon
# small_mii_cat
# changeEconomyLab
# groupempathy
# cutsTooFarNHS
# negotiationSpecifics
# labHandleLevelCrime
# profile_past_vote
# goodConductEURef
# likeSalmond
# groupempathy
# auth
# al
# natSecurityUKIP
# al
# snpUnited
# LRAL_mii_cat
# changeImmig
# anyUni
# resourceAccess
# reasonForUnemployment
# discrimChristians
# scotElectionVoteConst
# generalElectionVotePost
# conPriorities_nhs
# mpSecondJob
# changeCostLiveLab
# lrUKIP
# auth
# profile_religion
# changeCostLive
# small_mii_cat
# bestOnMII
# mii_cat
# englishness
# pidConnected
# partyContactLab
# englishness
# bestOnMII
# generalElectionVote
# britishness
# spendLeast
# lr
# pccVote
# devoResponsibleScotWelfare
# difficultBlameCoalition
# nonelecParticipation
# effectsEUTerror
# spendLeast
# competentFarron
# friendsEU
# changeEconomy
# miilabel
# expectationDevoScot
# generalElectionVote
# changeCostLive
# snpTone
# warmPoland
# lr
# negotiationSpecifics
# anyUni
# businessSupport
# al
# discrimBME
# nonelecParticipation
# lrCon
# responsibleImmigNone
# miilabel
# efficacyTooMuchEffort
# smallPartyWastedVote
# education
# scotElectionVoteList
# devoResponsibleScotWelfare
# ukipUnited
# likeLD
# mii_cat
# negotiationSpecifics
# eesEUIntegrationCon
# miilabel
# socialDistLab
# devoResponsibleScotTax
# scotDevoMax
# lr
# preferLabMajority
# devoResponsibleScotTax
# partySiteCon
# moreParl
# changeEconomyLab
# sharedContentOnline
# grnNone
# spendLeast
# lrLab
# spendLeast
# pccVote
# small_mii_cat
# scotDevoMax
# labHandleImmig
# redistUKIP
# successReduceInequalityLD
# achieveReduceImmigCon
# labHandleEcon
# reasonForUnemployment
# changeEducationLab
# redistUKIP
# pccVote
# responsibleDebtGlobalBanks
# bestLeaderCampaign
# approveScotGovt
# changeImmig
# scotIndepJoinEU
# partyIdSqueeze
# conUnited
# grnNone
# partyId
# cutsTooFarNHS
# warmAsian
# likeLD
# changeNHSLab
# handleMIILD
# profile_past_vote
# polAttention
# changeEducationLab
# goodTimePurchase
# localElectionVote
# labHandleEcon
# education
# scotElectionVoteConst
# discussantVoteName
# mii_cat
# devoResponsibleScotWelfare
# miilabel
# eesEUIntegrationCon
# noChanceCoalitionGrn
# handleMIILab
# lr
# englishness
# profile_newspaper
# mii_cat
# groupempathy
# changeNHSLab
# likeMiliband
# changeEducationLab
# mii_cat
# effectsEUTerror
# generalElectionVote
# econGenRetro
# mii_cat
# satDemUK
# ethno
# anyUni
# econGenRetro
# pccVote
# businessBonus
# small_mii_cat
# partyContactGrn
# scotIndepVoice
# education
# winConstituencySNP
# changeEducationLab
# labHandleImmig
# scotElectionVoteConst
# discussPolDays
# discussantVoteName
# participation
# electionInterest
# localEconNow
# grnUnited
# natSecurityUKIP
# achieveReduceImmigNone
# smallPartyWastedVote
# partyId
# majorityPartyCon
# generalElectionVote
# efficacyNoMatter
# blameLeave
# labHandleEcon
# engFairShare
# redistGreen
# localElectionVote
# labHandleEcon
# zeroHourContract
# zeroSum
# scotElectionVoteConst
# likeLD
# mii_cat
# euroElectionVote
# bestOnMII
# ukipUnited
# populism
# snpLookAfterWC
# pidInterestedOthers
# pidConnected
# nonelecParticipation
# lr
# small_mii_cat
# profile_religion
# sharedContentOnline
# satDemScot
# businessBonus
# infoSourcePeople
# partyContactCon
# partyContact
# lrLab
# lrLD
# participation
# ukCoopTrade
# effectsEUTerror
# immigLab
# scotDevoMax
# scotLab
# spendLeast
# lrLab
# small_mii_cat
# resourceAccess
# integrityFarron
# franceFairShare
# miilabel
# turkey
# discussantVoteName
# warmAtheist
# labHandleNHS
# EUIntegrationCon
# efficacyVoteEffort
# euMIISmall
# lrLD
# profile_religion
# successReduceInequalitySNP
# regSatisfaction
# negotiationSpecifics_none
# localElectionVote
# changeEducation
# populism
# changeEconomy
# polAttention
# cutsTooFarLocal
# discussantVoteName
# partyMember
# taxSpendGreen
# changeImmigLab
# approveScotGovt
# conPriorities
# LRAL_mii_cat
# miilabel
# likeFarron
# infoSourceInternet
# profile_newspaper
# warmFrance
# edlevel
# twitterInfo
# changeNHSLab
# certaintyRedistCon
# handleMIILab
# achieveReduceImmigNone
# small_mii_cat
# grnUnited
# lr
# grnUnited
# preferLabMajority
# euMIISmall
# responsibleDebtGlobalBanks
# anyUni
# reasonForUnemployment
# scotElectionVoteConst
# discrimMuslims
# fbInfo
# devoResponsibleScotWelfare
# warmMuslim
# anyUni
# mii_cat
# genTrust
# riskUnemployment
# likeFarron
# profile_education_age
# ukipHope
# scotCon
# likeSalmond
# eesEUIntegrationCon
# small_mii_cat
# profile_religion
# lrCon
# EUIntegrationCon
# riskUnemployment
# education
# ukipUnited
# refFairness
# competentFarron
# inequalityChangeLarger
# participation
# changeNHSLab
# efficacyNotUnderstand
# responsibleDebtGlobalBanks
# labHandleLevelCrime
# discrimWomen
# negotiationSpecifics_none
# tuSupport
# satDemEU
# resourceAccess
# negotiationSpecifics
# labHandleNHS
# lrLab
# ukipFear
# profile_newspaper
# warmGreece
# likeFarron
# small_mii_cat
# partyContactLab
# polAttention
# small_mii_cat
# efficacyUnderstand
# britishness
# scotFairShare
# lrLD
# fbInfo
# natSecurityCon
# ukCoopTrade
# eesEUIntegrationCon
# responsibleDebtConservatives
# redistCon
# efficacyNotUnderstand
# populism
# coalitionDontDeliver
# conPriorities_nhs
# bestOnMII
# approveScotGovt
# mii_cat
# EUIntegrationLab
# ldUnited
# scotElectionVoteConst
# partyContactGrn
# econGenRetro
# partyContact
# empathy
# mpSecondJob
# efficacyNotUnderstand
# ukipUnited
# resourceAccess
# spendMost
# lrLD
# partyContactOtherParty
# grnUnited
# small_mii_cat
# immigLab
# fbInfo
# cutsTooFarNHS
# achieveReduceImmigCon
# discussPolDays
# lrLD
# euMIISmall
# labHandleCostLive
# conPartnerUKIP
# participation
# newspaper
# britishness
# LRAL_mii_cat
# ldTone
# businessSupport
# partyContactLab
# partyId
# changeEducation
# devoResponsibleScotNHS
# devoResponsibleScotTax
# partyContactCon
# lrLD
# discussantVoteName
# mii_cat
# bestOnMII
# resourceAccess
# certaintyRedistUKIP
# lr
# generalElectionVote
# labHandleEduc
# miilabel
# euSources
# responsibleDebtConservatives
# EUIntegrationLab
# zeroSum
# debateTwoWatch
# ldUnited
# labHandleEduc
# miilabel
# spendLeast
# profile_religion
# nan
# changeEducation
# partyContact
# changeCrimeLab
# immigUKIP
# econGenRetro
# smallPartyWastedVote
# discussPolDays
# labPriorities_econ
# pidCommonParty
# education
# efficacyTooMuchEffort
# ptvLab
# ukipUnited
# pidConnected
# ldUnited
# bestOnMII
# generalElectionVote
# labHandleImmig
# age
# likeMiliband
# myPartyInfluence
# lrLD
# efficacyNoMatter
# euroElectionVote
# mii_cat
# al
# partySiteUKIP
# fbInfo
# partyContactCon
# EUMIICategory
# euRefExpectation
# localElectionVote
# generalElectionVote
# small_mii_cat
# engFairShare
# redistCon
# lrLab
# englishness
# discussantVoteName
# EUIntegrationCon
# successReduceInequalityPC
# lr
# labHandleCostLive
# profile_religion
# mii_cat
# immigLab
# lrLab
# participation
# preferOtherGov
# labHandleLevelCrime
# partyContactLab
# ukipNone
# aom
# immigUKIP
# scotElectionVoteConst
# satDemEU
# govtHandleLevelCrime
# conPartnerGreen
# lrLD
# efficacyNoMatter
# mii_cat
# inequalityChangeLarger
# immigUKIP
# polAttention
# bestOnMII
# lrCameron
# euroElectionVote
# small_mii_cat
# expectGoodConductGeneral
# bestOnMII
# businessBonus
# walesFairShare
# natSecurityLab
# ukCoopTrade
# changeNHS
# lrCon
# bestOnMII
# majorityPartyCon
# EUIntegrationCon
# majorityPartyCon
# conPartnerGreen
# warmBlack
# scotUnionMeBetterOff
# redistGreen
# mii_cat
# likeMiliband
# efficacyUnderstand
# changeImmigLab
# conSupport
# cooperateRUKGBP
# tryReduceInequalitySNP
# small_mii_cat
# referendumContact
# selfEcon
# pccVote
# handleMIILD
# electionInterest
# devoResponsibleScotNHS
# localElectionVote
# partyId
# tuSupport
# pccVote
# education
# britishness
# conPriorities_school
# ukipFear
# infoSourceInternet
# spendMost
# preferOtherGov
# certaintyScotIndependence
# changeNHS
# partyIdSqueeze
# labFear
# mii_cat
# participation
# efficacyNotUnderstand
# coalitionInTune
# partyContactCon
# successReduceInequalityNone
# certaintyRedistGreens
# electionInterest
# bestLeaderCampaign
# changeImmig
# pidConnected
# partyContactGrn
# twitterInfo
# immigLD
# accessDiscussPolitics
# efficacyTooMuchEffort
# effectsEUImmigration
# partyContactOtherParty
# pidConnected
# empathy
# redistLD
# nan
# bestOnMII
# ukipHope
# childvalues
# immigUKIP
# changeCostLive
# EUIntegrationLab
# discussPolDays
# lrCon
# redistGreen
# likeSalmond
# devoResponsibleScotNHS
# LRAL_mii_cat
# lrCon
# conPartnerGreen
# miilabel
# ptvLD
# labHandleNHS
# changeCrimeLab
# likeMiliband
# likeMiliband
# EUIntegrationCon
# satDemUK
# expectationDevoScot
# engFairShare
# pidInterestedOthers
# EUMIICategory
# polAttention
# efficacyTooMuchEffort
# changeNHS
# labHandleCostLive
# pccVote
# responsibleDebtGlobalBanks
# efficacyUnderstand
# participation
# electionInterest
# satDemEng
# generalElectionVote
# snpAngry
# scotFairShare
# age
# walesFairShare
# walesFairShare
# lrCon
# responsibleDebtLabour
# pccVote
# labPriorities
# generalElectionVotePost
# bestOnMII
# satDemUK
# ukipPriorities_nhs
# conPriorities_costLive
# labHandleCostLive
# grnFear
# bestOnMII
# negotiationSpecifics_none
# polForTheRich
# conLookAfterMC
# lrLab
# winConstituencyCon
# bestOnMII
# grnAngry
# bestOnMII
# bestOnMII
# age
# profile_newspaper
# reasonForUnemployment
# populism
# changeEconomy
# age
# efficacyNotUnderstand
# profile_past_vote
# snpSupport
# generalElectionVote
# bestOnMII
# LRAL_mii_cat
# difficultBlameCoalition
# labPartnerGreen
# EUMIICategory
# campaignVisionYes
# warmPoor
# natSecurityLab
# auth
# satDemEU
# efficacyNotUnderstand
# devoResponsibleScotPolice
# euMIISmall
# difficultBlameCoalition
# EUMIICategory
# likeLD
# efficacyNotUnderstand
# mii_cat
# pidInterestedOthers
# devoResponsibleScotPolice
# bestOnMII
# small_mii_cat
# partySiteUKIP
# efficacyUnderstand
# polAttention
# small_mii_cat
# partyIdSqueeze
# efficacyUnderstand
# snpAngry
# lrLab
# scotFairShare
# conUnited
# ldHope
# devoResponsibleScotSchools
# noChanceCoalitionGrn
# changeImmigLab
# devoResponsibleScotNHS
# natSecurityLab
# partyId
# EUIntegrationCon
# negotiationSpecifics_none
# lrCon
# polAttention
# businessBonus
# ptvLab
# eesEUIntegrationCon
# wbEcon
# miilabel
# profile_religion
# propMPDisab
# polForTheRich
# partyContactGrn
# labPriorities_costLive
# handleEUNegotiateLab
# scotElectionVoteConst
# efficacyTooMuchEffort
# redistGreen
# likeBNP
# ukipUnited
# small_mii_cat
# EUIntegrationLab
# generalElectionVoteUnsqueeze
# euSources
# snpPride
# nonelecParticipation
# changeImmigLab
# profile_religion_denom
# lrLab
# likeLab
# pidCommonParty
# warmUK
# generalElectionVoteUnsqueeze
# pidPraiseGood
# changeCostLiveLab
# blameLeave
# mii_cat
# generalElectionVoteSqueeze
# euDominance
# childvalues
# grnAngry
# EUIntegrationLab
# conPriorities_costLive
# labHandleEduc
# EUIntegrationUKIP
# goodTimePurchase
# partyContactLD
# responsibleImmigLabour
# bestOnMII
# changeCrimeLab
# EUMIICategory
# partyId
# ptvLDExp
# profile_past_vote
# likeLab
# lrCameron
# econPersonalRetro
# EUIntegrationLab
# EUMIICategory
# spendLeast
# twitterUse
# partyContactOtherParty
# fbInfo
# likeLab
# profile_past_vote
# partyIdStrength
# winConstituencyCon
# education
# generalElectionVoteUnsqueeze
# polAttention
# immigUKIP
# mii_cat
# empathy
# generalElectionVote
# age
# mii_cat
# small_mii_cat
# generalElectionVote
# responsibleImmigLabour
# generalElectionVoteSqueeze
# lrLab
# sharedContentOnline
# fbInfo
# bestOnMII
# scotFairShare
# redistLD
# mcEcon
# pidInterestedOthers
# euMIISmall
# redistLD
# remainVoteConLab
# partyContactCon
# discussantVoteName
# fbInfof
# conPride
# pidCommonParty
# responsibleDebtUKBanks
# discussantVoteName
# mii_cat
# likeFarron
# goodTimePurchase
# walesFairShare
# changeEconomy
# profile_religion
# immigLab
# responsibleDebtConservatives
# conPriorities
# efficacyVoteEffort
# efficacyUnderstand
# engFairShare
# generalElectionVoteSqueeze
# EUIntegrationLab
# lrLD
# snpPride
# labFear
# winConstituencyUKIP
# walesFairShare
# partyId
# changeCrimeLab
# age
# goodConductScotRef
# partyIdSqueeze
# difficultBlameCoalition
# changeEducation
# remainVoteConLab
# tryReduceInequalityDK
# likeCable
# difficultBlameCoalition
# generalElectionVoteUnsqueeze
# conUnited
# singlePartyEffective
# ptvLab
# generalElectionVoteSqueeze
# EUIntegrationLab
# effectsEUImmigration
# pidPraiseGood
# small_mii_cat
# polForTheRich
# infoSourceInternet
# responsibleDebtLabour
# moreParl
# ImpRelig
# efficacyVoteEffort
# education
# ldPriorities_costLive
# partyContact
# ldUnited
# pidConnected
# partyId
# fbInfo
# noChanceCoalitionNone
# socialCare
# generalElectionVote
# ldPriorities
# redistLD
# satDemEng
# bestLeaderCampaign
# ashcroft
# electionInterest
# pidCommonParty
# responsibleDebtLabour
# partyId
# immigLD
# EUMIICategory
# labPriorities_school
# partyIdSqueeze
# electionInterest
# labPartnerUKIP
# inequalityChangeLarger
# englishness
# changeImmig
# mii_cat
# localTurnoutRetro
# spendMost
# EUMIICategory
# partyContactCon
# profile_marital_stat
# partyIdSqueeze
# immigLab
# spendLeast
# efficacyVoteEffort
# labFear
# referendumContact
# noChanceCoalitionGrn
# resourceAccess
# likeMiliband
# achieveReduceImmigUKIP
# immigLD
# partyContact
# conPriorities_school
# small_mii_cat
# labHope
# partyContactLD
# satDemEU
# changeNHS
# populism
# polAttention
# subjectHE
# ldPriorities_school
# inequalityChange
# natSecurityLab
# responsibleDebtConservatives
# education
# inequalityChange
# partyContactLD
# lrCon
# blameLeave
# partyIdSqueeze
# econPersonalRetro
# generalElectionVoteUnsqueeze
# bestOnMII
# handleMIILD
# partyIdSqueeze
# efficacyNotUnderstand
# likeBNP
# racismAmount
# changeCostLiveLab
# conSupport
# likeBNP
# worstLeaderCampaign
# euMIISmall
# fbInfo
# ukipUnited
# conPartnerUKIP
# labPriorities_econ
# small_mii_cat
# partyContact
# conPriorities_nhs
# labGovTrust
# pccVote
# profile_newspaper
# econGenRetro
# spendLeast
# efficacyTooMuchEffort
# EUIntegrationCon
# localElectionVote
# spendMost
# econPersonalProsp
# partyContactLab
# grnFear
# mapInequality
# resourceAccess
# miilabel
# noChanceCoalitionLab
# worstLeaderCampaign
# participation
# scotElectionVoteConst
# goodTimePurchase
# profile_sexuality
# partyIdSqueeze
# LRAL_mii_cat
# discussantVoteName
# visitPartySite
# partyContactLab
# infoSourceInternet
# accessGovtRegulator
# likeBNP
# partyContactLab
# euRefExpectation
# efficacyTooMuchEffort
# partyIdStrength
# profile_work_type
# immigLD
# efficacyUnderstand
# labUnited
# ptvLab
# pidPraiseGood
# generalElectionVote
# partyContactCon
# efficacyUnderstand
# allSourceIncome
# profile_work_stat
# likeLab
# participation
# prefTradeoff
# mii_cat
# ldLookAfterMC
# engFairShare
# ptvLab
# twitterInfo
# EUIntegrationCon
# regSatisfaction
# germanyFairShare
# ashcroft
# responsibleCrimeNone
# winConstituencyUKIP
# profile_work_stat
# education
# bestLeaderCampaign
# govtHandleLevelCrime
# small_mii_cat
# snpFear
# eesEUIntegrationLab
# generalElectionVote
# labHandleNHS
# mapUKIP
# immigCon
# responsibleEconLibDems
# bestOnMII
# labHandleLevelCrime
# responsibleCrimeNone
# profile_newspaper
# profile_marital_stat
# efficacyUnderstand
# achieveReduceImmigUKIP
# discussantVoteName
# EUIntegrationCon
# miilabel
# infoSourceInternet
# generalElectionVotePost
# likeLD
# cspl
# twitterInfo
# noChanceCoalitionLD
# partyContact
# changeEducation
# responsibleImmigLabour
# small_mii_cat
# redistLab
# changeEconomy
# satDemEng
# certaintyScotIndependence
# partyId
# profile_newspaper
# mii_cat
# eesEUIntegrationLab
# EUIntegrationLab
# small_mii_cat
# responsibleDebtEU
# ukipUnited
# propMPDegree
# euSources
# englishness
# conPriorities_costLive
# noChanceCoalitionSNP
# noChanceCoalitionLD
# efficacyTooMuchEffort
# govtHandleLevelCrime
# scotElectionVoteConst
# negotiationSpecifics_none
# noChanceCoalitionPC
# satDemScot
# partyId
# labPriorities_school
# responsibleDebtUKBanks
# conPriorities_nhs
# lrLD
# EUIntegrationLab
# scotShareBurden
# EUMIICategory
# fbInfo
# mii_cat
# education
# worstLeaderCampaign
# selfRedistCertain
# generalElectionVote
# bestLeaderCampaign
# labPriorities_econ
# EUContactRemainLab
# devoResponsibleScotPolice
# certaintyRedistLD
# accessFluentSpeaker
# cspl
# redistLD
# labHandleLevelCrime
# mii_cat
# LRAL_mii_cat
# responsibleCrimeNone
# profile_work_stat
# education
# mii_cat
# referendumContact
# likeLab
# changeCostLiveLab
# small_mii_cat
# spendMost
# euCitizen
# partyContactUKIP
# bestOnMII
# partyId
# changeImmig
# EUIntegrationUKIP
# partyIdSqueeze
# likeBNP
# conPriorities
# ptvLD
# infoSourcePeople
# EUMIICategory
# ukipUnited
# econGenRetro
# ukipTone
# happyScotIndepResultNo
# partyIdStrength
# pidPraiseGood
# goodTimePurchase
# labSupport
# EUContactRemainCon
# devoResponsibleScotSchools
# responsibleDebtUKBanks
# zeroSum
# partyIdSqueeze
# responsibleDebtEU
# devoResponsibleScotSchools
# euID
# ptvLab
# worstLeaderCampaign
# efficacyNoMatter
# generalElectionVote
# changeCostLiveLab
# bestOnMII
# riskUnemployment
# resourceAccess2_111
# profile_work_type
# noChanceCoalitionPC
# achieveReduceImmigUKIP
# immigLD
# spendMost
# winConstituencyUKIP
# efficacyNoMatter
# profile_past_vote
# responsibleImmigLabour
# worstLeaderCampaign
# profile_work_stat
# generalElectionVote
# noChanceCoalitionNone
# ukipPriorities_econ
# education
# grnFear
# small_mii_cat
# coalitionDontDeliver
# bestOnMII
# bestOnMII
# LRAL_mii_cat
# participation
# profile_religion
# redistLab
# spendMost
# responsibleCrimeNone
# ukipTone
# euMIISmall
# partyIdSqueeze
# partyIdStrength
# labHandleEduc
# discussPolDaysD
# LRAL_mii_cat
# changeNHS
# devoResponsibleScotPolice
# participation
# handleMIILab
# euID
# prefTradeoff
# partyContactCon
# difficultBlameCoalition
# generalElectionVoteUnsqueeze
# labPriorities_costLive
# bestOnMII
# sharedContentOnline
# riskUnemployment
# numChildren
# warmDenmark
# ukipPriorities_school
# euMIISmall
# resourceAccess3_111
# immigUKIP
# mii_cat
# twitterUse
# natSecurityGrn
# turnoutUKGeneral
# participation
# effectsEUImmigration
# mii_cat
# partyContactLab
# efficacyEnjoyVote
# riskUnemployment
# LRAL_mii_cat
# ptvBNP
# spendLeast
# discussPolDays
# partyIdStrength
# likeBNP
# mii_cat
# newspaper
# generalElectionVote
# englishness
# partyId
# devoResponsibleScotPolice
# Age
# econGenRetro
# ukipTone
# generalElectionVote
# spendLeast
# profile_past_vote
# partyIdStrength
# pidInterestedOthers
# resourceAccess
# generalElectionVote
# partyIdSqueeze
# spendMost
# changeView
# eesEUIntegrationUKIP
# satDemEU
# mpSecondJob
# small_mii_cat
# propMPMuslim
# generalElectionVote
# partyContactGreen
# likeLab
# EUIntegrationUKIP
# profile_past_vote
# lr
# mii_cat
# winConstituencyGreen
# partyContactLab
# profile_past_vote
# scotRefExpectation
# eesEUIntegrationLab
# inequalityGoodBad
# scotElectionVoteConst
# profile_newspaper
# generalElectionVoteUnsqueeze
# changeCostLive
# changeCostLive
# majorityPartyCon
# winConstituencyUKIP
# localElectionVote
# ukipPriorities
# expectationDevoScot
# participation
# euKnow
# responsibleDebtLabour
# bestOnMII
# energyPriceCap
# satDemEU
# redistGreen
# localTurnoutRetro
# ukipUnited
# infoSourcePeople
# ldUnited
# EUIntegrationLab
# satDemEng
# profile_work_type
# ageGroup
# spendLeast
# generalElectionVote
# partyId
# partyContactLD
# germanyFairShare
# labPriorities_econ
# partyIdSqueeze
# devoResponsibleScotSchools
# LRAL_mii_cat
# changeEducation
# warmSpain
# bestOnMII
# partyContactLD
# impRace
# pidConnected
# generalElectionVoteSqueeze
# childvalues
# natSecurityLD
# small_mii_cat
# euMIISmall
# preferMPLocal
# labLookAfterBA
# snpFear
# otherSide
# allSourceIncome
# partyContact
# labTone
# propMPChrist
# successReduceInequalityDK
# tryReduceImmigCon
# pidCriticiseParty
# spendMost
# accessMedia
# dutyStrong
# partyId
# devoResponsibleScotNHS
# nan
# bestOnMII
# EUIntegrationLab
# scotElectionVoteList
# cooperateRUKGBP
# twitterInfof
# pidCommonParty
# achieveReduceImmigUKIP
# majorityPartyCon
# cabinetSupport
# EUIntegrationLD
# dutyToVote
# populism
# changeCrime
# EUMIICategory
# ukipPriorities_nhs
# small_mii_cat
# LRAL_mii_cat
# changeCostLive
# conPriorities_immig
# scotElectionVoteConst
# labSupport
# pidPraiseGood
# noChanceCoalitionSNP
# partyId
# houseBuild
# redistGreen
# efficacyNotUnderstand
# changeCostLive
# referendumContact
# redistLab
# englandGovern
# languageSkills
# generalElectionVote
# partyContactGrn
# betterDealEU
# EUMIICategory
# bestOnMII
# partyIdSqueeze
# ukipPride
# EUMIICategory
# generalElectionVote
# partyContactLab
# partyIdSqueeze
# conPriorities_costLive
# satDemEU
# pContactEday
# workingStatus
# conPriorities_econ
# conPriorities_costLive
# econGenProsp
# EUIntegrationCon
# partyIdSqueeze
# profile_marital_stat
# labLookAfterWC
# econGenProsp
# eesEUIntegrationUKIP
# profile_house_tenure
# coalitionDontDeliver
# euCitizen
# inequalityGoodBad
# redistGreen
# natSecurityGrn
# euID
# responsibleDebtEU
# pidCommonParty
# euID
# profile_house_tenure
# econPersonalRetro
# spendLeast
# participation
# miilabel
# partyContactCon
# changeCostLive
# bestOnMII
# profile_past_vote
# EUIntegrationUKIP
# euID
# discussantVoteName
# euID
# childvalues
# pidCommonParty
# responsibleNHSConservatives
# ldLookAfterBA
# campaigninfoRemain
# mapRepresent
# tryReduceInequalityNone
# ukipUnited
# mii_cat
# handleMIILab
# trustMPs
# labPriorities_school
# bestLeaderCampaign
# profile_work_stat
# changeCrime
# changeNHS
# winConstituencyUKIP
# scotIndepGoodEng
# ldPriorities_nhs
# efficacyNoMatter
# partyIdStrength
# ldSupport
# twitterUse
# twitterUse
# immigGreen
# certaintyUKRemain
# small_mii_cat
# worstLeaderCampaign
# partyIdSqueeze
# partyIdSqueeze
# debateThreeWatch
# discussantApprovalVoteName
# bestOnMII
# small_mii_cat
# goodTimePurchase
# ukipHope
# visitPartySite
# partyIdSqueeze
# generalElectionVoteSqueeze
# londonEcon
# partyContactCon
# infoSourcePeople
# ukipPriorities_econ
# redistLD
# immigLab
# partyContactOtherParty
# partyContactLab
# csplRank
# profile_marital_stat
# betterDealEU
# responsibleCostLiveCon
# generalElectionVoteUnsqueeze
# pidPraiseGood
# responsibleCostLiveLD
# ldFear
# generalElectionVote
# pidMyParty
# partyContactLab
# worryEconSecurity
# bestOnMII
# responsibleEconLibDems
# profile_work_stat
# pContactEday
# labPriorities
# infoSourcePaper
# EUMIICategory
# euID
# education
# eesEUIntegrationLab
# EUMIICategory
# generalElectionVoteUnsqueeze
# euID
# partyContactLab
# euID
# successReduceInequalityUKIP
# responsibleDebtEU
# regSatisfaction
# winConstituencyLab
# conPriorities_nhs
# remainTone
# profile_work_type
# tryReduceImmigDK
# EUIntegrationUKIP
# profile_sexuality
# achieveReduceImmigUKIP
# partyContact
# resourceAccess3_99
# spendMost
# labPriorities
# warmChristian
# profile_religion_denom
# EUIntegrationUKIP
# conPartnerUKIP
# spendMost
# partyIdSqueeze
# polKnowKerry
# changeView
# ukipPriorities_costLive
# partyContactGreen
# participation
# conNone
# inequalityChange
# mii_cat
# partyContactCon
# noChanceCoalitionLab
# euID
# labPriorities_costLive
# miilabel
# discussantVoteName
# trustMPs
# scotElectionVoteConst
# immigLab
# lrgreens
# ldSupport
# riskPoverty
# finlit
# labTone
# euID
# partyId
# dv
# responsibleEconLibDems
# profile_past_vote
# spendMost
# bestLeaderCampaign
# generalElectionVote
# ashcroft
# infoSourcePaper
# education
# conPartnerSNP
# tryReduceImmigLD
# euSources
# discussantVoteName
# ptvBNP
# generalElectionVote
# labPriorities_econ
# accessProfessional
# conPride
# generalElectionVote
# mainSourceIncome
# resourceAccess2_99
# goodTimePurchase
# handleMIILab
# spendMost
# worstLeaderCampaign
# referendumContact_none
# marital
# generalElectionVoteUnsqueeze
# govtHandleLevelCrime
# generalElectionVote
# partyId
# profile_work_stat
# LRAL_mii_cat
# noChanceCoalitionUKIP
# partyContactUKIP
# labPartnerUKIP
# euMIISmall
# scotIndepGoodEng
# sharedContentOnline
# labPriorities_nhs
# pccVote
# EUIntegrationUKIP
# partyContactLab
# education
# discussantClassName
# labPriorities_none
# localElectionVote
# satDemScot
# debateOneWatch
# partyContactOtherParty
# pidPraiseGood
# satDemEU
# pidInterestedOthers
# partyId
# cabinetSupport
# resourceAccess
# ukipPriorities_nhs
# LRAL_mii_cat
# pidConnected
# goodTimePurchase
# knowf
# polForTheRich
# natSecurityGrn
# englandGovern
# spendMost
# finlit
# conPriorities_immig
# riskUnemployment
# small_mii_cat
# partyIdSqueeze
# mii_cat
# education
# coalitionDontDeliver
# conPriorities
# partyContactLD
# labPride
# winConstituencyGreen
# partyContactLD
# changeCostLive
# scotShareBurden
# socialPressureVote
# csplPunishWrongs
# profile_work_industry
# partyIdStrength
# conPride
# bestOnMII
# profile_house_tenure
# mii_cat
# spendMost
# partyId
# ldPriorities_crime
# profile_house_tenure
# euID
# ukipFear
# expectationDevoScot
# eesEUIntegrationUKIP
# localElectionVote
# polKnowHollande
# winConstituencyLab
# LRAL_mii_cat
# small_mii_cat
# partyContactCon
# cspl
# ldLookAfterUnemp
# generalElectionVote
# partyContactCon
# discussantApprovalVoteName
# mii_cat
# scotElectionVoteConst
# labPriorities_nhs
# scotElectionVoteConst
# econPersonalRetro
# pidMyParty
# referendumContact_none
# trustMPs
# profile_marital_stat
# redistLD
# partyContactUKIP
# small_mii_cat
# partyContactLab
# subjectHE
# pidWeThey
# bestOnMII
# scotElectionVoteConst
# scotElectionVoteList
# responsibleCrimeConservatives
# riskUnemployment
# likeLD
# partyIdSqueeze
# ptvLD
# ptvBNP
# EUIntegrationLD
# winConstituencyCon
# ukipPriorities_school
# pidCriticiseParty
# riskUnemployment
# responsibleDebtLiberalDems
# partyContactCon
# mpBrexitView
# nonelecParticipation
# certaintyUKLeave
# labLookAfterUnemp
# profile_house_tenure
# partyIdStrength
# mii_cat
# propMPYoung
# eesEUIntegrationUKIP
# profile_house_tenure
# responsibleEconLibDems
# spendMost
# winConstituencyGreen
# partyIdSqueeze
# labPartnerUKIP
# bestOnMII
# ldAngry
# partyContactCon
# partyIdSqueeze
# twitterInfo
# discussPolDaysD
# ptvBNP
# generalElectionVoteUnsqueeze
# workingStatus
# EUMIICategory
# allSourceIncome
# pidWeThey
# scotElectionVoteList
# tryReduceImmigUKIP
# winConstituencyCon
# goodTimePurchase
# EUIntegrationLD
# polKnowPutin
# propMPWC
# populism
# changeCrime
# partyContactLab
# pidCriticiseParty
# econPersonalRetro
# EUMIICategory
# generalElectionVoteSqueeze
# partyIdSqueeze
# profile_turnout
# pidInterestedOthers
# EUIntegrationLD
# sharedContentOnline
# efficacyEnjoyVote
# LRAL_mii_cat
# bestOnMII
# ukipPriorities_econ
# partyIdSqueeze
# subjClass
# partyContactGreen
# remainTone
# scotElectionVoteConst
# pContactEday
# spendMost
# infoSourceRadio
# responsibleNHSConservatives
# labUnited
# spendMost
# profile_work_organisation
# resourceAccess
# grnAngry
# empathy
# ukipNone
# discussantVoteName
# LRAL_mii_cat
# small_mii_cat
# euSources
# small_mii_cat
# responsibleNHSConservatives
# ptvBNP
# polForTheRich
# belongGroup_99
# pidCriticiseParty
# empathy
# pidMyParty
# pidMyParty
# labHope
# achieveReduceImmigDK
# referendumContact
# bestOnMII
# responsibleDebtDontKnow
# profile_work_organisation
# EUIntegrationUKIP
# responsibleNHSLibDems
# generalElectionVote
# natSecurityLD
# generalElectionVote
# labUnited
# profile_house_tenure
# nationalUnemployment_a
# responsibleCrimeConservatives
# euroTurnout
# ldPriorities
# commonwealthCitizen
# winConstituencyGreen
# populism
# mii_cat
# EUMIICategory
# responsibleDebtOther
# pccVote
# ldFear
# labUnited
# education
# polKnowMerkel
# handleMIILab
# churchAttendance
# allSourceIncome
# spendMost
# efficacyEnjoyVote
# trustMPs
# gor
# winConstituencyCon
# labPride
# partyIdSqueeze
# partyIdSqueeze
# debateOneWatch
# bestOnMII
# dutyToVote
# responsibleDebtUKBanks
# responsibleEducationCon
# labPriorities_nhs
# LRAL_mii_cat
# polKnowNetanyahu
# labUnited
# responsibleEconNone
# changeCrime
# polPreferToFight
# responsibleCrimeConservatives
# govtNatSecuritySuccess
# small_mii_cat
# lrgreens
# ashcroft
# changeCrime
# partyId
# winConstituencyGreen
# bestLeaderCampaign
# education
# small_mii_cat
# certaintyEUUKIP
# ukipLookAfterMC
# ukipPriorities
# pccVote
# partyIdSqueeze
# profile_marital_stat
# labPartnerGreen
# partyIdSqueeze
# euSources
# EUMIICategory
# ukipPride
# generalElectionVoteSqueeze
# ashcroft
# ashcroft
# responsibleDebtLiberalDems
# mii_cat
# resourceAccess
# successReduceInequalityCon
# EUIntegrationLab
# bestOnMII
# EUMIICategory
# partyId
# education
# referendumContact
# likeLD
# euCitizen
# infoSourceRadio
# education
# generalElectionVote
# participation
# ptvBNP
# euID
# LRAL_mii_cat
# scotElectionVoteList
# efficacyPolCare
# childvalues
# responsibleNHSConservatives
# eesEUIntegrationLab
# ldAngry
# accessHealth
# bestOnMII
# bestOnMII
# EUIntegrationLD
# redistGreen
# devoResponsibleScotSchools
# buyHomeFuture
# education
# trustMPs
# partyIdStrength
# resourceAccess1_99
# euroTurnoutRetro
# profile_work_stat
# gor
# dutyToVote
# generalElectionVoteUnsqueeze
# winConstituencySNP
# mii_cat
# resourceAccess
# ukipPriorities_nhs
# riskPoverty
# commonwealthCitizen
# pidInterestedOthers
# conPriorities_costLive
# subjectHE
# localTurnoutRetro
# partyContactUKIP
# education
# partyIdSqueeze
# ukipPriorities_school
# natSecurityGrn
# small_mii_cat
# socialPressureVote
# euKnow
# partyId
# govtHandleLevelCrime
# localTurnout
# responsibleCostLiveCon
# allSourceIncome
# certaintyUKRemain
# certaintyRedistLab
# dutyToVote
# profile_newspaper
# euID
# scotElectionVoteConst
# propMPRace
# ldPriorities_econ
# trustMPs
# ukipPriorities_costLive
# socialPressureVote
# partyContactLab
# bestOnMII
# partyIdStrength
# generalElectionVote
# tryReduceInequalityUKIP
# creditLeave
# propMPLGBT
# referendumContact
# profile_house_tenure
# miilabel
# noChanceCoalitionPC
# spendMost
# selfRedistCertain
# blameLeave
# generalElectionVote
# turnoutUKGeneral
# partyIdSqueeze
# profile_newspaper
# econPersonalRetro
# labPriorities_costLive
# parliamentSupport
# ukipPriorities_costLive
# ukipPriorities_school
# EUIntegrationLD
# mii_cat
# generalElectionVote
# mii_cat
# spendMost
# euID
# partyIdSqueeze
# accessJobReference
# partyContactOtherParty
# immigGreen
# ukipPriorities
# profile_marital_stat
# reasonForVote
# partyIdSqueeze
# partyId
# conPriorities_econ
# mii_cat
# partyContactCon
# dutyToVote
# certaintyEUCon
# partyIdSqueeze
# mapEcon
# certaintyEUUKIP
# responsibleEducationLD
# labUnited
# responsibleEducationDontKnow
# eesEUIntegrationLD
# turnoutUKGeneral
# achieveReduceImmigUKIP
# discussantVoteName
# scotRefExpectation
# EUIntegrationUKIP
# partyContactOtherParty
# mii_cat
# ukipPriorities_crime
# infoSourceRadio
# profile_socgrade
# responsibleCostLiveCon
# small_mii_cat
# generalElectionVoteSqueeze
# redistGreen
# participation
# mii_cat
# csplRank
# prefTradeoff
# profile_sexuality
# partyContactLab
# blameLeave
# participation
# scotElectionVoteConst
# empathy
# education
# resourceAccess
# majorityPartyLab
# goodTimePurchase
# miilabel
# newspaper
# labPriorities_school
# socialPressureVote
# responsibleDebtOther
# partyId
# englandGovern
# changeCrime
# partyIdSqueeze
# generalElectionVote
# LRAL_mii_cat
# mii_cat
# euroElectionVote
# spendMost
# noChanceCoalitionUKIP
# pccVote
# bestOnMII
# currentUnionMember
# small_mii_cat
# LRAL_mii_cat
# expectationDevoScot
# moreParl
# profile_work_stat
# workingStatus
# LRAL_mii_cat
# small_mii_cat
# tryReduceInequalityCon
# responsibleDebtDontKnow
# strongestConnection
# partyContactLab
# ukipPriorities_school
# profile_work_industry
# conLookAfterMC
# mii_cat
# ukipPriorities_nhs
# partyIdSqueeze
# responsibleEconNone
# pccVote
# conPriorities_school
# immigUKIP
# pidInterestedOthers
# conPriorities_immig
# miilabel
# responsibleDebtOther
# generalElectionVotePost
# bestOnMII
# education
# gor
# pidPraiseGood
# turnoutUKGeneral
# partyContactLab
# spendLeast
# euID
# responsibleNHSDontKnow
# bestLeaderCampaign
# bestOnMII
# LRAL_mii_cat
# polKnowNetanyahu
# dutyLong
# ukipPride
# responsibleCostLiveDontKnow
# generalElectionVoteUnsqueeze
# EUMIICategory
# headHouseholdPast
# age
# mii_cat
# likeCandB
# partyId
# education
# econPersonalRetro
# euID
# miilabel
# responsibleDebtDontKnow
# profile_newspaper
# moreParl_111
# partyIdStrength
# education
# ldPriorities_econ
# lrgreens
# scotElectionVoteConst
# subjClass
# euID
# winConstituencyLab
# partyContact
# achieveReduceImmigCon
# ukipNone
# responsibleDebtLiberalDems
# mapUKBirth
# participation
# empathy
# infoSourceRadio
# profile_newspaper
# discussantApprovalVoteName
# propMPFemale
# responsibleCrimeConservatives
# partyContactCon
# workingStatus
# euID
# discussantClassName
# headHouseholdPast
# debateTwoWatch
# csplImproveStandards
# labPriorities_school
# partyContactLab
# partyId
# responsibleDebtTradeUnions
# bestOnMII
# infoSourcePaper
# partyIdSqueeze
# bestOnMII
# responsibleDebtTradeUnions
# ldPriorities_econ
# marital
# partyHelp
# generalElectionVoteUnsqueeze
# strongestConnection
# generalElectionVoteSqueeze
# mii_cat
# mii_cat
# spendMost
# small_mii_cat
# partyId
# infoSourcePeople
# generalElectionVote
# finlit
# partyContactLab
# LRAL_mii_cat
# small_mii_cat
# responsibleEconNone
# mii_cat
# profile_religion
# beliefTradeoff
# pidCriticiseParty
# spendLeast
# bestLeaderCampaign
# labPriorities_econ
# partyContactCon
# ldPriorities
# expectGoodConductEURef
# partyContactLD
# discussantVoteName
# warmRich
# reasonForVote
# scotIndepGoodEng
# econPersonalRetro
# generalElectionVote
# allSourceIncome
# ukipPriorities_costLive
# mii_cat
# tryReduceImmigLab
# ukipPriorities_costLive
# efficacyPolCare
# discussantClassName
# partyContactStrongerIn
# mainSourceIncome
# responsibleDebtOther
# infoSourceTV
# mii_cat
# conPriorities_immig
# EUContactLeaveNone
# natSecurityLD
# responsibleEducationDontKnow
# localElectionVote
# EUMIICategory
# EUIntegrationLD
# headHouseholdPast
# conPriorities_immig
# profile_marital_stat
# spendMost
# selfOccOrgSize
# partyIdSqueeze
# majorityPartyLab
# euRefInterest
# mapLiveWork
# mii_cat
# partyIdSqueeze
# EUMIICategory
# ldPriorities_none
# partyContactLab
# bestOnMII
# ldPriorities
# euSources
# mii_cat
# ...
# mii_cat
# infoSourcePeople
# generalElectionVote
# ldPride
# partyIdSqueeze
# EUContactRemainDK
# achieveReduceImmigCon
# discussantVoteName
# gor
# turnoutUKGeneral
# polKnowMiliband
# govtHandleImmig
# bestOnMII
# EUMIICategory
# smallVoterPref
# responsibleNHSLabour
# partyContactLab
# EUIntegrationGreen
# partyContactLab
# euID
# mii_cat
# redistLab
# profile_marital_stat
# mii_cat
# subjClass
# smallEmergency_99
# ashcroft
# selfOccOrgSize
# polKnowOsborne
# partyContactLab
# partyContactUKIP
# localElectionVote
# polKnowPutin
# discussantEthnicity
# livedAbroad
# miilabel
# mii_cat
# responsibleNHSLibDems
# partyContactLab
# responsibleCostLiveLD
# mii_cat
# education
# econPersonalProsp
# sharedContentOnline
# partyId
# gor
# nan
# regretsIHaveAFewEU
# partyContactUKIP
# small_mii_cat
# redistLD
# labUnited
# partyIdSqueeze
# trustYourMP
# nan
# partyContactUKIP
# regSatisfaction
# resourceAccess
# redistLD
# partyIdSqueeze
# responsibleEconDontKnow
# profile_newspaper
# partyContactCon
# partyContactGreen
# responsibleNHSLabour
# postalapply
# voteMethodEurope
# mapdefined
# miilabel
# partyContactCon
# mii_cat
# partyId
# partyContactOthLeave
# partyIdSqueeze
# finlit
# localUnemployment_a
# pidWeThey
# infoSourcePaper
# bestOnMII
# knowf
# referendumContact
# spendLeast
# small_mii_cat
# ldNone
# fatherCountryBorn
# labPriorities
# ptvLD
# mainSourceIncome
# profile_house_tenure
# localismImportance
# euSources_111
# scotReferendumOutside
# profile_work_stat
# generalElectionVote
# sexuality
# mii_cat
# partyContactLD
# responsibleCrimeDontKnow
# discussantVoteName
# conPriorities_econ
# pccVote
# small_mii_cat
# LRAL_mii_cat
# polKnowClegg
# labPartnerSNP
# headHouseholdPast
# mii_cat
# partyId
# responsibleDebtTradeUnions
# miilabel
# spendMost
# gor
# ukipPriorities
# accessCouncillor
# EUMIICategory
# mapdefined
# housing
# EUIntegrationGreen
# eesEUIntegrationGreen
# RPrivSchnew_dk
# achieveReduceImmigGrn
# workingStatus
# profile_work_stat
# miilabel
# partyId
# labPriorities_none
# mii_cat
# ldPriorities_school
# smallVoterPref
# belongGroup
# profile_work_industry
# changeCrime
# majorityPartyLab
# responsibleNHSLabour
# profile_work_stat
# small_mii_cat
# partyId
# labAngry
# allSourceIncome
# responsibleCostLiveNone
# polKnowMerkel
# euID
# miilabel
# polKnowHollande
# natSecurityLab
# partyContactUKIP
# mii_cat
# discussantturnoutName
# EUIntegrationLD
# likeFarron
# generalElectionVote
# EUIntegrationGreen
# labPriorities_crime
# generalElectionVoteUnsqueeze
# eesEUIntegrationLD
# profile_gross_household
# euKnow
# partyId
# mapdefined
# bestOnMII
# small_mii_cat
# partyContactLD
# fbUse
# eesEUIntegrationLD
# discussantVoteName
# euroElectionVote
# profile_socgrade
# EUIntegrationGreen
# profile_work_stat
# generalElectionVote
# responsibleCostLiveLD
# ns_sec
# conPartnerSNP
# profile_marital_stat
# partyContactUKIP
# regretsIHaveAFewEU
# labPartnerLD
# resourceAccess1_111
# mii_cat
# euMIISmall
# small_mii_cat
# socialDistLD
# eesEUIntegrationGreen
# responsibleEducationLD
# strongestConnection
# pidCriticiseParty
# homeOwn
# responsibleCrimeDontKnow
# dutyToVote
# myPartyWon
# accessFixComputer
# mii_cat
# miilabel
# partyId
# redistLab
# small_mii_cat
# turnoutUKGeneral
# riskUnemployment
# partyContactOtherParty
# miilabel
# profile_marital_stat
# profile_work_industry
# immigGreen
# polKnowMerkel
# bestOnMII
# pidRuinDay
# mii_cat
# strongestConnection
# labPriorities_nhs
# partyId
# small_mii_cat
# profile_newspaper
# discussantVoteName
# EUMIICategory
# allSourceIncome
# trustMPs
# bestOnMII
# mii_cat
# turnoutUKGeneral
# euID
# redistLab
# immigGreen
# partyContactUKIP
# small_mii_cat
# profile_household_children
# pidRuinDay
# euroElectionVote
# mapCon
# scotReferendumTurnout
# education
# mapLiveWork
# euID
# happyScotIndepResult
# education
# creditLeave
# spendMost
# knowMP
# turnoutUKGeneral
# mii_cat
# polKnowPutin
# profile_religion
# miilabel
# education
# partyContactLab
# ptvLD
# partyIdSqueeze
# mapdefined
# proConRemain
# subjClass
# mii_cat
# small_mii_cat
# profile_newspaper
# socialPressureVote
# responsibleNHSLibDems
# partyId
# discussantVoteName
# profile_past_vote
# education
# mortgagePayment
# conPriorities_none
# education
# partyId
# prefTradeoff
# noChanceCoalitionPC
# small_mii_cat
# knowf
# miilabel
# knowMP
# profile_work_type
# polKnowBercow
# mii_cat
# mii_cat
# generalElectionVoteUnsqueeze
# LRAL_mii_cat
# small_mii_cat
# mapLiveTime
# discussantEthnicity
# riskTaking
# ukipPriorities_crime
# ldCoalition
# profile_work_organisation
# ptvLD
# creditLeave
# labUnited
# mii_cat
# EUMIICategory
# mii_cat
# marital
# ns_sec_analytic
# conPriorities_immig
# partyContactCon
# responsibleImmigDontKnow
# bestOnMII
# profile_work_organisation
# accessCouncilWorker
# generalElectionVoteUnsqueeze
# generalElectionVote
# immigLD
# profile_religion
# riskUnemployment
# profile_newspaper
# profile_socgrade
# education
# education
# beliefTradeoff
# polKnowKerry
# mii_cat
# LRAL_mii_cat
# housing
# conNone
# bestOnMII
# econPersonalRetro
# partyContactOtherParty
# profile_work_type
# conPriorities_none
# miilabel
# education
# profile_work_industry
# education
# mapBlack
# econPersonalRetro
# profile_marital_stat
# profile_work_stat
# achieveReduceImmigLab
# polKnowMay
# profile_newspaper
# mpLooksAfterConstInterest
# selfOccStatus
# mii_cat
# profile_work_organisation
# taxSpendLab
# education
# riskPoverty
# mii_cat
# mii_cat
# profile_religion
# responsibleCostLiveLab
# mii_cat
# education
# EUIntegrationGreen
# small_mii_cat
# achieveReduceImmigDK
# miilabel
# profile_religion
# EUIntegrationUKIP
# infoSourceRadio
# gor
# newspaper
# miilabel
# mii_cat
# euSources_99
# mii_cat
# winConstituencyLD
# labPride
# childvalues
# mii_cat
# profile_past_vote
# partyContactOtherParty
# scotReferendumOutside
# locus
# education
# strongestConnection
# responsibleEducationLab
# lrgreens
# small_mii_cat
# LRAL_mii_cat
# education
# miilabel
# ptvLD
# partyIdSqueeze
# generalElectionVote
# small_mii_cat
# miilabel
# partyContactCon
# singlePartyEffective
# partyId
# partyContactCon
# worstLeaderCampaign
# responsibleEducationLab
# profile_newspaper
# gor
# euID
# winConstituencyLab
# partyId
# partyIdSqueeze
# lrgreens
# govtHandleImmig
# ukipPriorities_econ
# responsibleEducationLD
# education
# polKnowPutin
# partyContactCon
# strongestConnection
# generalElectionVote
# mii_cat
# euSources_111
# allSourceIncome
# childvalues
# mii_cat
# takeTheJobVoteOutcome
# gor
# localTurnoutRetro
# homeOwn
# EUMIICategory
# profile_religion
# mii_cat
# partyContactCon
# education
# mapTurnout
# generalElectionVote
# euRefInterest
# worstLeaderCampaign
# bestOnMII
# profile_work_type
# regretsIHaveAFewEU
# knowMP
# ldNone
# miilabel
# responsibleEducationLD
# mii_cat
# profile_newspaper
# achieveReduceImmigDK
# EUIntegrationLD
# infoSourceTV
# allSourceIncome
# bestOnMII
# responsibleImmigDontKnow
# profile_past_vote
# profile_work_stat
# polKnowNetanyahu
# mii_cat
# debateOneWatch
# spendMost
# headHouseholdPast
# profile_work_industry
# miilabel
# partyId
# profile_newspaper
# education
# generalElectionVoteUnsqueeze
# profile_religion
# ldCoalition_111
# education
# impAge
# spendLeast
# mii_cat
# education
# relationshipName
# noChanceCoalitionUKIP
# profile_work_industry
# polKnowPutin
# newspaper
# mii_cat
# profile_religion
# partyId
# partyContactLD
# responsibleNHSNone
# profile_work_type
# profile_religion
# ldNone
# mii_cat
# ldCoalition
# mii_cat
# profile_religion
# partyId
# spendLeast
# taxSpendLD
# workingStatus
# partyId
# spendMost
# decidedVote
# mii_cat
# miilabel
# mii_cat
# generalElectionVote
# riskPoverty
# generalElectionVote
# profile_house_tenure
# mii_cat
# csplRank
# ldUnited
# polKnowAssad
# childvalues
# profile_newspaper
# bestOnMII
# ns_sec
# polKnowMiliband
# LRAL_mii_cat
# small_mii_cat
# beliefTradeoff
# askVotePartner
# responsibleCostLiveLab
# debateTwoWatch
# generalElectionVote
# headHouseholdPast
# generalElectionVote
# small_mii_cat
# miilabel
# mapLiveWork
# profile_work_stat
# mii_cat
# profile_religion
# profile_work_organisation
# lrgreens
# bestOnMII
# profile_religion
# education
# small_mii_cat
# profile_newspaper
# gor
# partyId
# redistLab
# mii_cat
# infoSourceRadio
# gor
# mii_cat
# profile_religion
# responsibleEconConservatives
# registered
# polKnowClegg
# subjClass
# mii_cat
# EUMIICategory
# winConstituencyLab
# mii_cat
# partyId
# partyContactLab
# mii_cat
# bestOnMII
# education
# profile_work_stat
# noChanceCoalitionUKIP
# education
# bestOnMII
# reasonForVote
# noDependentsInHouse
# euroElectionVote
# likeClegg
# profile_newspaper
# mii_cat
# askVoteDiscuss
# noChanceCoalitionNone
# profile_work_industry
# conPartnerLD
# profile_work_type
# bestOnMII
# spendMost
# EUIntegrationGreen
# bestOnMII
# partyId
# ns_sec_analytic
# riskPoverty
# discussantVoteName
# fbUse
# discussantturnoutName
# euID
# profile_work_responsibility
# mii_cat
# generalElectionVote
# partyId
# gor
# profile_work_type
# selfOccStatus
# education
# partyContactNone
# education
# likeClegg
# localElectionVote
# localElectionVote
# mii_cat
# partyId
# discussantVoteName
# euroElectionVote
# small_mii_cat
# EUMIICategory
# motherCountryBorn
# mii_cat
# generalElectionVote
# lrgreens
# riskPoverty
# mii_cat
# miilabel
# gor
# decidedVote
# education
# mii_cat
# ns_sec_analytic
# successReduceInequalityLD
# postalapply
# subjectHE
# mii_cat
# profile_religion
# miilabel
# mii_cat
# changeCrime
# achieveReduceImmigDK
# relationshipName
# profile_religion
# fatherCountryBorn
# polKnowMerkel
# profile_newspaper
# profile_newspaper
# profile_religion
# mii_cat
# gor
# mii_cat
# preschoolKidsInHouse
# education
# pidRuinDay
# education
# euID
# ldUnited
# small_mii_cat
# polKnowKerry
# redistLD
# certaintyEUGreen
# miilabel
# mapdefined
# spendMost
# partyContactCon
# miilabel
# mii_cat
# bestOnMII
# achieveReduceImmigLD
# small_mii_cat
# labNone
# euID
# mii_cat
# mii_cat
# profile_ethnicity
# small_mii_cat
# workingStatus
# gor
# profile_work_stat
# profile_religion
# miilabel
# euRefTurnoutRetro
# certaintyUKLeave
# mii_cat
# voteMethoda
# small_mii_cat
# mii_cat
# mii_cat
# polKnowAssad
# profile_work_stat
# education
# mii_cat
# partyId
# miilabel
# profile_religion
# gor
# mii_cat
# profile_religion_denom
# profile_religion
# small_mii_cat
# worstLeaderCampaign
# responsibleEducationLab
# bestOnMII
# mii_cat
# mii_cat
# education
# polKnowPutin
# euSources_99
# lrCorbyn
# motherCountryBorn
# mii_cat
# profile_socgrade
# likeBlair
# profile_past_vote
# labAngry
# polKnowNetanyahu
# everUnionMember
# fatherCountryBorn
# mii_cat
# mii_cat
# education
# EUMIICategory
# generalElectionVote
# bestLeaderCampaign
# ns_sec_analytic
# polKnowOsborne
# immigGreen
# profile_religion
# profile_newspaper
# EUMIICategory
# gor
# generalElectionVote
# small_mii_cat
# motherCountryBorn
# profile_gross_household
# profile_religion
# generalElectionVote
# labNone
# achieveReduceImmigLab
# preschoolKidsInHouse
# mii_cat
# profile_past_vote
# ldTone
# partyId
# ns_sec
# mii_cat
# small_mii_cat
# voteMethod
# responsibleImmigConservatives
# miilabel
# discussantturnoutName
# majorityPartyLab
# mii_cat
# profile_past_vote
# riskPoverty
# mii_cat
# bestOnMII
# mii_cat
# relationshipName
# riskPoverty
# knowf
# localEcon
# headHouseholdPast
# conPartnerLD
# mii_cat
# profile_newspaper
# noDependentsInHouse
# education
# profile_work_type
# polKnowHollande
# selfOccSuperviseLast
# noChanceCoalitionLab
# euRefTurnoutRetro
# responsibleNHSLabour
# euRefTurnout
# EUIntegrationGreen
# likeClegg
# tolUncertain
# mii_cat
# newspaper
# profile_work_stat
# howDidYouFillRegForm
# regretsIHaveAFew
# mii_cat
# responsibleNHSNone
# mii_cat
# mii_cat
# gor
# responsibleCrimeLabour
# profile_religion
# profile_religion
# small_mii_cat
# gor
# bestOnMII
# profile_newspaper
# localElectionVote
# ldTone
# gor
# mii_cat
# achieveReduceImmigLab
# ns_sec_analytic
# miilabel
# homeAmtb
# workingStatus
# profile_house_tenure
# ns_sec
# winConstituencyLD
# mii_cat
# ns_sec
# miilabel
# mapWhite
# mii_cat
# profile_work_type
# mii_cat
# responsibleImmigConservatives
# voteMethodEurope
# EUMIICategory
# mii_cat
# trustMPs
# mapLiveWork
# localElectionVote
# noDependentsInHouse
# miilabel
# small_mii_cat
# certaintyEULab
# mii_cat
# profile_gross_household
# bestOnMII
# profile_religion
# small_mii_cat
# sharedContentOnline
# mii_cat
# small_mii_cat
# LRAL_mii_cat
# education
# headHouseholdPast
# euMIISmall
# discussantVoteName
# profile_house_tenure
# ns_sec
# riskPoverty
# singlePartyEffective
# mii_cat
# registered
# miilabel
# gor
# ns_sec
# nan
# bestOnMII
# mii_cat
# euMIISmall
# mii_cat
# mii_cat
# gor
# mii_cat
# miilabel
# small_mii_cat
# partyId
# polKnowAssad
# education
# efficacyPolCare
# small_mii_cat
# mii_cat
# marital
# polKnowMerkel
# miilabel
# EUIntegrationLD
# likeClegg
# preschoolKidsInHouse
# small_mii_cat
# profile_newspaper
# profile_religion_denom
# polKnowPutin
# creditLeave
# profile_gross_household
# localElectionVote
# socialDes_none
# tripleLock
# polKnowKerry
# mii_cat
# polPreferToFight
# mii_cat
# gor
# miilabel
# mii_cat
# polKnowOsborne
# mii_cat
# mii_cat
# registered
# achieveReduceImmigGrn
# mii_cat
# polKnowBercow
# countryOfBirth
# profile_past_vote
# workingStatus
# englandGovern
# small_mii_cat
# achieveReduceImmigGrn
# profile_newspaper
# euMIISmall
# miilabel
# mii_cat
# redistLab
# LRAL_mii_cat
# small_mii_cat
# gor
# profile_newspaper
# polKnowMay
# socialDes_dk
# ns_sec
# gor
# profile_past_vote
# labAngry
# profile_newspaper
# profile_newspaper
# mii_cat
# registered
# mii_cat
# miilabel
# education
# EUMIICategory
# gor
# profile_ethnicity
# redistLab
# EUMIICategory
# likeClegg
# mii_cat
# profile_religion
# singlePartyEffective
# miilabel
# gor
# miilabel
# mii_cat
# labUnited
# fatherCountryBorn
# EUMIICategory
# euKnow
# mii_cat
# euroElectionVote
# profile_religion
# mainSourceIncome
# ldUnited
# miilabel
# euRefTurnoutRetro
# belongGroup
# labUnited
# mii_cat
# efficacyPolCare
# disability
# gor
# responsibleEconConservatives
# profile_newspaper
# schoolKidsInHouse
# responsibleImmigDontKnow
# gor
# mii_cat
# mii_cat
# small_mii_cat
# education
# mii_cat
# mii_cat
# gor
# certaintyScotUnion
# profile_religion
# partyId
# gor
# bestOnMII
# polKnowAssad
# noChanceCoalitionLD
# labUnited
# otherCitizen
# mii_cat
# generalElectionVote
# gor
# mii_cat
# bestOnMII
# achieveReduceImmigLab
# ns_sec
# education
# polKnowMerkel
# mii_cat
# euKnow
# profile_work_type
# knowMP
# fbUse
# miilabel
# gor
# knowMP
# miilabel
# profile_religion
# gor
# allSourceIncome
# small_mii_cat
# mii_cat
# gor
# polKnowHollande
# partyId
# miilabel
# polKnowMay
# worstLeaderCampaign
# knowMP
# infoSourcePaper
# voteMethod
# trustYourMP
# ns_sec
# profile_religion
# bestOnMII
# polKnowAssad
# miilabel
# housing
# profile_newspaper
# fbUse
# mii_cat
# euRefFinal
# education
# small_mii_cat
# responsibleEducationLab
# mii_cat
# howDidYouFillRegForm
# polKnowMerkel
# miilabel
# homeOwn
# mii_cat
# achieveReduceImmigGrn
# belongGroup
# profile_household_size
# belongGroup
# ns_sec
# otherCitizen
# polKnowMiliband
# ldPride
# responsibleNHSNone
# likeAlanJohnson
# knowMP
# education
# miilabel
# profile_turnout
# knowMP
# polKnowBercow
# responsibleEconLabour
# bestOnMII
# polKnowMerkel
# mii_cat
# mii_cat
# infoSourceTV
# mainSourceIncome
# miilabel
# education
# polKnowPutin
# education
# gor
# allSourceIncome
# profile_religion
# newspaper
# ns_sec_analytic
# mii_cat
# mii_cat
# voteMethod
# mii_cat
# achieveReduceImmigGrn
# ns_sec_analytic
# socialDes
# mii_cat
# gor
# ashcroft
# EUIntegrationLD
# mii_cat
# allSourceIncome_99
# labUnited
# gor
# sharedContentOnline
# mii_cat
# bestOnMII
# mii_cat
# profile_newspaper
# mii_cat
# ns_sec
# mii_cat
# small_mii_cat
# polKnowNetanyahu
# bestOnMII
# participation
# mainSourceIncome
# miilabel
# mii_cat
# miilabel
# savings
# mii_cat
# ns_sec
# achieveReduceImmigLab
# responsibleImmigDontKnow
# winConstituencyLD
# polKnowOsborne
# riskTaking
# mii_cat
# miilabel
# worstLeaderCampaign
# profile_work_type
# howDidYouFillRegForm
# homeOwn
# gor
# headHouseholdPast
# responsibleCrimeLibDems
# education
# bestOnMII
# education
# LRAL_mii_cat
# knowMP
# voteMakesDifference
# responsibleCrimeLabour
# profile_newspaper
# gor
# polKnowHollande
# responsibleImmigConservatives
# profile_religion
# gor
# gor
# mii_cat
# LRAL_mii_cat
# polKnowClegg
# howDidYouFillRegForm
# mii_cat
# ns_sec
# responsibleEconConservatives
# miilabel
# profile_work_stat
# mii_cat
# gor
# bestOnMII
# small_mii_cat
# miilabel
# gor
# polKnowKerry
# ldHope
# education
# ns_sec_analytic
# generalElectionCertainty
# mii_cat
# locus
# mii_cat
# gor
# marital
# noChanceCoalitionCon
# mii_cat
# polKnowAssad
# ns_sec
# polKnowMay
# mii_cat
# fatherCountryBorn
# decidedVote
# education
# gor
# partyId
# profile_gross_household
# gor
# polKnowAssad
# profile_gross_household
# infoSourceTV
# mii_cat
# mii_cat
# mii_cat
# small_mii_cat
# mii_cat
# profile_newspaper
# small_mii_cat
# education
# partyId
# ns_sec
# mii_cat
# mii_cat
# ns_sec
# profile_work_stat
# mii_cat
# coalitionInTune
# mii_cat
# mii_cat
# education
# mii_cat
# workingStatus
# partyId
# achieveReduceImmigDK
# voteMethod_99
# polKnowPutin
# ns_sec
# profile_ethnicity
# schoolKidsInHouse
# howDidYouFillRegForm
# mii_cat
# passportExpired
# generalElectionVote
# registered
# profile_house_tenure
# profile_religion
# subjClass
# genElecTurnoutRetro
# gor
# mii_cat
# workingStatus
# partyId
# profile_religion
# mii_cat
# workingStatus
# mii_cat
# profile_past_vote
# beliefTradeoff
# profile_religion
# profile_work_type
# ns_sec_analytic
# small_mii_cat
# mii_cat
# coalitionInTune
# subjClass
# mii_cat
# profile_marital_stat
# workingStatus
# profile_religion
# polKnowBercow
# gor
# gor
# profile_newspaper
# education
# gor
# education
# polKnowPutin
# gor
# profile_house_tenure
# socialDes
# education
# subjClass
# mii_cat
# riskTaking
# polKnowMiliband
# registered
# polKnowOsborne
# profile_past_vote
# profile_house_tenure
# polKnowMiliband
# polKnowClegg
# workingStatus
# ns_sec
# ns_sec
# gender
# polKnowMerkel
# polKnowPutin
# education
# profile_household_size
# profile_ethnicity
# profile_newspaper
# gor
# profile_ethnicity
# gor
# profile_house_tenure

# %%
import six
def render_mpl_table(data, col_width=3.0, row_height=0.325, font_size=14,
                     header_color='#40466e', row_colors=['#f1f1f2', 'w'], edge_color='w',
                     bbox=[0, 0, 1, 1], header_columns=0,
                     ax=None, **kwargs):
    if ax is None:
        size = (np.array(data.shape[::-1]) + np.array([0, 1])) * np.array([col_width, row_height])
        fig, ax = plt.subplots(figsize=size)
        ax.axis('off')

    mpl_table = ax.table(cellText=data.values, bbox=bbox, colLabels=data.columns, **kwargs)

    mpl_table.auto_set_font_size(False)
    mpl_table.set_fontsize(font_size)

    for k, cell in six.iteritems(mpl_table._cells):
        cell.set_edgecolor(edge_color)
        if k[0] == 0 or k[1] < header_columns:
            cell.set_text_props(weight='bold', color='w')
            cell.set_facecolor(header_color)
        else:
            cell.set_facecolor(row_colors[k[0]%len(row_colors) ])
    return ax

render_mpl_table(df1, header_columns=0, col_width=2.0);

# %%
df["p-value"].hist(bins=100)
df["sample size"].hist(bins=100)

# %%
df1["blackEquality2W14__Gone much too far"][enviroProtection_hardcore.notnull()].var()
# enviroProtection_hardcore[df1["blackEquality2W14__Gone much too far"].notnull()].var()
# Out:
# 1.1621054410934448

# %%
pd.crosstab(index = climateChange, columns = enviroGrowth, normalize='index', margins=True).round(2)
# Out:
# enviroGrowthW4&7                                Economic growth should have priority  \
# climateChangeW7&10&11
# Climate changing due to human activity                                          0.03
# Climate changing but not due to human activity                                  0.14
# Climate not changing                                                            0.20
# Don't know                                                                      0.05
# All                                                                             0.06
#
# enviroGrowthW4&7                                   1     2     3     4     5  \
# climateChangeW7&10&11
# Climate changing due to human activity          0.02  0.05  0.07  0.09  0.20
# Climate changing but not due to human activity  0.08  0.12  0.12  0.09  0.19
# Climate not changing                            0.10  0.13  0.11  0.07  0.15
# Don't know                                      0.04  0.07  0.09  0.06  0.19
# All                                             0.04  0.07  0.09  0.08  0.20
#
# enviroGrowthW4&7                                   6     7     8     9  \
# climateChangeW7&10&11
# Climate changing due to human activity          0.12  0.12  0.10  0.04
# Climate changing but not due to human activity  0.07  0.06  0.04  0.01
# Climate not changing                            0.04  0.04  0.03  0.02
# Don't know                                      0.06  0.05  0.03  0.01
# All                                             0.10  0.09  0.08  0.03
#
# enviroGrowthW4&7                                Protecting the environment should have priority  \
# climateChangeW7&10&11
# Climate changing due to human activity                                                     0.09
# Climate changing but not due to human activity                                             0.02
# Climate not changing                                                                       0.02
# Don't know                                                                                 0.02
# All                                                                                        0.07
#
# enviroGrowthW4&7                                Don't know
# climateChangeW7&10&11
# Climate changing due to human activity                0.07
# Climate changing but not due to human activity        0.05
# Climate not changing                                  0.08
# Don't know                                            0.33
# All                                                   0.10

# %%
## immigSelf distribution by Leave/Remain

# %%
[x for x in BES_reduced_with_na.columns if re.match("immigSelf", x)]
# Out:
# ['immigSelfW7__Allow many more',
#  'immigSelfW8__Allow many more',
#  'immigSelfW9__Allow many more',
#  'immigSelfW10__Allow many more',
#  'immigSelfW11__Allow many more',
#  'immigSelfW12__Allow many more',
#  'immigSelfW14__Allow many more']

# %%
Leavers = BES_Panel["profile_eurefvote"] =="Leave the EU"
Remainers = BES_Panel["profile_eurefvote"] =="Stay/remain in the EU"

# %%
amalg_imm = amalgamate_waves(BES_reduced_with_na,"immigSelf",forward_fill=False)
euref_imm = amalgamate_waves(BES_reduced_with_na,"euRefVoteW",forward_fill=False)

# %%
amalg_imm.notnull().sum(),euref_imm.notnull().sum()
# Out:
# (56639, 69801)

# %%
prof_euref_imm = (BES_Panel["profile_eurefvote"]=="Leave the EU")
prof_euref_imm[BES_Panel["profile_eurefvote"]=="Don't know"] = np.nan

# %%
amalg_imm[euref_imm.notnull()].notnull().sum(), amalg_imm[prof_euref_imm.notnull()].notnull().sum()
# Out:
# (55233, 56296)

# %%
output_subfolder = BES_output_folder + os.sep + "Immigration_sentiment_by_euref" + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

Leave_imm =  amalg_imm[prof_euref_imm==1]
Remainer_imm = amalg_imm[prof_euref_imm==0]

sns.kdeplot(Leave_imm,     label="Leavers", bw=.5, ax = axes);#, cut=1);
sns.kdeplot(Remainer_imm,  label="Remainers", bw=.5, ax = axes);#, cut=1);

# ax.set_ylim([0,.2])
axes.set_xlim([0,10]);
axes.set_xticks(list(range(0,11)))
axes.set_xticklabels(BES_Panel["immigSelfW14"].cat.categories[0:11]);
axes.set_xlabel("Some people think that the UK should allow *many more* immigrants to come to the UK to live"+\
                "and others think that the UK should allow *many fewer* immigrants."+\
                "\nWhere would you place yourself and the parties on this scale?");

fname = output_subfolder + "Immigration_sentiment_by_euref" + ".png"
plt.savefig( fname, bbox_inches='tight' )
# Out:
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

Leave_imm =  amalg_imm[euref_imm==1]
Remainer_imm = amalg_imm[euref_imm==0]

sns.kdeplot(Leave_imm,     label="Leavers", bw=.5, ax = axes);#, cut=1);
sns.kdeplot(Remainer_imm,  label="Remainers", bw=.5, ax = axes);#, cut=1);

# ax.set_ylim([0,.2])
axes.set_xlim([0,10]);
axes.set_xticks(list(range(0,11)))
axes.set_xticklabels(BES_Panel["immigSelfW14"].cat.categories[0:11]);
axes.set_xlabel("Some people think that the UK should allow *many more* immigrants to come to the UK to live"+\
                "and others think that the UK should allow *many fewer* immigrants."+\
                "\nWhere would you place yourself and the parties on this scale?");

# fname = output_subfolder + "Immigration_sentiment_by_euref" + ".png"
# plt.savefig( fname, bbox_inches='tight' )

# %%
Leavers   = (BES_Panel['profile_eurefvote'] == "Leave the EU")
Remainers = (BES_Panel['profile_eurefvote'] == "Stay/remain in the EU")
amalgamated_euMIISmall = amalgamate_waves(BES_Panel, 'euMIISmallW', forward_fill=True)

# %%
SovOrImmLeavers = Leavers&amalgamated_euMIISmall.notnull()

Sov = amalgamated_euMIISmall[SovOrImmLeavers]
BES_sov = BES_reduced[SovOrImmLeavers]
drop_vars = [x for x in BES_reduced.columns if ("euRefVote" in x) or ("profile_eurefvote" in x)\
             or ("euMII" in x) or ("EUMII" in x)]
BES_sov = BES_sov.drop(drop_vars , axis=1)

# %%
sovereignty = "Sovereignty/EU bureaucracy"
immigration = "Immigration"
Sov = (amalgamated_euMIISmall==sovereignty)
Imm = (amalgamated_euMIISmall==immigration)
Oth = amalgamated_euMIISmall.notnull() & ~Imm & ~Sov

# %%
Sov[Leavers].sum(), Imm[Leavers].sum(), Oth[Leavers].sum()
# Out:
# (3933, 3391, 4088)

# %%
economy = "Economy"
cosmopolitanism = "Cosmopolitanism"
Eco = (amalgamated_euMIISmall==sovereignty)
Cos = (amalgamated_euMIISmall==immigration)

# %%
amalgamated_euMIISmall[Remainers].value_counts()
# Out:
# Economy                                   3717
# Cosmopolitanism                           1190
# Foreign policy                             992
# Protection of rights                       899
# No content to reason                       882
# Campaign/outcome fairness                  778
# Other                                      606
# Immigration                                495
# Other stability or uncertainty concern     449
# Sovereignty/EU bureaucracy                 410
# Social identity/partisanship               330
# Family                                     202
# EU spending/regulations/cost               197
# EU integration/stability                    64
# British/english identity                    34
# Name: euMIISmallW8, dtype: int64

# %%
# cat_col_mar_dict = {} # category-colour-marker dictionary

# colours = cycle('ycmkgbr')
# markers = cycle('v^<>,oD*x+')

def make_categorical_density_plot():
    fig, axes = plt.subplots(1, 1, figsize=(16,10))    
    sov_vars = (BES_reduced_with_na[[x for x in BES_reduced_with_na.columns if re.match(cat_var+"_", x)]][mask&amalg_imm.notnull()]==1)\
                .sum().sort_values(ascending=False)
    sov_vars = sov_vars.drop(sov_vars[sov_vars<min_sample].index)
    if len(sov_vars.index)==0:
        return
    
    for sov in sov_vars.index:
#         if sov not in cat_col_mar_dict.keys(): # try to give mii consistent colour, marker pairs
#             cat_col_mar_dict[sov] = (next(colours),next(markers))        
        sov_imm = amalg_imm[(BES_reduced_with_na[sov]==1.0)&mask]
        base_label = sov.split("_")[-1]

        (col, mar) = get_cat_col_mar(base_label)
        label = base_label +"(N="+str(sov_vars.loc[sov])+")"
        sns.kdeplot(sov_imm,
                    label=label,
                    bw=.5,
                    ax = axes,
                    color = col,
                    marker = mar,
                    alpha = .75);

    sns.kdeplot(amalg_imm,
                label="Everyone-Leaver/Remainer/Neither"+"(N="+str(amalg_imm.notnull().sum())+")",
                bw=.5,
                ax = axes,
                color = 'k',
                linewidth=7.0,
                alpha = .75);       

    # axes.set_ylim([0,.6])
    axes.set_xlim([0,10]);
    axes.set_xticks(list(range(0,11)))
    axes.set_xticklabels(BES_Panel["immigSelfW14"].cat.categories[0:11]);
    axes.set_xlabel("Some people think that the UK should allow *many more* immigrants to come to the UK to live"+\
                    "and others think that the UK should allow *many fewer* immigrants."+\
                    "\nWhere would you place yourself and the parties on this scale?");
    plt.legend(loc='upper right',title=cat_var);
    wave_descr = BES_file_manifest[ (BES_file_manifest["Only_or_Combined"]=="Only")\
                     & (BES_file_manifest["Wave No"]==wave) ]["Friendlier_Description"].values[0]    
    plt.title(question+"\n"\
             +wave_descr\
             +"\n"+subtitle);

    fname = cat_var + "_" + subtitle + ".png"
    plt.savefig( output_subfolder + clean_filename(fname), bbox_inches='tight' )
#     plt.close()

# %%
Treatment = "Sovereignty_vs_Immigration"
base_folder = create_subdir(BES_output_folder, Treatment)

sub_treatment = "category_by_immigself"
output_subfolder = create_subdir(base_folder, sub_treatment)

# %%
# get_cat_col_mar('immigration')

# %%
amalg_imm = amalgamate_waves(BES_reduced_with_na,"immigSelf",forward_fill=False)
masks = {"Leavers":"Leave the EU","Remainers":"Stay/remain in the EU","Don't know":"Don't know"}
# cat_vars = ["euMIISmallW7","euMIISmallW8","EUMIICategoryW7","EUMIICategoryW8"]
# cat_vars = sorted(list(set(["_".join(x.split("_")[:-1]) for x in BES_reduced_with_na.columns if re.match("bestOnMII|miilabel|small_mii_cat|mii_cat|LRAL_mii_cat|EUMIICategory|euMIISmall",x) ])))
cat_vars = sorted(list(set(["_".join(x.split("_")[:-1]) for x in BES_reduced_with_na.columns if re.match("EUMIICategory",x) ])))
min_sample = 100

for cat_var in cat_vars:
    question = "What matters most to you when deciding how to vote in the EU referendum?"
    wave = int(re.search("W(\d+)",cat_var).groups()[0])
    for subtitle,mask_cat in masks.items():
        print(cat_var,subtitle)
        if ("euRefVoteW"+str(wave)) not in BES_Panel.columns:
            mask = (BES_Panel["profile_eurefvote"]==mask_cat)
        else:
            mask = (BES_Panel["euRefVoteW"+str(wave)]==mask_cat)

        make_categorical_density_plot()
# Out:
# EUMIICategoryW7 Leavers
# EUMIICategoryW7 Remainers
# EUMIICategoryW7 Don't know
# EUMIICategoryW8 Leavers
# EUMIICategoryW8 Remainers
# EUMIICategoryW8 Don't know

# %%
lst = ['LRAL_mii_catW1',
 'LRAL_mii_catW10',
 'LRAL_mii_catW11',
 'LRAL_mii_catW12',
 'LRAL_mii_catW13',
 'LRAL_mii_catW2',
 'LRAL_mii_catW3',
 'LRAL_mii_catW4',
 'LRAL_mii_catW5',
 'LRAL_mii_catW6',
 'LRAL_mii_catW7',
 'LRAL_mii_catW8',
 'LRAL_mii_catW9']
sort_by_wave(lst)
# Out:
# ['LRAL_mii_catW1',
#  'LRAL_mii_catW2',
#  'LRAL_mii_catW3',
#  'LRAL_mii_catW4',
#  'LRAL_mii_catW5',
#  'LRAL_mii_catW6',
#  'LRAL_mii_catW7',
#  'LRAL_mii_catW8',
#  'LRAL_mii_catW9',
#  'LRAL_mii_catW10',
#  'LRAL_mii_catW11',
#  'LRAL_mii_catW12',
#  'LRAL_mii_catW13']

# %%
sorted(list(set(["_".join(x.split("_")[:-1]) for x in BES_reduced_with_na.columns if re.match("bestOnMII|miilabel|small_mii_cat|mii_cat|LRAL_mii_cat|EUMIICategory|euMIISmall",x) ])))
# Out:
# ['EUMIICategoryW7',
#  'EUMIICategoryW8',
#  'LRAL_mii_catW1',
#  'LRAL_mii_catW10',
#  'LRAL_mii_catW11',
#  'LRAL_mii_catW12',
#  'LRAL_mii_catW13',
#  'LRAL_mii_catW2',
#  'LRAL_mii_catW3',
#  'LRAL_mii_catW4',
#  'LRAL_mii_catW5',
#  'LRAL_mii_catW6',
#  'LRAL_mii_catW7',
#  'LRAL_mii_catW8',
#  'LRAL_mii_catW9',
#  'bestOnMIIW1',
#  'bestOnMIIW10',
#  'bestOnMIIW11',
#  'bestOnMIIW12',
#  'bestOnMIIW13',
#  'bestOnMIIW14',
#  'bestOnMIIW2',
#  'bestOnMIIW3',
#  'bestOnMIIW4',
#  'bestOnMIIW5',
#  'bestOnMIIW6',
#  'bestOnMIIW7',
#  'bestOnMIIW8',
#  'bestOnMIIW9',
#  'euMIISmallW7',
#  'euMIISmallW8',
#  'mii_catW1',
#  'mii_catW10',
#  'mii_catW11',
#  'mii_catW12',
#  'mii_catW13',
#  'mii_catW2',
#  'mii_catW3',
#  'mii_catW4',
#  'mii_catW5',
#  'mii_catW6',
#  'mii_catW7',
#  'mii_catW8',
#  'mii_catW9',
#  'miilabelW1',
#  'miilabelW2',
#  'miilabelW3',
#  'miilabelW4',
#  'miilabelW5',
#  'miilabelW6',
#  'small_mii_catW1',
#  'small_mii_catW10',
#  'small_mii_catW11',
#  'small_mii_catW12',
#  'small_mii_catW13',
#  'small_mii_catW2',
#  'small_mii_catW3',
#  'small_mii_catW4',
#  'small_mii_catW5',
#  'small_mii_catW6',
#  'small_mii_catW7',
#  'small_mii_catW8',
#  'small_mii_catW9']

# %%
list(set([x.split("W")[0] for x in BES_reduced_with_na.columns if "mii" in x.lower()]))
# Out:
# ['handleMIILD',
#  'handleMIILab',
#  'EUMIICategory',
#  'bestOnMII',
#  'handleMIIGrn',
#  'handleMIICon',
#  'miilabel',
#  'small_mii_cat',
#  'LRAL_mii_cat',
#  'euMIISmall',
#  'mii_cat',
#  'handleMIIUKIP']

# %%
sov_cols = [x for x in BES_reduced_with_na.columns if "sov" in x.lower()]
BES_reduced_with_na[sov_cols].notnull().sum()
# Out:
# UKsovereigntyW7__Strongly agree            28353
# UKsovereigntyW8__Strongly agree            31153
# UKsovereigntyPostW10__Strongly agree       26292
# UKsovereigntyPostW11__Strongly agree       27411
# UKsovereigntyPostW13__Strongly agree       27330
# UKsovereigntyPostW14__Strongly agree       26960
# EUMIICategoryW7_sovereignty                22599
# euMIISmallW7_Sovereignty/EU bureaucracy    21657
# EUMIICategoryW8_sovereignty                16181
# euMIISmallW8_Sovereignty/EU bureaucracy    15413
# dtype: int64

# %%
sov_corr = BES_reduced_with_na[Leavers].corrwith(BES_reduced_with_na["EUMIICategoryW7_sovereignty"][Leavers])
sov_corr.dropna().sort_values()
# Out:
# euMIISmallW7_Immigration                                        -0.350165
# EUMIICategoryW7_immigration                                     -0.334493
# scotIndepJoinEUW1__Very likely                                  -0.206965
# scotIndepJoinEUW2__Very likely                                  -0.178561
# cooperateRUKGBPW2__Very likely                                  -0.175416
# EUMIICategoryW7_democratic deficit                              -0.173026
# euMIISmallW7_Campaign/outcome fairness                          -0.171961
# euScepticismW7__Work towards single European government         -0.166412
# cooperateRUKGBPW1__Very likely                                  -0.161390
# polKnowHollandeW10_Prime Minister of Israel                     -0.160128
# euMIISmallW7_Economy                                            -0.159556
# euMIISmallW8_Immigration                                        -0.154674
# snpLookAfterMCW12__Very closely                                 -0.152811
# polKnowKerryW10_Secretary General of the United Nations         -0.152721
# happyScotIndepResultW1__Extremely happy                         -0.152528
# EUMIICategoryW7_truth                                           -0.150328
# lrSNPW4__Right                                                  -0.147274
# pocketBookAccurateDV2W1__Should definitely become independent   -0.147169
# lrSNPW5__Right                                                  -0.147008
# scotDevoMaxW7__It should have many more powers                  -0.145936
# likeSturgeonW9__Strongly like                                   -0.145202
# EUMIICategoryW8_immigration                                     -0.144396
# snpGovTrustW5__ Would do a good job                             -0.141427
# euMIISmallW7_No content to reason                               -0.139244
# likeSturgeonW8__Strongly like                                   -0.138433
# scotElectionVoteListW8_Scottish National Party (SNP)            -0.137989
# likeSturgeonW7__Strongly like                                   -0.137147
# scotDevoMaxW6__It should have many more powers                  -0.137131
# scotDevoMaxW3__It should have many more powers                  -0.135013
# likeSNPW8__Strongly like                                        -0.134750
#                                                                    ...
# conHopeW14_Yes                                                   0.131536
# scotElectionVoteConstW8_Scottish Conservative                    0.132417
# scotElectionVoteConstW2_Scottish Conservative                    0.132763
# devoResponsibleScotTaxW6_The UK Parliament                       0.134936
# devoResponsibleScotDefenceW3_The UK Parliament                   0.135539
# lr_scaleW6__Right                                                0.137634
# scotElectionVoteListW8_Scottish Conservative                     0.137698
# scotIndepVoiceW1__Very likely                                    0.137820
# likeGoveW7__Strongly like                                        0.140719
# likeGoveW8__Strongly like                                        0.143616
# UKsovereigntyW7__Strongly agree                                  0.144699
# scotElectionVoteConstW7_Scottish Conservative                    0.145534
# partyContactVoteLeaveW8_Yes                                      0.146124
# EUIntegrationSelfW7__Protect our independence                    0.148083
# scotElectionVoteConstW1_Scottish Conservative                    0.149318
# devoResponsibleScotWelfareW6_The UK Parliament                   0.152413
# snpAngryW6_Yes                                                   0.154168
# scotElectionVoteListW6_Scottish Conservative                     0.154343
# scotElectionVoteConstW3_Scottish Conservative                    0.154390
# scotElectionVoteConstW6_Scottish Conservative                    0.162124
# polKnowAssadW10_President of Syria                               0.163967
# scotElectionVoteListW3_Scottish Conservative                     0.170848
# scotElectionVoteConstW4_Scottish Conservative                    0.171832
# polKnowNetanyahuW10_Prime Minister of Israel                     0.183804
# polKnowKerryW10_United States Secretary of State                 0.190085
# polKnowHollandeW10_Prime Minister of Canada                      0.280692
# euMIISmallW8_Sovereignty/EU bureaucracy                          0.290195
# EUMIICategoryW8_sovereignty                                      0.324761
# euMIISmallW7_Sovereignty/EU bureaucracy                          0.770742
# EUMIICategoryW7_sovereignty                                      1.000000
# Length: 6783, dtype: float64

# %%
sov_corr[sov_corr.abs()>=.6].dropna().sort_index()
# Out:
# EUIntegrationSelfW10__Protect our independence                  0.655420
# EUIntegrationSelfW11__Protect our independence                  0.660549
# EUIntegrationSelfW12__Protect our independence                  0.668960
# EUIntegrationSelfW13__Protect our independence                  0.653175
# EUIntegrationSelfW14__Protect our independence                  0.637818
# EUIntegrationSelfW1__Protect our independence                   0.618248
# EUIntegrationSelfW3__Protect our independence                   0.644982
# EUIntegrationSelfW4__Protect our independence                   0.632688
# EUIntegrationSelfW6__Protect our independence                   0.629332
# EUIntegrationSelfW7__Protect our independence                   0.687578
# EUIntegrationSelfW8__Protect our independence                   0.671564
# EUIntegrationSelfW9__Protect our independence                   0.654135
# UKsovereigntyW7__Strongly agree                                 1.000000
# UKsovereigntyW8__Strongly agree                                 0.740863
# approveEUW2_Disapprove                                          0.614589
# approveEUW7__Strongly approve                                  -0.660900
# approveEUW9__Strongly approve                                  -0.647656
# echrW7__Strongly agree                                         -0.603572
# echrW8__Strongly agree                                         -0.616845
# eesEUIntegrationSelfW1__Unification should be pushed further   -0.614026
# eesEUIntegrationSelfW3__Unification should be pushed further   -0.633770
# eesEUIntegrationSelfW4__Unification should be pushed further   -0.616128
# eesEUIntegrationSelfW6__Unification should be pushed further   -0.622197
# efficacyNoMatterW8__Strongly agree                             -0.777778
# efficacyNotUnderstandW8__Strongly agree                         0.816497
# efficacyTooMuchEffortW8__Strongly agree                         0.838870
# euExpRefW7_To leave the European Union                          0.654665
# euIDW11_The leave side                                          0.613532
# euIDW12_The leave side                                          0.614126
# euIDW13_The leave side                                          0.607987
#                                                                   ...
# euIDW9_The leave side                                           0.610271
# euLawsLevelW7__Strongly agree                                  -0.616762
# euLawsLevelW8__Strongly agree                                  -0.617414
# euParlOverRideW7__Strongly agree                                0.669231
# euParlOverRideW8__Strongly agree                                0.653538
# euRedTapeW7__Strongly agree                                     0.651962
# euRedTapeW8__Strongly agree                                     0.625719
# euRefVote2W8_Leave the EU                                       0.620469
# euRefVoteUnsqueezeW7_Leave the EU                               0.652274
# euRefVoteUnsqueezeW8_Leave the EU                               0.636587
# euRefVoteW11_Leave the EU                                       0.603055
# euRefVoteW12_Leave the EU                                       0.610112
# euRefVoteW1_Leave the EU                                        0.604333
# euRefVoteW2_Leave the EU                                        0.614717
# euRefVoteW3_Leave the EU                                        0.610472
# euRefVoteW7_Leave the EU                                        0.633621
# euRefVoteW8_Leave the EU                                        0.617864
# euRefVoteW9_Leave the EU                                        0.600049
# euRefpastVoteW11_Leave the EU                                   0.601385
# euRefpastVoteW12_Leave the EU                                   0.604879
# euRefpastVoteW13_Leave the EU                                   0.601947
# euScepticismW7__Work towards single European government        -0.631470
# euUndermineIdentityW7__Strongly agree                           0.695269
# euUndermineIdentityW8__Strongly agree                           0.673194
# happyEULeaveW10__Extremely happy                                0.618346
# happyEULeaveW11__Extremely happy                                0.635543
# happyEULeaveW14__Extremely happy                                0.621810
# happyEULeaveW9__Extremely happy                                 0.615372
# happyLeaveW7__Very happy                                        0.636852
# ptvConW8__Very likely                                           0.777778
# Length: 62, dtype: float64

# %%
sov_corr = BES_reduced_with_na[Remainers].corrwith(BES_reduced_with_na["euMIISmallW7_Protection of rights"][Remainers])
sov_corr.dropna().sort_values()
# Out:
# polKnowAssadW10_President of Syria              -0.485071
# effectsEUWorkersW7__Much better                 -0.254117
# leftRightW11__Right                             -0.250966
# govtHandleEconW1__Very well                     -0.247156
# happyScotIndepResultNoW2__Extremely happy       -0.245585
# approveUKGovtW7__Strongly approve               -0.245244
# leftRightW13__Right                             -0.244588
# approveUKGovtW10__Strongly approve              -0.243639
# approveUKGovtW11__Strongly approve              -0.243500
# leftRightW7__Right                              -0.242571
# leftRightW10__Right                             -0.241563
# leftRightW14__Right                             -0.240772
# likeConW10__Strongly like                       -0.240174
# likeMayW11__Strongly like                       -0.240066
# leftRightW9__Right                              -0.239517
# approveUKGovtW3__Strongly approve               -0.239454
# approveUKGovtW2__Strongly approve               -0.239351
# leftRightW12__Right                             -0.238494
# conGovTrustW5__ Would do a good job             -0.237861
# effectsEUWorkersW8__Much better                 -0.237689
# likeConW11__Strongly like                       -0.236944
# govtHandleEconW7__Very well                     -0.236450
# approveUKGovtW1__Strongly approve               -0.235369
# effectsEUWorkersW14__Much better                -0.235334
# handleMIIConW5__Very well                       -0.234381
# effectsEUWorkersW11__Much better                -0.233278
# likeMayW10__Strongly like                       -0.232808
# likeMayW12__Strongly like                       -0.232604
# leftRightW2__Right                              -0.232342
# handleMIIConW7__Very well                       -0.232080
#                                                    ...
# likeCorbynW11__Strongly like                     0.227654
# dv2w2W2__Should definitely become independent    0.227683
# referendumSettledW4_Yes                          0.229099
# scotReferendumIntentionW6_Will vote 'Yes'        0.229883
# referendumSettledW6_Yes                          0.230120
# scotReferendumIntentionW4_Will vote 'Yes'        0.231273
# likeCorbynW8__Strongly like                      0.231782
# scotReferendumIntentionW7_Will vote 'Yes'        0.232140
# happyScotIndepResultW2__Extremely happy          0.233005
# likeCorbynW7__Strongly like                      0.234655
# scotReferendumIntentionW12_Will vote 'Yes'       0.238908
# welfarePreferenceW7__Much too low                0.242485
# welfarePreferenceW4__Much too low                0.248126
# welfarePreferenceW6__Much too low                0.258845
# welfarePreferenceW3__Much too low                0.259197
# EUMIICategoryW7_environment                      0.263806
# welfarePreferenceW2__Much too low                0.278245
# bestPMW12_Jeremy Corbyn                          0.289525
# bestPMW7_Jeremy Corbyn                           0.293180
# bestPMW8_Jeremy Corbyn                           0.295485
# EUMIICategoryW8_human rights                     0.314748
# EUMIICategoryW8_worker rights                    0.320554
# bestPMW10_Jeremy Corbyn                          0.334103
# bestPMW11_Jeremy Corbyn                          0.336007
# EUMIICategoryW7_equality                         0.412023
# euMIISmallW8_Protection of rights                0.526719
# EUMIICategoryW7_human rights                     0.585317
# EUMIICategoryW7_worker rights                    0.597789
# euMIISmallW7_Protection of rights                1.000000
# polKnowAssadW10_Prime Minister of Italy          1.000000
# Length: 6758, dtype: float64

# %%
sov_corr = BES_reduced_with_na[Remainers].corrwith(BES_reduced_with_na["euMIISmallW7_Cosmopolitanism"][Remainers])
sov_corr.dropna().sort_values()
# Out:
# polKnowNetanyahuW10_Prime Minister of Israel                   -0.323077
# euMIISmallW7_Economy                                           -0.243396
# EUIntegrationSelfW3__Protect our independence                  -0.181924
# EUIntegrationSelfW1__Protect our independence                  -0.180304
# EUIntegrationSelfW7__Protect our independence                  -0.176617
# EUIntegrationSelfW4__Protect our independence                  -0.175497
# approveEUW2_Disapprove                                         -0.168590
# EUIntegrationSelfW2__Protect our independence                  -0.168480
# EUMIICategoryW7_economy general                                -0.163660
# EUIntegrationSelfW8__Protect our independence                  -0.162372
# EUIntegrationSelfW6__Protect our independence                  -0.154300
# EUIntegrationSelfW12__Protect our independence                 -0.151779
# britishnessW12__Very strongly British                          -0.150780
# EUIntegrationSelfW13__Protect our independence                 -0.145060
# EUIntegrationSelfW9__Protect our independence                  -0.144143
# al_scaleW14__Authoritarian                                     -0.143392
# UKsovereigntyW7__Strongly agree                                -0.143173
# EUIntegrationSelfW10__Protect our independence                 -0.141292
# euUndermineIdentityW7__Strongly agree                          -0.139352
# al_scaleW13__Authoritarian                                     -0.138627
# UKsovereigntyW8__Strongly agree                                -0.137354
# euParlOverRideW8__Strongly agree                               -0.135122
# EUIntegrationSelfW11__Protect our independence                 -0.134777
# euParlOverRideW7__Strongly agree                               -0.133648
# al5W6__Strongly agree                                          -0.131881
# EUIntegrationSelfW14__Protect our independence                 -0.131799
# al_scaleW6__Authoritarian                                      -0.130950
# ukCoopMovementW7__Bad for Britain                              -0.130775
# ukCoopEuroW7__Bad for Britain                                  -0.130115
# immigrantsWelfareStateW8__Strongly agree                       -0.128696
#                                                                   ...
# immigSelfW14__Allow many more                                   0.125032
# partyContactLab_7W11_Yes                                        0.125543
# europeannessW11__Very strongly European                         0.126825
# europeannessW10__Very strongly European                         0.128584
# immigSelfW9__Allow many more                                    0.129894
# euLawsLevelW8__Strongly agree                                   0.129915
# euFinancialHelpW7__Strongly agree                               0.131779
# immigSelfW7__Allow many more                                    0.132891
# euLawsLevelW7__Strongly agree                                   0.133477
# labHandleEducW14__Very well                                     0.134366
# euFinancialHelpW2__Strongly agree                               0.136736
# europeannessW9__Very strongly European                          0.137545
# europeannessW8__Very strongly European                          0.141364
# ptvGrnExpW14__Very likely                                       0.142639
# eesEUIntegrationSelfW2__Unification should be pushed further    0.144130
# eesEUIntegrationSelfW1__Unification should be pushed further    0.147049
# euScepticismW7__Work towards single European government         0.151261
# europeannessW7__Very strongly European                          0.155108
# europeannessW12__Very strongly European                         0.160267
# eesEUIntegrationSelfW4__Unification should be pushed further    0.165286
# EUMIICategoryW8_freedom of movement                             0.168997
# eesEUIntegrationSelfW6__Unification should be pushed further    0.170288
# eesEUIntegrationSelfW3__Unification should be pushed further    0.174543
# polKnowNetanyahuW10_Secretary General of the United Nations     0.187253
# EUMIICategoryW8_EU identity/cosmopolitan                        0.233476
# euMIISmallW8_Cosmopolitanism                                    0.302632
# polKnowNetanyahuW10_President of France                         0.425905
# EUMIICategoryW7_freedom of movement                             0.467306
# EUMIICategoryW7_EU identity/cosmopolitan                        0.861237
# euMIISmallW7_Cosmopolitanism                                    1.000000
# Length: 6758, dtype: float64

# %%
[x for x in BES_reduced_with_na.columns if "climate" in x.lower()]
# Out:
# ['climateChangeW7__Climate not changing',
#  'climateChangeW10__Climate not changing',
#  'climateChangeW11__Climate not changing']

# %%
amalg_climate = amalgamate_waves(BES_reduced_with_na,"climateChangeW",forward_fill=False)

# %%
corr_climate = BES_reduced_with_na.corrwith(amalg_climate, drop=True)

# %%
sample_sizes = BES_reduced_with_na[amalg_climate.notnull()].notnull().sum()
sample_sizes.hist(bins=100)

# %%
sample_vars = BES_reduced_with_na[amalg_climate.notnull()].var()
sample_vars[sample_vars<=1].hist(bins=100)

# %%
low_sample_variance = list(sample_vars[sample_vars<0.01].index)

# %%
low_sample_size = list(sample_sizes[sample_sizes<1000].index)

# %%
BES_reduced_with_na.shape
# Out:
# (73703, 6864)

# %%
corr_climate.drop(low_sample_variance+low_sample_size,errors='ignore').sort_values(ascending=False)
# Out:
# climateChangeW7__Climate not changing                              1.000000
# climateChangeW10__Climate not changing                             0.962151
# climateChangeW11__Climate not changing                             0.781685
# enviroProtectionW3__Gone much too far                              0.454197
# enviroProtectionW6__Gone much too far                              0.445071
# enviroProtectionW7__Gone much too far                              0.437493
# enviroProtectionW2__Gone much too far                              0.434092
# enviroProtectionW12__Gone much too far                             0.431481
# enviroProtectionW4__Gone much too far                              0.424973
# enviroProtectionW1__Gone much too far                              0.411995
# enviroProtectionW14__Gone much too far                             0.377303
# happyTrumpW10__Extremely happy                                     0.357372
# likeNuttallW10__Strongly like                                      0.355601
# ptvUKIPW8__Very likely                                             0.354577
# euExpRefW7_To leave the European Union                             0.354053
# happyEULeaveW11__Extremely happy                                   0.348979
# happyLeaveW7__Very happy                                           0.348589
# likeFarageW11__Strongly like                                       0.347389
# happyEULeaveW14__Extremely happy                                   0.345988
# euIDW11_The leave side                                             0.344882
# happyEULeaveW10__Extremely happy                                   0.344202
# happyEULeaveW9__Extremely happy                                    0.343423
# likeFarageW10__Strongly like                                       0.341352
# likeUKIPW11__Strongly like                                         0.339765
# likeUKIPW10__Strongly like                                         0.339428
# euIDW13_The leave side                                             0.337828
# euRefVoteW2_Leave the EU                                           0.337493
# euIDW14_The leave side                                             0.335462
# likeUKIPW8__Strongly like                                          0.335298
# overseasAidW11__Strongly agree                                     0.334941
#                                                                      ...
# competentLucasW13__A great deal of competence                     -0.308356
# euLeaveBigBusinessW10__Much more likely                           -0.310637
# euLeaveBigBusinessW13__Much more likely                           -0.311507
# euLawsLevelW7__Strongly agree                                     -0.312630
# euLawsLevelW8__Strongly agree                                     -0.323574
# likeLucasW10__Strongly like                                       -0.323867
# likeBennettW4__Strongly like                                      -0.323928
# euLeaveBigBusinessW14__Much more likely                           -0.324802
# euLeaveBigBusinessW11__Much more likely                           -0.325906
# ptvGrnW3__Very likely                                             -0.327642
# likeLucasW11__Strongly like                                       -0.338085
# enviroGrowthW7__Protecting the environment should have priority   -0.339235
# likeLucasW14__Strongly like                                       -0.340936
# likeLucasW13__Strongly like                                       -0.343140
# likeGrnW6__Strongly like                                          -0.343410
# likeLucasW12__Strongly like                                       -0.348299
# likeGrnW5__Strongly like                                          -0.348771
# likeGrnW7__Strongly like                                          -0.353274
# likeGrnW1__Strongly like                                          -0.354968
# likeGrnW14__Strongly like                                         -0.355241
# likeGrnW8__Strongly like                                          -0.358195
# enviroGrowthW4__Protecting the environment should have priority   -0.358237
# likeGrnW11__Strongly like                                         -0.359971
# likeGrnW13__Strongly like                                         -0.361258
# likeGrnW2__Strongly like                                          -0.361417
# likeGrnW12__Strongly like                                         -0.362520
# likeGrnW10__Strongly like                                         -0.364228
# likeGrnW4__Strongly like                                          -0.367059
# likeGrnW9__Strongly like                                          -0.367082
# likeGrnW3__Strongly like                                          -0.381214
# Length: 5879, dtype: float64

# %%
corr_df_reduced = BES_reduced_with_na.corr(min_periods=100)

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2018, 12, 6, 7, 13, 36, 141473)

# %%
corr_df.to_msgpack(data_subfolder+"corr_df_reduced.msgpack")

# %%
data_subfolder
# Out:
# '../BES_analysis_data/W14_comb\\'

# %%
corr_df
# Out:
#                                                        ageW1  \
# ageW1                                               1.000000
# turnoutUKGeneralW1__Very likely that I will vote    0.197255
# turnoutUKGeneralW2__Very likely that I will vote    0.188298
# turnoutUKGeneralW3__Very likely that I will vote    0.176491
# turnoutUKGeneralW4__Very likely that I will vote    0.165196
# turnoutUKGeneralW5__Very likely that I will vote    0.129728
# turnoutUKGeneralW7__Very likely that I will vote    0.140742
# turnoutUKGeneralW8__Very likely that I will vote    0.130841
# turnoutUKGeneralW9__Very likely that I will vote    0.106640
# turnoutUKGeneralW10__Very likely that I will vote   0.121050
# turnoutUKGeneralW11__Very likely that I will vote   0.111680
# turnoutUKGeneralW12__Very likely that I will vote   0.109237
# generalElectionCertaintyW1__Completely certain      0.160816
# generalElectionCertaintyW2__Completely certain      0.160691
# generalElectionCertaintyW3__Completely certain      0.149089
# generalElectionCertaintyW4__Completely certain      0.143208
# generalElectionCertaintyUnsqW5__Completely certain  0.117682
# generalElectionCertaintySqW5__Completely certain    0.047833
# generalElectionCertaintyW5__Completely certain      0.134593
# generalElectionCertaintyW9__Completely certain      0.101503
# generalElectionCertaintyW10__Completely certain     0.161831
# generalElectionCertaintyW11__Completely certain     0.124237
# generalElectionCertaintyUnsqW12__Completely cer...  0.142468
# generalElectionCertaintySqW12__Completely certain   0.039447
# generalElectionCertaintyW12__Completely certain     0.150435
# partyIdStrengthW1__Not very strong                 -0.088032
# partyIdStrengthW2__Not very strong                 -0.088272
# partyIdStrengthW3__Not very strong                 -0.092298
# partyIdStrengthW4__Not very strong                 -0.100923
# partyIdStrengthW6__Not very strong                 -0.074076
# ...                                                      ...
# achieveReduceImmigNoneW12_Yes                      -0.055124
# achieveReduceImmigDKW12_Yes                        -0.095082
# ukipPriorities_noneW2_Yes                          -0.042152
# ukipPriorities_schoolW2_Yes                         0.066132
# ukipPriorities_crimeW2_Yes                          0.076589
# ukipPriorities_immigW2_Yes                          0.077274
# ukipPriorities_nhsW2_Yes                            0.076624
# partyContactLD_2W2_Yes                             -0.042083
# ukipPriorities_costLiveW2_Yes                       0.076383
# ukipPriorities_econW2_Yes                           0.069991
# ldPriorities_noneW2_Yes                             0.005323
# ldPriorities_schoolW2_Yes                           0.052216
# RV2W2_factory worker                                0.002715
# ldPriorities_crimeW2_Yes                            0.066998
# achieveReduceImmigGrnW12_Yes                       -0.026401
# scotReferendumIntentionW12_Will vote 'Yes'         -0.152983
# partyContact1W12_Yes                                0.028500
# partyContactUKIP_2W2_Yes                           -0.045619
# dv1ClassExpW2_Simmons                              -0.026658
# partyContactLD_5W2_Yes                              0.064451
# partyContactLD_4W2_Yes                              0.008540
# successReduceInequalityConW12_Yes                   0.074831
# bestPMW12_Jeremy Corbyn                            -0.246893
# partyContactUKIP_3W2_Yes                           -0.005263
# partyContactUKIP_4W2_Yes                            0.003654
# successReduceInequalityUKIPW12_Yes                  0.038569
# partyContactUKIP_5W2_Yes                            0.059558
# partyContactLDW12_Yes                               0.007367
# partyContactLabW12_Yes                             -0.050679
# partyContactConW12_Yes                              0.123966
#
#                                                     turnoutUKGeneralW1__Very likely that I will vote  \
# ageW1                                                                                       0.197255
# turnoutUKGeneralW1__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW2__Very likely that I will vote                                            0.764198
# turnoutUKGeneralW3__Very likely that I will vote                                            0.759795
# turnoutUKGeneralW4__Very likely that I will vote                                            0.722853
# turnoutUKGeneralW5__Very likely that I will vote                                            0.690068
# turnoutUKGeneralW7__Very likely that I will vote                                            0.658385
# turnoutUKGeneralW8__Very likely that I will vote                                            0.644661
# turnoutUKGeneralW9__Very likely that I will vote                                            0.575628
# turnoutUKGeneralW10__Very likely that I will vote                                           0.637073
# turnoutUKGeneralW11__Very likely that I will vote                                           0.539114
# turnoutUKGeneralW12__Very likely that I will vote                                           0.537678
# generalElectionCertaintyW1__Completely certain                                              0.263458
# generalElectionCertaintyW2__Completely certain                                              0.216912
# generalElectionCertaintyW3__Completely certain                                              0.198228
# generalElectionCertaintyW4__Completely certain                                              0.196072
# generalElectionCertaintyUnsqW5__Completely certain                                          0.170967
# generalElectionCertaintySqW5__Completely certain                                            0.094846
# generalElectionCertaintyW5__Completely certain                                              0.200336
# generalElectionCertaintyW9__Completely certain                                              0.110686
# generalElectionCertaintyW10__Completely certain                                             0.174311
# generalElectionCertaintyW11__Completely certain                                             0.121868
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.133917
# generalElectionCertaintySqW12__Completely certain                                           0.013887
# generalElectionCertaintyW12__Completely certain                                             0.129298
# partyIdStrengthW1__Not very strong                                                         -0.220303
# partyIdStrengthW2__Not very strong                                                         -0.197990
# partyIdStrengthW3__Not very strong                                                         -0.194247
# partyIdStrengthW4__Not very strong                                                         -0.204209
# partyIdStrengthW6__Not very strong                                                         -0.175705
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.032597
# achieveReduceImmigDKW12_Yes                                                                -0.107889
# ukipPriorities_noneW2_Yes                                                                  -0.119448
# ukipPriorities_schoolW2_Yes                                                                 0.042268
# ukipPriorities_crimeW2_Yes                                                                  0.069781
# ukipPriorities_immigW2_Yes                                                                  0.135624
# ukipPriorities_nhsW2_Yes                                                                    0.029629
# partyContactLD_2W2_Yes                                                                      0.012394
# ukipPriorities_costLiveW2_Yes                                                               0.034213
# ukipPriorities_econW2_Yes                                                                   0.029992
# ldPriorities_noneW2_Yes                                                                    -0.061897
# ldPriorities_schoolW2_Yes                                                                   0.061380
# RV2W2_factory worker                                                                        0.016852
# ldPriorities_crimeW2_Yes                                                                    0.032872
# achieveReduceImmigGrnW12_Yes                                                               -0.007092
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.015505
# partyContact1W12_Yes                                                                        0.118347
# partyContactUKIP_2W2_Yes                                                                   -0.009578
# dv1ClassExpW2_Simmons                                                                       0.036456
# partyContactLD_5W2_Yes                                                                      0.023266
# partyContactLD_4W2_Yes                                                                     -0.011803
# successReduceInequalityConW12_Yes                                                          -0.008027
# bestPMW12_Jeremy Corbyn                                                                     0.004161
# partyContactUKIP_3W2_Yes                                                                    0.015625
# partyContactUKIP_4W2_Yes                                                                   -0.030387
# successReduceInequalityUKIPW12_Yes                                                         -0.002910
# partyContactUKIP_5W2_Yes                                                                    0.045551
# partyContactLDW12_Yes                                                                       0.007479
# partyContactLabW12_Yes                                                                     -0.019289
# partyContactConW12_Yes                                                                      0.035658
#
#                                                     turnoutUKGeneralW2__Very likely that I will vote  \
# ageW1                                                                                       0.188298
# turnoutUKGeneralW1__Very likely that I will vote                                            0.764198
# turnoutUKGeneralW2__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW3__Very likely that I will vote                                            0.796294
# turnoutUKGeneralW4__Very likely that I will vote                                            0.749522
# turnoutUKGeneralW5__Very likely that I will vote                                            0.719718
# turnoutUKGeneralW7__Very likely that I will vote                                            0.690232
# turnoutUKGeneralW8__Very likely that I will vote                                            0.668758
# turnoutUKGeneralW9__Very likely that I will vote                                            0.593488
# turnoutUKGeneralW10__Very likely that I will vote                                           0.656597
# turnoutUKGeneralW11__Very likely that I will vote                                           0.557675
# turnoutUKGeneralW12__Very likely that I will vote                                           0.554028
# generalElectionCertaintyW1__Completely certain                                              0.200254
# generalElectionCertaintyW2__Completely certain                                              0.247561
# generalElectionCertaintyW3__Completely certain                                              0.194712
# generalElectionCertaintyW4__Completely certain                                              0.191790
# generalElectionCertaintyUnsqW5__Completely certain                                          0.162620
# generalElectionCertaintySqW5__Completely certain                                            0.064095
# generalElectionCertaintyW5__Completely certain                                              0.180135
# generalElectionCertaintyW9__Completely certain                                              0.114949
# generalElectionCertaintyW10__Completely certain                                             0.154220
# generalElectionCertaintyW11__Completely certain                                             0.116925
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.141007
# generalElectionCertaintySqW12__Completely certain                                           0.031531
# generalElectionCertaintyW12__Completely certain                                             0.145654
# partyIdStrengthW1__Not very strong                                                         -0.182855
# partyIdStrengthW2__Not very strong                                                         -0.198943
# partyIdStrengthW3__Not very strong                                                         -0.179716
# partyIdStrengthW4__Not very strong                                                         -0.193685
# partyIdStrengthW6__Not very strong                                                         -0.175826
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.032473
# achieveReduceImmigDKW12_Yes                                                                -0.115366
# ukipPriorities_noneW2_Yes                                                                  -0.119545
# ukipPriorities_schoolW2_Yes                                                                 0.027976
# ukipPriorities_crimeW2_Yes                                                                  0.063220
# ukipPriorities_immigW2_Yes                                                                  0.170457
# ukipPriorities_nhsW2_Yes                                                                    0.029429
# partyContactLD_2W2_Yes                                                                      0.026709
# ukipPriorities_costLiveW2_Yes                                                               0.021384
# ukipPriorities_econW2_Yes                                                                   0.041568
# ldPriorities_noneW2_Yes                                                                    -0.053392
# ldPriorities_schoolW2_Yes                                                                   0.079959
# RV2W2_factory worker                                                                        0.017081
# ldPriorities_crimeW2_Yes                                                                    0.044497
# achieveReduceImmigGrnW12_Yes                                                               -0.004907
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.021270
# partyContact1W12_Yes                                                                        0.128437
# partyContactUKIP_2W2_Yes                                                                   -0.008684
# dv1ClassExpW2_Simmons                                                                       0.009275
# partyContactLD_5W2_Yes                                                                      0.016408
# partyContactLD_4W2_Yes                                                                      0.002412
# successReduceInequalityConW12_Yes                                                           0.005912
# bestPMW12_Jeremy Corbyn                                                                     0.011041
# partyContactUKIP_3W2_Yes                                                                   -0.003251
# partyContactUKIP_4W2_Yes                                                                   -0.019684
# successReduceInequalityUKIPW12_Yes                                                         -0.006306
# partyContactUKIP_5W2_Yes                                                                    0.037717
# partyContactLDW12_Yes                                                                       0.010191
# partyContactLabW12_Yes                                                                     -0.004709
# partyContactConW12_Yes                                                                      0.032820
#
#                                                     turnoutUKGeneralW3__Very likely that I will vote  \
# ageW1                                                                                       0.176491
# turnoutUKGeneralW1__Very likely that I will vote                                            0.759795
# turnoutUKGeneralW2__Very likely that I will vote                                            0.796294
# turnoutUKGeneralW3__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW4__Very likely that I will vote                                            0.777261
# turnoutUKGeneralW5__Very likely that I will vote                                            0.722657
# turnoutUKGeneralW7__Very likely that I will vote                                            0.695322
# turnoutUKGeneralW8__Very likely that I will vote                                            0.678343
# turnoutUKGeneralW9__Very likely that I will vote                                            0.597681
# turnoutUKGeneralW10__Very likely that I will vote                                           0.666059
# turnoutUKGeneralW11__Very likely that I will vote                                           0.570709
# turnoutUKGeneralW12__Very likely that I will vote                                           0.568249
# generalElectionCertaintyW1__Completely certain                                              0.206107
# generalElectionCertaintyW2__Completely certain                                              0.205522
# generalElectionCertaintyW3__Completely certain                                              0.230607
# generalElectionCertaintyW4__Completely certain                                              0.214961
# generalElectionCertaintyUnsqW5__Completely certain                                          0.180325
# generalElectionCertaintySqW5__Completely certain                                            0.073151
# generalElectionCertaintyW5__Completely certain                                              0.200956
# generalElectionCertaintyW9__Completely certain                                              0.113767
# generalElectionCertaintyW10__Completely certain                                             0.146938
# generalElectionCertaintyW11__Completely certain                                             0.127537
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.148619
# generalElectionCertaintySqW12__Completely certain                                           0.028634
# generalElectionCertaintyW12__Completely certain                                             0.145729
# partyIdStrengthW1__Not very strong                                                         -0.175485
# partyIdStrengthW2__Not very strong                                                         -0.174241
# partyIdStrengthW3__Not very strong                                                         -0.192838
# partyIdStrengthW4__Not very strong                                                         -0.196393
# partyIdStrengthW6__Not very strong                                                         -0.174042
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.042032
# achieveReduceImmigDKW12_Yes                                                                -0.117731
# ukipPriorities_noneW2_Yes                                                                  -0.138180
# ukipPriorities_schoolW2_Yes                                                                 0.040911
# ukipPriorities_crimeW2_Yes                                                                  0.057184
# ukipPriorities_immigW2_Yes                                                                  0.168153
# ukipPriorities_nhsW2_Yes                                                                    0.039312
# partyContactLD_2W2_Yes                                                                     -0.020879
# ukipPriorities_costLiveW2_Yes                                                               0.017775
# ukipPriorities_econW2_Yes                                                                   0.038579
# ldPriorities_noneW2_Yes                                                                    -0.050749
# ldPriorities_schoolW2_Yes                                                                   0.053046
# RV2W2_factory worker                                                                        0.024015
# ldPriorities_crimeW2_Yes                                                                    0.045729
# achieveReduceImmigGrnW12_Yes                                                               -0.014036
# scotReferendumIntentionW12_Will vote 'Yes'                                                 -0.003734
# partyContact1W12_Yes                                                                        0.126100
# partyContactUKIP_2W2_Yes                                                                   -0.013527
# dv1ClassExpW2_Simmons                                                                       0.015619
# partyContactLD_5W2_Yes                                                                      0.015877
# partyContactLD_4W2_Yes                                                                      0.006367
# successReduceInequalityConW12_Yes                                                           0.010398
# bestPMW12_Jeremy Corbyn                                                                    -0.012647
# partyContactUKIP_3W2_Yes                                                                   -0.004976
# partyContactUKIP_4W2_Yes                                                                    0.000722
# successReduceInequalityUKIPW12_Yes                                                          0.010162
# partyContactUKIP_5W2_Yes                                                                    0.042553
# partyContactLDW12_Yes                                                                       0.010656
# partyContactLabW12_Yes                                                                     -0.005079
# partyContactConW12_Yes                                                                      0.034747
#
#                                                     turnoutUKGeneralW4__Very likely that I will vote  \
# ageW1                                                                                       0.165196
# turnoutUKGeneralW1__Very likely that I will vote                                            0.722853
# turnoutUKGeneralW2__Very likely that I will vote                                            0.749522
# turnoutUKGeneralW3__Very likely that I will vote                                            0.777261
# turnoutUKGeneralW4__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW5__Very likely that I will vote                                            0.815531
# turnoutUKGeneralW7__Very likely that I will vote                                            0.713893
# turnoutUKGeneralW8__Very likely that I will vote                                            0.702592
# turnoutUKGeneralW9__Very likely that I will vote                                            0.624421
# turnoutUKGeneralW10__Very likely that I will vote                                           0.676428
# turnoutUKGeneralW11__Very likely that I will vote                                           0.602598
# turnoutUKGeneralW12__Very likely that I will vote                                           0.592316
# generalElectionCertaintyW1__Completely certain                                              0.179419
# generalElectionCertaintyW2__Completely certain                                              0.189150
# generalElectionCertaintyW3__Completely certain                                              0.194102
# generalElectionCertaintyW4__Completely certain                                              0.262705
# generalElectionCertaintyUnsqW5__Completely certain                                          0.194838
# generalElectionCertaintySqW5__Completely certain                                            0.086639
# generalElectionCertaintyW5__Completely certain                                              0.226253
# generalElectionCertaintyW9__Completely certain                                              0.121041
# generalElectionCertaintyW10__Completely certain                                             0.161045
# generalElectionCertaintyW11__Completely certain                                             0.151560
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.158385
# generalElectionCertaintySqW12__Completely certain                                           0.003087
# generalElectionCertaintyW12__Completely certain                                             0.151070
# partyIdStrengthW1__Not very strong                                                         -0.163787
# partyIdStrengthW2__Not very strong                                                         -0.169762
# partyIdStrengthW3__Not very strong                                                         -0.173349
# partyIdStrengthW4__Not very strong                                                         -0.216334
# partyIdStrengthW6__Not very strong                                                         -0.183483
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.039584
# achieveReduceImmigDKW12_Yes                                                                -0.122865
# ukipPriorities_noneW2_Yes                                                                  -0.127375
# ukipPriorities_schoolW2_Yes                                                                 0.050824
# ukipPriorities_crimeW2_Yes                                                                  0.058549
# ukipPriorities_immigW2_Yes                                                                  0.150120
# ukipPriorities_nhsW2_Yes                                                                    0.028529
# partyContactLD_2W2_Yes                                                                     -0.007334
# ukipPriorities_costLiveW2_Yes                                                               0.022735
# ukipPriorities_econW2_Yes                                                                   0.031587
# ldPriorities_noneW2_Yes                                                                    -0.042048
# ldPriorities_schoolW2_Yes                                                                   0.042030
# RV2W2_factory worker                                                                        0.013371
# ldPriorities_crimeW2_Yes                                                                    0.040202
# achieveReduceImmigGrnW12_Yes                                                               -0.013670
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.040523
# partyContact1W12_Yes                                                                        0.115190
# partyContactUKIP_2W2_Yes                                                                   -0.000313
# dv1ClassExpW2_Simmons                                                                       0.007987
# partyContactLD_5W2_Yes                                                                      0.041015
# partyContactLD_4W2_Yes                                                                      0.011286
# successReduceInequalityConW12_Yes                                                           0.037329
# bestPMW12_Jeremy Corbyn                                                                    -0.000632
# partyContactUKIP_3W2_Yes                                                                    0.022456
# partyContactUKIP_4W2_Yes                                                                   -0.008737
# successReduceInequalityUKIPW12_Yes                                                          0.012661
# partyContactUKIP_5W2_Yes                                                                    0.024935
# partyContactLDW12_Yes                                                                       0.009404
# partyContactLabW12_Yes                                                                     -0.003206
# partyContactConW12_Yes                                                                      0.040379
#
#                                                     turnoutUKGeneralW5__Very likely that I will vote  \
# ageW1                                                                                       0.129728
# turnoutUKGeneralW1__Very likely that I will vote                                            0.690068
# turnoutUKGeneralW2__Very likely that I will vote                                            0.719718
# turnoutUKGeneralW3__Very likely that I will vote                                            0.722657
# turnoutUKGeneralW4__Very likely that I will vote                                            0.815531
# turnoutUKGeneralW5__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW7__Very likely that I will vote                                            0.728354
# turnoutUKGeneralW8__Very likely that I will vote                                            0.718490
# turnoutUKGeneralW9__Very likely that I will vote                                            0.642236
# turnoutUKGeneralW10__Very likely that I will vote                                           0.679955
# turnoutUKGeneralW11__Very likely that I will vote                                           0.620063
# turnoutUKGeneralW12__Very likely that I will vote                                           0.612475
# generalElectionCertaintyW1__Completely certain                                              0.152375
# generalElectionCertaintyW2__Completely certain                                              0.152723
# generalElectionCertaintyW3__Completely certain                                              0.151391
# generalElectionCertaintyW4__Completely certain                                              0.199968
# generalElectionCertaintyUnsqW5__Completely certain                                          0.216062
# generalElectionCertaintySqW5__Completely certain                                            0.085647
# generalElectionCertaintyW5__Completely certain                                              0.231657
# generalElectionCertaintyW9__Completely certain                                              0.121467
# generalElectionCertaintyW10__Completely certain                                             0.168535
# generalElectionCertaintyW11__Completely certain                                             0.131360
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.155440
# generalElectionCertaintySqW12__Completely certain                                           0.025333
# generalElectionCertaintyW12__Completely certain                                             0.140875
# partyIdStrengthW1__Not very strong                                                         -0.147187
# partyIdStrengthW2__Not very strong                                                         -0.145713
# partyIdStrengthW3__Not very strong                                                         -0.152222
# partyIdStrengthW4__Not very strong                                                         -0.188628
# partyIdStrengthW6__Not very strong                                                         -0.177718
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.038640
# achieveReduceImmigDKW12_Yes                                                                -0.124886
# ukipPriorities_noneW2_Yes                                                                  -0.121074
# ukipPriorities_schoolW2_Yes                                                                 0.043322
# ukipPriorities_crimeW2_Yes                                                                  0.052965
# ukipPriorities_immigW2_Yes                                                                  0.133257
# ukipPriorities_nhsW2_Yes                                                                    0.024842
# partyContactLD_2W2_Yes                                                                     -0.003149
# ukipPriorities_costLiveW2_Yes                                                               0.033773
# ukipPriorities_econW2_Yes                                                                   0.042556
# ldPriorities_noneW2_Yes                                                                    -0.052077
# ldPriorities_schoolW2_Yes                                                                   0.036798
# RV2W2_factory worker                                                                       -0.005341
# ldPriorities_crimeW2_Yes                                                                    0.055321
# achieveReduceImmigGrnW12_Yes                                                               -0.000049
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.043568
# partyContact1W12_Yes                                                                        0.117806
# partyContactUKIP_2W2_Yes                                                                   -0.014610
# dv1ClassExpW2_Simmons                                                                       0.030330
# partyContactLD_5W2_Yes                                                                      0.032773
# partyContactLD_4W2_Yes                                                                     -0.000652
# successReduceInequalityConW12_Yes                                                           0.040261
# bestPMW12_Jeremy Corbyn                                                                     0.020196
# partyContactUKIP_3W2_Yes                                                                   -0.002992
# partyContactUKIP_4W2_Yes                                                                   -0.027304
# successReduceInequalityUKIPW12_Yes                                                          0.007676
# partyContactUKIP_5W2_Yes                                                                    0.025247
# partyContactLDW12_Yes                                                                       0.014554
# partyContactLabW12_Yes                                                                     -0.004100
# partyContactConW12_Yes                                                                      0.011847
#
#                                                     turnoutUKGeneralW7__Very likely that I will vote  \
# ageW1                                                                                       0.140742
# turnoutUKGeneralW1__Very likely that I will vote                                            0.658385
# turnoutUKGeneralW2__Very likely that I will vote                                            0.690232
# turnoutUKGeneralW3__Very likely that I will vote                                            0.695322
# turnoutUKGeneralW4__Very likely that I will vote                                            0.713893
# turnoutUKGeneralW5__Very likely that I will vote                                            0.728354
# turnoutUKGeneralW7__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW8__Very likely that I will vote                                            0.833607
# turnoutUKGeneralW9__Very likely that I will vote                                            0.726400
# turnoutUKGeneralW10__Very likely that I will vote                                           0.767871
# turnoutUKGeneralW11__Very likely that I will vote                                           0.691635
# turnoutUKGeneralW12__Very likely that I will vote                                           0.674757
# generalElectionCertaintyW1__Completely certain                                              0.147995
# generalElectionCertaintyW2__Completely certain                                              0.152883
# generalElectionCertaintyW3__Completely certain                                              0.147473
# generalElectionCertaintyW4__Completely certain                                              0.168186
# generalElectionCertaintyUnsqW5__Completely certain                                          0.182485
# generalElectionCertaintySqW5__Completely certain                                            0.074653
# generalElectionCertaintyW5__Completely certain                                              0.194649
# generalElectionCertaintyW9__Completely certain                                              0.164457
# generalElectionCertaintyW10__Completely certain                                             0.182446
# generalElectionCertaintyW11__Completely certain                                             0.162068
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.181493
# generalElectionCertaintySqW12__Completely certain                                           0.021217
# generalElectionCertaintyW12__Completely certain                                             0.176188
# partyIdStrengthW1__Not very strong                                                         -0.143510
# partyIdStrengthW2__Not very strong                                                         -0.132948
# partyIdStrengthW3__Not very strong                                                         -0.141014
# partyIdStrengthW4__Not very strong                                                         -0.173428
# partyIdStrengthW6__Not very strong                                                         -0.160469
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.039939
# achieveReduceImmigDKW12_Yes                                                                -0.123908
# ukipPriorities_noneW2_Yes                                                                  -0.109007
# ukipPriorities_schoolW2_Yes                                                                 0.046078
# ukipPriorities_crimeW2_Yes                                                                  0.066274
# ukipPriorities_immigW2_Yes                                                                  0.128418
# ukipPriorities_nhsW2_Yes                                                                    0.037571
# partyContactLD_2W2_Yes                                                                     -0.019755
# ukipPriorities_costLiveW2_Yes                                                               0.048648
# ukipPriorities_econW2_Yes                                                                   0.037296
# ldPriorities_noneW2_Yes                                                                    -0.059028
# ldPriorities_schoolW2_Yes                                                                   0.059314
# RV2W2_factory worker                                                                        0.006579
# ldPriorities_crimeW2_Yes                                                                    0.068973
# achieveReduceImmigGrnW12_Yes                                                               -0.017941
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.035567
# partyContact1W12_Yes                                                                        0.126009
# partyContactUKIP_2W2_Yes                                                                   -0.016206
# dv1ClassExpW2_Simmons                                                                       0.036013
# partyContactLD_5W2_Yes                                                                      0.040033
# partyContactLD_4W2_Yes                                                                      0.006122
# successReduceInequalityConW12_Yes                                                           0.020414
# bestPMW12_Jeremy Corbyn                                                                     0.022934
# partyContactUKIP_3W2_Yes                                                                    0.014805
# partyContactUKIP_4W2_Yes                                                                   -0.010644
# successReduceInequalityUKIPW12_Yes                                                          0.003176
# partyContactUKIP_5W2_Yes                                                                    0.032908
# partyContactLDW12_Yes                                                                       0.025868
# partyContactLabW12_Yes                                                                     -0.014425
# partyContactConW12_Yes                                                                      0.009854
#
#                                                     turnoutUKGeneralW8__Very likely that I will vote  \
# ageW1                                                                                       0.130841
# turnoutUKGeneralW1__Very likely that I will vote                                            0.644661
# turnoutUKGeneralW2__Very likely that I will vote                                            0.668758
# turnoutUKGeneralW3__Very likely that I will vote                                            0.678343
# turnoutUKGeneralW4__Very likely that I will vote                                            0.702592
# turnoutUKGeneralW5__Very likely that I will vote                                            0.718490
# turnoutUKGeneralW7__Very likely that I will vote                                            0.833607
# turnoutUKGeneralW8__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW9__Very likely that I will vote                                            0.734659
# turnoutUKGeneralW10__Very likely that I will vote                                           0.759694
# turnoutUKGeneralW11__Very likely that I will vote                                           0.685300
# turnoutUKGeneralW12__Very likely that I will vote                                           0.659687
# generalElectionCertaintyW1__Completely certain                                              0.154870
# generalElectionCertaintyW2__Completely certain                                              0.136860
# generalElectionCertaintyW3__Completely certain                                              0.142380
# generalElectionCertaintyW4__Completely certain                                              0.166327
# generalElectionCertaintyUnsqW5__Completely certain                                          0.179004
# generalElectionCertaintySqW5__Completely certain                                            0.046932
# generalElectionCertaintyW5__Completely certain                                              0.175122
# generalElectionCertaintyW9__Completely certain                                              0.159645
# generalElectionCertaintyW10__Completely certain                                             0.186578
# generalElectionCertaintyW11__Completely certain                                             0.172300
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.193993
# generalElectionCertaintySqW12__Completely certain                                           0.027590
# generalElectionCertaintyW12__Completely certain                                             0.178615
# partyIdStrengthW1__Not very strong                                                         -0.148560
# partyIdStrengthW2__Not very strong                                                         -0.136047
# partyIdStrengthW3__Not very strong                                                         -0.137873
# partyIdStrengthW4__Not very strong                                                         -0.162042
# partyIdStrengthW6__Not very strong                                                         -0.167277
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.037385
# achieveReduceImmigDKW12_Yes                                                                -0.130802
# ukipPriorities_noneW2_Yes                                                                  -0.070200
# ukipPriorities_schoolW2_Yes                                                                 0.039378
# ukipPriorities_crimeW2_Yes                                                                  0.046198
# ukipPriorities_immigW2_Yes                                                                  0.108135
# ukipPriorities_nhsW2_Yes                                                                    0.018594
# partyContactLD_2W2_Yes                                                                     -0.000030
# ukipPriorities_costLiveW2_Yes                                                               0.018935
# ukipPriorities_econW2_Yes                                                                   0.013866
# ldPriorities_noneW2_Yes                                                                    -0.042307
# ldPriorities_schoolW2_Yes                                                                   0.037754
# RV2W2_factory worker                                                                       -0.015796
# ldPriorities_crimeW2_Yes                                                                    0.056421
# achieveReduceImmigGrnW12_Yes                                                               -0.029100
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.037266
# partyContact1W12_Yes                                                                        0.122946
# partyContactUKIP_2W2_Yes                                                                   -0.024897
# dv1ClassExpW2_Simmons                                                                       0.008268
# ...
# ldPriorities_schoolW2_Yes                                          -0.051744
# RV2W2_factory worker                                               -0.004672
# ldPriorities_crimeW2_Yes                                           -0.080799
# achieveReduceImmigGrnW12_Yes                                       -0.016004
# scotReferendumIntentionW12_Will vote 'Yes'                               NaN
# partyContact1W12_Yes                                               -0.029387
# partyContactUKIP_2W2_Yes                                           -0.361702
# dv1ClassExpW2_Simmons                                              -0.018670
# partyContactLD_5W2_Yes                                              0.200358
# partyContactLD_4W2_Yes                                              0.055403
# successReduceInequalityConW12_Yes                                   0.047726
# bestPMW12_Jeremy Corbyn                                            -0.083028
# partyContactUKIP_3W2_Yes                                            0.112085
# partyContactUKIP_4W2_Yes                                            0.038420
# successReduceInequalityUKIPW12_Yes                                  0.145913
# partyContactUKIP_5W2_Yes                                            1.000000
# partyContactLDW12_Yes                                              -0.051037
# partyContactLabW12_Yes                                             -0.048683
# partyContactConW12_Yes                                              0.027014
#
#                                                     partyContactLDW12_Yes  \
# ageW1                                                            0.007367
# turnoutUKGeneralW1__Very likely that I will vote                 0.007479
# turnoutUKGeneralW2__Very likely that I will vote                 0.010191
# turnoutUKGeneralW3__Very likely that I will vote                 0.010656
# turnoutUKGeneralW4__Very likely that I will vote                 0.009404
# turnoutUKGeneralW5__Very likely that I will vote                 0.014554
# turnoutUKGeneralW7__Very likely that I will vote                 0.025868
# turnoutUKGeneralW8__Very likely that I will vote                 0.021936
# turnoutUKGeneralW9__Very likely that I will vote                 0.010486
# turnoutUKGeneralW10__Very likely that I will vote                0.008992
# turnoutUKGeneralW11__Very likely that I will vote                0.028859
# turnoutUKGeneralW12__Very likely that I will vote                0.005428
# generalElectionCertaintyW1__Completely certain                  -0.044045
# generalElectionCertaintyW2__Completely certain                  -0.048243
# generalElectionCertaintyW3__Completely certain                  -0.042562
# generalElectionCertaintyW4__Completely certain                  -0.049664
# generalElectionCertaintyUnsqW5__Completely certain              -0.060105
# generalElectionCertaintySqW5__Completely certain                -0.034320
# generalElectionCertaintyW5__Completely certain                  -0.049803
# generalElectionCertaintyW9__Completely certain                  -0.054862
# generalElectionCertaintyW10__Completely certain                 -0.027858
# generalElectionCertaintyW11__Completely certain                 -0.043535
# generalElectionCertaintyUnsqW12__Completely cer...              -0.061298
# generalElectionCertaintySqW12__Completely certain               -0.031064
# generalElectionCertaintyW12__Completely certain                 -0.059675
# partyIdStrengthW1__Not very strong                               0.064869
# partyIdStrengthW2__Not very strong                               0.069946
# partyIdStrengthW3__Not very strong                               0.053852
# partyIdStrengthW4__Not very strong                               0.046522
# partyIdStrengthW6__Not very strong                               0.058803
# ...                                                                   ...
# achieveReduceImmigNoneW12_Yes                                    0.047772
# achieveReduceImmigDKW12_Yes                                     -0.023457
# ukipPriorities_noneW2_Yes                                        0.001955
# ukipPriorities_schoolW2_Yes                                     -0.062748
# ukipPriorities_crimeW2_Yes                                      -0.057659
# ukipPriorities_immigW2_Yes                                       0.011827
# ukipPriorities_nhsW2_Yes                                        -0.051421
# partyContactLD_2W2_Yes                                          -0.028053
# ukipPriorities_costLiveW2_Yes                                   -0.044430
# ukipPriorities_econW2_Yes                                       -0.103969
# ldPriorities_noneW2_Yes                                         -0.095691
# ldPriorities_schoolW2_Yes                                        0.040994
# RV2W2_factory worker                                            -0.026651
# ldPriorities_crimeW2_Yes                                         0.046378
# achieveReduceImmigGrnW12_Yes                                     0.005085
# scotReferendumIntentionW12_Will vote 'Yes'                      -0.098981
# partyContact1W12_Yes                                                  NaN
# partyContactUKIP_2W2_Yes                                         0.036154
# dv1ClassExpW2_Simmons                                            0.052774
# partyContactLD_5W2_Yes                                           0.145619
# partyContactLD_4W2_Yes                                           0.074418
# successReduceInequalityConW12_Yes                               -0.003914
# bestPMW12_Jeremy Corbyn                                         -0.023124
# partyContactUKIP_3W2_Yes                                        -0.019815
# partyContactUKIP_4W2_Yes                                         0.019390
# successReduceInequalityUKIPW12_Yes                              -0.051645
# partyContactUKIP_5W2_Yes                                        -0.051037
# partyContactLDW12_Yes                                            1.000000
# partyContactLabW12_Yes                                          -0.029154
# partyContactConW12_Yes                                           0.072883
#
#                                                     partyContactLabW12_Yes  \
# ageW1                                                            -0.050679
# turnoutUKGeneralW1__Very likely that I will vote                 -0.019289
# turnoutUKGeneralW2__Very likely that I will vote                 -0.004709
# turnoutUKGeneralW3__Very likely that I will vote                 -0.005079
# turnoutUKGeneralW4__Very likely that I will vote                 -0.003206
# turnoutUKGeneralW5__Very likely that I will vote                 -0.004100
# turnoutUKGeneralW7__Very likely that I will vote                 -0.014425
# turnoutUKGeneralW8__Very likely that I will vote                 -0.013938
# turnoutUKGeneralW9__Very likely that I will vote                 -0.001877
# turnoutUKGeneralW10__Very likely that I will vote                 0.000035
# turnoutUKGeneralW11__Very likely that I will vote                -0.015708
# turnoutUKGeneralW12__Very likely that I will vote                -0.023333
# generalElectionCertaintyW1__Completely certain                   -0.025423
# generalElectionCertaintyW2__Completely certain                   -0.012425
# generalElectionCertaintyW3__Completely certain                   -0.026128
# generalElectionCertaintyW4__Completely certain                   -0.041465
# generalElectionCertaintyUnsqW5__Completely certain               -0.024040
# generalElectionCertaintySqW5__Completely certain                 -0.043384
# generalElectionCertaintyW5__Completely certain                   -0.041968
# generalElectionCertaintyW9__Completely certain                   -0.012780
# generalElectionCertaintyW10__Completely certain                  -0.030628
# generalElectionCertaintyW11__Completely certain                  -0.038436
# generalElectionCertaintyUnsqW12__Completely cer...               -0.011362
# generalElectionCertaintySqW12__Completely certain                 0.016070
# generalElectionCertaintyW12__Completely certain                   0.001084
# partyIdStrengthW1__Not very strong                                0.018317
# partyIdStrengthW2__Not very strong                                0.004648
# partyIdStrengthW3__Not very strong                                0.024734
# partyIdStrengthW4__Not very strong                                0.016677
# partyIdStrengthW6__Not very strong                                0.028962
# ...                                                                    ...
# achieveReduceImmigNoneW12_Yes                                     0.042670
# achieveReduceImmigDKW12_Yes                                       0.043786
# ukipPriorities_noneW2_Yes                                         0.056368
# ukipPriorities_schoolW2_Yes                                      -0.033167
# ukipPriorities_crimeW2_Yes                                       -0.035632
# ukipPriorities_immigW2_Yes                                       -0.055758
# ukipPriorities_nhsW2_Yes                                         -0.058563
# partyContactLD_2W2_Yes                                            0.036928
# ukipPriorities_costLiveW2_Yes                                    -0.063601
# ukipPriorities_econW2_Yes                                        -0.084684
# ldPriorities_noneW2_Yes                                           0.073048
# ldPriorities_schoolW2_Yes                                        -0.074430
# RV2W2_factory worker                                             -0.003517
# ldPriorities_crimeW2_Yes                                         -0.025803
# achieveReduceImmigGrnW12_Yes                                      0.033502
# scotReferendumIntentionW12_Will vote 'Yes'                       -0.093099
# partyContact1W12_Yes                                                   NaN
# partyContactUKIP_2W2_Yes                                          0.020130
# dv1ClassExpW2_Simmons                                            -0.001115
# partyContactLD_5W2_Yes                                           -0.066480
# partyContactLD_4W2_Yes                                           -0.004371
# successReduceInequalityConW12_Yes                                -0.081612
# bestPMW12_Jeremy Corbyn                                           0.263940
# partyContactUKIP_3W2_Yes                                         -0.007776
# partyContactUKIP_4W2_Yes                                          0.018760
# successReduceInequalityUKIPW12_Yes                               -0.038079
# partyContactUKIP_5W2_Yes                                         -0.048683
# partyContactLDW12_Yes                                            -0.029154
# partyContactLabW12_Yes                                            1.000000
# partyContactConW12_Yes                                           -0.141567
#
#                                                     partyContactConW12_Yes
# ageW1                                                             0.123966
# turnoutUKGeneralW1__Very likely that I will vote                  0.035658
# turnoutUKGeneralW2__Very likely that I will vote                  0.032820
# turnoutUKGeneralW3__Very likely that I will vote                  0.034747
# turnoutUKGeneralW4__Very likely that I will vote                  0.040379
# turnoutUKGeneralW5__Very likely that I will vote                  0.011847
# turnoutUKGeneralW7__Very likely that I will vote                  0.009854
# turnoutUKGeneralW8__Very likely that I will vote                  0.017731
# turnoutUKGeneralW9__Very likely that I will vote                  0.011632
# turnoutUKGeneralW10__Very likely that I will vote                 0.009162
# turnoutUKGeneralW11__Very likely that I will vote                 0.028279
# turnoutUKGeneralW12__Very likely that I will vote                 0.010385
# generalElectionCertaintyW1__Completely certain                    0.020339
# generalElectionCertaintyW2__Completely certain                   -0.002775
# generalElectionCertaintyW3__Completely certain                   -0.004914
# generalElectionCertaintyW4__Completely certain                   -0.007256
# generalElectionCertaintyUnsqW5__Completely certain                0.006766
# generalElectionCertaintySqW5__Completely certain                  0.034707
# generalElectionCertaintyW5__Completely certain                    0.001770
# generalElectionCertaintyW9__Completely certain                   -0.041309
# generalElectionCertaintyW10__Completely certain                   0.003319
# generalElectionCertaintyW11__Completely certain                   0.032165
# generalElectionCertaintyUnsqW12__Completely cer...                0.022865
# generalElectionCertaintySqW12__Completely certain                -0.052206
# generalElectionCertaintyW12__Completely certain                   0.002989
# partyIdStrengthW1__Not very strong                                0.047208
# partyIdStrengthW2__Not very strong                                0.047098
# partyIdStrengthW3__Not very strong                                0.033250
# partyIdStrengthW4__Not very strong                                0.049338
# partyIdStrengthW6__Not very strong                                0.052799
# ...                                                                    ...
# achieveReduceImmigNoneW12_Yes                                    -0.122744
# achieveReduceImmigDKW12_Yes                                      -0.053935
# ukipPriorities_noneW2_Yes                                        -0.015503
# ukipPriorities_schoolW2_Yes                                       0.005051
# ukipPriorities_crimeW2_Yes                                        0.061561
# ukipPriorities_immigW2_Yes                                        0.020407
# ukipPriorities_nhsW2_Yes                                          0.053232
# partyContactLD_2W2_Yes                                           -0.004623
# ukipPriorities_costLiveW2_Yes                                     0.017363
# ukipPriorities_econW2_Yes                                         0.065861
# ldPriorities_noneW2_Yes                                          -0.040631
# ldPriorities_schoolW2_Yes                                         0.055457
# RV2W2_factory worker                                             -0.001835
# ldPriorities_crimeW2_Yes                                          0.020548
# achieveReduceImmigGrnW12_Yes                                     -0.021823
# scotReferendumIntentionW12_Will vote 'Yes'                       -0.201224
# partyContact1W12_Yes                                                   NaN
# partyContactUKIP_2W2_Yes                                         -0.013388
# dv1ClassExpW2_Simmons                                             0.028147
# partyContactLD_5W2_Yes                                           -0.038270
# partyContactLD_4W2_Yes                                            0.005504
# successReduceInequalityConW12_Yes                                 0.123835
# bestPMW12_Jeremy Corbyn                                          -0.307123
# partyContactUKIP_3W2_Yes                                         -0.002400
# partyContactUKIP_4W2_Yes                                         -0.009174
# successReduceInequalityUKIPW12_Yes                               -0.013097
# partyContactUKIP_5W2_Yes                                          0.027014
# partyContactLDW12_Yes                                             0.072883
# partyContactLabW12_Yes                                           -0.141567
# partyContactConW12_Yes                                            1.000000
#
# [6864 rows x 6864 columns]

# %%
gc.collect()
# Out:
# 35093
