# %%
dataset_name = "W14_comb"
df_list = [
           "BES_Panel",
           "BES_reduced_with_na",
#            "BES_reduced",
#            "BESnumeric"
          ]

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import pickle, os, gc, re

from IPython.display import display

import Jupyter_module_loader
from utility import *
# display_components, display_pca_data, weighted_kde, setup_directories,\
#                     get_manifest, get_small_files, clean_filename, create_subdir, amalgamate_waves

# %%
# you should clone this git to a subdirectory called 'BES_analysis_code' (in some directory - I call it BES_analysis - doesn't matter though)
# %matplotlib inline
encoding = "ISO-8859-1"

(BES_code_folder, BES_small_data_files, BES_data_folder,
 BES_output_folder, BES_file_manifest, BES_R_data_files) = setup_directories()

# %%
# %%time
global BES_Panel, BES_numeric, BES_reduced, BES_reduced_with_na, BES_non_numeric
data_subfolder = BES_data_folder + dataset_name + os.sep

(manifest, dataset_filename, dataset_description, dataset_citation,
 dataset_start, dataset_stop, dataset_wave) = get_manifest(dataset_name, BES_file_manifest)

# dataset_filename = "BES2015_W8_v1.6.dta"

for df in df_list:
    if df=="BES_Panel":
        globals()[df]  = pd.read_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))
#     elif df=="BES_reduced_with_na":
#         globals()[df] = pd.read_msgpack(data_subfolder + "BES_reduced" + '.msgpack')
#         nans = pd.read_msgpack(data_subfolder + "nans" + '.msgpack')
#         globals()[df][nans] = np.nan
# #         globals()[df] = temp[nans]
#         del nans
    else:
        globals()[df]  = pd.read_msgpack(data_subfolder + df + '.msgpack' )
        globals()[df].replace(-1,np.nan,inplace=True)
#         globals()[df] = globals()[df].apply(pd.to_numeric,downcast='integer')
    print(df+":")
    globals()[df].info(memory_usage='deep')    
(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)
# Out:
# BES_Panel:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73703 entries, 0 to 73702
# Columns: 5692 entries, id to small_mii_catW10
# dtypes: category(5483), datetime64[ns](31), float32(4), float64(154), int8(18), object(2)
# memory usage: 506.4 MB
# BES_reduced_with_na:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73703 entries, 0 to 73702
# Columns: 6864 entries, ageW1 to partyContactConW12_Yes
# dtypes: float32(6864)
# memory usage: 1.9 GB
# var_type (5692, 13)

# %%
## immigSelf distribution by Leave/Remain

# %%
# def amalgamate(df, pattern, forward_fill=True):
    
#     df_cols_dict = {int(re.search("W(\d+)", x).groups()[0]):x for x in df.columns if re.match(pattern, x)}
#     # sort volumns
#     df_cols = [df_cols_dict[x] for x in sorted(df_cols_dict.keys())]
#     # forward fill and and pick last column - or backward fill and pick first column
#     if forward_fill:
#         latest_series = df[df_cols].fillna(method="ffill",axis=1)[df_cols[-1]]
#     else:
#         latest_series = df[df_cols].fillna(method="bfill",axis=1)[df_cols[0]]
    
#     if df[df_cols[0]].dtype.name == "category":
#         latest_series = latest_series.astype(
#                     pd.api.types.CategoricalDtype(categories = df[df_cols[0]].cat.categories) )
#     return latest_series

# %%
[x for x in BES_reduced_with_na.columns if re.match("immigSelf", x)]
# Out:
# ['immigSelfW7__Allow many more',
#  'immigSelfW8__Allow many more',
#  'immigSelfW9__Allow many more',
#  'immigSelfW10__Allow many more',
#  'immigSelfW11__Allow many more',
#  'immigSelfW12__Allow many more',
#  'immigSelfW14__Allow many more']

# %%
Leavers = BES_Panel["profile_eurefvote"] =="Leave the EU"
Remainers = BES_Panel["profile_eurefvote"] =="Stay/remain in the EU"

# %%
amalg_imm = amalgamate_waves(BES_reduced_with_na,"immigSelf",forward_fill=False)
euref_imm = amalgamate_waves(BES_reduced_with_na,"euRefVoteW",forward_fill=False)

# %%
amalg_imm.notnull().sum(),euref_imm.notnull().sum()
# Out:
# (56639, 69801)

# %%
prof_euref_imm = (BES_Panel["profile_eurefvote"]=="Leave the EU")
prof_euref_imm[BES_Panel["profile_eurefvote"]=="Don't know"] = np.nan

# %%
amalg_imm[euref_imm.notnull()].notnull().sum(), amalg_imm[prof_euref_imm.notnull()].notnull().sum()
# Out:
# (55233, 56296)

# %%
output_subfolder = BES_output_folder + os.sep + "Immigration_sentiment_by_euref" + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

Leave_imm =  amalg_imm[prof_euref_imm==1]
Remainer_imm = amalg_imm[prof_euref_imm==0]

sns.kdeplot(Leave_imm,     label="Leavers", bw=.5, ax = axes);#, cut=1);
sns.kdeplot(Remainer_imm,  label="Remainers", bw=.5, ax = axes);#, cut=1);

# ax.set_ylim([0,.2])
axes.set_xlim([0,10]);
axes.set_xticks(list(range(0,11)))
axes.set_xticklabels(BES_Panel["immigSelfW14"].cat.categories[0:11]);
axes.set_xlabel("Some people think that the UK should allow *many more* immigrants to come to the UK to live"+\
                "and others think that the UK should allow *many fewer* immigrants."+\
                "\nWhere would you place yourself and the parties on this scale?");

fname = output_subfolder + "Immigration_sentiment_by_euref" + ".png"
plt.savefig( fname, bbox_inches='tight' )
# Out:
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\statsmodels\nonparametric\kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
fig, axes = plt.subplots(1, 1, figsize=(12,8))

Leave_imm =  amalg_imm[euref_imm==1]
Remainer_imm = amalg_imm[euref_imm==0]

sns.kdeplot(Leave_imm,     label="Leavers", bw=.5, ax = axes);#, cut=1);
sns.kdeplot(Remainer_imm,  label="Remainers", bw=.5, ax = axes);#, cut=1);

# ax.set_ylim([0,.2])
axes.set_xlim([0,10]);
axes.set_xticks(list(range(0,11)))
axes.set_xticklabels(BES_Panel["immigSelfW14"].cat.categories[0:11]);
axes.set_xlabel("Some people think that the UK should allow *many more* immigrants to come to the UK to live"+\
                "and others think that the UK should allow *many fewer* immigrants."+\
                "\nWhere would you place yourself and the parties on this scale?");

# fname = output_subfolder + "Immigration_sentiment_by_euref" + ".png"
# plt.savefig( fname, bbox_inches='tight' )

# %%
Leavers   = (BES_Panel['profile_eurefvote'] == "Leave the EU")
Remainers = (BES_Panel['profile_eurefvote'] == "Stay/remain in the EU")
amalgamated_euMIISmall = amalgamate_waves(BES_Panel, 'euMIISmallW', forward_fill=True)

# %%
SovOrImmLeavers = Leavers&amalgamated_euMIISmall.notnull()

Sov = amalgamated_euMIISmall[SovOrImmLeavers]
BES_sov = BES_reduced[SovOrImmLeavers]
drop_vars = [x for x in BES_reduced.columns if ("euRefVote" in x) or ("profile_eurefvote" in x)\
             or ("euMII" in x) or ("EUMII" in x)]
BES_sov = BES_sov.drop(drop_vars , axis=1)

# %%
sovereignty = "Sovereignty/EU bureaucracy"
immigration = "Immigration"
Sov = (amalgamated_euMIISmall==sovereignty)
Imm = (amalgamated_euMIISmall==immigration)
Oth = amalgamated_euMIISmall.notnull() & ~Imm & ~Sov

# %%
Sov[Leavers].sum(), Imm[Leavers].sum(), Oth[Leavers].sum()
# Out:
# (3933, 3391, 4088)

# %%
economy = "Economy"
cosmopolitanism = "Cosmopolitanism"
Eco = (amalgamated_euMIISmall==sovereignty)
Cos = (amalgamated_euMIISmall==immigration)

# %%
amalgamated_euMIISmall[Remainers].value_counts()
# Out:
# Economy                                   3717
# Cosmopolitanism                           1190
# Foreign policy                             992
# Protection of rights                       899
# No content to reason                       882
# Campaign/outcome fairness                  778
# Other                                      606
# Immigration                                495
# Other stability or uncertainty concern     449
# Sovereignty/EU bureaucracy                 410
# Social identity/partisanship               330
# Family                                     202
# EU spending/regulations/cost               197
# EU integration/stability                    64
# British/english identity                    34
# Name: euMIISmallW8, dtype: int64

# %%
# colours = cycle('ycmkgbr')
# markers = cycle('v^<>,oD*x+')

cat_col_mar_dict = {} # category-colour-marker dictionary
# basic set of common ones! 
cat_col_mar_dict['Conservative'] = ('b', '.')
cat_col_mar_dict['Conservative Party'] = ('b', '.')
cat_col_mar_dict['The Conservative candidate']       = ('b', 'x')
cat_col_mar_dict['Labour']       = ('r', '.')
cat_col_mar_dict['Labour Party']       = ('r', '.')
cat_col_mar_dict['The Labour candidate']       = ('r', 'x')
cat_col_mar_dict['Green Party']  = ('g', '.')
cat_col_mar_dict['The Green candidate']       = ('g', 'x')
cat_col_mar_dict['Plaid Cymru']  = ('k', '.')
cat_col_mar_dict['The Plaid Cymru candidate']  = ('k', 'x')
cat_col_mar_dict['Scottish National Party']           = ('c', '.')
cat_col_mar_dict['United Kingdom Independence Party'] = ('m', '.')
cat_col_mar_dict['The UKIP candidate'] = ('m', 'x')
cat_col_mar_dict['Liberal Democrat']                         = ('orange', '.')
cat_col_mar_dict['Liberal Democrats']                        = ('orange', '.')
cat_col_mar_dict['The Liberal Democrat candidate']                         = ('orange', 'x')

cat_col_mar_df = pd.DataFrame.from_dict(cat_col_mar_dict, orient='index', columns = ["colour","marker"])
cat_col_mar_df.to_csv(BES_small_data_files+"legend_colour_marker_dict.csv")

# %%
# (cat_col_mar_df["colour"] + cat_col_mar_df["marker"]).values

# %%
# list(colours)

# %%
# len(".,ov^<>12348spP*hH+xXDd|_")

# %%
cat_col_mar_df = pd.read_csv(BES_small_data_files+"legend_colour_marker_dict.csv",index_col=0)
cat_col_mar_df
from itertools import cycle
col_str = 'rbmkgcy'
mar_str = ".,ov^<>8spP*hH+xXDd|_1234"
colours = cycle(col_str)
markers = cycle(mar_str)
# markers = cycle('v^<>,oD*x+')
def get_next_col_mar():
    return (next(colours),next(markers))
    
    
def col_mar_comb_already_exists(colmar):
    return colmar in (cat_col_mar_df["colour"] + cat_col_mar_df["marker"]).values
    

def get_cat_col_mar(label):
    if label in cat_col_mar_df.index:
        row = cat_col_mar_df.loc[label]
        return (row["colour"],row["marker"])
    else:
        (col, mar) = get_next_col_mar()
        count = 0
        while col_mar_comb_already_exists(col+mar):
            (col, mar) = get_next_col_mar()
            count = count+1
            if count>=(len(col_str)-1)*(len(mar_str)-1):
                raise Exception("stuck hunting for next col mar combinations!")
        cat_col_mar_df.loc[label] = [col, mar]
        cat_col_mar_df.to_csv(BES_small_data_files+"legend_colour_marker_dict.csv")
        return (col, mar)

# %%
# cat_col_mar_dict = {} # category-colour-marker dictionary

# colours = cycle('ycmkgbr')
# markers = cycle('v^<>,oD*x+')

def make_categorical_density_plot():
    fig, axes = plt.subplots(1, 1, figsize=(16,10))    
    sov_vars = (BES_reduced_with_na[[x for x in BES_reduced_with_na.columns if re.match(cat_var+"_", x)]][mask&amalg_imm.notnull()]==1)\
                .sum().sort_values(ascending=False)
    sov_vars = sov_vars.drop(sov_vars[sov_vars<min_sample].index)
    if len(sov_vars.index)==0:
        return
    
    for sov in sov_vars.index:
#         if sov not in cat_col_mar_dict.keys(): # try to give mii consistent colour, marker pairs
#             cat_col_mar_dict[sov] = (next(colours),next(markers))        
        sov_imm = amalg_imm[(BES_reduced_with_na[sov]==1.0)&mask]
        base_label = sov.split("_")[-1]

        (col, mar) = get_cat_col_mar(base_label)
        label = base_label +"(N="+str(sov_vars.loc[sov])+")"
        sns.kdeplot(sov_imm,
                    label=label,
                    bw=.5,
                    ax = axes,
                    color = col,
                    marker = mar,
                    alpha = .75);

    sns.kdeplot(amalg_imm,
                label="Everyone-Leaver/Remainer/Neither"+"(N="+str(amalg_imm.notnull().sum())+")",
                bw=.5,
                ax = axes,
                color = 'k',
                linewidth=7.0,
                alpha = .75);       

    # axes.set_ylim([0,.6])
    axes.set_xlim([0,10]);
    axes.set_xticks(list(range(0,11)))
    axes.set_xticklabels(BES_Panel["immigSelfW14"].cat.categories[0:11]);
    axes.set_xlabel("Some people think that the UK should allow *many more* immigrants to come to the UK to live"+\
                    "and others think that the UK should allow *many fewer* immigrants."+\
                    "\nWhere would you place yourself and the parties on this scale?");
    plt.legend(loc='upper right',title=cat_var);
    wave_descr = BES_file_manifest[ (BES_file_manifest["Only_or_Combined"]=="Only")\
                     & (BES_file_manifest["Wave No"]==wave) ]["Friendlier_Description"].values[0]    
    plt.title(question+"\n"\
             +wave_descr\
             +"\n"+subtitle);

    fname = cat_var + "_" + subtitle + ".png"
    plt.savefig( output_subfolder + clean_filename(fname), bbox_inches='tight' )
#     plt.close()

# %%
Treatment = "Sovereignty_vs_Immigration"
base_folder = create_subdir(BES_output_folder, Treatment)

sub_treatment = "category_by_immigself"
output_subfolder = create_subdir(base_folder, sub_treatment)

# %%
# get_cat_col_mar('immigration')

# %%
amalg_imm = amalgamate_waves(BES_reduced_with_na,"immigSelf",forward_fill=False)
masks = {"Leavers":"Leave the EU","Remainers":"Stay/remain in the EU","Don't know":"Don't know"}
# cat_vars = ["euMIISmallW7","euMIISmallW8","EUMIICategoryW7","EUMIICategoryW8"]
# cat_vars = sorted(list(set(["_".join(x.split("_")[:-1]) for x in BES_reduced_with_na.columns if re.match("bestOnMII|miilabel|small_mii_cat|mii_cat|LRAL_mii_cat|EUMIICategory|euMIISmall",x) ])))
cat_vars = sorted(list(set(["_".join(x.split("_")[:-1]) for x in BES_reduced_with_na.columns if re.match("EUMIICategory",x) ])))
min_sample = 100

for cat_var in cat_vars:
    question = "What matters most to you when deciding how to vote in the EU referendum?"
    wave = int(re.search("W(\d+)",cat_var).groups()[0])
    for subtitle,mask_cat in masks.items():
        print(cat_var,subtitle)
        if ("euRefVoteW"+str(wave)) not in BES_Panel.columns:
            mask = (BES_Panel["profile_eurefvote"]==mask_cat)
        else:
            mask = (BES_Panel["euRefVoteW"+str(wave)]==mask_cat)

        make_categorical_density_plot()
# Out:
# EUMIICategoryW7 Leavers
# EUMIICategoryW7 Remainers
# EUMIICategoryW7 Don't know
# EUMIICategoryW8 Leavers
# EUMIICategoryW8 Remainers
# EUMIICategoryW8 Don't know

# %%
def sort_by_wave(lst):
    dict_by_wave = {int(x.split("W")[-1]):x for x in lst}
#     print(dict_by_wave)
    return [dict_by_wave[x] for x in sorted(dict_by_wave.keys())]

# %%
lst = ['LRAL_mii_catW1',
 'LRAL_mii_catW10',
 'LRAL_mii_catW11',
 'LRAL_mii_catW12',
 'LRAL_mii_catW13',
 'LRAL_mii_catW2',
 'LRAL_mii_catW3',
 'LRAL_mii_catW4',
 'LRAL_mii_catW5',
 'LRAL_mii_catW6',
 'LRAL_mii_catW7',
 'LRAL_mii_catW8',
 'LRAL_mii_catW9']
sort_by_wave(lst)
# Out:
# ['LRAL_mii_catW1',
#  'LRAL_mii_catW2',
#  'LRAL_mii_catW3',
#  'LRAL_mii_catW4',
#  'LRAL_mii_catW5',
#  'LRAL_mii_catW6',
#  'LRAL_mii_catW7',
#  'LRAL_mii_catW8',
#  'LRAL_mii_catW9',
#  'LRAL_mii_catW10',
#  'LRAL_mii_catW11',
#  'LRAL_mii_catW12',
#  'LRAL_mii_catW13']

# %%
sorted(list(set(["_".join(x.split("_")[:-1]) for x in BES_reduced_with_na.columns if re.match("bestOnMII|miilabel|small_mii_cat|mii_cat|LRAL_mii_cat|EUMIICategory|euMIISmall",x) ])))
# Out:
# ['EUMIICategoryW7',
#  'EUMIICategoryW8',
#  'LRAL_mii_catW1',
#  'LRAL_mii_catW10',
#  'LRAL_mii_catW11',
#  'LRAL_mii_catW12',
#  'LRAL_mii_catW13',
#  'LRAL_mii_catW2',
#  'LRAL_mii_catW3',
#  'LRAL_mii_catW4',
#  'LRAL_mii_catW5',
#  'LRAL_mii_catW6',
#  'LRAL_mii_catW7',
#  'LRAL_mii_catW8',
#  'LRAL_mii_catW9',
#  'bestOnMIIW1',
#  'bestOnMIIW10',
#  'bestOnMIIW11',
#  'bestOnMIIW12',
#  'bestOnMIIW13',
#  'bestOnMIIW14',
#  'bestOnMIIW2',
#  'bestOnMIIW3',
#  'bestOnMIIW4',
#  'bestOnMIIW5',
#  'bestOnMIIW6',
#  'bestOnMIIW7',
#  'bestOnMIIW8',
#  'bestOnMIIW9',
#  'euMIISmallW7',
#  'euMIISmallW8',
#  'mii_catW1',
#  'mii_catW10',
#  'mii_catW11',
#  'mii_catW12',
#  'mii_catW13',
#  'mii_catW2',
#  'mii_catW3',
#  'mii_catW4',
#  'mii_catW5',
#  'mii_catW6',
#  'mii_catW7',
#  'mii_catW8',
#  'mii_catW9',
#  'miilabelW1',
#  'miilabelW2',
#  'miilabelW3',
#  'miilabelW4',
#  'miilabelW5',
#  'miilabelW6',
#  'small_mii_catW1',
#  'small_mii_catW10',
#  'small_mii_catW11',
#  'small_mii_catW12',
#  'small_mii_catW13',
#  'small_mii_catW2',
#  'small_mii_catW3',
#  'small_mii_catW4',
#  'small_mii_catW5',
#  'small_mii_catW6',
#  'small_mii_catW7',
#  'small_mii_catW8',
#  'small_mii_catW9']

# %%
list(set([x.split("W")[0] for x in BES_reduced_with_na.columns if "mii" in x.lower()]))
# Out:
# ['handleMIILD',
#  'handleMIILab',
#  'EUMIICategory',
#  'bestOnMII',
#  'handleMIIGrn',
#  'handleMIICon',
#  'miilabel',
#  'small_mii_cat',
#  'LRAL_mii_cat',
#  'euMIISmall',
#  'mii_cat',
#  'handleMIIUKIP']

# %%
sov_cols = [x for x in BES_reduced_with_na.columns if "sov" in x.lower()]
BES_reduced_with_na[sov_cols].notnull().sum()
# Out:
# UKsovereigntyW7__Strongly agree            28353
# UKsovereigntyW8__Strongly agree            31153
# UKsovereigntyPostW10__Strongly agree       26292
# UKsovereigntyPostW11__Strongly agree       27411
# UKsovereigntyPostW13__Strongly agree       27330
# UKsovereigntyPostW14__Strongly agree       26960
# EUMIICategoryW7_sovereignty                22599
# euMIISmallW7_Sovereignty/EU bureaucracy    21657
# EUMIICategoryW8_sovereignty                16181
# euMIISmallW8_Sovereignty/EU bureaucracy    15413
# dtype: int64

# %%
sov_corr = BES_reduced_with_na[Leavers].corrwith(BES_reduced_with_na["EUMIICategoryW7_sovereignty"][Leavers])
sov_corr.dropna().sort_values()
# Out:
# euMIISmallW7_Immigration                                        -0.350165
# EUMIICategoryW7_immigration                                     -0.334493
# scotIndepJoinEUW1__Very likely                                  -0.206965
# scotIndepJoinEUW2__Very likely                                  -0.178561
# cooperateRUKGBPW2__Very likely                                  -0.175416
# EUMIICategoryW7_democratic deficit                              -0.173026
# euMIISmallW7_Campaign/outcome fairness                          -0.171961
# euScepticismW7__Work towards single European government         -0.166412
# cooperateRUKGBPW1__Very likely                                  -0.161390
# polKnowHollandeW10_Prime Minister of Israel                     -0.160128
# euMIISmallW7_Economy                                            -0.159556
# euMIISmallW8_Immigration                                        -0.154674
# snpLookAfterMCW12__Very closely                                 -0.152811
# polKnowKerryW10_Secretary General of the United Nations         -0.152721
# happyScotIndepResultW1__Extremely happy                         -0.152528
# EUMIICategoryW7_truth                                           -0.150328
# lrSNPW4__Right                                                  -0.147274
# pocketBookAccurateDV2W1__Should definitely become independent   -0.147169
# lrSNPW5__Right                                                  -0.147008
# scotDevoMaxW7__It should have many more powers                  -0.145936
# likeSturgeonW9__Strongly like                                   -0.145202
# EUMIICategoryW8_immigration                                     -0.144396
# snpGovTrustW5__ Would do a good job                             -0.141427
# euMIISmallW7_No content to reason                               -0.139244
# likeSturgeonW8__Strongly like                                   -0.138433
# scotElectionVoteListW8_Scottish National Party (SNP)            -0.137989
# likeSturgeonW7__Strongly like                                   -0.137147
# scotDevoMaxW6__It should have many more powers                  -0.137131
# scotDevoMaxW3__It should have many more powers                  -0.135013
# likeSNPW8__Strongly like                                        -0.134750
#                                                                    ...
# conHopeW14_Yes                                                   0.131536
# scotElectionVoteConstW8_Scottish Conservative                    0.132417
# scotElectionVoteConstW2_Scottish Conservative                    0.132763
# devoResponsibleScotTaxW6_The UK Parliament                       0.134936
# devoResponsibleScotDefenceW3_The UK Parliament                   0.135539
# lr_scaleW6__Right                                                0.137634
# scotElectionVoteListW8_Scottish Conservative                     0.137698
# scotIndepVoiceW1__Very likely                                    0.137820
# likeGoveW7__Strongly like                                        0.140719
# likeGoveW8__Strongly like                                        0.143616
# UKsovereigntyW7__Strongly agree                                  0.144699
# scotElectionVoteConstW7_Scottish Conservative                    0.145534
# partyContactVoteLeaveW8_Yes                                      0.146124
# EUIntegrationSelfW7__Protect our independence                    0.148083
# scotElectionVoteConstW1_Scottish Conservative                    0.149318
# devoResponsibleScotWelfareW6_The UK Parliament                   0.152413
# snpAngryW6_Yes                                                   0.154168
# scotElectionVoteListW6_Scottish Conservative                     0.154343
# scotElectionVoteConstW3_Scottish Conservative                    0.154390
# scotElectionVoteConstW6_Scottish Conservative                    0.162124
# polKnowAssadW10_President of Syria                               0.163967
# scotElectionVoteListW3_Scottish Conservative                     0.170848
# scotElectionVoteConstW4_Scottish Conservative                    0.171832
# polKnowNetanyahuW10_Prime Minister of Israel                     0.183804
# polKnowKerryW10_United States Secretary of State                 0.190085
# polKnowHollandeW10_Prime Minister of Canada                      0.280692
# euMIISmallW8_Sovereignty/EU bureaucracy                          0.290195
# EUMIICategoryW8_sovereignty                                      0.324761
# euMIISmallW7_Sovereignty/EU bureaucracy                          0.770742
# EUMIICategoryW7_sovereignty                                      1.000000
# Length: 6783, dtype: float64

# %%
sov_corr[sov_corr.abs()>=.6].dropna().sort_index()
# Out:
# EUIntegrationSelfW10__Protect our independence                  0.655420
# EUIntegrationSelfW11__Protect our independence                  0.660549
# EUIntegrationSelfW12__Protect our independence                  0.668960
# EUIntegrationSelfW13__Protect our independence                  0.653175
# EUIntegrationSelfW14__Protect our independence                  0.637818
# EUIntegrationSelfW1__Protect our independence                   0.618248
# EUIntegrationSelfW3__Protect our independence                   0.644982
# EUIntegrationSelfW4__Protect our independence                   0.632688
# EUIntegrationSelfW6__Protect our independence                   0.629332
# EUIntegrationSelfW7__Protect our independence                   0.687578
# EUIntegrationSelfW8__Protect our independence                   0.671564
# EUIntegrationSelfW9__Protect our independence                   0.654135
# UKsovereigntyW7__Strongly agree                                 1.000000
# UKsovereigntyW8__Strongly agree                                 0.740863
# approveEUW2_Disapprove                                          0.614589
# approveEUW7__Strongly approve                                  -0.660900
# approveEUW9__Strongly approve                                  -0.647656
# echrW7__Strongly agree                                         -0.603572
# echrW8__Strongly agree                                         -0.616845
# eesEUIntegrationSelfW1__Unification should be pushed further   -0.614026
# eesEUIntegrationSelfW3__Unification should be pushed further   -0.633770
# eesEUIntegrationSelfW4__Unification should be pushed further   -0.616128
# eesEUIntegrationSelfW6__Unification should be pushed further   -0.622197
# efficacyNoMatterW8__Strongly agree                             -0.777778
# efficacyNotUnderstandW8__Strongly agree                         0.816497
# efficacyTooMuchEffortW8__Strongly agree                         0.838870
# euExpRefW7_To leave the European Union                          0.654665
# euIDW11_The leave side                                          0.613532
# euIDW12_The leave side                                          0.614126
# euIDW13_The leave side                                          0.607987
#                                                                   ...
# euIDW9_The leave side                                           0.610271
# euLawsLevelW7__Strongly agree                                  -0.616762
# euLawsLevelW8__Strongly agree                                  -0.617414
# euParlOverRideW7__Strongly agree                                0.669231
# euParlOverRideW8__Strongly agree                                0.653538
# euRedTapeW7__Strongly agree                                     0.651962
# euRedTapeW8__Strongly agree                                     0.625719
# euRefVote2W8_Leave the EU                                       0.620469
# euRefVoteUnsqueezeW7_Leave the EU                               0.652274
# euRefVoteUnsqueezeW8_Leave the EU                               0.636587
# euRefVoteW11_Leave the EU                                       0.603055
# euRefVoteW12_Leave the EU                                       0.610112
# euRefVoteW1_Leave the EU                                        0.604333
# euRefVoteW2_Leave the EU                                        0.614717
# euRefVoteW3_Leave the EU                                        0.610472
# euRefVoteW7_Leave the EU                                        0.633621
# euRefVoteW8_Leave the EU                                        0.617864
# euRefVoteW9_Leave the EU                                        0.600049
# euRefpastVoteW11_Leave the EU                                   0.601385
# euRefpastVoteW12_Leave the EU                                   0.604879
# euRefpastVoteW13_Leave the EU                                   0.601947
# euScepticismW7__Work towards single European government        -0.631470
# euUndermineIdentityW7__Strongly agree                           0.695269
# euUndermineIdentityW8__Strongly agree                           0.673194
# happyEULeaveW10__Extremely happy                                0.618346
# happyEULeaveW11__Extremely happy                                0.635543
# happyEULeaveW14__Extremely happy                                0.621810
# happyEULeaveW9__Extremely happy                                 0.615372
# happyLeaveW7__Very happy                                        0.636852
# ptvConW8__Very likely                                           0.777778
# Length: 62, dtype: float64

# %%
sov_corr = BES_reduced_with_na[Remainers].corrwith(BES_reduced_with_na["euMIISmallW7_Protection of rights"][Remainers])
sov_corr.dropna().sort_values()
# Out:
# polKnowAssadW10_President of Syria              -0.485071
# effectsEUWorkersW7__Much better                 -0.254117
# leftRightW11__Right                             -0.250966
# govtHandleEconW1__Very well                     -0.247156
# happyScotIndepResultNoW2__Extremely happy       -0.245585
# approveUKGovtW7__Strongly approve               -0.245244
# leftRightW13__Right                             -0.244588
# approveUKGovtW10__Strongly approve              -0.243639
# approveUKGovtW11__Strongly approve              -0.243500
# leftRightW7__Right                              -0.242571
# leftRightW10__Right                             -0.241563
# leftRightW14__Right                             -0.240772
# likeConW10__Strongly like                       -0.240174
# likeMayW11__Strongly like                       -0.240066
# leftRightW9__Right                              -0.239517
# approveUKGovtW3__Strongly approve               -0.239454
# approveUKGovtW2__Strongly approve               -0.239351
# leftRightW12__Right                             -0.238494
# conGovTrustW5__ Would do a good job             -0.237861
# effectsEUWorkersW8__Much better                 -0.237689
# likeConW11__Strongly like                       -0.236944
# govtHandleEconW7__Very well                     -0.236450
# approveUKGovtW1__Strongly approve               -0.235369
# effectsEUWorkersW14__Much better                -0.235334
# handleMIIConW5__Very well                       -0.234381
# effectsEUWorkersW11__Much better                -0.233278
# likeMayW10__Strongly like                       -0.232808
# likeMayW12__Strongly like                       -0.232604
# leftRightW2__Right                              -0.232342
# handleMIIConW7__Very well                       -0.232080
#                                                    ...
# likeCorbynW11__Strongly like                     0.227654
# dv2w2W2__Should definitely become independent    0.227683
# referendumSettledW4_Yes                          0.229099
# scotReferendumIntentionW6_Will vote 'Yes'        0.229883
# referendumSettledW6_Yes                          0.230120
# scotReferendumIntentionW4_Will vote 'Yes'        0.231273
# likeCorbynW8__Strongly like                      0.231782
# scotReferendumIntentionW7_Will vote 'Yes'        0.232140
# happyScotIndepResultW2__Extremely happy          0.233005
# likeCorbynW7__Strongly like                      0.234655
# scotReferendumIntentionW12_Will vote 'Yes'       0.238908
# welfarePreferenceW7__Much too low                0.242485
# welfarePreferenceW4__Much too low                0.248126
# welfarePreferenceW6__Much too low                0.258845
# welfarePreferenceW3__Much too low                0.259197
# EUMIICategoryW7_environment                      0.263806
# welfarePreferenceW2__Much too low                0.278245
# bestPMW12_Jeremy Corbyn                          0.289525
# bestPMW7_Jeremy Corbyn                           0.293180
# bestPMW8_Jeremy Corbyn                           0.295485
# EUMIICategoryW8_human rights                     0.314748
# EUMIICategoryW8_worker rights                    0.320554
# bestPMW10_Jeremy Corbyn                          0.334103
# bestPMW11_Jeremy Corbyn                          0.336007
# EUMIICategoryW7_equality                         0.412023
# euMIISmallW8_Protection of rights                0.526719
# EUMIICategoryW7_human rights                     0.585317
# EUMIICategoryW7_worker rights                    0.597789
# euMIISmallW7_Protection of rights                1.000000
# polKnowAssadW10_Prime Minister of Italy          1.000000
# Length: 6758, dtype: float64

# %%
sov_corr = BES_reduced_with_na[Remainers].corrwith(BES_reduced_with_na["euMIISmallW7_Cosmopolitanism"][Remainers])
sov_corr.dropna().sort_values()
# Out:
# polKnowNetanyahuW10_Prime Minister of Israel                   -0.323077
# euMIISmallW7_Economy                                           -0.243396
# EUIntegrationSelfW3__Protect our independence                  -0.181924
# EUIntegrationSelfW1__Protect our independence                  -0.180304
# EUIntegrationSelfW7__Protect our independence                  -0.176617
# EUIntegrationSelfW4__Protect our independence                  -0.175497
# approveEUW2_Disapprove                                         -0.168590
# EUIntegrationSelfW2__Protect our independence                  -0.168480
# EUMIICategoryW7_economy general                                -0.163660
# EUIntegrationSelfW8__Protect our independence                  -0.162372
# EUIntegrationSelfW6__Protect our independence                  -0.154300
# EUIntegrationSelfW12__Protect our independence                 -0.151779
# britishnessW12__Very strongly British                          -0.150780
# EUIntegrationSelfW13__Protect our independence                 -0.145060
# EUIntegrationSelfW9__Protect our independence                  -0.144143
# al_scaleW14__Authoritarian                                     -0.143392
# UKsovereigntyW7__Strongly agree                                -0.143173
# EUIntegrationSelfW10__Protect our independence                 -0.141292
# euUndermineIdentityW7__Strongly agree                          -0.139352
# al_scaleW13__Authoritarian                                     -0.138627
# UKsovereigntyW8__Strongly agree                                -0.137354
# euParlOverRideW8__Strongly agree                               -0.135122
# EUIntegrationSelfW11__Protect our independence                 -0.134777
# euParlOverRideW7__Strongly agree                               -0.133648
# al5W6__Strongly agree                                          -0.131881
# EUIntegrationSelfW14__Protect our independence                 -0.131799
# al_scaleW6__Authoritarian                                      -0.130950
# ukCoopMovementW7__Bad for Britain                              -0.130775
# ukCoopEuroW7__Bad for Britain                                  -0.130115
# immigrantsWelfareStateW8__Strongly agree                       -0.128696
#                                                                   ...
# immigSelfW14__Allow many more                                   0.125032
# partyContactLab_7W11_Yes                                        0.125543
# europeannessW11__Very strongly European                         0.126825
# europeannessW10__Very strongly European                         0.128584
# immigSelfW9__Allow many more                                    0.129894
# euLawsLevelW8__Strongly agree                                   0.129915
# euFinancialHelpW7__Strongly agree                               0.131779
# immigSelfW7__Allow many more                                    0.132891
# euLawsLevelW7__Strongly agree                                   0.133477
# labHandleEducW14__Very well                                     0.134366
# euFinancialHelpW2__Strongly agree                               0.136736
# europeannessW9__Very strongly European                          0.137545
# europeannessW8__Very strongly European                          0.141364
# ptvGrnExpW14__Very likely                                       0.142639
# eesEUIntegrationSelfW2__Unification should be pushed further    0.144130
# eesEUIntegrationSelfW1__Unification should be pushed further    0.147049
# euScepticismW7__Work towards single European government         0.151261
# europeannessW7__Very strongly European                          0.155108
# europeannessW12__Very strongly European                         0.160267
# eesEUIntegrationSelfW4__Unification should be pushed further    0.165286
# EUMIICategoryW8_freedom of movement                             0.168997
# eesEUIntegrationSelfW6__Unification should be pushed further    0.170288
# eesEUIntegrationSelfW3__Unification should be pushed further    0.174543
# polKnowNetanyahuW10_Secretary General of the United Nations     0.187253
# EUMIICategoryW8_EU identity/cosmopolitan                        0.233476
# euMIISmallW8_Cosmopolitanism                                    0.302632
# polKnowNetanyahuW10_President of France                         0.425905
# EUMIICategoryW7_freedom of movement                             0.467306
# EUMIICategoryW7_EU identity/cosmopolitan                        0.861237
# euMIISmallW7_Cosmopolitanism                                    1.000000
# Length: 6758, dtype: float64

# %%
[x for x in BES_reduced_with_na.columns if "climate" in x.lower()]
# Out:
# ['climateChangeW7__Climate not changing',
#  'climateChangeW10__Climate not changing',
#  'climateChangeW11__Climate not changing']

# %%
amalg_climate = amalgamate_waves(BES_reduced_with_na,"climateChangeW",forward_fill=False)

# %%
corr_climate = BES_reduced_with_na.corrwith(amalg_climate, drop=True)

# %%
sample_sizes = BES_reduced_with_na[amalg_climate.notnull()].notnull().sum()
sample_sizes.hist(bins=100)

# %%
sample_vars = BES_reduced_with_na[amalg_climate.notnull()].var()
sample_vars[sample_vars<=1].hist(bins=100)

# %%
low_sample_variance = list(sample_vars[sample_vars<0.01].index)

# %%
low_sample_size = list(sample_sizes[sample_sizes<1000].index)

# %%
BES_reduced_with_na.shape
# Out:
# (73703, 6864)

# %%
corr_climate.drop(low_sample_variance+low_sample_size,errors='ignore').sort_values(ascending=False)
# Out:
# climateChangeW7__Climate not changing                              1.000000
# climateChangeW10__Climate not changing                             0.962151
# climateChangeW11__Climate not changing                             0.781685
# enviroProtectionW3__Gone much too far                              0.454197
# enviroProtectionW6__Gone much too far                              0.445071
# enviroProtectionW7__Gone much too far                              0.437493
# enviroProtectionW2__Gone much too far                              0.434092
# enviroProtectionW12__Gone much too far                             0.431481
# enviroProtectionW4__Gone much too far                              0.424973
# enviroProtectionW1__Gone much too far                              0.411995
# enviroProtectionW14__Gone much too far                             0.377303
# happyTrumpW10__Extremely happy                                     0.357372
# likeNuttallW10__Strongly like                                      0.355601
# ptvUKIPW8__Very likely                                             0.354577
# euExpRefW7_To leave the European Union                             0.354053
# happyEULeaveW11__Extremely happy                                   0.348979
# happyLeaveW7__Very happy                                           0.348589
# likeFarageW11__Strongly like                                       0.347389
# happyEULeaveW14__Extremely happy                                   0.345988
# euIDW11_The leave side                                             0.344882
# happyEULeaveW10__Extremely happy                                   0.344202
# happyEULeaveW9__Extremely happy                                    0.343423
# likeFarageW10__Strongly like                                       0.341352
# likeUKIPW11__Strongly like                                         0.339765
# likeUKIPW10__Strongly like                                         0.339428
# euIDW13_The leave side                                             0.337828
# euRefVoteW2_Leave the EU                                           0.337493
# euIDW14_The leave side                                             0.335462
# likeUKIPW8__Strongly like                                          0.335298
# overseasAidW11__Strongly agree                                     0.334941
#                                                                      ...
# competentLucasW13__A great deal of competence                     -0.308356
# euLeaveBigBusinessW10__Much more likely                           -0.310637
# euLeaveBigBusinessW13__Much more likely                           -0.311507
# euLawsLevelW7__Strongly agree                                     -0.312630
# euLawsLevelW8__Strongly agree                                     -0.323574
# likeLucasW10__Strongly like                                       -0.323867
# likeBennettW4__Strongly like                                      -0.323928
# euLeaveBigBusinessW14__Much more likely                           -0.324802
# euLeaveBigBusinessW11__Much more likely                           -0.325906
# ptvGrnW3__Very likely                                             -0.327642
# likeLucasW11__Strongly like                                       -0.338085
# enviroGrowthW7__Protecting the environment should have priority   -0.339235
# likeLucasW14__Strongly like                                       -0.340936
# likeLucasW13__Strongly like                                       -0.343140
# likeGrnW6__Strongly like                                          -0.343410
# likeLucasW12__Strongly like                                       -0.348299
# likeGrnW5__Strongly like                                          -0.348771
# likeGrnW7__Strongly like                                          -0.353274
# likeGrnW1__Strongly like                                          -0.354968
# likeGrnW14__Strongly like                                         -0.355241
# likeGrnW8__Strongly like                                          -0.358195
# enviroGrowthW4__Protecting the environment should have priority   -0.358237
# likeGrnW11__Strongly like                                         -0.359971
# likeGrnW13__Strongly like                                         -0.361258
# likeGrnW2__Strongly like                                          -0.361417
# likeGrnW12__Strongly like                                         -0.362520
# likeGrnW10__Strongly like                                         -0.364228
# likeGrnW4__Strongly like                                          -0.367059
# likeGrnW9__Strongly like                                          -0.367082
# likeGrnW3__Strongly like                                          -0.381214
# Length: 5879, dtype: float64

# %%
corr_df_reduced = BES_reduced_with_na.corr(min_periods=100)

# %%
import datetime
datetime.datetime.now()
# Out:
# datetime.datetime(2018, 12, 6, 7, 13, 36, 141473)

# %%
corr_df.to_msgpack(data_subfolder+"corr_df_reduced.msgpack")

# %%
data_subfolder
# Out:
# '../BES_analysis_data/W14_comb\\'

# %%
corr_df
# Out:
#                                                        ageW1  \
# ageW1                                               1.000000
# turnoutUKGeneralW1__Very likely that I will vote    0.197255
# turnoutUKGeneralW2__Very likely that I will vote    0.188298
# turnoutUKGeneralW3__Very likely that I will vote    0.176491
# turnoutUKGeneralW4__Very likely that I will vote    0.165196
# turnoutUKGeneralW5__Very likely that I will vote    0.129728
# turnoutUKGeneralW7__Very likely that I will vote    0.140742
# turnoutUKGeneralW8__Very likely that I will vote    0.130841
# turnoutUKGeneralW9__Very likely that I will vote    0.106640
# turnoutUKGeneralW10__Very likely that I will vote   0.121050
# turnoutUKGeneralW11__Very likely that I will vote   0.111680
# turnoutUKGeneralW12__Very likely that I will vote   0.109237
# generalElectionCertaintyW1__Completely certain      0.160816
# generalElectionCertaintyW2__Completely certain      0.160691
# generalElectionCertaintyW3__Completely certain      0.149089
# generalElectionCertaintyW4__Completely certain      0.143208
# generalElectionCertaintyUnsqW5__Completely certain  0.117682
# generalElectionCertaintySqW5__Completely certain    0.047833
# generalElectionCertaintyW5__Completely certain      0.134593
# generalElectionCertaintyW9__Completely certain      0.101503
# generalElectionCertaintyW10__Completely certain     0.161831
# generalElectionCertaintyW11__Completely certain     0.124237
# generalElectionCertaintyUnsqW12__Completely cer...  0.142468
# generalElectionCertaintySqW12__Completely certain   0.039447
# generalElectionCertaintyW12__Completely certain     0.150435
# partyIdStrengthW1__Not very strong                 -0.088032
# partyIdStrengthW2__Not very strong                 -0.088272
# partyIdStrengthW3__Not very strong                 -0.092298
# partyIdStrengthW4__Not very strong                 -0.100923
# partyIdStrengthW6__Not very strong                 -0.074076
# ...                                                      ...
# achieveReduceImmigNoneW12_Yes                      -0.055124
# achieveReduceImmigDKW12_Yes                        -0.095082
# ukipPriorities_noneW2_Yes                          -0.042152
# ukipPriorities_schoolW2_Yes                         0.066132
# ukipPriorities_crimeW2_Yes                          0.076589
# ukipPriorities_immigW2_Yes                          0.077274
# ukipPriorities_nhsW2_Yes                            0.076624
# partyContactLD_2W2_Yes                             -0.042083
# ukipPriorities_costLiveW2_Yes                       0.076383
# ukipPriorities_econW2_Yes                           0.069991
# ldPriorities_noneW2_Yes                             0.005323
# ldPriorities_schoolW2_Yes                           0.052216
# RV2W2_factory worker                                0.002715
# ldPriorities_crimeW2_Yes                            0.066998
# achieveReduceImmigGrnW12_Yes                       -0.026401
# scotReferendumIntentionW12_Will vote 'Yes'         -0.152983
# partyContact1W12_Yes                                0.028500
# partyContactUKIP_2W2_Yes                           -0.045619
# dv1ClassExpW2_Simmons                              -0.026658
# partyContactLD_5W2_Yes                              0.064451
# partyContactLD_4W2_Yes                              0.008540
# successReduceInequalityConW12_Yes                   0.074831
# bestPMW12_Jeremy Corbyn                            -0.246893
# partyContactUKIP_3W2_Yes                           -0.005263
# partyContactUKIP_4W2_Yes                            0.003654
# successReduceInequalityUKIPW12_Yes                  0.038569
# partyContactUKIP_5W2_Yes                            0.059558
# partyContactLDW12_Yes                               0.007367
# partyContactLabW12_Yes                             -0.050679
# partyContactConW12_Yes                              0.123966
#
#                                                     turnoutUKGeneralW1__Very likely that I will vote  \
# ageW1                                                                                       0.197255
# turnoutUKGeneralW1__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW2__Very likely that I will vote                                            0.764198
# turnoutUKGeneralW3__Very likely that I will vote                                            0.759795
# turnoutUKGeneralW4__Very likely that I will vote                                            0.722853
# turnoutUKGeneralW5__Very likely that I will vote                                            0.690068
# turnoutUKGeneralW7__Very likely that I will vote                                            0.658385
# turnoutUKGeneralW8__Very likely that I will vote                                            0.644661
# turnoutUKGeneralW9__Very likely that I will vote                                            0.575628
# turnoutUKGeneralW10__Very likely that I will vote                                           0.637073
# turnoutUKGeneralW11__Very likely that I will vote                                           0.539114
# turnoutUKGeneralW12__Very likely that I will vote                                           0.537678
# generalElectionCertaintyW1__Completely certain                                              0.263458
# generalElectionCertaintyW2__Completely certain                                              0.216912
# generalElectionCertaintyW3__Completely certain                                              0.198228
# generalElectionCertaintyW4__Completely certain                                              0.196072
# generalElectionCertaintyUnsqW5__Completely certain                                          0.170967
# generalElectionCertaintySqW5__Completely certain                                            0.094846
# generalElectionCertaintyW5__Completely certain                                              0.200336
# generalElectionCertaintyW9__Completely certain                                              0.110686
# generalElectionCertaintyW10__Completely certain                                             0.174311
# generalElectionCertaintyW11__Completely certain                                             0.121868
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.133917
# generalElectionCertaintySqW12__Completely certain                                           0.013887
# generalElectionCertaintyW12__Completely certain                                             0.129298
# partyIdStrengthW1__Not very strong                                                         -0.220303
# partyIdStrengthW2__Not very strong                                                         -0.197990
# partyIdStrengthW3__Not very strong                                                         -0.194247
# partyIdStrengthW4__Not very strong                                                         -0.204209
# partyIdStrengthW6__Not very strong                                                         -0.175705
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.032597
# achieveReduceImmigDKW12_Yes                                                                -0.107889
# ukipPriorities_noneW2_Yes                                                                  -0.119448
# ukipPriorities_schoolW2_Yes                                                                 0.042268
# ukipPriorities_crimeW2_Yes                                                                  0.069781
# ukipPriorities_immigW2_Yes                                                                  0.135624
# ukipPriorities_nhsW2_Yes                                                                    0.029629
# partyContactLD_2W2_Yes                                                                      0.012394
# ukipPriorities_costLiveW2_Yes                                                               0.034213
# ukipPriorities_econW2_Yes                                                                   0.029992
# ldPriorities_noneW2_Yes                                                                    -0.061897
# ldPriorities_schoolW2_Yes                                                                   0.061380
# RV2W2_factory worker                                                                        0.016852
# ldPriorities_crimeW2_Yes                                                                    0.032872
# achieveReduceImmigGrnW12_Yes                                                               -0.007092
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.015505
# partyContact1W12_Yes                                                                        0.118347
# partyContactUKIP_2W2_Yes                                                                   -0.009578
# dv1ClassExpW2_Simmons                                                                       0.036456
# partyContactLD_5W2_Yes                                                                      0.023266
# partyContactLD_4W2_Yes                                                                     -0.011803
# successReduceInequalityConW12_Yes                                                          -0.008027
# bestPMW12_Jeremy Corbyn                                                                     0.004161
# partyContactUKIP_3W2_Yes                                                                    0.015625
# partyContactUKIP_4W2_Yes                                                                   -0.030387
# successReduceInequalityUKIPW12_Yes                                                         -0.002910
# partyContactUKIP_5W2_Yes                                                                    0.045551
# partyContactLDW12_Yes                                                                       0.007479
# partyContactLabW12_Yes                                                                     -0.019289
# partyContactConW12_Yes                                                                      0.035658
#
#                                                     turnoutUKGeneralW2__Very likely that I will vote  \
# ageW1                                                                                       0.188298
# turnoutUKGeneralW1__Very likely that I will vote                                            0.764198
# turnoutUKGeneralW2__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW3__Very likely that I will vote                                            0.796294
# turnoutUKGeneralW4__Very likely that I will vote                                            0.749522
# turnoutUKGeneralW5__Very likely that I will vote                                            0.719718
# turnoutUKGeneralW7__Very likely that I will vote                                            0.690232
# turnoutUKGeneralW8__Very likely that I will vote                                            0.668758
# turnoutUKGeneralW9__Very likely that I will vote                                            0.593488
# turnoutUKGeneralW10__Very likely that I will vote                                           0.656597
# turnoutUKGeneralW11__Very likely that I will vote                                           0.557675
# turnoutUKGeneralW12__Very likely that I will vote                                           0.554028
# generalElectionCertaintyW1__Completely certain                                              0.200254
# generalElectionCertaintyW2__Completely certain                                              0.247561
# generalElectionCertaintyW3__Completely certain                                              0.194712
# generalElectionCertaintyW4__Completely certain                                              0.191790
# generalElectionCertaintyUnsqW5__Completely certain                                          0.162620
# generalElectionCertaintySqW5__Completely certain                                            0.064095
# generalElectionCertaintyW5__Completely certain                                              0.180135
# generalElectionCertaintyW9__Completely certain                                              0.114949
# generalElectionCertaintyW10__Completely certain                                             0.154220
# generalElectionCertaintyW11__Completely certain                                             0.116925
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.141007
# generalElectionCertaintySqW12__Completely certain                                           0.031531
# generalElectionCertaintyW12__Completely certain                                             0.145654
# partyIdStrengthW1__Not very strong                                                         -0.182855
# partyIdStrengthW2__Not very strong                                                         -0.198943
# partyIdStrengthW3__Not very strong                                                         -0.179716
# partyIdStrengthW4__Not very strong                                                         -0.193685
# partyIdStrengthW6__Not very strong                                                         -0.175826
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.032473
# achieveReduceImmigDKW12_Yes                                                                -0.115366
# ukipPriorities_noneW2_Yes                                                                  -0.119545
# ukipPriorities_schoolW2_Yes                                                                 0.027976
# ukipPriorities_crimeW2_Yes                                                                  0.063220
# ukipPriorities_immigW2_Yes                                                                  0.170457
# ukipPriorities_nhsW2_Yes                                                                    0.029429
# partyContactLD_2W2_Yes                                                                      0.026709
# ukipPriorities_costLiveW2_Yes                                                               0.021384
# ukipPriorities_econW2_Yes                                                                   0.041568
# ldPriorities_noneW2_Yes                                                                    -0.053392
# ldPriorities_schoolW2_Yes                                                                   0.079959
# RV2W2_factory worker                                                                        0.017081
# ldPriorities_crimeW2_Yes                                                                    0.044497
# achieveReduceImmigGrnW12_Yes                                                               -0.004907
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.021270
# partyContact1W12_Yes                                                                        0.128437
# partyContactUKIP_2W2_Yes                                                                   -0.008684
# dv1ClassExpW2_Simmons                                                                       0.009275
# partyContactLD_5W2_Yes                                                                      0.016408
# partyContactLD_4W2_Yes                                                                      0.002412
# successReduceInequalityConW12_Yes                                                           0.005912
# bestPMW12_Jeremy Corbyn                                                                     0.011041
# partyContactUKIP_3W2_Yes                                                                   -0.003251
# partyContactUKIP_4W2_Yes                                                                   -0.019684
# successReduceInequalityUKIPW12_Yes                                                         -0.006306
# partyContactUKIP_5W2_Yes                                                                    0.037717
# partyContactLDW12_Yes                                                                       0.010191
# partyContactLabW12_Yes                                                                     -0.004709
# partyContactConW12_Yes                                                                      0.032820
#
#                                                     turnoutUKGeneralW3__Very likely that I will vote  \
# ageW1                                                                                       0.176491
# turnoutUKGeneralW1__Very likely that I will vote                                            0.759795
# turnoutUKGeneralW2__Very likely that I will vote                                            0.796294
# turnoutUKGeneralW3__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW4__Very likely that I will vote                                            0.777261
# turnoutUKGeneralW5__Very likely that I will vote                                            0.722657
# turnoutUKGeneralW7__Very likely that I will vote                                            0.695322
# turnoutUKGeneralW8__Very likely that I will vote                                            0.678343
# turnoutUKGeneralW9__Very likely that I will vote                                            0.597681
# turnoutUKGeneralW10__Very likely that I will vote                                           0.666059
# turnoutUKGeneralW11__Very likely that I will vote                                           0.570709
# turnoutUKGeneralW12__Very likely that I will vote                                           0.568249
# generalElectionCertaintyW1__Completely certain                                              0.206107
# generalElectionCertaintyW2__Completely certain                                              0.205522
# generalElectionCertaintyW3__Completely certain                                              0.230607
# generalElectionCertaintyW4__Completely certain                                              0.214961
# generalElectionCertaintyUnsqW5__Completely certain                                          0.180325
# generalElectionCertaintySqW5__Completely certain                                            0.073151
# generalElectionCertaintyW5__Completely certain                                              0.200956
# generalElectionCertaintyW9__Completely certain                                              0.113767
# generalElectionCertaintyW10__Completely certain                                             0.146938
# generalElectionCertaintyW11__Completely certain                                             0.127537
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.148619
# generalElectionCertaintySqW12__Completely certain                                           0.028634
# generalElectionCertaintyW12__Completely certain                                             0.145729
# partyIdStrengthW1__Not very strong                                                         -0.175485
# partyIdStrengthW2__Not very strong                                                         -0.174241
# partyIdStrengthW3__Not very strong                                                         -0.192838
# partyIdStrengthW4__Not very strong                                                         -0.196393
# partyIdStrengthW6__Not very strong                                                         -0.174042
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.042032
# achieveReduceImmigDKW12_Yes                                                                -0.117731
# ukipPriorities_noneW2_Yes                                                                  -0.138180
# ukipPriorities_schoolW2_Yes                                                                 0.040911
# ukipPriorities_crimeW2_Yes                                                                  0.057184
# ukipPriorities_immigW2_Yes                                                                  0.168153
# ukipPriorities_nhsW2_Yes                                                                    0.039312
# partyContactLD_2W2_Yes                                                                     -0.020879
# ukipPriorities_costLiveW2_Yes                                                               0.017775
# ukipPriorities_econW2_Yes                                                                   0.038579
# ldPriorities_noneW2_Yes                                                                    -0.050749
# ldPriorities_schoolW2_Yes                                                                   0.053046
# RV2W2_factory worker                                                                        0.024015
# ldPriorities_crimeW2_Yes                                                                    0.045729
# achieveReduceImmigGrnW12_Yes                                                               -0.014036
# scotReferendumIntentionW12_Will vote 'Yes'                                                 -0.003734
# partyContact1W12_Yes                                                                        0.126100
# partyContactUKIP_2W2_Yes                                                                   -0.013527
# dv1ClassExpW2_Simmons                                                                       0.015619
# partyContactLD_5W2_Yes                                                                      0.015877
# partyContactLD_4W2_Yes                                                                      0.006367
# successReduceInequalityConW12_Yes                                                           0.010398
# bestPMW12_Jeremy Corbyn                                                                    -0.012647
# partyContactUKIP_3W2_Yes                                                                   -0.004976
# partyContactUKIP_4W2_Yes                                                                    0.000722
# successReduceInequalityUKIPW12_Yes                                                          0.010162
# partyContactUKIP_5W2_Yes                                                                    0.042553
# partyContactLDW12_Yes                                                                       0.010656
# partyContactLabW12_Yes                                                                     -0.005079
# partyContactConW12_Yes                                                                      0.034747
#
#                                                     turnoutUKGeneralW4__Very likely that I will vote  \
# ageW1                                                                                       0.165196
# turnoutUKGeneralW1__Very likely that I will vote                                            0.722853
# turnoutUKGeneralW2__Very likely that I will vote                                            0.749522
# turnoutUKGeneralW3__Very likely that I will vote                                            0.777261
# turnoutUKGeneralW4__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW5__Very likely that I will vote                                            0.815531
# turnoutUKGeneralW7__Very likely that I will vote                                            0.713893
# turnoutUKGeneralW8__Very likely that I will vote                                            0.702592
# turnoutUKGeneralW9__Very likely that I will vote                                            0.624421
# turnoutUKGeneralW10__Very likely that I will vote                                           0.676428
# turnoutUKGeneralW11__Very likely that I will vote                                           0.602598
# turnoutUKGeneralW12__Very likely that I will vote                                           0.592316
# generalElectionCertaintyW1__Completely certain                                              0.179419
# generalElectionCertaintyW2__Completely certain                                              0.189150
# generalElectionCertaintyW3__Completely certain                                              0.194102
# generalElectionCertaintyW4__Completely certain                                              0.262705
# generalElectionCertaintyUnsqW5__Completely certain                                          0.194838
# generalElectionCertaintySqW5__Completely certain                                            0.086639
# generalElectionCertaintyW5__Completely certain                                              0.226253
# generalElectionCertaintyW9__Completely certain                                              0.121041
# generalElectionCertaintyW10__Completely certain                                             0.161045
# generalElectionCertaintyW11__Completely certain                                             0.151560
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.158385
# generalElectionCertaintySqW12__Completely certain                                           0.003087
# generalElectionCertaintyW12__Completely certain                                             0.151070
# partyIdStrengthW1__Not very strong                                                         -0.163787
# partyIdStrengthW2__Not very strong                                                         -0.169762
# partyIdStrengthW3__Not very strong                                                         -0.173349
# partyIdStrengthW4__Not very strong                                                         -0.216334
# partyIdStrengthW6__Not very strong                                                         -0.183483
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.039584
# achieveReduceImmigDKW12_Yes                                                                -0.122865
# ukipPriorities_noneW2_Yes                                                                  -0.127375
# ukipPriorities_schoolW2_Yes                                                                 0.050824
# ukipPriorities_crimeW2_Yes                                                                  0.058549
# ukipPriorities_immigW2_Yes                                                                  0.150120
# ukipPriorities_nhsW2_Yes                                                                    0.028529
# partyContactLD_2W2_Yes                                                                     -0.007334
# ukipPriorities_costLiveW2_Yes                                                               0.022735
# ukipPriorities_econW2_Yes                                                                   0.031587
# ldPriorities_noneW2_Yes                                                                    -0.042048
# ldPriorities_schoolW2_Yes                                                                   0.042030
# RV2W2_factory worker                                                                        0.013371
# ldPriorities_crimeW2_Yes                                                                    0.040202
# achieveReduceImmigGrnW12_Yes                                                               -0.013670
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.040523
# partyContact1W12_Yes                                                                        0.115190
# partyContactUKIP_2W2_Yes                                                                   -0.000313
# dv1ClassExpW2_Simmons                                                                       0.007987
# partyContactLD_5W2_Yes                                                                      0.041015
# partyContactLD_4W2_Yes                                                                      0.011286
# successReduceInequalityConW12_Yes                                                           0.037329
# bestPMW12_Jeremy Corbyn                                                                    -0.000632
# partyContactUKIP_3W2_Yes                                                                    0.022456
# partyContactUKIP_4W2_Yes                                                                   -0.008737
# successReduceInequalityUKIPW12_Yes                                                          0.012661
# partyContactUKIP_5W2_Yes                                                                    0.024935
# partyContactLDW12_Yes                                                                       0.009404
# partyContactLabW12_Yes                                                                     -0.003206
# partyContactConW12_Yes                                                                      0.040379
#
#                                                     turnoutUKGeneralW5__Very likely that I will vote  \
# ageW1                                                                                       0.129728
# turnoutUKGeneralW1__Very likely that I will vote                                            0.690068
# turnoutUKGeneralW2__Very likely that I will vote                                            0.719718
# turnoutUKGeneralW3__Very likely that I will vote                                            0.722657
# turnoutUKGeneralW4__Very likely that I will vote                                            0.815531
# turnoutUKGeneralW5__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW7__Very likely that I will vote                                            0.728354
# turnoutUKGeneralW8__Very likely that I will vote                                            0.718490
# turnoutUKGeneralW9__Very likely that I will vote                                            0.642236
# turnoutUKGeneralW10__Very likely that I will vote                                           0.679955
# turnoutUKGeneralW11__Very likely that I will vote                                           0.620063
# turnoutUKGeneralW12__Very likely that I will vote                                           0.612475
# generalElectionCertaintyW1__Completely certain                                              0.152375
# generalElectionCertaintyW2__Completely certain                                              0.152723
# generalElectionCertaintyW3__Completely certain                                              0.151391
# generalElectionCertaintyW4__Completely certain                                              0.199968
# generalElectionCertaintyUnsqW5__Completely certain                                          0.216062
# generalElectionCertaintySqW5__Completely certain                                            0.085647
# generalElectionCertaintyW5__Completely certain                                              0.231657
# generalElectionCertaintyW9__Completely certain                                              0.121467
# generalElectionCertaintyW10__Completely certain                                             0.168535
# generalElectionCertaintyW11__Completely certain                                             0.131360
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.155440
# generalElectionCertaintySqW12__Completely certain                                           0.025333
# generalElectionCertaintyW12__Completely certain                                             0.140875
# partyIdStrengthW1__Not very strong                                                         -0.147187
# partyIdStrengthW2__Not very strong                                                         -0.145713
# partyIdStrengthW3__Not very strong                                                         -0.152222
# partyIdStrengthW4__Not very strong                                                         -0.188628
# partyIdStrengthW6__Not very strong                                                         -0.177718
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.038640
# achieveReduceImmigDKW12_Yes                                                                -0.124886
# ukipPriorities_noneW2_Yes                                                                  -0.121074
# ukipPriorities_schoolW2_Yes                                                                 0.043322
# ukipPriorities_crimeW2_Yes                                                                  0.052965
# ukipPriorities_immigW2_Yes                                                                  0.133257
# ukipPriorities_nhsW2_Yes                                                                    0.024842
# partyContactLD_2W2_Yes                                                                     -0.003149
# ukipPriorities_costLiveW2_Yes                                                               0.033773
# ukipPriorities_econW2_Yes                                                                   0.042556
# ldPriorities_noneW2_Yes                                                                    -0.052077
# ldPriorities_schoolW2_Yes                                                                   0.036798
# RV2W2_factory worker                                                                       -0.005341
# ldPriorities_crimeW2_Yes                                                                    0.055321
# achieveReduceImmigGrnW12_Yes                                                               -0.000049
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.043568
# partyContact1W12_Yes                                                                        0.117806
# partyContactUKIP_2W2_Yes                                                                   -0.014610
# dv1ClassExpW2_Simmons                                                                       0.030330
# partyContactLD_5W2_Yes                                                                      0.032773
# partyContactLD_4W2_Yes                                                                     -0.000652
# successReduceInequalityConW12_Yes                                                           0.040261
# bestPMW12_Jeremy Corbyn                                                                     0.020196
# partyContactUKIP_3W2_Yes                                                                   -0.002992
# partyContactUKIP_4W2_Yes                                                                   -0.027304
# successReduceInequalityUKIPW12_Yes                                                          0.007676
# partyContactUKIP_5W2_Yes                                                                    0.025247
# partyContactLDW12_Yes                                                                       0.014554
# partyContactLabW12_Yes                                                                     -0.004100
# partyContactConW12_Yes                                                                      0.011847
#
#                                                     turnoutUKGeneralW7__Very likely that I will vote  \
# ageW1                                                                                       0.140742
# turnoutUKGeneralW1__Very likely that I will vote                                            0.658385
# turnoutUKGeneralW2__Very likely that I will vote                                            0.690232
# turnoutUKGeneralW3__Very likely that I will vote                                            0.695322
# turnoutUKGeneralW4__Very likely that I will vote                                            0.713893
# turnoutUKGeneralW5__Very likely that I will vote                                            0.728354
# turnoutUKGeneralW7__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW8__Very likely that I will vote                                            0.833607
# turnoutUKGeneralW9__Very likely that I will vote                                            0.726400
# turnoutUKGeneralW10__Very likely that I will vote                                           0.767871
# turnoutUKGeneralW11__Very likely that I will vote                                           0.691635
# turnoutUKGeneralW12__Very likely that I will vote                                           0.674757
# generalElectionCertaintyW1__Completely certain                                              0.147995
# generalElectionCertaintyW2__Completely certain                                              0.152883
# generalElectionCertaintyW3__Completely certain                                              0.147473
# generalElectionCertaintyW4__Completely certain                                              0.168186
# generalElectionCertaintyUnsqW5__Completely certain                                          0.182485
# generalElectionCertaintySqW5__Completely certain                                            0.074653
# generalElectionCertaintyW5__Completely certain                                              0.194649
# generalElectionCertaintyW9__Completely certain                                              0.164457
# generalElectionCertaintyW10__Completely certain                                             0.182446
# generalElectionCertaintyW11__Completely certain                                             0.162068
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.181493
# generalElectionCertaintySqW12__Completely certain                                           0.021217
# generalElectionCertaintyW12__Completely certain                                             0.176188
# partyIdStrengthW1__Not very strong                                                         -0.143510
# partyIdStrengthW2__Not very strong                                                         -0.132948
# partyIdStrengthW3__Not very strong                                                         -0.141014
# partyIdStrengthW4__Not very strong                                                         -0.173428
# partyIdStrengthW6__Not very strong                                                         -0.160469
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.039939
# achieveReduceImmigDKW12_Yes                                                                -0.123908
# ukipPriorities_noneW2_Yes                                                                  -0.109007
# ukipPriorities_schoolW2_Yes                                                                 0.046078
# ukipPriorities_crimeW2_Yes                                                                  0.066274
# ukipPriorities_immigW2_Yes                                                                  0.128418
# ukipPriorities_nhsW2_Yes                                                                    0.037571
# partyContactLD_2W2_Yes                                                                     -0.019755
# ukipPriorities_costLiveW2_Yes                                                               0.048648
# ukipPriorities_econW2_Yes                                                                   0.037296
# ldPriorities_noneW2_Yes                                                                    -0.059028
# ldPriorities_schoolW2_Yes                                                                   0.059314
# RV2W2_factory worker                                                                        0.006579
# ldPriorities_crimeW2_Yes                                                                    0.068973
# achieveReduceImmigGrnW12_Yes                                                               -0.017941
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.035567
# partyContact1W12_Yes                                                                        0.126009
# partyContactUKIP_2W2_Yes                                                                   -0.016206
# dv1ClassExpW2_Simmons                                                                       0.036013
# partyContactLD_5W2_Yes                                                                      0.040033
# partyContactLD_4W2_Yes                                                                      0.006122
# successReduceInequalityConW12_Yes                                                           0.020414
# bestPMW12_Jeremy Corbyn                                                                     0.022934
# partyContactUKIP_3W2_Yes                                                                    0.014805
# partyContactUKIP_4W2_Yes                                                                   -0.010644
# successReduceInequalityUKIPW12_Yes                                                          0.003176
# partyContactUKIP_5W2_Yes                                                                    0.032908
# partyContactLDW12_Yes                                                                       0.025868
# partyContactLabW12_Yes                                                                     -0.014425
# partyContactConW12_Yes                                                                      0.009854
#
#                                                     turnoutUKGeneralW8__Very likely that I will vote  \
# ageW1                                                                                       0.130841
# turnoutUKGeneralW1__Very likely that I will vote                                            0.644661
# turnoutUKGeneralW2__Very likely that I will vote                                            0.668758
# turnoutUKGeneralW3__Very likely that I will vote                                            0.678343
# turnoutUKGeneralW4__Very likely that I will vote                                            0.702592
# turnoutUKGeneralW5__Very likely that I will vote                                            0.718490
# turnoutUKGeneralW7__Very likely that I will vote                                            0.833607
# turnoutUKGeneralW8__Very likely that I will vote                                            1.000000
# turnoutUKGeneralW9__Very likely that I will vote                                            0.734659
# turnoutUKGeneralW10__Very likely that I will vote                                           0.759694
# turnoutUKGeneralW11__Very likely that I will vote                                           0.685300
# turnoutUKGeneralW12__Very likely that I will vote                                           0.659687
# generalElectionCertaintyW1__Completely certain                                              0.154870
# generalElectionCertaintyW2__Completely certain                                              0.136860
# generalElectionCertaintyW3__Completely certain                                              0.142380
# generalElectionCertaintyW4__Completely certain                                              0.166327
# generalElectionCertaintyUnsqW5__Completely certain                                          0.179004
# generalElectionCertaintySqW5__Completely certain                                            0.046932
# generalElectionCertaintyW5__Completely certain                                              0.175122
# generalElectionCertaintyW9__Completely certain                                              0.159645
# generalElectionCertaintyW10__Completely certain                                             0.186578
# generalElectionCertaintyW11__Completely certain                                             0.172300
# generalElectionCertaintyUnsqW12__Completely cer...                                          0.193993
# generalElectionCertaintySqW12__Completely certain                                           0.027590
# generalElectionCertaintyW12__Completely certain                                             0.178615
# partyIdStrengthW1__Not very strong                                                         -0.148560
# partyIdStrengthW2__Not very strong                                                         -0.136047
# partyIdStrengthW3__Not very strong                                                         -0.137873
# partyIdStrengthW4__Not very strong                                                         -0.162042
# partyIdStrengthW6__Not very strong                                                         -0.167277
# ...                                                                                              ...
# achieveReduceImmigNoneW12_Yes                                                              -0.037385
# achieveReduceImmigDKW12_Yes                                                                -0.130802
# ukipPriorities_noneW2_Yes                                                                  -0.070200
# ukipPriorities_schoolW2_Yes                                                                 0.039378
# ukipPriorities_crimeW2_Yes                                                                  0.046198
# ukipPriorities_immigW2_Yes                                                                  0.108135
# ukipPriorities_nhsW2_Yes                                                                    0.018594
# partyContactLD_2W2_Yes                                                                     -0.000030
# ukipPriorities_costLiveW2_Yes                                                               0.018935
# ukipPriorities_econW2_Yes                                                                   0.013866
# ldPriorities_noneW2_Yes                                                                    -0.042307
# ldPriorities_schoolW2_Yes                                                                   0.037754
# RV2W2_factory worker                                                                       -0.015796
# ldPriorities_crimeW2_Yes                                                                    0.056421
# achieveReduceImmigGrnW12_Yes                                                               -0.029100
# scotReferendumIntentionW12_Will vote 'Yes'                                                  0.037266
# partyContact1W12_Yes                                                                        0.122946
# partyContactUKIP_2W2_Yes                                                                   -0.024897
# dv1ClassExpW2_Simmons                                                                       0.008268
# ...
# ldPriorities_schoolW2_Yes                                          -0.051744
# RV2W2_factory worker                                               -0.004672
# ldPriorities_crimeW2_Yes                                           -0.080799
# achieveReduceImmigGrnW12_Yes                                       -0.016004
# scotReferendumIntentionW12_Will vote 'Yes'                               NaN
# partyContact1W12_Yes                                               -0.029387
# partyContactUKIP_2W2_Yes                                           -0.361702
# dv1ClassExpW2_Simmons                                              -0.018670
# partyContactLD_5W2_Yes                                              0.200358
# partyContactLD_4W2_Yes                                              0.055403
# successReduceInequalityConW12_Yes                                   0.047726
# bestPMW12_Jeremy Corbyn                                            -0.083028
# partyContactUKIP_3W2_Yes                                            0.112085
# partyContactUKIP_4W2_Yes                                            0.038420
# successReduceInequalityUKIPW12_Yes                                  0.145913
# partyContactUKIP_5W2_Yes                                            1.000000
# partyContactLDW12_Yes                                              -0.051037
# partyContactLabW12_Yes                                             -0.048683
# partyContactConW12_Yes                                              0.027014
#
#                                                     partyContactLDW12_Yes  \
# ageW1                                                            0.007367
# turnoutUKGeneralW1__Very likely that I will vote                 0.007479
# turnoutUKGeneralW2__Very likely that I will vote                 0.010191
# turnoutUKGeneralW3__Very likely that I will vote                 0.010656
# turnoutUKGeneralW4__Very likely that I will vote                 0.009404
# turnoutUKGeneralW5__Very likely that I will vote                 0.014554
# turnoutUKGeneralW7__Very likely that I will vote                 0.025868
# turnoutUKGeneralW8__Very likely that I will vote                 0.021936
# turnoutUKGeneralW9__Very likely that I will vote                 0.010486
# turnoutUKGeneralW10__Very likely that I will vote                0.008992
# turnoutUKGeneralW11__Very likely that I will vote                0.028859
# turnoutUKGeneralW12__Very likely that I will vote                0.005428
# generalElectionCertaintyW1__Completely certain                  -0.044045
# generalElectionCertaintyW2__Completely certain                  -0.048243
# generalElectionCertaintyW3__Completely certain                  -0.042562
# generalElectionCertaintyW4__Completely certain                  -0.049664
# generalElectionCertaintyUnsqW5__Completely certain              -0.060105
# generalElectionCertaintySqW5__Completely certain                -0.034320
# generalElectionCertaintyW5__Completely certain                  -0.049803
# generalElectionCertaintyW9__Completely certain                  -0.054862
# generalElectionCertaintyW10__Completely certain                 -0.027858
# generalElectionCertaintyW11__Completely certain                 -0.043535
# generalElectionCertaintyUnsqW12__Completely cer...              -0.061298
# generalElectionCertaintySqW12__Completely certain               -0.031064
# generalElectionCertaintyW12__Completely certain                 -0.059675
# partyIdStrengthW1__Not very strong                               0.064869
# partyIdStrengthW2__Not very strong                               0.069946
# partyIdStrengthW3__Not very strong                               0.053852
# partyIdStrengthW4__Not very strong                               0.046522
# partyIdStrengthW6__Not very strong                               0.058803
# ...                                                                   ...
# achieveReduceImmigNoneW12_Yes                                    0.047772
# achieveReduceImmigDKW12_Yes                                     -0.023457
# ukipPriorities_noneW2_Yes                                        0.001955
# ukipPriorities_schoolW2_Yes                                     -0.062748
# ukipPriorities_crimeW2_Yes                                      -0.057659
# ukipPriorities_immigW2_Yes                                       0.011827
# ukipPriorities_nhsW2_Yes                                        -0.051421
# partyContactLD_2W2_Yes                                          -0.028053
# ukipPriorities_costLiveW2_Yes                                   -0.044430
# ukipPriorities_econW2_Yes                                       -0.103969
# ldPriorities_noneW2_Yes                                         -0.095691
# ldPriorities_schoolW2_Yes                                        0.040994
# RV2W2_factory worker                                            -0.026651
# ldPriorities_crimeW2_Yes                                         0.046378
# achieveReduceImmigGrnW12_Yes                                     0.005085
# scotReferendumIntentionW12_Will vote 'Yes'                      -0.098981
# partyContact1W12_Yes                                                  NaN
# partyContactUKIP_2W2_Yes                                         0.036154
# dv1ClassExpW2_Simmons                                            0.052774
# partyContactLD_5W2_Yes                                           0.145619
# partyContactLD_4W2_Yes                                           0.074418
# successReduceInequalityConW12_Yes                               -0.003914
# bestPMW12_Jeremy Corbyn                                         -0.023124
# partyContactUKIP_3W2_Yes                                        -0.019815
# partyContactUKIP_4W2_Yes                                         0.019390
# successReduceInequalityUKIPW12_Yes                              -0.051645
# partyContactUKIP_5W2_Yes                                        -0.051037
# partyContactLDW12_Yes                                            1.000000
# partyContactLabW12_Yes                                          -0.029154
# partyContactConW12_Yes                                           0.072883
#
#                                                     partyContactLabW12_Yes  \
# ageW1                                                            -0.050679
# turnoutUKGeneralW1__Very likely that I will vote                 -0.019289
# turnoutUKGeneralW2__Very likely that I will vote                 -0.004709
# turnoutUKGeneralW3__Very likely that I will vote                 -0.005079
# turnoutUKGeneralW4__Very likely that I will vote                 -0.003206
# turnoutUKGeneralW5__Very likely that I will vote                 -0.004100
# turnoutUKGeneralW7__Very likely that I will vote                 -0.014425
# turnoutUKGeneralW8__Very likely that I will vote                 -0.013938
# turnoutUKGeneralW9__Very likely that I will vote                 -0.001877
# turnoutUKGeneralW10__Very likely that I will vote                 0.000035
# turnoutUKGeneralW11__Very likely that I will vote                -0.015708
# turnoutUKGeneralW12__Very likely that I will vote                -0.023333
# generalElectionCertaintyW1__Completely certain                   -0.025423
# generalElectionCertaintyW2__Completely certain                   -0.012425
# generalElectionCertaintyW3__Completely certain                   -0.026128
# generalElectionCertaintyW4__Completely certain                   -0.041465
# generalElectionCertaintyUnsqW5__Completely certain               -0.024040
# generalElectionCertaintySqW5__Completely certain                 -0.043384
# generalElectionCertaintyW5__Completely certain                   -0.041968
# generalElectionCertaintyW9__Completely certain                   -0.012780
# generalElectionCertaintyW10__Completely certain                  -0.030628
# generalElectionCertaintyW11__Completely certain                  -0.038436
# generalElectionCertaintyUnsqW12__Completely cer...               -0.011362
# generalElectionCertaintySqW12__Completely certain                 0.016070
# generalElectionCertaintyW12__Completely certain                   0.001084
# partyIdStrengthW1__Not very strong                                0.018317
# partyIdStrengthW2__Not very strong                                0.004648
# partyIdStrengthW3__Not very strong                                0.024734
# partyIdStrengthW4__Not very strong                                0.016677
# partyIdStrengthW6__Not very strong                                0.028962
# ...                                                                    ...
# achieveReduceImmigNoneW12_Yes                                     0.042670
# achieveReduceImmigDKW12_Yes                                       0.043786
# ukipPriorities_noneW2_Yes                                         0.056368
# ukipPriorities_schoolW2_Yes                                      -0.033167
# ukipPriorities_crimeW2_Yes                                       -0.035632
# ukipPriorities_immigW2_Yes                                       -0.055758
# ukipPriorities_nhsW2_Yes                                         -0.058563
# partyContactLD_2W2_Yes                                            0.036928
# ukipPriorities_costLiveW2_Yes                                    -0.063601
# ukipPriorities_econW2_Yes                                        -0.084684
# ldPriorities_noneW2_Yes                                           0.073048
# ldPriorities_schoolW2_Yes                                        -0.074430
# RV2W2_factory worker                                             -0.003517
# ldPriorities_crimeW2_Yes                                         -0.025803
# achieveReduceImmigGrnW12_Yes                                      0.033502
# scotReferendumIntentionW12_Will vote 'Yes'                       -0.093099
# partyContact1W12_Yes                                                   NaN
# partyContactUKIP_2W2_Yes                                          0.020130
# dv1ClassExpW2_Simmons                                            -0.001115
# partyContactLD_5W2_Yes                                           -0.066480
# partyContactLD_4W2_Yes                                           -0.004371
# successReduceInequalityConW12_Yes                                -0.081612
# bestPMW12_Jeremy Corbyn                                           0.263940
# partyContactUKIP_3W2_Yes                                         -0.007776
# partyContactUKIP_4W2_Yes                                          0.018760
# successReduceInequalityUKIPW12_Yes                               -0.038079
# partyContactUKIP_5W2_Yes                                         -0.048683
# partyContactLDW12_Yes                                            -0.029154
# partyContactLabW12_Yes                                            1.000000
# partyContactConW12_Yes                                           -0.141567
#
#                                                     partyContactConW12_Yes
# ageW1                                                             0.123966
# turnoutUKGeneralW1__Very likely that I will vote                  0.035658
# turnoutUKGeneralW2__Very likely that I will vote                  0.032820
# turnoutUKGeneralW3__Very likely that I will vote                  0.034747
# turnoutUKGeneralW4__Very likely that I will vote                  0.040379
# turnoutUKGeneralW5__Very likely that I will vote                  0.011847
# turnoutUKGeneralW7__Very likely that I will vote                  0.009854
# turnoutUKGeneralW8__Very likely that I will vote                  0.017731
# turnoutUKGeneralW9__Very likely that I will vote                  0.011632
# turnoutUKGeneralW10__Very likely that I will vote                 0.009162
# turnoutUKGeneralW11__Very likely that I will vote                 0.028279
# turnoutUKGeneralW12__Very likely that I will vote                 0.010385
# generalElectionCertaintyW1__Completely certain                    0.020339
# generalElectionCertaintyW2__Completely certain                   -0.002775
# generalElectionCertaintyW3__Completely certain                   -0.004914
# generalElectionCertaintyW4__Completely certain                   -0.007256
# generalElectionCertaintyUnsqW5__Completely certain                0.006766
# generalElectionCertaintySqW5__Completely certain                  0.034707
# generalElectionCertaintyW5__Completely certain                    0.001770
# generalElectionCertaintyW9__Completely certain                   -0.041309
# generalElectionCertaintyW10__Completely certain                   0.003319
# generalElectionCertaintyW11__Completely certain                   0.032165
# generalElectionCertaintyUnsqW12__Completely cer...                0.022865
# generalElectionCertaintySqW12__Completely certain                -0.052206
# generalElectionCertaintyW12__Completely certain                   0.002989
# partyIdStrengthW1__Not very strong                                0.047208
# partyIdStrengthW2__Not very strong                                0.047098
# partyIdStrengthW3__Not very strong                                0.033250
# partyIdStrengthW4__Not very strong                                0.049338
# partyIdStrengthW6__Not very strong                                0.052799
# ...                                                                    ...
# achieveReduceImmigNoneW12_Yes                                    -0.122744
# achieveReduceImmigDKW12_Yes                                      -0.053935
# ukipPriorities_noneW2_Yes                                        -0.015503
# ukipPriorities_schoolW2_Yes                                       0.005051
# ukipPriorities_crimeW2_Yes                                        0.061561
# ukipPriorities_immigW2_Yes                                        0.020407
# ukipPriorities_nhsW2_Yes                                          0.053232
# partyContactLD_2W2_Yes                                           -0.004623
# ukipPriorities_costLiveW2_Yes                                     0.017363
# ukipPriorities_econW2_Yes                                         0.065861
# ldPriorities_noneW2_Yes                                          -0.040631
# ldPriorities_schoolW2_Yes                                         0.055457
# RV2W2_factory worker                                             -0.001835
# ldPriorities_crimeW2_Yes                                          0.020548
# achieveReduceImmigGrnW12_Yes                                     -0.021823
# scotReferendumIntentionW12_Will vote 'Yes'                       -0.201224
# partyContact1W12_Yes                                                   NaN
# partyContactUKIP_2W2_Yes                                         -0.013388
# dv1ClassExpW2_Simmons                                             0.028147
# partyContactLD_5W2_Yes                                           -0.038270
# partyContactLD_4W2_Yes                                            0.005504
# successReduceInequalityConW12_Yes                                 0.123835
# bestPMW12_Jeremy Corbyn                                          -0.307123
# partyContactUKIP_3W2_Yes                                         -0.002400
# partyContactUKIP_4W2_Yes                                         -0.009174
# successReduceInequalityUKIPW12_Yes                               -0.013097
# partyContactUKIP_5W2_Yes                                          0.027014
# partyContactLDW12_Yes                                             0.072883
# partyContactLabW12_Yes                                           -0.141567
# partyContactConW12_Yes                                            1.000000
#
# [6864 rows x 6864 columns]

# %%
gc.collect()
# Out:
# 0
