# %%
# %%time
dataset_name = "W29_only"
df_list = "BES_Panel"
#|BES_reduced_with_na"

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}

global BES_label_list, BES_df_list
# BES_reduced_with_na.index=BES_Panel.index
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (474, 13)
# CPU times: total: 2.84 s
# Wall time: 58.7 s

# %%
# BES_PanelW28 = BES_Panel.copy()
# lrSunak/lrStarmer

# %%
# BES_PanelW29 = BES_Panel.copy()
# scale data

# %%
# BES_PanelW27 = BES_Panel.copy()
# lr<party>, competent<Starmer|Sunak>

# %%
search(BES_Panel,"generalElection|al(\d|_)|lr(\d|_)|leftRight|lrCon|competent|like|p_past")

# W29 has 2024 vote, scales/items
# Out:
# generalElectionVote            26997
# generalElectionVoteNonVoter     4101
# likeSunak                      31098
# likeStarmer                    31098
# likeDavey                      31098
# likeSwinney                     2972
# likeIorwerth                    1943
# likeFarage                     31098
# likeRamsay                     14134
# likeDenyer                     13992
# likeHarvie                      1475
# likeSlater                      1497
# likeCon                        31098
# likeLab                        31098
# likeLD                         31098
# likeSNP                         2972
# likePC                          1943
# likeBrexitParty                31098
# likeGrn                        31098
# leftRight                      31098
# conCompetent                    7767
# labCompetent                    7767
# ldCompetent                     7767
# snpCompetent                     741
# pcCompetent                      477
# ...

# %%
BES_Panel["generalElectionVote"].value_counts()
# Out:
# generalElectionVote
# Labour                           9506
# Conservative                     5646
# Brexit Party/Reform UK           4051
# Liberal Democrat                 3614
# Green Party                      1985
# Scottish National Party (SNP)     714
# Other                             483
# An independent candidate          414
# Don't know                        342
# Plaid Cymru                       242
# Name: count, dtype: int64

# %%
## Is it that 2024: CON->LD didn't switch "because they felt the Conservative were too right-wing"?

# %%
party_replace = {"Labour":"LAB","Conservative":"CON","Brexit Party/Reform UK":"REFUK","Green Party":"GP","Scottish National Party (SNP)":"SNP",
                 "Other":"OTH","An independent candidate":"IND","Don't know":"DK","Plaid Cymru":"PC","I would/did not vote":"DNV","Liberal Democrat":"LD",
                "United Kingdom Independence Party (UKIP)":"UKIP"}
GE2024 = BES_PanelW29["generalElectionVote"].replace(party_replace)
display(GE2024.value_counts())

GE2019 = BES_PanelW29["p_past_vote_2019"].replace(party_replace)
display(GE2019.value_counts())

GECombo = GE2019.astype('object')+"-"+GE2024.astype('object')
display(GECombo.value_counts().head(10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 party_replace = {"Labour":"LAB","Conservative":"CON","Brexit Party/Reform UK":"REFUK","Green Party":"GP","Scottish National Party (SNP)":"SNP",
#       2                  "Other":"OTH","An independent candidate":"IND","Don't know":"DK","Plaid Cymru":"PC","I would/did not vote":"DNV","Liberal Democrat":"LD",
#       3                 "United Kingdom Independence Party (UKIP)":"UKIP"}
# ----> 4 GE2024 = BES_PanelW29["generalElectionVote"].replace(party_replace)
#       5 display(GE2024.value_counts())
#       7 GE2019 = BES_PanelW29["p_past_vote_2019"].replace(party_replace)
#
# NameError: name 'BES_PanelW29' is not defined

# %%
GE2024[GE2019=="CON"].value_counts()

# %%
# con destination breakdown
# CON-CON, CON-REFUK, CON-LAB, CON-LD, CON-GP/PC/SNP, CON-OTH/IND, CON-DK

# %%
combo_replace_dict = {"CON-GP":"CON-GP/PC/SNP","CON-PC":"CON-GP/PC/SNP","CON-SNP":"CON-GP/PC/SNP",
                      "CON-OTH":"CON-OTH/IND","CON-IND":"CON-OTH/IND","CON-DK":np.nan
    
}
GECONFlow = GECombo.replace(combo_replace_dict)
GECONFlow[GE2019!="CON"]=np.nan
GECONFlow.value_counts()

# %%
leftRight = BES_PanelW29["leftRight"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrCon = BES_PanelW28["lrCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrConGap = lrCon-leftRight
lrSunak = BES_PanelW28["lrCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrStarmer = BES_PanelW28["lrStarmer"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrLD = BES_PanelW28["lrLD"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrLDGap = lrLD-leftRight
lrLab = BES_PanelW28["lrLab"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)

# %%
data = pd.concat([leftRight,GECONFlow,BES_PanelW29["wt"]],axis=1)
data.columns = ["leftRight Self Placement","GE2019-2024","wt"]
palette = {"CON-CON":'blue',"CON-REFUK":'purple',"CON-OTH/IND":'grey',"CON-LD":'orange',"CON-LAB":'red',"CON-GP/PC/SNP":'green'}
sns.kdeplot(data=data,x="leftRight Self Placement",hue="GE2019-2024",weights="wt",
            # multiple='dodge',stat='count',shrink=.8,
            bw=.33,cut=0,palette=palette,);
plt.title("Where CON-2019 Voters Place Themselves On Left(0)-Right(10) Scale\nJune&July 2024 Fieldwork, weighted, split by 2024 Vote");

# %%
data = pd.concat([lrCon,GECONFlow,BES_PanelW29["wt"]],axis=1)
data.columns = ["CON Party lr placement","GE2019-2024","wt"]
palette = {"CON-CON":'blue',"CON-REFUK":'purple',"CON-OTH/IND":'grey',"CON-LD":'orange',"CON-LAB":'red',"CON-GP/PC/SNP":'green'}
sns.kdeplot(data=data,x="CON Party lr placement",hue="GE2019-2024",weights="wt",#multiple='dodge',stat='count',shrink=.8,
            cut=0,bw=.25,palette=palette);
plt.title("Where CON-2019 Voters Place Conservative Party On Left(0)-Right(10) Scale\nJune&July 2024 Fieldwork, weighted, split by 2024 Vote");

# %%
data = pd.concat([lrConGap,GECONFlow,BES_PanelW29["wt"]],axis=1)
data.columns = ["Self-Con LeftRight Placement Gap","GE2019-2024","wt"]
palette = {"CON-CON":'blue',"CON-REFUK":'purple',"CON-OTH/IND":'grey',"CON-LD":'orange',"CON-LAB":'red',"CON-GP/PC/SNP":'green'}
sns.kdeplot(data=data,x="Self-Con LeftRight Placement Gap",hue="GE2019-2024",weights="wt",#multiple='dodge',
            # stat='count', shrink=.8,
            palette=palette,cut=0,bw=.25);
plt.title("Conservative Party Is To My Right (+) or Left(+) (\nJune&July 2024 Fieldwork, weighted, split by 2024 Vote");

# %%
data = pd.concat([lrLDGap,GECONFlow,BES_PanelW29["wt"]],axis=1)
data.columns = ["Self-LD LeftRight Placement Gap","GE2019-2024","wt"]
palette = {"CON-CON":'blue',"CON-REFUK":'purple',"CON-OTH/IND":'grey',"CON-LD":'orange',"CON-LAB":'red',"CON-GP/PC/SNP":'green'}
sns.kdeplot(data=data,x="Self-LD LeftRight Placement Gap",hue="GE2019-2024",weights="wt",#multiple='dodge',
            # stat='count', shrink=.8,
            palette=palette,cut=0,bw=.25);
plt.title("Liberal Democrat Party Is To My Right (+) or Left(+) (\nJune&July 2024 Fieldwork, weighted, split by 2024 Vote");

# %%
scott_dataset = pd.read_csv("C:\\Users\\Gamer\\Downloads\\2024-UK-General-Election-Census-Constituency-Summaries-File-v1.1.csv")

# %%
scott_dataset.columns[220:290]

# %%
BES_GE_results = pd.read_stata("C:\\Users\\Gamer\\Downloads\\BES-2024-General-Election-results-file-v1.0.dta")
new_cols = ['c21Apprenticeship',
 'c21Level4plus',
 'c21LowerSchool',
 'c21NoQuals',
 'c21UpperSchool']
scott_dataset[new_cols] = BES_GE_results.set_index("pano").loc[scott_dataset["pano"]][new_cols]

# %%
# set(scott_dataset.columns).difference(set(BES_GE_results.columns))

# %%
# set(BES_GE_results.columns).difference(set(scott_dataset.columns))

# %%
# 2024 results, 2019 results, scotref and euref estimates
# census aggregates

# %%
## get some shapefile loaded DONE
## plot something on a chloropleth DONE (why is cmap such a hassle?)
## try this new feature engine DONE

## they use (stuff from feature engine) to reduce the feature set (for predicting vote)
## then apply Unupervised Random Forest to get a distance measure
## then k-means on distance (seems to me you should plot this first!)

## sounds like they're predicting "winning party vote share" ... but why?
## Multioutput regression is what we *ought* to use to predict the voteshares for *all* the parties


## Can repeat their work with single target (LAB%?)
## Can try to repeat with target vector (LAB/CON/LD ...)

# TODO
# check out "REFORM 2ND PLACES" DONE
# setup multi-reg - data prep DONE -> y= 7 value vector
# do multi-reg with RandomForestRegressor DONE (tutorial)
# do multi-reg with xgboost
# do with tensorflow

# %%
scott_dataset[scott_dataset["Second24"]=="RUK"]["Winner24"].value_counts()

scott_dataset[(scott_dataset["Winner24"]=="RUK")&(scott_dataset["Country"]=="England")]["Winner24"].value_counts()
#

# %%
scott_dataset[scott_dataset["pano"]==149]

# %%
party_col_dict = {"Lab":"r","Con":'b',"PC":'olive','Green':'green','RUK':'purple','Ind':'grey','LD':'orange','SNP':'yellow',
                 }

# %%
second_place_plot_df = scott_dataset.drop(133,errors='ignore')
second_place_plot_df["Second24"] = second_place_plot_df["Second24"].replace({"WPB":np.nan,"INet":np.nan,"NIP":np.nan})

# %%
g=sns.catplot(
    data=second_place_plot_df, kind="swarm",
    x="Winner24", y="Majority24", hue="Winner24", col="Second24",palette=party_col_dict,
    aspect=.7,col_wrap=4
)
plt.ylabel("%");
plt.hlines(scott_dataset["Majority24"].mean(),0,1,color='k',linestyles='dashdot',
           label="Mean Majority Across All UK Seats",alpha=0);
plt.legend();
g.refline(y=scott_dataset["Majority24"].mean(), color='black',linestyle='dashdot')
g.tick_params(axis='x', rotation=30);
plt.suptitle("Distribution of Seat (Party-Coloured) Majorities By Second Place Party\nDashed Line Is Average Majority Across All Seats")
# plt.xticks(rotation=90);
# Out:
# Text(0.5, 0.98, 'Distribution of Seat (Party-Coloured) Majorities By Second Place Party\nDashed Line Is Average Majority Across All Seats')

# %%
sns.swarmplot(data=scott_dataset[scott_dataset["Second24"]=="RUK"].drop(133,errors='ignore'),y="Majority24",
            x="Winner24",hue="Winner24",palette=party_col_dict);
plt.title("Majorities in Seats Where Reform Placed Second (2024 GE)\n(89 Labour Seats, 9 Conservative Seats)");
plt.ylabel("%");
plt.hlines(scott_dataset["Majority24"].mean(),0,1,color='k',linestyles='dashdot',
           label="Mean Majority Across All UK Seats");
plt.legend();

# %%
(scott_dataset[(scott_dataset["Winner24"]=="Lab")&(scott_dataset["Second24"]=="Con")]["Majority24"]<10).sum()
# Out:
# 85

# %%
(scott_dataset[(scott_dataset["Winner24"]=="Lab")&(scott_dataset["Second24"]=="RUK")]["Majority24"]<20).sum()
# Out:
# 30

# %%
scott_dataset[scott_dataset["Second24"]=="LD"]["Winner24"].value_counts()
# Out:
# Winner24
# Con    20
# Lab     6
# PC      1
# Name: count, dtype: int64

# %%
scott_cleaned = scott_dataset[scott_dataset["Country"]=="England"]
drop_cols = scott_cleaned.columns[scott_cleaned.notnull().all()==0]
scott_cleaned.drop(drop_cols,axis=1,inplace=True)

scott_cleaned = scott_cleaned.set_index("pano").drop(
    ["ONSConstID","ConstituencyName","Country","MPFirstName24","MPSurname24","Winner24","Second24","IndexOfChange"],axis=1)

scott_cleaned = pd.get_dummies(scott_cleaned).astype('float')

scott_cleaned = scott_cleaned.drop(scott_cleaned.columns[scott_cleaned.var()==0],axis=1)

scott_cleaned = scott_cleaned.drop(["Majority24","ConVote24","LabVote24","LDVote24","GreenVote24","RUKVote24","OtherVote24","TotalVote24"],axis=1)

scott_cleaned[['Con24', 'Lab24', 'LD24', 'Green24', 'RUK24', 'Other24']] = \
    scott_cleaned[['Con24', 'Lab24', 'LD24', 'Green24', 'RUK24', 'Other24']]\
    .apply(lambda x: x*scott_cleaned["Turnout24"]/100)
scott_cleaned["DNV24"]=100-scott_cleaned["Turnout24"]
scott_cleaned = scott_cleaned.drop("Turnout24",axis=1)

scott_cleaned = scott_cleaned.drop(['Majority19','ConVote19', 'LabVote19', 'LDVote19', 'GreenVote19', 'BrexitVote19', 'OtherVote19',  'TotalVote19',],axis=1)

scott_cleaned[['Con19', 'Lab19', 'LD19', 'Green19', 'Brexit19', 'Other19' ]] = \
    scott_cleaned[['Con19', 'Lab19', 'LD19', 'Green19', 'Brexit19', 'Other19']]\
    .apply(lambda x: x*scott_cleaned["Turnout19"]/100)
scott_cleaned["DNV19"]=100-scott_cleaned["Turnout19"]
scott_cleaned = scott_cleaned.drop("Turnout19",axis=1)

# drop speaker seat! pano 149
scott_cleaned = scott_cleaned.drop(149)

# OTHER is a big deal in 2024, don't think about dropping!

# %%
scott_cleaned[["Con24","Lab24","LD24","Green24","RUK24","Other24","DNV24"]]["Other24"].hist(bins=100);

# %%
import geopandas as gpd

# %%
fp = "C:\\Users\\Gamer\\Downloads\\hexConstituencies.json"
map_df = gpd.read_file(fp)
# map_df.to_crs(pyproj.CRS.from_epsg(4326), inplace=True)

# %%
map_df.plot();

# %%
party_col = {'Lab':"red", 'SNP':"yellow", 'Con':"blue", 'RUK':"purple", 'LD':"orange", 'Ind':'grey', 'Green':'green', 'PC':'olive', 'Spk':"black"}
from matplotlib.colors import LinearSegmentedColormap, ListedColormap
cmap = ListedColormap(party_col.values(),party_col.keys())

# %%
merged_df = map_df.merge(scott_dataset,left_on="PCON24CD",right_on="ONSConstID")

# %%
merged_df.plot(column="Winner24",legend=True,color=merged_df["Winner24"].apply(lambda x: party_col[x]));

# %%
merged_df = merged_df[merged_df["countryNM"]=="England"]

# %%
merged_df.plot(column="Winner24",legend=True,color=merged_df["Winner24"].apply(lambda x: party_col[x]));

# %%
merged_df.columns[0:50]
# Out:
# Index(['fid', 'PCON24CD', 'PCON24NM', 'PCON24NMW', 'name3', 'electorate',
#        'countryCD', 'countryNM', 'regionCD', 'regionNM', 'easting', 'northing',
#        'latitude', 'longitude', 'geometry', 'pano', 'ONSConstID',
#        'ConstituencyName', 'Country', 'Region', 'ConstituencyType', 'Winner24',
#        'Second24', 'Con24', 'Lab24', 'LD24', 'SNP24', 'PC24', 'Green24',
#        'RUK24', 'Other24', 'Majority24', 'Turnout24', 'ConVote24', 'LabVote24',
#        'LDVote24', 'SNPVote24', 'PCVote24', 'GreenVote24', 'RUKVote24',
#        'OtherVote24', 'TotalVote24', 'RejectedVote24', 'Electorate24',
#        'MPFirstName24', 'MPSurname24', 'MPGender24', 'IndexOfChange',
#        'Winner19', 'Second19'],
#       dtype='object')

# %%
merged_df[['ConVote24', 'LabVote24',
       'LDVote24', 'SNPVote24', 'PCVote24', 'GreenVote24', 'RUKVote24',
       'OtherVote24', 'TotalVote24', 'RejectedVote24','Electorate24',]]
# Out:
#      ConVote24  LabVote24  LDVote24  SNPVote24  PCVote24  GreenVote24  \
# 89       13770      23161      5496          0         0         2212
# 90        5383      24537      3051          0         0         5185
# 91       11497       3002     23765          0         0         2403
# 92        5392      20596      1985          0         0         4133
# 93       14489      13677      2809          0         0         2443
# ..         ...        ...       ...        ...       ...          ...
# 627      22001       9782      9867          0         0         5515
# 628      10725      15746      1590          0         0         2278
# 629      16624      20798      4727          0         0         3699
# 630      15901      11607      1755          0         0         1746
# 631      14081      19764      4052          0         0         2155
#
#      RUKVote24  OtherVote24  TotalVote24  RejectedVote24  Electorate24
# ...

# %%
## bare minimum target is CON/LAB/LD/GRN/RUK/OTH/DNV

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from feature_engine.selection import MRMR
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 3
#       1 from sklearn.datasets import load_breast_cancer
#       2 from sklearn.model_selection import train_test_split
# ----> 3 from feature_engine.selection import MRMR
#
# ModuleNotFoundError: No module named 'feature_engine'

# %%
X, y = load_breast_cancer(return_X_y=True, as_frame=True)
y = y.map({0:1, 1:0})
print(X.head())
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
y= pd.concat([y,y],axis=1).values

# %%
y = np.array([[31.4, 94], [40.5, 109], [25.0, 30]])
print(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=0)

# %%
sel = MRMR(method="FCQ", regression=False)
sel.fit(X, y)

# %%
pd.Series(sel.relevance_, index=sel.variables_).sort_values(
    ascending=False).plot.bar(figsize=(15, 4))
plt.title("Relevance")
plt.show()

# %%
sel = MRMR(
    method="RFCQ",
    scoring="roc_auc",
    param_grid = {"n_estimators": [5, 50, 500], "max_depth":[1,2,3]},
    cv=3,
    regression=False,
    random_state=42,
)

sel.fit(X, y)

# %%
pd.Series(sel.relevance_, index=sel.variables_).sort_values(
    ascending=False).plot.bar(figsize=(15, 4))
plt.title("Relevance")
plt.show()

# %%
from sklearn.datasets import fetch_california_housing

X, y = fetch_california_housing(return_X_y=True, as_frame=True)
X[['AveRooms', 'AveBedrms', 'AveOccup']] = X[['AveRooms', 'AveBedrms', 'AveOccup']].astype(int)

print(X.head())

# %%
sel = MRMR(
    variables = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup'],
    method="MIQ",
    max_features=4,
    discrete_features=[False, False, True, True, False, True],
    regression=True,
    random_state=42,
)

sel.fit(X,y)

# %%
clf

# %%
alg

# %%
# target_vars = ["Con24","Lab24","LD24","Green24","RUK24","Other24","DNV24"]
# y = scott_cleaned[target_vars].values
# X = scott_cleaned.drop(target_vars,axis=1).values

name="Con24"
pattern = "Con24"
# mask = ~BES_Panel["p_religion"].isin(["Yes - Judaism","Yes - Islam"])
df, corr_type = make_corr_summary(scott_cleaned.drop(["Lab24","LD24","Green24","RUK24","Other24","DNV24"],axis=1),
                                                     name, pattern=pattern)
display_corr(df,name,corr_type)

(explainer, shap_values, train_columns, train_index, alg,output_subfolder,metrics) = xgboost_run(
    title = "Which side in the Israeli-Palestinian conflict, if any, do you sympathise with more?",
                                    dataset=scott_cleaned.drop(["Lab24","LD24","Green24","RUK24","Other24","DNV24"],axis=1),
                                    var_list = [name],var_stub_list = [name,pattern],verbosity=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9cb73" style='display:inline'>
#   <caption>Top 20 positive (spearman) correlations for Con24</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cb73_level0_col0" class="col_heading level0 col0" >r</th>
#       <th id="T_9cb73_level0_col1" class="col_heading level0 col1" >p</th>
#       <th id="T_9cb73_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cb73_level0_row0" class="row_heading level0 row0" >Con19</th>
#       <td id="T_9cb73_row0_col0" class="data row0 col0" >0.900000</td>
#       <td id="T_9cb73_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_9cb73_row0_col2" class="data row0 col2" >542</td>
#     </tr>
#     <tr>
#       <th id="T_9cb73_level0_row1" class="row_heading level0 row1" >c21CarsFour</th>
#       <td id="T_9cb73_row1_col0" class="data row1 col0" >0.810000</td>
# ...

# %%
# target_vars = ["Con24","Lab24","LD24","Green24","RUK24","Other24","DNV24"]
# y = scott_cleaned[target_vars].values
# X = scott_cleaned.drop(target_vars,axis=1).values

name="Con24"
pattern = "Con24"
# mask = ~BES_Panel["p_religion"].isin(["Yes - Judaism","Yes - Islam"])
df, corr_type = make_corr_summary(scott_cleaned.drop(["Lab24","LD24","Green24","RUK24","Other24","DNV24"],axis=1),
                                                     name, pattern=pattern)
display_corr(df,name,corr_type)

(explainer, shap_values, train_columns, train_index, alg,output_subfolder,metrics) = xgboost_run(
    title = "Which side in the Israeli-Palestinian conflict, if any, do you sympathise with more?",
                                    dataset=scott_cleaned.drop(["LD24","Green24","RUK24","Other24","DNV24"],axis=1),
                                    var_list = ["Con24","Lab24"],var_stub_list = [name,pattern],verbosity=0,multi_target=True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9c65c" style='display:inline'>
#   <caption>Top 20 positive (spearman) correlations for Con24</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c65c_level0_col0" class="col_heading level0 col0" >r</th>
#       <th id="T_9c65c_level0_col1" class="col_heading level0 col1" >p</th>
#       <th id="T_9c65c_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c65c_level0_row0" class="row_heading level0 row0" >Con19</th>
#       <td id="T_9c65c_row0_col0" class="data row0 col0" >0.900000</td>
#       <td id="T_9c65c_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_9c65c_row0_col2" class="data row0 col2" >542</td>
#     </tr>
#     <tr>
#       <th id="T_9c65c_level0_row1" class="row_heading level0 row1" >c21CarsFour</th>
#       <td id="T_9c65c_row1_col0" class="data row1 col0" >0.810000</td>
# ...

# %%
xgb.__version__
# Out:
# '2.1.4'

# %%
shap.__version__
# Out:
# '0.46.0'

# %%
from sklearn.datasets import make_multilabel_classification
import numpy as np

X, y = make_multilabel_classification(
    n_samples=32, n_classes=5, n_labels=3, random_state=0
)
clf = xgb.XGBRegressor(tree_method="hist", multi_strategy="multi_output_tree")
clf.fit(X, y)
# multi_strategy = "multi_output_tree"
# np.testing.assert_allclose(clf.predict(X), y)
clf.predict(X)
# Out:
# array([[ 3.7375823e-04,  5.2168133e-04,  9.9990988e-01,  9.9953771e-01,
#          9.9960685e-01],
#        [ 9.9961704e-01,  9.9950856e-01,  5.8707705e-04,  9.9977481e-01,
#          5.0852843e-05],
#        [ 2.2894215e-04,  9.9962443e-01,  6.0942682e-04,  9.9982017e-01,
#          9.9953550e-01],
#        [ 5.8680773e-04,  3.4005364e-04,  3.5110107e-04,  3.8798276e-04,
#          9.9964082e-01],
#        [ 9.9994904e-01,  9.9991047e-01,  1.0002893e+00,  9.9985015e-01,
#          1.0000231e+00],
#        [ 7.4820127e-04,  9.9997020e-01,  7.9590798e-05,  9.9969554e-01,
#          4.1464763e-04],
#        [ 9.9996406e-01,  9.9996936e-01,  1.0001243e+00,  9.9998951e-01,
#          9.9987847e-01],
#        [ 7.4082207e-05,  9.9970067e-01,  2.6034593e-04, -1.3085557e-04,
#          1.2526056e-04],
#        [ 1.2612492e-05,  9.9999499e-01,  2.8785231e-04,  1.9400436e-04,
#         -2.8105278e-04],
#        [ 1.0000784e+00,  9.5898933e-05,  9.9968135e-01,  9.9970388e-01,
# ...

# %%
import argparse
from typing import Dict, List, Tuple

import numpy as np
from matplotlib import pyplot as plt

import xgboost as xgb

def plot_predt(y: np.ndarray, y_predt: np.ndarray, name: str) -> None:
    s = 25
    plt.scatter(y[:, 0], y[:, 1], c="navy", s=s, edgecolor="black", label="data")
    plt.scatter(
        y_predt[:, 0], y_predt[:, 1], c="cornflowerblue", s=s, edgecolor="black"
    )
    plt.xlim([-1, 2])
    plt.ylim([-1, 2])
    plt.show()


def gen_circle() -> Tuple[np.ndarray, np.ndarray]:
    "Generate a sample dataset that y is a 2 dim circle."
    rng = np.random.RandomState(1994)
    X = np.sort(200 * rng.rand(100, 1) - 100, axis=0)
    y = np.array([np.pi * np.sin(X).ravel(), np.pi * np.cos(X).ravel()]).T
    y[::5, :] += 0.5 - rng.rand(20, 2)
    y = y - y.min()
    y = y / y.max()
    return X, y


def rmse_model(plot_result: bool, strategy: str) -> None:
    """Draw a circle with 2-dim coordinate as target variables."""
    X, y = gen_circle()
    # Train a regressor on it
    reg = xgb.XGBRegressor(
        tree_method="hist",
        n_estimators=128,
        n_jobs=16,
        max_depth=8,
        multi_strategy=strategy,
        subsample=0.6,
    )
    reg.fit(X, y, eval_set=[(X, y)])

    y_predt = reg.predict(X)
    if plot_result:
        plot_predt(y, y_predt, "multi")


def custom_rmse_model(plot_result: bool, strategy: str) -> None:
    """Train using Python implementation of Squared Error."""

    def gradient(predt: np.ndarray, dtrain: xgb.DMatrix) -> np.ndarray:
        """Compute the gradient squared error."""
        y = dtrain.get_label().reshape(predt.shape)
        return predt - y

    def hessian(predt: np.ndarray, dtrain: xgb.DMatrix) -> np.ndarray:
        """Compute the hessian for squared error."""
        return np.ones(predt.shape)

    def squared_log(
        predt: np.ndarray, dtrain: xgb.DMatrix
    ) -> Tuple[np.ndarray, np.ndarray]:
        grad = gradient(predt, dtrain)
        hess = hessian(predt, dtrain)
        # both numpy.ndarray and cupy.ndarray works.
        return grad, hess

    def rmse(predt: np.ndarray, dtrain: xgb.DMatrix) -> Tuple[str, float]:
        y = dtrain.get_label().reshape(predt.shape)
        v = np.sqrt(np.sum(np.power(y - predt, 2)))
        return "PyRMSE", v

    X, y = gen_circle()
    Xy = xgb.DMatrix(X, y)
    results: Dict[str, Dict[str, List[float]]] = {}
    # Make sure the `num_target` is passed to XGBoost when custom objective is used.
    # When builtin objective is used, XGBoost can figure out the number of targets
    # automatically.
    booster = xgb.train(
        {
            "tree_method": "hist",
            "num_target": y.shape[1],
            "multi_strategy": strategy,
        },
        dtrain=Xy,
        num_boost_round=128,
        obj=squared_log,
        evals=[(Xy, "Train")],
        evals_result=results,
        custom_metric=rmse,
    )

    y_predt = booster.inplace_predict(X)
    if plot_result:
        plot_predt(y, y_predt, "multi")


# if __name__ == "__main__":
#     parser = argparse.ArgumentParser()
#     parser.add_argument("--plot", choices=[0, 1], type=int, default=1)
#     args = parser.parse_args()

#     # Train with builtin RMSE objective
#     # - One model per output.
#     rmse_model(args.plot == 1, "one_output_per_tree")
#     # - One model for all outputs, this is still working in progress, many features are
#     # missing.
#     rmse_model(args.plot == 1, "multi_output_tree")

#     # Train with custom objective.
#     # - One model per output.
#     custom_rmse_model(args.plot == 1, "one_output_per_tree")
#     # - One model for all outputs, this is still working in progress, many features are
#     # missing.
#     custom_rmse_model(args.plot == 1, "multi_output_tree")

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# # Create a random dataset
# rng = np.random.RandomState(1)
# X = np.sort(200 * rng.rand(100, 1) - 100, axis=0)
# y = np.array([np.pi * np.sin(X).ravel(), np.pi * np.cos(X).ravel()]).T
# y[::5, :] += 0.5 - rng.rand(20, 2)
target_vars = ["Con24","Lab24","LD24","Green24","RUK24","Other24","DNV24"]
y = scott_cleaned[target_vars].values
X = scott_cleaned.drop(target_vars,axis=1).values


# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_3 = RandomForestRegressor(max_depth=8,oob_score=True)
regr_1.fit(X, y)
regr_2.fit(X, y)
regr_3.fit(X, y)

# # Predict
# X_test = np.arange(-100.0, 100.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X)
y_2 = regr_2.predict(X)
y_3 = regr_3.predict(X)

# Plot the results
plt.figure()
s = 25
plt.scatter(y[:, 0], y[:, 1], c="navy", s=s, edgecolor="black", label="data")
plt.scatter(
    y_1[:, 0],
    y_1[:, 1],
    c="cornflowerblue",
    s=s,
    edgecolor="black",
    label="max_depth=2",
)
plt.scatter(y_2[:, 0], y_2[:, 1], c="red", s=s, edgecolor="black", label="max_depth=5")
plt.scatter(
    y_3[:, 0], y_3[:, 1], c="orange", s=s, edgecolor="black", label="max_depth=8"
)
# plt.xlim([-6, 6])
# plt.ylim([-6, 6])
plt.xlabel("target 1")
plt.ylabel("target 2")
plt.title("Multi-output Decision Tree Regression")
plt.legend(loc="best")
plt.show()

# %%
regr_3.oob_score_

# %%
regr_3.predict(X).shape,y.shape

# %%
from sklearn.tree import DecisionTreeRegressor

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(200 * rng.rand(100, 1) - 100, axis=0)
y = np.array([np.pi * np.sin(X).ravel(), np.pi * np.cos(X).ravel()]).T
y[::5, :] += 0.5 - rng.rand(20, 2)

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_3 = DecisionTreeRegressor(max_depth=8)
regr_1.fit(X, y)
regr_2.fit(X, y)
regr_3.fit(X, y)

# Predict
X_test = np.arange(-100.0, 100.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)
y_3 = regr_3.predict(X_test)

# Plot the results
plt.figure()
s = 25
plt.scatter(y[:, 0], y[:, 1], c="navy", s=s, edgecolor="black", label="data")
plt.scatter(
    y_1[:, 0],
    y_1[:, 1],
    c="cornflowerblue",
    s=s,
    edgecolor="black",
    label="max_depth=2",
)
plt.scatter(y_2[:, 0], y_2[:, 1], c="red", s=s, edgecolor="black", label="max_depth=5")
plt.scatter(
    y_3[:, 0], y_3[:, 1], c="orange", s=s, edgecolor="black", label="max_depth=8"
)
plt.xlim([-6, 6])
plt.ylim([-6, 6])
plt.xlabel("target 1")
plt.ylabel("target 2")
plt.title("Multi-output Decision Tree Regression")
plt.legend(loc="best")
plt.show()

# %%
# from keras.layers import Dense
from tensorflow.keras.layers import Dense
# from keras.layers.core import Dense
from keras.models import Sequential
from sklearn.datasets import make_regression

def get_dataset():
    # Create sample data with sklearn make_regression function
    X, y = make_regression(n_samples=1000, n_features=10, n_informative=7, n_targets=5, random_state=0)

    # Convert the data into Pandas Dataframes for easier maniplution and keeping stored column names
    # Create feature column names
    feature_cols = [
        "feature_01",
        "feature_02",
        "feature_03",
        "feature_04",
        "feature_05",
        "feature_06",
        "feature_07",
        "feature_08",
        "feature_09",
        "feature_10",
    ]

    df_features = pd.DataFrame(data=X, columns=feature_cols)

    # Create lable column names and dataframe
    label_cols = ["labels_01", "labels_02", "labels_03", "labels_04", "labels_05"]

    df_labels = pd.DataFrame(data=y, columns=label_cols)

    return df_features, df_labels

def get_model(n_inputs, n_outputs):
    model = Sequential()
    model.add(Dense(32, input_dim=n_inputs, kernel_initializer="he_uniform", activation="relu"))
    model.add(Dense(n_outputs, kernel_initializer="he_uniform"))
    model.compile(loss="mae", optimizer="adam")
    return model



# Create the datasets
X, y = get_dataset()

# Get the number of inputs and outputs from the dataset
n_inputs, n_outputs = X.shape[1], y.shape[1]



model = get_model(n_inputs, n_outputs)



model.fit(X, y, verbose=0, epochs=100)



model.evaluate(x=X, y=y)



model.predict(X.iloc[0:1, :])

# %%
shap.initjs()
explainer = shap.KernelExplainer(model=model.predict, data=X.head(50), link="identity")

# %%
############# SHAP Values for Multi-Output Regression Models

# https://shap.readthedocs.io/en/latest/example_notebooks/tabular_examples/model_agnostic/Multioutput%20Regression%20SHAP.html

# %%
import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from sklearn.datasets import make_regression

def get_dataset():
    # Create sample data with sklearn make_regression function
    n_features=204
    X, y = make_regression(n_samples=542, n_features=n_features, n_informative=7, n_targets=5, random_state=0)

    # Convert the data into Pandas Dataframes for easier maniplution and keeping stored column names
    # Create feature column names
    feature_cols = ["feature_"+ str(x) for x in range(1,n_features+1)  ]
        # "feature_01",
        # "feature_02",
        # "feature_03",
        # "feature_04",
        # "feature_05",
        # "feature_06",
        # "feature_07",
        # "feature_08",
        # "feature_09",
        # "feature_10",
    

    df_features = pd.DataFrame(data=X, columns=feature_cols)

    # Create lable column names and dataframe
    label_cols = ["labels_01", "labels_02", "labels_03", "labels_04", "labels_05"]

    df_labels = pd.DataFrame(data=y, columns=label_cols)

    return df_features, df_labels

def get_model(n_inputs, n_outputs):
    model = Sequential()
    model.add(Dense(32, input_dim=n_inputs, kernel_initializer="he_uniform", activation="relu"))
    model.add(Dense(n_outputs, kernel_initializer="he_uniform"))
    model.compile(loss="mae", optimizer="adam")
    return model

# Create the datasets
X, y = get_dataset()


# Get the number of inputs and outputs from the dataset
n_inputs, n_outputs = X.shape[1], y.shape[1]

model = get_model(n_inputs, n_outputs)

model.fit(X, y, verbose=0, epochs=100)

model.evaluate(x=X, y=y)

model.predict(X.iloc[0:1, :])
# Out:
# ...
# 1/1 [==============================] - 0s 27ms/step
# array([[146.01819, 163.6289 , 164.0096 , 160.828  , 105.30625]],
#       dtype=float32)

# %%
X
y
n_inputs, n_outputs,X.shape
# Out:
# (204, 5, (542, 204))

# %%
shap.initjs()
explainer = shap.KernelExplainer(model=model.predict, data=X.head(50), link="identity")

# Set the index of the specific example to explain
X_idx = 0

shap_value_single = explainer.shap_values(X=X.iloc[X_idx : X_idx + 1, :], nsamples=100)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
explainer.shap_values(X=X.iloc[X_idx : X_idx + 1, :,], nsamples=100).shape
# Out:
# ...
# 157/157 [==============================] - 0s 736us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[213], line 1
# ----> 1 explainer.shap_values(X=X.iloc[X_idx : X_idx + 1, :,], nsamples=100).shape
#
# File E:\Users\Gamer\anaconda3\envs\tf-n-gpu\lib\site-packages\shap\explainers\_kernel.py:271, in KernelExplainer.shap_values(self, X, **kwargs)
#     269 if self.keep_index:
#     270     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 271 explanations.append(self.explain(data, **kwargs))
#     272 if kwargs.get("gc_collect", False):
#     273     gc.collect()
#
# File E:\Users\Gamer\anaconda3\envs\tf-n-gpu\lib\site-packages\shap\explainers\_kernel.py:482, in KernelExplainer.explain(self, incoming_instance, **kwargs)
#     480 phi_var = np.zeros((self.data.groups_size, self.D))
#     481 for d in range(self.D):
# ...

# %%
X.iloc[X_idx : X_idx + 1, :].shape,shap_value_single.shape
# Out:
# ((1, 10), (1, 10, 5))

# %%
shap_value_single[:,:,current_label.value].shape
# Out:
# (1, 10)

# %%
import ipywidgets as widgets

# %%
# Create the list of all labels for the drop down list
list_of_labels = y.columns.to_list()

# Create a list of tuples so that the index of the label is what is returned
tuple_of_labels = list(zip(list_of_labels, range(len(list_of_labels))))

# Create a widget for the labels and then display the widget
current_label = widgets.Dropdown(options=tuple_of_labels, value=0, description="Select Label:")

# Display the dropdown list (Note: access index value with 'current_label.value')
current_label

# print the JS visualization code to the notebook
shap.initjs()

print(f"Current label Shown: {list_of_labels[current_label.value]}")
    # shap_values=shap_value_single[current_label.value],
shap.force_plot(
    base_value=explainer.expected_value[current_label.value],
    shap_values=shap_value_single[:,:,current_label.value],
    features=X.iloc[X_idx : X_idx + 1, :],
)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Note: We are limiting to the first 50 training examples since it takes time to calculate the full number of sampels
shap_values = explainer.shap_values(X=X.iloc[0:50, :], nsamples=100)
# Out:
# ...
# 157/157 [==============================] - 0s 787us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[214], line 2
#       1 # Note: We are limiting to the first 50 training examples since it takes time to calculate the full number of sampels
# ----> 2 shap_values = explainer.shap_values(X=X.iloc[0:50, :], nsamples=100)
#
# File E:\Users\Gamer\anaconda3\envs\tf-n-gpu\lib\site-packages\shap\explainers\_kernel.py:271, in KernelExplainer.shap_values(self, X, **kwargs)
#     269 if self.keep_index:
#     270     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 271 explanations.append(self.explain(data, **kwargs))
#     272 if kwargs.get("gc_collect", False):
#     273     gc.collect()
#
# ...

# %%
# print the JS visualization code to the notebook
shap.initjs()

print(f"Current Label Shown: {list_of_labels[current_label.value]}\n")

shap.summary_plot(shap_values=shap_values[:,:,current_label.value], features=X.iloc[0:50, :])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
print(f"Current Label Shown: {list_of_labels[current_label.value]}\n")

# print the JS visualization code to the notebook
shap.initjs()

shap.force_plot(
    base_value=explainer.expected_value[current_label.value],
    shap_values=shap_values[:,:,current_label.value],
    features=X.iloc[0:50, :],
)
# Out:
# Current Label Shown: labels_01
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
X.iloc[0:50, :].shape
# Out:
# (50, 10)

# %%
shap_values.shape
# Out:
# (50, 10, 5)

# %%
# target_vars = ["Con24","Lab24","LD24","Green24","RUK24","Other24","DNV24"]
# y = scott_cleaned[target_vars].values
# X = scott_cleaned.drop(target_vars,axis=1).values

name="Con24"
pattern = "Con24"
# mask = ~BES_Panel["p_religion"].isin(["Yes - Judaism","Yes - Islam"])
df, corr_type = make_corr_summary(scott_cleaned.drop(["Lab24","LD24","Green24","RUK24","Other24","DNV24"],axis=1),
                                                     name, pattern=pattern)
display_corr(df,name,corr_type)

(explainer, shap_values, train_columns, train_index, alg,output_subfolder,metrics) = xgboost_run(
    title = "Which side in the Israeli-Palestinian conflict, if any, do you sympathise with more?",
                                    dataset=scott_cleaned.drop(["LD24","Green24","RUK24","Other24","DNV24"],axis=1),
                                    var_list = ["Con24","Lab24"],var_stub_list = [name,pattern],verbosity=0,multi_target=True)

# %%
def get_model(n_inputs, n_outputs):
    model = Sequential()
    model.add(Dense(64, input_dim=n_inputs, kernel_initializer="he_uniform", activation="relu"))
    model.add(Dense(32, input_dim=n_inputs, kernel_initializer="he_uniform", activation="relu"))
    model.add(Dense(n_outputs, kernel_initializer="he_uniform"))
    model.compile(loss="mae", optimizer="adam")
    return model

# Create the datasets
X, y = get_dataset()

target_vars = ["Con24",]
drop_target_vars = ["LD24","Green24","RUK24","Other24","DNV24","Lab24",]
pred_vars = [x for x in scott_cleaned.columns if (x not in drop_target_vars) and (x not in target_vars)]

X = scott_cleaned[pred_vars]
y = scott_cleaned[target_vars]

# Get the number of inputs and outputs from the dataset
n_inputs, n_outputs = X.shape[1], y.shape[1]

model = get_model(n_inputs, n_outputs)

model.fit(X, y, verbose=0, epochs=100)

model.evaluate(x=X, y=y)

model.predict(X.iloc[0:1, :])
# Out:
# ...
# 1/1 [==============================] - 0s 29ms/step
# array([[472.0852]], dtype=float32)

# %%
model

# %%
n_inputs, n_outputs,X.shape
# model.get_config()
# Out:
# (204, 1, (542, 204))

# %%
X.corrwith(y[y.columns[0]]).sort_values()
# Out:
# Winner19_Lab    -0.792139
# c21Deprived3    -0.789208
# Lab19           -0.759893
# Second19_Con    -0.735267
# c21CarsNone     -0.730555
#                    ...
# c21CarsFour      0.786934
# c21CarsThree     0.790641
# Winner19_Con     0.801171
# Con19            0.913558
# Winner19_Spkr         NaN
# Length: 204, dtype: float64

# %%
# shap_values = explainer.shap_values(X=X.values)


shap_values = explainer.shap_values(X=X.iloc[0:50, :])
# Out:
# ...
# 3838/3838 [==============================] - 3s 672us/step

# %%
current_label.value
# Out:
# 3

# %%
# Note: We are limiting to the first 50 training examples since it takes time to calculate the full number of sampels
# shap_values = explainer.shap_values(X=X.iloc[0:50, :], nsamples=100)

# print the JS visualization code to the notebook
shap.initjs()

print(f"Current Label Shown: {list_of_labels[current_label.value]}\n")

shap.summary_plot(shap_values=shap_values[:,:,current_label.value], features=X.iloc[0:50, :])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# url = 'http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data'
# column_names = ['MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#                 'Acceleration', 'Model Year', 'Origin']

# raw_dataset = pd.read_csv(url, names=column_names,
#                           na_values='?', comment='\t',
#                           sep=' ', skipinitialspace=True)

# dataset = raw_dataset.copy()
# dataset = dataset.dropna()
# dataset['Origin'] = dataset['Origin'].map({1: 'USA', 2: 'Europe', 3: 'Japan'})
# dataset = pd.get_dummies(dataset, columns=['Origin'], prefix='', prefix_sep='')

# train_dataset = dataset.sample(frac=0.8, random_state=0)
# test_dataset = dataset.drop(train_dataset.index)

# train_features = train_dataset.copy()
# test_features = test_dataset.copy()

# train_labels = train_features.pop('MPG')
# test_labels = test_features.pop('MPG')

# %%
target_vars = ["Con24","LD24","Green24","RUK24","Other24","DNV24","Lab24",]
drop_target_vars = []
pred_vars = [x for x in scott_cleaned.columns if (x not in drop_target_vars) and (x not in target_vars) and (x in top_109)]

train_dataset = scott_cleaned#.sample(frac=1, random_state=0)
# test_dataset = scott_cleaned.drop(train_dataset.index)

train_features = train_dataset[pred_vars].copy()
# test_features = test_dataset[pred_vars].copy()

train_labels = train_dataset[target_vars]
# test_labels = test_dataset[target_vars]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# horsepower = np.array(train_labels)

# horsepower_normalizer = layers.Normalization(input_shape=[train_features.shape[1],], axis=None)
# horsepower_normalizer.adapt(horsepower)

# %%
# train_features.corrwith(train_labels["Con24"])

# %%
# train_labels[train_labels.columns[0]]

# %%
# horsepower_model.summary()

# %%
# %%time
horsepower_model_simple = Sequential()
horsepower_model_simple.add(Dense(32, input_shape=(train_features.shape[1],),activation='relu'))
horsepower_model_simple.add(Dense(train_labels.shape[1],activation='linear'))

horsepower_model_simple.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mean_squared_error')


normalizer = tf.keras.layers.Normalization(axis=-1)
n_outputs = train_labels.shape[1]
horsepower_model = tf.keras.Sequential([
    normalizer,
    # layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),    
    layers.Dense(n_outputs,)
])

horsepower_model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='mean_absolute_error')

history = horsepower_model_simple.fit(
    train_features,
    train_labels[train_labels.columns[0]],
    epochs=500,
    # Suppress logging.
    verbose=0,
    # Calculate validation results on 20% of the training data.
    validation_split = 0.2)

display( horsepower_model_simple.summary() )



hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
def plot_loss(history):
  plt.plot(history.history['loss'], label='loss')
  plt.plot(history.history['val_loss'], label='val_loss')
  # plt.ylim([0, 10])
  plt.xlabel('Epoch')
  plt.ylabel('Error [MPG]')
  plt.legend()
  plt.grid(True)
plot_loss(history)

display(pd.DataFrame( horsepower_model.predict(train_features),columns=target_vars,index=train_labels.index ).corrwith(train_labels))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:2
#
# NameError: name 'train_features' is not defined

# %%
train_features.shape
# Out:
# (542, 109)

# %%
train_labels[train_labels.columns[0]]
# Out:
# pano
# 7      17.925477
# 8      22.629077
# 10     22.457278
# 12     14.990356
# 19     28.217625
#          ...
# 645    18.736826
# 646     6.933532
# 647    14.385996
# 649     6.766218
# 650    18.064228
# Name: Con24, Length: 542, dtype: float64

# %%
pd.DataFrame( horsepower_model.predict(train_features),columns=target_vars,index=train_labels.index )["Con24"]#.corr(train_labels["Con24"])
# train_labels
# Out:
# 17/17 [==============================] - 0s 948us/step
# pano
# 7       2.155944
# 8       1.401672
# 10      4.261474
# 12      0.573241
# 19     11.636138
#          ...
# 645     3.092956
# 646   -10.198304
# 647     3.104980
# 649    -7.139405
# 650     6.333983
# Name: Con24, Length: 542, dtype: float32

# %%
preds = pd.DataFrame( horsepower_model.predict(train_features),columns=target_vars,index=train_labels.index )#.corrwith(pd.DataFrame(train_dataset.values))

preds
train_features.corrwith(preds["Con24"]).sort_values().dropna().tail(20)
# Out:
# 17/17 [==============================] - 0s 983us/step
# c21Age85plus                       0.361434
# c21Age50to54                       0.364796
# ConstituencyType_County            0.380362
# c21HouseOutright                   0.384890
# LD19                               0.387030
# c21HouseholdOneFamily66plus        0.419967
# c21HouseholdMarriedNoChildren      0.454432
# c21HouseMortgage                   0.456293
# c21SelfEmployedwithEmployees       0.479578
# c21NSSECLowerManager               0.484969
# c21NSSECHigherManager              0.501299
# c21SelfEmployedwithoutEmployees    0.506400
# c21DeprivedNone                    0.532380
# c21TwoAdultsEmployed               0.540095
# c21NSSECSmallEmployer              0.580658
# c21CarsTwo                         0.583395
# Winner19_Con                       0.592654
# c21CarsThree                       0.626557
# c21CarsFour                        0.636819
# Con19                              0.683573
# dtype: float64

# %%
temp = train_features.corrwith(preds["Con24"]).abs()
temp.loc[:] = 0
for target_col in train_labels.columns:
    temp = temp + train_features.corrwith(preds[target_col]).abs()
temp.sort_values(ascending=False).hist(bins=60)
# temp.sort_values(ascending=False)
# ["Winner_Spkr"]

top_109 = temp[temp>2].index

# %%
# pd.DataFrame( horsepower_model.predict(train_features),columns=target_vars,index=train_labels.index )
shap.sample(train_features, 300)
# Out:
#       RejectedVote24  Electorate24     Con19     Lab19      LD19  Green19  \
# pano
# 482             99.0       73886.0  45.16142  11.72172   8.89824  2.71653
# 222            159.0       72590.0  32.91591   4.85805  29.95914  0.00000
# 190            131.0       71685.0  18.82720  38.76304   1.64656  0.72816
# 549            137.0       73812.0  27.13536  24.70464   2.16576  1.13472
# 132            117.0       74362.0  28.62675   8.36325  27.76275  1.04625
# ...              ...           ...       ...       ...       ...      ...
# 91             219.0       79423.0  19.13080  34.02308  11.03232  2.01448
# 285            187.0       79478.0  46.17466  10.06894  15.61910  2.33730
# 421            197.0       74768.0  22.50024  31.42104   9.93324  2.86740
# 623            124.0       77538.0  18.94088  27.84512   3.21244  1.71648
# 448            165.0       71284.0  42.34644  13.52268   9.97956  2.55132
#
#       Brexit19  Other19  Electorate19  HanrettyLeave  ...  Winner19_LD  \
# ...

# %%
shap.kmeans(train_features, 100)

# %%
# %%time
sample = shap.sample(train_features,100)
explainer = shap.KernelExplainer(model=horsepower_model_simple.predict,
                                 data=sample,
                                 # data=train_features.iloc[0:50, :],
                                 link="identity",keep_index=True)
shap_values = explainer.shap_values(X=sample, nsamples=100,gc_collect=True)
# Out:
# ...
# 313/313 [==============================] - 0s 633us/step
# CPU times: total: 1min 41s
# Wall time: 1min 32s

# %%
pd.DataFrame(shap_values[:,:,0],columns=train_features.columns).abs().mean().sort_values()
# Out:
# c21EthnicityMixed                0.252317
# c21EthnicityWhiteRoma            0.267994
# c21Age65to69                     0.290757
# c21HouseholdLoneNondependents    0.294546
# c21NSSECIntermediate             0.300073
#                                    ...
# c21BornEngland                   0.712380
# c21DeprivedNone                  0.730086
# c21Age70to74                     1.262364
# c21HouseOutright                 1.286638
# c21Population                    2.487478
# Length: 109, dtype: float64

# %%
current_label
# Out:
# Dropdown(description='Select Label:', options=(('labels_01', 0), ('labels_02', 1), ('labels_03', 2), ('labels_…

# %%
shap_values.shape
# Out:
# (100, 109, 7)

# %%
# Note: We are limiting to the first 50 training examples since it takes time to calculate the full number of sampels
# shap_values = explainer.shap_values(X=X.iloc[0:50, :], nsamples=100)
# explainer = shap.KernelExplainer(model=horsepower_model.predict, data=train_features, link="identity")
# shap_values = explainer.shap_values(X=train_features)
# print the JS visualization code to the notebook
shap.initjs()

print(f"Current Label Shown: {list_of_labels[current_label.value]}\n")

shap.summary_plot(shap_values=shap_values[:,:,current_label.value], features=sample)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
horsepower_model_simple

# %%
# %%time
# sample = shap.sample(train_features,100)
# explainer = shap.KernelExplainer(model=horsepower_model.predict,
#                                  data=sample,
#                                  # data=train_features.iloc[0:50, :],
#                                  link="identity",keep_index=True)
# shap_values = explainer.shap_values(X=sample, nsamples=100,gc_collect=True)

explainer = shap.DeepExplainer(horsepower_model_simple, train_features)
shap_values = explainer.shap_values(train_features)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[856], line 9
#       1 # %%time
#       2 # sample = shap.sample(train_features,100)
#       3 # explainer = shap.KernelExplainer(model=horsepower_model.predict,
#    (...)
#       6 #                                  link="identity",keep_index=True)
#       7 # shap_values = explainer.shap_values(X=sample, nsamples=100,gc_collect=True)
# ----> 9 explainer = shap.DeepExplainer(horsepower_model_simple, train_features)
#      10 shap_values = explainer.shap_values(train_features)
#
# File E:\Users\Gamer\anaconda3\envs\tf-n-gpu\lib\site-packages\shap\explainers\_deep\__init__.py:90, in DeepExplainer.__init__(self, model, data, session, learning_phase_flags)
#      87 super().__init__(model, masker)
#      89 if framework == 'tensorflow':
# ---> 90     self.explainer = TFDeep(model, data, session, learning_phase_flags)
# ...

# %%
sample = shap.sample(train_features,100)

# explain predictions of the model on four images
e = shap.DeepExplainer(model=horsepower_model_simple, data=train_features.iloc[0:50].values)
# ...or pass tensors directly
# e = shap.DeepExplainer((horsepower_model_simple.layers[0].input, horsepower_model_simple.layers[-1].output), train_features.values)
shap_values = e.shap_values(train_features.iloc[0:50].values)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[884], line 7
#       4 e = shap.DeepExplainer(model=horsepower_model_simple, data=train_features.iloc[0:50].values)
#       5 # ...or pass tensors directly
#       6 # e = shap.DeepExplainer((horsepower_model_simple.layers[0].input, horsepower_model_simple.layers[-1].output), train_features.values)
# ----> 7 shap_values = e.shap_values(train_features.iloc[0:50].values)
#
# File E:\Users\Gamer\anaconda3\envs\tf-n-gpu\lib\site-packages\shap\explainers\_deep\__init__.py:159, in DeepExplainer.shap_values(self, X, ranked_outputs, output_rank_order, check_additivity)
#     115 def shap_values(self, X, ranked_outputs=None, output_rank_order='max', check_additivity=True):
#     116     """Return approximate SHAP values for the model applied to the data given by X.
#     117
#     118     Parameters
#    (...)
#     157
# ...

# %%
# Load dataset
df = pd.read_csv('data.csv')
df = df.drop('Unnamed: 32', axis=1)

# Encode categorical column using integers
lab_enc = preprocessing.LabelEncoder()
df['diagnosis_enc'] = lab_enc.fit_transform(df['diagnosis'])

# Get features and labels
X = df.drop(['id', 'diagnosis', 'diagnosis_enc'], axis=1)
Y = df['diagnosis_enc']

# Perform train test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# Perform standardization
scaler = StandardScaler()
scaler.fit(x_train)
X_train_norm = scaler.transform(x_train)
X_test_norm = scaler.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[885], line 2
#       1 # Load dataset
# ----> 2 df = pd.read_csv('data.csv')
#       3 df = df.drop('Unnamed: 32', axis=1)
#       5 # Encode categorical column using integers
#
# ...

# %%
import pandas as pd
from keras.layers import Dense
from keras.models import Sequential
from sklearn.datasets import make_regression

def get_dataset():
    # Create sample data with sklearn make_regression function
    X, y = make_regression(n_samples=1000, n_features=10, n_informative=7, n_targets=5, random_state=0)

    # Convert the data into Pandas Dataframes for easier maniplution and keeping stored column names
    # Create feature column names
    feature_cols = [
        "feature_01",
        "feature_02",
        "feature_03",
        "feature_04",
        "feature_05",
        "feature_06",
        "feature_07",
        "feature_08",
        "feature_09",
        "feature_10",
    ]

    df_features = pd.DataFrame(data=X, columns=feature_cols)

    # Create lable column names and dataframe
    label_cols = ["labels_01", "labels_02", "labels_03", "labels_04", "labels_05"]

    df_labels = pd.DataFrame(data=y, columns=label_cols)

    return df_features, df_labels

def get_model(n_inputs, n_outputs):
    model = Sequential()
    model.add(Dense(32, input_dim=n_inputs, kernel_initializer="he_uniform", activation="relu"))
    model.add(Dense(n_outputs, kernel_initializer="he_uniform"))
    model.compile(loss="mae", optimizer="adam")
    return model

# Create the datasets
X, y = get_dataset()

target_vars = ["Con24",]
drop_target_vars = ["LD24","Green24","RUK24","Other24","DNV24","Lab24",]
pred_vars = [x for x in scott_cleaned.columns if (x not in drop_target_vars) and (x not in target_vars)]

X = scott_cleaned[pred_vars]
y = scott_cleaned[target_vars]

# Get the number of inputs and outputs from the dataset
n_inputs, n_outputs = X.shape[1], y.shape[1]

model = get_model(n_inputs, n_outputs)

model.fit(X, y, verbose=0, epochs=100)

model.evaluate(x=X, y=y)

model.predict(X.iloc[0:1, :])

explainer = shap.KernelExplainer(model=model.predict, data=X.head(50), link="identity")

# Set the index of the specific example to explain
X_idx = 0

shap_value_single = explainer.shap_values(X=X.iloc[X_idx : X_idx + 1, :], nsamples=100)

X.iloc[X_idx : X_idx + 1, :]

import ipywidgets as widgets

# Create the list of all labels for the drop down list
list_of_labels = y.columns.to_list()

# Create a list of tuples so that the index of the label is what is returned
tuple_of_labels = list(zip(list_of_labels, range(len(list_of_labels))))

# Create a widget for the labels and then display the widget
current_label = widgets.Dropdown(options=tuple_of_labels, value=0, description="Select Label:")

# Display the dropdown list (Note: access index value with 'current_label.value')
current_label

# print the JS visualization code to the notebook
shap.initjs()

print(f"Current label Shown: {list_of_labels[current_label.value]}")
# Out:
# ...
# 157/157 [==============================] - 0s 669us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 67
#      64 # Set the index of the specific example to explain
#      65 X_idx = 0
# ---> 67 shap_value_single = explainer.shap_values(X=X.iloc[X_idx : X_idx + 1, :], nsamples=100)
#      69 X.iloc[X_idx : X_idx + 1, :]
#      71 import ipywidgets as widgets
#
# File E:\Users\Gamer\anaconda3\envs\tf-n-gpu\lib\site-packages\shap\explainers\_kernel.py:271, in KernelExplainer.shap_values(self, X, **kwargs)
#     269 if self.keep_index:
#     270     data = convert_to_instance_with_index(data, column_name, index_value[i:i + 1], index_name)
# --> 271 explanations.append(self.explain(data, **kwargs))
#     272 if kwargs.get("gc_collect", False):
#     273     gc.collect()
#
# ...

# %%
shap.force_plot(
    base_value=explainer.expected_value[current_label.value],
    shap_values=shap_value_single[:,:,current_label.value],
    features=X.iloc[X_idx : X_idx + 1, :],
)
# Out:
# <div id='iM4PEBT2252JAFVJAYRC8'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
# ...

# %%
# explainer = shap.Explainer(model=model.predict, data=X.head(50), link="identity")

explainer = shap.GradientExplainer(model=model,data=X.head(50).values)

# %%
# Note: We are limiting to the first 50 training examples since it takes time to calculate the full number of sampels
shap_values = explainer.shap_values(X=X.iloc[0:50, :].values, nsamples=200)

# print the JS visualization code to the notebook
shap.initjs()

print(f"Current Label Shown: {list_of_labels[current_label.value]}\n")

shap.summary_plot(shap_values=shap_values[:,:,current_label.value], features=X.iloc[0:50, :])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
X.iloc[0:50, :].values
# Out:
# array([[1.790000e+02, 7.855300e+04, 3.836025e+01, ..., 1.000000e+00,
#         0.000000e+00, 3.250000e+01],
#        [1.560000e+02, 7.026800e+04, 4.503767e+01, ..., 1.000000e+00,
#         0.000000e+00, 3.530000e+01],
#        [1.840000e+02, 7.402500e+04, 3.560505e+01, ..., 1.000000e+00,
#         0.000000e+00, 2.590000e+01],
#        ...,
#        [1.480000e+02, 8.001100e+04, 2.912147e+01, ..., 1.000000e+00,
#         0.000000e+00, 3.530000e+01],
#        [1.380000e+02, 7.962200e+04, 1.844094e+01, ..., 0.000000e+00,
#         0.000000e+00, 4.190000e+01],
#        [1.800000e+02, 7.493300e+04, 3.906914e+01, ..., 1.000000e+00,
#         0.000000e+00, 3.090000e+01]])

# %%
X
# Out:
#       RejectedVote24  Electorate24     Con19     Lab19      LD19  Green19  \
# pano
# 7              179.0       78553.0  38.36025  14.93775  11.81250  2.39625
# 8              156.0       70268.0  45.03767  13.92344   3.62967  1.19048
# 10             184.0       74025.0  35.60505  27.29844   8.16582  2.11926
# 12             105.0       71546.0  41.24064  17.31926   4.06980  1.97030
# 19             214.0       77969.0  45.63220  11.83840  14.30725  3.00490
# ...              ...           ...       ...       ...       ...      ...
# 645            137.0       77329.0  42.82983  15.00588   5.30199  2.56230
# 646            142.0       77767.0  17.50074  31.02060   4.04490  2.02536
# 647            109.0       79918.0  41.40280   4.49984  22.15032  1.99360
# 649            228.0       79557.0  18.58482  37.73160   5.23158  2.80311
# 650            184.0       76228.0  37.37139  22.54482  14.05851  0.01506
#
#       Brexit19  Other19  Electorate19  HanrettyLeave  ...  Winner19_LD  \
# ...
