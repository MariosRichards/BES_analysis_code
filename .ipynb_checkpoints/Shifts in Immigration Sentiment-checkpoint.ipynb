# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import gc
import re

from itertools import cycle
from IPython.display import display
import pickle, os

import seaborn as sns

encoding = "ISO-8859-1"

import Jupyter_module_loader

# %%
# you should clone this git to this subdirectory (in some directory - I call it BES_analysis - doesn't matter though)

if os.getcwd().split(os.sep)[-1] != 'BES_analysis_code':
    raise Exception("Stop! You're in the wrong directory - should be in 'BES_analysis_code'")

BES_code_folder   = "../BES_analysis_code/" # we should be here!
BES_small_data_files = BES_code_folder + "small data files" + os.sep
if not os.path.exists( BES_small_data_files ):
    os.makedirs( BES_small_data_files )

# we should create these if they don't already exist
BES_data_folder   = "../BES_analysis_data/"
if not os.path.exists( BES_data_folder ):
    os.makedirs( BES_data_folder )

BES_output_folder = "../BES_analysis_output/"
if not os.path.exists( BES_output_folder ):
    os.makedirs( BES_output_folder )
    
BES_file_manifest = pd.read_csv( BES_small_data_files + "BES_file_manifest.csv" )

BES_R_data_files = BES_data_folder + "R_data" + os.sep
if not os.path.exists( BES_R_data_files ):
    os.makedirs( BES_R_data_files )

# %%
dataset_name = "W13_comb"

# %%
# %%time

manifest = BES_file_manifest[ BES_file_manifest["Name"] == dataset_name ]

data_subfolder = BES_data_folder + dataset_name + os.sep

dataset_filename = manifest["Stata_Filename"].values[0]
# dataset_description = manifest["Friendlier_Description"].values[0]
# dataset_citation = manifest["Citation"].values[0]
# dataset_start = manifest["Date_Start"].values[0]
# dataset_stop = manifest["Date_Stop"].values[0]
# dataset_wave = manifest["Wave No"].values[0]

BES_Panel = pd.read_stata( data_subfolder + dataset_filename )
print("BES_Panel", BES_Panel.shape )

####

BES_numeric = pd.read_hdf( data_subfolder + "BESnumeric.hdf", "BESnumeric" )
print("BES_numeric",  BES_numeric.shape )

var_type    = pd.read_csv( data_subfolder + "var_type.csv", encoding=encoding)
var_type.set_index("Unnamed: 0", inplace=True)
print("var_type",  var_type.shape )

fname = data_subfolder + "cat_dictionary.pkl"
with open(fname, "rb") as f:
    cat_dictionary = pickle.load( f )
    
####

BES_non_numeric = pd.read_hdf( data_subfolder + "BESnon_numeric.hdf", "BESnon_numeric" )
print("BES_non_numeric",  BES_non_numeric.shape )

BES_reduced = pd.read_hdf( data_subfolder + "BES_reduced.hdf", "BES_reduced" )
print("BES_reduced",  BES_reduced.shape )

BES_reduced_with_na = pd.read_hdf( data_subfolder + "BES_reduced_with_na.hdf", "BES_reduced_with_na")
print("BES_reduced_with_na", BES_reduced_with_na.shape )

fname = data_subfolder + "new_old_col_names.pkl"
with open(fname, "rb") as f:
    new_old_col_names = pickle.load(f)
# Out:
# BES_Panel (69486, 5173)
# BES_numeric (69486, 4993)
# var_type (5173, 13)
# BES_non_numeric (69486, 125)
# BES_reduced (69486, 2526)
# BES_reduced_with_na (69486, 2526)
# Wall time: 24min 15s

# %%
from sklearn import datasets
from sklearn.decomposition import PCA, IncrementalPCA, NMF, TruncatedSVD, FastICA, FactorAnalysis, SparsePCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from gaussian_kde import gaussian_kde
from utility import display_components, display_pca_data, weighted_kde

# %%
[x for x in BES_Panel.columns if "imm" in x.lower()]
# immigEcon, immigCultural 

# immigrationLevel SINGLE CHOICE W4W6
# immigContributeTake SCALE W7W8

# immigSelf W7W8W9W10W11W12W13
# immig<parties> W7W8W9W10W11W12W13

# immigrantsWelfareState DYNAMIC GRIDW1W2W3W4W7W8W10W11Topup
# immigEcon W1W2W3W4W6W7W8W10W11W13
# immigCultural W1W2W3W4W6W7W8W10W11W13

# changeImmig The level of immigration  W1W2W3W4W7W8W10W11
# changeImmigLab GRIDW1W2W3W4W7W10

# tryReduceImmig<parties> W4

# achieveReduceImmig<parties> W4W7W9W10W11W12

# responsibleImmig<parties> W1W2W3W4

# govtHandleImmig GRIDW1W2W3W4W7
# labHandleImmig GRID W1W2W3W4W7
 # <parties>Priorities_immig W1W2W3W4W6W9

# controlImmig W8W9W10W11W13

# effectsEUImmigration W7W8W10W11W13
# Out:
# ['changeImmigW1',
#  'responsibleImmigConservativesW1',
#  'responsibleImmigLibDemsW1',
#  'responsibleImmigLabourW1',
#  'responsibleImmigScottishGovtW1',
#  'responsibleImmigWelshGovtW1',
#  'responsibleImmigNoneW1',
#  'responsibleImmigDontKnowW1',
#  'changeImmigLabW1',
#  'immigEconW1',
#  'immigCulturalW1',
#  'immigrantsWelfareStateW1',
#  'govtHandleImmigW1',
#  'labHandleImmigW1',
#  'conPriorities_immigW1',
#  'labPriorities_immigW1',
#  'ldPriorities_immigW1',
#  'ukipPriorities_immigW1',
#  'changeImmigW2',
#  'responsibleImmigConservativesW2',
#  'responsibleImmigLibDemsW2',
#  'responsibleImmigLabourW2',
#  'responsibleImmigScottishGovtW2',
#  'responsibleImmigWelshGovtW2',
#  'responsibleImmigNoneW2',
#  'responsibleImmigDontKnowW2',
#  'changeImmigLabW2',
#  'immigrantsWelfareStateW2',
#  'immigEconW2',
#  'immigCulturalW2',
#  'conPriorities_immigW2',
#  'labPriorities_immigW2',
#  'ldPriorities_immigW2',
#  'ukipPriorities_immigW2',
#  'govtHandleImmigW2',
#  'labHandleImmigW2',
#  'changeImmigW3',
#  'responsibleImmigConservativesW3',
#  'responsibleImmigLibDemsW3',
#  'responsibleImmigLabourW3',
#  'responsibleImmigScottishGovtW3',
#  'responsibleImmigWelshGovtW3',
#  'responsibleImmigNoneW3',
#  'responsibleImmigDontKnowW3',
#  'changeImmigLabW3',
#  'immigrantsWelfareStateW3',
#  'immigEconW3',
#  'immigCulturalW3',
#  'govtHandleImmigW3',
#  'labHandleImmigW3',
#  'conPriorities_immigW3',
#  'labPriorities_immigW3',
#  'ldPriorities_immigW3',
#  'ukipPriorities_immigW3',
#  'changeImmigW4',
#  'responsibleImmigConservativesW4',
#  'responsibleImmigLibDemsW4',
#  'responsibleImmigLabourW4',
#  'responsibleImmigScottishGovtW4',
#  'responsibleImmigWelshGovtW4',
#  'responsibleImmigNoneW4',
#  'responsibleImmigDontKnowW4',
#  'changeImmigLabW4',
#  'immigrationLevelW4',
#  'immigrantsWelfareStateW4',
#  'immigEconW4',
#  'immigCulturalW4',
#  'tryReduceImmigConW4',
#  'tryReduceImmigLabW4',
#  'tryReduceImmigLDW4',
#  'tryReduceImmigSNPW4',
#  'tryReduceImmigPCW4',
#  'tryReduceImmigUKIPW4',
#  'tryReduceImmigGrnW4',
#  'tryReduceImmigNoneW4',
#  'tryReduceImmigDKW4',
#  'achieveReduceImmigConW4',
#  'achieveReduceImmigLabW4',
#  'achieveReduceImmigLDW4',
#  'achieveReduceImmigSNPW4',
#  'achieveReduceImmigPCW4',
#  'achieveReduceImmigUKIPW4',
#  'achieveReduceImmigGrnW4',
#  'achieveReduceImmigNoneW4',
#  'achieveReduceImmigDKW4',
#  'govtHandleImmigW4',
#  'labHandleImmigW4',
#  'conPriorities_immigW4',
#  'labPriorities_immigW4',
#  'ldPriorities_immigW4',
#  'ukipPriorities_immigW4',
#  'conPriorities2_immigW4',
#  'labPriorities2_immigW4',
#  'ldPriorities2_immigW4',
#  'ukipPriorities2_immigW4',
#  'immigrationLevelW6',
#  'conPriorities_immigW6',
#  'labPriorities_immigW6',
#  'ldPriorities_immigW6',
#  'ukipPriorities_immigW6',
#  'changeImmigW7',
#  'changeImmigLabW7',
#  'immigContributeTakeW7',
#  'effectsEUImmigrationW7',
#  'immigrantsWelfareStateW7',
#  'immigEconW7',
#  'immigCulturalW7',
#  'immigSelfW7',
#  'immigConW7',
#  'immigLabW7',
#  'immigLDW7',
#  'immigSNPW7',
#  'immigPCW7',
#  'immigUKIPW7',
#  'immigGreenW7',
#  'achieveReduceImmigConW7',
#  'achieveReduceImmigLabW7',
#  'achieveReduceImmigLDW7',
#  'achieveReduceImmigSNPW7',
#  'achieveReduceImmigPCW7',
#  'achieveReduceImmigUKIPW7',
#  'achieveReduceImmigGrnW7',
#  'achieveReduceImmigNoneW7',
#  'achieveReduceImmigDKW7',
#  'govtHandleImmigW7',
#  'labHandleImmigW7',
#  'changeImmigW8',
#  'immigContributeTakeW8',
#  'effectsEUImmigrationW8',
#  'immigrantsWelfareStateW8',
#  'controlImmigW8',
#  'immigEconW8',
#  'immigCulturalW8',
#  'immigSelfW8',
#  'immigConW8',
#  'immigLabW8',
#  'immigLDW8',
#  'immigSNPW8',
#  'immigPCW8',
#  'immigUKIPW8',
#  'immigGreenW8',
#  'controlImmigW9',
#  'immigSelfW9',
#  'immigConW9',
#  'immigLabW9',
#  'immigLDW9',
#  'immigSNPW9',
#  'immigPCW9',
#  'immigUKIPW9',
#  'immigGreenW9',
#  'achieveReduceImmigConW9',
#  'achieveReduceImmigLabW9',
#  'achieveReduceImmigLDW9',
#  'achieveReduceImmigSNPW9',
#  'achieveReduceImmigPCW9',
#  'achieveReduceImmigUKIPW9',
#  'achieveReduceImmigGrnW9',
#  'achieveReduceImmigNoneW9',
#  'achieveReduceImmigDKW9',
#  'conPriorities_immigW9',
#  'labPriorities_immigW9',
#  'ldPriorities_immigW9',
#  'ukipPriorities_immigW9',
#  'controlImmigW10',
#  'effectsEUImmigrationW10',
#  'immigEconW10',
#  'immigCulturalW10',
#  'immigSelfW10',
#  'immigConW10',
#  'immigLabW10',
#  'immigLDW10',
#  'immigSNPW10',
#  'immigPCW10',
#  'immigUKIPW10',
#  'immigGreenW10',
#  'achieveReduceImmigConW10',
#  'achieveReduceImmigLabW10',
#  'achieveReduceImmigLDW10',
#  'achieveReduceImmigSNPW10',
#  'achieveReduceImmigPCW10',
#  'achieveReduceImmigUKIPW10',
#  'achieveReduceImmigGrnW10',
#  'achieveReduceImmigNoneW10',
#  'achieveReduceImmigDKW10',
#  'changeImmigW10',
#  'changeImmigLabW10',
#  'discrimMenW10',
#  'discrimMuslimsW10',
#  'immigrantsWelfareStateW10',
#  'controlImmigW11',
#  'effectsEUImmigrationW11',
#  'immigEconW11',
#  'immigCulturalW11',
#  'immigSelfW11',
#  'immigConW11',
#  'immigLabW11',
#  'immigLDW11',
#  'immigSNPW11',
#  'immigPCW11',
#  'immigUKIPW11',
#  'immigGreenW11',
#  'achieveReduceImmigConW11',
#  'achieveReduceImmigLabW11',
#  'achieveReduceImmigLDW11',
#  'achieveReduceImmigSNPW11',
#  'achieveReduceImmigPCW11',
#  'achieveReduceImmigUKIPW11',
#  'achieveReduceImmigGrnW11',
#  'achieveReduceImmigNoneW11',
#  'achieveReduceImmigDKW11',
#  'changeImmigW11',
#  'immigrantsWelfareStateW11',
#  'achieveReduceImmigConW12',
#  'achieveReduceImmigLabW12',
#  'achieveReduceImmigLDW12',
#  'achieveReduceImmigSNPW12',
#  'achieveReduceImmigPCW12',
#  'achieveReduceImmigUKIPW12',
#  'achieveReduceImmigGrnW12',
#  'achieveReduceImmigNoneW12',
#  'achieveReduceImmigDKW12',
#  'immigSelfW12',
#  'immigConW12',
#  'immigLabW12',
#  'immigLDW12',
#  'immigSNPW12',
#  'immigPCW12',
#  'immigUKIPW12',
#  'immigGreenW12',
#  'controlImmigW13',
#  'effectsEUImmigrationW13',
#  'immigEconW13',
#  'immigCulturalW13',
#  'immigSelfW13',
#  'immigConW13',
#  'immigLabW13',
#  'immigLDW13',
#  'immigSNPW13',
#  'immigPCW13',
#  'immigUKIPW13',
#  'immigGreenW13']

# %%
# euMIISmall -> immigration selected
# EUMIICategory -> immigration
['EUMIICategoryW7', 'euMIISmallW7', 'EUMIICategoryW8', 'euMIISmallW8']

# %%
[x for x in BES_reduced.columns if "eumii" in x.lower()]
# Out:
# []

# %%
[x for x in BES_Panel.columns if "eumii" in x.lower()]
# Out:
# ['EUMIICategoryW7', 'euMIISmallW7', 'EUMIICategoryW8', 'euMIISmallW8']

# %%
temp = BES_Panel[[x for x in BES_Panel.columns if "eumii" in x.lower()]]
temp2 = (temp == "immigration") | (temp == "Immigration")
temp3 = temp2.astype('float')
temp3.columns = [x+"_immigration" for x in temp3.columns]
eumii_vars = temp3

# %%
# euPriorityBalance SINGLE CHOICEW10W11W12W13
# Brexit priority: access to single market versus controlling immigration?

# %%
[x for x in BES_Panel.columns if re.match("miilabelW\d",x)]
# Out:
# ['miilabelW1',
#  'miilabelW2',
#  'miilabelW3',
#  'miilabelW4',
#  'miilabelW5',
#  'miilabelW6']

# %%
temp = BES_Panel[[x for x in BES_Panel.columns if re.match("miilabelW\d",x)]]
temp2 = (temp == "immigration") | (temp == "Immigration")
temp3 = temp2.astype('float')
temp3.columns = [x+"_immigration" for x in temp3.columns]
mii_vars = temp3
# miilabel W1W2W3W4W5W6
#

# %%
# [x for x in BES_immig.columns if "discrim" in x]

# %%
BES_immig = pd.concat( [ BES_reduced[[x for x in BES_reduced.columns if "imm" in x.lower()]].drop("miilabelW1_immigration",axis=1), eumii_vars, mii_vars], axis=1)
BES_immig = BES_immig.drop([x for x in BES_immig.columns if "discrim" in x], axis=1)

# %%
Treatment = dataset_name + "_immigration"

# %%
output_subfolder = BES_output_folder + Treatment + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
# normalise data (subtract out the mean, divide through by standard deviation)
clean_feature_set_std = StandardScaler().fit_transform(BES_immig.values )
BES_std = pd.DataFrame(      clean_feature_set_std,
                             columns = BES_immig.columns,
                             index   = BES_immig.index      )

# %%
# %%time
# 5 mins
## RUN (some variant of) PCA (potentially v slow!)
n_components = BES_std.shape[1]
# n_components = 2
# (svd_solver='full', n_components='mle',whiten=True)
# decomp = PCA(n_components = n_components,svd_solver='full')
# decomp = FastICA(algorithm='deflation', fun='exp', fun_args=None, max_iter=1000,
#     n_components=None, random_state=None, tol=0.07, w_init=None, whiten=False) # 2h 1min 4s "fast"
# decomp = SparsePCA(n_components=n_components, alpha=2,max_iter=1000,n_jobs=4,tol=1e-10, verbose=True) # 5min
#
# alpha=2 -> 1hr

decomp = FactorAnalysis(svd_method = 'lapack',n_components = n_components) ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 
# ,n_components=30

X_r = decomp.fit_transform(BES_std)

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_reduced.index)
# Out:
# Wall time: 9.45 s

# %%
# treatdir = BES_data_folder+Treatment
# subdir = BES_data_folder+Treatment+decomp_method
load_suff = "FactorAnalysis"
save = True # False => Load

if save & ( 'decomp' in globals() ): # SAVE    ##( 'decomp' not in globals() )
    decomp_method = str(decomp).split("(")[0] 
    subdir = output_subfolder + decomp_method
    fname = subdir+ os.sep + decomp_method
    # create dir, save decomp object, BES_decomp, BES_std    
    if not os.path.exists(subdir): os.makedirs(subdir)
    with open(fname+".pkl", "wb") as f: pickle.dump( decomp, f )
    BES_decomp.to_hdf(fname+".hdf"        , decomp_method)
    BES_std.to_hdf(   fname+"_std"+".hdf" , decomp_method)
    
else: # LOAD decomp results (default is SAVE)
    decomp_method = load_suff
    subdir = output_subfolder + os.sep + decomp_method    
    fname = subdir + os.sep + decomp_method
    if not os.path.exists(subdir): raise Exception(subdir + ' does not exist!')
    # load decomp object, BES_decomp, BES_std, n_components
    with open(fname+".pkl", "rb") as f: decomp = pickle.load(f) 
    BES_decomp = pd.read_hdf(fname+".hdf")
    BES_std    = pd.read_hdf(fname+"_std"+".hdf")
    n_components = decomp.components_.shape[0]

# %%
display_pca_data(n_components, decomp, BES_std)
# Out:
# average log-likelihood of all samples: -184.3192984628109
# number of iterations: 2

# %%
(BES_decomp, comp_labels, comp_dict) = display_components(n_components, decomp,
                                                          BES_immig.columns, BES_decomp, manifest, 
                                                          save_folder = subdir,  
                                                          show_first_x_comps= 4, show_histogram = False)

# %%
# SUPER USEFUL FOR FEATURE EXTRACTION/VARIABLE PREP!

if hasattr(decomp, 'noise_variance_'):
    if not isinstance(decomp.noise_variance_, float):
        NoiseVariance = pd.DataFrame( decomp.noise_variance_ , index = BES_std.columns, columns = ["noise_variance_"])
        NoiseVariance.hist( bins = int(len( NoiseVariance )/10) )
        NoiseVariance = NoiseVariance.sort_values(by="noise_variance_")
        display( NoiseVariance )
        display( NoiseVariance[ NoiseVariance["noise_variance_"]>.9 ].sort_index() )
# Out:
#                                            noise_variance_
# immigEconW2__Good for economy                     0.382414
# immigEconW7__Good for economy                     0.387306
# immigCulturalW2__Enriches cultural life           0.389836
# immigEconW8__Good for economy                     0.393393
# immigCulturalW7__Enriches cultural life           0.401314
# immigEconW4__Good for economy                     0.402059
# immigCulturalW11__Enriches cultural life          0.403007
# immigCulturalW8__Enriches cultural life           0.404270
# immigEconW3__Good for economy                     0.410145
# immigSelfW8__Allow many more                      0.412613
# immigCulturalW10__Enriches cultural life          0.413385
# immigrantsWelfareStateW7__Strongly agree          0.413880
# immigCulturalW1__Enriches cultural life           0.417827
# immigCulturalW4__Enriches cultural life           0.418194
# immigrantsWelfareStateW4__Strongly agree          0.419998
# immigrantsWelfareStateW3__Strongly agree          0.421849
# immigEconW1__Good for economy                     0.421895
# immigrantsWelfareStateW2__Strongly agree          0.423518
# immigCulturalW3__Enriches cultural life           0.423902
# immigSelfW11__Allow many more                     0.426724
# immigSelfW10__Allow many more                     0.427953
# immigSelfW7__Allow many more                      0.429043
# immigrantsWelfareStateW8__Strongly agree          0.429582
# euPriorityBalanceW11__Control immigration         0.429862
# immigEconW11__Good for economy                    0.436471
# immigEconW10__Good for economy                    0.441863
# immigrantsWelfareStateW1__Strongly agree          0.453967
# immigrantsWelfareStateW11__Strongly agree         0.457664
# immigCulturalW13__Enriches cultural life          0.458888
# immigSelfW9__Allow many more                      0.462116
# ...                                                    ...
# achieveReduceImmigLabW11_Yes                      0.749951
# effectsEUImmigrationW7__Much higher               0.751002
# responsibleImmigLibDemsW4_Yes                     0.754727
# immigConW11__Allow many more                      0.756000
# achieveReduceImmigDKW9_Yes                        0.762422
# responsibleImmigLibDemsW1_Yes                     0.762686
# achieveReduceImmigDKW12_Yes                       0.762879
# immigUKIPW9__Allow many more                      0.763093
# achieveReduceImmigDKW10_Yes                       0.763593
# achieveReduceImmigPCW4_Yes                        0.765219
# achieveReduceImmigLabW12_Yes                      0.766014
# immigUKIPW11__Allow many more                     0.766849
# responsibleImmigDontKnowW4_Yes                    0.771667
# immigUKIPW10__Allow many more                     0.773652
# responsibleImmigDontKnowW3_Yes                    0.784525
# responsibleImmigDontKnowW2_Yes                    0.786130
# achieveReduceImmigConW7_Yes                       0.790322
# achieveReduceImmigGrnW4_Yes                       0.791008
# achieveReduceImmigLDW11_Yes                       0.794912
# achieveReduceImmigLDW12_Yes                       0.803192
# achieveReduceImmigLDW9_Yes                        0.805431
# responsibleImmigDontKnowW1_Yes                    0.806291
# achieveReduceImmigSNPW4_Yes                       0.814051
# achieveReduceImmigLDW4_Yes                        0.820084
# tryReduceImmigGrnW4_Yes                           0.821974
# achieveReduceImmigGrnW12_Yes                      0.825021
# achieveReduceImmigGrnW11_Yes                      0.834623
# achieveReduceImmigGrnW9_Yes                       0.838234
# achieveReduceImmigLDW7_Yes                        0.838574
# achieveReduceImmigGrnW7_Yes                       0.856383
#
# [152 rows x 1 columns]
# Empty DataFrame
# Columns: [noise_variance_]
# Index: []

# %%
BES_decomp[0].hist()

# %%
BES_export_to_R = BES_immig.apply(lambda x: x.astype('category'))
BES_export_to_R = BES_export_to_R.apply(lambda x: x.cat.remove_unused_categories())
BES_export_to_R = BES_export_to_R.apply(lambda x: x.cat.codes)
BES_export_to_R = BES_export_to_R.replace(-1,np.nan)

filename = Treatment+"_export_to_R"

BES_export_to_R.to_stata(BES_R_data_files + filename + ".dta")
display(filename)

# %%
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\io\stata.py:2121: InvalidColumnName:
# Not all pandas column names were valid Stata variable names.
# The following replacements have been made:
#
#     b'changeImmigW1__Getting a lot higher'   ->   changeImmigW1__Getting_a_lot_hig
#     b'changeImmigLabW1__Getting a lot higher'   ->   changeImmigLabW1__Getting_a_lot_
#     b'immigEconW1__Good for economy'   ->   immigEconW1__Good_for_economy
#     b'immigCulturalW1__Enriches cultural life'   ->   immigCulturalW1__Enriches_cultur
#     b'immigrantsWelfareStateW1__Strongly agree'   ->   immigrantsWelfareStateW1__Strong
#     b'changeImmigW2__Getting a lot higher'   ->   changeImmigW2__Getting_a_lot_hig
#     b'changeImmigLabW2__Getting a lot higher'   ->   changeImmigLabW2__Getting_a_lot_
#     b'immigrantsWelfareStateW2__Strongly agree'   ->   immigrantsWelfareStateW2__Strong
#     b'immigEconW2__Good for economy'   ->   immigEconW2__Good_for_economy
#     b'immigCulturalW2__Enriches cultural life'   ->   immigCulturalW2__Enriches_cultur
#     b'changeImmigW3__Getting a lot higher'   ->   changeImmigW3__Getting_a_lot_hig
#     b'changeImmigLabW3__Getting a lot higher'   ->   changeImmigLabW3__Getting_a_lot_
#     b'immigrantsWelfareStateW3__Strongly agree'   ->   immigrantsWelfareStateW3__Strong
#     b'immigEconW3__Good for economy'   ->   immigEconW3__Good_for_economy
#     b'immigCulturalW3__Enriches cultural life'   ->   immigCulturalW3__Enriches_cultur
#     b'changeImmigW4__Getting a lot higher'   ->   changeImmigW4__Getting_a_lot_hig
#     b'changeImmigLabW4__Getting a lot higher'   ->   changeImmigLabW4__Getting_a_lot_
#     b'immigrationLevelW4__Increased a lot'   ->   immigrationLevelW4__Increased_a_
#     b'immigrantsWelfareStateW4__Strongly agree'   ->   immigrantsWelfareStateW4__Strong
#     b'immigEconW4__Good for economy'   ->   immigEconW4__Good_for_economy
#     b'immigCulturalW4__Enriches cultural life'   ->   immigCulturalW4__Enriches_cultur
#     b'immigrationLevelW6__Increased a lot'   ->   immigrationLevelW6__Increased_a_
#     b'changeImmigW7__Getting a lot higher'   ->   changeImmigW7__Getting_a_lot_hig
#     b'changeImmigLabW7__Getting a lot higher'   ->   changeImmigLabW7__Getting_a_lot_
#     b'immigContributeTakeW7__Get more than they pay'   ->   immigContributeTakeW7__Get_more_
#     b'effectsEUImmigrationW7__Much higher'   ->   effectsEUImmigrationW7__Much_hig
#     b'immigrantsWelfareStateW7__Strongly agree'   ->   immigrantsWelfareStateW7__Strong
#     b'immigEconW7__Good for economy'   ->   immigEconW7__Good_for_economy
#     b'immigCulturalW7__Enriches cultural life'   ->   immigCulturalW7__Enriches_cultur
#     b'immigSelfW7__Allow many more'   ->   immigSelfW7__Allow_many_more
#     b'immigConW7__Allow many more'   ->   immigConW7__Allow_many_more
#     b'immigLabW7__Allow many more'   ->   immigLabW7__Allow_many_more
#     b'immigUKIPW7__Allow many more'   ->   immigUKIPW7__Allow_many_more
#     b'changeImmigW8__Getting a lot higher'   ->   changeImmigW8__Getting_a_lot_hig
#     b'immigContributeTakeW8__Get more than they pay'   ->   immigContributeTakeW8__Get_more_
#     b'effectsEUImmigrationW8__Much higher'   ->   effectsEUImmigrationW8__Much_hig
#     b'immigrantsWelfareStateW8__Strongly agree'   ->   immigrantsWelfareStateW8__Strong
#     b'immigEconW8__Good for economy'   ->   immigEconW8__Good_for_economy
#     b'immigCulturalW8__Enriches cultural life'   ->   immigCulturalW8__Enriches_cultur
#     b'immigSelfW8__Allow many more'   ->   immigSelfW8__Allow_many_more
#     b'immigConW8__Allow many more'   ->   immigConW8__Allow_many_more
#     b'immigLabW8__Allow many more'   ->   immigLabW8__Allow_many_more
#     b'immigLDW8__Allow many more'   ->   immigLDW8__Allow_many_more
#     b'immigUKIPW8__Allow many more'   ->   immigUKIPW8__Allow_many_more
#     b'controlImmigW9__Complete control'   ->   controlImmigW9__Complete_control
#     b'immigSelfW9__Allow many more'   ->   immigSelfW9__Allow_many_more
#     b'immigConW9__Allow many more'   ->   immigConW9__Allow_many_more
#     b'immigLabW9__Allow many more'   ->   immigLabW9__Allow_many_more
#     b'immigUKIPW9__Allow many more'   ->   immigUKIPW9__Allow_many_more
#     b'controlImmigW10__Complete control'   ->   controlImmigW10__Complete_contro
#     b'euPriorityBalanceW10__Control immigration'   ->   euPriorityBalanceW10__Control_im
#     b'effectsEUImmigrationW10__Much higher'   ->   effectsEUImmigrationW10__Much_hi
#     b'immigEconW10__Good for economy'   ->   immigEconW10__Good_for_economy
#     b'immigCulturalW10__Enriches cultural life'   ->   immigCulturalW10__Enriches_cultu
#     b'immigSelfW10__Allow many more'   ->   immigSelfW10__Allow_many_more
#     b'immigConW10__Allow many more'   ->   immigConW10__Allow_many_more
#     b'immigUKIPW10__Allow many more'   ->   immigUKIPW10__Allow_many_more
#     b'changeImmigW10__Getting a lot higher'   ->   changeImmigW10__Getting_a_lot_hi
#     b'changeImmigLabW10__Getting a lot higher'   ->   changeImmigLabW10__Getting_a_lot
#     b'immigrantsWelfareStateW10__Strongly agree'   ->   immigrantsWelfareStateW10__Stron
#     b'controlImmigW11__Complete control'   ->   controlImmigW11__Complete_contro
#     b'euPriorityBalanceW11__Control immigration'   ->   euPriorityBalanceW11__Control_im
#     b'effectsEUImmigrationW11__Much higher'   ->   effectsEUImmigrationW11__Much_hi
#     b'immigEconW11__Good for economy'   ->   immigEconW11__Good_for_economy
#     b'immigCulturalW11__Enriches cultural life'   ->   immigCulturalW11__Enriches_cultu
#     b'immigSelfW11__Allow many more'   ->   immigSelfW11__Allow_many_more
#     b'immigConW11__Allow many more'   ->   immigConW11__Allow_many_more
#     b'immigLabW11__Allow many more'   ->   immigLabW11__Allow_many_more
#     b'immigUKIPW11__Allow many more'   ->   immigUKIPW11__Allow_many_more
#     b'changeImmigW11__Getting a lot higher'   ->   changeImmigW11__Getting_a_lot_hi
#     b'immigrantsWelfareStateW11__Strongly agree'   ->   immigrantsWelfareStateW11__Stron
#     b'euPriorityBalanceW12__Control immigration'   ->   euPriorityBalanceW12__Control_im
#     b'controlImmigW13__Complete control'   ->   controlImmigW13__Complete_contro
#     b'euPriorityBalanceW13__Control immigration'   ->   euPriorityBalanceW13__Control_im
#     b'effectsEUImmigrationW13__Much higher'   ->   effectsEUImmigrationW13__Much_hi
#     b'immigEconW13__Good for economy'   ->   immigEconW13__Good_for_economy
#     b'immigCulturalW13__Enriches cultural life'   ->   immigCulturalW13__Enriches_cultu
#     b'responsibleImmigConservativesW4_Yes'   ->   responsibleImmigConservativesW4_
#     b'responsibleImmigConservativesW2_Yes'   ->   responsibleImmigConservativesW2_
#     b'responsibleImmigConservativesW1_Yes'   ->   responsibleImmigConservativesW1_
#     b'responsibleImmigConservativesW3_Yes'   ->   responsibleImmigConservativesW3_
#
# If this is not what you expect, please make sure you have Stata-compliant
# column names in your DataFrame (strings only, max 32 characters, only
# alphanumerics and underscores, no Stata reserved words)
#
#   warnings.warn(ws, InvalidColumnName)
# 'W13_comb_immigration_export_to_R'

# %%
# try again with just the lowest noise variables
# immigEcon, immigCulturalm, immigSelf, immigrantsWelfareState, euPriorityBalance,

# %%
BES_immig = BES_reduced[[x for x in BES_reduced.columns if re.match("immigEcon|immigCultural|immigSelf|immigrantsWelfareState|euPriorityBalance",x)]]

# %%
Treatment = dataset_name + "_immigration_narrower"

# %%
output_subfolder = BES_output_folder + Treatment + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
clean_feature_set_std = StandardScaler().fit_transform(BES_immig.values )
BES_std = pd.DataFrame(      clean_feature_set_std,
                             columns = BES_immig.columns,
                             index   = BES_immig.index      )

# %%
# %%time

n_components = BES_std.shape[1]

decomp = FactorAnalysis(svd_method = 'lapack',n_components = n_components) ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 

X_r = decomp.fit_transform(BES_std)

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_immig.index)
# Out:
# Wall time: 699 ms

# %%
# treatdir = BES_data_folder+Treatment
# subdir = BES_data_folder+Treatment+decomp_method
load_suff = "FactorAnalysis"
save = True # False => Load

if save & ( 'decomp' in globals() ): # SAVE    ##( 'decomp' not in globals() )
    decomp_method = str(decomp).split("(")[0] 
    subdir = output_subfolder + decomp_method
    fname = subdir+ os.sep + decomp_method
    # create dir, save decomp object, BES_decomp, BES_std    
    if not os.path.exists(subdir): os.makedirs(subdir)
    with open(fname+".pkl", "wb") as f: pickle.dump( decomp, f )
    BES_decomp.to_hdf(fname+".hdf"        , decomp_method)
    BES_std.to_hdf(   fname+"_std"+".hdf" , decomp_method)
    
else: # LOAD decomp results (default is SAVE)
    decomp_method = load_suff
    subdir = output_subfolder + os.sep + decomp_method    
    fname = subdir + os.sep + decomp_method
    if not os.path.exists(subdir): raise Exception(subdir + ' does not exist!')
    # load decomp object, BES_decomp, BES_std, n_components
    with open(fname+".pkl", "rb") as f: decomp = pickle.load(f) 
    BES_decomp = pd.read_hdf(fname+".hdf")
    BES_std    = pd.read_hdf(fname+"_std"+".hdf")
    n_components = decomp.components_.shape[0]

# %%
display_pca_data(n_components, decomp, BES_std)
# Out:
# average log-likelihood of all samples: -37.503080085249834
# number of iterations: 2

# %%
(BES_decomp, comp_labels, comp_dict) = display_components(n_components, decomp,
                                                          BES_immig.columns, BES_decomp, manifest, 
                                                          save_folder = subdir,  
                                                          show_first_x_comps= 4, show_histogram = False)

# %%
# SUPER USEFUL FOR FEATURE EXTRACTION/VARIABLE PREP!

if hasattr(decomp, 'noise_variance_'):
    if not isinstance(decomp.noise_variance_, float):
        NoiseVariance = pd.DataFrame( decomp.noise_variance_ , index = BES_std.columns, columns = ["noise_variance_"])
        NoiseVariance.hist( bins = int(len( NoiseVariance )/10) )
        NoiseVariance = NoiseVariance.sort_values(by="noise_variance_")
        display( NoiseVariance )
        display( NoiseVariance[ NoiseVariance["noise_variance_"]>.9 ].sort_index() )
# Out:
#                                            noise_variance_
# immigEconW2__Good for economy                     0.402361
# immigCulturalW2__Enriches cultural life           0.418750
# immigCulturalW11__Enriches cultural life          0.421834
# immigCulturalW10__Enriches cultural life          0.430265
# immigEconW8__Good for economy                     0.431331
# immigEconW7__Good for economy                     0.433332
# immigCulturalW8__Enriches cultural life           0.440764
# immigEconW3__Good for economy                     0.443343
# immigCulturalW3__Enriches cultural life           0.445631
# immigSelfW8__Allow many more                      0.449151
# immigSelfW11__Allow many more                     0.450599
# immigCulturalW7__Enriches cultural life           0.450815
# immigSelfW10__Allow many more                     0.454518
# immigEconW1__Good for economy                     0.461058
# immigCulturalW13__Enriches cultural life          0.463876
# immigCulturalW1__Enriches cultural life           0.464649
# immigEconW4__Good for economy                     0.465622
# immigEconW10__Good for economy                    0.465789
# immigSelfW7__Allow many more                      0.470599
# immigEconW11__Good for economy                    0.470753
# euPriorityBalanceW11__Control immigration         0.472167
# immigrantsWelfareStateW3__Strongly agree          0.479104
# immigrantsWelfareStateW11__Strongly agree         0.479800
# immigrantsWelfareStateW2__Strongly agree          0.481143
# immigCulturalW4__Enriches cultural life           0.483733
# immigSelfW9__Allow many more                      0.484930
# immigEconW13__Good for economy                    0.494962
# immigrantsWelfareStateW10__Strongly agree         0.509609
# euPriorityBalanceW13__Control immigration         0.509682
# immigrantsWelfareStateW7__Strongly agree          0.510610
# immigrantsWelfareStateW8__Strongly agree          0.510861
# euPriorityBalanceW10__Control immigration         0.516111
# immigrantsWelfareStateW1__Strongly agree          0.531326
# euPriorityBalanceW12__Control immigration         0.539193
# immigrantsWelfareStateW4__Strongly agree          0.539942
# Empty DataFrame
# Columns: [noise_variance_]
# Index: []

# %%
BES_export_to_R = BES_immig.apply(lambda x: x.astype('category'))
BES_export_to_R = BES_export_to_R.apply(lambda x: x.cat.remove_unused_categories())
BES_export_to_R = BES_export_to_R.apply(lambda x: x.cat.codes)
BES_export_to_R = BES_export_to_R.replace(-1,np.nan)

filename = Treatment+"_export_to_R"

BES_export_to_R.to_stata(BES_R_data_files + filename + ".dta")
display(filename)
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\io\stata.py:2121: InvalidColumnName:
# Not all pandas column names were valid Stata variable names.
# The following replacements have been made:
#
#     b'immigEconW1__Good for economy'   ->   immigEconW1__Good_for_economy
#     b'immigCulturalW1__Enriches cultural life'   ->   immigCulturalW1__Enriches_cultur
#     b'immigrantsWelfareStateW1__Strongly agree'   ->   immigrantsWelfareStateW1__Strong
#     b'immigrantsWelfareStateW2__Strongly agree'   ->   immigrantsWelfareStateW2__Strong
#     b'immigEconW2__Good for economy'   ->   immigEconW2__Good_for_economy
#     b'immigCulturalW2__Enriches cultural life'   ->   immigCulturalW2__Enriches_cultur
#     b'immigrantsWelfareStateW3__Strongly agree'   ->   immigrantsWelfareStateW3__Strong
#     b'immigEconW3__Good for economy'   ->   immigEconW3__Good_for_economy
#     b'immigCulturalW3__Enriches cultural life'   ->   immigCulturalW3__Enriches_cultur
#     b'immigrantsWelfareStateW4__Strongly agree'   ->   immigrantsWelfareStateW4__Strong
#     b'immigEconW4__Good for economy'   ->   immigEconW4__Good_for_economy
#     b'immigCulturalW4__Enriches cultural life'   ->   immigCulturalW4__Enriches_cultur
#     b'immigrantsWelfareStateW7__Strongly agree'   ->   immigrantsWelfareStateW7__Strong
#     b'immigEconW7__Good for economy'   ->   immigEconW7__Good_for_economy
#     b'immigCulturalW7__Enriches cultural life'   ->   immigCulturalW7__Enriches_cultur
#     b'immigSelfW7__Allow many more'   ->   immigSelfW7__Allow_many_more
#     b'immigrantsWelfareStateW8__Strongly agree'   ->   immigrantsWelfareStateW8__Strong
#     b'immigEconW8__Good for economy'   ->   immigEconW8__Good_for_economy
#     b'immigCulturalW8__Enriches cultural life'   ->   immigCulturalW8__Enriches_cultur
#     b'immigSelfW8__Allow many more'   ->   immigSelfW8__Allow_many_more
#     b'immigSelfW9__Allow many more'   ->   immigSelfW9__Allow_many_more
#     b'euPriorityBalanceW10__Control immigration'   ->   euPriorityBalanceW10__Control_im
#     b'immigEconW10__Good for economy'   ->   immigEconW10__Good_for_economy
#     b'immigCulturalW10__Enriches cultural life'   ->   immigCulturalW10__Enriches_cultu
#     b'immigSelfW10__Allow many more'   ->   immigSelfW10__Allow_many_more
#     b'immigrantsWelfareStateW10__Strongly agree'   ->   immigrantsWelfareStateW10__Stron
#     b'euPriorityBalanceW11__Control immigration'   ->   euPriorityBalanceW11__Control_im
#     b'immigEconW11__Good for economy'   ->   immigEconW11__Good_for_economy
#     b'immigCulturalW11__Enriches cultural life'   ->   immigCulturalW11__Enriches_cultu
#     b'immigSelfW11__Allow many more'   ->   immigSelfW11__Allow_many_more
#     b'immigrantsWelfareStateW11__Strongly agree'   ->   immigrantsWelfareStateW11__Stron
#     b'euPriorityBalanceW12__Control immigration'   ->   euPriorityBalanceW12__Control_im
#     b'euPriorityBalanceW13__Control immigration'   ->   euPriorityBalanceW13__Control_im
#     b'immigEconW13__Good for economy'   ->   immigEconW13__Good_for_economy
#     b'immigCulturalW13__Enriches cultural life'   ->   immigCulturalW13__Enriches_cultu
#
# If this is not what you expect, please make sure you have Stata-compliant
# column names in your DataFrame (strings only, max 32 characters, only
# alphanumerics and underscores, no Stata reserved words)
#
#   warnings.warn(ws, InvalidColumnName)
# 'W13_comb_immigration_narrower_export_to_R'

# %%
hq_subset = BES_Panel[[x for x in BES_Panel.columns if re.match("immigEcon|immigCultural|immigSelf|immigrantsWelfareState|euPriorityBalance",x)]].notnull().sum(axis=1)>30

# %%
hq_subset.sum()
# Out:
# 9138

# %%
BES_export_to_R = BES_immig[hq_subset].apply(lambda x: x.astype('category'))
BES_export_to_R = BES_export_to_R.apply(lambda x: x.cat.remove_unused_categories())
BES_export_to_R = BES_export_to_R.apply(lambda x: x.cat.codes)
BES_export_to_R = BES_export_to_R.replace(-1,np.nan)

filename = Treatment+"_export_to_R"

BES_export_to_R.to_stata(BES_R_data_files + filename + ".dta")
display(filename)
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\io\stata.py:2121: InvalidColumnName:
# Not all pandas column names were valid Stata variable names.
# The following replacements have been made:
#
#     b'immigEconW1__Good for economy'   ->   immigEconW1__Good_for_economy
#     b'immigCulturalW1__Enriches cultural life'   ->   immigCulturalW1__Enriches_cultur
#     b'immigrantsWelfareStateW1__Strongly agree'   ->   immigrantsWelfareStateW1__Strong
#     b'immigrantsWelfareStateW2__Strongly agree'   ->   immigrantsWelfareStateW2__Strong
#     b'immigEconW2__Good for economy'   ->   immigEconW2__Good_for_economy
#     b'immigCulturalW2__Enriches cultural life'   ->   immigCulturalW2__Enriches_cultur
#     b'immigrantsWelfareStateW3__Strongly agree'   ->   immigrantsWelfareStateW3__Strong
#     b'immigEconW3__Good for economy'   ->   immigEconW3__Good_for_economy
#     b'immigCulturalW3__Enriches cultural life'   ->   immigCulturalW3__Enriches_cultur
#     b'immigrantsWelfareStateW4__Strongly agree'   ->   immigrantsWelfareStateW4__Strong
#     b'immigEconW4__Good for economy'   ->   immigEconW4__Good_for_economy
#     b'immigCulturalW4__Enriches cultural life'   ->   immigCulturalW4__Enriches_cultur
#     b'immigrantsWelfareStateW7__Strongly agree'   ->   immigrantsWelfareStateW7__Strong
#     b'immigEconW7__Good for economy'   ->   immigEconW7__Good_for_economy
#     b'immigCulturalW7__Enriches cultural life'   ->   immigCulturalW7__Enriches_cultur
#     b'immigSelfW7__Allow many more'   ->   immigSelfW7__Allow_many_more
#     b'immigrantsWelfareStateW8__Strongly agree'   ->   immigrantsWelfareStateW8__Strong
#     b'immigEconW8__Good for economy'   ->   immigEconW8__Good_for_economy
#     b'immigCulturalW8__Enriches cultural life'   ->   immigCulturalW8__Enriches_cultur
#     b'immigSelfW8__Allow many more'   ->   immigSelfW8__Allow_many_more
#     b'immigSelfW9__Allow many more'   ->   immigSelfW9__Allow_many_more
#     b'euPriorityBalanceW10__Control immigration'   ->   euPriorityBalanceW10__Control_im
#     b'immigEconW10__Good for economy'   ->   immigEconW10__Good_for_economy
#     b'immigCulturalW10__Enriches cultural life'   ->   immigCulturalW10__Enriches_cultu
#     b'immigSelfW10__Allow many more'   ->   immigSelfW10__Allow_many_more
#     b'immigrantsWelfareStateW10__Strongly agree'   ->   immigrantsWelfareStateW10__Stron
#     b'euPriorityBalanceW11__Control immigration'   ->   euPriorityBalanceW11__Control_im
#     b'immigEconW11__Good for economy'   ->   immigEconW11__Good_for_economy
#     b'immigCulturalW11__Enriches cultural life'   ->   immigCulturalW11__Enriches_cultu
#     b'immigSelfW11__Allow many more'   ->   immigSelfW11__Allow_many_more
#     b'immigrantsWelfareStateW11__Strongly agree'   ->   immigrantsWelfareStateW11__Stron
#     b'euPriorityBalanceW12__Control immigration'   ->   euPriorityBalanceW12__Control_im
#     b'euPriorityBalanceW13__Control immigration'   ->   euPriorityBalanceW13__Control_im
#     b'immigEconW13__Good for economy'   ->   immigEconW13__Good_for_economy
#     b'immigCulturalW13__Enriches cultural life'   ->   immigCulturalW13__Enriches_cultu
#
# If this is not what you expect, please make sure you have Stata-compliant
# column names in your DataFrame (strings only, max 32 characters, only
# alphanumerics and underscores, no Stata reserved words)
#
#   warnings.warn(ws, InvalidColumnName)
# 'W13_comb_immigration_narrower_export_to_R'

# %%
# sankey diagram for imm_preferences?

# %%
from ipysankeywidget import SankeyWidget
from ipywidgets import Layout
from ipywidgets import Button, VBox, HBox, Output
from IPython.display import display, clear_output

# %%
cmap = ['red','purple','blue','yellow','black','orange','grey','cyan','brown','green','pink','olive','peru',
        'fuchsia', 'chartreuse']

# %%
from ipysankeywidget import SankeyWidget
from ipywidgets import Layout
from ipywidgets import Button, VBox, HBox, Output
from IPython.display import display, clear_output

cmap = ['red','purple','blue','yellow','black','orange','grey','cyan','brown','green','pink','olive','peru',
        'fuchsia', 'chartreuse']

def flatten(A):
    rt = []
    for i in A:
        if isinstance(i,list): rt.extend(flatten(i))
        else: rt.append(i)
    return rt

def make_sankey(BES, links, order, first_year, second_year, first_col, second_col,
                replace_dict, threshold, colour, fixed_order, scale, nodes, wt_col, groups, group_index):
    
    crosstab = pd.crosstab(index   = BES[ first_col  ],
                           columns = BES[ second_col ],
                           values  = BES[ wt_col ],
                           aggfunc = sum, dropna = False,
                           normalize=True)*scale

    if order == []: # initialise
        order = [ [[x+first_year]  for x in fixed_order] ]
    order.append( [[x+second_year] for x in fixed_order] ) # add new layer
    

    for col in crosstab.columns:
        if col not in replace_dict.keys():
            continue        
        second_party = replace_dict[ col ]
        for ind in crosstab[col].index:
            if ind not in replace_dict.keys():
                continue
            first_party = replace_dict[ ind ]
            
            if crosstab[col][ind]>threshold:
                if colour == []:
                    col_to_use = colourmap[first_party]
                else:
                    col_to_use = cmap[colour]
                
                node_id_first = first_party+first_year
                
                # add group if not already present
                if first_year not in group_index.keys():
                    group_index[first_year] = len(groups)
                    groups.append( {'id': first_year, 'title': first_year, 'nodes': []} )
                    
                if node_id_first not in [x['id'] for x in nodes]:
                    nodes.append({'id':node_id_first, 'direction':'l'})
                    groups[group_index[first_year]]['nodes'].append(node_id_first)                    
                    
                node_id_second = second_party+second_year
                
                # add group if not already present
                if second_year not in group_index.keys():
                    group_index[second_year] = len(groups)
                    groups.append( {'id': second_year, 'title': second_year, 'nodes': []} )                
                
                if node_id_second not in [x['id'] for x in nodes]:
                    nodes.append({'id':node_id_second, 'direction':'l'})
                    groups[group_index[second_year]]['nodes'].append(node_id_second)

                if colour ==[]:
                    d = {'source': node_id_first,
                         'target': node_id_second,
                         'value': crosstab[col][ind],
                         'color': col_to_use}
                else:
                    d = {'source': node_id_first,
                         'target': node_id_second,
                         'value': crosstab[col][ind],
                         'color': col_to_use,'type' : str(colour)}                    
                links.append(d)

    return links, order, nodes, groups, group_index

def sankify():
    colour = []
    order  = []
    links  = []
    # ["W7","W8","W9","W10","W11","W12","W13"]
    pairs = [(x,im_var+x) for x in wave_list]
    scale = 100
    nodes = []
    wt_col = 'wt_new_W13'
    groups = []
    group_index = {}
    for pair_no in range(0,len(pairs)-1):


        (links, order, nodes, groups, group_index) = make_sankey(BES_Panel, links, order,
                            pairs[pair_no][0], pairs[pair_no+1][0],
                            pairs[pair_no][1], pairs[pair_no+1][1],
                            replace_dict, threshold, colour, fixed_order = base_order, scale=scale, nodes=nodes, wt_col = wt_col, groups=groups, group_index=group_index)    

    sankey = SankeyWidget(links=links, order=order, nodes=[], groups=groups, margins = margins, scale=diagram_scale, layout=layout)
    return sankey

def sankify_init_col(): 
    # sankify with colour sets by initial choice

    colour = []
    order  = []
    links  = []

    pairs = [(x,im_var+x) for x in wave_list]
    scale = 100
    nodes = []
    wt_col = 'wt_new_W13'
    groups = []
    group_index = {}

    for party in base_order:
        order  = []
        BES = BES_immig.loc[ BES_immig[immig_vars[0]]==party ]
        scale = 100 * BES.shape[0]/BES_immig.shape[0]
        colour = list(colourmap.values()).index( colourmap[replace_dict[party]] )    

        for pair_no in range(0,len(pairs)-1):

            (links, order, nodes, groups, group_index) = make_sankey(BES, links, order,
                                pairs[pair_no][0], pairs[pair_no+1][0],
                                pairs[pair_no][1], pairs[pair_no+1][1],
                                replace_dict, threshold, colour, fixed_order = base_order,
                                scale=scale, nodes=nodes, wt_col = wt_col, groups=groups, group_index=group_index)    

    sankey = SankeyWidget(layout=layout,links=links, order=order, nodes=[], groups=groups, margins = margins, scale=diagram_scale)
    return sankey

# %%
def sankify():
    colour = []
    order  = []
    links  = []
    # ["W7","W8","W9","W10","W11","W12","W13"]
    pairs = [(x,im_var+x) for x in wave_list]
    scale = 100
    nodes = []
    wt_col = 'wt_new_W13'
    groups = []
    group_index = {}
    for pair_no in range(0,len(pairs)-1):


        (links, order, nodes, groups, group_index) = make_sankey(BES_Panel, links, order,
                            pairs[pair_no][0], pairs[pair_no+1][0],
                            pairs[pair_no][1], pairs[pair_no+1][1],
                            replace_dict, threshold, colour, fixed_order = base_order, scale=scale, nodes=nodes, wt_col = wt_col, groups=groups, group_index=group_index)    

    sankey = SankeyWidget(links=links, order=order, nodes=[], groups=groups, margins = margins, scale=diagram_scale, layout=layout)
    return sankey

# %%
def sankify_init_col(): 
    # sankify with colour sets by initial choice

    colour = []
    order  = []
    links  = []

    pairs = [(x,im_var+x) for x in wave_list]
    scale = 100
    nodes = []
    wt_col = 'wt_new_W13'
    groups = []
    group_index = {}

    for party in base_order:
        order  = []
        BES = BES_immig.loc[ BES_immig[immig_vars[0]]==party ]
        scale = 100 * BES.shape[0]/BES_immig.shape[0]
        colour = list(colourmap.values()).index( colourmap[replace_dict[party]] )    

        for pair_no in range(0,len(pairs)-1):

            (links, order, nodes, groups, group_index) = make_sankey(BES, links, order,
                                pairs[pair_no][0], pairs[pair_no+1][0],
                                pairs[pair_no][1], pairs[pair_no+1][1],
                                replace_dict, threshold, colour, fixed_order = base_order,
                                scale=scale, nodes=nodes, wt_col = wt_col, groups=groups, group_index=group_index)    

    sankey = SankeyWidget(layout=layout,links=links, order=order, nodes=[], groups=groups, margins = margins, scale=diagram_scale)
    return sankey

# %%
im_var = "immigSelf"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

wave_list = ["W7","W8","W9","W10","W11"]

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Allow many fewerW7', '1W7', '2W7', '3W7', "Don't k…

# %%
BES_Panel[[x for x in BES_Panel.columns if "immigEcon" in x]].notnull().sum()
# Out:
# immigEconW1     30333
# immigEconW2     30240
# immigEconW3     28108
# immigEconW4     31440
# immigEconW7     30895
# immigEconW8     33502
# immigEconW10    30319
# immigEconW11    31014
# immigEconW13    31197
# dtype: int64

# %%
BES_Panel[[x for x in BES_Panel.columns if "immigSelf" in x]].notnull().sum()
# Out:
# immigSelfW7     30895
# immigSelfW8     33502
# immigSelfW9     30036
# immigSelfW10    30319
# immigSelfW11    31014
# immigSelfW12     9008
# immigSelfW13     1292
# dtype: int64

# %%
im_var = "immigEcon"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankey = sankify()
sankey.auto_save_png(BES_output_folder+os.sep+"leftRight_sankey.png")
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Bad for economyW1', '2W1', '3W1', '4W1', '5W1', "D…

# %%
BES_output_folder
# Out:
# '../BES_analysis_output/'

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankey = sankify_init_col()
sankey.auto_save_png(BES_output_folder+os.sep+"immigEcon.png")
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Bad for economyW1', '2W1', '3W1', '4W1', '5W1', '6…

# %%
wave_list = ["W1","W13"]

threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Undermines cultural lifeW1', '2W1', '3W1', '4W1', …

# %%
# now compared immigCultural
im_var = "immigCultural"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Undermines cultural lifeW1', '2W1', '3W1', '4W1', …

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Undermines cultural lifeW1', '2W1', '3W1', '4W1', …

# %%
# immigSelf W7W8W9W10W11W12W13
im_var = "immigSelf"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# specific problem with the last two waves not overlapping the prior data!
wave_list = ['W7', 'W8', 'W9', 'W10', 'W11']

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Allow many fewerW7', '1W7', '2W7', '3W7', "Don't k…

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Allow many fewerW7', '1W7', '2W7', '3W7', '4W7', '…

# %%
#immigrantsWelfareState
im_var = "immigrantsWelfareState"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Strongly disagreeW1', 'DisagreeW1', 'Neither agree…

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
# sankify_init_col()
sankey = sankify_init_col()
sankey.auto_save_png(BES_output_folder+os.sep+"W13_comb_imm_corr"+os.sep+"immigrantsWelfareState.png")
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Strongly disagreeW1', 'DisagreeW1', 'Neither agree…

# %%
# immigrationLevel
im_var = "immigrationLevel"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W4', 'title': 'W4', 'nodes': ['Decreased a lotW4', 'Decreased a littleW4', 'Left …

# %%
# immigContributeTake
# kind of a hassle because the categories are floats!

BES_Panel[[x for x in BES_Panel.columns if "immigContributeTake" in x]] = BES_Panel[[x for x in BES_Panel.columns if "immigContributeTake" in x]].apply(lambda x: x.cat.set_categories([str(x) for x in x.cat.categories]))

# %%
im_var = "immigContributeTake"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Pay more than they getW7', 'Get more than they pay…

# %%
# changeImmig
im_var = "changeImmig"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=180, right=180)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Getting a little lowerW1', 'Staying about the same…

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=180, right=180)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankey = sankify_init_col()
sankey.auto_save_png(BES_output_folder+os.sep+"W13_comb_imm_corr"+os.sep+"changeImmig.png")
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Getting a lot lowerW1', 'Getting a little lowerW1'…

# %%
# changeImmig
im_var = "changeImmigLab"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Getting a lot higherW1', 'Getting a little lowerW1…

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['Getting a lot lowerW1', 'Getting a little lowerW1'…

# %%
# controlImmig
im_var = "controlImmig"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W8', 'title': 'W8', 'nodes': ['No control at allW8', 'A little controlW8', 'Some …

# %%
threshold = 0.01
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=20
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W8', 'title': 'W8', 'nodes': ['No control at allW8', 'A little controlW8', 'Some …

# %%
# asylum, eu, noneu, students, families

# %%
im_var = "asylumMore"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
im_var = "euMore"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
im_var = "noneuMore"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
im_var = "studentsMore"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
im_var = "familiesMore"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Many fewerW7', '1W7', '2W7', '3W7', '4W7', '5W7', …

# %%
# effectsEUImmigration

# %%
im_var = "effectsEUImmigration"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Much lowerW7', 'LowerW7', 'About the sameW7', 'Muc…

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['Much lowerW7', 'LowerW7', 'About the sameW7', 'Hig…

# %%
# euPriorityBalance

# %%
im_var = "euPriorityBalance"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W10', 'title': 'W10', 'nodes': ['Access to the single marketW10', '1W10', '2W10',…

# %%
threshold = 0.01
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W10', 'title': 'W10', 'nodes': ['Access to the single marketW10', '1W10', '2W10',…

# %%
# euMIISmall

# %%
# len(BES_immig[immig_vars[0]].cat.categories)
# Out:
# 15

# %%
# euMIISmall
im_var = "euMIISmall"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W7', 'title': 'W7', 'nodes': ['ImmigrationW7', 'EconomyW7', 'British/english iden…

# %%
# EUMIICategory
# 54 categories - too many!

# %%
# miilabel
len(BES_immig[immig_vars[0]].cat.categories)
# Out:
# 31

# %%
im_var = "miilabel"

immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars_minus_wt_col = immig_vars.copy()
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]

# %%
var_list=  []
for ind in range(0,len(immig_vars_minus_wt_col)):
    vc = BES_immig[immig_vars_minus_wt_col[ind]].value_counts()
    sig_var = vc[vc/vc.sum()>.03].index
    [var_list.append(x) for x in sig_var if x not in var_list]
var_list
# Out:
# ['economy general',
#  'immigration',
#  "Don't know",
#  'flooding',
#  'unemployment',
#  'poverty, living stds',
#  'scot const',
#  'europe',
#  'nhs',
#  'terrorism',
#  'international probs',
#  'services-spending',
#  'social inequalities',
#  'politics-neg']

# %%
ordered_by_freq = var_list
#BES_immig[immig_vars_minus_wt_col].stack().value_counts().index
temp = list(ordered_by_freq[0:12])
temp.append("Other")

for x in immig_vars_minus_wt_col:
    BES_immig[x] = BES_immig[x].cat.set_categories(temp)#.fillna("Other")
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\ipykernel\__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories#.drop("Other")

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['unemploymentW1', 'economy generalW1', "Don't knowW…

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=5
sankify_init_col()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['economy generalW1', 'immigrationW1', "Don't knowW1…

# %%
#

# %%
imvar_list = ["immigEcon","immigCultural", "immigSelf",
             "immigrationLevel", "immigContributeTake",
             "immigrantsWelfareState", "controlImmig",
             "effectsEUImmigration", "euPriorityBalance",
             "changeImmig", "changeImmigLab",
             "govtHandleImmig", "labHandleImmig",
             "asylumMore", "euMore", "noneuMore", "studentsMore", "familiesMore"]

# %%
# np.empty( (10,10) )
number_of_waves = 13
imvars_by_waves = pd.DataFrame(np.full( ( len(imvar_list),number_of_waves), np.nan),
                  columns = ["W"+str(x) for x in range(1,number_of_waves+1)],
                  index = imvar_list ).T

# %%
#BES_Panel[immig_vars[0]].cat.codes.max()
max_range
# Out:
# 10

# %%
for im_var in imvar_list:
    immig_vars = [x for x in BES_Panel.columns if re.match(im_var+"W\d",  x)]
    wave_list = [x.split(im_var)[1] for x in immig_vars]

    BES_immig = BES_Panel[immig_vars].replace("Don't know",np.nan).apply(lambda x: x.cat.codes).replace(-1,np.nan)
#     print(immig_vars, wave_list)
    max_range = len(BES_Panel[immig_vars[0]].cat.categories.drop("Don't know",errors='ignore'))-1
    print(immig_vars[0], max_range)
    for wave in wave_list:
        wt_new = "wt_new_"+wave
        wt_old = "wt_full_"+wave
        if wt_new in BES_Panel.columns:
            wt = BES_Panel[wt_new]
        else:
            wt = BES_Panel[wt_old]
        imvars_by_waves.loc[wave,im_var] = (BES_immig[im_var+wave].multiply(wt).mean())/max_range
        
    top_cat = BES_Panel[immig_vars[0]].cat.categories.drop("Don't know",errors='ignore')[-1]
    imvars_by_waves.rename(index=str, columns={im_var: im_var + "_" + top_cat}, inplace=True)

imvars_by_waves
# Out:
# immigEconW1 6
# immigCulturalW1 6
# immigSelfW7 10
# immigrationLevelW4 4
# immigContributeTakeW7 6
# immigrantsWelfareStateW1 4
# controlImmigW8 4
# effectsEUImmigrationW7 4
# euPriorityBalanceW10 10
# changeImmigW1 4
# changeImmigLabW1 4
# govtHandleImmigW1 4
# labHandleImmigW1 4
# asylumMoreW7 10
# euMoreW7 10
# noneuMoreW7 10
# studentsMoreW7 10
# familiesMoreW7 10
#      immigEcon_Good for economy  immigCultural_Enriches cultural life  \
# W1                     0.422969                              0.405089
# W2                     0.424609                              0.409209
# W3                     0.401930                              0.393543
# W4                     0.457556                              0.432202
# W5                          NaN                                   NaN
# W6                          NaN                                   NaN
# W7                     0.450405                              0.414961
# W8                     0.461082                              0.428667
# W9                          NaN                                   NaN
# W10                    0.510847                              0.458711
# W11                    0.537817                              0.474287
# W12                         NaN                                   NaN
# W13                    0.519733                              0.452213
#
#      immigSelf_Allow many more  immigrationLevel_Increased a lot  \
# W1                         NaN                               NaN
# W2                         NaN                               NaN
# W3                         NaN                               NaN
# W4                         NaN                          0.217151
# W5                         NaN                               NaN
# W6                         NaN                          0.235075
# W7                    0.294593                               NaN
# W8                    0.297304                               NaN
# W9                    0.314482                               NaN
# W10                   0.296479                               NaN
# W11                   0.306642                               NaN
# W12                   0.323433                               NaN
# W13                   0.277810                               NaN
#
#      immigContributeTake_Get more than they pay  \
# W1                                          NaN
# W2                                          NaN
# W3                                          NaN
# W4                                          NaN
# W5                                          NaN
# W6                                          NaN
# W7                                     0.655993
# W8                                     0.615500
# W9                                          NaN
# W10                                         NaN
# W11                                         NaN
# W12                                         NaN
# W13                                         NaN
#
#      immigrantsWelfareState_Strongly agree  controlImmig_Complete control  \
# W1                                0.619937                            NaN
# W2                                0.643482                            NaN
# W3                                0.669404                            NaN
# W4                                0.620283                            NaN
# W5                                     NaN                            NaN
# W6                                     NaN                            NaN
# W7                                0.631499                            NaN
# W8                                0.624870                       0.316654
# W9                                     NaN                       0.508021
# W10                               0.550885                       0.494319
# W11                               0.536697                       0.522855
# W12                                    NaN                            NaN
# W13                                    NaN                       0.509571
#
#      effectsEUImmigration_Much higher  euPriorityBalance_Control immigration  \
# W1                                NaN                                    NaN
# W2                                NaN                                    NaN
# W3                                NaN                                    NaN
# W4                                NaN                                    NaN
# W5                                NaN                                    NaN
# W6                                NaN                                    NaN
# W7                           0.344286                                    NaN
# W8                           0.338188                                    NaN
# W9                                NaN                                    NaN
# W10                          0.365133                               0.524150
# W11                          0.363980                               0.507932
# W12                               NaN                               0.526275
# W13                          0.360474                               0.494464
#
#      changeImmig_Getting a lot higher  changeImmigLab_Getting a lot higher  \
# W1                           0.744253                             0.644485
# W2                           0.731656                             0.630306
# W3                           0.762521                             0.652189
# W4                           0.773037                             0.643577
# W5                                NaN                                  NaN
# W6                                NaN                                  NaN
# W7                           0.793386                             0.686475
# W8                           0.792248                                  NaN
# W9                                NaN                                  NaN
# W10                          0.656667                             0.632893
# W11                          0.605033                                  NaN
# W12                               NaN                                  NaN
# W13                               NaN                                  NaN
#
#      govtHandleImmig_Very well  labHandleImmig_Very well  \
# W1                    0.380639                  0.414651
# W2                    0.342947                  0.403055
# W3                    0.273102                  0.325407
# W4                    0.271421                  0.348061
# W5                         NaN                       NaN
# W6                         NaN                       NaN
# W7                    0.239651                  0.337831
# W8                         NaN                       NaN
# W9                         NaN                       NaN
# W10                        NaN                       NaN
# W11                        NaN                       NaN
# W12                        NaN                       NaN
# W13                        NaN                       NaN
#
#      asylumMore_Many more  euMore_Many more  noneuMore_Many more  \
# W1                    NaN               NaN                  NaN
# W2                    NaN               NaN                  NaN
# W3                    NaN               NaN                  NaN
# W4                    NaN               NaN                  NaN
# W5                    NaN               NaN                  NaN
# W6                    NaN               NaN                  NaN
# W7               0.312620          0.364955             0.316704
# W8               0.318247          0.366504             0.338750
# W9                    NaN               NaN                  NaN
# W10                   NaN               NaN                  NaN
# W11                   NaN               NaN                  NaN
# W12                   NaN               NaN                  NaN
# W13              0.314533          0.406980             0.371492
#
#      studentsMore_Many more  familiesMore_Many more
# W1                      NaN                     NaN
# W2                      NaN                     NaN
# W3                      NaN                     NaN
# W4                      NaN                     NaN
# W5                      NaN                     NaN
# W6                      NaN                     NaN
# W7                 0.428538                0.372131
# W8                 0.438382                0.362413
# W9                      NaN                     NaN
# W10                     NaN                     NaN
# W11                     NaN                     NaN
# W12                     NaN                     NaN
# W13                0.442802                0.393313

# %%
len(set(imvars_by_waves.columns))
# Out:
# 18

# %%
# imvars_by_waves.index[imvars_by_waves[imvar].isnull()]
# Out:
# Index(['W1', 'W2', 'W3', 'W4', 'W5', 'W6', 'W9', 'W10', 'W11', 'W12'], dtype='object')

# %%
# multiple line plot
# create a color palette
palette = plt.get_cmap('Set1')
# style
plt.style.use('seaborn-darkgrid')
f = plt.figure(figsize=(10,10))

num=1
for imvar in imvars_by_waves.columns:
#     plt.plot( imvars_by_waves.index, imvars_by_waves[imvar], color=palette(num))
    g = sns.pointplot(imvars_by_waves.index, imvars_by_waves[imvar], color =cmap[num%(len(cmap))], label = imvar)
# plt.plot( 'x', 'y2', data=df, marker='', color='olive', linewidth=2)
# plt.plot( 'x', 'y3', data=df, marker='', color='olive', linewidth=2, linestyle='dashed', label="toto")
    num=num+1
g.legend();
# Out:
# No handles with labels found to put in legend.

# %%
wave_dates.loc[3]
# Out:
# Timestamp('2014-09-01 00:00:00')

# %%
wave_dates = BES_file_manifest[BES_file_manifest["Only_or_Combined"]=="Only"][["Wave No","Date_Start"]].set_index("Wave No")
wave_dates = wave_dates.sort_index()
wave_dates = wave_dates["Date_Start"].apply(lambda x: pd.to_datetime(x))

# %%
# date = pd.date_range("2017-03", freq="M", periods=15)
# count = np.random.rand(15,4)
# df1 = pd.DataFrame({"date":date, "count" : count[:,0]})
# df2 = pd.DataFrame({"date":date, "count" : count[:,1]+0.7})
# df3 = pd.DataFrame({"date":date, "count" : count[:,2]+2})

f, ax = plt.subplots(1, 1, figsize=(10,10))
# x_col='date'
# y_col = 'count'
num=1
for imvar in imvars_by_waves.columns:
    notnull_vals = imvars_by_waves[imvar].notnull()
    if num<=10:
        marker = 'o'
    else:
        marker = 'v'
    
    ax.plot_date(wave_dates.values[notnull_vals],
                 imvars_by_waves[imvar][notnull_vals],
                 color=cmap[num%len(cmap)],
                 label=imvar,
                 linestyle="-",
                 marker = marker)
    num = num +1
# ax.plot_date(wave_dates, df2["count"], color="red", label="B", linestyle="-")
# ax.plot_date(wave_dates, df3["count"], color="green", label="C", linestyle="-")

ax.legend(loc="upper left", bbox_to_anchor=(1,1))
# legend(loc="upper left", bbox_to_anchor=(1,1))

plt.gcf().autofmt_xdate()
plt.axvline(x=wave_dates.loc[3], alpha=.9)
plt.text(wave_dates.loc[3],.8,'Peak UKIP (post EU elec.)',rotation=45)
plt.axvline(x=wave_dates.loc[8], alpha=.9)
plt.text(wave_dates.loc[8],.8,'2016 EU referendum',rotation=45)

dataset_citation = "Source: " + manifest["Citation"].values[0]
plt.annotate(dataset_citation, (0,0), (0, -40),
                             xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 7)  

Treatment = "W13_comb_imm_corr"
plt.savefig(BES_output_folder+ Treatment + os.sep + "Immigration_variables_by_waves.png",bbox_inches='tight');
plt.show()

# %%
# LDA on voters who switched/stayed
# easier imm variables - immigEcon/immigCultural
# W8 -> W10

# %%
[ x for x in BES_Panel.columns if "immigEcon" in x]
# Out:
# ['immigEconW1',
#  'immigEconW2',
#  'immigEconW3',
#  'immigEconW4',
#  'immigEconW7',
#  'immigEconW8',
#  'immigEconW10',
#  'immigEconW11',
#  'immigEconW13']

# %%
ImmBadW8 = (BES_Panel["immigEconW3"]=='Bad for economy') & (BES_Panel["immigEconW4"].notnull())
ChangedMind = BES_Panel[ImmBadW8]["immigEconW4"] != 'Bad for economy'
ChangedMind.value_counts()
# Out:
# False    3015
# True     2047
# Name: immigEconW4, dtype: int64

# %%
ImmBadW8 = (BES_Panel["immigEconW8"]=='Bad for economy') & (BES_Panel["immigEconW10"].notnull())
ChangedMind = BES_Panel[ImmBadW8]["immigEconW10"] != 'Bad for economy'
ChangedMind.value_counts()
# pretty distinct!
# Out:
# False    1773
# True     1725
# Name: immigEconW10, dtype: int64

# %%
BES_imm = BES_reduced[ImmBadW8]
# BES_imm = BES_imm.drop([x for x in BES_imm.columns if "immigEcon" in x] , axis=1)
# BES_imm = BES_imm.drop([x for x in BES_imm.columns if "immigCultural" in x] , axis=1)
# BES_imm = BES_imm.drop([x for x in BES_imm.columns if "immigSelf" in x] , axis=1)
# BES_imm = BES_imm.drop([x for x in BES_imm.columns if "immigrantsWelfareState" in x] , axis=1)
# BES_imm = BES_imm.drop([x for x in BES_imm.columns if "euPriorityBalance" in x] , axis=1)
# BES_imm = BES_imm.drop([x for x in BES_imm.columns if "UKIP" in x] , axis=1)

# immigrantsWelfareState, UKIP, euPriorityBalance, immigSelf
# weird stuff about passport variables!
# BES_imm = BES_imm.drop([x for x in BES_imm.columns if "passport" in x] , axis=1)

# %%
Treatment = "AntiImmigrantThaw"
output_subfolder = BES_output_folder + Treatment + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
from sklearn import datasets
from sklearn.decomposition import PCA, IncrementalPCA, NMF, TruncatedSVD, FastICA, FactorAnalysis, SparsePCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from gaussian_kde import gaussian_kde
from utility import display_components, display_pca_data, weighted_kde

# %%
# normalise data (subtract out the mean, divide through by standard deviation)
clean_feature_set_std = StandardScaler().fit_transform(BES_imm.values )
BES_std = pd.DataFrame(      clean_feature_set_std,
                             columns = BES_imm.columns,
                             index   = BES_imm.index      )

# %%
# %%time
n_components = BES_std.shape[1]
n_components = 1

decomp = LinearDiscriminantAnalysis() ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 

X_r = decomp.fit_transform(BES_std, ChangedMind)

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_imm.index)
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\sklearn\discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# Wall time: 18.5 s

# %%
# treatdir = BES_data_folder+Treatment
# subdir = BES_data_folder+Treatment+decomp_method
load_suff = "LinearDiscriminatAnalysis"
save = True # False => Load

if save & ( 'decomp' in globals() ): # SAVE    ##( 'decomp' not in globals() )
    decomp_method = str(decomp).split("(")[0] 
    subdir = output_subfolder + decomp_method
    fname = subdir+ os.sep + decomp_method
    # create dir, save decomp object, BES_decomp, BES_std    
    if not os.path.exists(subdir): os.makedirs(subdir)
    with open(fname+".pkl", "wb") as f: pickle.dump( decomp, f )
    BES_decomp.to_hdf(fname+".hdf"        , decomp_method)
    BES_std.to_hdf(   fname+"_std"+".hdf" , decomp_method)
    
else: # LOAD decomp results (default is SAVE)
    decomp_method = load_suff
    subdir = output_subfolder + os.sep + decomp_method    
    fname = subdir + os.sep + decomp_method
    if not os.path.exists(subdir): raise Exception(subdir + ' does not exist!')
    # load decomp object, BES_decomp, BES_std, n_components
    with open(fname+".pkl", "rb") as f: decomp = pickle.load(f) 
    BES_decomp = pd.read_hdf(fname+".hdf")
    BES_std    = pd.read_hdf(fname+"_std"+".hdf")
    n_components = decomp.components_.shape[0]

# %%
(BES_decomp, comp_labels, comp_dict) = display_components(n_components, decomp,
                                                          BES_imm.columns, BES_decomp, manifest, 
                                                          save_folder = subdir,  
                                                          show_first_x_comps= 4, show_histogram = False)

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor    

# def calculate_vif_(X, thresh=100):
#     cols = X.columns
#     variables = np.arange(X.shape[1])
#     dropped=True
#     while dropped:
#         dropped=False
#         c = X[cols[variables]].values
#         vif = [variance_inflation_factor(c, ix) for ix in np.arange(c.shape[1])]

#         maxloc = vif.index(max(vif))
#         if max(vif) > thresh:
#             print('dropping \'' + X[cols[variables]].columns[maxloc] + '\' at index: ' + str(maxloc))
#             variables = np.delete(variables, maxloc)
#             dropped=True

#     print('Remaining variables:')
#     print(X.columns[variables])
#     return X[cols[variables]]

# %%
gc.collect()
# Out:
# 121

# %%
imm_corr = BES_imm.corrwith(ChangedMind).sort_values().dropna()
imm_corr
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-1471-214cd156dc79> in <module>()
# ----> 1 all_imm_corr = BES_reduced.corrwith(ChangedMind).sort_values().dropna()
#       2 all_imm_corr
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\frame.py in corrwith(self, other, axis, drop)
#    6658
#    6659         if isinstance(other, Series):
# -> 6660             return this.apply(other.corr, axis=axis)
#    6661
#    6662         other = other._get_numeric_data()
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6002                          args=args,
#    6003                          kwds=kwds)
# -> 6004         return op.get_result()
#    6005
#    6006     def applymap(self, func):
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\apply.py in get_result(self)
#     316                                       *self.args, **self.kwds)
#     317
# --> 318         return super(FrameRowApply, self).get_result()
#     319
#     320     def apply_broadcast(self):
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     230             # Create a dummy Series from an empty array
#     231             from pandas import Series
# --> 232             values = self.values
#     233             index = self.obj._get_axis(self.axis)
#     234             labels = self.agg_axis
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\apply.py in values(self)
#      93     @cache_readonly
#      94     def values(self):
# ---> 95         return self.obj.values
#      96
#      97     @cache_readonly
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\generic.py in values(self)
#    4627         """
#    4628         self._consolidate_inplace()
# -> 4629         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    4630
#    4631     @property
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\internals.py in as_array(self, transpose, items)
#    3947             arr = mgr.blocks[0].get_values()
#    3948         else:
# -> 3949             arr = mgr._interleave()
#    3950
#    3951         return arr.transpose() if transpose else arr
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\internals.py in _interleave(self)
#    3958         dtype = _interleaved_dtype(self.blocks)
#    3959
# -> 3960         result = np.empty(self.shape, dtype=dtype)
#    3961
#    3962         if result.shape[0] == 0:
#
# MemoryError:

# %%
imm_corr = BES_imm.corrwith(ChangedMind).sort_values().dropna()
imm_corr
# Out:
# immigrantsWelfareStateW4__Strongly agree                          -0.337812
# immigrantsWelfareStateW7__Strongly agree                          -0.224540
# immigrantsWelfareStateW1__Strongly agree                          -0.220215
# blackEqualityW1W2W3W4W5__Gone much too far                        -0.201304
# blackEqualityW6W7W8W9__Gone much too far                          -0.196532
# immigrantsWelfareStateW8__Strongly agree                          -0.188933
# bestOnMIIW4_United Kingdom Independence Party (UKIP)              -0.184657
# immigrantsWelfareStateW11__Strongly agree                         -0.177405
# ukipGovTrustW5__ Would do a good job                              -0.173302
# handleMIIUKIPW5__Very well                                        -0.167739
# euRefVoteW4_Leave the EU                                          -0.167337
# benefitsToMigrantsW7__Never                                       -0.165939
# bestOnMIIW5_United Kingdom Independence Party (UKIP)              -0.165635
# bestOnMIIW6_United Kingdom Independence Party (UKIP)              -0.162511
# generalElectionVoteW5_United Kingdom Independence Party (UKIP)    -0.161770
# euRefVoteW6_Leave the EU                                          -0.161699
# immigContributeTakeW8__Get more than they pay                     -0.161199
# bestOnMIIW9_United Kingdom Independence Party (UKIP)              -0.159106
# immigrantsWelfareStateW2__Strongly agree                          -0.157057
# generalElectionVoteW4_United Kingdom Independence Party (UKIP)    -0.154405
# profile_past_vote_2015_United Kingdom Independence Party (UKIP)   -0.154250
# generalElectionVoteW7_United Kingdom Independence Party (UKIP)    -0.150161
# ashcroftW4_United Kingdom Independence Party (UKIP)               -0.149012
# likeFarageW4__Strongly like                                       -0.148019
# euPriorityBalanceW13__Control immigration                         -0.147643
# likeUKIPW8__Strongly like                                         -0.146937
# likeUKIPW7__Strongly like                                         -0.146217
# changeCrimeW4__Getting a lot higher                               -0.145169
# likeUKIPW9__Strongly like                                         -0.144703
# ptvUKIPW9__Very likely                                            -0.144207
#                                                                      ...
# handleMIILDW5__Very well                                           0.156867
# euFinancialHelpW2__Strongly agree                                  0.158041
# euCloserW7__Strongly agree                                         0.158964
# noneuMoreW8__Many more                                             0.159690
# immigCulturalW1__Enriches cultural life                            0.165516
# studentsMoreW8__Many more                                          0.171624
# noneuMoreW7__Many more                                             0.171750
# immigCulturalW11__Enriches cultural life                           0.173041
# immigCulturalW13__Enriches cultural life                           0.174114
# asylumMoreW8__Many more                                            0.176693
# immigCulturalW3__Enriches cultural life                            0.177709
# euUKRichW7__Strongly agree                                         0.179781
# familiesMoreW8__Many more                                          0.182137
# studentsMoreW7__Many more                                          0.186444
# asylumMoreW7__Many more                                            0.187989
# familiesMoreW7__Many more                                          0.189828
# immigCulturalW7__Enriches cultural life                            0.190251
# immigCulturalW8__Enriches cultural life                            0.194086
# euMoreW7__Many more                                                0.196520
# euMoreW8__Many more                                                0.197107
# immigCulturalW2__Enriches cultural life                            0.198542
# immigEconW10__Good for economy                                     0.205505
# immigEconW11__Good for economy                                     0.216669
# immigEconW13__Good for economy                                     0.223610
# immigEconW1__Good for economy                                      0.224324
# immigEconW8__Good for economy                                      0.251563
# immigEconW2__Good for economy                                      0.259986
# immigEconW7__Good for economy                                      0.266894
# immigCulturalW4__Enriches cultural life                            0.456169
# immigEconW4__Good for economy                                      0.796006
# Length: 2518, dtype: float64

# %%
imm_corr[[x for x in imm_corr.index if "euRef" in x]]

# %%
# realignment by social conservatism?

# %%
BES_reduced[ [x for x in BES_reduced if "immigEcon" in x or "al_scale" in x] ].corr()
# Out:
#                                    immigEconW1__Good for economy  \
# immigEconW1__Good for economy                           1.000000
# immigEconW2__Good for economy                           0.695170
# immigEconW3__Good for economy                           0.591612
# immigEconW4__Good for economy                           0.533203
# immigEconW7__Good for economy                           0.406240
# immigEconW8__Good for economy                           0.356433
# immigEconW10__Good for economy                          0.253667
# immigEconW11__Good for economy                          0.266874
# immigEconW13__Good for economy                          0.278760
# al_scaleW7W8W9__Authoritarian                          -0.284692
# al_scaleW6__Authoritarian                              -0.372838
# al_scaleW1W2W3W4W5__Authoritarian                      -0.427680
# al_scaleW10W11W12__Authoritarian                       -0.189378
# al_scaleW13__Authoritarian                             -0.228255
#
#                                    immigEconW2__Good for economy  \
# immigEconW1__Good for economy                           0.695170
# immigEconW2__Good for economy                           1.000000
# immigEconW3__Good for economy                           0.660060
# immigEconW4__Good for economy                           0.587393
# immigEconW7__Good for economy                           0.447572
# immigEconW8__Good for economy                           0.397549
# immigEconW10__Good for economy                          0.281049
# immigEconW11__Good for economy                          0.296500
# immigEconW13__Good for economy                          0.308631
# al_scaleW7W8W9__Authoritarian                          -0.312424
# al_scaleW6__Authoritarian                              -0.409137
# al_scaleW1W2W3W4W5__Authoritarian                      -0.443589
# al_scaleW10W11W12__Authoritarian                       -0.207430
# al_scaleW13__Authoritarian                             -0.250529
#
#                                    immigEconW3__Good for economy  \
# immigEconW1__Good for economy                           0.591612
# immigEconW2__Good for economy                           0.660060
# immigEconW3__Good for economy                           1.000000
# immigEconW4__Good for economy                           0.623558
# immigEconW7__Good for economy                           0.462452
# immigEconW8__Good for economy                           0.405043
# immigEconW10__Good for economy                          0.285870
# immigEconW11__Good for economy                          0.306964
# immigEconW13__Good for economy                          0.320517
# al_scaleW7W8W9__Authoritarian                          -0.323991
# al_scaleW6__Authoritarian                              -0.432566
# al_scaleW1W2W3W4W5__Authoritarian                      -0.429213
# al_scaleW10W11W12__Authoritarian                       -0.220789
# al_scaleW13__Authoritarian                             -0.262039
#
#                                    immigEconW4__Good for economy  \
# immigEconW1__Good for economy                           0.533203
# immigEconW2__Good for economy                           0.587393
# immigEconW3__Good for economy                           0.623558
# immigEconW4__Good for economy                           1.000000
# immigEconW7__Good for economy                           0.522405
# immigEconW8__Good for economy                           0.460278
# immigEconW10__Good for economy                          0.328776
# immigEconW11__Good for economy                          0.349357
# immigEconW13__Good for economy                          0.361689
# al_scaleW7W8W9__Authoritarian                          -0.342958
# al_scaleW6__Authoritarian                              -0.476817
# al_scaleW1W2W3W4W5__Authoritarian                      -0.436678
# al_scaleW10W11W12__Authoritarian                       -0.225291
# al_scaleW13__Authoritarian                             -0.276387
#
#                                    immigEconW7__Good for economy  \
# immigEconW1__Good for economy                           0.406240
# immigEconW2__Good for economy                           0.447572
# immigEconW3__Good for economy                           0.462452
# immigEconW4__Good for economy                           0.522405
# immigEconW7__Good for economy                           1.000000
# immigEconW8__Good for economy                           0.618014
# immigEconW10__Good for economy                          0.427058
# immigEconW11__Good for economy                          0.440985
# immigEconW13__Good for economy                          0.447992
# al_scaleW7W8W9__Authoritarian                          -0.485004
# al_scaleW6__Authoritarian                              -0.366924
# al_scaleW1W2W3W4W5__Authoritarian                      -0.316674
# al_scaleW10W11W12__Authoritarian                       -0.290938
# al_scaleW13__Authoritarian                             -0.328597
#
#                                    immigEconW8__Good for economy  \
# immigEconW1__Good for economy                           0.356433
# immigEconW2__Good for economy                           0.397549
# immigEconW3__Good for economy                           0.405043
# immigEconW4__Good for economy                           0.460278
# immigEconW7__Good for economy                           0.618014
# immigEconW8__Good for economy                           1.000000
# immigEconW10__Good for economy                          0.461033
# immigEconW11__Good for economy                          0.471190
# immigEconW13__Good for economy                          0.481693
# al_scaleW7W8W9__Authoritarian                          -0.497568
# al_scaleW6__Authoritarian                              -0.331176
# al_scaleW1W2W3W4W5__Authoritarian                      -0.289487
# al_scaleW10W11W12__Authoritarian                       -0.313879
# al_scaleW13__Authoritarian                             -0.357873
#
#                                    immigEconW10__Good for economy  \
# immigEconW1__Good for economy                            0.253667
# immigEconW2__Good for economy                            0.281049
# immigEconW3__Good for economy                            0.285870
# immigEconW4__Good for economy                            0.328776
# immigEconW7__Good for economy                            0.427058
# immigEconW8__Good for economy                            0.461033
# immigEconW10__Good for economy                           1.000000
# immigEconW11__Good for economy                           0.514476
# immigEconW13__Good for economy                           0.486080
# al_scaleW7W8W9__Authoritarian                           -0.296985
# al_scaleW6__Authoritarian                               -0.219517
# al_scaleW1W2W3W4W5__Authoritarian                       -0.183047
# al_scaleW10W11W12__Authoritarian                        -0.469514
# al_scaleW13__Authoritarian                              -0.338184
#
#                                    immigEconW11__Good for economy  \
# immigEconW1__Good for economy                            0.266874
# immigEconW2__Good for economy                            0.296500
# immigEconW3__Good for economy                            0.306964
# immigEconW4__Good for economy                            0.349357
# immigEconW7__Good for economy                            0.440985
# immigEconW8__Good for economy                            0.471190
# immigEconW10__Good for economy                           0.514476
# immigEconW11__Good for economy                           1.000000
# immigEconW13__Good for economy                           0.615729
# al_scaleW7W8W9__Authoritarian                           -0.305137
# al_scaleW6__Authoritarian                               -0.240821
# al_scaleW1W2W3W4W5__Authoritarian                       -0.212922
# al_scaleW10W11W12__Authoritarian                        -0.346258
# al_scaleW13__Authoritarian                              -0.374339
#
#                                    immigEconW13__Good for economy  \
# immigEconW1__Good for economy                            0.278760
# immigEconW2__Good for economy                            0.308631
# immigEconW3__Good for economy                            0.320517
# immigEconW4__Good for economy                            0.361689
# immigEconW7__Good for economy                            0.447992
# immigEconW8__Good for economy                            0.481693
# immigEconW10__Good for economy                           0.486080
# immigEconW11__Good for economy                           0.615729
# immigEconW13__Good for economy                           1.000000
# al_scaleW7W8W9__Authoritarian                           -0.318521
# al_scaleW6__Authoritarian                               -0.256709
# al_scaleW1W2W3W4W5__Authoritarian                       -0.227272
# al_scaleW10W11W12__Authoritarian                        -0.347480
# al_scaleW13__Authoritarian                              -0.492688
#
#                                    al_scaleW7W8W9__Authoritarian  \
# immigEconW1__Good for economy                          -0.284692
# immigEconW2__Good for economy                          -0.312424
# immigEconW3__Good for economy                          -0.323991
# immigEconW4__Good for economy                          -0.342958
# immigEconW7__Good for economy                          -0.485004
# immigEconW8__Good for economy                          -0.497568
# immigEconW10__Good for economy                         -0.296985
# immigEconW11__Good for economy                         -0.305137
# immigEconW13__Good for economy                         -0.318521
# al_scaleW7W8W9__Authoritarian                           1.000000
# al_scaleW6__Authoritarian                               0.538965
# al_scaleW1W2W3W4W5__Authoritarian                       0.474406
# al_scaleW10W11W12__Authoritarian                        0.472245
# al_scaleW13__Authoritarian                              0.528087
#
#                                    al_scaleW6__Authoritarian  \
# immigEconW1__Good for economy                      -0.372838
# immigEconW2__Good for economy                      -0.409137
# immigEconW3__Good for economy                      -0.432566
# immigEconW4__Good for economy                      -0.476817
# immigEconW7__Good for economy                      -0.366924
# immigEconW8__Good for economy                      -0.331176
# immigEconW10__Good for economy                     -0.219517
# immigEconW11__Good for economy                     -0.240821
# immigEconW13__Good for economy                     -0.256709
# al_scaleW7W8W9__Authoritarian                       0.538965
# al_scaleW6__Authoritarian                           1.000000
# al_scaleW1W2W3W4W5__Authoritarian                   0.685899
# al_scaleW10W11W12__Authoritarian                    0.349483
# al_scaleW13__Authoritarian                          0.417840
#
#                                    al_scaleW1W2W3W4W5__Authoritarian  \
# immigEconW1__Good for economy                              -0.427680
# immigEconW2__Good for economy                              -0.443589
# immigEconW3__Good for economy                              -0.429213
# immigEconW4__Good for economy                              -0.436678
# immigEconW7__Good for economy                              -0.316674
# immigEconW8__Good for economy                              -0.289487
# immigEconW10__Good for economy                             -0.183047
# immigEconW11__Good for economy                             -0.212922
# immigEconW13__Good for economy                             -0.227272
# al_scaleW7W8W9__Authoritarian                               0.474406
# al_scaleW6__Authoritarian                                   0.685899
# al_scaleW1W2W3W4W5__Authoritarian                           1.000000
# al_scaleW10W11W12__Authoritarian                            0.299981
# al_scaleW13__Authoritarian                                  0.363682
#
#                                    al_scaleW10W11W12__Authoritarian  \
# immigEconW1__Good for economy                             -0.189378
# immigEconW2__Good for economy                             -0.207430
# immigEconW3__Good for economy                             -0.220789
# immigEconW4__Good for economy                             -0.225291
# immigEconW7__Good for economy                             -0.290938
# immigEconW8__Good for economy                             -0.313879
# immigEconW10__Good for economy                            -0.469514
# immigEconW11__Good for economy                            -0.346258
# immigEconW13__Good for economy                            -0.347480
# al_scaleW7W8W9__Authoritarian                              0.472245
# al_scaleW6__Authoritarian                                  0.349483
# al_scaleW1W2W3W4W5__Authoritarian                          0.299981
# al_scaleW10W11W12__Authoritarian                           1.000000
# al_scaleW13__Authoritarian                                 0.585676
#
#                                    al_scaleW13__Authoritarian
# immigEconW1__Good for economy                       -0.228255
# immigEconW2__Good for economy                       -0.250529
# immigEconW3__Good for economy                       -0.262039
# immigEconW4__Good for economy                       -0.276387
# immigEconW7__Good for economy                       -0.328597
# immigEconW8__Good for economy                       -0.357873
# immigEconW10__Good for economy                      -0.338184
# immigEconW11__Good for economy                      -0.374339
# immigEconW13__Good for economy                      -0.492688
# al_scaleW7W8W9__Authoritarian                        0.528087
# al_scaleW6__Authoritarian                            0.417840
# al_scaleW1W2W3W4W5__Authoritarian                    0.363682
# al_scaleW10W11W12__Authoritarian                     0.585676
# al_scaleW13__Authoritarian                           1.000000

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "immigCultural" in x] ].corrwith(al_lazy, drop=True)
# Out:
# immigCulturalW1__Enriches cultural life    -0.400835
# immigCulturalW2__Enriches cultural life    -0.428178
# immigCulturalW3__Enriches cultural life    -0.444245
# immigCulturalW4__Enriches cultural life    -0.452386
# immigCulturalW7__Enriches cultural life    -0.465251
# immigCulturalW8__Enriches cultural life    -0.463512
# immigCulturalW10__Enriches cultural life   -0.415242
# immigCulturalW11__Enriches cultural life   -0.419797
# immigCulturalW13__Enriches cultural life   -0.458830
# dtype: float64

# %%
al2 = BES_reduced[ [x for x in BES_reduced if "al2" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "immigCultural" in x] ].corrwith(al2, drop=TImrue)
# Out:
# immigCulturalW1__Enriches cultural life    -0.357114
# immigCulturalW2__Enriches cultural life    -0.380981
# immigCulturalW3__Enriches cultural life    -0.406893
# immigCulturalW4__Enriches cultural life    -0.406130
# immigCulturalW7__Enriches cultural life    -0.416954
# immigCulturalW8__Enriches cultural life    -0.417275
# immigCulturalW10__Enriches cultural life   -0.377027
# immigCulturalW11__Enriches cultural life   -0.387615
# immigCulturalW13__Enriches cultural life   -0.424768
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "immigEcon" in x] ].corrwith(al_lazy, drop=True)
# Out:
# immigEconW1__Good for economy    -0.398126
# immigEconW2__Good for economy    -0.429514
# immigEconW3__Good for economy    -0.440752
# immigEconW4__Good for economy    -0.463793
# immigEconW7__Good for economy    -0.472159
# immigEconW8__Good for economy    -0.472411
# immigEconW10__Good for economy   -0.394237
# immigEconW11__Good for economy   -0.387586
# immigEconW13__Good for economy   -0.429380
# dtype: float64

# %%
al2 = BES_reduced[ [x for x in BES_reduced if "al2" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "immigEcon" in x] ].corrwith(al2, drop=True)
# Out:
# immigEconW1__Good for economy    -0.352247
# immigEconW2__Good for economy    -0.383921
# immigEconW3__Good for economy    -0.388108
# immigEconW4__Good for economy    -0.419039
# immigEconW7__Good for economy    -0.426494
# immigEconW8__Good for economy    -0.423879
# immigEconW10__Good for economy   -0.361115
# immigEconW11__Good for economy   -0.350245
# immigEconW13__Good for economy   -0.379244
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "immigSelf" in x] ].corrwith(al_lazy, drop=True)
# Out:
# immigSelfW7__Allow many more    -0.488444
# immigSelfW8__Allow many more    -0.490682
# immigSelfW9__Allow many more    -0.479568
# immigSelfW10__Allow many more   -0.438696
# immigSelfW11__Allow many more   -0.448425
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "immigrantsWelfareState" in x] ].corrwith(al_lazy, drop=True)
# Out:
# immigrantsWelfareStateW1__Strongly agree     0.431052
# immigrantsWelfareStateW2__Strongly agree     0.460039
# immigrantsWelfareStateW3__Strongly agree     0.494433
# immigrantsWelfareStateW4__Strongly agree     0.498391
# immigrantsWelfareStateW7__Strongly agree     0.502201
# immigrantsWelfareStateW8__Strongly agree     0.498834
# immigrantsWelfareStateW10__Strongly agree    0.454553
# immigrantsWelfareStateW11__Strongly agree    0.465612
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "controlImmig" in x] ].corrwith(al_lazy, drop=True)
# Out:
# controlImmigW9__Complete control     0.312930
# controlImmigW10__Complete control    0.238897
# controlImmigW11__Complete control    0.277157
# controlImmigW13__Complete control    0.290759
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "effectsEUImmigration" in x] ].corrwith(al_lazy, drop=True)
# Out:
# effectsEUImmigrationW7__Much higher    -0.154839
# effectsEUImmigrationW8__Much higher    -0.197488
# effectsEUImmigrationW10__Much higher   -0.160112
# effectsEUImmigrationW11__Much higher   -0.189163
# effectsEUImmigrationW13__Much higher   -0.187361
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "euPriorityBalance" in x] ].corrwith(al_lazy, drop=True)
# Out:
# euPriorityBalanceW10__Control immigration    0.418034
# euPriorityBalanceW11__Control immigration    0.430452
# euPriorityBalanceW12__Control immigration    0.456111
# euPriorityBalanceW13__Control immigration    0.466009
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "changeImmig" in x] ].corrwith(al_lazy, drop=True)
# Out:
# changeImmigW1__Getting a lot higher        0.340271
# changeImmigLabW1__Getting a lot higher     0.152314
# changeImmigW2__Getting a lot higher        0.362287
# changeImmigLabW2__Getting a lot higher     0.167442
# changeImmigW3__Getting a lot higher        0.379347
# changeImmigLabW3__Getting a lot higher     0.199524
# changeImmigW4__Getting a lot higher        0.351209
# changeImmigLabW4__Getting a lot higher     0.159036
# changeImmigW7__Getting a lot higher        0.396410
# changeImmigLabW7__Getting a lot higher     0.205500
# changeImmigW8__Getting a lot higher        0.376823
# changeImmigW10__Getting a lot higher       0.221959
# changeImmigLabW10__Getting a lot higher    0.191727
# changeImmigW11__Getting a lot higher       0.229182
# dtype: float64

# %%
al_lazy = BES_reduced[ [x for x in BES_reduced if "al_scale" in x] ].mean(axis=1)
BES_reduced[ [x for x in BES_reduced if "euMore" in x] ].corrwith(al_lazy, drop=True)
# Out:
# euMoreW7__Many more       -0.392712
# noneuMoreW7__Many more    -0.363350
# euMoreW8__Many more       -0.393122
# noneuMoreW8__Many more    -0.334082
# euMoreW13__Many more      -0.341576
# noneuMoreW13__Many more   -0.319996
# dtype: float64

# %%
all_corr = BES_reduced.corrwith(al_lazy, drop=True)

# %%
all_corr.drop([x for x in BES_reduced.columns if "al" in x]).sort_values()
# Out:
# immigSelfW8__Allow many more                     -0.490682
# immigSelfW7__Allow many more                     -0.488444
# asylumMoreW13__Many more                         -0.481439
# asylumMoreW8__Many more                          -0.480110
# asylumMoreW7__Many more                          -0.479987
# immigSelfW9__Allow many more                     -0.479568
# immigEconW8__Good for economy                    -0.472411
# immigEconW7__Good for economy                    -0.472159
# immigEconW4__Good for economy                    -0.463793
# immigSelfW11__Allow many more                    -0.448425
# immigEconW3__Good for economy                    -0.440752
# immigSelfW10__Allow many more                    -0.438696
# natSecuritySelfW13__Protect civil liberties      -0.435211
# immigEconW2__Good for economy                    -0.429514
# immigEconW13__Good for economy                   -0.429380
# echrW8__Strongly agree                           -0.416940
# immigrationLevelW6__Increased a lot              -0.415254
# euLawsLevelW8__Strongly agree                    -0.413852
# immigrationLevelW4__Increased a lot              -0.411728
# familiesMoreW8__Many more                        -0.405549
# immigEconW1__Good for economy                    -0.398126
# euLawsLevelW7__Strongly agree                    -0.397721
# familiesMoreW7__Many more                        -0.397457
# echrW7__Strongly agree                           -0.395028
# immigEconW10__Good for economy                   -0.394237
# euUKRichW8__Strongly agree                       -0.393851
# euMoreW8__Many more                              -0.393122
# euMoreW7__Many more                              -0.392712
# euUKRichW7__Strongly agree                       -0.391089
# familiesMoreW13__Many more                       -0.390114
#                                                     ...
# happyEULeaveW9__Extremely happy                   0.396640
# effectsEUWorkersW8__Much better                   0.396824
# EUIntegrationSelfW12__Protect our independence    0.402747
# govtHandoutsW3__Strongly agree                    0.405450
# EUIntegrationSelfW7__Protect our independence     0.405819
# EUIntegrationSelfW13__Protect our independence    0.407589
# EUIntegrationSelfW8__Protect our independence     0.410298
# govtHandoutsW7__Strongly agree                    0.418832
# ukCoopMovementW7__Bad for Britain                 0.419087
# UKsovereigntyW7__Strongly agree                   0.419315
# ukCoopMovementW8__Bad for Britain                 0.421487
# harkBackW7__Strongly agree                        0.424231
# immigrantsWelfareStateW1__Strongly agree          0.431052
# govtHandoutsW4__Strongly agree                    0.435046
# euParlOverRideW7__Strongly agree                  0.438165
# euUndermineIdentityW8__Strongly agree             0.438418
# UKsovereigntyW8__Strongly agree                   0.438845
# overseasAidW10__Strongly agree                    0.454434
# immigrantsWelfareStateW10__Strongly agree         0.454553
# immigContributeTakeW8__Get more than they pay     0.454557
# euParlOverRideW8__Strongly agree                  0.455117
# immigContributeTakeW7__Get more than they pay     0.458688
# euUndermineIdentityW7__Strongly agree             0.458940
# immigrantsWelfareStateW2__Strongly agree          0.460039
# immigrantsWelfareStateW11__Strongly agree         0.465612
# overseasAidW11__Strongly agree                    0.473874
# immigrantsWelfareStateW3__Strongly agree          0.494433
# immigrantsWelfareStateW4__Strongly agree          0.498391
# immigrantsWelfareStateW8__Strongly agree          0.498834
# immigrantsWelfareStateW7__Strongly agree          0.502201
# Length: 1952, dtype: float64

# %%
# add these later!
[x for x in BES_Panel.columns if "More" in x]
# Out:
# ['asylumMoreW7',
#  'euMoreW7',
#  'noneuMoreW7',
#  'studentsMoreW7',
#  'familiesMoreW7',
#  'asylumMoreW8',
#  'euMoreW8',
#  'noneuMoreW8',
#  'studentsMoreW8',
#  'familiesMoreW8',
#  'asylumMoreW13',
#  'euMoreW13',
#  'noneuMoreW13',
#  'studentsMoreW13',
#  'familiesMoreW13']

# %%
# Someone said Leavers favoured the Single Market

# %%
var_list=  []
for ind in range(0,len(immig_vars_minus_wt_col)):
    vc = BES_immig[immig_vars_minus_wt_col[ind]].value_counts()
    sig_var = vc[vc/vc.sum()>.03].index
    [var_list.append(x) for x in sig_var if x not in var_list]
var_list
# Out:
# ['Other', 'economy general', 'immigration', "Don't know", 'nhs']

# %%
crosstab = pd.crosstab(index   = BES_Panel[ 'euRefVoteW13'  ],
                       columns = BES_Panel[ "euPriorityBalanceW13" ],
                       values  = BES_Panel[ wt_col ],
                       aggfunc = sum, dropna = False, margins=True)

for ind in crosstab.index:
    crosstab.loc[ind] = crosstab.loc[ind]*100/crosstab.loc[ind].drop("All").sum()

crosstab = crosstab.drop("All")

# %%
crosstab
# Out:
# euPriorityBalanceW13   Access to the single market         1          2  \
# euRefVoteW13
# Stay/remain in the EU                    22.528569  9.312571  13.586069
# Leave the EU                              1.146638  0.682937   1.750504
# I would/will not vote                     3.922249  1.109108   3.827625
# Don't know                                2.173814  1.068329   4.463716
#
# euPriorityBalanceW13           3         4          5         6         7  \
# euRefVoteW13
# Stay/remain in the EU  10.880282  4.645471  10.342544  3.959815  3.597119
# Leave the EU            2.705950  2.870969  12.101909  5.946840  9.602497
# I would/will not vote   3.491027  2.270498  12.137132  3.155837  6.350051
# Don't know              5.807027  5.492599  12.812778  4.447323  6.850793
#
# euPriorityBalanceW13           8         9  Control immigration  Don't know  \
# euRefVoteW13
# Stay/remain in the EU   2.923394  1.040120             2.576948   14.607099
# Leave the EU           13.562555  8.342332            31.362223    9.924649
# I would/will not vote   3.955586  3.274070            10.565722   45.941095
# Don't know              6.404115  2.021008             5.905898   42.552599
#
# euPriorityBalanceW13     All
# euRefVoteW13
# Stay/remain in the EU  100.0
# Leave the EU           100.0
# I would/will not vote  100.0
# Don't know             100.0

# %%
crosstab.loc["Leave the EU"][crosstab.loc["Leave the EU"].index[0:5]].sum()
# Out:
# 9.156997134315004

# %%
# Factor Analysis on lr_scale to make more normal?

# %%
BES_Panel[[x for x in BES_Panel.columns if "lr1" in x]].notnull().sum()
# Out:
# lr1W6            30148
# lr1W13           31197
# lr1W1W2W3W4W5    41674
# lr1W7W8W9        39857
# lr1W10W11W12     35104
# dtype: int64

# %%
BES_Panel[[x for x in BES_Panel.columns if re.match("(al|lr)\dW1W2W3W4W5",x)]].notnull().sum()
# Out:
# lr1W1W2W3W4W5    41674
# lr2W1W2W3W4W5    41674
# lr3W1W2W3W4W5    41674
# lr4W1W2W3W4W5    41674
# lr5W1W2W3W4W5    41674
# al1W1W2W3W4W5    41665
# al2W1W2W3W4W5    41665
# al3W1W2W3W4W5    41665
# al4W1W2W3W4W5    41665
# al5W1W2W3W4W5    41665
# dtype: int64

# %%
BES_vals = BES_Panel[[x for x in BES_Panel.columns if re.match("(al|lr)\dW1W2W3W4W5",x)]]
BES_vals = BES_vals.replace("Don't know",np.nan).dropna().apply(lambda x: x.cat.codes)
BES_vals.shape
# Out:
# (35840, 10)

# %%
# Out:
# Wall time: 3.47 s

# %%
xt_std_lr = (xt-xt.mean())/xt.std()

# %%
# still not normal - what distribution is it?
# Out:
# array([-0.88170621, -1.76802023,  0.4414475 , ...,  0.03996744,
#        -0.00900711, -0.2731986 ])

# %%
import matplotlib.pyplot as plt
import scipy
import scipy.stats
from scipy.stats._continuous_distns import _distn_names
size = len(xt_std_lr)
x = scipy.arange(size)
y = xt_std_lr
h = plt.hist(y, bins=range(48), color='w')

dist_names = [ 'alpha', 'anglit', 'arcsine', 'beta', 'betaprime', 'bradford', 'burr', 'cauchy', 'chi', 'chi2', 'cosine', 'dgamma', 'dweibull', 'erlang', 'expon', 'exponweib', 'exponpow', 'f', 'fatiguelife', 'fisk', 'foldcauchy', 'foldnorm', 'frechet_r', 'frechet_l', 'genlogistic', 'genpareto', 'genexpon', 'genextreme', 'gausshyper', 'gamma', 'gengamma', 'genhalflogistic', 'gilbrat', 'gompertz', 'gumbel_r', 'gumbel_l', 'halfcauchy', 'halflogistic', 'halfnorm', 'hypsecant', 'invgamma', 'invgauss', 'invweibull', 'johnsonsb', 'johnsonsu', 'ksone', 'kstwobign', 'laplace', 'logistic', 'loggamma', 'loglaplace', 'lognorm', 'lomax', 'maxwell', 'mielke', 'nakagami', 'ncx2', 'ncf', 'nct', 'norm', 'pareto', 'pearson3', 'powerlaw', 'powerlognorm', 'powernorm', 'rdist', 'reciprocal', 'rayleigh', 'rice', 'recipinvgauss', 'semicircular', 't', 'triang', 'truncexpon', 'truncnorm', 'tukeylambda', 'uniform', 'vonmises', 'wald', 'weibull_min', 'weibull_max', 'wrapcauchy'] 

for dist_name in dist_names:
    dist = getattr(scipy.stats, dist_name)
    param = dist.fit(y)
    pdf_fitted = dist.pdf(x, *param[:-2], loc=param[-2], scale=param[-1]) * size
    plt.plot(pdf_fitted, label=dist_name)
    plt.xlim(0,47)
plt.legend(loc='upper right')
plt.show()
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:437: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:2305: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu

# %%
# http://www.handsonmachinelearning.com/blog/WEjdW/fitting-probability-distributions-with-python-part-1
import scipy
import scipy.stats

import matplotlib
import matplotlib.pyplot as plt
class Distribution(object):
    
    def __init__(self,dist_names_list = []):
        dist_list = [ 'alpha', 'anglit', 'arcsine', 'beta', 'betaprime', 'bradford', 'burr', 'cauchy', 'chi', 'chi2', 'cosine', 'dgamma', 'dweibull', 'erlang', 'expon', 'exponweib', 'exponpow', 'f', 'fatiguelife', 'fisk', 'foldcauchy', 'foldnorm', 'frechet_r', 'frechet_l', 'genlogistic', 'genpareto', 'genexpon', 'genextreme', 'gausshyper', 'gamma', 'gengamma', 'genhalflogistic', 'gilbrat', 'gompertz', 'gumbel_r', 'gumbel_l', 'halfcauchy', 'halflogistic', 'halfnorm', 'hypsecant', 'invgamma', 'invgauss', 'invweibull', 'johnsonsb', 'johnsonsu', 'ksone', 'kstwobign', 'laplace', 'logistic', 'loggamma', 'loglaplace', 'lognorm', 'lomax', 'maxwell', 'mielke', 'nakagami', 'ncx2', 'ncf', 'nct', 'norm', 'pareto', 'pearson3', 'powerlaw', 'powerlognorm', 'powernorm', 'rdist', 'reciprocal', 'rayleigh', 'rice', 'recipinvgauss', 'semicircular', 't', 'triang', 'truncexpon', 'truncnorm', 'tukeylambda', 'uniform', 'vonmises', 'wald', 'weibull_min', 'weibull_max', 'wrapcauchy'] 
        self.dist_names = ['johnsonsu']
        self.dist_results = []
        self.params = {}
        
        self.DistributionName = ""
        self.PValue = 0
        self.Param = None
        
        self.isFitted = False
        
        
    def Fit(self, y):
        self.dist_results = []
        self.params = {}
        for dist_name in self.dist_names:
            dist = getattr(scipy.stats, dist_name)
            param = dist.fit(y)
            
            self.params[dist_name] = param
            #Applying the Kolmogorov-Smirnov test
            D, p = scipy.stats.kstest(y, dist_name, args=param);
            self.dist_results.append((dist_name,p))

        #select the best fitted distribution
        sel_dist,p = (max(self.dist_results,key=lambda item:item[1]))
        #store the name of the best fit and its p value
        self.DistributionName = sel_dist
        self.PValue = p
        
        self.isFitted = True
        return self.DistributionName,self.PValue
    
    def Random(self, n = 1):
        if self.isFitted:
            dist_name = self.DistributionName
            param = self.params[dist_name]
            #initiate the scipy distribution
            dist = getattr(scipy.stats, dist_name)
            return dist.rvs(*param[:-2], loc=param[-2], scale=param[-1], size=n)
        else:
            raise ValueError('Must first run the Fit method.')
            
    def Plot(self,y):
        x = self.Random(n=len(y))
        plt.hist(x, alpha=0.5, label='Fitted', bins=100)
        plt.hist(y, alpha=0.5, label='Actual', bins=100)
        plt.legend(loc='upper right')

# %%
dst = Distribution()
dst.Fit(xt_std_lr)
dst.Plot(xt_std_lr)
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:2305: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:312: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.0/np.pi/np.sqrt(x*(1-x))
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:437: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\optimize\minpack.py:163: RuntimeWarning: The iteration is not making good progress, as measured by the
#   improvement from the last ten iterations.
#   warnings.warn(msg, RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:589: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:593: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:1037: RuntimeWarning: invalid value encountered in subtract
#   mu2 = mu2p - mu * mu
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 395.85.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 358.15.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 386.425.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 383.2833333333333.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.5708333333333.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 384.33055555555563.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 382.4979166666667.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 372.28749999999997.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 382.890625.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 376.4763888888888.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.98177083333326.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 380.01076388888885.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.9308159722222.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 373.051099537037.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 374.67283950617286.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.1545380015432.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 382.3391364454733.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 380.01712721836424.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.18362750771615.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.4940188560957.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.85289271476347.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 376.8808138288751.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.233048870992.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 376.6318191032949.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 376.7492264600956.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.05782075709567.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.5620939820968.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.36438782299535.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.6738037055625.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.96181649421237.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.7655224204742.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 376.5851770721325.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.57108092127714.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 376.92307585651884.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.30491077948534.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.9555113062959.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 377.96024019723325.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.5574879319971.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.91811594899787.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.6613805988536.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 378.3940282343274.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.29524320583505.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.9627447101359.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.0337866281624.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 379.6892921271399.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 380.24839773007125.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 380.7298540759648.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 381.22080731399797.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 382.3143176569158.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 380.58104892016297.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 380.69265278701437.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 381.83476367057744.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 383.5385306158653.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 385.463149860228.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 385.7155013381331.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 387.1605488996072.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 389.9118157417298.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 386.8997623937868.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 386.7693691408765.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 389.13431732569666.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 390.8437253194784.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 385.55927597393224.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 390.072025931237.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 392.37646396674154.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 394.52069181273885.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 387.7996299336339.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 393.78011708611575.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 397.2202944322803.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 399.16069254536626.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 401.6612419767803.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 393.54810448380385.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 389.6025493765176.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 391.9920851687297.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 394.1777912280305.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 394.4926346001439.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 396.76021216736115.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 400.3233422977939.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 404.488970862326.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 400.7077210958056.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 402.5725899399034.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 410.6868866652127.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 398.54119761641107.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 403.027451183288.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 404.1873162270292.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 402.2390665306075.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 408.7357047968975.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 405.61908750736336.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 406.184145829882.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 410.1223391569192.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 404.55012379731033.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 399.44867919754927.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 407.4539241670767.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 407.5614407541377.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 409.248503017692.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 410.3308859974444.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 412.4031212807787.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 413.86774936353333.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 417.07466196176165.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 412.0329127038199.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 412.310569136539.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 415.42493674655066.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 420.6249422122089.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 412.0926128163212.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 417.4175718798833.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 421.18550090914255.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 418.9122788859372.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 420.1780717385042.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 422.5546392344809.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 421.6101481749032.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 421.9140206948267.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 421.1635852426043.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 418.918442784328.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 424.6831162125137.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 428.4873433378898.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 422.9405469116108.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 423.829027746114.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 428.45941267774447.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 421.3036852576821.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 423.9892469097257.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 424.70655074734805.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 421.8763929549158.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 423.98143539811423.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 427.0409906700354.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 429.909643376212.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 428.31537918166845.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 431.4586877907051.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 435.2735178130006.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 435.08258948504226.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 427.3005604317716.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 430.79721521745745.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 429.79466558374406.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 429.7371766875101.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 434.0664852961661.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 437.44944772836334.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 432.7493438962861.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 433.72540823570046.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 433.59901828636873.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 434.66918353420056.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 438.5127191269672.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 442.87174589857887.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 437.20505530174603.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 438.77434030453605.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 439.86589707290875.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 442.9361414915129.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 442.38659746688086.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 446.245304433221.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 441.12564743405653.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 442.4321115876012.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 445.04703934748477.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 443.08654333605006.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 444.53329508508295.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 446.86699409117.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 443.4437264365789.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 446.2500624710847.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 444.9689587118276.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 444.94880498539476.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 443.8199960737829.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 445.7949565777456.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 447.1491631985933.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 445.36601085981175.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 446.3568183363758.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 448.7613321894045.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 447.52599816049906.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 447.00396314289367.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 446.51860453800526.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 448.76316640492.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 450.4617441774741.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 450.23933248637235.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 447.44878652509703.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 449.1804644402772.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 450.91150022997226.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 452.7926687456618.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 454.1744650505117.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 449.1302061564507.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 452.40928161278055.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 452.42636016578797.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 453.4086681599449.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 456.6102061891407.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 460.35020620548573.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 456.13174711705096.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 457.99297986918623.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 459.21523406651943.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 462.4265167269482.
#   RuntimeWarning)
# ...
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 674.8627165368714.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 676.2404040661013.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 677.0415474404565.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 679.0246752483008.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 676.6732691818472.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 675.6042028857858.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 675.2861022956281.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 674.4586269059987.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 676.119608612885.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 678.4581454872249.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 680.661171328074.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 676.4130905501406.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 677.5306840025492.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 678.2362216973811.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 679.8007689373787.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 681.8990519631752.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 682.6491888817136.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 683.3981628742885.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 685.8681715678201.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 688.708053244425.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 680.854179584142.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 683.0984131950447.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 684.6481242681627.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 688.22229310321.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 691.9063498627438.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 689.3939794310836.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 692.5417625491032.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 693.1066938785928.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 696.7123281194504.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 691.8775619692497.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 691.2629960145782.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 699.1988086553256.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 704.6870664313833.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 692.3664273296686.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 695.6258529220049.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 698.593053148617.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 701.6186984483738.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 703.7342478480487.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value 694.8417334389494.
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2562: RuntimeWarning: The shape parameter of the erlang distribution has been given a non-integer value array(698.59305315).
#   RuntimeWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\ipykernel\__main__.py:26: DeprecationWarning: `frechet_r` is deprecated!
# The distribution `frechet_r` is a synonym for `weibull_min`; this historical
# usage is deprecated because of possible confusion with the (quite different)
# Frechet distribution.  To preserve the existing behavior of the program, use
# `scipy.stats.weibull_min`.  For the Frechet distribution (i.e. the Type II
# extreme value distribution), use `scipy.stats.invweibull`.
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\ipykernel\__main__.py:26: DeprecationWarning: `frechet_l` is deprecated!
# The distribution `frechet_l` is a synonym for `weibull_max`; this historical
# usage is deprecated because of possible confusion with the (quite different)
# Frechet distribution.  To preserve the existing behavior of the program, use
# `scipy.stats.weibull_max`.  For the Frechet distribution (i.e. the Type II
# extreme value distribution), use `scipy.stats.invweibull`.
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:2159: RuntimeWarning: divide by zero encountered in true_divide
#   val = val + cnk * (-1) ** ki / (1.0 - c * ki)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:1615: RuntimeWarning: invalid value encountered in log
#   return log(self._pdf(x, *args))
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:1615: RuntimeWarning: divide by zero encountered in log
#   return log(self._pdf(x, *args))
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\integrate\quadpack.py:385: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   warnings.warn(msg, IntegrationWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:44: RuntimeWarning: floating point number truncated to an integer
#   return 1.0 - sc.smirnov(n, x)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:3785: RuntimeWarning: divide by zero encountered in true_divide
#   return c**2 / (c**2 - n**2)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:3776: RuntimeWarning: divide by zero encountered in power
#   return cd2*x**(c-1)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\integrate\quadpack.py:385: IntegrationWarning: Extremely bad integrand behavior occurs at some points of the
#   integration interval.
#   warnings.warn(msg, IntegrationWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\integrate\quadpack.py:385: IntegrationWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg, IntegrationWarning)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:4502: RuntimeWarning: overflow encountered in double_scalars
#   return 2*nu**nu/sc.gamma(nu)*(x**(2*nu-1.0))*np.exp(-nu*x*x)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:5250: RuntimeWarning: divide by zero encountered in power
#   return np.power((1.0 - x**2), c / 2.0 - 1) / sc.beta(0.5, c / 2.0)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:5358: RuntimeWarning: invalid value encountered in log
#   self.d = np.log(b*1.0 / a)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:5823: RuntimeWarning: divide by zero encountered in log
#   self._logdelta = np.log(self._delta)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:5823: RuntimeWarning: invalid value encountered in log
#   self._logdelta = np.log(self._delta)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_continuous_distns.py:5883: RuntimeWarning: divide by zero encountered in power
#   Px = Fx**(lam-1.0) + (np.asarray(1-Fx))**(lam-1.0)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\optimize\optimize.py:563: RuntimeWarning: invalid value encountered in subtract
#   numpy.max(numpy.abs(fsim[0] - fsim[1:])) <= fatol):
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\numpy\core\_methods.py:26: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\scipy\stats\_distn_infrastructure.py:1821: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
dst.DistributionName
# Out:
# 'johnsonsu'

# %%
dst_2 = Distribution()
dst_2.Fit(xt_std_lr)
dst_2.Plot(xt_std_lr)

# %%
param = dst_2.params['johnsonsu']
dist = dist = getattr(scipy.stats, 'johnsonsu')
jssu = dist.rvs(*param[:-2], loc=param[-2], scale=param[-1], size=len(xt_std_lr))

# %%
np.histogram(jssu)
# Out:
# (array([    1,     3,    12,   135,  9604, 59395,   310,    17,     6,
#             3], dtype=int64),
#  array([-25.59195721, -20.63814574, -15.68433427, -10.73052281,
#          -5.77671134,  -0.82289987,   4.1309116 ,   9.08472306,
#          14.03853453,  18.992346  ,  23.94615747]))

# %%
dst.dist_results
# Out:
# [('alpha', 0.0),
#  ('anglit', 0.0),
#  ('arcsine', 0.0),
#  ('beta', 0.0),
#  ('betaprime', 0.0),
#  ('bradford', 0.0),
#  ('burr', 0.0),
#  ('cauchy', 1.1141639281547515e-89),
#  ('chi', 0.0),
#  ('chi2', 0.0),
#  ('cosine', 0.0),
#  ('dgamma', 2.3457984904793263e-60),
#  ('dweibull', 1.552442194321803e-62),
#  ('erlang', 0.0),
#  ('expon', 0.0),
#  ('exponweib', 0.0),
#  ('exponpow', 0.0),
#  ('f', 0.0),
#  ('fatiguelife', 0.0),
#  ('fisk', 1.024420931366208e-183),
#  ('foldcauchy', 9.57813153311581e-148),
#  ('foldnorm', 0.0),
#  ('frechet_r', 0.0),
#  ('frechet_l', 0.0),
#  ('genlogistic', 4.2145143990827293e-221),
#  ('genpareto', 0.0),
#  ('genexpon', 0.0),
#  ('genextreme', 0.0),
#  ('gausshyper', 0.0),
#  ('gamma', 0.0),
#  ('gengamma', 0.0),
#  ('genhalflogistic', 0.0),
#  ('gilbrat', 0.0),
#  ('gompertz', 0.0),
#  ('gumbel_r', 0.0),
#  ('gumbel_l', 0.0),
#  ('halfcauchy', 0.0),
#  ('halflogistic', 0.0),
#  ('halfnorm', 0.0),
#  ('hypsecant', 6.517754071971198e-114),
#  ('invgamma', 0.0),
#  ('invgauss', 0.0),
#  ('invweibull', 0.0),
#  ('johnsonsb', 0.0),
#  ('johnsonsu', 1.3021199660499904e-35),
#  ('ksone', 0.0),
#  ('kstwobign', 0.0),
#  ('laplace', 2.894021516964732e-46),
#  ('logistic', 5.748720208256494e-184),
#  ('loggamma', 0.0),
#  ('loglaplace', 0.0),
#  ('lognorm', 0.0),
#  ('lomax', 0.0),
#  ('maxwell', 0.0),
#  ('mielke', 1.5397772360720331e-190),
#  ('nakagami', 0.0),
#  ('ncx2', 0.0),
#  ('ncf', 0.0),
#  ('nct', 5.387699417259343e-50),
#  ('norm', 0.0),
#  ('pareto', 0.0),
#  ('pearson3', 0.0),
#  ('powerlaw', 0.0),
#  ('powerlognorm', 0.0),
#  ('powernorm', 0.0),
#  ('rdist', 0.0),
#  ('reciprocal', 0.0),
#  ('rayleigh', 0.0),
#  ('rice', 0.0),
#  ('recipinvgauss', 0.0),
#  ('semicircular', 0.0),
#  ('t', 6.7359955194894305e-59),
#  ('triang', 0.0),
#  ('truncexpon', 0.0),
#  ('truncnorm', 0.0),
#  ('tukeylambda', 4.1375326490984426e-55),
#  ('uniform', 0.0),
#  ('vonmises', 0.0),
#  ('wald', 0.0),
#  ('weibull_min', 0.0),
#  ('weibull_max', 0.0),
#  ('wrapcauchy', nan)]

# %%
sns.kdeplot(BES_decomp[0]);

# %%
lr_vars = ['lr5W1W2W3W4W5', 'lr1W1W2W3W4W5', 'lr2W1W2W3W4W5',
       'lr4W1W2W3W4W5', 'lr3W1W2W3W4W5']
lr_coeffs = comp_dict[0]["components_"].loc[lr_vars]
lr_coeffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-1166-baea4c010fdb> in <module>()
#       1 lr_vars = ['lr5W1W2W3W4W5', 'lr1W1W2W3W4W5', 'lr2W1W2W3W4W5',
#       2        'lr4W1W2W3W4W5', 'lr3W1W2W3W4W5']
# ----> 3 lr_coeffs = comp_dict[0]["components_"].loc[lr_vars]
#       4 lr_coeffs
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1899                     raise ValueError('Cannot index with multidimensional key')
#    1900
# -> 1901                 return self._getitem_iterable(key, axis=axis)
#    1902
#    1903             # nested tuple slicing
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1141             if labels.is_unique and Index(keyarr).is_unique:
#    1142                 indexer = ax.get_indexer_for(key)
# -> 1143                 self._validate_read_indexer(key, indexer, axis)
#    1144
#    1145                 d = {axis: [ax.reindex(keyarr)[0], indexer]}
#
# ~\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1204                 raise KeyError(
#    1205                     u"None of [{key}] are in the [{axis}]".format(
# -> 1206                         key=key, axis=self.obj._get_axis_name(axis)))
#    1207
#    1208             # we skip the warning on Categorical/Interval
#
# KeyError: "None of [['lr5W1W2W3W4W5', 'lr1W1W2W3W4W5', 'lr2W1W2W3W4W5', 'lr4W1W2W3W4W5', 'lr3W1W2W3W4W5']] are in the [index]"

# %%
al_vars = ['al5W1W2W3W4W5', 'al1W1W2W3W4W5', 'al2W1W2W3W4W5',
       'al4W1W2W3W4W5', 'al3W1W2W3W4W5']
al_coeffs = comp_dict[1]["components_"].loc[al_vars]
al_coeffs
# Out:
# al5W1W2W3W4W5    125.219822
# al1W1W2W3W4W5    125.924860
# al2W1W2W3W4W5    112.967775
# al4W1W2W3W4W5     82.824421
# al3W1W2W3W4W5    120.098470
# Name: components_, dtype: float64

# %%
BES_vals[lr_vars].multiply(lr_coeffs).sum(axis=1).hist(bins=100)

# %%
BES_vals[lr_vars].hist(bins=5);

# %%
some_vars = np.array(lr_vars)[[1,2]]
BES_vals[some_vars].multiply(lr_coeffs.loc[some_vars]).sum(axis=1).hist(bins=100)
print(some_vars)
# Out:
# ['lr1W1W2W3W4W5' 'lr2W1W2W3W4W5']

# %%
np.array(lr_vars)[[1,2]]
# Out:
# array(['lr1W1W2W3W4W5', 'lr2W1W2W3W4W5'], dtype='<U13')

# %%
lr_coeffs
# Out:
# lr5W1W2W3W4W5    106.539255
# lr1W1W2W3W4W5    113.869114
# lr2W1W2W3W4W5    123.687908
# lr4W1W2W3W4W5    128.892847
# lr3W1W2W3W4W5    130.223882
# Name: components_, dtype: float64

# %%
BES_vals[np.array(lr_vars)[[0,4]]].sum(axis=1).hist(bins=25)

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.gca()
BES_vals[[x for x in BES_Panel.columns if re.match("(al|lr)\dW1W2W3W4W5",x)]].hist(ax=ax, bins=5);
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\IPython\core\interactiveshell.py:2963: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
fig = plt.figure(figsize=(10,10))
ax = plt.gca()
al_lr_vals = [x for x in BES_Panel.columns if re.match("(al|lr)\dW13",x)]
BES_vals = BES_Panel[al_lr_vals]
BES_vals = BES_vals.replace("Don't know",np.nan).dropna().apply(lambda x: x.cat.codes)
BES_vals[al_lr_vals].hist(ax=ax, bins=5);
# Out:
# C:\Users\Marios\AppData\Local\conda\conda\envs\BES_analysis\lib\site-packages\IPython\core\interactiveshell.py:2963: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
lr_vals = [x for x in BES_Panel.columns if re.match("(lr)\dW13",x)]
lr_corr = pd.get_dummies(BES_Panel[lr_vals].replace("Don't know",np.nan).dropna()).corr()
lr_corr = lr_corr.drop([x for x in lr_corr.index if "Don't know" in x]).drop([x for x in lr_corr.columns if "Don't know" in x],axis=1)
lr_corr = lr_corr.where(np.triu(np.ones(lr_corr.shape), k=5).astype(np.bool))
lr_corr.stack().sort_values()
# Out:
# lr2W13_Agree                       lr5W13_Strongly agree               -0.308321
#                                    lr3W13_Strongly agree               -0.299146
# lr3W13_Neither agree nor disagree  lr4W13_Strongly agree               -0.282135
# lr1W13_Strongly agree              lr3W13_Agree                        -0.270785
# lr2W13_Agree                       lr4W13_Strongly agree               -0.267444
# lr2W13_Strongly agree              lr4W13_Agree                        -0.258811
# lr2W13_Neither agree nor disagree  lr4W13_Strongly agree               -0.254170
# lr1W13_Disagree                    lr3W13_Strongly agree               -0.242997
# lr4W13_Agree                       lr5W13_Strongly agree               -0.241625
# lr1W13_Agree                       lr3W13_Neither agree nor disagree   -0.240571
# lr2W13_Strongly agree              lr5W13_Neither agree nor disagree   -0.235876
# lr2W13_Neither agree nor disagree  lr3W13_Strongly agree               -0.234598
# lr1W13_Strongly agree              lr4W13_Agree                        -0.233512
# lr1W13_Disagree                    lr4W13_Strongly agree               -0.232381
# lr2W13_Strongly agree              lr4W13_Neither agree nor disagree   -0.231590
# lr1W13_Strongly agree              lr3W13_Neither agree nor disagree   -0.228944
# lr1W13_Neither agree nor disagree  lr3W13_Strongly agree               -0.227698
# lr2W13_Neither agree nor disagree  lr5W13_Strongly agree               -0.225953
# lr2W13_Strongly agree              lr5W13_Agree                        -0.222787
# lr1W13_Disagree                    lr2W13_Strongly agree               -0.216912
# lr3W13_Neither agree nor disagree  lr5W13_Strongly agree               -0.208382
# lr3W13_Disagree                    lr4W13_Strongly agree               -0.207235
# lr2W13_Strongly agree              lr4W13_Disagree                     -0.204270
# lr3W13_Agree                       lr5W13_Strongly agree               -0.200664
# lr3W13_Strongly agree              lr5W13_Neither agree nor disagree   -0.196125
# lr1W13_Agree                       lr3W13_Disagree                     -0.195540
# lr3W13_Strongly agree              lr5W13_Agree                        -0.194849
# lr1W13_Neither agree nor disagree  lr4W13_Strongly agree               -0.187931
# lr4W13_Neither agree nor disagree  lr5W13_Strongly agree               -0.185622
# lr1W13_Strongly agree              lr4W13_Neither agree nor disagree   -0.182735
#                                                                           ...
# lr4W13_Strongly disagree           lr5W13_Strongly disagree             0.322379
# lr1W13_Strongly disagree           lr4W13_Strongly disagree             0.326005
# lr2W13_Neither agree nor disagree  lr3W13_Neither agree nor disagree    0.339528
# lr3W13_Strongly disagree           lr5W13_Strongly disagree             0.342135
# lr3W13_Neither agree nor disagree  lr4W13_Neither agree nor disagree    0.345053
# lr1W13_Strongly disagree           lr3W13_Strongly disagree             0.352675
# lr2W13_Neither agree nor disagree  lr5W13_Neither agree nor disagree    0.354417
# lr1W13_Agree                       lr3W13_Agree                         0.372881
# lr2W13_Agree                       lr4W13_Agree                         0.383995
#                                    lr3W13_Agree                         0.385390
# lr2W13_Disagree                    lr4W13_Disagree                      0.387879
# lr2W13_Strongly disagree           lr4W13_Strongly disagree             0.391221
# lr3W13_Agree                       lr4W13_Agree                         0.391601
# lr2W13_Disagree                    lr5W13_Disagree                      0.396386
#                                    lr3W13_Disagree                      0.400163
# lr2W13_Agree                       lr5W13_Agree                         0.401456
# lr3W13_Disagree                    lr4W13_Disagree                      0.413009
# lr3W13_Strongly disagree           lr4W13_Strongly disagree             0.426703
# lr2W13_Strongly disagree           lr3W13_Strongly disagree             0.427897
# lr1W13_Strongly agree              lr5W13_Strongly agree                0.434440
# lr2W13_Strongly disagree           lr5W13_Strongly disagree             0.435824
# lr1W13_Strongly agree              lr2W13_Strongly agree                0.497262
#                                    lr4W13_Strongly agree                0.510447
# lr3W13_Strongly agree              lr5W13_Strongly agree                0.531486
# lr4W13_Strongly agree              lr5W13_Strongly agree                0.532863
# lr2W13_Strongly agree              lr4W13_Strongly agree                0.613378
#                                    lr5W13_Strongly agree                0.613887
# lr3W13_Strongly agree              lr4W13_Strongly agree                0.617051
# lr2W13_Strongly agree              lr3W13_Strongly agree                0.621080
# lr1W13_Strongly agree              lr3W13_Strongly agree                0.626961
# Length: 210, dtype: float64

# %%
lr_corr.stack().sort_values().head(10)
# Out:
# lr2W13_Agree                       lr5W13_Strongly agree               -0.308321
#                                    lr3W13_Strongly agree               -0.299146
# lr3W13_Neither agree nor disagree  lr4W13_Strongly agree               -0.282135
# lr1W13_Strongly agree              lr3W13_Agree                        -0.270785
# lr2W13_Agree                       lr4W13_Strongly agree               -0.267444
# lr2W13_Strongly agree              lr4W13_Agree                        -0.258811
# lr2W13_Neither agree nor disagree  lr4W13_Strongly agree               -0.254170
# lr1W13_Disagree                    lr3W13_Strongly agree               -0.242997
# lr4W13_Agree                       lr5W13_Strongly agree               -0.241625
# lr1W13_Agree                       lr3W13_Neither agree nor disagree   -0.240571
# dtype: float64

# %%
lr_corr.stack().sort_values().tail(10)
# Out:
# lr2W13_Strongly disagree  lr5W13_Strongly disagree    0.435824
# lr1W13_Strongly agree     lr2W13_Strongly agree       0.497262
#                           lr4W13_Strongly agree       0.510447
# lr3W13_Strongly agree     lr5W13_Strongly agree       0.531486
# lr4W13_Strongly agree     lr5W13_Strongly agree       0.532863
# lr2W13_Strongly agree     lr4W13_Strongly agree       0.613378
#                           lr5W13_Strongly agree       0.613887
# lr3W13_Strongly agree     lr4W13_Strongly agree       0.617051
# lr2W13_Strongly agree     lr3W13_Strongly agree       0.621080
# lr1W13_Strongly agree     lr3W13_Strongly agree       0.626961
# dtype: float64

# %%
lr_vals = [x for x in BES_Panel.columns if re.match("(al)\dW13",x)]
lr_corr = pd.get_dummies(BES_Panel[lr_vals].replace("Don't know",np.nan).dropna()).corr()
lr_corr = lr_corr.drop([x for x in lr_corr.index if "Don't know" in x]).drop([x for x in lr_corr.columns if "Don't know" in x],axis=1)
lr_corr = lr_corr.where(np.triu(np.ones(lr_corr.shape), k=5).astype(np.bool))
# Out:
# al2W13_Strongly disagree  al5W13_Disagree             0.339247
# al1W13_Agree              al3W13_Agree                0.342035
# al3W13_Strongly agree     al4W13_Strongly agree       0.348991
# al2W13_Strongly agree     al3W13_Strongly agree       0.410938
# al1W13_Strongly disagree  al3W13_Strongly disagree    0.424401
# al1W13_Strongly agree     al2W13_Strongly agree       0.434277
# al3W13_Strongly agree     al5W13_Strongly agree       0.506730
# al1W13_Strongly agree     al5W13_Strongly agree       0.507991
# al2W13_Strongly agree     al5W13_Strongly agree       0.528989
# al1W13_Strongly agree     al3W13_Strongly agree       0.556836
# dtype: float64

# %%
lr_corr.stack().sort_values().head(10)
# Out:
# al2W13_Strongly disagree           al5W13_Strongly agree               -0.263793
# al2W13_Strongly agree              al5W13_Neither agree nor disagree   -0.260398
# al1W13_Strongly agree              al5W13_Neither agree nor disagree   -0.250918
# al3W13_Strongly agree              al5W13_Neither agree nor disagree   -0.236659
# al1W13_Strongly agree              al3W13_Neither agree nor disagree   -0.233113
# al2W13_Strongly disagree           al3W13_Strongly agree               -0.219194
# al1W13_Neither agree nor disagree  al3W13_Strongly agree               -0.213828
# al3W13_Neither agree nor disagree  al5W13_Strongly agree               -0.210994
# al1W13_Neither agree nor disagree  al5W13_Strongly agree               -0.206367
# al1W13_Disagree                    al5W13_Strongly agree               -0.195342
# dtype: float64

# %%
lr_corr.stack().sort_values().tail(10)
# Out:
# al2W13_Strongly disagree  al5W13_Disagree             0.339247
# al1W13_Agree              al3W13_Agree                0.342035
# al3W13_Strongly agree     al4W13_Strongly agree       0.348991
# al2W13_Strongly agree     al3W13_Strongly agree       0.410938
# al1W13_Strongly disagree  al3W13_Strongly disagree    0.424401
# al1W13_Strongly agree     al2W13_Strongly agree       0.434277
# al3W13_Strongly agree     al5W13_Strongly agree       0.506730
# al1W13_Strongly agree     al5W13_Strongly agree       0.507991
# al2W13_Strongly agree     al5W13_Strongly agree       0.528989
# al1W13_Strongly agree     al3W13_Strongly agree       0.556836
# dtype: float64

# %%
BES_Panel["leftRightW1"].cat.c
# Out:
# Index(['Left', '1', '2', '3', '4', '5', '6', '7', '8', '9', 'Right',
#        'Don't know'],
#       dtype='object')

# %%
## Who are the centrists?

# %%
Centrist_corr = BES_reduced.corrwith( (BES_Panel[[x for x in BES_Panel if "leftRight" in x]]=="5").mean(axis=1) )
Centrist_corr.sort_values()
# Out:
# electionInterestW6__Very interested                             -0.217982
# lrUKIPW6__Right                                                 -0.215856
# participation_3W6_Yes                                           -0.213117
# lrUKIPW5__Right                                                 -0.202915
# registerChangeW3_Yes, I was told I have to re-register          -0.199676
# electionInterestW4__Very interested                             -0.197470
# electionInterestW5__Very interested                             -0.196442
# bestLeaderCampaignW5_Ed Miliband                                -0.195241
# lrUKIPW4__Right                                                 -0.193869
# bestOnMIIW6_Labour                                              -0.193095
# profile_work_statW7_Working part time (8-29 hours a week)       -0.186613
# partyContact1W6_Yes                                             -0.186244
# worstLeaderCampaignW6_Nick Clegg                                -0.182033
# lrUKIPW7__Right                                                 -0.179335
# bestOnMIIW4_Labour                                              -0.178696
# tryReduceInequalityLabW4_Yes                                    -0.177799
# bestOnMIIW5_Labour                                              -0.176377
# lrUKIPW2__Right                                                 -0.171132
# worstLeaderCampaignW5_Nick Clegg                                -0.170850
# allSourceIncome_1W6_Yes                                         -0.169478
# profile_newspaperW13_Other local daily morning newspaper        -0.165198
# bestOnMIIW2_Labour                                              -0.164604
# discussPolDaysW6__7 days                                        -0.164266
# subjClassW12_Yes, middle class                                  -0.164173
# partyIdW11_Labour                                               -0.162364
# subjClassW10_Yes, middle class                                  -0.160631
# lrUKIPW12__Right                                                -0.160416
# partyIdW10_Labour                                               -0.157914
# workingStatusW1W2W3W4W5_Working part time (8-29 hours a week)   -0.156646
# partyIdW12_Labour                                               -0.154725
#                                                                    ...
# profile_work_statW7_Retired                                      0.156583
# labPartnerUKIPW4_Would join Labour                               0.157232
# decidedVoteW5_No, not decided yet                                0.157840
# labPartnerUKIPW5_Would join Labour                               0.162081
# efficacyNoMatterW6__Strongly agree                               0.164132
# partyIdW1_No - none                                              0.164380
# tryReduceInequalityNoneW4_Yes                                    0.164754
# tuSupportW7__Mainly leave                                        0.164852
# partyIdW10_No - none                                             0.165104
# lrgreensW6__Right                                                0.165663
# euRefVoteW7_Leave the EU                                         0.166994
# conPartnerGreenW5_Would join Conservatives                       0.172839
# decidedVoteW4_No, not decided yet                                0.174011
# partyIdW2_No - none                                              0.174157
# efficacyNoMatterW10__Strongly agree                              0.174867
# partyIdW11_No - none                                             0.175246
# euRefVoteW3_Leave the EU                                         0.178620
# euRefVoteW6_Leave the EU                                         0.179481
# partyIdW8_No - none                                              0.180735
# euRefVoteW4_Leave the EU                                         0.181211
# partyIdW12_No - none                                             0.182340
# efficacyNoMatterW4__Strongly agree                               0.184442
# partyIdW3_No - none                                              0.185970
# partyIdW13_No - none                                             0.187645
# partyIdW9_No - none                                              0.192610
# partyIdW7_No - none                                              0.196700
# partyIdW4_No - none                                              0.199051
# efficacyNoMatterW9__Strongly agree                               0.204913
# partyIdW6_No - none                                              0.206723
# efficacyNoMatterW7__Strongly agree                               0.216720
# Length: 2526, dtype: float64

# %%
everCentrist = np.any(BES_Panel[[x for x in BES_Panel if "leftRight" in x]]=="5",axis=1).astype('float')

# %%
everCentrist_corr = BES_reduced.corrwith( pd.DataFrame(everCentrist)[0] )
everCentrist_corr.sort_values()
# Out:
# electionInterestW6__Very interested                                     -0.175549
# lrUKIPW6__Right                                                         -0.173736
# lrUKIPW5__Right                                                         -0.168031
# electionInterestW4__Very interested                                     -0.166703
# participation_3W6_Yes                                                   -0.163846
# lrUKIPW4__Right                                                         -0.159577
# electionInterestW5__Very interested                                     -0.159473
# lrUKIPW2__Right                                                         -0.148543
# lrUKIPW7__Right                                                         -0.147266
# partyContact1W6_Yes                                                     -0.136471
# electionInterestW13__Very interested                                    -0.135506
# lrUKIPW11__Right                                                        -0.134562
# lrUKIPW12__Right                                                        -0.133828
# subjClassW2_W4W7W9_Yes, middle class                                    -0.133673
# discussPolDaysW6__7 days                                                -0.131517
# conPartnerUKIPW4_Would join Conservatives                               -0.131063
# tryReduceInequalityLabW4_Yes                                            -0.130390
# immigEconW3__Good for economy                                           -0.130345
# electionInterestW12__Very interested                                    -0.127304
# bestLeaderCampaignW5_Ed Miliband                                        -0.127179
# EUIntegrationConW8__Protect our independence                            -0.126312
# EUIntegrationConW9__Protect our independence                            -0.126222
# profile_education_age__Still at school/Full time student                -0.124456
# redistConW13__Government should be less concerned about equal incomes   -0.123067
# EUIntegrationConW7__Protect our independence                            -0.122895
# conPartnerUKIPW5_Would join Conservatives                               -0.122262
# immigEconW2__Good for economy                                           -0.121496
# immigCulturalW2__Enriches cultural life                                 -0.118757
# subjClassW10_Yes, middle class                                          -0.118747
# registerChangeW3_Yes, I was told I have to re-register                  -0.118296
#                                                                            ...
# partyIdW8_No - none                                                      0.125085
# ageGroup__66+                                                            0.125607
# euRefVoteW6_Leave the EU                                                 0.126441
# al_scaleW7W8W9__Authoritarian                                            0.126741
# labPartnerUKIPW5_Would join Labour                                       0.126833
# partyIdW10_No - none                                                     0.127199
# Age                                                                      0.127657
# tuSupportW7__Mainly leave                                                0.127763
# partyIdStrengthW13__Not very strong                                      0.127802
# partyIdW1_No - none                                                      0.128034
# strongLeaderW11__Strongly agree                                          0.129726
# partyIdW11_No - none                                                     0.129991
# conPartnerGreenW5_Would join Conservatives                               0.130519
# euRefVoteW4_Leave the EU                                                 0.130624
# partyIdW3_No - none                                                      0.132731
# partyIdW2_No - none                                                      0.133504
# lrgreensW6__Right                                                        0.134313
# partyIdW9_No - none                                                      0.134331
# partyIdW7_No - none                                                      0.137140
# decidedVoteW4_No, not decided yet                                        0.139318
# partyIdW12_No - none                                                     0.142206
# efficacyNoMatterW11__Strongly agree                                      0.142432
# partyIdW6_No - none                                                      0.143405
# partyIdW4_No - none                                                      0.143772
# partyIdW13_No - none                                                     0.145066
# efficacyNoMatterW6__Strongly agree                                       0.155762
# efficacyNoMatterW4__Strongly agree                                       0.161354
# efficacyNoMatterW10__Strongly agree                                      0.164768
# efficacyNoMatterW9__Strongly agree                                       0.173797
# efficacyNoMatterW7__Strongly agree                                       0.184546
# Length: 2526, dtype: float64

# %%
everCentrist_corr.loc[[x for x in BES_reduced.columns if "lr_scale" in x]]
# Out:
# lr_scaleW7W8W9__Right       -0.019895
# lr_scaleW6__Right           -0.000912
# lr_scaleW1W2W3W4W5__Right   -0.020097
# lr_scaleW10W11W12__Right    -0.006131
# lr_scaleW13__Right          -0.003457
# dtype: float64

# %%
everCentrist_corr.loc[[x for x in BES_reduced.columns if "al_scale" in x]]
# Out:
# al_scaleW7W8W9__Authoritarian        0.126741
# al_scaleW6__Authoritarian            0.123687
# al_scaleW1W2W3W4W5__Authoritarian    0.123512
# al_scaleW10W11W12__Authoritarian     0.114016
# al_scaleW13__Authoritarian           0.110439
# dtype: float64

# %%
# leftRight
im_var = "leftRight"

immig_vars = [x for x in BES_Panel.columns if im_var in x]
wave_list = [x.split(im_var)[1] for x in immig_vars]
immig_vars.append('wt_new_W13')
BES_immig = BES_Panel[immig_vars]
replace_dict = {x:x for x in BES_immig[immig_vars[0]].cat.categories}
colourmap = {BES_immig[immig_vars[0]].cat.categories[x]:cmap[x] for x in range(0, len( BES_immig[immig_vars[0]].cat.categories)) } 
base_order = BES_immig[immig_vars[0]].cat.categories

# %%
threshold = 0.5
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=2
sankify()
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['LeftW1', '1W1', '2W1', '3W1', '4W1', '5W1', "Don't…

# %%
threshold = 0.1
margins=dict(top=30, bottom=10, left=150, right=150)
layout = Layout(width="1000", height="650")
diagram_scale=10
sankey = sankify_init_col()
sankey
sankey.auto_save_png(BES_output_folder+os.sep+"leftRight_sankey.png")
# Out:
# SankeyWidget(groups=[{'id': 'W1', 'title': 'W1', 'nodes': ['LeftW1', '1W1', '2W1', '3W1', '4W1', '5W1', '6W1',…

# %%
# 'lrUKIPW2__Right'
# 'EUIntegrationUKIPW7__Protect our independence'
# 'immigUKIPW7__Allow many more'
# 'tryReduceImmigUKIPW4_Yes',
# 'tryReduceInequalityUKIPW4_Yes',
# 'certaintyEUUKIPW8__Very certain'
# 'conPartnerUKIPW4_Would join Conservatives'
# 'labPartnerUKIPW4_Would join Labour'
# 'noChanceCoalitionUKIPW11_Yes'

# %%
all_placement = [x for x in BES_reduced if re.match("lr[^0-9_]+W\d+__Right"+\
                                    '|EUIntegration[^S]+W\d+__Protect our independence'\
                                    '|immig[^S]+W\d+__Allow many more'\
                                    '|tryReduceImmig\w+W\d+_Yes'\
                                    '|tryReduceInequality\w+W\d+_Yes'\
                                    '|certaintyEU\w+W\d+__Very certain'\
                                    '|conPartner\w+W\d+_Would join Conservatives'\
                                    '|labPartner\w+W\d+_Would join Labour'\
                                    '|noChanceCoalition\w+W\d+_Yes'\
                                    ,x)]

# %%
## Factor Analysis by <other>placement

# %%
# sorted([x for x in BES_reduced if "UKIP" in x])
# Placement
# 'lrUKIPW2__Right'
# 'EUIntegrationUKIPW7__Protect our independence'
# 'immigUKIPW7__Allow many more'
# 'tryReduceImmigUKIPW4_Yes',
# 'tryReduceInequalityUKIPW4_Yes',
# 'certaintyEUUKIPW8__Very certain'
# 'conPartnerUKIPW4_Would join Conservatives'
# 'labPartnerUKIPW4_Would join Labour'
# 'noChanceCoalitionUKIPW11_Yes'

# Preference
# 'winConstituencyUKIPW4__100 - Very likely to win'
#'handleMIIUKIPW5__Very well'
#'likeUKIPW7__Strongly like'
#'ptvUKIPW7__Very likely'
#'achieveReduceImmigUKIPW11_Yes' ?
# 'ashcroftW4_United Kingdom Independence Party (UKIP)'
#'bestOnMIIW11_United Kingdom Independence Party (UKIP)'

#'generalElectionVoteW10_United Kingdom Independence Party (UKIP)'
# 'partyIdW10_United Kingdom Independence Party (UKIP)'
#'profile_past_vote_2005_United Kingdom Independence Party (UKIP)'

# %%
 [x for x in BES_reduced if re.match("lr[^_]+W\d+(__Right|__Strongly agree)|leftRightW\d+__Right",x)]
# Out:
# ['leftRightW1__Right',
#  'leftRightW2__Right',
#  'lrConW2__Right',
#  'lrLabW2__Right',
#  'lrLDW2__Right',
#  'lrUKIPW2__Right',
#  'leftRightW3__Right',
#  'leftRightW4__Right',
#  'lrConW4__Right',
#  'lrLabW4__Right',
#  'lrLDW4__Right',
#  'lrUKIPW4__Right',
#  'lrgreensW4__Right',
#  'leftRightW5__Right',
#  'lrConW5__Right',
#  'lrLabW5__Right',
#  'lrLDW5__Right',
#  'lrUKIPW5__Right',
#  'lrgreensW5__Right',
#  'leftRightW6__Right',
#  'lrConW6__Right',
#  'lrLabW6__Right',
#  'lrLDW6__Right',
#  'lrUKIPW6__Right',
#  'lrgreensW6__Right',
#  'lr1W6__Strongly agree',
#  'lr2W6__Strongly agree',
#  'lr3W6__Strongly agree',
#  'lr4W6__Strongly agree',
#  'lr5W6__Strongly agree',
#  'leftRightW7__Right',
#  'lrConW7__Right',
#  'lrLabW7__Right',
#  'lrLDW7__Right',
#  'lrUKIPW7__Right',
#  'lrCameronW7__Right',
#  'lrCorbynW7__Right',
#  'leftRightW10__Right',
#  'lrConW10__Right',
#  'leftRightW11__Right',
#  'lrConW11__Right',
#  'lrLabW11__Right',
#  'lrLDW11__Right',
#  'lrUKIPW11__Right',
#  'leftRightW12__Right',
#  'lrConW12__Right',
#  'lrLabW12__Right',
#  'lrLDW12__Right',
#  'lrUKIPW12__Right',
#  'lrgreensW12__Right',
#  'lrMayW12__Right  10',
#  'lrCorbynW12__Right',
#  'leftRightW13__Right',
#  'lr1W13__Strongly agree',
#  'lr2W13__Strongly agree',
#  'lr3W13__Strongly agree',
#  'lr4W13__Strongly agree',
#  'lr5W13__Strongly agree',
#  'lr1W1W2W3W4W5__Strongly agree',
#  'lr2W1W2W3W4W5__Strongly agree',
#  'lr3W1W2W3W4W5__Strongly agree',
#  'lr4W1W2W3W4W5__Strongly agree',
#  'lr5W1W2W3W4W5__Strongly agree',
#  'lr1W7W8W9__Strongly agree',
#  'lr2W7W8W9__Strongly agree',
#  'lr3W7W8W9__Strongly agree',
#  'lr4W7W8W9__Strongly agree',
#  'lr5W7W8W9__Strongly agree',
#  'lr1W10W11W12__Strongly agree',
#  'lr2W10W11W12__Strongly agree',
#  'lr3W10W11W12__Strongly agree',
#  'lr4W10W11W12__Strongly agree',
#  'lr5W10W11W12__Strongly agree']

# %%
# lr placement inc self + lr values
lr_placement_inc_self_lr_vals = [x for x in BES_reduced if re.match("lr[^_]+W\d+(__Right|__Strongly agree)|leftRightW\d+__Right",x)]
BES = BES_reduced[lr_placement_inc_self_lr_vals]
Treatment = dataset_name + "lr_placement_inc_self_lr_Vals"

# %%
# lr placement inc self
lr_placement_inc_self = [x for x in BES_reduced if re.match("lr[^0-9_]+W\d+__Right|leftRightW\d+__Right",x)]
BES = BES_reduced[lr_placement_inc_self]
Treatment = dataset_name + "lr_placement_inc_self"

# %%
BES = BES_reduced[lr_placement]
Treatment = dataset_name + "lr_placement"

# %%
#all_placement
BES = BES_reduced[all_placement]
Treatment = dataset_name + "all_placement"
# confusing!

# %%
BES_std.shape[1]
# Out:
# 37

# %%
output_subfolder = BES_output_folder + Treatment + os.sep
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# normalise data (subtract out the mean, divide through by standard deviation)

clean_feature_set_std = StandardScaler().fit_transform(BES.values )
BES_std = pd.DataFrame(      clean_feature_set_std,
                             columns = BES.columns,
                             index   = BES.index      )
    

n_components = BES_std.shape[1]
# n_components = 3
decomp = FactorAnalysis(svd_method = 'lapack',n_components = n_components) ## ~10s ,n_components=30 -> 1.5 hrs
decomp_method = str(decomp).split("(")[0] 

X_r = decomp.fit_transform(BES_std)

BES_decomp = pd.DataFrame(   X_r,
                             columns = range(0,n_components),
                             index   = BES_std.index)
                             

load_suff = "FactorAnalysis"
save = True # False => Load

if save & ( 'decomp' in globals() ): # SAVE    ##( 'decomp' not in globals() )
    decomp_method = str(decomp).split("(")[0] 
    subdir = output_subfolder + decomp_method
    fname = subdir+ os.sep + decomp_method
    # create dir, save decomp object, BES_decomp, BES_std    
    if not os.path.exists(subdir): os.makedirs(subdir)
    with open(fname+".pkl", "wb") as f: pickle.dump( decomp, f )
    BES_decomp.to_hdf(fname+".hdf"        , decomp_method)
    BES_std.to_hdf(   fname+"_std"+".hdf" , decomp_method)
    
else: # LOAD decomp results (default is SAVE)
    decomp_method = load_suff
    subdir = output_subfolder + os.sep + decomp_method    
    fname = subdir + os.sep + decomp_method
    if not os.path.exists(subdir): raise Exception(subdir + ' does not exist!')
    # load decomp object, BES_decomp, BES_std, n_components
    with open(fname+".pkl", "rb") as f: decomp = pickle.load(f) 
    BES_decomp = pd.read_hdf(fname+".hdf")
    BES_std    = pd.read_hdf(fname+"_std"+".hdf")
    n_components = decomp.components_.shape[0] 
    
    
(BES_decomp, comp_labels, comp_dict) = display_components(n_components, decomp,
                                                          BES_std.columns, BES_decomp, manifest, 
                                                          save_folder = subdir,  
                                                          show_first_x_comps= 5, show_histogram = False)

# %%
from sklearn import cluster
X = X_r

two_means = cluster.MiniBatchKMeans(n_clusters=7)
two_means.fit(X)

labels = two_means.labels_
cluster_centers = two_means.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

# %%
x_axis = 0
y_axis = 1

xlim = np.floor( BES_decomp.loc[ :, x_axis ].min() ), np.ceil( BES_decomp.loc[ :, x_axis ].max() )
ylim = np.floor( BES_decomp.loc[ :, y_axis ].min() ), np.ceil( BES_decomp.loc[ :, y_axis ].max() )

fig = plt.figure( figsize=(16,10) )
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, x_axis], X[my_members, y_axis], col + '.', alpha=.5)
    plt.plot(cluster_center[x_axis], cluster_center[y_axis], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    
plt.xlim(xlim)
plt.ylim(ylim)
    
plt.xlabel( comp_labels[x_axis] )
plt.ylabel( comp_labels[y_axis] ) 
plt.title('Estimated number of clusters: %d' % n_clusters_);

# %%
x_axis = 0
y_axis = 2


fig = plt.figure( figsize=(16,10) )
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, x_axis], X[my_members, y_axis], col + '.', alpha=.5)
    plt.plot(cluster_center[x_axis], cluster_center[y_axis], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    
plt.xlim(xlim)
plt.ylim(ylim)
    
plt.xlabel( comp_labels[x_axis] )
plt.ylabel( comp_labels[y_axis] ) 
plt.title('Estimated number of clusters: %d' % n_clusters_);

# %%
# %%time
import numpy as np
from sklearn.cluster import MeanShift, estimate_bandwidth
# from sklearn.datasets.samples_generator import make_blobs

X = X_r

# The following bandwidth can be automatically detected using
bandwidth = estimate_bandwidth(X, quantile=0.5, n_samples=1000)

ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
# ms = MeanShift()
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

labels_unique = np.unique(labels)
n_clusters_ = len(labels_unique)

print("number of estimated clusters : %d" % n_clusters_)


fig = plt.figure( figsize=(16,10) )
plt.clf()

colors = cycle('bgrcmykbgrcmykbgrcmykbgrcmyk')
for k, col in zip(range(n_clusters_), colors):
    my_members = labels == k
    cluster_center = cluster_centers[k]
    plt.plot(X[my_members, x_axis], X[my_members, y_axis], col + '.')
    plt.plot(cluster_center[x_axis], cluster_center[y_axis], 'o', markerfacecolor=col,
             markeredgecolor='k', markersize=14)
    
plt.xlim(xlim)
plt.ylim(ylim)
    
plt.xlabel( comp_labels[x_axis] )
plt.ylabel( comp_labels[y_axis] ) 
plt.title('Estimated number of clusters: %d' % n_clusters_)
# plt.show()

fig.savefig(output_subfolder + decomp_method+ os.sep +"Cluster_estimation.png",bbox_inches='tight')
# Out:
# number of estimated clusters : 22
# Wall time: 16 s

# %%
#
