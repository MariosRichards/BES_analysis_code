# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re, os, pickle

# %%
dataset_folder = "C:\\Users\\Marios\\Documents\\GitHub\\Thomas Prosser project\\datasets\\"
output_folder = "C:\\Users\\Marios\\Documents\\GitHub\\Thomas Prosser project\\output\\"

# %%
def get_dta_header_labels(filepath):

    reader = pd.io.stata.StataReader( filepath )
    header = reader.variable_labels()
    labels = reader.value_labels()
    return header,labels

# %%
group_to_type_dict = {'party_names':'obs_vars','country_variables':'obs_vars','observation_variables':'obs_vars',
 'party_id':'obs_vars',
 'source_variables':'dataset_vars',
 'party_electoral':'elec_vars',
 'dummied_variables':'dummy_vars',
 'dummiable_variables':'dropped',
 'policy_dimensions':'expert_op', 'ideological_dimensions':'expert_op',
       'eu_policy_questions':'expert_op', 'eu_integration_admission':'expert_op',
       'leadership_divisions':'expert_op', 'ukraine_specific_questions':'expert_op',
       'party_characteristics':'expert_op', 'eu_membership_requirements':'expert_op',
       'immigration_integration_pos':'man_cod',
 'index_jahn_lr':"id_dim",'index_jahn_gg':"id_dim",'index_jahn_oberst_cohesion':"id_dim",
 'index_franzmann_kaiser':"id_dim",'index_budge':"id_dim",'adhoc_index':"id_dim",
        "man_cod":"man_cod","coder_ratings":"coder_ratings",
        "computed_values":"id_dim","parlgov_index":"id_dim",
        "notes":"notes",
                           
                           }

# %%
partyfacts_core_parties = pd.read_csv(dataset_folder+"PartyFacts"+os.sep+ "partyfacts-core-parties.csv")
partyfacts_external_parties = pd.read_csv(dataset_folder+"PartyFacts"+os.sep+ "partyfacts-external-parties.csv")
partyfacts_countries = pd.read_csv(dataset_folder+"PartyFacts"+os.sep+ "partyfacts-countries.csv")
partyfacts_datasets = pd.read_csv(dataset_folder+"PartyFacts"+os.sep+ "partyfacts-datasets.csv")

pf_country_to_code = partyfacts_countries[["country","name"]].set_index("name")["country"].apply(lambda x: x.lower())

# %%
shared_columns = ["partyfacts_id","year","edate","dataset","dataset_index","country"]
shared_description = {"partyfacts_id":"PartyFacts party id","year":"observative year","edate":"observation full date",
                      "dataset":"Source dataset (partyfacts schema when present)","dataset_index":"Source dataset row index","country":"ISO 3166-1 alpha-3 country codes"}

# %%
CHES_comb = pd.read_pickle(dataset_folder+"CHES"+os.sep+"CHES_comb_linked.zip",compression='zip')

CHES_comb[[x for x in CHES_comb.columns if "intgroup__" in x]] = CHES_comb[[x for x in CHES_comb.columns if "intgroup__" in x]].astype(float)
CHES_comb[["year","partyfacts_id"]].isnull().sum(),CHES_comb.shape

dataset = "ches"
ds_brac = "("+dataset+")"
CHES_comb["dataset"] = dataset
CHES_comb["dataset_index"] = CHES_comb.index

CHES_comb = CHES_comb.rename(columns={x:ds_brac+x for x in CHES_comb.columns if x not in shared_columns})

CHES_vl = pd.read_csv(dataset_folder+"CHES"+os.sep+"CHES_comb_variable_list.csv")
CHES_vl.columns = ["variable","group"]
    
CHES_vl["type"] = CHES_vl["group"].apply(lambda x: group_to_type_dict[x] if x in group_to_type_dict.keys() else np.nan )
CHES_vl.loc[CHES_vl["variable"].apply(lambda x: x in shared_columns),"type"] = "cross-dataset"

CHES_vl["integrated_variable"] = CHES_vl.apply(lambda x: ds_brac+x["variable"] if x["type"] != "cross-dataset" else x["variable"], axis=1)

description = shared_description.copy()
CHES_vl["description"] = CHES_vl["variable"].apply(lambda x: description[x] if x in description.keys() else np.nan )

CHES_vl.loc[CHES_vl.index.max()+1] = ["dataset_index","source_variables","dataset_vars","dataset_index",np.nan]

# %%
manifesto_project = pd.read_pickle(dataset_folder+"CMP"+os.sep+ "manifesto_project_linked.zip",compression='zip')

manifesto_project["year"] = manifesto_project["edate"].dt.year

cmp_country_replace_dict = {"North Macedonia":"Macedonia","Bosnia-Herzegovina":"Bosnia and Herzegovina","South Korea":"Korea (South)"}
manifesto_project["country"] = manifesto_project["countryname"].replace(cmp_country_replace_dict).apply(lambda x: pf_country_to_code.loc[x])

cmp_family_replace_dict = {'eco ecologist':'green', 'lef socialist or other left':'rad left', 'soc social democratic':'socialist',
       'lib liberal':'liberal', 'chr christian democrat':'christdem', 'con conservative':'cons',
       'nat nationalist':'rad right', 'agr agrarian':'agrarian', 'eth ethnic-regional':'regional',
       'sip special issue':'special issue', 'div divers alliance':'coalition', 'mi missing information':np.nan}

# for more consistency with other datasets
manifesto_project = manifesto_project.rename(columns={"parfam":"family"})

family_col = "family"
manifesto_project[family_col] = manifesto_project[family_col].replace(cmp_family_replace_dict)
dummies = pd.get_dummies(manifesto_project[family_col] ,prefix=family_col, prefix_sep='__')
dummies.loc[manifesto_project[family_col].isnull(),:] = np.nan
manifesto_project[dummies.columns] = dummies



dataset = "manifesto"
ds_brac = "("+dataset+")"
manifesto_project["dataset"] = dataset
manifesto_project["dataset_index"] = manifesto_project.index
manifesto_project = manifesto_project.rename(columns={x:ds_brac+x for x in manifesto_project.columns if x not in shared_columns})

manifesto_project[["year","partyfacts_id"]].isnull().sum(),manifesto_project.shape
# could dummy political families, normalise numerical columns
# Out:
# (year             0
#  partyfacts_id    6
#  dtype: int64,
#  (4582, 188))

# %%
cmp_vl = pd.DataFrame(columns = ["variable","group","type","integrated_variable","description"])
cmp_vl["integrated_variable"] = manifesto_project.columns
cmp_vl["variable"] = cmp_vl["integrated_variable"].apply(lambda x: x.replace(ds_brac,""))

cmp_var_to_group_dict = {
       'country':'country_variables', 'countryname':'country_variables', 'oecdmember':'country_variables', 'eumember':'country_variables',
       'edate':'observation_variables', 'date':'observation_variables',
       'party':'party_id', 'partyname':'party_names', 'partyabbrev':'party_names',
       'family':'dummiable_variables', 'coderid':'observation_variables',
       'manual':'observation_variables', 'coderyear':'observation_variables', 'testresult':'observation_variables', 'testeditsim':'observation_variables',
       'pervote':'party_electoral', 'voteest':'party_electoral', 'presvote':'party_electoral', 'absseat':'party_electoral', 'totseats':'party_electoral',
       'progtype':'observation_variables',  'datasetorigin':'observation_variables', 'corpusversion':'observation_variables', 'total':'observation_variables',
       'rile':'computed_values', 'planeco':'computed_values', 'markeco':'computed_values', 'welfare':'computed_values', 'intpeace':'computed_values',
       'datasetversion':'source_variables', 'partyfacts_id':'party_id', 'year':'observation_variables', 'dataset':'source_variables',
       'dataset_index':'source_variables',
 }

cmp_var_to_group_dict.update({x.replace(ds_brac,""):"man_cod" for x in manifesto_project.columns if re.search("peruncod|per\d+",x)})
cmp_var_to_group_dict.update({x.replace(ds_brac,""):"dummied_variables" for x in manifesto_project.columns if "family__" in x})

# pf_core_vl["description"] = pf_core_vl["variable"].apply(lambda x: pf_core_var_description[x] if x in pf_core_var_description.keys() else np.nan )    
cmp_vl["group"] = cmp_vl["variable"].apply(lambda x: cmp_var_to_group_dict[x] if x in cmp_var_to_group_dict.keys() else np.nan )
cmp_vl["type"] = cmp_vl["group"].apply(lambda x: group_to_type_dict[x] if x in group_to_type_dict.keys() else np.nan )
cmp_vl.loc[cmp_vl["variable"].apply(lambda x: x in shared_columns),"type"] = "cross-dataset"

header,labels = get_dta_header_labels(dataset_folder+"CMP"+os.sep+ "MPDataset_MPDS2020a_stata14.dta")

cmp_vl["description"] = cmp_vl["variable"].apply(lambda x: header[x] if x in header.keys() else np.nan )    

cmp_vl["description"] = cmp_vl["variable"].apply(lambda x: shared_description[x] if x in shared_description.keys() else x )

# %%
pip_ideol = pd.read_pickle( dataset_folder+"PIP"+os.sep+"ideological_indices_linked.zip" , compression = 'zip' )

pip_ideol = pip_ideol.rename(columns = {"Year":"year"})
pip_ideol.loc[pip_ideol["year"].isnull(),"year"]= 2017

pip_ideol["year"] = pip_ideol["year"].astype(int)

pip_ideol = pip_ideol.rename(columns = {"Quarter":"edate","CMP party code":"CMP party name",})
pip_ideol = pip_ideol.drop('party family membership',axis=1) ## it's just the CMP family code


pip_country_replace_dict = {"Great Britain":"United Kingdom","USA":"United States"}
pip_ideol["country"] = pip_ideol["Country name"].replace(pip_country_replace_dict).apply(lambda x: pf_country_to_code.loc[x])

dataset = "pip"
ds_brac = "("+dataset+")"
pip_ideol["dataset"] = dataset
pip_ideol["dataset_index"] = pip_ideol.index


pip_ideol = pip_ideol.rename(columns={x:ds_brac+x for x in pip_ideol.columns if x not in shared_columns})

pip_ideol[["year","partyfacts_id"]].isnull().sum(),pip_ideol.shape
# dummy party families, normalize
# Out:
# (year             0
#  partyfacts_id    0
#  dtype: int64,
#  (3953, 48))

# %%
pip_ideol_vl = pd.DataFrame(columns = ["variable","group","type","integrated_variable","description"])

pip_ideol_vl["integrated_variable"] = pip_ideol.columns

pip_ideol_vl["variable"] = pip_ideol_vl["integrated_variable"].apply(lambda x: x.replace(ds_brac,""))

pip_ideol_var_to_group_dict = {
    'Unique ID for each observation (ISO.Quarter.Party)':'observation_variables',
    'Numeric country code (ISO)':'country_variables', 'Country name':'country_variables',
    'year':'observation_variables', 'edate':'observation_variables',
    'Consecutive number of the quarters':'party_electoral',
    'Dummy: 1 = Government party':'party_electoral', 'Existence of a party':'party_electoral',
    'CMP party name':'party_names', 'Name of party (english)':'party_names', 'party abbreviation':'party_names',
    'Party code according to CMP':'party_id', 'Name of the government party':'party_names',
    'partyfacts_id':"party_id",'partyfacts_id_cmp':"party_id", 'country':'country_variables', 'dataset':'source_variables',
    'Index Jahn: LR':"index_jahn_lr", 'Index Jahn: LR Importance':"index_jahn_lr",
    'Index Jahn: LR Core':"index_jahn_lr", 'Index Jahn: LR Core Importance':"index_jahn_lr",
    'Index Jahn: LR Plus':"index_jahn_lr", 'Index Jahn: LR Plus Importance':"index_jahn_lr",
    'Index Jahn: LR (Unstandardized)':"index_jahn_lr",
    'Index Jahn: LR Core (Unstandardized)':"index_jahn_lr",
    'Index Jahn: LR Plus (Unstandardized)':"index_jahn_lr",
    'Index Jahn: GG':"index_jahn_gg",'Index Jahn: GG Importance':"index_jahn_gg",
    'Index Jahn: GG Core':"index_jahn_gg",
    'Index Jahn: GG Core Importance':"index_jahn_gg", 'Index Jahn: GG Plus':"index_jahn_gg",
    'Index Jahn: GG Plus Importance':"index_jahn_gg",
    'Index Jahn: GG (Unstandardized)':"index_jahn_gg",
    'Index Jahn: GG Core (Unstandardized)':"index_jahn_gg",
    'Index Jahn: GG Plus (Unstandardized)':"index_jahn_gg",
    'Index Jahn/Oberst: LR Cohesion':"index_jahn_oberst_cohesion",
    'Index Jahn/Oberst: GG Cohesion':"index_jahn_oberst_cohesion",
    'Index Franzmann/Kaiser: Left-Right':"index_franzmann_kaiser",
    'Index Franzmann/Kaiser: Economic Dimension':"index_franzmann_kaiser",
    'Index Franzmann/Kaiser: Non-Economic Dimension':"index_franzmann_kaiser",
    'Index Budge et al.: RILE':"index_budge",
    'Index Budge et al.: Planned Economy':"index_budge",
    'Index Budge et al.: Market Economy':"index_budge",
    'Index Budge et al.: Welfare':"index_budge",
    'Index Budge et al.: International Peace':"index_budge",
    'Ad hoc-Index: Pro/Anti EU (Warntjen, Hix, Crombez 2008)':"adhoc_index",
    'Ad hoc-Index: GG light (Knill)':"adhoc_index",
    'dataset_index':'source_variables',
                          }


pip_ideol_var_description = {
 
}



 # country and year excepted as a shared variables
# PImPo_vl["description"] = PImPo_vl["variable"].apply(lambda x: pimpo_var_description[x] if x in pimpo_var_description.keys() else np.nan )    
pip_ideol_vl["group"] = pip_ideol_vl["variable"].apply(lambda x: pip_ideol_var_to_group_dict[x] if x in pip_ideol_var_to_group_dict.keys() else np.nan )
pip_ideol_vl["type"] = pip_ideol_vl["group"].apply(lambda x: group_to_type_dict[x] if x in group_to_type_dict.keys() else np.nan )
pip_ideol_vl.loc[pip_ideol_vl["variable"].apply(lambda x: x in shared_columns),"type"] = "cross-dataset"
pip_ideol_vl["description"] = pip_ideol_vl["variable"].apply(lambda x: shared_description[x] if x in shared_description.keys() else x )

# %%
euromanifesto = pd.read_pickle( dataset_folder+"Euromanifesto"+os.sep+"Euromanifesto_linked.zip" , compression = 'zip' )

euromanifesto["year"] = euromanifesto["year"].astype(int)

euromanifesto[[x for x in euromanifesto.columns if "per_" in x]] = euromanifesto[[x for x in euromanifesto.columns if "per_" in x]].replace("Unavailable",np.nan).astype(float)
# euromanifesto.dtypes.value_counts()
subregion_list = ["Flanders","Wallonia","Great Britain","Northern Ireland"]
euromanifesto["region"] = euromanifesto["region"].apply(lambda x: np.nan if x not in subregion_list else x)
euromanifesto = euromanifesto.rename(columns = {"region":"country_sub_region"})

emp_country_replace_dict = {"Europe":"European Union","UK":"United Kingdom","The Netherlands":"Netherlands"}
euromanifesto["country"] = euromanifesto["country"].replace(emp_country_replace_dict).apply(lambda x: pf_country_to_code.loc[x])

euromanifesto[["total","emcs_id"]] = euromanifesto[["total","emcs_id"]].astype(int)
euromanifesto[["rile_mrg","planeco","markeco","welfare","pro_anti_EU"]] = euromanifesto[["rile_mrg","planeco","markeco","welfare","pro_anti_EU"]].astype(float)

float_list = ["EPseats","marpor","cphl","eep","member","EPvote","EPseatsum",
              'left', 'environ', 'liberta', 'religious', 'state', 'multicult',
              'integration', 'pubservice', 'redistribut', 'liberties', 'lifestyle',
              'immigration',"NATvote","NATseats"]

replace_dict = {"Inapplicable":np.nan,"Unavailable":np.nan, # currently unclear if there's any point in distinguishing
     "No EES code available":np.nan,"Unknown":np.nan,"No answer":np.nan,"Did not compete":np.nan,
     'No answer':np.nan,'Libertarian':1,'Authoritarian':10,'Religious':1,'Secular':10,
     'Free enterprise':1,'State interventionism':10,'Multiculturalism':1,'Ethnocentrism':10,
     'Pro EU-integration':1,'Anti EU-integration':10,'Raising taxes':1,'Cut taxes':10,
     'Fully in favour of redistribution from the rich to the poor':1,'Fully opposed to redistribution from the rich to the poor':10,
     'Civil liberties':1,'Law and Order':10,'Strong support for liberal policies':1,'Strong refusal of liberal policies':10,
     'Fully in favour of immigration':1,'Fully opposed to immigration':10,
     'Environmental protection':1,'Economic growth':10,'Left':1,'Right':10,                
}

euromanifesto[float_list] = euromanifesto[float_list].replace(replace_dict).astype(float)

## I think you should dummy pfamily, mfamily, ofamily
# but maybe, post-checking, expect mfamily to get dropped?

emp_family_replace_dict = {'Unavailable':np.nan, 'Unknown':np.nan, 'Coalition':'coalition', 'Ecologist':'green', 'Communist':'rad left',
       'Social Democratic':'socialist', 'Liberal':'liberal', 'Christian Democratic':'christdem', 'Conservative':'cons',
       'Nationalist':'rad right', 'Agrarian':'agrarian', 'Ethnic-regional':'regional', 'Special Issue':'special issue',
                           
       'Unknown':np.nan, 'Green Parties':'green', '(Post-)Communist Parties':'(post-)communist',
       'Social Democratic Parties':'socialist', 'Liberal Parties':'liberal',
       'Christian Democratic Parties':'christdem', 'Conservative Parties':'cons',
       'Nationalist Parties':'rad right', 'Agrarian Parties':'agrarian', 'Regional Parties':'regional',
       'Special Interest Parties':'special issue',
                           
       'Other':np.nan, 'Green Parties':'green', '(Post-)Communist Parties':'(post-)communist',
       'Social Democratic Parties':'socialist', 'Liberal Parties':'liberal',
       'Christian Democratic Parties':'christdem', 'Conservative Parties':'cons',
       'Nationalist Parties':'rad right', 'Agrarian Parties':'agrarian', 'Regional Parties':'regional',
       'Special Interest Parties':'special issue',
        }

family_col = "pfamily"
euromanifesto[family_col] = euromanifesto[family_col].replace(emp_family_replace_dict)
dummies = pd.get_dummies(euromanifesto[family_col] ,prefix=family_col, prefix_sep='__')
dummies.loc[euromanifesto[family_col].isnull(),:] = np.nan
euromanifesto[dummies.columns] = dummies

family_col = "ofamily"
euromanifesto[family_col] = euromanifesto[family_col].replace(emp_family_replace_dict)
dummies = pd.get_dummies(euromanifesto[family_col] ,prefix=family_col, prefix_sep='__')
dummies.loc[euromanifesto[family_col].isnull(),:] = np.nan
euromanifesto[dummies.columns] = dummies

family_col = "mfamily"
euromanifesto[family_col] = euromanifesto[family_col].replace(emp_family_replace_dict)
dummies = pd.get_dummies(euromanifesto[family_col] ,prefix=family_col, prefix_sep='__')
dummies.loc[euromanifesto[family_col].isnull(),:] = np.nan
euromanifesto[dummies.columns] = dummies


dataset = "ees14"
ds_brac = "("+dataset+")"
euromanifesto["dataset"] = dataset
euromanifesto["dataset_index"] = euromanifesto.index
euromanifesto = euromanifesto.rename(columns={x:ds_brac+x for x in euromanifesto.columns if x not in shared_columns})

euromanifesto[["year","partyfacts_id"]].isnull().sum(), euromanifesto.shape
# Out:
# (year              0
#  partyfacts_id    77
#  dtype: int64,
#  (977, 805))

# %%
emp_vl = pd.DataFrame(columns = ["variable","group","type","integrated_variable","description"])
emp_vl["integrated_variable"] = euromanifesto.columns
emp_vl["variable"] = emp_vl["integrated_variable"].apply(lambda x: x.replace("("+dataset+")",""))

emp_var_to_group_dict = {
            
        'za_nr':'source_variables', 'version':'source_variables', 'doi':'source_variables',
        'partyname':'party_names', 'initials':'party_names',
        'year':'observation_variables','country_year':'observation_variables','emcs_year':'observation_variables',
        'country':'country_variables','country_sub_region':'country_variables',
        'EPseats':'party_electoral','EPvote':'party_electoral', 'EPseatsum':'party_electoral',
            'NATvote':'party_electoral', 'NATseats':'party_electoral',
            'eep':'party_electoral','member':'party_electoral',
            'gov':'party_electoral', 'pm':'party_electoral',
        'emcs':'party_id','ees':'party_id', 'marpor':'party_id', 'cphl':'party_id',
        'partyinfo':'party_electoral',
        'pfamily':'dummiable_variables', 'mfamily':'dummiable_variables', 'ofamily':'dummiable_variables',
        'group':'dummiable_variables','manif':'observation_variables',
        
       'left':'coder_ratings', 'environ':'coder_ratings','liberta':'coder_ratings', 
       'religious':'coder_ratings', 'state':'coder_ratings', 'multicult':'coder_ratings', 'integration':'coder_ratings',
       'pubservice':'coder_ratings', 'redistribut':'coder_ratings', 'liberties':'coder_ratings', 'lifestyle':'coder_ratings',
       'immigration':'coder_ratings',
       'rile_mrg':'computed_values', 'planeco':'computed_values', 'markeco':'computed_values', 'welfare':'computed_values',
       'pro_anti_EU':'computed_values', 'total':'observation_variables',
                         
       'ees_id':'party_id', 'ees_party':'party_names', 'emcs_id':'party_id', 'emcs_party':'party_names',
       'partyfacts_id_ees_id':'party_id', 'partyfacts_id_emcs':'party_id', 'partyfacts_id_cmp':'party_id',
       'partyfacts_id_ches':'party_id', 'partyfacts_id':'party_id', 'dataset':'source_variables',
       'dataset_index':'source_variables',
                                       
}

emp_var_to_group_dict.update({x.replace(ds_brac,""):"man_cod" for x in euromanifesto.columns if "per_" in x})
emp_var_to_group_dict.update({x.replace(ds_brac,""):"dummied_variables" for x in euromanifesto.columns if "family__" in x})

# pf_core_vl["description"] = pf_core_vl["variable"].apply(lambda x: pf_core_var_description[x] if x in pf_core_var_description.keys() else np.nan )    
emp_vl["group"] = emp_vl["variable"].apply(lambda x: emp_var_to_group_dict[x] if x in emp_var_to_group_dict.keys() else np.nan )
emp_vl["type"] = emp_vl["group"].apply(lambda x: group_to_type_dict[x] if x in group_to_type_dict.keys() else np.nan )
emp_vl.loc[emp_vl["variable"].apply(lambda x: x in shared_columns),"type"] = "cross-dataset"

header,labels = get_dta_header_labels(dataset_folder+"Euromanifesto"+os.sep+ "ZA5102_v2-0-0.dta")

emp_vl["description"] = emp_vl["variable"].apply(lambda x: header[x] if x in header.keys() else np.nan )  

emp_vl["description"] = emp_vl["variable"].apply(lambda x: shared_description[x] if x in shared_description.keys() else x )

# %%
pf_core = partyfacts_core_parties[['country', 'partyfacts_id',  'name_short', 'name',
       'name_english', 'name_other', 'year_first', 'year_last', 'share',
       'share_year', 'new', 'wikipedia', 'description', 'comment', 'created',
       'modified']].copy()

pf_core["country"] = pf_core["country"].apply(lambda x: x.lower())

dataset = "pf"
ds_brac = "("+dataset+")"
pf_core["dataset"] = dataset

pf_core["dataset_index"] = pf_core.index

pf_core = pf_core.rename(columns={x:ds_brac+x for x in pf_core.columns if x not in shared_columns})


pf_core_vl = pd.DataFrame(columns = ["variable","group","type","integrated_variable","description"])
pf_core_vl["integrated_variable"] = pf_core.columns
pf_core_vl["variable"] = pf_core_vl["integrated_variable"].apply(lambda x: x.replace("("+dataset+")",""))

pf_core_var_to_group_dict = {'country':'country_variables', 'partyfacts_id':'party_id', 'dataset':'source_variables',
       'name_short':'party_names', 'name':'party_names','name_english':'party_names', 'name_other':'party_names',
       'year_first':'party_electoral', 'year_last':'party_electoral', 'share':'party_electoral',
       'share_year':'party_electoral', 'new':'notes', 'wikipedia':'party_id',
       'description':'notes', 'comment':'notes',
       'created':'source_variables','modified':'source_variables','dataset_index':'source_variables',
            
}
# could change these to vote/vote_year


pf_core_var_description = {"country":"ISO-code of the country",
"partyfacts_id":"Party Facts identification number",
"name_short":"Common abbreviation of party",
"name":"Name of party in language of origin",
"name_english":"Name of party in English",
"name_other":"Party name in languages with non-latin letters",
"year_first":"Foundation of the party",
"year_last":"Dissolvement of the party (blank if still existing)",
"share":"Result in a parliamentary election",
"share_year":"Year of the election result",
"new":"Genuinely new party",
"wikipedia":"Link to the respective Wikipedia homepage",
"description":"For further description",
"comment":"Section for comments",
"created":"Date of creation in Party Facts",
"modified":"Date of last modification",}


 
 
 # country and year excepted as a shared variables
pf_core_vl["description"] = pf_core_vl["variable"].apply(lambda x: pf_core_var_description[x] if x in pf_core_var_description.keys() else np.nan )
pf_core_vl["group"] = pf_core_vl["variable"].apply(lambda x: pf_core_var_to_group_dict[x] if x in pf_core_var_to_group_dict.keys() else np.nan )
pf_core_vl["type"] = pf_core_vl["group"].apply(lambda x: group_to_type_dict[x] if x in group_to_type_dict.keys() else np.nan )
pf_core_vl.loc[pf_core_vl["variable"].apply(lambda x: x in shared_columns),"type"] = "cross-dataset"

pf_core_vl["description"] = pf_core_vl["variable"].apply(lambda x: shared_description[x] if x in shared_description.keys() else x )

# %%
parlgov_party = pd.read_pickle(dataset_folder+"PARLGOV"+os.sep+ "parlgov_party_linked.zip",compression='zip')


parlgov_party["country_name_short"] = parlgov_party["country_name_short"].apply(lambda x: x.lower())
parlgov_party = parlgov_party.rename(columns = {"country_name_short":"country"})

# dummy family and try to line it up with CHES family categories
# aligning to the ches family 'standard'
# note - socdem -> socialist and communist/socialist -> rad left, Right-wing -> rad right
# and no 'confessional' option just "special issue"
family_replace_dict = {'Liberal':'liberal', 'Conservative':'cons', 'Social democracy':'socialist', 'Right-wing':'rad right',
       'Special issue':'special issue', 'Communist/Socialist':'rad left', 'no family':'no family',
       'Christian democracy':'christdem', 'Green/Ecologist':'green', 'Agrarian':'agrarian', 'to be coded':np.nan}
parlgov_party["family_name"] = parlgov_party["family_name"].replace(family_replace_dict)
#family__no family
dummies = pd.get_dummies(parlgov_party["family_name"] ,prefix="family", prefix_sep='__')
dummies.loc[parlgov_party["family_name"].isnull(),:] = np.nan
parlgov_party[dummies.columns]  =dummies
dataset = "parlgov"
ds_brac = "("+dataset+")"

parlgov_party["dataset"] = dataset
parlgov_party["dataset_index"] = parlgov_party.index
parlgov_party = parlgov_party.rename(columns={x:ds_brac+x for x in parlgov_party.columns if x not in shared_columns})

parlgov_party[["partyfacts_id"]].isnull().sum(), parlgov_party.shape
# Out:
# (partyfacts_id    279
#  dtype: int64,
#  (1651, 39))

# %%
parlgov_party_vl = pd.DataFrame(columns = ["variable","group","type","integrated_variable","description"])
parlgov_party_vl["integrated_variable"] = parlgov_party.columns

parlgov_party_vl["variable"] = parlgov_party_vl["integrated_variable"].apply(lambda x: x.replace(ds_brac,""))

parlgov_party_var_to_group_dict = {'country':'country_variables', 'country_name':'country_variables',
       'party_name_short':'party_names','party_name_english':'party_names', 'party_name':'party_names', 'party_name_ascii':'party_names',
       'family_name_short':'dummiable_variables', 'family_name':'dummiable_variables', 'family_id':'dummiable_variables',
       'left_right':'parlgov_index', 'state_market':'parlgov_index', 'liberty_authority':'parlgov_index', 'eu_anti_pro':'parlgov_index',
       'cmp':'party_id', 'euprofiler':'party_id', 'ees':'party_id',
       'castles_mair':'party_id', 'huber_inglehart':'party_id', 'ray':'party_id', 'benoit_laver':'party_id', 'chess':'party_id',
       'country_id':'country_variables', 'party_id':'party_id', 'partyfacts_id':'party_id',
       'partyfacts_id_cmp':'party_id', 'partyfacts_id_ches':'party_id', 'partyfacts_id_ees':'party_id',
       'dataset':'source_variables','dataset_index':'source_variables',
       'family__agrarian':'dummied_variables', 'family__christdem':'dummied_variables', 'family__cons':'dummied_variables',
       'family__green':'dummied_variables', 'family__liberal':'dummied_variables', 'family__no family':'dummied_variables',
       'family__rad left':'dummied_variables', 'family__rad right':'dummied_variables', 'family__socialist':'dummied_variables',
       'family__special issue':'dummied_variables',
                                  }
    

            

# could change these to vote/vote_year

parlgov_variable = pd.read_pickle(dataset_folder+"PARLGOV"+os.sep+ "parlgov_variable.zip",compression='zip')
parlgov_party_var_description = parlgov_variable[parlgov_variable["table_name"]=="view_party"].set_index("name")["description"].to_dict()


 
 
 # country and year excepted as a shared variables
parlgov_party_vl["description"] = parlgov_party_vl["variable"].apply(lambda x: parlgov_party_var_description[x] if x in parlgov_party_var_description.keys() else np.nan )    
parlgov_party_vl["group"] = parlgov_party_vl["variable"].apply(lambda x: parlgov_party_var_to_group_dict[x] if x in parlgov_party_var_to_group_dict.keys() else np.nan )
parlgov_party_vl["type"] = parlgov_party_vl["group"].apply(lambda x: group_to_type_dict[x] if x in group_to_type_dict.keys() else np.nan )
parlgov_party_vl.loc[parlgov_party_vl["variable"].apply(lambda x: x in shared_columns),"type"] = "cross-dataset"

parlgov_party_vl["description"] = parlgov_party_vl["variable"].apply(lambda x: shared_description[x] if x in shared_description.keys() else x )

# %%
parlgov_cabinet = pd.read_pickle( dataset_folder+"PARLGOV"+os.sep+ "parlgov_cabinet_linked.zip" ,compression='zip')

parlgov_cabinet[["election_date","start_date"]] = parlgov_cabinet[["election_date","start_date"]].apply(lambda x: pd.to_datetime(x))
parlgov_cabinet["year"] = parlgov_cabinet["start_date"].dt.year



# parlgov_cabinet[["year","partyfacts_id"]].isnull().sum(), parlgov_cabinet.shape

# %%
parlgov_election = pd.read_pickle(dataset_folder+"PARLGOV"+os.sep+ "parlgov_election_linked.zip",compression='zip')

parlgov_election["election_date"] = pd.to_datetime(parlgov_election["election_date"])
parlgov_election["year"] = parlgov_election["election_date"].dt.year
parlgov_election[["year","partyfacts_id"]].isnull().sum(), parlgov_election.shape
# Out:
# (year               0
#  partyfacts_id    722
#  dtype: int64,
#  (8623, 18))

# %%
PImPo = pd.read_pickle( dataset_folder+"CMP"+os.sep+"PImPo_linked.zip", compression='zip' )

PImPo["year"] = PImPo["edate"].dt.year
PImPo["country"] = PImPo["country"].apply(lambda x: x.title()).apply(lambda x: pf_country_to_code.loc[x])

dataset = "pimpo"
ds_brac = "("+dataset+")"
PImPo["dataset"] = dataset
PImPo["dataset_index"] = PImPo.index

# normalize saliency variables to 0-1
PImPo[[x for x in PImPo.columns if "saliency" in x]] = PImPo[[x for x in PImPo.columns if "saliency" in x]]/100

PImPo = PImPo.rename(columns={x:ds_brac+x for x in PImPo.columns if x not in shared_columns})


PImPo[["year","partyfacts_id"]].isnull().sum(), PImPo.shape
# Out:
# (year             0
#  partyfacts_id    0
#  dtype: int64,
#  (242, 20))

# %%
# https://manifesto-project.wzb.eu/down/datasets/pimpo/PImPo_codebook.pdf

PImPo_vl = pd.DataFrame(columns = ["variable","group","type","integrated_variable"])

PImPo_vl["integrated_variable"] = PImPo.columns
PImPo_vl["variable"] = PImPo_vl["integrated_variable"].apply(lambda x: x.replace(ds_brac,""))


pimpo_var_to_group_dict = {"country":"country_variables",
                           "party":"party_id",
                           "date":"observation_variables",
                           "edate":"observation_variables",
                           "totals":"observation_variables",
                           "totals_immi":"observation_variables",
                           "totals_inti":"observation_variables",
                           
                           "saliency":"immigration_integration_pos",
                           "saliency_immi":"immigration_integration_pos",
                           "saliency_inti":"immigration_integration_pos",
                           "immi_pos":"immigration_integration_pos",
                           "immi_pos_saliency":"immigration_integration_pos",
                           "inti_pos":"immigration_integration_pos",
                           "inti_pos_saliency":"immigration_integration_pos",
                           
                           "partyname":"party_names",
                           "partyfacts_id":"party_id",
                           "year":"observation_variables",
                           "dataset":"source_variables",'dataset_index':'source_variables',
                           "countryname":"country_variables",
                          }


pimpo_var_description = {
 'country': 'Harmonised country code',
 'countryname': 'Country name',
 'party': 'MARPOR party id',
 'partyname' : 'MARPOR party name',
 'partyfacts_id': "Partyfacts unique party id",
 'dataset': 'Source dataset',
 'date': 'Election date',
 'edate': 'Election date(datetime)',
 'year': 'Election year',
 'totals': 'Total QS coded',
 'totals_immi': 'Total QS on immigration',
 'totals_inti': 'Total QS on integration',
 'saliency': 'Fraction of QS on immi + inte',
 'saliency_immi': 'Fraction of QS on immigration',
 'saliency_inti': 'Fraction of QS on integration',
 'immi_pos': '(Pos ImmigQS-Neg ImmigQS)/(Pos + Neg + Neut ImmigQS)',
 'immi_pos_saliency': '1-(Neut ImmigQS/(Pos + Neg + Neut ImmigQS))',
 'inti_pos': '(Pos IntiQS-Neg IntiQS)/(Pos + Neg + Neut IntiQS)',
 'inti_pos_saliency': '1-(Neut IntiQS/(Pos + Neg + Neut IntiQS))',
 
}

# pimpo_group_to_type_dict = {'party_names':'obs_vars','country_variables':'obs_vars','observation_variables':'obs_vars',
#  'party_id':'obs_vars',
#  'source_variables':'dataset_vars',
#  'party_electoral':'elec_vars',
#  'dummied_variables':'placeholder!',
#  'dummiable_variables':'dropped',
#  'policy_dimensions':'expert_op', 'ideological_dimensions':'expert_op',
#        'eu_policy_questions':'expert_op', 'eu_integration_admission':'expert_op',
#        'leadership_divisions':'expert_op', 'ukraine_specific_questions':'expert_op',
#        'party_characteristics':'expert_op', 'eu_membership_requirements':'expert_op',
#        'immigration_integration_pos':'man_cod',          
                           
#                            }
 
 
 # country and year excepted as a shared variables
PImPo_vl["description"] = PImPo_vl["variable"].apply(lambda x: pimpo_var_description[x] if x in pimpo_var_description.keys() else np.nan )    
PImPo_vl["group"] = PImPo_vl["variable"].apply(lambda x: pimpo_var_to_group_dict[x] if x in pimpo_var_to_group_dict.keys() else np.nan )
PImPo_vl["type"] = PImPo_vl["group"].apply(lambda x: group_to_type_dict[x] if x in group_to_type_dict.keys() else np.nan )
PImPo_vl.loc[PImPo_vl["variable"].apply(lambda x: x in shared_columns),"type"] = "cross-dataset"

PImPo_vl["description"] = PImPo_vl["variable"].apply(lambda x: shared_description[x] if x in shared_description.keys() else x )

# %%
merged_vl = pd.concat([PImPo_vl,
    parlgov_party_vl,
    pf_core_vl,
    emp_vl,
    pip_ideol_vl,
    cmp_vl,
    CHES_vl,],axis=0)

merged_vl = merged_vl.drop_duplicates()

# %%
em_to_mcp_mapping = pd.read_csv( dataset_folder+"CMP"+os.sep+"emp_mpds_mapping.csv" )
em_to_mcp_mapping = em_to_mcp_mapping[['emp_2014', 'value', 'mp_hb4', 'mp_hb5']]

no_mapping = (em_to_mcp_mapping["mp_hb5"]=="0")
em_to_mcp_mapping["latest"] = em_to_mcp_mapping["mp_hb5"]
em_to_mcp_mapping.loc[no_mapping,"latest"] = "emp_"+em_to_mcp_mapping.loc[no_mapping,"emp_2014"]

mapping_dictionary = em_to_mcp_mapping.set_index("emp_2014")["latest"].to_dict()

# euromanifesto = euromanifesto.rename(columns=mapping_dictionary)

# %%
# set.intersection(set(euromanifesto.columns),set(manifesto_project.columns))

# %%
# mapping_dictionary

# %%
# [x for x in euromanifesto.columns if "per" in x]

# which 'governmental frame is the comparable one?'
# or the sum of all 3?

## boo - frustrating!

## ... I guess

# %%
df = pd.concat([CHES_comb,manifesto_project,pip_ideol,euromanifesto,PImPo])

# %%
df_means = df.groupby("partyfacts_id").mean()

# parlgov_party
# df_means
parlgov_party.set_index("partyfacts_id").shape, df_means.shape
# ((1651, 27), (1248, 1135))
# pd.Series(df_means.append( parlgov_party.set_index("partyfacts_id") ).index).value_counts()
# pd.Series(df_means.index).value_counts()
pf_index_int = set(df_means.index)

# parlgov_party.set_index("partyfacts_id").loc[df_means.index]
# pf_index_int = list(set.intersection(set(df_means.index),set(parlgov_party["partyfacts_id"])))
# [parlgov_party["partyfacts_id"]].apply(lambda x: x in pf_index_int
df_merged = df_means.merge( parlgov_party, how='left', on= "partyfacts_id")
df_merged = df_merged.merge( pf_core, how='left', on= "partyfacts_id")


##################

mask = merged_vl.apply(lambda x: x["type"] in ['man_cod', 'dummy_vars', 'expert_op', 'id_dim', 'elec_vars',
       'coder_ratings', ],axis=1)

reasonable_colums = [x for x in df_merged.columns if x in merged_vl["integrated_variable"][mask].values]
reasonable_colums = reasonable_colums + ['(pimpo)totals', '(pimpo)totals_immi', '(pimpo)totals_inti', '(manifesto)total','partyfacts_id']

df_merged_small = df_merged[reasonable_colums].copy()
df_merged_small["partyfacts_id"] = df_merged_small["partyfacts_id"].astype(int)
df_merged_small = df_merged_small.set_index("partyfacts_id")


# set partyfacts_id to index

# curious about these!
df_merged = df_merged_small

# %%
# parlgov_party["(parlgov)left_right"]
# merged_vl["type"].value_counts(dropna=False).index


# merged_vl[merged_vl["variable"].apply(lambda x: x in ["new","description","comment"])]

df_merged[merged_vl[merged_vl["type"]=="dummy_vars"]["integrated_variable"]].sum().sort_values().head(59)
# Out:
# (parlgov)family__no family                                            0.000000
# (ches)mip_one__multiculturalism                                       1.000000
# (ees14)mfamily__coalition                                             1.000000
# (ches)mip_three__environment                                          2.000000
# (ches)mip_one__social lifestyle                                       3.000000
# (ches)mip_two__environment                                            3.000000
# (ches)mip_two__urban vs rural                                         3.500000
# (ees14)ofamily__agrarian                                              3.500000
# (ees14)pfamily__agrarian                                              3.833333
# (ches)mip_one__civil liberties                                        4.000000
# (ches)intgroup__alliance of democrats                                 4.000000
# (ches)mip_two__ethnic minorities                                      4.000000
# (ches)mip_two__religious principles                                   4.000000
# (ches)mip_three__religious principles                                 4.000000
# (ches)mip_one__international security                                 4.000000
# (ches)mip_one__urban vs rural                                         5.000000
# (ches)mip_three__international security                               5.000000
# (ches)mip_two__international security                                 5.000000
# (manifesto)family__coalition                                          5.142857
# (ches)epgroup__Independence/Democracy (ID)                            6.000000
# (ches)mip_three__immigration                                          6.000000
# (ches)mip_two__multiculturalism                                       6.000000
# (ches)mip_one__religious principles                                   6.000000
# (ches)mip_one__deregulation                                           7.000000
# (ches)epgroup__no group                                               7.000000
# (ches)mip_one__state intervention                                     7.000000
# (ches)mip_three__decentralization                                     7.000000
# (ches)family__confessional                                            7.482143
# (ches)family__agrarian                                                7.690476
# (ches)mip_three__urban vs rural                                       8.000000
# (ees14)mfamily__agrarian                                              8.000000
# (ches)mip_three__ethnic minorities                                    8.500000
# (ches)mip_two__decentralization                                       9.000000
# (ees14)mfamily__special issue                                        10.000000
# (ches)mip_two__civil liberties                                       10.000000
# (ches)epgroup__Union for Europe of the Nations (UEN)                 10.000000
# (ches)mip_three__nationalism                                         11.000000
# (ches)mip_two__immigration                                           11.000000
# (ches)mip_one__ethnic minorities                                     11.000000
# (ches)mip_one__EU integration                                        11.500000
# (ches)mip_three__corruption                                          12.000000
# (ches)mip_one__decentralization                                      12.000000
# (ches)mip_three__civil liberties                                     12.500000
# (ches)intgroup__global greens                                        13.000000
# (ches)mip_three__social lifestyle                                    13.000000
# (ches)mip_one__corruption                                            13.000000
# (ches)mip_one__immigration                                           13.000000
# (ches)epgroup__European United Left – Nordic Green Left (GUE-NGL)    14.000000
# (ches)mip_three__multiculturalism                                    14.500000
# (ees14)ofamily__special issue                                        15.000000
# (ches)mip_two__state intervention                                    15.500000
# (ees14)mfamily__regional                                             15.875000
# (ches)mip_three__redistribution                                      16.500000
# (ches)mip_one__environment                                           17.000000
# (ches)mip_two__nationalism                                           17.000000
# (ches)mip_one__anti-elite                                            18.000000
# (ches)mip_two__anti-elite                                            18.000000
# (ees14)mfamily__green                                                18.000000
# (ees14)ofamily__green                                                18.000000
# dtype: float64

# %%
# Out:
# {'per101b': 'per102',
#  'per101a': 'per101',
#  'per1011b': 'per102',
#  'per1011a': 'per101',
#  'per10111b': 'per102',
#  'per10111a': 'per101',
#  'per10112b': 'per102',
#  'per10112a': 'per101',
#  'per1012b': 'per102',
#  'per1012a': 'per101',
#  'per1013b': 'per102',
#  'per1013a': 'per101',
#  'per1014b': 'per102',
#  'per1014a': 'per101',
#  'per1015b': 'per102',
#  'per1015a': 'per101',
#  'per103b': 'emp_per103b',
#  'per103a': 'per103_1',
#  'per104b': 'per105',
#  'per104a': 'per104',
#  'per1041b': 'per105',
#  'per1041a': 'per104',
#  'per1042b': 'per105',
#  'per1042a': 'per104',
#  'per1043b': 'per105',
#  'per1043a': 'per104',
#  'per106b': 'emp_per106b',
#  'per106a': 'per106',
#  'per1061b': 'emp_per1061b',
#  'per1061a': 'per106',
#  'per1062b': 'emp_per1062b',
#  'per1062a': 'per106',
#  'per1063b': 'emp_per1063b',
#  'per1063a': 'per106',
#  'per107b': 'per109',
#  'per107a': 'per107',
#  'per108b': 'per110',
#  'per108a': 'per108',
#  'per1081b': 'per110',
#  'per1081a': 'per108',
#  'per1082b': 'per108',
#  'per1082a': 'per110',
#  'per2011b': 'emp_per2011b',
#  'per2011a': 'per201_1',
#  'per2012b': 'emp_per2012b',
#  'per2012a': 'per201_2',
#  'per20121b': 'emp_per20121b',
#  'per20121a': 'per201_2',
#  'per20122b': 'emp_per20122b',
#  'per20122a': 'per201_2',
#  'per202b': 'per202_2',
#  'per202a': 'per202_1',
#  'per203b': 'per204',
#  'per203a': 'per203',
#  'per301b': 'per302',
#  'per301a': 'per301',
#  'per3011b': 'per110',
#  'per3011a': 'per108',
#  'per303b': 'emp_per303b',
#  'per303a': 'per303',
#  'per304b': 'emp_per304b',
#  'per304a': 'per304',
#  'per305b': 'emp_per305b',
#  'per305a': 'per305_3',
#  'per306b': 'per110',
#  'per306a': 'per108',
#  'per308b': 'per110',
#  'per308a': 'per108',
#  'per310b': 'per110',
#  'per310a': 'per108',
#  'per3101b': 'emp_per3101b',
#  'per3101a': 'emp_per3101a',
#  'per312b': 'emp_per312b',
#  'per312a': 'emp_per312a',
#  'per314b': 'per110',
#  'per314a': 'per108',
#  'per3141b': 'emp_per3141b',
#  'per3141a': 'emp_per3141a',
#  'per316b': 'per110',
#  'per316a': 'per108',
#  'per3161b': 'per110',
#  'per3161a': 'per108',
#  'per3162b': 'per110',
#  'per3162a': 'per108',
#  'per3163b': 'per110',
#  'per3163a': 'per108',
#  'per318b': 'emp_per318b',
#  'per318a': 'emp_per318a',
#  'per319b': 'emp_per319b',
#  'per319a': 'emp_per319a',
#  'per3191b': 'emp_per3191b',
#  'per3191a': 'emp_per3191a',
#  'per3192b': 'emp_per3192b',
#  'per3192a': 'emp_per3192a',
#  'per401b': 'emp_per401b',
#  'per401a': 'per401',
#  'per4011b': 'emp_per4011b',
#  'per4011a': 'emp_per4011a',
#  'per4012b': 'emp_per4012b',
#  'per4012a': 'per401',
#  'per402b': 'emp_per402b',
#  'per402a': 'per402',
#  'per403b': 'emp_per403b',
#  'per403a': 'per403',
#  'per404b': 'emp_per404b',
#  'per404a': 'per404',
#  'per405b': 'emp_per405b',
#  'per405a': 'per405',
#  'per406b': 'per407',
#  'per406a': 'per406',
#  'per408b': 'emp_per408b',
#  'per408a': 'per408',
#  'per4081b': 'emp_per4081b',
#  'per4081a': 'per701',
#  'per4082b': 'emp_per4082b',
#  'per4082a': 'per408',
#  'per40821b': 'emp_per40821b',
#  'per40821a': 'per408',
#  'per40822b': 'emp_per40822b',
#  'per40822a': 'per408',
#  'per40823b': 'emp_per40823b',
#  'per40823a': 'per408',
#  'per40824b': 'emp_per40824b',
#  'per40824a': 'emp_per40824a',
#  'per4084b': 'emp_per4084b',
#  'per4084a': 'per407',
#  'per4086b': 'emp_per4086b',
#  'per4086a': 'emp_per4086a',
#  'per4087b': 'emp_per4087b',
#  'per4087a': 'emp_per4087a',
#  'per4088b': 'emp_per4088b',
#  'per4088a': 'per411',
#  'per409b': 'emp_per409b',
#  'per409a': 'per409',
#  'per410b': 'emp_per410b',
#  'per410a': 'per410',
#  'per411b': 'emp_per411b',
#  'per411a': 'per411 ',
#  'per412b': 'emp_per412b',
#  'per412a': 'per412',
#  'per4121b': 'emp_per4121b',
#  'per4121a': 'per412',
#  'per4122b': 'emp_per4122b',
#  'per4122a': 'emp_per4122a',
#  'per4123b': 'emp_per4123b',
#  'per4123a': 'per413',
#  'per4124b': 'emp_per4124b',
#  'per4124a': 'per412',
#  'per413b': 'emp_per413b',
#  'per413a': 'per413',
#  'per4132b': 'per413',
#  'per4132a': 'emp_per4132a',
#  'per414b': 'emp_per414b',
#  'per414a': 'per414',
#  'per415b': 'emp_per415b',
#  'per415a': 'per415 ',
#  'per416b': 'emp_per416b',
#  'per416a': 'per416_1',
#  'per501b': 'emp_per501b',
#  'per501a': 'per501',
#  'per5011b': 'emp_per5011b',
#  'per5011a': 'per501',
#  'per5012b': 'emp_per5012b',
#  'per5012a': 'per501',
#  'per5013b': 'emp_per5013b',
#  'per5013a': 'per501',
#  'per502b': 'emp_per502b',
#  'per502a': 'per502',
#  'per503b': 'emp_per503b',
#  'per503a': 'per503',
#  'per504b': 'per505',
#  'per504a': 'per504',
#  'per5041b': 'emp_per5041b',
#  'per5041a': 'per701',
#  'per5042b': 'emp_per5042b',
#  'per5042a': 'per701',
#  'per5043b': 'per505',
#  'per5043a': 'per504',
#  'per5044b': 'per505',
#  'per5044a': 'per504',
#  'per5045b': 'per505',
#  'per5045a': 'per504',
#  'per506b': 'per507',
#  'per506a': 'per506',
#  'per601b': 'per602_1',
#  'per601a': 'per601_1',
#  'per6011b': 'per601_2',
#  'per6011a': 'per602_2',
#  'per60111b': 'per601_2',
#  'per60111a': 'per602_2',
#  'per60112b': 'per601_2',
#  'per60112a': 'per602_2',
#  'per60113b': 'per601_2',
#  'per60113a': 'per602_2',
#  'per6021b': 'per110',
#  'per6021a': 'per108',
#  'per603b': 'per604',
#  'per603a': 'per603',
#  'per605b': 'per605_2',
#  'per605a': 'per605_1',
#  'per6051b': 'per605_2',
#  'per6051a': 'per605_1',
#  'per606b': 'emp_per606b',
#  'per606a': 'per606',
#  'per607b': 'per608_1',
#  'per607a': 'per607_1',
#  'per701b': 'per702',
#  'per701a': 'per701',
#  'per7031b': 'per703_2',
#  'per7031a': 'per703_1',
#  'per704b': 'emp_per704b',
#  'per704a': 'per704',
#  'per705b': 'emp_per705b',
#  'per705a': 'per705',
#  'per7051b': 'emp_per7051b',
#  'per7051a': 'per705',
#  'per7052b': 'emp_per7052b',
#  'per7052a': 'per705',
#  'per7053b': 'emp_per7053b',
#  'per7053a': 'per705',
#  'per70531b': 'emp_per70531b',
#  'per70531a': 'per705',
#  'per70532b': 'emp_per70532b',
#  'per70532a': 'per705',
#  'per70533b': 'emp_per70533b',
#  'per70533a': 'per705',
#  'per7054b': 'emp_per7054b',
#  'per7054a': 'per705',
#  'per706b': 'emp_per706b',
#  'per706a': 'per706',
#  'per7061b': 'emp_per7061b',
#  'per7061a': 'per706',
#  'per7062b': 'emp_per7062b',
#  'per7062a': 'per706',
#  'per7063b': 'emp_per7063b',
#  'per7063a': 'per706',
#  'per7064b': 'emp_per7064b',
#  'per7064a': 'per706',
#  'per_v_6012': 'emp_per_v_6012'}

# %%
# df_merged.select_dtypes('object')

# %%
# parlgov_party
# int_pgov = parlgov_party[parlgov_party["partyfacts_id"].notnull()].copy()
# int_pgov["partyfacts_id"] = int_pgov["partyfacts_id"].astype(int)
# int_pgov = int_pgov.set_index("partyfacts_id")


# int_pgov.loc[pf_index_int]

# # match on 

# # df_means[int_pgov.columns][] = int_pgov.loc[pf_index_int]#,int_pgov.columns]
# df_means.loc[pf_index_int][int_pgov.columns] = int_pgov.loc[pf_index_int][int_pgov.columns]

# df[[x for x in df.columns if re.search("country$",x)]].drop_duplicates()[100:150]

# %%
# partyfacts_external_parties[partyfacts_external_parties["partyfacts_id"]==4630]

# %%
# df[df["partyfacts_id"]==57][[x for x in df.columns if re.search("country$",x)]]

# %%
# CHES_comb[ CHES_comb["partyfacts_id"]==602 ]#[[x for x in CHES_comb.columns if "id" in x]+["(ches)source"]]

# %%
# partyfacts_external_parties[ (partyfacts_external_parties["dataset_key"]=='ches')
#                             &(partyfacts_external_parties["dataset_party_id"]=="2618")]

# #
# #[partyfacts_external_parties["partyfacts_id"]==4630]

# %%
# partyfacts_external_parties[ (partyfacts_external_parties["dataset_party_id"]=="602")]

# %%
# df.groupby("partyfacts_id").first()[[x for x in df.columns if re.search("country$",x)]].drop_duplicates().apply(lambda x: len(x.dropna().unique()),axis=1).sort_values(ascending=False).head(50)

# 4714.0    2  BUG INTRODUCED BY ME (manual id dict issue in "integrating party datasets") -> FIXED 
# 4630.0    2  BUG INTRODUCED BY ME (country translation dict issue in "chapel hill datasets") -> FIXED 
# 602.0     2  BUG INTRODUCED BY ME (country translation dict issue in "chapel hill datasets") -> FIXED 
# 1328.0    2  BUG INTRODUCED BY ME (country translation dict issue in "chapel hill datasets") -> FIXED 
# 57.0      2  BUG INTRODUCED BY ME (country translation dict issue in "chapel hill datasets") -> FIXED 

# Done - countries now match between all datasets!

# %%
# %%time
# corrs = df_merged_small.corr()
# # ["partyfacts_id"]

# %%
## we should normalize countries too!

# %%
def not_zero_or_nan(x):
    if pd.isnull(x):
        return False
    elif x==0:
        return False
    else:
        return True

# %%
# %%time
corrs = df_merged_small.corr()
corrs = corrs.where(np.triu(np.ones(corrs.shape),k=2).astype(np.bool))
df_corrs = corrs.stack().reset_index()
df_corrs.columns = ['Row','Column','Value']
# df.drop(df.index[df["Value"]==1.0],inplace=True)


df_corrs["NZ"] = df_corrs.apply(lambda x: (df_merged[x["Row"]].apply(not_zero_or_nan)&df_merged[x["Column"]].apply(not_zero_or_nan)).sum(),axis=1)
# 36 minutes here!
df_corrs["N"] = df_corrs.apply(lambda x: (df_merged[x["Row"]].notnull()&df_merged[x["Column"]].notnull()).sum(),axis=1)

# df_corrs.sort_values(by="Value")
# Out:
# Wall time: 43min 18s

# %%
# (df_merged["(ches)mip_one__social lifestyle"]==0)
df_corrs
# Out:
#                        Row              Column     Value    NZ     N
# 0               (ches)vote        (ches)future  0.245066   132   148
# 1               (ches)vote         (ches)eu_ep  0.124846   343   356
# 2               (ches)vote     (ches)eu_fiscal  0.065551   132   148
# 3               (ches)vote     (ches)eu_employ  0.147335   208   222
# 4               (ches)vote   (ches)eu_cohesion  0.172689   360   375
# ...                    ...                 ...       ...   ...   ...
# 589568      (pf)share_year  (pimpo)totals_inti  0.070380    98    98
# 589569      (pf)share_year    (manifesto)total  0.169961  1033  1033
# 589570       (pimpo)totals  (pimpo)totals_inti  0.738844    99    99
# 589571       (pimpo)totals    (manifesto)total  0.829728   109   109
# 589572  (pimpo)totals_immi    (manifesto)total  0.676948    95    95
#
# [589573 rows x 5 columns]

# %%
# df_merged["(ches)conflict_res"].value_counts()

# %%
df_corrs[df_corrs["N"]>10].sort_values(by="Value").head(50)
# Out:
#                                               Row  \
# 78646                          (ches)conflict_res
# 78645                          (ches)conflict_res
# 78741                         (ches)region_status
# 70834                           (ches)eu_good_gov
# 54951                                 (ches)cosmo
# 1149                            (ches)eu_position
# 71060                           (ches)eu_good_gov
# 499996                         (ees14)per_v2_404b
# 471083                         (ees14)per_v1_316a
# 65205                            (ches)eu_benefit
# 54950                                 (ches)cosmo
# 70835                           (ches)eu_good_gov
# 9549                             (ches)eu_foreign
# 65207                            (ches)eu_benefit
# 77168                      (ches)corrupt_salience
# 78180                            (ches)membership
# 65204                            (ches)eu_benefit
# 16009                            (ches)eu_intmark
# 2235                                 (ches)future
# 1474                            (ches)eu_position
# 2495                                 (ches)future
# 19077                               (ches)enlarge
# 70811                            (ches)eu_pol_req
# 316254                   (pip)Index Jahn: GG Core
# 319899  (pip)Index Jahn: GG Core (Unstandardized)
# 59053                                    (ches)us
# 68295                (ches)international_security
# 70335                           (ches)eu_econ_req
# 66208                            (ches)eu_benefit
# 77167                      (ches)corrupt_salience
# 339904                         (ees14)integration
# 65533                            (ches)eu_benefit
# 9874                             (ches)eu_foreign
# 72402                            (ches)eu_budgets
# 10645                                 (ches)lrgen
# 16042                            (ches)eu_intmark
# 477241                        (ees14)per_v2_3162a
# 339221                         (ees14)integration
# 68294                (ches)international_security
# 159454                    (ches)family__rad right
# 78181                            (ches)membership
# 97698                   (ches)anti_islam_rhetoric
# 10646                                 (ches)lrgen
# 3221                                  (ches)eu_ep
# 61089                                 (ches)minor
# 70818                            (ches)eu_pol_req
# 70809                            (ches)eu_pol_req
# 44512                             (ches)lifestyle
# 67276                       (ches)enviro_salience
# 12803                                (ches)galtan
#
#                                      Column     Value   NZ    N
# 78646                     (ches)russia_role -0.987668   12   12
# 78645                       (ches)languages -0.987145   12   12
# 78741                     (ches)russia_role -0.962091   12   12
# 70834                    (ches)conflict_res -0.937574   12   12
# 54951                   (ches)region_status -0.921834   12   12
# 1149                       (ches)eu_benefit -0.921185  269  336
# 71060            (parlgov)liberty_authority -0.889403   16   16
# 499996                        (pf)year_last -0.886484    1   26
# 471083                        (pf)year_last -0.886484    1   26
# 65205                     (ches)eu_good_gov -0.883873   10   12
# 54950                    (ches)conflict_res -0.882274   12   12
# 70835                   (ches)region_status -0.880151   12   12
# 9549                       (ches)eu_benefit -0.880139  268  335
# 65207                      (ches)eu_budgets -0.871252  220  273
# 77168                   (ches)region_status -0.869423   12   12
# 78180                    (ches)conflict_res -0.865030   12   12
# 65204                      (ches)eu_pol_req -0.864841   10   12
# 16009                      (ches)eu_benefit -0.863363  269  336
# 2235                       (ches)eu_benefit -0.862501   85  113
# 1474                     (ees14)integration -0.856445  241  241
# 2495                     (ees14)integration -0.853652  110  115
# 19077                      (ches)eu_benefit -0.844782   41   55
# 70811            (parlgov)liberty_authority -0.842395   16   16
# 316254  (pip)Ad hoc-Index: GG light (Knill) -0.842262  502  559
# 319899  (pip)Ad hoc-Index: GG light (Knill) -0.842262  502  559
# 59053          (ches)international_security -0.836821  169  171
# 68295                     (ches)russia_role -0.834337   12   12
# 70335                    (ches)conflict_res -0.832825   12   12
# 66208                  (parlgov)eu_anti_pro -0.823702  237  293
# 77167                    (ches)conflict_res -0.821031   12   12
# 339904                 (parlgov)eu_anti_pro -0.815623  235  236
# 65533                    (ees14)pro_anti_EU -0.808238  165  217
# 9874                     (ees14)integration -0.803664  234  234
# 72402                    (ees14)integration -0.794761  181  181
# 10645                    (ches)conflict_res -0.794651   12   12
# 16042                   (ches)protectionism -0.793251  269  269
# 477241                        (pf)year_last -0.791160    6   26
# 339221                   (ees14)pro_anti_EU -0.786591  273  280
# 68294                       (ches)languages -0.786384   12   12
# 159454                      (pimpo)inti_pos -0.785737    7   60
# 78181                   (ches)region_status -0.784508   12   12
# 97698                       (pimpo)immi_pos -0.779071   61   64
# 10646                   (ches)region_status -0.777178   12   12
# 3221                       (ches)eu_benefit -0.766821  268  335
# 61089                   (ches)region_status -0.766757   12   12
# 70818            (parlgov)family__rad right -0.766085    5   17
# 70809                   (parlgov)left_right -0.763588   16   16
# 44512                      (ches)eu_pol_req -0.762888   79   79
# 67276                      (ches)galtan_new -0.762134  116  116
# 12803                      (ches)eu_pol_req -0.759342   88   88

# %%
df_corrs[df_corrs["N"]>10].sort_values(by="Value").tail(50)
# Out:
#                                                       Row  \
# 425674                               (ees14)per_v3_20122b
# 424313                               (ees14)per_v1_20122b
# 240041                                 (manifesto)per1026
# 355208                               (ees14)per_v1_10111b
# 588429                      (ees14)pfamily__special issue
# 169501  (ches)epgroup__Party of European Socialists (PES)
# 280951                                (manifesto)per305_6
# 588227                            (ees14)pfamily__liberal
# 588330                           (ees14)pfamily__regional
# 522987                                (ees14)per_v3_4084b
# 509744                                (ees14)per_v3_4081b
# 465034                                 (ees14)per_v3_314b
# 578445                                 (ees14)per_v3_606b
# 308124                                (pip)Index Jahn: LR
# 588174                              (ees14)pfamily__green
# 478112                                (ees14)per_v1_3163b
# 415160                                (ees14)per_v3_2011b
# 588380                          (ees14)pfamily__socialist
# 155769                                (ches)family__green
# 482848                                 (ees14)per_v2_319b
# 174829                      (ches)intgroup__global greens
# 588065                          (ees14)pfamily__christdem
# 587953                   (ees14)pfamily__(post-)communist
# 445534                                 (ees14)per_v3_304b
# 451275                                 (ees14)per_v1_306b
# 314775                                (pip)Index Jahn: GG
# 469527                                 (ees14)per_v1_316b
# 237654                                 (manifesto)per1022
# 413461                                (ees14)per_v3_1082a
# 527368                                (ees14)per_v3_4087b
# 133145                    (ches)mip_one__social lifestyle
# 462603                                 (ees14)per_v3_312b
# 316241                           (pip)Index Jahn: GG Core
# 509772                                (ees14)per_v3_4081b
# 302092                           (manifesto)family__green
# 174138                      (ches)intgroup__global greens
# 480422                                 (ees14)per_v1_318b
# 538659                                (ees14)per_v1_4121b
# 493656                                (ees14)per_v2_4012a
# 480070                                 (ees14)per_v1_318b
# 481346                                 (ees14)per_v3_318b
# 389370                                 (ees14)per_v2_106b
# 464783                                 (ees14)per_v3_314b
# 174848                      (ches)intgroup__global greens
# 493667                                (ees14)per_v2_4012a
# 465062                                 (ees14)per_v3_314b
# 515009                               (ees14)per_v3_40821a
# 135218                         (ches)mip_one__environment
# 483312                                 (ees14)per_v1_319a
# 309608                           (pip)Index Jahn: LR Core
#
#                                            Column     Value   NZ    N
# 425674                        (ees14)per_v3_4087b  0.977018    1  181
# 424313                       (ees14)per_v3_20122b  0.977030    2  181
# 240041                        (ees14)per_v3_4011a  0.977419    1  178
# 355208                        (ees14)per_v1_1012b  0.978043    2  181
# 588429              (ees14)ofamily__special issue  0.978258   15  249
# 169501    (ches)intgroup__socialist international  0.978982   27  191
# 280951                       (ees14)per_v1_20121b  0.979010    1  127
# 588227                    (ees14)ofamily__liberal  0.979066   38  249
# 588330                   (ees14)ofamily__regional  0.979210   24  249
# 522987                        (ees14)per_v1_5012b  0.980254    1  181
# 509744                         (ees14)per_v3_606b  0.984220    1  218
# 465034                         (ees14)per_v3_606b  0.984220    1  218
# 578445                         (ees14)per_v3_705b  0.984220    1  218
# 308124       (pip)Index Jahn: LR (Unstandardized)  0.984708  558  559
# 588174                      (ees14)ofamily__green  0.984915   18  249
# 478112                         (ees14)per_v1_706b  0.985515    1  218
# 415160                         (ees14)per_v3_403b  0.986536    1  218
# 588380                  (ees14)ofamily__socialist  0.987512   45  249
# 155769                      (ees14)ofamily__green  0.987546   14  193
# 482848                        (ees14)per_v2_3191b  0.988696    2  181
# 174829                      (ees14)pfamily__green  0.988936   12  162
# 588065                  (ees14)ofamily__christdem  0.989198   35  249
# 587953           (ees14)ofamily__(post-)communist  0.990416   24  249
# 445534                        (ees14)per_v3_3162b  0.990740    1  218
# 451275                        (ees14)per_v2_7064b  0.994052    1  218
# 314775       (pip)Index Jahn: GG (Unstandardized)  0.994628  558  559
# 469527                       (ees14)per_v1_70533b  0.994836    1  181
# 237654                         (ees14)per_v1_409b  0.995901    1  178
# 413461                       (ees14)per_v3_40822b  0.998571    1  181
# 527368                       (ees14)per_v3_60112b  0.998819    1  181
# 133145                        (ees14)per_v3_6021b  0.999068    1  153
# 462603                        (ees14)per_v1_7063b  1.000000    1  218
# 316241  (pip)Index Jahn: GG Core (Unstandardized)  1.000000  546  559
# 509772                         (ees14)per_v3_705b  1.000000    1  218
# 302092                      (ees14)mfamily__green  1.000000   16  215
# 174138                   (manifesto)family__green  1.000000   13  171
# 480422                        (ees14)per_v1_7052b  1.000000    1  218
# 538659                        (ees14)per_v1_4124b  1.000000    1  218
# 493656                        (ees14)per_v1_4121b  1.000000    1  218
# 480070                         (ees14)per_v3_318b  1.000000    1  218
# 481346                        (ees14)per_v1_7052b  1.000000    1  218
# 389370                        (ees14)per_v2_1061b  1.000000    2  181
# 464783                        (ees14)per_v3_4081b  1.000000    1  218
# 174848                      (ees14)mfamily__green  1.000000   12  153
# 493667                        (ees14)per_v1_4124b  1.000000    1  218
# 465062                         (ees14)per_v3_705b  1.000000    1  218
# 515009                       (ees14)per_v3_40822a  1.000000    1  181
# 135218              (ches)intgroup__global greens  1.000000   11  145
# 483312                        (ees14)per_v1_3192a  1.000000    5  181
# 309608  (pip)Index Jahn: LR Core (Unstandardized)  1.000000  557  559

# %%
not_id_vars = df_corrs[["Row","Column"]].applymap(lambda x: ("id" not in x) & (x not in shared_columns)).all(axis=1)

df_corrs_non_id = df_corrs[not_id_vars].copy()

df_corrs_non_id["Row_ds"] = df_corrs_non_id["Row"].apply(lambda x: (x.split("(")[1]).split(")")[0])
df_corrs_non_id["Col_ds"] = df_corrs_non_id["Column"].apply(lambda x: (x.split("(")[1]).split(")")[0])
df_corrs_ni_nm = df_corrs_non_id[df_corrs_non_id["Row_ds"]!=df_corrs_non_id["Col_ds"]].copy()

# %%
df_corrs_ni_nm[df_corrs_ni_nm["NZ"]>20].sort_values(by="Value").tail(100)[0:50]
# Out:
#                                             Row  \
# 40641                              (ches)redist
# 51789                           (ches)multicult
# 36431                             (ches)pubserv
# 10936                               (ches)lrgen
# 210810                        (manifesto)per414
# 36428                             (ches)pubserv
# 161298                  (ches)family__socialist
# 43426                              (ches)civlib
# 300518             (manifesto)family__christdem
# 156680                    (ches)family__liberal
# 40638                              (ches)redist
# 12042                              (ches)lrecon
# 76131                       (ches)econ_interven
# 12045                              (ches)lrecon
# 75451                       (ches)econ_interven
# 300508             (manifesto)family__christdem
# 61401                               (ches)minor
# 15260                               (ches)vote1
# 15070                               (ches)vote1
# 12046                              (ches)lrecon
# 199396                        (manifesto)per401
# 155799                      (ches)family__green
# 100657                             (ches)epvote
# 156690                    (ches)family__liberal
# 332783                            (ees14)EPvote
# 2160                          (ches)eu_position
# 40642                              (ches)redist
# 39220                               (ches)dereg
# 42746                              (ches)civlib
# 186018                        (manifesto)per105
# 161258                  (ches)family__socialist
# 161268                  (ches)family__socialist
# 178417  (ches)intgroup__socialist international
# 38535                               (ches)dereg
# 37113                             (ches)pubserv
# 589571                            (pimpo)totals
# 342682                         (ees14)lifestyle
# 335634                              (ees14)left
# 334218                           (ees14)NATvote
# 302827               (manifesto)family__liberal
# 158731                  (ches)family__rad right
# 41323                              (ches)redist
# 159466                  (ches)family__rad right
# 45521                           (ches)lifestyle
# 178407  (ches)intgroup__socialist international
# 10953                               (ches)lrgen
# 178447  (ches)intgroup__socialist international
# 99952                              (ches)epvote
# 65523                          (ches)eu_benefit
# 85313                          (ches)galtan_new
#
#                                               Column     Value   NZ    N  \
# 40641                              (ees14)pubservice  0.786904  114  114
# 51789                     (parlgov)liberty_authority  0.787298  370  370
# 36431                              (ees14)pubservice  0.788116  114  114
# 10936        (pip)Index Franzmann/Kaiser: Left-Right  0.789114  192  192
# 210810       (pip)Index Budge et al.: Market Economy  0.789905  446  555
# 36428                                   (ees14)state  0.790288  217  217
# 161298                    (parlgov)family__socialist  0.791420   40  327
# 43426                     (parlgov)liberty_authority  0.791520  363  363
# 300518                     (ees14)ofamily__christdem  0.796394   21  205
# 156680                       (ees14)pfamily__liberal  0.796969   29  210
# 40638                                   (ees14)state  0.798123  216  216
# 12042                                   (ees14)state  0.800072  234  234
# 76131                          (parlgov)state_market  0.801739  303  303
# 12045                              (ees14)pubservice  0.802073  116  116
# 75451                                   (ees14)state  0.802678  178  178
# 300508                     (ees14)pfamily__christdem  0.802853   21  224
# 61401                               (ees14)multicult  0.803975  213  213
# 15260                                  (ees14)EPvote  0.805845  161  162
# 15070                             (manifesto)pervote  0.809531  181  181
# 12046                             (ees14)redistribut  0.811571  117  117
# 199396       (pip)Index Budge et al.: Market Economy  0.811837  441  555
# 155799                        (parlgov)family__green  0.813178   23  327
# 100657                                     (pf)share  0.815086  300  303
# 156690                       (ees14)ofamily__liberal  0.815695   25  193
# 332783                                     (pf)share  0.816822  273  273
# 2160                            (parlgov)eu_anti_pro  0.817444  423  426
# 40642                             (ees14)redistribut  0.817720  115  115
# 39220                          (parlgov)state_market  0.818726  361  361
# 42746                               (ees14)lifestyle  0.819061   95   95
# 186018  (pip)Index Budge et al.: International Peace  0.819359  341  555
# 161258                     (ees14)pfamily__socialist  0.819934   26  210
# 161268                     (ees14)ofamily__socialist  0.823035   25  193
# 178417                     (ees14)ofamily__socialist  0.824800   22  161
# 38535                                   (ees14)state  0.824978  216  216
# 37113                          (parlgov)state_market  0.827496  364  364
# 589571                              (manifesto)total  0.829728  109  109
# 342682                    (parlgov)liberty_authority  0.830195   92   92
# 335634                           (parlgov)left_right  0.832465  245  245
# 334218                                     (pf)share  0.834071  257  258
# 302827                       (ees14)pfamily__liberal  0.834672   37  224
# 158731                  (manifesto)family__rad right  0.835346   28  273
# 41323                          (parlgov)state_market  0.836409  362  362
# 159466                    (parlgov)family__rad right  0.837075   33  327
# 45521                     (parlgov)liberty_authority  0.837213  363  363
# 178407                     (ees14)pfamily__socialist  0.839124   22  162
# 10953                                    (ees14)left  0.840800  236  236
# 178447                    (parlgov)family__socialist  0.840837   27  184
# 99952                                 (ees14)NATvote  0.841639  211  213
# 65523                             (ees14)integration  0.842915  168  217
# 85313                               (ees14)lifestyle  0.847572   47   47
#
#            Row_ds     Col_ds
# 40641        ches      ees14
# 51789        ches    parlgov
# 36431        ches      ees14
# 10936        ches        pip
# 210810  manifesto        pip
# 36428        ches      ees14
# 161298       ches    parlgov
# 43426        ches    parlgov
# 300518  manifesto      ees14
# 156680       ches      ees14
# 40638        ches      ees14
# 12042        ches      ees14
# 76131        ches    parlgov
# 12045        ches      ees14
# 75451        ches      ees14
# 300508  manifesto      ees14
# 61401        ches      ees14
# 15260        ches      ees14
# 15070        ches  manifesto
# 12046        ches      ees14
# 199396  manifesto        pip
# 155799       ches    parlgov
# 100657       ches         pf
# 156690       ches      ees14
# 332783      ees14         pf
# 2160         ches    parlgov
# 40642        ches      ees14
# 39220        ches    parlgov
# 42746        ches      ees14
# 186018  manifesto        pip
# 161258       ches      ees14
# 161268       ches      ees14
# 178417       ches      ees14
# 38535        ches      ees14
# 37113        ches    parlgov
# 589571      pimpo  manifesto
# 342682      ees14    parlgov
# 335634      ees14    parlgov
# 334218      ees14         pf
# 302827  manifesto      ees14
# 158731       ches  manifesto
# 41323        ches    parlgov
# 159466       ches    parlgov
# 45521        ches    parlgov
# 178407       ches      ees14
# 10953        ches      ees14
# 178447       ches    parlgov
# 99952        ches      ees14
# 65523        ches      ees14
# 85313        ches      ees14

# %%
df_corrs_ni_nm[df_corrs_ni_nm["NZ"]>20].sort_values(by="Value").head(50)
# Out:
#                                                       Row  \
# 1474                                    (ches)eu_position
# 2495                                         (ches)future
# 66208                                    (ches)eu_benefit
# 339904                                 (ees14)integration
# 65533                                    (ches)eu_benefit
# 9874                                     (ches)eu_foreign
# 72402                                    (ches)eu_budgets
# 97698                           (ches)anti_islam_rhetoric
# 3546                                          (ches)eu_ep
# 6666                                    (ches)eu_cohesion
# 16334                                    (ches)eu_intmark
# 212542                                  (manifesto)per416
# 212537                                  (manifesto)per416
# 190504                                  (manifesto)per110
# 4564                                      (ches)eu_fiscal
# 213406                                  (manifesto)per501
# 213411                                  (manifesto)per501
# 97700                           (ches)anti_islam_rhetoric
# 46925                                      (ches)religion
# 19378                                       (ches)enlarge
# 47966                             (ches)religion_salience
# 5603                                      (ches)eu_employ
# 62081                                         (ches)minor
# 49694                                         (ches)immig
# 328588  (pip)Ad hoc-Index: Pro/Anti EU (Warntjen, Hix,...
# 337773                                   (ees14)religious
# 19228                                       (ches)enlarge
# 13125                                        (ches)galtan
# 76477                            (ches)antielite_salience
# 18376                                       (ches)enlargw
# 51783                                     (ches)multicult
# 44834                                     (ches)lifestyle
# 67203                                        (ches)enviro
# 2640                                         (ches)future
# 67572                               (ches)enviro_salience
# 9478                                      (ches)eu_asylum
# 35370                                     (ches)eu_turkey
# 17949                                       (ches)eu_agri
# 62083                                         (ches)minor
# 7743                                     (ches)eu_environ
# 66540                                        (ches)enviro
# 66983                                        (ches)enviro
# 19865                                       (ches)enlarge
# 36054                                     (ches)eu_turkey
# 68261                               (ches)enviro_salience
# 18581                                       (ches)enlargw
# 2584                                         (ches)future
# 85306                                    (ches)galtan_new
# 67554                               (ches)enviro_salience
# 35374                                     (ches)eu_turkey
#
#                                                    Column     Value   NZ    N  \
# 1474                                   (ees14)integration -0.856445  241  241
# 2495                                   (ees14)integration -0.853652  110  115
# 66208                                (parlgov)eu_anti_pro -0.823702  237  293
# 339904                               (parlgov)eu_anti_pro -0.815623  235  236
# 65533                                  (ees14)pro_anti_EU -0.808238  165  217
# 9874                                   (ees14)integration -0.803664  234  234
# 72402                                  (ees14)integration -0.794761  181  181
# 97698                                     (pimpo)immi_pos -0.779071   61   64
# 3546                                   (ees14)integration -0.751806  232  232
# 6666                                   (ees14)integration -0.746160  234  234
# 16334                                  (ees14)integration -0.740654  223  223
# 212542          (pip)Index Jahn: GG Core (Unstandardized) -0.725244  324  555
# 212537                           (pip)Index Jahn: GG Core -0.725244  324  555
# 190504  (pip)Ad hoc-Index: Pro/Anti EU (Warntjen, Hix,... -0.720812  250  555
# 4564                                   (ees14)integration -0.719373  110  115
# 213406                           (pip)Index Jahn: GG Core -0.717762  488  555
# 213411          (pip)Index Jahn: GG Core (Unstandardized) -0.717762  488  555
# 97700                                     (pimpo)inti_pos -0.711581   66   66
# 46925                                    (ees14)religious -0.710164  184  184
# 19378                                  (ees14)integration -0.707093   47   47
# 47966                                    (ees14)religious -0.706007  165  165
# 5603                                   (ees14)integration -0.699217  162  163
# 62081                                     (pimpo)immi_pos -0.697019   68   71
# 49694                                     (pimpo)immi_pos -0.676626   68   71
# 328588                                 (ees14)per_v1_108b -0.673583   84  212
# 337773                         (parlgov)liberty_authority -0.662293  209  209
# 19228                                   (manifesto)per601 -0.659772   56   59
# 13125                                    (ees14)religious -0.657010  197  197
# 76477                                  (ees14)pro_anti_EU -0.654978  178  181
# 18376                                  (ees14)integration -0.653943   91   91
# 51783                                     (pimpo)immi_pos -0.649123   68   71
# 44834                                    (ees14)religious -0.648777  184  184
# 67203                               (ees14)pfamily__green -0.647938   21  207
# 2640                                  (ees14)per_v2_3011b -0.641846   86  115
# 67572                                      (ees14)environ -0.626793  195  195
# 9478                           (parlgov)liberty_authority -0.624672  332  333
# 35370                                  (ees14)integration -0.624260  210  215
# 17949                                 (ees14)per_v2_7031b -0.617504   71  138
# 62083                                     (pimpo)inti_pos -0.616977   74   75
# 7743                                   (ees14)immigration -0.613837   83   83
# 66540                 (pip)Ad hoc-Index: GG light (Knill) -0.608581  260  271
# 66983                                  (ees14)per_v2_501a -0.608039  186  209
# 19865                          (parlgov)liberty_authority -0.607614   69   69
# 36054                          (parlgov)liberty_authority -0.607190  301  305
# 68261                          (parlgov)liberty_authority -0.605711  317  317
# 18581                                 (ees14)per_v2_3161b -0.604744   24   86
# 2584                                   (ees14)per_v2_108b -0.604363   86  115
# 85306                                    (ees14)religious -0.603529   76   76
# 67554             (pip)Index Franzmann/Kaiser: Left-Right -0.601505  156  156
# 35374                                    (ees14)lifestyle -0.600463   94   94
#
#            Row_ds     Col_ds
# 1474         ches      ees14
# 2495         ches      ees14
# 66208        ches    parlgov
# 339904      ees14    parlgov
# 65533        ches      ees14
# 9874         ches      ees14
# 72402        ches      ees14
# 97698        ches      pimpo
# 3546         ches      ees14
# 6666         ches      ees14
# 16334        ches      ees14
# 212542  manifesto        pip
# 212537  manifesto        pip
# 190504  manifesto        pip
# 4564         ches      ees14
# 213406  manifesto        pip
# 213411  manifesto        pip
# 97700        ches      pimpo
# 46925        ches      ees14
# 19378        ches      ees14
# 47966        ches      ees14
# 5603         ches      ees14
# 62081        ches      pimpo
# 49694        ches      pimpo
# 328588        pip      ees14
# 337773      ees14    parlgov
# 19228        ches  manifesto
# 13125        ches      ees14
# 76477        ches      ees14
# 18376        ches      ees14
# 51783        ches      pimpo
# 44834        ches      ees14
# 67203        ches      ees14
# 2640         ches      ees14
# 67572        ches      ees14
# 9478         ches    parlgov
# 35370        ches      ees14
# 17949        ches      ees14
# 62083        ches      pimpo
# 7743         ches      ees14
# 66540        ches        pip
# 66983        ches      ees14
# 19865        ches    parlgov
# 36054        ches    parlgov
# 68261        ches    parlgov
# 18581        ches      ees14
# 2584         ches      ees14
# 85306        ches      ees14
# 67554        ches        pip
# 35374        ches      ees14

# %%
df_merged[[x for x in df_merged if "family" in x]].corr().dropna(how='all')[[x for x in df_merged if "mfamily" in x]].loc[[x for x in df_merged if "(manifesto)family" in x]]
# Out:
#                                   (ees14)mfamily__agrarian  \
# (manifesto)family__agrarian                       0.933163
# (manifesto)family__christdem                     -0.071310
# (manifesto)family__coalition                           NaN
# (manifesto)family__cons                          -0.074193
# (manifesto)family__green                         -0.055743
# (manifesto)family__liberal                       -0.085856
# (manifesto)family__rad left                      -0.068041
# (manifesto)family__rad right                      0.019062
# (manifesto)family__regional                      -0.055743
# (manifesto)family__socialist                     -0.087711
# (manifesto)family__special issue                 -0.045650
#
#                                   (ees14)mfamily__christdem  \
# (manifesto)family__agrarian                       -0.067344
# (manifesto)family__christdem                       0.913433
# (manifesto)family__coalition                            NaN
# (manifesto)family__cons                           -0.093148
# (manifesto)family__green                          -0.104092
# (manifesto)family__liberal                        -0.120333
# (manifesto)family__rad left                       -0.127057
# (manifesto)family__rad right                      -0.120586
# (manifesto)family__regional                       -0.104092
# (manifesto)family__socialist                      -0.157938
# (manifesto)family__special issue                  -0.085244
#
#                                   (ees14)mfamily__coalition  \
# (manifesto)family__agrarian                             NaN
# (manifesto)family__christdem                            NaN
# (manifesto)family__coalition                            NaN
# (manifesto)family__cons                                 NaN
# (manifesto)family__green                                NaN
# (manifesto)family__liberal                              NaN
# (manifesto)family__rad left                             NaN
# (manifesto)family__rad right                            NaN
# (manifesto)family__regional                             NaN
# (manifesto)family__socialist                            NaN
# (manifesto)family__special issue                        NaN
#
#                                   (ees14)mfamily__cons  (ees14)mfamily__green  \
# (manifesto)family__agrarian                  -0.063803              -0.052018
# (manifesto)family__christdem                 -0.126158              -0.102855
# (manifesto)family__coalition                       NaN                    NaN
# (manifesto)family__cons                       0.871103              -0.107013
# (manifesto)family__green                     -0.098618               1.000000
# (manifesto)family__liberal                   -0.151891              -0.123835
# (manifesto)family__rad left                  -0.120375              -0.098140
# (manifesto)family__rad right                 -0.114244              -0.093142
# (manifesto)family__regional                  -0.040581              -0.080402
# (manifesto)family__socialist                 -0.142959              -0.126511
# (manifesto)family__special issue             -0.080761              -0.065844
#
#                                   (ees14)mfamily__liberal  \
# (manifesto)family__agrarian                     -0.082243
# (manifesto)family__christdem                    -0.162620
# (manifesto)family__coalition                          NaN
# (manifesto)family__cons                         -0.130990
# (manifesto)family__green                        -0.127120
# (manifesto)family__liberal                       0.904719
# (manifesto)family__rad left                     -0.155165
# (manifesto)family__rad right                    -0.115347
# (manifesto)family__regional                     -0.127120
# (manifesto)family__socialist                    -0.166183
# (manifesto)family__special issue                -0.047357
#
#                                   (ees14)mfamily__rad left  \
# (manifesto)family__agrarian                      -0.065029
# (manifesto)family__christdem                     -0.128583
# (manifesto)family__coalition                           NaN
# (manifesto)family__cons                          -0.088650
# (manifesto)family__green                         -0.100513
# (manifesto)family__liberal                       -0.154810
# (manifesto)family__rad left                       0.976392
# (manifesto)family__rad right                     -0.116439
# (manifesto)family__regional                      -0.100513
# (manifesto)family__socialist                     -0.158155
# (manifesto)family__special issue                 -0.082313
#
#                                   (ees14)mfamily__rad right  \
# (manifesto)family__agrarian                       -0.055452
# (manifesto)family__christdem                      -0.057260
# (manifesto)family__coalition                            NaN
# (manifesto)family__cons                           -0.114079
# (manifesto)family__green                          -0.085711
# (manifesto)family__liberal                        -0.132012
# (manifesto)family__rad left                       -0.104620
# (manifesto)family__rad right                       0.872361
# (manifesto)family__regional                       -0.085711
# (manifesto)family__socialist                      -0.134864
# (manifesto)family__special issue                  -0.070191
#
#                                   (ees14)mfamily__regional  \
# (manifesto)family__agrarian                      -0.051992
# (manifesto)family__christdem                     -0.102804
# (manifesto)family__coalition                           NaN
# (manifesto)family__cons                          -0.106959
# (manifesto)family__green                         -0.080362
# (manifesto)family__liberal                       -0.123773
# (manifesto)family__rad left                      -0.098091
# (manifesto)family__rad right                     -0.032333
# (manifesto)family__regional                       0.931475
# (manifesto)family__socialist                     -0.126447
# (manifesto)family__special issue                 -0.065811
#
#                                   (ees14)mfamily__socialist  \
# (manifesto)family__agrarian                       -0.087033
# (manifesto)family__christdem                      -0.134402
# (manifesto)family__coalition                            NaN
# (manifesto)family__cons                           -0.105216
# (manifesto)family__green                          -0.134524
# (manifesto)family__liberal                        -0.169340
# (manifesto)family__rad left                       -0.164203
# (manifesto)family__rad right                      -0.155840
# (manifesto)family__regional                       -0.128770
# (manifesto)family__socialist                       0.900042
# (manifesto)family__special issue                  -0.055331
#
#                                   (ees14)mfamily__special issue
# (manifesto)family__agrarian                           -0.040517
# (manifesto)family__christdem                          -0.080115
# (manifesto)family__coalition                                NaN
# (manifesto)family__cons                               -0.083354
# (manifesto)family__green                              -0.062626
# (manifesto)family__liberal                            -0.096457
# (manifesto)family__rad left                           -0.076443
# (manifesto)family__rad right                           0.002622
# (manifesto)family__regional                           -0.062626
# (manifesto)family__socialist                          -0.098541
# (manifesto)family__special issue                       0.850892

# %%
df_first = df.groupby("partyfacts_id").first()
[x for x in df_first.columns if "mfamily" in x]

discrepancies = df_first[["(ees14)mfamily","(manifesto)family"]].apply(lambda x: True if pd.notnull(x["(ees14)mfamily"]) &\
                                                      pd.notnull(x["(manifesto)family"]) &\
                                                      (x["(ees14)mfamily"]!=x["(manifesto)family"]) \
                                                      else False, axis=1)

# %%
df_first[["(ees14)mfamily","(manifesto)family"]][discrepancies].merge( pf_core, how='left', on= "partyfacts_id")
# Out:
#     partyfacts_id (ees14)mfamily (manifesto)family country (pf)name_short  \
# 0            45.0      socialist           liberal     nld            D66
# 1           139.0           cons          regional     esp            CiU
# 2           461.0      christdem           liberal     lva         LPP/LC
# 3           472.0           cons         socialist     svn            SDS
# 4           536.0      christdem              cons     dnk             KF
# 5           553.0       regional         rad right     bel             VB
# 6           768.0        liberal     special issue     ita            IdV
# 7           800.0      socialist              cons     dnk             CD
# 8           802.0        liberal         socialist     ita             PD
# 9           852.0       rad left              cons     lva              V
# 10         1308.0      socialist         christdem     prt         CDS/PP
# 11         1359.0      socialist              cons     prt        PPD/PSD
# 12         1388.0      socialist           liberal     gbr             LD
# 13         1467.0      socialist     special issue     nld           PvdD
# 14         1689.0       agrarian         rad right     fin           SP/P
# 15         1691.0        liberal              cons     hun         Fidesz
# 16         1976.0  special issue         rad right     deu            AfD
# 17         3210.0      rad right         christdem     rou            PMP
#
#                                              (pf)name  \
# 0                                       Democraten 66
# 1                                 Convergència i Unió
# 2              Latvijas Pirmā partija / Latvijas Ceļš
# 3                       Slovenska demokratska stranka
# 4                             Konservative Folkeparti
# 5                                Vlaams Blok / Belang
# 6                Lista di Pietro -- Italia del Valori
# 7                                 Centrumdemokraterne
# 8                                 Partito Democratico
# 9                                           Vienotība
# 10      Centro Democrático e Social / Partido Popular
# 11  Partido Popular Democrático / Partido Social D...
# 12                                  Liberal Democrats
# 13                              Partij voor de Dieren
# 14                   Suomen Puolue / Perussuomalaiset
# 15                  Fidesz – Magyar Polgári Szövetség
# 16                        Alternative für Deutschland
# 17                         Partidul Mișcarea Populară
#
#                                      (pf)name_english  \
# 0                                        Democrats 66
# 1                               Convergence and Unity
# 2             Latvian First Party / Latvian Way Party
# 3                          Slovenian Democratic Party
# 4                         Conservative People's Party
# 5                            Flemish Block / Interest
# 6                   List Di Pietro -- Italy of Values
# 7                                    Centre Democrats
# 8                                    Democratic Party
# 9                                               Unity
# 10      Democratic and Social Center / People's Party
# 11  Popular Democratic Party / Social Democratic P...
# 12                                  Liberal Democrats
# 13                              Party for the Animals
# 14                           Finns Party / True Finns
# 15                  Fidesz – Hungarian Civic Alliance
# 16                            Alternative for Germany
# 17                            People's Movement Party
#
#               (pf)name_other  (pf)year_first  (pf)year_last  (pf)share  \
# 0                        NaN            1966            NaN       15.5
# 1                        NaN            1977         2015.0        5.1
# 2                        NaN            2006         2011.0        8.6
# 3                        NaN            1989            NaN       29.3
# 4                        NaN            1915            NaN       23.7
# 5                        NaN            1978         2004.0       12.0
# 6                        NaN            2001            NaN        4.5
# 7                        NaN            1976         2005.0        8.3
# 8                        NaN            2007            NaN       34.0
# 9                        NaN            2010            NaN       31.9
# 10                       NaN            1975            NaN       16.8
# 11                       NaN            1975            NaN       51.6
# 12                       NaN            1988            NaN       23.0
# 13                       NaN            2002            NaN        1.9
# 14  Swedish: Sannfinländarna            1995            NaN       19.1
# 15                       NaN            1988            NaN       41.1
# 16                       NaN            2013            NaN       12.6
# 17                       NaN            2014            NaN        5.3
#
#     (pf)share_year (pf)new                                      (pf)wikipedia  \
# 0           1994.0     NaN         https://en.wikipedia.org/wiki/Democrats_66
# 1           1989.0   False  https://en.wikipedia.org/wiki/Convergence_and_...
# 2           2006.0     NaN               https://en.wikipedia.org/wiki/LPP/LC
# 3           2008.0     NaN  https://en.wikipedia.org/wiki/Social_Democrati...
# 4           1901.0     NaN  https://en.wikipedia.org/wiki/Konservative_Fol...
# 5           2007.0     NaN          https://en.wikipedia.org/wiki/Vlaams_Blok
# 6           2008.0     NaN    https://en.wikipedia.org/wiki/Italia_dei_Valori
# 7           1981.0     NaN  https://en.wikipedia.org/wiki/CentrumDemokraterne
# 8           2008.0     NaN  https://en.wikipedia.org/wiki/Democratic_Party...
# 9           2010.0     NaN   https://en.wikipedia.org/wiki/Unity_%28Latvia%29
# 10          1976.0     NaN  https://en.wikipedia.org/wiki/People's_Party_(...
# 11          1991.0     NaN  https://en.wikipedia.org/wiki/Social_Democrati...
# 12          2010.0   False  https://en.wikipedia.org/wiki/Liberal_Democrat...
# 13          2012.0     NaN  https://en.wikipedia.org/wiki/Party_for_the_An...
# 14          2011.0     NaN           https://en.wikipedia.org/wiki/True_Finns
# 15          2002.0    True               https://en.wikipedia.org/wiki/Fidesz
# 16          2017.0    True  https://en.wikipedia.org/wiki/Alternative_for_...
# 17          2016.0     NaN  https://en.wikipedia.org/wiki/People%27s_Movem...
#
#    (pf)description (pf)comment                       (pf)created  \
# 0              NaN         NaN  2012-12-29 10:52:34.820000+00:00
# 1              NaN         NaN  2012-12-29 10:52:51.970000+00:00
# 2              NaN         NaN  2012-12-29 10:53:51.824000+00:00
# 3              NaN         NaN  2012-12-29 10:53:53.970000+00:00
# 4              NaN         NaN  2012-12-29 10:54:06.352000+00:00
# 5              NaN         NaN  2012-12-29 10:54:09.626000+00:00
# 6              NaN         NaN  2012-12-29 10:54:51.936000+00:00
# 7              NaN         NaN  2012-12-29 10:54:58.153000+00:00
# 8              NaN         NaN  2012-12-29 10:54:58.533000+00:00
# 9              NaN         NaN  2012-12-29 10:55:08.498000+00:00
# 10             NaN         NaN  2012-12-29 10:56:41.657000+00:00
# 11             NaN         NaN  2012-12-29 10:56:51.710000+00:00
# 12             NaN         NaN  2012-12-29 10:56:57.662000+00:00
# 13             NaN         NaN  2012-12-29 10:57:14.303000+00:00
# 14             NaN         NaN  2012-12-29 10:58:00.513000+00:00
# 15             NaN         NaN  2012-12-29 10:58:00.948000+00:00
# 16             NaN         NaN  2014-02-09 22:01:50.700503+00:00
# 17             NaN         NaN  2015-02-20 15:23:45.067900+00:00
#
#                         (pf)modified dataset  dataset_index
# 0   2018-07-07 20:07:29.344645+00:00      pf           4592
# 1   2018-07-07 20:09:33.885712+00:00      pf           5936
# 2   2018-07-14 12:21:18.326124+00:00      pf           3786
# 3   2018-07-07 20:09:18.119613+00:00      pf           5767
# 4   2018-07-07 20:02:58.338165+00:00      pf           1642
# 5   2018-07-14 12:21:18.308649+00:00      pf            530
# 6   2018-07-07 20:05:43.382873+00:00      pf           3321
# 7   2018-07-07 20:02:57.454036+00:00      pf           1638
# 8   2018-07-07 20:05:34.501399+00:00      pf           3276
# 9   2018-07-07 20:06:32.145733+00:00      pf           3826
# 10  2020-02-17 18:04:09.387810+00:00      pf           5170
# 11  2018-07-07 20:08:30.672132+00:00      pf           5194
# 12  2018-06-10 13:45:41.270867+00:00      pf           6598
# 13  2018-07-07 20:07:37.366664+00:00      pf           4615
# 14  2020-06-22 21:18:20.287430+00:00      pf           2089
# 15  2017-06-10 12:37:17.471789+00:00      pf           2807
# 16  2019-02-04 10:28:35.625346+00:00      pf           2329
# 17  2018-11-10 23:51:43.904998+00:00      pf           5279

# %%
emp_to_cmp_maps = {"(ees14)"+k.replace("per","per_v1_"):"(manifesto)"+v for k,v in mapping_dictionary.items() if "emp" not in v}
emp_to_cmp_maps.update({"(ees14)"+k.replace("per","per_v2_"):"(manifesto)"+v for k,v in mapping_dictionary.items() if "emp" not in v})
emp_to_cmp_maps.update({"(ees14)"+k.replace("per","per_v3_"):"(manifesto)"+v for k,v in mapping_dictionary.items() if "emp" not in v})
emp_to_cmp_maps = [(v,k) for k,v in emp_to_cmp_maps.items()]

# %%
# [x for x in emp_to_cmp_maps if x in list(df_corrs_ni_nm.set_index(["Row","Column"]).index.values)]
emp_to_cmp_maps
# Out:
# [('(ees14)per_v1_101b', '(manifesto)per102'),
#  ('(ees14)per_v1_101a', '(manifesto)per101'),
#  ('(ees14)per_v1_1011b', '(manifesto)per102'),
#  ('(ees14)per_v1_1011a', '(manifesto)per101'),
#  ('(ees14)per_v1_10111b', '(manifesto)per102'),
#  ('(ees14)per_v1_10111a', '(manifesto)per101'),
#  ('(ees14)per_v1_10112b', '(manifesto)per102'),
#  ('(ees14)per_v1_10112a', '(manifesto)per101'),
#  ('(ees14)per_v1_1012b', '(manifesto)per102'),
#  ('(ees14)per_v1_1012a', '(manifesto)per101'),
#  ('(ees14)per_v1_1013b', '(manifesto)per102'),
#  ('(ees14)per_v1_1013a', '(manifesto)per101'),
#  ('(ees14)per_v1_1014b', '(manifesto)per102'),
#  ('(ees14)per_v1_1014a', '(manifesto)per101'),
#  ('(ees14)per_v1_1015b', '(manifesto)per102'),
#  ('(ees14)per_v1_1015a', '(manifesto)per101'),
#  ('(ees14)per_v1_103a', '(manifesto)per103_1'),
#  ('(ees14)per_v1_104b', '(manifesto)per105'),
#  ('(ees14)per_v1_104a', '(manifesto)per104'),
#  ('(ees14)per_v1_1041b', '(manifesto)per105'),
#  ('(ees14)per_v1_1041a', '(manifesto)per104'),
#  ('(ees14)per_v1_1042b', '(manifesto)per105'),
#  ('(ees14)per_v1_1042a', '(manifesto)per104'),
#  ('(ees14)per_v1_1043b', '(manifesto)per105'),
#  ('(ees14)per_v1_1043a', '(manifesto)per104'),
#  ('(ees14)per_v1_106a', '(manifesto)per106'),
#  ('(ees14)per_v1_1061a', '(manifesto)per106'),
#  ('(ees14)per_v1_1062a', '(manifesto)per106'),
#  ('(ees14)per_v1_1063a', '(manifesto)per106'),
#  ('(ees14)per_v1_107b', '(manifesto)per109'),
#  ('(ees14)per_v1_107a', '(manifesto)per107'),
#  ('(ees14)per_v1_108b', '(manifesto)per110'),
#  ('(ees14)per_v1_108a', '(manifesto)per108'),
#  ('(ees14)per_v1_1081b', '(manifesto)per110'),
#  ('(ees14)per_v1_1081a', '(manifesto)per108'),
#  ('(ees14)per_v1_1082b', '(manifesto)per108'),
#  ('(ees14)per_v1_1082a', '(manifesto)per110'),
#  ('(ees14)per_v1_2011a', '(manifesto)per201_1'),
#  ('(ees14)per_v1_2012a', '(manifesto)per201_2'),
#  ('(ees14)per_v1_20121a', '(manifesto)per201_2'),
#  ('(ees14)per_v1_20122a', '(manifesto)per201_2'),
#  ('(ees14)per_v1_202b', '(manifesto)per202_2'),
#  ('(ees14)per_v1_202a', '(manifesto)per202_1'),
#  ('(ees14)per_v1_203b', '(manifesto)per204'),
#  ('(ees14)per_v1_203a', '(manifesto)per203'),
#  ('(ees14)per_v1_301b', '(manifesto)per302'),
#  ('(ees14)per_v1_301a', '(manifesto)per301'),
#  ('(ees14)per_v1_3011b', '(manifesto)per110'),
#  ('(ees14)per_v1_3011a', '(manifesto)per108'),
#  ('(ees14)per_v1_303a', '(manifesto)per303'),
#  ('(ees14)per_v1_304a', '(manifesto)per304'),
#  ('(ees14)per_v1_305a', '(manifesto)per305_3'),
#  ('(ees14)per_v1_306b', '(manifesto)per110'),
#  ('(ees14)per_v1_306a', '(manifesto)per108'),
#  ('(ees14)per_v1_308b', '(manifesto)per110'),
#  ('(ees14)per_v1_308a', '(manifesto)per108'),
#  ('(ees14)per_v1_310b', '(manifesto)per110'),
#  ('(ees14)per_v1_310a', '(manifesto)per108'),
#  ('(ees14)per_v1_314b', '(manifesto)per110'),
#  ('(ees14)per_v1_314a', '(manifesto)per108'),
#  ('(ees14)per_v1_316b', '(manifesto)per110'),
#  ('(ees14)per_v1_316a', '(manifesto)per108'),
#  ('(ees14)per_v1_3161b', '(manifesto)per110'),
#  ('(ees14)per_v1_3161a', '(manifesto)per108'),
#  ('(ees14)per_v1_3162b', '(manifesto)per110'),
#  ('(ees14)per_v1_3162a', '(manifesto)per108'),
#  ('(ees14)per_v1_3163b', '(manifesto)per110'),
#  ('(ees14)per_v1_3163a', '(manifesto)per108'),
#  ('(ees14)per_v1_401a', '(manifesto)per401'),
#  ('(ees14)per_v1_4012a', '(manifesto)per401'),
#  ('(ees14)per_v1_402a', '(manifesto)per402'),
#  ('(ees14)per_v1_403a', '(manifesto)per403'),
#  ('(ees14)per_v1_404a', '(manifesto)per404'),
#  ('(ees14)per_v1_405a', '(manifesto)per405'),
#  ('(ees14)per_v1_406b', '(manifesto)per407'),
#  ('(ees14)per_v1_406a', '(manifesto)per406'),
#  ('(ees14)per_v1_408a', '(manifesto)per408'),
#  ('(ees14)per_v1_4081a', '(manifesto)per701'),
#  ('(ees14)per_v1_4082a', '(manifesto)per408'),
#  ('(ees14)per_v1_40821a', '(manifesto)per408'),
#  ('(ees14)per_v1_40822a', '(manifesto)per408'),
#  ('(ees14)per_v1_40823a', '(manifesto)per408'),
#  ('(ees14)per_v1_4084a', '(manifesto)per407'),
#  ('(ees14)per_v1_4088a', '(manifesto)per411'),
#  ('(ees14)per_v1_409a', '(manifesto)per409'),
#  ('(ees14)per_v1_410a', '(manifesto)per410'),
#  ('(ees14)per_v1_411a', '(manifesto)per411 '),
#  ('(ees14)per_v1_412a', '(manifesto)per412'),
#  ('(ees14)per_v1_4121a', '(manifesto)per412'),
#  ('(ees14)per_v1_4123a', '(manifesto)per413'),
#  ('(ees14)per_v1_4124a', '(manifesto)per412'),
#  ('(ees14)per_v1_413a', '(manifesto)per413'),
#  ('(ees14)per_v1_4132b', '(manifesto)per413'),
#  ('(ees14)per_v1_414a', '(manifesto)per414'),
#  ('(ees14)per_v1_415a', '(manifesto)per415 '),
#  ('(ees14)per_v1_416a', '(manifesto)per416_1'),
#  ('(ees14)per_v1_501a', '(manifesto)per501'),
#  ('(ees14)per_v1_5011a', '(manifesto)per501'),
#  ('(ees14)per_v1_5012a', '(manifesto)per501'),
#  ('(ees14)per_v1_5013a', '(manifesto)per501'),
#  ('(ees14)per_v1_502a', '(manifesto)per502'),
#  ('(ees14)per_v1_503a', '(manifesto)per503'),
#  ('(ees14)per_v1_504b', '(manifesto)per505'),
#  ('(ees14)per_v1_504a', '(manifesto)per504'),
#  ('(ees14)per_v1_5041a', '(manifesto)per701'),
#  ('(ees14)per_v1_5042a', '(manifesto)per701'),
#  ('(ees14)per_v1_5043b', '(manifesto)per505'),
#  ('(ees14)per_v1_5043a', '(manifesto)per504'),
#  ('(ees14)per_v1_5044b', '(manifesto)per505'),
#  ('(ees14)per_v1_5044a', '(manifesto)per504'),
#  ('(ees14)per_v1_5045b', '(manifesto)per505'),
#  ('(ees14)per_v1_5045a', '(manifesto)per504'),
#  ('(ees14)per_v1_506b', '(manifesto)per507'),
#  ('(ees14)per_v1_506a', '(manifesto)per506'),
#  ('(ees14)per_v1_601b', '(manifesto)per602_1'),
#  ('(ees14)per_v1_601a', '(manifesto)per601_1'),
#  ('(ees14)per_v1_6011b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_6011a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_60111b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_60111a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_60112b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_60112a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_60113b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_60113a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_6021b', '(manifesto)per110'),
#  ('(ees14)per_v1_6021a', '(manifesto)per108'),
#  ('(ees14)per_v1_603b', '(manifesto)per604'),
#  ('(ees14)per_v1_603a', '(manifesto)per603'),
#  ('(ees14)per_v1_605b', '(manifesto)per605_2'),
#  ('(ees14)per_v1_605a', '(manifesto)per605_1'),
#  ('(ees14)per_v1_6051b', '(manifesto)per605_2'),
#  ('(ees14)per_v1_6051a', '(manifesto)per605_1'),
#  ('(ees14)per_v1_606a', '(manifesto)per606'),
#  ('(ees14)per_v1_607b', '(manifesto)per608_1'),
#  ('(ees14)per_v1_607a', '(manifesto)per607_1'),
#  ('(ees14)per_v1_701b', '(manifesto)per702'),
#  ('(ees14)per_v1_701a', '(manifesto)per701'),
#  ('(ees14)per_v1_7031b', '(manifesto)per703_2'),
#  ('(ees14)per_v1_7031a', '(manifesto)per703_1'),
#  ('(ees14)per_v1_704a', '(manifesto)per704'),
#  ('(ees14)per_v1_705a', '(manifesto)per705'),
#  ('(ees14)per_v1_7051a', '(manifesto)per705'),
#  ('(ees14)per_v1_7052a', '(manifesto)per705'),
#  ('(ees14)per_v1_7053a', '(manifesto)per705'),
#  ('(ees14)per_v1_70531a', '(manifesto)per705'),
#  ('(ees14)per_v1_70532a', '(manifesto)per705'),
#  ('(ees14)per_v1_70533a', '(manifesto)per705'),
#  ('(ees14)per_v1_7054a', '(manifesto)per705'),
#  ('(ees14)per_v1_706a', '(manifesto)per706'),
#  ('(ees14)per_v1_7061a', '(manifesto)per706'),
#  ('(ees14)per_v1_7062a', '(manifesto)per706'),
#  ('(ees14)per_v1_7063a', '(manifesto)per706'),
#  ('(ees14)per_v1_7064a', '(manifesto)per706'),
#  ('(ees14)per_v2_101b', '(manifesto)per102'),
#  ('(ees14)per_v2_101a', '(manifesto)per101'),
#  ('(ees14)per_v2_1011b', '(manifesto)per102'),
#  ('(ees14)per_v2_1011a', '(manifesto)per101'),
#  ('(ees14)per_v2_10111b', '(manifesto)per102'),
#  ('(ees14)per_v2_10111a', '(manifesto)per101'),
#  ('(ees14)per_v2_10112b', '(manifesto)per102'),
#  ('(ees14)per_v2_10112a', '(manifesto)per101'),
#  ('(ees14)per_v2_1012b', '(manifesto)per102'),
#  ('(ees14)per_v2_1012a', '(manifesto)per101'),
#  ('(ees14)per_v2_1013b', '(manifesto)per102'),
#  ('(ees14)per_v2_1013a', '(manifesto)per101'),
#  ('(ees14)per_v2_1014b', '(manifesto)per102'),
#  ('(ees14)per_v2_1014a', '(manifesto)per101'),
#  ('(ees14)per_v2_1015b', '(manifesto)per102'),
#  ('(ees14)per_v2_1015a', '(manifesto)per101'),
#  ('(ees14)per_v2_103a', '(manifesto)per103_1'),
#  ('(ees14)per_v2_104b', '(manifesto)per105'),
#  ('(ees14)per_v2_104a', '(manifesto)per104'),
#  ('(ees14)per_v2_1041b', '(manifesto)per105'),
#  ('(ees14)per_v2_1041a', '(manifesto)per104'),
#  ('(ees14)per_v2_1042b', '(manifesto)per105'),
#  ('(ees14)per_v2_1042a', '(manifesto)per104'),
#  ('(ees14)per_v2_1043b', '(manifesto)per105'),
#  ('(ees14)per_v2_1043a', '(manifesto)per104'),
#  ('(ees14)per_v2_106a', '(manifesto)per106'),
#  ('(ees14)per_v2_1061a', '(manifesto)per106'),
#  ('(ees14)per_v2_1062a', '(manifesto)per106'),
#  ('(ees14)per_v2_1063a', '(manifesto)per106'),
#  ('(ees14)per_v2_107b', '(manifesto)per109'),
#  ('(ees14)per_v2_107a', '(manifesto)per107'),
#  ('(ees14)per_v2_108b', '(manifesto)per110'),
#  ('(ees14)per_v2_108a', '(manifesto)per108'),
#  ('(ees14)per_v2_1081b', '(manifesto)per110'),
#  ('(ees14)per_v2_1081a', '(manifesto)per108'),
#  ('(ees14)per_v2_1082b', '(manifesto)per108'),
#  ('(ees14)per_v2_1082a', '(manifesto)per110'),
#  ('(ees14)per_v2_2011a', '(manifesto)per201_1'),
#  ('(ees14)per_v2_2012a', '(manifesto)per201_2'),
#  ('(ees14)per_v2_20121a', '(manifesto)per201_2'),
#  ('(ees14)per_v2_20122a', '(manifesto)per201_2'),
#  ('(ees14)per_v2_202b', '(manifesto)per202_2'),
#  ('(ees14)per_v2_202a', '(manifesto)per202_1'),
#  ('(ees14)per_v2_203b', '(manifesto)per204'),
#  ('(ees14)per_v2_203a', '(manifesto)per203'),
#  ('(ees14)per_v2_301b', '(manifesto)per302'),
#  ('(ees14)per_v2_301a', '(manifesto)per301'),
#  ('(ees14)per_v2_3011b', '(manifesto)per110'),
#  ('(ees14)per_v2_3011a', '(manifesto)per108'),
#  ('(ees14)per_v2_303a', '(manifesto)per303'),
#  ('(ees14)per_v2_304a', '(manifesto)per304'),
#  ('(ees14)per_v2_305a', '(manifesto)per305_3'),
#  ('(ees14)per_v2_306b', '(manifesto)per110'),
#  ('(ees14)per_v2_306a', '(manifesto)per108'),
#  ('(ees14)per_v2_308b', '(manifesto)per110'),
#  ('(ees14)per_v2_308a', '(manifesto)per108'),
#  ('(ees14)per_v2_310b', '(manifesto)per110'),
#  ('(ees14)per_v2_310a', '(manifesto)per108'),
#  ('(ees14)per_v2_314b', '(manifesto)per110'),
#  ('(ees14)per_v2_314a', '(manifesto)per108'),
#  ('(ees14)per_v2_316b', '(manifesto)per110'),
#  ('(ees14)per_v2_316a', '(manifesto)per108'),
#  ('(ees14)per_v2_3161b', '(manifesto)per110'),
#  ('(ees14)per_v2_3161a', '(manifesto)per108'),
#  ('(ees14)per_v2_3162b', '(manifesto)per110'),
#  ('(ees14)per_v2_3162a', '(manifesto)per108'),
#  ('(ees14)per_v2_3163b', '(manifesto)per110'),
#  ('(ees14)per_v2_3163a', '(manifesto)per108'),
#  ('(ees14)per_v2_401a', '(manifesto)per401'),
#  ('(ees14)per_v2_4012a', '(manifesto)per401'),
#  ('(ees14)per_v2_402a', '(manifesto)per402'),
#  ('(ees14)per_v2_403a', '(manifesto)per403'),
#  ('(ees14)per_v2_404a', '(manifesto)per404'),
#  ('(ees14)per_v2_405a', '(manifesto)per405'),
#  ('(ees14)per_v2_406b', '(manifesto)per407'),
#  ('(ees14)per_v2_406a', '(manifesto)per406'),
#  ('(ees14)per_v2_408a', '(manifesto)per408'),
#  ('(ees14)per_v2_4081a', '(manifesto)per701'),
#  ('(ees14)per_v2_4082a', '(manifesto)per408'),
#  ('(ees14)per_v2_40821a', '(manifesto)per408'),
#  ('(ees14)per_v2_40822a', '(manifesto)per408'),
#  ('(ees14)per_v2_40823a', '(manifesto)per408'),
#  ('(ees14)per_v2_4084a', '(manifesto)per407'),
#  ('(ees14)per_v2_4088a', '(manifesto)per411'),
#  ('(ees14)per_v2_409a', '(manifesto)per409'),
#  ('(ees14)per_v2_410a', '(manifesto)per410'),
#  ('(ees14)per_v2_411a', '(manifesto)per411 '),
#  ('(ees14)per_v2_412a', '(manifesto)per412'),
#  ('(ees14)per_v2_4121a', '(manifesto)per412'),
#  ('(ees14)per_v2_4123a', '(manifesto)per413'),
#  ('(ees14)per_v2_4124a', '(manifesto)per412'),
#  ('(ees14)per_v2_413a', '(manifesto)per413'),
#  ('(ees14)per_v2_4132b', '(manifesto)per413'),
#  ('(ees14)per_v2_414a', '(manifesto)per414'),
#  ('(ees14)per_v2_415a', '(manifesto)per415 '),
#  ('(ees14)per_v2_416a', '(manifesto)per416_1'),
#  ('(ees14)per_v2_501a', '(manifesto)per501'),
#  ('(ees14)per_v2_5011a', '(manifesto)per501'),
#  ('(ees14)per_v2_5012a', '(manifesto)per501'),
#  ('(ees14)per_v2_5013a', '(manifesto)per501'),
#  ('(ees14)per_v2_502a', '(manifesto)per502'),
#  ('(ees14)per_v2_503a', '(manifesto)per503'),
#  ('(ees14)per_v2_504b', '(manifesto)per505'),
#  ('(ees14)per_v2_504a', '(manifesto)per504'),
#  ('(ees14)per_v2_5041a', '(manifesto)per701'),
#  ('(ees14)per_v2_5042a', '(manifesto)per701'),
#  ('(ees14)per_v2_5043b', '(manifesto)per505'),
#  ('(ees14)per_v2_5043a', '(manifesto)per504'),
#  ('(ees14)per_v2_5044b', '(manifesto)per505'),
#  ('(ees14)per_v2_5044a', '(manifesto)per504'),
#  ('(ees14)per_v2_5045b', '(manifesto)per505'),
#  ('(ees14)per_v2_5045a', '(manifesto)per504'),
#  ('(ees14)per_v2_506b', '(manifesto)per507'),
#  ('(ees14)per_v2_506a', '(manifesto)per506'),
#  ('(ees14)per_v2_601b', '(manifesto)per602_1'),
#  ('(ees14)per_v2_601a', '(manifesto)per601_1'),
#  ('(ees14)per_v2_6011b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_6011a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_60111b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_60111a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_60112b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_60112a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_60113b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_60113a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_6021b', '(manifesto)per110'),
#  ('(ees14)per_v2_6021a', '(manifesto)per108'),
#  ('(ees14)per_v2_603b', '(manifesto)per604'),
#  ('(ees14)per_v2_603a', '(manifesto)per603'),
#  ('(ees14)per_v2_605b', '(manifesto)per605_2'),
#  ('(ees14)per_v2_605a', '(manifesto)per605_1'),
#  ('(ees14)per_v2_6051b', '(manifesto)per605_2'),
#  ('(ees14)per_v2_6051a', '(manifesto)per605_1'),
#  ('(ees14)per_v2_606a', '(manifesto)per606'),
#  ('(ees14)per_v2_607b', '(manifesto)per608_1'),
#  ('(ees14)per_v2_607a', '(manifesto)per607_1'),
#  ('(ees14)per_v2_701b', '(manifesto)per702'),
#  ('(ees14)per_v2_701a', '(manifesto)per701'),
#  ('(ees14)per_v2_7031b', '(manifesto)per703_2'),
#  ('(ees14)per_v2_7031a', '(manifesto)per703_1'),
#  ('(ees14)per_v2_704a', '(manifesto)per704'),
#  ('(ees14)per_v2_705a', '(manifesto)per705'),
#  ('(ees14)per_v2_7051a', '(manifesto)per705'),
#  ('(ees14)per_v2_7052a', '(manifesto)per705'),
#  ('(ees14)per_v2_7053a', '(manifesto)per705'),
#  ('(ees14)per_v2_70531a', '(manifesto)per705'),
#  ('(ees14)per_v2_70532a', '(manifesto)per705'),
#  ('(ees14)per_v2_70533a', '(manifesto)per705'),
#  ('(ees14)per_v2_7054a', '(manifesto)per705'),
#  ('(ees14)per_v2_706a', '(manifesto)per706'),
#  ('(ees14)per_v2_7061a', '(manifesto)per706'),
#  ('(ees14)per_v2_7062a', '(manifesto)per706'),
#  ('(ees14)per_v2_7063a', '(manifesto)per706'),
#  ('(ees14)per_v2_7064a', '(manifesto)per706'),
#  ('(ees14)per_v3_101b', '(manifesto)per102'),
#  ('(ees14)per_v3_101a', '(manifesto)per101'),
#  ('(ees14)per_v3_1011b', '(manifesto)per102'),
#  ('(ees14)per_v3_1011a', '(manifesto)per101'),
#  ('(ees14)per_v3_10111b', '(manifesto)per102'),
#  ('(ees14)per_v3_10111a', '(manifesto)per101'),
#  ('(ees14)per_v3_10112b', '(manifesto)per102'),
#  ('(ees14)per_v3_10112a', '(manifesto)per101'),
#  ('(ees14)per_v3_1012b', '(manifesto)per102'),
#  ('(ees14)per_v3_1012a', '(manifesto)per101'),
#  ('(ees14)per_v3_1013b', '(manifesto)per102'),
#  ('(ees14)per_v3_1013a', '(manifesto)per101'),
#  ('(ees14)per_v3_1014b', '(manifesto)per102'),
#  ('(ees14)per_v3_1014a', '(manifesto)per101'),
#  ('(ees14)per_v3_1015b', '(manifesto)per102'),
#  ('(ees14)per_v3_1015a', '(manifesto)per101'),
#  ('(ees14)per_v3_103a', '(manifesto)per103_1'),
#  ('(ees14)per_v3_104b', '(manifesto)per105'),
#  ('(ees14)per_v3_104a', '(manifesto)per104'),
#  ('(ees14)per_v3_1041b', '(manifesto)per105'),
#  ('(ees14)per_v3_1041a', '(manifesto)per104'),
#  ('(ees14)per_v3_1042b', '(manifesto)per105'),
#  ('(ees14)per_v3_1042a', '(manifesto)per104'),
#  ('(ees14)per_v3_1043b', '(manifesto)per105'),
#  ('(ees14)per_v3_1043a', '(manifesto)per104'),
#  ('(ees14)per_v3_106a', '(manifesto)per106'),
#  ('(ees14)per_v3_1061a', '(manifesto)per106'),
#  ('(ees14)per_v3_1062a', '(manifesto)per106'),
#  ('(ees14)per_v3_1063a', '(manifesto)per106'),
#  ('(ees14)per_v3_107b', '(manifesto)per109'),
#  ('(ees14)per_v3_107a', '(manifesto)per107'),
#  ('(ees14)per_v3_108b', '(manifesto)per110'),
#  ('(ees14)per_v3_108a', '(manifesto)per108'),
#  ('(ees14)per_v3_1081b', '(manifesto)per110'),
#  ('(ees14)per_v3_1081a', '(manifesto)per108'),
#  ('(ees14)per_v3_1082b', '(manifesto)per108'),
#  ('(ees14)per_v3_1082a', '(manifesto)per110'),
#  ('(ees14)per_v3_2011a', '(manifesto)per201_1'),
#  ('(ees14)per_v3_2012a', '(manifesto)per201_2'),
#  ('(ees14)per_v3_20121a', '(manifesto)per201_2'),
#  ('(ees14)per_v3_20122a', '(manifesto)per201_2'),
#  ('(ees14)per_v3_202b', '(manifesto)per202_2'),
#  ('(ees14)per_v3_202a', '(manifesto)per202_1'),
#  ('(ees14)per_v3_203b', '(manifesto)per204'),
#  ('(ees14)per_v3_203a', '(manifesto)per203'),
#  ('(ees14)per_v3_301b', '(manifesto)per302'),
#  ('(ees14)per_v3_301a', '(manifesto)per301'),
#  ('(ees14)per_v3_3011b', '(manifesto)per110'),
#  ('(ees14)per_v3_3011a', '(manifesto)per108'),
#  ('(ees14)per_v3_303a', '(manifesto)per303'),
#  ('(ees14)per_v3_304a', '(manifesto)per304'),
#  ('(ees14)per_v3_305a', '(manifesto)per305_3'),
#  ('(ees14)per_v3_306b', '(manifesto)per110'),
#  ('(ees14)per_v3_306a', '(manifesto)per108'),
#  ('(ees14)per_v3_308b', '(manifesto)per110'),
#  ('(ees14)per_v3_308a', '(manifesto)per108'),
#  ('(ees14)per_v3_310b', '(manifesto)per110'),
#  ('(ees14)per_v3_310a', '(manifesto)per108'),
#  ('(ees14)per_v3_314b', '(manifesto)per110'),
#  ('(ees14)per_v3_314a', '(manifesto)per108'),
#  ('(ees14)per_v3_316b', '(manifesto)per110'),
#  ('(ees14)per_v3_316a', '(manifesto)per108'),
#  ('(ees14)per_v3_3161b', '(manifesto)per110'),
#  ('(ees14)per_v3_3161a', '(manifesto)per108'),
#  ('(ees14)per_v3_3162b', '(manifesto)per110'),
#  ('(ees14)per_v3_3162a', '(manifesto)per108'),
#  ('(ees14)per_v3_3163b', '(manifesto)per110'),
#  ('(ees14)per_v3_3163a', '(manifesto)per108'),
#  ('(ees14)per_v3_401a', '(manifesto)per401'),
#  ('(ees14)per_v3_4012a', '(manifesto)per401'),
#  ('(ees14)per_v3_402a', '(manifesto)per402'),
#  ('(ees14)per_v3_403a', '(manifesto)per403'),
#  ('(ees14)per_v3_404a', '(manifesto)per404'),
#  ('(ees14)per_v3_405a', '(manifesto)per405'),
#  ('(ees14)per_v3_406b', '(manifesto)per407'),
#  ('(ees14)per_v3_406a', '(manifesto)per406'),
#  ('(ees14)per_v3_408a', '(manifesto)per408'),
#  ('(ees14)per_v3_4081a', '(manifesto)per701'),
#  ('(ees14)per_v3_4082a', '(manifesto)per408'),
#  ('(ees14)per_v3_40821a', '(manifesto)per408'),
#  ('(ees14)per_v3_40822a', '(manifesto)per408'),
#  ('(ees14)per_v3_40823a', '(manifesto)per408'),
#  ('(ees14)per_v3_4084a', '(manifesto)per407'),
#  ('(ees14)per_v3_4088a', '(manifesto)per411'),
#  ('(ees14)per_v3_409a', '(manifesto)per409'),
#  ('(ees14)per_v3_410a', '(manifesto)per410'),
#  ('(ees14)per_v3_411a', '(manifesto)per411 '),
#  ('(ees14)per_v3_412a', '(manifesto)per412'),
#  ('(ees14)per_v3_4121a', '(manifesto)per412'),
#  ('(ees14)per_v3_4123a', '(manifesto)per413'),
#  ('(ees14)per_v3_4124a', '(manifesto)per412'),
#  ('(ees14)per_v3_413a', '(manifesto)per413'),
#  ('(ees14)per_v3_4132b', '(manifesto)per413'),
#  ('(ees14)per_v3_414a', '(manifesto)per414'),
#  ('(ees14)per_v3_415a', '(manifesto)per415 '),
#  ('(ees14)per_v3_416a', '(manifesto)per416_1'),
#  ('(ees14)per_v3_501a', '(manifesto)per501'),
#  ('(ees14)per_v3_5011a', '(manifesto)per501'),
#  ('(ees14)per_v3_5012a', '(manifesto)per501'),
#  ('(ees14)per_v3_5013a', '(manifesto)per501'),
#  ('(ees14)per_v3_502a', '(manifesto)per502'),
#  ('(ees14)per_v3_503a', '(manifesto)per503'),
#  ('(ees14)per_v3_504b', '(manifesto)per505'),
#  ('(ees14)per_v3_504a', '(manifesto)per504'),
#  ('(ees14)per_v3_5041a', '(manifesto)per701'),
#  ('(ees14)per_v3_5042a', '(manifesto)per701'),
#  ('(ees14)per_v3_5043b', '(manifesto)per505'),
#  ('(ees14)per_v3_5043a', '(manifesto)per504'),
#  ('(ees14)per_v3_5044b', '(manifesto)per505'),
#  ('(ees14)per_v3_5044a', '(manifesto)per504'),
#  ('(ees14)per_v3_5045b', '(manifesto)per505'),
#  ('(ees14)per_v3_5045a', '(manifesto)per504'),
#  ('(ees14)per_v3_506b', '(manifesto)per507'),
#  ('(ees14)per_v3_506a', '(manifesto)per506'),
#  ('(ees14)per_v3_601b', '(manifesto)per602_1'),
#  ('(ees14)per_v3_601a', '(manifesto)per601_1'),
#  ('(ees14)per_v3_6011b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_6011a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_60111b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_60111a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_60112b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_60112a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_60113b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_60113a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_6021b', '(manifesto)per110'),
#  ('(ees14)per_v3_6021a', '(manifesto)per108'),
#  ('(ees14)per_v3_603b', '(manifesto)per604'),
#  ('(ees14)per_v3_603a', '(manifesto)per603'),
#  ('(ees14)per_v3_605b', '(manifesto)per605_2'),
#  ('(ees14)per_v3_605a', '(manifesto)per605_1'),
#  ('(ees14)per_v3_6051b', '(manifesto)per605_2'),
#  ('(ees14)per_v3_6051a', '(manifesto)per605_1'),
#  ('(ees14)per_v3_606a', '(manifesto)per606'),
#  ('(ees14)per_v3_607b', '(manifesto)per608_1'),
#  ('(ees14)per_v3_607a', '(manifesto)per607_1'),
#  ('(ees14)per_v3_701b', '(manifesto)per702'),
#  ('(ees14)per_v3_701a', '(manifesto)per701'),
#  ('(ees14)per_v3_7031b', '(manifesto)per703_2'),
#  ('(ees14)per_v3_7031a', '(manifesto)per703_1'),
#  ('(ees14)per_v3_704a', '(manifesto)per704'),
#  ('(ees14)per_v3_705a', '(manifesto)per705'),
#  ('(ees14)per_v3_7051a', '(manifesto)per705'),
#  ('(ees14)per_v3_7052a', '(manifesto)per705'),
#  ('(ees14)per_v3_7053a', '(manifesto)per705'),
#  ('(ees14)per_v3_70531a', '(manifesto)per705'),
#  ('(ees14)per_v3_70532a', '(manifesto)per705'),
#  ('(ees14)per_v3_70533a', '(manifesto)per705'),
#  ('(ees14)per_v3_7054a', '(manifesto)per705'),
#  ('(ees14)per_v3_706a', '(manifesto)per706'),
#  ('(ees14)per_v3_7061a', '(manifesto)per706'),
#  ('(ees14)per_v3_7062a', '(manifesto)per706'),
#  ('(ees14)per_v3_7063a', '(manifesto)per706'),
#  ('(ees14)per_v3_7064a', '(manifesto)per706')]

# %%
# df_corrs_ni_nm[df_corrs_ni_nm["Row"]=='(manifesto)per102'].head(50)
df_corrs_ni_nm[df_corrs_ni_nm["Column"]=='(ees14)per_v3_101b'].head(50)
# Out:
#                              Row              Column     Value  NZ    N  \
# 399                   (ches)vote  (ees14)per_v3_101b -0.013168   9  186
# 1488           (ches)eu_position  (ees14)per_v3_101b  0.000075  10  189
# 2509                (ches)future  (ees14)per_v3_101b -0.222186   3   89
# 3560                 (ches)eu_ep  (ees14)per_v3_101b  0.034204  10  185
# 4578             (ches)eu_fiscal  (ees14)per_v3_101b -0.228733   3   89
# 5617             (ches)eu_employ  (ees14)per_v3_101b -0.157231   5  126
# 6680           (ches)eu_cohesion  (ees14)per_v3_101b  0.027583  10  185
# 7752            (ches)eu_environ  (ees14)per_v3_101b -0.147682   5  127
# 8812             (ches)eu_asylum  (ees14)per_v3_101b -0.024277   8  172
# 9888            (ches)eu_foreign  (ees14)per_v3_101b  0.002686  10  185
# 10973                (ches)lrgen  (ees14)per_v3_101b  0.082680  10  189
# 12058               (ches)lrecon  (ees14)per_v3_101b  0.085301  10  187
# 13142               (ches)galtan  (ees14)per_v3_101b  0.093679  10  187
# 14218                 (ches)govt  (ees14)per_v3_101b  0.022674   7  187
# 15284                (ches)vote1  (ees14)per_v3_101b -0.088522   5  133
# 16348           (ches)eu_intmark  (ees14)per_v3_101b  0.035572  10  184
# 17411              (ches)eu_agri  (ees14)per_v3_101b  0.090103   4  115
# 18390              (ches)enlargw  (ees14)per_v3_101b -0.038936   3   78
# 19391              (ches)enlarge  (ees14)per_v3_101b  0.113680   1   37
# 20252        (ches)eu_ep_dissent  (ees14)per_v3_101b  0.012583   3  115
# 21286   (ches)eu_intmark_dissent  (ees14)per_v3_101b  0.008665   2  115
# 22319    (ches)eu_employ_dissent  (ees14)per_v3_101b -0.025145   2  115
# 23351      (ches)eu_agri_dissent  (ees14)per_v3_101b  0.185236   2  115
# 24382  (ches)eu_cohesion_dissent  (ees14)per_v3_101b  0.171405   3  115
# 25412   (ches)eu_environ_dissent  (ees14)per_v3_101b  0.096558   2  115
# 26441    (ches)eu_asylum_dissent  (ees14)per_v3_101b  0.059614   3  115
# 27412      (ches)enlargw_dissent  (ees14)per_v3_101b  0.114495   2   78
# 28405      (ches)enlarge_dissent  (ees14)per_v3_101b -0.052807   1   37
# 29267             (ches)lrgen_sd  (ees14)per_v3_101b -0.033608   7  169
# 30322            (ches)lrecon_sd  (ees14)per_v3_101b  0.051524   9  179
# 31377            (ches)galtan_sd  (ees14)per_v3_101b -0.052291   8  179
# 32420                (ches)govt1  (ees14)per_v3_101b -0.032339   3  136
# 33403                (ches)govt2  (ees14)per_v3_101b -0.118631   3   90
# 34362                (ches)govt3  (ees14)per_v3_101b -0.126989   3   90
# 35384            (ches)eu_turkey  (ees14)per_v3_101b -0.107080  10  182
# 36444              (ches)pubserv  (ees14)per_v3_101b  0.094134  10  184
# 37495     (ches)pubserv_salience  (ees14)per_v3_101b -0.045149   8  155
# 38551                (ches)dereg  (ees14)per_v3_101b  0.090385  10  183
# 39600       (ches)dereg_salience  (ees14)per_v3_101b  0.021259   8  154
# 40654               (ches)redist  (ees14)per_v3_101b  0.106064  10  183
# 41702      (ches)redist_salience  (ees14)per_v3_101b -0.045372  10  175
# 42756               (ches)civlib  (ees14)per_v3_101b  0.060257  10  184
# 43801      (ches)civlib_salience  (ees14)per_v3_101b -0.108439   8  155
# 44851            (ches)lifestyle  (ees14)per_v3_101b  0.076104  10  184
# 45894   (ches)lifestyle_salience  (ees14)per_v3_101b -0.011048   8  155
# 46942             (ches)religion  (ees14)per_v3_101b  0.172244  10  183
# 47983    (ches)religion_salience  (ees14)per_v3_101b  0.140642   8  154
# 49029                (ches)immig  (ees14)per_v3_101b  0.070308  10  185
# 50071       (ches)immig_salience  (ees14)per_v3_101b -0.012414  10  181
# 51118            (ches)multicult  (ees14)per_v3_101b  0.069489  10  185
#
#       Row_ds Col_ds
# 399     ches  ees14
# 1488    ches  ees14
# 2509    ches  ees14
# 3560    ches  ees14
# 4578    ches  ees14
# 5617    ches  ees14
# 6680    ches  ees14
# 7752    ches  ees14
# 8812    ches  ees14
# 9888    ches  ees14
# 10973   ches  ees14
# 12058   ches  ees14
# 13142   ches  ees14
# 14218   ches  ees14
# 15284   ches  ees14
# 16348   ches  ees14
# 17411   ches  ees14
# 18390   ches  ees14
# 19391   ches  ees14
# 20252   ches  ees14
# 21286   ches  ees14
# 22319   ches  ees14
# 23351   ches  ees14
# 24382   ches  ees14
# 25412   ches  ees14
# 26441   ches  ees14
# 27412   ches  ees14
# 28405   ches  ees14
# 29267   ches  ees14
# 30322   ches  ees14
# 31377   ches  ees14
# 32420   ches  ees14
# 33403   ches  ees14
# 34362   ches  ees14
# 35384   ches  ees14
# 36444   ches  ees14
# 37495   ches  ees14
# 38551   ches  ees14
# 39600   ches  ees14
# 40654   ches  ees14
# 41702   ches  ees14
# 42756   ches  ees14
# 43801   ches  ees14
# 44851   ches  ees14
# 45894   ches  ees14
# 46942   ches  ees14
# 47983   ches  ees14
# 49029   ches  ees14
# 50071   ches  ees14
# 51118   ches  ees14

# %%
emp_to_cmp_maps
# Out:
# [('(ees14)per_v1_101b', '(manifesto)per102'),
#  ('(ees14)per_v1_101a', '(manifesto)per101'),
#  ('(ees14)per_v1_1011b', '(manifesto)per102'),
#  ('(ees14)per_v1_1011a', '(manifesto)per101'),
#  ('(ees14)per_v1_10111b', '(manifesto)per102'),
#  ('(ees14)per_v1_10111a', '(manifesto)per101'),
#  ('(ees14)per_v1_10112b', '(manifesto)per102'),
#  ('(ees14)per_v1_10112a', '(manifesto)per101'),
#  ('(ees14)per_v1_1012b', '(manifesto)per102'),
#  ('(ees14)per_v1_1012a', '(manifesto)per101'),
#  ('(ees14)per_v1_1013b', '(manifesto)per102'),
#  ('(ees14)per_v1_1013a', '(manifesto)per101'),
#  ('(ees14)per_v1_1014b', '(manifesto)per102'),
#  ('(ees14)per_v1_1014a', '(manifesto)per101'),
#  ('(ees14)per_v1_1015b', '(manifesto)per102'),
#  ('(ees14)per_v1_1015a', '(manifesto)per101'),
#  ('(ees14)per_v1_103a', '(manifesto)per103_1'),
#  ('(ees14)per_v1_104b', '(manifesto)per105'),
#  ('(ees14)per_v1_104a', '(manifesto)per104'),
#  ('(ees14)per_v1_1041b', '(manifesto)per105'),
#  ('(ees14)per_v1_1041a', '(manifesto)per104'),
#  ('(ees14)per_v1_1042b', '(manifesto)per105'),
#  ('(ees14)per_v1_1042a', '(manifesto)per104'),
#  ('(ees14)per_v1_1043b', '(manifesto)per105'),
#  ('(ees14)per_v1_1043a', '(manifesto)per104'),
#  ('(ees14)per_v1_106a', '(manifesto)per106'),
#  ('(ees14)per_v1_1061a', '(manifesto)per106'),
#  ('(ees14)per_v1_1062a', '(manifesto)per106'),
#  ('(ees14)per_v1_1063a', '(manifesto)per106'),
#  ('(ees14)per_v1_107b', '(manifesto)per109'),
#  ('(ees14)per_v1_107a', '(manifesto)per107'),
#  ('(ees14)per_v1_108b', '(manifesto)per110'),
#  ('(ees14)per_v1_108a', '(manifesto)per108'),
#  ('(ees14)per_v1_1081b', '(manifesto)per110'),
#  ('(ees14)per_v1_1081a', '(manifesto)per108'),
#  ('(ees14)per_v1_1082b', '(manifesto)per108'),
#  ('(ees14)per_v1_1082a', '(manifesto)per110'),
#  ('(ees14)per_v1_2011a', '(manifesto)per201_1'),
#  ('(ees14)per_v1_2012a', '(manifesto)per201_2'),
#  ('(ees14)per_v1_20121a', '(manifesto)per201_2'),
#  ('(ees14)per_v1_20122a', '(manifesto)per201_2'),
#  ('(ees14)per_v1_202b', '(manifesto)per202_2'),
#  ('(ees14)per_v1_202a', '(manifesto)per202_1'),
#  ('(ees14)per_v1_203b', '(manifesto)per204'),
#  ('(ees14)per_v1_203a', '(manifesto)per203'),
#  ('(ees14)per_v1_301b', '(manifesto)per302'),
#  ('(ees14)per_v1_301a', '(manifesto)per301'),
#  ('(ees14)per_v1_3011b', '(manifesto)per110'),
#  ('(ees14)per_v1_3011a', '(manifesto)per108'),
#  ('(ees14)per_v1_303a', '(manifesto)per303'),
#  ('(ees14)per_v1_304a', '(manifesto)per304'),
#  ('(ees14)per_v1_305a', '(manifesto)per305_3'),
#  ('(ees14)per_v1_306b', '(manifesto)per110'),
#  ('(ees14)per_v1_306a', '(manifesto)per108'),
#  ('(ees14)per_v1_308b', '(manifesto)per110'),
#  ('(ees14)per_v1_308a', '(manifesto)per108'),
#  ('(ees14)per_v1_310b', '(manifesto)per110'),
#  ('(ees14)per_v1_310a', '(manifesto)per108'),
#  ('(ees14)per_v1_314b', '(manifesto)per110'),
#  ('(ees14)per_v1_314a', '(manifesto)per108'),
#  ('(ees14)per_v1_316b', '(manifesto)per110'),
#  ('(ees14)per_v1_316a', '(manifesto)per108'),
#  ('(ees14)per_v1_3161b', '(manifesto)per110'),
#  ('(ees14)per_v1_3161a', '(manifesto)per108'),
#  ('(ees14)per_v1_3162b', '(manifesto)per110'),
#  ('(ees14)per_v1_3162a', '(manifesto)per108'),
#  ('(ees14)per_v1_3163b', '(manifesto)per110'),
#  ('(ees14)per_v1_3163a', '(manifesto)per108'),
#  ('(ees14)per_v1_401a', '(manifesto)per401'),
#  ('(ees14)per_v1_4012a', '(manifesto)per401'),
#  ('(ees14)per_v1_402a', '(manifesto)per402'),
#  ('(ees14)per_v1_403a', '(manifesto)per403'),
#  ('(ees14)per_v1_404a', '(manifesto)per404'),
#  ('(ees14)per_v1_405a', '(manifesto)per405'),
#  ('(ees14)per_v1_406b', '(manifesto)per407'),
#  ('(ees14)per_v1_406a', '(manifesto)per406'),
#  ('(ees14)per_v1_408a', '(manifesto)per408'),
#  ('(ees14)per_v1_4081a', '(manifesto)per701'),
#  ('(ees14)per_v1_4082a', '(manifesto)per408'),
#  ('(ees14)per_v1_40821a', '(manifesto)per408'),
#  ('(ees14)per_v1_40822a', '(manifesto)per408'),
#  ('(ees14)per_v1_40823a', '(manifesto)per408'),
#  ('(ees14)per_v1_4084a', '(manifesto)per407'),
#  ('(ees14)per_v1_4088a', '(manifesto)per411'),
#  ('(ees14)per_v1_409a', '(manifesto)per409'),
#  ('(ees14)per_v1_410a', '(manifesto)per410'),
#  ('(ees14)per_v1_411a', '(manifesto)per411 '),
#  ('(ees14)per_v1_412a', '(manifesto)per412'),
#  ('(ees14)per_v1_4121a', '(manifesto)per412'),
#  ('(ees14)per_v1_4123a', '(manifesto)per413'),
#  ('(ees14)per_v1_4124a', '(manifesto)per412'),
#  ('(ees14)per_v1_413a', '(manifesto)per413'),
#  ('(ees14)per_v1_4132b', '(manifesto)per413'),
#  ('(ees14)per_v1_414a', '(manifesto)per414'),
#  ('(ees14)per_v1_415a', '(manifesto)per415 '),
#  ('(ees14)per_v1_416a', '(manifesto)per416_1'),
#  ('(ees14)per_v1_501a', '(manifesto)per501'),
#  ('(ees14)per_v1_5011a', '(manifesto)per501'),
#  ('(ees14)per_v1_5012a', '(manifesto)per501'),
#  ('(ees14)per_v1_5013a', '(manifesto)per501'),
#  ('(ees14)per_v1_502a', '(manifesto)per502'),
#  ('(ees14)per_v1_503a', '(manifesto)per503'),
#  ('(ees14)per_v1_504b', '(manifesto)per505'),
#  ('(ees14)per_v1_504a', '(manifesto)per504'),
#  ('(ees14)per_v1_5041a', '(manifesto)per701'),
#  ('(ees14)per_v1_5042a', '(manifesto)per701'),
#  ('(ees14)per_v1_5043b', '(manifesto)per505'),
#  ('(ees14)per_v1_5043a', '(manifesto)per504'),
#  ('(ees14)per_v1_5044b', '(manifesto)per505'),
#  ('(ees14)per_v1_5044a', '(manifesto)per504'),
#  ('(ees14)per_v1_5045b', '(manifesto)per505'),
#  ('(ees14)per_v1_5045a', '(manifesto)per504'),
#  ('(ees14)per_v1_506b', '(manifesto)per507'),
#  ('(ees14)per_v1_506a', '(manifesto)per506'),
#  ('(ees14)per_v1_601b', '(manifesto)per602_1'),
#  ('(ees14)per_v1_601a', '(manifesto)per601_1'),
#  ('(ees14)per_v1_6011b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_6011a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_60111b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_60111a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_60112b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_60112a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_60113b', '(manifesto)per601_2'),
#  ('(ees14)per_v1_60113a', '(manifesto)per602_2'),
#  ('(ees14)per_v1_6021b', '(manifesto)per110'),
#  ('(ees14)per_v1_6021a', '(manifesto)per108'),
#  ('(ees14)per_v1_603b', '(manifesto)per604'),
#  ('(ees14)per_v1_603a', '(manifesto)per603'),
#  ('(ees14)per_v1_605b', '(manifesto)per605_2'),
#  ('(ees14)per_v1_605a', '(manifesto)per605_1'),
#  ('(ees14)per_v1_6051b', '(manifesto)per605_2'),
#  ('(ees14)per_v1_6051a', '(manifesto)per605_1'),
#  ('(ees14)per_v1_606a', '(manifesto)per606'),
#  ('(ees14)per_v1_607b', '(manifesto)per608_1'),
#  ('(ees14)per_v1_607a', '(manifesto)per607_1'),
#  ('(ees14)per_v1_701b', '(manifesto)per702'),
#  ('(ees14)per_v1_701a', '(manifesto)per701'),
#  ('(ees14)per_v1_7031b', '(manifesto)per703_2'),
#  ('(ees14)per_v1_7031a', '(manifesto)per703_1'),
#  ('(ees14)per_v1_704a', '(manifesto)per704'),
#  ('(ees14)per_v1_705a', '(manifesto)per705'),
#  ('(ees14)per_v1_7051a', '(manifesto)per705'),
#  ('(ees14)per_v1_7052a', '(manifesto)per705'),
#  ('(ees14)per_v1_7053a', '(manifesto)per705'),
#  ('(ees14)per_v1_70531a', '(manifesto)per705'),
#  ('(ees14)per_v1_70532a', '(manifesto)per705'),
#  ('(ees14)per_v1_70533a', '(manifesto)per705'),
#  ('(ees14)per_v1_7054a', '(manifesto)per705'),
#  ('(ees14)per_v1_706a', '(manifesto)per706'),
#  ('(ees14)per_v1_7061a', '(manifesto)per706'),
#  ('(ees14)per_v1_7062a', '(manifesto)per706'),
#  ('(ees14)per_v1_7063a', '(manifesto)per706'),
#  ('(ees14)per_v1_7064a', '(manifesto)per706'),
#  ('(ees14)per_v2_101b', '(manifesto)per102'),
#  ('(ees14)per_v2_101a', '(manifesto)per101'),
#  ('(ees14)per_v2_1011b', '(manifesto)per102'),
#  ('(ees14)per_v2_1011a', '(manifesto)per101'),
#  ('(ees14)per_v2_10111b', '(manifesto)per102'),
#  ('(ees14)per_v2_10111a', '(manifesto)per101'),
#  ('(ees14)per_v2_10112b', '(manifesto)per102'),
#  ('(ees14)per_v2_10112a', '(manifesto)per101'),
#  ('(ees14)per_v2_1012b', '(manifesto)per102'),
#  ('(ees14)per_v2_1012a', '(manifesto)per101'),
#  ('(ees14)per_v2_1013b', '(manifesto)per102'),
#  ('(ees14)per_v2_1013a', '(manifesto)per101'),
#  ('(ees14)per_v2_1014b', '(manifesto)per102'),
#  ('(ees14)per_v2_1014a', '(manifesto)per101'),
#  ('(ees14)per_v2_1015b', '(manifesto)per102'),
#  ('(ees14)per_v2_1015a', '(manifesto)per101'),
#  ('(ees14)per_v2_103a', '(manifesto)per103_1'),
#  ('(ees14)per_v2_104b', '(manifesto)per105'),
#  ('(ees14)per_v2_104a', '(manifesto)per104'),
#  ('(ees14)per_v2_1041b', '(manifesto)per105'),
#  ('(ees14)per_v2_1041a', '(manifesto)per104'),
#  ('(ees14)per_v2_1042b', '(manifesto)per105'),
#  ('(ees14)per_v2_1042a', '(manifesto)per104'),
#  ('(ees14)per_v2_1043b', '(manifesto)per105'),
#  ('(ees14)per_v2_1043a', '(manifesto)per104'),
#  ('(ees14)per_v2_106a', '(manifesto)per106'),
#  ('(ees14)per_v2_1061a', '(manifesto)per106'),
#  ('(ees14)per_v2_1062a', '(manifesto)per106'),
#  ('(ees14)per_v2_1063a', '(manifesto)per106'),
#  ('(ees14)per_v2_107b', '(manifesto)per109'),
#  ('(ees14)per_v2_107a', '(manifesto)per107'),
#  ('(ees14)per_v2_108b', '(manifesto)per110'),
#  ('(ees14)per_v2_108a', '(manifesto)per108'),
#  ('(ees14)per_v2_1081b', '(manifesto)per110'),
#  ('(ees14)per_v2_1081a', '(manifesto)per108'),
#  ('(ees14)per_v2_1082b', '(manifesto)per108'),
#  ('(ees14)per_v2_1082a', '(manifesto)per110'),
#  ('(ees14)per_v2_2011a', '(manifesto)per201_1'),
#  ('(ees14)per_v2_2012a', '(manifesto)per201_2'),
#  ('(ees14)per_v2_20121a', '(manifesto)per201_2'),
#  ('(ees14)per_v2_20122a', '(manifesto)per201_2'),
#  ('(ees14)per_v2_202b', '(manifesto)per202_2'),
#  ('(ees14)per_v2_202a', '(manifesto)per202_1'),
#  ('(ees14)per_v2_203b', '(manifesto)per204'),
#  ('(ees14)per_v2_203a', '(manifesto)per203'),
#  ('(ees14)per_v2_301b', '(manifesto)per302'),
#  ('(ees14)per_v2_301a', '(manifesto)per301'),
#  ('(ees14)per_v2_3011b', '(manifesto)per110'),
#  ('(ees14)per_v2_3011a', '(manifesto)per108'),
#  ('(ees14)per_v2_303a', '(manifesto)per303'),
#  ('(ees14)per_v2_304a', '(manifesto)per304'),
#  ('(ees14)per_v2_305a', '(manifesto)per305_3'),
#  ('(ees14)per_v2_306b', '(manifesto)per110'),
#  ('(ees14)per_v2_306a', '(manifesto)per108'),
#  ('(ees14)per_v2_308b', '(manifesto)per110'),
#  ('(ees14)per_v2_308a', '(manifesto)per108'),
#  ('(ees14)per_v2_310b', '(manifesto)per110'),
#  ('(ees14)per_v2_310a', '(manifesto)per108'),
#  ('(ees14)per_v2_314b', '(manifesto)per110'),
#  ('(ees14)per_v2_314a', '(manifesto)per108'),
#  ('(ees14)per_v2_316b', '(manifesto)per110'),
#  ('(ees14)per_v2_316a', '(manifesto)per108'),
#  ('(ees14)per_v2_3161b', '(manifesto)per110'),
#  ('(ees14)per_v2_3161a', '(manifesto)per108'),
#  ('(ees14)per_v2_3162b', '(manifesto)per110'),
#  ('(ees14)per_v2_3162a', '(manifesto)per108'),
#  ('(ees14)per_v2_3163b', '(manifesto)per110'),
#  ('(ees14)per_v2_3163a', '(manifesto)per108'),
#  ('(ees14)per_v2_401a', '(manifesto)per401'),
#  ('(ees14)per_v2_4012a', '(manifesto)per401'),
#  ('(ees14)per_v2_402a', '(manifesto)per402'),
#  ('(ees14)per_v2_403a', '(manifesto)per403'),
#  ('(ees14)per_v2_404a', '(manifesto)per404'),
#  ('(ees14)per_v2_405a', '(manifesto)per405'),
#  ('(ees14)per_v2_406b', '(manifesto)per407'),
#  ('(ees14)per_v2_406a', '(manifesto)per406'),
#  ('(ees14)per_v2_408a', '(manifesto)per408'),
#  ('(ees14)per_v2_4081a', '(manifesto)per701'),
#  ('(ees14)per_v2_4082a', '(manifesto)per408'),
#  ('(ees14)per_v2_40821a', '(manifesto)per408'),
#  ('(ees14)per_v2_40822a', '(manifesto)per408'),
#  ('(ees14)per_v2_40823a', '(manifesto)per408'),
#  ('(ees14)per_v2_4084a', '(manifesto)per407'),
#  ('(ees14)per_v2_4088a', '(manifesto)per411'),
#  ('(ees14)per_v2_409a', '(manifesto)per409'),
#  ('(ees14)per_v2_410a', '(manifesto)per410'),
#  ('(ees14)per_v2_411a', '(manifesto)per411 '),
#  ('(ees14)per_v2_412a', '(manifesto)per412'),
#  ('(ees14)per_v2_4121a', '(manifesto)per412'),
#  ('(ees14)per_v2_4123a', '(manifesto)per413'),
#  ('(ees14)per_v2_4124a', '(manifesto)per412'),
#  ('(ees14)per_v2_413a', '(manifesto)per413'),
#  ('(ees14)per_v2_4132b', '(manifesto)per413'),
#  ('(ees14)per_v2_414a', '(manifesto)per414'),
#  ('(ees14)per_v2_415a', '(manifesto)per415 '),
#  ('(ees14)per_v2_416a', '(manifesto)per416_1'),
#  ('(ees14)per_v2_501a', '(manifesto)per501'),
#  ('(ees14)per_v2_5011a', '(manifesto)per501'),
#  ('(ees14)per_v2_5012a', '(manifesto)per501'),
#  ('(ees14)per_v2_5013a', '(manifesto)per501'),
#  ('(ees14)per_v2_502a', '(manifesto)per502'),
#  ('(ees14)per_v2_503a', '(manifesto)per503'),
#  ('(ees14)per_v2_504b', '(manifesto)per505'),
#  ('(ees14)per_v2_504a', '(manifesto)per504'),
#  ('(ees14)per_v2_5041a', '(manifesto)per701'),
#  ('(ees14)per_v2_5042a', '(manifesto)per701'),
#  ('(ees14)per_v2_5043b', '(manifesto)per505'),
#  ('(ees14)per_v2_5043a', '(manifesto)per504'),
#  ('(ees14)per_v2_5044b', '(manifesto)per505'),
#  ('(ees14)per_v2_5044a', '(manifesto)per504'),
#  ('(ees14)per_v2_5045b', '(manifesto)per505'),
#  ('(ees14)per_v2_5045a', '(manifesto)per504'),
#  ('(ees14)per_v2_506b', '(manifesto)per507'),
#  ('(ees14)per_v2_506a', '(manifesto)per506'),
#  ('(ees14)per_v2_601b', '(manifesto)per602_1'),
#  ('(ees14)per_v2_601a', '(manifesto)per601_1'),
#  ('(ees14)per_v2_6011b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_6011a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_60111b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_60111a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_60112b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_60112a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_60113b', '(manifesto)per601_2'),
#  ('(ees14)per_v2_60113a', '(manifesto)per602_2'),
#  ('(ees14)per_v2_6021b', '(manifesto)per110'),
#  ('(ees14)per_v2_6021a', '(manifesto)per108'),
#  ('(ees14)per_v2_603b', '(manifesto)per604'),
#  ('(ees14)per_v2_603a', '(manifesto)per603'),
#  ('(ees14)per_v2_605b', '(manifesto)per605_2'),
#  ('(ees14)per_v2_605a', '(manifesto)per605_1'),
#  ('(ees14)per_v2_6051b', '(manifesto)per605_2'),
#  ('(ees14)per_v2_6051a', '(manifesto)per605_1'),
#  ('(ees14)per_v2_606a', '(manifesto)per606'),
#  ('(ees14)per_v2_607b', '(manifesto)per608_1'),
#  ('(ees14)per_v2_607a', '(manifesto)per607_1'),
#  ('(ees14)per_v2_701b', '(manifesto)per702'),
#  ('(ees14)per_v2_701a', '(manifesto)per701'),
#  ('(ees14)per_v2_7031b', '(manifesto)per703_2'),
#  ('(ees14)per_v2_7031a', '(manifesto)per703_1'),
#  ('(ees14)per_v2_704a', '(manifesto)per704'),
#  ('(ees14)per_v2_705a', '(manifesto)per705'),
#  ('(ees14)per_v2_7051a', '(manifesto)per705'),
#  ('(ees14)per_v2_7052a', '(manifesto)per705'),
#  ('(ees14)per_v2_7053a', '(manifesto)per705'),
#  ('(ees14)per_v2_70531a', '(manifesto)per705'),
#  ('(ees14)per_v2_70532a', '(manifesto)per705'),
#  ('(ees14)per_v2_70533a', '(manifesto)per705'),
#  ('(ees14)per_v2_7054a', '(manifesto)per705'),
#  ('(ees14)per_v2_706a', '(manifesto)per706'),
#  ('(ees14)per_v2_7061a', '(manifesto)per706'),
#  ('(ees14)per_v2_7062a', '(manifesto)per706'),
#  ('(ees14)per_v2_7063a', '(manifesto)per706'),
#  ('(ees14)per_v2_7064a', '(manifesto)per706'),
#  ('(ees14)per_v3_101b', '(manifesto)per102'),
#  ('(ees14)per_v3_101a', '(manifesto)per101'),
#  ('(ees14)per_v3_1011b', '(manifesto)per102'),
#  ('(ees14)per_v3_1011a', '(manifesto)per101'),
#  ('(ees14)per_v3_10111b', '(manifesto)per102'),
#  ('(ees14)per_v3_10111a', '(manifesto)per101'),
#  ('(ees14)per_v3_10112b', '(manifesto)per102'),
#  ('(ees14)per_v3_10112a', '(manifesto)per101'),
#  ('(ees14)per_v3_1012b', '(manifesto)per102'),
#  ('(ees14)per_v3_1012a', '(manifesto)per101'),
#  ('(ees14)per_v3_1013b', '(manifesto)per102'),
#  ('(ees14)per_v3_1013a', '(manifesto)per101'),
#  ('(ees14)per_v3_1014b', '(manifesto)per102'),
#  ('(ees14)per_v3_1014a', '(manifesto)per101'),
#  ('(ees14)per_v3_1015b', '(manifesto)per102'),
#  ('(ees14)per_v3_1015a', '(manifesto)per101'),
#  ('(ees14)per_v3_103a', '(manifesto)per103_1'),
#  ('(ees14)per_v3_104b', '(manifesto)per105'),
#  ('(ees14)per_v3_104a', '(manifesto)per104'),
#  ('(ees14)per_v3_1041b', '(manifesto)per105'),
#  ('(ees14)per_v3_1041a', '(manifesto)per104'),
#  ('(ees14)per_v3_1042b', '(manifesto)per105'),
#  ('(ees14)per_v3_1042a', '(manifesto)per104'),
#  ('(ees14)per_v3_1043b', '(manifesto)per105'),
#  ('(ees14)per_v3_1043a', '(manifesto)per104'),
#  ('(ees14)per_v3_106a', '(manifesto)per106'),
#  ('(ees14)per_v3_1061a', '(manifesto)per106'),
#  ('(ees14)per_v3_1062a', '(manifesto)per106'),
#  ('(ees14)per_v3_1063a', '(manifesto)per106'),
#  ('(ees14)per_v3_107b', '(manifesto)per109'),
#  ('(ees14)per_v3_107a', '(manifesto)per107'),
#  ('(ees14)per_v3_108b', '(manifesto)per110'),
#  ('(ees14)per_v3_108a', '(manifesto)per108'),
#  ('(ees14)per_v3_1081b', '(manifesto)per110'),
#  ('(ees14)per_v3_1081a', '(manifesto)per108'),
#  ('(ees14)per_v3_1082b', '(manifesto)per108'),
#  ('(ees14)per_v3_1082a', '(manifesto)per110'),
#  ('(ees14)per_v3_2011a', '(manifesto)per201_1'),
#  ('(ees14)per_v3_2012a', '(manifesto)per201_2'),
#  ('(ees14)per_v3_20121a', '(manifesto)per201_2'),
#  ('(ees14)per_v3_20122a', '(manifesto)per201_2'),
#  ('(ees14)per_v3_202b', '(manifesto)per202_2'),
#  ('(ees14)per_v3_202a', '(manifesto)per202_1'),
#  ('(ees14)per_v3_203b', '(manifesto)per204'),
#  ('(ees14)per_v3_203a', '(manifesto)per203'),
#  ('(ees14)per_v3_301b', '(manifesto)per302'),
#  ('(ees14)per_v3_301a', '(manifesto)per301'),
#  ('(ees14)per_v3_3011b', '(manifesto)per110'),
#  ('(ees14)per_v3_3011a', '(manifesto)per108'),
#  ('(ees14)per_v3_303a', '(manifesto)per303'),
#  ('(ees14)per_v3_304a', '(manifesto)per304'),
#  ('(ees14)per_v3_305a', '(manifesto)per305_3'),
#  ('(ees14)per_v3_306b', '(manifesto)per110'),
#  ('(ees14)per_v3_306a', '(manifesto)per108'),
#  ('(ees14)per_v3_308b', '(manifesto)per110'),
#  ('(ees14)per_v3_308a', '(manifesto)per108'),
#  ('(ees14)per_v3_310b', '(manifesto)per110'),
#  ('(ees14)per_v3_310a', '(manifesto)per108'),
#  ('(ees14)per_v3_314b', '(manifesto)per110'),
#  ('(ees14)per_v3_314a', '(manifesto)per108'),
#  ('(ees14)per_v3_316b', '(manifesto)per110'),
#  ('(ees14)per_v3_316a', '(manifesto)per108'),
#  ('(ees14)per_v3_3161b', '(manifesto)per110'),
#  ('(ees14)per_v3_3161a', '(manifesto)per108'),
#  ('(ees14)per_v3_3162b', '(manifesto)per110'),
#  ('(ees14)per_v3_3162a', '(manifesto)per108'),
#  ('(ees14)per_v3_3163b', '(manifesto)per110'),
#  ('(ees14)per_v3_3163a', '(manifesto)per108'),
#  ('(ees14)per_v3_401a', '(manifesto)per401'),
#  ('(ees14)per_v3_4012a', '(manifesto)per401'),
#  ('(ees14)per_v3_402a', '(manifesto)per402'),
#  ('(ees14)per_v3_403a', '(manifesto)per403'),
#  ('(ees14)per_v3_404a', '(manifesto)per404'),
#  ('(ees14)per_v3_405a', '(manifesto)per405'),
#  ('(ees14)per_v3_406b', '(manifesto)per407'),
#  ('(ees14)per_v3_406a', '(manifesto)per406'),
#  ('(ees14)per_v3_408a', '(manifesto)per408'),
#  ('(ees14)per_v3_4081a', '(manifesto)per701'),
#  ('(ees14)per_v3_4082a', '(manifesto)per408'),
#  ('(ees14)per_v3_40821a', '(manifesto)per408'),
#  ('(ees14)per_v3_40822a', '(manifesto)per408'),
#  ('(ees14)per_v3_40823a', '(manifesto)per408'),
#  ('(ees14)per_v3_4084a', '(manifesto)per407'),
#  ('(ees14)per_v3_4088a', '(manifesto)per411'),
#  ('(ees14)per_v3_409a', '(manifesto)per409'),
#  ('(ees14)per_v3_410a', '(manifesto)per410'),
#  ('(ees14)per_v3_411a', '(manifesto)per411 '),
#  ('(ees14)per_v3_412a', '(manifesto)per412'),
#  ('(ees14)per_v3_4121a', '(manifesto)per412'),
#  ('(ees14)per_v3_4123a', '(manifesto)per413'),
#  ('(ees14)per_v3_4124a', '(manifesto)per412'),
#  ('(ees14)per_v3_413a', '(manifesto)per413'),
#  ('(ees14)per_v3_4132b', '(manifesto)per413'),
#  ('(ees14)per_v3_414a', '(manifesto)per414'),
#  ('(ees14)per_v3_415a', '(manifesto)per415 '),
#  ('(ees14)per_v3_416a', '(manifesto)per416_1'),
#  ('(ees14)per_v3_501a', '(manifesto)per501'),
#  ('(ees14)per_v3_5011a', '(manifesto)per501'),
#  ('(ees14)per_v3_5012a', '(manifesto)per501'),
#  ('(ees14)per_v3_5013a', '(manifesto)per501'),
#  ('(ees14)per_v3_502a', '(manifesto)per502'),
#  ('(ees14)per_v3_503a', '(manifesto)per503'),
#  ('(ees14)per_v3_504b', '(manifesto)per505'),
#  ('(ees14)per_v3_504a', '(manifesto)per504'),
#  ('(ees14)per_v3_5041a', '(manifesto)per701'),
#  ('(ees14)per_v3_5042a', '(manifesto)per701'),
#  ('(ees14)per_v3_5043b', '(manifesto)per505'),
#  ('(ees14)per_v3_5043a', '(manifesto)per504'),
#  ('(ees14)per_v3_5044b', '(manifesto)per505'),
#  ('(ees14)per_v3_5044a', '(manifesto)per504'),
#  ('(ees14)per_v3_5045b', '(manifesto)per505'),
#  ('(ees14)per_v3_5045a', '(manifesto)per504'),
#  ('(ees14)per_v3_506b', '(manifesto)per507'),
#  ('(ees14)per_v3_506a', '(manifesto)per506'),
#  ('(ees14)per_v3_601b', '(manifesto)per602_1'),
#  ('(ees14)per_v3_601a', '(manifesto)per601_1'),
#  ('(ees14)per_v3_6011b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_6011a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_60111b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_60111a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_60112b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_60112a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_60113b', '(manifesto)per601_2'),
#  ('(ees14)per_v3_60113a', '(manifesto)per602_2'),
#  ('(ees14)per_v3_6021b', '(manifesto)per110'),
#  ('(ees14)per_v3_6021a', '(manifesto)per108'),
#  ('(ees14)per_v3_603b', '(manifesto)per604'),
#  ('(ees14)per_v3_603a', '(manifesto)per603'),
#  ('(ees14)per_v3_605b', '(manifesto)per605_2'),
#  ('(ees14)per_v3_605a', '(manifesto)per605_1'),
#  ('(ees14)per_v3_6051b', '(manifesto)per605_2'),
#  ('(ees14)per_v3_6051a', '(manifesto)per605_1'),
#  ('(ees14)per_v3_606a', '(manifesto)per606'),
#  ('(ees14)per_v3_607b', '(manifesto)per608_1'),
#  ('(ees14)per_v3_607a', '(manifesto)per607_1'),
#  ('(ees14)per_v3_701b', '(manifesto)per702'),
#  ('(ees14)per_v3_701a', '(manifesto)per701'),
#  ('(ees14)per_v3_7031b', '(manifesto)per703_2'),
#  ('(ees14)per_v3_7031a', '(manifesto)per703_1'),
#  ('(ees14)per_v3_704a', '(manifesto)per704'),
#  ('(ees14)per_v3_705a', '(manifesto)per705'),
#  ('(ees14)per_v3_7051a', '(manifesto)per705'),
#  ('(ees14)per_v3_7052a', '(manifesto)per705'),
#  ('(ees14)per_v3_7053a', '(manifesto)per705'),
#  ('(ees14)per_v3_70531a', '(manifesto)per705'),
#  ('(ees14)per_v3_70532a', '(manifesto)per705'),
#  ('(ees14)per_v3_70533a', '(manifesto)per705'),
#  ('(ees14)per_v3_7054a', '(manifesto)per705'),
#  ('(ees14)per_v3_706a', '(manifesto)per706'),
#  ('(ees14)per_v3_7061a', '(manifesto)per706'),
#  ('(ees14)per_v3_7062a', '(manifesto)per706'),
#  ('(ees14)per_v3_7063a', '(manifesto)per706'),
#  ('(ees14)per_v3_7064a', '(manifesto)per706')]

# %%
df_corrs_ni_nm_ind = df_corrs_ni_nm.set_index(["Row","Column"])

emp_to_cmp_maps = [x for x in emp_to_cmp_maps if x in list(df_corrs_ni_nm_ind.index)]


# emp_to_cmp_df = df_corrs_ni_nm.set_index(["Row","Column"]).loc[emp_to_cmp_maps]
# emp_to_cmp_df



# .loc[[("(ches)vote","(manifesto)pervote"),
#                                           ("(ches)vote","(manifesto)pervote"),
#                                           ('(manifesto)per102','(ees14)per_v1_101b', )]]

# df_corrs_ni_nm.set_index(["Row","Column"]).index.values

# %%
emp_to_cmp_df = df_corrs_ni_nm.set_index(["Row","Column"]).loc[emp_to_cmp_maps]
emp_to_cmp_df
# Out:
#                                            Value  NZ    N     Row_ds Col_ds
# Row               Column
# (manifesto)per102 (ees14)per_v1_101b    0.136782  20  226  manifesto  ees14
# (manifesto)per101 (ees14)per_v1_101a    0.327090  83  226  manifesto  ees14
# (manifesto)per102 (ees14)per_v1_1011b  -0.031570   1  207  manifesto  ees14
# (manifesto)per101 (ees14)per_v1_1011a   0.017238  16  207  manifesto  ees14
# (manifesto)per102 (ees14)per_v1_10111b -0.002120   1  151  manifesto  ees14
# ...                                          ...  ..  ...        ...    ...
# (manifesto)per706 (ees14)per_v3_706a    0.049410  37  226  manifesto  ees14
#                   (ees14)per_v3_7061a   0.068662  66  226  manifesto  ees14
#                   (ees14)per_v3_7062a   0.115359  29  226  manifesto  ees14
#                   (ees14)per_v3_7063a   0.151174  59  226  manifesto  ees14
#                   (ees14)per_v3_7064a   0.019731   4  178  manifesto  ees14
#
# [426 rows x 5 columns]

# %%
emp_to_cmp_df.sort_values(by='Value').head(50)

# (manifesto)per705	(ees14)per_v3_7051a	-0.104599	24	226	manifesto	ees14
# Underprivileged Minority Groups
# Very general favourable references to underprivileged minorities who
# are defined neither in economic nor in demographic terms (e.g. the
# handicapped, homosexuals, immigrants, indigenous). Only includes
# favourable statements that cannot be classified in other categories
# (e.g. 503, 504, 604, 607 etc.)
# UMG: Handicapped+
# Out:
#                                              Value   NZ    N     Row_ds Col_ds
# Row                 Column
# (manifesto)per108   (ees14)per_v1_1082b  -0.144478    7  151  manifesto  ees14
# (manifesto)per705   (ees14)per_v3_7051a  -0.104599   24  226  manifesto  ees14
# (manifesto)per706   (ees14)per_v1_7063a  -0.103755   92  226  manifesto  ees14
# (manifesto)per705   (ees14)per_v1_7054a  -0.092240   22  207  manifesto  ees14
# (manifesto)per701   (ees14)per_v1_4081a  -0.091280  128  226  manifesto  ees14
# (manifesto)per201_1 (ees14)per_v1_2011a  -0.089523   41  150  manifesto  ees14
# (manifesto)per305_3 (ees14)per_v2_305a   -0.081742   37  150  manifesto  ees14
# (manifesto)per408   (ees14)per_v3_40823a -0.081729    9  151  manifesto  ees14
# (manifesto)per108   (ees14)per_v3_314a   -0.080537    4  178  manifesto  ees14
# (manifesto)per408   (ees14)per_v1_408a   -0.080256  148  226  manifesto  ees14
# (manifesto)per501   (ees14)per_v1_5011a  -0.080218   82  151  manifesto  ees14
# (manifesto)per108   (ees14)per_v3_310a   -0.074869    1  178  manifesto  ees14
# (manifesto)per705   (ees14)per_v3_70532a -0.069565    4  151  manifesto  ees14
# (manifesto)per108   (ees14)per_v3_316a   -0.068641    6  178  manifesto  ees14
# (manifesto)per305_3 (ees14)per_v3_305a   -0.067723   21  150  manifesto  ees14
# (manifesto)per108   (ees14)per_v1_306a   -0.067200   37  178  manifesto  ees14
# (manifesto)per706   (ees14)per_v2_7064a  -0.066158   25  178  manifesto  ees14
# (manifesto)per108   (ees14)per_v3_1082b  -0.060474    1  151  manifesto  ees14
# (manifesto)per101   (ees14)per_v1_1012a  -0.059875   25  207  manifesto  ees14
# (manifesto)per602_2 (ees14)per_v1_60112a -0.059175    1  127  manifesto  ees14
# (manifesto)per106   (ees14)per_v3_1063a  -0.058778    3  151  manifesto  ees14
# (manifesto)per408   (ees14)per_v3_408a   -0.058086  106  226  manifesto  ees14
# (manifesto)per706   (ees14)per_v1_7062a  -0.056525   60  226  manifesto  ees14
# (manifesto)per108   (ees14)per_v2_1082b  -0.054536    9  151  manifesto  ees14
# (manifesto)per101   (ees14)per_v3_10111a -0.053942    3  151  manifesto  ees14
# (manifesto)per408   (ees14)per_v2_408a   -0.053688  177  226  manifesto  ees14
# (manifesto)per108   (ees14)per_v3_308a   -0.053389    2  178  manifesto  ees14
# (manifesto)per101   (ees14)per_v2_10111a -0.051551   25  151  manifesto  ees14
# (manifesto)per108   (ees14)per_v1_314a   -0.050771   14  178  manifesto  ees14
# (manifesto)per408   (ees14)per_v3_4082a  -0.050654   18  226  manifesto  ees14
# (manifesto)per204   (ees14)per_v3_203b   -0.049768    5  226  manifesto  ees14
# (manifesto)per602_2 (ees14)per_v2_60111a -0.048992    6  127  manifesto  ees14
# (manifesto)per202_1 (ees14)per_v3_202a   -0.043622  107  150  manifesto  ees14
# (manifesto)per101   (ees14)per_v1_10112a -0.043585    4  151  manifesto  ees14
# (manifesto)per110   (ees14)per_v1_6021b  -0.043506    9  178  manifesto  ees14
# (manifesto)per202_2 (ees14)per_v1_202b   -0.042274    0  138  manifesto  ees14
# (manifesto)per202_1 (ees14)per_v1_202a   -0.042147  110  150  manifesto  ees14
# (manifesto)per605_2 (ees14)per_v3_6051b  -0.041918    3  138  manifesto  ees14
# (manifesto)per412   (ees14)per_v1_4124a  -0.041862    6  207  manifesto  ees14
# (manifesto)per101   (ees14)per_v2_1015a  -0.041526    2  151  manifesto  ees14
# (manifesto)per705   (ees14)per_v3_705a   -0.040222   30  226  manifesto  ees14
# (manifesto)per505   (ees14)per_v1_5044b  -0.040178    2  226  manifesto  ees14
# (manifesto)per102   (ees14)per_v2_1012b  -0.039905    9  207  manifesto  ees14
# (manifesto)per505   (ees14)per_v2_5043b  -0.039600   15  226  manifesto  ees14
# (manifesto)per702   (ees14)per_v3_701b   -0.039541    1  226  manifesto  ees14
# (manifesto)per110   (ees14)per_v2_3163b  -0.036834    4  178  manifesto  ees14
# (manifesto)per505   (ees14)per_v2_5045b  -0.035455    2  226  manifesto  ees14
# (manifesto)per706   (ees14)per_v1_706a   -0.035348   40  226  manifesto  ees14
# (manifesto)per602_1 (ees14)per_v2_601b   -0.035331   14  150  manifesto  ees14
# (manifesto)per702   (ees14)per_v2_701b   -0.034869   10  226  manifesto  ees14

# %%
# (manifesto)per701	(ees14)per_v1_4081a	-0.091280	128	226	manifesto	ees14
# (manifesto)per701: Labour Groups Positive
# (ees14)per_v1_4081a: Creating Jobs (Positive) - National Level


# (manifesto)per408	(ees14)per_v1_408a	-0.080256	148	226	manifesto	ees14
# per408: Economic Goals (unspecified in any other category)
# per_v1_408a: Economic Goals: General - National Level

# (manifesto)per408	(ees14)per_v2_408a	-0.053688	177	226	manifesto	ees14
# per408: Economic Goals (unspecified in any other category)
# per_v1_408a: Economic Goals: General - European Level

# (manifesto)per202_1	(ees14)per_v1_202a	-0.042147	110	150	manifesto	ees14
# (manifesto)per202_1:Democracy General: Positive
# (ees14)per_v1_202a:Democracy+ - National

# %%
euromanifesto['(ees14)per_v3_70531a'].sum()

# df_corrs.set_index(["Row","Column"]).loc['(manifesto)per705', '(ees14)per_v2_70531a']
# Out:
# 0.0

# %%
df_corrs_ni_nm["Row"].apply(lambda x: )
# Out:
#                        Row               Column     Value    NZ     N Row_ds  \
# 183             (ches)vote   (manifesto)pervote  0.926617   317   320   ches
# 184             (ches)vote   (manifesto)absseat  0.644378   314   320   ches
# 185             (ches)vote  (manifesto)totseats -0.093048   322   325   ches
# 186             (ches)vote  (manifesto)peruncod  0.011273   276   325   ches
# 187             (ches)vote    (manifesto)per101  0.026725   213   325   ches
# ...                    ...                  ...       ...   ...   ...    ...
# 589567      (pf)share_year   (pimpo)totals_immi  0.124098    94    94     pf
# 589568      (pf)share_year   (pimpo)totals_inti  0.070380    98    98     pf
# 589569      (pf)share_year     (manifesto)total  0.169961  1033  1033     pf
# 589571       (pimpo)totals     (manifesto)total  0.829728   109   109  pimpo
# 589572  (pimpo)totals_immi     (manifesto)total  0.676948    95    95  pimpo
#
#            Col_ds
# 183     manifesto
# 184     manifesto
# 185     manifesto
# 186     manifesto
# 187     manifesto
# ...           ...
# 589567      pimpo
# 589568      pimpo
# 589569  manifesto
# 589571  manifesto
# 589572  manifesto
#
# [318756 rows x 7 columns]

# %%
### Errors in assigning family???

manifesto_project[manifesto_project["partyfacts_id"]==461] # liberal???
euromanifesto[euromanifesto["partyfacts_id"]==852] # rad left???
euromanifesto[euromanifesto["partyfacts_id"]==1308] # socialist is pushing it - they were *once* in a coalition *with* a socialist party
euromanifesto[euromanifesto["partyfacts_id"]==1359] # similiarly, everyone pegs these are centre-right, liberal conservatives
# Out:
#      (ees14)za_nr      (ees14)version           (ees14)doi (ees14)partyname  \
# 91         5102.0  2.0.0 (2018-01-02)  doi:10.4232/1.12830  Partido Popular
# 225        5102.0  2.0.0 (2018-01-02)  doi:10.4232/1.12830  Partido Popular
# 356        5102.0  2.0.0 (2018-01-02)  doi:10.4232/1.12830  Partido Popular
# 682        5102.0  2.0.0 (2018-01-02)  doi:10.4232/1.12830  Partido Popular
#
#     (ees14)initials  year  (ees14)EPseats country (ees14)country_sub_region  \
# 91               PP  1987             4.0     prt                       NaN
# 225              PP  1994             3.0     prt                       NaN
# 356              PP  1999             2.0     prt                       NaN
# 682              PP  2009             2.0     prt                       NaN
#
#     (ees14)country_year  ... (ees14)mfamily__cons (ees14)mfamily__green  \
# 91                35_87  ...                  0.0                   0.0
# 225               35_94  ...                  0.0                   0.0
# 356               35_99  ...                  0.0                   0.0
# 682               35_09  ...                  0.0                   0.0
#
#     (ees14)mfamily__liberal  (ees14)mfamily__rad left  \
# 91                      0.0                       0.0
# 225                     0.0                       0.0
# 356                     0.0                       0.0
# 682                     0.0                       0.0
#
#      (ees14)mfamily__rad right  (ees14)mfamily__regional  \
# 91                         0.0                       0.0
# 225                        0.0                       0.0
# 356                        0.0                       0.0
# 682                        0.0                       0.0
#
#      (ees14)mfamily__socialist (ees14)mfamily__special issue dataset  \
# 91                         1.0                           0.0   ees14
# 225                        1.0                           0.0   ees14
# 356                        1.0                           0.0   ees14
# 682                        1.0                           0.0   ees14
#
#     dataset_index
# 91             91
# 225           225
# 356           356
# 682           682
#
# [4 rows x 805 columns]

# %%
# df_merged["(ches)mip_one__social lifestyle"].value_counts(dropna=False)
# df_merged["(emp)per_v3_6021b"].value_counts(dropna=False)
CHES_comb[CHES_comb["(ches)enlarge"].notnull()]["(ches)source"].value_counts()
# Out:
# 2002_CHES_dataset_means.dta    73
# Name: (ches)source, dtype: int64

# %%
# (cmp)per1022	(emp)per_v1_409b	0.995901	178	cmp	emp
# (per1022)Western States: Negative
# Negative mentions of Western states, including the USA and Germany.
# (per_v1_409b) Keynesian Demand Management (negative, national-level)

# Spurious correlation because of sparse datasets?
# (ches)mip_one__social lifestyle
# (per_v3_6021b)EU Integration (negative, unspecified level)

# %%
# Comforting

# 182063	(cmp)party	(pip)Party code according to CMP	1.000000	555	cmp	pip
# 328913	(emp)marpor	(parlgov)cmp	1.000000	165	emp	parlgov
# 182097	(cmp)party	(emp)marpor	1.000000	205	cmp	emp
# 304166	(pip)Party code according to CMP	(emp)marpor	1.000000	195	pip	emp
# 572049	(pimpo)party	(parlgov)cmp	1.000000	83	pimpo	parlgov
# 328897	(emp)marpor	(pimpo)party	1.000000	58	emp	pimpo
# 182764	(cmp)party	(pimpo)party	1.000000	109	cmp	pimpo
# 304831	(pip)Party code according to CMP	(pimpo)party	1.000000	108	pip	pimpo

# %%
# df["per_v1_4012a"].sum()

# %%
# df["per_v2_4012a"].sum()

# %%
# df["per_v3_4012a"].sum()

# %%
mapping_dictionary

# %%
{k:v for (k,v) in mapping_dictionary.items() if v=="per101"}

# %%
[x for x in df.columns if "per102" in x]

# %%
df_corrs[df_corrs["Row"]=="per607_1"].sort_values(by="Value").tail(50)

# %%
# per607_1	per_v2_3141a	0.716565	150

# multiculturalism positive <-> pos mentions about European Central Bank???
print(df["per607_1"].notnull().sum())
df["per607_1"].value_counts()

# %%
df["per_v2_3141a"].notnull().sum()
# 977 instances
df["per_v2_3141a"].value_counts()
# 803 are zero

# %%
df_merged["per607_1"].value_counts()
# 392 party notnull values
# 170 0s

# %%
mapping_dictionary

# %%
grouped_by_party = df.groupby("partyfacts_id").mean()

# %%
grouped_by_party.notnull().sum().sort_values().tail(50)

# %%
df["per_v1_101a"].notnull().sum()

# %%
df.dtypes.value_counts()

# %%
df.select_dtypes('object')

# %%
euromanifesto.dtypes.value_counts()

# %%
euromanifesto.select_dtypes('category')

# %%
euromanifesto.select_dtypes('float64')

# %%
partyfacts_core_parties

# %%
partyfacts_core_parties

# %%
df_merged.dtypes.value_counts()

# %%
df_merged.select_dtypes('object').dropna(how='all')

# %%
df["country"].value_counts()

# %%
df_merged#["country"].describe()

# 1924 - 2019, 768 countries, 1258 parties

# %%
manifesto_project[(manifesto_project["country"]=="gbr")&(manifesto_project["(cmp)party"]==51320)]

# %%
51620,51420

manifesto_project[(manifesto_project["country"]=="cze")&(manifesto_project["(cmp)party"]==82320)]
                 #].sort_values(by="(cmp)pervote").tail(20)
#

# %%
# C:\Users\Marios\Documents\GitHub\Thomas Prosser project\datasets\Party Level
df_corrs_ni_nm.to_pickle(dataset_folder+"Party Level"+os.sep+ "df_corrs_ni_nm.zip",compression='zip')
df.to_pickle(dataset_folder+"Party Level"+os.sep+ "df.zip",compression='zip')
df_merged.to_pickle(dataset_folder+"Party Level"+os.sep+ "df_merged.zip",compression='zip')

# %%
df.shape,df_merged.shape
# Out:
# ((11819, 1214), (1258, 1180))

# %%
df.dtypes.value_counts()
# Out:
# float64           1044
# float32            109
# object              58
# datetime64[ns]       3
# dtype: int64

# %%
df.select_dtypes('object')
# Out:
#     (ches)eumember country (ches)party (ches)family  \
# 0              Yes     bel      PCB/KP     rad left
# 1              Yes     bel          PS    socialist
# 2              Yes     bel          SP    socialist
# 3              Yes     bel       ECOLO        green
# 4              Yes     bel      AGALEV        green
# ..             ...     ...         ...          ...
# 237            NaN     nzl         NaN          NaN
# 238            NaN     nzl         NaN          NaN
# 239            NaN     nzl         NaN          NaN
# 240            NaN     nzl         NaN          NaN
# 241            NaN     nzl         NaN          NaN
#
#                     (ches)source (ches)partyname1 (ches)partyname2  \
# 0    1984-1999_dataset_means.dta              NaN              NaN
# 1    1984-1999_dataset_means.dta              NaN              NaN
# 2    1984-1999_dataset_means.dta              NaN              NaN
# 3    1984-1999_dataset_means.dta              NaN              NaN
# 4    1984-1999_dataset_means.dta              NaN              NaN
# ..                           ...              ...              ...
# 237                          NaN              NaN              NaN
# 238                          NaN              NaN              NaN
# 239                          NaN              NaN              NaN
# 240                          NaN              NaN              NaN
# 241                          NaN              NaN              NaN
#
#     (ches)intgroup (ches)epgroup (ches)party_name  ... (emp)mfamily  \
# 0              NaN           NaN              NaN  ...          NaN
# 1              NaN           NaN              NaN  ...          NaN
# 2              NaN           NaN              NaN  ...          NaN
# 3              NaN           NaN              NaN  ...          NaN
# 4              NaN           NaN              NaN  ...          NaN
# ..             ...           ...              ...  ...          ...
# 237            NaN           NaN              NaN  ...          NaN
# 238            NaN           NaN              NaN  ...          NaN
# 239            NaN           NaN              NaN  ...          NaN
# 240            NaN           NaN              NaN  ...          NaN
# 241            NaN           NaN              NaN  ...          NaN
#
#     (emp)ofamily (emp)group (emp)manif (emp)gov (emp)pm (emp)ees_party  \
# 0            NaN        NaN        NaN      NaN     NaN            NaN
# 1            NaN        NaN        NaN      NaN     NaN            NaN
# 2            NaN        NaN        NaN      NaN     NaN            NaN
# 3            NaN        NaN        NaN      NaN     NaN            NaN
# 4            NaN        NaN        NaN      NaN     NaN            NaN
# ..           ...        ...        ...      ...     ...            ...
# 237          NaN        NaN        NaN      NaN     NaN            NaN
# 238          NaN        NaN        NaN      NaN     NaN            NaN
# 239          NaN        NaN        NaN      NaN     NaN            NaN
# 240          NaN        NaN        NaN      NaN     NaN            NaN
# 241          NaN        NaN        NaN      NaN     NaN            NaN
#
#     (emp)emcs_party            (pimpo)partyname (pimpo)countryname
# 0               NaN                         NaN                NaN
# 1               NaN                         NaN                NaN
# 2               NaN                         NaN                NaN
# 3               NaN                         NaN                NaN
# 4               NaN                         NaN                NaN
# ..              ...                         ...                ...
# 237             NaN  New Zealand National Party        New Zealand
# 238             NaN     New Zealand First Party        New Zealand
# 239             NaN                 Māori Party        New Zealand
# 240             NaN                 Māori Party        New Zealand
# 241             NaN                  Mana Party        New Zealand
#
# [11819 rows x 58 columns]

# %%
df_means_prt_yr = df.groupby(["partyfacts_id","year"]).mean()

# parlgov_party
# df_means
# parlgov_party.set_index(["partyfacts_id",:]).shape, df_means.shape
# ((1651, 27), (1248, 1135))
# pd.Series(df_means.append( parlgov_party.set_index("partyfacts_id") ).index).value_counts()
# pd.Series(df_means.index).value_counts()
# pf_index_int = set(df_means.index)

# parlgov_party.set_index("partyfacts_id").loc[df_means.index]
# pf_index_int = list(set.intersection(set(df_means.index),set(parlgov_party["partyfacts_id"])))
# [parlgov_party["partyfacts_id"]].apply(lambda x: x in pf_index_int
# df_merged = df_means.merge( parlgov_party, how='left', on= ["partyfacts_id","year"])
# df_merged = df_merged.merge( pf_core, how='left', on= ["partyfacts_id","year"])


##################

mask = merged_vl.apply(lambda x: x["type"] in ['man_cod', 'dummy_vars', 'expert_op', 'id_dim', 'elec_vars',
       'coder_ratings', ],axis=1)

reasonable_colums = [x for x in df_means_prt_yr.columns if x in merged_vl["integrated_variable"][mask].values]
reasonable_colums = reasonable_colums + ['(pimpo)totals', '(pimpo)totals_immi', '(pimpo)totals_inti', '(manifesto)total','partyfacts_id']
reasonable_colums.remove('partyfacts_id')

df_merged_small = df_means_prt_yr[reasonable_colums].copy()
# df_merged_small["partyfacts_id"] = df_merged_small["partyfacts_id"].astype(int)
# df_merged_small = df_merged_small.set_index("partyfacts_id")


# set partyfacts_id to index

# curious about these!
# df_merged = df_merged_small

# %%
# df_merged_small

# %%
# %%time
corrs = df_merged_small.corr()
corrs = corrs.where(np.triu(np.ones(corrs.shape),k=2).astype(np.bool))
df_corrs = corrs.stack().reset_index()
df_corrs.columns = ['Row','Column','Value']
# df.drop(df.index[df["Value"]==1.0],inplace=True)


df_corrs["NZ"] = df_corrs.apply(lambda x: (df_merged[x["Row"]].apply(not_zero_or_nan)&df_merged[x["Column"]].apply(not_zero_or_nan)).sum(),axis=1)
# 36 minutes here!
df_corrs["N"] = df_corrs.apply(lambda x: (df_merged[x["Row"]].notnull()&df_merged[x["Column"]].notnull()).sum(),axis=1)

# df_corrs.sort_values(by="Value")
# Out:
# Wall time: 35min 51s

# %%
not_id_vars = df_corrs[["Row","Column"]].applymap(lambda x: ("id" not in x) & (x not in shared_columns)).all(axis=1)

df_corrs_non_id = df_corrs[not_id_vars].copy()

df_corrs_non_id["Row_ds"] = df_corrs_non_id["Row"].apply(lambda x: (x.split("(")[1]).split(")")[0])
df_corrs_non_id["Col_ds"] = df_corrs_non_id["Column"].apply(lambda x: (x.split("(")[1]).split(")")[0])
df_corrs_ni_nm = df_corrs_non_id[df_corrs_non_id["Row_ds"]!=df_corrs_non_id["Col_ds"]].copy()

# %%
# C:\Users\Marios\Documents\GitHub\Thomas Prosser project\datasets\Party Level
df_corrs_ni_nm.to_pickle(dataset_folder+"Party Level"+os.sep+ "df_corrs_ni_nm_pty_yr.zip",compression='zip')
# df.to_pickle(dataset_folder+"Party Level"+os.sep+ "df.zip",compression='zip')
df_merged_small.to_pickle(dataset_folder+"Party Level"+os.sep+ "df_merged_pty_yr.zip",compression='zip')
