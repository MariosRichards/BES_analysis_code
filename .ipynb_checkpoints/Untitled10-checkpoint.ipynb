# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import gc
import re

from itertools import cycle
from IPython.display import display
import pickle, os

import seaborn as sns

encoding = "ISO-8859-1"

import Jupyter_module_loader

# %%
# you should clone this git to this subdirectory (in some directory - I call it BES_analysis - doesn't matter though)

if os.getcwd().split(os.sep)[-1] != 'BES_analysis_code':
    raise Exception("Stop! You're in the wrong directory - should be in 'BES_analysis_code'")

BES_code_folder   = "../BES_analysis_code/" # we should be here!
BES_small_data_files = BES_code_folder + "small data files" + os.sep
if not os.path.exists( BES_small_data_files ):
    os.makedirs( BES_small_data_files )

# we should create these if they don't already exist
BES_data_folder   = "../BES_analysis_data/"
if not os.path.exists( BES_data_folder ):
    os.makedirs( BES_data_folder )

BES_output_folder = "../BES_analysis_output/"
if not os.path.exists( BES_output_folder ):
    os.makedirs( BES_output_folder )
    
BES_file_manifest = pd.read_csv( BES_small_data_files + "BES_file_manifest.csv" )

BES_R_data_files = BES_data_folder + "R_data" + os.sep
if not os.path.exists( BES_R_data_files ):
    os.makedirs( BES_R_data_files )

# %%
from sklearn import datasets
from sklearn.decomposition import PCA, IncrementalPCA, NMF, TruncatedSVD, FastICA, FactorAnalysis, SparsePCA
from sklearn.preprocessing import StandardScaler
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from gaussian_kde import gaussian_kde
from utility import display_components, display_pca_data, weighted_kde

# %%
dataset_name = "W13_comb"

# %%
# %%time

manifest = BES_file_manifest[ BES_file_manifest["Name"] == dataset_name ]

data_subfolder = BES_data_folder + dataset_name + os.sep

dataset_filename = manifest["Stata_Filename"].values[0]
# dataset_description = manifest["Friendlier_Description"].values[0]
# dataset_citation = manifest["Citation"].values[0]
# dataset_start = manifest["Date_Start"].values[0]
# dataset_stop = manifest["Date_Stop"].values[0]
# dataset_wave = manifest["Wave No"].values[0]

BES_Panel  = pd.read_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))
print("BES_Panel", BES_Panel.shape )
# Out:
# BES_Panel (68625, 5150)

# %%
####

# BES_numeric = pd.read_msgpack( data_subfolder + "BESnumeric.hdf".replace('.hdf','.msgpack') )
# BES_numeric.info(memory_usage='deep')
try:
    var_type    = pd.read_hdf( data_subfolder + "var_type.hdf", encoding=encoding)
except:
    var_type    = pd.read_csv( data_subfolder + "var_type.csv", encoding=encoding)
    var_type.set_index("Unnamed: 0", inplace=True)
print("var_type",  var_type.shape )

fname = data_subfolder + "cat_dictionary.pkl"
with open(fname, "rb") as f:
    cat_dictionary = pickle.load( f )
    
####

# BES_non_numeric = pd.read_hdf( data_subfolder + "BESnon_numeric.hdf", "BESnon_numeric" )
# print("BES_non_numeric",  BES_non_numeric.shape )

# BES_reduced = pd.read_hdf( data_subfolder + "BES_reduced.hdf", "BES_reduced" )
# print("BES_reduced",  BES_reduced.shape )

BES_reduced_with_na = pd.read_msgpack( data_subfolder + "BES_reduced_with_na.hdf".replace('.hdf','.msgpack') )
BES_reduced_with_na.info(memory_usage='deep')

# fname = data_subfolder + "new_old_col_names.pkl"
# with open(fname, "rb") as f:
#     new_old_col_names = pickle.load(f)
# Out:
# var_type (5173, 8)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68625 entries, 0 to 68624
# Columns: 2572 entries, turnoutUKGeneralW1__Very likely that I will vote to partyContact1W2_Yes
# dtypes: float32(2571), uint8(1)
# memory usage: 673.6 MB

# %%
def hdf_shring_to_msgpack(hdf_file):
    df = pd.read_hdf( data_subfolder + hdf_file+".hdf", hdf_file )
    df = df.apply(pd.to_numeric,downcast='float')
    df.to_msgpack(data_subfolder + hdf_file+".hdf".replace('.hdf','.msgpack'))
    del df
    gc.collect()
    
# hdf_shring_to_msgpack("BES_reduced_with_na")

# %%
fname = data_subfolder + "new_old_col_names.pkl"
with open(fname, "rb") as f:
    new_old_col_names = pickle.load(f)
old_new_col_names = {v: k for k, v in new_old_col_names.items()}

# %%
## augment dataset
# pan_dataset_values
# census data
# 

pan_dataset_values = pd.read_csv( BES_small_data_files + "pan_dataset_values.csv", encoding=encoding)

# %%
max_wave = int(re.match("W(\d+)_",dataset_name).groups()[0])
num_to_wave = {x:"W"+str(x) for x in range(1,max_wave+1)}
num_to_weight = { y:[x for x in BES_Panel.columns.sort_values(ascending=False) if re.match("wt_(new|full)_W"+str(y)+"$",x)][0] for y in range(1,max_wave+1) }
weights = BES_Panel[list(num_to_weight.values())].copy()

# %%
# http://www.britishelectionstudy.com/data-object/2017-bes-constituency-results-with-census-and-candidate-data/
BES_census_data = pd.read_stata( BES_small_data_files + "BES-2017-General-Election-results-file-v1.0.dta" )
print("BES_census_data", BES_census_data.shape )

## SHOULD BE REPLACED WITH pan_dataset_variables reference
pano_var_dict = {int(x.replace("panoW","")):x for x in BES_Panel.columns if "pano" in x}
sorted_pano_vars = [ pano_var_dict[x] for x in sorted( pano_var_dict.keys() ) ]

BES_reduced_with_na["pano"] = BES_Panel[sorted_pano_vars].bfill(axis=1).iloc[:, 0]


# len()
census_vars = [x for x in BES_census_data.columns if re.match('c\w',x) ]
census_vars.append("leaveHanretty")
census_vars.append("remainHanretty")
census_vars.append("pano")
# ConstituencyType
BES_reduced_with_na = pd.merge(BES_reduced_with_na, BES_census_data[census_vars], how = 'left', on = 'pano')
# Out:
# BES_census_data (632, 308)

# %%
import sys, gc

def sizeof_fmt(num, suffix='B'):
    ''' By Fred Cirera, after https://stackoverflow.com/a/1094933/1870254'''
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f%s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f%s%s" % (num, 'Yi', suffix)

def memory_use(locs = locals().items()):
    gc.collect()
    # locals().items()
    for name, size in sorted(((name, sys.getsizeof(value)) for name,value in locs),
                             key= lambda x: -x[1])[:10]:
        print("{:>30}: {:>8}".format(name,sizeof_fmt(size)))
memory_use()
# Out:
#                       focal_df: 676.1MiB
#            BES_reduced_with_na: 673.6MiB
#                      BES_Panel: 410.7MiB
#                            _41:  82.6MiB
#                            _59:  32.6MiB
#                      immigDiff:  19.5MiB
#                          train:  14.6MiB
#                        X_train:   9.8MiB
#                        weights:   7.3MiB
#                         X_test:   4.8MiB

# %%
import shap
import xgboost as xgb
from sklearn.preprocessing import Imputer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from sklearn.linear_model import ElasticNet
from xgboost import XGBClassifier, XGBRegressor
from sklearn.metrics import accuracy_score, mean_squared_error, mean_absolute_error, explained_variance_score, r2_score

# %%
def get_base_from_BES(im_var, waves=None, noNans = False):

    if waves:
        wave_list = waves
    else:
        wave_list = [x.replace(im_var,"") for x in BES_Panel.columns if re.match(im_var+"W\d+$",  x)]
    
    immig_vars = [im_var+x for x in wave_list]

    if noNans:
        all_in_dataset = BES_Panel[immig_vars].notnull().all(axis=1)

        max_range = len(BES_Panel[immig_vars[0]].cat.categories.drop("Don't know",errors='ignore'))-1
        max_cat = BES_Panel[immig_vars[0]].cat.categories.drop("Don't know",errors='ignore')[max_range]
        BES_immig = BES_Panel[immig_vars][all_in_dataset]\
        .replace("Don't know",np.nan)\
        .apply(lambda x: x.cat.codes)\
        .replace(-1,np.nan)\
        .apply(lambda x: x.fillna(x.median())) / max_range
    else:
        all_in_dataset = BES_Panel[immig_vars].isnull()
        
        max_range = len(BES_Panel[immig_vars[0]].cat.categories.drop("Don't know",errors='ignore'))-1
        max_cat = BES_Panel[immig_vars[0]].cat.categories.drop("Don't know",errors='ignore')[max_range]
        BES_immig = BES_Panel[immig_vars]\
        .replace("Don't know",np.nan)\
        .apply(lambda x: x.cat.codes)\
        .replace(-1,np.nan)\
        .apply(lambda x: x.fillna(x.median())) / max_range
        
        BES_immig[all_in_dataset] = np.nan
        all_in_dataset = ~all_in_dataset
        
        
    return BES_immig, all_in_dataset

def get_base(im_var, waves=None, noNans = False):
# get df containing all waves of some variable
# specify waves with integers! (makes sorting easier) - crash if you choose waves not present?

    wave_dict = {int(re.match(im_var+"W(\d+)",  x).groups()[0]):x for x in BES_reduced_with_na.columns if re.match(im_var+"W\d+($|_)",  x)}

    if waves:
        immig_vars = [wave_dict[x] for x in sorted(intersection(waves,wave_dict.keys()))]
    else:
        immig_vars = [wave_dict[x] for x in sorted(wave_dict.keys())]

    if noNans:
        all_in_dataset = BES_reduced_with_na[immig_vars].notnull().all(axis=1)
        max_range = BES_reduced_with_na[immig_vars].max().max()
        BES_immig = BES_reduced_with_na[immig_vars][all_in_dataset]\
        .apply(lambda x: x.fillna(x.median())) / max_range
    else:
        all_in_dataset = BES_reduced_with_na[immig_vars].isnull()
        max_range = BES_reduced_with_na[immig_vars].max().max()
        BES_immig = BES_reduced_with_na[immig_vars] / max_range

        all_in_dataset = ~all_in_dataset
        
        
    return BES_immig, all_in_dataset

def intersection(lst1, lst2): 
  
    # Use of hybrid method 
    temp = set(lst2) 
    lst3 = [value for value in lst1 if value in temp] 
    return lst3 

def get_diff(imvar_list):
    num = 0
    for im_var in imvar_list:

        print(im_var)
        immig, mask = get_base(im_var,noNans = False)

        waves_tmp = [re.search("(W\d+)",x).groups()[0] for x in immig.columns]
        replace_wave = ["("+waves_tmp[a]+"->"+waves_tmp[a+1]+")" for a,b in enumerate(immig.columns[1:])]
        temp = [immig.columns[0]]
        temp.extend([re.sub("W\d+",replace_wave[i],x) for i,x in enumerate(immig.columns[1:])])
        immig.columns = temp     
        if num ==0:
            immigDiff = immig.diff(axis=1).drop(immig.columns[0],axis=1)
        else:
            immigDiff = pd.concat( [immigDiff, immig.diff(axis=1).drop(immig.columns[0],axis=1)], axis=1)
        num = num + 1
    return immigDiff

# %%
Treatment = "Remain_but_no_do_over"

### focal variable??

# %%
# var_stub = "partyId"
# var_list = [x for x in BES_reduced_with_na.columns if re.match(var_stub+"W\d+_No - none",x)]
# # "partyIdStrength",
# var_stub_list = ["partyId", "partyIdSqueeze",  "generalElectionVote", "ashcroft", "generalElectionCertainty"]
# # base_list = [x for x in BES_reduced_with_na.columns if var_stub in x][0:len(var_list)]
# var_list

# %%
var_stub = "euRefDoOver"
var_list = [x for x in BES_reduced_with_na.columns if re.match(var_stub,x)]
# "partyIdStrength",
# var_stub_list = ["partyId", "partyIdSqueeze",  "generalElectionVote", "ashcroft", "generalElectionCertainty"]
var_stub_list = ["euRefDoOver"]
# base_list = [x for x in BES_reduced_with_na.columns if var_stub in x][0:len(var_list)]
var_list
# Out:
# ['euRefDoOverW13_Yes', 'euRefDoOverW10_Yes', 'euRefDoOverW11_Yes']

# %%
imvar_list = [var_stub]

immigDiff = get_diff(imvar_list)
# Out:
# immigSelf

# %%
var_stub = "immigSelf"
var_list = [x for x in immigDiff.columns if re.match(var_stub,x)]
# "partyIdStrength",
# var_stub_list = ["partyId", "partyIdSqueeze",  "generalElectionVote", "ashcroft", "generalElectionCertainty"]
# var_stub_list = ["euRefVote","profile_eurefvote_Leave the EU"]
var_stub_list = ["immigSelf"]
# base_list = [x for x in BES_reduced_with_na.columns if var_stub in x][0:len(var_list)]
var_list
# Out:
# ['immigSelf(W7->W8)__Allow many more',
#  'immigSelf(W8->W9)__Allow many more',
#  'immigSelf(W9->W10)__Allow many more',
#  'immigSelf(W10->W11)__Allow many more']

# %%
# immigDiff

# %%
thresh = 0.01 # -> 76 variables
# thresh = 0.05 # -> 65 variables!
# thresh = 0.1 # -> 134 variables
# thresh = 0.5 # -> 134 variables

# %%
# %%time

focal_df = BES_reduced_with_na

diff_feature_candidate_list = []
ordinalised_vars = var_type[ var_type["type"].apply(lambda x: x in [0, 1, 2, 3, 5, 6])].index
# ordinalised_vars = var_type[ np.logical_and( var_type["type"].apply(lambda x: x in [0, 1, 2, 3, 5, 6]),
#                                              var_type["dataset_name"] == dataset_name )].index
reduced_ordinal_vars = [x for x in new_old_col_names.keys() if new_old_col_names[x] in ordinalised_vars]
vars_present = intersection(reduced_ordinal_vars, BES_reduced_with_na.columns)


for focal_var in var_list:
    print(focal_var)
    corr = BES_reduced_with_na[vars_present].corrwith(focal_df[focal_var])
    reduced_corr = corr.sort_values()

    high_corr = reduced_corr[ np.logical_or( reduced_corr< reduced_corr.quantile(thresh) ,
                                             reduced_corr> reduced_corr.quantile(1-thresh) ) ]
    diff_feature_candidate_list.extend(list(high_corr.index))
print(len(diff_feature_candidate_list))
# Out:
# euRefDoOverW13_Yes
# euRefDoOverW10_Yes
# euRefDoOverW11_Yes
# 150

# %%
# diff_feature_candidate_list

# %%
temp  = [x for x in diff_feature_candidate_list if re.search("W\d+",x)]
temp2 = [x for x in temp if not re.search("(W\d+){2}",x)]
temp3 = [re.match("([a-zA-Z0-9_]+?)(W\d+){1}",x).groups(0)[0] if re.match("([a-zA-Z0-9_]+)(W\d+){1}",x) else x for x in temp2 ]
imvar_list = list(set(temp3))
auto_gen = imvar_list

# %%
auto_gen
# Out:
# ['socialIdentityGlobalLeave',
#  'euLeaveVoice',
#  'euID',
#  'immigSelf',
#  'bestPM',
#  'socialIdentityGlobalRemain',
#  'euPriorityBalance',
#  'happyEULeave',
#  'euRefVote',
#  'satDemEU',
#  'effectsEUEcon',
#  'euLawsLevel',
#  'echr',
#  'expectGoodConductEURef',
#  'europeanness',
#  'approveEU',
#  'euRefDoOver',
#  'euPreventWar',
#  'EUIntegrationSelf',
#  'euUKRich',
#  'euLeaveBigBusiness',
#  'euRefFinalPost']

# %%
imvar_list = auto_gen

immigDiff = get_diff(imvar_list)
# Out:
# socialIdentityGlobalLeave
# euLeaveVoice
# euID
# immigSelf
# bestPM
# socialIdentityGlobalRemain
# euPriorityBalance
# happyEULeave
# euRefVote
# satDemEU
# effectsEUEcon
# euLawsLevel
# echr
# expectGoodConductEURef
# europeanness
# approveEU
# euRefDoOver
# euPreventWar
# EUIntegrationSelf
# euUKRich
# euLeaveBigBusiness
# euRefFinalPost

# %%
# lr_pos =  [x for x in BES_reduced_with_na.columns if re.match("lrCon|lrLab",x)]
# lr_pos.remove('lrConW10__Right')
# lr_pos

# %%
# immigDiff

# %%
# immigDiff = BES_reduced_with_na[lr_pos].diff(axis=1)[lr_pos[1::2]]

# %%
# lrLab-lrCon

# %%
# var_stub = "partyId"
# var_list = [x for x in BES_reduced_with_na.columns if re.match(var_stub+"W\d+_No - none",x)]
# # "partyIdStrength",
# var_stub_list = ["partyId", "partyIdSqueeze",  "generalElectionVote", "ashcroft", "generalElectionCertainty"]
# # base_list = [x for x in BES_reduced_with_na.columns if var_stub in x][0:len(var_list)]
# var_list

# %%
# party_id_none_delta = BES_reduced_with_na[var_list].astype('float').diff(axis=1).drop(var_list[0],axis=1)
# party_id_none_delta
# var_list = var_list[1:]
# var_list

# %%
# var_list = immigDiff.columns
# var_stub_list = ['lrLab','lrCon']

# %%
# var_list.remove('partydiffconlabW5__There is not much difference between them')
# var_list = var_list[-2:]

# %%
BES_Panel['happyEULeaveW11'].notnull().sum()
# Out:
# 31014

# %%
BES_reduced_with_na['euRefVoteW13_Leave the EU'] = BES_Panel["euRefVoteW13"].cat.codes
BES_reduced_with_na['euRefVoteW13_Leave the EU'] = BES_reduced_with_na['euRefVoteW13_Leave the EU'].replace(2, np.nan).replace(3, np.nan).replace(-1, np.nan)

BES_reduced_with_na['euRefVoteW11_Leave the EU'] = BES_Panel["euRefVoteW11"].cat.codes
BES_reduced_with_na['euRefVoteW11_Leave the EU'] = BES_reduced_with_na['euRefVoteW11_Leave the EU'].replace(2, np.nan).replace(3, np.nan).replace(-1, np.nan)

BES_reduced_with_na['generalElectionVoteW10__Conservative'] = (BES_Panel['generalElectionVoteW10']=="Conservative")
BES_reduced_with_na.loc[BES_Panel['generalElectionVoteW10'].isnull(),'generalElectionVoteW10__Conservative'] = np.nan

BES_reduced_with_na['generalElectionVoteW11__Conservative'] = BES_Panel['generalElectionVoteW11']=="Conservative"
BES_reduced_with_na.loc[BES_Panel['generalElectionVoteW11'].isnull(),'generalElectionVoteW11__Conservative'] = np.nan

BES_reduced_with_na['generalElectionVoteW13__Conservative'] = BES_Panel['generalElectionVoteW13']=="Conservative"
BES_reduced_with_na.loc[BES_Panel['generalElectionVoteW11'].isnull(),'generalElectionVoteW11__Conservative'] = np.nan

# %%
var_list
# Out:
# ['euRefDoOverW13_Yes', 'euRefDoOverW10_Yes', 'euRefDoOverW11_Yes']

# %%
var_list = ['euRefVoteW8_Leave the EU']
# mask = immigDiff["polAttention(W7->W8)__Pay a great deal of attention"].notnull()
# immigDiff["polAttention(W7->W8)__Pay a great deal of attention"] = np.random.randn(immigDiff["polAttention(W7->W8)__Pay a great deal of attention"].size)
# immigDiff["polAttention(W7->W8)__Pay a great deal of attention"][~mask] = np.nan

# %%
[x for x in BES_reduced_with_na.columns if "euRefVote" in x]
# Out:
# ['euRefVoteW4_Leave the EU',
#  'euRefVoteW8_Leave the EU',
#  'euRefVoteW6_Leave the EU',
#  'euRefVoteW7_Leave the EU',
#  'euRefVoteW12_Leave the EU',
#  'euRefVoteW1_Leave the EU',
#  'euRefVoteW10_Leave the EU',
#  'euRefVoteW3_Leave the EU']

# %%
# for target_var,base_var in zip(var_list,base_list):
for target_var in var_list:
    wave_no = int( re.search( 'W(\d+)($|_|\))', target_var ).groups()[0] )
    weight_var = num_to_weight[wave_no]    
    print( target_var, wave_no )
    
    # mask and remove rows where we don't have *target* data
    mask   = BES_reduced_with_na[target_var].notnull()
    mask = mask & (BES_reduced_with_na['euRefVoteW'+ str(wave_no) + '_Leave the EU']==0.0)    
    target = BES_reduced_with_na[target_var][mask]
    

    
#     mask = party_id_none_delta[target_var].notnull()
#     target = party_id_none_delta[target_var][mask]
    
    
#     mask = immigDiff[target_var].notnull()
#     target = immigDiff[target_var][mask]
    if sum(mask)<100:
        continue

    
#     train  = pd.concat(BES_reduced_with_na[mask]
    train = pd.concat( [ BES_reduced_with_na[mask] , immigDiff[mask] ] , axis=1 )
    print()
#     train = immigDiff[mask].copy()
    # drop variables from other waves
    other_waves = "("+"|".join([num_to_wave[x] for x in range(1,14) if (x>wave_no) or (x<wave_no) ]) +")" +"([^0-9-]|$)"
    train = train.drop( [x for x in train.columns if re.search(other_waves,x)] , axis=1 )       
    
    for var_stub in var_stub_list:
        train = train.drop([x for x in train.columns if var_stub in x], axis=1)    


    sample_weights = weights[weight_var][mask]
    print("missing vals in sample weights: "+ str( sample_weights.isnull().sum() ) )
    sample_weights = sample_weights.fillna(sample_weights.median())

    output_subfolder = BES_output_folder + "xgboost_"+Treatment + os.sep + target_var.replace(">","") + os.sep
    if not os.path.exists( output_subfolder ):
        os.makedirs( output_subfolder )


    ############################

    alg = XGBRegressor(
     learning_rate =0.04,
     n_estimators= 100,
     max_depth=3,
     min_child_weight=1,
     gamma=0,
     subsample=0.75,
     colsample_bytree=0.9,
     colsample_bylevel=.85,
     objective= 'reg:linear',
     scale_pos_weight=1.0,
     reg_alpha=0,
     reg_lambda=1,
     njobs=3,
     seed=27)

    # split data into train and test sets
    # fit, validate and find overfitting limit
    seed = 7
    test_size = 0.33

    X_train, X_test, y_train, y_test = train_test_split(pd.concat([train,sample_weights],axis=1), target, test_size=test_size,
                                                        random_state=seed, stratify=round(target))



    eval_set = [(X_test, y_test)]

    sample_weight = X_train[weight_var].values
    sample_weight_eval_set = X_test[weight_var].values
    X_train.drop(weight_var, axis=1, inplace=True)
    X_test.drop(weight_var, axis=1, inplace=True)

    alg.fit(X_train, y_train, eval_metric='rmse', 
            early_stopping_rounds=alg.get_params()['n_estimators']*.1, eval_set=eval_set,
            verbose=True, sample_weight= sample_weight)

    # make predictions for test data
    predictions = alg.predict(X_test)

    # evaluate predictions
    MSE = mean_squared_error(y_test, predictions)
    MAE = mean_absolute_error(y_test, predictions)
    EV = explained_variance_score(y_test, predictions)
    R2 = r2_score(y_test, predictions)

    print("MSE: %.2f, MAE: %.2f, EV: %.2f, R2: %.2f" % (MSE, MAE, EV, R2) )
    alg.set_params(n_estimators=alg.best_iteration)

    ####################################
    # fit to full dataset at non-overfitting level
    alg.fit(train, target, verbose = True, sample_weight = sample_weights)




    shap_values = shap.TreeExplainer(alg).shap_values(train);


    #################################
    threshold = .1
    min_features = 20
    global_shap_vals = np.abs(shap_values).mean(0)[:-1]
    n_top_features = sum(global_shap_vals[np.argsort(global_shap_vals)]>=threshold)
    if n_top_features <min_features:
        n_top_features = min_features



    ##########################

    inds = np.argsort(global_shap_vals)[-n_top_features:]

    y_pos = np.arange(n_top_features)
    plt.figure(figsize=(16,10))
    plt.title(target_var);
    plt.barh(y_pos, global_shap_vals[inds], color="#1E88E5")
    plt.yticks(y_pos, train.columns[inds])
    plt.gca().spines['right'].set_visible(False)
    plt.gca().spines['top'].set_visible(False)
    plt.xlabel("mean SHAP value magnitude (change in log odds)")
    plt.gcf().set_size_inches(6, 4.5)

    plt.savefig( output_subfolder + "mean_impact" + ".png", bbox_inches='tight' )

    plt.show()

    ####################
    
    fig = plt.figure()
    fig.suptitle(target_var);
    shap.summary_plot( shap_values, train, max_display=n_top_features, plot_type='dot' );
    fig.savefig( output_subfolder + "summary_plot" + ".png", bbox_inches='tight' )



#     ##################
#     count = 0
#     for name in train.columns[inds[::-1]]:
#         fig = plt.figure(figsize = (16,10))
#         fig.suptitle(target_var);
#         shap.dependence_plot(name, shap_values, train)
#         fig.savefig(output_subfolder + "featureNo "+str(count) + " " + name.replace("/","_").replace(">","")[0:30] + ".png", bbox_inches='tight')
#         count = count + 1
# Out:
# euRefDoOverW13_Yes 13
#
# missing vals in sample weights: 1
# [0]	validation_0-rmse:0.491817
# Will train until validation_0-rmse hasn't improved in 10.0 rounds.
# [1]	validation_0-rmse:0.484262
# [2]	validation_0-rmse:0.4769
# [3]	validation_0-rmse:0.470072
# [4]	validation_0-rmse:0.463582
# [5]	validation_0-rmse:0.457492
# [6]	validation_0-rmse:0.451899
# [7]	validation_0-rmse:0.446767
# [8]	validation_0-rmse:0.441766
# [9]	validation_0-rmse:0.43716
# [10]	validation_0-rmse:0.432939
# [11]	validation_0-rmse:0.428859
# [12]	validation_0-rmse:0.424976
# [13]	validation_0-rmse:0.421507
# [14]	validation_0-rmse:0.418129
# [15]	validation_0-rmse:0.415018
# [16]	validation_0-rmse:0.412182
# [17]	validation_0-rmse:0.409403
# [18]	validation_0-rmse:0.406898
# [19]	validation_0-rmse:0.404509
# [20]	validation_0-rmse:0.402272
# [21]	validation_0-rmse:0.400323
# [22]	validation_0-rmse:0.398354
# [23]	validation_0-rmse:0.396495
# [24]	validation_0-rmse:0.39489
# [25]	validation_0-rmse:0.393371
# [26]	validation_0-rmse:0.39194
# [27]	validation_0-rmse:0.390679
# [28]	validation_0-rmse:0.389452
# [29]	validation_0-rmse:0.388279
# [30]	validation_0-rmse:0.387229
# [31]	validation_0-rmse:0.386173
# [32]	validation_0-rmse:0.385347
# [33]	validation_0-rmse:0.384448
# [34]	validation_0-rmse:0.383659
# [35]	validation_0-rmse:0.382841
# [36]	validation_0-rmse:0.382008
# [37]	validation_0-rmse:0.381199
# [38]	validation_0-rmse:0.380513
# [39]	validation_0-rmse:0.379887
# [40]	validation_0-rmse:0.379347
# [41]	validation_0-rmse:0.378727
# [42]	validation_0-rmse:0.378209
# [43]	validation_0-rmse:0.377743
# [44]	validation_0-rmse:0.377319
# [45]	validation_0-rmse:0.376927
# [46]	validation_0-rmse:0.376564
# [47]	validation_0-rmse:0.376145
# [48]	validation_0-rmse:0.375789
# [49]	validation_0-rmse:0.375437
# [50]	validation_0-rmse:0.375095
# [51]	validation_0-rmse:0.374817
# [52]	validation_0-rmse:0.374592
# [53]	validation_0-rmse:0.374287
# [54]	validation_0-rmse:0.373973
# [55]	validation_0-rmse:0.37375
# [56]	validation_0-rmse:0.373498
# [57]	validation_0-rmse:0.373248
# [58]	validation_0-rmse:0.373052
# [59]	validation_0-rmse:0.372814
# [60]	validation_0-rmse:0.372611
# [61]	validation_0-rmse:0.372461
# [62]	validation_0-rmse:0.372268
# [63]	validation_0-rmse:0.372017
# [64]	validation_0-rmse:0.371833
# [65]	validation_0-rmse:0.371689
# [66]	validation_0-rmse:0.371445
# [67]	validation_0-rmse:0.371334
# [68]	validation_0-rmse:0.371131
# [69]	validation_0-rmse:0.370909
# [70]	validation_0-rmse:0.370709
# [71]	validation_0-rmse:0.370659
# [72]	validation_0-rmse:0.370516
# [73]	validation_0-rmse:0.370434
# [74]	validation_0-rmse:0.37031
# [75]	validation_0-rmse:0.370228
# [76]	validation_0-rmse:0.370121
# [77]	validation_0-rmse:0.369968
# [78]	validation_0-rmse:0.369892
# [79]	validation_0-rmse:0.369811
# [80]	validation_0-rmse:0.369716
# [81]	validation_0-rmse:0.369607
# [82]	validation_0-rmse:0.369563
# [83]	validation_0-rmse:0.369481
# [84]	validation_0-rmse:0.369444
# [85]	validation_0-rmse:0.369404
# [86]	validation_0-rmse:0.3693
# [87]	validation_0-rmse:0.369264
# [88]	validation_0-rmse:0.369104
# [89]	validation_0-rmse:0.368986
# [90]	validation_0-rmse:0.368898
# [91]	validation_0-rmse:0.368895
# [92]	validation_0-rmse:0.368756
# [93]	validation_0-rmse:0.368672
# [94]	validation_0-rmse:0.368588
# [95]	validation_0-rmse:0.368546
# [96]	validation_0-rmse:0.368443
# [97]	validation_0-rmse:0.368392
# [98]	validation_0-rmse:0.368367
# [99]	validation_0-rmse:0.368291
# MSE: 0.14, MAE: 0.28, EV: 0.18, R2: 0.18
# euRefDoOverW10_Yes 10
#
# missing vals in sample weights: 0
# [0]	validation_0-rmse:0.491376
# Will train until validation_0-rmse hasn't improved in 10.0 rounds.
# [1]	validation_0-rmse:0.483395
# [2]	validation_0-rmse:0.475811
# [3]	validation_0-rmse:0.468612
# [4]	validation_0-rmse:0.461968
# [5]	validation_0-rmse:0.455645
# [6]	validation_0-rmse:0.44969
# [7]	validation_0-rmse:0.444101
# [8]	validation_0-rmse:0.439067
# [9]	validation_0-rmse:0.434242
# [10]	validation_0-rmse:0.429814
# [11]	validation_0-rmse:0.425569
# [12]	validation_0-rmse:0.421773
# [13]	validation_0-rmse:0.418212
# [14]	validation_0-rmse:0.414724
# [15]	validation_0-rmse:0.411647
# [16]	validation_0-rmse:0.408683
# [17]	validation_0-rmse:0.405864
# [18]	validation_0-rmse:0.403197
# [19]	validation_0-rmse:0.40076
# [20]	validation_0-rmse:0.398438
# [21]	validation_0-rmse:0.396336
# [22]	validation_0-rmse:0.394322
# [23]	validation_0-rmse:0.3924
# [24]	validation_0-rmse:0.390611
# [25]	validation_0-rmse:0.388977
# [26]	validation_0-rmse:0.387451
# [27]	validation_0-rmse:0.385968
# [28]	validation_0-rmse:0.384538
# [29]	validation_0-rmse:0.383345
# [30]	validation_0-rmse:0.382206
# [31]	validation_0-rmse:0.381048
# [32]	validation_0-rmse:0.379974
# [33]	validation_0-rmse:0.379101
# [34]	validation_0-rmse:0.378171
# [35]	validation_0-rmse:0.377304
# [36]	validation_0-rmse:0.376451
# [37]	validation_0-rmse:0.375742
# [38]	validation_0-rmse:0.374988
# [39]	validation_0-rmse:0.374299
# [40]	validation_0-rmse:0.373654
# [41]	validation_0-rmse:0.37318
# [42]	validation_0-rmse:0.372676
# [43]	validation_0-rmse:0.372157
# [44]	validation_0-rmse:0.371609
# [45]	validation_0-rmse:0.371107
# [46]	validation_0-rmse:0.370575
# [47]	validation_0-rmse:0.370129
# [48]	validation_0-rmse:0.36965
# [49]	validation_0-rmse:0.36921
# [50]	validation_0-rmse:0.368876
# [51]	validation_0-rmse:0.368625
# [52]	validation_0-rmse:0.368237
# [53]	validation_0-rmse:0.367871
# [54]	validation_0-rmse:0.36753
# [55]	validation_0-rmse:0.367228
# [56]	validation_0-rmse:0.36691
# [57]	validation_0-rmse:0.366704
# [58]	validation_0-rmse:0.366593
# [59]	validation_0-rmse:0.366365
# [60]	validation_0-rmse:0.366098
# [61]	validation_0-rmse:0.365822
# [62]	validation_0-rmse:0.365614
# [63]	validation_0-rmse:0.365402
# [64]	validation_0-rmse:0.365203
# [65]	validation_0-rmse:0.364998
# [66]	validation_0-rmse:0.364744
# [67]	validation_0-rmse:0.364515
# [68]	validation_0-rmse:0.364393
# [69]	validation_0-rmse:0.364222
# [70]	validation_0-rmse:0.364068
# [71]	validation_0-rmse:0.363943
# [72]	validation_0-rmse:0.363805
# [73]	validation_0-rmse:0.363689
# [74]	validation_0-rmse:0.363551
# [75]	validation_0-rmse:0.363353
# [76]	validation_0-rmse:0.363222
# [77]	validation_0-rmse:0.36311
# [78]	validation_0-rmse:0.362981
# [79]	validation_0-rmse:0.362903
# [80]	validation_0-rmse:0.362737
# [81]	validation_0-rmse:0.362696
# [82]	validation_0-rmse:0.362585
# [83]	validation_0-rmse:0.36255
# [84]	validation_0-rmse:0.362531
# [85]	validation_0-rmse:0.362438
# [86]	validation_0-rmse:0.36236
# [87]	validation_0-rmse:0.362328
# [88]	validation_0-rmse:0.362249
# [89]	validation_0-rmse:0.362119
# [90]	validation_0-rmse:0.361992
# [91]	validation_0-rmse:0.3619
# [92]	validation_0-rmse:0.36187
# [93]	validation_0-rmse:0.361823
# [94]	validation_0-rmse:0.361787
# [95]	validation_0-rmse:0.36177
# [96]	validation_0-rmse:0.361721
# [97]	validation_0-rmse:0.361648
# [98]	validation_0-rmse:0.361594
# [99]	validation_0-rmse:0.36148
# MSE: 0.13, MAE: 0.27, EV: 0.21, R2: 0.21
# euRefDoOverW11_Yes 11
#
# missing vals in sample weights: 0
# [0]	validation_0-rmse:0.491527
# Will train until validation_0-rmse hasn't improved in 10.0 rounds.
# [1]	validation_0-rmse:0.483326
# [2]	validation_0-rmse:0.475552
# [3]	validation_0-rmse:0.468283
# [4]	validation_0-rmse:0.461326
# [5]	validation_0-rmse:0.454778
# [6]	validation_0-rmse:0.448683
# [7]	validation_0-rmse:0.442999
# [8]	validation_0-rmse:0.437715
# [9]	validation_0-rmse:0.432877
# [10]	validation_0-rmse:0.428009
# [11]	validation_0-rmse:0.423482
# [12]	validation_0-rmse:0.419238
# [13]	validation_0-rmse:0.415381
# [14]	validation_0-rmse:0.411793
# [15]	validation_0-rmse:0.408328
# [16]	validation_0-rmse:0.405408
# [17]	validation_0-rmse:0.402411
# [18]	validation_0-rmse:0.399599
# [19]	validation_0-rmse:0.397102
# [20]	validation_0-rmse:0.394593
# [21]	validation_0-rmse:0.392487
# [22]	validation_0-rmse:0.390326
# [23]	validation_0-rmse:0.388327
# [24]	validation_0-rmse:0.386586
# [25]	validation_0-rmse:0.384743
# [26]	validation_0-rmse:0.383025
# [27]	validation_0-rmse:0.381375
# [28]	validation_0-rmse:0.380014
# [29]	validation_0-rmse:0.378446
# [30]	validation_0-rmse:0.376934
# [31]	validation_0-rmse:0.375755
# [32]	validation_0-rmse:0.374672
# [33]	validation_0-rmse:0.373484
# [34]	validation_0-rmse:0.372534
# [35]	validation_0-rmse:0.371592
# [36]	validation_0-rmse:0.370763
# [37]	validation_0-rmse:0.369971
# [38]	validation_0-rmse:0.36934
# [39]	validation_0-rmse:0.368599
# [40]	validation_0-rmse:0.367945
# [41]	validation_0-rmse:0.367302
# [42]	validation_0-rmse:0.366721
# [43]	validation_0-rmse:0.366089
# [44]	validation_0-rmse:0.365365
# [45]	validation_0-rmse:0.364803
# [46]	validation_0-rmse:0.364317
# [47]	validation_0-rmse:0.363841
# [48]	validation_0-rmse:0.363303
# [49]	validation_0-rmse:0.362915
# [50]	validation_0-rmse:0.362413
# [51]	validation_0-rmse:0.362175
# [52]	validation_0-rmse:0.361759
# [53]	validation_0-rmse:0.361425
# [54]	validation_0-rmse:0.361078
# [55]	validation_0-rmse:0.36067
# [56]	validation_0-rmse:0.360383
# [57]	validation_0-rmse:0.360002
# [58]	validation_0-rmse:0.359733
# [59]	validation_0-rmse:0.359401
# [60]	validation_0-rmse:0.35919
# [61]	validation_0-rmse:0.358851
# [62]	validation_0-rmse:0.358586
# [63]	validation_0-rmse:0.35836
# [64]	validation_0-rmse:0.358116
# [65]	validation_0-rmse:0.357969
# [66]	validation_0-rmse:0.357813
# [67]	validation_0-rmse:0.357682
# [68]	validation_0-rmse:0.357437
# [69]	validation_0-rmse:0.357196
# [70]	validation_0-rmse:0.35697
# [71]	validation_0-rmse:0.356765
# [72]	validation_0-rmse:0.356656
# [73]	validation_0-rmse:0.356554
# [74]	validation_0-rmse:0.356395
# [75]	validation_0-rmse:0.356188
# [76]	validation_0-rmse:0.356073
# [77]	validation_0-rmse:0.355924
# [78]	validation_0-rmse:0.355846
# [79]	validation_0-rmse:0.355786
# [80]	validation_0-rmse:0.355678
# [81]	validation_0-rmse:0.355588
# [82]	validation_0-rmse:0.355496
# [83]	validation_0-rmse:0.355357
# [84]	validation_0-rmse:0.355271
# [85]	validation_0-rmse:0.355239
# [86]	validation_0-rmse:0.355142
# [87]	validation_0-rmse:0.355078
# [88]	validation_0-rmse:0.354975
# [89]	validation_0-rmse:0.354825
# [90]	validation_0-rmse:0.354705
# [91]	validation_0-rmse:0.354667
# [92]	validation_0-rmse:0.354553
# [93]	validation_0-rmse:0.354526
# [94]	validation_0-rmse:0.354408
# [95]	validation_0-rmse:0.354279
# [96]	validation_0-rmse:0.354132
# [97]	validation_0-rmse:0.354073
# [98]	validation_0-rmse:0.353921
# [99]	validation_0-rmse:0.353884
# MSE: 0.13, MAE: 0.27, EV: 0.25, R2: 0.25

# %%
[x for x in train.columns if "generalElectionVote" in x]
# Out:
# ['generalElectionVoteW10_Labour',
#  'generalElectionVoteW10_United Kingdom Independence Party (UKIP)',
#  'generalElectionVoteW10_Liberal Democrat',
#  'generalElectionVoteW10_Scottish National Party (SNP)',
#  'generalElectionVoteW10_Green Party',
#  'generalElectionVoteW10_Plaid Cymru']

# %%
immigDiff["polAttention(W7->W8)__Pay a great deal of attention"][mask].notnull().sum()
# euRefVoteW4: satDemEU(W3->W4)__Very satisfied FINE
# euRefVoteW8: polAtten, likeGrn NOT FINE
# euRefVoteW6: satDemEU(W4->W6)__Very satisfied FINE


# likeGrn(W7->W8)__Strongly like
# satDemEU(W4->W6)__Very satisfied #  fine
var_array = ["polAttention(W7->W8)__Pay a great deal of attention",
             "likeGrn(W7->W8)__Strongly like",
             "satDemEU(W3->W4)__Very satisfied",
             "satDemEU(W4->W6)__Very satisfied"]

# %%
immigDiff[var_array].describe()
# Out:
#        polAttention(W7->W8)__Pay a great deal of attention  \
# count                                       24035.000000
# mean                                           -0.007883
# std                                             1.002270
# min                                            -3.841206
# 25%                                            -0.677913
# 50%                                             0.007219
# 75%                                             0.661153
# max                                             4.344720
#
#        likeGrn(W7->W8)__Strongly like  satDemEU(W3->W4)__Very satisfied  \
# count                    21629.000000                      19714.000000
# mean                         0.007476                         -0.005563
# std                          0.152041                          0.225097
# min                         -1.000000                         -1.000000
# 25%                         -0.100000                          0.000000
# 50%                          0.000000                          0.000000
# 75%                          0.100000                          0.000000
# max                          1.000000                          1.000000
#
#        satDemEU(W4->W6)__Very satisfied
# count                      22698.000000
# mean                           0.007945
# std                            0.225356
# min                           -1.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                            1.000000

# %%
immigDiff[mask].notnull().sum()
# Out:
# euLeaveVoice(W7->W8)__Much higher                           20439
# euLeaveVoice(W8->W10)__Much higher                          12979
# euLeaveVoice(W10->W11)__Much higher                         11999
# euLeaveVoice(W11->W13)__Much higher                         12886
# euID(W10->W11)_The leave side                               11628
# govtHandouts(W1->W2)__Strongly agree                        14648
# govtHandouts(W2->W3)__Strongly agree                        14689
# govtHandouts(W3->W4)__Strongly agree                        15138
# govtHandouts(W4->W7)__Strongly agree                        18344
# conPartnerUKIP(W4->W5)_Would join Conservatives             13308
# electionInterest(W4->W5)__Very interested                   17912
# electionInterest(W5->W6)__Very interested                   18166
# electionInterest(W6->W11)__Very interested                  12452
# electionInterest(W11->W12)__Very interested                 14041
# electionInterest(W12->W13)__Very interested                 14352
# generalElectionVote(W1->W2)_British National Party (BNP)    11811
# generalElectionVote(W2->W3)_British National Party (BNP)    11971
# generalElectionVote(W3->W4)_British National Party (BNP)    12630
# generalElectionVote(W4->W5)_British National Party (BNP)    15629
# generalElectionVote(W5->W7)_Plaid Cymru                     15261
# generalElectionVote(W7->W8)_Plaid Cymru                     17428
# generalElectionVote(W8->W10)_Plaid Cymru                    10353
# generalElectionVote(W10->W11)_Plaid Cymru                    9832
# generalElectionVote(W11->W12)_Plaid Cymru                   12007
# generalElectionVote(W12->W13)_Plaid Cymru                   12527
# controlImmig(W9->W10)__Complete control                     12006
# controlImmig(W10->W11)__Complete control                    11174
# controlImmig(W11->W13)__Complete control                    12272
# euRefVote(W1->W3)_Leave the EU                              11510
# euRefVote(W3->W4)_Leave the EU                              13007
#                                                             ...
# immigCon(W10->W11)__Allow many more                         10048
# immigLab(W7->W8)__Allow many more                           16467
# immigLab(W8->W9)__Allow many more                           14691
# immigLab(W9->W11)__Allow many more                          11594
# lrUKIP(W2->W4)__Right                                       11981
# lrUKIP(W4->W5)__Right                                       14204
# lrUKIP(W5->W6)__Right                                       14632
# lrUKIP(W6->W7)__Right                                       14991
# lrUKIP(W7->W11)__Right                                      12644
# lrUKIP(W11->W12)__Right                                     10940
# euRedTape(W7->W8)__Strongly agree                           19428
# EUIntegrationSelf(W7->W8)__Protect our independence         20850
# EUIntegrationSelf(W8->W9)__Protect our independence         18040
# EUIntegrationSelf(W9->W10)__Protect our independence        13230
# EUIntegrationSelf(W10->W11)__Protect our independence       12153
# EUIntegrationSelf(W11->W12)__Protect our independence       13444
# EUIntegrationSelf(W12->W13)__Protect our independence       13707
# immigEcon(W1->W2)__Good for economy                         14202
# immigEcon(W2->W3)__Good for economy                         14221
# immigEcon(W3->W4)__Good for economy                         14751
# immigEcon(W4->W7)__Good for economy                         17819
# immigEcon(W7->W8)__Good for economy                         20682
# immigEcon(W8->W10)__Good for economy                        13141
# immigEcon(W10->W11)__Good for economy                       12087
# immigEcon(W11->W13)__Good for economy                       12962
# remainTone(W7->W8)__5 - Hope                                19046
# normEU(W7->W8)__Strongly agree                              15830
# EUIntegrationLD(W8->W11)__Protect our independence          10158
# EUIntegrationLD(W11->W12)__Protect our independence         10632
# EUIntegrationLD(W12->W13)__Protect our independence         10976
# Length: 303, dtype: int64

# %%
threshold = .1
min_features = 20
global_shap_vals = np.abs(shap_values).mean(0)[:-1]
n_top_features = sum(global_shap_vals[np.argsort(global_shap_vals)]>=threshold)
if n_top_features <min_features:
    n_top_features = min_features



##########################

inds = np.argsort(global_shap_vals)[-n_top_features:]

y_pos = np.arange(n_top_features)
plt.figure(figsize=(16,10))
plt.title(target_var);
plt.barh(y_pos, global_shap_vals[inds], color="#1E88E5")
plt.yticks(y_pos, train.columns[inds])
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.xlabel("mean SHAP value magnitude (change in log odds)")
plt.gcf().set_size_inches(6, 4.5)
# Out:
# C:\ProgramData\Anaconda3\envs\BES_analysis\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in greater_equal
#   after removing the cwd from sys.path.

# %%
shap_values.shape
# Out:
# (24266, 52)

# %%
import gc
gc.collect()
# Out:
# 8133

# %%
fig = plt.figure()
fig.suptitle("FGFGFGFGFG");
shap.summary_plot( shap_values, train, max_display=n_top_features, plot_type='dot');
fig.savefig( output_subfolder + "summary_plot" + ".png", bbox_inches='tight' )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-9f3d9be0e48f> in <module>()
#       1 fig = plt.figure()
#       2 fig.suptitle("FGFGFGFGFG");
# ----> 3 fig.set_title("Better title");
#       4 shap.summary_plot( shap_values, train, max_display=n_top_features, plot_type='dot', title ="gfgfgf" );
#       5 fig.savefig( output_subfolder + "summary_plot" + ".png", bbox_inches='tight' )
#
# AttributeError: 'Figure' object has no attribute 'set_title'

# %%
output_subfolder
# Out:
# '../BES_analysis_output/xgboost_testing\\partyIdW13_No - none\\'
