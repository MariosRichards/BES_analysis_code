# %%
# lets open BES wave 14!

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import gc
import re

from itertools import cycle
from IPython.display import display
import pickle, os

import seaborn as sns

encoding = "ISO-8859-1"

import Jupyter_module_loader

# %%
# you should clone this git to this subdirectory (in some directory - I call it BES_analysis - doesn't matter though)

if os.getcwd().split(os.sep)[-1] != 'BES_analysis_code':
    raise Exception("Stop! You're in the wrong directory - should be in 'BES_analysis_code'")

BES_code_folder   = "../BES_analysis_code/" # we should be here!
BES_small_data_files = BES_code_folder + "small data files" + os.sep
if not os.path.exists( BES_small_data_files ):
    os.makedirs( BES_small_data_files )

# we should create these if they don't already exist
BES_data_folder   = "../BES_analysis_data/"
if not os.path.exists( BES_data_folder ):
    os.makedirs( BES_data_folder )

BES_output_folder = "../BES_analysis_output/"
if not os.path.exists( BES_output_folder ):
    os.makedirs( BES_output_folder )
    
BES_file_manifest = pd.read_csv( BES_small_data_files + "BES_file_manifest.csv" )

BES_R_data_files = BES_data_folder + "R_data" + os.sep
if not os.path.exists( BES_R_data_files ):
    os.makedirs( BES_R_data_files )

# %%
dataset_name = "W14_comb"

# %%
# dataset_name = "W14_only"
# data_subfolder = BES_data_folder + dataset_name + os.sep
# dataset_filename = "BES2017_W14_v0.3.dta"
# BES_Panel  = pd.read_stata(data_subfolder + dataset_filename)
# print("BES_Panel", BES_Panel.shape )

# %%
# dataset_name = "W14_only"
# data_subfolder = BES_data_folder + dataset_name + os.sep
# BES_Panel.to_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))

# %%
# dataset_name = "W14_comb"
# data_subfolder = BES_data_folder + dataset_name + os.sep
# dataset_filename = "BES2017_W14_Panel_v0.3.dta"
# BES_Panel2  = pd.read_stata(data_subfolder + dataset_filename)
# print("BES_Panel2", BES_Panel2.shape )
# BES_Panel2.to_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))

# %%
# BES_Panel2.to_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))

# %%
# %%time

manifest = BES_file_manifest[ BES_file_manifest["Name"] == dataset_name ]

data_subfolder = BES_data_folder + dataset_name + os.sep

dataset_filename = manifest["Stata_Filename"].values[0]
# dataset_description = manifest["Friendlier_Description"].values[0]
# dataset_citation = manifest["Citation"].values[0]
# dataset_start = manifest["Date_Start"].values[0]
# dataset_stop = manifest["Date_Stop"].values[0]
# dataset_wave = manifest["Wave No"].values[0]

BES_Panel  = pd.read_msgpack(data_subfolder + dataset_filename.replace('.dta','.msgpack'))
print("BES_Panel", BES_Panel.shape )

####

# BES_numeric = pd.read_hdf( data_subfolder + "BESnumeric.hdf", "BESnumeric" )
# print("BES_numeric",  BES_numeric.shape )

# var_type    = pd.read_csv( data_subfolder + "var_type.csv", encoding=encoding)
# var_type.set_index("Unnamed: 0", inplace=True)
# print("var_type",  var_type.shape )

# fname = data_subfolder + "cat_dictionary.pkl"
# with open(fname, "rb") as f:
#     cat_dictionary = pickle.load( f )
    
# ####

# # BES_non_numeric = pd.read_hdf( data_subfolder + "BESnon_numeric.hdf", "BESnon_numeric" )
# # print("BES_non_numeric",  BES_non_numeric.shape )

# BES_reduced = pd.read_hdf( data_subfolder + "BES_reduced.hdf", "BES_reduced" )
# print("BES_reduced",  BES_reduced.shape )

# BES_reduced_with_na = pd.read_hdf( data_subfolder + "BES_reduced_with_na.hdf", "BES_reduced_with_na")
# print("BES_reduced_with_na", BES_reduced_with_na.shape )

# fname = data_subfolder + "new_old_col_names.pkl"
# with open(fname, "rb") as f:
#     new_old_col_names = pickle.load(f)
# Out:
# BES_Panel (73703, 5692)
# Wall time: 9.09 s

# %%
euIDcols = [x for x in BES_Panel.columns if "euID" in x]
euIDcols

# %%
output_subfolder = BES_output_folder +  os.sep + "randomFunPlots"
if not os.path.exists( output_subfolder ):
    os.makedirs( output_subfolder )

# %%
plt.figure(figsize=(12,8))
sns.countplot(BES_Panel["euID"]);
plt.savefig(output_subfolder +  os.sep + "euID" + ".png", bbox_inches='tight')

# %%
euIDs = [x for x in BES_Panel.columns if re.match("euID\d", x)]
euIDs
# Out:
# ['euID1', 'euID2', 'euID3', 'euID4', 'euID6', 'euID7']

# %%
plt.figure(figsize=(12,8))
euID_for_plot = BES_Panel[euIDs].apply(lambda x: x.cat.codes).replace(-1, np.nan).stack().reset_index().drop("level_0",axis=1)
euID_for_plot = BES_Panel[euIDs].stack().reset_index().drop("level_0",axis=1)
euID_for_plot[0] = euID_for_plot[0].astype('category').cat.set_categories(BES_Panel[euIDs[0]].cat.categories)
sns.countplot(data = euID_for_plot, x = "level_1",hue=0);
plt.xticks(rotation=45);
plt.savefig(output_subfolder +  os.sep + "euID_subquestions" + ".png", bbox_inches='tight')

# %%
pIDs = [x for x in BES_Panel.columns if re.match("pid", x)]
pIDs
# Out:
# ['pidWeThey',
#  'pidInterestedOthers',
#  'pidCriticiseParty',
#  'pidCommonParty',
#  'pidRuinDay',
#  'pidConnected',
#  'pidMyParty',
#  'pidPraiseGood']

# %%
plt.figure(figsize=(12,8))
euID_for_plot = BES_Panel[pIDs].apply(lambda x: x.cat.codes).replace(-1, np.nan).stack().reset_index().drop("level_0",axis=1)
euID_for_plot = BES_Panel[pIDs].stack().reset_index().drop("level_0",axis=1)
euID_for_plot[0] = euID_for_plot[0].astype('category').cat.set_categories(BES_Panel[pIDs[0]].cat.categories)
sns.countplot(data = euID_for_plot, x = "level_1",hue=0);
plt.xticks(rotation=45);
plt.savefig(output_subfolder + os.sep + "partyID_subquestions" + ".png", bbox_inches='tight')

# %%
partyId = [x for x in BES_Panel.columns if re.match("partyId", x)]
partyId
# Out:
# ['partyIdStrength', 'partyId', 'partyIdSqueeze']

# %%
BES_Panel[partyId]
# Out:
#        partyIdStrength                                   partyId  \
# 0        Fairly strong                              Conservative
# 1      Not very strong                          Liberal Democrat
# 2        Fairly strong                                    Labour
# 3      Not very strong                              Conservative
# 4                  NaN                                 No - none
# 5        Fairly strong                                     Other
# 6          Very strong                                    Labour
# 7      Not very strong                                 No - none
# 8      Not very strong                              Conservative
# 9      Not very strong                                    Labour
# 10                 NaN                                 No - none
# 11         Very strong                              Conservative
# 12       Fairly strong                              Conservative
# 13       Fairly strong                              Conservative
# 14       Fairly strong                              Conservative
# 15     Not very strong                                    Labour
# 16       Fairly strong                                 No - none
# 17         Very strong                              Conservative
# 18     Not very strong                          Liberal Democrat
# 19     Not very strong                              Conservative
# 20     Not very strong                                 No - none
# 21         Very strong                                    Labour
# 22                 NaN                                 No - none
# 23       Fairly strong                                    Labour
# 24       Fairly strong                              Conservative
# 25                 NaN                                 No - none
# 26       Fairly strong                              Conservative
# 27     Not very strong                              Conservative
# 28     Not very strong                                 No - none
# 29       Fairly strong                              Conservative
# ...                ...                                       ...
# 31033      Very strong             Scottish National Party (SNP)
# 31034              NaN                                 No - none
# 31035      Very strong             Scottish National Party (SNP)
# 31036  Not very strong                                 No - none
# 31037    Fairly strong  United Kingdom Independence Party (UKIP)
# 31038    Fairly strong                              Conservative
# 31039    Fairly strong                                    Labour
# 31040    Fairly strong                                    Labour
# 31041              NaN                                 No - none
# 31042    Fairly strong                                    Labour
# 31043    Fairly strong                              Conservative
# 31044  Not very strong                                    Labour
# 31045              NaN                                 No - none
# 31046  Not very strong                              Conservative
# 31047    Fairly strong                              Conservative
# 31048    Fairly strong                               Green Party
# 31049  Not very strong                                Don't know
# 31050      Very strong                                    Labour
# 31051  Not very strong                               Green Party
# 31052  Not very strong                                 No - none
# 31053    Fairly strong  United Kingdom Independence Party (UKIP)
# 31054    Fairly strong                                    Labour
# 31055    Fairly strong                                    Labour
# 31056  Not very strong                                 No - none
# 31057  Not very strong                          Liberal Democrat
# 31058              NaN                                 No - none
# 31059    Fairly strong                          Liberal Democrat
# 31060  Not very strong                              Conservative
# 31061    Fairly strong                              Conservative
# 31062       Don't know                                    Labour
#
#                                  partyIdSqueeze
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                     No - none
# 5                                           NaN
# 6                                           NaN
# 7                                   Green Party
# 8                                           NaN
# 9                                           NaN
# 10                                    No - none
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                 Conservative
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                             Liberal Democrat
# 21                                          NaN
# 22                                    No - none
# 23                                          NaN
# 24                                          NaN
# 25                                    No - none
# 26                                          NaN
# 27                                          NaN
# 28     United Kingdom Independence Party (UKIP)
# 29                                          NaN
# ...                                         ...
# 31033                                       NaN
# 31034                                 No - none
# 31035                                       NaN
# 31036                               Green Party
# 31037                                       NaN
# 31038                                       NaN
# 31039                                       NaN
# 31040                                       NaN
# 31041                                 No - none
# 31042                                       NaN
# 31043                                       NaN
# 31044                                       NaN
# 31045                                 No - none
# 31046                                       NaN
# 31047                                       NaN
# 31048                                       NaN
# 31049                                    Labour
# 31050                                       NaN
# 31051                                       NaN
# 31052                               Green Party
# 31053                                       NaN
# 31054                                       NaN
# 31055                                       NaN
# 31056                              Conservative
# 31057                                       NaN
# 31058                                 No - none
# 31059                                       NaN
# 31060                                       NaN
# 31061                                       NaN
# 31062                                       NaN
#
# [31063 rows x 3 columns]

# %%
sns.countplot(BES_Panel["partyIdStrength"]);

# %%
sns.countplot(BES_Panel["partyId"]);
plt.xticks(rotation =90);

# %%
# over wave comparison?
# - test with everything first
# - summarise with SA/A - SD/D
# - party/neither-none/dk

# %%
partyId = [x for x in BES_Panel.columns if re.match("partyIdW", x)]
partyId
# Out:
# ['partyIdW1',
#  'partyIdW2',
#  'partyIdW3',
#  'partyIdW4',
#  'partyIdW6',
#  'partyIdW7',
#  'partyIdW8',
#  'partyIdW9',
#  'partyIdW10',
#  'partyIdW11',
#  'partyIdW12',
#  'partyIdW13',
#  'partyIdW14']

# %%
BES_Panel[partyId]
# Out:
#                                       partyIdW1  \
# 0                                        Labour
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                  Conservative
# 4                                  Conservative
# 5                                        Labour
# 6                                        Labour
# 7      United Kingdom Independence Party (UKIP)
# 8                                        Labour
# 9                                  Conservative
# 10                                 Conservative
# 11     United Kingdom Independence Party (UKIP)
# 12                                 Conservative
# 13                                    No - none
# 14                                          NaN
# 15                                    No - none
# 16                                 Conservative
# 17                                        Other
# 18                                       Labour
# 19     United Kingdom Independence Party (UKIP)
# 20                                 Conservative
# 21                             Liberal Democrat
# 22     United Kingdom Independence Party (UKIP)
# 23                                    No - none
# 24     United Kingdom Independence Party (UKIP)
# 25                                       Labour
# 26                                    No - none
# 27                             Liberal Democrat
# 28                                 Conservative
# 29                                    No - none
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                                       partyIdW2  \
# 0      United Kingdom Independence Party (UKIP)
# 1                                           NaN
# 2                              Liberal Democrat
# 3                                  Conservative
# 4                                  Conservative
# 5                                        Labour
# 6                                         Other
# 7                                  Conservative
# 8                                        Labour
# 9                                  Conservative
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                 Conservative
# 14                                 Conservative
# 15                                    No - none
# 16                                 Conservative
# 17                                        Other
# 18                                       Labour
# 19     United Kingdom Independence Party (UKIP)
# 20                                          NaN
# 21                                          NaN
# 22     United Kingdom Independence Party (UKIP)
# 23                                    No - none
# 24     United Kingdom Independence Party (UKIP)
# 25                                       Labour
# 26                                    No - none
# 27                             Liberal Democrat
# 28                                 Conservative
# 29                 British National Party (BNP)
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                                       partyIdW3         partyIdW4  \
# 0                                           NaN            Labour
# 1                                  Conservative      Conservative
# 2                              Liberal Democrat  Liberal Democrat
# 3                                           NaN               NaN
# 4                                           NaN               NaN
# 5                                        Labour            Labour
# 6                                           NaN             Other
# 7      United Kingdom Independence Party (UKIP)      Conservative
# 8                                        Labour            Labour
# 9                                  Conservative               NaN
# 10                                          NaN      Conservative
# 11                                          NaN               NaN
# 12                                 Conservative               NaN
# 13                                    No - none      Conservative
# 14     United Kingdom Independence Party (UKIP)      Conservative
# 15                                    No - none               NaN
# 16                                 Conservative      Conservative
# 17                                        Other               NaN
# 18                                       Labour            Labour
# 19     United Kingdom Independence Party (UKIP)               NaN
# 20                                          NaN               NaN
# 21                                          NaN               NaN
# 22     United Kingdom Independence Party (UKIP)        Don't know
# 23                                    No - none       Green Party
# 24     United Kingdom Independence Party (UKIP)               NaN
# 25                                          NaN               NaN
# 26                                          NaN         No - none
# 27                             Liberal Democrat  Liberal Democrat
# 28                                 Conservative      Conservative
# 29                                    No - none            Labour
# ...                                         ...               ...
# 73673                                       NaN               NaN
# 73674                                       NaN               NaN
# 73675                                       NaN               NaN
# 73676                                       NaN               NaN
# 73677                                       NaN               NaN
# 73678                                       NaN               NaN
# 73679                                       NaN               NaN
# 73680                                       NaN               NaN
# 73681                                       NaN               NaN
# 73682                                       NaN               NaN
# 73683                                       NaN               NaN
# 73684                                       NaN               NaN
# 73685                                       NaN               NaN
# 73686                                       NaN               NaN
# 73687                                       NaN               NaN
# 73688                                       NaN               NaN
# 73689                                       NaN               NaN
# 73690                                       NaN               NaN
# 73691                                       NaN               NaN
# 73692                                       NaN               NaN
# 73693                                       NaN               NaN
# 73694                                       NaN               NaN
# 73695                                       NaN               NaN
# 73696                                       NaN               NaN
# 73697                                       NaN               NaN
# 73698                                       NaN               NaN
# 73699                                       NaN               NaN
# 73700                                       NaN               NaN
# 73701                                       NaN               NaN
# 73702                                       NaN               NaN
#
#                                       partyIdW6  \
# 0                                        Labour
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                           NaN
# 4                                           NaN
# 5                                        Labour
# 6                 Scottish National Party (SNP)
# 7                                  Conservative
# 8                                        Labour
# 9                                  Conservative
# 10                                 Conservative
# 11                                          NaN
# 12                                 Conservative
# 13     United Kingdom Independence Party (UKIP)
# 14                                 Conservative
# 15                             Liberal Democrat
# 16                                 Conservative
# 17                Scottish National Party (SNP)
# 18                                       Labour
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22     United Kingdom Independence Party (UKIP)
# 23                                    No - none
# 24                                          NaN
# 25                                          NaN
# 26                                    No - none
# 27                             Liberal Democrat
# 28                                 Conservative
# 29                                       Labour
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                                       partyIdW7  \
# 0                                        Labour
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                           NaN
# 4                                           NaN
# 5                                        Labour
# 6                 Scottish National Party (SNP)
# 7                                  Conservative
# 8                                     No - none
# 9                                  Conservative
# 10                                 Conservative
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                 Conservative
# 15                                          NaN
# 16                                 Conservative
# 17                                          NaN
# 18                                       Labour
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22     United Kingdom Independence Party (UKIP)
# 23                                          NaN
# 24                                          NaN
# 25                                       Labour
# 26                                    No - none
# 27                                          NaN
# 28                                 Conservative
# 29                                       Labour
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                            partyIdW8     partyIdW9  \
# 0                             Labour        Labour
# 1                       Conservative  Conservative
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# 5                                NaN           NaN
# 6      Scottish National Party (SNP)           NaN
# 7                                NaN           NaN
# 8                          No - none        Labour
# 9                                NaN  Conservative
# 10                      Conservative           NaN
# 11                               NaN           NaN
# 12                               NaN           NaN
# 13                               NaN           NaN
# 14                      Conservative  Conservative
# 15                               NaN           NaN
# 16                      Conservative           NaN
# 17                         No - none     No - none
# 18                               NaN        Labour
# 19                               NaN           NaN
# 20                               NaN           NaN
# 21                               NaN           NaN
# 22                         No - none     No - none
# 23                               NaN           NaN
# 24                               NaN           NaN
# 25                               NaN           NaN
# 26                               NaN           NaN
# 27                               NaN           NaN
# 28                      Conservative  Conservative
# 29                         No - none        Labour
# ...                              ...           ...
# 73673                            NaN           NaN
# 73674                            NaN           NaN
# 73675                            NaN           NaN
# 73676                            NaN           NaN
# 73677                            NaN           NaN
# 73678                            NaN           NaN
# 73679                            NaN           NaN
# 73680                            NaN           NaN
# 73681                            NaN           NaN
# 73682                            NaN           NaN
# 73683                            NaN           NaN
# 73684                            NaN           NaN
# 73685                            NaN           NaN
# 73686                            NaN           NaN
# 73687                            NaN           NaN
# 73688                            NaN           NaN
# 73689                            NaN           NaN
# 73690                            NaN           NaN
# 73691                            NaN           NaN
# 73692                            NaN           NaN
# 73693                            NaN           NaN
# 73694                            NaN           NaN
# 73695                            NaN           NaN
# 73696                            NaN           NaN
# 73697                            NaN           NaN
# 73698                            NaN           NaN
# 73699                            NaN           NaN
# 73700                            NaN           NaN
# 73701                            NaN           NaN
# 73702                            NaN           NaN
#
#                                      partyIdW10        partyIdW11  \
# 0      United Kingdom Independence Party (UKIP)               NaN
# 1                                  Conservative      Conservative
# 2                              Liberal Democrat  Liberal Democrat
# 3                                           NaN               NaN
# 4                                           NaN               NaN
# 5                                           NaN            Labour
# 6                                        Labour            Labour
# 7                                  Conservative      Conservative
# 8                                        Labour            Labour
# 9                                           NaN               NaN
# 10                                 Conservative               NaN
# 11                                          NaN               NaN
# 12                                          NaN               NaN
# 13                                 Conservative      Conservative
# 14                                 Conservative      Conservative
# 15                                          NaN               NaN
# 16                                 Conservative               NaN
# 17                                    No - none         No - none
# 18                                          NaN               NaN
# 19                                          NaN               NaN
# 20                                          NaN               NaN
# 21                                          NaN  Liberal Democrat
# 22                                          NaN               NaN
# 23                                          NaN         No - none
# 24                                          NaN               NaN
# 25                                          NaN               NaN
# 26                                          NaN               NaN
# 27                                          NaN               NaN
# 28                                          NaN      Conservative
# 29                                       Labour         No - none
# ...                                         ...               ...
# 73673                                       NaN               NaN
# 73674                                       NaN               NaN
# 73675                                       NaN               NaN
# 73676                                       NaN               NaN
# 73677                                       NaN               NaN
# 73678                                       NaN               NaN
# 73679                                       NaN               NaN
# 73680                                       NaN               NaN
# 73681                                       NaN               NaN
# 73682                                       NaN               NaN
# 73683                                       NaN               NaN
# 73684                                       NaN               NaN
# 73685                                       NaN               NaN
# 73686                                       NaN               NaN
# 73687                                       NaN               NaN
# 73688                                       NaN               NaN
# 73689                                       NaN               NaN
# 73690                                       NaN               NaN
# 73691                                       NaN               NaN
# 73692                                       NaN               NaN
# 73693                                       NaN               NaN
# 73694                                       NaN               NaN
# 73695                                       NaN               NaN
# 73696                                       NaN               NaN
# 73697                                       NaN               NaN
# 73698                                       NaN               NaN
# 73699                                       NaN               NaN
# 73700                                       NaN               NaN
# 73701                                       NaN               NaN
# 73702                                       NaN               NaN
#
#              partyIdW12                     partyIdW13  \
# 0                   NaN                            NaN
# 1          Conservative                   Conservative
# 2      Liberal Democrat               Liberal Democrat
# 3                   NaN                            NaN
# 4                   NaN                            NaN
# 5                   NaN                         Labour
# 6                Labour                         Labour
# 7          Conservative                   Conservative
# 8                Labour                         Labour
# 9          Conservative                            NaN
# 10                  NaN                            NaN
# 11                  NaN                            NaN
# 12                  NaN                            NaN
# 13         Conservative                   Conservative
# 14         Conservative                   Conservative
# 15                  NaN                            NaN
# 16         Conservative                            NaN
# 17            No - none  Scottish National Party (SNP)
# 18                  NaN                            NaN
# 19                  NaN                            NaN
# 20                  NaN                            NaN
# 21                  NaN                            NaN
# 22                  NaN                            NaN
# 23          Green Party                            NaN
# 24                  NaN                            NaN
# 25                  NaN                            NaN
# 26                  NaN                            NaN
# 27                  NaN                            NaN
# 28         Conservative                   Conservative
# 29               Labour                         Labour
# ...                 ...                            ...
# 73673               NaN                            NaN
# 73674               NaN                            NaN
# 73675               NaN                            NaN
# 73676               NaN                            NaN
# 73677               NaN                            NaN
# 73678               NaN                            NaN
# 73679               NaN                            NaN
# 73680               NaN                            NaN
# 73681               NaN                            NaN
# 73682               NaN                            NaN
# 73683               NaN                            NaN
# 73684               NaN                            NaN
# 73685               NaN                            NaN
# 73686               NaN                            NaN
# 73687               NaN                            NaN
# 73688               NaN                            NaN
# 73689               NaN                            NaN
# 73690               NaN                            NaN
# 73691               NaN                            NaN
# 73692               NaN                            NaN
# 73693               NaN                            NaN
# 73694               NaN                            NaN
# 73695               NaN                            NaN
# 73696               NaN                            NaN
# 73697               NaN                            NaN
# 73698               NaN                            NaN
# 73699               NaN                            NaN
# 73700               NaN                            NaN
# 73701               NaN                            NaN
# 73702               NaN                            NaN
#
#                                      partyIdW14
# 0                                           NaN
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                        Labour
# 7                                  Conservative
# 8                                     No - none
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                        Other
# 18                                       Labour
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                    No - none
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                 Conservative
# 29                                       Labour
# ...                                         ...
# 73673             Scottish National Party (SNP)
# 73674                                 No - none
# 73675             Scottish National Party (SNP)
# 73676                                 No - none
# 73677  United Kingdom Independence Party (UKIP)
# 73678                              Conservative
# 73679                                    Labour
# 73680                                    Labour
# 73681                                 No - none
# 73682                                    Labour
# 73683                              Conservative
# 73684                                    Labour
# 73685                                 No - none
# 73686                              Conservative
# 73687                              Conservative
# 73688                               Green Party
# 73689                                Don't know
# 73690                                    Labour
# 73691                               Green Party
# 73692                                 No - none
# 73693  United Kingdom Independence Party (UKIP)
# 73694                                    Labour
# 73695                                    Labour
# 73696                                 No - none
# 73697                          Liberal Democrat
# 73698                                 No - none
# 73699                          Liberal Democrat
# 73700                              Conservative
# 73701                              Conservative
# 73702                                    Labour
#
# [73703 rows x 13 columns]

# %%
BES_Panel[partyId[0]].cat.categories
# Out:
# Index(['Conservative', 'Labour', 'Liberal Democrat',
#        'Scottish National Party (SNP)', 'Plaid Cymru',
#        'United Kingdom Independence Party (UKIP)', 'Green Party',
#        'British National Party (BNP)', 'Other', 'No - none', 'Don't know'],
#       dtype='object')

# %%
party_cats = []
for col_num in range(0,len(partyId)):
    party_cats.extend(list(BES_Panel[partyId[col_num]].cat.categories))
    
party_cats = list(set(party_cats))
for col_num in range(0,len(partyId)):
    BES_Panel[partyId[col_num]] = BES_Panel[partyId[col_num]].cat.set_categories(party_cats)

# %%
BES_Panel[partyId]
# Out:
#                                       partyIdW1  \
# 0                                        Labour
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                  Conservative
# 4                                  Conservative
# 5                                        Labour
# 6                                        Labour
# 7      United Kingdom Independence Party (UKIP)
# 8                                        Labour
# 9                                  Conservative
# 10                                 Conservative
# 11     United Kingdom Independence Party (UKIP)
# 12                                 Conservative
# 13                                    No - none
# 14                                          NaN
# 15                                    No - none
# 16                                 Conservative
# 17                                        Other
# 18                                       Labour
# 19     United Kingdom Independence Party (UKIP)
# 20                                 Conservative
# 21                             Liberal Democrat
# 22     United Kingdom Independence Party (UKIP)
# 23                                    No - none
# 24     United Kingdom Independence Party (UKIP)
# 25                                       Labour
# 26                                    No - none
# 27                             Liberal Democrat
# 28                                 Conservative
# 29                                    No - none
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                                       partyIdW2  \
# 0      United Kingdom Independence Party (UKIP)
# 1                                           NaN
# 2                              Liberal Democrat
# 3                                  Conservative
# 4                                  Conservative
# 5                                        Labour
# 6                                         Other
# 7                                  Conservative
# 8                                        Labour
# 9                                  Conservative
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                 Conservative
# 14                                 Conservative
# 15                                    No - none
# 16                                 Conservative
# 17                                        Other
# 18                                       Labour
# 19     United Kingdom Independence Party (UKIP)
# 20                                          NaN
# 21                                          NaN
# 22     United Kingdom Independence Party (UKIP)
# 23                                    No - none
# 24     United Kingdom Independence Party (UKIP)
# 25                                       Labour
# 26                                    No - none
# 27                             Liberal Democrat
# 28                                 Conservative
# 29                 British National Party (BNP)
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                                       partyIdW3         partyIdW4  \
# 0                                           NaN            Labour
# 1                                  Conservative      Conservative
# 2                              Liberal Democrat  Liberal Democrat
# 3                                           NaN               NaN
# 4                                           NaN               NaN
# 5                                        Labour            Labour
# 6                                           NaN             Other
# 7      United Kingdom Independence Party (UKIP)      Conservative
# 8                                        Labour            Labour
# 9                                  Conservative               NaN
# 10                                          NaN      Conservative
# 11                                          NaN               NaN
# 12                                 Conservative               NaN
# 13                                    No - none      Conservative
# 14     United Kingdom Independence Party (UKIP)      Conservative
# 15                                    No - none               NaN
# 16                                 Conservative      Conservative
# 17                                        Other               NaN
# 18                                       Labour            Labour
# 19     United Kingdom Independence Party (UKIP)               NaN
# 20                                          NaN               NaN
# 21                                          NaN               NaN
# 22     United Kingdom Independence Party (UKIP)        Don't know
# 23                                    No - none       Green Party
# 24     United Kingdom Independence Party (UKIP)               NaN
# 25                                          NaN               NaN
# 26                                          NaN         No - none
# 27                             Liberal Democrat  Liberal Democrat
# 28                                 Conservative      Conservative
# 29                                    No - none            Labour
# ...                                         ...               ...
# 73673                                       NaN               NaN
# 73674                                       NaN               NaN
# 73675                                       NaN               NaN
# 73676                                       NaN               NaN
# 73677                                       NaN               NaN
# 73678                                       NaN               NaN
# 73679                                       NaN               NaN
# 73680                                       NaN               NaN
# 73681                                       NaN               NaN
# 73682                                       NaN               NaN
# 73683                                       NaN               NaN
# 73684                                       NaN               NaN
# 73685                                       NaN               NaN
# 73686                                       NaN               NaN
# 73687                                       NaN               NaN
# 73688                                       NaN               NaN
# 73689                                       NaN               NaN
# 73690                                       NaN               NaN
# 73691                                       NaN               NaN
# 73692                                       NaN               NaN
# 73693                                       NaN               NaN
# 73694                                       NaN               NaN
# 73695                                       NaN               NaN
# 73696                                       NaN               NaN
# 73697                                       NaN               NaN
# 73698                                       NaN               NaN
# 73699                                       NaN               NaN
# 73700                                       NaN               NaN
# 73701                                       NaN               NaN
# 73702                                       NaN               NaN
#
#                                       partyIdW6  \
# 0                                        Labour
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                           NaN
# 4                                           NaN
# 5                                        Labour
# 6                 Scottish National Party (SNP)
# 7                                  Conservative
# 8                                        Labour
# 9                                  Conservative
# 10                                 Conservative
# 11                                          NaN
# 12                                 Conservative
# 13     United Kingdom Independence Party (UKIP)
# 14                                 Conservative
# 15                             Liberal Democrat
# 16                                 Conservative
# 17                Scottish National Party (SNP)
# 18                                       Labour
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22     United Kingdom Independence Party (UKIP)
# 23                                    No - none
# 24                                          NaN
# 25                                          NaN
# 26                                    No - none
# 27                             Liberal Democrat
# 28                                 Conservative
# 29                                       Labour
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                                       partyIdW7  \
# 0                                        Labour
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                           NaN
# 4                                           NaN
# 5                                        Labour
# 6                 Scottish National Party (SNP)
# 7                                  Conservative
# 8                                     No - none
# 9                                  Conservative
# 10                                 Conservative
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                 Conservative
# 15                                          NaN
# 16                                 Conservative
# 17                                          NaN
# 18                                       Labour
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22     United Kingdom Independence Party (UKIP)
# 23                                          NaN
# 24                                          NaN
# 25                                       Labour
# 26                                    No - none
# 27                                          NaN
# 28                                 Conservative
# 29                                       Labour
# ...                                         ...
# 73673                                       NaN
# 73674                                       NaN
# 73675                                       NaN
# 73676                                       NaN
# 73677                                       NaN
# 73678                                       NaN
# 73679                                       NaN
# 73680                                       NaN
# 73681                                       NaN
# 73682                                       NaN
# 73683                                       NaN
# 73684                                       NaN
# 73685                                       NaN
# 73686                                       NaN
# 73687                                       NaN
# 73688                                       NaN
# 73689                                       NaN
# 73690                                       NaN
# 73691                                       NaN
# 73692                                       NaN
# 73693                                       NaN
# 73694                                       NaN
# 73695                                       NaN
# 73696                                       NaN
# 73697                                       NaN
# 73698                                       NaN
# 73699                                       NaN
# 73700                                       NaN
# 73701                                       NaN
# 73702                                       NaN
#
#                            partyIdW8     partyIdW9  \
# 0                             Labour        Labour
# 1                       Conservative  Conservative
# 2                                NaN           NaN
# 3                                NaN           NaN
# 4                                NaN           NaN
# 5                                NaN           NaN
# 6      Scottish National Party (SNP)           NaN
# 7                                NaN           NaN
# 8                          No - none        Labour
# 9                                NaN  Conservative
# 10                      Conservative           NaN
# 11                               NaN           NaN
# 12                               NaN           NaN
# 13                               NaN           NaN
# 14                      Conservative  Conservative
# 15                               NaN           NaN
# 16                      Conservative           NaN
# 17                         No - none     No - none
# 18                               NaN        Labour
# 19                               NaN           NaN
# 20                               NaN           NaN
# 21                               NaN           NaN
# 22                         No - none     No - none
# 23                               NaN           NaN
# 24                               NaN           NaN
# 25                               NaN           NaN
# 26                               NaN           NaN
# 27                               NaN           NaN
# 28                      Conservative  Conservative
# 29                         No - none        Labour
# ...                              ...           ...
# 73673                            NaN           NaN
# 73674                            NaN           NaN
# 73675                            NaN           NaN
# 73676                            NaN           NaN
# 73677                            NaN           NaN
# 73678                            NaN           NaN
# 73679                            NaN           NaN
# 73680                            NaN           NaN
# 73681                            NaN           NaN
# 73682                            NaN           NaN
# 73683                            NaN           NaN
# 73684                            NaN           NaN
# 73685                            NaN           NaN
# 73686                            NaN           NaN
# 73687                            NaN           NaN
# 73688                            NaN           NaN
# 73689                            NaN           NaN
# 73690                            NaN           NaN
# 73691                            NaN           NaN
# 73692                            NaN           NaN
# 73693                            NaN           NaN
# 73694                            NaN           NaN
# 73695                            NaN           NaN
# 73696                            NaN           NaN
# 73697                            NaN           NaN
# 73698                            NaN           NaN
# 73699                            NaN           NaN
# 73700                            NaN           NaN
# 73701                            NaN           NaN
# 73702                            NaN           NaN
#
#                                      partyIdW10        partyIdW11  \
# 0      United Kingdom Independence Party (UKIP)               NaN
# 1                                  Conservative      Conservative
# 2                              Liberal Democrat  Liberal Democrat
# 3                                           NaN               NaN
# 4                                           NaN               NaN
# 5                                           NaN            Labour
# 6                                        Labour            Labour
# 7                                  Conservative      Conservative
# 8                                        Labour            Labour
# 9                                           NaN               NaN
# 10                                 Conservative               NaN
# 11                                          NaN               NaN
# 12                                          NaN               NaN
# 13                                 Conservative      Conservative
# 14                                 Conservative      Conservative
# 15                                          NaN               NaN
# 16                                 Conservative               NaN
# 17                                    No - none         No - none
# 18                                          NaN               NaN
# 19                                          NaN               NaN
# 20                                          NaN               NaN
# 21                                          NaN  Liberal Democrat
# 22                                          NaN               NaN
# 23                                          NaN         No - none
# 24                                          NaN               NaN
# 25                                          NaN               NaN
# 26                                          NaN               NaN
# 27                                          NaN               NaN
# 28                                          NaN      Conservative
# 29                                       Labour         No - none
# ...                                         ...               ...
# 73673                                       NaN               NaN
# 73674                                       NaN               NaN
# 73675                                       NaN               NaN
# 73676                                       NaN               NaN
# 73677                                       NaN               NaN
# 73678                                       NaN               NaN
# 73679                                       NaN               NaN
# 73680                                       NaN               NaN
# 73681                                       NaN               NaN
# 73682                                       NaN               NaN
# 73683                                       NaN               NaN
# 73684                                       NaN               NaN
# 73685                                       NaN               NaN
# 73686                                       NaN               NaN
# 73687                                       NaN               NaN
# 73688                                       NaN               NaN
# 73689                                       NaN               NaN
# 73690                                       NaN               NaN
# 73691                                       NaN               NaN
# 73692                                       NaN               NaN
# 73693                                       NaN               NaN
# 73694                                       NaN               NaN
# 73695                                       NaN               NaN
# 73696                                       NaN               NaN
# 73697                                       NaN               NaN
# 73698                                       NaN               NaN
# 73699                                       NaN               NaN
# 73700                                       NaN               NaN
# 73701                                       NaN               NaN
# 73702                                       NaN               NaN
#
#              partyIdW12                     partyIdW13  \
# 0                   NaN                            NaN
# 1          Conservative                   Conservative
# 2      Liberal Democrat               Liberal Democrat
# 3                   NaN                            NaN
# 4                   NaN                            NaN
# 5                   NaN                         Labour
# 6                Labour                         Labour
# 7          Conservative                   Conservative
# 8                Labour                         Labour
# 9          Conservative                            NaN
# 10                  NaN                            NaN
# 11                  NaN                            NaN
# 12                  NaN                            NaN
# 13         Conservative                   Conservative
# 14         Conservative                   Conservative
# 15                  NaN                            NaN
# 16         Conservative                            NaN
# 17            No - none  Scottish National Party (SNP)
# 18                  NaN                            NaN
# 19                  NaN                            NaN
# 20                  NaN                            NaN
# 21                  NaN                            NaN
# 22                  NaN                            NaN
# 23          Green Party                            NaN
# 24                  NaN                            NaN
# 25                  NaN                            NaN
# 26                  NaN                            NaN
# 27                  NaN                            NaN
# 28         Conservative                   Conservative
# 29               Labour                         Labour
# ...                 ...                            ...
# 73673               NaN                            NaN
# 73674               NaN                            NaN
# 73675               NaN                            NaN
# 73676               NaN                            NaN
# 73677               NaN                            NaN
# 73678               NaN                            NaN
# 73679               NaN                            NaN
# 73680               NaN                            NaN
# 73681               NaN                            NaN
# 73682               NaN                            NaN
# 73683               NaN                            NaN
# 73684               NaN                            NaN
# 73685               NaN                            NaN
# 73686               NaN                            NaN
# 73687               NaN                            NaN
# 73688               NaN                            NaN
# 73689               NaN                            NaN
# 73690               NaN                            NaN
# 73691               NaN                            NaN
# 73692               NaN                            NaN
# 73693               NaN                            NaN
# 73694               NaN                            NaN
# 73695               NaN                            NaN
# 73696               NaN                            NaN
# 73697               NaN                            NaN
# 73698               NaN                            NaN
# 73699               NaN                            NaN
# 73700               NaN                            NaN
# 73701               NaN                            NaN
# 73702               NaN                            NaN
#
#                                      partyIdW14
# 0                                           NaN
# 1                                  Conservative
# 2                              Liberal Democrat
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                        Labour
# 7                                  Conservative
# 8                                     No - none
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                        Other
# 18                                       Labour
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                    No - none
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                 Conservative
# 29                                       Labour
# ...                                         ...
# 73673             Scottish National Party (SNP)
# 73674                                 No - none
# 73675             Scottish National Party (SNP)
# 73676                                 No - none
# 73677  United Kingdom Independence Party (UKIP)
# 73678                              Conservative
# 73679                                    Labour
# 73680                                    Labour
# 73681                                 No - none
# 73682                                    Labour
# 73683                              Conservative
# 73684                                    Labour
# 73685                                 No - none
# 73686                              Conservative
# 73687                              Conservative
# 73688                               Green Party
# 73689                                Don't know
# 73690                                    Labour
# 73691                               Green Party
# 73692                                 No - none
# 73693  United Kingdom Independence Party (UKIP)
# 73694                                    Labour
# 73695                                    Labour
# 73696                                 No - none
# 73697                          Liberal Democrat
# 73698                                 No - none
# 73699                          Liberal Democrat
# 73700                              Conservative
# 73701                              Conservative
# 73702                                    Labour
#
# [73703 rows x 13 columns]

# %%
wave_list = [re.search("(W\d+)",x).groups()[0] for x in partyId]
wave_list
# Out:
# ['W1',
#  'W2',
#  'W3',
#  'W4',
#  'W6',
#  'W7',
#  'W8',
#  'W9',
#  'W10',
#  'W11',
#  'W12',
#  'W13',
#  'W14']

# %%
wt_wave_list = []
for wave in wave_list:
    wt_new = "wt_new_"+wave
    wt_old = "wt_full_"+wave
    if wt_new in BES_Panel.columns:
        wt = BES_Panel[wt_new]
        wt_wave_list.append(wt_new)
    else:
        wt = BES_Panel[wt_old]
        wt_wave_list.append(wt_old)
wt_wave_list
# Out:
# ['wt_full_W1',
#  'wt_full_W2',
#  'wt_full_W3',
#  'wt_full_W4',
#  'wt_new_W6',
#  'wt_new_W7',
#  'wt_new_W8',
#  'wt_new_W9',
#  'wt_new_W10',
#  'wt_new_W11',
#  'wt_new_W12',
#  'wt_new_W13',
#  'wt_new_W14']

# %%
test_df = pd.DataFrame(columns = partyId)
for pos in range(0,len(partyId)):
    
    test = pd.crosstab( index = np.ones( len(BES_Panel[partyId[pos]]) ) ,
                 columns = BES_Panel[partyId[pos]] ,
                 values = BES_Panel[wt_wave_list[pos]], aggfunc = sum, normalize='index' ).loc[1.0]
    test_df[partyId[pos]] = test
test_df = test_df.stack().reset_index()
test_df.columns = ["party","wave","percentage"]
# test_df["wave"] = test_df["wave"].apply(lambda x: re.search("(W\d+)",x).groups()[0])
test_df["wave"] = test_df["wave"].apply(lambda x: int(re.search("W(\d+)",x).groups()[0]))
# test_df["wave"] = test_df["wave"].astype('category').cat.set_categories(wave_list, ordered=True)
plt.figure(figsize=(12,8));
sns.lineplot(data = test_df, hue = "party", x = "wave", y="percentage");
plt.xticks([1,2,3,4,6,7,8,9,10,11,12,13,14],rotation = 90);

# %%
test_df = pd.DataFrame(columns = partyId)
coal_party = {"Left":["Labour","Liberal Democrat", "Scottish National Party (SNP)", "Plaid Cymru", "Green Party"],
              "Right":["Conservative","United Kingdom Independence Party (UKIP)", "British National Party (BNP)"],
              "Don't Know":["Don't know","Other"],
              "None":["No-none"]}
party_coal = {"Labour":"Left", "Liberal Democrat":"Left","Scottish National Party (SNP)":"Left",
              "Plaid Cymru":"Left","Green Party":"Left","Conservative":"Right","United Kingdom Independence Party (UKIP)":"Right",
              "British National Party (BNP)":"Right","Don't know":"Don't Know", "Other": "Don't know", 'No - none':"None"}

for pos in range(0,len(partyId)):
    
    test = pd.crosstab( index = np.ones( len(BES_Panel[partyId[pos]]) ) ,
                 columns = BES_Panel[partyId[pos]].apply(lambda x: party_coal[x]), 
                 values = BES_Panel[wt_wave_list[pos]], aggfunc = sum, normalize='index' ).loc[1.0]
    test_df[partyId[pos]] = test
test_df = test_df.stack().reset_index()
test_df.columns = ["party","wave","percentage"]
# test_df["wave"] = test_df["wave"].apply(lambda x: re.search("(W\d+)",x).groups()[0])
test_df["wave"] = test_df["wave"].apply(lambda x: int(re.search("W(\d+)",x).groups()[0]))
# test_df["wave"] = test_df["wave"].astype('category').cat.set_categories(wave_list, ordered=True)
plt.figure(figsize=(12,8));
sns.lineplot(data = test_df, hue = "party", x = "wave", y="percentage");
plt.xticks([1,2,3,4,6,7,8,9,10,11,12,13,14],rotation = 90);



test_df_red = test_df.copy()
test_df_red["party"] = test_df_red["party"].cat.set_categories(["Left","Right","Don't Know", "None"])
for left_party in ["Labour","Liberal Democrat", "Scottish National Party (SNP)", "Plaid Cymru", "Green Party"]:
    test_df_red.loc[ test_df["party"] == left_party  , "party"] = "Left"
for right_party in ["Conservative","United Kingdom Independence Party (UKIP)", "British National Party (BNP)"]:
    test_df_red.loc[ test_df["party"] == right_party , "party"] = "Right"
for dk_party in ["Don't know","Other"]:
    test_df_red.loc[ test_df["party"] == dk_party    , "party"] = "Don't Know"
for dk_party in ["No-none"]:
    test_df_red.loc[ test_df["party"] == dk_party    , "party"] = "None"
test_df
# plt.figure(figsize=(12,8));
# sns.lineplot(data = test_df_red, hue = "party", x = "wave", y="percentage");
# plt.xticks([1,2,3,4,6,7,8,9,10,11,12,13,14],rotation = 90);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-112-729cf1d8d204> in <module>()
#      11
#      12     test = pd.crosstab( index = np.ones( len(BES_Panel[partyId[pos]]) ) ,
# ---> 13                  columns = BES_Panel[partyId[pos]].apply(lambda x: party_coal[x]),
#      14                  values = BES_Panel[wt_wave_list[pos]], aggfunc = sum, normalize='index' ).loc[1.0]
#      15     test_df[partyId[pos]] = test
#
# ~\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2350             # row-wise access
#    2351             if is_extension_type(self.dtype):
# -> 2352                 mapped = self._values.map(f)
#    2353             else:
#    2354                 values = self.asobject
#
# ~\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\categorical.py in map(self, mapper)
#     999
#    1000         """
# -> 1001         new_categories = self.categories.map(mapper)
#    1002         try:
#    1003             return self.from_codes(self._codes.copy(),
#
# ~\Anaconda3\envs\BES_analysis\lib\site-packages\pandas\core\indexes\base.py in map(self, mapper)
#    2774         """
#    2775         from .multi import MultiIndex
# -> 2776         mapped_values = self._arrmap(self.values, mapper)
#    2777         attributes = self._get_attributes_dict()
#    2778         if mapped_values.size and isinstance(mapped_values[0], tuple):
#
# pandas\_libs\algos_common_helper.pxi in pandas._libs.algos.arrmap_object (pandas\_libs\algos.c:31954)()
#
# <ipython-input-112-729cf1d8d204> in <lambda>(x)
#      11
#      12     test = pd.crosstab( index = np.ones( len(BES_Panel[partyId[pos]]) ) ,
# ---> 13                  columns = BES_Panel[partyId[pos]].apply(lambda x: party_coal[x]),
#      14                  values = BES_Panel[wt_wave_list[pos]], aggfunc = sum, normalize='index' ).loc[1.0]
#      15     test_df[partyId[pos]] = test
#
# KeyError: 'No - none'

# %%
{k:v for k,v in coal_party.items()}
# Out:
# {"Don't Know": ["Don't know", 'Other'],
#  'Left': ['Labour',
#   'Liberal Democrat',
#   'Scottish National Party (SNP)',
#   'Plaid Cymru',
#   'Green Party'],
#  'None': ['No-none'],
#  'Right': ['Conservative',
#   'United Kingdom Independence Party (UKIP)',
#   'British National Party (BNP)']}

# %%
euIDcols = [x for x in BES_Panel.columns if "euIDW" in x]
euIDcols
# Out:
# ['euIDW7',
#  'euIDW8',
#  'euIDW9',
#  'euIDW10',
#  'euIDW11',
#  'euIDW12',
#  'euIDW13',
#  'euIDW14']

# %%
euId = [x for x in BES_Panel.columns if re.match("euIDW", x)]
wave_list = [re.search("(W\d+)",x).groups()[0] for x in euId]
test_df = pd.DataFrame(columns = euId)
for pos in range(0,len(euId)):
    
    test = pd.crosstab( index = np.ones( len(BES_Panel[euId[pos]]) ) ,
                 columns = BES_Panel[euId[pos]] ,
                 values = BES_Panel[wt_wave_list[pos]], aggfunc = sum, normalize='index' ).loc[1.0]
    test_df[euId[pos]] = test
test_df = test_df.stack().reset_index()
test_df.columns = ["party","wave","percentage"]
test_df["wave"] = test_df["wave"].apply(lambda x: int(re.search("W(\d+)",x).groups()[0]))

plt.figure(figsize=(12,8));
sns.lineplot(data = test_df, hue = "party", x = "wave", y="percentage");
plt.xticks([7,8,9,10,11,12,13,14],rotation = 90);
