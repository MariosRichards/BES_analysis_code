# %%
# %%time
dataset_name = "W19_comb"
df_list = 'BES_reduced_with_na|BES_Panel'
# %matplotlib inline
# %run BES_header.py {dataset_name} {df_list}
(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (8079, 14)
# Wall time: 1min 30s

# %%
pan_dataset_allr_values = pd.read_pickle(BES_small_data_files + "pan_dataset_allr_valuesW19"+".zip",compression='zip')
pan_dataset_ages = pd.read_pickle(BES_small_data_files + "pan_dataset_ages"+".zip", compression='zip')
pan_dataset_votes = pd.read_pickle(BES_small_data_files+"pan_dataset_votes"+".zip",compression='zip')

# %%
# Out:
#        Economic: Left <-> Right{gaussian-ish}complete_fully  \
# id
# 1                                              -1.913311
# 2                                               1.929016
# 3                                              -0.313073
# 4                                               0.643054
# 5                                               1.004469
# ...                                                  ...
# 98447                                           0.217387
# 98448                                           0.791833
# 98449                                          -0.789732
# 98450                                          -0.056723
# 98451                                          -0.351287
#
#        Social: Liberalism <-> Conservatism{gaussian-ish}complete_fully
# id
# 1                                               1.379564
# 2                                              -0.648342
# 3                                               0.242132
# 4                                               0.470176
# 5                                               0.012041
# ...                                                  ...
# 98447                                          -0.585382
# 98448                                          -1.276719
# 98449                                          -0.721598
# 98450                                           0.706377
# 98451                                           0.371110
#
# [97006 rows x 2 columns]

# %%
# search(BES_reduced_with_na,"blackEquality")

# %%
# %%time
# blackEquality_corr = BES_reduced_with_na.corrwith(BES_reduced_with_na["blackEqualityW6_W14__Gone much too far"])

# %%
# blackEquality_corr.dropna().sort_values().tail(50)

# %%
# BES_reduced_with_na

# %%
Treatment = "D8_10immigEcon_with_basis"
var_stub = "D8_10immigEcon"

var_list = ["D8_10immigEcon"]
var_stub_list = [var_stub,"immigEcon","immigCultural","immigSelf"]



# def optional_mask_fn(wave=[]):
#     return BES_Panel["generalElectionVoteW19"]=="Conservative"

# %%
temp = pd.get_dummies(BES_Panel["immigEconW8"],prefix="baseval").drop("baseval_Don't know",axis=1)

# temp["baseval"] = BES_reduced_with_na["immigEconW8__Good for economy"]
temp["constant"] = 1.0
BES_reduced_with_na[temp.columns] = temp

# %%
BES_reduced_with_na["D8_10immigEcon"] = (BES_reduced_with_na["immigEconW10__Good for economy"]) -\
                      (BES_reduced_with_na["immigEconW8__Good for economy"])

# %%
# temp["D8_10immigEcon"] = BES_reduced_with_na["D8_10immigEcon"]

# %%
# %%time
colname = "D8_10immigEcon"
xgboost_run(subdir=colname,dataset=BES_reduced_with_na,
            var_list=var_list,var_stub_list=var_stub_list,use_mean_weights=True,
            min_features = min(BES_reduced_with_na.shape[1]-1,20),
            title = colname+"\n\nNeg Imm Shift <---   ---> Pos Imm Shift")
# Out:
# [13:56:26] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.28522
# Will train until validation_0-rmse hasn't improved in 50.800000000000004 rounds.
# [1]	validation_0-rmse:1.275
# [2]	validation_0-rmse:1.26287
# [3]	validation_0-rmse:1.25217
# [4]	validation_0-rmse:1.24095
# [5]	validation_0-rmse:1.22995
# [6]	validation_0-rmse:1.21948
# [7]	validation_0-rmse:1.21032
# [8]	validation_0-rmse:1.20224
# [9]	validation_0-rmse:1.19626
# [10]	validation_0-rmse:1.18981
# [11]	validation_0-rmse:1.18657
# [12]	validation_0-rmse:1.18034
# [13]	validation_0-rmse:1.17548
# [14]	validation_0-rmse:1.17116
# [15]	validation_0-rmse:1.16725
# [16]	validation_0-rmse:1.16176
# [17]	validation_0-rmse:1.15699
# [18]	validation_0-rmse:1.15105
# [19]	validation_0-rmse:1.14809
# [20]	validation_0-rmse:1.14242
# [21]	validation_0-rmse:1.13892
# [22]	validation_0-rmse:1.1352
# [23]	validation_0-rmse:1.13279
# [24]	validation_0-rmse:1.1281
# [25]	validation_0-rmse:1.12404
# [26]	validation_0-rmse:1.12102
# [27]	validation_0-rmse:1.12032
# [28]	validation_0-rmse:1.11865
# [29]	validation_0-rmse:1.11679
# [30]	validation_0-rmse:1.11404
# [31]	validation_0-rmse:1.11097
# [32]	validation_0-rmse:1.10811
# [33]	validation_0-rmse:1.10579
# [34]	validation_0-rmse:1.10393
# [35]	validation_0-rmse:1.10144
# [36]	validation_0-rmse:1.09973
# [37]	validation_0-rmse:1.09637
# [38]	validation_0-rmse:1.09393
# [39]	validation_0-rmse:1.09135
# [40]	validation_0-rmse:1.09046
# [41]	validation_0-rmse:1.08891
# [42]	validation_0-rmse:1.08675
# [43]	validation_0-rmse:1.08568
# [44]	validation_0-rmse:1.08331
# [45]	validation_0-rmse:1.08196
# [46]	validation_0-rmse:1.08138
# [47]	validation_0-rmse:1.07935
# [48]	validation_0-rmse:1.07848
# [49]	validation_0-rmse:1.07714
# [50]	validation_0-rmse:1.0755
# [51]	validation_0-rmse:1.0751
# [52]	validation_0-rmse:1.07406
# [53]	validation_0-rmse:1.07296
# [54]	validation_0-rmse:1.0722
# [55]	validation_0-rmse:1.0712
# [56]	validation_0-rmse:1.07
# [57]	validation_0-rmse:1.06903
# [58]	validation_0-rmse:1.06848
# [59]	validation_0-rmse:1.06779
# [60]	validation_0-rmse:1.06683
# [61]	validation_0-rmse:1.06559
# [62]	validation_0-rmse:1.0655
# [63]	validation_0-rmse:1.06508
# [64]	validation_0-rmse:1.06441
# [65]	validation_0-rmse:1.06382
# [66]	validation_0-rmse:1.06326
# [67]	validation_0-rmse:1.06306
# [68]	validation_0-rmse:1.0624
# [69]	validation_0-rmse:1.06188
# [70]	validation_0-rmse:1.06072
# [71]	validation_0-rmse:1.06001
# [72]	validation_0-rmse:1.05943
# [73]	validation_0-rmse:1.05917
# [74]	validation_0-rmse:1.05913
# [75]	validation_0-rmse:1.05878
# [76]	validation_0-rmse:1.05851
# [77]	validation_0-rmse:1.05776
# [78]	validation_0-rmse:1.05759
# [79]	validation_0-rmse:1.05724
# [80]	validation_0-rmse:1.05679
# [81]	validation_0-rmse:1.05675
# [82]	validation_0-rmse:1.05617
# [83]	validation_0-rmse:1.05563
# [84]	validation_0-rmse:1.0554
# [85]	validation_0-rmse:1.05508
# [86]	validation_0-rmse:1.05484
# [87]	validation_0-rmse:1.05478
# [88]	validation_0-rmse:1.05398
# [89]	validation_0-rmse:1.0538
# [90]	validation_0-rmse:1.0536
# [91]	validation_0-rmse:1.05338
# [92]	validation_0-rmse:1.05302
# [93]	validation_0-rmse:1.05306
# [94]	validation_0-rmse:1.05259
# [95]	validation_0-rmse:1.05256
# [96]	validation_0-rmse:1.05225
# [97]	validation_0-rmse:1.05211
# [98]	validation_0-rmse:1.05211
# [99]	validation_0-rmse:1.05178
# [100]	validation_0-rmse:1.05154
# [101]	validation_0-rmse:1.05141
# [102]	validation_0-rmse:1.05107
# [103]	validation_0-rmse:1.05077
# [104]	validation_0-rmse:1.05051
# [105]	validation_0-rmse:1.05011
# [106]	validation_0-rmse:1.05014
# [107]	validation_0-rmse:1.04998
# [108]	validation_0-rmse:1.04988
# [109]	validation_0-rmse:1.04957
# [110]	validation_0-rmse:1.0494
# [111]	validation_0-rmse:1.04916
# [112]	validation_0-rmse:1.0491
# [113]	validation_0-rmse:1.04865
# [114]	validation_0-rmse:1.04876
# [115]	validation_0-rmse:1.04859
# [116]	validation_0-rmse:1.04851
# [117]	validation_0-rmse:1.0486
# [118]	validation_0-rmse:1.04858
# [119]	validation_0-rmse:1.04838
# [120]	validation_0-rmse:1.04808
# [121]	validation_0-rmse:1.04807
# [122]	validation_0-rmse:1.04778
# [123]	validation_0-rmse:1.04791
# [124]	validation_0-rmse:1.0478
# [125]	validation_0-rmse:1.04772
# [126]	validation_0-rmse:1.04764
# [127]	validation_0-rmse:1.04723
# [128]	validation_0-rmse:1.04712
# [129]	validation_0-rmse:1.04717
# [130]	validation_0-rmse:1.04703
# [131]	validation_0-rmse:1.04706
# [132]	validation_0-rmse:1.04697
# [133]	validation_0-rmse:1.04697
# [134]	validation_0-rmse:1.04684
# [135]	validation_0-rmse:1.04688
# [136]	validation_0-rmse:1.04643
# [137]	validation_0-rmse:1.04641
# [138]	validation_0-rmse:1.04656
# [139]	validation_0-rmse:1.04634
# [140]	validation_0-rmse:1.04623
# [141]	validation_0-rmse:1.04612
# [142]	validation_0-rmse:1.04614
# [143]	validation_0-rmse:1.04619
# [144]	validation_0-rmse:1.04603
# [145]	validation_0-rmse:1.04578
# [146]	validation_0-rmse:1.04549
# [147]	validation_0-rmse:1.04535
# [148]	validation_0-rmse:1.04522
# [149]	validation_0-rmse:1.04508
# [150]	validation_0-rmse:1.0451
# [151]	validation_0-rmse:1.04482
# [152]	validation_0-rmse:1.04474
# [153]	validation_0-rmse:1.04447
# [154]	validation_0-rmse:1.04441
# [155]	validation_0-rmse:1.04439
# [156]	validation_0-rmse:1.04422
# [157]	validation_0-rmse:1.0441
# [158]	validation_0-rmse:1.04407
# [159]	validation_0-rmse:1.04418
# [160]	validation_0-rmse:1.04424
# [161]	validation_0-rmse:1.04416
# [162]	validation_0-rmse:1.04409
# [163]	validation_0-rmse:1.04406
# [164]	validation_0-rmse:1.04408
# [165]	validation_0-rmse:1.04432
# [166]	validation_0-rmse:1.04447
# [167]	validation_0-rmse:1.04442
# [168]	validation_0-rmse:1.04416
# [169]	validation_0-rmse:1.04414
# [170]	validation_0-rmse:1.04409
# [171]	validation_0-rmse:1.04405
# [172]	validation_0-rmse:1.04381
# [173]	validation_0-rmse:1.04392
# [174]	validation_0-rmse:1.04403
# [175]	validation_0-rmse:1.04397
# [176]	validation_0-rmse:1.04397
# [177]	validation_0-rmse:1.04406
# [178]	validation_0-rmse:1.04421
# [179]	validation_0-rmse:1.04442
# [180]	validation_0-rmse:1.04451
# [181]	validation_0-rmse:1.04465
# [182]	validation_0-rmse:1.04454
# [183]	validation_0-rmse:1.04451
# [184]	validation_0-rmse:1.04444
# [185]	validation_0-rmse:1.04439
# [186]	validation_0-rmse:1.04434
# [187]	validation_0-rmse:1.04442
# [188]	validation_0-rmse:1.04442
# [189]	validation_0-rmse:1.04416
# [190]	validation_0-rmse:1.04432
# [191]	validation_0-rmse:1.04446
# [192]	validation_0-rmse:1.04441
# [193]	validation_0-rmse:1.04433
# [194]	validation_0-rmse:1.04436
# [195]	validation_0-rmse:1.0444
# [196]	validation_0-rmse:1.04442
# [197]	validation_0-rmse:1.04446
# [198]	validation_0-rmse:1.04437
# [199]	validation_0-rmse:1.04435
# [200]	validation_0-rmse:1.04448
# [201]	validation_0-rmse:1.0445
# [202]	validation_0-rmse:1.04455
# [203]	validation_0-rmse:1.04449
# [204]	validation_0-rmse:1.04436
# [205]	validation_0-rmse:1.04418
# [206]	validation_0-rmse:1.04414
# [207]	validation_0-rmse:1.04419
# [208]	validation_0-rmse:1.04414
# [209]	validation_0-rmse:1.04386
# [210]	validation_0-rmse:1.04391
# [211]	validation_0-rmse:1.04384
# [212]	validation_0-rmse:1.04367
# [213]	validation_0-rmse:1.04353
# [214]	validation_0-rmse:1.04353
# [215]	validation_0-rmse:1.04366
# [216]	validation_0-rmse:1.04382
# [217]	validation_0-rmse:1.04374
# [218]	validation_0-rmse:1.04351
# [219]	validation_0-rmse:1.04347
# [220]	validation_0-rmse:1.04351
# [221]	validation_0-rmse:1.0436
# [222]	validation_0-rmse:1.04368
# [223]	validation_0-rmse:1.04393
# [224]	validation_0-rmse:1.04409
# [225]	validation_0-rmse:1.0441
# [226]	validation_0-rmse:1.04409
# [227]	validation_0-rmse:1.04407
# [228]	validation_0-rmse:1.04406
# [229]	validation_0-rmse:1.04394
# [230]	validation_0-rmse:1.04386
# [231]	validation_0-rmse:1.04388
# [232]	validation_0-rmse:1.04394
# [233]	validation_0-rmse:1.04401
# [234]	validation_0-rmse:1.04405
# [235]	validation_0-rmse:1.04417
# [236]	validation_0-rmse:1.04418
# [237]	validation_0-rmse:1.04402
# [238]	validation_0-rmse:1.04411
# [239]	validation_0-rmse:1.04412
# [240]	validation_0-rmse:1.04419
# [241]	validation_0-rmse:1.04411
# [242]	validation_0-rmse:1.04403
# [243]	validation_0-rmse:1.04419
# [244]	validation_0-rmse:1.04424
# [245]	validation_0-rmse:1.04433
# [246]	validation_0-rmse:1.04432
# [247]	validation_0-rmse:1.04436
# [248]	validation_0-rmse:1.04442
# [249]	validation_0-rmse:1.04457
# [250]	validation_0-rmse:1.0448
# [251]	validation_0-rmse:1.04478
# [252]	validation_0-rmse:1.04467
# [253]	validation_0-rmse:1.04471
# [254]	validation_0-rmse:1.04466
# [255]	validation_0-rmse:1.04465
# [256]	validation_0-rmse:1.04458
# [257]	validation_0-rmse:1.04478
# [258]	validation_0-rmse:1.04473
# [259]	validation_0-rmse:1.04463
# [260]	validation_0-rmse:1.04494
# [261]	validation_0-rmse:1.04489
# [262]	validation_0-rmse:1.04479
# [263]	validation_0-rmse:1.04466
# [264]	validation_0-rmse:1.04475
# [265]	validation_0-rmse:1.04461
# [266]	validation_0-rmse:1.0445
# [267]	validation_0-rmse:1.04445
# [268]	validation_0-rmse:1.04459
# [269]	validation_0-rmse:1.04448
# [270]	validation_0-rmse:1.04436
# Stopping. Best iteration:
# [219]	validation_0-rmse:1.04347
#
# MSE: 1.09, MAE: 0.77, EV: 0.35, R2: 0.35
# [14:10:35] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Wall time: 33min 12s
# (<shap.explainers.tree.TreeExplainer at 0xc419308>,
#  array([[ 0.        ,  0.        ,  0.        , ...,  0.11608671,
#           0.09732102,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.10658664,
#           0.09547708,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ..., -0.8833826 ,
#           0.06481348,  0.        ],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.08796766,
#           0.07794596,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.09296983,
#           0.08098631,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.122004  ,
#           0.12074557,  0.        ]], dtype=float32),
#  Index(['turnoutUKGeneralW1__Very likely that I will vote',
#         'turnoutUKGeneralW2__Very likely that I will vote',
#         'turnoutUKGeneralW3__Very likely that I will vote',
#         'turnoutUKGeneralW4__Very likely that I will vote',
#         'turnoutUKGeneralW5__Very likely that I will vote',
#         'turnoutUKGeneralW7__Very likely that I will vote',
#         'turnoutUKGeneralW8__Very likely that I will vote',
#         'turnoutUKGeneralW9__Very likely that I will vote',
#         'turnoutUKGeneralW10__Very likely that I will vote',
#         'turnoutUKGeneralW11__Very likely that I will vote',
#         ...
#         'partyContactConW3_Yes', 'partyContact1W3_Yes',
#         'baseval_Bad for economy', 'baseval_2', 'baseval_3', 'baseval_4',
#         'baseval_5', 'baseval_6', 'baseval_Good for economy', 'constant'],
#        dtype='object', length=9492),
#  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=0.85,
#               colsample_bynode=1, colsample_bytree=0.6, gamma=0,
#               importance_type='gain', learning_rate=0.05, max_delta_step=0,
#               max_depth=6, min_child_weight=6, missing=None, n_estimators=219,
#               n_jobs=1, njobs=3, nthread=None, objective='reg:linear',
#               random_state=0, reg_alpha=5e-05, reg_lambda=1,
#               scale_pos_weight=1.0, seed=729, silent=None, subsample=0.8,
#               verbosity=1))

# %%
BES_reduced_with_na["D8_10immigEcon"] = BES_reduced_with_na["D8_10immigEcon"].abs()*BES_reduced_with_na["D8_10immigEcon"]

# %%
# %%time
colname = "D8_10immigEcon"
xgboost_run(subdir=colname,dataset=BES_reduced_with_na,
            var_list=var_list,var_stub_list=var_stub_list,
            min_features = min(BES_reduced_with_na.shape[1]-1,20),
            title = colname+"\n\nNeg Imm Shift <---   ---> Pos Imm Shift")
# Out:
# [14:37:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.28522
# Will train until validation_0-rmse hasn't improved in 21.900000000000002 rounds.
# [1]	validation_0-rmse:1.275
# [2]	validation_0-rmse:1.26287
# [3]	validation_0-rmse:1.25217
# [4]	validation_0-rmse:1.24095
# [5]	validation_0-rmse:1.22995
# [6]	validation_0-rmse:1.21948
# [7]	validation_0-rmse:1.21032
# [8]	validation_0-rmse:1.20224
# [9]	validation_0-rmse:1.19626
# [10]	validation_0-rmse:1.18981
# [11]	validation_0-rmse:1.18657
# [12]	validation_0-rmse:1.18034
# [13]	validation_0-rmse:1.17548
# [14]	validation_0-rmse:1.17116
# [15]	validation_0-rmse:1.16725
# [16]	validation_0-rmse:1.16176
# [17]	validation_0-rmse:1.15699
# [18]	validation_0-rmse:1.15105
# [19]	validation_0-rmse:1.14809
# [20]	validation_0-rmse:1.14242
# [21]	validation_0-rmse:1.13892
# [22]	validation_0-rmse:1.1352
# [23]	validation_0-rmse:1.13279
# [24]	validation_0-rmse:1.1281
# [25]	validation_0-rmse:1.12404
# [26]	validation_0-rmse:1.12102
# [27]	validation_0-rmse:1.12032
# [28]	validation_0-rmse:1.11865
# [29]	validation_0-rmse:1.11679
# [30]	validation_0-rmse:1.11404
# [31]	validation_0-rmse:1.11097
# [32]	validation_0-rmse:1.10811
# [33]	validation_0-rmse:1.10579
# [34]	validation_0-rmse:1.10393
# [35]	validation_0-rmse:1.10144
# [36]	validation_0-rmse:1.09973
# [37]	validation_0-rmse:1.09637
# [38]	validation_0-rmse:1.09393
# [39]	validation_0-rmse:1.09135
# [40]	validation_0-rmse:1.09046
# [41]	validation_0-rmse:1.08891
# [42]	validation_0-rmse:1.08675
# [43]	validation_0-rmse:1.08568
# [44]	validation_0-rmse:1.08331
# [45]	validation_0-rmse:1.08196
# [46]	validation_0-rmse:1.08138
# [47]	validation_0-rmse:1.07935
# [48]	validation_0-rmse:1.07848
# [49]	validation_0-rmse:1.07714
# [50]	validation_0-rmse:1.0755
# [51]	validation_0-rmse:1.0751
# [52]	validation_0-rmse:1.07406
# [53]	validation_0-rmse:1.07296
# [54]	validation_0-rmse:1.0722
# [55]	validation_0-rmse:1.0712
# [56]	validation_0-rmse:1.07
# [57]	validation_0-rmse:1.06903
# [58]	validation_0-rmse:1.06848
# [59]	validation_0-rmse:1.06779
# [60]	validation_0-rmse:1.06683
# [61]	validation_0-rmse:1.06559
# [62]	validation_0-rmse:1.0655
# [63]	validation_0-rmse:1.06508
# [64]	validation_0-rmse:1.06441
# [65]	validation_0-rmse:1.06382
# [66]	validation_0-rmse:1.06326
# [67]	validation_0-rmse:1.06306
# [68]	validation_0-rmse:1.0624
# [69]	validation_0-rmse:1.06188
# [70]	validation_0-rmse:1.06072
# [71]	validation_0-rmse:1.06001
# [72]	validation_0-rmse:1.05943
# [73]	validation_0-rmse:1.05917
# [74]	validation_0-rmse:1.05913
# [75]	validation_0-rmse:1.05878
# [76]	validation_0-rmse:1.05851
# [77]	validation_0-rmse:1.05776
# [78]	validation_0-rmse:1.05759
# [79]	validation_0-rmse:1.05724
# [80]	validation_0-rmse:1.05679
# [81]	validation_0-rmse:1.05675
# [82]	validation_0-rmse:1.05617
# [83]	validation_0-rmse:1.05563
# [84]	validation_0-rmse:1.0554
# [85]	validation_0-rmse:1.05508
# [86]	validation_0-rmse:1.05484
# [87]	validation_0-rmse:1.05478
# [88]	validation_0-rmse:1.05398
# [89]	validation_0-rmse:1.0538
# [90]	validation_0-rmse:1.0536
# [91]	validation_0-rmse:1.05338
# [92]	validation_0-rmse:1.05302
# [93]	validation_0-rmse:1.05306
# [94]	validation_0-rmse:1.05259
# [95]	validation_0-rmse:1.05256
# [96]	validation_0-rmse:1.05225
# [97]	validation_0-rmse:1.05211
# [98]	validation_0-rmse:1.05211
# [99]	validation_0-rmse:1.05178
# [100]	validation_0-rmse:1.05154
# [101]	validation_0-rmse:1.05141
# [102]	validation_0-rmse:1.05107
# [103]	validation_0-rmse:1.05077
# [104]	validation_0-rmse:1.05051
# [105]	validation_0-rmse:1.05011
# [106]	validation_0-rmse:1.05014
# [107]	validation_0-rmse:1.04998
# [108]	validation_0-rmse:1.04988
# [109]	validation_0-rmse:1.04957
# [110]	validation_0-rmse:1.0494
# [111]	validation_0-rmse:1.04916
# [112]	validation_0-rmse:1.0491
# [113]	validation_0-rmse:1.04865
# [114]	validation_0-rmse:1.04876
# [115]	validation_0-rmse:1.04859
# [116]	validation_0-rmse:1.04851
# [117]	validation_0-rmse:1.0486
# [118]	validation_0-rmse:1.04858
# [119]	validation_0-rmse:1.04838
# [120]	validation_0-rmse:1.04808
# [121]	validation_0-rmse:1.04807
# [122]	validation_0-rmse:1.04778
# [123]	validation_0-rmse:1.04791
# [124]	validation_0-rmse:1.0478
# [125]	validation_0-rmse:1.04772
# [126]	validation_0-rmse:1.04764
# [127]	validation_0-rmse:1.04723
# [128]	validation_0-rmse:1.04712
# [129]	validation_0-rmse:1.04717
# [130]	validation_0-rmse:1.04703
# [131]	validation_0-rmse:1.04706
# [132]	validation_0-rmse:1.04697
# [133]	validation_0-rmse:1.04697
# [134]	validation_0-rmse:1.04684
# [135]	validation_0-rmse:1.04688
# [136]	validation_0-rmse:1.04643
# [137]	validation_0-rmse:1.04641
# [138]	validation_0-rmse:1.04656
# [139]	validation_0-rmse:1.04634
# [140]	validation_0-rmse:1.04623
# [141]	validation_0-rmse:1.04612
# [142]	validation_0-rmse:1.04614
# [143]	validation_0-rmse:1.04619
# [144]	validation_0-rmse:1.04603
# [145]	validation_0-rmse:1.04578
# [146]	validation_0-rmse:1.04549
# [147]	validation_0-rmse:1.04535
# [148]	validation_0-rmse:1.04522
# [149]	validation_0-rmse:1.04508
# [150]	validation_0-rmse:1.0451
# [151]	validation_0-rmse:1.04482
# [152]	validation_0-rmse:1.04474
# [153]	validation_0-rmse:1.04447
# [154]	validation_0-rmse:1.04441
# [155]	validation_0-rmse:1.04439
# [156]	validation_0-rmse:1.04422
# [157]	validation_0-rmse:1.0441
# [158]	validation_0-rmse:1.04407
# [159]	validation_0-rmse:1.04418
# [160]	validation_0-rmse:1.04424
# [161]	validation_0-rmse:1.04416
# [162]	validation_0-rmse:1.04409
# [163]	validation_0-rmse:1.04406
# [164]	validation_0-rmse:1.04408
# [165]	validation_0-rmse:1.04432
# [166]	validation_0-rmse:1.04447
# [167]	validation_0-rmse:1.04442
# [168]	validation_0-rmse:1.04416
# [169]	validation_0-rmse:1.04414
# [170]	validation_0-rmse:1.04409
# [171]	validation_0-rmse:1.04405
# [172]	validation_0-rmse:1.04381
# [173]	validation_0-rmse:1.04392
# [174]	validation_0-rmse:1.04403
# [175]	validation_0-rmse:1.04397
# [176]	validation_0-rmse:1.04397
# [177]	validation_0-rmse:1.04406
# [178]	validation_0-rmse:1.04421
# [179]	validation_0-rmse:1.04442
# [180]	validation_0-rmse:1.04451
# [181]	validation_0-rmse:1.04465
# [182]	validation_0-rmse:1.04454
# [183]	validation_0-rmse:1.04451
# [184]	validation_0-rmse:1.04444
# [185]	validation_0-rmse:1.04439
# [186]	validation_0-rmse:1.04434
# [187]	validation_0-rmse:1.04442
# [188]	validation_0-rmse:1.04442
# [189]	validation_0-rmse:1.04416
# [190]	validation_0-rmse:1.04432
# [191]	validation_0-rmse:1.04446
# [192]	validation_0-rmse:1.04441
# [193]	validation_0-rmse:1.04433
# [194]	validation_0-rmse:1.04436
# Stopping. Best iteration:
# [172]	validation_0-rmse:1.04381
#
# MSE: 1.09, MAE: 0.77, EV: 0.35, R2: 0.35
# [14:47:34] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Wall time: 25min 41s
# (<shap.explainers.tree.TreeExplainer at 0x6356d388>,
#  array([[ 0.        ,  0.        ,  0.        , ...,  0.11296251,
#           0.09592932,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.10509006,
#           0.0931106 ,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ..., -0.84988314,
#           0.06461152,  0.        ],
#         ...,
#         [ 0.        ,  0.        ,  0.        , ...,  0.08602198,
#           0.07453869,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.09252245,
#           0.07820954,  0.        ],
#         [ 0.        ,  0.        ,  0.        , ...,  0.11886267,
#           0.11873872,  0.        ]], dtype=float32),
#  Index(['turnoutUKGeneralW1__Very likely that I will vote',
#         'turnoutUKGeneralW2__Very likely that I will vote',
#         'turnoutUKGeneralW3__Very likely that I will vote',
#         'turnoutUKGeneralW4__Very likely that I will vote',
#         'turnoutUKGeneralW5__Very likely that I will vote',
#         'turnoutUKGeneralW7__Very likely that I will vote',
#         'turnoutUKGeneralW8__Very likely that I will vote',
#         'turnoutUKGeneralW9__Very likely that I will vote',
#         'turnoutUKGeneralW10__Very likely that I will vote',
#         'turnoutUKGeneralW11__Very likely that I will vote',
#         ...
#         'partyContactConW3_Yes', 'partyContact1W3_Yes',
#         'baseval_Bad for economy', 'baseval_2', 'baseval_3', 'baseval_4',
#         'baseval_5', 'baseval_6', 'baseval_Good for economy', 'constant'],
#        dtype='object', length=9492),
#  XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=0.85,
#               colsample_bynode=1, colsample_bytree=0.6, gamma=0,
#               importance_type='gain', learning_rate=0.05, max_delta_step=0,
#               max_depth=6, min_child_weight=6, missing=None, n_estimators=172,
#               n_jobs=1, njobs=3, nthread=None, objective='reg:linear',
#               random_state=0, reg_alpha=5e-05, reg_lambda=1,
#               scale_pos_weight=1.0, seed=729, silent=None, subsample=0.8,
#               verbosity=1))

# %%
# 10 - 30s, r/ev=.15
# 5 - 60s, r/ev=.22
# 3 - 90s, r/ev =.24
# 2 - 120s, r/ev = .22
# 1 - 260s, r/ev = .25
BES_reduced_with_na.shape
# Out:
# (97006, 9531)

# %%
memory_use(locs = locals().items())
# Out:
#            BES_reduced_with_na:   3.4GiB
#                      BES_Panel: 944.5MiB
#                       var_type:   6.5MiB
#                             __:   1.5MiB
#                           temp:   1.5MiB
#                             _9:   1.5MiB
#                 cat_dictionary: 288.1KiB
#              new_old_col_names: 288.1KiB
#              old_new_col_names: 144.1KiB
#              BES_file_manifest:  58.7KiB

# %%
gc.collect()
# Out:
# 20

# %%
nulls = BES_reduced_with_na[BES_reduced_with_na["D8_10immigEcon"].notnull()].notnull().sum()

# %%
nulls.hist(bins=100)

# %%
nulls[nulls>5000]
# Out:
# turnoutUKGeneralW1__Very likely that I will vote     9111
# turnoutUKGeneralW2__Very likely that I will vote     9788
# turnoutUKGeneralW3__Very likely that I will vote     9705
# turnoutUKGeneralW4__Very likely that I will vote    11210
# turnoutUKGeneralW5__Very likely that I will vote     9880
#                                                     ...
# immigEconW8_4                                       18197
# immigEconW8_5                                       18197
# immigEconW8_6                                       18197
# immigEconW8_Good for economy                        18197
# immigEconW8_Don't know                              18197
# Length: 7373, dtype: int64

# %%
notnulls = BES_reduced_with_na.notnull().sum()

# %%
# %%time
sums = BES_reduced_with_na.sum()
# Out:
# Wall time: 3min 42s

# %%
# Out:
#  0.0     7897
#  1.0     4565
# -1.0     2078
#  4.0     1781
#  9.0      720
# -4.0      511
#  16.0     247
# -9.0      168
#  25.0      65
#  36.0      64
# -16.0      63
# -36.0      20
# -25.0      18
# Name: D8_10immigEcon, dtype: int64

# %%
# %%time
zeroes = (BES_reduced_with_na==0).sum()
# Out:
# Wall time: 3.17 s

# %%
zeroes.hist(bins=100)

# %%
nonzeroes = notnulls-zeroes
nonzeroes[nonzeroes<=200]
# Out:
# bestOnMIIW1_Plaid Cymru                                         81
# generalElectionVoteW2_British National Party (BNP)             120
# generalElectionVoteW3_British National Party (BNP)             131
# generalElectionVoteW4_British National Party (BNP)              78
# generalElectionVoteUnsqueezeW4_British National Party (BNP)     50
#                                                               ...
# partyContactLD_4W13_Yes                                        184
# referendumContact_9W2_Yes                                      164
# paperDays_2_111W18_Yes                                         168
# partyContactLab_4W2_Yes                                        195
# referendumContact_9W3_Yes                                      200
# Length: 1293, dtype: int64

# %%
sums.hist(bins=100)

# %%
sums[sums<=300000].sort_values()
# Out:
# cogempathyIRTW14                                            -69.131851
# affempathyIRTW14                                            -19.265257
# zeroSumIRTW14                                                 0.042665
# mii_catW13_Referendum unspecified                             1.000000
# mii_catW6_domestic emergency                                  1.000000
#                                                              ...
# mapAsianW3                                               280879.000000
# warmRichW11__Very warm                                   290472.000000
# EUIntegrationBrexitW16__Protect our independence         291372.000000
# agreePartyW17                                            293484.000000
# scotRefExpectationTurnoutW1__100% of people will vote    298707.000000
# Length: 9416, dtype: float32

# %%
sums[(sums<100)&(sums>=1)].sort_values().tail(50)
# Out:
# p_past_vote_2017_British National Party (BNP)                            1.0
# mii_catW6_domestic emergency                                             1.0
# motherVoteW3W14_W17_8.0                                                  1.0
# mii_catW13_Referendum unspecified                                        1.0
# ns_secW6W7W8W9_L8.2 Employers in small establishments in agriculture     1.0
#                                                                         ...
# knowMPW2_John Robertson                                                 99.0
# mii_catW4_nat ident, goals-loss                                         99.0
# p_ethnicityW7_Black Caribbean                                           99.0
# partyIdSqueezeTIGW15_Scottish National Party (SNP)                      99.0
# p_ethnicityW2_Pakistani                                                 99.0
# Length: 770, dtype: float32

# %%
search(BES_Panel,"profiles")
# Out:
# profiles_newspaper2W16    13775
# profiles_newspaper2W17    34366
# dtype: int64

# %%
## delete variables

profiles_newspaper2W16    13775
profiles_newspaper2W17    34366

# %%
## How about amalgamating all the variables that span waves?

# %%
# gender_Female 916 gaps
# paperDays

# %%
def add_pairs(wave_pair):
    pair1_cols = [x for x in search(df,wave_pair[0]).index if x.replace(wave_pair[0],wave_pair[1]) in df.columns]
    pair2_cols = [x.replace(wave_pair[0],wave_pair[1]) for x in pair1_cols]

    prefix = "D"+"_".join([x.replace("W","") for x in wave_pair])
    delta_df = pd.DataFrame(df[pair2_cols].values - df[pair1_cols].values,
                            columns = [prefix+x.replace(wave_pair[0],"") for x in pair1_cols])
    if pair1_cols!=[]:
        biggest_dtype = df[pair1_cols].dtypes.value_counts().index[-1].name
        biggest_dtype = "Int64" # nino_df screws this up by introducing floats!
        delta_df = delta_df.astype(biggest_dtype).astype('float32')
        df[delta_df.columns] = delta_df
        
treatment_dict = {}

# %%
# %%time
## target = D7_8immigEcon
wno1 = "8"
wno2 = "10"

base = "immigCultural"

Treatment = "D"+wno1+"_"+wno2+base+"_with_all_wave_vars"

# df = BES_reduced_with_na[search(BES_reduced_with_na,"|".join( ["W"+wno1,"W"+wno2,"W9"] ) ).index].copy()
df = BES_reduced_with_na.copy()
df[["Economic Left-Right","Social Liberal-Authoritarian"]] = pan_dataset_allr_values[['Economic: Left <-> Right{gaussian-ish}complete_fully','Social: Liberalism <-> Conservatism{gaussian-ish}complete_fully']]
df["Age"] = pan_dataset_ages["Age_at_W10"]

var1 = match(BES_reduced_with_na,base+"W"+wno1).index[0]
var2 = match(BES_reduced_with_na,base+"W"+wno2).index[0]

temp = pd.get_dummies(BES_Panel[base+"W"+wno1],prefix="baseval").drop("baseval_Don't know",axis=1)

# df["constant"] = 1.0
df[temp.columns] = temp

mask = BES_reduced_with_na[var1].notnull() & BES_reduced_with_na[var2].notnull()

var_stub = "D"+wno1+"_"+wno2+base

var_list = [var_stub]
var_stub_list = [var_stub,base,"immigEcon","immigSelf"]

add_pairs(["W"+wno1,"W"+wno2])
add_pairs(["W9","W10"])
add_pairs(["W8","W9"])

df[var_stub] = (BES_reduced_with_na[var2]) -\
                      (BES_reduced_with_na[var1])[mask]  


(explainer, shap_values, train_columns, alg) = xgboost_run(subdir=Treatment,dataset=df,
                                                      var_list=var_list,var_stub_list=var_stub_list,use_mean_weights=True,
                                                      min_features = min(BES_reduced_with_na.shape[1]-1,50),
           title = var_stub+"\n\nMore Neg "+base+" Shift Than Av. <---   ---> More Pos "+base+" Shift Than Av.", Treatment=Treatment)

# (explainer, shap_values, train.columns, alg) = xgboost_run(subdir=colname,dataset=BES_reduced_with_na,
#             var_list=var_list,var_stub_list=var_stub_list,use_mean_weights=True,
#             min_features = min(BES_reduced_with_na.shape[1]-1,20),
#             title = colname+"\n\nNeg Imm Shift <---   ---> Pos Imm Shift")


treatment_dict[Treatment]  =shap_array(shap_values, train_columns, threshold = .1, min_features = 50)
# Out:
# [13:06:58] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1.33103
# Will train until validation_0-rmse hasn't improved in 18.3 rounds.
# [1]	validation_0-rmse:1.32415
# [2]	validation_0-rmse:1.31218
# [3]	validation_0-rmse:1.30058
# [4]	validation_0-rmse:1.29165
# [5]	validation_0-rmse:1.28228
# [6]	validation_0-rmse:1.2781
# [7]	validation_0-rmse:1.2703
# [8]	validation_0-rmse:1.26306
# [9]	validation_0-rmse:1.2557
# [10]	validation_0-rmse:1.24995
# [11]	validation_0-rmse:1.24361
# [12]	validation_0-rmse:1.23655
# [13]	validation_0-rmse:1.22987
# [14]	validation_0-rmse:1.22436
# [15]	validation_0-rmse:1.2185
# [16]	validation_0-rmse:1.21403
# [17]	validation_0-rmse:1.21067
# [18]	validation_0-rmse:1.20718
# [19]	validation_0-rmse:1.20255
# [20]	validation_0-rmse:1.19868
# [21]	validation_0-rmse:1.19518
# [22]	validation_0-rmse:1.19086
# [23]	validation_0-rmse:1.18868
# [24]	validation_0-rmse:1.1839
# [25]	validation_0-rmse:1.18117
# [26]	validation_0-rmse:1.17994
# [27]	validation_0-rmse:1.17827
# [28]	validation_0-rmse:1.17489
# [29]	validation_0-rmse:1.17353
# [30]	validation_0-rmse:1.17138
# [31]	validation_0-rmse:1.17011
# [32]	validation_0-rmse:1.16864
# [33]	validation_0-rmse:1.16709
# [34]	validation_0-rmse:1.16435
# [35]	validation_0-rmse:1.16242
# [36]	validation_0-rmse:1.16006
# [37]	validation_0-rmse:1.15788
# [38]	validation_0-rmse:1.1554
# [39]	validation_0-rmse:1.15256
# [40]	validation_0-rmse:1.15173
# [41]	validation_0-rmse:1.15029
# [42]	validation_0-rmse:1.14788
# [43]	validation_0-rmse:1.14649
# [44]	validation_0-rmse:1.14512
# [45]	validation_0-rmse:1.1445
# [46]	validation_0-rmse:1.14348
# [47]	validation_0-rmse:1.14282
# [48]	validation_0-rmse:1.14179
# [49]	validation_0-rmse:1.14084
# [50]	validation_0-rmse:1.13993
# [51]	validation_0-rmse:1.13888
# [52]	validation_0-rmse:1.13763
# [53]	validation_0-rmse:1.13581
# [54]	validation_0-rmse:1.13446
# [55]	validation_0-rmse:1.13399
# [56]	validation_0-rmse:1.13333
# [57]	validation_0-rmse:1.13289
# [58]	validation_0-rmse:1.13164
# [59]	validation_0-rmse:1.1307
# [60]	validation_0-rmse:1.13038
# [61]	validation_0-rmse:1.12931
# [62]	validation_0-rmse:1.12923
# [63]	validation_0-rmse:1.12824
# [64]	validation_0-rmse:1.12796
# [65]	validation_0-rmse:1.12765
# [66]	validation_0-rmse:1.12698
# [67]	validation_0-rmse:1.12599
# [68]	validation_0-rmse:1.12471
# [69]	validation_0-rmse:1.12472
# [70]	validation_0-rmse:1.12373
# [71]	validation_0-rmse:1.12346
# [72]	validation_0-rmse:1.12338
# [73]	validation_0-rmse:1.12284
# [74]	validation_0-rmse:1.12199
# [75]	validation_0-rmse:1.12128
# [76]	validation_0-rmse:1.12126
# [77]	validation_0-rmse:1.12073
# [78]	validation_0-rmse:1.12048
# [79]	validation_0-rmse:1.11983
# [80]	validation_0-rmse:1.11901
# [81]	validation_0-rmse:1.11881
# [82]	validation_0-rmse:1.11881
# [83]	validation_0-rmse:1.11849
# [84]	validation_0-rmse:1.1178
# [85]	validation_0-rmse:1.11794
# [86]	validation_0-rmse:1.11783
# [87]	validation_0-rmse:1.1178
# [88]	validation_0-rmse:1.11751
# [89]	validation_0-rmse:1.1173
# [90]	validation_0-rmse:1.11722
# [91]	validation_0-rmse:1.11733
# [92]	validation_0-rmse:1.11718
# [93]	validation_0-rmse:1.11701
# [94]	validation_0-rmse:1.1171
# [95]	validation_0-rmse:1.11707
# [96]	validation_0-rmse:1.11705
# [97]	validation_0-rmse:1.11626
# [98]	validation_0-rmse:1.11513
# [99]	validation_0-rmse:1.11472
# [100]	validation_0-rmse:1.11501
# [101]	validation_0-rmse:1.11498
# [102]	validation_0-rmse:1.11492
# [103]	validation_0-rmse:1.11469
# [104]	validation_0-rmse:1.11433
# [105]	validation_0-rmse:1.11393
# [106]	validation_0-rmse:1.11373
# [107]	validation_0-rmse:1.11366
# [108]	validation_0-rmse:1.11344
# [109]	validation_0-rmse:1.11349
# [110]	validation_0-rmse:1.11365
# [111]	validation_0-rmse:1.11368
# [112]	validation_0-rmse:1.11376
# [113]	validation_0-rmse:1.11371
# [114]	validation_0-rmse:1.11334
# [115]	validation_0-rmse:1.11323
# [116]	validation_0-rmse:1.11312
# [117]	validation_0-rmse:1.11275
# [118]	validation_0-rmse:1.11228
# [119]	validation_0-rmse:1.11208
# [120]	validation_0-rmse:1.11203
# [121]	validation_0-rmse:1.11191
# [122]	validation_0-rmse:1.11173
# [123]	validation_0-rmse:1.11174
# [124]	validation_0-rmse:1.11178
# [125]	validation_0-rmse:1.11148
# [126]	validation_0-rmse:1.11158
# [127]	validation_0-rmse:1.11167
# [128]	validation_0-rmse:1.11153
# [129]	validation_0-rmse:1.11119
# [130]	validation_0-rmse:1.11122
# [131]	validation_0-rmse:1.11113
# [132]	validation_0-rmse:1.11104
# [133]	validation_0-rmse:1.11099
# [134]	validation_0-rmse:1.11097
# [135]	validation_0-rmse:1.11077
# [136]	validation_0-rmse:1.11073
# [137]	validation_0-rmse:1.11071
# [138]	validation_0-rmse:1.11045
# [139]	validation_0-rmse:1.11014
# [140]	validation_0-rmse:1.1101
# [141]	validation_0-rmse:1.10987
# [142]	validation_0-rmse:1.10963
# [143]	validation_0-rmse:1.1096
# [144]	validation_0-rmse:1.10956
# [145]	validation_0-rmse:1.10937
# [146]	validation_0-rmse:1.10926
# [147]	validation_0-rmse:1.10946
# [148]	validation_0-rmse:1.10923
# [149]	validation_0-rmse:1.10928
# [150]	validation_0-rmse:1.10916
# [151]	validation_0-rmse:1.10877
# [152]	validation_0-rmse:1.10869
# [153]	validation_0-rmse:1.10873
# [154]	validation_0-rmse:1.10861
# [155]	validation_0-rmse:1.10872
# [156]	validation_0-rmse:1.10853
# [157]	validation_0-rmse:1.10877
# [158]	validation_0-rmse:1.1086
# [159]	validation_0-rmse:1.10853
# [160]	validation_0-rmse:1.10852
# [161]	validation_0-rmse:1.1083
# [162]	validation_0-rmse:1.10811
# [163]	validation_0-rmse:1.10798
# [164]	validation_0-rmse:1.10773
# [165]	validation_0-rmse:1.10732
# [166]	validation_0-rmse:1.1072
# [167]	validation_0-rmse:1.10717
# [168]	validation_0-rmse:1.10705
# [169]	validation_0-rmse:1.10702
# [170]	validation_0-rmse:1.10703
# [171]	validation_0-rmse:1.10704
# [172]	validation_0-rmse:1.10709
# [173]	validation_0-rmse:1.10675
# [174]	validation_0-rmse:1.10691
# [175]	validation_0-rmse:1.10686
# [176]	validation_0-rmse:1.107
# [177]	validation_0-rmse:1.10695
# [178]	validation_0-rmse:1.10694
# [179]	validation_0-rmse:1.10713
# [180]	validation_0-rmse:1.10721
# [181]	validation_0-rmse:1.10695
# [182]	validation_0-rmse:1.1071
# MSE: 1.22, MAE: 0.81, EV: 0.29, R2: 0.29
# [13:17:16] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Wall time: 28min 32s

# %%
df["Economic Left-Right"]
# Out:
# id
# 1       -1.913311
# 2        1.929016
# 3       -0.313073
# 4        0.643054
# 5        1.004469
#            ...
# 98447    0.217387
# 98448    0.791833
# 98449   -0.789732
# 98450   -0.056723
# 98451   -0.351287
# Name: Economic Left-Right, Length: 97006, dtype: float64

# %%
# Out:
#        Age_at_W1_rounded  Age_at_W1  Age_at_W2  Age_at_W3  Age_at_W4  \
# id
# 1                     58  57.850863  57.855603  58.335336  58.833221
# 2                     62  61.847247  61.851987  62.331720  62.829605
# 3                     76  75.812681  75.817421  76.297154  76.795039
# 4                     51  50.984062  50.988802  51.468535  51.966419
# 5                     68  67.984062  67.988802  68.468535  68.966419
# ...                  ...        ...        ...        ...        ...
# 98447                 23  23.378732  23.383472  23.863205  24.361089
# 98448                 24  24.378732  24.383472  24.863205  25.361089
# 98449                 30  30.331278  30.336018  30.815751  31.313636
# 98450                 20  20.378732  20.383472  20.863205  21.361089
# 98451                 38  38.378732  38.383472  38.863205  39.361089
#
#        Age_at_W5  Age_at_W6  Age_at_W7  Age_at_W8  Age_at_W9  ...  \
# id                                                            ...
# 1      58.909397  58.970528  59.900456  60.019697  60.106970  ...
# 2      62.905781  62.966912  63.896840  64.016081  64.103355  ...
# 3      76.871215  76.932346  77.862274  77.981515  78.068788  ...
# 4      52.042595  52.103727  53.033655  53.152896  53.240169  ...
# 5      69.042595  69.103727  70.033655  70.152896  70.240169  ...
# ...          ...        ...        ...        ...        ...  ...
# 98447  24.437265  24.498397  25.428324  25.547566  25.634839  ...
# 98448  25.437265  25.498397  26.428324  26.547566  26.634839  ...
# 98449  31.389812  31.450943  32.380871  32.500112  32.587385  ...
# 98450  21.437265  21.498397  22.428324  22.547566  22.634839  ...
# 98451  39.437265  39.498397  40.428324  40.547566  40.634839  ...
#
#        standardAgeGroup_at_W1  equalisedAgeGroup_at_W1  \
# id
# 1                       56-65             (57.0, 65.0]
# 2                       56-65             (57.0, 65.0]
# 3                         66+            (65.0, 100.0]
# 4                       46-55             (49.0, 57.0]
# 5                         66+            (65.0, 100.0]
# ...                       ...                      ...
# 98447                   18-25             (22.0, 31.0]
# 98448                   18-25             (22.0, 31.0]
# 98449                   26-35             (22.0, 31.0]
# 98450                   18-25             (11.0, 22.0]
# 98451                   36-45             (31.0, 40.0]
#
#        equalisedAgeGroup_at_W1_detailed  equalLengthAgeGroup_at_W1  \
# id
# 1                          (57.0, 61.0]                   (55, 60]
# 2                          (61.0, 65.0]                   (60, 65]
# 3                         (69.0, 100.0]                   (75, 80]
# 4                          (49.0, 54.0]                   (50, 55]
# 5                          (65.0, 69.0]                   (65, 70]
# ...                                 ...                        ...
# 98447                      (22.0, 27.0]                   (20, 25]
# 98448                      (22.0, 27.0]                   (20, 25]
# 98449                      (27.0, 31.0]                   (25, 30]
# 98450                      (18.0, 22.0]                   (15, 20]
# 98451                      (35.0, 40.0]                   (35, 40]
#
#        standardAgeGroup_at_W19  equalisedAgeGroup_at_W19  \
# id
# 1                        56-65              (63.0, 71.0]
# 2                          66+              (63.0, 71.0]
# 3                          66+             (71.0, 106.0]
# 4                        56-65              (55.0, 63.0]
# 5                          66+             (71.0, 106.0]
# ...                        ...                       ...
# 98447                    26-35              (28.0, 37.0]
# 98448                    26-35              (28.0, 37.0]
# 98449                    36-45              (28.0, 37.0]
# 98450                    26-35              (17.0, 28.0]
# 98451                    36-45              (37.0, 46.0]
#
#        equalisedAgeGroup_at_W19_detailed  equalLengthAgeGroup_at_W19  \
# id
# 1                           (63.0, 67.0]                    (60, 65]
# 2                           (67.0, 71.0]                    (65, 70]
# 3                          (75.0, 106.0]                    (80, 85]
# 4                           (55.0, 59.0]                    (55, 60]
# 5                           (71.0, 75.0]                    (70, 75]
# ...                                  ...                         ...
# 98447                       (28.0, 33.0]                    (25, 30]
# 98448                       (28.0, 33.0]                    (30, 35]
# 98449                       (33.0, 37.0]                    (35, 40]
# 98450                       (24.0, 28.0]                    (25, 30]
# 98451                       (41.0, 46.0]                    (40, 45]
#
#        rough_predictions  Age_at_W1_missing_values
# id
# 1              61.709015                 57.872400
# 2              61.180431                 61.868784
# 3              71.241913                 75.834218
# 4              50.193882                 51.005599
# 5              67.017960                 68.005599
# ...                  ...                       ...
# 98447          28.690456                 23.400269
# 98448          15.019540                 24.400269
# 98449          33.571175                 30.352815
# 98450          30.570265                 20.400269
# 98451          33.969242                 38.400269
#
# [97006 rows x 30 columns]
