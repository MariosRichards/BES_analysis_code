# %%
# Get a nice list of all the Attitudinal BES Variables, maybe with some structure!

# %%
# %%time
dataset_name = "W19_comb"
df_list = [ "BES_Panel" ]

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}

if "id" in BES_Panel.columns:
    BES_Panel = BES_Panel.set_index("id").sort_index()

(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)    
    
# get full set of inferred "cross wave" auth-lib/left-right values and ages
# pan_dataset_allr_values = pd.read_csv(BES_small_data_files + "pan_dataset_allr_valuesW19"+".csv")
pan_dataset_ages = pd.read_pickle(BES_small_data_files + "pan_dataset_ages"+".zip", compression='zip')

pan_dataset_votes = pd.read_pickle(BES_small_data_files+"pan_dataset_votes"+".zip",compression='zip')
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (7911, 14)
# Wall time: 27.2 s

# %%
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# Wall time: 4min 38s

# %%
W19_cols = BES_Panel.columns

# %%
W16_cols = BES_Panel.columns

# %%
W13_cols = BES_Panel.columns

# %%
W10_cols = BES_Panel.columns

# %%
# W13
# welfarePreference

# %%
dataset_name = "W18_only"
data_subfolder = BES_data_folder + dataset_name + os.sep
(manifest, dataset_filename, dataset_description, dataset_citation,
 dataset_start, dataset_stop, dataset_wave) = get_manifest(dataset_name, BES_file_manifest)
BES_Panel = pd.read_stata(data_subfolder + dataset_filename)

# slow

# %%
set(W10_cols) - set(W19_cols)
# Out:
# {'BESwave10_SamplesurveyW10',
#  'DailyweightW8',
#  'MIIEU_textW7',
#  'MIIEU_textW8',
#  'MII_textW1',
#  'MII_textW10',
#  'MII_textW2',
#  'MII_textW3',
#  'MII_textW4',
#  'MII_textW5',
#  'MII_textW6',
#  'MII_textW7',
#  'MII_textW8',
#  'MII_textW9',
#  'RPrivSchnew_dkW1W2W3W4W7W9W10',
#  'ReasonForvoteOthW6',
#  'achieveReduceImmigDKW10',
#  'achieveReduceImmigDKW4',
#  'achieveReduceImmigDKW7',
#  'achieveReduceImmigDKW9',
#  'age_pdlW8',
#  'al1W10',
#  'al2W10',
#  'al3W10',
#  'al4W10',
#  'al5W10',
#  'al_scaleW10',
#  'bestLeaderCampaignUKW6',
#  'bestOnMIIOthW1',
#  'bestOnMIIOthW10',
#  'bestOnMIIOthW2',
#  'bestOnMIIOthW3',
#  'bestOnMIIOthW4',
#  'bestOnMIIOthW5',
#  'bestOnMIIOthW6',
#  'bestOnMIIOthW7',
#  'bestOnMIIOthW8',
#  'bestOnMIIOthW9',
#  'blackEqualityW10',
#  'blackEqualityW6W7W8W9',
#  'contactMPSubjectW4',
#  'country',
#  'country_of_residence1W8',
#  'country_of_residence2W8',
#  'currentUnionMemberW10',
#  'currentUnionMemberW2',
# ...

# %%
# W19_comb
# sovereignty1W19, sovereignty2W19



BES_Panel["socLib2W15"].value_counts()
# Out:
# North East    1781
# Name: socLib2W15, dtype: int64

# %%
# BES_reduced_with_na.to_pickle(data_subfolder +"BES_reduced_with_na.zip"  ,compression='zip')

# %%
search(BES_Panel,"traditionalism|auth")
# Out:
# auth1W7              7829
# auth2W7              7829
# auth3W7              7829
# auth4W7              7829
# auth1W10             7720
# auth2W10             7720
# auth3W10             7720
# auth4W10             7720
# authLong1W10         7631
# authLong2W10         7631
# authLong3W10         7631
# authLong4W10         7631
# auth1W11             7883
# auth2W11             7883
# auth3W11             7883
# auth4W11             7883
# auth1W14             7939
# auth2W14             7939
# auth3W14             7939
# auth4W14             7939
# traditionalismW15    1727
# respectAuthW15       1736
# dtype: int64

# %%
# W10_comb
search(BES_Panel,"personality|traditionalism|respectAuth|socialDes|welfarePreference")
# Out:
# welfarePreferenceW2               5656
# welfarePreferenceW3               7039
# welfarePreferenceW4               7957
# welfarePreferenceW6               7608
# welfarePreferenceW7               7682
# personality_agreeableness        51217
# personality_conscientiousness    51217
# personality_extraversion         51218
# personality_neuroticism          51215
# personality_openness             51215
# socialDesScaleW1W2W3W4W5         41686
# socialDes_1W1W2W3W4W5            41686
# socialDes_2W1W2W3W4W5            41686
# socialDes_3W1W2W3W4W5            41686
# socialDes_4W1W2W3W4W5            41686
# socialDes_noneW1W2W3W4W5         41686
# socialDes_dkW1W2W3W4W5           41686
# dtype: int64

# %%
# W13_comb
search(BES_Panel,"personality|traditionalism|respectAuth|socialDes|welfarePreference")
# Out:
# welfarePreferenceW2               5656
# welfarePreferenceW3               7039
# welfarePreferenceW4               7962
# welfarePreferenceW6               7614
# welfarePreferenceW7               7682
# welfarePreferenceW11             31014
# personality_agreeableness        51237
# personality_conscientiousness    51237
# personality_extraversion         51238
# personality_neuroticism          51235
# personality_openness             51235
# socialDesScaleW1W2W3W4W5         41690
# socialDes_1W1W2W3W4W5            41690
# socialDes_2W1W2W3W4W5            41690
# socialDes_3W1W2W3W4W5            41690
# socialDes_4W1W2W3W4W5            41690
# socialDes_noneW1W2W3W4W5         41690
# socialDes_dkW1W2W3W4W5           41690
# dtype: int64

# %%
# what happened to those personality variables?
# W16_comb

search(BES_Panel,"personality|traditionalism|respectAuth|socialDes")
# socialDes_X variables also missing

# present in wave 16_comb
# Out:
# traditionalismW15                 1727
# respectAuthW15                    1736
# personality_agreeableness        51245
# personality_conscientiousness    51245
# personality_extraversion         51246
# personality_neuroticism          51243
# personality_openness             51243
# socialDesScaleW1W2W3W4W5         41692
# socialDes_1W1W2W3W4W5            41692
# socialDes_2W1W2W3W4W5            41692
# socialDes_3W1W2W3W4W5            41692
# socialDes_4W1W2W3W4W5            41692
# socialDes_noneW1W2W3W4W5         41692
# socialDes_dkW1W2W3W4W5           41692
# dtype: int64

# %%
# gc.collect()
def make_corr_summary(input_df, name,  corr_type = "spearman", pattern=None, sample_size_text = "N", correlation_text = "r",
                      abs_correlation_text = "abs_r", p_value_text = "p",
                      min_p_value = 0.01, min_variance = 0.0, min_sample_size = 500):

    if pattern is None:
        pattern=name
    #df1 = input_df
    focal_var = input_df[name]
    focal_mask = focal_var.notnull()


    pattern_list = [x for x in input_df.columns if re.search(pattern,x)]

    variances = input_df[focal_mask].astype('float32').var()
    low_var_list = list(variances[variances<min_variance].index)
    sample_sizes = input_df[focal_mask].notnull().sum()
    low_sample_size_list = list(sample_sizes[sample_sizes<min_sample_size].index)

    drop_list = pattern_list+low_var_list+low_sample_size_list


    if corr_type == "pearson":
        df = input_df.drop(drop_list,axis=1).astype('float32').apply(lambda x: corr_simple_pearsonr(x,focal_var)).apply(pd.Series)
    elif corr_type == "spearman":
        df = input_df.drop(drop_list,axis=1).astype('float32').apply(lambda x: corr_simple_spearmanr(x,focal_var)).apply(pd.Series)

    if len(df.columns)!=3:
        df=df.T
    df.columns = [correlation_text,p_value_text,sample_size_text]
 
    df[sample_size_text] = df[sample_size_text].astype('int')
    df[abs_correlation_text] = df[correlation_text].abs()

    zero_var_other_way_around_list = list(df[df[correlation_text].isnull()].index)
    df.dropna(inplace=True)

    insignificant_list = df[df[p_value_text]>min_p_value].index
    df.drop(insignificant_list,inplace=True)

    df.sort_values(by=abs_correlation_text,ascending=False,inplace=True)


    stub_dict = {}
    drop_list = []
    # drop repeated references to same variable in different waves???
    # so, what about different categories??? eg. blahWX_subcat
    # how about, just replace wave match as "X"
    # create a dictionary keyed on the top corr variable with all the drops inside
    for ind in df.index:
        waveless = remove_wave(ind)
        if waveless in stub_dict.keys():
            drop_list.append(ind)
            stub_dict[waveless].append(ind)
        else:
            stub_dict[waveless] = [ind]
    df.drop(drop_list,inplace=True)
    return df, corr_type

# %%
BES_Panel = pd.read_pickle("..\\BES_analysis_data\\"+"W19_comb"+os.sep+"BES_Panelv02",compression='zip')
BES_Panel = BES_Panel.set_index("id")
BES_Panel = BES_Panel.sort_index()

# pan_dataset_allr_values = pan_dataset_allr_values.set_index("id").loc[BES_Panel.index]

# %%
var_dict = {}

# %%
# BES_vals = pd.DataFrame(index = BES_Panel.index) # initiate with largest index possible

# %%
# do we include 

# polPreferToFight
# Parties and politicians in the UK are more concerned with fighting each other than with furthering the public interest.

# bringTogether SINGLE W18 
# Do you think that the election campaign will bring together people who have different political views or will it drive them apart?

# %%
var_dict["W10_missing_vars"] = "welfarePreference"
# W10_comb

# welfarePreference
# Do you think that the amount of money families on welfare receive is too high or too low?
# val_cols = match(BES_Panel,var_dict["W10_missing_vars"]).sort_index().index
# BES_vals[val_cols] = BES_Panel[ val_cols ].replace("Don't know",np.nan).apply(lambda x: x.cat.codes).replace(-1,np.nan)

# %%
var_dict["big5_personality"] = "personality"
# W16_comb variables not present in W19_comb

# traditionalismW15                 1727
# Some people think that everyone should be allowed to live however they want, even if that means some traditional values
# have to be abandoned. Other people think that we should preserve traditional values, even if that means some people
# cannot live how they want to. Where would you place yourself and the parties on this scale?
# respectAuthW15                    1736
# Some people think that society would be a better place if people had more respect for authority.
# Other people think society would be a better place if people questioned authority more often.
# Where would you place yourself and the parties on this scale?

## Bah - these are broken!

# personality_agreeableness        51245
# personality_conscientiousness    51245
# personality_extraversion         51246
# personality_neuroticism          51243
# personality_openness             51243
## big 5 yougov measure (quite noisy)

# val_cols = match(BES_Panel,var_dict["big5_personality"]).sort_index().index
# BES_vals[val_cols] = BES_Panel[val_cols].astype('float32')

# %%
var_dict["social_desirability"] = "socialDes"

# socialDesScaleW1W2W3W4W5         41692
# socialDes_1W1W2W3W4W5            41692
# socialDes_2W1W2W3W4W5            41692
# socialDes_3W1W2W3W4W5            41692
# socialDes_4W1W2W3W4W5            41692
# socialDes_noneW1W2W3W4W5         41692
# socialDes_dkW1W2W3W4W5           41692

# I always smile at people every time I meet them
# socialDes_2
# I always practice what I preach
# socialDes_3
# If I say to people that I will do something, I always keep my promise no matter how inconvenient it might be
# socialDes_4
# I would never lie to people
# socialDes_none
# None of these statements apply to me
# Not randomized,exclude other punches
# socialDes_dk
# Don’t know
# Not randomized,exclude other punches

# val_cols = match(BES_Panel,var_dict["social_desirability"]).sort_index().index
# BES_vals[val_cols] = BES_Panel[ val_cols ].replace("Don't know",np.nan).apply(lambda x: x.cat.codes).replace(-1,np.nan)

# %%
BES_vals
# Out:
#        welfarePreferenceExpW2  welfarePreferenceExpW3  welfarePreferenceExpW4  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     2.0                     2.0
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 97153                     NaN                     NaN                     NaN
# 97154                     NaN                     NaN                     NaN
# 97155                     NaN                     NaN                     NaN
# 97156                     NaN                     NaN                     NaN
# 97157                     NaN                     NaN                     NaN
#
# ...

# %%
BES_vals = BES_vals.astype('float32')

# %%
BES_vals_backup = BES_vals.copy()

# %%
var_dict["trust"] = "genTrust|trust|(con|grn|lab|ld|pc|snp|ukp)GovTrust"

# genTrust W7|15|17|19
# Generally speaking, would you say that most people can be trusted, or that you can’t be too careful in dealing with people?

# trustMPs W1|2|3|4|6|7|8|9|10|12|15|16|17|18|19
# How much trust do you have in Members of Parliament in general?

# trustYourMP W1|2|3|4|16|17
# How much trust do you have in the MP in your local constituency?

# trust(Parliament|Courts)W17
# How much do you trust the Parliament at Westminster?/How much do you trust British Courts?

# trust(Scot|Welsh|Westminster)GovtW19
# How much of the time do you think you can trust the government in Westminster(/Scotland/Wales) to do what is right?

# (con|grn|lab|ld|pc|snp|ukip)GovTrustW5
# How much would you expect each of the following political parties to do a good job or a bad job if they are
# in government after the General Election (either by themselves or as part of a coalition)?

# %%
# trust -> govtHandleImmig/likeLD
#

# %%
trust_per_resp = BES_reduced_with_na[match(BES_reduced_with_na,"genTrust|trust|(con|grn|lab|ld|pc|snp|ukp)GovTrust").index].mean(axis=1)

# %%
# %%time
BES_reduced_with_na["trust_per_resp"] = trust_per_resp
pattern = "trust_per_resp"
name = "trust_per_resp"
corr_type = "spearman"
corr_df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type, pattern=pattern)
display_corr(corr_df, name, corr_type, text_wrap_length=50)
# Out:
# <style  type="text/css" >
# </style><table id="T_86ed3fd2_8cba_11ea_b5c0_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for trust_per_resp</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r</th>        <th class="col_heading level0 col1" >p</th>        <th class="col_heading level0 col2" >N</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86ed3fd2_8cba_11ea_b5c0_20cf301b91b3level0_row0" class="row_heading level0 row0" >trustParliamentW17__10.0</th>
#                         <td id="T_86ed3fd2_8cba_11ea_b5c0_20cf301b91b3row0_col0" class="data row0 col0" >0.840000</td>
#                         <td id="T_86ed3fd2_8cba_11ea_b5c0_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_86ed3fd2_8cba_11ea_b5c0_20cf301b91b3row0_col2" class="data row0 col2" >33018</td>
#             </tr>
#             <tr>
# ...

# %%
var_dict["trust_in_officials"] = "cspl"
# "cspl"

# csplConductPublicOfficialsW2    5659
# Overall, how would you rate the standards of conduct of public office holders in the United Kingdom?
# csplImproveStandardsW2          5660
# authorities in the United Kingdom are committed to improving standards in public life?
# csplUncoverWrongsW2             5660
# authorities will generally uncover wrongdoing by people in public life?
# csplPunishWrongsW2              5660
# when people in public life are caught doing wrong, the authorities will punish them?

# cspl1
# How often do you think politicians do special favours for people
# and organisations who give very large contributions to their party?
# cspl2 W7
# When politicians do special favours for contributors, do you think that this is:
# cspl3 W7
# What legal limit, if any, should be placed on donations to a political party?
# cspl4 W7
# How often do you think Members of Parliament decide what to do based on what
# their financial donors want, rather than on what they really believe:
# cspl5 W7
# How important is the issue of how political parties are funded in the UK?
# cspl6 W7
# And what legal limit, if any, should be placed on donations to groups campaigning in referendums?

# Please order the following reasons for people to make very large donations (say in excess of £100,000)
# to a political party from most common (first) to least common (last)
# csplRank_1W7                    7761
# They believe in what that party stands for
# csplRank_2W7                    7761
# They hope to have more access to and influence over that party
# csplRank_3W7                    7761
# They hope to be given some favours or special treatment

# %%
# voteMakesDifferenceW4     31551
# voteMakesDifferenceW11    30956
# How likely is it that your vote will make a difference
# in terms of which party wins the election in your local constituency?

# prPreference W4|6|9|11|13|15|16|19
# Thinking about the outcomes of general elections, which of these statements is
# more important to you? (Please tick the statement you prefer)

# enviroGrowth W4W6W7W16W17

# %%
# In the past 7 days, how much election news or information have you heard about …
# infoNationalW18    9529
# National politics, parties and candidates
# infoLocalW18       9529
# My constituency’s local constituency politics, parties, and candidates

# euGovtLeafletW7    30871
# euGovtLeafletW8    33502
# Have you received and read the UK Government’s leaflet “Why the Government believes that
# voting to remain in the European Union is the best decision for the UK”?

# S1 (?)
# Have you watched more than 15 minutes of television programmes about news,
# politics or current affairs on the following channels during the last 3 days? *Tick all that apply*

# S1_1W18    37825
# S1_2W18    37825
# S1_3W18    37825
# S1_4W18    37825
# S1_5W18    37825
# S1_6W18    37825
# S1_7W18    37825
# S1_8W18    37825
# S1_9W18    37825

# infoSourceTV
# Television
# infoSourcePaper
# Newspaper (including online)
# infoSourceRadio
# Radio
# infoSourceInternet
# Internet (not including online newspapers)
# infoSourcePeople
# Talking to other people W4W5W6W7W8W13

# %%
#

# %%
# During the next 12 months, how likely or unlikely is it that...
# W1W2W3W4W6W8W9W10W11W14W15W16W17
# riskPoverty
# There will be times when you don’t have enough money to cover your day to day living costs
# riskUnemployment
# You will be out of a job and looking for work

# econPersonalRetro
# W1W2W3W4W6W7W8W10W11W12W13W14W15W16W17
# Now, a few questions about economic conditions.
# How does the *financial situation of your household* now compare with what it was 12 months ago? Has it:

# econGenRetro
# W1W2W3W4W6W7W8W10W11W12W13W14W15W16W17
# How do you think the *general economic situation in this country* has changed over the *last 12 months*? Has it:

# econPersonalProsp
# Financial situation of your household
# econGenProsp
# General economic situation in this country

# perceptionsOfPoor
# How much do you agree or disagree with the following statements?
# reasonForUnemployment
# When someone is unemployed, it’s usually through no fault of their own
# immigrantsWelfareState
# Immigrants are a burden on the welfare state W8
# govtHandouts
# Too many people these days like to rely on government handouts
# polForTheRich
# Politicians only care about people with money
# businessBonus
# In business, bonuses are a fair way to reward hard work W1W2W3W4

# borrowEssentials
# Have you needed to borrow money in the last year to pay for household bills, groceries, or other essential day-to-day items?

# smallEmergency
# Suppose that you have an emergency expense that costs £300. Based on your current financial situation, how would you pay for this expense? *Please select all that apply*

# %%
# economyResponsibleW17    34366
# How much is the UK government responsible for how the nation’s economy has changed over the past 12 months?

# responsibleDebt(Conservatives|DontKnow|EU|GlobalBanks|Labour|LiberalDems|None|Other|TradeUnions|UKBanks) W1W2W3W4
# In your opinion, who is responsible for the size of Britain’s national debt? *Please tick all that apply.*

# %%
# Do you think that each of these has gone too far or not far enough?
# cutsTooFarNational W1W2W3W4W6W7W12W14W18
# Cuts to public spending in general
# cutsTooFarNHS
# Cuts to NHS spending*
# cutsTooFarLocal
# Cuts to local services in my area
# privatTooFar
# Private companies running public services
# enviroProtection
# Measures to protect the environment
# tuitionFeesTooFar W6W13
# Increases in tuition fees for University students

# %%
var_dict["efficacyGrid"] = "efficacy|smallVoterPref|smallPartyWastedVote|antiIntellectual"
# efficacyGrid DYNAMIC GRID W1W2W3W4W6W7W8 W10W11W15W16W17 How much do you agree or disagree with the following statements?

# efficacyUnderstand
# I have a pretty good understanding of the important political issues facing our country
# W9W15W16
# antiIntellectual
# I’d rather put my trust in the wisdom of ordinary people than the opinions of experts
# W7W8W9W10W11W15W16W17
# efficacyTooMuchEffort
# It takes too much time and effort to be active in politics and public affairs
# W9W15W16W17
# efficacyNotUnderstand
# It is often difficult for me to understand what is going on in government and politics
# W9W15W16W17
# efficacyPolCare
# Politicians don’t care what people like me think
# W9W15W16W17
# efficacyVoteEffort- Show if youngPerson!=1
# Going to vote is a lot of effort
# W2W4W6
# efficacyEnjoyVote- Show if youngPerson!=1
# Voting is an enjoyable experience
# W2W4W6
# smallPartyWastedVote
# People who vote for small parties are throwing away their vote
# W4W6W11W17
# smallVoterPref
# People should vote for the party they like the most, even if it’s not likely to win
# W4W6W17
# efficacyNoMatter
# It doesn’t matter which political party is in power
# W4W6W8W9W10W11W15W16W17
# efficacyEU
# I have a pretty good understanding of the important issues at stake in the EU referendum
# W8

# %%
var_dict["misc"] = "pcGoneMadW15|womenJobs|UKsovereigntyPost|strongLeader|renationaliseRail|overseasAid|grammar"+\
      "|genderRoles|gayMarriage|climateChange|turkey|keepNukes|zeroHourContract|abortion|monarch|automation"+\
      "|socialPressureVote|dutyToVote|racismAmount"

# racismAmountW4    31551
# Do you think there is a lot of racial prejudice in Britain nowadays, a little or hardly any?

# dutyToVote2 W1W2W3W4W6W7W8W12W14W15W17W18
# It is every citizen’s duty to vote in an election
# socialPressureVote W1W2W3W4W6W7W8W12W14W15W17W18
# Most people I know usually vote in general elections

# socialCareW13    31136
# Should social care for the elderly be paid from general taxation or from the person’s own money (if necessary by selling their home)?

# automationW16                  9330
# How likely do you think it is that in the next 30 years robots and computers will do much of the work currently done by humans?

# And do you think robots and computers doing more of the work currently done by humans would be good or bad for…
# automationEffectsSelfW16       9330
# automationEffectsSelf : you personally
# automationEffectsCountryW16    9330
# automationEffectsCountry: the country as a whole

# monarchW8    33502
# Britain should continue to have a monarchy

# abortionBirthDefectW16    37959
# a woman to have an abortion if there is a strong chance of serious defect in the baby?
# abortionLowIncomeW16      37959
# a woman to have an abortion if the family has a very low income and cannot afford any more children?

# zeroHourContractW6    28721
# Do you think it should be legal for employers to hire workers on contracts that do not give a
# guarantee a minimum number of paid hours per week (also known as zero-hours contracts)?

# keepNukes
# Britain should keep its submarines with nuclear weapons

# turkey SCALE W7 W8
# Would the EU be better or worse if it allowed Turkey to join as a member

# climateChange 

# gayMarriage
# Gay or lesbian couples should have the right to marry one another if they want

# genderRoles
# A man’s job is to earn money, a woman’s job is to look after the home and family

# grammar SINGLE W10W11 Would you support or oppose re-introducing grammar schools?

# overseasAid
# Britain should stop all government spending on overseas aid

# renationaliseRail
# Britain should renationalise the railways

# strongLeader
# The best way to run the country would be to have a strong leader who does not have to bother with parliament or elections

# UKsovereigntyPost
# The EU has undermined the powers of the UK parliament

# womenJobs
# Nowadays, women are given unfair advantages over men when applying for jobs

# pcGoneMadW15
# Some people think that the way people talk needs to be more sensitive to people from different backgrounds.
# Others think that many people are just too easily offended. Where would you place yourself on this scale?

# match(BES_Panel,"pcGoneMadW15|womenJobs|UKsovereigntyPost|strongLeader|renationaliseRail|overseasAid|grammar|genderRoles"+\
#       "|gayMarriage|climateChange|turkey|keepNukes|zeroHourContract|abortion|monarch|automation|socialPressureVote|dutyToVote|racismAmount").sort_index().index

# %%
var_dict["equality"] = "blackEquality|femaleEquality|gayEquality"

# goneTooFarGrid

# blackEquality
# Attempts to give equal opportunities to ethnic minorities
# femaleEquality
# Attempts to give equal opportunities to women
# gayEquality
# Attempts to give equal opportunities to gays and lesbians

# %%
var_dict["ethnic_minority_perceptions"] = "embes"

# embesgrid
# embesExpectationsGapW4
# There is often a big gap between what people from my ethnic group expect out of life and what we actually get.
# embesDiscriminationW4
# Non-White people don’t have the same opportunities and chances in life as White people,
# as they are held back by prejudice and discrimination
# embeshelpW4               
# Do you think it would make them more likely to help if they were of the same ethnic minority background as yourself?

# %%
var_dict["pol_comp_vars"] = "al\d+|lr\d+"
# How much do you agree or disagree with the following statements?
# W1W2W3W4W5|W6|W7W8W9|W10W11W12|W13|W14W15|W16|W17
# roworder randomize
# ROWS
# lr1
# Government should redistribute income from the better off to those who are less well off
# lr2
# Big business takes advantage of ordinary people
# lr3
# Ordinary working people do not get their fair share of the nation’s wealth
# lr4
# There is one law for the rich and one for the poor
# lr5
# Management will always try to get the better of employees if it gets the chance
# lr_scale


# Some people feel that government should make much greater efforts to make people’s incomes more equal.
# Other people feel that government should be much less concerned about how equal people’s incomes are.
# Where would you place yourself and the political parties on this scale?
# W1W2W4W6W7
# redistSelf Yourself
# selfRedistCertain

# How much do you agree or disagree with the following statements?
# W1W2W3W4W5|W6|W7W8W9|W10W11W12|W13|W14W15|W16|W17
# al1
# Young people today don’t have enough respect for traditional British values
# al2
# For some crimes, the death penalty is the most appropriate sentence
# al3
# Schools should teach children to obey authority
# al4
# Censorship of films and magazines is necessary to uphold moral standards
# al5
# People who break the law should be given stiffer sentences
# al_scale

# %%
var_dict["need_for_closure_control"] = "locus|tolUncertain"
# "locus|tolUncertain"

# locus1W8           24536
# locus1W9            7659
# Many times I feel that I have little influence over the things that happen to me.

# locus2W8           24536
# locus2W9            7659
# When I make plans, I am almost certain that I can make them work.

# tolUncertain1W8    24536
# I hate not knowing what the future holds
# tolUncertain2W8    24536
# I strongly prefer to be certain about the outcome before making a decision
# tolUncertain3W8    24536
# I hate uncertainty

# %%
var_dict["risk_tolerance"] = "riskScale|riskTaking"

# riskScaleW8             33502
# We will now ask you to imagine four different situations.
# Each time we will ask you to choose between a guaranteed payment and an even (50-50)
# chance of getting $300 or getting nothing. Please imagine the following situation.
# You can choose between a guaranteed payment of…., or having an even (50-50) chance of getting £300 or getting nothing.
# (The first round is a choice between a 50/50 chance of £300 or a guaranteed payment of £160.
# Subsequent rounds are determined by choices made in the previous rounds.
# The routing of the rounds and the final score as coded in the riskScale variable is shown below,
# higher scores mean more risk taking)

# riskTakingW1W2W3W4W5    41899
# riskTakingW7            30895
# riskTakingW8            33502
#Generally speaking, how willing are you to take risks?

# %%
var_dict["ethnonationalism"] = "ethno"

# ethnoGrid DYNAMIC GRID W7 W9W10 How much do you agree or disagree with the following statements?
# roworder randomize
# ROWS
# ethno1
# Britain has a lot to learn from other countries in running its affairs
# ethno2
# I would rather be a citizen of Britain than of any other country in the world
# ethno3
# There are some things about Britain today that make me ashamed to be British
# ethno4
# People in Britain are too ready to criticise their country
# ethno5
# The world would be a better place if people from other countries were more like the British
# ethno6
# I am often less proud of Britain than I would like to be

# %%
var_dict["preference_for_change"] = "radical|harkBack"

# prefChangeGrid DYNAMIC GRID W7 W10W11 How much do you agree or disagree with the following statements?
# roworder randomize
# ROWS
# radical
# We need to fundamentally change the way society works in Britain
# harkBack
# Things in Britain were better in the past

# %%
var_dict["freeSpeech"] = "freeSpeech"

# Consider a person who believe that whites are racially superior to all other races. Do you think such a person should be allowed to . .
# ROWS
# freeSpeechRacistSpeech
# Make a speech in your community
# freeSpeechRacistElection
# stand as a candidate in elections
# freeSpeechRacistTV
# give interviews on television to put their case
# freeSpeechRacistTeach
# teach 15 year olds in schools

# Consider a person who advocates doing away with elections and letting the military run the country. Do you think such a person people should be allowed to . .
# ROWS
# freeSpeechMilitarySpeech
# Make a speech in your community
# freeSpeechMilitaryElection
# stand as a candidate in elections
# freeSpeechMilitaryTV
# give interviews on television to put their case
# freeSpeechMilitaryTeach
# teach 15 year olds in schools

# Consider a Muslim clergyman who preaches hatred of the West. Do you think such a person should be allowed to . .
# ROWS
# freeSpeechIslamistSpeech
# Make a speech in your community
# freeSpeechIslamistElection
# stand as a candidate in elections
# freeSpeechIslamistTV
# give interviews on television to put their case
# freeSpeechIslamistTeach
# teach 15 year olds in schools

# %%
var_dict["euAgreeDisagree2"] = "normEU|willOfPeople|euUndermineIdentity|britishPride"

# How much do you agree or disagree with the following statements?
# roworder randomize
# ROWS
# normEU
# Most people I know will vote to remain in the European Union W15
# willOfPeople
# Britain should leave the EU because that is what people voted for W15W16
# euUndermineIdentity
# Being a member of the European Union undermines Britain’s distinctive identity
# britishPride
# I feel proud to be British W15W16W17

# %%
var_dict["corbynPredictors"] = "prefTradeoff|beliefTradeoff"

# How much do you agree or disagree with the following statements?
# prefTradeoff
# The party I support shouldn't compromise on its values just to get more votes
# beliefTradeoff
# Parties are more likely to win elections when they stick to their principles

# %%
var_dict["activeOpenMinded"] = "aom"

# activeOpenMinded GRID W7 Do you agree or disagree with the following statements?
# ROWS
# aom1
# Allowing oneself to be convinced by an opposing argument is a sign of good character
# aom2
# People should take into consideration evidence that goes against their beliefs
# aom3
# People should revise their beliefs in response to new information or evidence
# aom4
# Changing your mind is a sign of weakness
# aom5
# Intuition is the best guide in making decisions
# aom6
# It is important to persevere in your beliefs even when evidence is brought to bear against them
# aom7
# One should disregard evidence that conflicts with one's established beliefs

# %%
var_dict["authoritarianism"] = "auth"

# Please tell me which one you think is more important for a child to have:
# W10W11W14W19    
# auth1
# Independence
# Respect for elders

# auth2
# Obedience
# Self-reliance

# auth3
# To be considerate
# To be well-behaved

# auth4
# Curiosity
# Good manners

# auth5
# Orderly
# Imaginative

# How much do you agree or disagree with the following statement?
# authLong1W10    7631
# It is more important for a child to have independence than respect for elders.
# authLong2W10    7631
# It is more important for a child to have obedience than self-reliance.
# authLong3W10    7631
# It is more important for a child to be considerate than well-behaved.
# authLong4W10    7631
# It is more important for a child to have curiosity than good manners.

# %%
var_dict["competitiveness"] = "competitiveness"

# competitiveness1W19    8126
# competitiveness2W19    8126
# competitiveness3W19    8126
# competitiveness4W19    8126

# Which trait is more important for a child to be?
# competitiveness1 SINGLE CHOICE W19 
# Kind
# Tough

# competitiveness2 SINGLE CHOICE W19
# Compromising
# Aggressive

# competitiveness3
# Strong-willed
# Good-natured

# competitiveness4
# Forceful
# Empathetic

# %%
var_dict["populism"] = "populism"

# Populism DYNAMIC GRID W7W10W11W15W17 topup Do you agree or disagree with the following statements?
# roworder randomize
# ROWS
# populism1
# The politicians in the UK Parliament need to follow the will of the people
# populism2
# The people, and not politicians, should make our most important policy decisions.
# populism4
# I would rather be represented by a citizen than by a specialized politician
# populism5
# Elected officials talk too much and take too little action
# populism6
# What people call “compromise” in politics is really just selling out on one’s principles

# %%
var_dict["sexism"] = "benevolentSexism|hostileSexism"

# benevolentSexism1W19    8126
# Women should be cherished and protected by men
# benevolentSexism2W19    8126
# Many women have a quality of purity that few men possess
# benevolentSexism3W19    8126
# A good woman should be set on a pedestal by her man

# hostileSexism1W19       8126
# Most women fail to appreciate fully all that men do for them
# hostileSexism2W19       8126
# Women seek to gain power by getting control over men
# hostileSexism3W19       8126
# Most women interpret innocent remarks or acts as being sexist

# hostileSexismM1W19      8126
# Most men fail to appreciate fully all that women do for them
# hostileSexismM2W19      8126
# Men seek to gain power by getting control over men

# %%
var_dict["community"] = "community"

# community1W19    8126
# Which description comes closest to describing your ideal community?
# Having neighbours who have a lot in common with each other
# Having neighbours who are different in interesting ways
# community2W19    8126
# Which statement comes closer to your own views – even if neither is exactly right?
# It is **important** to me that people in my community speak English well.
# It is **not important** to me that people in my community speak English well.
# community3W19    8126
# Which statement comes closer to your own views – even if neither is exactly right?
# I’m **bothered** when I see people in my community wearing clothing customary in other countries
# I’m **not bothered** when I see people in my community wearing clothing customary in other countries
# community4W19    8126
# Which statement comes closer to your own views – even if neither is exactly right?
# Strong communities that emphasize strong marriages and families make real freedom possible.
# Real freedom is when people can make their own choices without family or community trying to restrain them.

# %%
var_dict["incremental"] = "incremental"

# incremental1W19    8126
# Which statement comes closer to your own views – even if neither is exactly right?
# To understand the world, people must free their minds from established traditions.
# Established traditions provide the wisdom necessary to understand the world.
# incremental2W19    8126
# Which statement comes closer to your own views – even if neither is exactly right?
# If ideas have been around for a long time, they probably need to be updated.
# If ideas have been around for a long time, they probably have wisdom in them
# incremental3W19    8126
# Which statement comes closer to your own views – even if neither is exactly right?
# The world is always changing, so we **should adjust** our view of moral behavior to those changes
# Even though the world is always changing, we **should not adjust** our view of moral behavior to those changes.
# incremental4W19    8126
# Which statement comes closer to your own views – even if neither is exactly right?
# It is better to **stick with established ideas** that have proven their value
# It is better to **search for new ways** of doing things that might be better.

# %%
var_dict["discrimination"] = "discrim"

# discrim discrim GRID W10W14 How much discrimination is there for or against the following groups?
# roworder randomize
# ROWS
# discrimBME
# Black and minority ethnic
# discrimWhite
# Whites
# discrimWomen
# Women
# discrimMen
# Men
# discrimMuslims
# Muslims
# discrimChristians
# Christians

# %%
var_dict["social_dominance_orientation"] = "sdo"

# Show how much you favor or oppose each idea below by selecting a number from 1 to 7 on the scale below.
# You can work quickly; your first feeling is generally best.

# sdoantiegal1W15     6982
# Group equality should not be our primary goal.
# sdoantiegal2W15     6982
# It is unjust to try to make groups equal.
# sdoantiegal3W15     6982
# We should do what we can to equalize conditions for different groups.
# sdoantiegal4W15     6982
# We should work to give all groups an equal chance to succeed.
# sdodominance1W15    6982
# An ideal society requires some groups to be on top and others to be on the bottom.
# sdodominance2W15    6982
# Some groups of people are simply inferior to other groups.
# sdodominance3W15    6982
# No one group should dominate in society.
# sdodominance4W15    6982
# Groups at the bottom are just as deserving as groups at the top.

# %%
var_dict["groupempathy"] = "groupempathy"

# We are interested in how you feel about people from other groups in our society.
# How well do the following phrases describe you?
# groupempathy1W14    7691
# I sometimes try to better understand people of other racial or ethnic groups by imagining how things
# look from their perspective.
# groupempathy2W14    7691
# Before criticizing somebody from another racial or ethnic group, I try to imagine how I would feel if I were in their place.
# groupempathy3W14    7691
# I often have tender, concerned feelings for people from another racial or ethnic group who are less fortunate than me.
# groupempathy4W14    7691
# When I see someone being taken advantage of due to their race or ethnicity, I feel protective towards them.

# %%
var_dict["empathy"] = "empathy"

# empathy1W14     7691
# I can usually figure out when my friends are scared
# empathy2W14     7691
# I can usually realize quickly when a friend is angry
# empathy3W14     7691
# I can usually figure out when people are cheerful
# empathy4W14     7691
# I am not usually aware of my friends’ feelings
# empathy5W14     7691
# When someone is feeling ‘down’ I can usually understand how they feel
# empathy6W14     7691
# After being with a friend who is sad about something, I usually feel sad
# empathy7W14     7691
# My friends' unhappiness doesn't make me feel anything
# empathy8W14     7691
# Other people's feelings don't bother me at all
# empathy9W14     7691
# I don't become sad when I see other people crying
# empathy10W14    7691
# My friends' emotions don’t affect me much

# %%
var_dict["childvalues"] = "childvalues"

# Here is a list of qualities that children can be encouraged to learn at home. Which, if any, do you consider
# to be especially important? Please choose up to five
# childvalues_1
# Independence
# childvalues_2
# Hard work
# childvalues_3
# Feeling of responsibility
# childvalues_4
# Imagination
# childvalues_5
# Tolerance and respect for other people
# childvalues_6
# Thrift, saving money and things
# childvalues_7
# Determination, perseverance
# childvalues_8
# Relgious faith
# childvalues_9
# Unselfishness
# childvalues_10
# Obedience

# %%
var_dict["zeroSum"] = "zeroSum"

# zeroSum DYNAMIC GRID W14 How much do you agree or disagree with the following statement?
# zeroSum7
# The only way to make someone better off is to make someone else worse off
# zeroSum11
# Everyone can be a winner at the same time
# zeroSum 5
# Life isn’t about winners and losers, everyone can do well
# zeroSum9
# There are ways to make everyone better off without anyone losing out
# zeroSum1
# One person’s loss is another person’s gain
# zeroSum4
# There’s only so much to go around. Life is about how big a slice of the pie you can get.

# zeroSumIRTW14 -> might be a summary of all?

# %%
pd.Series(var_dict).to_pickle(BES_small_data_files+"attitudinal_var_patterns.zip",compression='zip')

# %%
val_cols = match(BES_reduced_with_na,"|".join(var_dict.values())).index
BES_vals[val_cols] = BES_reduced_with_na[val_cols].astype('float32')

# %%
BES_reduced_with_na[val_cols].astype('float32').shape
# Out:
# (97158, 503)

# %%
# %%time
raw_corrs = BES_vals.corr()
# Out:
# Wall time: 1min 45s

# %%
# from sklearn.covariance import LedoitWolf
# cov = LedoitWolf().fit(BES_vals.values)
# cov.covariance_

# %%
ncomp = 100
drop_rows = BES_vals.index[(BES_vals.notnull().sum(axis=1)<=ncomp)]
drop_cols = BES_vals.columns[(BES_vals.notnull().sum(axis=0)<=ncomp)]

# %%
X = BES_vals.drop(drop_rows).drop(drop_cols,axis=1)
X.shape
# Out:
# (42727, 523)

# %%
from statsmodels.multivariate.pca import PCA
pc = PCA(data=X.values,ncomp=10, missing='fill-em')

# an hour~

# %%
Y = pd.DataFrame(pc.transformed_data,index=X.index,columns=X.columns)

# %%
# %%time
from statsmodels.multivariate.pca import PCA
pc2 = PCA(data=Y,ncomp=10)
# Out:
# Wall time: 21min 45s

# %%
pc2.loadings["comp_0"].sort_values(ascending=False).head(50)
# Out:
# overseasAidW11__Strongly agree                0.108575
# al2W7W8W9__Strongly agree                     0.107287
# al2W13__Strongly agree                        0.106671
# al1W13__Strongly agree                        0.106067
# overseasAidW10__Strongly agree                0.104671
# al2W10W11W12__Strongly agree                  0.103258
# al1W7W8W9__Strongly agree                     0.102540
# al5W7W8W9__Strongly agree                     0.102176
# euUndermineIdentityW8__Strongly agree         0.101458
# al1W10W11W12__Strongly agree                  0.100785
# overseasAidW14__Strongly agree                0.100454
# al5W13__Strongly agree                        0.099886
# al5W10W11W12__Strongly agree                  0.098549
# al2W14W15__Strongly agree                     0.097366
# euUndermineIdentityW7__Strongly agree         0.097150
# al1W14W15__Strongly agree                     0.096784
# blackEqualityW6_W14__Gone much too far        0.096187
# ...

# %%
pc2.loadings["comp_1"].sort_values(ascending=False).head(50)
# Out:
# conGovTrustW5__ Would do a good job               0.112871
# trustMPsW6__A great deal of trust                 0.105843
# trustMPsW7__A great deal of trust                 0.102740
# trustMPsW9__A great deal of trust                 0.099024
# trustMPsW4__A great deal of trust                 0.097758
# trustMPsW10__A great deal of trust                0.097190
# trustMPsW3__A great deal of trust                 0.093030
# trustMPsW2__A great deal of trust                 0.088041
# trustMPsW1__A great deal of trust                 0.086704
# zeroHourContractW6__Should definitely be legal    0.081905
# trustMPsW19__A great deal of trust                0.080904
# grammarW11__Strongly support                      0.068037
# monarchW8__Strongly agree                         0.065015
# trustYourMPW4__A great deal of trust              0.064218
# keepNukesW12__Strongly agree                      0.063474
# trustMPsW18__A great deal of trust                0.062999
# ...

# %%
pc2.loadings["comp_2"].sort_values(ascending=False).head(50)
# Out:
# efficacyUnderstandW4__Strongly agree      0.162263
# efficacyUnderstandW6__Strongly agree      0.161613
# efficacyUnderstandW7__Strongly agree      0.156858
# efficacyUnderstandW8__Strongly agree      0.153912
# efficacyUnderstandW2__Strongly agree      0.152456
# efficacyUnderstandW3__Strongly agree      0.149488
# efficacyUnderstandW1__Strongly agree      0.149206
# efficacyUnderstandW9__Strongly agree      0.138183
# efficacyEUW8__Strongly agree              0.136322
# efficacyUnderstandW11__Strongly agree     0.129577
# efficacyUnderstandW10__Strongly agree     0.124432
# efficacyEnjoyVoteW4__Strongly agree       0.116821
# dutyToVote2W2__Strongly agree             0.112270
# efficacyEnjoyVoteW2__Strongly agree       0.109307
# dutyToVote2W4__Strongly agree             0.109104
# efficacyUnderstandW15__Strongly agree     0.107795
# dutyToVote2W3__Strongly agree             0.107326
# efficacyEnjoyVoteW6__Strongly agree       0.107055
# ...

# %%
pc2.loadings["comp_3"].sort_values(ascending=False).head(50)
# Out:
# efficacyPolCareW2__Strongly agree                   0.096281
# efficacyPolCareW4__Strongly agree                   0.092190
# efficacyPolCareW1__Strongly agree                   0.089790
# freeSpeechRacistSpeechW15__Definitely               0.087020
# freeSpeechIslamistElectionW15__Definitely           0.086813
# freeSpeechIslamistTVW15__Definitely                 0.086666
# efficacyPolCareW3__Strongly agree                   0.086557
# freeSpeechRacistElectionW15__Definitely             0.086247
# freeSpeechIslamistSpeechW15__Definitely             0.085693
# freeSpeechMilitarySpeechW15__Definitely             0.085432
# freeSpeechRacistTVW15__Definitely                   0.084756
# efficacyPolCareW6__Strongly agree                   0.084649
# freeSpeechMilitaryTVW15__Definitely                 0.084325
# freeSpeechMilitaryElectionW15__Definitely           0.081997
# discrimMenW14__A lot of discrimination against      0.072010
# ...

# %%
pc2.loadings["comp_4"].sort_values(ascending=False).tail(50)
# Out:
# efficacyNoMatterW17__Strongly agree                                                                                               -0.060218
# zeroSum4W14__Strongly agree                                                                                                       -0.060374
# al2W16__Strongly agree                                                                                                            -0.060452
# al2W17__Strongly agree                                                                                                            -0.061009
# freeSpeechRacistTeachW15__Definitely                                                                                              -0.062190
# antiIntellectualW16__Strongly agree                                                                                               -0.062777
# auth4W11_Imaginative                                                                                                              -0.062868
# ...

# %%
BES_decomp= pc2.factors
BES_decomp.columns = [int(x.replace("comp_","")) for x in BES_decomp.columns]

# %%
pc2.components_
n_components=10,
BES_decomp= pc2.factors,
cols = X.columns,
decomp.components_ = pc2.loadings

# %%
(_, comp_labels, comp_dict) = display_components(n_components=10,decomp=pc2,cols = X.columns,BES_decomp=BES_decomp,
                                                 manifest=manifest,show_first_x_comps=10)

# %%
# %debug
# Out:
# > c:\programdata\anaconda3\envs\bes_analysis\lib\site-packages\matplotlib\axes\_base.py(3158)_validate_converted_limits()
#    3156             if (isinstance(converted_limit, Real)
#    3157                     and not np.isfinite(converted_limit)):
# -> 3158                 raise ValueError("Axis limits cannot be NaN or Inf")
#    3159             return converted_limit
#    3160
#
# ipdb> quit

# %%
def display_components(n_components, decomp, cols, BES_decomp, manifest, 
                       save_folder = False, show_first_x_comps=4,
                       show_histogram=True, flip_axes=True, max_comp=20, max_var_per_comp = 30):
    
    if hasattr(decomp, 'coef_'):
        decomp_components = decomp.coef_
    elif hasattr(decomp, 'loadings'):
        decomp_components = decomp.loadings      
#         decomp_components.columns = [int(x.replace("comp_","")) for x in decomp_components]
    elif hasattr(decomp, 'components_'):
        decomp_components = decomp.components_

    else:
        raise ValueError('no component attribute in decomp')    

    # hardcoded at 20?    
    n_comps = min(n_components,max_comp)
    comp_labels = {}
    comp_dict = {}

    for comp_no in range(0,n_comps):

        fig, axes = plt.subplots(ncols=1+show_histogram)
        
        comp = pd.DataFrame( decomp_components[comp_no], index = cols )
        comp.columns = ["components_"]
        comp["comp_absmag"] = comp["components_"].abs()
        comp = comp.sort_values(by="comp_absmag",ascending=True)        
        
        if show_histogram:
            comp_ax = axes[0]
            
            hist_ax = axes[1]
            hist_ax.set_xlabel("abs. variable coeffs")
            hist_ax.set_title("Histogram of abs. variable coeffs")
            comp["comp_absmag"].hist( bins=30, ax=hist_ax, figsize=(10,6) )
            
        else:
            comp_ax = axes
            
        # set top abs_mag variable to label
        comp_labels[comp_no] = comp.index[-1:][0] # last label (= highest magnitude)
        # if top abs_mag variable is negative
     
        if flip_axes & (comp[-1:]["components_"].values[0] < 0):

            comp["components_"]         = -comp["components_"]
            decomp_components[comp_no]  = -decomp_components[comp_no]
            BES_decomp[comp_no]         = -BES_decomp[comp_no]

        dataset_description = manifest["Friendlier_Description"].values[0]
        title = "Comp. "+str(comp_no)+" (" + comp.index[-1:][0] + ")"
        comp_labels[comp_no] = title
        comp_ax.set_title( dataset_description + "\n" + title )
        comp_ax.set_xlabel("variable coeffs")
        xlim = (min(comp["components_"].min(),-1) , max(comp["components_"].max(),1) )
        comp["components_"].tail(max_var_per_comp).plot( kind='barh', ax=comp_ax, figsize=(10,6), xlim=xlim )
        dataset_citation = "Source: " + manifest["Citation"].values[0]

        if (save_folder != False):
            comp_ax.annotate(dataset_citation, (0,0), (0, -40),
                             xycoords='axes fraction', textcoords='offset points', va='top', fontsize = 7)            
            fname = save_folder + clean_filename(title) + ".png"
            fig.savefig( fname, bbox_inches='tight' )

        comp_dict[comp_no] = comp
        # show first x components
        if (comp_no >= min(show_first_x_comps,n_components)):
            plt.close()

        
    return (BES_decomp, comp_labels, comp_dict)

# %%
from pyppca import ppca
C, ss, M, X, Ye = ppca(X,ncomp,True)

Implements probabilistic PCA for data with missing values,
    using a factorizing distribution over hidden states and hidden observations.
    Args:
        Y:   (N by D ) input numpy ndarray of data vectors
        d:   (  int  ) dimension of latent space
        dia: (boolean) if True: print objective each step
    Returns:
        ss: ( float ) isotropic variance outside subspace
        C:  (D by d ) C*C' + I*ss is covariance model, C has scaled principal directions as cols
        M:  (D by 1 ) data mean
        X:  (N by d ) expected states
        Ye: (N by D ) expected complete observations (differs from Y if data is missing)

# %%
search(BES_Panel,"howLongLivedHere")
# Out:
# howLongLivedHereW19    8105
# dtype: int64

# %%
search(BES_reduced_with_na,"howLongLivedHereW19")
# Out:
# howLongLivedHereW19__All my life    7975
# dtype: int64

# %%
# %%time
# BES_reduced_with_na["trust_per_resp"] = trust_per_resp
pattern = "howLongLivedHereW19__All my life"
name = "howLongLivedHereW19__All my life"
corr_type = "spearman"
corr_df,corr_type = make_corr_summary(BES_reduced_with_na, name, corr_type, pattern=pattern)
display_corr(corr_df, name, corr_type, text_wrap_length=50)
# Out:
# <style  type="text/css" >
# </style><table id="T_6d2fb1d8_8d89_11ea_8542_20cf301b91b3" style='display:inline'><caption>Top 20 positive (spearman) correlations for howLongLivedHereW19__All my life</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >r</th>        <th class="col_heading level0 col1" >p</th>        <th class="col_heading level0 col2" >N</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d2fb1d8_8d89_11ea_8542_20cf301b91b3level0_row0" class="row_heading level0 row0" >mapLiveTimeW3__More than ten years</th>
#                         <td id="T_6d2fb1d8_8d89_11ea_8542_20cf301b91b3row0_col0" class="data row0 col0" >0.560000</td>
#                         <td id="T_6d2fb1d8_8d89_11ea_8542_20cf301b91b3row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_6d2fb1d8_8d89_11ea_8542_20cf301b91b3row0_col2" class="data row0 col2" >1918</td>
#             </tr>
# ...

# %%
search(BES_Panel,"wt_new")
# Out:
# wt_new_W10           30237
# wt_new_W11           30956
# wt_new_W14           31063
# wt_new_W15           30842
# wt_new_W16           37959
# wt_new_W1_W16         2427
# wt_new_W18           37825
# wt_new_W6W7          21081
# wt_new_W2W6          23163
# wt_new_W2W6W7        17076
# wt_new_W9_W13        12562
# wt_new_W12           34394
# wt_new_W1_W11         6473
# wt_new_W1_W12         5833
# wt_new_W1_W13         5301
# wt_new_W6_W11         9373
# wt_new_W6_W12         8398
# wt_new_W6_W13         7622
# wt_new_W11_W13       21520
# wt_new_W13W16        14647
# wt_new_W13_result    31135
# wt_new_W6W16          9587
# wt_new_W2W16          8388
# wt_new_W17           34366
# wt_new_W13W17        15744
# wt_new_W6W13W19       8743
# wt_new_W9W19         13604
# wt_new_W13_W19        5861
# wt_new_W13W19        15811
# wt_new_W16W19        21840
# wt_new_W17W18W19     19000
# wt_new_W19_result    32177
# wt_new_W9            30036
# wt_new_W8            33502
# ...

# %%
BES_Panel[["id","wt_new_W19_result"]][BES_Panel["wave19"]].sort_values(by="id")
# Out:
#           id  wt_new_W19_result
# 27337      2           0.471180
# 3540       3           0.346831
# 6014       6           0.468355
# 1026       7           0.532937
# 12562     14           0.656503
# ...      ...                ...
# 7630   98435           1.182517
# 7982   98437           1.872448
# 7029   98440           2.950034
# 6556   98445           1.446198
# 31539  98449           6.031430
#
# [32806 rows x 2 columns]

# %%
# cogempathyIRTW14, affempathyIRTW14, zeroSumIRTW14
