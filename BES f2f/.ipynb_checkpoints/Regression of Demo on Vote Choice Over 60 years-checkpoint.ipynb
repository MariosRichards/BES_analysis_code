# %%
# %%time
## Just an easy way to load utility functions
dataset_name = "W19_only"
df_list = []

# %matplotlib inline 
# %run f2f_header.py {dataset_name} {df_list}

global BES_label_list, BES_df_list

# %run f2f_utility.py

BES_df_list = pickle.load( open( "E:\\BES_analysis_data\\Face_to_face\\BES_df_list.pickle", "rb" ) )
# f2f_harmonised = pd.read_pickle("E:\\BES_analysis_data\\Face_to_face\\f2f_harmonised.zip", compression='zip')
BES_label_list = pickle.load( open( "E:\\BES_analysis_data\\Face_to_face\\BES_label_list.pickle", "rb" ) )
demo_var_dict = pickle.load( open( "E:\\BES_analysis_data\\Face_to_face\\demo_var_dict.pickle", "rb" ) )
var_type_dict_nonans = pickle.load( open( "E:\\BES_analysis_data\\Face_to_face\\var_type_dict_nonans.pickle", "rb" ) )

f2f_harmonised = pd.read_pickle("E:\\BES_analysis_data\\Face_to_face\\f2f_harmonised_temp.zip", compression='zip')


generic_cols = f2f_harmonised.columns
list_of_scale_harm_vars = ["Age","year_past_min_sch_leave_age","in_school_past_min_age"]



## BUGS

BES_label_list["1959"]["v1236"] = 'LOCAL ELECTION VOTE 1963(2nd)'
BES_label_list["1964"]["v1236"] = 'LOCAL ELECTION VOTE 1963(2nd)'
BES_label_list["1966"]["v1236"] = 'LOCAL ELECTION VOTE 1963(2nd)'
BES_label_list["1970"]["v1236"] = 'LOCAL ELECTION VOTE 1963(2nd)'

BES_label_list["2015"]['edlevel'] = 'Education level (summary)'
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>

# %%
## easiest breakdown - drop non-voting, just look at bloc vs bloc

# %%
search(f2f_harmonised,"bloc|housing")
# Out:
# housing_det      51587
# housing          51587
# bloc             52198
# bloc_complete    52132
# dtype: int64

# %%
f2f_harmonised["bloc_complete"].value_counts(dropna=False)
# Out:
# Left-Lib      24460
# Right-Auth    17675
# Neither        9997
# NaN             599
# Name: bloc_complete, dtype: int64

# %%
mask = f2f_harmonised["bloc_complete"].isin(["Left-Lib","Right-Auth"])
f2f_harmonised["auth_right_vote"] = f2f_harmonised["bloc_complete"]=="Right-Auth"
pd.get_dummies(f2f_harmonised["housing_det"][mask]).groupby(f2f_harmonised["dataset"][mask]).corrwith(f2f_harmonised["auth_right_vote"][mask])
# Out:
#               MORT       OWN  OWN-MORT  RENT-ALL   RENT-HA   RENT-LA   RENT-PR
# dataset
# 1959           NaN       NaN  0.067672       NaN       NaN -0.060479 -0.016846
# 1964           NaN       NaN  0.064108       NaN       NaN -0.060381 -0.014639
# 1966           NaN       NaN  0.066733       NaN       NaN -0.059364 -0.016523
# 1970           NaN       NaN  0.050155       NaN       NaN -0.058856 -0.000557
# 1974_feb  0.015360  0.016330       NaN       NaN       NaN -0.021718 -0.010495
# 1974_oct  0.018641  0.017384       NaN       NaN       NaN -0.033603 -0.001142
# 1979      0.005803  0.028094       NaN       NaN       NaN -0.025632 -0.002963
# 1983           NaN       NaN  0.031815       NaN -0.020021 -0.027697 -0.006229
# 1987           NaN       NaN  0.024745       NaN -0.012747 -0.020557 -0.012254
# 1992      0.018250  0.024655       NaN       NaN -0.026715 -0.038790 -0.008565
# 1997      0.012431  0.000907       NaN       NaN  0.002525 -0.019836  0.007001
# 2001      0.002718  0.008410       NaN -0.012325       NaN       NaN       NaN
# 2005     -0.008005  0.018562       NaN       NaN -0.004481 -0.009876 -0.004810
# 2010     -0.003067  0.005386       NaN       NaN -0.001012 -0.010678  0.007858
# 2015     -0.008814  0.021636       NaN       NaN  0.008192 -0.021246 -0.008077
# 2017     -0.000919  0.016350       NaN       NaN -0.013249 -0.004714 -0.010492
# 2019     -0.006949  0.012852       NaN       NaN -0.001740 -0.000158 -0.007249

# %%
mask = f2f_harmonised["bloc_complete"].isin(["Left-Lib","Right-Auth"])
f2f_harmonised["auth_right_vote"] = f2f_harmonised["bloc_complete"]=="Right-Auth"
df = pd.get_dummies(f2f_harmonised["housing"][mask]).groupby(f2f_harmonised["dataset"][mask]).corrwith(f2f_harmonised["auth_right_vote"][mask])
df.plot(kind='bar',title="Right_Auth");

# %%
def party_by_housing(vote):
    f2f_harmonised[vote] = f2f_harmonised["vote_complete"]==vote
    df = pd.get_dummies(f2f_harmonised["housing"]).groupby(f2f_harmonised["dataset"]).corrwith(f2f_harmonised[vote])
    df.plot(kind='bar',title=vote);

# %%
party_by_housing("CON"),party_by_housing("LAB"),party_by_housing("LD"),party_by_housing("DNV");

# %%
f2f_harmonised.columns
# Out:
# Index(['dataset', 'uid', 'housing_det', 'housing', 'inc', 'vote', 'year', 'wt',
#        'age', 'vote_simple', 'bloc', 'birth_year', 'harmonised_voted',
#        'inc_det', 'vote_complete', 'vote_complete_simple', 'bloc_complete',
#        'turnout_complete', 'gender', 'gender_complete', 'age_left_education',
#        'age_left_education_2', 'age_left_education_3', 'anyQuals',
#        'rsa_or_city_and_guilds', 'overseas_other_postschl', 'overseas_degree',
#        'other_academic_vocational', 'other_tech_business',
#        'higher_onc_ond_bec_tec', 'ordinary_gen_onc_ond_bec_tec',
#        'trade_appenticeship', 'nursing', 'teachers_training',
#        'city_and_guilds_cert_part1', 'city_and_guilds_full_tech',
#        'city_and_guilds_advanced_final', 'city_and_guilds_craft_ordinary',
#        'rsa_other_commercial', 'school_cert_or_matric',
#        'uni_cnaa_degree_or_diploma', 'os_schl_leav_qual',
#        'a_level_scot_higher', 'cse_grade_1_scot_lower', 'cse_grade_2_5',
#        'professional_qualification', 'spec_qual_gained_at_work',
#        'other_qualification', 'highest_qualification', 'nvq_sqv_l1',
#        'nvq_sqv_l2', 'nvq_sqv_l3', 'nvq_sqv_l4', 'nvq_sqv_l5', 'edqual21',
#        'att_university', 'att_commercial_training',
#        'att_polytech_or_techcollege', 'att_night_school',
#        'att_non_voc_training', 'att_other', 'att_art_school',
#        'att_college_of_commerce', 'att_teacher_training',
#        'att_trade_military_apprent', 'att_tech_college_teacher_nursing',
#        'att_tech_or_occ_training', 'att_summer_schl_corresp_courses',
#        'att_NoFE', 'att_forces_training', 'school_type', 'school_selective',
#        'school_fees', 'school_fees_when', 'school_where', 'school_type_2',
#        'auth_right_vote', 'CON', 'LAB', 'LD', 'DNV'],
#       dtype='object')

# %%
f2f_harmonised["CON"] = f2f_harmonised["vote_complete_simple"]=="CON"
f2f_harmonised["LAB"] = f2f_harmonised["vote_complete_simple"]=="LAB"
f2f_harmonised["DNV"] = f2f_harmonised["vote_complete_simple"]=="DNV"
f2f_harmonised["LD"]  = f2f_harmonised["vote_complete_simple"]=="LD"
f2f_harmonised["REFUK"]  = f2f_harmonised["vote_complete_simple"]=="REFUK"
f2f_harmonised["decade"] = f2f_harmonised["age"]/10
f2f_harmonised["generation"] = f2f_harmonised["age"]/20
inc_maxes = f2f_harmonised.groupby("dataset")["inc_det"].max().to_dict()
f2f_harmonised["inc_norm"] = f2f_harmonised.apply(lambda x: x["inc_det"]/inc_maxes[x["dataset"]] , axis=1 )#.groupby(f2f_harmonised["dataset"]).hist()
## do a proper version with weighting/quantiles

f2f_harmonised["inc_norm_wt"]=np.nan
temp = (f2f_harmonised[f2f_harmonised["wt"].notnull()].groupby("dataset").apply(lambda x: weighted_qcut(x["inc_det"],x["wt"],21)).cat.codes/20)
reverse_dict = {v:k for k,v in f2f_harmonised[f2f_harmonised["wt"].notnull()].groupby("dataset").apply(lambda x: x["uid"]).to_dict().items()}
f2f_harmonised.loc[f2f_harmonised["wt"].notnull(),"inc_norm_wt"]=temp.loc[f2f_harmonised["uid"][f2f_harmonised["wt"].notnull()].apply(lambda x: reverse_dict[x])].values
# weighted_qcut
f2f_harmonised["inc_norm_wt"].hist(bins=100)
f2f_harmonised[["inc_det","inc_norm","inc_norm_wt"]].corr()
# Out:
#               inc_det  inc_norm  inc_norm_wt
# inc_det      1.000000  0.927910     0.866745
# inc_norm     0.927910  1.000000     0.951784
# inc_norm_wt  0.866745  0.951784     1.000000

# %%
wt_means = f2f_harmonised.groupby("dataset")["wt"].mean().to_dict()
f2f_harmonised["wt_norm"] = f2f_harmonised.apply(lambda x: x["wt"]/wt_means[x["dataset"]] , axis=1 )

# %%
f2f_harmonised.groupby("dataset")["wt_norm"].mean()
# Out:
# dataset
# 1959        1.0
# 1964        1.0
# 1966        1.0
# 1970        1.0
# 1974_feb    1.0
# 1974_oct    1.0
# 1979        1.0
# 1983        1.0
# 1987        1.0
# 1992        1.0
# 1997        1.0
# 2001        1.0
# 2005        1.0
# 2010        1.0
# 2015        1.0
# 2017        1.0
# 2019        1.0
# Name: wt_norm, dtype: float64

# %%
f2f_harmonised.groupby("dataset")["age_left_education_3"].apply(lambda x: x.isnull().sum())
# Out:
# dataset
# 1959         38
# 1964         38
# 1966         38
# 1970         38
# 1974_feb     16
# 1974_oct     21
# 1979          2
# 1983          7
# 1987         12
# 1992         15
# 1997         17
# 2001          6
# 2005          5
# 2010          4
# 2015         94
# 2017         38
# 2019        178
# Name: age_left_education_3, dtype: int64

# %%
f2f_harmonised.groupby("dataset")["age"].std()
# Out:
# dataset
# 1959        17.009940
# 1964        17.009940
# 1966        16.967905
# 1970        16.973223
# 1974_feb    17.453201
# 1974_oct    17.589125
# 1979        17.188263
# 1983        17.798715
# 1987        17.799558
# 1992        17.529583
# 1997        18.060027
# 2001        18.033689
# 2005        17.783624
# 2010        17.858522
# 2015        18.062168
# 2017        18.447279
# 2019        17.846707
# Name: age, dtype: float64

# %%
f2f_harmonised.groupby("dataset")["age_left_education_3"].value_counts()
# Out:
# dataset  age_left_education_3
# 1959     15 or younger           2271
#          16                       307
#          18                       263
#          19 or older               43
# 1964     15 or younger           2271
#                                  ...
# 2017     16                       311
# 2019     19 or older             1672
#          15 or younger            964
#          18                       681
#          16                       451
# Name: age_left_education_3, Length: 68, dtype: int64

# %%
ge_to_date_dict = {'1959':"8/10/1959", '1964':"15/10/1964", '1966':"31/3/1966", '1970':"18/6/1970", '1974_feb':"28/2/1974",
 '1974_oct':"10/10/1974", '1979':"5/3/1979", '1983':"9/6/1983",'1987':"11/6/1987", '1992':"9/4/1992",
 '1997':"1/5/1997", '2001':"7/6/2001", '2005':"5/5/2005", '2010':"6/5/2010", '2015':"7/5/2015",
 '2017':"8/6/2017", '2019':"12/12/2019"}

def errplot(x, y, yerr, **kwargs):
    ax = plt.gca()
    data = kwargs.pop("data")
#     raise Exception
    data.plot(x=x, y=y, yerr=yerr,xerr=None, kind="line", ax=ax, **kwargs)

def OLS_party_housing(variance_scaled = False, regularised=False, regression_type="OLS",const=True,
                     cols = ['age', 'inc_det', 'gender_complete', 'housing'],drop_first=True,dummy_na=False,
                     dummied_cols = None,
                     mask = f2f_harmonised["bloc_complete"].isin(["Left-Lib","Right-Auth"]),
                     target = "auth_right_vote",
                     error_bars=False, hide_const=False,add_actual=False,
                     ax=None,single_legend=False):

    import statsmodels.api as sm
    from sklearn.preprocessing import StandardScaler
    from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
    wt_var = "wt_norm"
    
    
#     mask = 
    if regression_type=="Weighted_OLS":
        mask = mask & f2f_harmonised[wt_var].notnull()
    if dummied_cols == None:
        dummied_cols = list(pd.get_dummies(f2f_harmonised[cols][mask],drop_first=drop_first,dummy_na=dummy_na).columns)

    if const:
        dummied_cols = ["const"]+dummied_cols
    if add_actual:
        dummied_cols = ["actual"]+dummied_cols
    results_df = pd.DataFrame(columns = dummied_cols)        
    # add error_bar columns
    if error_bars:
        dummied_errs = [x+'_err' for x in dummied_cols]
        results_df[dummied_errs]=np.nan
        
    scaler = StandardScaler()

    for ge in f2f_harmonised["dataset"].unique():
    # ge = "1979"
        df = f2f_harmonised[mask][f2f_harmonised["dataset"][mask]==ge][cols+[target]]
        if regression_type == "Weighted_OLS":
            sample_weight = f2f_harmonised[mask][f2f_harmonised["dataset"][mask]==ge][wt_var]
#             raise Exception
        X = pd.get_dummies(df.drop([target],axis=1),drop_first=drop_first,dummy_na=dummy_na)
        X = X[intersection(X.columns, dummied_cols)]
        
        if variance_scaled:
            X = pd.DataFrame(scaler.fit_transform(X,sample_weight=sample_weight),columns=X.columns,index=X.index)
        if const:
            X = sm.add_constant(X)

        Y = df[target]
        if regression_type == "OLS":
            model = sm.OLS(Y,X)
        elif regression_type == "Logit":
            model = sm.Logit(Y,X)
        elif regression_type == "Probit":
            model = sm.Probit(Y,X)
        elif regression_type == "Weighted_OLS":
            if regularised:
                model = ElasticNet(fit_intercept=False,alpha=0.0)
#                 LinearRegression()
            else:
                model = LinearRegression(fit_intercept=False)
                
            model.fit(X, Y, sample_weight=sample_weight)
            

        # results.params
        if regression_type == "Weighted_OLS":
            results_df.loc[ge,X.columns] = model.coef_
        else:
            if regularised:        
                results = model.fit_regularized()
            else:
                results = model.fit()            
            results_df.loc[ge,X.columns] = results.params.values
            
        # error bars
        # dodgy, grabbing only
        if error_bars:
            if regression_type == "Weighted_OLS":
                model = sm.OLS(Y,X)
            # otherwise use sm model used prior
            results = model.fit()
            errors = results.conf_int()
            results_df.loc[ge,[x+"_err" for x in X.columns]] = (results_df.loc[ge,X.columns]-errors[0]).values
#             raise Exception
        
        if add_actual:
            if regression_type == "Weighted_OLS":
                results_df.loc[ge,"actual"] = sum(Y.loc[X.dropna().index]*sample_weight.loc[X.dropna().index])/sum(sample_weight.loc[X.dropna().index])
#                 (Y.loc[X.dropna().index]*sample_weight.loc[X.dropna().index]).mean()
#                 results_df.loc[ge,"actual"] = Y.mean()
#                 raise Exception
            else:
                results_df.loc[ge,"actual"] = Y.loc[X.dropna().index].mean()

    results_df = results_df.sort_index()
    title = 'Pr('+target+')'
    if variance_scaled:
        title = title+"_scaled"
#     else:
#         title = title+"_unscaled"
    if regularised:
        title = title+"_regularised"
#     else:
#         title = title+"_unscaled"        
#     results_df.plot(kind='line',title=title)  

    if ax is None:
        plt.figure(figsize=(12,6));
        ax=plt.gca()
        
#     if single_legend:
#         legend=False
#     else:
#         legend='auto'

    if error_bars:
        res_df = results_df[dummied_cols].reset_index().melt(id_vars='index')
        res_df["index"] = res_df["index"].replace(ge_to_date_dict).apply(lambda x: pd.to_datetime(x))
        res_df.columns = ["GE Date","Factor","Impact"]
        res_df["Impact"] = res_df["Impact"].astype('float')

        err_df = results_df[dummied_errs].reset_index().melt(id_vars='index')
        err_df["index"] = err_df["index"].replace(ge_to_date_dict).apply(lambda x: pd.to_datetime(x))
        err_df.columns = ["GE Date","Factor","Impact"]
        err_df["Impact"] = err_df["Impact"].astype('float')
        res_df["yerr"] = err_df["Impact"]
        if hide_const:
            res_df = res_df.replace("const",np.nan).dropna()
#         res_df
        g = sns.FacetGrid(res_df, hue="Factor",height=6,aspect=1.5)
        g.map_dataframe(errplot, "GE Date", "Impact", "yerr",ax=ax)# test ax!
        g.add_legend()    
    
    else:
    

        res_df = results_df.reset_index().melt(id_vars='index')
        res_df["index"] = res_df["index"].replace(ge_to_date_dict).apply(lambda x: pd.to_datetime(x))
        res_df.columns = ["GE Date","Factor","Impact"]
        res_df["Impact"] = res_df["Impact"].astype('float')
        if hide_const:
            res_df = res_df.replace("const",np.nan).dropna()
        sns.lineplot(data = res_df,x="GE Date",y="Impact",hue="Factor",style="Factor",markers=True,ax=ax);
        ax.set_title(title);
#         plt.xticks(rotation=90);   
#         plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

    if single_legend:
        handles, labels = ax.get_legend_handles_labels()
        ax.get_legend().remove()
        legend_data = (handles, labels)
    else:
        legend_data = None
    
    
    return res_df,legend_data

# %%
def plot_OLS_set(target_list, X_list, figsize=(16.5, 6),  sharey=True, regression_type="Weighted_OLS",regularised=False,
                 variance_scaled=False,drop_first=False,hide_const=False,add_actual=True,dummied_cols=None, single_legend=True):
    fig, axs = plt.subplots(ncols=len(target_list),figsize=figsize, sharey=sharey);
    ax_pos = 0
    for target in target_list:
        df,(handles, labels)=OLS_party_housing(variance_scaled=variance_scaled,drop_first=drop_first,cols = X_list,
                    target=target,mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type=regression_type, regularised=regularised, hide_const=hide_const,add_actual=add_actual,
                    dummied_cols=dummied_cols,single_legend=single_legend,
                    ax=axs[ax_pos])
        ax_pos=ax_pos+1
    if single_legend:
#         handles, labels = axs[0].get_legend_handles_labels()
        fig.legend(handles, labels, 
                   loc='upper center',
                   bbox_to_anchor=(0.43, 0.05),
                   fancybox=False, shadow=False, ncol=7);
#         raise Exception
#     return (handles, labels)

# %%
plot_OLS_set(["CON","LAB","DNV"], ["generation"], figsize=(16.5, 6),  sharey=True)

# %%
plot_OLS_set(["CON","LAB","DNV"], ["inc_norm_wt"], figsize=(16.5, 6),  sharey=True)

# %%
plot_OLS_set(["CON","LAB","DNV"], ["gender_complete"], figsize=(16.5, 6),  sharey=True)

# %%
plot_OLS_set(["CON","LAB","DNV"], ["housing"], figsize=(16.5, 6),  sharey=True,drop_first=False,dummied_cols=["housing_OWN"])

# %%
plot_OLS_set(["CON","LAB","DNV"], ["housing_det"], figsize=(16.5, 6),  sharey=True,drop_first=False,
             dummied_cols=["housing_det_OWN","housing_det_OWN-MORT","housing_det_MORT"])

# %%
plot_OLS_set(["CON","LAB","DNV"], ["housing_det"], figsize=(16.5, 6),  sharey=True,drop_first=False,
             dummied_cols=["housing_det_RENT-ALL","housing_det_RENT-PR","housing_det_RENT-LA","housing_det_RENT-HA"])

# %%
plot_OLS_set(["CON","LAB","DNV"], ["age_left_education_3"], figsize=(16.5, 6),  sharey=True, drop_first=True)

# %%
plot_OLS_set(["CON","LAB","DNV"], ["age_left_education_3"], figsize=(16.5, 6),  sharey=True,regularised=False,drop_first=True)

# %%
pd.crosstab(f2f_harmonised["age_left_education_3"],f2f_harmonised["dataset"],values=f2f_harmonised["wt"],aggfunc=sum,normalize='columns').T.plot(kind='line')

# %%
## dumbest version
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["housing_det"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS", regularised=False, hide_const=False,add_actual=True)

# %%
## dumbest version
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["housing_det"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS", regularised=False, hide_const=False,add_actual=True)

# %%
## dumbest version
df=OLS_party_housing(variance_scaled=True,drop_first=True,cols = ["housing"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS", regularised=False, hide_const=False,add_actual=True)

# %%
f2f_harmonised.groupby("dataset")[["decade","inc_norm_wt","gender_complete","housing","age_left_education_3","vote_complete_simple","wt"]].apply(lambda x: x.isnull().sum())
# Out:
#           decade  inc_norm_wt  gender_complete  housing  age_left_education_3  \
# dataset
# 1959           0            0                0       97                    38
# 1964           0         1153                0      103                    38
# 1966           0         1048                0      103                    38
# 1970           0         1567                0      109                    38
# 1974_feb       0            0                0       56                    16
# 1974_oct       0            0                0       16                    21
# 1979           0            0                0       44                     2
# 1983           0            0                0      113                     7
# 1987           0            0                0       76                    12
# 1992           0            0                0       80                    15
# 1997           0          245                0       77                    17
# 2001           0            0                0       49                     6
# 2005           0            0                0      101                     5
# 2010           0            0                0       39                     4
# 2015           0          224                0        0                    94
# 2017           0          127                0        0                    38
# 2019           0          444                0       81                   178
#
#           vote_complete_simple    wt
# dataset
# 1959                         0     0
# 1964                         0  1153
# 1966                         0  1048
# 1970                         0  1567
# 1974_feb                     0     0
# 1974_oct                     0     0
# 1979                         0     0
# 1983                         0     0
# 1987                         0     0
# 1992                         0     0
# 1997                         0   245
# 2001                         0     0
# 2005                         0     0
# 2010                         0     0
# 2015                         0   224
# 2017                         0   127
# 2019                         0   444

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["decade","inc_norm_wt","gender_complete","housing","age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="OLS", regularised=True, hide_const=True)

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=True,cols = ["decade","inc_norm_wt","gender_complete","housing","age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Logit", regularised=True, hide_const=True)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6012312762310359
#             Iterations: 25
#             Function evaluations: 25
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5602794104852483
#             Iterations: 25
#             Function evaluations: 25
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5239127580825917
#             Iterations: 29
#             Function evaluations: 29
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5355687486023778
#             Iterations: 30
#             Function evaluations: 30
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.4669653570817005
#             Iterations: 32
#             Function evaluations: 32
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.4354836582587936
#             Iterations: 35
#             Function evaluations: 35
#             Gradient evaluations: 35
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.47191674450231885
#             Iterations: 32
#             Function evaluations: 32
#             Gradient evaluations: 32
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5910478028023564
#             Iterations: 26
#             Function evaluations: 26
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6075175777975133
#             Iterations: 25
#             Function evaluations: 26
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6216865871604104
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.622293598363495
#             Iterations: 23
#             Function evaluations: 23
#             Gradient evaluations: 23
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5810205966024511
#             Iterations: 22
#             Function evaluations: 22
#             Gradient evaluations: 22
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5666533396272992
#             Iterations: 25
#             Function evaluations: 25
#             Gradient evaluations: 25
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6410230948595177
#             Iterations: 24
#             Function evaluations: 24
#             Gradient evaluations: 24
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6004531534428277
#             Iterations: 21
#             Function evaluations: 21
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6121050370679249
#             Iterations: 21
#             Function evaluations: 22
#             Gradient evaluations: 21
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.563819918997768
#             Iterations: 25
#             Function evaluations: 26
#             Gradient evaluations: 25

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["decade","inc_norm_wt","gender_complete","housing","age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="OLS", regularised=True)

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="OLS", regularised=True,const=True)

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="OLS", regularised=True,const=True)

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["age"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="OLS", regularised=True,const=True)

# %%
df=OLS_party_housing(variance_scaled=False,drop_first=False,cols = ["housing_det"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="OLS", regularised=True,const=True)

# %%
df=OLS_party_housing(variance_scaled=False,drop_first=False,cols = ["inc_norm_wt"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="OLS", regularised=True,const=True)

# %%
df=OLS_party_housing(variance_scaled=False,drop_first=False,cols = ["inc_norm_wt"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Logit", regularised=True,const=True)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5517670103022901
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6432043637897441
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5504149235509468
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.56317728263795
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6031462098765685
#             Iterations: 13
#             Function evaluations: 13
#             Gradient evaluations: 13
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6412730660036616
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6676143799602551
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5894099076577111
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5541256478623707
#             Iterations: 15
#             Function evaluations: 15
#             Gradient evaluations: 15
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5456532282222282
#             Iterations: 14
#             Function evaluations: 15
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6218299486332445
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6529810182816208
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6510017885248423
#             Iterations: 12
#             Function evaluations: 13
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6338949126584086
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6820292918332603
#             Iterations: 11
#             Function evaluations: 11
#             Gradient evaluations: 11
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6753157125443925
#             Iterations: 12
#             Function evaluations: 12
#             Gradient evaluations: 12
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6303391945711369
#             Iterations: 14
#             Function evaluations: 14
#             Gradient evaluations: 14

# %%
df=OLS_party_housing(variance_scaled=False,drop_first=True,cols = ["age","inc_norm_wt","gender_complete","housing"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Logit", regularised=True,const=True)
# Out:
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5394386166729295
#             Iterations: 31
#             Function evaluations: 36
#             Gradient evaluations: 31
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6362545366086783
#             Iterations: 29
#             Function evaluations: 33
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5497657754027354
#             Iterations: 30
#             Function evaluations: 35
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5614516106969294
#             Iterations: 30
#             Function evaluations: 34
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6019680929944481
#             Iterations: 34
#             Function evaluations: 38
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6376399030958194
#             Iterations: 30
#             Function evaluations: 33
#             Gradient evaluations: 30
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6640671013922834
#             Iterations: 28
#             Function evaluations: 31
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5784071008207922
#             Iterations: 29
#             Function evaluations: 33
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.529505363148384
#             Iterations: 29
#             Function evaluations: 33
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5210176492204395
#             Iterations: 29
#             Function evaluations: 33
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6048859216895897
#             Iterations: 28
#             Function evaluations: 32
#             Gradient evaluations: 28
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6226881900887522
#             Iterations: 29
#             Function evaluations: 32
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6252592933614163
#             Iterations: 29
#             Function evaluations: 32
#             Gradient evaluations: 29
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6036438477813415
#             Iterations: 34
#             Function evaluations: 38
#             Gradient evaluations: 34
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.6544549153015166
#             Iterations: 26
#             Function evaluations: 29
#             Gradient evaluations: 26
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.641179380840517
#             Iterations: 27
#             Function evaluations: 30
#             Gradient evaluations: 27
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 0.5937436373809818
#             Iterations: 29
#             Function evaluations: 32
#             Gradient evaluations: 29

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,
                    cols = ["decade","inc_norm_wt","gender_complete","housing"],
                    dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete"].notnull()&f2f_harmonised["wt"].notnull(),
                    error_bars=True,regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,
                    cols = ["decade","inc_norm_wt","gender_complete","housing"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete"].notnull()&f2f_harmonised["wt"].notnull(),
                    error_bars=False,regression_type="Weighted_OLS")

# %%
# Out:
#               inc_det  inc_norm  inc_norm_wt
# inc_det      1.000000  0.927910     0.866745
# inc_norm     0.927910  1.000000     0.951784
# inc_norm_wt  0.866745  0.951784     1.000000

# %%
f2f_harmonised["vote_complete_simple"].value_counts(dropna=False)
# Out:
# CON      17150
# LAB      16387
# DNV       9997
# LD        6381
# SNP       1147
# DK         599
# REFUK      525
# GP         281
# PC         264
# Name: vote_complete_simple, dtype: int64

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=True,cols = ["decade","inc_norm_wt","gender_complete","housing","age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=True,cols = ["decade","inc_norm_wt","gender_complete","housing","age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=True,cols = ["decade","inc_norm_wt","gender_complete","housing","age_left_education_3"],
#                     dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="DNV",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["decade","inc_norm_wt","gender_complete","housing"],
                    dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="CON",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["decade","inc_norm_wt","gender_complete","housing"],
                    dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LAB",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["decade","inc_norm_wt","gender_complete","housing"],
                    dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="LD",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["decade","inc_norm_wt","gender_complete","housing"],
                    dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="DNV",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True,drop_first=False,cols = ["decade","inc_norm_wt","gender_complete","housing"],
                    dummied_cols = ['decade', 'inc_norm_wt', 'gender_complete', 'housing_OWN'],
                    target="REFUK",mask = f2f_harmonised["vote_complete_simple"].notnull()&f2f_harmonised["wt"].notnull(),
                    regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=False,drop_first=False,dummied_cols = ['age', 'inc_det', 'gender_complete', 'housing_OWN'],
                    target="CON",)

# %%
df=OLS_party_housing(variance_scaled=False,drop_first=False,dummied_cols = ['age', 'inc_det', 'gender_complete', 'housing_OWN'])

# %%
pd.crosstab(f2f_harmonised["age_left_education_3"],f2f_harmonised["dataset"],values=f2f_harmonised["wt"],aggfunc=sum,normalize='columns').T.plot(kind='line')

# %%
f2f_harmonised["age_left_education_3"].value_counts(dropna=False)
# Out:
# 15 or younger    26250
# 16               10028
# 19 or older       8148
# 18                7738
# NaN                567
# Name: age_left_education_3, dtype: int64

# %%
df=OLS_party_housing(variance_scaled=True,cols=['age', 'inc_det', 'age_left_education_3', 'gender_complete', 'housing'],
                     drop_first=True)

# %%
df=OLS_party_housing(variance_scaled=True,cols=['age',  'gender_complete', 'housing_det'],
                     # 'age_left_education_3',
                     drop_first=False,regression_type="Weighted_OLS")

# %%
df=OLS_party_housing(variance_scaled=True)

# %%
df=OLS_party_housing(variance_scaled=False,regularised=True)

# %%
df=OLS_party_housing(variance_scaled=False,regularised=False,regression_type="Logit")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.656737
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636146
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657394
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647644
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590821
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.539041
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554295
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.622294
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635619
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651485
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.659568
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.618922
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.613847
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.653762
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.654533
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630246
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636145
#          Iterations 5

# %%
OLS_party_housing(variance_scaled=True,regularised=False,regression_type="Logit")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.656737
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636146
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657394
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.647644
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590821
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.539041
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554295
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.622294
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635619
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651485
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.659568
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.618922
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.613847
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.653762
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.654533
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.630246
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636145
#          Iterations 5

# %%
OLS_party_housing(variance_scaled=True,regularised=False,regression_type="Probit")
# Out:
# Optimization terminated successfully.
#          Current function value: 0.656829
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.636147
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.657348
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.647784
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.591125
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.539341
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.554594
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.622290
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.635640
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.651556
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.659619
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.619224
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.613884
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.653643
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.654544
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.630520
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.636247
#          Iterations 5

# %%
df = OLS_party_housing(variance_scaled=True,regularised=False,regression_type="OLS",const=False)

# %%
df=OLS_party_housing(variance_scaled=False)

# %%
df=OLS_party_housing(variance_scaled=False,regression_type="Weighted_OLS")
