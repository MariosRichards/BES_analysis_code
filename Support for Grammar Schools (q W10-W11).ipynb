# %%
### grammar school support predictors?

# %%
# %%time
dataset_name = "W14_comb"
df_list = "BES_Panel|BES_reduced_with_na"
#|BES_reduced_with_na"

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}

global BES_label_list, BES_df_list
# BES_reduced_with_na.index=BES_Panel.index
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (5692, 13)
# CPU times: total: 1.11 s
# Wall time: 12.1 s

# %%
search(BES_reduced_with_na,"grammar")
# Out:
# grammarW10__Strongly support    26208
# grammarW11__Strongly support    27104
# dtype: int64

# %%
# pubPrivEfficient
name="grammarW10__Strongly support"

# BES_num[name] = BES_Panel[name].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).loc[BES_num.index]
df, corr_type = make_corr_summary(BES_reduced_with_na, name)
display_corr(df,name,corr_type)

(explainer, shap_values, train_columns, train_index, alg,output_subfolder,metrics) = xgboost_run(
    title = "Would you support or oppose re-introducing grammar schools?",dataset=BES_reduced_with_na,
                                                    var_list = [name],var_stub_list = [name,"grammar"],verbosity=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_06973" style='display:inline'>
#   <caption>Top 20 positive (spearman) correlations for grammarW10__Strongly support</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06973_level0_col0" class="col_heading level0 col0" >r</th>
#       <th id="T_06973_level0_col1" class="col_heading level0 col1" >p</th>
#       <th id="T_06973_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06973_level0_row0" class="row_heading level0 row0" >grammarW11__Strongly support</th>
#       <td id="T_06973_row0_col0" class="data row0 col0" >0.840000</td>
#       <td id="T_06973_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_06973_row0_col2" class="data row0 col2" >18023</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row1" class="row_heading level0 row1" >leftRightW6__Right</th>
#       <td id="T_06973_row1_col0" class="data row1 col0" >0.560000</td>
#       <td id="T_06973_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_06973_row1_col2" class="data row1 col2" >11191</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row2" class="row_heading level0 row2" >likeConW11__Strongly like</th>
#       <td id="T_06973_row2_col0" class="data row2 col0" >0.520000</td>
#       <td id="T_06973_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_06973_row2_col2" class="data row2 col2" >18562</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row3" class="row_heading level0 row3" >ptvConW11__Very likely</th>
#       <td id="T_06973_row3_col0" class="data row3 col0" >0.510000</td>
#       <td id="T_06973_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_06973_row3_col2" class="data row3 col2" >18154</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row4" class="row_heading level0 row4" >generalElectionVoteUnsqueezeW11_Conservative</th>
#       <td id="T_06973_row4_col0" class="data row4 col0" >0.510000</td>
#       <td id="T_06973_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_06973_row4_col2" class="data row4 col2" >13015</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row5" class="row_heading level0 row5" >likeMayW11__Strongly like</th>
#       <td id="T_06973_row5_col0" class="data row5 col0" >0.500000</td>
#       <td id="T_06973_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_06973_row5_col2" class="data row5 col2" >18495</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row6" class="row_heading level0 row6" >thatcherGoodW1_Good for Britain</th>
#       <td id="T_06973_row6_col0" class="data row6 col0" >0.500000</td>
#       <td id="T_06973_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_06973_row6_col2" class="data row6 col2" >9232</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row7" class="row_heading level0 row7" >approveUKGovtW11__Strongly approve</th>
#       <td id="T_06973_row7_col0" class="data row7 col0" >0.490000</td>
#       <td id="T_06973_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_06973_row7_col2" class="data row7 col2" >18790</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row8" class="row_heading level0 row8" >likeDavisW13__Strongly like</th>
#       <td id="T_06973_row8_col0" class="data row8 col0" >0.490000</td>
#       <td id="T_06973_row8_col1" class="data row8 col1" >0.00</td>
#       <td id="T_06973_row8_col2" class="data row8 col2" >6566</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row9" class="row_heading level0 row9" >ptvConExpW14__Very likely</th>
#       <td id="T_06973_row9_col0" class="data row9 col0" >0.490000</td>
#       <td id="T_06973_row9_col1" class="data row9 col1" >0.00</td>
#       <td id="T_06973_row9_col2" class="data row9 col2" >3560</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row10" class="row_heading level0 row10" >likeGoveW8__Strongly like</th>
#       <td id="T_06973_row10_col0" class="data row10 col0" >0.470000</td>
#       <td id="T_06973_row10_col1" class="data row10 col1" >0.00</td>
#       <td id="T_06973_row10_col2" class="data row10 col2" >15370</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row11" class="row_heading level0 row11" >generalElectionVoteW11_Conservative</th>
#       <td id="T_06973_row11_col0" class="data row11 col0" >0.470000</td>
#       <td id="T_06973_row11_col1" class="data row11 col1" >0.00</td>
#       <td id="T_06973_row11_col2" class="data row11 col2" >16489</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row12" class="row_heading level0 row12" >likeBorisW13__Strongly like</th>
#       <td id="T_06973_row12_col0" class="data row12 col0" >0.470000</td>
#       <td id="T_06973_row12_col1" class="data row12 col1" >0.00</td>
#       <td id="T_06973_row12_col2" class="data row12 col2" >8605</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row13" class="row_heading level0 row13" >conGovTrustW5__ Would do a good job</th>
#       <td id="T_06973_row13_col0" class="data row13 col0" >0.470000</td>
#       <td id="T_06973_row13_col1" class="data row13 col1" >0.00</td>
#       <td id="T_06973_row13_col2" class="data row13 col2" >12284</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row14" class="row_heading level0 row14" >likeNuttallW10__Strongly like</th>
#       <td id="T_06973_row14_col0" class="data row14 col0" >0.460000</td>
#       <td id="T_06973_row14_col1" class="data row14 col1" >0.00</td>
#       <td id="T_06973_row14_col2" class="data row14 col2" >10763</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row15" class="row_heading level0 row15" >likeCameronW6__Strongly like</th>
#       <td id="T_06973_row15_col0" class="data row15 col0" >0.460000</td>
#       <td id="T_06973_row15_col1" class="data row15 col1" >0.00</td>
#       <td id="T_06973_row15_col2" class="data row15 col2" >12622</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row16" class="row_heading level0 row16" >handleEUNegotiateW12__Very well</th>
#       <td id="T_06973_row16_col0" class="data row16 col0" >0.460000</td>
#       <td id="T_06973_row16_col1" class="data row16 col1" >0.00</td>
#       <td id="T_06973_row16_col2" class="data row16 col2" >18079</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row17" class="row_heading level0 row17" >preferLabCoalitionW5__Ranked fifth</th>
#       <td id="T_06973_row17_col0" class="data row17 col0" >0.460000</td>
#       <td id="T_06973_row17_col1" class="data row17 col1" >0.00</td>
#       <td id="T_06973_row17_col2" class="data row17 col2" >12029</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row18" class="row_heading level0 row18" >handleMIIConW12__Very well</th>
#       <td id="T_06973_row18_col0" class="data row18 col0" >0.450000</td>
#       <td id="T_06973_row18_col1" class="data row18 col1" >0.00</td>
#       <td id="T_06973_row18_col2" class="data row18 col2" >3995</td>
#     </tr>
#     <tr>
#       <th id="T_06973_level0_row19" class="row_heading level0 row19" >generalElectionVotePostW12_Conservative</th>
#       <td id="T_06973_row19_col0" class="data row19 col0" >0.450000</td>
#       <td id="T_06973_row19_col1" class="data row19 col1" >0.00</td>
#       <td id="T_06973_row19_col2" class="data row19 col2" >2442</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_9ab42" style='display:inline'>
#   <caption>Top 20 negative (spearman) correlations for grammarW10__Strongly support</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9ab42_level0_col0" class="col_heading level0 col0" >r</th>
#       <th id="T_9ab42_level0_col1" class="col_heading level0 col1" >p</th>
#       <th id="T_9ab42_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9ab42_level0_row0" class="row_heading level0 row0" >bestPMW7_Jeremy Corbyn</th>
#       <td id="T_9ab42_row0_col0" class="data row0 col0" >-0.530000</td>
#       <td id="T_9ab42_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_9ab42_row0_col2" class="data row0 col2" >8348</td>
#     </tr>
#     <tr>
#       <th id="T_9ab42_level0
# MSE: 0.90, MAE: 0.75, EV: 0.43, R2: 0.43

# %%
# pubPrivEfficient
name="grammarW11__Strongly support"

# BES_num[name] = BES_Panel[name].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan).loc[BES_num.index]
df, corr_type = make_corr_summary(BES_reduced_with_na, name)
display_corr(df,name,corr_type)

(explainer, shap_values, train_columns, train_index, alg,output_subfolder,metrics) = xgboost_run(
    title = "Would you support or oppose re-introducing grammar schools?",dataset=BES_reduced_with_na,
                                                    var_list = [name],var_stub_list = [name,"grammar"],verbosity=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_16663" style='display:inline'>
#   <caption>Top 20 positive (spearman) correlations for grammarW11__Strongly support</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_16663_level0_col0" class="col_heading level0 col0" >r</th>
#       <th id="T_16663_level0_col1" class="col_heading level0 col1" >p</th>
#       <th id="T_16663_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_16663_level0_row0" class="row_heading level0 row0" >grammarW10__Strongly support</th>
#       <td id="T_16663_row0_col0" class="data row0 col0" >0.840000</td>
#       <td id="T_16663_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_16663_row0_col2" class="data row0 col2" >18023</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row1" class="row_heading level0 row1" >leftRightW11__Right</th>
#       <td id="T_16663_row1_col0" class="data row1 col0" >0.590000</td>
#       <td id="T_16663_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_16663_row1_col2" class="data row1 col2" >22844</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row2" class="row_heading level0 row2" >likeConW11__Strongly like</th>
#       <td id="T_16663_row2_col0" class="data row2 col0" >0.560000</td>
#       <td id="T_16663_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_16663_row2_col2" class="data row2 col2" >26186</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row3" class="row_heading level0 row3" >thatcherGoodW1_Good for Britain</th>
#       <td id="T_16663_row3_col0" class="data row3 col0" >0.550000</td>
#       <td id="T_16663_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_16663_row3_col2" class="data row3 col2" >9975</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row4" class="row_heading level0 row4" >ptvConW12__Very likely</th>
#       <td id="T_16663_row4_col0" class="data row4 col0" >0.550000</td>
#       <td id="T_16663_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_16663_row4_col2" class="data row4 col2" >5352</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row5" class="row_heading level0 row5" >generalElectionVoteUnsqueezeW12_Conservative</th>
#       <td id="T_16663_row5_col0" class="data row5 col0" >0.550000</td>
#       <td id="T_16663_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_16663_row5_col2" class="data row5 col2" >14226</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row6" class="row_heading level0 row6" >likeMayW11__Strongly like</th>
#       <td id="T_16663_row6_col0" class="data row6 col0" >0.540000</td>
#       <td id="T_16663_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_16663_row6_col2" class="data row6 col2" >26130</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row7" class="row_heading level0 row7" >likeDavisW13__Strongly like</th>
#       <td id="T_16663_row7_col0" class="data row7 col0" >0.530000</td>
#       <td id="T_16663_row7_col1" class="data row7 col1" >0.00</td>
#       <td id="T_16663_row7_col2" class="data row7 col2" >7717</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row8" class="row_heading level0 row8" >approveUKGovtW11__Strongly approve</th>
#       <td id="T_16663_row8_col0" class="data row8 col0" >0.530000</td>
#       <td id="T_16663_row8_col1" class="data row8 col1" >0.00</td>
#       <td id="T_16663_row8_col2" class="data row8 col2" >26447</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row9" class="row_heading level0 row9" >likeMoggW14__Strongly like</th>
#       <td id="T_16663_row9_col0" class="data row9 col0" >0.520000</td>
#       <td id="T_16663_row9_col1" class="data row9 col1" >0.00</td>
#       <td id="T_16663_row9_col2" class="data row9 col2" >3308</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row10" class="row_heading level0 row10" >ptvConExpW14__Very likely</th>
#       <td id="T_16663_row10_col0" class="data row10 col0" >0.520000</td>
#       <td id="T_16663_row10_col1" class="data row10 col1" >0.00</td>
#       <td id="T_16663_row10_col2" class="data row10 col2" >3895</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row11" class="row_heading level0 row11" >likeGoveW8__Strongly like</th>
#       <td id="T_16663_row11_col0" class="data row11 col0" >0.510000</td>
#       <td id="T_16663_row11_col1" class="data row11 col1" >0.00</td>
#       <td id="T_16663_row11_col2" class="data row11 col2" >16406</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row12" class="row_heading level0 row12" >likeBorisW13__Strongly like</th>
#       <td id="T_16663_row12_col0" class="data row12 col0" >0.510000</td>
#       <td id="T_16663_row12_col1" class="data row12 col1" >0.00</td>
#       <td id="T_16663_row12_col2" class="data row12 col2" >10072</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row13" class="row_heading level0 row13" >handleEUNegotiateW12__Very well</th>
#       <td id="T_16663_row13_col0" class="data row13 col0" >0.510000</td>
#       <td id="T_16663_row13_col1" class="data row13 col1" >0.00</td>
#       <td id="T_16663_row13_col2" class="data row13 col2" >21193</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row14" class="row_heading level0 row14" >generalElectionVoteW12_Conservative</th>
#       <td id="T_16663_row14_col0" class="data row14 col0" >0.510000</td>
#       <td id="T_16663_row14_col1" class="data row14 col1" >0.00</td>
#       <td id="T_16663_row14_col2" class="data row14 col2" >19714</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row15" class="row_heading level0 row15" >conGovTrustW5__ Would do a good job</th>
#       <td id="T_16663_row15_col0" class="data row15 col0" >0.510000</td>
#       <td id="T_16663_row15_col1" class="data row15 col1" >0.00</td>
#       <td id="T_16663_row15_col2" class="data row15 col2" >13380</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row16" class="row_heading level0 row16" >profile_past_vote_2017_Conservative</th>
#       <td id="T_16663_row16_col0" class="data row16 col0" >0.500000</td>
#       <td id="T_16663_row16_col1" class="data row16 col1" >0.00</td>
#       <td id="T_16663_row16_col2" class="data row16 col2" >21509</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row17" class="row_heading level0 row17" >likeCameronW6__Strongly like</th>
#       <td id="T_16663_row17_col0" class="data row17 col0" >0.500000</td>
#       <td id="T_16663_row17_col1" class="data row17 col1" >0.00</td>
#       <td id="T_16663_row17_col2" class="data row17 col2" >13658</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row18" class="row_heading level0 row18" >scotElectionVoteListW8_Scottish Conservative</th>
#       <td id="T_16663_row18_col0" class="data row18 col0" >0.490000</td>
#       <td id="T_16663_row18_col1" class="data row18 col1" >0.00</td>
#       <td id="T_16663_row18_col2" class="data row18 col2" >1908</td>
#     </tr>
#     <tr>
#       <th id="T_16663_level0_row19" class="row_heading level0 row19" >handleMIIConW12__Very well</th>
#       <td id="T_16663_row19_col0" class="data row19 col0" >0.490000</td>
#       <td id="T_16663_row19_col1" class="data row19 col1" >0.00</td>
#       <td id="T_16663_row19_col2" class="data row19 col2" >4794</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4a42b" style='display:inline'>
#   <caption>Top 20 negative (spearman) correlations for grammarW11__Strongly support</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a42b_level0_col0" class="col_heading level0 col0" >r</th>
#       <th id="T_4a42b_level0_col1" class="col_heading level0 col1" >p</th>
#       <th id="T_4a42b_level0_col2" class="col_heading level0 col2" >N</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a42b_level0_row0" class="row_heading level0 row0" >bestPMW8_Jeremy Corbyn</th>
#       <td id="T_4a42b_row0_col0" class="data row0 col0" >-0.560000</td>
#       <td id="T_4a42b_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_4a42b_row0_col2" class="data row0 col2" >9255</td>
#     </tr>
#     <tr>
#       <th id="T_4a42b_lev
# MSE: 0.92, MAE: 0.75, EV: 0.47, R2: 0.47
