# %%
# %%time
dataset_name = "W20_only"
df_list = "BES_Panel"

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}
(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)    

# get full set of inferred "cross wave" auth-lib/left-right values and ages
# pan_dataset_allr_values = pd.read_pickle(BES_small_data_files + "pan_dataset_allr_valuesW19"+".zip",compression='zip')
# # pan_dataset_allr_values = pan_dataset_allr_values.loc[BES_Panel.index].sort_index()
# pan_dataset_ages = pd.read_pickle(BES_small_data_files + "pan_dataset_ages"+".zip", compression='zip')
# pan_dataset_votes = pd.read_pickle(BES_small_data_files+"pan_dataset_votes"+".zip",compression='zip')
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (463, 14)

# %%
initial_year = 1945
final_year = 2135
years = list(range(initial_year,final_year))
period = 40
euro_sentiment = [np.cos( (np.pi)*(x-1935)/40 ) for x in years]


fig_x_size=10
plt.figure(figsize=(fig_x_size,fig_x_size*7/16));
sns.set(font_scale=1.8);
sns.lineplot(x = years,y=euro_sentiment)
ax = plt.gca()
# plt.gca().set_xlabel(r'$\rho/\rho_{ref}\;\rightarrow$', color='red')
ax.set_ylabel('Public Skews More Euro-\n$\longleftarrow$ -phile     -skeptic $\longrightarrow$');
plt.yticks([]);

import matplotlib.patches as patches
from matplotlib.patches import Patch
# build a rectangle in axes coords
def add_phase(start_year,period,close):
    left, width = start_year, period
    bottom, height = -1, 2
    right = left + width
    top = bottom + height
    
    if close==True:
        color='yellow'
    else:
        color='blue'

    p = patches.Rectangle(
        (left, bottom), width, height,
        fill=True, color=color,  clip_on=False, alpha=.2
        );
    ax.add_patch(p);

close=False
add_phase(start_year=1945,period=30,close=close)



for start_year in range(1975,final_year,period):
    close=not close
#     print(start_year,close)
    add_phase(start_year=start_year,period=period,close=close)



# transform=ax.transAxes,
legend_elements = [Patch(facecolor='blue', edgecolor='b',
                         label='UK far from EU',alpha=.2),
                   Patch(facecolor='yellow', edgecolor='y',
                         label='UK close to EU',alpha=.2),
                  ]

# Create the figure
ax.legend(handles=legend_elements,loc="lower center", bbox_to_anchor=(0.5, -0.3),ncol=2)


plt.title("Cyclical Theory of UK-EU Relations\nDriven by Lagged Generational Attitudes");
