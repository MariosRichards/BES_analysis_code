# %%
## How do people feel about "the Left" and "the Right" on "divisiveness"?

# %%
## Upshot - pretty even, ppl like parties they place close to their own position

## Country important!

## Not so comfortable with the Wave 20 country variable
### redo with early waves -> figured out which are doable

### do "nice" version of individual parties x country

### redo with wave 19 and use 'Objective' Ec L-R/Soc L-A axes



## -> Red Wall regression?

# %%
## Very hard to think of a "divisive" measure ...

## if we read as just "like/dislike" we can look at

## how people rate parties on the lr-scale x whether they like them
## how people rate themselves on the lr-scale

## IDEA: Drop 5s to get rid of 5/DK ambiguity?

##

# %%
## if we want coverage on lr<party>, like<party, leftRight, country
# -> Wave 20, Wave 17


# lr variables
# lr GRID W2W3W4 W5W7W8W9W10W11W12W15W16W17W18W20
# leftRight W1W2W3W4W5W7W8W9W10W11W12W13W14W15W16W17W18W19W20
# like<party> All waves
# country - theoretically all waves - but missing in W18

# W20, W17, W16?,W15?,W12?,W11?,W10?,W9?,W8?,W7?,W5?,W4?,W3?,W2?

# %%
## Isn't there a lrCorbyn/lrMay for one wave?
# lrCorbyn,lrMay            34394 W12!!


## Cover lrTIG/lrUKIP/lrBNP

# %%
### Framework

# paired variables (likeX, lrX)
# split variables (leftRight)

# mask by country

# %%
def weighted_mean(x, **kws):
    val, weight = map(np.asarray, zip(*x))
    mask = (~np.isnan(val))&(~np.isnan(weight))
    val, weight = val[mask],weight[mask]
    return (val * weight).sum() / weight.sum()

# %%
# %%time
dataset_name = "W12_only"
df_list = "BES_Panel"

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# Wall time: 295 ms

# %%
search(BES_Panel,"Corbyn")
# Out:
# likeCorbyn          34394
# lrCorbyn            34394
# labCandCorbynite    34394
# dtype: int64

# %%
England  = BES_Panel["country"]==1
England.name = "England"
Scotland = BES_Panel["country"]==2
Scotland.name = "Scotland"
Wales    = BES_Panel["country"]==3
Wales.name = "Wales"
Britain  = BES_Panel["country"].notnull()
Britain.name = "Britain"
BES_Panel["country"].value_counts(dropna=False)
# Out:
# 1    28894
# 2     3388
# 3     2084
# Name: country, dtype: int64

# %%
search(BES_Panel,"leftRight|^lr(Con|Lab|LD|Brexit|greens)|like(Con|Lab|LD|Brexit|Grn)")


# could simplify to England only!
# Out:
# likeCon            32177
# likeLab            32177
# likeLD             32177
# likeBrexitParty    32177
# likeGrn            32177
# leftRight          32177
# dtype: int64

# %%
sns.countplot( BES_Panel["leftRight"] )

# %%
leftRight = BES_Panel["leftRight"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
# leftRight.value_counts()


country = England
weighted_mean( list(zip(leftRight[country],BES_Panel["wt"][country])) )
# Out:
# 5.062006910319587

# %%
country = Scotland
weighted_mean( list(zip(leftRight[country],BES_Panel["wt"][country])) )
# Out:
# 4.4777964183514145

# %%
country = Wales
weighted_mean( list(zip(leftRight[country],BES_Panel["wt"][country])) )
# Out:
# 4.764634601102411

# %%
# sns.kdeplot(leftRight,bw=.5,cut=0)*10

pd.crosstab(leftRight,BES_Panel["country"],normalize='columns')*10
# Out:
# country         1         2         3
# row_0
# 0.0      0.340747  0.505865  0.463369
# 1.0      0.273758  0.395894  0.381966
# 2.0      0.857896  1.253666  1.058234
# 3.0      1.288853  1.708211  1.634314
# 4.0      0.942747  1.162023  0.857858
# 5.0      2.116827  1.975806  2.185348
# 6.0      1.093248  0.916422  0.864120
# 7.0      1.335745  1.008065  1.127113
# 8.0      1.060200  0.678152  0.914214
# 9.0      0.307253  0.157625  0.137758
# 10.0     0.382726  0.238270  0.375704

# %%
# sns.countplot(leftRight)*(100/leftRight.sum())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-211-e89d1b71b3dd> in <module>
# ----> 1 sns.countplot(leftRight)*(100/leftRight.sum())
#
# TypeError: unsupported operand type(s) for *: 'AxesSubplot' and 'float'

# %%
sns.barplot(data=chart_df,
                     x=x_axis, y=ques, hue=party_or_leader,palette=palette,style=party_or_leader,dashes=style_dict,
                     markers=True,
                     estimator=weighted_mean,n_boot=1000 );

# %%
lrCon = BES_Panel["lrCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrLab = BES_Panel["lrLab"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrLD = BES_Panel["lrLD"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrBrexit = BES_Panel["lrBrexit"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrgreens = BES_Panel["lrgreens"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)



likeCon = BES_Panel["likeCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLab = BES_Panel["likeLab"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLD  = BES_Panel["likeLD"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeGrn = BES_Panel["likeGrn"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeBrexitParty = BES_Panel["likeBrexitParty"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)

# leftRight
# lrCon
# likeCon

# %%
likeCon.groupby(lrCon).mean().plot()

# %%
likeCon.groupby(lrCon-leftRight).mean().plot()

# %%
likeLab.groupby(lrLab).mean().plot()

# %%
likeLab.groupby(lrLab-leftRight).mean().plot()

# %%
likeLD.groupby(lrLD).mean().plot(),likeLD.groupby(lrLD-leftRight).mean().plot()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x119f5088>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x119f5088>)

# %%
likeBrexitParty.groupby(lrBrexit).mean().plot(),likeBrexitParty.groupby(lrBrexit-leftRight).mean().plot()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x11a4c0c8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11a4c0c8>)

# %%
likeGrn.groupby(lrgreens).mean().plot(),likeGrn.groupby(lrgreens-leftRight).mean().plot()
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x11aba648>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x11aba648>)

# %%
likeGrn.groupby(lrgreens).mean().plot(),likeGrn.groupby(lrgreens-leftRight).mean().plot(),likeGrn.groupby(leftRight).mean().plot(),
plt.legend()

# %%
leftRight[mask].value_counts(dropna=False)
# Out:
# 5.0     3666
# 3.0     3076
# 7.0     2425
# 6.0     2345
# 4.0     2121
# 2.0     1963
# 8.0     1821
# 0.0      761
# 1.0      703
# 10.0     565
# 9.0      503
# dtype: int64

# %%
search(BES_Panel,"country")
# Out:
# country            13126
# p_country_birth    30185
# dtype: int64

# %%
BES_Panel["country"].value_counts()
# Out:
# 1.0    11127
# 2.0     1214
# 3.0      785
# Name: country, dtype: int64

# %%
# ## force england only!
# BES_Panel = BES_Panel[BES_Panel["country"]==1.0]

# ## oof makes a big difference!

search(BES_Panel,"likePC|likeSNP|lrPC|lrSNP")
# Out:
# likeSNP    34366
# likePC      2084
# lrSNP       3388
# lrPC        2084
# dtype: int64

# %%
def all_party_position_plot(country = Britain,n_boot=10):

    sns.set(font_scale=1.5)
    party_like_list = ['likeCon', 'likeLab', 'likeLD', 'likeBrexitParty', 'likeGrn','likePC','likeSNP']
    party_lr_list   = ['lrCon',  'lrLab',    'lrLD',  'lrBrexit',        'lrgreens','lrPC','lrSNP']
    rename_dict = {"likeBrexitParty":"likeBXP","lrgreens":"lrGrn","lrBrexit":"lrBXP"}



    party_likes = BES_Panel[party_like_list][country]\
                    .rename(columns=rename_dict)\
                    .apply(lambda x: x.replace("Don't know",np.nan).cat.codes.replace(-1,np.nan))

    party_lr    = BES_Panel[party_lr_list][country]\
                    .rename(columns=rename_dict)\
                    .apply(lambda x: x.replace("Don't know",np.nan).cat.codes.replace(-1,np.nan))

    party_likes["lrSelf"] = BES_Panel["leftRight"][country].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)

    party_likes["wt"] = BES_Panel["wt"][country]

    all_parties = party_likes.melt(id_vars = ["wt","lrSelf"],var_name = "likevar",value_name = "like")
    party_lr = party_lr.melt(var_name = "lrvar",value_name = "lr")
    all_parties[party_lr.columns] = party_lr
    all_parties = all_parties.dropna()

    df = pd.DataFrame()
    y_axis = "How Much Do People Like A Party"
    df[y_axis] = list(zip(all_parties["like"].values,all_parties["wt"].values))
    x_axis_list = ["Perceived LR Party Position","Perceived LR Party Position Relative To Yours","Your LR Position"]

    df[x_axis_list[0]] = all_parties["lr"].values
    df[x_axis_list[1]] = (all_parties["lr"]-all_parties["lrSelf"]).values
    df[x_axis_list[2]] = all_parties["lrSelf"].values

    df = df.melt(id_vars = y_axis, value_vars = x_axis_list)
    plt.figure(figsize=(12,8));
    sns.lineplot(data=df,
                x = "value",
                y = y_axis,
                hue = "variable",
                estimator=weighted_mean,n_boot=10 );
    plt.ylim([0,10]);
    plt.title("Breakdown for "+country.name + " in " +dataset_name)
    
    
    county_to_num = {'England':1,'Scotland':2,'Wales':3,'Britain':'All'}
    
    sns.lineplot(data=pd.crosstab(leftRight,BES_Panel["country"],normalize='columns',margins=True)[county_to_num[country.name]]*10,alpha=.3)

# %%
country= England
county_to_num = {'England':1,'Scotland':2,'Wales':3,'Britain':'All'}
sns.lineplot(pd.crosstab(leftRight,BES_Panel["country"],normalize='columns',margins=True)[county_to_num[country.name]]*10)

# %%
# %%time

all_party_position_plot(country = Britain,n_boot=10)
# Out:
# Wall time: 10.8 s

# %%
# %%time

all_party_position_plot(country = England,n_boot=10)
# Out:
# Wall time: 8.23 s

# %%
# %%time

all_party_position_plot(country = Scotland,n_boot=10)
# Out:
# Wall time: 1.12 s

# %%
# %%time

# all_party_position_plot(country = Scotland,n_boot=10)

# %%
# %%time

all_party_position_plot(country = Wales,n_boot=10)
# Out:
# Wall time: 619 ms

# %%
lrCon = BES_Panel["lrCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrLab = BES_Panel["lrLab"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrLD = BES_Panel["lrLD"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrBrexit = BES_Panel["lrBrexit"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrgreens = BES_Panel["lrgreens"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)



likeCon = BES_Panel["likeCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLab = BES_Panel["likeLab"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLD  = BES_Panel["likeLD"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeGrn = BES_Panel["likeGrn"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeBrexitParty = BES_Panel["likeBrexitParty"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
def position_plot(likeParty,lrParty,partyName,allParties = False,country=Britain):

  
    mask = likeParty[country].notnull() & lrgreens[country].notnull() & BES_Panel["wt"][country].notnull() & leftRight[country].notnull()

    df = pd.DataFrame()
    y_axis = "How Much Do People Like The "+partyName+" Party"
    df[y_axis] = list(zip(likeParty[country][mask].values,BES_Panel["wt"][country][mask].values))
    x_axis_list = ["Perceived LR "+partyName+" Position","Perceived LR "+partyName+" Position Relative To Yours","Your LR Position"]

    df[x_axis_list[0]] = lrParty[country][mask].values
    df[x_axis_list[1]] = (lrParty-leftRight)[country][mask].values
    df[x_axis_list[2]] = leftRight[country][mask].values

    df = df.melt(id_vars = y_axis, value_vars = x_axis_list)
    plt.figure(figsize=(12,8));
    sns.lineplot(data=df,
                x = "value",
                y = y_axis,
                hue = "variable",
                estimator=weighted_mean,n_boot=1000 );
    plt.ylim([0,10]);

# %%
# %debug

# %%
position_plot(likeGrn,lrgreens,"Green",England)

# %%
position_plot(likeCon,lrCon,"Con",England)

# %%
position_plot(likeLab,lrLab,"Lab",England)

# %%
position_plot(likeBrexitParty,lrBrexit,"BXP",England)

# %%
position_plot(likeLD,lrLD,"LD",England)

# %%
# likeGrn.groupby(lrgreens).mean().plot(),likeGrn.groupby(lrgreens-leftRight).mean().plot(),likeGrn.groupby(leftRight).mean().plot(),


mask = likeGrn.notnull() & lrgreens.notnull() & BES_Panel["wt"].notnull()
#& (lr_scale<=3) & redistSelf.notnull()
x_axis = "Left-Right Position Assigned To Greens"
y_axis = "How Much Do People Like The Greens"

df = pd.DataFrame()
df[x_axis] = lrgreens[mask]
df[y_axis] = list(zip(likeGrn[mask].values,BES_Panel["wt"][mask].values))

sns.lineplot(data=df,
            x = x_axis,
            y = y_axis,
            estimator=weighted_mean,n_boot=1000 );
plt.ylim([0,10]);

# %%
search(BES_Panel,"redist")
# Out:
# redistSelf      31468
# redistCon       31468
# redistLab       31468
# redistLD        31468
# redistSNP        2730
# redistPC         1804
# redistBrexit    31468
# redistGreen     31468
# dtype: int64

# %%
# redistSelf = BES_Pa

redistSelf = BES_Panel["redistSelf"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
al_scale = BES_Panel["al_scale"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lr_scale = BES_Panel["lr_scale"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)

# %%
redistSelf.value_counts()
# Out:
# 5.0     4319
# 0.0     3993
# 3.0     3326
# 7.0     3013
# 10.0    2774
# 4.0     2588
# 2.0     2053
# 6.0     1963
# 8.0     1863
# 1.0     1089
# 9.0      628
# dtype: int64

# %%
al_scale.value_counts()
# Out:
# 15.0    2658
# 14.0    2399
# 13.0    2226
# 16.0    2071
# 12.0    1932
# 10.0    1759
# 11.0    1741
# 17.0    1660
# 18.0    1414
# 9.0     1356
# 8.0     1242
# 7.0     1054
# 19.0    1019
# 6.0      969
# 20.0     822
# 5.0      772
# 4.0      608
# 3.0      434
# 2.0      346
# 1.0      234
# 0.0      198
# dtype: int64

# %%
# Out:
# [(10.0, 0.6617759474891951),
#  (3.0, 0.5558412964192835),
#  (10.0, 0.6811994788171307),
#  (11.0, 0.7779260840415743),
#  (11.0, 0.7482749782166852),
#  (0.0, 0.8331114808567869),
#  (0.0, 0.45739138222567405),
#  (nan, 0.6490292522643417),
#  (2.0, 0.6561746477219595),
#  (3.0, 0.9124985119585506),
#  (10.0, 0.9097618414246665),
#  (12.0, 0.7084815980598074),
#  (2.0, 0.7773041220525557),
#  (8.0, 0.6206693983188135),
#  (5.0, 1.0021560759224728),
#  (6.0, 1.4738336638979155),
#  (nan, 0.8979344417567628),
#  (12.0, 0.6566059427929376),
#  (11.0, 0.7328678398524224),
#  (nan, 1.066731544274993),
#  (10.0, 1.8394489616883685),
#  (6.0, 0.4202745069287297),
#  (nan, 1.4219086484218932),
#  (6.0, 1.7846147561988366),
#  (7.0, 1.3764784854803445),
#  (3.0, 0.6005293254723517),
#  (5.0, 0.5399305827948258),
#  (6.0, 0.6833052641471135),
#  (2.0, 0.6330552799089934),
#  (2.0, 0.36766806451579237),
#  (0.0, 0.448324147834365),
#  (5.0, 0.7709570998850104),
#  (5.0, 0.5176338142527357),
#  (9.0, 1.2584081409038417),
#  (7.0, 1.591993303394191),
#  (8.0, 0.6444544014568481),
#  (5.0, 0.8840357577531666),
#  (10.0, 0.5859068034163092),
#  (13.0, 0.9491692580159001),
#  (6.0, 0.6805217566190632),
#  (8.0, 0.7537076465506242),
#  (nan, 0.9838730671673633),
#  (nan, 0.7904119331203956),
#  (5.0, 0.8213002067767556),
#  (0.0, 0.8847641415151406),
#  (0.0, 0.7556481352915433),
#  (7.0, 0.8668553518443955),
#  (0.0, 0.7489140484120236),
#  (4.0, 0.7182365424978479),
#  (8.0, 0.45739138222567405),
#  (nan, 0.9244427997562085),
#  (nan, 1.0762895268063775),
#  (5.0, 0.448388239978597),
#  ...]

# %%
al_scale.max()
# Out:
# 20.0

# %%
BES_Panel["al_scale"]
# Out:
# id
# 2                     4
# 7         Authoritarian
# 8                     5
# 9                   NaN
# 15                  5.5
#               ...
# 102854                4
# 102855              5.5
# 102856              5.5
# 102857              9.5
# 102858              4.5
# Name: al_scale, Length: 31468, dtype: category
# Categories (21, object): [Libertarian < 0.5 < 1 < 1.5 ... 8.5 < 9 < 9.5 < Authoritarian]

# %%
mask = al_scale.notnull() & lr_scale.notnull() & BES_Panel["wt"].notnull()

df = pd.DataFrame()
df["al_scale"] = al_scale[mask]
df["lr_scale_wts"] = list(zip(lr_scale[mask].values,BES_Panel["wt"][mask].values))

sns.lineplot(data=df,
            x = "al_scale",
            y = "lr_scale_wts",
            estimator=weighted_mean,n_boot=1000 );
plt.ylim([0,20])
# Out:
# (0.0, 20.0)

# %%
mask = al_scale.notnull() & lr_scale.notnull() & BES_Panel["wt"].notnull() & (lr_scale<=6)

df = pd.DataFrame()
df["al_scale"] = al_scale[mask]
df["lr_scale_wts"] = list(zip(lr_scale[mask].values,BES_Panel["wt"][mask].values))

sns.lineplot(data=df,
            x = "al_scale",
            y = "lr_scale_wts",
            estimator=weighted_mean,n_boot=1000 );
plt.ylim([0,20])
# Out:
# (0.0, 20.0)

# %%
mask = al_scale.notnull() & lr_scale.notnull() & BES_Panel["wt"].notnull() & (lr_scale<=6) & redistSelf.notnull()

df = pd.DataFrame()
df["Social Liberal-Social Authoritarian"] = al_scale[mask]
df["Support Income Equality-\nOppose Income Equalisation"] = list(zip(redistSelf[mask].values,BES_Panel["wt"][mask].values))
sns.set(font_scale=1.5)
plt.figure(figsize=(12,8));

sns.lineplot(data=df,
            x = "Social Liberal-Social Authoritarian",
            y = "Support Income Equality-\nOppose Income Equalisation",
            estimator=weighted_mean,n_boot=1000 );
plt.ylim([0,10]);
plt.title("Some people feel that government should make much greater efforts to make people’s incomes more equal.\nOther people feel that government should be much less concerned about how equal people’s incomes are.\nWhere would you place yourself on this scale?"
         +"\n('Leftmost' half of the population)");

# %%
mask = al_scale.notnull() & lr_scale.notnull() & BES_Panel["wt"].notnull() & (lr_scale<=3) & redistSelf.notnull()

df = pd.DataFrame()
df["al_scale"] = al_scale[mask]
df["lr_scale_wts"] = list(zip(redistSelf[mask].values,BES_Panel["wt"][mask].values))

sns.lineplot(data=df,
            x = "al_scale",
            y = "lr_scale_wts",
            estimator=weighted_mean,n_boot=1000 );
plt.ylim([0,10]);

# %%
# %%time
dataset_name = "W12_only"
df_list = "BES_Panel"

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}

England  = BES_Panel["country"]==1
England.name = "England"
Scotland = BES_Panel["country"]==2
Scotland.name = "Scotland"
Wales    = BES_Panel["country"]==3
Wales.name = "Wales"
Britain  = BES_Panel["country"].notnull()
Britain.name = "Britain"
BES_Panel["country"].value_counts(dropna=False)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# Wall time: 311 ms
# 1.0    27662
# 2.0     4262
# 3.0     2469
# NaN        1
# Name: country, dtype: int64

# %%
lrMay = BES_Panel["lrMay"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrCorbyn = BES_Panel["lrCorbyn"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrCon = BES_Panel["lrCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
lrLab = BES_Panel["lrLab"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)

likeCon = BES_Panel["likeCon"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLab = BES_Panel["likeLab"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeMay  = BES_Panel["likeMay"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeCorbyn = BES_Panel["likeCorbyn"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)

leftRight = BES_Panel["leftRight"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)

def position_plot(likeParty,lrParty,partyName,allParties = False,country=Britain):

  
    mask = likeParty[country].notnull() & lrParty[country].notnull() & BES_Panel["wt"][country].notnull() & leftRight[country].notnull()

    df = pd.DataFrame()
    y_axis = "How Much Do People Like The "+partyName+" Party"
    df[y_axis] = list(zip(likeParty[country][mask].values,BES_Panel["wt"][country][mask].values))
    x_axis_list = ["Perceived LR "+partyName+" Position","Perceived LR "+partyName+" Position Relative To Yours","Your LR Position"]

    df[x_axis_list[0]] = lrParty[country][mask].values
    df[x_axis_list[1]] = (lrParty-leftRight)[country][mask].values
    df[x_axis_list[2]] = leftRight[country][mask].values

    df = df.melt(id_vars = y_axis, value_vars = x_axis_list)
    plt.figure(figsize=(12,8));
    sns.lineplot(data=df,
                x = "value",
                y = y_axis,
                hue = "variable",
                estimator=weighted_mean,n_boot=1000 );
    plt.ylim([0,10]);

# %%
position_plot(likeCon,lrCon,"CON",England)

# %%
position_plot(likeMay,lrMay,"MAY",England)

# %%
position_plot(likeLab,lrLab,"LAB",England)

# %%
position_plot(likeCorbyn,lrCorbyn,"CORBYN",England)
