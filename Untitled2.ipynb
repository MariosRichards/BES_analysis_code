# %%
dataset_name = "W19_comb"
df_list = [ "BES_Panel", "BES_reduced_with_na"]

# %%
import warnings
warnings.filterwarnings('ignore')

from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)

# %matplotlib inline

import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sns
import pickle, os, gc, re

sns.set();
sns.set_palette("colorblind")

from IPython.display import display, display_html, HTML
from IPython.core.debugger import set_trace
# plt.rcParams["axes.grid"] = False

import Jupyter_module_loader
from utility import *
import gaussian_kde

import warnings
warnings.filterwarnings('ignore')

import holoviews as hv
from holoviews import opts

encoding = "ISO-8859-1"

# you should clone this git to a subdirectory called 'BES_analysis_code' (in some directory - I call it BES_analysis - doesn't matter though)
# %matplotlib inline
(BES_code_folder, BES_small_data_files, BES_data_folder,
 BES_output_folder, BES_file_manifest, BES_R_data_files) = setup_directories()

global BES_Panel, BES_numeric, BES_reduced, BES_reduced_with_na, BES_non_numeric
data_subfolder = BES_data_folder + dataset_name + os.sep

(manifest, dataset_filename, dataset_description, dataset_citation,
 dataset_start, dataset_stop, dataset_wave) = get_manifest(dataset_name, BES_file_manifest)

for df in df_list:
    if df=="BES_Panel":
        globals()[df]  = pd.read_pickle(data_subfolder + dataset_filename.replace('.dta','.zip'),compression='zip')
    else:
        globals()[df]  = pd.read_pickle(data_subfolder + df + '.zip',compression='zip' )
        globals()[df].replace(-1,np.nan,inplace=True)
  
(var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)

# get full set of inferred "cross wave" auth-lib/left-right values and ages
pan_dataset_allr_values = pd.read_csv(BES_small_data_files + "pan_dataset_allr_values"+".csv")
pan_dataset_ages = pd.read_csv( BES_small_data_files + "pan_dataset_ages"+".csv" )
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (7911, 14)

# %%
with open(BES_data_folder+os.sep+"Portes"+os.sep+"treatment_dict-04-04.pkl", 'rb') as f:
    treatment_dict = pickle.load(f)

# %%
treatment_dict
# Out:
# {'D8_10immigEC_with_deltas': D8_10immigSelf__Allow many more                                      0.201055
#  D8_10immigrantsWelfareState__Strongly agree                          0.178006
#  D8_10ukCoopMovement__Bad for Britain                                 0.112159
#  ukCoopMovementW10__Bad for Britain                                   0.093811
#  euMoreW8__Many more                                                  0.080439
#  D8_10changeImmig__Getting a lot higher                               0.059744
#  noneuMoreW8__Many more                                               0.056848
#  D8_10europeanness__Very strongly European                            0.046659
#  immigSelfW10__Allow many more                                        0.035453
#  D9_10immigSelf__Allow many more                                      0.032473
#  euPriorityBalanceW10__Control immigration                            0.030343
#  immigContributeTakeW8__Get more than they pay                        0.028929
#  D8_10EUIntegrationSelf__Protect our independence                     0.025192
#  euCloserW8__Strongly agree                                           0.023369
#  D8_10effectsEUImmigration__Much higher                               0.022945
#  immigrantsWelfareStateW8__Strongly agree                             0.018619
#  euMoreW13__Many more                                                 0.017729
#  euDominanceW8__Many more powers                                      0.016242
#  immigSelfW8__Allow many more                                         0.014947
#  euLawsLevelW8__Strongly agree                                        0.014600
#  discussPolDaysW8__7 days                                             0.013080
#  D8_10socialIdentityGlobalRemain__A great deal in common              0.012372
#  D8_10leaveImpactBritain__A very large impact                         0.011452
#  D8_10effectsEUEcon__Much better                                      0.010139
#  D8_10effectsEUNHS__Much better                                       0.009904
#  asylumMoreW8__Many more                                              0.009768
#  immigSelfW11__Allow many more                                        0.009422
#  D9_10trustMPs__A great deal of trust                                 0.009164
#  D9_10ptvLD__Very likely                                              0.009007
#  trustMPsW10__A great deal of trust                                   0.008946
#  euUKRichW8__Strongly agree                                           0.008145
#  changeImmigW10__Getting a lot higher                                 0.008145
#  D9_10bestOnMII_United Kingdom Independence Party (UKIP)              0.007951
#  econGenRetroW10__Got a lot better                                    0.007535
#  likeCorbynW11__Strongly like                                         0.007213
#  studentsMoreW8__Many more                                            0.006884
#  D8_10effectsEUWorkers__Much better                                   0.006631
#  discrimBMEW10__A lot of discrimination against                       0.006486
#  discrimMuslimsW10__A lot of discrimination against                   0.006401
#  debateTwoWatchW8_Yes                                                 0.006357
#  D8_10mii_cat_immigration                                             0.006295
#  achieveReduceImmigUKIPW12_Yes                                        0.005999
#  euPriorityBalanceW13__Control immigration                            0.005978
#  D9_10euID4__Strongly agree                                           0.005947
#  familiesMoreW8__Many more                                            0.005906
#  euRefExpectationW8__100 - UK will definitely vote to leave the EU    0.005860
#  changeEconomyLabW10__Getting a lot better                            0.005794
#  D8_10ukCoopTrade__Bad for Britain                                    0.005742
#  populism5W10__Strongly agree                                         0.005663
#  D8_10likeUKIP__Strongly like                                         0.005596
#  dtype: float32,
#  'D8_9immigSelf_with_deltas': asylumMoreW8__Many more                                   0.172246
#  D8_9immigCon__Allow many more                             0.109478
#  D8_9immigUKIP__Allow many more                            0.093727
#  familiesMoreW8__Many more                                 0.061157
#  D8_9immigLab__Allow many more                             0.049670
#  EUIntegrationSelfW9__Protect our independence             0.044812
#  immigConW9__Allow many more                               0.036162
#  socialIdentityGlobalRemainW9__A great deal in common      0.034792
#  D8_9immigLD__Allow many more                              0.033692
#  D8_9europeanness__Very strongly European                  0.033266
#  immigUKIPW8__Allow many more                              0.033100
#  euMoreW8__Many more                                       0.030698
#  small_mii_catW9_Immigration                               0.029911
#  D8_9EUIntegrationSelf__Protect our independence           0.029801
#  controlImmigW9__Complete control                          0.025753
#  ptvUKIPW9__Very likely                                    0.023723
#  happyEULeaveW9__Extremely happy                           0.023692
#  D8_9immigGreen__Allow many more                           0.023446
#  immigUKIPW9__Allow many more                              0.022918
#  likeFarageW9__Strongly like                               0.022511
#  noneuMoreW8__Many more                                    0.018462
#  studentsMoreW8__Many more                                 0.017025
#  immigLabW9__Allow many more                               0.016557
#  europeannessW9__Very strongly European                    0.016018
#  D8_9likeFarage__Strongly like                             0.015951
#  D8_9socialIdentityGlobalLeave__A great deal in common     0.013740
#  mii_catW9_immigration                                     0.013286
#  approveEUW9__Strongly approve                             0.012822
#  D8_9immigSNP__Allow many more                             0.012025
#  benefitsToMigrantsW8__Never                               0.011736
#  likeOsborneW8__Strongly like                              0.011732
#  likeConW9__Strongly like                                  0.011389
#  likeUKIPW9__Strongly like                                 0.011176
#  proConRemainW8__7- Upsides of remaining                   0.010923
#  effectsEUImmigrationW8__Much higher                       0.010352
#  likeCameronW8__Strongly like                              0.010295
#  ageW9                                                     0.009883
#  EUIntegrationConW9__Protect our independence              0.009834
#  immigLDW9__Allow many more                                0.009424
#  D8_9socialIdentityGlobalRemain__A great deal in common    0.009178
#  ageW8                                                     0.009043
#  likeGoveW9__Strongly like                                 0.009013
#  betterDealEUW8__Much better                               0.009006
#  achieveReduceImmigNoneW9_Yes                              0.008983
#  euCloserW8__Strongly agree                                0.008711
#  socialIdentityGlobalLeaveW9__A great deal in common       0.008703
#  D8_9likeUKIP__Strongly like                               0.008585
#  immigSNPW9__Allow many more                               0.007367
#  ptvConW9__Very likely                                     0.007251
#  D8_9likeBoris__Strongly like                              0.007244
#  dtype: float32,
#  'D8_9immigSelf_with_deltas_restrict_to_controlImmigW8mask': asylumMoreW8__Many more                                              0.101941
#  D8_9immigCon__Allow many more                                        0.092049
#  familiesMoreW8__Many more                                            0.073137
#  D8_9immigUKIP__Allow many more                                       0.069076
#  D8_9immigLD__Allow many more                                         0.045739
#  D8_9immigLab__Allow many more                                        0.034654
#  EUIntegrationSelfW9__Protect our independence                        0.028466
#  immigConW9__Allow many more                                          0.026264
#  likeFarageW9__Strongly like                                          0.021179
#  happyEULeaveW9__Extremely happy                                      0.019456
#  immigUKIPW8__Allow many more                                         0.018531
#  noneuMoreW8__Many more                                               0.017325
#  handleMIIUKIPW9__Very well                                           0.015059
#  socialIdentityGlobalLeaveW9__A great deal in common                  0.014636
#  D8_9europeanness__Very strongly European                             0.013773
#  achieveReduceImmigUKIPW9_Yes                                         0.013758
#  controlImmigW8__Complete control                                     0.012557
#  immigUKIPW9__Allow many more                                         0.012371
#  socialIdentityGlobalRemainW9__A great deal in common                 0.012336
#  D8_9bestOnMII_No party is best able to handle this issue             0.011395
#  studentsMoreW8__Many more                                            0.011123
#  D8_9EUIntegrationSelf__Protect our independence                      0.010919
#  D8_9immigGreen__Allow many more                                      0.010583
#  likeBorisW8__Strongly like                                           0.010298
#  controlImmigW9__Complete control                                     0.009993
#  immigConW8__Allow many more                                          0.009281
#  euMoreW8__Many more                                                  0.009217
#  likeLabW8__Strongly like                                             0.009118
#  likeOsborneW9__Strongly like                                         0.008702
#  D8_9satDemEU__Very satisfied                                         0.008471
#  ageW8                                                                0.008403
#  immigGreenW9__Allow many more                                        0.008179
#  EUIntegrationSelfW8__Protect our independence                        0.007739
#  euRefExpectationW8__100 - UK will definitely vote to leave the EU    0.007404
#  bestOnMIIW8_Scottish National Party (SNP)                            0.007339
#  immigLabW9__Allow many more                                          0.007211
#  D8_9likeBoris__Strongly like                                         0.007166
#  D8_9likeLab__Strongly like                                           0.007162
#  mii_catW9_immigration                                                0.006881
#  britishnessW9__Very strongly British                                 0.006813
#  D8_9likeFarage__Strongly like                                        0.006620
#  monarchW8__Strongly agree                                            0.006558
#  D8_9bestOnMII_Conservative                                           0.006423
#  D8_9socialIdentityGlobalRemain__A great deal in common               0.006394
#  ageW9                                                                0.006380
#  generalElectionVoteW9_Conservative                                   0.006283
#  ptvUKIPW9__Very likely                                               0.006276
#  D8_9likeGove__Strongly like                                          0.006176
#  immigLDW9__Allow many more                                           0.006116
#  likeConW9__Strongly like                                             0.006110
#  dtype: float32,
#  'D8_9immigSelf_with_deltas_most_immig_negative_half': EUIntegrationSelfW9__Protect our independence           0.111889
#  D8_9immigUKIP__Allow many more                          0.095351
#  immigrantsWelfareStateW8__Strongly agree                0.065387
#  D8_9immigCon__Allow many more                           0.052229
#  immigConW9__Allow many more                             0.050967
#  likeUKIPW9__Strongly like                               0.046174
#  socialIdentityGlobalRemainW9__A great deal in common    0.045398
#  immigUKIPW9__Allow many more                            0.043513
#  small_mii_catW9_Immigration                             0.040921
#  euMoreW8__Many more                                     0.040118
#  euIDW9_The leave side                                   0.037060
#  mii_catW9_immigration                                   0.032303
#  D8_9europeanness__Very strongly European                0.030376
#  happyEULeaveW9__Extremely happy                         0.029846
#  europeannessW9__Very strongly European                  0.029025
#  likeFarageW9__Strongly like                             0.028025
#  ptvUKIPW9__Very likely                                  0.026039
#  changeImmigW8__Getting a lot higher                     0.019469
#  EUIntegrationConW9__Protect our independence            0.017832
#  immigUKIPW8__Allow many more                            0.017220
#  noneuMoreW8__Many more                                  0.016126
#  controlImmigW9__Complete control                        0.015578
#  al2W7W8W9__Strongly agree                               0.012530
#  al_scaleW7W8W9__Authoritarian                           0.012161
#  satDemEUW9__Very satisfied                              0.011487
#  ageW8                                                   0.011117
#  small_mii_catW8_Immigration                             0.009895
#  asylumMoreW8__Many more                                 0.009113
#  blameLeave_5W9_Yes                                      0.008166
#  ukCoopMovementW8__Bad for Britain                       0.008154
#  mii_catW8_immigration                                   0.007686
#  D8_9likeFarage__Strongly like                           0.007673
#  remainToneW8__5 - Hope                                  0.007313
#  benefitsToMigrantsW8__Never                             0.007102
#  socialIdentityGlobalLeaveW9__A great deal in common     0.007010
#  familiesMoreW8__Many more                               0.006475
#  likeCorbynW9__Strongly like                             0.006339
#  ageW9                                                   0.005973
#  achieveReduceImmigNoneW9_Yes                            0.005835
#  immigContributeTakeW8__Get more than they pay           0.005568
#  negotiationSpecifics_2W9_Yes                            0.005370
#  immigLDW9__Allow many more                              0.005206
#  likeMcDonnellW9__Strongly like                          0.005030
#  likeGoveW8__Strongly like                               0.004944
#  proConRemainW8__7- Upsides of remaining                 0.004941
#  approveEUW9__Strongly approve                           0.004735
#  changeNHSW8__Getting a lot better                       0.004594
#  bestOnMIIW9_Conservative                                0.004573
#  likeCameronW8__Strongly like                            0.004433
#  infoSourceInternetW8__More than 2 hours                 0.004180
#  dtype: float32,
#  'D8_9immigSelf_with_deltas_most_immig_positive_half': asylumMoreW8__Many more                                 0.122046
#  D8_9immigLab__Allow many more                           0.108214
#  D8_9immigCon__Allow many more                           0.078990
#  euMoreW8__Many more                                     0.059958
#  EUIntegrationSelfW9__Protect our independence           0.055449
#  immigrantsWelfareStateW8__Strongly agree                0.053310
#  D8_9immigGreen__Allow many more                         0.052233
#  immigLDW9__Allow many more                              0.037296
#  D8_9immigLD__Allow many more                            0.036708
#  europeannessW9__Very strongly European                  0.034778
#  familiesMoreW8__Many more                               0.032322
#  happyEULeaveW9__Extremely happy                         0.032137
#  britishnessW9__Very strongly British                    0.029348
#  D8_9immigUKIP__Allow many more                          0.028570
#  D8_9immigSNP__Allow many more                           0.027929
#  changeImmigW8__Getting a lot higher                     0.023723
#  likeUKIPW9__Strongly like                               0.021562
#  likeUKIPW8__Strongly like                               0.021302
#  controlImmigW9__Complete control                        0.021256
#  likeFarageW9__Strongly like                             0.021232
#  immigContributeTakeW8__Get more than they pay           0.018453
#  immigUKIPW9__Allow many more                            0.018302
#  mii_catW9_immigration                                   0.017878
#  ptvUKIPW9__Very likely                                  0.013915
#  approveEUW9__Strongly approve                           0.012827
#  al_scaleW7W8W9__Authoritarian                           0.012687
#  immigLabW9__Allow many more                             0.012136
#  edlevelW8W9W10__Postgrad                                0.011942
#  noneuMoreW8__Many more                                  0.011817
#  immigGreenW9__Allow many more                           0.011328
#  ageW9                                                   0.011019
#  ageW8                                                   0.010929
#  immigConW9__Allow many more                             0.010706
#  euRefVoteW9_Leave the EU                                0.009897
#  englishnessW9__Very strongly English                    0.009866
#  studentsMoreW8__Many more                               0.009124
#  socialIdentityGlobalRemainW9__A great deal in common    0.008821
#  EUIntegrationConW8__Protect our independence            0.008768
#  immigConW8__Allow many more                             0.007976
#  satDemEUW9__Very satisfied                              0.007787
#  EUIntegrationLabW8__Protect our independence            0.007010
#  small_mii_catW8_Immigration                             0.006957
#  immigSNPW9__Allow many more                             0.006907
#  labUnitedW8__Very united                                0.006639
#  euUndermineIdentityW8__Strongly agree                   0.006631
#  likeLabW8__Strongly like                                0.006200
#  antiIntellectualW9__Strongly agree                      0.005678
#  small_mii_catW9_Immigration                             0.005404
#  changeEconomyW9__Getting a lot better                   0.005394
#  immigUKIPW8__Allow many more                            0.005222
#  dtype: float32,
#  'D7_8immigSelf_with_deltas': D7_8asylumMore__Many more                                                0.152047
#  D7_8euMore__Many more                                                    0.089016
#  D7_8immigCon__Allow many more                                            0.073079
#  D7_8immigUKIP__Allow many more                                           0.071990
#  D7_8familiesMore__Many more                                              0.066419
#  D7_8immigrantsWelfareState__Strongly agree                               0.038372
#  D7_8noneuMore__Many more                                                 0.037817
#  D7_8immigLab__Allow many more                                            0.032345
#  D7_8studentsMore__Many more                                              0.019774
#  D7_8immigGreen__Allow many more                                          0.017715
#  D7_8immigLD__Allow many more                                             0.016603
#  asylumMoreW7__Many more                                                  0.011644
#  immigUKIPW8__Allow many more                                             0.011257
#  EUIntegrationSelfW8__Protect our independence                            0.009947
#  euMoreW8__Many more                                                      0.009299
#  immigUKIPW7__Allow many more                                             0.007685
#  D7_8ukCoopMovement__Bad for Britain                                      0.007116
#  D7_8changeImmig__Getting a lot higher                                    0.006767
#  asylumMoreW8__Many more                                                  0.006506
#  leftRightW7__Right                                                       0.005376
#  changeImmigW8__Getting a lot higher                                      0.005358
#  familiesMoreW7__Many more                                                0.005347
#  immigConW8__Allow many more                                              0.004962
#  euRefVoteW8_Leave the EU                                                 0.004652
#  euLeaveVoiceW8__Much higher                                              0.004607
#  ukCoopMovementW8__Bad for Britain                                        0.004097
#  noneuMoreW8__Many more                                                   0.003746
#  immigGreenW8__Allow many more                                            0.003600
#  familiesMoreW8__Many more                                                0.003579
#  likeFarageW8__Strongly like                                              0.003553
#  proConRemainW8__7- Upsides of remaining                                  0.003495
#  likeCameronW8__Strongly like                                             0.003402
#  studentsMoreW8__Many more                                                0.003191
#  immigLabW7__Allow many more                                              0.003092
#  immigrantsWelfareStateW7__Strongly agree                                 0.003067
#  immigConW7__Allow many more                                              0.003060
#  generalElectionVoteW8_Conservative                                       0.002975
#  D7_8EUIntegrationSelf__Protect our independence                          0.002956
#  socialIdentityGlobalLeaveW8__A great deal in common                      0.002919
#  likeOsborneW8__Strongly like                                             0.002795
#  redistSelfW7__Government should be less concerned about equal incomes    0.002717
#  likeGoveW8__Strongly like                                                0.002683
#  ptvConW7__Very likely                                                    0.002641
#  leaveToneW8__5 - Hope                                                    0.002623
#  likeCameronW7__Strongly like                                             0.002606
#  D7_8leaveTone__5 - Hope                                                  0.002601
#  lr1W7W8W9__Strongly agree                                                0.002563
#  effectsEUImmigrationW8__Much higher                                      0.002451
#  immigLDW8__Allow many more                                               0.002381
#  likeUKIPW8__Strongly like                                                0.002359
#  dtype: float32,
#  'D10_17immigSelf_with_deltas': D10_17euPriorityBalance__Control immigration                            0.125046
#  D10_17immigCon__Allow many more                                         0.120634
#  D10_17changeImmig__Getting a lot higher                                 0.103359
#  immigConW17__Allow many more                                            0.063474
#  euPriorityBalanceW17__Control immigration                               0.052464
#  immigUKIPW10__Allow many more                                           0.051185
#  D10_17happyEULeave__Extremely happy                                     0.047758
#  D10_17EUIntegrationSelf__Protect our independence                       0.043146
#  D10_17overseasAid__Strongly agree                                       0.040731
#  natSecuritySelfW10__Protect civil liberties                             0.039731
#  D10_17europeanness__Very strongly European                              0.035556
#  immigBrexitW17__Allow many more                                         0.034209
#  ukCoopMovementW10__Bad for Britain                                      0.029037
#  approveEUW10__Strongly approve                                          0.024100
#  immigConW10__Allow many more                                            0.021891
#  likeMayW10__Strongly like                                               0.021703
#  D10_17immigGreen__Allow many more                                       0.020965
#  immigrantsWelfareStateW10__Strongly agree                               0.019228
#  changeImmigW17__Getting a lot higher                                    0.018333
#  D10_17effectsEUImmigration__Much higher                                 0.017056
#  immigLabW10__Allow many more                                            0.016148
#  trustCourtsW17__10.0                                                    0.015595
#  D10_17immigLab__Allow many more                                         0.015300
#  blackEqualityW17__Gone much too far                                     0.015116
#  effectsEUImmigrationW17__Much higher                                    0.012273
#  likeConW10__Strongly like                                               0.011282
#  EUIntegrationSelfW10__Protect our independence                          0.011093
#  ptvConW10__Very likely                                                  0.009341
#  D10_17immigLD__Allow many more                                          0.009107
#  overseasAidW10__Strongly agree                                          0.009053
#  D10_17EUIntegrationCon__Protect our independence                        0.008090
#  immigLDW17__Allow many more                                             0.007198
#  EUIntegrationUKIPW10__Protect our independence                          0.006749
#  satDemEUW10__Very satisfied                                             0.006687
#  likeFarageW17__Strongly like                                            0.006637
#  D10_17likeLab__Strongly like                                            0.006631
#  immigLabW17__Allow many more                                            0.006123
#  D10_17leftRight__Right                                                  0.005744
#  EUIntegrationConW17__Protect our independence                           0.005742
#  D10_17likeCorbyn__Strongly like                                         0.005460
#  redistLDW10__Government should be less concerned about equal incomes    0.005373
#  discrimWhiteW10__A lot of discrimination against                        0.005299
#  al_scaleW10W11W12__Authoritarian                                        0.005208
#  ptvConW17__Very likely                                                  0.005117
#  D10_17likeGrn__Strongly like                                            0.004874
#  D10_17euLeaveVoice__Much higher                                         0.004823
#  EUIntegrationLDW10__Protect our independence                            0.004805
#  happyScotIndepResultW17__Extremely happy                                0.004708
#  leftRightW17__Right                                                     0.004682
#  strongLeaderW17__Strongly agree                                         0.004681
#  dtype: float32,
#  'D10_17immigSelf_with_deltas_and_intermediates': D10_17immigCon__Allow many more                      0.130552
#  D10_17euPriorityBalance__Control immigration         0.102178
#  D10_17changeImmig__Getting a lot higher              0.090792
#  D10_17happyEULeave__Extremely happy                  0.048354
#  immigConW17__Allow many more                         0.042322
#  D10_17overseasAid__Strongly agree                    0.038467
#  immigUKIPW10__Allow many more                        0.037906
#  D10_17europeanness__Very strongly European           0.033585
#  euPriorityBalanceW17__Control immigration            0.033222
#  D10_17EUIntegrationSelf__Protect our independence    0.031787
#  D10_15ukCoopMovement__Bad for Britain                0.027951
#  natSecuritySelfW10__Protect civil liberties          0.025487
#  D10_17immigGreen__Allow many more                    0.018635
#  D12_17euPriorityBalance__Control immigration         0.018075
#  D11_17effectsEUImmigration__Much higher              0.017818
#  D11_17euPriorityBalance__Control immigration         0.017530
#  approveEUW10__Strongly approve                       0.017124
#  immigBrexitW17__Allow many more                      0.016726
#  ukCoopMovementW10__Bad for Britain                   0.016434
#  immigrantsWelfareStateW10__Strongly agree            0.016245
#  likeMayW10__Strongly like                            0.013623
#  likeConW12__Strongly like                            0.012027
#  D10_15changeImmig__Getting a lot higher              0.011473
#  changeImmigW17__Getting a lot higher                 0.011013
#  immigLabW10__Allow many more                         0.010906
#  trustCourtsW17__10.0                                 0.010242
#  EUIntegrationSelfW10__Protect our independence       0.010235
#  D10_17effectsEUImmigration__Much higher              0.010086
#  D10_17immigLab__Allow many more                      0.009985
#  blackEqualityW17__Gone much too far                  0.009358
#  satDemEUW10__Very satisfied                          0.008613
#  ptvConW10__Very likely                               0.007686
#  effectsEUImmigrationW17__Much higher                 0.007570
#  euPriorityBalanceW15__Control immigration            0.007174
#  D10_16euPriorityBalance__Control immigration         0.006839
#  D10_17immigLD__Allow many more                       0.006692
#  euMoreW13__Many more                                 0.005969
#  D10_12euPriorityBalance__Control immigration         0.005631
#  D10_17EUIntegrationCon__Protect our independence     0.005344
#  immigConW10__Allow many more                         0.005343
#  overseasAidW10__Strongly agree                       0.005020
#  D10_15euPriorityBalance__Control immigration         0.005017
#  D12_16euPriorityBalance__Control immigration         0.004848
#  EUIntegrationUKIPW10__Protect our independence       0.004778
#  D10_17effectsEUTerror__Much higher                   0.004388
#  D10_14euPriorityBalance__Control immigration         0.004046
#  populism1W10__Strongly agree                         0.004018
#  D11_17likeSNP__Strongly like                         0.003976
#  D11_17changeImmig__Getting a lot higher              0.003713
#  ptvConW17__Very likely                               0.003648
#  dtype: float32,
#  'D1_7immigEcon_with_deltas': D1_7immigrantsWelfareState__Strongly agree                      0.169651
#  euMoreW7__Many more                                             0.049725
#  changeImmigW1__Getting a lot higher                             0.043230
#  ukCoopMovementW7__Bad for Britain                               0.042287
#  immigrantsWelfareStateW1__Strongly agree                        0.041959
#  D1_7changeImmig__Getting a lot higher                           0.031319
#  immigrantsWelfareStateW7__Strongly agree                        0.021431
#  changeImmigLabW1__Getting a lot higher                          0.016269
#  D1_7trustMPs__A great deal of trust                             0.015615
#  familiesMoreW7__Many more                                       0.015501
#  immigContributeTakeW7__Get more than they pay                   0.014945
#  asylumMoreW7__Many more                                         0.014911
#  D1_7euRefVote_Leave the EU                                      0.009478
#  likeMilibandW1__Strongly like                                   0.009229
#  D1_7mii_cat_immigration                                         0.008681
#  euUKRichW7__Strongly agree                                      0.007911
#  D1_7small_mii_cat_Immigration                                   0.007056
#  euCloserW7__Strongly agree                                      0.006822
#  euRefVoteUnsqueezeW7_Leave the EU                               0.005991
#  blairGoodW1_Good for Britain                                    0.005873
#  D1_7satDemEU__Very satisfied                                    0.004784
#  mii_catW1_economy-general                                       0.004723
#  blackEqualityW1W2W3W4W5__Gone much too far                      0.004286
#  al_scaleW1W2W3W4W5__Authoritarian                               0.003967
#  changeImmigW7__Getting a lot higher                             0.003920
#  eesEUIntegrationSelfW1__Unification should be pushed further    0.003811
#  mii_catW1_immigration                                           0.003802
#  generalElectionVoteW1_Labour                                    0.003802
#  effectsEUEconW7__Much better                                    0.003465
#  turnoutUKGeneralW1__Very likely that I will vote                0.003363
#  studentsMoreW7__Many more                                       0.003317
#  D1_7likeCameron__Strongly like                                  0.003287
#  polAttentionW1__Pay a great deal of attention                   0.003034
#  D1_7polAttention__Pay a great deal of attention                 0.002750
#  euRefVoteW7_Leave the EU                                        0.002730
#  infoSourcePaperW7__More than 2 hours                            0.002670
#  euRefVoteW1_Leave the EU                                        0.002621
#  noneuMoreW7__Many more                                          0.002581
#  lrUKIPW16__Right                                                0.002545
#  likeCameronW7__Strongly like                                    0.002378
#  approveEUW7__Strongly approve                                   0.002316
#  euLawsLevelW7__Strongly agree                                   0.002273
#  immigrantsWelfareStateW10__Strongly agree                       0.002240
#  changeEconomyLabW1__Getting a lot better                        0.002219
#  likeUKIPW18__Strongly like                                      0.002178
#  effectsEUImmigrationW7__Much higher                             0.002170
#  ukCoopTradeW7__Bad for Britain                                  0.002168
#  lrLabW7__Right                                                  0.002108
#  happyEULeaveW14__Extremely happy                                0.002050
#  eesEUIntegrationUKIPW1__Unification should be pushed further    0.002000
#  dtype: float32,
#  'D1_7immigCultural_with_deltas': D1_7immigrantsWelfareState__Strongly agree              0.125084
#  asylumMoreW7__Many more                                 0.054969
#  immigrantsWelfareStateW1__Strongly agree                0.053135
#  D1_7changeImmig__Getting a lot higher                   0.036103
#  ukCoopMovementW7__Bad for Britain                       0.030203
#  changeImmigW1__Getting a lot higher                     0.029409
#  euMoreW7__Many more                                     0.022366
#  blackEqualityW1W2W3W4W5__Gone much too far              0.020830
#  familiesMoreW7__Many more                               0.013055
#  changeImmigLabW1__Getting a lot higher                  0.012389
#  approveEUW7__Strongly approve                           0.009062
#  immigrantsWelfareStateW7__Strongly agree                0.008998
#  noneuMoreW7__Many more                                  0.007988
#  D1_7satDemEU__Very satisfied                            0.007275
#  LRAL_mii_catW1_Lib-auth                                 0.007161
#  D1_7euRefVote_Leave the EU                              0.006145
#  lr1W1W2W3W4W5__Strongly agree                           0.005898
#  changeImmigW7__Getting a lot higher                     0.005771
#  euCloserW7__Strongly agree                              0.005436
#  changeEconomyLabW1__Getting a lot better                0.005423
#  EUIntegrationSelfW1__Protect our independence           0.005237
#  D1_7trustMPs__A great deal of trust                     0.005185
#  D1_7likeLab__Strongly like                              0.004981
#  EUIntegrationSelfW7__Protect our independence           0.004933
#  bestOnMIIW1_Labour                                      0.004773
#  D1_7EUIntegrationSelf__Protect our independence         0.004546
#  euRefVoteW1_Leave the EU                                0.004507
#  changeCostLiveLabW1__Getting a lot higher               0.004477
#  ptvGrnW7__Very likely                                   0.004319
#  D1_7likeGrn__Strongly like                              0.004164
#  happyEULeaveW14__Extremely happy                        0.003815
#  socialIdentityGlobalRemainW7__A great deal in common    0.003761
#  studentsMoreW7__Many more                               0.003500
#  changeNHSLabW1__Getting a lot better                    0.003174
#  changeEducationLabW1__Getting a lot better              0.003088
#  small_mii_catW1_Immigration                             0.002990
#  al2W1W2W3W4W5__Strongly agree                           0.002876
#  winConstituencyConW12__100 - Very likely to win         0.002699
#  ptvLabW1__Very likely                                   0.002660
#  mii_catW1_immigration                                   0.002558
#  D1_7LRAL_mii_cat_Left-right                             0.002509
#  ethno5W7__Strongly agree                                0.002325
#  LRAL_mii_catW1_Left-right                               0.002324
#  likeMayW11__Strongly like                               0.002282
#  partyIdStrengthW10__Not very strong                     0.002234
#  likeAlanJohnsonW7__Strongly like                        0.002191
#  ukCoopTradeW7__Bad for Britain                          0.002185
#  changeImmigW11__Getting a lot higher                    0.002176
#  D1_7EUIntegrationCon__Protect our independence          0.002063
#  achieveReduceImmigConW7_Yes                             0.002048
#  dtype: float32,
#  'D7_8immigEcon_with_deltas': D7_8immigrantsWelfareState__Strongly agree                               0.061379
#  D7_8euMore__Many more                                                    0.037285
#  D7_8ukCoopMovement__Bad for Britain                                      0.027814
#  D7_8immigContributeTake__Get more than they pay                          0.026543
#  immigrantsWelfareStateW7__Strongly agree                                 0.022944
#  D7_8noneuMore__Many more                                                 0.021128
#  D7_8familiesMore__Many more                                              0.015920
#  D7_8asylumMore__Many more                                                0.010442
#  D7_8studentsMore__Many more                                              0.009052
#  changeImmigW7__Getting a lot higher                                      0.008390
#  immigContributeTakeW7__Get more than they pay                            0.008066
#  D7_8changeImmig__Getting a lot higher                                    0.008020
#  D7_8euUKRich__Strongly agree                                             0.007914
#  D7_8europeanness__Very strongly European                                 0.007464
#  D7_8trustMPs__A great deal of trust                                      0.007272
#  D7_8effectsEUImmigration__Much higher                                    0.006801
#  euDominanceW8__Many more powers                                          0.005511
#  euMoreW8__Many more                                                      0.005361
#  debateTwoWatchW8_Yes                                                     0.005344
#  mii_catW7_immigration                                                    0.004544
#  immigrantsWelfareStateW8__Strongly agree                                 0.004218
#  small_mii_catW7_Immigration                                              0.004172
#  D7_8turkey__Much better                                                  0.004051
#  euUKRichW8__Strongly agree                                               0.003632
#  D7_8likeLab__Strongly like                                               0.003572
#  likeAlanJohnsonW7__Strongly like                                         0.003379
#  familiesMoreW7__Many more                                                0.003350
#  asylumMoreW7__Many more                                                  0.003056
#  D7_8leaveTone__5 - Hope                                                  0.002923
#  ukCoopMovementW7__Bad for Britain                                        0.002794
#  D7_8euParlOverRide__Strongly agree                                       0.002461
#  D7_8effectsEUEcon__Much better                                           0.002403
#  proConRemainW8__7- Upsides of remaining                                  0.002371
#  D7_8socialIdentityGlobalRemain__A great deal in common                   0.002358
#  effectsEUEconW8__Much better                                             0.002346
#  D7_8benefitsToMigrants__Never                                            0.002284
#  likeOsborneW8__Strongly like                                             0.002150
#  discussPolDaysW8__7 days                                                 0.002135
#  campaigninfoRemainW8__Strongly agree                                     0.002124
#  D7_8effectsEUUnemployment__Much higher                                   0.002122
#  trustMPsW7__A great deal of trust                                        0.002033
#  euFinancialHelpW7__Strongly agree                                        0.002005
#  expectGoodConductEURefW7__Conducted unfairly                             0.001955
#  govtHandoutsW7__Strongly agree                                           0.001837
#  effectsEUFinanceW8__Much better                                          0.001837
#  noneuMoreW8__Many more                                                   0.001799
#  ptvGrnW7__Very likely                                                    0.001753
#  benefitsToMigrantsW8__Never                                              0.001721
#  effectsEUUnemploymentW8__Much higher                                     0.001701
#  redistUKIPW7__Government should be less concerned about equal incomes    0.001694
#  dtype: float32,
#  'D8_10immigEcon_with_deltas': D8_10immigrantsWelfareState__Strongly agree                               0.099848
#  D8_10ukCoopMovement__Bad for Britain                                      0.079443
#  ukCoopMovementW10__Bad for Britain                                        0.043690
#  immigrantsWelfareStateW8__Strongly agree                                  0.035443
#  D8_10changeImmig__Getting a lot higher                                    0.032594
#  euMoreW8__Many more                                                       0.031884
#  noneuMoreW8__Many more                                                    0.022891
#  immigContributeTakeW8__Get more than they pay                             0.021782
#  euPriorityBalanceW10__Control immigration                                 0.018849
#  D8_10effectsEUImmigration__Much higher                                    0.016330
#  asylumMoreW8__Many more                                                   0.015296
#  D8_10EUIntegrationSelf__Protect our independence                          0.015281
#  D8_10europeanness__Very strongly European                                 0.013979
#  D8_10small_mii_cat_Immigration                                            0.007741
#  immigrantsWelfareStateW10__Strongly agree                                 0.005999
#  D8_10effectsEUNHS__Much better                                            0.005692
#  D8_10mii_cat_immigration                                                  0.005689
#  studentsMoreW8__Many more                                                 0.005625
#  likeBorisW8__Strongly like                                                0.005396
#  changeImmigW10__Getting a lot higher                                      0.004915
#  lrConW10__Right                                                           0.004912
#  discussPolDaysW8__7 days                                                  0.004897
#  debateTwoWatchW8_Yes                                                      0.004474
#  euLawsLevelW8__Strongly agree                                             0.004322
#  immigUKIPW8__Allow many more                                              0.003749
#  D8_10effectsEUEcon__Much better                                           0.003692
#  D8_10leaveImpactBritain__A very large impact                              0.003443
#  D8_10effectsEUWorkers__Much better                                        0.003395
#  germanyFairShareW8__Much more than its fair share                         0.003378
#  D8_10effectsEUUnemployment__Much higher                                   0.003310
#  changeImmigW8__Getting a lot higher                                       0.003115
#  bestOnMIIW10_United Kingdom Independence Party (UKIP)                     0.003108
#  trustMPsW10__A great deal of trust                                        0.003019
#  riskPovertyW10__Very likely                                               0.002863
#  likeConW10__Strongly like                                                 0.002765
#  satDemEUW8__Very satisfied                                                0.002728
#  D8_10socialIdentityGlobalRemain__A great deal in common                   0.002725
#  al1W7W8W9__Strongly agree                                                 0.002679
#  efficacyPolCareW10__Strongly agree                                        0.002658
#  benefitsToMigrantsW8__Never                                               0.002644
#  generalElectionVoteW10_United Kingdom Independence Party (UKIP)           0.002432
#  D8_10polAttention__Pay a great deal of attention                          0.002405
#  redistUKIPW10__Government should be less concerned about equal incomes    0.002329
#  euCloserW8__Strongly agree                                                0.002312
#  socialIdentityGlobalLeaveW10__A great deal in common                      0.002294
#  euUKRichW8__Strongly agree                                                0.002291
#  EUIntegrationLDW10__Protect our independence                              0.002199
#  changeEconomyLabW10__Getting a lot better                                 0.002172
#  europeannessW10__Very strongly European                                   0.002138
#  D8_10ukCoopTrade__Bad for Britain                                         0.002130
#  dtype: float32,
#  'D10_17immigEcon_with_deltas': ukCoopMovementW10__Bad for Britain                                         0.089443
#  immigrantsWelfareStateW10__Strongly agree                                  0.055894
#  D10_17euPriorityBalance__Control immigration                               0.043938
#  D10_17changeImmig__Getting a lot higher                                    0.043833
#  blackEqualityW17__Gone much too far                                        0.025884
#  D10_17europeanness__Very strongly European                                 0.024566
#  D10_17overseasAid__Strongly agree                                          0.021687
#  natSecuritySelfW10__Protect civil liberties                                0.016450
#  changeImmigW17__Getting a lot higher                                       0.015396
#  euPriorityBalanceW10__Control immigration                                  0.012459
#  D10_17EUIntegrationSelf__Protect our independence                          0.011900
#  euPriorityBalanceW17__Control immigration                                  0.011648
#  D10_17euLeaveVoice__Much higher                                            0.011126
#  immigGreenW17__Allow many more                                             0.009603
#  al5W10W11W12__Strongly agree                                               0.009409
#  ptvUKIPW17__Very likely                                                    0.008509
#  al_scaleW10W11W12__Authoritarian                                           0.008430
#  D10_17immigCon__Allow many more                                            0.007914
#  D10_17effectsEUWorkers__Much better                                        0.007440
#  D10_17effectsEUNHS__Much better                                            0.007420
#  D10_17euLeaveBigBusiness__Much more likely                                 0.007344
#  likeUKIPW17__Strongly like                                                 0.006742
#  trustCourtsW17__10.0                                                       0.005540
#  D10_17euRefDoOver_Yes                                                      0.005436
#  euID6W10__Strongly agree                                                   0.005380
#  immigConW17__Allow many more                                               0.005300
#  D10_17ptvUKIP__Very likely                                                 0.005264
#  britishnessW10__Very strongly British                                      0.005256
#  EUIntegrationSelfW10__Protect our independence                             0.005033
#  D10_17likeGrn__Strongly like                                               0.004943
#  gayEqualityW17__Gone much too far                                          0.004819
# ...
#  D7_8tot_nino             0.002170
#  nonEU_regW7_nino         0.002042
#  dEUpostrefW17_nino       0.001982
#  D1_7asia_nino            0.001961
#  dEU_regW17_nino          0.001897
#  asiaW8_nino              0.001886
#  EUprefreW7_nino          0.001881
#  dtype: float32,
#  'D7_8immigCultural_with_full_nino_and_bes': D7_8immigrantsWelfareState__Strongly agree                             0.034727
#  D7_8euMore__Many more                                                  0.031635
#  D7_8asylumMore__Many more                                              0.028529
#  D7_8familiesMore__Many more                                            0.022821
#  D7_8noneuMore__Many more                                               0.022446
#  euCloserW8__Strongly agree                                             0.013183
#  D7_8immigContributeTake__Get more than they pay                        0.011798
#  D7_8euCloser__Strongly agree                                           0.011279
#  D7_8ukCoopMovement__Bad for Britain                                    0.009154
#  D7_8infoSourcePeople__More than 2 hours                                0.008688
#  immigrantsWelfareStateW7__Strongly agree                               0.006849
#  likeOsborneW8__Strongly like                                           0.006676
#  ptvGrnW7__Very likely                                                  0.006163
#  D7_8europeanness__Very strongly European                               0.005665
#  D7_8studentsMore__Many more                                            0.005158
#  familiesMoreW8__Many more                                              0.004854
#  D7_8trustMPs__A great deal of trust                                    0.004748
#  asylumMoreW7__Many more                                                0.004535
#  D7_8turkey__Much better                                                0.003721
#  approveEUW7__Strongly approve                                          0.003690
#  govtHandoutsW7__Strongly agree                                         0.003679
#  D7_8immigUKIP__Allow many more                                         0.003554
#  euMoreW8__Many more                                                    0.003495
#  D7_8changeImmig__Getting a lot higher                                  0.003409
#  D7_8euLawsLevel__Strongly agree                                        0.003297
#  trustMPsW8__A great deal of trust                                      0.003032
#  D7_8benefitsToMigrants__Never                                          0.003021
#  D7_8socialIdentityGlobalRemain__A great deal in common                 0.003017
#  immigUKIPW7__Allow many more                                           0.002884
#  certaintyUKLeaveW8__Very sure                                          0.002700
#  euRefExpectationW8__100 - UK will definitely vote to leave the EU      0.002517
#  D7_8satDemEU__Very satisfied                                           0.002497
#  ukCoopTradeW8__Bad for Britain                                         0.002451
#  D7_8normEU__Strongly agree                                             0.002389
#  D7_8euUndermineIdentity__Strongly agree                                0.002366
#  D7_8euSources_3_Yes                                                    0.002297
#  proConRemainW8__7- Upsides of remaining                                0.002272
#  euRefExpectationW7__100 - UK will definitely vote to leave the EU      0.002259
#  satDemEUW8__Very satisfied                                             0.002167
#  debateTwoWatchW8_Yes                                                   0.002053
#  immigContributeTakeW7__Get more than they pay                          0.002018
#  D7_8UKsovereignty__Strongly agree                                      0.002017
#  D7_8euRefExpectation__100 - UK will definitely vote to leave the EU    0.002002
#  D7_8immigLab__Allow many more                                          0.001948
#  lrUKIPW8__Right                                                        0.001904
#  euSources_1W8_Yes                                                      0.001862
#  lrConW7__Right                                                         0.001859
#  noneuMoreW7__Many more                                                 0.001783
#  al_scaleW7W8W9__Authoritarian                                          0.001779
#  immigrantsWelfareStateW8__Strongly agree                               0.001770
#  dtype: float32,
#  'D7_8immigSelf_with_ONS_data_alone': immigECSW8__Good                                                                                                                                                                                                             0.646640
#  immigECW8__Good for Econ&Cult                                                                                                                                                                                                0.549216
#  D8_10immigECS                                                                                                                                                                                                                0.210593
#  D8_10immigEC                                                                                                                                                                                                                 0.097306
#  W8Passports held by sex by age:Females|Age 65 and over|Africa: Central and Western Africa                                                                                                                                    0.006822
#  W8Communal establishment management and type:Total|Other establishment: Education.1                                                                                                                                          0.006342
#  W8Communal establishment management and type:Other establishment: Education.1                                                                                                                                                0.003451
#  W8Accommodation type by car or van availability by number of usual residents aged 17 or over in household:Whole house or bungalow|1 car or van in household|No usual residents aged 17 or over in household                  0.003268
#  W8Marital and civil partnership status by sex by age:Males|Age 24 and under|Separated (but still legally married or still legally in a same-sex civil partnership)                                                           0.002991
#  W8Ethnic group by sex by age:All persons|Age 65 and over|Other ethnic group: Arab                                                                                                                                            0.002806
#  W8Communal establishment management and type:Other establishment: Approved premises (probation/bail hostel)                                                                                                                  0.002787
#  W8National identity by ethnic group:Scottish and British only identity|White: Irish                                                                                                                                          0.002764
#  W8Tenure by car or van availability by ethnic group of Household Reference Person (HRP):Rented: Social rented|2 or more cars or vans in household|All categories: Ethnic group of HRP                                        0.002218
#  W8Economic activity by provision of unpaid care by general health:Economically inactive: Looking after home or family|Provides 1 to 19 hours unpaid care a week|All categories: General health                               0.002133
#  W8Country of birth by sex by age:Males|Age 35 to 49|Europe: United Kingdom: United Kingdom not otherwise specified                                                                                                           0.002098
#  W8Economic activity by provision of unpaid care by general health:Economically active: Unemployed: Full-time students|Provides 50 or more hours unpaid care a week|Fair health                                               0.002082
#  W8Tenure by household composition:Owned: Owned with a mortgage or loan or shared ownership|One family only: Married or same-sex civil partnership couple: Dependent children                                                 0.001994
#  W8Passports held by year of arrival in the UK:Middle East and Asia: Total|Arrived before 1961                                                                                                                                0.001980
#  W8Tenure by number of persons per room in household by accommodation type:Rented: Social rented|Over 1.5 persons per room|All categories: Accommodation type                                                                 0.001969
#  W8Accommodation type by type of central heating in household by tenure:Whole house or bungalow: Semi-detached|Does have central heating|Rented: Social rented                                                                0.001916
#  W8Industry by religion:C Manufacturing|Sikh                                                                                                                                                                                  0.001889
#  W8Country of birth by ethnic group:The Americas and the Caribbean: North America and the Caribbean|Asian/Asian British                                                                                                       0.001877
#  W8General health by religion by sex by age:All persons|Age 16 to 49|Fair health|Religion not stated                                                                                                                          0.001847
#  W8Household lifestage:Total|Age of HRP 35 to 54: Two or more person household: With dependent children                                                                                                                       0.001836
#  W8Marital and civil partnership status by sex by age:Males|All categories: Age|Widowed or surviving partner from a same-sex civil partnership                                                                                0.001784
#  W8Provision of unpaid care by general health by sex by age:Males|Age 0 to 24|Provides 50 or more hours unpaid care a week|Bad or very bad health                                                                             0.001772
#  W8General health by ethnic group by sex by age:Females|Age 0 to 15|Bad or very bad health|Mixed/multiple ethnic group                                                                                                        0.001768
#  W8Tenure by number of persons per room in household by accommodation type:Owned: Owned with a mortgage or loan or shared ownership|Over 1.0 and up to 1.5 persons per room|Whole house or bungalow: Detached                 0.001761
#  W8Ethnic group by age of arrival in the UK:White: Irish|Age of arrival in the UK: 65 and over                                                                                                                                0.001756
#  W8Economic activity by country of birth by age:Age 16 to 49|Economically inactive: Retired|Europe: Other Europe: Rest of Europe                                                                                              0.001744
#  W8Country of birth:Europe: Guernsey                                                                                                                                                                                          0.001744
#  W8Accommodation type by car or van availability by number of usual residents aged 17 or over in household:Whole house or bungalow|All categories: Car or van availability|No usual residents aged 17 or over in household    0.001697
#  W8Long-term health problem or disability by car or van availability by age:Age 50 to 64|1 car or van in household|Day-to-day activities limited a little                                                                     0.001641
#  W8General health by religion by sex by age:All persons|Age 65 and over|Fair health|Sikh                                                                                                                                      0.001639
#  W8Occupancy rating (rooms) by household composition:Occupancy rating (rooms) of -1 or less|One family only: All aged 65 and over                                                                                             0.001589
#  W8Student accommodation by age:Living in a communal establishment: Total|Age 18 to 19                                                                                                                                        0.001556
#  W8Country of birth (detailed):Total|Africa: Africa not otherwise specified                                                                                                                                                   0.001541
#  W8Passports held by country of birth:Europe: Other Europe: EU countries: Total|Africa: North Africa                                                                                                                          0.001533
#  W8Tenure by number of persons per room in household by accommodation type:Rented: Social rented|Over 1.0 and up to 1.5 persons per room|Whole house or bungalow: Terraced (including end-terrace)                            0.001500
#  W8Residence type by sex by age:Age 20 to 24|Lives in a communal establishment|All persons                                                                                                                                    0.001489
#  W8Religion of dependent child by sex:Sikh|Females                                                                                                                                                                            0.001459
#  W8Passports held (detailed):Middle East and Asia: Southern Asia: Afghanistan                                                                                                                                                 0.001456
#  W8Provision of unpaid care by general health by sex by age:Males|All categories: Age|Provides unpaid care: Total|Very good or good health                                                                                    0.001450
#  W8Living arrangements by sex by age:All categories: Age 16 and over|Males|Not living in a couple: Widowed or surviving partner from a same-sex civil partnership                                                             0.001434
#  W8Tenure by car or van availability by number of usual residents aged 17 or over in household:All categories: Tenure|All categories: Car or van availability|No usual residents aged 17 or over in household                 0.001433
#  W8Passports held by country of birth:Europe: Ireland|Middle East and Asia: Middle East                                                                                                                                       0.001405
#  W8Tenure by number of persons per room in household by accommodation type:Rented: Private rented or living rent free|Up to 0.5 persons per room|Whole house or bungalow: Terraced (including end-terrace)                    0.001376
#  W8Industry by religion:A, B, D, E Agriculture, energy and water|Sikh                                                                                                                                                         0.001357
#  W8General health by religion by sex by age:Females|Age 16 to 49|Very good or good health|Jewish                                                                                                                              0.001325
#  W8Communal establishment residents:Total|Medical and care establishment: NHS: Mental health hospital/unit (including secure units)                                                                                           0.001305
#  dtype: float32}

# %%
np.unique( flatten([treatment_dict[x].index for x in treatment_dict.keys()]) )
# Out:
# array(['D10_11immigrantsWelfareState__Strongly agree',
#        'D10_12euPriorityBalance__Control immigration',
#        'D10_14euPriorityBalance__Control immigration',
#        'D10_15changeImmig__Getting a lot higher',
#        'D10_15euPriorityBalance__Control immigration',
#        'D10_15ukCoopMovement__Bad for Britain',
#        'D10_16euPriorityBalance__Control immigration',
#        'D10_17EUIntegrationCon__Protect our independence',
#        'D10_17EUIntegrationSelf__Protect our independence',
#        'D10_17antiIntellectual__Strongly agree',
#        'D10_17changeEconomyLab__Getting a lot better',
#        'D10_17changeImmig__Getting a lot higher',
#        'D10_17effectsEUImmigration__Much higher',
#        'D10_17effectsEUNHS__Much better',
#        'D10_17effectsEUTerror__Much higher',
#        'D10_17effectsEUWorkers__Much better',
#        'D10_17euLeaveBigBusiness__Much more likely',
#        'D10_17euLeaveScotIndep__Much more likely',
#        'D10_17euLeaveVoice__Much higher',
#        'D10_17euPriorityBalance__Control immigration',
#        'D10_17euRefDoOver_Yes',
#        'D10_17europeanness__Very strongly European',
#        'D10_17happyEULeave__Extremely happy',
#        'D10_17immigCon__Allow many more',
#        'D10_17immigGreen__Allow many more',
#        'D10_17immigLD__Allow many more',
#        'D10_17immigLab__Allow many more', 'D10_17leftRight__Right',
#        'D10_17likeCorbyn__Strongly like', 'D10_17likeGrn__Strongly like',
#        'D10_17likeLab__Strongly like', 'D10_17lrCon__Right',
#        'D10_17overseasAid__Strongly agree', 'D10_17ptvCon__Very likely',
#        'D10_17ptvGrn__Very likely', 'D10_17ptvUKIP__Very likely',
#        'D11_17changeImmig__Getting a lot higher',
#        'D11_17effectsEUImmigration__Much higher',
#        'D11_17euPriorityBalance__Control immigration',
#        'D11_17likeSNP__Strongly like',
#        'D12_16euPriorityBalance__Control immigration',
#        'D12_17euPriorityBalance__Control immigration',
#        'D1_7EUIntegrationCon__Protect our independence',
#        'D1_7EUIntegrationSelf__Protect our independence',
#        'D1_7LRAL_mii_cat_Left-right', 'D1_7asia_nino',
#        'D1_7changeImmig__Getting a lot higher', 'D1_7dnonEU_reg_nino',
#        'D1_7euRefVote_Leave the EU',
#        'D1_7immigrantsWelfareState__Strongly agree',
#        'D1_7likeCameron__Strongly like', 'D1_7likeGrn__Strongly like',
#        'D1_7likeLab__Strongly like', 'D1_7mii_cat_immigration',
#        'D1_7other_europe_nino',
#        'D1_7polAttention__Pay a great deal of attention',
#        'D1_7satDemEU__Very satisfied', 'D1_7small_mii_cat_Immigration',
#        'D1_7total_nino', 'D1_7trustMPs__A great deal of trust',
#        'D7_8EUIntegrationSelf__Protect our independence',
#        'D7_8EU_reg_nino', 'D7_8UKsovereignty__Strongly agree',
#        'D7_8asia_nino', 'D7_8asylumMore__Many more',
#        'D7_8benefitsToMigrants__Never',
#        'D7_8changeImmig__Getting a lot higher',
#        'D7_8childBenefitsRepatriate__No, not at any level',
#        'D7_8dnonEU_reg_nino', 'D7_8effectsEUEcon__Much better',
#        'D7_8effectsEUImmigration__Much higher',
#        'D7_8effectsEUUnemployment__Much higher',
#        'D7_8euCloser__Strongly agree', 'D7_8euLawsLevel__Strongly agree',
#        'D7_8euMore__Many more', 'D7_8euParlOverRide__Strongly agree',
#        'D7_8euRefExpectation__100 - UK will definitely vote to leave the EU',
#        'D7_8euSources_3_Yes', 'D7_8euUKRich__Strongly agree',
#        'D7_8euUndermineIdentity__Strongly agree',
#        'D7_8europeanness__Very strongly European',
#        'D7_8familiesMore__Many more', 'D7_8immigCon__Allow many more',
#        'D7_8immigContributeTake__Get more than they pay',
#        'D7_8immigGreen__Allow many more', 'D7_8immigLD__Allow many more',
#        'D7_8immigLab__Allow many more', 'D7_8immigUKIP__Allow many more',
#        'D7_8immigrantsWelfareState__Strongly agree',
#        'D7_8infoSourcePeople__More than 2 hours',
#        'D7_8leaveTone__5 - Hope', 'D7_8likeLab__Strongly like',
#        'D7_8nonEU_reg_nino', 'D7_8noneuMore__Many more',
#        'D7_8normEU__Strongly agree',
#        'D7_8polAttention__Pay a great deal of attention',
#        'D7_8rest_world_nino', 'D7_8satDemEU__Very satisfied',
#        'D7_8socialIdentityGlobalRemain__A great deal in common',
#        'D7_8studentsMore__Many more', 'D7_8tot_nino', 'D7_8total_nino',
#        'D7_8trustMPs__A great deal of trust', 'D7_8turkey__Much better',
#        'D7_8ukCoopMovement__Bad for Britain',
#        'D8_10EUIntegrationSelf__Protect our independence',
#        'D8_10changeImmig__Getting a lot higher',
#        'D8_10effectsEUEcon__Much better',
#        'D8_10effectsEUImmigration__Much higher',
#        'D8_10effectsEUNHS__Much better',
#        'D8_10effectsEUUnemployment__Much higher',
#        'D8_10effectsEUWorkers__Much better',
#        'D8_10euLeaveBigBusiness__Much more likely',
#        'D8_10europeanness__Very strongly European', 'D8_10immigEC',
#        'D8_10immigECS', 'D8_10immigGreen__Allow many more',
#        'D8_10immigSelf__Allow many more',
#        'D8_10immigUKIP__Allow many more',
#        'D8_10immigrantsWelfareState__Strongly agree',
#        'D8_10leaveImpactBritain__A very large impact',
#        'D8_10likeUKIP__Strongly like', 'D8_10mii_cat_immigration',
#        'D8_10polAttention__Pay a great deal of attention',
#        'D8_10satDemEU__Very satisfied', 'D8_10small_mii_cat_Immigration',
#        'D8_10socialIdentityGlobalRemain__A great deal in common',
#        'D8_10trustMPs__A great deal of trust',
#        'D8_10ukCoopMovement__Bad for Britain',
#        'D8_10ukCoopTrade__Bad for Britain',
#        'D8_9EUIntegrationSelf__Protect our independence',
#        'D8_9bestOnMII_Conservative',
#        'D8_9bestOnMII_No party is best able to handle this issue',
#        'D8_9europeanness__Very strongly European',
#        'D8_9immigCon__Allow many more', 'D8_9immigGreen__Allow many more',
#        'D8_9immigLD__Allow many more', 'D8_9immigLab__Allow many more',
#        'D8_9immigSNP__Allow many more', 'D8_9immigUKIP__Allow many more',
#        'D8_9likeBoris__Strongly like', 'D8_9likeFarage__Strongly like',
#        'D8_9likeGove__Strongly like', 'D8_9likeLab__Strongly like',
#        'D8_9likeUKIP__Strongly like', 'D8_9satDemEU__Very satisfied',
#        'D8_9socialIdentityGlobalLeave__A great deal in common',
#        'D8_9socialIdentityGlobalRemain__A great deal in common',
#        'D9_10bestOnMII_United Kingdom Independence Party (UKIP)',
#        'D9_10euID4__Strongly agree', 'D9_10immigSelf__Allow many more',
#        'D9_10ptvLD__Very likely', 'D9_10trustMPs__A great deal of trust',
#        'EUIntegrationConW17__Protect our independence',
#        'EUIntegrationConW8__Protect our independence',
#        'EUIntegrationConW9__Protect our independence',
#        'EUIntegrationLDW10__Protect our independence',
#        'EUIntegrationLabW8__Protect our independence',
#        'EUIntegrationSelfW10__Protect our independence',
#        'EUIntegrationSelfW15__Protect our independence',
#        'EUIntegrationSelfW16__Protect our independence',
#        'EUIntegrationSelfW1__Protect our independence',
#        'EUIntegrationSelfW7__Protect our independence',
#        'EUIntegrationSelfW8__Protect our independence',
#        'EUIntegrationSelfW9__Protect our independence',
#        'EUIntegrationUKIPW10__Protect our independence', 'EU_regW10_nino',
#        'EU_regW17_nino', 'EU_regW8_nino', 'EUprefreW7_nino',
#        'LRAL_mii_catW1_Left-right', 'LRAL_mii_catW1_Lib-auth',
#        'W8Accommodation type by car or van availability by number of usual residents aged 17 or over in household:Whole house or bungalow|1 car or van in household|No usual residents aged 17 or over in household',
#        'W8Accommodation type by car or van availability by number of usual residents aged 17 or over in household:Whole house or bungalow|All categories: Car or van availability|No usual residents aged 17 or over in household',
#        'W8Accommodation type by type of central heating in household by tenure:Whole house or bungalow: Semi-detached|Does have central heating|Rented: Social rented',
#        'W8Communal establishment management and type:Other establishment: Approved premises (probation/bail hostel)',
#        'W8Communal establishment management and type:Other establishment: Education.1',
#        'W8Communal establishment management and type:Total|Other establishment: Education.1',
#        'W8Communal establishment residents:Total|Medical and care establishment: NHS: Mental health hospital/unit (including secure units)',
#        'W8Country of birth (detailed):Total|Africa: Africa not otherwise specified',
#        'W8Country of birth by ethnic group:The Americas and the Caribbean: North America and the Caribbean|Asian/Asian British',
#        'W8Country of birth by sex by age:Males|Age 35 to 49|Europe: United Kingdom: United Kingdom not otherwise specified',
#        'W8Country of birth:Europe: Guernsey',
#        'W8Economic activity by country of birth by age:Age 16 to 49|Economically inactive: Retired|Europe: Other Europe: Rest of Europe',
#        'W8Economic activity by provision of unpaid care by general health:Economically active: Unemployed: Full-time students|Provides 50 or more hours unpaid care a week|Fair health',
#        'W8Economic activity by provision of unpaid care by general health:Economically inactive: Looking after home or family|Provides 1 to 19 hours unpaid care a week|All categories: General health',
#        'W8Ethnic group by age of arrival in the UK:White: Irish|Age of arrival in the UK: 65 and over',
#        'W8Ethnic group by sex by age:All persons|Age 65 and over|Other ethnic group: Arab',
#        'W8General health by ethnic group by sex by age:Females|Age 0 to 15|Bad or very bad health|Mixed/multiple ethnic group',
#        'W8General health by religion by sex by age:All persons|Age 16 to 49|Fair health|Religion not stated',
#        'W8General health by religion by sex by age:All persons|Age 65 and over|Fair health|Sikh',
#        'W8General health by religion by sex by age:Females|Age 16 to 49|Very good or good health|Jewish',
#        'W8Household lifestage:Total|Age of HRP 35 to 54: Two or more person household: With dependent children',
#        'W8Industry by religion:A, B, D, E Agriculture, energy and water|Sikh',
#        'W8Industry by religion:C Manufacturing|Sikh',
#        'W8Living arrangements by sex by age:All categories: Age 16 and over|Males|Not living in a couple: Widowed or surviving partner from a same-sex civil partnership',
#        'W8Long-term health problem or disability by car or van availability by age:Age 50 to 64|1 car or van in household|Day-to-day activities limited a little',
#        'W8Marital and civil partnership status by sex by age:Males|Age 24 and under|Separated (but still legally married or still legally in a same-sex civil partnership)',
#        'W8Marital and civil partnership status by sex by age:Males|All categories: Age|Widowed or surviving partner from a same-sex civil partnership',
#        'W8National identity by ethnic group:Scottish and British only identity|White: Irish',
#        'W8Occupancy rating (rooms) by household composition:Occupancy rating (rooms) of -1 or less|One family only: All aged 65 and over',
#        'W8Passports held (detailed):Middle East and Asia: Southern Asia: Afghanistan',
#        'W8Passports held by country of birth:Europe: Ireland|Middle East and Asia: Middle East',
#        'W8Passports held by country of birth:Europe: Other Europe: EU countries: Total|Africa: North Africa',
#        'W8Passports held by sex by age:Females|Age 65 and over|Africa: Central and Western Africa',
#        'W8Passports held by year of arrival in the UK:Middle East and Asia: Total|Arrived before 1961',
#        'W8Provision of unpaid care by general health by sex by age:Males|Age 0 to 24|Provides 50 or more hours unpaid care a week|Bad or very bad health',
#        'W8Provision of unpaid care by general health by sex by age:Males|All categories: Age|Provides unpaid care: Total|Very good or good health',
#        'W8Religion of dependent child by sex:Sikh|Females',
#        'W8Residence type by sex by age:Age 20 to 24|Lives in a communal establishment|All persons',
#        'W8Student accommodation by age:Living in a communal establishment: Total|Age 18 to 19',
#        'W8Tenure by car or van availability by ethnic group of Household Reference Person (HRP):Rented: Social rented|2 or more cars or vans in household|All categories: Ethnic group of HRP',
#        'W8Tenure by car or van availability by number of usual residents aged 17 or over in household:All categories: Tenure|All categories: Car or van availability|No usual residents aged 17 or over in household',
#        'W8Tenure by household composition:Owned: Owned with a mortgage or loan or shared ownership|One family only: Married or same-sex civil partnership couple: Dependent children',
#        'W8Tenure by number of persons per room in household by accommodation type:Owned: Owned with a mortgage or loan or shared ownership|Over 1.0 and up to 1.5 persons per room|Whole house or bungalow: Detached',
#        'W8Tenure by number of persons per room in household by accommodation type:Rented: Private rented or living rent free|Up to 0.5 persons per room|Whole house or bungalow: Terraced (including end-terrace)',
#        'W8Tenure by number of persons per room in household by accommodation type:Rented: Social rented|Over 1.0 and up to 1.5 persons per room|Whole house or bungalow: Terraced (including end-terrace)',
#        'W8Tenure by number of persons per room in household by accommodation type:Rented: Social rented|Over 1.5 persons per room|All categories: Accommodation type',
#        'achieveReduceImmigBrexitW17_Yes', 'achieveReduceImmigConW7_Yes',
#        'achieveReduceImmigNoneW9_Yes', 'achieveReduceImmigUKIPW10_Yes',
#        'achieveReduceImmigUKIPW12_Yes', 'achieveReduceImmigUKIPW9_Yes',
#        'ageW17', 'ageW8', 'ageW9', 'al1W10W11W12__Strongly agree',
#        'al1W7W8W9__Strongly agree', 'al2W1W2W3W4W5__Strongly agree',
#        'al2W7W8W9__Strongly agree', 'al3W10W11W12__Strongly agree',
#        'al5W10W11W12__Strongly agree', 'al_scaleW10W11W12__Authoritarian',
#        'al_scaleW1W2W3W4W5__Authoritarian',
#        'al_scaleW7W8W9__Authoritarian',
#        'antiIntellectualW10__Strongly agree',
#        'antiIntellectualW9__Strongly agree',
#        'approveEUW10__Strongly approve', 'approveEUW7__Strongly approve',
#        'approveEUW9__Strongly approve', 'asiaW10_nino', 'asiaW17_nino',
#        'asiaW1_nino', 'asiaW7_nino', 'asiaW8_nino',
#        'asylumMoreW7__Many more', 'asylumMoreW8__Many more',
#        'benefitsToMigrantsW7__Never', 'benefitsToMigrantsW8__Never',
#        'bestOnMIIW10_United Kingdom Independence Party (UKIP)',
#        'bestOnMIIW1_Labour', 'bestOnMIIW8_Scottish National Party (SNP)',
#        'bestOnMIIW9_Conservative', 'betterDealEUW8__Much better',
#        'blackEqualityW16__Gone much too far',
#        'blackEqualityW17__Gone much too far',
#        'blackEqualityW1W2W3W4W5__Gone much too far',
#        'blairGoodW1_Good for Britain', 'blameLeave_5W9_Yes',
#        'brexitNextPrefW17__Leave with no deal',
#        'britishnessW10__Very strongly British',
#        'britishnessW9__Very strongly British',
#        'campaigninfoRemainW8__Strongly agree',
#        'cantLiveWithEU_1W17_Unacceptable',
#        'certaintyUKLeaveW8__Very sure',
#        'changeCostLiveLabW1__Getting a lot higher',
#        'changeCostLiveW17__Getting a lot higher',
#        'changeCrimeW10__Getting a lot higher',
#        'changeCrimeW14__Getting a lot higher',
#        'changeEconomyLabW10__Getting a lot better',
#        'changeEconomyLabW1__Getting a lot better',
#        'changeEconomyW9__Getting a lot better',
#        'changeEducationLabW1__Getting a lot better',
#        'changeImmigLabW1__Getting a lot higher',
#        'changeImmigW10__Getting a lot higher',
#        'changeImmigW11__Getting a lot higher',
#        'changeImmigW17__Getting a lot higher',
#        'changeImmigW1__Getting a lot higher',
#        'changeImmigW7__Getting a lot higher',
#        'changeImmigW8__Getting a lot higher',
#        'changeNHSLabW1__Getting a lot better',
#        'changeNHSW8__Getting a lot better',
#        'controlImmigW8__Complete control',
#        'controlImmigW9__Complete control', 'dEU_regW10_nino',
#        'dEU_regW17_nino', 'dEU_regW1_nino', 'dEU_regW7_nino',
#        'dEU_regW8_nino', 'dEUpostrefW10_nino', 'dEUpostrefW17_nino',
#        'debateOneWatchW8_Yes', 'debateTwoWatchW8_Yes',
#        'discrimBMEW10__A lot of discrimination against',
#        'discrimMuslimsW10__A lot of discrimination against',
#        'discrimWhiteW10__A lot of discrimination against',
#        'discussPolDaysW8__7 days', 'dnonEU_regW10_nino',
#        'dnonEU_regW17_nino', 'dnonEU_regW1_nino', 'dnonEU_regW7_nino',
#        'dnonEU_regW8_nino', 'econGenRetroW10__Got a lot better',
#        'edlevelW8W9W10__Postgrad',
#        'eesEUIntegrationSelfW1__Unification should be pushed further',
#        'eesEUIntegrationUKIPW1__Unification should be pushed further',
#        'effectsEUEconW15__Much better', 'effectsEUEconW7__Much better',
#        'effectsEUEconW8__Much better', 'effectsEUFinanceW8__Much better',
#        'effectsEUImmigrationW17__Much higher',
#        'effectsEUImmigrationW7__Much higher',
#        'effectsEUImmigrationW8__Much higher',
#        'effectsEUTerrorW15__Much higher',
#        'effectsEUUnemploymentW8__Much higher',
#        'effectsEUWorkersW10__Much better',
#        'effectsEUWorkersW8__Much better',
#        'efficacyPolCareW10__Strongly agree',
#        'englishnessW9__Very strongly English', 'ethno5W7__Strongly agree',
#        'euCloserW7__Strongly agree', 'euCloserW8__Strongly agree',
#        'euDominanceW8__Many more powers',
#        'euFinancialHelpW7__Strongly agree', 'euID2W17__Strongly agree',
#        'euID4W11__Strongly agree', 'euID6W10__Strongly agree',
#        'euIDW9_The leave side', 'euKnow3W8_False',
#        'euLawsLevelW7__Strongly agree', 'euLawsLevelW8__Strongly agree',
#        'euLeaveBigBusinessW10__Much more likely',
#        'euLeaveVoiceW8__Much higher', 'euMoreW13__Many more',
#        'euMoreW7__Many more', 'euMoreW8__Many more',
#        'euParlOverRideW8__Strongly agree',
#        'euPriorityBalanceW10__Control immigration',
#        'euPriorityBalanceW13__Control immigration',
#        'euPriorityBalanceW15__Control immigration',
#        'euPriorityBalanceW16__Control immigration',
#        'euPriorityBalanceW17__Control immigration',
#        'euRefCertaintyW8__Completely certain', 'euRefDoOverW10_Yes',
#        'euRefDoOverW17_Yes',
#        'euRefExpectationW7__100 - UK will definitely vote to leave the EU',
#        'euRefExpectationW8__100 - UK will definitely vote to leave the EU',
#        'euRefVoteUnsqueezeW7_Leave the EU', 'euRefVoteW1_Leave the EU',
#        'euRefVoteW7_Leave the EU', 'euRefVoteW8_Leave the EU',
#        'euRefVoteW9_Leave the EU', 'euSources_1W8_Yes',
#        'euUKRichW7__Strongly agree', 'euUKRichW8__Strongly agree',
#        'euUndermineIdentityW8__Strongly agree',
#        'europeannessW10__Very strongly European',
#        'europeannessW9__Very strongly European',
#        'expectGoodConductEURefW7__Conducted unfairly',
#        'familiesMoreW7__Many more', 'familiesMoreW8__Many more',
#        'gayEqualityW17__Gone much too far',
#        'genderRolesW10__Strongly agree',
#        'generalElectionVoteW10_United Kingdom Independence Party (UKIP)',
#        'generalElectionVoteW1_Labour',
#        'generalElectionVoteW8_Conservative',
#        'generalElectionVoteW9_Conservative',
#        'germanyFairShareW8__Much more than its fair share',
#        'govtHandleNHSW7__Very well', 'govtHandoutsW7__Strongly agree',
#        'handleMIIUKIPW9__Very well', 'happyEULeaveW10__Extremely happy',
#        'happyEULeaveW14__Extremely happy',
#        'happyEULeaveW9__Extremely happy',
#        'happyScotIndepResultW17__Extremely happy',
#        'happyTrumpW10__Extremely happy', 'harkBackW10__Strongly agree',
#        'hungParliamentResponseW17__Very likely',
#        'immigBrexitW17__Allow many more', 'immigConW10__Allow many more',
#        'immigConW17__Allow many more', 'immigConW7__Allow many more',
#        'immigConW8__Allow many more', 'immigConW9__Allow many more',
#        'immigContributeTakeW7__Get more than they pay',
#        'immigContributeTakeW8__Get more than they pay',
#        'immigECSW8__Good', 'immigECW8__Good for Econ&Cult',
#        'immigGreenW10__Allow many more', 'immigGreenW17__Allow many more',
#        'immigGreenW8__Allow many more', 'immigGreenW9__Allow many more',
#        'immigLDW10__Allow many more', 'immigLDW17__Allow many more',
#        'immigLDW8__Allow many more', 'immigLDW9__Allow many more',
#        'immigLabW10__Allow many more', 'immigLabW17__Allow many more',
#        'immigLabW7__Allow many more', 'immigLabW9__Allow many more',
#        'immigSNPW9__Allow many more', 'immigSelfW10__Allow many more',
#        'immigSelfW11__Allow many more', 'immigSelfW8__Allow many more',
#        'immigUKIPW10__Allow many more', 'immigUKIPW7__Allow many more',
#        'immigUKIPW8__Allow many more', 'immigUKIPW9__Allow many more',
#        'immigrantsWelfareStateW10__Strongly agree',
#        'immigrantsWelfareStateW1__Strongly agree',
#        'immigrantsWelfareStateW7__Strongly agree',
#        'immigrantsWelfareStateW8__Strongly agree',
#        'infoSourceInternetW8__More than 2 hours',
#        'infoSourcePaperW7__More than 2 hours',
#        'infoSourceRadioW4__More than 2 hours', 'labUnitedW8__Very united',
#        'leaveImpactBritainW10__A very large impact',
#        'leaveToneW8__5 - Hope', 'leftRightW10__Right',
#        'leftRightW17__Right', 'leftRightW7__Right',
#        'likeAlanJohnsonW7__Strongly like', 'likeBorisW8__Strongly like',
#        'likeBorisW9__Strongly like', 'likeBrexitPartyW19__Strongly like',
#        'likeCameronW7__Strongly like', 'likeCameronW8__Strongly like',
#        'likeConW10__Strongly like', 'likeConW12__Strongly like',
#        'likeConW9__Strongly like', 'likeCorbynW11__Strongly like',
#        'likeCorbynW9__Strongly like', 'likeFarageW17__Strongly like',
#        'likeFarageW8__Strongly like', 'likeFarageW9__Strongly like',
#        'likeGoveW8__Strongly like', 'likeGoveW9__Strongly like',
#        'likeGrnW17__Strongly like', 'likeLabW18__Strongly like',
#        'likeLabW8__Strongly like', 'likeMayW10__Strongly like',
#        'likeMayW11__Strongly like', 'likeMcDonnellW9__Strongly like',
#        'likeMilibandW1__Strongly like', 'likeOsborneW7__Strongly like',
#        'likeOsborneW8__Strongly like', 'likeOsborneW9__Strongly like',
#        'likeUKIPW17__Strongly like', 'likeUKIPW18__Strongly like',
#        'likeUKIPW8__Strongly like', 'likeUKIPW9__Strongly like',
#        'lr1W1W2W3W4W5__Strongly agree', 'lr1W7W8W9__Strongly agree',
#        'lrConW10__Right', 'lrConW17__Right', 'lrConW7__Right',
#        'lrLDW17__Right', 'lrLabW7__Right', 'lrMayW12__Right',
#        'lrUKIPW10__Right', 'lrUKIPW11__Right', 'lrUKIPW16__Right',
#        'lrUKIPW8__Right', 'lrgreensW10__Right', 'lrgreensW11__Right',
#        'majorityPartyLDW18__Very likely', 'mii_catW10_europe',
#        'mii_catW10_immigration', 'mii_catW1_economy-general',
#        'mii_catW1_immigration', 'mii_catW7_immigration',
#        'mii_catW8_immigration', 'mii_catW9_immigration',
#        'monarchW8__Strongly agree',
#        'natSecurityConW11__Protect civil liberties',
#        'natSecuritySelfW10__Protect civil liberties',
#        'negotiationSpecifics_2W9_Yes', 'nonEU_regW17_nino',
#        'nonEU_regW1_nino', 'nonEU_regW7_nino', 'nonEU_regW8_nino',
#        'noneuMoreW7__Many more', 'noneuMoreW8__Many more', 'otherW7_nino',
#        'other_europeW10_nino', 'other_europeW7_nino',
#        'other_europeW8_nino', 'overseasAidW10__Strongly agree',
#        'partyIdStrengthW10__Not very strong',
#        'polAttentionW1__Pay a great deal of attention',
#        'populism1W10__Strongly agree', 'populism5W10__Strongly agree',
#        'populism6W10__Strongly agree',
#        'proConRemainW8__7- Upsides of remaining',
#        'profile_gross_personalW7__£100,000 and over',
#        'profile_work_organisationW17_Unemployed',
#        'ptvBrexitPartyW17__Very likely', 'ptvConW10__Very likely',
#        'ptvConW17__Very likely', 'ptvConW7__Very likely',
#        'ptvConW9__Very likely', 'ptvGrnW7__Very likely',
#        'ptvLDW10__Very likely', 'ptvLabW1__Very likely',
#        'ptvLabW7__Very likely', 'ptvUKIPW17__Very likely',
#        'ptvUKIPW7__Very likely', 'ptvUKIPW9__Very likely',
#        'redistConW7__Government should be less concerned about equal incomes',
#        'redistGreenW17__Government should be less concerned about equal incomes',
#        'redistLDW10__Government should be less concerned about equal incomes',
#        'redistSelfW7__Government should be less concerned about equal incomes',
#        'redistUKIPW10__Government should be less concerned about equal incomes',
#        'redistUKIPW7__Government should be less concerned about equal incomes',
#        'remainToneW8__5 - Hope', 'renationaliseRailW10__Strongly agree',
#        'rest_worldW10_nino', 'rest_worldW17_nino', 'rest_worldW1_nino',
#        'rest_worldW7_nino', 'riskPovertyW10__Very likely',
#        'satDemEUW10__Very satisfied', 'satDemEUW8__Very satisfied',
#        'satDemEUW9__Very satisfied', 'small_mii_catW10_Immigration',
#        'small_mii_catW1_Immigration', 'small_mii_catW7_Europe',
#        'small_mii_catW7_Immigration', 'small_mii_catW8_Immigration',
#        'small_mii_catW9_Immigration',
#        'socialIdentityGlobalLeaveW10__A great deal in common',
#        'socialIdentityGlobalLeaveW8__A great deal in common',
#        'socialIdentityGlobalLeaveW9__A great deal in common',
#        'socialIdentityGlobalRemainW10__A great deal in common',
#        'socialIdentityGlobalRemainW7__A great deal in common',
#        'socialIdentityGlobalRemainW8__A great deal in common',
#        'socialIdentityGlobalRemainW9__A great deal in common',
#        'strongLeaderW10__Strongly agree',
#        'strongLeaderW17__Strongly agree', 'studentsMoreW7__Many more',
#        'studentsMoreW8__Many more',
#        'taxSpendConW14__Government should increase taxes a lot and spend much more on health and social services',
#        'totW10_nino', 'totW17_nino', 'totW8_nino', 'totalW10_nino',
#        'totalW17_nino', 'totalW7_nino', 'trustCourtsW17__10.0',
#        'trustMPsW10__A great deal of trust',
#        'trustMPsW7__A great deal of trust',
#        'trustMPsW8__A great deal of trust',
#        'trustYourMPW2__A great deal of trust',
#        'turnoutUKGeneralW1__Very likely that I will vote',
#        'ukCoopMovementW10__Bad for Britain',
#        'ukCoopMovementW15__Bad for Britain',
#        'ukCoopMovementW7__Bad for Britain',
#        'ukCoopMovementW8__Bad for Britain',
#        'ukCoopTradeW7__Bad for Britain', 'ukCoopTradeW8__Bad for Britain',
#        'warmAsianW11__Very warm', 'warmBlackW11__Very warm',
#        'warmPolandW7__Very warm', 'warmWhiteW11__Very warm',
#        'winConstituencyConW12__100 - Very likely to win'], dtype='<U217')

# %%
len( np.unique( flatten([treatment_dict[x].index for x in treatment_dict.keys()]) ) )
# Out:
# 566

# %%
pd.DataFrame(treatment_dict)
# Out:
#                                                  D8_10immigEC_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                          NaN
# D10_12euPriorityBalance__Control immigration                          NaN
# D10_14euPriorityBalance__Control immigration                          NaN
# D10_15changeImmig__Getting a lot higher                               NaN
# D10_15euPriorityBalance__Control immigration                          NaN
# ...                                                                   ...
# warmAsianW11__Very warm                                               NaN
# warmBlackW11__Very warm                                               NaN
# warmPolandW7__Very warm                                               NaN
# warmWhiteW11__Very warm                                               NaN
# winConstituencyConW12__100 - Very likely to win                       NaN
#
#                                                  D8_9immigSelf_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                           NaN
# D10_12euPriorityBalance__Control immigration                           NaN
# D10_14euPriorityBalance__Control immigration                           NaN
# D10_15changeImmig__Getting a lot higher                                NaN
# D10_15euPriorityBalance__Control immigration                           NaN
# ...                                                                    ...
# warmAsianW11__Very warm                                                NaN
# warmBlackW11__Very warm                                                NaN
# warmPolandW7__Very warm                                                NaN
# warmWhiteW11__Very warm                                                NaN
# winConstituencyConW12__100 - Very likely to win                        NaN
#
#                                                  D8_9immigSelf_with_deltas_restrict_to_controlImmigW8mask  \
# D10_11immigrantsWelfareState__Strongly agree                                                   NaN
# D10_12euPriorityBalance__Control immigration                                                   NaN
# D10_14euPriorityBalance__Control immigration                                                   NaN
# D10_15changeImmig__Getting a lot higher                                                        NaN
# D10_15euPriorityBalance__Control immigration                                                   NaN
# ...                                                                                            ...
# warmAsianW11__Very warm                                                                        NaN
# warmBlackW11__Very warm                                                                        NaN
# warmPolandW7__Very warm                                                                        NaN
# warmWhiteW11__Very warm                                                                        NaN
# winConstituencyConW12__100 - Very likely to win                                                NaN
#
#                                                  D8_9immigSelf_with_deltas_most_immig_negative_half  \
# D10_11immigrantsWelfareState__Strongly agree                                                   NaN
# D10_12euPriorityBalance__Control immigration                                                   NaN
# D10_14euPriorityBalance__Control immigration                                                   NaN
# D10_15changeImmig__Getting a lot higher                                                        NaN
# D10_15euPriorityBalance__Control immigration                                                   NaN
# ...                                                                                            ...
# warmAsianW11__Very warm                                                                        NaN
# warmBlackW11__Very warm                                                                        NaN
# warmPolandW7__Very warm                                                                        NaN
# warmWhiteW11__Very warm                                                                        NaN
# winConstituencyConW12__100 - Very likely to win                                                NaN
#
#                                                  D8_9immigSelf_with_deltas_most_immig_positive_half  \
# D10_11immigrantsWelfareState__Strongly agree                                                   NaN
# D10_12euPriorityBalance__Control immigration                                                   NaN
# D10_14euPriorityBalance__Control immigration                                                   NaN
# D10_15changeImmig__Getting a lot higher                                                        NaN
# D10_15euPriorityBalance__Control immigration                                                   NaN
# ...                                                                                            ...
# warmAsianW11__Very warm                                                                        NaN
# warmBlackW11__Very warm                                                                        NaN
# warmPolandW7__Very warm                                                                        NaN
# warmWhiteW11__Very warm                                                                        NaN
# winConstituencyConW12__100 - Very likely to win                                                NaN
#
#                                                  D7_8immigSelf_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                           NaN
# D10_12euPriorityBalance__Control immigration                           NaN
# D10_14euPriorityBalance__Control immigration                           NaN
# D10_15changeImmig__Getting a lot higher                                NaN
# D10_15euPriorityBalance__Control immigration                           NaN
# ...                                                                    ...
# warmAsianW11__Very warm                                                NaN
# warmBlackW11__Very warm                                                NaN
# warmPolandW7__Very warm                                                NaN
# warmWhiteW11__Very warm                                                NaN
# winConstituencyConW12__100 - Very likely to win                        NaN
#
#                                                  D10_17immigSelf_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                             NaN
# D10_12euPriorityBalance__Control immigration                             NaN
# D10_14euPriorityBalance__Control immigration                             NaN
# D10_15changeImmig__Getting a lot higher                                  NaN
# D10_15euPriorityBalance__Control immigration                             NaN
# ...                                                                      ...
# warmAsianW11__Very warm                                                  NaN
# warmBlackW11__Very warm                                                  NaN
# warmPolandW7__Very warm                                                  NaN
# warmWhiteW11__Very warm                                                  NaN
# winConstituencyConW12__100 - Very likely to win                          NaN
#
#                                                  D10_17immigSelf_with_deltas_and_intermediates  \
# D10_11immigrantsWelfareState__Strongly agree                                               NaN
# D10_12euPriorityBalance__Control immigration                                          0.005631
# D10_14euPriorityBalance__Control immigration                                          0.004046
# D10_15changeImmig__Getting a lot higher                                               0.011473
# D10_15euPriorityBalance__Control immigration                                          0.005017
# ...                                                                                        ...
# warmAsianW11__Very warm                                                                    NaN
# warmBlackW11__Very warm                                                                    NaN
# warmPolandW7__Very warm                                                                    NaN
# warmWhiteW11__Very warm                                                                    NaN
# winConstituencyConW12__100 - Very likely to win                                            NaN
#
#                                                  D1_7immigEcon_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                           NaN
# D10_12euPriorityBalance__Control immigration                           NaN
# D10_14euPriorityBalance__Control immigration                           NaN
# D10_15changeImmig__Getting a lot higher                                NaN
# D10_15euPriorityBalance__Control immigration                           NaN
# ...                                                                    ...
# warmAsianW11__Very warm                                                NaN
# warmBlackW11__Very warm                                                NaN
# warmPolandW7__Very warm                                                NaN
# warmWhiteW11__Very warm                                                NaN
# winConstituencyConW12__100 - Very likely to win                        NaN
#
#                                                  D1_7immigCultural_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                               NaN
# D10_12euPriorityBalance__Control immigration                               NaN
# D10_14euPriorityBalance__Control immigration                               NaN
# D10_15changeImmig__Getting a lot higher                                    NaN
# D10_15euPriorityBalance__Control immigration                               NaN
# ...                                                                        ...
# warmAsianW11__Very warm                                                    NaN
# warmBlackW11__Very warm                                                    NaN
# warmPolandW7__Very warm                                                    NaN
# warmWhiteW11__Very warm                                                    NaN
# winConstituencyConW12__100 - Very likely to win                       0.002699
#
#                                                  ...  \
# D10_11immigrantsWelfareState__Strongly agree     ...
# D10_12euPriorityBalance__Control immigration     ...
# D10_14euPriorityBalance__Control immigration     ...
# D10_15changeImmig__Getting a lot higher          ...
# D10_15euPriorityBalance__Control immigration     ...
# ...                                              ...
# warmAsianW11__Very warm                          ...
# warmBlackW11__Very warm                          ...
# warmPolandW7__Very warm                          ...
# warmWhiteW11__Very warm                          ...
# winConstituencyConW12__100 - Very likely to win  ...
#
#                                                  D7_8immigCultural_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                               NaN
# D10_12euPriorityBalance__Control immigration                               NaN
# D10_14euPriorityBalance__Control immigration                               NaN
# D10_15changeImmig__Getting a lot higher                                    NaN
# D10_15euPriorityBalance__Control immigration                               NaN
# ...                                                                        ...
# warmAsianW11__Very warm                                                    NaN
# warmBlackW11__Very warm                                                    NaN
# warmPolandW7__Very warm                                                    NaN
# warmWhiteW11__Very warm                                                    NaN
# winConstituencyConW12__100 - Very likely to win                            NaN
#
#                                                  D8_10immigCultural_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                                NaN
# D10_12euPriorityBalance__Control immigration                                NaN
# D10_14euPriorityBalance__Control immigration                                NaN
# D10_15changeImmig__Getting a lot higher                                     NaN
# D10_15euPriorityBalance__Control immigration                                NaN
# ...                                                                         ...
# warmAsianW11__Very warm                                                     NaN
# warmBlackW11__Very warm                                                     NaN
# warmPolandW7__Very warm                                                     NaN
# warmWhiteW11__Very warm                                                     NaN
# winConstituencyConW12__100 - Very likely to win                             NaN
#
#                                                  D10_17immigCultural_with_deltas  \
# D10_11immigrantsWelfareState__Strongly agree                                 NaN
# D10_12euPriorityBalance__Control immigration                                 NaN
# D10_14euPriorityBalance__Control immigration                                 NaN
# D10_15changeImmig__Getting a lot higher                                      NaN
# D10_15euPriorityBalance__Control immigration                                 NaN
# ...                                                                          ...
# warmAsianW11__Very warm                                                      NaN
# warmBlackW11__Very warm                                                      NaN
# warmPolandW7__Very warm                                                      NaN
# warmWhiteW11__Very warm                                                      NaN
# winConstituencyConW12__100 - Very likely to win                              NaN
#
#                                                  D7_8immigEcon_with_deltas_all_wave_variables  \
# D10_11immigrantsWelfareState__Strongly agree                                              NaN
# D10_12euPriorityBalance__Control immigration                                              NaN
# D10_14euPriorityBalance__Control immigration                                              NaN
# D10_15changeImmig__Getting a lot higher                                                   NaN
# D10_15euPriorityBalance__Control immigration                                              NaN
# ...                                                                                       ...
# warmAsianW11__Very warm                                                                   NaN
# warmBlackW11__Very warm                                                                   NaN
# warmPolandW7__Very warm                                                                   NaN
# warmWhiteW11__Very warm                                                                   NaN
# winConstituencyConW12__100 - Very likely to win                                           NaN
#
#                                                  D10_17immigCultural_with_deltas_from_all_wave_pairs_adjacent_or_oth  \
# D10_11immigrantsWelfareState__Strongly agree                                              0.006391
# D10_12euPriorityBalance__Control immigration                                                   NaN
# D10_14euPriorityBalance__Control immigration                                                   NaN
# D10_15changeImmig__Getting a lot higher                                                        NaN
# D10_15euPriorityBalance__Control immigration                                                   NaN
# ...                                                                                            ...
# warmAsianW11__Very warm                                                                   0.002331
# warmBlackW11__Very warm                                                                   0.008305
# warmPolandW7__Very warm                                                                        NaN
# warmWhiteW11__Very warm                                                                   0.007677
# winConstituencyConW12__100 - Very likely to win                                                NaN
#
#                                                  D7_8immigEcon_with_full_nino  \
# D10_11immigrantsWelfareState__Strongly agree                              NaN
# D10_12euPriorityBalance__Control immigration                              NaN
# D10_14euPriorityBalance__Control immigration                              NaN
# D10_15changeImmig__Getting a lot higher                                   NaN
# D10_15euPriorityBalance__Control immigration                              NaN
# ...                                                                       ...
# warmAsianW11__Very warm                                                   NaN
# warmBlackW11__Very warm                                                   NaN
# warmPolandW7__Very warm                                              0.001908
# warmWhiteW11__Very warm                                                   NaN
# winConstituencyConW12__100 - Very likely to win                           NaN
#
#                                                  D7_8immigCultural_with_full_nino  \
# D10_11immigrantsWelfareState__Strongly agree                                  NaN
# D10_12euPriorityBalance__Control immigration                                  NaN
# D10_14euPriorityBalance__Control immigration                                  NaN
# D10_15changeImmig__Getting a lot higher                                       NaN
# D10_15euPriorityBalance__Control immigration                                  NaN
# ...                                                                           ...
# warmAsianW11__Very warm                                                       NaN
# warmBlackW11__Very warm                                                       NaN
# warmPolandW7__Very warm                                                       NaN
# warmWhiteW11__Very warm                                                       NaN
# winConstituencyConW12__100 - Very likely to win                               NaN
#
#                                                  D7_8immigSelf_with_full_nino  \
# D10_11immigrantsWelfareState__Strongly agree                              NaN
# D10_12euPriorityBalance__Control immigration                              NaN
# D10_14euPriorityBalance__Control immigration                              NaN
# D10_15changeImmig__Getting a lot higher                                   NaN
# D10_15euPriorityBalance__Control immigration                              NaN
# ...                                                                       ...
# warmAsianW11__Very warm                                                   NaN
# warmBlackW11__Very warm                                                   NaN
# warmPolandW7__Very warm                                                   NaN
# warmWhiteW11__Very warm                                                   NaN
# winConstituencyConW12__100 - Very likely to win                           NaN
#
#                                                  D7_8immigCultural_with_full_nino_and_bes  \
# D10_11immigrantsWelfareState__Strongly agree                                          NaN
# D10_12euPriorityBalance__Control immigration                                          NaN
# D10_14euPriorityBalance__Control immigration                                          NaN
# D10_15changeImmig__Getting a lot higher                                               NaN
# D10_15euPriorityBalance__Control immigration                                          NaN
# ...                                                                                   ...
# warmAsianW11__Very warm                                                               NaN
# warmBlackW11__Very warm                                                               NaN
# warmPolandW7__Very warm                                                               NaN
# warmWhiteW11__Very warm                                                               NaN
# winConstituencyConW12__100 - Very likely to win                                       NaN
#
#                                                  D7_8immigSelf_with_ONS_data_alone
# D10_11immigrantsWelfareState__Strongly agree                                   NaN
# D10_12euPriorityBalance__Control immigration                                   NaN
# D10_14euPriorityBalance__Control immigration                                   NaN
# D10_15changeImmig__Getting a lot higher                                        NaN
# D10_15euPriorityBalance__Control immigration                                   NaN
# ...                                                                            ...
# warmAsianW11__Very warm                                                        NaN
# warmBlackW11__Very warm                                                        NaN
# warmPolandW7__Very warm                                                        NaN
# warmWhiteW11__Very warm                                                        NaN
# winConstituencyConW12__100 - Very likely to win                                NaN
#
# [566 rows x 23 columns]

# %%
df = pd.DataFrame()

# %%
df_list =[]
for col in list(treatment_dict.keys()):
    df_list.append(pd.Series(treatment_dict[ col ]))
df = pd.concat(df_list,axis=1)
df.columns = list(treatment_dict.keys())

# %%
df
# Out:
#                                                     D8_10immigEC_with_deltas  \
# D8_10immigSelf__Allow many more                                     0.201055
# D8_10immigrantsWelfareState__Strongly agree                         0.178006
# D8_10ukCoopMovement__Bad for Britain                                0.112159
# ukCoopMovementW10__Bad for Britain                                  0.093811
# euMoreW8__Many more                                                 0.080439
# ...                                                                      ...
# W8Passports held by country of birth:Europe: Ir...                       NaN
# W8Tenure by number of persons per room in house...                       NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                       NaN
# W8General health by religion by sex by age:Fema...                       NaN
# W8Communal establishment residents:Total|Medica...                       NaN
#
#                                                     D8_9immigSelf_with_deltas  \
# D8_10immigSelf__Allow many more                                           NaN
# D8_10immigrantsWelfareState__Strongly agree                               NaN
# D8_10ukCoopMovement__Bad for Britain                                      NaN
# ukCoopMovementW10__Bad for Britain                                        NaN
# euMoreW8__Many more                                                  0.030698
# ...                                                                       ...
# W8Passports held by country of birth:Europe: Ir...                        NaN
# W8Tenure by number of persons per room in house...                        NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                        NaN
# W8General health by religion by sex by age:Fema...                        NaN
# W8Communal establishment residents:Total|Medica...                        NaN
#
#                                                     D8_9immigSelf_with_deltas_restrict_to_controlImmigW8mask  \
# D8_10immigSelf__Allow many more                                                                   NaN
# D8_10immigrantsWelfareState__Strongly agree                                                       NaN
# D8_10ukCoopMovement__Bad for Britain                                                              NaN
# ukCoopMovementW10__Bad for Britain                                                                NaN
# euMoreW8__Many more                                                                          0.009217
# ...                                                                                               ...
# W8Passports held by country of birth:Europe: Ir...                                                NaN
# W8Tenure by number of persons per room in house...                                                NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                                                NaN
# W8General health by religion by sex by age:Fema...                                                NaN
# W8Communal establishment residents:Total|Medica...                                                NaN
#
#                                                     D8_9immigSelf_with_deltas_most_immig_negative_half  \
# D8_10immigSelf__Allow many more                                                                   NaN
# D8_10immigrantsWelfareState__Strongly agree                                                       NaN
# D8_10ukCoopMovement__Bad for Britain                                                              NaN
# ukCoopMovementW10__Bad for Britain                                                                NaN
# euMoreW8__Many more                                                                          0.040118
# ...                                                                                               ...
# W8Passports held by country of birth:Europe: Ir...                                                NaN
# W8Tenure by number of persons per room in house...                                                NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                                                NaN
# W8General health by religion by sex by age:Fema...                                                NaN
# W8Communal establishment residents:Total|Medica...                                                NaN
#
#                                                     D8_9immigSelf_with_deltas_most_immig_positive_half  \
# D8_10immigSelf__Allow many more                                                                   NaN
# D8_10immigrantsWelfareState__Strongly agree                                                       NaN
# D8_10ukCoopMovement__Bad for Britain                                                              NaN
# ukCoopMovementW10__Bad for Britain                                                                NaN
# euMoreW8__Many more                                                                          0.059958
# ...                                                                                               ...
# W8Passports held by country of birth:Europe: Ir...                                                NaN
# W8Tenure by number of persons per room in house...                                                NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                                                NaN
# W8General health by religion by sex by age:Fema...                                                NaN
# W8Communal establishment residents:Total|Medica...                                                NaN
#
#                                                     D7_8immigSelf_with_deltas  \
# D8_10immigSelf__Allow many more                                           NaN
# D8_10immigrantsWelfareState__Strongly agree                               NaN
# D8_10ukCoopMovement__Bad for Britain                                      NaN
# ukCoopMovementW10__Bad for Britain                                        NaN
# euMoreW8__Many more                                                  0.009299
# ...                                                                       ...
# W8Passports held by country of birth:Europe: Ir...                        NaN
# W8Tenure by number of persons per room in house...                        NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                        NaN
# W8General health by religion by sex by age:Fema...                        NaN
# W8Communal establishment residents:Total|Medica...                        NaN
#
#                                                     D10_17immigSelf_with_deltas  \
# D8_10immigSelf__Allow many more                                             NaN
# D8_10immigrantsWelfareState__Strongly agree                                 NaN
# D8_10ukCoopMovement__Bad for Britain                                        NaN
# ukCoopMovementW10__Bad for Britain                                     0.029037
# euMoreW8__Many more                                                         NaN
# ...                                                                         ...
# W8Passports held by country of birth:Europe: Ir...                          NaN
# W8Tenure by number of persons per room in house...                          NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                          NaN
# W8General health by religion by sex by age:Fema...                          NaN
# W8Communal establishment residents:Total|Medica...                          NaN
#
#                                                     D10_17immigSelf_with_deltas_and_intermediates  \
# D8_10immigSelf__Allow many more                                                               NaN
# D8_10immigrantsWelfareState__Strongly agree                                                   NaN
# D8_10ukCoopMovement__Bad for Britain                                                          NaN
# ukCoopMovementW10__Bad for Britain                                                       0.016434
# euMoreW8__Many more                                                                           NaN
# ...                                                                                           ...
# W8Passports held by country of birth:Europe: Ir...                                            NaN
# W8Tenure by number of persons per room in house...                                            NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                                            NaN
# W8General health by religion by sex by age:Fema...                                            NaN
# W8Communal establishment residents:Total|Medica...                                            NaN
#
#                                                     D1_7immigEcon_with_deltas  \
# D8_10immigSelf__Allow many more                                           NaN
# D8_10immigrantsWelfareState__Strongly agree                               NaN
# D8_10ukCoopMovement__Bad for Britain                                      NaN
# ukCoopMovementW10__Bad for Britain                                        NaN
# euMoreW8__Many more                                                       NaN
# ...                                                                       ...
# W8Passports held by country of birth:Europe: Ir...                        NaN
# W8Tenure by number of persons per room in house...                        NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                        NaN
# W8General health by religion by sex by age:Fema...                        NaN
# W8Communal establishment residents:Total|Medica...                        NaN
#
#                                                     D1_7immigCultural_with_deltas  \
# D8_10immigSelf__Allow many more                                               NaN
# D8_10immigrantsWelfareState__Strongly agree                                   NaN
# D8_10ukCoopMovement__Bad for Britain                                          NaN
# ukCoopMovementW10__Bad for Britain                                            NaN
# euMoreW8__Many more                                                           NaN
# ...                                                                           ...
# W8Passports held by country of birth:Europe: Ir...                            NaN
# W8Tenure by number of persons per room in house...                            NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                            NaN
# W8General health by religion by sex by age:Fema...                            NaN
# W8Communal establishment residents:Total|Medica...                            NaN
#
#                                                     ...  \
# D8_10immigSelf__Allow many more                     ...
# D8_10immigrantsWelfareState__Strongly agree         ...
# D8_10ukCoopMovement__Bad for Britain                ...
# ukCoopMovementW10__Bad for Britain                  ...
# euMoreW8__Many more                                 ...
# ...                                                 ...
# W8Passports held by country of birth:Europe: Ir...  ...
# W8Tenure by number of persons per room in house...  ...
# W8Industry by religion:A, B, D, E Agriculture, ...  ...
# W8General health by religion by sex by age:Fema...  ...
# W8Communal establishment residents:Total|Medica...  ...
#
#                                                     D7_8immigCultural_with_deltas  \
# D8_10immigSelf__Allow many more                                               NaN
# D8_10immigrantsWelfareState__Strongly agree                                   NaN
# D8_10ukCoopMovement__Bad for Britain                                          NaN
# ukCoopMovementW10__Bad for Britain                                            NaN
# euMoreW8__Many more                                                      0.005345
# ...                                                                           ...
# W8Passports held by country of birth:Europe: Ir...                            NaN
# W8Tenure by number of persons per room in house...                            NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                            NaN
# W8General health by religion by sex by age:Fema...                            NaN
# W8Communal establishment residents:Total|Medica...                            NaN
#
#                                                     D8_10immigCultural_with_deltas  \
# D8_10immigSelf__Allow many more                                                NaN
# D8_10immigrantsWelfareState__Strongly agree                               0.073106
# D8_10ukCoopMovement__Bad for Britain                                      0.036289
# ukCoopMovementW10__Bad for Britain                                        0.044240
# euMoreW8__Many more                                                       0.022465
# ...                                                                            ...
# W8Passports held by country of birth:Europe: Ir...                             NaN
# W8Tenure by number of persons per room in house...                             NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                             NaN
# W8General health by religion by sex by age:Fema...                             NaN
# W8Communal establishment residents:Total|Medica...                             NaN
#
#                                                     D10_17immigCultural_with_deltas  \
# D8_10immigSelf__Allow many more                                                 NaN
# D8_10immigrantsWelfareState__Strongly agree                                     NaN
# D8_10ukCoopMovement__Bad for Britain                                            NaN
# ukCoopMovementW10__Bad for Britain                                         0.037001
# euMoreW8__Many more                                                             NaN
# ...                                                                             ...
# W8Passports held by country of birth:Europe: Ir...                              NaN
# W8Tenure by number of persons per room in house...                              NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                              NaN
# W8General health by religion by sex by age:Fema...                              NaN
# W8Communal establishment residents:Total|Medica...                              NaN
#
#                                                     D7_8immigEcon_with_deltas_all_wave_variables  \
# D8_10immigSelf__Allow many more                                                              NaN
# D8_10immigrantsWelfareState__Strongly agree                                                  NaN
# D8_10ukCoopMovement__Bad for Britain                                                         NaN
# ukCoopMovementW10__Bad for Britain                                                      0.004398
# euMoreW8__Many more                                                                     0.001269
# ...                                                                                          ...
# W8Passports held by country of birth:Europe: Ir...                                           NaN
# W8Tenure by number of persons per room in house...                                           NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                                           NaN
# W8General health by religion by sex by age:Fema...                                           NaN
# W8Communal establishment residents:Total|Medica...                                           NaN
#
#                                                     D10_17immigCultural_with_deltas_from_all_wave_pairs_adjacent_or_oth  \
# D8_10immigSelf__Allow many more                                                                   NaN
# D8_10immigrantsWelfareState__Strongly agree                                                       NaN
# D8_10ukCoopMovement__Bad for Britain                                                              NaN
# ukCoopMovementW10__Bad for Britain                                                           0.071348
# euMoreW8__Many more                                                                          0.005289
# ...                                                                                               ...
# W8Passports held by country of birth:Europe: Ir...                                                NaN
# W8Tenure by number of persons per room in house...                                                NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                                                NaN
# W8General health by religion by sex by age:Fema...                                                NaN
# W8Communal establishment residents:Total|Medica...                                                NaN
#
#                                                     D7_8immigEcon_with_full_nino  \
# D8_10immigSelf__Allow many more                                              NaN
# D8_10immigrantsWelfareState__Strongly agree                                  NaN
# D8_10ukCoopMovement__Bad for Britain                                         NaN
# ukCoopMovementW10__Bad for Britain                                           NaN
# euMoreW8__Many more                                                     0.009339
# ...                                                                          ...
# W8Passports held by country of birth:Europe: Ir...                           NaN
# W8Tenure by number of persons per room in house...                           NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                           NaN
# W8General health by religion by sex by age:Fema...                           NaN
# W8Communal establishment residents:Total|Medica...                           NaN
#
#                                                     D7_8immigCultural_with_full_nino  \
# D8_10immigSelf__Allow many more                                                  NaN
# D8_10immigrantsWelfareState__Strongly agree                                      NaN
# D8_10ukCoopMovement__Bad for Britain                                             NaN
# ukCoopMovementW10__Bad for Britain                                          0.005002
# euMoreW8__Many more                                                         0.002858
# ...                                                                              ...
# W8Passports held by country of birth:Europe: Ir...                               NaN
# W8Tenure by number of persons per room in house...                               NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                               NaN
# W8General health by religion by sex by age:Fema...                               NaN
# W8Communal establishment residents:Total|Medica...                               NaN
#
#                                                     D7_8immigSelf_with_full_nino  \
# D8_10immigSelf__Allow many more                                              NaN
# D8_10immigrantsWelfareState__Strongly agree                                  NaN
# D8_10ukCoopMovement__Bad for Britain                                         NaN
# ukCoopMovementW10__Bad for Britain                                           NaN
# euMoreW8__Many more                                                          NaN
# ...                                                                          ...
# W8Passports held by country of birth:Europe: Ir...                           NaN
# W8Tenure by number of persons per room in house...                           NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                           NaN
# W8General health by religion by sex by age:Fema...                           NaN
# W8Communal establishment residents:Total|Medica...                           NaN
#
#                                                     D7_8immigCultural_with_full_nino_and_bes  \
# D8_10immigSelf__Allow many more                                                          NaN
# D8_10immigrantsWelfareState__Strongly agree                                              NaN
# D8_10ukCoopMovement__Bad for Britain                                                     NaN
# ukCoopMovementW10__Bad for Britain                                                       NaN
# euMoreW8__Many more                                                                 0.003495
# ...                                                                                      ...
# W8Passports held by country of birth:Europe: Ir...                                       NaN
# W8Tenure by number of persons per room in house...                                       NaN
# W8Industry by religion:A, B, D, E Agriculture, ...                                       NaN
# W8General health by religion by sex by age:Fema...                                       NaN
# W8Communal establishment residents:Total|Medica...                                       NaN
#
#                                                     D7_8immigSelf_with_ONS_data_alone
# D8_10immigSelf__Allow many more                                                   NaN
# D8_10immigrantsWelfareState__Strongly agree                                       NaN
# D8_10ukCoopMovement__Bad for Britain                                              NaN
# ukCoopMovementW10__Bad for Britain                                                NaN
# euMoreW8__Many more                                                               NaN
# ...                                                                               ...
# W8Passports held by country of birth:Europe: Ir...                           0.001405
# W8Tenure by number of persons per room in house...                           0.001376
# W8Industry by religion:A, B, D, E Agriculture, ...                           0.001357
# W8General health by religion by sex by age:Fema...                           0.001325
# W8Communal establishment residents:Total|Medica...                           0.001305
#
# [566 rows x 23 columns]

# %%
df.shape
# Out:
# (566, 23)

# %%
df.mean(axis=1).sort_values(ascending=False).head(80)
# Out:
# immigECSW8__Good                                   0.646640
# immigECW8__Good for Econ&Cult                      0.549216
# D8_10immigECS                                      0.210593
# D8_10immigSelf__Allow many more                    0.201055
# D1_7immigrantsWelfareState__Strongly agree         0.147368
#                                                      ...
# natSecuritySelfW10__Protect civil liberties        0.016808
# D7_8immigLD__Allow many more                       0.016603
# asiaW1_nino                                        0.016208
# immigContributeTakeW8__Get more than they pay      0.016192
# D7_8immigContributeTake__Get more than they pay    0.016170
# Length: 80, dtype: float32

# %%
df.stack()[df.stack()<.3].hist(bins=100)

# %%
df.mean(axis=1).sort_values(ascending=False).tail(50)
# Out:
# W8Marital and civil partnership status by sex by age:Males|All categories: Age|Widowed or surviving partner from a same-sex civil partnership                                                                                0.001784
# W8Provision of unpaid care by general health by sex by age:Males|Age 0 to 24|Provides 50 or more hours unpaid care a week|Bad or very bad health                                                                             0.001772
# W8General health by ethnic group by sex by age:Females|Age 0 to 15|Bad or very bad health|Mixed/multiple ethnic group                                                                                                        0.001768
# W8Tenure by number of persons per room in household by accommodation type:Owned: Owned with a mortgage or loan or shared ownership|Over 1.0 and up to 1.5 persons per room|Whole house or bungalow: Detached                 0.001761
# W8Ethnic group by age of arrival in the UK:White: Irish|Age of arrival in the UK: 65 and over                                                                                                                                0.001756
# W8Economic activity by country of birth by age:Age 16 to 49|Economically inactive: Retired|Europe: Other Europe: Rest of Europe                                                                                              0.001744
# W8Country of birth:Europe: Guernsey                                                                                                                                                                                          0.001744
# D7_8UKsovereignty__Strongly agree                                                                                                                                                                                            0.001732
# effectsEUUnemploymentW8__Much higher                                                                                                                                                                                         0.001701
# W8Accommodation type by car or van availability by number of usual residents aged 17 or over in household:Whole house or bungalow|All categories: Car or van availability|No usual residents aged 17 or over in household    0.001697
# changeCostLiveW17__Getting a lot higher                                                                                                                                                                                      0.001669
# ptvLabW7__Very likely                                                                                                                                                                                                        0.001667
# profile_gross_personalW7__£100,000 and over                                                                                                                                                                                  0.001646
# W8Long-term health problem or disability by car or van availability by age:Age 50 to 64|1 car or van in household|Day-to-day activities limited a little                                                                     0.001641
# W8General health by religion by sex by age:All persons|Age 65 and over|Fair health|Sikh                                                                                                                                      0.001639
# socialIdentityGlobalRemainW8__A great deal in common                                                                                                                                                                         0.001632
# euKnow3W8_False                                                                                                                                                                                                              0.001591
# W8Occupancy rating (rooms) by household composition:Occupancy rating (rooms) of -1 or less|One family only: All aged 65 and over                                                                                             0.001589
# euRefCertaintyW8__Completely certain                                                                                                                                                                                         0.001571
# W8Student accommodation by age:Living in a communal establishment: Total|Age 18 to 19                                                                                                                                        0.001556
# euFinancialHelpW7__Strongly agree                                                                                                                                                                                            0.001547
# W8Country of birth (detailed):Total|Africa: Africa not otherwise specified                                                                                                                                                   0.001541
# W8Passports held by country of birth:Europe: Other Europe: EU countries: Total|Africa: North Africa                                                                                                                          0.001533
# likeOsborneW7__Strongly like                                                                                                                                                                                                 0.001505
# W8Tenure by number of persons per room in household by accommodation type:Rented: Social rented|Over 1.0 and up to 1.5 persons per room|Whole house or bungalow: Terraced (including end-terrace)                            0.001500
# W8Residence type by sex by age:Age 20 to 24|Lives in a communal establishment|All persons                                                                                                                                    0.001489
# W8Religion of dependent child by sex:Sikh|Females                                                                                                                                                                            0.001459
# W8Passports held (detailed):Middle East and Asia: Southern Asia: Afghanistan                                                                                                                                                 0.001456
# W8Provision of unpaid care by general health by sex by age:Males|All categories: Age|Provides unpaid care: Total|Very good or good health                                                                                    0.001450
# taxSpendConW14__Government should increase taxes a lot and spend much more on health and social services                                                                                                                     0.001436
# W8Living arrangements by sex by age:All categories: Age 16 and over|Males|Not living in a couple: Widowed or surviving partner from a same-sex civil partnership                                                             0.001434
# W8Tenure by car or van availability by number of usual residents aged 17 or over in household:All categories: Tenure|All categories: Car or van availability|No usual residents aged 17 or over in household                 0.001433
# W8Passports held by country of birth:Europe: Ireland|Middle East and Asia: Middle East                                                                                                                                       0.001405
# W8Tenure by number of persons per room in household by accommodation type:Rented: Private rented or living rent free|Up to 0.5 persons per room|Whole house or bungalow: Terraced (including end-terrace)                    0.001376
# W8Industry by religion:A, B, D, E Agriculture, energy and water|Sikh                                                                                                                                                         0.001357
# W8General health by religion by sex by age:Females|Age 16 to 49|Very good or good health|Jewish                                                                                                                              0.001325
# W8Communal establishment residents:Total|Medical and care establishment: NHS: Mental health hospital/unit (including secure units)                                                                                           0.001305
# debateOneWatchW8_Yes                                                                                                                                                                                                         0.001288
# lrMayW12__Right                                                                                                                                                                                                              0.001279
# govtHandleNHSW7__Very well                                                                                                                                                                                                   0.001274
# natSecurityConW11__Protect civil liberties                                                                                                                                                                                   0.001255
# small_mii_catW7_Europe                                                                                                                                                                                                       0.001223
# effectsEUWorkersW8__Much better                                                                                                                                                                                              0.001206
# infoSourceRadioW4__More than 2 hours                                                                                                                                                                                         0.001181
# D7_8childBenefitsRepatriate__No, not at any level                                                                                                                                                                            0.001159
# ptvUKIPW7__Very likely                                                                                                                                                                                                       0.001146
# renationaliseRailW10__Strongly agree                                                                                                                                                                                         0.001131
# socialIdentityGlobalRemainW10__A great deal in common                                                                                                                                                                        0.001098
# euID4W11__Strongly agree                                                                                                                                                                                                     0.001075
# EUIntegrationSelfW16__Protect our independence                                                                                                                                                                               0.001043
# dtype: float32

# %%
var_list = list(df.mean(axis=1).sort_values(ascending=False)[df.mean(axis=1).sort_values(ascending=False)>=.01].index)

# %%
var_list
# Out:
# ['immigECSW8__Good',
#  'immigECW8__Good for Econ&Cult',
#  'D8_10immigECS',
#  'D8_10immigSelf__Allow many more',
#  'D1_7immigrantsWelfareState__Strongly agree',
#  'D8_10immigEC',
#  'D8_10immigrantsWelfareState__Strongly agree',
#  'D8_9immigCon__Allow many more',
#  'D10_17euPriorityBalance__Control immigration',
#  'D8_10ukCoopMovement__Bad for Britain',
#  'D7_8immigCon__Allow many more',
#  'D8_9immigUKIP__Allow many more',
#  'D10_17immigCon__Allow many more',
#  'D8_9immigLab__Allow many more',
#  'D10_17changeImmig__Getting a lot higher',
#  'EUIntegrationSelfW9__Protect our independence',
#  'asylumMoreW8__Many more',
#  'immigrantsWelfareStateW1__Strongly agree',
#  'D7_8immigrantsWelfareState__Strongly agree',
#  'ukCoopMovementW10__Bad for Britain',
#  'D7_8euMore__Many more',
#  'D8_9immigLD__Allow many more',
#  'D7_8asylumMore__Many more',
#  'euIDW9_The leave side',
#  'immigConW17__Allow many more',
#  'D8_10changeImmig__Getting a lot higher',
#  'changeImmigW1__Getting a lot higher',
#  'immigSelfW10__Allow many more',
#  'D1_7changeImmig__Getting a lot higher',
#  'D10_17overseasAid__Strongly agree',
#  'D9_10immigSelf__Allow many more',
#  'immigUKIPW10__Allow many more',
#  'immigConW9__Allow many more',
#  'D10_17europeanness__Very strongly European',
#  'D8_10europeanness__Very strongly European',
#  'D8_9immigGreen__Allow many more',
#  'D10_17happyEULeave__Extremely happy',
#  'D10_15ukCoopMovement__Bad for Britain',
#  'euPriorityBalanceW17__Control immigration',
#  'likeUKIPW9__Strongly like',
#  'happyEULeaveW9__Extremely happy',
#  'D10_17EUIntegrationSelf__Protect our independence',
#  'D7_8immigUKIP__Allow many more',
#  'D8_9europeanness__Very strongly European',
#  'D7_8familiesMore__Many more',
#  'small_mii_catW9_Immigration',
#  'immigUKIPW9__Allow many more',
#  'blackEqualityW17__Gone much too far',
#  'D7_8noneuMore__Many more',
#  'likeFarageW9__Strongly like',
#  'immigrantsWelfareStateW8__Strongly agree',
#  'immigrantsWelfareStateW10__Strongly agree',
#  'euMoreW8__Many more',
#  'socialIdentityGlobalRemainW9__A great deal in common',
#  'approveEUW10__Strongly approve',
#  'D8_10EUIntegrationSelf__Protect our independence',
#  'europeannessW9__Very strongly European',
#  'D8_9EUIntegrationSelf__Protect our independence',
#  'D8_9immigSNP__Allow many more',
#  'familiesMoreW8__Many more',
#  'D10_17immigGreen__Allow many more',
#  'D8_10effectsEUImmigration__Much higher',
#  'immigBrexitW17__Allow many more',
#  'euMoreW7__Many more',
#  'controlImmigW9__Complete control',
#  'britishnessW9__Very strongly British',
#  'D12_17euPriorityBalance__Control immigration',
#  'D11_17effectsEUImmigration__Much higher',
#  'noneuMoreW8__Many more',
#  'D7_8immigGreen__Allow many more',
#  'mii_catW9_immigration',
#  'D11_17euPriorityBalance__Control immigration',
#  'ptvUKIPW9__Very likely',
#  'D7_8immigLab__Allow many more',
#  'changeImmigW17__Getting a lot higher',
#  'natSecuritySelfW10__Protect civil liberties',
#  'D7_8immigLD__Allow many more',
#  'asiaW1_nino',
#  'immigContributeTakeW8__Get more than they pay',
#  'D7_8immigContributeTake__Get more than they pay',
#  'D7_8ukCoopMovement__Bad for Britain',
#  'handleMIIUKIPW9__Very well',
#  'immigSelfW8__Allow many more',
#  'immigUKIPW8__Allow many more',
#  'immigrantsWelfareStateW7__Strongly agree',
#  'immigLDW9__Allow many more',
#  'D10_17effectsEUImmigration__Much higher',
#  'changeImmigLabW1__Getting a lot higher',
#  'EUIntegrationConW9__Protect our independence',
#  'achieveReduceImmigUKIPW9_Yes',
#  'D8_9socialIdentityGlobalLeave__A great deal in common',
#  'immigConW10__Allow many more',
#  'ukCoopMovementW7__Bad for Britain',
#  'D8_10immigUKIP__Allow many more',
#  'likeMayW10__Strongly like',
#  'changeImmigW8__Getting a lot higher',
#  'euPriorityBalanceW10__Control immigration',
#  'D10_17immigLab__Allow many more',
#  'asylumMoreW7__Many more',
#  'blackEqualityW1W2W3W4W5__Gone much too far',
#  'controlImmigW8__Complete control',
#  'al2W7W8W9__Strongly agree',
#  'al3W10W11W12__Strongly agree',
#  'other_europeW8_nino',
#  'likeConW12__Strongly like',
#  'immigLabW9__Allow many more',
#  'edlevelW8W9W10__Postgrad',
#  'likeUKIPW8__Strongly like',
#  'D10_15changeImmig__Getting a lot higher',
#  'D8_9bestOnMII_No party is best able to handle this issue',
#  'ukCoopMovementW8__Bad for Britain',
#  'D10_17euLeaveVoice__Much higher',
#  'immigLabW10__Allow many more',
#  'trustCourtsW17__10.0',
#  'D1_7trustMPs__A great deal of trust',
#  'euCloserW8__Strongly agree',
#  'approveEUW9__Strongly approve',
#  'D8_9likeFarage__Strongly like']

# %%
np.unique( [[x for x in re.match("(.*)W\d+|D\d+_\d+(.*?)_",x).groups() if x][0] for x in var_list if re.match("(.*)W\d+|D\d+_\d+(.*?)_",x)] )
# Out:
# array(['EUIntegrationCon', 'EUIntegrationSelf', 'achieveReduceImmigUKIP',
#        'al2W7W8', 'al3W10W11', 'approveEU', 'asia', 'asylumMore',
#        'bestOnMII', 'blackEquality', 'blackEqualityW1W2W3W4',
#        'britishness', 'changeImmig', 'changeImmigLab', 'controlImmig',
#        'edlevelW8W9', 'effectsEUImmigration', 'euCloser', 'euID',
#        'euLeaveVoice', 'euMore', 'euPriorityBalance', 'europeanness',
#        'familiesMore', 'handleMIIUKIP', 'happyEULeave', 'immigBrexit',
#        'immigCon', 'immigContributeTake', 'immigEC', 'immigECS',
#        'immigGreen', 'immigLD', 'immigLab', 'immigSNP', 'immigSelf',
#        'immigUKIP', 'immigrantsWelfareState', 'likeCon', 'likeFarage',
#        'likeMay', 'likeUKIP', 'mii_cat', 'natSecuritySelf', 'noneuMore',
#        'other_europe', 'overseasAid', 'ptvUKIP', 'small_mii_cat',
#        'socialIdentityGlobalLeave', 'socialIdentityGlobalRemain',
#        'trustCourts', 'trustMPs', 'ukCoopMovement'], dtype='<U26')

# %%
"EUIntegrationCon|EUIntegrationSelf|achieveReduceImmigUKIP|al2|al3|approveEU|blackEquality|britishness"+\
     "|changeImmig|changeImmigLab|controlImmig|edlevel|effectsEUImmigration|euCloser|euID|euLeaveVoice|euPriorityBalance"+\
     "|europeanness|happyEULeave"+\
     "|immigBrexit|immigCon|immigGreen|immigLD|immigLab|immigSNP|immigSelf|immigUKIP"+\
     "|immigrantsWelfareState|natSecuritySelf|overseasAid|ptvUKIP"+\
     "|mii_cat|small_mii_cat|bestOnMII|handleMIIUKIP"+\
     "|noneuMore|asylumMore|euMore|familiesMore"+\
     "|likeCon|likeFarage|likeMay|likeUKIP|"+\
     "socialIdentityGlobalLeave|socialIdentityGlobalRemain"+\
     "trustCourts|trustMPs|ukCoopMovement"
# Out:
# 'EUIntegrationCon|EUIntegrationSelf|achieveReduceImmigUKIP|al2|al3|approveEU|blackEquality|britishness|changeImmig|changeImmigLab|controlImmig|edlevel|effectsEUImmigration|euCloser|euID|euLeaveVoice|euPriorityBalance|europeanness|happyEULeave|immigBrexit|immigCon|immigGreen|immigLD|immigLab|immigSNP|immigSelf|immigUKIP|immigrantsWelfareState|natSecuritySelf|overseasAid|ptvUKIP|mii_cat|small_mii_cat|bestOnMII|handleMIIUKIP|noneuMore|asylumMore|euMore|familiesMore|likeCon|likeFarage|likeMay|likeUKIP|socialIdentityGlobalLeave|socialIdentityGlobalRemaintrustCourts|trustMPs|ukCoopMovement'

# %%
# asia,other_europ

# %%
re.match("(.*)W\d+|D\d+_\d+(.*)_",'immigECSW8__Good').groups()[0]
# Out:
# 'immigECS'

# %%
[x for x in list( re.match("(.*)W\d+|D\d+_\d+(.*)_",'D8_10immigSelf__Allow many more').groups() ) if x][0]
# Out:
# 'immigSelf_'

# %%
memory_use(locs = locals().items())
# Out:
#                      BES_Panel: 797.6MiB
#               pan_dataset_ages:  24.4MiB
#                       var_type:   6.3MiB
#        pan_dataset_allr_values:   3.5MiB
#              new_old_col_names: 576.1KiB
#                            _13: 479.9KiB
#                 cat_dictionary: 288.1KiB
#              old_new_col_names: 288.1KiB
#                             df: 167.0KiB
#                            _42: 167.0KiB

# %%
var_list = list(df.mean(axis=1).sort_values(ascending=False)[df.mean(axis=1).sort_values(ascending=False)>=.005].index)

# %%
var_list
# Out:
# ['immigECSW8__Good',
#  'immigECW8__Good for Econ&Cult',
#  'D8_10immigECS',
#  'D8_10immigSelf__Allow many more',
#  'D1_7immigrantsWelfareState__Strongly agree',
#  'D8_10immigEC',
#  'D8_10immigrantsWelfareState__Strongly agree',
#  'D8_9immigCon__Allow many more',
#  'D10_17euPriorityBalance__Control immigration',
#  'D8_10ukCoopMovement__Bad for Britain',
#  'D7_8immigCon__Allow many more',
#  'D8_9immigUKIP__Allow many more',
#  'D10_17immigCon__Allow many more',
#  'D8_9immigLab__Allow many more',
#  'D10_17changeImmig__Getting a lot higher',
#  'EUIntegrationSelfW9__Protect our independence',
#  'asylumMoreW8__Many more',
#  'immigrantsWelfareStateW1__Strongly agree',
#  'D7_8immigrantsWelfareState__Strongly agree',
#  'ukCoopMovementW10__Bad for Britain',
#  'D7_8euMore__Many more',
#  'D8_9immigLD__Allow many more',
#  'D7_8asylumMore__Many more',
#  'euIDW9_The leave side',
#  'immigConW17__Allow many more',
#  'D8_10changeImmig__Getting a lot higher',
#  'changeImmigW1__Getting a lot higher',
#  'immigSelfW10__Allow many more',
#  'D1_7changeImmig__Getting a lot higher',
#  'D10_17overseasAid__Strongly agree',
#  'D9_10immigSelf__Allow many more',
#  'immigUKIPW10__Allow many more',
#  'immigConW9__Allow many more',
#  'D10_17europeanness__Very strongly European',
#  'D8_10europeanness__Very strongly European',
#  'D8_9immigGreen__Allow many more',
#  'D10_17happyEULeave__Extremely happy',
#  'D10_15ukCoopMovement__Bad for Britain',
#  'euPriorityBalanceW17__Control immigration',
#  'likeUKIPW9__Strongly like',
#  'happyEULeaveW9__Extremely happy',
#  'D10_17EUIntegrationSelf__Protect our independence',
#  'D7_8immigUKIP__Allow many more',
#  'D8_9europeanness__Very strongly European',
#  'D7_8familiesMore__Many more',
#  'small_mii_catW9_Immigration',
#  'immigUKIPW9__Allow many more',
#  'blackEqualityW17__Gone much too far',
#  'D7_8noneuMore__Many more',
#  'likeFarageW9__Strongly like',
#  'immigrantsWelfareStateW8__Strongly agree',
#  'immigrantsWelfareStateW10__Strongly agree',
#  'euMoreW8__Many more',
#  'socialIdentityGlobalRemainW9__A great deal in common',
#  'approveEUW10__Strongly approve',
#  'D8_10EUIntegrationSelf__Protect our independence',
#  'europeannessW9__Very strongly European',
#  'D8_9EUIntegrationSelf__Protect our independence',
#  'D8_9immigSNP__Allow many more',
#  'familiesMoreW8__Many more',
#  'D10_17immigGreen__Allow many more',
#  'D8_10effectsEUImmigration__Much higher',
#  'immigBrexitW17__Allow many more',
#  'euMoreW7__Many more',
#  'controlImmigW9__Complete control',
#  'britishnessW9__Very strongly British',
#  'D12_17euPriorityBalance__Control immigration',
#  'D11_17effectsEUImmigration__Much higher',
#  'noneuMoreW8__Many more',
#  'D7_8immigGreen__Allow many more',
#  'mii_catW9_immigration',
#  'D11_17euPriorityBalance__Control immigration',
#  'ptvUKIPW9__Very likely',
#  'D7_8immigLab__Allow many more',
#  'changeImmigW17__Getting a lot higher',
#  'natSecuritySelfW10__Protect civil liberties',
#  'D7_8immigLD__Allow many more',
#  'asiaW1_nino',
#  'immigContributeTakeW8__Get more than they pay',
#  'D7_8immigContributeTake__Get more than they pay',
#  'D7_8ukCoopMovement__Bad for Britain',
#  'handleMIIUKIPW9__Very well',
#  'immigSelfW8__Allow many more',
#  'immigUKIPW8__Allow many more',
#  'immigrantsWelfareStateW7__Strongly agree',
#  'immigLDW9__Allow many more',
#  'D10_17effectsEUImmigration__Much higher',
#  'changeImmigLabW1__Getting a lot higher',
#  'EUIntegrationConW9__Protect our independence',
#  'achieveReduceImmigUKIPW9_Yes',
#  'D8_9socialIdentityGlobalLeave__A great deal in common',
#  'immigConW10__Allow many more',
#  'ukCoopMovementW7__Bad for Britain',
#  'D8_10immigUKIP__Allow many more',
#  'likeMayW10__Strongly like',
#  'changeImmigW8__Getting a lot higher',
#  'euPriorityBalanceW10__Control immigration',
#  'D10_17immigLab__Allow many more',
#  'asylumMoreW7__Many more',
#  'blackEqualityW1W2W3W4W5__Gone much too far',
#  'controlImmigW8__Complete control',
#  'al2W7W8W9__Strongly agree',
#  'al3W10W11W12__Strongly agree',
#  'other_europeW8_nino',
#  'likeConW12__Strongly like',
#  'immigLabW9__Allow many more',
#  'edlevelW8W9W10__Postgrad',
#  'likeUKIPW8__Strongly like',
#  'D10_15changeImmig__Getting a lot higher',
#  'D8_9bestOnMII_No party is best able to handle this issue',
#  'ukCoopMovementW8__Bad for Britain',
#  'D10_17euLeaveVoice__Much higher',
#  'immigLabW10__Allow many more',
#  'trustCourtsW17__10.0',
#  'D1_7trustMPs__A great deal of trust',
#  'euCloserW8__Strongly agree',
#  'approveEUW9__Strongly approve',
#  'D8_9likeFarage__Strongly like',
#  'euRefVoteW9_Leave the EU',
#  'ageW8',
#  'englishnessW9__Very strongly English',
#  'immigGreenW9__Allow many more',
#  'lrgreensW11__Right',
#  'satDemEUW9__Very satisfied',
#  'euLawsLevelW8__Strongly agree',
#  'immigSelfW11__Allow many more',
#  'likeMilibandW1__Strongly like',
#  'immigLDW10__Allow many more',
#  'D9_10trustMPs__A great deal of trust',
#  'likeGoveW9__Strongly like',
#  'D9_10ptvLD__Very likely',
#  'betterDealEUW8__Much better',
#  'al_scaleW7W8W9__Authoritarian',
#  'euMoreW13__Many more',
#  'EUIntegrationConW8__Protect our independence',
#  'likeConW9__Strongly like',
#  'likeOsborneW9__Strongly like',
#  'D1_7mii_cat_immigration',
#  'D8_9likeUKIP__Strongly like',
#  'D8_9satDemEU__Very satisfied',
#  'D7_8euUKRich__Strongly agree',
#  'changeImmigW10__Getting a lot higher',
#  'small_mii_catW8_Immigration',
#  'studentsMoreW8__Many more',
#  'D7_8euCloser__Strongly agree',
#  'ageW9',
#  'warmBlackW11__Very warm',
#  'blameLeave_5W9_Yes',
#  'D7_8studentsMore__Many more',
#  'other_europeW10_nino',
#  'socialIdentityGlobalLeaveW9__A great deal in common',
#  'D9_10bestOnMII_United Kingdom Independence Party (UKIP)',
#  'changeImmigW7__Getting a lot higher',
#  'euUKRichW7__Strongly agree',
#  'likeBorisW8__Strongly like',
#  'D1_7euRefVote_Leave the EU',
#  'rest_worldW17_nino',
#  'D8_9socialIdentityGlobalRemain__A great deal in common',
#  'D8_10small_mii_cat_Immigration',
#  'mii_catW8_immigration',
#  'warmWhiteW11__Very warm',
#  'likeLabW8__Strongly like',
#  'euDominanceW8__Many more powers',
#  'ptvConW10__Very likely',
#  'D10_17effectsEUWorkers__Much better',
#  'D10_17effectsEUNHS__Much better',
#  'achieveReduceImmigNoneW9_Yes',
#  'immigConW8__Allow many more',
#  'econGenRetroW10__Got a lot better',
#  'bestOnMIIW8_Scottish National Party (SNP)',
#  'remainToneW8__5 - Hope',
#  'ptvConW9__Very likely',
#  'likeCorbynW11__Strongly like',
#  'D8_9likeBoris__Strongly like',
#  'immigLDW17__Allow many more',
#  'D8_9likeLab__Strongly like',
#  'LRAL_mii_catW1_Lib-auth',
#  'immigSNPW9__Allow many more',
#  'D1_7small_mii_cat_Immigration',
#  'likeConW10__Strongly like',
#  'EUIntegrationLabW8__Protect our independence',
#  'dnonEU_regW1_nino',
#  'D8_10effectsEUEcon__Much better',
#  'D8_10socialIdentityGlobalRemain__A great deal in common',
#  'D10_16euPriorityBalance__Control immigration',
#  'W8Passports held by sex by age:Females|Age 65 and over|Africa: Central and Western Africa',
#  'al_scaleW10W11W12__Authoritarian',
#  'brexitNextPrefW17__Leave with no deal',
#  'D10_17EUIntegrationCon__Protect our independence',
#  'D7_8effectsEUImmigration__Much higher',
#  'immigContributeTakeW7__Get more than they pay',
#  'labUnitedW8__Very united',
#  'euUndermineIdentityW8__Strongly agree',
#  'D10_17likeLab__Strongly like',
#  'EUIntegrationSelfW8__Protect our independence',
#  'monarchW8__Strongly agree',
#  'D7_8infoSourcePeople__More than 2 hours',
#  'asiaW7_nino',
#  'D8_9bestOnMII_Conservative',
#  'effectsEUImmigrationW8__Much higher',
#  'D10_11immigrantsWelfareState__Strongly agree',
#  'EUIntegrationSelfW10__Protect our independence',
#  'W8Communal establishment management and type:Total|Other establishment: Education.1',
#  'generalElectionVoteW9_Conservative',
#  'D7_8total_nino',
#  'D8_10leaveImpactBritain__A very large impact',
#  'D10_17immigLD__Allow many more',
#  'satDemEUW10__Very satisfied',
#  'immigGreenW17__Allow many more',
#  'effectsEUImmigrationW17__Much higher',
#  'dEU_regW8_nino',
#  'ptvUKIPW17__Very likely',
#  'D8_9likeGove__Strongly like',
#  'D8_10satDemEU__Very satisfied',
#  'euCloserW7__Strongly agree',
#  'immigLabW17__Allow many more',
#  'D8_10effectsEUNHS__Much better',
#  'likeCameronW8__Strongly like',
#  'D1_7satDemEU__Very satisfied',
#  'achieveReduceImmigUKIPW12_Yes',
#  'euID2W17__Strongly agree',
#  'D8_10mii_cat_immigration',
#  'euRefVoteUnsqueezeW7_Leave the EU',
#  'euPriorityBalanceW13__Control immigration',
#  'discrimBMEW10__A lot of discrimination against',
#  'D9_10euID4__Strongly agree',
#  'lr1W1W2W3W4W5__Strongly agree',
#  'blairGoodW1_Good for Britain',
#  'benefitsToMigrantsW8__Never',
#  'achieveReduceImmigUKIPW10_Yes',
#  'D10_17leftRight__Right',
#  'antiIntellectualW9__Strongly agree',
#  'populism5W10__Strongly agree',
#  'D7_8europeanness__Very strongly European',
#  'al5W10W11W12__Strongly agree',
#  'likeFarageW17__Strongly like',
#  'D10_12euPriorityBalance__Control immigration',
#  'D8_10likeUKIP__Strongly like',
#  'D10_17euLeaveBigBusiness__Much more likely',
#  'euRefDoOverW10_Yes',
#  'D10_17likeCorbyn__Strongly like',
#  'D10_17euRefDoOver_Yes',
#  'familiesMoreW7__Many more',
#  'changeEconomyW9__Getting a lot better',
#  'D10_17likeGrn__Strongly like',
#  'euID6W10__Strongly agree',
#  'leftRightW7__Right',
#  'redistLDW10__Government should be less concerned about equal incomes',
#  'negotiationSpecifics_2W9_Yes',
#  'D10_17ptvUKIP__Very likely',
#  'britishnessW10__Very strongly British',
#  'totalW10_nino',
#  'EUIntegrationSelfW1__Protect our independence',
#  'D7_8rest_world_nino',
#  'EUIntegrationUKIPW10__Protect our independence',
#  'otherW7_nino',
#  'happyEULeaveW10__Extremely happy',
#  'D7_8changeImmig__Getting a lot higher',
#  'likeMcDonnellW9__Strongly like',
#  'D10_15euPriorityBalance__Control immigration',
#  'D8_10effectsEUWorkers__Much better']

# %%
np.unique( [[x for x in re.match("(.*)W\d+|D\d+_\d+(.*?)_",x).groups() if x][0] for x in var_list if re.match("(.*)W\d+|D\d+_\d+(.*?)_",x)] )
# Out:
# array(['EUIntegrationCon', 'EUIntegrationLab', 'EUIntegrationSelf',
#        'EUIntegrationUKIP', 'LRAL_mii_cat', 'achieveReduceImmigNone',
#        'achieveReduceImmigUKIP', 'age', 'al2W7W8', 'al3W10W11',
#        'al5W10W11', 'al_scaleW10W11', 'al_scaleW7W8', 'antiIntellectual',
#        'approveEU', 'asylumMore', 'benefitsToMigrants', 'bestOnMII',
#        'betterDealEU', 'blackEquality', 'blackEqualityW1W2W3W4',
#        'blairGood', 'blameLeave_5', 'brexitNextPref', 'britishness',
#        'changeEconomy', 'changeImmig', 'changeImmigLab', 'controlImmig',
#        'discrimBME', 'econGenRetro', 'edlevelW8W9', 'effectsEUEcon',
#        'effectsEUImmigration', 'effectsEUNHS', 'effectsEUWorkers',
#        'englishness', 'euCloser', 'euDominance', 'euID', 'euID2', 'euID4',
#        'euID6', 'euLawsLevel', 'euLeaveBigBusiness', 'euLeaveVoice',
#        'euMore', 'euPriorityBalance', 'euRefDoOver', 'euRefVote',
#        'euRefVoteUnsqueeze', 'euUKRich', 'euUndermineIdentity',
#        'europeanness', 'familiesMore', 'generalElectionVote',
#        'handleMIIUKIP', 'happyEULeave', 'immigBrexit', 'immigCon',
#        'immigContributeTake', 'immigEC', 'immigECS', 'immigGreen',
#        'immigLD', 'immigLab', 'immigSNP', 'immigSelf', 'immigUKIP',
#        'immigrantsWelfareState', 'infoSourcePeople', 'labUnited',
#        'leaveImpactBritain', 'leftRight', 'likeBoris', 'likeCameron',
#        'likeCon', 'likeCorbyn', 'likeFarage', 'likeGove', 'likeGrn',
#        'likeLab', 'likeMay', 'likeMcDonnell', 'likeMiliband',
#        'likeOsborne', 'likeUKIP', 'lr1W1W2W3W4', 'lrgreens', 'mii',
#        'mii_cat', 'monarch', 'natSecuritySelf', 'negotiationSpecifics_2',
#        'noneuMore', 'overseasAid', 'populism5', 'ptvCon', 'ptvLD',
#        'ptvUKIP', 'redistLD', 'remainTone', 'satDemEU', 'small',
#        'small_mii_cat', 'socialIdentityGlobalLeave',
#        'socialIdentityGlobalRemain', 'studentsMore', 'trustCourts',
#        'trustMPs', 'ukCoopMovement', 'warmBlack', 'warmWhite'],
#       dtype='<U26')

# %%
# 'W8Passports held by sex by age:Females|Age 65 and over|Africa: Central and Western Africa',
# 'W8Communal establishment management and type:Total|Other establishment: Education.1'
# ['asiaW1_nino', 'other_europeW8_nino', 'other_europeW10_nino', 'rest_worldW17_nino', 'dnonEU_regW1_nino', 'asiaW7_nino', 'D7_8total_nino', 'dEU_regW8_nino', 'totalW10_nino', 'D7_8rest_world_nino', 'otherW7_nino']

# %%
var_list = [x for x in var_list if ("nino" not in x) and (x not in ['W8Passports held by sex by age:Females|Age 65 and over|Africa: Central and Western Africa','W8Communal establishment management and type:Total|Other establishment: Education.1'])]

# %%
nino_vars
# Out:
# ['asiaW1_nino',
#  'other_europeW8_nino',
#  'other_europeW10_nino',
#  'rest_worldW17_nino',
#  'dnonEU_regW1_nino',
#  'asiaW7_nino',
#  'D7_8total_nino',
#  'dEU_regW8_nino',
#  'totalW10_nino',
#  'D7_8rest_world_nino',
#  'otherW7_nino']

# %%
['EUIntegration',
       'LRAL_mii_cat', 'achieveReduceImmig',
       'age', 'al1|al2|al3|al4|al5',
       'antiIntellectual',
       'approveEU', 'asylumMore', 'benefitsToMigrants', 'bestOnMII',
       'betterDealEU', 'blackEquality',
       'blairGood', 'blameLeave', 'brexitNextPref', 'britishness',
       'changeEconomy', 'changeImmig', 'controlImmig',
       'discrimBME', 'econGenRetro', 'edlevel', 'effectsEU',
       'englishness', 'euCloser', 'euDominance', 'euID',
       'euLawsLevel', 'euLeaveBigBusiness', 'euLeaveVoice',
       'euMore', 'euPriorityBalance', 'euRefDoOver', 'euRefVote',
       'euUKRich', 'euUndermineIdentity',
       'europeanness', 'familiesMore', 'generalElectionVote',
       'handleMIIUKIP', 'happyEULeave', 'immigBrexit', 'immigCon',
       'immigContributeTake', 'immigGreen',
       'immigLD', 'immigLab', 'immigSNP', 'immigUKIP',
       'immigrantsWelfareState', 'infoSourcePeople', 'labUnited',
       'leaveImpactBritain', 'leftRight', 'likeBoris', 'likeCameron',
       'likeCon', 'likeCorbyn', 'likeFarage', 'likeGove', 'likeGrn',
       'likeLab', 'likeMay', 'likeMcDonnell', 'likeMiliband',
       'likeOsborne', 'likeUKIP', 'lr1', 'lrgreens', 'mii',
       'mii_cat', 'monarch', 'natSecuritySelf', 'negotiationSpecifics',
       'noneuMore', 'overseasAid', 'populism', 'ptvCon', 'ptvLD',
       'ptvUKIP', 'redistLD', 'remainTone', 'satDemEU', 'small',
       'socialIdentityGlobalLeave',
       'socialIdentityGlobalRemain', 'studentsMore', 'trustCourts',
       'trustMPs', 'ukCoopMovement', 'warmBlack', 'warmWhite']
# Out:
# (['EUIntegration',
#   'LRAL_mii_cat',
#   'achieveReduceImmig',
#   'age',
#   'al1|al2|al3|al4|al5',
#   'antiIntellectual',
#   'approveEU',
#   'asylumMore',
#   'benefitsToMigrants',
#   'bestOnMII',
#   'betterDealEU',
#   'blackEquality',
#   'blairGood',
#   'blameLeave',
#   'brexitNextPref',
#   'britishness',
#   'changeEconomy',
#   'changeImmig',
#   'controlImmig',
#   'discrimBME',
#   'econGenRetro',
#   'edlevel',
#   'effectsEU',
#   'englishness',
#   'euCloser',
#   'euDominance',
#   'euID',
#   'euLawsLevel',
#   'euLeaveBigBusiness',
#   'euLeaveVoice',
#   'euMore',
#   'euPriorityBalance',
#   'euRefDoOver',
#   'euRefVote',
#   'euUKRich',
#   'euUndermineIdentity',
#   'europeanness',
#   'familiesMore',
#   'generalElectionVote',
#   'handleMIIUKIP',
#   'happyEULeave',
#   'immigBrexit',
#   'immigCon',
#   'immigContributeTake',
#   'immigGreen',
#   'immigLD',
#   'immigLab',
#   'immigSNP',
#   'immigUKIP',
#   'immigrantsWelfareState',
#   'infoSourcePeople',
#   'labUnited',
#   'leaveImpactBritain',
#   'leftRight',
#   'likeBoris',
#   'likeCameron',
#   'likeCon',
#   'likeCorbyn',
#   'likeFarage',
#   'likeGove',
#   'likeGrn',
#   'likeLab',
#   'likeMay',
#   'likeMcDonnell',
#   'likeMiliband',
#   'likeOsborne',
#   'likeUKIP',
#   'lr1',
#   'lrgreens',
#   'mii',
#   'mii_cat',
#   'monarch',
#   'natSecuritySelf',
#   'negotiationSpecifics',
#   'noneuMore',
#   'overseasAid',
#   'populism',
#   'ptvCon',
#   'ptvLD',
#   'ptvUKIP',
#   'redistLD',
#   'remainTone',
#   'satDemEU',
#   'small',
#   'socialIdentityGlobalLeave',
#   'socialIdentityGlobalRemain',
#   'studentsMore',
#   'trustCourts',
#   'trustMPs',
#   'ukCoopMovement',
#   'warmBlack',
#   'warmWhite'],)

# %%
gc.collect()
# Out:
# 20

# %%
from sklearn import preprocessing
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import RFE
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from statsmodels.stats.outliers_influence import variance_inflation_factor  
def calculate_vif_(X):
    variables = list(X.columns)
    vif = {variable:variance_inflation_factor(exog=X.values, exog_idx=ix) for ix,variable in enumerate(list(X.columns))}
    return vif
from scipy import stats
stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)

# %%
X_sm = X[minus_immig_vars]
X_sm['genImmigSentiment'] = (genImmigSentiment[ImmBadW8].values - genImmigSentiment[ImmBadW8].values.mean())/genImmigSentiment[ImmBadW8].values.std()
# X_sm["intercept"] = 1.0
logit_model=sm.Logit(y,X_sm)
result=logit_model.fit()
print(result.summary())

# %%
BES_reduced_with_na
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-119-e77e8f0720f2> in <module>
# ----> 1 BES_reduced_with_na
#
# NameError: name 'BES_reduced_with_na' is not defined

# %%
BES_reduced_with_na
# Out:
#        turnoutUKGeneralW1__Very likely that I will vote  \
# 0                                                  <NA>
# 1                                                     4
# 2                                                  <NA>
# 3                                                  <NA>
# 4                                                  <NA>
# ...                                                 ...
# 97153                                                 4
# 97154                                              <NA>
# 97155                                              <NA>
# 97156                                                 0
# 97157                                              <NA>
#
#        turnoutUKGeneralW2__Very likely that I will vote  \
# 0                                                  <NA>
# 1                                                     4
# 2                                                  <NA>
# 3                                                     4
# 4                                                  <NA>
# ...                                                 ...
# 97153                                                 4
# 97154                                              <NA>
# 97155                                              <NA>
# 97156                                                 0
# 97157                                              <NA>
#
#        turnoutUKGeneralW3__Very likely that I will vote  \
# 0                                                  <NA>
# 1                                                     4
# 2                                                  <NA>
# 3                                                     4
# 4                                                  <NA>
# ...                                                 ...
# 97153                                                 4
# 97154                                              <NA>
# 97155                                              <NA>
# 97156                                              <NA>
# 97157                                              <NA>
#
#        turnoutUKGeneralW4__Very likely that I will vote  \
# 0                                                  <NA>
# 1                                                     4
# 2                                                  <NA>
# 3                                                     3
# 4                                                  <NA>
# ...                                                 ...
# 97153                                                 4
# 97154                                                 4
# 97155                                              <NA>
# 97156                                              <NA>
# 97157                                              <NA>
#
#        turnoutUKGeneralW5__Very likely that I will vote  \
# 0                                                  <NA>
# 1                                                  <NA>
# 2                                                  <NA>
# 3                                                     4
# 4                                                  <NA>
# ...                                                 ...
# 97153                                                 4
# 97154                                                 4
# 97155                                              <NA>
# 97156                                              <NA>
# 97157                                              <NA>
#
#        turnoutUKGeneralW7__Very likely that I will vote  \
# 0                                                  <NA>
# 1                                                     4
# 2                                                  <NA>
# 3                                                     3
# 4                                                  <NA>
# ...                                                 ...
# 97153                                              <NA>
# 97154                                                 4
# 97155                                              <NA>
# 97156                                              <NA>
# 97157                                              <NA>
#
#        turnoutUKGeneralW8__Very likely that I will vote  \
# 0                                                  <NA>
# 1                                                     4
# 2                                                  <NA>
# 3                                                     4
# 4                                                  <NA>
# ...                                                 ...
# 97153                                              <NA>
# 97154                                                 4
# 97155                                                 3
# 97156                                              <NA>
# 97157                                                 4
#
#        turnoutUKGeneralW9__Very likely that I will vote  \
# 0                                                     4
# 1                                                     4
# 2                                                  <NA>
# 3                                                     4
# 4                                                  <NA>
# ...                                                 ...
# 97153                                              <NA>
# 97154                                                 4
# 97155                                              <NA>
# 97156                                              <NA>
# 97157                                                 4
#
#        turnoutUKGeneralW10__Very likely that I will vote  \
# 0                                                   <NA>
# 1                                                      4
# 2                                                   <NA>
# 3                                                      4
# 4                                                   <NA>
# ...                                                  ...
# 97153                                               <NA>
# 97154                                               <NA>
# 97155                                               <NA>
# 97156                                               <NA>
# 97157                                               <NA>
#
#        turnoutUKGeneralW11__Very likely that I will vote  ...  \
# 0                                                      4  ...
# 1                                                      4  ...
# 2                                                      3  ...
# 3                                                      4  ...
# 4                                                   <NA>  ...
# ...                                                  ...  ...
# 97153                                               <NA>  ...
# 97154                                               <NA>  ...
# 97155                                               <NA>  ...
# 97156                                               <NA>  ...
# 97157                                                  4  ...
#
#        conPriorities2_schoolW4_Yes  conPriorities2_nhsW4_Yes  \
# 0                             <NA>                      <NA>
# 1                             <NA>                      <NA>
# 2                             <NA>                      <NA>
# 3                             <NA>                      <NA>
# 4                             <NA>                      <NA>
# ...                            ...                       ...
# 97153                        False                     False
# 97154                         <NA>                      <NA>
# 97155                         <NA>                      <NA>
# 97156                         <NA>                      <NA>
# 97157                         <NA>                      <NA>
#
#        conPriorities2_costLiveW4_Yes  \
# 0                               <NA>
# 1                               <NA>
# 2                               <NA>
# 3                               <NA>
# 4                               <NA>
# ...                              ...
# 97153                          False
# 97154                           <NA>
# 97155                           <NA>
# 97156                           <NA>
# 97157                           <NA>
#
#        devoResponsibleWalesJusticeW2_The UK Parliament  \
# 0                                                 <NA>
# 1                                                 True
# 2                                                 <NA>
# 3                                                False
# 4                                                 <NA>
# ...                                                ...
# 97153                                             <NA>
# 97154                                             <NA>
# 97155                                             <NA>
# 97156                                             <NA>
# 97157                                             <NA>
#
#        conPriorities2_immigW4_Yes  conPriorities2_crimeW4_Yes  \
# 0                            <NA>                        <NA>
# 1                            <NA>                        <NA>
# 2                            <NA>                        <NA>
# 3                            <NA>                        <NA>
# 4                            <NA>                        <NA>
# ...                           ...                         ...
# 97153                       False                       False
# 97154                        <NA>                        <NA>
# 97155                        <NA>                        <NA>
# 97156                        <NA>                        <NA>
# 97157                        <NA>                        <NA>
#
#        sharedContentOnline_1W5_Yes  partySiteOthW5_Yes  euCitizenW1_Yes  \
# 0                            False                <NA>            False
# 1                             <NA>                <NA>            False
# 2                             <NA>                <NA>             <NA>
# 3                            False                <NA>             <NA>
# 4                             <NA>                <NA>             <NA>
# ...                            ...                 ...              ...
# 97153                        False                <NA>            False
# 97154                         <NA>                <NA>             <NA>
# 97155                         <NA>                <NA>             <NA>
# 97156                         <NA>                <NA>            False
# 97157                         <NA>                <NA>             <NA>
#
#        conPriorities2_natsecW4_Yes
# 0                             <NA>
# 1                             <NA>
# 2                             <NA>
# 3                             <NA>
# 4                             <NA>
# ...                            ...
# 97153                         True
# 97154                         <NA>
# 97155                         <NA>
# 97156                         <NA>
# 97157                         <NA>
#
# [97158 rows x 11963 columns]

# %%
search(BES_reduced_with_na,"redistSelf",mask=BES_reduced_with_na["profile_education_age__Still at school/Full time student"].notnull())
# Out:
# redistSelfW1__Government should be less concerned about equal incomes     27034
# redistSelfW2__Government should be less concerned about equal incomes     25758
# redistSelfW3__Government should be less concerned about equal incomes     24416
# redistSelfW4__Government should be less concerned about equal incomes     27410
# redistSelfW6__Government should be less concerned about equal incomes     26880
# redistSelfW7__Government should be less concerned about equal incomes     20741
# redistSelfW10__Government should be less concerned about equal incomes    17905
# redistSelfW11__Government should be less concerned about equal incomes    19131
# redistSelfW12__Government should be less concerned about equal incomes     5383
# redistSelfW13__Government should be less concerned about equal incomes    19153
# redistSelfW14__Government should be less concerned about equal incomes    16343
# redistSelfW15__Government should be less concerned about equal incomes    14468
# redistSelfW16__Government should be less concerned about equal incomes    11662
# redistSelfW17__Government should be less concerned about equal incomes    12494
# redistSelfW18__Government should be less concerned about equal incomes    15188
# redistSelfW19__Government should be less concerned about equal incomes    13108
# dtype: int64

# %%
search(BES_reduced_with_na,"redistSelf",mask=BES_reduced_with_na["profile_gross_household__£150,000 and over"].notnull())
# Out:
# redistSelfW1__Government should be less concerned about equal incomes     20419
# redistSelfW2__Government should be less concerned about equal incomes     19579
# redistSelfW3__Government should be less concerned about equal incomes     18516
# redistSelfW4__Government should be less concerned about equal incomes     21008
# redistSelfW6__Government should be less concerned about equal incomes     20591
# redistSelfW7__Government should be less concerned about equal incomes     15901
# redistSelfW10__Government should be less concerned about equal incomes    14015
# redistSelfW11__Government should be less concerned about equal incomes    14897
# redistSelfW12__Government should be less concerned about equal incomes     4162
# redistSelfW13__Government should be less concerned about equal incomes    14953
# redistSelfW14__Government should be less concerned about equal incomes    12571
# redistSelfW15__Government should be less concerned about equal incomes    11127
# redistSelfW16__Government should be less concerned about equal incomes     8976
# redistSelfW17__Government should be less concerned about equal incomes     9634
# redistSelfW18__Government should be less concerned about equal incomes    11667
# redistSelfW19__Government should be less concerned about equal incomes    10058
# dtype: int64

# %%
search(BES_reduced_with_na,"profile_education_age")
# Out:
# profile_education_ageW7__Still at school/Full time student                                                                                            29686
# profile_education_ageW13__Still at school/Full time student                                                                                           30471
# profile_education_ageW18__Semi-Skilled or Unskilled Manual Work (e.g. machine operator, assembler, postman, waitress, cleaner, labourer, driver, b    37221
# profile_education_ageW19__e                                                                                                                           31511
# profile_education_age__Still at school/Full time student                                                                                              49513
# dtype: int64

# %%
search(BES_reduced_with_na,"profile_gross")
# Out:
# profile_gross_householdW7__£150,000 and over     22540
# profile_gross_personalW7__£100,000 and over      23165
# profile_gross_householdW10__£150,000 and over    22543
# profile_gross_householdW11__£150,000 and over    22800
# profile_gross_householdW12__£150,000 and over    25263
# profile_gross_householdW13__£150,000 and over    23264
# profile_gross_householdW14__£150,000 and over    22786
# profile_gross_householdW15__£150,000 and over    23169
# profile_gross_householdW17__£150,000 and over    25013
# profile_gross_householdW18__£150,000 and over    28091
# profile_gross_personalW18__£100,000 and over     27958
# profile_gross_householdW19__£150,000 and over    23913
# profile_gross_personalW19__£100,000 and over     23878
# profile_gross_household__£150,000 and over       36951
# profile_gross_personal__£100,000 and over        38674
# profile_gross_householdW16__£150,000 and over    27458
# dtype: int64

# %%
BES_Panel["profile_gross_household"]
# Out:
# 0          Â£5,000 to Â£9,999 per year
# 1        Â£30,000 to Â£34,999 per year
# 2        Â£15,000 to Â£19,999 per year
# 3        Â£35,000 to Â£39,999 per year
# 4                                  NaN
#                      ...
# 97153    Â£25,000 to Â£29,999 per year
# 97154    Â£70,000 to Â£99,999 per year
# 97155                              NaN
# 97156    Â£20,000 to Â£24,999 per year
# 97157                              NaN
# Name: profile_gross_household, Length: 97158, dtype: category
# Categories (17, object): [under Â£5,000 per year < Â£5,000 to Â£9,999 per year < Â£10,000 to Â£14,999 per year < Â£15,000 to Â£19,999 per year ... Â£100,000 to Â£149,999 per year < Â£150,000 and over < Prefer not to answer < Don't know]

# %%
BES_reduced_with_na["profile_gross_household__£150,000 and over"]
# Out:
# 0           1
# 1           6
# 2           3
# 3           7
# 4        <NA>
#          ...
# 97153       5
# 97154      12
# 97155    <NA>
# 97156       4
# 97157    <NA>
# Name: profile_gross_household__£150,000 and over, Length: 97158, dtype: Int8

# %%
BES_Panel["profile_gross_household"].cat.categories
# Out:
# Index(['under Â£5,000 per year', 'Â£5,000 to Â£9,999 per year',
#        'Â£10,000 to Â£14,999 per year', 'Â£15,000 to Â£19,999 per year',
#        'Â£20,000 to Â£24,999 per year', 'Â£25,000 to Â£29,999 per year',
#        'Â£30,000 to Â£34,999 per year', 'Â£35,000 to Â£39,999 per year',
#        'Â£40,000 to Â£44,999 per year', 'Â£45,000 to Â£49,999 per year',
#        'Â£50,000 to Â£59,999 per year', 'Â£60,000 to Â£69,999 per year',
#        'Â£70,000 to Â£99,999 per year', 'Â£100,000 to Â£149,999 per year',
#        'Â£150,000 and over', 'Prefer not to answer', 'Don't know'],
#       dtype='object')

# %%
BES_Panel["profile_gross_household"].cat.categories[:-2]
# Out:
# Index(['under Â£5,000 per year', 'Â£5,000 to Â£9,999 per year',
#        'Â£10,000 to Â£14,999 per year', 'Â£15,000 to Â£19,999 per year',
#        'Â£20,000 to Â£24,999 per year', 'Â£25,000 to Â£29,999 per year',
#        'Â£30,000 to Â£34,999 per year', 'Â£35,000 to Â£39,999 per year',
#        'Â£40,000 to Â£44,999 per year', 'Â£45,000 to Â£49,999 per year',
#        'Â£50,000 to Â£59,999 per year', 'Â£60,000 to Â£69,999 per year',
#        'Â£70,000 to Â£99,999 per year', 'Â£100,000 to Â£149,999 per year',
#        'Â£150,000 and over'],
#       dtype='object')

# %%
np.log(5000),np.log(10000),
np.log([5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,60000,70000,100000,150000,200000,np.nan,np.nan])
# Out:
# array([ 8.51719319,  9.21034037,  9.61580548,  9.90348755, 10.1266311 ,
#        10.30895266, 10.46310334, 10.59663473, 10.71441777, 10.81977828,
#        11.00209984, 11.15625052, 11.51292546, 11.91839057, 12.20607265,
#                nan,         nan])

# %%
gross_household_replace_dict = dict(zip(BES_Panel["profile_gross_household"].cat.categories,np.log([5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,60000,70000,100000,150000,200000,np.nan,np.nan])))

# %%
BES_Panel["profile_gross_personal"].cat.categories
# Out:
# Index(['under Â£5,000 per year', 'Â£5,000 to Â£9,999 per year',
#        'Â£10,000 to Â£14,999 per year', 'Â£15,000 to Â£19,999 per year',
#        'Â£20,000 to Â£24,999 per year', 'Â£25,000 to Â£29,999 per year',
#        'Â£30,000 to Â£34,999 per year', 'Â£35,000 to Â£39,999 per year',
#        'Â£40,000 to Â£44,999 per year', 'Â£45,000 to Â£49,999 per year',
#        'Â£50,000 to Â£59,999 per year', 'Â£60,000 to Â£69,999 per year',
#        'Â£70,000 to Â£99,999 per year', 'Â£100,000 and over',
#        'Prefer not to answer', 'Don't know'],
#       dtype='object')

# %%
gross_personal_replace_dict = dict(zip(BES_Panel["profile_gross_personal"].cat.categories,np.log([5000,10000,15000,20000,25000,30000,35000,40000,45000,50000,60000,70000,100000,150000,np.nan,np.nan])))

# %%
df = BES_reduced_with_na[["profile_education_age__Still at school/Full time student","redistSelfW1__Government should be less concerned about equal incomes"]]

# %%
df["profile_gross_household"] = BES_Panel["profile_gross_household"].replace(gross_household_replace_dict)

# %%
df = df.dropna()
X = df[["profile_education_age__Still at school/Full time student","profile_gross_household"]].astype('float32')
y = df["redistSelfW1__Government should be less concerned about equal incomes"].astype('float32')

# %%
# X_sm = X[minus_immig_vars]
# X_sm['genImmigSentiment'] = (genImmigSentiment[ImmBadW8].values - genImmigSentiment[ImmBadW8].values.mean())/genImmigSentiment[ImmBadW8].values.std()
# X_sm["intercept"] = 1.0
# X = (X-X.mean())/X.std()
X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                                       OLS Regression Results
# =================================================================================================================================
# Dep. Variable:     redistSelfW1__Government should be less concerned about equal incomes   R-squared:                       0.048
# Model:                                                                               OLS   Adj. R-squared:                  0.048
# Method:                                                                    Least Squares   F-statistic:                     515.1
# Date:                                                                   Fri, 10 Apr 2020   Prob (F-statistic):          5.71e-219
# Time:                                                                           12:47:23   Log-Likelihood:                -51570.
# No. Observations:                                                                  20369   AIC:                         1.031e+05
# Df Residuals:                                                                      20366   BIC:                         1.032e+05
# Df Model:                                                                              2
# Covariance Type:                                                               nonrobust
# ============================================================================================================================
#                                                                coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------
# const                                                        4.2784      0.021    200.643      0.000       4.237       4.320
# profile_education_age__Still at school/Full time student    -0.0089      0.022     -0.403      0.687      -0.052       0.034
# profile_gross_household                                      0.6867      0.022     31.081      0.000       0.643       0.730
# ==============================================================================
# Omnibus:                     2788.377   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              828.526
# Skew:                           0.217   Prob(JB):                    1.22e-180
# Kurtosis:                       2.112   Cond. No.                         1.31
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
BES_Panel["profile_education_age"]
# Out:
# 0        15 or under
# 1                20+
# 2                 16
# 3                 16
# 4                NaN
#             ...
# 97153            20+
# 97154            20+
# 97155            NaN
# 97156          17-18
# 97157            NaN
# Name: profile_education_age, Length: 97158, dtype: category
# Categories (7, object): [15 or under < 16 < 17-18 < 19 < 20+ < Still at school/Full time student < Can't remember]

# %%
search(BES_Panel,"edlevel")
# Out:
# edlevelW1_W6      35625
# edlevelW7         28633
# edlevelW8W9W10    40615
# edlevelW11        28823
# edlevelW12        32014
# edlevelW13        29078
# edlevelW14        28821
# edlevelW15        28518
# edlevelW16        34904
# edlevelW17        29354
# edlevelW18        31916
# edlevelW19        29830
# dtype: int64

# %%
BES_Panel["edlevelW1_W6"]
# Out:
# 0        No qualifications
# 1                     GCSE
# 2                      NaN
# 3                  A-level
# 4                      NaN
#                ...
# 97153        Undergraduate
# 97154        Undergraduate
# 97155                  NaN
# 97156                  NaN
# 97157                  NaN
# Name: edlevelW1_W6, Length: 97158, dtype: category
# Categories (6, object): [No qualifications < Below GCSE < GCSE < A-level < Undergraduate < Postgrad]

# %%
search(BES_reduced_with_na,"edlevel")
# Out:
# edlevelW1_W6__Postgrad      35625
# edlevelW7__Postgrad         28633
# edlevelW8W9W10__Postgrad    40615
# edlevelW11__Postgrad        28823
# edlevelW12__Postgrad        32014
# edlevelW13__Postgrad        29078
# edlevelW14__Postgrad        28821
# edlevelW15__Postgrad        28518
# edlevelW16__Postgrad        34904
# edlevelW17__Postgrad        29354
# edlevelW18__Postgrad        31916
# edlevelW19__Postgrad        29830
# dtype: int64

# %%
df = BES_reduced_with_na[["edlevelW1_W6__Postgrad","redistSelfW1__Government should be less concerned about equal incomes","Age"]]
df["profile_gross_household"] = BES_Panel["profile_gross_household"].replace(gross_household_replace_dict)

# %%
df = df.dropna()
X = df[["edlevelW1_W6__Postgrad","profile_gross_household","Age"]].astype('float32')
y = df["redistSelfW1__Government should be less concerned about equal incomes"].astype('float32')

# %%
# X_sm = X[minus_immig_vars]
# X_sm['genImmigSentiment'] = (genImmigSentiment[ImmBadW8].values - genImmigSentiment[ImmBadW8].values.mean())/genImmigSentiment[ImmBadW8].values.std()
# X_sm["intercept"] = 1.0
# X = (X-X.mean())/X.std()
X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                                       OLS Regression Results
# =================================================================================================================================
# Dep. Variable:     redistSelfW1__Government should be less concerned about equal incomes   R-squared:                       0.047
# Model:                                                                               OLS   Adj. R-squared:                  0.047
# Method:                                                                    Least Squares   F-statistic:                     282.8
# Date:                                                                   Fri, 10 Apr 2020   Prob (F-statistic):          3.13e-179
# Time:                                                                           12:55:29   Log-Likelihood:                -43527.
# No. Observations:                                                                  17242   AIC:                         8.706e+04
# Df Residuals:                                                                      17238   BIC:                         8.709e+04
# Df Model:                                                                              3
# Covariance Type:                                                               nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -6.0155      0.358    -16.818      0.000      -6.717      -5.314
# edlevelW1_W6__Postgrad      0.0179      0.018      0.997      0.319      -0.017       0.053
# profile_gross_household     0.9303      0.034     27.232      0.000       0.863       0.997
# Age                         0.0104      0.002      6.762      0.000       0.007       0.013
# ==============================================================================
# Omnibus:                     2248.416   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              709.927
# Skew:                           0.236   Prob(JB):                    6.94e-155
# Kurtosis:                       2.125   Cond. No.                         854.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
search(BES_reduced_with_na,"lr1")
# Out:
# lr1W6__Strongly agree            28906
# lr1W13__Strongly agree           29384
# lr1W16__Strongly agree           35291
# lr1W17__Strongly agree           32078
# lr1W1W2W3W4W5__Strongly agree    39939
# lr1W14W15__Strongly agree        33899
# lr1W7W8W9__Strongly agree        37764
# lr1W10W11W12__Strongly agree     32143
# dtype: int64

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"

df = BES_reduced_with_na[["edlevelW1_W6__Postgrad",redist_var,"Age"]]
df["profile_gross_household"] = BES_Panel["profile_gross_household"].replace(gross_household_replace_dict)

df = df.dropna()
X = df[["edlevelW1_W6__Postgrad","profile_gross_household","Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.035
# Model:                                       OLS   Adj. R-squared:                  0.035
# Method:                            Least Squares   F-statistic:                     303.5
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):          1.38e-193
# Time:                                   15:56:29   Log-Likelihood:                -39144.
# No. Observations:                          25331   AIC:                         7.830e+04
# Df Residuals:                              25327   BIC:                         7.833e+04
# Df Model:                                      3
# Covariance Type:                       nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       5.5115      0.107     51.425      0.000       5.301       5.722
# edlevelW1_W6__Postgrad      0.0296      0.006      5.284      0.000       0.019       0.041
# profile_gross_household    -0.3043      0.010    -29.389      0.000      -0.325      -0.284
# Age                         0.0015      0.000      3.389      0.001       0.001       0.002
# ==============================================================================
# Omnibus:                     1919.523   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1195.758
# Skew:                          -0.405   Prob(JB):                    2.21e-260
# Kurtosis:                       2.310   Cond. No.                         789.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"
income_var = "profile_gross_household"

df = BES_reduced_with_na[["edlevelW1_W6__Postgrad",redist_var,"Age"]]
df[income_var] = BES_Panel[income_var].replace(gross_household_replace_dict)

ed_vars = list(BES_Panel["edlevelW1_W6"].cat.categories)
ed_vars.remove('No qualifications')
df[ed_vars] = pd.get_dummies(BES_Panel["edlevelW1_W6"],drop_first=True)

df = df.dropna()
X = df[ed_vars+[income_var,"Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.039
# Model:                                       OLS   Adj. R-squared:                  0.039
# Method:                            Least Squares   F-statistic:                     146.3
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):          1.44e-212
# Time:                                   16:21:06   Log-Likelihood:                -39089.
# No. Observations:                          25331   AIC:                         7.819e+04
# Df Residuals:                              25323   BIC:                         7.826e+04
# Df Model:                                      7
# Covariance Type:                       nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       5.7525      0.110     52.384      0.000       5.537       5.968
# Below GCSE                 -0.1297      0.042     -3.119      0.002      -0.211      -0.048
# GCSE                       -0.1237      0.030     -4.136      0.000      -0.182      -0.065
# A-level                    -0.1449      0.031     -4.714      0.000      -0.205      -0.085
# Undergraduate              -0.0448      0.029     -1.519      0.129      -0.103       0.013
# Postgrad                    0.1376      0.035      3.942      0.000       0.069       0.206
# profile_gross_household    -0.3098      0.010    -29.938      0.000      -0.330      -0.290
# Age                         0.0009      0.000      1.919      0.055   -1.85e-05       0.002
# ==============================================================================
# Omnibus:                     1840.844   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1184.855
# Skew:                          -0.408   Prob(JB):                    5.15e-258
# Kurtosis:                       2.324   Cond. No.                         811.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"
income_var = "profile_gross_household"

df = BES_reduced_with_na[["edlevelW1_W6__Postgrad",redist_var,"Age"]]
df[income_var] = BES_Panel[income_var].replace(gross_household_replace_dict)


ed_vars = list(BES_Panel["edlevelW1_W6"].cat.categories)
# ed_vars.remove('No qualifications')
df[ed_vars] = pd.get_dummies(BES_Panel["edlevelW1_W6"],drop_first=False)

df = df.dropna()
X = df[ed_vars+[income_var,"Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.039
# Model:                                       OLS   Adj. R-squared:                  0.039
# Method:                            Least Squares   F-statistic:                     146.3
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):          1.44e-212
# Time:                                   16:21:30   Log-Likelihood:                -39089.
# No. Observations:                          25331   AIC:                         7.819e+04
# Df Residuals:                              25323   BIC:                         7.826e+04
# Df Model:                                      7
# Covariance Type:                       nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       4.8871      0.094     51.870      0.000       4.702       5.072
# No qualifications           0.8654      0.027     32.593      0.000       0.813       0.917
# Below GCSE                  0.7357      0.032     23.052      0.000       0.673       0.798
# GCSE                        0.7417      0.021     35.157      0.000       0.700       0.783
# A-level                     0.7205      0.022     33.441      0.000       0.678       0.763
# Undergraduate               0.8207      0.022     37.599      0.000       0.778       0.863
# Postgrad                    1.0030      0.028     35.585      0.000       0.948       1.058
# profile_gross_household    -0.3098      0.010    -29.938      0.000      -0.330      -0.290
# Age                         0.0009      0.000      1.919      0.055   -1.85e-05       0.002
# ==============================================================================
# Omnibus:                     1840.844   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1184.855
# Skew:                          -0.408   Prob(JB):                    5.15e-258
# Kurtosis:                       2.324   Cond. No.                     4.54e+15
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.34e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"
income_var = "profile_gross_household"

df = BES_reduced_with_na[["edlevelW1_W6__Postgrad",redist_var,"Age"]]
df[income_var] = BES_Panel[income_var].replace(gross_household_replace_dict)

drop_var = "Undergraduate"
ed_vars = list(BES_Panel["edlevelW1_W6"].cat.categories)
ed_vars.remove(drop_var)
df[ed_vars] = pd.get_dummies(BES_Panel["edlevelW1_W6"],drop_first=False).drop(drop_var,axis=1)

df = df.dropna()
X = df[ed_vars+[income_var,"Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.039
# Model:                                       OLS   Adj. R-squared:                  0.039
# Method:                            Least Squares   F-statistic:                     146.3
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):          1.44e-212
# Time:                                   16:26:26   Log-Likelihood:                -39089.
# No. Observations:                          25331   AIC:                         7.819e+04
# Df Residuals:                              25323   BIC:                         7.826e+04
# Df Model:                                      7
# Covariance Type:                       nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                       5.7078      0.112     50.916      0.000       5.488       5.928
# No qualifications           0.0448      0.029      1.519      0.129      -0.013       0.103
# Below GCSE                 -0.0850      0.035     -2.395      0.017      -0.155      -0.015
# GCSE                       -0.0790      0.020     -3.915      0.000      -0.119      -0.039
# A-level                    -0.1001      0.020     -5.061      0.000      -0.139      -0.061
# Postgrad                    0.1824      0.025      7.305      0.000       0.133       0.231
# profile_gross_household    -0.3098      0.010    -29.938      0.000      -0.330      -0.290
# Age                         0.0009      0.000      1.919      0.055   -1.85e-05       0.002
# ==============================================================================
# Omnibus:                     1840.844   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1184.855
# Skew:                          -0.408   Prob(JB):                    5.15e-258
# Kurtosis:                       2.324   Cond. No.                         829.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"
income_var = "profile_gross_household"
ed_var = "anyUniW7"
# drop_var = "No, I have never attended higher education"
drop_var = ["Yes, but I didn't complete higher education","Yes, I am currently enrolled in higher education","Don't know"]
df = BES_reduced_with_na[[redist_var,"Age"]]
df[income_var] = BES_Panel[income_var].replace(gross_household_replace_dict)


ed_vars = list(BES_Panel[ed_var].cat.categories)
# ed_vars.remove(drop_var)
ed_vars = [x for x in ed_vars if x not in drop_var]
df[ed_vars] = pd.get_dummies(BES_Panel[ed_var],drop_first=False).drop(drop_var,axis=1)

df = df.dropna()
X = df[ed_vars+[income_var,"Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.037
# Model:                                       OLS   Adj. R-squared:                  0.037
# Method:                            Least Squares   F-statistic:                     284.0
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):          4.68e-240
# Time:                                   16:51:57   Log-Likelihood:                -45972.
# No. Observations:                          29627   AIC:                         9.195e+04
# Df Residuals:                              29622   BIC:                         9.200e+04
# Df Model:                                      4
# Covariance Type:                       nonrobust
# ==============================================================================================================
#                                                  coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------------------
# const                                          5.6936      0.100     57.070      0.000       5.498       5.889
# No, I have never attended higher education    -0.0336      0.017     -1.920      0.055      -0.068       0.001
# Yes, I graduated from higher education         0.0511      0.016      3.156      0.002       0.019       0.083
# profile_gross_household                       -0.3100      0.009    -33.460      0.000      -0.328      -0.292
# Age                                            0.0002      0.000      0.548      0.584      -0.001       0.001
# ==============================================================================
# Omnibus:                     2418.687   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1356.378
# Skew:                          -0.379   Prob(JB):                    2.93e-295
# Kurtosis:                       2.276   Cond. No.                         795.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"
income_var = "profile_gross_household"
ed_var = "educationW1_W6"
# drop_var = "No, I have never attended higher education"
drop_var = ["University or CNAA first degree (eg BA, B.Sc, B.Ed)"]
df = BES_reduced_with_na[[redist_var,"Age"]]
df[income_var] = BES_Panel[income_var].replace(gross_household_replace_dict)


ed_vars = list(BES_Panel[ed_var].cat.categories)
# ed_vars.remove(drop_var)
ed_vars = [x for x in ed_vars if x not in drop_var]
df[ed_vars] = pd.get_dummies(BES_Panel[ed_var],drop_first=False).drop(drop_var,axis=1)

df = df.dropna()
X = df[ed_vars+[income_var,"Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.046
# Model:                                       OLS   Adj. R-squared:                  0.046
# Method:                            Least Squares   F-statistic:                     68.46
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):          1.14e-284
# Time:                                   17:01:36   Log-Likelihood:                -45827.
# No. Observations:                          29627   AIC:                         9.170e+04
# Df Residuals:                              29605   BIC:                         9.188e+04
# Df Model:                                     21
# Covariance Type:                       nonrobust
# =========================================================================================================================
#                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# const                                                     5.8227      0.104     55.740      0.000       5.618       6.027
# No formal qualifications                                  0.0261      0.031      0.853      0.394      -0.034       0.086
# Youth training certificate/skillseekers                   0.0475      0.120      0.397      0.691      -0.187       0.282
# Recognised trade apprenticeship completed                -0.0270      0.056     -0.479      0.632      -0.138       0.084
# Clerical and commercial                                  -0.2479      0.053     -4.643      0.000      -0.353      -0.143
# City and Guild certificate                                0.0015      0.036      0.041      0.967      -0.068       0.071
# City and Guild certificate - advanced                    -0.0390      0.047     -0.829      0.407      -0.131       0.053
# onc                                                      -0.1171      0.066     -1.787      0.074      -0.246       0.011
# CSE grades 2-5                                           -0.0114      0.049     -0.232      0.816      -0.107       0.084
# CSE grade 1, GCE O level, GCSE, School Certificate       -0.1556      0.025     -6.348      0.000      -0.204      -0.108
# Scottish Ordinary/ Lower Certificate                      0.0214      0.069      0.312      0.755      -0.113       0.156
# GCE A level or Higher Certificate                        -0.1917      0.024     -8.068      0.000      -0.238      -0.145
# Scottish Higher Certificate                               0.1074      0.042      2.544      0.011       0.025       0.190
# Nursing qualification (eg SEN, SRN, SCM, RGN)            -0.0874      0.055     -1.576      0.115      -0.196       0.021
# Teaching qualification (not degree)                      -0.1405      0.050     -2.815      0.005      -0.238      -0.043
# University diploma                                       -0.0457      0.036     -1.269      0.204      -0.116       0.025
# University or CNAA higher degree (eg M.Sc, Ph.D)          0.1625      0.026      6.240      0.000       0.111       0.214
# Other technical, professional or higher qualification    -0.2043      0.024     -8.646      0.000      -0.251      -0.158
# Don't know                                               -0.0990      0.080     -1.235      0.217      -0.256       0.058
# Prefer not to say                                        -0.1297      0.076     -1.717      0.086      -0.278       0.018
# profile_gross_household                                  -0.3165      0.010    -33.093      0.000      -0.335      -0.298
# Age                                                       0.0004      0.000      0.843      0.399      -0.000       0.001
# ==============================================================================
# Omnibus:                     2221.826   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1318.668
# Skew:                          -0.381   Prob(JB):                    4.52e-287
# Kurtosis:                       2.302   Cond. No.                         969.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"
income_var = "profile_gross_household"
ed_var = "educationW1_W6"
# drop_var = "No, I have never attended higher education"
drop_var = ["University or CNAA first degree (eg BA, B.Sc, B.Ed)"]
# drop_var = ["Don't know","Prefer not to say"]
mask =((BES_Panel["Age"]>=20) & (BES_Panel["Age"]<=40)).fillna(False)
df = BES_reduced_with_na[[redist_var,"Age"]][mask]
df[income_var] = BES_Panel[income_var][mask].replace(gross_household_replace_dict)


ed_vars = list(BES_Panel[ed_var].cat.categories)
# ed_vars.remove(drop_var)
ed_vars = [x for x in ed_vars if x not in drop_var]
df[ed_vars] = pd.get_dummies(BES_Panel[ed_var][mask],drop_first=False).drop(drop_var,axis=1)

df = df.dropna()
X = df[ed_vars+[income_var,"Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.048
# Model:                                       OLS   Adj. R-squared:                  0.046
# Method:                            Least Squares   F-statistic:                     20.75
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):           4.90e-77
# Time:                                   17:16:22   Log-Likelihood:                -13352.
# No. Observations:                           8613   AIC:                         2.675e+04
# Df Residuals:                               8591   BIC:                         2.690e+04
# Df Model:                                     21
# Covariance Type:                       nonrobust
# =========================================================================================================================
#                                                             coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------------------------
# const                                                     5.5282      0.181     30.462      0.000       5.172       5.884
# No formal qualifications                                  0.0477      0.091      0.524      0.600      -0.131       0.226
# Youth training certificate/skillseekers                   0.0727      0.174      0.418      0.676      -0.268       0.413
# Recognised trade apprenticeship completed                 0.0082      0.136      0.060      0.952      -0.259       0.275
# Clerical and commercial                                  -0.1159      0.136     -0.855      0.393      -0.382       0.150
# City and Guild certificate                               -0.0470      0.082     -0.571      0.568      -0.208       0.114
# City and Guild certificate - advanced                    -0.0268      0.102     -0.263      0.793      -0.227       0.173
# onc                                                      -0.3409      0.263     -1.296      0.195      -0.856       0.175
# CSE grades 2-5                                            0.1057      0.153      0.690      0.490      -0.194       0.406
# CSE grade 1, GCE O level, GCSE, School Certificate       -0.0636      0.054     -1.177      0.239      -0.170       0.042
# Scottish Ordinary/ Lower Certificate                      0.0541      0.167      0.325      0.745      -0.272       0.381
# GCE A level or Higher Certificate                        -0.0897      0.038     -2.383      0.017      -0.163      -0.016
# Scottish Higher Certificate                               0.2346      0.073      3.214      0.001       0.092       0.378
# Nursing qualification (eg SEN, SRN, SCM, RGN)            -0.1189      0.150     -0.791      0.429      -0.413       0.176
# Teaching qualification (not degree)                       0.0155      0.132      0.117      0.907      -0.243       0.274
# University diploma                                       -0.0045      0.059     -0.078      0.938      -0.120       0.110
# University or CNAA higher degree (eg M.Sc, Ph.D)          0.1739      0.040      4.353      0.000       0.096       0.252
# Other technical, professional or higher qualification    -0.1995      0.046     -4.357      0.000      -0.289      -0.110
# Don't know                                               -0.0529      0.140     -0.377      0.706      -0.328       0.222
# Prefer not to say                                        -0.0885      0.152     -0.583      0.560      -0.386       0.209
# profile_gross_household                                  -0.3198      0.017    -18.741      0.000      -0.353      -0.286
# Age                                                       0.0084      0.002      3.997      0.000       0.004       0.013
# ==============================================================================
# Omnibus:                      685.307   Durbin-Watson:                   1.998
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              356.970
# Skew:                          -0.338   Prob(JB):                     3.05e-78
# Kurtosis:                       2.267   Cond. No.                         695.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
redist_var = "lr1W1W2W3W4W5__Strongly agree"
income_var = "profile_gross_household"
ed_var = "subjectHEW1W2W3"
# drop_var = "No, I have never attended higher education"
drop_var = ["I never attended higher education (university etc)","Other","Don't know"]
# drop_var = ["Don't know","Prefer not to say"]
# mask =((BES_Panel["Age"]>=20) & (BES_Panel["Age"]<=40)).fillna(False)
df = BES_reduced_with_na[[redist_var,"Age"]]#[mask]
df[income_var] = BES_Panel[income_var]\
                    .replace(gross_household_replace_dict)


ed_vars = list(BES_Panel[ed_var].cat.categories)
# ed_vars.remove(drop_var)
ed_vars = [x for x in ed_vars if x not in drop_var]
df[ed_vars] = pd.get_dummies(BES_Panel[ed_var]#[mask]
                             ,drop_first=False).drop(drop_var,axis=1)

df = df.dropna()
X = df[ed_vars+[income_var,"Age"]].astype('float32')
y = df[redist_var].astype('float32')

X = sm.add_constant(X)
logit_model=sm.OLS(y,X)
result=logit_model.fit()
print(result.summary())
# Out:
#                                   OLS Regression Results
# =========================================================================================
# Dep. Variable:     lr1W1W2W3W4W5__Strongly agree   R-squared:                       0.046
# Model:                                       OLS   Adj. R-squared:                  0.045
# Method:                            Least Squares   F-statistic:                     202.5
# Date:                           Fri, 10 Apr 2020   Prob (F-statistic):          8.05e-295
# Time:                                   17:31:49   Log-Likelihood:                -45837.
# No. Observations:                          29627   AIC:                         9.169e+04
# Df Residuals:                              29619   BIC:                         9.176e+04
# Df Model:                                      7
# Covariance Type:                       nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# const                                                    5.6978      0.101     56.457      0.000       5.500       5.896
# Engineering, Mathematics or Natural sciences             0.0096      0.024      0.397      0.691      -0.038       0.057
# Humanities, social sciences, psychology or education     0.3055      0.020     15.552      0.000       0.267       0.344
# Medicine                                                -0.1754      0.066     -2.655      0.008      -0.305      -0.046
# Law                                                     -0.0389      0.058     -0.666      0.505      -0.153       0.076
# Economics or business                                   -0.1138      0.030     -3.735      0.000      -0.174      -0.054
# profile_gross_household                                 -0.3137      0.009    -33.171      0.000      -0.332      -0.295
# Age                                                      0.0003      0.000      0.808      0.419      -0.000       0.001
# ==============================================================================
# Omnibus:                     2246.004   Durbin-Watson:                   1.978
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1310.161
# Skew:                          -0.376   Prob(JB):                    3.18e-285
# Kurtosis:                       2.296   Cond. No.                         812.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
BES_Panel["edlevelW1_W6"].value_counts()
drop_var = "Undergraduate"

# %%
BES_Panel["educationW1_W6"].value_counts()
drop_var = ["Don't know","Prefer not to say"]
# Out:
# University or CNAA first degree (eg BA, B.Sc, B.Ed)      8514
# GCE A level or Higher Certificate                        5556
# Other technical, professional or higher qualification    5191
# CSE grade 1, GCE O level, GCSE, School Certificate       4945
# University or CNAA higher degree (eg M.Sc, Ph.D)         3557
# No formal qualifications                                 2927
# City and Guild certificate                               1762
# University diploma                                       1624
# Scottish Higher Certificate                              1204
# City and Guild certificate - advanced                     890
# Teaching qualification (not degree)                       847
# Prefer not to say                                         836
# CSE grades 2-5                                            831
# Clerical and commercial                                   768
# Nursing qualification (eg SEN, SRN, SCM, RGN)             631
# Recognised trade apprenticeship completed                 601
# Don't know                                                493
# Scottish Ordinary/ Lower Certificate                      425
# onc                                                       423
# Youth training certificate/skillseekers                   120
# Name: educationW1_W6, dtype: int64

# %%
list( search(BES_reduced_with_na,"education").index )
# Out:
# ['changeEducationW1__Getting a lot better',
#  'changeEducationLabW1__Getting a lot better',
#  'changeEducationW2__Getting a lot better',
#  'changeEducationLabW2__Getting a lot better',
#  'changeEducationW3__Getting a lot better',
#  'changeEducationLabW3__Getting a lot better',
#  'changeEducationW4__Getting a lot better',
#  'changeEducationLabW4__Getting a lot better',
#  'changeEducationW7__Getting a lot better',
#  'changeEducationLabW7__Getting a lot better',
#  'anyUniW7__Yes, I graduated from higher education',
#  'changeEducationW8__Getting a lot better',
#  'anyUniW9__Yes, I graduated from higher education',
#  'changeEducationW10__Getting a lot better',
#  'changeEducationLabW10__Getting a lot better',
#  'anyUniW10__Yes, I graduated from higher education',
#  'changeEducationW11__Getting a lot better',
#  'anyUniW11__Yes, I graduated from higher education',
#  'changeEducationW12__Getting a lot better',
#  'changeEducationLabW12__Getting a lot better',
#  'anyUniW12__Yes, I graduated from higher education',
#  'anyUniW13__Yes, I graduated from higher education',
#  'changeEducationW14__Getting a lot better',
#  'anyUniW14__Yes, I graduated from higher education',
#  'changeEducationW15__Getting a lot better',
#  'anyUniW15__Yes, I graduated from higher education',
#  'changeEducationW16__Getting a lot better',
#  'anyUniW16__Yes, I graduated from higher education',
#  'changeEducationW17__Getting a lot better',
#  'anyUniW17__Yes, I graduated from higher education',
#  'changeEducationW18__Getting a lot better',
#  'changeEducationLabW18__Getting a lot better',
#  'anyUniW19__Yes, I graduated from higher education',
#  'profile_education_ageW7__Still at school/Full time student',
#  'profile_education_ageW13__Still at school/Full time student',
#  'profile_education_ageW18__Semi-Skilled or Unskilled Manual Work (e.g. machine operator, assembler, postman, waitress, cleaner, labourer, driver, b',
#  'profile_education_ageW19__e',
#  'profile_education_age__Still at school/Full time student',
#  'educationW1_W6_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW1_W6_GCE A level or Higher Certificate',
#  'educationW1_W6_Other technical, professional or higher qualification',
#  'educationW1_W6_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW1_W6_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW1_W6_No formal qualifications',
#  'educationW1_W6_City and Guild certificate',
#  'educationW1_W6_University diploma',
#  'educationW1_W6_Scottish Higher Certificate',
#  'educationW1_W6_City and Guild certificate - advanced',
#  'educationW1_W6_Teaching qualification (not degree)',
#  'educationW1_W6_CSE grades 2-5',
#  'educationW1_W6_Clerical and commercial',
#  'educationW1_W6_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW1_W6_Recognised trade apprenticeship completed',
#  'educationW1_W6_Scottish Ordinary/ Lower Certificate',
#  'educationW1_W6_onc',
#  'educationW1_W6_Youth training certificate/skillseekers',
#  'spendMost4W2_Education',
#  'spendLeast4W2_Education',
#  'spendMost5W2_Education',
#  'spendLeast5W2_Education',
#  'spendMost6W2_Education',
#  'spendLeast6W2_Education',
#  'educationW2_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW2_Other technical, professional or higher qualification',
#  'educationW2_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW2_GCE A level or Higher Certificate',
#  'educationW2_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW2_No formal qualifications',
#  'educationW2_City and Guild certificate',
#  'educationW2_University diploma',
#  'educationW2_Scottish Higher Certificate',
#  'educationW2_Teaching qualification (not degree)',
#  'educationW2_Clerical and commercial',
#  'educationW2_City and Guild certificate - advanced',
#  'educationW2_CSE grades 2-5',
#  'educationW2_Recognised trade apprenticeship completed',
#  'educationW2_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW2_onc',
#  'educationW2_Scottish Ordinary/ Lower Certificate',
#  'educationW2_Youth training certificate/skillseekers',
#  'spendMost4W3_Education',
#  'spendLeast4W3_Education',
#  'spendMost5W3_Education',
#  'spendLeast5W3_Education',
#  'spendMost6W3_Education',
#  'spendLeast6W3_Education',
#  'educationW3_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW3_Other technical, professional or higher qualification',
#  'educationW3_GCE A level or Higher Certificate',
#  'educationW3_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW3_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW3_No formal qualifications',
#  'educationW3_City and Guild certificate',
#  'educationW3_University diploma',
#  'educationW3_Scottish Higher Certificate',
#  'educationW3_Teaching qualification (not degree)',
#  'educationW3_City and Guild certificate - advanced',
#  'educationW3_CSE grades 2-5',
#  'educationW3_Clerical and commercial',
#  'educationW3_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW3_Recognised trade apprenticeship completed',
#  'educationW3_onc',
#  'educationW3_Scottish Ordinary/ Lower Certificate',
#  'educationW3_Youth training certificate/skillseekers',
#  'educationW4_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW4_GCE A level or Higher Certificate',
#  'educationW4_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW4_Other technical, professional or higher qualification',
#  'educationW4_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW4_No formal qualifications',
#  'educationW4_City and Guild certificate',
#  'educationW4_University diploma',
#  'educationW4_Scottish Higher Certificate',
#  'educationW4_City and Guild certificate - advanced',
#  'educationW4_CSE grades 2-5',
#  'educationW4_Teaching qualification (not degree)',
#  'educationW4_Clerical and commercial',
#  'educationW4_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW4_Recognised trade apprenticeship completed',
#  'educationW4_onc',
#  'educationW4_Scottish Ordinary/ Lower Certificate',
#  'educationW4_Youth training certificate/skillseekers',
#  'educationW6_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW6_Other technical, professional or higher qualification',
#  'educationW6_GCE A level or Higher Certificate',
#  'educationW6_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW6_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW6_No formal qualifications',
#  'educationW6_City and Guild certificate',
#  'educationW6_University diploma',
#  'educationW6_Scottish Higher Certificate',
#  'educationW6_City and Guild certificate - advanced',
#  'educationW6_Teaching qualification (not degree)',
#  'educationW6_CSE grades 2-5',
#  'educationW6_Clerical and commercial',
#  'educationW6_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW6_Recognised trade apprenticeship completed',
#  'educationW6_onc',
#  'educationW6_Scottish Ordinary/ Lower Certificate',
#  'educationW6_Youth training certificate/skillseekers',
#  'educationW7_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW7_GCE A level or Higher Certificate',
#  'educationW7_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW7_Other technical, professional or higher qualification',
#  'educationW7_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW7_No formal qualifications',
#  'educationW7_City and Guild certificate',
#  'educationW7_University diploma',
#  'educationW7_City and Guild certificate - advanced',
#  'educationW7_Scottish Higher Certificate',
#  'educationW7_Teaching qualification (not degree)',
#  'educationW7_CSE grades 2-5',
#  'educationW7_Clerical and commercial',
#  'educationW7_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW7_Recognised trade apprenticeship completed',
#  'educationW7_onc',
#  'educationW7_Scottish Ordinary/ Lower Certificate',
#  'educationW7_Youth training certificate/skillseekers',
#  'educationW8W9W10_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW8W9W10_GCE A level or Higher Certificate',
#  'educationW8W9W10_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW8W9W10_Other technical, professional or higher qualification',
#  'educationW8W9W10_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW8W9W10_No formal qualifications',
#  'educationW8W9W10_City and Guild certificate',
#  'educationW8W9W10_University diploma',
#  'educationW8W9W10_City and Guild certificate - advanced',
#  'educationW8W9W10_Teaching qualification (not degree)',
#  'educationW8W9W10_CSE grades 2-5',
#  'educationW8W9W10_Scottish Higher Certificate',
#  'educationW8W9W10_Clerical and commercial',
#  'educationW8W9W10_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW8W9W10_Recognised trade apprenticeship completed',
#  'educationW8W9W10_onc',
#  'educationW8W9W10_Scottish Ordinary/ Lower Certificate',
#  'educationW8W9W10_Youth training certificate/skillseekers',
#  'educationW9_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW9_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW9_GCE A level or Higher Certificate',
#  'educationW9_Other technical, professional or higher qualification',
#  'educationW9_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW9_No formal qualifications',
#  'educationW9_City and Guild certificate',
#  'educationW9_University diploma',
#  'educationW9_City and Guild certificate - advanced',
#  'educationW9_Teaching qualification (not degree)',
#  'educationW9_CSE grades 2-5',
#  'educationW9_Scottish Higher Certificate',
#  'educationW9_Clerical and commercial',
#  'educationW9_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW9_Recognised trade apprenticeship completed',
#  'educationW9_onc',
#  'educationW9_Scottish Ordinary/ Lower Certificate',
#  'educationW9_Youth training certificate/skillseekers',
#  'educationW11_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW11_GCE A level or Higher Certificate',
#  'educationW11_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW11_Other technical, professional or higher qualification',
#  'educationW11_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW11_No formal qualifications',
#  'educationW11_City and Guild certificate',
#  'educationW11_University diploma',
#  'educationW11_City and Guild certificate - advanced',
#  'educationW11_Teaching qualification (not degree)',
#  'educationW11_Scottish Higher Certificate',
#  'educationW11_CSE grades 2-5',
#  'educationW11_Clerical and commercial',
#  'educationW11_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW11_Recognised trade apprenticeship completed',
#  'educationW11_onc',
#  'educationW11_Scottish Ordinary/ Lower Certificate',
#  'educationW11_Youth training certificate/skillseekers',
#  'educationW12_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW12_GCE A level or Higher Certificate',
#  'educationW12_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW12_Other technical, professional or higher qualification',
#  'educationW12_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW12_No formal qualifications',
#  'educationW12_City and Guild certificate',
#  'educationW12_University diploma',
#  'educationW12_City and Guild certificate - advanced',
#  'educationW12_Teaching qualification (not degree)',
#  'educationW12_Scottish Higher Certificate',
#  'educationW12_CSE grades 2-5',
#  'educationW12_Clerical and commercial',
#  'educationW12_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW12_Recognised trade apprenticeship completed',
#  'educationW12_onc',
#  'educationW12_Scottish Ordinary/ Lower Certificate',
#  'educationW12_Youth training certificate/skillseekers',
#  'educationW13_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW13_GCE A level or Higher Certificate',
#  'educationW13_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW13_Other technical, professional or higher qualification',
#  'educationW13_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW13_No formal qualifications',
#  'educationW13_City and Guild certificate',
#  'educationW13_University diploma',
#  'educationW13_City and Guild certificate - advanced',
#  'educationW13_Teaching qualification (not degree)',
#  'educationW13_CSE grades 2-5',
#  'educationW13_Scottish Higher Certificate',
#  'educationW13_Clerical and commercial',
#  'educationW13_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW13_Recognised trade apprenticeship completed',
#  'educationW13_onc',
#  'educationW13_Scottish Ordinary/ Lower Certificate',
#  'educationW13_Youth training certificate/skillseekers',
#  'educationW14_University or CNAA first degree (e.g. BA, B.Sc, B.Ed)',
#  'educationW14_GCE A level or Higher Certificate',
#  'educationW14_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW14_Other technical, professional or higher qualification',
#  'educationW14_University or CNAA higher degree (e.g. M.Sc, Ph.D)',
#  'educationW14_No formal qualifications',
#  'educationW14_City & Guilds certificate',
#  'educationW14_University diploma',
#  'educationW14_City & Guilds certificate - advanced',
#  'educationW14_Teaching qualification (not degree)',
#  'educationW14_CSE grades 2-5',
#  'educationW14_Scottish Higher Certificate',
#  'educationW14_Clerical and commercial',
#  'educationW14_Nursing qualification (e.g. SEN, SRN, SCM, RGN)',
#  'educationW14_Recognised trade apprenticeship completed',
#  'educationW14_ONC',
#  'educationW14_Scottish Ordinary/ Lower Certificate',
#  'educationW14_Youth training certificate/skillseekers',
#  'educationW15_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW15_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW15_GCE A level or Higher Certificate',
#  'educationW15_Other technical, professional or higher qualification',
#  'educationW15_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW15_No formal qualifications',
#  'educationW15_City and Guild certificate',
#  'educationW15_University diploma',
#  'educationW15_City and Guild certificate - advanced',
#  'educationW15_Teaching qualification (not degree)',
#  'educationW15_CSE grades 2-5',
#  'educationW15_Clerical and commercial',
#  'educationW15_Scottish Higher Certificate',
#  'educationW15_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW15_Recognised trade apprenticeship completed',
#  'educationW15_onc',
#  'educationW15_Scottish Ordinary/ Lower Certificate',
#  'educationW15_Youth training certificate/skillseekers',
#  'subjectHEW15_Humanities, social sciences, psychology or education',
#  'subjectHEW15_I never attended higher education (university etc)',
#  'subjectHECurrentW15_Humanities, social sciences, psychology or education',
#  'educationW16_University or CNAA first degree (eg BA, B.Sc, B.Ed)',
#  'educationW16_GCE A level or Higher Certificate',
#  'educationW16_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW16_Other technical, professional or higher qualification',
#  'educationW16_University or CNAA higher degree (eg M.Sc, Ph.D)',
#  'educationW16_No formal qualifications',
#  'educationW16_City and Guild certificate',
#  'educationW16_University diploma',
#  'educationW16_City and Guild certificate - advanced',
#  'educationW16_Teaching qualification (not degree)',
#  'educationW16_CSE grades 2-5',
#  'educationW16_Clerical and commercial',
#  'educationW16_Scottish Higher Certificate',
#  'educationW16_Nursing qualification (eg SEN, SRN, SCM, RGN)',
#  'educationW16_Recognised trade apprenticeship completed',
#  'educationW16_onc',
#  'educationW16_Scottish Ordinary/ Lower Certificate',
#  'educationW16_Youth training certificate/skillseekers',
#  'subjectHEW16_Humanities, social sciences, psychology or education',
#  'subjectHEW16_I never attended higher education (university etc)',
#  'subjectHECurrentW16_Humanities, social sciences, psychology or education',
#  'educationW17_16.0',
#  'educationW17_South West',
#  'educationW17_Scotland',
#  'educationW17_18.0',
#  'educationW17_17.0',
#  'educationW17_North East',
#  'educationW17_West Midlands',
#  'educationW17_15.0',
#  'educationW17_20.0',
#  'educationW17_East of England',
#  'educationW17_14.0',
#  'educationW17_South East',
#  'educationW17_East Midlands',
#  'educationW17_Northern Ireland',
#  'educationW17_Non UK & Invalid',
#  'educationW17_19.0',
#  'educationW17_Yorkshire and the Humber',
#  'educationW17_London',
#  'educationW17_Wales',
#  'educationW17_North West',
#  'educationW18_University or CNAA first degree (e.g. BA, B.Sc, B.Ed)',
#  'educationW18_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW18_Other technical, professional or higher qualification',
#  'educationW18_GCE A level or Higher Certificate',
#  'educationW18_University or CNAA higher degree (e.g. M.Sc, Ph.D)',
#  'educationW18_No formal qualifications',
#  'educationW18_City & Guilds certificate',
#  'educationW18_University diploma',
#  'educationW18_City & Guilds certificate - advanced',
#  'educationW18_Teaching qualification (not degree)',
#  'educationW18_CSE grades 2-5',
#  'educationW18_Clerical and commercial',
#  'educationW18_Nursing qualification (e.g. SEN, SRN, SCM, RGN)',
#  'educationW18_Scottish Higher Certificate',
#  'educationW18_Recognised trade apprenticeship completed',
#  'educationW18_onc',
#  'educationW18_Scottish Ordinary/ Lower Certificate',
#  'educationW18_Youth training certificate/skillseekers',
#  'educationW19_University or CNAA first degree (e.g. BA, B.Sc, B.Ed)',
#  'educationW19_CSE grade 1, GCE O level, GCSE, School Certificate',
#  'educationW19_GCE A level or Higher Certificate',
#  'educationW19_Other technical, professional or higher qualification',
#  'educationW19_University or CNAA higher degree (e.g. M.Sc, Ph.D)',
#  'educationW19_No formal qualifications',
#  'educationW19_City & Guilds certificate',
#  'educationW19_University diploma',
#  'educationW19_City & Guilds certificate - advanced',
#  'educationW19_Teaching qualification (not degree)',
#  'educationW19_CSE grades 2-5',
#  'educationW19_Clerical and commercial',
#  'educationW19_Nursing qualification (e.g. SEN, SRN, SCM, RGN)',
#  'educationW19_Scottish Higher Certificate',
#  'educationW19_Recognised trade apprenticeship completed',
#  'educationW19_onc',
#  'educationW19_Scottish Ordinary/ Lower Certificate',
#  'educationW19_Youth training certificate/skillseekers',
#  'JACS_subject_labelW19_Education',
#  'subjectHEW1W2W3_Humanities, social sciences, psychology or education',
#  'subjectHEW1W2W3_I never attended higher education (university etc)',
#  'subjectHECurrentW1W2W3_Humanities, social sciences, psychology or education',
#  'mii_catW5_education',
#  'mii_catW2_education',
#  'mii_catW4_education',
#  'mii_catW9_education',
#  'mii_catW7_education',
#  'mii_catW8_education',
#  'mii_catW1_education',
#  'mii_catW6_education',
#  'mii_catW11_education',
#  'mii_catW12_education',
#  'mii_catW13_education',
#  'mii_catW3_education',
#  'mii_catW10_education',
#  'profile_work_industryW14_Education',
#  'profile_work_industryW18_Education',
#  'profile_work_industryW19_Education',
#  'responsibleEducationConW3_Yes',
#  'responsibleEducationLDW3_Yes',
#  'responsibleEducationLabW3_Yes',
#  'responsibleEducationDontKnowW3_Yes',
#  'responsibleEducationNoneW3_Yes',
#  'responsibleEducationWelshGovtW3_Yes',
#  'responsibleEducationScotGovtW3_Yes',
#  'responsibleEducationDontKnowW1_Yes',
#  'responsibleEducationNoneW1_Yes',
#  'responsibleEducationWelshGovtW1_Yes',
#  'responsibleEducationScotGovtW1_Yes',
#  'responsibleEducationLabW1_Yes',
#  'responsibleEducationLDW1_Yes',
#  'responsibleEducationConW1_Yes',
#  'responsibleEducationDontKnowW4_Yes',
#  'responsibleEducationNoneW4_Yes',
#  'responsibleEducationConW4_Yes',
#  'responsibleEducationLDW4_Yes',
#  'responsibleEducationLabW4_Yes',
#  'responsibleEducationScotGovtW4_Yes',
#  'responsibleEducationWelshGovtW4_Yes',
#  'responsibleEducationLDW2_Yes',
#  'responsibleEducationWelshGovtW2_Yes',
#  'responsibleEducationNoneW2_Yes',
#  'responsibleEducationDontKnowW2_Yes',
#  'responsibleEducationConW2_Yes',
#  'responsibleEducationLabW2_Yes',
#  'responsibleEducationScotGovtW2_Yes']

# %%
search(BES_Panel,"anyUni")
BES_Panel["anyUniW7"].value_counts()
drop_var = ["Yes, but I didn't complete higher education","Yes, I am currently enrolled in higher education","Don't know"]
# Out:
# Yes, I graduated from higher education              13744
# No, I have never attended higher education          12117
# Yes, but I didn't complete higher education          2211
# Yes, I am currently enrolled in higher education     1953
# Don't know                                            870
# Name: anyUniW7, dtype: int64

# %%
search(BES_Panel,"Sexuality")
# Out:
# sexualityW14             7801
# sexualityW17            34025
# profile_sexualityW10    30237
# dtype: int64

# %%
BES_Panel[search(BES_Panel,"disability").index]
# BES_Panel["subjectHEW1W2W3"].value_counts()
# Out:
#       disabilityW6       disabilityW14 disabilityW19          disability
# 0              Yes                 NaN           Yes  Yes, limited a lot
# 1              NaN                 NaN            No                  No
# 2              NaN                 NaN            No                 NaN
# 3               No                 NaN           Yes                  No
# 4              NaN  Yes, limited a lot            No                 NaN
# ...            ...                 ...           ...                 ...
# 97153          Yes                 NaN           NaN                  No
# 97154           No                 NaN           NaN                  No
# 97155          NaN                 NaN           NaN                  No
# 97156          NaN                 NaN           NaN                 NaN
# 97157          NaN                 NaN           NaN                  No
#
# [97158 rows x 4 columns]

# %%
search(BES_Panel,"paperdays")
# Out:
# paperDays_1_1W18       1385
# paperDays_1_2W18       1385
# paperDays_1_3W18       1385
# paperDays_1_111W18     1385
# paperDays_2_1W18       6006
#                        ...
# paperDays_18_111W18    1232
# paperDays_19_1W18      1656
# paperDays_19_2W18      1656
# paperDays_19_3W18      1656
# paperDays_19_111W18    1656
# Length: 76, dtype: int64

# %%
search(BES_Panel,"paperslast")
# Out:
# papersLastThree_multiple_99W18    17749
# dtype: int64

# %%
BES_Panel["motherCountryBornW8"].cat.categories
# Out:
# Index(['UK', 'EU: pre-2004', 'EU: post-2004', 'European outside EU', 'Africa',
#        'East Asia', 'South-East/Central Asia', 'South Asia', 'North America',
#        'Caribbean/Central America', 'South America', 'Oceania & Antarctica',
#        'Middle East', 'Not coded'],
#       dtype='object')

# %%
search(BES_Panel,"motherCountry")
# Out:
# motherCountryBornW8    24295
# dtype: int64

# %%
match(BES_Panel,"country")
# Out:
# countryOfBirth                 36842
# abroadCountry_1W8               5258
# abroadCountry_2W8               5258
# motherCountryBornW8            24295
# fatherCountryBornW8            24295
# automationEffectsCountryW16     9330
# countryOfBirthW17              34366
# countryW1                      30382
# countryW2                      30467
# countryW3                      27052
# countryW5                      31039
# countryW6                      29446
# countryW7                      32251
# countryW8                      33505
# countryW9                      30173
# countryW10                     32830
# countryW11                     33374
# countryW12                     36948
# countryW13                     33140
# countryW14                     32697
# countryW15                     31028
# countryW16                     39471
# countryW17                     34366
# countryW19                     32205
# dtype: int64

# %%
match(BES_reduced_with_na,"country")
# Out:
# countryOfBirth_England                                 36570
# countryOfBirth_Scotland                                36570
# countryOfBirth_Wales                                   36570
# countryOfBirth_Other: European Union member country    36570
# countryOfBirth_Other: Rest of world                    36570
#                                                        ...
# countryW17_Scotland                                    34366
# countryW17_Wales                                       34366
# countryW19_English                                     32205
# countryW19_Scotland                                    32205
# countryW19_Wales                                       32205
# Length: 67, dtype: int64
