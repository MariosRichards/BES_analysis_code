# %%
### Trying to get a separate sense of
### <Political Compass Distance Like Party/Politican Factor> vs <Competence/Valence Like Party/Politician Factor>



### (1) Look at slices of like<Party> along political compass axes for different waves
# (where you think the party/voters haven't moved much

# %%
# %%time
dataset_name = "W25_comb"
df_list = "BES_Panel"

# %matplotlib inline 
# %run BES_header.py {dataset_name} {df_list}

global BES_label_list, BES_df_list
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# var_type (10365, 13)
# Wall time: 7min 3s

# %%
search(BES_Panel,"likeBNP|likeUKIP|likeBXP|likeBrexit")
# Out:
# likeUKIPW1            15332
# likeBNPW1             15322
# likeUKIPW2            15364
# likeBNPW2             15353
# likeUKIPW3            13854
# likeBNPW3             13854
# likeUKIPW4            15695
# likeBNPW4             15695
# likeUKIPW5            15443
# likeBNPW5             15443
# likeUKIPW6            15008
# likeBNPW6             15008
# likeUKIPW7            30895
# likeUKIPW8            33502
# likeUKIPW9            30036
# likeUKIPW10           30237
# likeUKIPW11           30956
# likeUKIPW12           34394
# likeUKIPW13           31135
# likeUKIPW14           31063
# likeUKIPW15           30842
# likeBrexitPartyW15    30842
# likeUKIPW16           37959
# likeBrexitPartyW16    37959
# likeBrexitPartyW17    34366
# likeUKIPW17           34366
# likeBrexitPartyW18    37825
# likeUKIPW18           37825
# likeBrexitPartyW19    32177
# likeBrexitPartyW20    31468
# likeBrexitPartyW21    30281
# likeBrexitPartyW22    28113
# likeBrexitPartyW23    30949
# ...

# %%
search(BES_Panel,"al_scale|lr_scale|likeCon")
# Out:
# likeConW1          15335
# likeConW2          15369
# likeConW3          13854
# likeConW4          15695
# likeConW5          15443
# likeConW6          15008
# likeConW7          30895
# likeConW8          33502
# likeConW9          30036
# likeConW10         30237
# likeConW11         30956
# likeConW12         34394
# likeConW13         31135
# likeConW14         31063
# likeConW15         30842
# likeConW16         37959
# likeConW17         34366
# likeConW18         37825
# likeConW19         32177
# likeConW20         31468
# likeConW21         30281
# likeConW22         28113
# likeConW23         30949
# likeConW24         15405
# likeConW25         30407
# lr_scaleW1_W5      38859
# al_scaleW1_W5      38260
# lr_scaleW6         27819
# al_scaleW6         27288
# lr_scaleW7_W9      36472
# al_scaleW7_W9      35873
# lr_scaleW10_W12    30352
# al_scaleW10_W12    30088
# lr_scaleW13        28064
# al_scaleW13        27252
# lr_scaleW14W15     32385
# al_scaleW14W15     31629
# ...

# %%
# likeConW13         31135,lr_scaleW13        28064,al_scaleW13        27252

# %%
al_scale = BES_Panel["al_scaleW13"].cat.codes.replace(-1,np.nan)
lr_scale = BES_Panel["lr_scaleW13"].cat.codes.replace(-1,np.nan)
likeCon  = BES_Panel["likeConW13"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLab  = BES_Panel["likeLabW13"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
mask = al_scale.notnull()&lr_scale.notnull()&likeCon.notnull()
print(mask.sum())
# Out:
# 25197

# %%
al_scaleW25 = BES_Panel["al_scaleW25"].cat.codes.replace(-1,np.nan)
lr_scaleW25 = BES_Panel["lr_scaleW25"].cat.codes.replace(-1,np.nan)
likeConW25  = BES_Panel["likeConW25"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLabW25  = BES_Panel["likeLabW25"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
maskW25 = al_scaleW25.notnull()&lr_scaleW25.notnull()&likeConW25.notnull()
print(maskW25.sum())
# Out:
# 23898

# %%
al_scaleW17 = BES_Panel["al_scaleW17_W19"].cat.codes.replace(-1,np.nan)
lr_scaleW17 = BES_Panel["lr_scaleW17_W19"].cat.codes.replace(-1,np.nan)
likeConW17  = BES_Panel["likeConW17"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLabW17  = BES_Panel["likeLabW17"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
maskW17 = al_scaleW17.notnull()&lr_scaleW17.notnull()&likeConW17.notnull()
print(maskW17.sum())
# Out:
# 27155

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
sns.lineplot(x=al_scale[mask&(lr_scale==10)],y=likeCon[mask&(lr_scale==10)],ax=ax1,c='r');
ax1.set_ylim([0,10]);
sns.lineplot(x=lr_scale[mask&(al_scale==10)],y=likeCon[mask&(al_scale==10)],ax=ax2,c='b');
ax2.set_ylim([0,10]);

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
sns.lineplot(x=al_scaleW17[maskW17&(lr_scaleW17==10)],y=likeConW17[maskW17&(lr_scaleW17==10)],ax=ax1,c='r');
ax1.set_ylim([0,10]);
sns.lineplot(x=lr_scaleW17[maskW17&(al_scaleW17==10)],y=likeConW17[maskW17&(al_scaleW17==10)],ax=ax2,c='b');
ax2.set_ylim([0,10]);

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
sns.lineplot(x=al_scaleW25[maskW25&(lr_scaleW25==10)],y=likeConW25[maskW25&(lr_scaleW25==10)],ax=ax1,c='r');
ax1.set_ylim([0,10]);
sns.lineplot(x=lr_scaleW25[maskW25&(al_scaleW25==10)],y=likeConW25[maskW25&(al_scaleW25==10)],ax=ax2,c='b');
ax2.set_ylim([0,10]);

# %%
### lazy option - fit a line to these trends

# %%
al_scaleW5 = BES_Panel["al_scaleW1_W5"].cat.codes.replace(-1,np.nan)
lr_scaleW5 = BES_Panel["lr_scaleW1_W5"].cat.codes.replace(-1,np.nan)
likeConW5  = BES_Panel["likeConW5"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLabW5  = BES_Panel["likeLabW5"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeBNPW5  = BES_Panel["likeBNPW5"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeUKIPW5  = BES_Panel["likeUKIPW5"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
maskW5 = al_scaleW5.notnull()&lr_scaleW5.notnull()&likeConW5.notnull()
print(maskW5.sum())
# Out:
# 12984

# %%
fig, (ax1, ax2,ax3,ax4) = plt.subplots(4, 1,)
sns.lineplot(x=al_scaleW5[(lr_scaleW5==10)],y=likeLabW5[(lr_scaleW5==10)],ax=ax1,c='r');
ax1.set_ylim([0,10]);
sns.lineplot(x=al_scaleW5[(lr_scaleW5==10)],y=likeConW5[(lr_scaleW5==10)],ax=ax2,c='b');
ax2.set_ylim([0,10]);
sns.lineplot(x=al_scaleW5[(lr_scaleW5==10)],y=likeUKIPW5[(lr_scaleW5==10)],ax=ax3,c='m');
ax3.set_ylim([0,10]);
sns.lineplot(x=al_scaleW5[(lr_scaleW5==10)],y=likeBNPW5[(lr_scaleW5==10)],ax=ax4,c='k');
ax4.set_ylim([0,10]);

# %%
al_scaleW16 = BES_Panel["al_scaleW16"].cat.codes.replace(-1,np.nan)
lr_scaleW16 = BES_Panel["lr_scaleW16"].cat.codes.replace(-1,np.nan)
likeConW16  = BES_Panel["likeConW16"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeLabW16  = BES_Panel["likeLabW16"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeBXPW16  = BES_Panel["likeBrexitPartyW16"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
likeUKIPW16  = BES_Panel["likeUKIPW16"].replace("Don't know",np.nan).cat.codes.replace(-1,np.nan)
maskW16 = al_scaleW16.notnull()&lr_scaleW16.notnull()&likeConW16.notnull()
print(maskW16.sum())

fig, (ax1, ax2,ax3,ax4) = plt.subplots(4, 1,sharex=True)
val_mask = lr_scaleW16==10
val_ser = al_scaleW16
sns.lineplot(x=val_ser[val_mask],y=likeLabW16[val_mask],ax=ax1,c='r');
ax1.set_ylim([0,10]);
sns.lineplot(x=val_ser[val_mask],y=likeConW16[val_mask],ax=ax2,c='b');
ax2.set_ylim([0,10]);
sns.lineplot(x=val_ser[val_mask],y=likeUKIPW16[val_mask],ax=ax3,c='m');
ax3.set_ylim([0,10]);
sns.lineplot(x=val_ser[val_mask],y=likeBXPW16[val_mask],ax=ax4,c='k');
ax4.set_ylim([0,10]);
# Out:
# 29603
