# %%
# %%time
dataset_name = None
df_list = None
# %matplotlib inline
# %run BES_header.py {dataset_name} {df_list}
# (var_type, cat_dictionary, new_old_col_names, old_new_col_names) = get_small_files(data_subfolder, encoding)

# pan_dataset_allr_values = pd.read_pickle(BES_small_data_files + "pan_dataset_allr_valuesW19"+".zip",compression='zip')
# pan_dataset_ages = pd.read_pickle(BES_small_data_files + "pan_dataset_ages"+".zip", compression='zip')
# pan_dataset_votes = pd.read_pickle(BES_small_data_files+"pan_dataset_votes"+".zip",compression='zip')
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Documents\GitHub\BES_analysis\BES_analysis_code\BES_header.py in <module>
#      47
#      48 (manifest, dataset_filename, dataset_description, dataset_citation,
# ---> 49  dataset_start, dataset_stop, dataset_wave) = get_manifest(dataset_name, BES_file_manifest)
#      50
#      51 for df in df_list:
#
# ~\Documents\GitHub\BES_analysis\BES_analysis_code\utility.py in get_manifest(dataset_name, BES_file_manifest)
#     215 def get_manifest(dataset_name, BES_file_manifest):
#     216     manifest = BES_file_manifest[ BES_file_manifest["Name"] == dataset_name ]
# ...

# %%
BES_Panel = pd.read_stata( BES_data_folder+"W20_only"+os.sep+"BES2019_W20_v0.1-3.dta" )

# %%
list(BES_Panel.columns)
# Out:
# ['id',
#  'starttime',
#  'endtime',
#  'wt',
#  'turnoutUKGeneral',
#  'generalElectionVote',
#  'partyIdStrength',
#  'partyId',
#  'partyIdSqueeze',
#  'mii',
#  'bestOnMII',
#  'polAttention',
#  'pidWeThey',
#  'pidInterestedOthers',
#  'pidCriticiseParty',
#  'pidCommonParty',
#  'pidRuinDay',
#  'pidConnected',
#  'pidMyParty',
#  'pidPraiseGood',
#  'likeJohnson',
#  'likeStarmer',
#  'likeDavey',
#  'likeSturgeon',
#  'likePrice',
#  'likeFarage',
#  'likeBartley',
#  'likeBerry',
#  'infoSourceTV',
#  'infoSourcePaper',
#  'infoSourceRadio',
#  'infoSourceInternet',
#  'likeCon',
#  'likeLab',
#  'likeLD',
#  'likeSNP',
#  'likePC',
#  'likeBrexitParty',
#  'likeGrn',
#  'riskPoverty',
#  'riskUnemployment',
#  'goodTimePurchase',
#  'econPersonalRetro',
#  'econGenRetro',
#  'econPersonalProsp',
#  'econGenProsp',
#  'EUIntegrationSelf',
#  'EUIntegrationCon',
#  'EUIntegrationLab',
#  'EUIntegrationLD',
#  'EUIntegrationSNP',
#  'EUIntegrationPC',
# ...

# %%
BES_Panel.dtypes.value_counts().head(50)
# Out:
# category          133
# category           25
# category           24
# category           15
# category           14
# category           13
# category           10
# category            9
# category            8
# category            8
# category            8
# category            8
# category            7
# category            7
# category            7
# category            6
# category            6
# category            5
# category            5
# category            4
# category            4
# float64             4
# category            3
# category            3
# datetime64[ns]      3
# category            3
# category            3
# category            3
# category            3
# category            3
# category            2
# category            2
# category            2
# category            2
# category            2
# category            2
# category            2
# category            2
# category            2
# category            1
# category            1
# ...

# %%
BES_Panel.select_dtypes('int')
# Out:
#           id
# 0      73834
# 1      30819
# 2      85683
# 3      88493
# 4      70377
# ...      ...
# 31463  98618
# 31464  76606
# 31465  71245
# 31466  57289
# 31467  60225
#
# [31468 rows x 1 columns]

# %%
BES_Panel.select_dtypes('float64')
# Out:
#              wt  jobzone   pano  country
# 0      0.491959      2.0    1.0      3.0
# 1      0.697966      3.0    1.0      3.0
# 2      0.336462      3.0    1.0      NaN
# 3      0.692304      NaN    1.0      NaN
# 4      0.378309      4.0    1.0      3.0
# ...         ...      ...    ...      ...
# 31463  3.096918      3.0  650.0      NaN
# 31464  0.704609      3.0  650.0      NaN
# 31465  0.891473      NaN  650.0      1.0
# 31466  0.406014      NaN    NaN      NaN
# 31467  0.849900      NaN    NaN      1.0
#
# [31468 rows x 4 columns]

# %%
BES_Panel.select_dtypes('datetime64[ns]')
# Out:
#                     starttime                 endtime   respdate
# 0     2020-06-14 08:38:23.516 2020-06-14 09:19:45.511 2020-06-14
# 1     2020-06-06 14:10:13.553 2020-06-06 16:07:33.552 2020-06-06
# 2     2020-06-11 20:11:45.718 2020-06-11 21:10:40.393 2020-06-11
# 3     2020-06-21 14:53:19.797 2020-06-21 15:21:12.316 2020-06-21
# 4     2020-06-04 21:51:07.482 2020-06-04 22:09:16.629 2020-06-04
# ...                       ...                     ...        ...
# 31463 2020-06-20 11:10:33.140 2020-06-20 11:27:05.695 2020-06-20
# 31464 2020-06-04 17:06:34.248 2020-06-04 17:28:44.602 2020-06-04
# 31465 2020-06-16 21:06:15.459 2020-06-16 21:20:50.883 2020-06-16
# 31466 2020-06-05 15:06:41.754 2020-06-05 15:31:30.633 2020-06-05
# 31467 2020-06-16 10:54:28.712 2020-06-16 11:19:31.872 2020-06-16
#
# [31468 rows x 3 columns]

# %%
BES_Panel.to_pickle( BES_data_folder+"W20_only"+os.sep+"BES2019_W20_v0.1-3.zip" , compression = 'zip' )
